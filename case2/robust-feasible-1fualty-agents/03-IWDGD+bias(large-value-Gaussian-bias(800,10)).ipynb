# %% [raw]
# 基于初始化的权重梯度下降无中心资源分配算法+部分用户的梯度计算有误差（设备损坏导致的计算误差）

# %% [raw]
# 服从大值高斯分布的噪声

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(54,2000), dtype=np.float64) #100个agent的资源量 定义成一个矩阵
sum_resource=np.zeros(shape=(1,2000), dtype=np.float64)#存放每一次迭代后所有用户资源量的总和
sum_cost=np.zeros(shape=(1,2000), dtype=np.float64)#存放每一次迭代后所有用户成本的总和
iteration_update = 1 #迭代步长 
A=np.loadtxt("Adjacency_Matrix_generator_zero.txt") #网络拓扑的邻接矩阵 对角元素要为0
D=np.zeros(shape=(54,54))# 网络的度矩阵
L=np.zeros(shape=(54,54))# 网络的拉普拉斯矩阵 L=D-A
W=np.zeros(shape=(54,54)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
iteration=[]#绘图横坐标
generator_a_values= np.loadtxt("generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("generator_b_values.txt")#每个agent的成本函数中的超参数b
generator_c_values= np.loadtxt("generator_c_values.txt")#每个agent的成本函数中的超参数c
agent_gradient=np.zeros(shape=(54,2000), dtype=np.float64)  
bias=np.loadtxt("2000_Gaussian_distribution_(800,10).txt")

# %%
#根据邻接矩阵生成网络对应的度矩阵
for i in range(0,54):
    d=0
    for j in range(0,54):
        if A[i][j]==1:
            d=d+1
    D[i][i]=d

#根据邻接矩阵和度矩阵计算拉普拉斯矩阵
L=D-A

#选择用拉普拉斯矩阵作为聚合矩阵
W=L
    
#资源量的初始化 需要给定可行的初始化 即满足平均资源约束
for i in range (0,54):
    agent_resource_quantity[i][0]=6000/54
    
#总资源量 初始化
sum=0
for i in range (0,54):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

iteration.append(0)

#初始梯度计算 随机选择一个用户作为biased 用户
for i in range (0,54):
    if i==48:
        agent_gradient[i][0]=2*generator_c_values[i]*agent_resource_quantity[i][0]+generator_b_values[i]+bias[0]
    else:
        agent_gradient[i][0]=2*generator_c_values[i]*agent_resource_quantity[i][0]+generator_b_values[i]
        

#用户总成本初始化
sum=0
for i in range(0,54):
    sum=sum+(generator_c_values[i]*(agent_resource_quantity[i][0])*(agent_resource_quantity[i][0])+generator_b_values[i]*agent_resource_quantity[i][0]+generator_a_values[i])
sum_cost[0][0]=sum

# %%
#基于初始化的权重梯度下降无中心资源分配算法
def IWDGD_Gaussian_bias(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias):
    
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************IWDGD算法+计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,54):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,2000):#迭代次数
        iteration.append(k)
 
        #所有用户资源申请量基于可行初始化权重梯度下降的迭代  假设部分用户因为设备损坏 导致梯度的计算有误差     
        for i in range (0,54):
            weight_gradient_sum = np.float64(0)
            for j in range (0,54):        
                weight_gradient_sum=weight_gradient_sum+W[i][j]*agent_gradient[j][k-1]
            #weight_gradient_sum = np.round(weight_gradient_sum, decimals=3)
            agent_resource_quantity[i][k]=agent_resource_quantity[i][k-1]-iteration_update*weight_gradient_sum
            #agent_resource_quantity[i][k] = np.round(agent_resource_quantity[i][k], decimals=3)
        
        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,54):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,54):
            sum2=sum2+(generator_c_values[i]*(agent_resource_quantity[i][k])*(agent_resource_quantity[i][k])+generator_b_values[i]*agent_resource_quantity[i][k]+generator_a_values[i])
        sum_cost[0][k]=sum2
        
        #计算当前迭代的用户梯度
        for i in range (0,54): 
            if i==48:
                agent_gradient[i][k]=2*generator_c_values[i]*agent_resource_quantity[i][k]+generator_b_values[i]+bias[k]
            else:
                agent_gradient[i][k]=2*generator_c_values[i]*agent_resource_quantity[i][k]+generator_b_values[i]
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%20==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,54):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=1/(pow(k+1,0.5)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
IWDGD_Gaussian_bias(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias)
# Out:
# ****************************IWDGD算法+计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 111.11111111111111
# agent 2 的初始资源申请量为: 111.11111111111111
# agent 3 的初始资源申请量为: 111.11111111111111
# agent 4 的初始资源申请量为: 111.11111111111111
# agent 5 的初始资源申请量为: 111.11111111111111
# agent 6 的初始资源申请量为: 111.11111111111111
# agent 7 的初始资源申请量为: 111.11111111111111
# agent 8 的初始资源申请量为: 111.11111111111111
# agent 9 的初始资源申请量为: 111.11111111111111
# agent 10 的初始资源申请量为: 111.11111111111111
# agent 11 的初始资源申请量为: 111.11111111111111
# agent 12 的初始资源申请量为: 111.11111111111111
# agent 13 的初始资源申请量为: 111.11111111111111
# agent 14 的初始资源申请量为: 111.11111111111111
# agent 15 的初始资源申请量为: 111.11111111111111
# agent 16 的初始资源申请量为: 111.11111111111111
# agent 17 的初始资源申请量为: 111.11111111111111
# agent 18 的初始资源申请量为: 111.11111111111111
# agent 19 的初始资源申请量为: 111.11111111111111
# agent 20 的初始资源申请量为: 111.11111111111111
# agent 21 的初始资源申请量为: 111.11111111111111
# agent 22 的初始资源申请量为: 111.11111111111111
# agent 23 的初始资源申请量为: 111.11111111111111
# agent 24 的初始资源申请量为: 111.11111111111111
# agent 25 的初始资源申请量为: 111.11111111111111
# agent 26 的初始资源申请量为: 111.11111111111111
# agent 27 的初始资源申请量为: 111.11111111111111
# agent 28 的初始资源申请量为: 111.11111111111111
# agent 29 的初始资源申请量为: 111.11111111111111
# agent 30 的初始资源申请量为: 111.11111111111111
# agent 31 的初始资源申请量为: 111.11111111111111
# agent 32 的初始资源申请量为: 111.11111111111111
# agent 33 的初始资源申请量为: 111.11111111111111
# agent 34 的初始资源申请量为: 111.11111111111111
# agent 35 的初始资源申请量为: 111.11111111111111
# agent 36 的初始资源申请量为: 111.11111111111111
# agent 37 的初始资源申请量为: 111.11111111111111
# agent 38 的初始资源申请量为: 111.11111111111111
# agent 39 的初始资源申请量为: 111.11111111111111
# agent 40 的初始资源申请量为: 111.11111111111111
# agent 41 的初始资源申请量为: 111.11111111111111
# agent 42 的初始资源申请量为: 111.11111111111111
# agent 43 的初始资源申请量为: 111.11111111111111
# agent 44 的初始资源申请量为: 111.11111111111111
# agent 45 的初始资源申请量为: 111.11111111111111
# agent 46 的初始资源申请量为: 111.11111111111111
# agent 47 的初始资源申请量为: 111.11111111111111
# agent 48 的初始资源申请量为: 111.11111111111111
# agent 49 的初始资源申请量为: 111.11111111111111
# agent 50 的初始资源申请量为: 111.11111111111111
# agent 51 的初始资源申请量为: 111.11111111111111
# agent 52 的初始资源申请量为: 111.11111111111111
# agent 53 的初始资源申请量为: 111.11111111111111
# agent 54 的初始资源申请量为: 111.11111111111111
# *************************
# 初始资源申请量总和为: 6000.000000000006
# *************************
# 初始成本总和为: 139226.02283950621
# *************************
# 迭代步长为: 1
# *****************************************************************************
# 19 次迭代中的结果：
# agent 1 在 19 次迭代中的资源申请量为: -53.22046783535453
# agent 2 在 19 次迭代中的资源申请量为: -53.22046783535453
# agent 3 在 19 次迭代中的资源申请量为: -56.19510604371365
# agent 4 在 19 次迭代中的资源申请量为: 189.88295496185867
# agent 5 在 19 次迭代中的资源申请量为: 275.11165892721823
# agent 6 在 19 次迭代中的资源申请量为: -51.78318170101889
# agent 7 在 19 次迭代中的资源申请量为: 53.010829262030484
# agent 8 在 19 次迭代中的资源申请量为: -42.39310307510702
# agent 9 在 19 次迭代中的资源申请量为: -31.320787184080075
# agent 10 在 19 次迭代中的资源申请量为: 340.08983367132134
# agent 11 在 19 次迭代中的资源申请量为: 1064.1481184704076
# agent 12 在 19 次迭代中的资源申请量为: -43.90483130388958
# agent 13 在 19 次迭代中的资源申请量为: -49.77439910522132
# agent 14 在 19 次迭代中的资源申请量为: 115.37405416422797
# agent 15 在 19 次迭代中的资源申请量为: -61.05127224942548
# agent 16 在 19 次迭代中的资源申请量为: 38.89093034828214
# agent 17 在 19 次迭代中的资源申请量为: -54.254410848234514
# agent 18 在 19 次迭代中的资源申请量为: -67.17836985118531
# agent 19 在 19 次迭代中的资源申请量为: 38.50365413885292
# agent 20 在 19 次迭代中的资源申请量为: 608.5706269289055
# agent 21 在 19 次迭代中的资源申请量为: 332.9354006926749
# agent 22 在 19 次迭代中的资源申请量为: -50.78760524123416
# agent 23 在 19 次迭代中的资源申请量为: -70.97033739091722
# agent 24 在 19 次迭代中的资源申请量为: 276.71932237228145
# agent 25 在 19 次迭代中的资源申请量为: 231.57834775494467
# agent 26 在 19 次迭代中的资源申请量为: -73.12002252268718
# agent 27 在 19 次迭代中的资源申请量为: 509.93864044563094
# agent 28 在 19 次迭代中的资源申请量为: 312.67776257142697
# agent 29 在 19 次迭代中的资源申请量为: 419.98763582777696
# agent 30 在 19 次迭代中的资源申请量为: 87.92105259060365
# agent 31 在 19 次迭代中的资源申请量为: -17.466104367747334
# agent 32 在 19 次迭代中的资源申请量为: -12.102291989694976
# agent 33 在 19 次迭代中的资源申请量为: -251.2043136286229
# agent 34 在 19 次迭代中的资源申请量为: 217.0484966433297
# agent 35 在 19 次迭代中的资源申请量为: 280.2771130852174
# agent 36 在 19 次迭代中的资源申请量为: 810.4267763890043
# agent 37 在 19 次迭代中的资源申请量为: 604.3130976618992
# agent 38 在 19 次迭代中的资源申请量为: -31.482353858101423
# agent 39 在 19 次迭代中的资源申请量为: 297.76425354106516
# agent 40 在 19 次迭代中的资源申请量为: 386.9803146001176
# agent 41 在 19 次迭代中的资源申请量为: -226.8459873226461
# agent 42 在 19 次迭代中的资源申请量为: 107.73203585771441
# agent 43 在 19 次迭代中的资源申请量为: 530.9768151024813
# agent 44 在 19 次迭代中的资源申请量为: 952.688708980193
# agent 45 在 19 次迭代中的资源申请量为: 2978.995473987242
# agent 46 在 19 次迭代中的资源申请量为: 550.321632958485
# agent 47 在 19 次迭代中的资源申请量为: 1813.583514839603
# agent 48 在 19 次迭代中的资源申请量为: 3052.767319076929
# agent 49 在 19 次迭代中的资源申请量为: -11958.26996651843
# agent 50 在 19 次迭代中的资源申请量为: 1104.8423652793501
# agent 51 在 19 次迭代中的资源申请量为: 322.3937359283451
# agent 52 在 19 次迭代中的资源申请量为: 322.3937359283451
# agent 53 在 19 次迭代中的资源申请量为: 45.975386968009474
# agent 54 在 19 次迭代中的资源申请量为: -18.276220083106253
# 资源申请量总和为: 6000.000000000005
# ****************************************************************************
# 成本总和为: 4189916.9021745054
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 39 次迭代中的结果：
# agent 1 在 39 次迭代中的资源申请量为: -53.87848717148046
# agent 2 在 39 次迭代中的资源申请量为: -53.87848717148046
# agent 3 在 39 次迭代中的资源申请量为: -52.851890170585776
# agent 4 在 39 次迭代中的资源申请量为: 215.93909085831996
# agent 5 在 39 次迭代中的资源申请量为: 271.4909511831788
# agent 6 在 39 次迭代中的资源申请量为: -52.67546280715264
# agent 7 在 39 次迭代中的资源申请量为: 43.5754406716008
# agent 8 在 39 次迭代中的资源申请量为: -47.14342520377313
# agent 9 在 39 次迭代中的资源申请量为: -37.432493712371866
# agent 10 在 39 次迭代中的资源申请量为: 316.5944587687118
# agent 11 在 39 次迭代中的资源申请量为: 1274.2780787507472
# agent 12 在 39 次迭代中的资源申请量为: -48.36140270152781
# agent 13 在 39 次迭代中的资源申请量为: -51.83290607500571
# agent 14 在 39 次迭代中的资源申请量为: 74.378760354633
# agent 15 在 39 次迭代中的资源申请量为: -55.7116323234668
# agent 16 在 39 次迭代中的资源申请量为: 38.564194842975326
# agent 17 在 39 次迭代中的资源申请量为: -53.750382887125056
# agent 18 在 39 次迭代中的资源申请量为: -63.14537374547872
# agent 19 在 39 次迭代中的资源申请量为: 48.50986513673403
# agent 20 在 39 次迭代中的资源申请量为: 849.3813766793633
# agent 21 在 39 次迭代中的资源申请量为: 459.6110649844753
# agent 22 在 39 次迭代中的资源申请量为: -89.43065192178365
# agent 23 在 39 次迭代中的资源申请量为: -88.18123641830964
# agent 24 在 39 次迭代中的资源申请量为: 306.9859390882639
# agent 25 在 39 次迭代中的资源申请量为: 312.23949334430864
# agent 26 在 39 次迭代中的资源申请量为: -74.95191906620605
# agent 27 在 39 次迭代中的资源申请量为: 535.8294133596127
# agent 28 在 39 次迭代中的资源申请量为: 385.7195391005786
# agent 29 在 39 次迭代中的资源申请量为: 472.50043621531034
# agent 30 在 39 次迭代中的资源申请量为: 87.43413694072814
# agent 31 在 39 次迭代中的资源申请量为: -26.892921830374537
# agent 32 在 39 次迭代中的资源申请量为: -23.413737012799466
# agent 33 在 39 次迭代中的资源申请量为: -238.276681467853
# agent 34 在 39 次迭代中的资源申请量为: 242.86903299629
# agent 35 在 39 次迭代中的资源申请量为: 352.19214493057393
# agent 36 在 39 次迭代中的资源申请量为: 900.7503549166977
# agent 37 在 39 次迭代中的资源申请量为: 675.2243459634226
# agent 38 在 39 次迭代中的资源申请量为: -14.324060476018758
# agent 39 在 39 次迭代中的资源申请量为: 500.6538319256791
# agent 40 在 39 次迭代中的资源申请量为: 525.2150943942515
# agent 41 在 39 次迭代中的资源申请量为: -235.31892627103366
# agent 42 在 39 次迭代中的资源申请量为: 139.3860721827934
# agent 43 在 39 次迭代中的资源申请量为: 799.299704631534
# agent 44 在 39 次迭代中的资源申请量为: 1248.3861607309548
# agent 45 在 39 次迭代中的资源申请量为: 2181.017502512461
# agent 46 在 39 次迭代中的资源申请量为: 483.13040622367674
# agent 47 在 39 次迭代中的资源申请量为: 2029.1702491570647
# agent 48 在 39 次迭代中的资源申请量为: 2109.6164280757257
# agent 49 在 39 次迭代中的资源申请量为: -13437.49460999171
# agent 50 在 39 次迭代中的资源申请量为: 1443.4554877922103
# agent 51 在 39 次迭代中的资源申请量为: 686.8645165750299
# agent 52 在 39 次迭代中的资源申请量为: 686.8645165750299
# agent 53 在 39 次迭代中的资源申请量为: 41.95224767741334
# agent 54 在 39 次迭代中的资源申请量为: 59.86635088519114
# 资源申请量总和为: 6000.000000000006
# ****************************************************************************
# 成本总和为: 5157999.015629967
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 59 次迭代中的结果：
# agent 1 在 59 次迭代中的资源申请量为: -50.892492417027015
# agent 2 在 59 次迭代中的资源申请量为: -50.892492417027015
# agent 3 在 59 次迭代中的资源申请量为: -49.918337012925875
# agent 4 在 59 次迭代中的资源申请量为: 238.59067083052292
# agent 5 在 59 次迭代中的资源申请量为: 290.3250556549795
# agent 6 在 59 次迭代中的资源申请量为: -49.93518745537081
# agent 7 在 59 次迭代中的资源申请量为: 57.90137612068054
# agent 8 在 59 次迭代中的资源申请量为: -45.97922249086625
# agent 9 在 59 次迭代中的资源申请量为: -36.328186973756274
# agent 10 在 59 次迭代中的资源申请量为: 316.6985508752523
# agent 11 在 59 次迭代中的资源申请量为: 1369.6991196566494
# agent 12 在 59 次迭代中的资源申请量为: -47.723435511331004
# agent 13 在 59 次迭代中的资源申请量为: -49.497349082236326
# agent 14 在 59 次迭代中的资源申请量为: 75.5895531862876
# agent 15 在 59 次迭代中的资源申请量为: -51.44526176962647
# agent 16 在 59 次迭代中的资源申请量为: 54.7662209380393
# agent 17 在 59 次迭代中的资源申请量为: -50.65135256705018
# agent 18 在 59 次迭代中的资源申请量为: -58.29993133849462
# agent 19 在 59 次迭代中的资源申请量为: 72.72435573748298
# agent 20 在 59 次迭代中的资源申请量为: 1030.8067237657658
# agent 21 在 59 次迭代中的资源申请量为: 560.5075409621611
# agent 22 在 59 次迭代中的资源申请量为: -88.38959939771954
# agent 23 在 59 次迭代中的资源申请量为: -77.31541643281221
# agent 24 在 59 次迭代中的资源申请量为: 338.93002557530275
# agent 25 在 59 次迭代中的资源申请量为: 376.47102361898664
# agent 26 在 59 次迭代中的资源申请量为: -55.33389016818848
# agent 27 在 59 次迭代中的资源申请量为: 556.0829102759874
# agent 28 在 59 次迭代中的资源申请量为: 426.4520160667111
# agent 29 在 59 次迭代中的资源申请量为: 497.8652262591373
# agent 30 在 59 次迭代中的资源申请量为: 91.85748132392035
# agent 31 在 59 次迭代中的资源申请量为: -25.063241941042428
# agent 32 在 59 次迭代中的资源申请量为: -21.330022989473825
# agent 33 在 59 次迭代中的资源申请量为: -228.13592807765465
# agent 34 在 59 次迭代中的资源申请量为: 267.83604974473735
# agent 35 在 59 次迭代中的资源申请量为: 363.4807049505463
# agent 36 在 59 次迭代中的资源申请量为: 866.2657751062869
# agent 37 在 59 次迭代中的资源申请量为: 624.9283910689894
# agent 38 在 59 次迭代中的资源申请量为: -8.86145778747149
# agent 39 在 59 次迭代中的资源申请量为: 706.9875334132505
# agent 40 在 59 次迭代中的资源申请量为: 620.2132585497237
# agent 41 在 59 次迭代中的资源申请量为: -206.47241149975127
# agent 42 在 59 次迭代中的资源申请量为: 210.91118483663422
# agent 43 在 59 次迭代中的资源申请量为: 858.843487567081
# agent 44 在 59 次迭代中的资源申请量为: 1219.3326498274243
# agent 45 在 59 次迭代中的资源申请量为: 1762.2134534177872
# agent 46 在 59 次迭代中的资源申请量为: 340.67748164672497
# agent 47 在 59 次迭代中的资源申请量为: 1697.9299275847488
# agent 48 在 59 次迭代中的资源申请量为: 1626.7374352195245
# agent 49 在 59 次迭代中的资源申请量为: -13716.00659323649
# agent 50 在 59 次迭代中的资源申请量为: 1420.5574655220796
# agent 51 在 59 次迭代中的资源申请量为: 935.4655877680316
# agent 52 在 59 次迭代中的资源申请量为: 935.4655877680316
# agent 53 在 59 次迭代中的资源申请量为: 56.62849039464467
# agent 54 在 59 次迭代中的资源申请量为: 98.72949533220664
# 资源申请量总和为: 6000.0
# ****************************************************************************
# 成本总和为: 5315133.577403473
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 79 次迭代中的结果：
# agent 1 在 79 次迭代中的资源申请量为: -47.88764955338798
# agent 2 在 79 次迭代中的资源申请量为: -47.88764955338798
# agent 3 在 79 次迭代中的资源申请量为: -47.25171641554108
# agent 4 在 79 次迭代中的资源申请量为: 260.1440068362283
# agent 5 在 79 次迭代中的资源申请量为: 309.26067724488945
# agent 6 在 79 次迭代中的资源申请量为: -47.093933279312935
# agent 7 在 79 次迭代中的资源申请量为: 73.45607443408869
# agent 8 在 79 次迭代中的资源申请量为: -43.65110733735465
# agent 9 在 79 次迭代中的资源申请量为: -34.396612033673364
# agent 10 在 79 次迭代中的资源申请量为: 329.2793100523539
# agent 11 在 79 次迭代中的资源申请量为: 1443.534085123626
# agent 12 在 79 次迭代中的资源申请量为: -45.49790572802996
# agent 13 在 79 次迭代中的资源申请量为: -46.73716334424468
# agent 14 在 79 次迭代中的资源申请量为: 87.20858884035667
# agent 15 在 79 次迭代中的资源申请量为: -47.95075196174844
# agent 16 在 79 次迭代中的资源申请量为: 70.80756646403131
# agent 17 在 79 次迭代中的资源申请量为: -47.65009621016837
# agent 18 在 79 次迭代中的资源申请量为: -54.17770193699287
# agent 19 在 79 次迭代中的资源申请量为: 93.38083767096636
# agent 20 在 79 次迭代中的资源申请量为: 1174.9514623538628
# agent 21 在 79 次迭代中的资源申请量为: 657.1758851723268
# agent 22 在 79 次迭代中的资源申请量为: -75.76459340918987
# agent 23 在 79 次迭代中的资源申请量为: -60.460791123533866
# agent 24 在 79 次迭代中的资源申请量为: 380.89823386674294
# agent 25 在 79 次迭代中的资源申请量为: 433.2610799733428
# agent 26 在 79 次迭代中的资源申请量为: -35.040531673179416
# agent 27 在 79 次迭代中的资源申请量为: 571.3644168774974
# agent 28 在 79 次迭代中的资源申请量为: 456.36701778065105
# agent 29 在 79 次迭代中的资源申请量为: 506.72211128384834
# agent 30 在 79 次迭代中的资源申请量为: 93.92525810713654
# agent 31 在 79 次迭代中的资源申请量为: -23.276374423483567
# agent 32 在 79 次迭代中的资源申请量为: -19.555003359926737
# agent 33 在 79 次迭代中的资源申请量为: -224.95372594834186
# agent 34 在 79 次迭代中的资源申请量为: 277.80627067208286
# agent 35 在 79 次迭代中的资源申请量为: 356.82241851901676
# agent 36 在 79 次迭代中的资源申请量为: 820.770324186259
# agent 37 在 79 次迭代中的资源申请量为: 574.8013600330348
# agent 38 在 79 次迭代中的资源申请量为: -6.271344531025068
# agent 39 在 79 次迭代中的资源申请量为: 899.8743663282229
# agent 40 在 79 次迭代中的资源申请量为: 671.6314317298833
# agent 41 在 79 次迭代中的资源申请量为: -182.23508199781074
# agent 42 在 79 次迭代中的资源申请量为: 270.41475298608526
# agent 43 在 79 次迭代中的资源申请量为: 854.5143657762205
# agent 44 在 79 次迭代中的资源申请量为: 1132.3049536670583
# agent 45 在 79 次迭代中的资源申请量为: 1509.0207283839145
# agent 46 在 79 次迭代中的资源申请量为: 242.83025745132989
# agent 47 在 79 次迭代中的资源申请量为: 1411.7234888587086
# agent 48 在 79 次迭代中的资源申请量为: 1354.0860970047927
# agent 49 在 79 次迭代中的资源申请量为: -13849.792747075742
# agent 50 在 79 次迭代中的资源申请量为: 1355.854688225052
# agent 51 在 79 次迭代中的资源申请量为: 1066.9179186190322
# agent 52 在 79 次迭代中的资源申请量为: 1066.9179186190322
# agent 53 在 79 次迭代中的资源申请量为: 72.21150868726446
# agent 54 在 79 次迭代中的资源申请量为: 107.29301906714164
# 资源申请量总和为: 6000.000000000006
# ****************************************************************************
# 成本总和为: 5386115.54876991
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: -45.21406858003563
# agent 2 在 99 次迭代中的资源申请量为: -45.21406858003563
# agent 3 在 99 次迭代中的资源申请量为: -44.82617175961635
# agent 4 在 99 次迭代中的资源申请量为: 280.37895440181836
# agent 5 在 99 次迭代中的资源申请量为: 326.1229244632752
# agent 6 在 99 次迭代中的资源申请量为: -44.545374330165
# agent 7 在 99 次迭代中的资源申请量为: 87.4687138048825
# agent 8 在 99 次迭代中的资源申请量为: -41.34013876240785
# agent 9 在 99 次迭代中的资源申请量为: -32.73092016449874
# agent 10 在 99 次迭代中的资源申请量为: 344.1833765043977
# agent 11 在 99 次迭代中的资源申请量为: 1508.3762573563843
# agent 12 在 99 次迭代中的资源申请量为: -43.07929169638433
# agent 13 在 99 次迭代中的资源申请量为: -44.196978778317636
# agent 14 在 99 次迭代中的资源申请量为: 100.00556860075652
# agent 15 在 99 次迭代中的资源申请量为: -45.0591977908848
# agent 16 在 99 次迭代中的资源申请量为: 85.05800850164076
# agent 17 在 99 次迭代中的资源申请量为: -45.007791249243105
# agent 18 在 99 次迭代中的资源申请量为: -50.7440586685251
# agent 19 在 99 次迭代中的资源申请量为: 108.74345819558727
# agent 20 在 99 次迭代中的资源申请量为: 1291.0507233942499
# agent 21 在 99 次迭代中的资源申请量为: 753.6035644910559
# agent 22 在 99 次迭代中的资源申请量为: -59.577976956301455
# agent 23 在 99 次迭代中的资源申请量为: -42.50404906942117
# agent 24 在 99 次迭代中的资源申请量为: 427.14384234900916
# agent 25 在 99 次迭代中的资源申请量为: 485.05563237187835
# agent 26 在 99 次迭代中的资源申请量为: -16.16093820115022
# agent 27 在 99 次迭代中的资源申请量为: 583.5379296199927
# agent 28 在 99 次迭代中的资源申请量为: 480.44061830243334
# agent 29 在 99 次迭代中的资源申请量为: 507.3407848240454
# agent 30 在 99 次迭代中的资源申请量为: 94.2361049345624
# agent 31 在 99 次迭代中的资源申请量为: -22.319939216702007
# agent 32 在 99 次迭代中的资源申请量为: -18.818168489962524
# agent 33 在 99 次迭代中的资源申请量为: -225.57310832225062
# agent 34 在 99 次迭代中的资源申请量为: 278.0865718779546
# agent 35 在 99 次迭代中的资源申请量为: 344.3977683253805
# agent 36 在 99 次迭代中的资源申请量为: 777.0753996488024
# agent 37 在 99 次迭代中的资源申请量为: 530.6989038075966
# agent 38 在 99 次迭代中的资源申请量为: -5.066966680787967
# agent 39 在 99 次迭代中的资源申请量为: 1075.7126133268487
# agent 40 在 99 次迭代中的资源申请量为: 695.7647186403971
# agent 41 在 99 次迭代中的资源申请量为: -167.32515257822385
# agent 42 在 99 次迭代中的资源申请量为: 307.8025548767792
# agent 43 在 99 次迭代中的资源申请量为: 833.3520216051991
# agent 44 在 99 次迭代中的资源申请量为: 1045.6343098642237
# agent 45 在 99 次迭代中的资源申请量为: 1338.1167271246723
# agent 46 在 99 次迭代中的资源申请量为: 171.7914229822306
# agent 47 在 99 次迭代中的资源申请量为: 1206.2169744636526
# agent 48 在 99 次迭代中的资源申请量为: 1175.2310030711265
# agent 49 在 99 次迭代中的资源申请量为: -13925.241571075436
# agent 50 在 99 次迭代中的资源申请量为: 1285.2053024926322
# agent 51 在 99 次迭代中的资源申请量为: 1123.9754308761985
# agent 52 在 99 次迭代中的资源申请量为: 1123.9754308761985
# agent 53 在 99 次迭代中的资源申请量为: 86.3181333295266
# agent 54 在 99 次迭代中的资源申请量为: 102.44418164496915
# 资源申请量总和为: 6000.000000000011
# ****************************************************************************
# 成本总和为: 5423134.790278288
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 119 次迭代中的结果：
# agent 1 在 119 次迭代中的资源申请量为: -42.89004353258389
# agent 2 在 119 次迭代中的资源申请量为: -42.89004353258389
# agent 3 在 119 次迭代中的资源申请量为: -42.658970436896546
# agent 4 在 119 次迭代中的资源申请量为: 298.9948893429809
# agent 5 在 119 次迭代中的资源申请量为: 340.7871815890773
# agent 6 在 119 次迭代中的资源申请量为: -42.32237156109944
# agent 7 在 119 次迭代中的资源申请量为: 99.64162795302843
# agent 8 在 119 次迭代中的资源申请量为: -39.31893623669994
# agent 9 在 119 次迭代中的资源申请量为: -31.450892146476836
# agent 10 在 119 次迭代中的资源申请量为: 357.92961349812896
# agent 11 在 119 次迭代中的资源申请量为: 1565.440379885349
# agent 12 在 119 次迭代中的资源申请量为: -40.88409104771914
# agent 13 在 119 次迭代中的资源申请量为: -41.97668470847973
# agent 14 在 119 次迭代中的资源申请量为: 111.54232542861342
# agent 15 在 119 次迭代中的资源申请量为: -42.65444695321546
# agent 16 在 119 次迭代中的资源申请量为: 97.43949409366104
# agent 17 在 119 次迭代中的资源申请量为: -42.72481884495438
# agent 18 在 119 次迭代中的资源申请量为: -47.878670298839964
# agent 19 在 119 次迭代中的资源申请量为: 120.0912540771954
# agent 20 在 119 次迭代中的资源申请量为: 1385.904810566655
# agent 21 在 119 次迭代中的资源申请量为: 849.1534704060361
# agent 22 在 119 次迭代中的资源申请量为: -42.51329063566694
# agent 23 在 119 次迭代中的资源申请量为: -24.935147230430747
# agent 24 在 119 次迭代中的资源申请量为: 473.83559901403595
# agent 25 在 119 次迭代中的资源申请量为: 532.7974494451812
# agent 26 在 119 次迭代中的资源申请量为: 1.1883973988980792
# agent 27 在 119 次迭代中的资源申请量为: 593.8040166204735
# agent 28 在 119 次迭代中的资源申请量为: 500.59740793124155
# agent 29 在 119 次迭代中的资源申请量为: 504.4577485175124
# agent 30 在 119 次迭代中的资源申请量为: 93.62872988778082
# agent 31 在 119 次迭代中的资源申请量为: -21.95345292498654
# agent 32 在 119 次迭代中的资源申请量为: -18.751387040430828
# agent 33 在 119 次迭代中的资源申请量为: -227.91949002921635
# agent 34 在 119 次迭代中的资源申请量为: 273.6275243256441
# agent 35 在 119 次迭代中的资源申请量为: 330.8542286837235
# agent 36 在 119 次迭代中的资源申请量为: 741.184790316559
# agent 37 在 119 次迭代中的资源申请量为: 495.5524125355597
# agent 38 在 119 次迭代中的资源申请量为: -4.491332767308609
# agent 39 在 119 次迭代中的资源申请量为: 1233.877408853651
# agent 40 在 119 次迭代中的资源申请量为: 704.0378232202659
# agent 41 在 119 次迭代中的资源申请量为: -159.89482045437396
# agent 42 在 119 次迭代中的资源申请量为: 325.8752109766815
# agent 43 在 119 次迭代中的资源申请量为: 808.5521193489155
# agent 44 在 119 次迭代中的资源申请量为: 974.3511536283258
# agent 45 在 119 次迭代中的资源申请量为: 1217.9833237620903
# agent 46 在 119 次迭代中的资源申请量为: 121.97410919624569
# agent 47 在 119 次迭代中的资源申请量为: 1063.6694788350806
# agent 48 在 119 次迭代中的资源申请量为: 1051.6571110533564
# agent 49 在 119 次迭代中的资源申请量为: -13992.802917609382
# agent 50 在 119 次迭代中的资源申请量为: 1216.1180899990184
# agent 51 在 119 次迭代中的资源申请量为: 1136.3155808497072
# agent 52 在 119 次迭代中的资源申请量为: 1136.3155808497072
# agent 53 在 119 次迭代中的资源申请量为: 98.6256580643358
# agent 54 在 119 次迭代中的资源申请量为: 93.10580783663426
# 资源申请量总和为: 6000.000000000004
# ****************************************************************************
# 成本总和为: 5460061.8882799605
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 139 次迭代中的结果：
# agent 1 在 139 次迭代中的资源申请量为: -40.87855778041025
# agent 2 在 139 次迭代中的资源申请量为: -40.87855778041025
# agent 3 在 139 次迭代中的资源申请量为: -40.7416309006512
# agent 4 在 139 次迭代中的资源申请量为: 315.8446016252687
# agent 5 在 139 次迭代中的资源申请量为: 353.48321366621997
# agent 6 在 139 次迭代中的资源申请量为: -40.392221833957635
# agent 7 在 139 次迭代中的资源申请量为: 110.15222332070627
# agent 8 在 139 次迭代中的资源申请量为: -37.601085631395094
# agent 9 在 139 次迭代中的资源申请量为: -30.465599415295227
# agent 10 在 139 次迭代中的资源申请量为: 369.77267595962303
# agent 11 在 139 次迭代中的资源申请量为: 1615.1351419669945
# agent 12 在 139 次迭代中的资源申请量为: -38.988640034519214
# agent 13 在 139 次迭代中的资源申请量为: -40.056574231655404
# agent 14 在 139 次迭代中的资源申请量为: 121.42860064830448
# agent 15 在 139 次迭代中的资源申请量为: -40.631963844533644
# agent 16 在 139 次迭代中的资源申请量为: 108.15543037617985
# agent 17 在 139 次迭代中的资源申请量为: -40.75394808805447
# agent 18 在 139 次迭代中的资源申请量为: -45.46131504577198
# agent 19 在 139 次迭代中的资源申请量为: 128.81415467974946
# agent 20 在 139 次迭代中的资源申请量为: 1464.9861468119166
# agent 21 在 139 次迭代中的资源申请量为: 942.3617108515286
# agent 22 在 139 次迭代中的资源申请量为: -25.6256973256858
# agent 23 在 139 次迭代中的资源申请量为: -8.254379727254221
# agent 24 在 139 次迭代中的资源申请量为: 519.121538276512
# agent 25 在 139 次迭代中的资源申请量为: 576.9692921561514
# agent 26 在 139 次迭代中的资源申请量为: 17.10368268350124
# agent 27 在 139 次迭代中的资源申请量为: 602.8404968626754
# agent 28 在 139 次迭代中的资源申请量为: 517.9067009291563
# agent 29 在 139 次迭代中的资源申请量为: 500.68673263421715
# agent 30 在 139 次迭代中的资源申请量为: 92.69457582642437
# agent 31 在 139 次迭代中的资源申请量为: -21.890613951516734
# agent 32 在 139 次迭代中的资源申请量为: -18.997126069914437
# agent 33 在 139 次迭代中的资源申请量为: -230.74979827980673
# agent 34 在 139 次迭代中的资源申请量为: 267.55550816721285
# agent 35 在 139 次迭代中的资源申请量为: 318.41314158463155
# agent 36 在 139 次迭代中的资源申请量为: 713.2504558783985
# agent 37 在 139 次迭代中的资源申请量为: 468.5100334406871
# agent 38 在 139 次迭代中的资源申请量为: -4.163378300124968
# agent 39 在 139 次迭代中的资源申请量为: 1375.2109160038822
# agent 40 在 139 次迭代中的资源申请量为: 703.5070209992869
# agent 41 在 139 次迭代中的资源申请量为: -157.5229323491929
# agent 42 在 139 次迭代中的资源申请量为: 330.09984783214713
# agent 43 在 139 次迭代中的资源申请量为: 784.651456744134
# agent 44 在 139 次迭代中的资源申请量为: 918.9939811411965
# agent 45 在 139 次迭代中的资源申请量为: 1136.3219577590671
# agent 46 在 139 次迭代中的资源申请量为: 86.54750051239976
# agent 47 在 139 次迭代中的资源申请量为: 964.0099961497218
# agent 48 在 139 次迭代中的资源申请量为: 967.9655379475046
# agent 49 在 139 次迭代中的资源申请量为: -14076.975733704996
# agent 50 在 139 次迭代中的资源申请量为: 1150.6314378723612
# agent 51 在 139 次迭代中的资源申请量为: 1122.5752178876455
# agent 52 在 139 次迭代中的资源申请量为: 1122.5752178876455
# agent 53 在 139 次迭代中的资源申请量为: 109.27312826714098
# agent 54 在 139 次迭代中的资源申请量为: 83.48047894496041
# 资源申请量总和为: 6000.000000000006
# ****************************************************************************
# 成本总和为: 5513838.023786616
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 159 次迭代中的结果：
# agent 1 在 159 次迭代中的资源申请量为: -39.125664272878716
# agent 2 在 159 次迭代中的资源申请量为: -39.125664272878716
# agent 3 在 159 次迭代中的资源申请量为: -39.04592794522054
# agent 4 在 159 次迭代中的资源申请量为: 330.9356611681526
# agent 5 在 159 次迭代中的资源申请量为: 364.54973491210757
# agent 6 在 159 次迭代中的资源申请量为: -38.70702526472445
# agent 7 在 159 次迭代中的资源申请量为: 119.29998929744818
# agent 8 在 159 次迭代中的资源申请量为: -36.12942801041235
# agent 9 在 159 次迭代中的资源申请量为: -29.659410931950077
# agent 10 在 159 次迭代中的资源申请量为: 379.87101435199236
# agent 11 在 159 次迭代中的资源申请量为: 1658.3419211199919
# agent 12 在 159 次迭代中的资源申请量为: -37.36091334570935
# agent 13 在 159 次迭代中的资源申请量为: -38.388189784695214
# agent 14 在 159 次迭代中的资源申请量为: 129.87855630085926
# agent 15 在 159 次迭代中的资源申请量为: -38.90188786380328
# agent 16 在 159 次迭代中的资源申请量为: 117.49600481942929
# agent 17 在 159 次迭代中的资源申请量为: -39.03936779271169
# agent 18 在 159 次迭代中的资源申请量为: -43.38545550017831
# agent 19 在 159 次迭代中的资源申请量为: 135.94432698085274
# agent 20 在 159 次迭代中的资源申请量为: 1532.568513604281
# agent 21 在 159 次迭代中的资源申请量为: 1032.013498452598
# agent 22 在 159 次迭代中的资源申请量为: -9.369643699416546
# agent 23 在 159 次迭代中的资源申请量为: 7.3965190874051885
# agent 24 在 159 次迭代中的资源申请量为: 562.211778028335
# agent 25 在 159 次迭代中的资源申请量为: 617.9098011745145
# agent 26 在 159 次迭代中的资源申请量为: 31.718620183949966
# agent 27 在 159 次迭代中的资源申请量为: 610.8214942585199
# agent 28 在 159 次迭代中的资源申请量为: 533.0817731560928
# agent 29 在 159 次迭代中的资源申请量为: 497.11242137557184
# agent 30 在 159 次迭代中的资源申请量为: 91.77779519021028
# agent 31 在 159 次迭代中的资源申请量为: -21.920535493080433
# agent 32 在 159 次迭代中的资源申请量为: -19.309682198024838
# agent 33 在 159 次迭代中的资源申请量为: -233.3757574418947
# agent 34 在 159 次迭代中的资源申请量为: 261.6599836092364
# agent 35 在 159 次迭代中的资源申请量为: 307.44756964918065
# agent 36 在 159 次迭代中的资源申请量为: 686.8510469836216
# agent 37 在 159 次迭代中的资源申请量为: 442.52469869668306
# agent 38 在 159 次迭代中的资源申请量为: -4.156943022782247
# agent 39 在 159 次迭代中的资源申请量为: 1501.2131465689376
# agent 40 在 159 次迭代中的资源申请量为: 698.5019902205552
# agent 41 在 159 次迭代中的资源申请量为: -158.24426643579667
# agent 42 在 159 次迭代中的资源申请量为: 325.5779575785257
# agent 43 在 159 次迭代中的资源申请量为: 762.5330012650074
# agent 44 在 159 次迭代中的资源申请量为: 870.6778518853934
# agent 45 在 159 次迭代中的资源申请量为: 1082.7782118840619
# agent 46 在 159 次迭代中的资源申请量为: 50.65745587202584
# agent 47 在 159 次迭代中的资源申请量为: 878.5982795916591
# agent 48 在 159 次迭代中的资源申请量为: 908.4735399925898
# agent 49 在 159 次迭代中的资源申请量为: -14128.652378195102
# agent 50 在 159 次迭代中的资源申请量为: 1081.18037022676
# agent 51 在 159 次迭代中的资源申请量为: 1094.3247321901686
# agent 52 在 159 次迭代中的资源申请量为: 1094.3247321901686
# agent 53 在 159 次迭代中的资源申请量为: 118.53944130907095
# agent 54 在 159 次迭代中的资源申请量为: 75.10470829530273
# 资源申请量总和为: 5999.999999999996
# ****************************************************************************
# 成本总和为: 5544122.489200313
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 179 次迭代中的结果：
# agent 1 在 179 次迭代中的资源申请量为: -37.60176265831579
# agent 2 在 179 次迭代中的资源申请量为: -37.60176265831579
# agent 3 在 179 次迭代中的资源申请量为: -37.553853097938905
# agent 4 在 179 次迭代中的资源申请量为: 344.35252533471873
# agent 5 在 179 次迭代中的资源申请量为: 374.1735640220908
# agent 6 在 179 次迭代中的资源申请量为: -37.23745024477025
# agent 7 在 179 次迭代中的资源申请量为: 127.24613843318929
# agent 8 在 179 次迭代中的资源申请量为: -34.865408569954916
# agent 9 在 179 次迭代中的资源申请量为: -28.998486598360785
# agent 10 在 179 次迭代中的资源申请量为: 388.52302963201964
# agent 11 在 179 次迭代中的资源申请量为: 1695.8795862631948
# agent 12 在 179 次迭代中的资源申请量为: -35.95912070599887
# agent 13 在 179 次迭代中的资源申请量为: -36.93778739870785
# agent 14 在 179 次迭代中的资源申请量为: 137.13280050930405
# agent 15 在 179 次迭代中的资源申请量为: -37.41111025937569
# agent 16 在 179 次迭代中的资源申请量为: 125.61801811096626
# agent 17 在 179 次迭代中的资源申请量为: -37.54620660976378
# agent 18 在 179 次迭代中的资源申请量为: -41.581704298409974
# agent 19 在 179 次迭代中的资源申请量为: 141.93064263268815
# agent 20 在 179 次迭代中的资源申请量为: 1591.4743443615737
# agent 21 在 179 次迭代中的资源申请量为: 1117.3292840480826
# agent 22 在 179 次迭代中的资源申请量为: 6.0540090922283625
# agent 23 在 179 次迭代中的资源申请量为: 22.002594027358317
# agent 24 在 179 次迭代中的资源申请量为: 602.7161322799542
# agent 25 在 179 次迭代中的资源申请量为: 655.7721632855797
# agent 26 在 179 次迭代中的资源申请量为: 45.145324320250964
# agent 27 在 179 次迭代中的资源申请量为: 618.0029584298609
# agent 28 在 179 次迭代中的资源申请量为: 546.5243258768751
# agent 29 在 179 次迭代中的资源申请量为: 493.7835912646302
# agent 30 在 179 次迭代中的资源申请量为: 90.87302760498238
# agent 31 在 179 次迭代中的资源申请量为: -22.01105289227448
# agent 32 在 179 次迭代中的资源申请量为: -19.653744348336744
# agent 33 在 179 次迭代中的资源申请量为: -235.877649165745
# agent 34 在 179 次迭代中的资源申请量为: 256.04467389804825
# agent 35 在 179 次迭代中的资源申请量为: 297.7421627218546
# agent 36 在 179 次迭代中的资源申请量为: 666.6653734993264
# agent 37 在 179 次迭代中的资源申请量为: 422.64373786674963
# agent 38 在 179 次迭代中的资源申请量为: -4.176678169695574
# agent 39 在 179 次迭代中的资源申请量为: 1612.8124077828754
# agent 40 在 179 次迭代中的资源申请量为: 690.492145079982
# agent 41 在 179 次迭代中的资源申请量为: -160.88276453867422
# agent 42 在 179 次迭代中的资源申请量为: 315.3910850986474
# agent 43 在 179 次迭代中的资源申请量为: 741.3839641471315
# agent 44 在 179 次迭代中的资源申请量为: 832.1042258129735
# agent 45 在 179 次迭代中的资源申请量为: 1021.1930549245296
# agent 46 在 179 次迭代中的资源申请量为: 24.773342117814778
# agent 47 在 179 次迭代中的资源申请量为: 813.1818292497413
# agent 48 在 179 次迭代中的资源申请量为: 843.183610983217
# agent 49 在 179 次迭代中的资源申请量为: -14138.371957606309
# agent 50 在 179 次迭代中的资源申请量为: 1015.2099423460623
# agent 51 在 179 次迭代中的资源申请量为: 1056.3389356725677
# agent 52 在 179 次迭代中的资源申请量为: 1056.3389356725677
# agent 53 在 179 次迭代中的资源申请量为: 126.58926229013238
# agent 54 在 179 次迭代中的资源申请量为: 67.64575112717732
# 资源申请量总和为: 6000.000000000001
# ****************************************************************************
# 成本总和为: 5542608.602568776
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: -36.25932858150288
# agent 2 在 199 次迭代中的资源申请量为: -36.25932858150288
# agent 3 在 199 次迭代中的资源申请量为: -36.229114324716434
# agent 4 在 199 次迭代中的资源申请量为: 356.24111787032393
# agent 5 在 199 次迭代中的资源申请量为: 382.6559324792183
# agent 6 在 199 次迭代中的资源申请量为: -35.93948407448595
# agent 7 在 199 次迭代中的资源申请量为: 134.25143658712824
# agent 8 在 199 次迭代中的资源申请量为: -33.761072415921724
# agent 9 在 199 次迭代中的资源申请量为: -28.42322819006323
# agent 10 在 199 次迭代中的资源申请量为: 396.00337037833333
# agent 11 在 199 次迭代中的资源申请量为: 1728.7231523887478
# agent 12 在 199 次迭代中的资源申请量为: -34.739398787413585
# agent 13 在 199 次迭代中的资源申请量为: -35.66059576251898
# agent 14 在 199 次迭代中的资源申请量为: 143.433355793783
# agent 15 在 199 次迭代中的资源申请量为: -36.10338962179435
# agent 16 在 199 次迭代中的资源申请量为: 132.77936858445503
# agent 17 在 199 次迭代中的资源申请量为: -36.228212346078834
# agent 18 在 199 次迭代中的资源申请量为: -39.988465515329494
# agent 19 在 199 次迭代中的资源申请量为: 147.18090432935028
# agent 20 在 199 次迭代中的资源申请量为: 1643.7610203533548
# agent 21 在 199 次迭代中的资源申请量为: 1197.8868459161365
# agent 22 在 199 次迭代中的资源申请量为: 20.565238800153253
# agent 23 在 199 次迭代中的资源申请量为: 35.59563561663448
# agent 24 在 199 次迭代中的资源申请量为: 640.5906733128289
# agent 25 在 199 次迭代中的资源申请量为: 690.7903255200471
# agent 26 在 199 次迭代中的资源申请量为: 57.492269781691505
# agent 27 在 199 次迭代中的资源申请量为: 624.5458452648994
# agent 28 在 199 次迭代中的资源申请量为: 558.5970041728359
# agent 29 在 199 次迭代中的资源申请量为: 491.1370392155748
# agent 30 在 199 次迭代中的资源申请量为: 90.11121149443062
# agent 31 在 199 次迭代中的资源申请量为: -22.089825474254656
# agent 32 在 199 次迭代中的资源申请量为: -19.9542865656937
# agent 33 在 199 次迭代中的资源申请量为: -237.98942056639567
# agent 34 在 199 次迭代中的资源申请量为: 251.203555255747
# agent 35 在 199 次迭代中的资源申请量为: 289.6365292282825
# agent 36 在 199 次迭代中的资源申请量为: 650.1629789831768
# agent 37 在 199 次迭代中的资源申请量为: 406.23426532679537
# agent 38 在 199 次迭代中的资源申请量为: -4.258908791622147
# agent 39 在 199 次迭代中的资源申请量为: 1711.598142512025
# agent 40 在 199 次迭代中的资源申请量为: 681.275314532714
# agent 41 在 199 次迭代中的资源申请量为: -164.61920350923384
# agent 42 在 199 次迭代中的资源申请量为: 302.1069215700444
# agent 43 在 199 次迭代中的资源申请量为: 722.4526073240731
# agent 44 在 199 次迭代中的资源申请量为: 800.5754136089504
# agent 45 在 199 次迭代中的资源申请量为: 954.2362513737804
# agent 46 在 199 次迭代中的资源申请量为: 3.3083321903089953
# agent 47 在 199 次迭代中的资源申请量为: 760.7587236286139
# agent 48 在 199 次迭代中的资源申请量为: 772.2823732477964
# agent 49 在 199 次迭代中的资源申请量为: -14115.454834664362
# agent 50 在 199 次迭代中的资源申请量为: 952.8155380201799
# agent 51 在 199 次迭代中的资源申请量为: 1013.8441128948804
# agent 52 在 199 次迭代中的资源申请量为: 1013.8441128948804
# agent 53 在 199 次迭代中的资源申请量为: 133.67836917394587
# agent 54 在 199 次迭代中的资源申请量为: 61.602808146768254
# 资源申请量总和为: 6000.000000000001
# ****************************************************************************
# 成本总和为: 5516433.853339339
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 219 次迭代中的结果：
# agent 1 在 219 次迭代中的资源申请量为: -35.068966568582276
# agent 2 在 219 次迭代中的资源申请量为: -35.068966568582276
# agent 3 在 219 次迭代中的资源申请量为: -35.046248427916815
# agent 4 在 219 次迭代中的资源申请量为: 366.77166944344737
# agent 5 在 219 次迭代中的资源申请量为: 390.18368161687556
# agent 6 在 219 次迭代中的资源申请量为: -34.783789534091916
# agent 7 在 219 次迭代中的资源申请量为: 140.47302040196544
# agent 8 在 219 次迭代中的资源申请量为: -32.78496834946536
# agent 9 在 219 次迭代中的资源申请量为: -27.91299435603277
# agent 10 在 219 次迭代中的资源申请量为: 402.563049611303
# agent 11 在 219 次迭代中的资源申请量为: 1757.6851993695425
# agent 12 在 219 次迭代中的资源申请量为: -33.6651783915062
# agent 13 在 219 次迭代中的资源申请量为: -34.525310475276804
# agent 14 在 219 次迭代中的资源申请量为: 148.97772682805942
# agent 15 在 219 次迭代中的资源申请量为: -34.94244654908623
# agent 16 在 219 次迭代中的资源申请量为: 139.1378587875661
# agent 17 在 219 次迭代中的资源申请量为: -35.05424647063008
# agent 18 在 219 次迭代中的资源申请量为: -38.56462724506586
# agent 19 在 219 次迭代中的资源申请量为: 151.88641610454337
# agent 20 在 219 次迭代中的资源申请量为: 1690.824408485362
# agent 21 在 219 次迭代中的资源申请量为: 1273.5410677811924
# agent 22 在 219 次迭代中的资源申请量为: 34.149337142444665
# agent 23 在 219 次迭代中的资源申请量为: 48.23074218385962
# agent 24 在 219 次迭代中的资源申请量为: 675.8719078103607
# agent 25 在 219 次迭代中的资源申请量为: 723.1532864530736
# agent 26 在 219 次迭代中的资源申请量为: 68.86067784816798
# agent 27 在 219 次迭代中的资源申请量为: 630.5847493715269
# agent 28 在 219 次迭代中的资源申请量为: 569.5277296783552
# agent 29 在 219 次迭代中的资源申请量为: 489.09252594829553
# agent 30 在 219 次迭代中的资源申请量为: 89.47460231120314
# agent 31 在 219 次迭代中的资源申请量为: -22.15120532357478
# agent 32 在 219 次迭代中的资源申请量为: -20.209335102727692
# agent 33 在 219 次迭代中的资源申请量为: -239.79258015954667
# agent 34 在 219 次迭代中的资源申请量为: 247.04621299067486
# agent 35 在 219 次迭代中的资源申请量为: 282.8952844672978
# agent 36 在 219 次迭代中的资源申请量为: 636.244036538494
# agent 37 在 219 次迭代中的资源申请量为: 392.3656628935761
# agent 38 在 219 次迭代中的资源申请量为: -4.324458207603616
# agent 39 在 219 次迭代中的资源申请量为: 1798.769603783159
# agent 40 在 219 次迭代中的资源申请量为: 671.5056362193433
# agent 41 在 219 次迭代中的资源申请量为: -168.91131754762745
# agent 42 在 219 次迭代中的资源申请量为: 287.27625052234555
# agent 43 在 219 次迭代中的资源申请量为: 705.3763007485853
# agent 44 在 219 次迭代中的资源申请量为: 774.1307377657462
# agent 45 在 219 次迭代中的资源申请量为: 912.2275925870736
# agent 46 在 219 次迭代中的资源申请量为: -15.61127390385277
# agent 47 在 219 次迭代中的资源申请量为: 717.6011763229537
# agent 48 在 219 次迭代中的资源申请量为: 726.0257740379834
# agent 49 在 219 次迭代中的资源申请量为: -14123.036169716346
# agent 50 在 219 次迭代中的资源申请量为: 894.0011665745603
# agent 51 在 219 次迭代中的资源申请量为: 969.1778908152573
# agent 52 在 219 次迭代中的资源申请量为: 969.1778908152573
# agent 53 在 219 次迭代中的资源申请量为: 139.96900423042257
# agent 54 在 219 次迭代中的资源申请量为: 56.6742044076443
# 资源申请量总和为: 6000.00000000001
# ****************************************************************************
# 成本总和为: 5515756.811078854
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 239 次迭代中的结果：
# agent 1 在 239 次迭代中的资源申请量为: -33.996231764926804
# agent 2 在 239 次迭代中的资源申请量为: -33.996231764926804
# agent 3 在 239 次迭代中的资源申请量为: -33.978792104734225
# agent 4 在 239 次迭代中的资源申请量为: 376.13116849740175
# agent 5 在 239 次迭代中的资源申请量为: 396.97209370247896
# agent 6 在 239 次迭代中的资源申请量为: -33.741723739201674
# agent 7 在 239 次迭代中的资源申请量为: 146.0910527072909
# agent 8 在 239 次迭代中的资源申请量为: -31.90247981711317
# agent 9 在 239 次迭代中的资源申请量为: -27.43187786496865
# agent 10 在 239 次迭代中的资源申请量为: 408.4220738236548
# agent 11 在 239 次迭代中的资源申请量为: 1783.573112800691
# agent 12 在 239 次迭代中的资源申请量为: -32.70275159795871
# agent 13 在 239 次迭代中的资源申请量为: -33.50296347687829
# agent 14 在 239 次迭代中的资源申请量为: 153.95438538835054
# agent 15 在 239 次迭代中的资源申请量为: -33.895815349268545
# agent 16 在 239 次迭代中的资源申请量为: 144.87359833689015
# agent 17 在 239 次迭代中的资源申请量为: -33.995513732140765
# agent 18 在 239 次迭代中的资源申请量为: -37.2731108848633
# agent 19 在 239 次迭代中的资源申请量为: 156.2539315666942
# agent 20 在 239 次迭代中的资源申请量为: 1733.7664166798681
# agent 21 在 239 次迭代中的资源申请量为: 1344.3344897761856
# agent 22 在 239 次迭代中的资源申请量为: 46.82893968057365
# agent 23 在 239 次迭代中的资源申请量为: 59.97421990447012
# agent 24 在 239 次迭代中的资源申请量为: 708.7085432223247
# agent 25 在 239 次迭代中的资源申请量为: 753.1047144317118
# agent 26 在 239 次迭代中的资源申请量为: 79.35326150593066
# agent 27 在 239 次迭代中的资源申请量为: 636.0752169126282
# agent 28 在 239 次迭代中的资源申请量为: 579.5270334964288
# agent 29 在 239 次迭代中的资源申请量为: 487.56442542211437
# agent 30 在 239 次迭代中的资源申请量为: 88.99436275731118
# agent 31 在 239 次迭代中的资源申请量为: -22.156233265937992
# agent 32 在 239 次迭代中的资源申请量为: -20.379357630197134
# agent 33 在 239 次迭代中的资源申请量为: -241.20742057927725
# agent 34 在 239 次迭代中的资源申请量为: 243.76771608859363
# agent 35 在 239 次迭代中的资源申请量为: 277.036114756791
# agent 36 在 239 次迭代中的资源申请量为: 624.1225083562422
# agent 37 在 239 次迭代中的资源申请量为: 379.90219444377254
# agent 38 在 239 次迭代中的资源申请量为: -4.539023884148001
# agent 39 在 239 次迭代中的资源申请量为: 1875.7332184595218
# agent 40 在 239 次迭代中的资源申请量为: 662.0016313703808
# agent 41 在 239 次迭代中的资源申请量为: -173.33305468667703
# agent 42 在 239 次迭代中的资源申请量为: 272.21730901087255
# agent 43 在 239 次迭代中的资源申请量为: 689.8041949870582
# agent 44 在 239 次迭代中的资源申请量为: 750.8107547606319
# agent 45 在 239 次迭代中的资源申请量为: 906.4983462336052
# agent 46 在 239 次迭代中的资源申请量为: -32.372728061923674
# agent 47 在 239 次迭代中的资源申请量为: 678.0932483316852
# agent 48 在 239 次迭代中的资源申请量为: 715.9887810738886
# agent 49 在 239 次迭代中的资源申请量为: -14184.860067958234
# agent 50 在 239 次迭代中的资源申请量为: 836.9092395388238
# agent 51 在 239 次迭代中的资源申请量为: 924.7351351585542
# agent 52 在 239 次迭代中的资源申请量为: 924.7351351585542
# agent 53 在 239 次迭代中的资源申请量为: 145.64017675869076
# agent 54 在 239 次迭代中的资源申请量为: 52.76663306270943
# 资源申请量总和为: 5999.999999999996
# ****************************************************************************
# 成本总和为: 5559288.410965117
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 259 次迭代中的结果：
# agent 1 在 259 次迭代中的资源申请量为: -33.022221283340215
# agent 2 在 259 次迭代中的资源申请量为: -33.022221283340215
# agent 3 在 259 次迭代中的资源申请量为: -33.005028567882945
# agent 4 在 259 次迭代中的资源申请量为: 384.48944496637415
# agent 5 在 259 次迭代中的资源申请量为: 403.1439295470109
# agent 6 在 259 次迭代中的资源申请量为: -32.790585215833175
# agent 7 在 259 次迭代中的资源申请量为: 151.20729132254564
# agent 8 在 259 次迭代中的资源申请量为: -31.097015549895687
# agent 9 在 259 次迭代中的资源申请量为: -26.978507770285155
# agent 10 在 259 次迭代中的资源申请量为: 413.73228349664794
# agent 11 在 259 次迭代中的资源申请量为: 1806.9490901128725
# agent 12 在 259 次迭代中的资源申请量为: -31.829377270706466
# agent 13 在 259 次迭代中的资源申请量为: -32.56999496753144
# agent 14 在 259 次迭代中的资源申请量为: 158.47646847991535
# agent 15 在 259 次迭代中的资源申请量为: -32.93970371205439
# agent 16 在 259 次迭代中的资源申请量为: 150.0917465305581
# agent 17 在 259 次迭代中的资源申请量为: -33.02839327911341
# agent 18 在 259 次迭代中的资源申请量为: -36.0914800031288
# agent 19 在 259 次迭代中的资源申请量为: 160.33501618291064
# agent 20 在 259 次迭代中的资源申请量为: 1773.2816743371998
# agent 21 在 259 次迭代中的资源申请量为: 1410.4316196409166
# agent 22 在 259 次迭代中的资源申请量为: 58.64506846130418
# agent 23 在 259 次迭代中的资源申请量为: 70.89173975060373
# agent 24 在 259 次迭代中的资源申请量为: 739.2426328295587
# agent 25 在 259 次迭代中的资源申请量为: 780.8390486968785
# agent 26 在 259 次迭代中的资源申请量为: 89.05432254184274
# agent 27 在 259 次迭代中的资源申请量为: 641.3190783606368
# agent 28 在 259 次迭代中的资源申请量为: 588.7268025850112
# agent 29 在 259 次迭代中的资源申请量为: 486.65961760939246
# agent 30 在 259 次迭代中的资源申请量为: 88.6407871774631
# agent 31 在 259 次迭代中的资源申请量为: -22.126477310919192
# agent 32 在 259 次迭代中的资源申请量为: -20.493087295751188
# agent 33 在 259 次迭代中的资源申请量为: -242.34393000720374
# agent 34 在 259 次迭代中的资源申请量为: 241.1186687058459
# agent 35 在 259 次迭代中的资源申请量为: 272.43303660869776
# agent 36 在 259 次迭代中的资源申请量为: 614.2068903527403
# agent 37 在 259 次迭代中的资源申请量为: 369.72610268047407
# agent 38 在 259 次迭代中的资源申请量为: -4.62593274607201
# agent 39 在 259 次迭代中的资源申请量为: 1943.5517564921172
# agent 40 在 259 次迭代中的资源申请量为: 652.8891145082558
# agent 41 在 259 次迭代中的资源申请量为: -177.6924310592538
# agent 42 在 259 次迭代中的资源申请量为: 257.48343180415594
# agent 43 在 259 次迭代中的资源申请量为: 676.2458709670493
# agent 44 在 259 次迭代中的资源申请量为: 731.6507809664297
# agent 45 在 259 次迭代中的资源申请量为: 861.4774286909638
# agent 46 在 259 次迭代中的资源申请量为: -46.99687068013109
# agent 47 在 259 次迭代中的资源申请量为: 646.404217471036
# agent 48 在 259 次迭代中的资源申请量为: 666.6848331091273
# agent 49 在 259 次迭代中的资源申请量为: -14168.291141272928
# agent 50 在 259 次迭代中的资源申请量为: 785.3691753977187
# agent 51 在 259 次迭代中的资源申请量为: 881.4619072459692
# agent 52 在 259 次迭代中的资源申请量为: 881.4619072459692
# agent 53 在 259 次迭代中的资源申请量为: 150.79969342995045
# agent 54 在 259 次迭代中的资源申请量为: 49.82192096922917
# 资源申请量总和为: 6000.0
# ****************************************************************************
# 成本总和为: 5541034.546892843
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 279 次迭代中的结果：
# agent 1 在 279 次迭代中的资源申请量为: -32.11692905373643
# agent 2 在 279 次迭代中的资源申请量为: -32.11692905373643
# agent 3 在 279 次迭代中的资源申请量为: -32.098369454376495
# agent 4 在 279 次迭代中的资源申请量为: 392.0151404607872
# agent 5 在 279 次迭代中的资源申请量为: 408.8888773922441
# agent 6 在 279 次迭代中的资源申请量为: -31.902878321764284
# agent 7 在 279 次迭代中的资源申请量为: 155.98356780551924
# agent 8 在 279 次迭代中的资源申请量为: -30.34184665064918
# agent 9 在 279 次迭代中的资源申请量为: -26.52016824515334
# agent 10 在 279 次迭代中的资源申请量为: 418.6342872657333
# agent 11 在 279 次迭代中的资源申请量为: 1828.4232097367615
# agent 12 在 279 次迭代中的资源申请量为: -31.020975637864566
# agent 13 在 279 次迭代中的资源申请量为: -31.69976338757205
# agent 14 在 279 次迭代中的资源申请量为: 162.67215129903778
# agent 15 在 279 次迭代中的资源申请量为: -32.04630148061635
# agent 16 在 279 次迭代中的资源申请量为: 154.95477589488016
# agent 17 在 279 次迭代中的资源申请量为: -32.1256808995402
# agent 18 在 279 次迭代中的资源申请量为: -34.99353466255768
# agent 19 在 279 次迭代中的资源申请量为: 164.28862921594953
# agent 20 在 279 次迭代中的资源申请量为: 1810.0401948831927
# agent 21 在 279 次迭代中的资源申请量为: 1472.0710259377709
# agent 22 在 279 次迭代中的资源申请量为: 69.65133661032053
# agent 23 在 279 次迭代中的资源申请量为: 81.05198554481414
# agent 24 在 279 次迭代中的资源申请量为: 767.6967905639267
# agent 25 在 279 次迭代中的资源申请量为: 806.6188644482695
# agent 26 在 279 次迭代中的资源申请量为: 98.05249778537365
# agent 27 在 279 次迭代中的资源申请量为: 646.4018647792685
# agent 28 在 279 次迭代中的资源申请量为: 597.2910973938551
# agent 29 在 279 次迭代中的资源申请量为: 486.63025785771885
# agent 30 在 279 次迭代中的资源申请量为: 88.49358421009958
# agent 31 在 279 次迭代中的资源申请量为: -22.02345953754576
# agent 32 在 279 次迭代中的资源申请量为: -20.511656982673053
# agent 33 在 279 次迭代中的资源申请量为: -243.03142430332096
# agent 34 在 279 次迭代中的资源申请量为: 239.37103125203276
# agent 35 在 279 次迭代中的资源申请量为: 269.31154387238155
# agent 36 在 279 次迭代中的资源申请量为: 606.1511182829778
# agent 37 在 279 次迭代中的资源申请量为: 361.3413726742976
# agent 38 在 279 次迭代中的资源申请量为: -4.664974101873199
# agent 39 在 279 次迭代中的资源申请量为: 2003.6236824734697
# agent 40 在 279 次迭代中的资源申请量为: 644.9016484287179
# agent 41 在 279 次迭代中的资源申请量为: -181.77873900138047
# agent 42 在 279 次迭代中的资源申请量为: 243.82324141269206
# agent 43 在 279 次迭代中的资源申请量为: 665.5361792835569
# agent 44 在 279 次迭代中的资源申请量为: 716.583098788436
# agent 45 在 279 次迭代中的资源申请量为: 844.4252827515454
# agent 46 在 279 次迭代中的资源申请量为: -60.385539315544264
# agent 47 在 279 次迭代中的资源申请量为: 621.5265401074151
# agent 48 在 279 次迭代中的资源申请量为: 644.6219283078838
# agent 49 在 279 次迭代中的资源申请量为: -14218.489736437603
# agent 50 在 279 次迭代中的资源申请量为: 740.1502662230337
# agent 51 在 279 次迭代中的资源申请量为: 841.4016424097546
# agent 52 在 279 次迭代中的资源申请量为: 841.4016424097546
# agent 53 在 279 次迭代中的资源申请量为: 155.60655256553588
# agent 54 在 279 次迭代中的资源申请量为: 48.231996198499345
# 资源申请量总和为: 6000.000000000002
# ****************************************************************************
# 成本总和为: 5576751.398495192
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 299 次迭代中的结果：
# agent 1 在 299 次迭代中的资源申请量为: -31.278988511650848
# agent 2 在 299 次迭代中的资源申请量为: -31.278988511650848
# agent 3 在 299 次迭代中的资源申请量为: -31.26155810090628
# agent 4 在 299 次迭代中的资源申请量为: 398.853422339334
# agent 5 在 299 次迭代中的资源申请量为: 414.20862023696293
# agent 6 在 299 次迭代中的资源申请量为: -31.08282848123939
# agent 7 在 299 次迭代中的资源申请量为: 160.40956184961738
# agent 8 在 299 次迭代中的资源申请量为: -29.63143458104725
# agent 9 在 299 次迭代中的资源申请量为: -26.075030563415247
# agent 10 在 299 次迭代中的资源申请量为: 423.25581905261595
# agent 11 在 299 次迭代中的资源申请量为: 1848.335468676932
# agent 12 在 299 次迭代中的资源申请量为: -30.263503881433948
# agent 13 在 299 次迭代中的资源申请量为: -30.894336528337146
# agent 14 在 299 次迭代中的资源申请量为: 166.62602576686763
# agent 15 在 299 次迭代中的资源申请量为: -31.21826962345324
# agent 16 在 299 次迭代中的资源申请量为: 159.45477985357633
# agent 17 在 299 次迭代中的资源申请量为: -31.291456527056166
# agent 18 在 299 次迭代中的资源申请量为: -33.970090122966425
# agent 19 在 299 次迭代中的资源申请量为: 168.06412830550462
# agent 20 在 299 次迭代中的资源申请量为: 1844.4388403244602
# agent 21 在 299 次迭代中的资源申请量为: 1529.549456857723
# agent 22 在 299 次迭代中的资源申请量为: 79.90888459738613
# agent 23 在 299 次迭代中的资源申请量为: 90.52554435500835
# agent 24 在 299 次迭代中的资源申请量为: 794.1878122102222
# agent 25 在 299 次迭代中的资源申请量为: 830.5859831078719
# agent 26 在 299 次迭代中的资源申请量为: 106.42657827961051
# agent 27 在 299 次迭代中的资源申请量为: 650.9732568113259
# agent 28 在 299 次迭代中的资源申请量为: 605.2533783232433
# agent 29 在 299 次迭代中的资源申请量为: 486.4251135395863
# agent 30 在 299 次迭代中的资源申请量为: 88.36930695427012
# agent 31 在 299 次迭代中的资源申请量为: -21.888852558783643
# agent 32 在 299 次迭代中的资源申请量为: -20.481199940072408
# agent 33 在 299 次迭代中的资源申请量为: -243.647556566611
# agent 34 在 299 次迭代中的资源申请量为: 238.01163057139186
# agent 35 在 299 次迭代中的资源申请量为: 265.7679629846323
# agent 36 在 299 次迭代中的资源申请量为: 597.9027924062657
# agent 37 在 299 次迭代中的资源申请量为: 352.3681324473599
# agent 38 在 299 次迭代中的资源申请量为: -4.888781043475181
# agent 39 在 299 次迭代中的资源申请量为: 2056.4695145574074
# agent 40 在 299 次迭代中的资源申请量为: 637.3242363420852
# agent 41 在 299 次迭代中的资源申请量为: -185.5003100782364
# agent 42 在 299 次迭代中的资源申请量为: 231.2227247173278
# agent 43 在 299 次迭代中的资源申请量为: 654.0801325871515
# agent 44 在 299 次迭代中的资源申请量为: 700.0794481714494
# agent 45 在 299 次迭代中的资源申请量为: 804.790701690848
# agent 46 在 299 次迭代中的资源申请量为: -73.35799769298595
# agent 47 在 299 次迭代中的资源申请量为: 591.0906896917527
# agent 48 在 299 次迭代中的资源申请量为: 600.8453609207323
# agent 49 在 299 次迭代中的资源申请量为: -14192.260605202999
# agent 50 在 299 次迭代中的资源申请量为: 692.3709321768717
# agent 51 在 299 次迭代中的资源申请量为: 802.7507209200638
# agent 52 在 299 次迭代中的资源申请量为: 802.7507209200638
# agent 53 在 299 次迭代中的资源申请量为: 160.05939402510523
# agent 54 在 299 次迭代中的资源申请量为: 46.53471194368642
# 资源申请量总和为: 5999.999999999992
# ****************************************************************************
# 成本总和为: 5552024.665005617
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 319 次迭代中的结果：
# agent 1 在 319 次迭代中的资源申请量为: -30.495969878726864
# agent 2 在 319 次迭代中的资源申请量为: -30.495969878726864
# agent 3 在 319 次迭代中的资源申请量为: -30.47807811590331
# agent 4 在 319 次迭代中的资源申请量为: 405.1024525007755
# agent 5 在 319 次迭代中的资源申请量为: 419.1851648309711
# agent 6 在 319 次迭代中的资源申请量为: -30.313562824591553
# agent 7 在 319 次迭代中的资源申请量为: 164.55704735721957
# agent 8 在 319 次迭代中的资源申请量为: -28.96525124021246
# agent 9 在 319 次迭代中的资源申请量为: -25.64803787138897
# agent 10 在 319 次迭代中的资源申请量为: 427.5735233721568
# agent 11 在 319 次迭代中的资源申请量为: 1866.8566650613109
# agent 12 在 319 次迭代中的资源申请量为: -29.555363795809015
# agent 13 在 319 次迭代中的资源申请量为: -30.13875799521049
# agent 14 在 319 次迭代中的资源申请量为: 170.32051406482884
# agent 15 在 319 次迭代中的资源申请量为: -30.441345391525974
# agent 16 在 319 次迭代中的资源申请量为: 163.66887134505134
# agent 17 在 319 次迭代中的资源申请量为: -30.5087013369791
# agent 18 在 319 次迭代中的资源申请量为: -33.013273180889
# agent 19 在 319 次迭代中的资源申请量为: 171.64095299470483
# agent 20 在 319 次迭代中的资源申请量为: 1876.6064708513675
# agent 21 在 319 次迭代中的资源申请量为: 1583.1436714851125
# agent 22 在 319 次迭代中的资源申请量为: 89.46856021556161
# agent 23 在 319 次迭代中的资源申请量为: 99.35780706099844
# agent 24 在 319 次迭代中的资源申请量为: 818.8799081457678
# agent 25 在 319 次迭代中的资源申请量为: 852.8966188326473
# agent 26 在 319 次迭代中的资源申请量为: 114.21834179096251
# agent 27 在 319 次迭代中的资源申请量为: 655.3754245569949
# agent 28 在 319 次迭代中的资源申请量为: 612.6907741373045
# agent 29 在 319 次迭代中的资源申请量为: 486.62111879239586
# agent 30 在 319 次迭代中的资源申请量为: 88.32288620074183
# agent 31 在 319 次迭代中的资源申请量为: -21.745155250121066
# agent 32 在 319 次迭代中的资源申请量为: -20.433746833844197
# agent 33 在 319 次迭代中的资源申请量为: -244.08916621811616
# agent 34 在 319 次迭代中的资源申请量为: 236.92738009934288
# agent 35 在 319 次迭代中的资源申请量为: 263.1622570904332
# agent 36 在 319 次迭代中的资源申请量为: 589.6662897368603
# agent 37 在 319 次迭代中的资源申请量为: 343.61406662600575
# agent 38 在 319 次迭代中的资源申请量为: -5.059141342913776
# agent 39 在 319 次迭代中的资源申请量为: 2102.972673129636
# agent 40 在 319 次迭代中的资源申请量为: 630.326241114105
# agent 41 在 319 次迭代中的资源申请量为: -189.00541437481303
# agent 42 在 319 次迭代中的资源申请量为: 219.49701462843265
# agent 43 在 319 次迭代中的资源申请量为: 644.4919504468437
# agent 44 在 319 次迭代中的资源申请量为: 685.2385412068033
# agent 45 在 319 次迭代中的资源申请量为: 801.2110901599925
# agent 46 在 319 次迭代中的资源申请量为: -87.97692403576741
# agent 47 在 319 次迭代中的资源申请量为: 564.3249456767292
# agent 48 在 319 次迭代中的资源申请量为: 591.6569913387834
# agent 49 在 319 次迭代中的资源申请量为: -14232.32649620291
# agent 50 在 319 次迭代中的资源申请量为: 648.8121598090706
# agent 51 在 319 次迭代中的资源申请量为: 766.3223524422589
# agent 52 在 319 次迭代中的资源申请量为: 766.3223524422589
# agent 53 在 319 次迭代中的资源申请量为: 164.22976436450608
# agent 54 在 319 次迭代中的资源申请量为: 45.42751185950202
# 资源申请量总和为: 5999.999999999989
# ****************************************************************************
# 成本总和为: 5580738.207263978
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 339 次迭代中的结果：
# agent 1 在 339 次迭代中的资源申请量为: -29.76171947163688
# agent 2 在 339 次迭代中的资源申请量为: -29.76171947163688
# agent 3 在 339 次迭代中的资源申请量为: -29.740492555432397
# agent 4 在 339 次迭代中的资源申请量为: 410.85455201879165
# agent 5 在 339 次迭代中的资源申请量为: 423.8580034026911
# agent 6 在 339 次迭代中的资源申请量为: -29.588043025994242
# agent 7 在 339 次迭代中的资源申请量为: 168.45639243818903
# agent 8 在 339 次迭代中的资源申请量为: -28.336023141061766
# agent 9 在 339 次迭代中的资源申请量为: -25.23450043215924
# agent 10 在 339 次迭代中的资源申请量为: 431.6437892151306
# agent 11 在 339 次迭代中的资源申请量为: 1884.1985244518362
# agent 12 在 339 次迭代中的资源申请量为: -28.888655333986442
# agent 13 在 339 次迭代中的资源申请量为: -29.42557429205054
# agent 14 在 339 次迭代中的资源申请量为: 173.8045780358924
# agent 15 在 339 次迭代中的资源申请量为: -29.707995795135208
# agent 16 在 339 次迭代中的资源申请量为: 167.62764756754595
# ...
# agent 88 在 1969 次迭代中的资源申请量为: 69.76435110386305
# agent 89 在 1969 次迭代中的资源申请量为: 43.34157509339627
# agent 90 在 1969 次迭代中的资源申请量为: 63.4687668842171
# agent 91 在 1969 次迭代中的资源申请量为: 45.91192253757303
# agent 92 在 1969 次迭代中的资源申请量为: 60.84797633601673
# agent 93 在 1969 次迭代中的资源申请量为: 43.54157509339627
# agent 94 在 1969 次迭代中的资源申请量为: -308.0004086474034
# agent 95 在 1969 次迭代中的资源申请量为: 64.56876688421711
# agent 96 在 1969 次迭代中的资源申请量为: 64.7687668842171
# agent 97 在 1969 次迭代中的资源申请量为: 77.29841980305117
# agent 98 在 1969 次迭代中的资源申请量为: 78.09841980305119
# agent 99 在 1969 次迭代中的资源申请量为: 56.113650073377215
# agent 100 在 1969 次迭代中的资源申请量为: 51.927754472110436
# 资源申请量总和为: 5000.000000000601
# ****************************************************************************
# 成本总和为: 481136.24589276453
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1979 次迭代中的结果：
# agent 1 在 1979 次迭代中的资源申请量为: 51.27006707690581
# agent 2 在 1979 次迭代中的资源申请量为: 64.64446590580393
# agent 3 在 1979 次迭代中的资源申请量为: 46.30362914396822
# agent 4 在 1979 次迭代中的资源申请量为: 68.51958062286069
# agent 5 在 1979 次迭代中的资源申请量为: 69.3195806228607
# agent 6 在 1979 次迭代中的资源申请量为: 76.53369684486103
# agent 7 在 1979 次迭代中的资源申请量为: 41.67148344619318
# agent 8 在 1979 次迭代中的资源申请量为: 39.80153963170045
# agent 9 在 1979 次迭代中的资源申请量为: 45.60362914396822
# agent 10 在 1979 次迭代中的资源申请量为: 59.14490298302985
# agent 11 在 1979 次迭代中的资源申请量为: 48.153398835051256
# agent 12 在 1979 次迭代中的资源申请量为: 52.17006707690581
# agent 13 在 1979 次迭代中的资源申请量为: 69.81958062286068
# agent 14 在 1979 次迭代中的资源申请量为: 58.54490298302985
# agent 15 在 1979 次迭代中的资源申请量为: 46.00362914396821
# agent 16 在 1979 次迭代中的资源申请量为: 46.203629143968215
# agent 17 在 1979 次迭代中的资源申请量为: 47.553398835051254
# agent 18 在 1979 次迭代中的资源申请量为: 49.15339883505125
# agent 19 在 1979 次迭代中的资源申请量为: 43.659200342858824
# agent 20 在 1979 次迭代中的资源申请量为: 59.04490298302984
# agent 21 在 1979 次迭代中的资源申请量为: 40.971483446193176
# agent 22 在 1979 次迭代中的资源申请量为: 41.27148344619318
# agent 23 在 1979 次迭代中的资源申请量为: 50.6700670769058
# agent 24 在 1979 次迭代中的资源申请量为: 42.859200342858834
# agent 25 在 1979 次迭代中的资源申请量为: 47.853398835051244
# agent 26 在 1979 次迭代中的资源申请量为: 41.97148344619318
# agent 27 在 1979 次迭代中的资源申请量为: 69.51958062286069
# agent 28 在 1979 次迭代中的资源申请量为: 54.432751587925196
# agent 29 在 1979 次迭代中的资源申请量为: 43.15920034285884
# agent 30 在 1979 次迭代中的资源申请量为: 41.37148344619318
# agent 31 在 1979 次迭代中的资源申请量为: 64.04446590580393
# agent 32 在 1979 次迭代中的资源申请量为: 58.84490298302985
# agent 33 在 1979 次迭代中的资源申请量为: 43.959200342858836
# agent 34 在 1979 次迭代中的资源申请量为: 55.33275158792521
# agent 35 在 1979 次迭代中的资源申请量为: 41.07148344619318
# agent 36 在 1979 次迭代中的资源申请量为: 45.30362914396822
# agent 37 在 1979 次迭代中的资源申请量为: 55.6327515879252
# agent 38 在 1979 次迭代中的资源申请量为: 42.65920034285883
# agent 39 在 1979 次迭代中的资源申请量为: 45.803629143968216
# agent 40 在 1979 次迭代中的资源申请量为: 52.9700670769058
# agent 41 在 1979 次迭代中的资源申请量为: 70.21958062286068
# agent 42 在 1979 次迭代中的资源申请量为: 45.00362914396821
# agent 43 在 1979 次迭代中的资源申请量为: 54.832751587925195
# agent 44 在 1979 次迭代中的资源申请量为: 56.032751587925205
# agent 45 在 1979 次迭代中的资源申请量为: 51.0700670769058
# agent 46 在 1979 次迭代中的资源申请量为: 59.144902983029844
# agent 47 在 1979 次迭代中的资源申请量为: 48.55339883505125
# agent 48 在 1979 次迭代中的资源申请量为: 45.90362914396821
# agent 49 在 1979 次迭代中的资源申请量为: 45.203629143968215
# agent 50 在 1979 次迭代中的资源申请量为: 43.25920034285883
# agent 51 在 1979 次迭代中的资源申请量为: 51.1700670769058
# agent 52 在 1979 次迭代中的资源申请量为: 59.04490298302985
# agent 53 在 1979 次迭代中的资源申请量为: 41.17148344619318
# agent 54 在 1979 次迭代中的资源申请量为: 60.24490298302985
# agent 55 在 1979 次迭代中的资源申请量为: 75.43369684486102
# agent 56 在 1979 次迭代中的资源申请量为: 43.25920034285883
# agent 57 在 1979 次迭代中的资源申请量为: 64.04446590580392
# agent 58 在 1979 次迭代中的资源申请量为: 44.70362914396822
# agent 59 在 1979 次迭代中的资源申请量为: 50.770067076905804
# agent 60 在 1979 次迭代中的资源申请量为: 59.344902983029854
# agent 61 在 1979 次迭代中的资源申请量为: 69.91958062286068
# agent 62 在 1979 次迭代中的资源申请量为: 48.753398835051264
# agent 63 在 1979 次迭代中的资源申请量为: 41.17148344619318
# agent 64 在 1979 次迭代中的资源申请量为: 47.053398835051254
# agent 65 在 1979 次迭代中的资源申请量为: 45.203629143968215
# agent 66 在 1979 次迭代中的资源申请量为: 69.61958062286068
# agent 67 在 1979 次迭代中的资源申请量为: 45.80362914396822
# agent 68 在 1979 次迭代中的资源申请量为: 47.55339883505127
# agent 69 在 1979 次迭代中的资源申请量为: 48.05339883505126
# agent 70 在 1979 次迭代中的资源申请量为: 63.644465905803926
# agent 71 在 1979 次迭代中的资源申请量为: 76.43369684486102
# agent 72 在 1979 次迭代中的资源申请量为: 63.84446590580392
# agent 73 在 1979 次迭代中的资源申请量为: 46.20362914396822
# agent 74 在 1979 次迭代中的资源申请量为: 41.171483446193186
# agent 75 在 1979 次迭代中的资源申请量为: 55.032751587925205
# agent 76 在 1979 次迭代中的资源申请量为: 49.65339883505126
# agent 77 在 1979 次迭代中的资源申请量为: 43.15920034285884
# agent 78 在 1979 次迭代中的资源申请量为: 52.470067076905806
# agent 79 在 1979 次迭代中的资源申请量为: 45.30362914396822
# agent 80 在 1979 次迭代中的资源申请量为: 45.503629143968226
# agent 81 在 1979 次迭代中的资源申请量为: 41.671483446193186
# agent 82 在 1979 次迭代中的资源申请量为: 48.353398835051266
# agent 83 在 1979 次迭代中的资源申请量为: 43.95920034285884
# agent 84 在 1979 次迭代中的资源申请量为: 55.132751587925206
# agent 85 在 1979 次迭代中的资源申请量为: 59.04490298302986
# agent 86 在 1979 次迭代中的资源申请量为: 51.7700670769058
# agent 87 在 1979 次迭代中的资源申请量为: 64.04446590580393
# agent 88 在 1979 次迭代中的资源申请量为: 69.11958062286068
# agent 89 在 1979 次迭代中的资源申请量为: 42.85920034285884
# agent 90 在 1979 次迭代中的资源申请量为: 62.84446590580392
# agent 91 在 1979 次迭代中的资源申请量为: 45.403629143968224
# agent 92 在 1979 次迭代中的资源申请量为: 60.24490298302986
# agent 93 在 1979 次迭代中的资源申请量为: 43.05920034285884
# agent 94 在 1979 次迭代中的资源申请量为: -253.3500670157153
# agent 95 在 1979 次迭代中的资源申请量为: 63.94446590580393
# agent 96 在 1979 次迭代中的资源申请量为: 64.14446590580393
# agent 97 在 1979 次迭代中的资源申请量为: 76.63369684486102
# agent 98 在 1979 次迭代中的资源申请量为: 77.43369684486105
# agent 99 在 1979 次迭代中的资源申请量为: 55.53275158792522
# agent 100 在 1979 次迭代中的资源申请量为: 51.37006707690581
# 资源申请量总和为: 5000.000000000602
# ****************************************************************************
# 成本总和为: 441946.8613739335
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1989 次迭代中的结果：
# agent 1 在 1989 次迭代中的资源申请量为: 51.81250604681149
# agent 2 在 1989 次迭代中的资源申请量为: 65.24496186474043
# agent 3 在 1989 次迭代中的资源申请量为: 46.814861447814465
# agent 4 在 1989 次迭代中的资源申请量为: 69.14183618751233
# agent 5 在 1989 次迭代中的资源申请量为: 69.94183618751232
# agent 6 在 1989 次迭代中的资源申请量为: 77.17891072059015
# agent 7 在 1989 次迭代中的资源申请量为: 42.16128552459087
# agent 8 在 1989 次迭代中的资源申请量为: 40.285782381452655
# agent 9 在 1989 次迭代中的资源申请量为: 46.11486144781447
# agent 10 在 1989 次迭代中的资源申请量为: 59.724826598156646
# agent 11 在 1989 次迭代中的资源申请量为: 48.679274655980436
# agent 12 在 1989 次迭代中的资源申请量为: 52.7125060468115
# agent 13 在 1989 次迭代中的资源申请量为: 70.44183618751232
# agent 14 在 1989 次迭代中的资源申请量为: 59.12482659815663
# agent 15 在 1989 次迭代中的资源申请量为: 46.514861447814454
# agent 16 在 1989 次迭代中的资源申请量为: 46.71486144781446
# agent 17 在 1989 次迭代中的资源申请量为: 48.079274655980434
# agent 18 在 1989 次迭代中的资源申请量为: 49.67927465598043
# agent 19 在 1989 次迭代中的资源申请量为: 44.15821180713581
# agent 20 在 1989 次迭代中的资源申请量为: 59.624826598156645
# agent 21 在 1989 次迭代中的资源申请量为: 41.46128552459088
# agent 22 在 1989 次迭代中的资源申请量为: 41.76128552459088
# agent 23 在 1989 次迭代中的资源申请量为: 51.21250604681149
# agent 24 在 1989 次迭代中的资源申请量为: 43.35821180713581
# agent 25 在 1989 次迭代中的资源申请量为: 48.37927465598044
# agent 26 在 1989 次迭代中的资源申请量为: 42.46128552459088
# agent 27 在 1989 次迭代中的资源申请量为: 70.14183618751233
# agent 28 在 1989 次迭代中的资源申请量为: 54.99328822336203
# agent 29 在 1989 次迭代中的资源申请量为: 43.658211807135814
# agent 30 在 1989 次迭代中的资源申请量为: 41.861285524590876
# agent 31 在 1989 次迭代中的资源申请量为: 64.64496186474042
# agent 32 在 1989 次迭代中的资源申请量为: 59.42482659815665
# agent 33 在 1989 次迭代中的资源申请量为: 44.45821180713582
# agent 34 在 1989 次迭代中的资源申请量为: 55.89328822336204
# agent 35 在 1989 次迭代中的资源申请量为: 41.56128552459088
# agent 36 在 1989 次迭代中的资源申请量为: 45.81486144781447
# agent 37 在 1989 次迭代中的资源申请量为: 56.193288223362046
# agent 38 在 1989 次迭代中的资源申请量为: 43.15821180713583
# agent 39 在 1989 次迭代中的资源申请量为: 46.31486144781447
# agent 40 在 1989 次迭代中的资源申请量为: 53.512506046811495
# agent 41 在 1989 次迭代中的资源申请量为: 70.84183618751233
# agent 42 在 1989 次迭代中的资源申请量为: 45.514861447814475
# agent 43 在 1989 次迭代中的资源申请量为: 55.39328822336204
# agent 44 在 1989 次迭代中的资源申请量为: 56.593288223362045
# agent 45 在 1989 次迭代中的资源申请量为: 51.61250604681151
# agent 46 在 1989 次迭代中的资源申请量为: 59.72482659815666
# agent 47 在 1989 次迭代中的资源申请量为: 49.079274655980456
# agent 48 在 1989 次迭代中的资源申请量为: 46.414861447814474
# agent 49 在 1989 次迭代中的资源申请量为: 45.71486144781447
# agent 50 在 1989 次迭代中的资源申请量为: 43.75821180713582
# agent 51 在 1989 次迭代中的资源申请量为: 51.71250604681151
# agent 52 在 1989 次迭代中的资源申请量为: 59.62482659815666
# agent 53 在 1989 次迭代中的资源申请量为: 41.66128552459089
# agent 54 在 1989 次迭代中的资源申请量为: 60.82482659815666
# agent 55 在 1989 次迭代中的资源申请量为: 76.07891072059017
# agent 56 在 1989 次迭代中的资源申请量为: 43.75821180713582
# agent 57 在 1989 次迭代中的资源申请量为: 64.64496186474044
# agent 58 在 1989 次迭代中的资源申请量为: 45.21486144781448
# agent 59 在 1989 次迭代中的资源申请量为: 51.3125060468115
# agent 60 在 1989 次迭代中的资源申请量为: 59.924826598156656
# agent 61 在 1989 次迭代中的资源申请量为: 70.54183618751233
# agent 62 在 1989 次迭代中的资源申请量为: 49.27927465598045
# agent 63 在 1989 次迭代中的资源申请量为: 41.66128552459088
# agent 64 在 1989 次迭代中的资源申请量为: 47.57927465598044
# agent 65 在 1989 次迭代中的资源申请量为: 45.714861447814464
# agent 66 在 1989 次迭代中的资源申请量为: 70.24183618751233
# agent 67 在 1989 次迭代中的资源申请量为: 46.314861447814465
# agent 68 在 1989 次迭代中的资源申请量为: 48.07927465598044
# agent 69 在 1989 次迭代中的资源申请量为: 48.57927465598044
# agent 70 在 1989 次迭代中的资源申请量为: 64.24496186474042
# agent 71 在 1989 次迭代中的资源申请量为: 77.07891072059016
# agent 72 在 1989 次迭代中的资源申请量为: 64.44496186474042
# agent 73 在 1989 次迭代中的资源申请量为: 46.71486144781446
# agent 74 在 1989 次迭代中的资源申请量为: 41.66128552459087
# agent 75 在 1989 次迭代中的资源申请量为: 55.59328822336203
# agent 76 在 1989 次迭代中的资源申请量为: 50.179274655980436
# agent 77 在 1989 次迭代中的资源申请量为: 43.65821180713581
# agent 78 在 1989 次迭代中的资源申请量为: 53.01250604681148
# agent 79 在 1989 次迭代中的资源申请量为: 45.81486144781445
# agent 80 在 1989 次迭代中的资源申请量为: 46.014861447814454
# agent 81 在 1989 次迭代中的资源申请量为: 42.161285524590866
# agent 82 在 1989 次迭代中的资源申请量为: 48.879274655980424
# agent 83 在 1989 次迭代中的资源申请量为: 44.4582118071358
# agent 84 在 1989 次迭代中的资源申请量为: 55.69328822336202
# agent 85 在 1989 次迭代中的资源申请量为: 59.62482659815663
# agent 86 在 1989 次迭代中的资源申请量为: 52.31250604681147
# agent 87 在 1989 次迭代中的资源申请量为: 64.64496186474041
# agent 88 在 1989 次迭代中的资源申请量为: 69.74183618751232
# agent 89 在 1989 次迭代中的资源申请量为: 43.358211807135795
# agent 90 在 1989 次迭代中的资源申请量为: 63.444961864740414
# agent 91 在 1989 次迭代中的资源申请量为: 45.91486144781446
# agent 92 在 1989 次迭代中的资源申请量为: 60.82482659815664
# agent 93 在 1989 次迭代中的资源申请量为: 43.558211807135805
# agent 94 在 1989 次迭代中的资源申请量为: -307.502304008354
# agent 95 在 1989 次迭代中的资源申请量为: 64.54496186474043
# agent 96 在 1989 次迭代中的资源申请量为: 64.74496186474042
# agent 97 在 1989 次迭代中的资源申请量为: 77.27891072059015
# agent 98 在 1989 次迭代中的资源申请量为: 78.07891072059016
# agent 99 在 1989 次迭代中的资源申请量为: 56.09328822336204
# agent 100 在 1989 次迭代中的资源申请量为: 51.912506046811494
# 资源申请量总和为: 5000.00000000061
# ****************************************************************************
# 成本总和为: 480751.6150944412
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1999 次迭代中的结果：
# agent 1 在 1999 次迭代中的资源申请量为: 52.28750300959567
# agent 2 在 1999 次迭代中的资源申请量为: 65.70719386224265
# agent 3 在 1999 次迭代中的资源申请量为: 47.304555671293876
# agent 4 在 1999 次迭代中的资源申请量为: 69.60066380940363
# agent 5 在 1999 次迭代中的资源申请量为: 70.40066380940364
# agent 6 在 1999 次迭代中的资源申请量为: 77.63334677440892
# agent 7 在 1999 次迭代中的资源申请量为: 42.66967264487908
# agent 8 在 1999 次迭代中的资源申请量为: 40.803782278606974
# agent 9 在 1999 次迭代中的资源申请量为: 46.60455567129387
# agent 10 在 1999 次迭代中的资源申请量为: 60.19043448649229
# agent 11 在 1999 次迭代中的资源申请量为: 49.16095600731385
# agent 12 在 1999 次迭代中的资源申请量为: 53.18750300959567
# agent 13 在 1999 次迭代中的资源申请量为: 70.90066380940364
# agent 14 在 1999 次迭代中的资源申请量为: 59.590434486492285
# agent 15 在 1999 次迭代中的资源申请量为: 47.00455567129387
# agent 16 在 1999 次迭代中的资源申请量为: 47.20455567129387
# agent 17 在 1999 次迭代中的资源申请量为: 48.560956007313855
# agent 18 在 1999 次迭代中的资源申请量为: 50.16095600731384
# agent 19 在 1999 次迭代中的资源申请量为: 44.65696275413371
# agent 20 在 1999 次迭代中的资源申请量为: 60.09043448649229
# agent 21 在 1999 次迭代中的资源申请量为: 41.969672644879076
# agent 22 在 1999 次迭代中的资源申请量为: 42.26967264487908
# agent 23 在 1999 次迭代中的资源申请量为: 51.687503009595666
# agent 24 在 1999 次迭代中的资源申请量为: 43.856962754133704
# agent 25 在 1999 次迭代中的资源申请量为: 48.86095600731384
# agent 26 在 1999 次迭代中的资源申请量为: 42.969672644879076
# agent 27 在 1999 次迭代中的资源申请量为: 70.60066380940364
# agent 28 在 1999 次迭代中的资源申请量为: 55.46299243299678
# agent 29 在 1999 次迭代中的资源申请量为: 44.15696275413371
# agent 30 在 1999 次迭代中的资源申请量为: 42.369672644879074
# agent 31 在 1999 次迭代中的资源申请量为: 65.10719386224265
# agent 32 在 1999 次迭代中的资源申请量为: 59.89043448649229
# agent 33 在 1999 次迭代中的资源申请量为: 44.95696275413371
# agent 34 在 1999 次迭代中的资源申请量为: 56.36299243299679
# agent 35 在 1999 次迭代中的资源申请量为: 42.06967264487908
# agent 36 在 1999 次迭代中的资源申请量为: 46.30455567129387
# agent 37 在 1999 次迭代中的资源申请量为: 56.66299243299678
# agent 38 在 1999 次迭代中的资源申请量为: 43.65696275413371
# agent 39 在 1999 次迭代中的资源申请量为: 46.80455567129387
# agent 40 在 1999 次迭代中的资源申请量为: 53.987503009595656
# agent 41 在 1999 次迭代中的资源申请量为: 71.30066380940363
# agent 42 在 1999 次迭代中的资源申请量为: 46.00455567129386
# agent 43 在 1999 次迭代中的资源申请量为: 55.862992432996776
# agent 44 在 1999 次迭代中的资源申请量为: 57.06299243299678
# agent 45 在 1999 次迭代中的资源申请量为: 52.087503009595665
# agent 46 在 1999 次迭代中的资源申请量为: 60.19043448649228
# agent 47 在 1999 次迭代中的资源申请量为: 49.560956007313834
# agent 48 在 1999 次迭代中的资源申请量为: 46.90455567129386
# agent 49 在 1999 次迭代中的资源申请量为: 46.20455567129386
# agent 50 在 1999 次迭代中的资源申请量为: 44.256962754133696
# agent 51 在 1999 次迭代中的资源申请量为: 52.18750300959566
# agent 52 在 1999 次迭代中的资源申请量为: 60.090434486492285
# agent 53 在 1999 次迭代中的资源申请量为: 42.16967264487907
# agent 54 在 1999 次迭代中的资源申请量为: 61.29043448649229
# agent 55 在 1999 次迭代中的资源申请量为: 76.53334677440893
# agent 56 在 1999 次迭代中的资源申请量为: 44.256962754133696
# agent 57 在 1999 次迭代中的资源申请量为: 65.10719386224265
# agent 58 在 1999 次迭代中的资源申请量为: 45.70455567129387
# agent 59 在 1999 次迭代中的资源申请量为: 51.78750300959566
# agent 60 在 1999 次迭代中的资源申请量为: 60.39043448649228
# agent 61 在 1999 次迭代中的资源申请量为: 71.00066380940363
# agent 62 在 1999 次迭代中的资源申请量为: 49.76095600731384
# agent 63 在 1999 次迭代中的资源申请量为: 42.16967264487907
# agent 64 在 1999 次迭代中的资源申请量为: 48.06095600731384
# agent 65 在 1999 次迭代中的资源申请量为: 46.20455567129387
# agent 66 在 1999 次迭代中的资源申请量为: 70.70066380940365
# agent 67 在 1999 次迭代中的资源申请量为: 46.80455567129387
# agent 68 在 1999 次迭代中的资源申请量为: 48.560956007313855
# agent 69 在 1999 次迭代中的资源申请量为: 49.06095600731385
# agent 70 在 1999 次迭代中的资源申请量为: 64.70719386224265
# agent 71 在 1999 次迭代中的资源申请量为: 77.53334677440894
# agent 72 在 1999 次迭代中的资源申请量为: 64.90719386224265
# agent 73 在 1999 次迭代中的资源申请量为: 47.20455567129387
# agent 74 在 1999 次迭代中的资源申请量为: 42.16967264487908
# agent 75 在 1999 次迭代中的资源申请量为: 56.062992432996786
# agent 76 在 1999 次迭代中的资源申请量为: 50.66095600731385
# agent 77 在 1999 次迭代中的资源申请量为: 44.156962754133716
# agent 78 在 1999 次迭代中的资源申请量为: 53.48750300959567
# agent 79 在 1999 次迭代中的资源申请量为: 46.304555671293876
# agent 80 在 1999 次迭代中的资源申请量为: 46.50455567129388
# agent 81 在 1999 次迭代中的资源申请量为: 42.669672644879086
# agent 82 在 1999 次迭代中的资源申请量为: 49.36095600731386
# agent 83 在 1999 次迭代中的资源申请量为: 44.95696275413372
# agent 84 在 1999 次迭代中的资源申请量为: 56.162992432996795
# agent 85 在 1999 次迭代中的资源申请量为: 60.090434486492306
# agent 86 在 1999 次迭代中的资源申请量为: 52.787503009595675
# agent 87 在 1999 次迭代中的资源申请量为: 65.10719386224267
# agent 88 在 1999 次迭代中的资源申请量为: 70.20066380940365
# agent 89 在 1999 次迭代中的资源申请量为: 43.85696275413372
# agent 90 在 1999 次迭代中的资源申请量为: 63.90719386224266
# agent 91 在 1999 次迭代中的资源申请量为: 46.40455567129388
# agent 92 在 1999 次迭代中的资源申请量为: 61.2904344864923
# agent 93 在 1999 次迭代中的资源申请量为: 44.056962754133714
# agent 94 在 1999 次迭代中的资源申请量为: -354.99060937572244
# agent 95 在 1999 次迭代中的资源申请量为: 65.00719386224264
# agent 96 在 1999 次迭代中的资源申请量为: 65.20719386224265
# agent 97 在 1999 次迭代中的资源申请量为: 77.73334677440893
# agent 98 在 1999 次迭代中的资源申请量为: 78.53334677440893
# agent 99 在 1999 次迭代中的资源申请量为: 56.56299243299678
# agent 100 在 1999 次迭代中的资源申请量为: 52.38750300959567
# 资源申请量总和为: 5000.000000000611
# ****************************************************************************
# 成本总和为: 519680.87715154316
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 2025-01-21 17:29:43.153

# %%
np.savetxt('../data/03-agent_resource_quantity_large_value_Gaussian_bias(800,10).txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/03-sum_cost_large_value_Gaussian_bias(800,10).txt',sum_cost,fmt='%0.8f')#用户成本总和 
np.savetxt('../data/03-sum_resource_large_value_Gaussian_bias(800,10).txt',sum_resource,fmt='%0.8f')#用户资源总和 
np.savetxt('../data/03-agent_gradient_large_value_Gaussian_bias(800,10).txt',agent_gradient,fmt='%0.8f')#用户迭代梯度
