# %% [raw]
# 大值的确定性噪声+鲁棒算法ARC

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(54,2000), dtype=np.float64) #100个agent的资源量 定义成一个矩阵
sum_resource=np.zeros(shape=(1,2000), dtype=np.float64)#存放每一次迭代后所有用户资源量的总和
sum_cost=np.zeros(shape=(1,2000), dtype=np.float64)#存放每一次迭代后所有用户成本的总和
iteration_update = 1 #迭代步长 
A=np.loadtxt("Adjacency_Matrix_generator_zero.txt") #网络拓扑的邻接矩阵 对角元素要为0
D=np.zeros(shape=(54,54))# 网络的度矩阵
L=np.zeros(shape=(54,54))# 网络的拉普拉斯矩阵 L=D-A
W=np.zeros(shape=(54,54)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
iteration=[]#绘图横坐标
generator_a_values= np.loadtxt("generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("generator_b_values.txt")#每个agent的成本函数中的超参数a
generator_c_values= np.loadtxt("generator_c_values.txt")#每个agent的成本函数中的超参数a
agent_gradient=np.zeros(shape=(54,2000), dtype=np.float64) 
bias=800
C=np.zeros(shape=(1,2000), dtype=np.float64)#adaptive robust clipping的裁剪参数 
#设置为全局第b大的梯度信息 b为网络中设备损坏的用户上界 每一次迭代就需要计算一次新的C值

# %%
#根据邻接矩阵生成网络对应的度矩阵
for i in range(0,54):
    d=0
    for j in range(0,54):
        if A[i][j]==1:
            d=d+1
    D[i][i]=d

#根据邻接矩阵和度矩阵计算拉普拉斯矩阵
L=D-A

#选择用拉普拉斯矩阵作为聚合矩阵
W=L
    
#资源量的初始化 需要给定可行的初始化 即满足平均资源约束
for i in range (0,54):
    agent_resource_quantity[i][0]=6000/54
    
#总资源量 初始化
sum=0
for i in range (0,54):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

iteration.append(0)

#初始梯度计算 随机选择一个用户作为biased 用户
for i in range (0,54):
    if i==48:
        agent_gradient[i][0]=2*generator_c_values[i]*agent_resource_quantity[i][0]+generator_b_values[i]+bias
    else:
        agent_gradient[i][0]=2*generator_c_values[i]*agent_resource_quantity[i][0]+generator_b_values[i]
        
#用户总成本初始化
sum=0
for i in range(0,54):
    sum=sum+(generator_c_values[i]*(agent_resource_quantity[i][0])*(agent_resource_quantity[i][0])+generator_b_values[i]*agent_resource_quantity[i][0]+generator_a_values[i])
sum_cost[0][0]=sum
    
#计算初始的C值 因为网络中噪声用户的数量为1 所以选择第4大的梯度作为clipping的阈值
column_data = agent_gradient[:, 0]
second_largest = np.partition(np.abs(column_data), -2)[-2]
C[0][0]=second_largest

# %%
#基于初始化的权重梯度下降无中心资源分配算法
def IWDGD_deterministic_bias_C(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias,C):
    
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************IWDGD算法+计算误差+鲁棒****************************")
    print("相关变量初始值为：")
    for i in range (0,54):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,2000):#迭代次数
        iteration.append(k)
 
        #所有用户资源申请量基于可行初始化权重梯度下降的迭代  假设部分用户因为设备损坏 导致梯度的计算有误差     
        for i in range (0,54):
            weight_gradient_sum = np.float64(0)
            for j in range (0,54):  
                if np.abs(agent_gradient[j][k-1])>C[0][k-1]:
                    weight_gradient_sum=weight_gradient_sum+W[i][j]*(C[0][k-1]/np.abs(agent_gradient[j][k-1])*agent_gradient[j][k-1])
                else:
                    weight_gradient_sum=weight_gradient_sum+W[i][j]*agent_gradient[j][k-1]                   
                #weight_gradient_sum = np.round(weight_gradient_sum, decimals=3)
            agent_resource_quantity[i][k]=agent_resource_quantity[i][k-1]-iteration_update*weight_gradient_sum
                #agent_resource_quantity[i][k] = np.round(agent_resource_quantity[i][k], decimals=3)                      
        
        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,54):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,54):
            sum2=sum2+(generator_c_values[i]*(agent_resource_quantity[i][k])*(agent_resource_quantity[i][k])+generator_b_values[i]*agent_resource_quantity[i][k]+generator_a_values[i])
        sum_cost[0][k]=sum2
        
        #计算当前迭代的用户梯度
        for i in range (0,54): 
            if i==48:
                agent_gradient[i][k]=2*generator_c_values[i]*agent_resource_quantity[i][k]+generator_b_values[i]+bias
            else:
                agent_gradient[i][k]=2*generator_c_values[i]*agent_resource_quantity[i][k]+generator_b_values[i]
                
        #计算当前迭代的C值
        column_data = agent_gradient[:, k]
        second_largest = np.partition(np.abs(column_data), -2)[-2]
        C[0][k]=second_largest
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%20==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,54):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=1/(pow(k+1,0.05)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
IWDGD_deterministic_bias_C(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias,C)
# Out:
# ****************************IWDGD算法+计算误差+鲁棒****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 111.11111111111111
# agent 2 的初始资源申请量为: 111.11111111111111
# agent 3 的初始资源申请量为: 111.11111111111111
# agent 4 的初始资源申请量为: 111.11111111111111
# agent 5 的初始资源申请量为: 111.11111111111111
# agent 6 的初始资源申请量为: 111.11111111111111
# agent 7 的初始资源申请量为: 111.11111111111111
# agent 8 的初始资源申请量为: 111.11111111111111
# agent 9 的初始资源申请量为: 111.11111111111111
# agent 10 的初始资源申请量为: 111.11111111111111
# agent 11 的初始资源申请量为: 111.11111111111111
# agent 12 的初始资源申请量为: 111.11111111111111
# agent 13 的初始资源申请量为: 111.11111111111111
# agent 14 的初始资源申请量为: 111.11111111111111
# agent 15 的初始资源申请量为: 111.11111111111111
# agent 16 的初始资源申请量为: 111.11111111111111
# agent 17 的初始资源申请量为: 111.11111111111111
# agent 18 的初始资源申请量为: 111.11111111111111
# agent 19 的初始资源申请量为: 111.11111111111111
# agent 20 的初始资源申请量为: 111.11111111111111
# agent 21 的初始资源申请量为: 111.11111111111111
# agent 22 的初始资源申请量为: 111.11111111111111
# agent 23 的初始资源申请量为: 111.11111111111111
# agent 24 的初始资源申请量为: 111.11111111111111
# agent 25 的初始资源申请量为: 111.11111111111111
# agent 26 的初始资源申请量为: 111.11111111111111
# agent 27 的初始资源申请量为: 111.11111111111111
# agent 28 的初始资源申请量为: 111.11111111111111
# agent 29 的初始资源申请量为: 111.11111111111111
# agent 30 的初始资源申请量为: 111.11111111111111
# agent 31 的初始资源申请量为: 111.11111111111111
# agent 32 的初始资源申请量为: 111.11111111111111
# agent 33 的初始资源申请量为: 111.11111111111111
# agent 34 的初始资源申请量为: 111.11111111111111
# agent 35 的初始资源申请量为: 111.11111111111111
# agent 36 的初始资源申请量为: 111.11111111111111
# agent 37 的初始资源申请量为: 111.11111111111111
# agent 38 的初始资源申请量为: 111.11111111111111
# agent 39 的初始资源申请量为: 111.11111111111111
# agent 40 的初始资源申请量为: 111.11111111111111
# agent 41 的初始资源申请量为: 111.11111111111111
# agent 42 的初始资源申请量为: 111.11111111111111
# agent 43 的初始资源申请量为: 111.11111111111111
# agent 44 的初始资源申请量为: 111.11111111111111
# agent 45 的初始资源申请量为: 111.11111111111111
# agent 46 的初始资源申请量为: 111.11111111111111
# agent 47 的初始资源申请量为: 111.11111111111111
# agent 48 的初始资源申请量为: 111.11111111111111
# agent 49 的初始资源申请量为: 111.11111111111111
# agent 50 的初始资源申请量为: 111.11111111111111
# agent 51 的初始资源申请量为: 111.11111111111111
# agent 52 的初始资源申请量为: 111.11111111111111
# agent 53 的初始资源申请量为: 111.11111111111111
# agent 54 的初始资源申请量为: 111.11111111111111
# *************************
# 初始资源申请量总和为: 6000.000000000006
# *************************
# 初始成本总和为: 139226.02283950621
# *************************
# 迭代步长为: 1
# *****************************************************************************
# 19 次迭代中的结果：
# agent 1 在 19 次迭代中的资源申请量为: -54.172604271121735
# agent 2 在 19 次迭代中的资源申请量为: -54.172604271121735
# agent 3 在 19 次迭代中的资源申请量为: -57.53179389741818
# agent 4 在 19 次迭代中的资源申请量为: 188.98011109663244
# agent 5 在 19 次迭代中的资源申请量为: 268.51350562308386
# agent 6 在 19 次迭代中的资源申请量为: -53.20698265724077
# agent 7 在 19 次迭代中的资源申请量为: 46.87012224784495
# agent 8 在 19 次迭代中的资源申请量为: -43.199123631910176
# agent 9 在 19 次迭代中的资源申请量为: -33.100771928145605
# agent 10 在 19 次迭代中的资源申请量为: 338.47075316613535
# agent 11 在 19 次迭代中的资源申请量为: 1053.7380555194632
# agent 12 在 19 次迭代中的资源申请量为: -44.390156011093175
# agent 13 在 19 次迭代中的资源申请量为: -51.12564433728686
# agent 14 在 19 次迭代中的资源申请量为: 113.08782801220575
# agent 15 在 19 次迭代中的资源申请量为: -62.42467322386163
# agent 16 在 19 次迭代中的资源申请量为: 32.85141203095347
# agent 17 在 19 次迭代中的资源申请量为: -55.68794851818711
# agent 18 在 19 次迭代中的资源申请量为: -67.76334503197018
# agent 19 在 19 次迭代中的资源申请量为: 30.62176678343429
# agent 20 在 19 次迭代中的资源申请量为: 598.0888590676449
# agent 21 在 19 次迭代中的资源申请量为: 332.53249255330246
# agent 22 在 19 次迭代中的资源申请量为: -50.966500756849
# agent 23 在 19 次迭代中的资源申请量为: -71.27898560341738
# agent 24 在 19 次迭代中的资源申请量为: 271.8245057030947
# agent 25 在 19 次迭代中的资源申请量为: 226.2069503989774
# agent 26 在 19 次迭代中的资源申请量为: -73.793409459927
# agent 27 在 19 次迭代中的资源申请量为: 470.5713792680261
# agent 28 在 19 次迭代中的资源申请量为: 308.0222905797318
# agent 29 在 19 次迭代中的资源申请量为: 349.7759077819615
# agent 30 在 19 次迭代中的资源申请量为: 77.8720621546953
# agent 31 在 19 次迭代中的资源申请量为: -20.19678183771703
# agent 32 在 19 次迭代中的资源申请量为: -15.039808300011465
# agent 33 在 19 次迭代中的资源申请量为: -269.66817147994783
# agent 34 在 19 次迭代中的资源申请量为: 189.45274596596542
# agent 35 在 19 次迭代中的资源申请量为: 152.659253188446
# agent 36 在 19 次迭代中的资源申请量为: 319.9031594042568
# agent 37 在 19 次迭代中的资源申请量为: 80.19028919592115
# agent 38 在 19 次迭代中的资源申请量为: -63.418254078795904
# agent 39 在 19 次迭代中的资源申请量为: 264.57079982339
# agent 40 在 19 次迭代中的资源申请量为: 336.95299475206207
# agent 41 在 19 次迭代中的资源申请量为: -231.97952964808604
# agent 42 在 19 次迭代中的资源申请量为: 81.1614269813106
# agent 43 在 19 次迭代中的资源申请量为: 307.2592646660914
# agent 44 在 19 次迭代中的资源申请量为: 244.07620690693898
# agent 45 在 19 次迭代中的资源申请量为: 415.390085501416
# agent 46 在 19 次迭代中的资源申请量为: -252.08633875410703
# agent 47 在 19 次迭代中的资源申请量为: 205.02106112563413
# agent 48 在 19 次迭代中的资源申请量为: 242.5862639342724
# agent 49 在 19 次迭代中的资源申请量为: -234.8755325276551
# agent 50 在 19 次迭代中的资源申请量为: 40.14849311992369
# agent 51 在 19 次迭代中的资源申请量为: 169.59177609033225
# agent 52 在 19 次迭代中的资源申请量为: 169.59177609033225
# agent 53 在 19 次迭代中的资源申请量为: 40.158534161000375
# agent 54 在 19 次迭代中的资源申请量为: -106.66317266860955
# 资源申请量总和为: 6000.000000000002
# ****************************************************************************
# 成本总和为: 76457.23795475191
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 39 次迭代中的结果：
# agent 1 在 39 次迭代中的资源申请量为: -57.994060034205916
# agent 2 在 39 次迭代中的资源申请量为: -57.994060034205916
# agent 3 在 39 次迭代中的资源申请量为: -57.38332891370432
# agent 4 在 39 次迭代中的资源申请量为: 208.68522274734644
# agent 5 在 39 次迭代中的资源申请量为: 244.16392021077064
# agent 6 在 39 次迭代中的资源申请量为: -57.464294362083635
# agent 7 在 39 次迭代中的资源申请量为: 18.86406359754204
# agent 8 在 39 次迭代中的资源申请量为: -51.63144137624109
# agent 9 在 39 次迭代中的资源申请量为: -45.95695987493956
# agent 10 在 39 次迭代中的资源申请量为: 299.00561409046475
# agent 11 在 39 次迭代中的资源申请量为: 1212.222628296294
# agent 12 在 39 次迭代中的资源申请量为: -51.517106960717726
# agent 13 在 39 次迭代中的资源申请量为: -56.488458029026106
# agent 14 在 39 次迭代中的资源申请量为: 56.096202328081844
# agent 15 在 39 次迭代中的资源申请量为: -60.552388810669854
# agent 16 在 39 次迭代中的资源申请量为: 14.617189068634914
# agent 17 在 39 次迭代中的资源申请量为: -58.5052947219163
# agent 18 在 39 次迭代中的资源申请量为: -66.16803094197569
# agent 19 在 39 次迭代中的资源申请量为: 10.577145594002808
# agent 20 在 39 次迭代中的资源申请量为: 781.0946665518628
# agent 21 在 39 次迭代中的资源申请量为: 453.4419661282668
# agent 22 在 39 次迭代中的资源申请量为: -91.45806807526914
# agent 23 在 39 次迭代中的资源申请量为: -91.61355159588061
# agent 24 在 39 次迭代中的资源申请量为: 285.06648458504026
# agent 25 在 39 次迭代中的资源申请量为: 286.109613758456
# agent 26 在 39 次迭代中的资源申请量为: -80.91235910827378
# agent 27 在 39 次迭代中的资源申请量为: 459.9681128887091
# agent 28 在 39 次迭代中的资源申请量为: 366.0725480787863
# agent 29 在 39 次迭代中的资源申请量为: 310.2170613984022
# agent 30 在 39 次迭代中的资源申请量为: 55.62427734554497
# agent 31 在 39 次迭代中的资源申请量为: -40.475634659531025
# agent 32 在 39 次迭代中的资源申请量为: -38.52521886733095
# agent 33 在 39 次迭代中的资源申请量为: -299.6571932353791
# agent 34 在 39 次迭代中的资源申请量为: 125.82812122549491
# agent 35 在 39 次迭代中的资源申请量为: 110.90108882577208
# agent 36 在 39 次迭代中的资源申请量为: 332.5285952268191
# agent 37 在 39 次迭代中的资源申请量为: 91.8591181499892
# agent 38 在 39 次迭代中的资源申请量为: -60.83406005781854
# agent 39 在 39 次迭代中的资源申请量为: 364.1813375200978
# agent 40 在 39 次迭代中的资源申请量为: 338.55791982662925
# agent 41 在 39 次迭代中的资源申请量为: -275.7334217289485
# agent 42 在 39 次迭代中的资源申请量为: -1.2421352617326455
# agent 43 在 39 次迭代中的资源申请量为: 353.91540789546355
# agent 44 在 39 次迭代中的资源申请量为: 330.6868445124775
# agent 45 在 39 次迭代中的资源申请量为: 407.29139419272747
# agent 46 在 39 次迭代中的资源申请量为: -264.77402594436154
# agent 47 在 39 次迭代中的资源申请量为: 192.96302713149944
# agent 48 在 39 次迭代中的资源申请量为: 198.69469364121738
# agent 49 在 39 次迭代中的资源申请量为: -278.03881371034777
# agent 50 在 39 次迭代中的资源申请量为: 1.866265744923389
# agent 51 在 39 次迭代中的资源申请量为: 187.15380327652386
# agent 52 在 39 次迭代中的资源申请量为: 187.15380327652386
# agent 53 在 39 次迭代中的资源申请量为: 18.494292722095395
# agent 54 在 39 次迭代中的资源申请量为: -158.98252353189943
# 资源申请量总和为: 6000.000000000001
# ****************************************************************************
# 成本总和为: 72366.35018321249
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 59 次迭代中的结果：
# agent 1 在 59 次迭代中的资源申请量为: -58.48070139418771
# agent 2 在 59 次迭代中的资源申请量为: -58.48070139418771
# agent 3 在 59 次迭代中的资源申请量为: -57.834666068027
# agent 4 在 59 次迭代中的资源申请量为: 219.62999886232654
# agent 5 在 59 次迭代中的资源申请量为: 240.48872573822257
# agent 6 在 59 次迭代中的资源申请量为: -58.23026921877203
# agent 7 在 59 次迭代中的资源申请量为: 13.365756320428655
# agent 8 在 59 次迭代中的资源申请量为: -54.87373261367792
# agent 9 在 59 次迭代中的资源申请量为: -51.18318801831843
# agent 10 在 59 次迭代中的资源申请量为: 272.70631625203765
# agent 11 在 59 次迭代中的资源申请量为: 1233.6788002657865
# agent 12 在 59 次迭代中的资源申请量为: -54.80534953703784
# agent 13 在 59 次迭代中的资源申请量为: -57.74976565503071
# agent 14 在 59 次迭代中的资源申请量为: 34.33039048570766
# agent 15 在 59 次迭代中的资源申请量为: -59.958954270435896
# agent 16 在 59 次迭代中的资源申请量为: 11.645168869837924
# agent 17 在 59 次迭代中的资源申请量为: -58.8870886707379
# agent 18 在 59 次迭代中的资源申请量为: -64.46273555820781
# agent 19 在 59 次迭代中的资源申请量为: 5.019268506048405
# agent 20 在 59 次迭代中的资源申请量为: 878.6427107347778
# agent 21 在 59 次迭代中的资源申请量为: 538.2243324818594
# agent 22 在 59 次迭代中的资源申请量为: -94.59317685676112
# agent 23 在 59 次迭代中的资源申请量为: -87.09764085884204
# agent 24 在 59 次迭代中的资源申请量为: 295.3268872982412
# agent 25 在 59 次迭代中的资源申请量为: 322.9993473341126
# agent 26 在 59 次迭代中的资源申请量为: -70.17389101406118
# agent 27 在 59 次迭代中的资源申请量为: 457.13017379154115
# agent 28 在 59 次迭代中的资源申请量为: 389.5993284547778
# agent 29 在 59 次迭代中的资源申请量为: 287.1469576883768
# agent 30 在 59 次迭代中的资源申请量为: 45.89802556570052
# agent 31 在 59 次迭代中的资源申请量为: -47.6407864298987
# agent 32 在 59 次迭代中的资源申请量为: -46.41048295514493
# agent 33 在 59 次迭代中的资源申请量为: -315.3827863068912
# agent 34 在 59 次迭代中的资源申请量为: 86.0338431893329
# agent 35 在 59 次迭代中的资源申请量为: 83.70046885147174
# agent 36 在 59 次迭代中的资源申请量为: 325.43320792691065
# agent 37 在 59 次迭代中的资源申请量为: 87.5791090104829
# agent 38 在 59 次迭代中的资源申请量为: -60.08776137786088
# agent 39 在 59 次迭代中的资源申请量为: 456.48889275608514
# agent 40 在 59 次迭代中的资源申请量为: 330.3717060266431
# agent 41 在 59 次迭代中的资源申请量为: -290.2684936008749
# agent 42 在 59 次迭代中的资源申请量为: -51.962633980059024
# agent 43 在 59 次迭代中的资源申请量为: 354.4963032766019
# agent 44 在 59 次迭代中的资源申请量为: 354.0436554308474
# agent 45 在 59 次迭代中的资源申请量为: 398.1720350786246
# agent 46 在 59 次迭代中的资源申请量为: -271.76620135317256
# agent 47 在 59 次迭代中的资源申请量为: 176.27472700741708
# agent 48 在 59 次迭代中的资源申请量为: 180.25380863210134
# agent 49 在 59 次迭代中的资源申请量为: -304.66153980911986
# agent 50 在 59 次迭代中的资源申请量为: -13.77685528744945
# agent 51 在 59 次迭代中的资源申请量为: 190.1975770842295
# agent 52 在 59 次迭代中的资源申请量为: 190.1975770842295
# agent 53 在 59 次迭代中的资源申请量为: 13.722774530087378
# agent 54 在 59 次迭代中的资源申请量为: -184.02847230609018
# 资源申请量总和为: 5999.999999999998
# ****************************************************************************
# 成本总和为: 70299.90825044572
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 79 次迭代中的结果：
# agent 1 在 79 次迭代中的资源申请量为: -58.77887220037719
# agent 2 在 79 次迭代中的资源申请量为: -58.77887220037719
# agent 3 在 79 次迭代中的资源申请量为: -58.37980058157448
# agent 4 在 79 次迭代中的资源申请量为: 226.09231657946322
# agent 5 在 79 次迭代中的资源申请量为: 238.14721114763336
# agent 6 在 79 次迭代中的资源申请量为: -58.66797801217731
# agent 7 在 79 次迭代中的资源申请量为: 10.521831934932305
# agent 8 在 79 次迭代中的资源申请量为: -56.512850910193606
# agent 9 在 79 次迭代中的资源申请量为: -53.87125011436592
# agent 10 在 79 次迭代中的资源申请量为: 258.5540356911275
# agent 11 在 79 次迭代中的资源申请量为: 1229.0439717076306
# agent 12 在 79 次迭代中的资源申请量为: -56.49856974043475
# agent 13 在 79 次迭代中的资源申请量为: -58.37541337640882
# agent 14 在 79 次迭代中的资源申请量为: 23.808124835796928
# agent 15 在 79 次迭代中的资源申请量为: -59.8305234537416
# agent 16 在 79 次迭代中的资源申请量为: 9.632400802064026
# agent 17 在 79 次迭代中的资源申请量为: -59.15006811195381
# agent 18 在 79 次迭代中的资源申请量为: -63.49224515099172
# agent 19 在 79 次迭代中的资源申请量为: 3.185723150273578
# agent 20 在 79 次迭代中的资源申请量为: 936.5275212596811
# agent 21 在 79 次迭代中的资源申请量为: 608.1950110489868
# agent 22 在 79 次迭代中的资源申请量为: -88.09867375545113
# agent 23 在 79 次迭代中的资源申请量为: -78.51875422443118
# agent 24 在 79 次迭代中的资源申请量为: 313.0013215006266
# agent 25 在 79 次迭代中的资源申请量为: 350.1151213429505
# agent 26 在 79 次迭代中的资源申请量为: -60.23954400941602
# agent 27 在 79 次迭代中的资源申请量为: 455.1622980009589
# agent 28 在 79 次迭代中的资源申请量为: 402.49160215971136
# agent 29 在 79 次迭代中的资源申请量为: 273.524114189278
# agent 30 在 79 次迭代中的资源申请量为: 40.5705176867429
# agent 31 在 79 次迭代中的资源申请量为: -51.29744984640476
# agent 32 在 79 次迭代中的资源申请量为: -50.41246096247916
# agent 33 在 79 次迭代中的资源申请量为: -324.4313871493008
# agent 34 在 79 次迭代中的资源申请量为: 63.1312278172858
# agent 35 在 79 次迭代中的资源申请量为: 66.3364499477231
# agent 36 在 79 次迭代中的资源申请量为: 315.83299960961483
# agent 37 在 79 次迭代中的资源申请量为: 79.78837367986466
# agent 38 在 79 次迭代中的资源申请量为: -59.87337133085528
# agent 39 在 79 次迭代中的资源申请量为: 539.4681905460106
# agent 40 在 79 次迭代中的资源申请量为: 320.203509369211
# agent 41 在 79 次迭代中的资源申请量为: -299.32856508275194
# agent 42 在 79 次迭代中的资源申请量为: -85.56440189796079
# agent 43 在 79 次迭代中的资源申请量为: 344.50393168641267
# agent 44 在 79 次迭代中的资源申请量为: 354.01429869399817
# agent 45 在 79 次迭代中的资源申请量为: 389.7426861426127
# agent 46 在 79 次迭代中的资源申请量为: -276.16220748662494
# agent 47 在 79 次迭代中的资源申请量为: 164.57667477213448
# agent 48 在 79 次迭代中的资源申请量为: 170.84026024722496
# agent 49 在 79 次迭代中的资源申请量为: -336.1675045545552
# agent 50 在 79 次迭代中的资源申请量为: -23.289716266662175
# agent 51 在 79 次迭代中的资源申请量为: 188.33838278806752
# agent 52 在 79 次迭代中的资源申请量为: 188.33838278806752
# agent 53 在 79 次迭代中的资源申请量为: 10.900543619464827
# agent 54 在 79 次迭代中的资源申请量为: -198.8685543260602
# 资源申请量总和为: 5999.999999999999
# ****************************************************************************
# 成本总和为: 68881.51802616952
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: -59.08091655438699
# agent 2 在 99 次迭代中的资源申请量为: -59.08091655438699
# agent 3 在 99 次迭代中的资源申请量为: -58.85093931670674
# agent 4 在 99 次迭代中的资源申请量为: 229.63520759636572
# agent 5 在 99 次迭代中的资源申请量为: 235.93802261170913
# agent 6 在 99 次迭代中的资源申请量为: -59.03950116572767
# agent 7 在 99 次迭代中的资源申请量为: 8.300581701478869
# agent 8 在 99 次迭代中的资源申请量为: -57.50055169193813
# agent 9 在 99 次迭代中的资源申请量为: -55.44872005836605
# agent 10 在 99 次迭代中的资源申请量为: 250.25543714582776
# agent 11 在 99 次迭代中的资源申请量为: 1219.8917417904115
# agent 12 在 99 次迭代中的资源申请量为: -57.51166695896886
# agent 13 在 99 次迭代中的资源申请量为: -58.829863865604565
# agent 14 在 99 次迭代中的资源申请量为: 17.687883368416678
# agent 15 在 99 次迭代中的资源申请量为: -59.86991575439946
# agent 16 在 99 次迭代中的资源申请量为: 7.7394268379715605
# agent 17 在 99 次迭代中的资源申请量为: -59.41467766015951
# agent 18 在 99 次迭代中的资源申请量为: -62.93186493410018
# agent 19 在 99 次迭代中的资源申请量为: 2.2843140050782687
# agent 20 在 99 次迭代中的资源申请量为: 973.8525919810106
# agent 21 在 99 次迭代中的资源申请量为: 669.4089653883871
# agent 22 在 99 次迭代中的资源申请量为: -79.43400468688573
# agent 23 在 99 次迭代中的资源申请量为: -69.75307345743106
# agent 24 在 99 次迭代中的资源申请量为: 333.28087056627294
# agent 25 在 99 次迭代中的资源申请量为: 371.6775473610663
# agent 26 在 99 次迭代中的资源申请量为: -52.141197009993945
# agent 27 在 99 次迭代中的资源申请量为: 453.55326812776525
# agent 28 在 99 次迭代中的资源申请量为: 410.6160526812975
# agent 29 在 99 次迭代中的资源申请量为: 264.8396185160129
# agent 30 在 99 次迭代中的资源申请量为: 37.35944183064693
# agent 31 在 99 次迭代中的资源申请量为: -53.42942939487966
# agent 32 在 99 次迭代中的资源申请量为: -52.74038367228854
# agent 33 在 99 次迭代中的资源申请量为: -329.97473827313274
# agent 34 在 99 次迭代中的资源申请量为: 49.32527229095416
# agent 35 在 99 次迭代中的资源申请量为: 54.89942275848459
# agent 36 在 99 次迭代中的资源申请量为: 306.96071212891854
# agent 37 在 99 次迭代中的资源申请量为: 72.38039810033338
# agent 38 在 99 次迭代中的资源申请量为: -59.78950433305897
# agent 39 在 99 次迭代中的资源申请量为: 613.3909335544771
# agent 40 在 99 次迭代中的资源申请量为: 310.0416697583168
# agent 41 在 99 次迭代中的资源申请量为: -306.24202052473936
# agent 42 在 99 次迭代中的资源申请量为: -110.30988251806913
# agent 43 在 99 次迭代中的资源申请量为: 332.9749313302271
# agent 44 在 99 次迭代中的资源申请量为: 346.9183291182844
# agent 45 在 99 次迭代中的资源申请量为: 381.68239720691224
# agent 46 在 99 次迭代中的资源申请量为: -279.45237730829643
# agent 47 在 99 次迭代中的资源申请量为: 156.2011645728109
# agent 48 在 99 次迭代中的资源申请量为: 163.97873982382748
# agent 49 在 99 次迭代中的资源申请量为: -372.3687797970553
# agent 50 在 99 次迭代中的资源申请量为: -30.899949825966928
# agent 51 在 99 次迭代中的资源申请量为: 184.65617662863383
# agent 52 在 99 次迭代中的资源申请量为: 184.65617662863383
# agent 53 在 99 次迭代中的资源申请量为: 8.613732427563122
# agent 54 在 99 次迭代中的资源申请量为: -208.90615252155288
# 资源申请量总和为: 5999.999999999998
# ****************************************************************************
# 成本总和为: 67861.31983915289
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 119 次迭代中的结果：
# agent 1 在 119 次迭代中的资源申请量为: -59.35365111041137
# agent 2 在 119 次迭代中的资源申请量为: -59.35365111041137
# agent 3 在 119 次迭代中的资源申请量为: -59.22100943840345
# agent 4 在 119 次迭代中的资源申请量为: 231.31384289861154
# agent 5 在 119 次迭代中的资源申请量为: 234.02730635246874
# agent 6 在 119 次迭代中的资源申请量为: -59.34622256767714
# agent 7 在 119 次迭代中的资源申请量为: 6.5238583232369045
# agent 8 在 119 次迭代中的资源申请量为: -58.1590775539718
# agent 9 在 119 次迭代中的资源申请量为: -56.46570431871564
# agent 10 在 119 次迭代中的资源申请量为: 244.87635059339127
# agent 11 在 119 次迭代中的资源申请量为: 1211.145943147167
# agent 12 在 119 次迭代中的资源申请量为: -58.18531268407429
# agent 13 在 119 次迭代中的资源申请量为: -59.18091132545786
# agent 14 在 119 次迭代中的资源申请量为: 13.68326331029407
# agent 15 在 119 次迭代中的资源申请量为: -59.961377246064544
# agent 16 在 119 次迭代中的资源申请量为: 6.112862611782539
# agent 17 在 119 次迭代中的资源申请量为: -59.64856824757803
# agent 18 在 119 次迭代中的资源申请量为: -62.57628608101654
# agent 19 在 119 次迭代中的资源申请量为: 1.6997370517780652
# agent 20 在 119 次迭代中的资源申请量为: 999.9028210846983
# agent 21 在 119 次迭代中的资源申请量为: 723.7910256205969
# agent 22 在 119 次迭代中的资源申请量为: -70.76501347645413
# agent 23 在 119 次迭代中的资源申请量为: -61.690390894299966
# agent 24 在 119 次迭代中的资源申请量为: 353.18918789972065
# agent 25 在 119 次迭代中的资源申请量为: 389.5739489323266
# agent 26 在 119 次迭代中的资源申请量为: -45.46464305344159
# agent 27 在 119 次迭代中的资源申请量为: 452.3242852495937
# agent 28 在 119 次迭代中的资源申请量为: 416.2654291220366
# agent 29 在 119 次迭代中的资源申请量为: 258.95569423254153
# agent 30 在 119 次迭代中的资源申请量为: 35.27759723819286
# agent 31 在 119 次迭代中的资源申请量为: -54.78433031341456
# agent 32 在 119 次迭代中的资源申请量为: -54.213811048193804
# agent 33 在 119 次迭代中的资源申请量为: -333.5905852746964
# agent 34 在 119 次迭代中的资源申请量为: 40.4727714492783
# agent 35 在 119 次迭代中的资源申请量为: 47.01179446941211
# agent 36 在 119 次迭代中的资源申请量为: 299.43744584253227
# agent 37 在 119 次迭代中的资源申请量为: 66.069220086571
# agent 38 在 119 次迭代中的资源申请量为: -59.7128035604648
# agent 39 在 119 次迭代中的资源申请量为: 679.1284210892428
# agent 40 在 119 次迭代中的资源申请量为: 300.8556860817664
# agent 41 在 119 次迭代中的资源申请量为: -311.8510437479532
# agent 42 在 119 次迭代中的资源申请量为: -129.77041235280544
# agent 43 在 119 次迭代中的资源申请量为: 322.33565785926254
# agent 44 在 119 次迭代中的资源申请量为: 338.4186744146493
# agent 45 在 119 次迭代中的资源申请量为: 374.1335523318708
# agent 46 在 119 次迭代中的资源申请量为: -282.32263347863454
# agent 47 在 119 次迭代中的资源申请量为: 149.29585004409898
# agent 48 在 119 次迭代中的资源申请量为: 157.8844421508659
# agent 49 在 119 次迭代中的资源申请量为: -411.0817661702162
# agent 50 在 119 次迭代中的资源申请量为: -38.01897986497332
# agent 51 在 119 次迭代中的资源申请量为: 180.20866992785972
# agent 52 在 119 次迭代中的资源申请量为: 180.20866992785972
# agent 53 在 119 次迭代中的资源申请量为: 6.770444849469328
# agent 54 在 119 次迭代中的资源申请量为: -216.17626927384526
# 资源申请量总和为: 6000.000000000002
# ****************************************************************************
# 成本总和为: 67148.19653725311
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 139 次迭代中的结果：
# agent 1 在 139 次迭代中的资源申请量为: -59.57761905164341
# agent 2 在 139 次迭代中的资源申请量为: -59.57761905164341
# agent 3 在 139 次迭代中的资源申请量为: -59.49928470447361
# agent 4 在 139 次迭代中的资源申请量为: 231.8744031328532
# agent 5 在 139 次迭代中的资源申请量为: 232.4999045222059
# agent 6 在 139 次迭代中的资源申请量为: -59.585324781496794
# agent 7 在 139 次迭代中的资源申请量为: 5.151603920870102
# agent 8 在 139 次迭代中的资源申请量为: -58.62137927231703
# agent 9 在 139 次迭代中的资源申请量为: -57.16464911745396
# agent 10 在 139 次迭代中的资源申请量为: 241.14962191696668
# agent 11 在 139 次迭代中的资源申请量为: 1203.9245161078159
# agent 12 在 139 次迭代中的资源申请量为: -58.65951587078085
# agent 13 在 139 次迭代中的资源申请量为: -59.44815311404511
# agent 14 在 139 次迭代中的资源申请量为: 10.889152243783968
# agent 15 在 139 次迭代中的资源申请量为: -60.05573354423517
# agent 16 在 139 次迭代中的资源申请量为: 4.818829778944224
# agent 17 在 139 次迭代中的资源申请量为: -59.83521306116981
# agent 18 在 139 次迭代中的资源申请量为: -62.32044789447809
# agent 19 在 139 次迭代中的资源申请量为: 1.3167368297933386
# agent 20 在 139 次迭代中的资源申请量为: 1019.5174932584575
# agent 21 在 139 次迭代中的资源申请量为: 772.176357181069
# agent 22 在 139 次迭代中的资源申请量为: -62.73666216215463
# agent 23 在 139 次迭代中的资源申请量为: -54.49422458128457
# agent 24 在 139 次迭代中的资源申请量为: 371.56699494762773
# agent 25 在 139 次迭代中的资源申请量为: 404.8090156510111
# agent 26 在 139 次迭代中的资源申请量为: -39.84458647075502
# agent 27 在 139 次迭代中的资源申请量为: 451.4613767948815
# agent 28 在 139 次迭代中的资源申请量为: 420.53350966222484
# agent 29 在 139 次迭代中的资源申请量为: 254.7920003988636
# agent 30 在 139 次迭代中的资源申请量为: 33.84641660474779
# agent 31 在 139 次迭代中的资源申请量为: -55.70335573943363
# agent 32 在 139 次迭代中的资源申请量为: -55.20942305243386
# agent 33 在 139 次迭代中的资源申请量为: -336.0829651490056
# agent 34 在 139 次迭代中的资源申请量为: 34.45885083674157
# agent 35 在 139 次迭代中的资源申请量为: 41.331149677354304
# agent 36 在 139 次迭代中的资源申请量为: 293.22642575125036
# agent 37 在 139 次迭代中的资源申请量为: 60.85659822632243
# agent 38 在 139 次迭代中的资源申请量为: -59.60636285746905
# agent 39 在 139 次迭代中的资源申请量为: 737.6477936837246
# agent 40 在 139 次迭代中的资源申请量为: 292.9749881242834
# agent 41 在 139 次迭代中的资源申请量为: -316.4804166296052
# agent 42 在 139 次迭代中的资源申请量为: -145.57957627687085
# agent 43 在 139 次迭代中的资源申请量为: 313.1478332700324
# agent 44 在 139 次迭代中的资源申请量为: 330.35489889971814
# agent 45 在 139 次迭代中的资源申请量为: 367.2100679728872
# agent 46 在 139 次迭代中的资源申请量为: -284.9768953334154
# agent 47 在 139 次迭代中的资源申请量为: 143.11388452794347
# agent 48 在 139 次迭代中的资源申请量为: 152.15318445073075
# agent 49 在 139 次迭代中的资源申请量为: -451.2159344772096
# agent 50 在 139 次迭代中的资源申请量为: -45.018274478249936
# agent 51 在 139 次迭代中的资源申请量为: 175.38394808869492
# agent 52 在 139 次迭代中的资源申请量为: 175.38394808869492
# agent 53 在 139 次迭代中的资源申请量为: 5.342209908031833
# agent 54 在 139 次迭代中的资源申请量为: -221.62009778690296
# 资源申请量总和为: 6000.0
# ****************************************************************************
# 成本总和为: 66690.88250070797
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 159 次迭代中的结果：
# agent 1 在 159 次迭代中的资源申请量为: -59.74933054735004
# agent 2 在 159 次迭代中的资源申请量为: -59.74933054735004
# agent 3 在 159 次迭代中的资源申请量为: -59.701132658009826
# agent 4 在 159 次迭代中的资源申请量为: 231.8201819389871
# agent 5 在 159 次迭代中的资源申请量为: 231.35116990904305
# agent 6 在 159 次迭代中的资源申请量为: -59.76197312827796
# agent 7 在 159 次迭代中的资源申请量为: 4.136532379480958
# agent 8 在 159 次迭代中的资源申请量为: -58.95230980112346
# agent 9 在 159 次迭代中的资源申请量为: -57.66382589075219
# agent 10 在 159 次迭代中的资源申请量为: 238.4790995492322
# agent 11 在 159 次迭代中的资源申请量为: 1198.3420089620606
# agent 12 在 159 次迭代中的资源申请量为: -59.00086428561653
# agent 13 在 159 次迭代中的资源申请量为: -59.64500187264842
# agent 14 在 159 次迭代中的资源申请量为: 8.884222715182517
# agent 15 在 159 次迭代中的资源申请量为: -60.13198619046746
# agent 16 在 159 次迭代中的资源申请量为: 3.8496031361743803
# agent 17 在 159 次迭代中的资源申请量为: -59.97242063433609
# agent 18 在 159 次迭代中的资源申请量为: -62.1119491849869
# agent 19 在 159 次迭代中的资源申请量为: 1.1133396437859098
# agent 20 在 159 次迭代中的资源申请量为: 1035.3039358662209
# agent 21 在 159 次迭代中的资源申请量为: 815.1539854228392
# agent 22 在 159 次迭代中的资源申请量为: -55.50531620962518
# agent 23 在 159 次迭代中的资源申请量为: -48.12576122602178
# agent 24 在 159 次迭代中的资源申请量为: 388.11874227507775
# agent 25 在 159 次迭代中的资源申请量为: 417.9924280959607
# agent 26 在 159 次迭代中的资源申请量为: -35.028984316612025
# agent 27 在 159 次迭代中的资源申请量为: 450.91911313548604
# agent 28 在 159 次迭代中的资源申请量为: 423.98257610764904
# agent 29 在 159 次迭代中的资源申请量为: 251.76347670269465
# agent 30 在 159 次迭代中的资源申请量为: 32.819564803974984
# agent 31 在 159 次迭代中的资源申请量为: -56.35594102680386
# agent 32 在 159 次迭代中的资源申请量为: -55.91500259009628
# agent 33 在 159 次迭代中的资源申请量为: -337.87550926233195
# agent 34 在 159 次迭代中的资源申请量为: 30.180024480673275
# agent 35 在 159 次迭代中的资源申请量为: 37.09745768045756
# agent 36 在 159 次迭代中的资源申请量为: 288.12811064431634
# agent 37 在 159 次迭代中的资源申请量为: 56.58098522912644
# agent 38 在 159 次迭代中的资源申请量为: -59.46447781120309
# agent 39 在 159 次迭代中的资源申请量为: 789.8570208748349
# agent 40 在 159 次迭代中的资源申请量为: 286.40901413027154
# agent 41 在 159 次迭代中的资源申请量为: -320.3102825677277
# agent 42 在 159 次迭代中的资源申请量为: -158.59647221620946
# agent 43 在 159 次迭代中的资源申请量为: 305.4095165032505
# agent 44 在 159 次迭代中的资源申请量为: 323.2177182130726
# agent 45 在 159 次迭代中的资源申请量为: 360.89523346576175
# agent 46 在 159 次迭代中的资源申请量为: -287.4786912374487
# agent 47 在 159 次迭代中的资源申请量为: 137.39589142648592
# agent 48 在 159 次迭代中的资源申请量为: 146.67526365488192
# agent 49 在 159 次迭代中的资源申请量为: -492.05588959222047
# agent 50 在 159 次迭代中的资源申请量为: -51.956276530083755
# agent 51 在 159 次迭代中的资源申请量为: 170.35860035328216
# agent 52 在 159 次迭代中的资源申请量为: 170.35860035328216
# agent 53 在 159 次迭代中的资源申请量为: 4.28160064573288
# agent 54 在 159 次迭代中的资源申请量为: -225.7662889719776
# 资源申请量总和为: 5999.999999999999
# ****************************************************************************
# 成本总和为: 66452.88345581254
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 179 次迭代中的结果：
# agent 1 在 179 次迭代中的资源申请量为: -59.87214758986645
# agent 2 在 179 次迭代中的资源申请量为: -59.87214758986645
# agent 3 在 179 次迭代中的资源申请量为: -59.84067332874129
# agent 4 在 179 次迭代中的资源申请量为: 231.47573794983353
# agent 5 在 179 次迭代中的资源申请量为: 230.54218385515108
# agent 6 在 179 次迭代中的资源申请量为: -59.88430045647357
# agent 7 在 179 次迭代中的资源申请量为: 3.4272754939418597
# agent 8 在 179 次迭代中的资源申请量为: -59.18831099645324
# agent 9 在 179 次迭代中的资源申请量为: -58.026853528616215
# agent 10 在 179 次迭代中的资源申请量为: 236.54769808137632
# agent 11 在 179 次迭代中的资源申请量为: 1194.2433163882495
# agent 12 在 179 次迭代中的资源申请量为: -59.24606816447377
# agent 13 在 179 次迭代中的资源申请量为: -59.782957769682056
# agent 14 在 179 次迭代中的资源申请量为: 7.441097135371855
# agent 15 在 179 次迭代中的资源申请量为: -60.182274765601264
# agent 16 在 179 次迭代中的资源申请量为: 3.1701362874078427
# agent 17 在 179 次迭代中的资源申请量为: -60.064004450265074
# agent 18 在 179 次迭代中的资源申请量为: -61.924850269812694
# agent 19 在 179 次迭代中的资源申请量为: 1.0758619022396978
# agent 20 在 179 次迭代中的资源申请量为: 1048.6958039307387
# agent 21 在 179 次迭代中的资源申请量为: 853.2730553824787
# agent 22 在 179 次迭代中的资源申请量为: -49.05997106023524
# agent 23 在 179 次迭代中的资源申请量为: -42.494258995058885
# agent 24 在 179 次迭代中的资源申请量为: 402.8935002697521
# agent 25 在 179 次迭代中的资源申请量为: 429.5364568678171
# agent 26 在 179 次迭代中的资源申请量为: -30.842393664722188
# agent 27 在 179 次迭代中的资源申请量为: 450.6457215374222
# agent 28 在 179 次迭代中的资源申请量为: 426.91496006114414
# agent 29 在 179 次迭代中的资源申请量为: 249.5294860887931
# agent 30 在 179 次迭代中的资源申请量为: 32.06201984736292
# agent 31 在 179 次迭代中的资源申请量为: -56.83270251618961
# agent 32 在 179 次迭代中的资源申请量为: -56.43081215795396
# agent 33 在 179 次迭代中的资源申请量为: -339.2029436111088
# agent 34 在 179 次迭代中的资源申请量为: 27.034165972576762
# agent 35 在 179 次迭代中的资源申请量为: 33.86365652295949
# agent 36 在 179 次迭代中的资源申请量为: 283.9339956473698
# agent 37 在 179 次迭代中的资源申请量为: 53.06755758154206
# agent 38 在 179 次迭代中的资源申请量为: -59.29208724717891
# agent 39 在 179 次迭代中的资源申请量为: 836.5598597055802
# agent 40 在 179 次迭代中的资源申请量为: 281.034865678439
# agent 41 在 179 次迭代中的资源申请量为: -323.47085250226843
# agent 42 在 179 次迭代中的资源申请量为: -169.3599151904192
# agent 43 在 179 次迭代中的资源申请量为: 298.95560338705917
# agent 44 在 179 次迭代中的资源申请量为: 317.0423339751395
# agent 45 在 179 次迭代中的资源申请量为: 355.12797911797134
# agent 46 在 179 次迭代中的资源申请量为: -289.85110558956336
# agent 47 在 179 次迭代中的资源申请量为: 132.0434293367914
# agent 48 在 179 次迭代中的资源申请量为: 141.41971678225548
# agent 49 在 179 次迭代中的资源申请量为: -533.07645566541
# agent 50 在 179 次迭代中的资源申请量为: -58.81264840156032
# agent 51 在 179 次迭代中的资源申请量为: 165.23521009626558
# agent 52 在 179 次迭代中的资源申请量为: 165.23521009626558
# agent 53 在 179 次迭代中的资源申请量为: 3.535411226636569
# agent 54 在 179 次迭代中的资源申请量为: -228.95257069441226
# 资源申请量总和为: 6000.0
# ****************************************************************************
# 成本总和为: 66405.09677702513
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: -59.95169031837395
# agent 2 在 199 次迭代中的资源申请量为: -59.95169031837395
# agent 3 在 199 次迭代中的资源申请量为: -59.92952521345752
# agent 4 在 199 次迭代中的资源申请量为: 231.04170067812925
# agent 5 在 199 次迭代中的资源申请量为: 230.02597625506888
# agent 6 在 199 次迭代中的资源申请量为: -59.960630686308114
# agent 7 在 199 次迭代中的资源申请量为: 2.9755402160798035
# agent 8 在 199 次迭代中的资源申请量为: -59.35232504630939
# agent 9 在 199 次迭代中的资源申请量为: -58.29129417299371
# agent 10 在 199 次迭代中的资源申请量为: 235.16562430802412
# agent 11 在 199 次迭代中的资源申请量为: 1191.4174021302374
# agent 12 在 199 次迭代中的资源申请量为: -59.41805859756935
# agent 13 在 199 次迭代中的资源申请量为: -59.87189943452518
# agent 14 在 199 次迭代中的资源申请量为: 6.420804319434367
# agent 15 在 199 次迭代中的资源申请量为: -60.2050701556244
# agent 16 在 199 次迭代中的资源申请量为: 2.7394959528627183
# agent 17 在 199 次迭代中的资源申请量为: -60.11566134602175
# agent 18 在 199 次迭代中的资源申请量为: -61.74658192099223
# agent 19 在 199 次迭代中的资源申请量为: 1.1863000113954918
# agent 20 在 199 次迭代中的资源申请量为: 1060.4963207404103
# agent 21 在 199 次迭代中的资源申请量为: 887.0709213076282
# agent 22 在 199 次迭代中的资源申请量为: -43.33383212625421
# agent 23 在 199 次迭代中的资源申请量为: -37.50354273092165
# agent 24 在 199 次迭代中的资源申请量为: 416.05819937913236
# agent 25 在 199 次迭代中的资源申请量为: 439.7421699602014
# agent 26 在 199 次迭代中的资源申请量为: -27.15886655610147
# agent 27 在 199 次迭代中的资源申请量为: 450.59354618696364
# agent 28 在 199 次迭代中的资源申请量为: 429.49978554771525
# agent 29 在 199 次迭代中的资源申请量为: 247.87725318708732
# agent 30 在 199 次迭代中的资源申请量为: 31.49454615848415
# agent 31 在 199 次迭代中的资源申请量为: -57.185931634010316
# agent 32 在 199 次迭代中的资源申请量为: -56.81437721221406
# agent 33 在 199 次迭代中的资源申请量为: -340.20346200750515
# agent 34 在 199 次迭代中的资源申请量为: 24.673073628410336
# agent 35 在 199 次迭代中的资源申请量为: 31.35301532911359
# agent 36 在 199 次迭代中的资源申请量为: 280.4669592620648
# agent 37 在 199 次迭代中的资源申请量为: 50.166271394927215
# agent 38 在 199 次迭代中的资源申请量为: -59.09682772488362
# agent 39 在 199 次迭代中的资源申请量为: 878.4514662744616
# agent 40 在 199 次迭代中的资源申请量为: 276.6890293829257
# agent 41 在 199 次迭代中的资源申请量为: -326.0691406605012
# agent 42 在 199 次迭代中的资源申请量为: -178.2625487934105
# agent 43 在 199 次迭代中的资源申请量为: 293.5913603637683
# agent 44 在 199 次迭代中的资源申请量为: 311.72765832632695
# agent 45 在 199 次迭代中的资源申请量为: 349.84027253365
# agent 46 在 199 次迭代中的资源申请量为: -292.1056488991993
# agent 47 在 199 次迭代中的资源申请量为: 127.00829200833007
# agent 48 在 199 次迭代中的资源申请量为: 136.37604959130226
# agent 49 在 199 次迭代中的资源申请量为: -573.8783833739236
# agent 50 在 199 次迭代中的资源申请量为: -65.5536177904372
# agent 51 在 199 次迭代中的资源申请量为: 160.08406707902242
# agent 52 在 199 次迭代中的资源申请量为: 160.08406707902242
# agent 53 在 199 次迭代中的资源申请量为: 3.0536003035795147
# agent 54 在 199 次迭代中的资源申请量为: -231.41016217584894
# 资源申请量总和为: 5999.999999999999
# ****************************************************************************
# 成本总和为: 66522.89611364197
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 219 次迭代中的结果：
# agent 1 在 219 次迭代中的资源申请量为: -59.99396518551248
# agent 2 在 219 次迭代中的资源申请量为: -59.99396518551248
# agent 3 在 219 次迭代中的资源申请量为: -59.97702895654858
# agent 4 在 219 次迭代中的资源申请量为: 230.6360038563407
# agent 5 在 219 次迭代中的资源申请量为: 229.75723895553276
# agent 6 在 219 次迭代中的资源申请量为: -59.99851196469842
# agent 7 在 219 次迭代中的资源申请量为: 2.738702252643595
# agent 8 在 219 次迭代中的资源申请量为: -59.46009747151265
# agent 9 在 219 次迭代中的资源申请量为: -58.481257197969384
# agent 10 在 219 次迭代中的资源申请量为: 234.2076773372578
# agent 11 在 219 次迭代中的资源申请量为: 1189.660624547979
# agent 12 在 219 次迭代中的资源申请量为: -59.53257450745804
# agent 13 在 219 次迭代中的资源申请量为: -59.92019943682833
# agent 14 在 219 次迭代中的资源申请量为: 5.72980317665661
# agent 15 在 219 次迭代中的资源申请量为: -60.20183743428203
# agent 16 在 219 次迭代中的资源申请量为: 2.518660205338456
# agent 17 在 219 次迭代中的资源申请量为: -60.13329429626623
# agent 18 在 219 次迭代中的资源申请量为: -61.57136626927752
# agent 19 在 219 次迭代中的资源申请量为: 1.4236525345332538
# agent 20 在 219 次迭代中的资源申请量为: 1071.1660752849514
# agent 21 在 219 次迭代中的资源申请量为: 917.0608659203889
# agent 22 在 219 次迭代中的资源申请量为: -38.24575752110177
# agent 23 在 219 次迭代中的资源申请量为: -33.06575074336031
# agent 24 在 219 次迭代中的资源申请量为: 427.8061343018794
# agent 25 在 219 次迭代中的资源申请量为: 448.840064865051
# agent 26 在 219 次迭代中的资源申请量为: -23.88533515127992
# agent 27 在 219 次迭代中的资源申请量为: 450.7217157365975
# agent 28 在 219 次迭代中的资源申请量为: 431.8354902572794
# agent 29 在 219 次迭代中的资源申请量为: 246.66512777166741
# agent 30 在 219 次迭代中的资源申请量为: 31.06734973373099
# agent 31 在 219 次迭代中的资源申请量为: -57.44813787235671
# agent 32 在 219 次迭代中的资源申请量为: -57.101173632008646
# agent 33 在 219 次迭代中的资源申请量为: -340.9637866180195
# agent 34 在 219 次迭代中的资源申请量为: 22.88215935058357
# agent 35 在 219 次迭代中的资源申请量为: 29.384677786489657
# agent 36 在 219 次迭代中的资源申请量为: 277.58551163180414
# agent 37 在 219 次迭代中的资源申请量为: 47.756545539489416
# agent 38 在 219 次迭代中的资源申请量为: -58.88615383345069
# agent 39 在 219 次迭代中的资源申请量为: 916.1279501655249
# agent 40 在 219 次迭代中的资源申请量为: 273.20765585002215
# agent 41 在 219 次迭代中的资源申请量为: -328.19672622254365
# agent 42 在 219 次迭代中的资源申请量为: -185.61733986178575
# agent 43 在 219 次迭代中的资源申请量为: 289.13542898791206
# agent 44 在 219 次迭代中的资源申请量为: 307.14630768270393
# agent 45 在 219 次迭代中的资源申请量为: 344.97001791883974
# agent 46 在 219 次迭代中的资源申请量为: -294.2503619046281
# agent 47 在 219 次迭代中的资源申请量为: 122.25877257598061
# agent 48 在 219 次迭代中的资源申请量为: 131.53823121234174
# agent 49 在 219 次迭代中的资源申请量为: -614.1573407497368
# agent 50 在 219 次迭代中的资源申请量为: -72.14895913563304
# agent 51 在 219 次迭代中的资源申请量为: 154.9570662404553
# agent 52 在 219 次迭代中的资源申请量为: 154.9570662404553
# agent 53 在 219 次迭代中的资源申请量为: 2.792155313772639
# agent 54 在 219 次迭代中的资源申请量为: -233.30381208243358
# 资源申请量总和为: 5999.999999999998
# ****************************************************************************
# 成本总和为: 66784.75386371341
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 239 次迭代中的结果：
# agent 1 在 239 次迭代中的资源申请量为: -60.00465763807032
# agent 2 在 239 次迭代中的资源申请量为: -60.00465763807032
# agent 3 在 239 次迭代中的资源申请量为: -59.990719869170704
# agent 4 在 239 次迭代中的资源申请量为: 230.32291235742724
# agent 5 在 239 次迭代中的资源申请量为: 229.69535228126074
# agent 6 在 239 次迭代中的资源申请量为: -60.00449876813046
# agent 7 在 239 次迭代中的资源申请量为: 2.680092237725521
# agent 8 在 239 次迭代中的资源申请量为: -59.52313632880788
# agent 9 在 239 次迭代中的资源申请量为: -58.61334082843419
# agent 10 在 239 次迭代中的资源申请量为: 233.5849530802987
# agent 11 在 239 次迭代中的资源申请量为: 1188.7932754500637
# agent 12 在 239 次迭代中的资源申请量为: -59.60116396867616
# agent 13 在 239 次迭代中的资源申请量为: -59.93491320890806
# agent 14 在 239 次迭代中的资源申请量为: 5.300531632098593
# agent 15 在 239 次迭代中的资源申请量为: -60.17534162084757
# agent 16 在 239 次迭代中的资源申请量为: 2.4728625667741255
# agent 17 在 239 次迭代中的资源申请量为: -60.1223909993604
# agent 18 在 239 次迭代中的资源申请量为: -61.396856643788745
# agent 19 在 239 次迭代中的资源申请量为: 1.7665455215456731
# agent 20 在 239 次迭代中的资源申请量为: 1080.9777058434838
# agent 21 在 239 次迭代中的资源申请量为: 943.7178867250014
# agent 22 在 239 次迭代中的资源申请量为: -33.71591700565581
# agent 23 在 239 次迭代中的资源申请量为: -29.10436599892394
# agent 24 在 239 次迭代中的资源申请量为: 438.3224715477594
# agent 25 在 239 次迭代中的资源申请量为: 457.01146027296426
# agent 26 在 239 次迭代中的资源申请量为: -20.95124940175916
# agent 27 在 239 次迭代中的资源申请量为: 450.99600144424164
# agent 28 在 239 次迭代中的资源申请量为: 433.98182325159905
# agent 29 在 239 次迭代中的资源申请量为: 245.79358670847276
# agent 30 在 239 次迭代中的资源申请量为: 30.747098139901897
# agent 31 在 239 次迭代中的资源申请量为: -57.640951479427216
# agent 32 在 239 次迭代中的资源申请量为: -57.31459774554262
# agent 33 在 239 次迭代中的资源申请量为: -341.54173549920273
# agent 34 在 239 次迭代中的资源申请量为: 21.520694510804226
# agent 35 在 239 次迭代中的资源申请量为: 27.834223694656032
# agent 36 在 239 次迭代中的资源申请量为: 275.17843232376833
# agent 37 在 239 次迭代中的资源申请量为: 45.74321288608891
# agent 38 在 239 次迭代中的资源申请量为: -58.66644706206311
# agent 39 在 239 次迭代中的资源申请量为: 950.0994786308117
# agent 40 在 239 次迭代中的资源申请量为: 270.4421847348911
# agent 41 在 239 次迭代中的资源申请量为: -329.932323734882
# agent 42 在 239 次迭代中的资源申请量为: -191.6839446479918
# agent 43 在 239 次迭代中的资源申请量为: 285.4311291524162
# agent 44 在 239 次迭代中的资源申请量为: 303.17949889159684
# agent 45 在 239 次迭代中的资源申请量为: 340.4642734930073
# agent 46 在 239 次迭代中的资源申请量为: -296.2919559044919
# agent 47 在 239 次迭代中的资源申请量为: 117.76996338375669
# agent 48 在 239 次迭代中的资源申请量为: 126.9007509741945
# agent 49 在 239 次迭代中的资源申请量为: -653.68365347526
# agent 50 在 239 次迭代中的资源申请量为: -78.57528710492653
# agent 51 在 239 次迭代中的资源申请量为: 149.8933612092061
# agent 52 在 239 次迭代中的资源申请量为: 149.8933612092061
# agent 53 在 239 次迭代中的资源申请量为: 2.713346566688273
# agent 54 在 239 次迭代中的资源申请量为: -234.75436414932068
# 资源申请量总和为: 6000.0
# ****************************************************************************
# 成本总和为: 67171.51335706495
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 259 次迭代中的结果：
# agent 1 在 259 次迭代中的资源申请量为: -59.988894302948765
# agent 2 在 259 次迭代中的资源申请量为: -59.988894302948765
# agent 3 在 259 次迭代中的资源申请量为: -59.97674635420912
# agent 4 在 259 次迭代中的资源申请量为: 230.13272600270886
# agent 5 在 259 次迭代中的资源申请量为: 229.80493799684268
# agent 6 在 259 次迭代中的资源申请量为: -59.98419204727876
# agent 7 在 259 次迭代中的资源申请量为: 2.768472933748317
# agent 8 在 259 次迭代中的资源申请量为: -59.550237029425055
# agent 9 在 259 次迭代中的资源申请量为: -58.69962333623728
# agent 10 在 259 次迭代中的资源申请量为: 233.2308627715203
# agent 11 在 259 次迭代中的资源申请量为: 1188.6614306476824
# agent 12 在 259 次迭代中的资源申请量为: -59.6326987898897
# agent 13 在 259 次迭代中的资源申请量为: -59.92198224067915
# agent 14 在 259 次迭代中的资源申请量为: 5.081702015917259
# agent 15 在 259 次迭代中的资源申请量为: -60.12878098552649
# agent 16 在 259 次迭代中的资源申请量为: 2.571942879025414
# agent 17 在 259 次迭代中的资源申请量为: -60.087831441729755
# agent 18 在 259 次迭代中的资源申请量为: -61.222403379211684
# agent 19 在 259 次迭代中的资源申请量为: 2.194963037950142
# agent 20 在 259 次迭代中的资源申请量为: 1090.099665134058
# agent 21 在 259 次迭代中的资源申请量为: 967.4705932373352
# agent 22 在 259 次迭代中的资源申请量为: -29.671390825120742
# agent 23 在 259 次迭代中的资源申请量为: -25.553853904917844
# agent 24 在 259 次迭代中的资源申请量为: 447.77291139243925
# agent 25 在 259 次迭代中的资源申请量为: 464.401276653376
# agent 26 在 259 次迭代中的资源申请量为: -18.301917850812572
# agent 27 在 259 次迭代中的资源申请量为: 451.3879101738187
# agent 28 在 259 次迭代中的资源申请量为: 435.9767316192522
# agent 29 在 259 次迭代中的资源申请量为: 245.18962964697874
# agent 30 在 259 次迭代中的资源申请量为: 30.510240367997557
# agent 31 在 259 次迭代中的资源申请量为: -57.77961636881649
# agent 32 在 259 次迭代中的资源申请量为: -57.47099841254538
# agent 33 在 259 次迭代中的资源申请量为: -341.97794537845266
# agent 34 在 259 次迭代中的资源申请量为: 20.491126690375406
# agent 35 在 259 次迭代中的资源申请量为: 26.612159730788374
# agent 36 在 259 次迭代中的资源申请量为: 273.15817948155643
# agent 37 在 259 次迭代中的资源申请量为: 44.051208161189685
# agent 38 在 259 次迭代中的资源申请量为: -58.442869250002374
# agent 39 在 259 次迭代中的资源申请量为: 980.8031265599082
# agent 40 在 259 次迭代中的资源申请量为: 268.26392120645875
# agent 41 在 259 次迭代中的资源申请量为: -331.34314650185075
# agent 42 在 259 次迭代中的资源申请量为: -196.68061045831516
# agent 43 在 259 次迭代中的资源申请量为: 282.34698315009103
# agent 44 在 259 次迭代中的资源申请量为: 299.7257303983728
# agent 45 在 259 次迭代中的资源申请量为: 336.27897285634555
# agent 46 在 259 次迭代中的资源申请量为: -298.2363628026348
# agent 47 在 259 次迭代中的资源申请量为: 113.52094151070617
# agent 48 在 259 次迭代中的资源申请量为: 122.45788930390775
# agent 49 在 259 次迭代中的资源申请量为: -692.2868473668115
# agent 50 在 259 次迭代中的资源申请量为: -84.81569047395773
# agent 51 在 259 次迭代中的资源申请量为: 144.92242511337778
# agent 52 在 259 次迭代中的资源申请量为: 144.92242511337778
# agent 53 在 259 次迭代中的资源申请量为: 2.785126125015381
# agent 54 在 259 次迭代中的资源申请量为: -235.85267810780047
# 资源申请量总和为: 5999.999999999995
# ****************************************************************************
# 成本总和为: 67665.96828574894
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 279 次迭代中的结果：
# agent 1 在 279 次迭代中的资源申请量为: -59.95119232846078
# agent 2 在 279 次迭代中的资源申请量为: -59.95119232846078
# agent 3 在 279 次迭代中的资源申请量为: -59.94018554255916
# agent 4 在 279 次迭代中的资源申请量为: 230.07485634263404
# agent 5 在 279 次迭代中的资源申请量为: 230.0555643525971
# agent 6 在 279 次迭代中的资源申请量为: -59.94235095757061
# agent 7 在 279 次迭代中的资源申请量为: 2.9773263759344957
# agent 8 在 279 次迭代中的资源申请量为: -59.54833486573194
# agent 9 在 279 次迭代中的资源申请量为: -58.74926859697736
# agent 10 在 279 次迭代中的资源申请量为: 233.0936181859819
# agent 11 在 279 次迭代中的资源申请量为: 1189.1345493387635
# agent 12 在 279 次迭代中的资源申请量为: -59.6342113764452
# agent 13 在 279 次迭代中的资源申请量为: -59.886416109196276
# agent 14 在 279 次迭代中的资源申请量为: 5.033018223634336
# agent 15 在 279 次迭代中的资源申请量为: -60.06535089185117
# agent 16 在 279 次迭代中的资源申请量为: 2.790030672408381
# agent 17 在 279 次迭代中的资源申请量为: -60.03386505421612
# agent 18 在 279 次迭代中的资源申请量为: -61.04815659774006
# agent 19 在 279 次迭代中的资源申请量为: 2.6910746615770833
# agent 20 在 279 次迭代中的资源申请量为: 1098.6418044034808
# agent 21 在 279 次迭代中的资源申请量为: 988.6988607529483
# agent 22 在 279 次迭代中的资源申请量为: -26.047723746737653
# agent 23 在 279 次迭代中的资源申请量为: -22.35838048768943
# agent 24 在 279 次迭代中的资源申请量为: 456.3014807710272
# agent 25 在 279 次迭代中的资源申请量为: 471.12655133170773
# agent 26 在 279 次迭代中的资源申请量为: -15.894117918435597
# agent 27 在 279 次迭代中的资源申请量为: 451.87371393916527
# agent 28 在 279 次迭代中的资源申请量为: 437.84551000684183
# agent 29 在 279 次迭代中的资源申请量为: 244.7979186186538
# agent 30 在 279 次迭代中的资源申请量为: 30.339398835933267
# agent 31 在 279 次迭代中的资源申请量为: -57.87537987715028
# agent 32 在 279 次迭代中的资源申请量为: -57.582346877898225
# agent 33 在 279 次迭代中的资源申请量为: -342.30223317063485
# agent 34 在 279 次迭代中的资源申请量为: 19.72265290734455
# agent 35 在 279 次迭代中的资源申请量为: 25.6517338264367
# agent 36 在 279 次迭代中的资源申请量为: 271.45531171913626
# agent 37 在 279 次迭代中的资源申请量为: 42.62097914112837
# agent 38 在 279 次迭代中的资源申请量为: -58.21946891057236
# agent 39 在 279 次迭代中的资源申请量为: 1008.6142686695531
# agent 40 在 279 次迭代中的资源申请量为: 266.5639640978668
# agent 41 在 279 次迭代中的资源申请量为: -332.48610329106464
# agent 42 在 279 次迭代中的资源申请量为: -200.7910099192979
# agent 43 在 279 次迭代中的资源申请量为: 279.77396031479844
# agent 44 在 279 次迭代中的资源申请量为: 296.7008605901324
# agent 45 在 279 次迭代中的资源申请量为: 332.3776109913131
# agent 46 在 279 次迭代中的资源申请量为: -300.08891297090895
# agent 47 在 279 次迭代中的资源申请量为: 109.49374936025634
# agent 48 在 279 次迭代中的资源申请量为: 118.20370601372707
# agent 49 在 279 次迭代中的资源申请量为: -729.8433235974725
# agent 50 在 279 次迭代中的资源申请量为: -90.85860792236414
# agent 51 在 279 次迭代中的资源申请量为: 140.06614299647165
# agent 52 在 279 次迭代中的资源申请量为: 140.06614299647165
# agent 53 在 279 次迭代中的资源申请量为: 2.980346500585881
# agent 54 在 279 次迭代中的资源申请量为: -236.66857359907618
# 资源申请量总和为: 5999.999999999999
# ****************************************************************************
# 成本总和为: 68252.59784401367
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 299 次迭代中的结果：
# agent 1 在 299 次迭代中的资源申请量为: -59.89548200133885
# agent 2 在 299 次迭代中的资源申请量为: -59.89548200133885
# agent 3 在 299 次迭代中的资源申请量为: -59.88527108535252
# agent 4 在 299 次迭代中的资源申请量为: 230.14636205797188
# agent 5 在 299 次迭代中的资源申请量为: 230.42120796616308
# agent 6 在 299 次迭代中的资源申请量为: -59.88301190648897
# agent 7 在 299 次迭代中的资源申请量为: 3.2841668402801893
# agent 8 在 299 次迭代中的资源申请量为: -59.52301711786717
# agent 9 在 299 次迭代中的资源申请量为: -58.76944341501563
# agent 10 在 299 次迭代中的资源申请量为: 233.13187658662267
# agent 11 在 299 次迭代中的资源申请量为: 1190.1022210059407
# agent 12 在 299 次迭代中的资源申请量为: -59.611394901035936
# agent 13 在 299 次迭代中的资源申请量为: -59.832444668830554
# agent 14 在 299 次迭代中的资源申请量为: 5.122069489515056
# agent 15 在 299 次迭代中的资源申请量为: -59.98803520998283
# agent 16 在 299 次迭代中的资源申请量为: 3.1050495610162088
# agent 17 在 299 次迭代中的资源申请量为: -59.96415149231843
# agent 18 在 299 次迭代中的资源申请量为: -60.87460507953566
# agent 19 在 299 次迭代中的资源申请量为: 3.239479331024821
# agent 20 在 299 次迭代中的资源申请量为: 1106.680290204079
# agent 21 在 299 次迭代中的资源申请量为: 1007.7352774034044
# agent 22 在 299 次迭代中的资源申请量为: -22.788855416518054
# agent 23 在 299 次迭代中的资源申请量为: -19.470421954494686
# agent 24 在 299 次迭代中的资源申请量为: 464.03173402788275
# agent 25 在 299 次迭代中的资源申请量为: 477.28254692211937
# agent 26 在 299 次迭代中的资源申请量为: -13.693132481599939
# agent 27 在 299 次迭代中的资源申请量为: 452.43361167586085
# agent 28 在 299 次迭代中的资源申请量为: 439.6058742835433
# agent 29 在 299 次迭代中的资源申请量为: 244.57546575907978
# agent 30 在 299 次迭代中的资源申请量为: 30.22131774326706
# agent 31 在 299 次迭代中的资源申请量为: -57.93683506239492
# agent 32 在 299 次迭代中的资源申请量为: -57.65772998079514
# agent 33 在 299 次迭代中的资源申请量为: -342.53721957206255
# agent 34 在 299 次迭代中的资源申请量为: 19.1619983457278
# agent 35 在 299 次迭代中的资源申请量为: 24.901726356534738
# agent 36 在 299 次迭代中的资源申请量为: 270.0142275192255
# agent 37 在 299 次迭代中的资源申请量为: 41.40492835975789
# agent 38 在 299 次迭代中的资源申请量为: -57.99935312627282
# agent 39 在 299 次迭代中的资源申请量为: 1033.8562926881912
# agent 40 在 299 次迭代中的资源申请量为: 265.25136748468435
# agent 41 在 299 次迭代中的资源申请量为: -333.40901248163414
# agent 42 在 299 次迭代中的资源申请量为: -204.16926382330502
# agent 43 在 299 次迭代中的资源申请量为: 277.6220706096479
# agent 44 在 299 次迭代中的资源申请量为: 294.03578922354535
# agent 45 在 299 次迭代中的资源申请量为: 328.7298171761518
# agent 46 在 299 次迭代中的资源申请量为: -301.85444017243793
# agent 47 在 299 次迭代中的资源申请量为: 105.67281094603385
# agent 48 在 299 次迭代中的资源申请量为: 114.13212260042349
# agent 49 在 299 次迭代中的资源申请量为: -766.2665009982486
# agent 50 在 299 次迭代中的资源申请量为: -96.69672931892335
# agent 51 在 299 次迭代中的资源申请量为: 135.3404094253686
# agent 52 在 299 次迭代中的资源申请量为: 135.3404094253686
# agent 53 在 299 次迭代中的资源申请量为: 3.2760233629294078
# agent 54 在 299 次迭代中的资源申请量为: -237.25671111357033
# 资源申请量总和为: 5999.999999999999
# ****************************************************************************
# 成本总和为: 68917.38480720746
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 319 次迭代中的结果：
# agent 1 在 319 次迭代中的资源申请量为: -59.825156140550384
# agent 2 在 319 次迭代中的资源申请量为: -59.825156140550384
# agent 3 在 319 次迭代中的资源申请量为: -59.81555754595488
# agent 4 在 319 次迭代中的资源申请量为: 230.33743648216452
# agent 5 在 319 次迭代中的资源申请量为: 230.87968867548042
# agent 6 在 319 次迭代中的资源申请量为: -59.80959571025112
# agent 7 在 319 次迭代中的资源申请量为: 3.6699393766873314
# agent 8 在 319 次迭代中的资源申请量为: -59.478850908669926
# agent 9 在 319 次迭代中的资源申请量为: -58.76587426339843
# agent 10 在 319 次迭代中的资源申请量为: 233.31204113792262
# agent 11 在 319 次迭代中的资源申请量为: 1191.4710962056508
# agent 12 在 319 次迭代中的资源申请量为: -59.56892334401617
# agent 13 在 319 次迭代中的资源申请量为: -59.76364259579636
# agent 14 在 319 次迭代中的资源申请量为: 5.322374698674398
# agent 15 在 319 次迭代中的资源申请量为: -59.89951843086303
# agent 16 在 319 次迭代中的资源申请量为: 3.4982140926386656
# agent 17 在 319 次迭代中的资源申请量为: -59.881821823647776
# agent 18 在 319 次迭代中的资源申请量为: -60.70234366207492
# agent 19 在 319 次迭代中的资源申请量为: 3.8271321650938184
# agent 20 在 319 次迭代中的资源申请量为: 1114.2713012748875
# agent 21 在 319 次迭代中的资源申请量为: 1024.8686600426747
# agent 22 在 319 次迭代中的资源申请量为: -19.846434519650938
# agent 23 在 319 次迭代中的资源申请量为: -16.849504504738103
# agent 24 在 319 次迭代中的资源申请量为: 471.06904874203474
# agent 25 在 319 次迭代中的资源申请量为: 482.9473244215963
# agent 26 在 319 次迭代中的资源申请量为: -11.670699752572077
# agent 27 在 319 次迭代中的资源申请量为: 453.05104875687533
# agent 28 在 319 次迭代中的资源申请量为: 441.270837453153
# agent 29 在 319 次迭代中的资源申请量为: 244.48827538141072
# agent 30 在 319 次迭代中的资源申请量为: 30.145633058748626
# agent 31 在 319 次迭代中的资源申请量为: -57.970717511482235
# agent 32 在 319 次迭代中的资源申请量为: -57.704231713551145
# agent 33 在 319 次迭代中的资源申请量为: -342.7005007785737
# agent 34 在 319 次迭代中的资源申请量为: 18.767971208635835
# agent 35 在 319 次迭代中的资源申请量为: 24.321985839807148
# agent 36 在 319 次迭代中的资源申请量为: 268.7900105968066
# agent 37 在 319 次迭代中的资源申请量为: 40.364742022006936
# agent 38 在 319 次迭代中的资源申请量为: -57.784858354004896
# agent 39 在 319 次迭代中的资源申请量为: 1056.8087520487331
# agent 40 在 319 次迭代中的资源申请量为: 264.250790093357
# agent 41 在 319 次迭代中的资源申请量为: -334.15180508821135
# agent 42 在 319 次迭代中的资源申请量为: -206.94418633034115
# agent 43 在 319 次迭代中的资源申请量为: 275.8171673190206
# agent 44 在 319 次迭代中的资源申请量为: 291.6738219143524
# agent 45 在 319 次迭代中的资源申请量为: 325.31011378196627
# agent 46 在 319 次迭代中的资源申请量为: -303.53736941267545
# agent 47 在 319 次迭代中的资源申请量为: 102.04447831094656
# agent 48 在 319 次迭代中的资源申请量为: 110.23698360155271
# agent 49 在 319 次迭代中的资源申请量为: -801.4989715553718
# agent 50 在 319 次迭代中的资源申请量为: -102.32608610329325
# agent 51 在 319 次迭代中的资源申请量为: 130.75638983451904
# agent 52 在 319 次迭代中的资源申请量为: 130.75638983451904
# agent 53 在 319 次迭代中的资源申请量为: 3.6526992015710675
# agent 54 在 319 次迭代中的资源申请量为: -237.66054138324887
# 资源申请量总和为: 5999.999999999999
# ****************************************************************************
# 成本总和为: 69647.67940004091
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 339 次迭代中的结果：
# agent 1 在 339 次迭代中的资源申请量为: -59.74312704356272
# agent 2 在 339 次迭代中的资源申请量为: -59.74312704356272
# agent 3 在 339 次迭代中的资源申请量为: -59.734041639663445
# agent 4 在 339 次迭代中的资源申请量为: 230.6348768237348
# agent 5 在 339 次迭代中的资源申请量为: 231.41214788880202
# agent 6 在 339 次迭代中的资源申请量为: -59.724999243265486
# agent 7 在 339 次迭代中的资源申请量为: 4.118509147143804
# agent 8 在 339 次迭代中的资源申请量为: -59.41960535470061
# agent 9 在 339 次迭代中的资源申请量为: -58.74320515525851
# agent 10 在 339 次迭代中的资源申请量为: 233.60648333741298
# agent 11 在 339 次迭代中的资源申请量为: 1193.1622486709034
# agent 12 在 339 次迭代中的资源申请量为: -59.51066886231794
# agent 13 在 339 次迭代中的资源申请量为: -59.68303126169326
# agent 14 在 339 次迭代中的资源申请量为: 5.612073909345472
# ...
# agent 87 在 1969 次迭代中的资源申请量为: 60.428212926771465
# agent 88 在 1969 次迭代中的资源申请量为: 65.13986864738705
# agent 89 在 1969 次迭代中的资源申请量为: 40.55214195118097
# agent 90 在 1969 次迭代中的资源申请量为: 59.228212926771455
# agent 91 在 1969 次迭代中的资源申请量为: 42.9434444188975
# agent 92 在 1969 次迭代中的资源申请量为: 56.9337350093275
# agent 93 在 1969 次迭代中的资源申请量为: 40.752141951180974
# agent 94 在 1969 次迭代中的资源申请量为: 36.36555174906529
# agent 95 在 1969 次迭代中的资源申请量为: 60.328212926771485
# agent 96 在 1969 次迭代中的资源申请量为: 60.52821292677148
# agent 97 在 1969 次迭代中的资源申请量为: 72.21385551212578
# agent 98 在 1969 次迭代中的资源申请量为: 73.0138555121258
# agent 99 在 1969 次迭代中的资源申请量为: 52.48132536580415
# agent 100 在 1969 次迭代中的资源申请量为: 48.54257034141721
# 资源申请量总和为: 4999.999999999974
# ****************************************************************************
# 成本总和为: 335425.89808577474
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1979 次迭代中的结果：
# agent 1 在 1979 次迭代中的资源申请量为: 48.4425703414172
# agent 2 在 1979 次迭代中的资源申请量为: 61.02821292677151
# agent 3 在 1979 次迭代中的资源申请量为: 43.843444418897526
# agent 4 在 1979 次迭代中的资源申请量为: 64.53986864738707
# agent 5 在 1979 次迭代中的资源申请量为: 65.33986864738706
# agent 6 在 1979 次迭代中的资源申请量为: 72.11385551212577
# agent 7 在 1979 次迭代中的资源申请量为: 39.5020292169083
# agent 8 在 1979 次迭代中的资源申请量为: 37.756927756062886
# agent 9 在 1979 次迭代中的资源申请量为: 43.1434444188975
# agent 10 在 1979 次迭代中的资源申请量为: 55.8337350093275
# agent 11 在 1979 次迭代中的资源申请量为: 45.521159695078595
# agent 12 在 1979 次迭代中的资源申请量为: 49.34257034141717
# agent 13 在 1979 次迭代中的资源申请量为: 65.83986864738704
# agent 14 在 1979 次迭代中的资源申请量为: 55.233735009327496
# agent 15 在 1979 次迭代中的资源申请量为: 43.5434444188975
# agent 16 在 1979 次迭代中的资源申请量为: 43.743444418897504
# agent 17 在 1979 次迭代中的资源申请量为: 44.92115969507859
# agent 18 在 1979 次迭代中的资源申请量为: 46.521159695078595
# agent 19 在 1979 次迭代中的资源申请量为: 41.35214195118097
# agent 20 在 1979 次迭代中的资源申请量为: 55.7337350093275
# agent 21 在 1979 次迭代中的资源申请量为: 38.802029216908295
# agent 22 在 1979 次迭代中的资源申请量为: 39.102029216908285
# agent 23 在 1979 次迭代中的资源申请量为: 47.84257034141717
# agent 24 在 1979 次迭代中的资源申请量为: 40.55214195118097
# agent 25 在 1979 次迭代中的资源申请量为: 45.22115969507859
# agent 26 在 1979 次迭代中的资源申请量为: 39.802029216908295
# agent 27 在 1979 次迭代中的资源申请量为: 65.53986864738704
# agent 28 在 1979 次迭代中的资源申请量为: 51.38132536580411
# agent 29 在 1979 次迭代中的资源申请量为: 40.852141951180975
# agent 30 在 1979 次迭代中的资源申请量为: 39.202029216908294
# agent 31 在 1979 次迭代中的资源申请量为: 60.428212926771465
# agent 32 在 1979 次迭代中的资源申请量为: 55.53373500932749
# agent 33 在 1979 次迭代中的资源申请量为: 41.65214195118097
# agent 34 在 1979 次迭代中的资源申请量为: 52.28132536580411
# agent 35 在 1979 次迭代中的资源申请量为: 38.90202921690829
# agent 36 在 1979 次迭代中的资源申请量为: 42.8434444188975
# agent 37 在 1979 次迭代中的资源申请量为: 52.58132536580411
# agent 38 在 1979 次迭代中的资源申请量为: 40.35214195118097
# agent 39 在 1979 次迭代中的资源申请量为: 43.3434444188975
# agent 40 在 1979 次迭代中的资源申请量为: 50.14257034141716
# agent 41 在 1979 次迭代中的资源申请量为: 66.23986864738703
# agent 42 在 1979 次迭代中的资源申请量为: 42.5434444188975
# agent 43 在 1979 次迭代中的资源申请量为: 51.78132536580411
# agent 44 在 1979 次迭代中的资源申请量为: 52.98132536580411
# agent 45 在 1979 次迭代中的资源申请量为: 48.242570341417164
# agent 46 在 1979 次迭代中的资源申请量为: 55.8337350093275
# agent 47 在 1979 次迭代中的资源申请量为: 45.92115969507859
# agent 48 在 1979 次迭代中的资源申请量为: 43.4434444188975
# agent 49 在 1979 次迭代中的资源申请量为: 42.743444418897504
# agent 50 在 1979 次迭代中的资源申请量为: 40.95214195118097
# agent 51 在 1979 次迭代中的资源申请量为: 48.34257034141717
# agent 52 在 1979 次迭代中的资源申请量为: 55.7337350093275
# agent 53 在 1979 次迭代中的资源申请量为: 39.00202921690829
# agent 54 在 1979 次迭代中的资源申请量为: 56.9337350093275
# agent 55 在 1979 次迭代中的资源申请量为: 71.01385551212576
# agent 56 在 1979 次迭代中的资源申请量为: 40.95214195118097
# agent 57 在 1979 次迭代中的资源申请量为: 60.428212926771465
# agent 58 在 1979 次迭代中的资源申请量为: 42.243444418897504
# agent 59 在 1979 次迭代中的资源申请量为: 47.942570341417166
# agent 60 在 1979 次迭代中的资源申请量为: 56.0337350093275
# agent 61 在 1979 次迭代中的资源申请量为: 65.93986864738704
# agent 62 在 1979 次迭代中的资源申请量为: 46.12115969507859
# agent 63 在 1979 次迭代中的资源申请量为: 39.00202921690829
# agent 64 在 1979 次迭代中的资源申请量为: 44.421159695078586
# agent 65 在 1979 次迭代中的资源申请量为: 42.743444418897504
# agent 66 在 1979 次迭代中的资源申请量为: 65.63986864738705
# agent 67 在 1979 次迭代中的资源申请量为: 43.3434444188975
# agent 68 在 1979 次迭代中的资源申请量为: 44.92115969507859
# agent 69 在 1979 次迭代中的资源申请量为: 45.42115969507859
# agent 70 在 1979 次迭代中的资源申请量为: 60.02821292677146
# agent 71 在 1979 次迭代中的资源申请量为: 72.01385551212576
# agent 72 在 1979 次迭代中的资源申请量为: 60.228212926771455
# agent 73 在 1979 次迭代中的资源申请量为: 43.743444418897504
# agent 74 在 1979 次迭代中的资源申请量为: 39.00202921690829
# agent 75 在 1979 次迭代中的资源申请量为: 51.98132536580411
# agent 76 在 1979 次迭代中的资源申请量为: 47.021159695078595
# agent 77 在 1979 次迭代中的资源申请量为: 40.852141951180975
# agent 78 在 1979 次迭代中的资源申请量为: 49.64257034141716
# agent 79 在 1979 次迭代中的资源申请量为: 42.8434444188975
# agent 80 在 1979 次迭代中的资源申请量为: 43.0434444188975
# agent 81 在 1979 次迭代中的资源申请量为: 39.50202921690829
# agent 82 在 1979 次迭代中的资源申请量为: 45.7211596950786
# agent 83 在 1979 次迭代中的资源申请量为: 41.65214195118097
# agent 84 在 1979 次迭代中的资源申请量为: 52.08132536580411
# agent 85 在 1979 次迭代中的资源申请量为: 55.7337350093275
# agent 86 在 1979 次迭代中的资源申请量为: 48.942570341417166
# agent 87 在 1979 次迭代中的资源申请量为: 60.428212926771465
# agent 88 在 1979 次迭代中的资源申请量为: 65.13986864738705
# agent 89 在 1979 次迭代中的资源申请量为: 40.55214195118097
# agent 90 在 1979 次迭代中的资源申请量为: 59.228212926771455
# agent 91 在 1979 次迭代中的资源申请量为: 42.9434444188975
# agent 92 在 1979 次迭代中的资源申请量为: 56.9337350093275
# agent 93 在 1979 次迭代中的资源申请量为: 40.752141951180974
# agent 94 在 1979 次迭代中的资源申请量为: 36.36555174906508
# agent 95 在 1979 次迭代中的资源申请量为: 60.328212926771485
# agent 96 在 1979 次迭代中的资源申请量为: 60.52821292677148
# agent 97 在 1979 次迭代中的资源申请量为: 72.21385551212578
# agent 98 在 1979 次迭代中的资源申请量为: 73.0138555121258
# agent 99 在 1979 次迭代中的资源申请量为: 52.48132536580415
# agent 100 在 1979 次迭代中的资源申请量为: 48.54257034141721
# 资源申请量总和为: 4999.999999999974
# ****************************************************************************
# 成本总和为: 335425.8980857747
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1989 次迭代中的结果：
# agent 1 在 1989 次迭代中的资源申请量为: 48.4425703414172
# agent 2 在 1989 次迭代中的资源申请量为: 61.02821292677151
# agent 3 在 1989 次迭代中的资源申请量为: 43.843444418897526
# agent 4 在 1989 次迭代中的资源申请量为: 64.53986864738707
# agent 5 在 1989 次迭代中的资源申请量为: 65.33986864738706
# agent 6 在 1989 次迭代中的资源申请量为: 72.11385551212577
# agent 7 在 1989 次迭代中的资源申请量为: 39.5020292169083
# agent 8 在 1989 次迭代中的资源申请量为: 37.756927756062886
# agent 9 在 1989 次迭代中的资源申请量为: 43.1434444188975
# agent 10 在 1989 次迭代中的资源申请量为: 55.8337350093275
# agent 11 在 1989 次迭代中的资源申请量为: 45.521159695078595
# agent 12 在 1989 次迭代中的资源申请量为: 49.34257034141717
# agent 13 在 1989 次迭代中的资源申请量为: 65.83986864738704
# agent 14 在 1989 次迭代中的资源申请量为: 55.233735009327496
# agent 15 在 1989 次迭代中的资源申请量为: 43.5434444188975
# agent 16 在 1989 次迭代中的资源申请量为: 43.743444418897504
# agent 17 在 1989 次迭代中的资源申请量为: 44.92115969507859
# agent 18 在 1989 次迭代中的资源申请量为: 46.521159695078595
# agent 19 在 1989 次迭代中的资源申请量为: 41.35214195118097
# agent 20 在 1989 次迭代中的资源申请量为: 55.7337350093275
# agent 21 在 1989 次迭代中的资源申请量为: 38.802029216908295
# agent 22 在 1989 次迭代中的资源申请量为: 39.102029216908285
# agent 23 在 1989 次迭代中的资源申请量为: 47.84257034141717
# agent 24 在 1989 次迭代中的资源申请量为: 40.55214195118097
# agent 25 在 1989 次迭代中的资源申请量为: 45.22115969507859
# agent 26 在 1989 次迭代中的资源申请量为: 39.802029216908295
# agent 27 在 1989 次迭代中的资源申请量为: 65.53986864738704
# agent 28 在 1989 次迭代中的资源申请量为: 51.38132536580411
# agent 29 在 1989 次迭代中的资源申请量为: 40.852141951180975
# agent 30 在 1989 次迭代中的资源申请量为: 39.202029216908294
# agent 31 在 1989 次迭代中的资源申请量为: 60.428212926771465
# agent 32 在 1989 次迭代中的资源申请量为: 55.53373500932749
# agent 33 在 1989 次迭代中的资源申请量为: 41.65214195118097
# agent 34 在 1989 次迭代中的资源申请量为: 52.28132536580411
# agent 35 在 1989 次迭代中的资源申请量为: 38.90202921690829
# agent 36 在 1989 次迭代中的资源申请量为: 42.8434444188975
# agent 37 在 1989 次迭代中的资源申请量为: 52.58132536580411
# agent 38 在 1989 次迭代中的资源申请量为: 40.35214195118097
# agent 39 在 1989 次迭代中的资源申请量为: 43.3434444188975
# agent 40 在 1989 次迭代中的资源申请量为: 50.14257034141716
# agent 41 在 1989 次迭代中的资源申请量为: 66.23986864738703
# agent 42 在 1989 次迭代中的资源申请量为: 42.5434444188975
# agent 43 在 1989 次迭代中的资源申请量为: 51.78132536580411
# agent 44 在 1989 次迭代中的资源申请量为: 52.98132536580411
# agent 45 在 1989 次迭代中的资源申请量为: 48.242570341417164
# agent 46 在 1989 次迭代中的资源申请量为: 55.8337350093275
# agent 47 在 1989 次迭代中的资源申请量为: 45.92115969507859
# agent 48 在 1989 次迭代中的资源申请量为: 43.4434444188975
# agent 49 在 1989 次迭代中的资源申请量为: 42.743444418897504
# agent 50 在 1989 次迭代中的资源申请量为: 40.95214195118097
# agent 51 在 1989 次迭代中的资源申请量为: 48.34257034141717
# agent 52 在 1989 次迭代中的资源申请量为: 55.7337350093275
# agent 53 在 1989 次迭代中的资源申请量为: 39.00202921690829
# agent 54 在 1989 次迭代中的资源申请量为: 56.9337350093275
# agent 55 在 1989 次迭代中的资源申请量为: 71.01385551212576
# agent 56 在 1989 次迭代中的资源申请量为: 40.95214195118097
# agent 57 在 1989 次迭代中的资源申请量为: 60.428212926771465
# agent 58 在 1989 次迭代中的资源申请量为: 42.243444418897504
# agent 59 在 1989 次迭代中的资源申请量为: 47.942570341417166
# agent 60 在 1989 次迭代中的资源申请量为: 56.0337350093275
# agent 61 在 1989 次迭代中的资源申请量为: 65.93986864738704
# agent 62 在 1989 次迭代中的资源申请量为: 46.12115969507859
# agent 63 在 1989 次迭代中的资源申请量为: 39.00202921690829
# agent 64 在 1989 次迭代中的资源申请量为: 44.421159695078586
# agent 65 在 1989 次迭代中的资源申请量为: 42.743444418897504
# agent 66 在 1989 次迭代中的资源申请量为: 65.63986864738705
# agent 67 在 1989 次迭代中的资源申请量为: 43.3434444188975
# agent 68 在 1989 次迭代中的资源申请量为: 44.92115969507859
# agent 69 在 1989 次迭代中的资源申请量为: 45.42115969507859
# agent 70 在 1989 次迭代中的资源申请量为: 60.02821292677146
# agent 71 在 1989 次迭代中的资源申请量为: 72.01385551212576
# agent 72 在 1989 次迭代中的资源申请量为: 60.228212926771455
# agent 73 在 1989 次迭代中的资源申请量为: 43.743444418897504
# agent 74 在 1989 次迭代中的资源申请量为: 39.00202921690829
# agent 75 在 1989 次迭代中的资源申请量为: 51.98132536580411
# agent 76 在 1989 次迭代中的资源申请量为: 47.021159695078595
# agent 77 在 1989 次迭代中的资源申请量为: 40.852141951180975
# agent 78 在 1989 次迭代中的资源申请量为: 49.64257034141716
# agent 79 在 1989 次迭代中的资源申请量为: 42.8434444188975
# agent 80 在 1989 次迭代中的资源申请量为: 43.0434444188975
# agent 81 在 1989 次迭代中的资源申请量为: 39.50202921690829
# agent 82 在 1989 次迭代中的资源申请量为: 45.7211596950786
# agent 83 在 1989 次迭代中的资源申请量为: 41.65214195118097
# agent 84 在 1989 次迭代中的资源申请量为: 52.08132536580411
# agent 85 在 1989 次迭代中的资源申请量为: 55.7337350093275
# agent 86 在 1989 次迭代中的资源申请量为: 48.942570341417166
# agent 87 在 1989 次迭代中的资源申请量为: 60.428212926771465
# agent 88 在 1989 次迭代中的资源申请量为: 65.13986864738705
# agent 89 在 1989 次迭代中的资源申请量为: 40.55214195118097
# agent 90 在 1989 次迭代中的资源申请量为: 59.228212926771455
# agent 91 在 1989 次迭代中的资源申请量为: 42.9434444188975
# agent 92 在 1989 次迭代中的资源申请量为: 56.9337350093275
# agent 93 在 1989 次迭代中的资源申请量为: 40.752141951180974
# agent 94 在 1989 次迭代中的资源申请量为: 36.36555174906486
# agent 95 在 1989 次迭代中的资源申请量为: 60.328212926771485
# agent 96 在 1989 次迭代中的资源申请量为: 60.52821292677148
# agent 97 在 1989 次迭代中的资源申请量为: 72.21385551212578
# agent 98 在 1989 次迭代中的资源申请量为: 73.0138555121258
# agent 99 在 1989 次迭代中的资源申请量为: 52.48132536580415
# agent 100 在 1989 次迭代中的资源申请量为: 48.54257034141721
# 资源申请量总和为: 4999.999999999974
# ****************************************************************************
# 成本总和为: 335425.8980857747
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1999 次迭代中的结果：
# agent 1 在 1999 次迭代中的资源申请量为: 48.4425703414172
# agent 2 在 1999 次迭代中的资源申请量为: 61.02821292677151
# agent 3 在 1999 次迭代中的资源申请量为: 43.843444418897526
# agent 4 在 1999 次迭代中的资源申请量为: 64.53986864738707
# agent 5 在 1999 次迭代中的资源申请量为: 65.33986864738706
# agent 6 在 1999 次迭代中的资源申请量为: 72.11385551212577
# agent 7 在 1999 次迭代中的资源申请量为: 39.5020292169083
# agent 8 在 1999 次迭代中的资源申请量为: 37.756927756062886
# agent 9 在 1999 次迭代中的资源申请量为: 43.1434444188975
# agent 10 在 1999 次迭代中的资源申请量为: 55.8337350093275
# agent 11 在 1999 次迭代中的资源申请量为: 45.521159695078595
# agent 12 在 1999 次迭代中的资源申请量为: 49.34257034141717
# agent 13 在 1999 次迭代中的资源申请量为: 65.83986864738704
# agent 14 在 1999 次迭代中的资源申请量为: 55.233735009327496
# agent 15 在 1999 次迭代中的资源申请量为: 43.5434444188975
# agent 16 在 1999 次迭代中的资源申请量为: 43.743444418897504
# agent 17 在 1999 次迭代中的资源申请量为: 44.92115969507859
# agent 18 在 1999 次迭代中的资源申请量为: 46.521159695078595
# agent 19 在 1999 次迭代中的资源申请量为: 41.35214195118097
# agent 20 在 1999 次迭代中的资源申请量为: 55.7337350093275
# agent 21 在 1999 次迭代中的资源申请量为: 38.802029216908295
# agent 22 在 1999 次迭代中的资源申请量为: 39.102029216908285
# agent 23 在 1999 次迭代中的资源申请量为: 47.84257034141717
# agent 24 在 1999 次迭代中的资源申请量为: 40.55214195118097
# agent 25 在 1999 次迭代中的资源申请量为: 45.22115969507859
# agent 26 在 1999 次迭代中的资源申请量为: 39.802029216908295
# agent 27 在 1999 次迭代中的资源申请量为: 65.53986864738704
# agent 28 在 1999 次迭代中的资源申请量为: 51.38132536580411
# agent 29 在 1999 次迭代中的资源申请量为: 40.852141951180975
# agent 30 在 1999 次迭代中的资源申请量为: 39.202029216908294
# agent 31 在 1999 次迭代中的资源申请量为: 60.428212926771465
# agent 32 在 1999 次迭代中的资源申请量为: 55.53373500932749
# agent 33 在 1999 次迭代中的资源申请量为: 41.65214195118097
# agent 34 在 1999 次迭代中的资源申请量为: 52.28132536580411
# agent 35 在 1999 次迭代中的资源申请量为: 38.90202921690829
# agent 36 在 1999 次迭代中的资源申请量为: 42.8434444188975
# agent 37 在 1999 次迭代中的资源申请量为: 52.58132536580411
# agent 38 在 1999 次迭代中的资源申请量为: 40.35214195118097
# agent 39 在 1999 次迭代中的资源申请量为: 43.3434444188975
# agent 40 在 1999 次迭代中的资源申请量为: 50.14257034141716
# agent 41 在 1999 次迭代中的资源申请量为: 66.23986864738703
# agent 42 在 1999 次迭代中的资源申请量为: 42.5434444188975
# agent 43 在 1999 次迭代中的资源申请量为: 51.78132536580411
# agent 44 在 1999 次迭代中的资源申请量为: 52.98132536580411
# agent 45 在 1999 次迭代中的资源申请量为: 48.242570341417164
# agent 46 在 1999 次迭代中的资源申请量为: 55.8337350093275
# agent 47 在 1999 次迭代中的资源申请量为: 45.92115969507859
# agent 48 在 1999 次迭代中的资源申请量为: 43.4434444188975
# agent 49 在 1999 次迭代中的资源申请量为: 42.743444418897504
# agent 50 在 1999 次迭代中的资源申请量为: 40.95214195118097
# agent 51 在 1999 次迭代中的资源申请量为: 48.34257034141717
# agent 52 在 1999 次迭代中的资源申请量为: 55.7337350093275
# agent 53 在 1999 次迭代中的资源申请量为: 39.00202921690829
# agent 54 在 1999 次迭代中的资源申请量为: 56.9337350093275
# agent 55 在 1999 次迭代中的资源申请量为: 71.01385551212576
# agent 56 在 1999 次迭代中的资源申请量为: 40.95214195118097
# agent 57 在 1999 次迭代中的资源申请量为: 60.428212926771465
# agent 58 在 1999 次迭代中的资源申请量为: 42.243444418897504
# agent 59 在 1999 次迭代中的资源申请量为: 47.942570341417166
# agent 60 在 1999 次迭代中的资源申请量为: 56.0337350093275
# agent 61 在 1999 次迭代中的资源申请量为: 65.93986864738704
# agent 62 在 1999 次迭代中的资源申请量为: 46.12115969507859
# agent 63 在 1999 次迭代中的资源申请量为: 39.00202921690829
# agent 64 在 1999 次迭代中的资源申请量为: 44.421159695078586
# agent 65 在 1999 次迭代中的资源申请量为: 42.743444418897504
# agent 66 在 1999 次迭代中的资源申请量为: 65.63986864738705
# agent 67 在 1999 次迭代中的资源申请量为: 43.3434444188975
# agent 68 在 1999 次迭代中的资源申请量为: 44.92115969507859
# agent 69 在 1999 次迭代中的资源申请量为: 45.42115969507859
# agent 70 在 1999 次迭代中的资源申请量为: 60.02821292677146
# agent 71 在 1999 次迭代中的资源申请量为: 72.01385551212576
# agent 72 在 1999 次迭代中的资源申请量为: 60.228212926771455
# agent 73 在 1999 次迭代中的资源申请量为: 43.743444418897504
# agent 74 在 1999 次迭代中的资源申请量为: 39.00202921690829
# agent 75 在 1999 次迭代中的资源申请量为: 51.98132536580411
# agent 76 在 1999 次迭代中的资源申请量为: 47.021159695078595
# agent 77 在 1999 次迭代中的资源申请量为: 40.852141951180975
# agent 78 在 1999 次迭代中的资源申请量为: 49.64257034141716
# agent 79 在 1999 次迭代中的资源申请量为: 42.8434444188975
# agent 80 在 1999 次迭代中的资源申请量为: 43.0434444188975
# agent 81 在 1999 次迭代中的资源申请量为: 39.50202921690829
# agent 82 在 1999 次迭代中的资源申请量为: 45.7211596950786
# agent 83 在 1999 次迭代中的资源申请量为: 41.65214195118097
# agent 84 在 1999 次迭代中的资源申请量为: 52.08132536580411
# agent 85 在 1999 次迭代中的资源申请量为: 55.7337350093275
# agent 86 在 1999 次迭代中的资源申请量为: 48.942570341417166
# agent 87 在 1999 次迭代中的资源申请量为: 60.428212926771465
# agent 88 在 1999 次迭代中的资源申请量为: 65.13986864738705
# agent 89 在 1999 次迭代中的资源申请量为: 40.55214195118097
# agent 90 在 1999 次迭代中的资源申请量为: 59.228212926771455
# agent 91 在 1999 次迭代中的资源申请量为: 42.9434444188975
# agent 92 在 1999 次迭代中的资源申请量为: 56.9337350093275
# agent 93 在 1999 次迭代中的资源申请量为: 40.752141951180974
# agent 94 在 1999 次迭代中的资源申请量为: 36.36555174906465
# agent 95 在 1999 次迭代中的资源申请量为: 60.328212926771485
# agent 96 在 1999 次迭代中的资源申请量为: 60.52821292677148
# agent 97 在 1999 次迭代中的资源申请量为: 72.21385551212578
# agent 98 在 1999 次迭代中的资源申请量为: 73.0138555121258
# agent 99 在 1999 次迭代中的资源申请量为: 52.48132536580415
# agent 100 在 1999 次迭代中的资源申请量为: 48.54257034141721
# 资源申请量总和为: 4999.999999999973
# ****************************************************************************
# 成本总和为: 335425.8980857747
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 2025-01-21 17:22:04.244

# %%
np.savetxt('../data/01-robust-agent_resource_quantity_large_value_deterministic_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/01-robust-sum_cost_large_value_deterministic_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/01-robust-sum_resource_large_value_deterministic_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
np.savetxt('../data/01-robust-agent_gradient_large_value_deterministic_bias.txt',agent_gradient,fmt='%0.8f')#用户迭代梯度
