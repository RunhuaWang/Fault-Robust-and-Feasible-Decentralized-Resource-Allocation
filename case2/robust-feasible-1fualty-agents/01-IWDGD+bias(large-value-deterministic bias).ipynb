# %% [raw]
# 基于初始化的权重梯度下降无中心资源分配算法+部分用户的梯度计算有误差（设备损坏导致的计算误差）

# %% [raw]
# 大值的确定性噪声

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(54,2000), dtype=np.float64) #100个agent的资源量 定义成一个矩阵
sum_resource=np.zeros(shape=(1,2000), dtype=np.float64)#存放每一次迭代后所有用户资源量的总和
sum_cost=np.zeros(shape=(1,2000), dtype=np.float64)#存放每一次迭代后所有用户成本的总和
iteration_update = 1 #迭代步长 
A=np.loadtxt("Adjacency_Matrix_generator_zero.txt") #网络拓扑的邻接矩阵 对角元素要为0
D=np.zeros(shape=(54,54))# 网络的度矩阵
L=np.zeros(shape=(54,54))# 网络的拉普拉斯矩阵 L=D-A
W=np.zeros(shape=(54,54)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
iteration=[]#绘图横坐标
generator_a_values= np.loadtxt("generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("generator_b_values.txt")#每个agent的成本函数中的超参数b
generator_c_values= np.loadtxt("generator_c_values.txt")#每个agent的成本函数中的超参数c
agent_gradient=np.zeros(shape=(54,2000), dtype=np.float64) 
bias=800

# %%
#根据邻接矩阵生成网络对应的度矩阵
for i in range(0,54):
    d=0
    for j in range(0,54):
        if A[i][j]==1:
            d=d+1
    D[i][i]=d

#根据邻接矩阵和度矩阵计算拉普拉斯矩阵
L=D-A

#选择用拉普拉斯矩阵作为聚合矩阵
W=L
    
#资源量的初始化 需要给定可行的初始化 即满足平均资源约束
for i in range (0,54):
    agent_resource_quantity[i][0]=6000/54
    
#总资源量 初始化
sum=0
for i in range (0,54):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

iteration.append(0)

#初始梯度计算 随机选择一个用户作为biased 用户
for i in range (0,54):
    if i==48:
        agent_gradient[i][0]=2*generator_c_values[i]*agent_resource_quantity[i][0]+generator_b_values[i]+bias
    else:
        agent_gradient[i][0]=2*generator_c_values[i]*agent_resource_quantity[i][0]+generator_b_values[i]
        

#用户总成本初始化
sum=0
for i in range(0,54):
    sum=sum+(generator_c_values[i]*(agent_resource_quantity[i][0])*(agent_resource_quantity[i][0])+generator_b_values[i]*agent_resource_quantity[i][0]+generator_a_values[i])
sum_cost[0][0]=sum

# %%
#基于初始化的权重梯度下降无中心资源分配算法
def IWDGD_deterministic_bias(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias):
    
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************IWDGD算法+计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,54):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,2000):#迭代次数
        iteration.append(k)
 
        #所有用户资源申请量基于可行初始化权重梯度下降的迭代  假设部分用户因为设备损坏 导致梯度的计算有误差     
        for i in range (0,54):
            weight_gradient_sum = np.float64(0)
            for j in range (0,54):        
                weight_gradient_sum=weight_gradient_sum+W[i][j]*agent_gradient[j][k-1]
            #weight_gradient_sum = np.round(weight_gradient_sum, decimals=3)
            agent_resource_quantity[i][k]=agent_resource_quantity[i][k-1]-iteration_update*weight_gradient_sum
            #agent_resource_quantity[i][k] = np.round(agent_resource_quantity[i][k], decimals=3)
        
        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,54):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,54):
            sum2=sum2+(generator_c_values[i]*(agent_resource_quantity[i][k])*(agent_resource_quantity[i][k])+generator_b_values[i]*agent_resource_quantity[i][k]+generator_a_values[i])
        sum_cost[0][k]=sum2
        
        #计算当前迭代的用户梯度
        for i in range (0,54): 
            if i==48:
                agent_gradient[i][k]=2*generator_c_values[i]*agent_resource_quantity[i][k]+generator_b_values[i]+bias
            else:
                agent_gradient[i][k]=2*generator_c_values[i]*agent_resource_quantity[i][k]+generator_b_values[i]
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%20==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,54):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=1/(pow(k+1,0.5)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
IWDGD_deterministic_bias(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias)
# Out:
# ****************************IWDGD算法+计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 111.11111111111111
# agent 2 的初始资源申请量为: 111.11111111111111
# agent 3 的初始资源申请量为: 111.11111111111111
# agent 4 的初始资源申请量为: 111.11111111111111
# agent 5 的初始资源申请量为: 111.11111111111111
# agent 6 的初始资源申请量为: 111.11111111111111
# agent 7 的初始资源申请量为: 111.11111111111111
# agent 8 的初始资源申请量为: 111.11111111111111
# agent 9 的初始资源申请量为: 111.11111111111111
# agent 10 的初始资源申请量为: 111.11111111111111
# agent 11 的初始资源申请量为: 111.11111111111111
# agent 12 的初始资源申请量为: 111.11111111111111
# agent 13 的初始资源申请量为: 111.11111111111111
# agent 14 的初始资源申请量为: 111.11111111111111
# agent 15 的初始资源申请量为: 111.11111111111111
# agent 16 的初始资源申请量为: 111.11111111111111
# agent 17 的初始资源申请量为: 111.11111111111111
# agent 18 的初始资源申请量为: 111.11111111111111
# agent 19 的初始资源申请量为: 111.11111111111111
# agent 20 的初始资源申请量为: 111.11111111111111
# agent 21 的初始资源申请量为: 111.11111111111111
# agent 22 的初始资源申请量为: 111.11111111111111
# agent 23 的初始资源申请量为: 111.11111111111111
# agent 24 的初始资源申请量为: 111.11111111111111
# agent 25 的初始资源申请量为: 111.11111111111111
# agent 26 的初始资源申请量为: 111.11111111111111
# agent 27 的初始资源申请量为: 111.11111111111111
# agent 28 的初始资源申请量为: 111.11111111111111
# agent 29 的初始资源申请量为: 111.11111111111111
# agent 30 的初始资源申请量为: 111.11111111111111
# agent 31 的初始资源申请量为: 111.11111111111111
# agent 32 的初始资源申请量为: 111.11111111111111
# agent 33 的初始资源申请量为: 111.11111111111111
# agent 34 的初始资源申请量为: 111.11111111111111
# agent 35 的初始资源申请量为: 111.11111111111111
# agent 36 的初始资源申请量为: 111.11111111111111
# agent 37 的初始资源申请量为: 111.11111111111111
# agent 38 的初始资源申请量为: 111.11111111111111
# agent 39 的初始资源申请量为: 111.11111111111111
# agent 40 的初始资源申请量为: 111.11111111111111
# agent 41 的初始资源申请量为: 111.11111111111111
# agent 42 的初始资源申请量为: 111.11111111111111
# agent 43 的初始资源申请量为: 111.11111111111111
# agent 44 的初始资源申请量为: 111.11111111111111
# agent 45 的初始资源申请量为: 111.11111111111111
# agent 46 的初始资源申请量为: 111.11111111111111
# agent 47 的初始资源申请量为: 111.11111111111111
# agent 48 的初始资源申请量为: 111.11111111111111
# agent 49 的初始资源申请量为: 111.11111111111111
# agent 50 的初始资源申请量为: 111.11111111111111
# agent 51 的初始资源申请量为: 111.11111111111111
# agent 52 的初始资源申请量为: 111.11111111111111
# agent 53 的初始资源申请量为: 111.11111111111111
# agent 54 的初始资源申请量为: 111.11111111111111
# *************************
# 初始资源申请量总和为: 6000.000000000006
# *************************
# 初始成本总和为: 139226.02283950621
# *************************
# 迭代步长为: 1
# *****************************************************************************
# 19 次迭代中的结果：
# agent 1 在 19 次迭代中的资源申请量为: -53.22822634967707
# agent 2 在 19 次迭代中的资源申请量为: -53.22822634967707
# agent 3 在 19 次迭代中的资源申请量为: -56.205085495434986
# agent 4 在 19 次迭代中的资源申请量为: 189.87525699083866
# agent 5 在 19 次迭代中的资源申请量为: 275.05875731847226
# agent 6 在 19 次迭代中的资源申请量为: -51.793810063693684
# agent 7 在 19 次迭代中的资源申请量为: 52.961901420567344
# agent 8 在 19 次迭代中的资源申请量为: -42.39986228029184
# agent 9 在 19 次迭代中的资源申请量为: -31.33563480589927
# agent 10 在 19 次迭代中的资源申请量为: 340.07544270829385
# agent 11 在 19 次迭代中的资源申请量为: 1064.0618563594987
# agent 12 在 19 次迭代中的资源申请量为: -43.908844682243966
# agent 13 在 19 次迭代中的资源申请量为: -49.78444070243371
# agent 14 在 19 次迭代中的资源申请量为: 115.35419137788278
# agent 15 在 19 次迭代中的资源申请量为: -61.06157097734335
# agent 16 在 19 次迭代中的资源申请量为: 38.84290949853569
# agent 17 在 19 次迭代中的资源申请量为: -54.26503895870307
# agent 18 在 19 次迭代中的资源申请量为: -67.18319835123276
# agent 19 在 19 次迭代中的资源申请量为: 38.43897174323693
# agent 20 在 19 次迭代中的资源申请量为: 608.4830102794232
# agent 21 在 19 次迭代中的资源申请量为: 332.9318423147024
# agent 22 在 19 次迭代中的资源申请量为: -50.78917328158364
# agent 23 在 19 次迭代中的资源申请量为: -70.97304860918071
# agent 24 在 19 次迭代中的资源申请量为: 276.6801684963319
# agent 25 在 19 次迭代中的资源申请量为: 231.53502998921525
# agent 26 在 19 次迭代中的资源申请量为: -73.12589900018699
# agent 27 在 19 次迭代中的资源申请量为: 509.6913590738468
# agent 28 在 19 次迭代中的资源申请量为: 312.6406942475426
# agent 29 在 19 次迭代中的资源申请量为: 419.5031562932209
# agent 30 在 19 次迭代中的资源申请量为: 87.84381727533423
# agent 31 在 19 次迭代中的资源申请量为: -17.489274548089757
# agent 32 在 19 次迭代中的资源申请量为: -12.127330082942336
# agent 33 在 19 次迭代中的资源申请量为: -251.3510257099285
# agent 34 在 19 次迭代中的资源申请量为: 216.8223845791901
# agent 35 在 19 次迭代中的资源申请量为: 279.4295339467987
# agent 36 在 19 次迭代中的资源申请量为: 808.0919165729674
# agent 37 在 19 次迭代中的资源申请量为: 601.7945738766185
# agent 38 在 19 次迭代中的资源申请量为: -31.665307226999175
# agent 39 在 19 次迭代中的资源申请量为: 297.5012328052939
# agent 40 在 19 次迭代中的资源申请量为: 386.5826619228604
# agent 41 在 19 次迭代中的资源申请量为: -226.89076120542452
# agent 42 在 19 次迭代中的资源申请量为: 107.5123329199475
# agent 43 在 19 次迭代中的资源申请量为: 529.4458839068178
# agent 44 在 19 次迭代中的资源申请量为: 948.9227133122203
# agent 45 在 19 次迭代中的资源申请量为: 2964.099013065584
# agent 46 在 19 次迭代中的资源申请量为: 546.9589010002455
# agent 47 在 19 次迭代中的资源申请量为: 1805.1492411361776
# agent 48 在 19 次迭代中的资源申请量为: 3037.1198971471954
# agent 49 在 19 次迭代中的资源申请量为: -11893.069840611863
# agent 50 在 19 次迭代中的资源申请量为: 1098.956260798961
# agent 51 在 19 次迭代中的资源申请量为: 321.2430300344369
# agent 52 在 19 次迭代中的资源申请量为: 321.2430300344369
# agent 53 在 19 次迭代中的资源申请量为: 45.9292295281808
# agent 54 在 19 次迭代中的资源申请量为: -18.90460268205068
# 资源申请量总和为: 5999.9999999999945
# ****************************************************************************
# 成本总和为: 4144198.6071083676
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 39 次迭代中的结果：
# agent 1 在 39 次迭代中的资源申请量为: -53.89601329626078
# agent 2 在 39 次迭代中的资源申请量为: -53.89601329626078
# agent 3 在 39 次迭代中的资源申请量为: -52.86970075117949
# agent 4 在 39 次迭代中的资源申请量为: 215.9000005216819
# agent 5 在 39 次迭代中的资源申请量为: 271.37605496406286
# agent 6 在 39 次迭代中的资源申请量为: -52.694176793456386
# agent 7 在 39 次迭代中的资源申请量为: 43.472784243579234
# agent 8 在 39 次迭代中的资源申请量为: -47.16455948964039
# agent 9 在 39 次迭代中的资源申请量为: -37.46970596064861
# agent 10 在 39 次迭代中的资源申请量为: 316.49525713266524
# agent 11 在 39 次迭代中的资源申请量为: 1273.9735488042832
# agent 12 在 39 次迭代中的资源申请量为: -48.37738474967406
# agent 13 在 39 次迭代中的资源申请量为: -51.8514883034722
# agent 14 在 39 次迭代中的资源申请量为: 74.28268858081493
# agent 15 在 39 次迭代中的资源申请量为: -55.73105314716306
# agent 16 在 39 次迭代中的资源申请量为: 38.465353345416915
# agent 17 在 39 次迭代中的资源申请量为: -53.76889579944448
# agent 18 在 39 次迭代中的资源申请量为: -63.159383426214205
# agent 19 在 39 次迭代中的资源申请量为: 48.3419012652691
# agent 20 在 39 次迭代中的资源申请量为: 849.0373634253366
# agent 21 在 39 次迭代中的资源申请量为: 459.57277924949676
# agent 22 在 39 次迭代中的资源申请量为: -89.44247772105359
# agent 23 在 39 次迭代中的资源申请量为: -88.20102950784369
# agent 24 在 39 次迭代中的资源申请量为: 306.88915911101805
# agent 25 在 39 次迭代中的资源申请量为: 312.11998398902216
# agent 26 在 39 次迭代中的资源申请量为: -74.98428846947787
# agent 27 在 39 次迭代中的资源申请量为: 535.6141924542974
# agent 28 在 39 次迭代中的资源申请量为: 385.63551170492866
# agent 29 在 39 次迭代中的资源申请量为: 472.01029307754044
# agent 30 在 39 次迭代中的资源申请量为: 87.32086126019888
# agent 31 在 39 次迭代中的资源申请量为: -26.952187323475965
# agent 32 在 39 次迭代中的资源申请量为: -23.480377061149497
# agent 33 在 39 次迭代中的资源申请量为: -238.4963276605145
# agent 34 在 39 次迭代中的资源申请量为: 242.39006233517543
# agent 35 在 39 次迭代中的资源申请量为: 351.59464356748526
# agent 36 在 39 次迭代中的资源申请量为: 898.9559961651386
# agent 37 在 39 次迭代中的资源申请量为: 673.5175038942573
# agent 38 在 39 次迭代中的资源申请量为: -14.427903378790539
# agent 39 在 39 次迭代中的资源申请量为: 500.0779659665812
# agent 40 在 39 次迭代中的资源申请量为: 524.4870883815265
# agent 41 在 39 次迭代中的资源申请量为: -235.52793631927887
# agent 42 在 39 次迭代中的资源申请量为: 138.7373485041785
# agent 43 在 39 次迭代中的资源申请量为: 798.1849454341012
# agent 44 在 39 次迭代中的资源申请量为: 1245.9586457044197
# agent 45 在 39 次迭代中的资源申请量为: 2168.573918577054
# agent 46 在 39 次迭代中的资源申请量为: 480.4441165596981
# agent 47 在 39 次迭代中的资源申请量为: 2025.0931873053337
# agent 48 在 39 次迭代中的资源申请量为: 2096.399479655021
# agent 49 在 39 次迭代中的资源申请量为: -13383.43543534843
# agent 50 在 39 次迭代中的资源申请量为: 1439.8618166109134
# agent 51 在 39 次迭代中的资源申请量为: 685.0006406493561
# agent 52 在 39 次迭代中的资源申请量为: 685.0006406493561
# agent 53 在 39 次迭代中的资源申请量为: 41.854205019566905
# agent 54 在 39 次迭代中的资源申请量为: 59.18639969464614
# 资源申请量总和为: 5999.99999999999
# ****************************************************************************
# 成本总和为: 5116124.280289338
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 59 次迭代中的结果：
# agent 1 在 59 次迭代中的资源申请量为: -50.915481759930344
# agent 2 在 59 次迭代中的资源申请量为: -50.915481759930344
# agent 3 在 59 次迭代中的资源申请量为: -49.93958757362988
# agent 4 在 59 次迭代中的资源申请量为: 238.51651588888996
# agent 5 在 59 次迭代中的资源申请量为: 290.1770754433472
# agent 6 在 59 次迭代中的资源申请量为: -49.957214912236694
# agent 7 在 59 次迭代中的资源申请量为: 57.77125744509617
# agent 8 在 59 次迭代中的资源申请量为: -46.00787047887394
# agent 9 在 59 次迭代中的资源申请量为: -36.37075897690022
# agent 10 在 59 次迭代中的资源申请量为: 316.5337335617389
# agent 11 在 59 次迭代中的资源申请量为: 1369.2262850691366
# agent 12 在 59 次迭代中的资源申请量为: -47.74823014846329
# agent 13 在 59 次迭代中的资源申请量为: -49.519768704227786
# agent 14 在 59 次迭代中的资源申请量为: 75.4436866969892
# agent 15 在 59 次迭代中的资源申请量为: -51.46834688687174
# agent 16 在 59 次迭代中的资源申请量为: 54.64036750669965
# agent 17 在 59 次迭代中的资源申请量为: -50.67308436995479
# agent 18 在 59 次迭代中的资源申请量为: -58.32026507953083
# agent 19 在 59 次迭代中的资源申请量为: 72.52783786057263
# agent 20 在 59 次迭代中的资源申请量为: 1030.2732626630159
# agent 21 在 59 次迭代中的资源申请量为: 560.406140093813
# agent 22 在 59 次迭代中的资源申请量为: -88.41590958385991
# agent 23 在 59 次迭代中的资源申请量为: -77.35522812195603
# agent 24 在 59 次迭代中的资源申请量为: 338.7893924723107
# agent 25 在 59 次迭代中的资源申请量为: 376.2947863276153
# agent 26 在 59 次迭代中的资源申请量为: -55.39011784220749
# agent 27 在 59 次迭代中的资源申请量为: 556.012665765799
# agent 28 在 59 次迭代中的资源申请量为: 426.3400149082867
# agent 29 在 59 次迭代中的资源申请量为: 497.6104905174528
# agent 30 在 59 次迭代中的资源申请量为: 91.76144534900487
# agent 31 在 59 次迭代中的资源申请量为: -25.125127590826
# agent 32 在 59 次迭代中的资源申请量为: -21.39866661273423
# agent 33 在 59 次迭代中的资源申请量为: -228.32179445590828
# agent 34 在 59 次迭代中的资源申请量为: 267.385452907287
# agent 35 在 59 次迭代中的资源申请量为: 363.3866416292847
# agent 36 在 59 次迭代中的资源申请量为: 868.2227061054467
# agent 37 在 59 次迭代中的资源申请量为: 627.1209683700969
# agent 38 在 59 次迭代中的资源申请量为: -8.79794875266257
# agent 39 在 59 次迭代中的资源申请量为: 706.2440714314807
# agent 40 在 59 次迭代中的资源申请量为: 619.5098903405884
# agent 41 在 59 次迭代中的资源申请量为: -206.7489301912551
# agent 42 在 59 次迭代中的资源申请量为: 210.11506482298051
# agent 43 在 59 次迭代中的资源申请量为: 858.6288403342946
# agent 44 在 59 次迭代中的资源申请量为: 1221.7056019321494
# agent 45 在 59 次迭代中的资源申请量为: 1764.1885124863813
# agent 46 在 59 次迭代中的资源申请量为: 345.02288706008534
# agent 47 在 59 次迭代中的资源申请量为: 1704.796373925266
# agent 48 在 59 次迭代中的资源申请量为: 1630.5401458631347
# agent 49 在 59 次迭代中的资源申请量为: -13731.832241275484
# agent 50 在 59 次迭代中的资源申请量为: 1423.439532329211
# agent 51 在 59 次迭代中的资源申请量为: 933.8681822638827
# agent 52 在 59 次迭代中的资源申请量为: 933.8681822638827
# agent 53 在 59 次迭代中的资源申请量为: 56.501613894459126
# agent 54 在 59 次迭代中的资源申请量为: 98.35242954775524
# 资源申请量总和为: 5999.999999999996
# ****************************************************************************
# 成本总和为: 5327910.917501105
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 79 次迭代中的结果：
# agent 1 在 79 次迭代中的资源申请量为: -47.90338301182419
# agent 2 在 79 次迭代中的资源申请量为: -47.90338301182419
# agent 3 在 79 次迭代中的资源申请量为: -47.26625931673416
# agent 4 在 79 次迭代中的资源申请量为: 260.0567648947283
# agent 5 在 79 次迭代中的资源申请量为: 309.1604806122607
# agent 6 在 79 次迭代中的资源申请量为: -47.10858364940349
# agent 7 在 79 次迭代中的资源申请量为: 73.37071224482858
# agent 8 在 79 次迭代中的资源申请量为: -43.670728795304946
# agent 9 在 79 次迭代中的资源申请量为: -34.414974754674255
# agent 10 在 79 次迭代中的资源申请量为: 329.12937453500905
# agent 11 在 79 次迭代中的资源申请量为: 1443.1117742796903
# agent 12 在 79 次迭代中的资源申请量为: -45.51908318663796
# agent 13 在 79 次迭代中的资源申请量为: -46.7527142744154
# agent 14 在 79 次迭代中的资源申请量为: 87.08972164361074
# agent 15 在 79 次迭代中的资源申请量为: -47.96590530894756
# agent 16 在 79 次迭代中的资源申请量为: 70.72343722037292
# agent 17 在 79 次迭代中的资源申请量为: -47.664713207938014
# agent 18 在 79 次迭代中的资源申请量为: -54.19397443641458
# agent 19 在 79 次迭代中的资源申请量为: 93.28630792635539
# agent 20 在 79 次迭代中的资源申请量为: 1174.4860346657315
# agent 21 在 79 次迭代中的资源申请量为: 657.0130615161261
# agent 22 在 79 次迭代中的资源申请量为: -75.80123012812197
# agent 23 在 79 次迭代中的资源申请量为: -60.50946598829012
# agent 24 在 79 次迭代中的资源申请量为: 380.7715057095491
# agent 25 在 79 次迭代中的资源申请量为: 433.10510823443764
# agent 26 在 79 次迭代中的资源申请量为: -35.09929850408506
# agent 27 在 79 次迭代中的资源申请量为: 571.3668050962557
# agent 28 在 79 次迭代中的资源申请量为: 456.2838542654104
# agent 29 在 79 次迭代中的资源申请量为: 506.80712709423847
# agent 30 在 79 次迭代中的资源申请量为: 93.9206162071527
# agent 31 在 79 次迭代中的资源申请量为: -23.293066274410627
# agent 32 在 79 次迭代中的资源申请量为: -19.571729626487162
# agent 33 在 79 次迭代中的资源申请量为: -224.94875416921747
# agent 34 在 79 次迭代中的资源申请量为: 277.75335421019474
# agent 35 在 79 次迭代中的资源申请量为: 357.1016648377689
# agent 36 在 79 次迭代中的资源申请量为: 822.196483831853
# agent 37 在 79 次迭代中的资源申请量为: 576.2920012528358
# agent 38 在 79 次迭代中的资源申请量为: -6.210560715778158
# agent 39 在 79 次迭代中的资源申请量为: 899.350311389528
# agent 40 在 79 次迭代中的资源申请量为: 671.4861226687323
# agent 41 在 79 次迭代中的资源申请量为: -182.3985023104782
# agent 42 在 79 次迭代中的资源申请量为: 269.9999922770646
# agent 43 在 79 次迭代中的资源申请量为: 855.1253370429923
# agent 44 在 79 次迭代中的资源申请量为: 1134.5826928833828
# agent 45 在 79 次迭代中的资源申请量为: 1517.4899153766792
# agent 46 在 79 次迭代中的资源申请量为: 245.32178306647518
# agent 47 在 79 次迭代中的资源申请量为: 1417.0474777617248
# agent 48 在 79 次迭代中的资源申请量为: 1363.218091606684
# agent 49 在 79 次迭代中的资源申请量为: -13880.275789518615
# agent 50 在 79 次迭代中的资源申请量为: 1358.7617594384953
# agent 51 在 79 次迭代中的资源申请量为: 1066.7439477584005
# agent 52 在 79 次迭代中的资源申请量为: 1066.7439477584005
# agent 53 在 79 次迭代中的资源申请量为: 72.12430869982092
# agent 54 在 79 次迭代中的资源申请量为: 107.45022218280548
# 资源申请量总和为: 5999.9999999999945
# ****************************************************************************
# 成本总和为: 5410436.627773323
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: -45.221932585608144
# agent 2 在 99 次迭代中的资源申请量为: -45.221932585608144
# agent 3 在 99 次迭代中的资源申请量为: -44.8329683344179
# agent 4 在 99 次迭代中的资源申请量为: 280.29930997612865
# agent 5 在 99 次迭代中的资源申请量为: 326.0744254933701
# agent 6 在 99 次迭代中的资源申请量为: -44.551765313323074
# agent 7 在 99 次迭代中的资源申请量为: 87.43050700134776
# agent 8 在 99 次迭代中的资源申请量为: -41.34807338767644
# agent 9 在 99 次迭代中的资源申请量为: -32.72926297865513
# agent 10 在 99 次迭代中的资源申请量为: 344.0986625802178
# agent 11 在 99 次迭代中的资源申请量为: 1508.1011386132284
# agent 12 在 99 次迭代中的资源申请量为: -43.09096729892322
# agent 13 在 99 次迭代中的资源申请量为: -44.20392871472386
# agent 14 在 99 次迭代中的资源申请量为: 99.9450874864572
# agent 15 在 99 次迭代中的资源申请量为: -45.06530470297827
# agent 16 在 99 次迭代中的资源申请量为: 85.01820805268767
# agent 17 在 99 次迭代中的资源申请量为: -45.014199926153125
# agent 18 在 99 次迭代中的资源申请量为: -50.75343089070816
# agent 19 在 99 次迭代中的资源申请量为: 108.74129823386495
# agent 20 在 99 次迭代中的资源申请量为: 1290.7686390332024
# agent 21 在 99 次迭代中的资源申请量为: 753.4090826191136
# agent 22 在 99 次迭代中的资源申请量为: -59.61736800314759
# agent 23 在 99 次迭代中的资源申请量为: -42.548971585514366
# agent 24 在 99 次迭代中的资源申请量为: 427.04153686989906
# agent 25 在 99 次迭代中的资源申请量为: 484.94042121831455
# agent 26 在 99 次迭代中的资源申请量为: -16.208430177326534
# agent 27 在 99 次迭代中的资源申请量为: 583.6136881358011
# agent 28 在 99 次迭代中的资源申请量为: 480.3928117602174
# agent 29 在 99 次迭代中的资源申请量为: 507.6147404248253
# agent 30 在 99 次迭代中的资源申请量为: 94.28328312303715
# agent 31 在 99 次迭代中的资源申请量为: -22.305033751641997
# agent 32 在 99 次迭代中的资源申请量为: -18.799101843548172
# agent 33 在 99 次迭代中的资源申请量为: -225.47155577364782
# agent 34 在 99 次迭代中的资源申请量为: 278.2767564359975
# agent 35 在 99 次迭代中的资源申请量为: 344.8545558734278
# agent 36 在 99 次迭代中的资源申请量为: 778.9199112107515
# agent 37 在 99 次迭代中的资源申请量为: 532.5529751024617
# agent 38 在 99 次迭代中的资源申请量为: -4.977791280715788
# agent 39 在 99 次迭代中的资源申请量为: 1075.430327668776
# agent 40 在 99 次迭代中的资源申请量为: 695.985426489858
# agent 41 在 99 次迭代中的资源申请量为: -167.33947196199995
# agent 42 在 99 次迭代中的资源申请量为: 307.79881299645916
# agent 43 在 99 次迭代中的资源申请量为: 834.2220243287159
# agent 44 在 99 次迭代中的资源申请量为: 1048.3083736290782
# agent 45 在 99 次迭代中的资源申请量为: 1349.0880702725183
# agent 46 在 99 次迭代中的资源申请量为: 174.82669356889213
# agent 47 在 99 次迭代中的资源申请量为: 1211.6541088594383
# agent 48 在 99 次迭代中的资源申请量为: 1187.0938562049553
# agent 49 在 99 次迭代中的资源申请量为: -13968.918987361545
# agent 50 在 99 次迭代中的资源申请量为: 1288.826688008843
# agent 51 在 99 次迭代中的资源申请量为: 1124.738012722666
# agent 52 在 99 次迭代中的资源申请量为: 1124.738012722666
# agent 53 在 99 次迭代中的资源申请量为: 86.27629927701943
# agent 54 在 99 次迭代中的资源申请量为: 102.85673246361935
# 资源申请量总和为: 5999.999999999996
# ****************************************************************************
# 成本总和为: 5457905.07138579
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 119 次迭代中的结果：
# agent 1 在 119 次迭代中的资源申请量为: -42.890082916988014
# agent 2 在 119 次迭代中的资源申请量为: -42.890082916988014
# agent 3 在 119 次迭代中的资源申请量为: -42.65821307152461
# agent 4 在 119 次迭代中的资源申请量为: 298.9379464330369
# agent 5 在 119 次迭代中的资源申请量为: 340.78944744985745
# agent 6 在 119 次迭代中的资源申请量为: -42.32089168421361
# agent 7 在 119 次迭代中的资源申请量为: 99.64824277382453
# agent 8 在 119 次迭代中的资源申请量为: -39.31619107377399
# agent 9 在 119 次迭代中的资源申请量为: -31.435299882727488
# agent 10 在 119 次迭代中的资源申请量为: 357.91703346634426
# agent 11 在 119 次迭代中的资源申请量为: 1565.347725246709
# agent 12 在 119 次迭代中的资源申请量为: -40.88547105968664
# agent 13 在 119 次迭代中的资源申请量为: -41.97532880484274
# agent 14 在 119 次迭代中的资源申请量为: 111.54139388688971
# agent 15 在 119 次迭代中的资源申请量为: -42.652206209279576
# agent 16 在 119 次迭代中的资源申请量为: 97.44288700888592
# agent 17 在 119 次迭代中的资源申请量为: -42.72336481380142
# agent 18 在 119 次迭代中的资源申请量为: -47.8804853420807
# agent 19 在 119 次迭代中的资源申请量为: 120.1554856769618
# agent 20 在 119 次迭代中的资源申请量为: 1385.8314296051547
# agent 21 在 119 次迭代中的资源申请量为: 848.9621626584004
# agent 22 在 119 次迭代中的资源申请量为: -42.5486010631772
# agent 23 在 119 次迭代中的资源申请量为: -24.96867482938492
# agent 24 在 119 次迭代中的资源申请量为: 473.7670283616676
# agent 25 在 119 次迭代中的资源申请量为: 532.7330267765227
# agent 26 在 119 次迭代中的资源申请量为: 1.1586277779275953
# agent 27 在 119 次迭代中的资源申请量为: 593.9084062806883
# agent 28 在 119 次迭代中的资源申请量为: 500.58663786879293
# agent 29 在 119 次迭代中的资源申请量为: 504.7928123374143
# agent 30 在 119 次迭代中的资源申请量为: 93.7012998295079
# agent 31 在 119 次迭代中的资源申请量为: -21.92042877883982
# agent 32 在 119 次迭代中的资源申请量为: -18.712502074318593
# agent 33 在 119 次迭代中的资源申请量为: -227.77571753813
# agent 34 在 119 次迭代中的资源申请量为: 273.9363983450579
# agent 35 在 119 次迭代中的资源申请量为: 331.3203243018271
# agent 36 在 119 次迭代中的资源申请量为: 742.2457582852866
# agent 37 在 119 次迭代中的资源申请量为: 496.590818328574
# agent 38 在 119 次迭代中的资源申请量为: -4.411170592714665
# agent 39 在 119 次迭代中的资源申请量为: 1233.8357938408524
# agent 40 在 119 次迭代中的资源申请量为: 704.4702328489168
# agent 41 在 119 次迭代中的资源申请量为: -159.79269459262585
# agent 42 在 119 次迭代中的资源申请量为: 326.19214095081344
# agent 43 在 119 次迭代中的资源申请量为: 809.3900923981545
# agent 44 在 119 次迭代中的资源申请量为: 976.0091460038108
# agent 45 在 119 次迭代中的资源申请量为: 1228.1245163896724
# agent 46 在 119 次迭代中的资源申请量为: 123.31639736533421
# agent 47 在 119 次迭代中的资源申请量为: 1066.5264007208862
# agent 48 在 119 次迭代中的资源申请量为: 1062.061441327503
# agent 49 在 119 次迭代中的资源申请量为: -14029.503742932797
# agent 50 在 119 次迭代中的资源申请量为: 1218.6649635225358
# agent 51 在 119 次迭代中的资源申请量为: 1137.5709546869882
# agent 52 在 119 次迭代中的资源申请量为: 1137.5709546869882
# agent 53 在 119 次迭代中的资源申请量为: 98.62847515049381
# agent 54 在 119 次迭代中的资源申请量为: 93.58474758560396
# 资源申请量总和为: 5999.999999999989
# ****************************************************************************
# 成本总和为: 5489287.617731105
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 139 次迭代中的结果：
# agent 1 在 139 次迭代中的资源申请量为: -40.87416702005068
# agent 2 在 139 次迭代中的资源申请量为: -40.87416702005068
# agent 3 在 139 次迭代中的资源申请量为: -40.73761949374446
# agent 4 在 139 次迭代中的资源申请量为: 315.8149265582982
# agent 5 在 139 次迭代中的资源申请量为: 353.51283688829614
# agent 6 在 139 次迭代中的资源申请量为: -40.38753443685545
# agent 7 在 139 次迭代中的资源申请量为: 110.18135369040179
# agent 8 在 139 次迭代中的资源申请量为: -37.59248955572198
# agent 9 在 139 次迭代中的资源申请量为: -30.446429022615032
# agent 10 在 139 次迭代中的资源申请量为: 369.81245206773787
# agent 11 在 139 次迭代中的资源申请量为: 1615.183644571305
# agent 12 在 139 次迭代中的资源申请量为: -38.982970683838516
# agent 13 在 139 次迭代中的资源申请量为: -40.05159485528753
# agent 14 在 139 次迭代中的资源申请量为: 121.46708822305898
# agent 15 在 139 次迭代中的资源申请量为: -40.626346577787004
# agent 16 在 139 次迭代中的资源申请量为: 108.18119891962246
# agent 17 在 139 次迭代中的资源申请量为: -40.74932550921582
# agent 18 在 139 次迭代中的资源申请量为: -45.45806287662299
# agent 19 在 139 次迭代中的资源申请量为: 128.8976433757203
# agent 20 在 139 次迭代中的资源申请量为: 1465.0622566917093
# agent 21 在 139 次迭代中的资源申请量为: 942.2002280397213
# agent 22 在 139 次迭代中的资源申请量为: -25.652926766590365
# agent 23 在 139 次迭代中的资源申请量为: -8.27457306437174
# agent 24 在 139 次迭代中的资源申请量为: 519.0791065768367
# agent 25 在 139 次迭代中的资源申请量为: 576.9425464051529
# agent 26 在 139 次迭代中的资源申请量为: 17.09062470060502
# agent 27 在 139 次迭代中的资源申请量为: 602.8678724785055
# agent 28 在 139 次迭代中的资源申请量为: 517.9177289457061
# agent 29 在 139 次迭代中的资源申请量为: 500.87003091074155
# agent 30 在 139 次迭代中的资源申请量为: 92.75296038055406
# agent 31 在 139 次迭代中的资源申请量为: -21.856953159465924
# agent 32 在 139 次迭代中的资源申请量为: -18.95834870410689
# agent 33 在 139 次迭代中的资源申请量为: -230.63590351282517
# agent 34 在 139 次迭代中的资源申请量为: 267.8308971669441
# agent 35 在 139 次迭代中的资源申请量为: 318.5654443812728
# agent 36 在 139 次迭代中的资源申请量为: 712.2008055568277
# agent 37 在 139 次迭代中的资源申请量为: 467.36118650035905
# agent 38 在 139 次迭代中的资源申请量为: -4.172737099988904
# agent 39 在 139 次迭代中的资源申请量为: 1375.3006481130417
# agent 40 在 139 次迭代中的资源申请量为: 703.9200458044503
# agent 41 在 139 次迭代中的资源申请量为: -157.36883958088288
# agent 42 在 139 次迭代中的资源申请量为: 330.5418101584693
# agent 43 在 139 次迭代中的资源申请量为: 784.9248650709884
# agent 44 在 139 次迭代中的资源申请量为: 917.88663078984
# agent 45 在 139 次迭代中的资源申请量为: 1137.9547835596047
# agent 46 在 139 次迭代中的资源申请量为: 83.99749205139229
# agent 47 在 139 次迭代中的资源申请量为: 960.6589265673342
# agent 48 在 139 次迭代中的资源申请量为: 968.4718995282672
# agent 49 在 139 次迭代中的资源申请量为: -14073.635917827292
# agent 50 在 139 次迭代中的资源申请量为: 1149.5062318960345
# agent 51 在 139 次迭代中的资源申请量为: 1123.6653206940914
# agent 52 在 139 次迭代中的资源申请量为: 1123.6653206940914
# agent 53 在 139 次迭代中的资源申请量为: 109.29971846852317
# agent 54 在 139 次迭代中的资源申请量为: 83.75038034180335
# 资源申请量总和为: 5999.999999999994
# ****************************************************************************
# 成本总和为: 5511156.486703599
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 159 次迭代中的结果：
# agent 1 在 159 次迭代中的资源申请量为: -39.127532672197276
# agent 2 在 159 次迭代中的资源申请量为: -39.127532672197276
# agent 3 在 159 次迭代中的资源申请量为: -39.047046517816256
# agent 4 在 159 次迭代中的资源申请量为: 330.91736818299535
# agent 5 在 159 次迭代中的资源申请量为: 364.53882772858515
# agent 6 在 159 次迭代中的资源申请量为: -38.708031415794295
# agent 7 在 159 次迭代中的资源申请量为: 119.29104995864004
# agent 8 在 159 次迭代中的资源申请量为: -36.12806289083069
# agent 9 在 159 次迭代中的资源申请量为: -29.66048163880374
# agent 10 在 159 次迭代中的资源申请量为: 379.90354031024503
# agent 11 在 159 次迭代中的资源申请量为: 1658.35753433649
# agent 12 在 159 次迭代中的资源申请量为: -37.35772073567185
# agent 13 在 159 次迭代中的资源申请量为: -38.38834379919456
# agent 14 在 159 次迭代中的资源申请量为: 129.8983094794331
# agent 15 在 159 次迭代中的资源申请量为: -38.90234394324965
# agent 16 在 159 次迭代中的资源申请量为: 117.48613782953001
# agent 17 在 159 次迭代中的资源申请量为: -39.04016368007309
# agent 18 在 159 次迭代中的资源申请量为: -43.38556862616535
# agent 19 在 159 次迭代中的资源申请量为: 135.94400350812734
# agent 20 在 159 次迭代中的资源申请量为: 1532.593034817905
# agent 21 在 159 次迭代中的资源申请量为: 1031.885036778869
# agent 22 在 159 次迭代中的资源申请量为: -9.39118089579209
# agent 23 在 159 次迭代中的资源申请量为: 7.381744767466152
# agent 24 在 159 次迭代中的资源申请量为: 562.1500286245238
# agent 25 在 159 次迭代中的资源申请量为: 617.8605521461311
# agent 26 在 159 次迭代中的资源申请量为: 31.70673218443881
# agent 27 在 159 次迭代中的资源申请量为: 610.8431529977903
# agent 28 在 159 次迭代中的资源申请量为: 533.0676106802987
# agent 29 在 159 次迭代中的资源申请量为: 497.05158999782043
# agent 30 在 159 次迭代中的资源申请量为: 91.75829773456351
# agent 31 在 159 次迭代中的资源申请量为: -21.92457293757467
# agent 32 在 159 次迭代中的资源申请量为: -19.313837638261568
# agent 33 在 159 次迭代中的资源申请量为: -233.43062449051857
# agent 34 在 159 次迭代中的资源申请量为: 261.6015323704624
# agent 35 在 159 次迭代中的资源申请量为: 307.3718581609925
# agent 36 在 159 次迭代中的资源申请量为: 687.7572195478239
# agent 37 在 159 次迭代中的资源申请量为: 443.52140264047523
# agent 38 在 159 次迭代中的资源申请量为: -4.097928677207928
# agent 39 在 159 次迭代中的资源申请量为: 1501.1180244912434
# agent 40 在 159 次迭代中的资源申请量为: 698.4498537474498
# agent 41 在 159 次迭代中的资源申请量为: -158.1716974407461
# agent 42 在 159 次迭代中的资源申请量为: 325.72759783106073
# agent 43 在 159 次迭代中的资源申请量为: 762.2119633655433
# agent 44 在 159 次迭代中的资源申请量为: 871.2924125891325
# agent 45 在 159 次迭代中的资源申请量为: 1068.3462214498327
# agent 46 在 159 次迭代中的资源申请量为: 52.69685224070643
# agent 47 在 159 次迭代中的资源申请量为: 880.2542166432407
# agent 48 在 159 次迭代中的资源申请量为: 895.2088502458104
# agent 49 在 159 次迭代中的资源申请量为: -14107.271424411867
# agent 50 在 159 次迭代中的资源申请量为: 1082.203210050079
# agent 51 在 159 次迭代中的资源申请量为: 1094.2935240239303
# agent 52 在 159 次迭代中的资源申请量为: 1094.2935240239303
# agent 53 在 159 次迭代中的资源申请量为: 118.53255168062546
# agent 54 在 159 次迭代中的资源申请量为: 74.95872791776009
# 资源申请量总和为: 5999.999999999994
# ****************************************************************************
# 成本总和为: 5527022.285197658
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 179 次迭代中的结果：
# agent 1 在 179 次迭代中的资源申请量为: -37.60294543703334
# agent 2 在 179 次迭代中的资源申请量为: -37.60294543703334
# agent 3 在 179 次迭代中的资源申请量为: -37.55424116989295
# agent 4 在 179 次迭代中的资源申请量为: 344.3378921828587
# agent 5 在 179 次迭代中的资源申请量为: 374.1669530649732
# agent 6 在 179 次迭代中的资源申请量为: -37.2377152427286
# agent 7 在 179 次迭代中的资源申请量为: 127.24068498729761
# agent 8 在 179 次迭代中的资源申请量为: -34.866551768451714
# agent 9 在 179 次迭代中的资源申请量为: -29.001574405799175
# agent 10 在 179 次迭代中的资源申请量为: 388.523919854676
# agent 11 在 179 次迭代中的资源申请量为: 1695.8687135709426
# agent 12 在 179 次迭代中的资源申请量为: -35.959270683998994
# agent 13 在 179 次迭代中的资源申请量为: -36.937899995412494
# agent 14 在 179 次迭代中的资源申请量为: 137.1299764641614
# agent 15 在 179 次迭代中的资源申请量为: -37.41152565176165
# agent 16 在 179 次迭代中的资源申请量为: 125.61287120162335
# agent 17 在 179 次迭代中的资源申请量为: -37.54638269763868
# agent 18 在 179 次迭代中的资源申请量为: -41.58271011961212
# agent 19 在 179 次迭代中的资源申请量为: 141.91551399184374
# agent 20 在 179 次迭代中的资源申请量为: 1591.442027375483
# agent 21 在 179 次迭代中的资源申请量为: 1117.217868633163
# agent 22 在 179 次迭代中的资源申请量为: 6.034509250104026
# agent 23 在 179 次迭代中的资源申请量为: 21.9866590457498
# agent 24 在 179 次迭代中的资源申请量为: 602.6632568409615
# agent 25 在 179 次迭代中的资源申请量为: 655.7250512733848
# agent 26 在 179 次迭代中的资源申请量为: 45.130379229685374
# agent 27 在 179 次迭代中的资源申请量为: 618.0536120503962
# agent 28 在 179 次迭代中的资源申请量为: 546.5125524567875
# agent 29 在 179 次迭代中的资源申请量为: 493.8223745067632
# agent 30 在 179 次迭代中的资源申请量为: 90.86689270423238
# agent 31 在 179 次迭代中的资源申请量为: -22.017823411050447
# agent 32 在 179 次迭代中的资源申请量为: -19.661836197325087
# agent 33 在 179 次迭代中的资源申请量为: -235.8955731879135
# agent 34 在 179 次迭代中的资源申请量为: 255.98972414926078
# agent 35 在 179 次迭代中的资源申请量为: 297.88606775523454
# agent 36 在 179 次迭代中的资源申请量为: 667.7552292237904
# agent 37 在 179 次迭代中的资源申请量为: 423.85442799007876
# agent 38 在 179 次迭代中的资源申请量为: -4.107955777316224
# agent 39 在 179 次迭代中的资源申请量为: 1612.7448214918672
# agent 40 在 179 次迭代中的资源申请量为: 690.4722516258539
# agent 41 在 179 次迭代中的资源申请量为: -160.87426257385755
# agent 42 在 179 次迭代中的资源申请量为: 315.4321611609658
# agent 43 在 179 次迭代中的资源申请量为: 741.5990063089495
# agent 44 在 179 次迭代中的资源申请量为: 833.4729437073797
# agent 45 在 179 次迭代中的资源申请量为: 1012.7662086346246
# agent 46 在 179 次迭代中的资源申请量为: 26.845910196381155
# agent 47 在 179 次迭代中的资源申请量为: 816.7109662940157
# agent 48 在 179 次迭代中的资源申请量为: 835.5843508856693
# agent 49 在 179 次迭代中的资源申请量为: -14133.932147043597
# agent 50 在 179 次迭代中的资源申请量为: 1017.395035089414
# agent 51 在 179 次迭代中的资源申请量为: 1056.396092314841
# agent 52 在 179 次迭代中的资源申请量为: 1056.396092314841
# agent 53 在 179 次迭代中的资源申请量为: 126.58473506788235
# agent 54 在 179 次迭代中的资源申请量为: 67.65562790427362
# 资源申请量总和为: 5999.999999999991
# ****************************************************************************
# 成本总和为: 5539056.952117522
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: -36.25832239191612
# agent 2 在 199 次迭代中的资源申请量为: -36.25832239191612
# agent 3 在 199 次迭代中的资源申请量为: -36.22677848658106
# agent 4 在 199 次迭代中的资源申请量为: 356.23180166321583
# agent 5 在 199 次迭代中的资源申请量为: 382.6640497897768
# agent 6 在 199 次迭代中的资源申请量为: -35.936876096894174
# agent 7 在 199 次迭代中的资源申请量为: 134.25958932863696
# agent 8 在 199 次迭代中的资源申请量为: -33.760450631455825
# agent 9 在 199 次迭代中的资源申请量为: -28.42112731800744
# agent 10 在 199 次迭代中的资源申请量为: 396.0023140780583
# agent 11 在 199 次迭代中的资源申请量为: 1728.7289475405248
# agent 12 在 199 次迭代中的资源申请量为: -34.73908478827165
# agent 13 在 199 次迭代中的资源申请量为: -35.658097186172476
# agent 14 在 199 次迭代中的资源申请量为: 143.43328849266203
# agent 15 在 199 次迭代中的资源申请量为: -36.1010155353399
# agent 16 在 199 次迭代中的资源申请量为: 132.78751079097395
# agent 17 在 199 次迭代中的资源申请量为: -36.225542851921496
# agent 18 在 199 次迭代中的资源申请量为: -39.9884369300349
# agent 19 在 199 次迭代中的资源申请量为: 147.1880966802016
# agent 20 在 199 次迭代中的资源申请量为: 1643.7401028144143
# agent 21 在 199 次迭代中的资源申请量为: 1197.7876431058512
# agent 22 在 199 次迭代中的资源申请量为: 20.547955802625527
# agent 23 在 199 次迭代中的资源申请量为: 35.5809168591276
# agent 24 在 199 次迭代中的资源申请量为: 640.5551256218764
# agent 25 在 199 次迭代中的资源申请量为: 690.7601079959613
# agent 26 在 199 次迭代中的资源申请量为: 57.479931735789734
# agent 27 在 199 次迭代中的资源申请量为: 624.647255326426
# agent 28 在 199 次迭代中的资源申请量为: 558.5960496323551
# agent 29 在 199 次迭代中的资源申请量为: 491.3061528383935
# agent 30 在 199 次迭代中的资源申请量为: 90.13155062358084
# agent 31 在 199 次迭代中的资源申请量为: -22.08697155533274
# agent 32 在 199 次迭代中的资源申请量为: -19.951384811976766
# agent 33 在 199 次迭代中的资源申请量为: -237.95638217490014
# agent 34 在 199 次迭代中的资源申请量为: 251.24268146043346
# agent 35 在 199 次迭代中的资源申请量为: 289.97377642329195
# agent 36 在 199 次迭代中的资源申请量为: 651.1908719336002
# agent 37 在 199 次迭代中的资源申请量为: 407.38223389748924
# agent 38 在 199 次迭代中的资源申请量为: -4.16552845787626
# agent 39 在 199 次迭代中的资源申请量为: 1711.620586870354
# agent 40 在 199 次迭代中的资源申请量为: 681.3944628202014
# agent 41 在 199 次迭代中的资源申请量为: -164.5996616047802
# agent 42 在 199 次迭代中的资源申请量为: 302.2004338564606
# agent 43 在 199 次迭代中的资源申请量为: 723.0495716319272
# agent 44 在 199 次迭代中的资源申请量为: 802.2111991540296
# agent 45 在 199 次迭代中的资源申请量为: 966.9857748022004
# agent 46 在 199 次迭代中的资源申请量为: 4.836758213939824
# agent 47 在 199 次迭代中的资源申请量为: 764.6569589149506
# agent 48 在 199 次迭代中的资源申请量为: 785.4451991503809
# agent 49 在 199 次迭代中的资源申请量为: -14155.809761582272
# agent 50 在 199 次迭代中的资源申请量为: 955.5012235576008
# agent 51 在 199 次迭代中的资源申请量为: 1014.2666934860897
# agent 52 在 199 次迭代中的资源申请量为: 1014.2666934860897
# agent 53 在 199 次迭代中的资源申请量为: 133.68626563112005
# agent 54 在 199 次迭代中的资源申请量为: 61.80396878503055
# 资源申请量总和为: 5999.999999999997
# ****************************************************************************
# 成本总和为: 5548636.89201487
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 219 次迭代中的结果：
# agent 1 在 219 次迭代中的资源申请量为: -35.05879129798075
# agent 2 在 219 次迭代中的资源申请量为: -35.05879129798075
# agent 3 在 219 次迭代中的资源申请量为: -35.03588735930458
# agent 4 在 219 次迭代中的资源申请量为: 366.7816507296203
# agent 5 在 219 次迭代中的资源申请量为: 390.25071039423403
# agent 6 在 219 次迭代中的资源申请量为: -34.772754274538556
# agent 7 在 219 次迭代中的资源申请量为: 140.53357984001843
# agent 8 在 219 次迭代中的资源申请量为: -32.77363237248046
# agent 9 在 219 次迭代中的资源申请量为: -27.890312312731066
# agent 10 在 219 次迭代中的资源申请量为: 402.6046919100062
# agent 11 在 219 次迭代中的资源申请量为: 1757.832180768385
# agent 12 在 219 次迭代中的资源申请量为: -33.65766710857901
# agent 13 在 219 次迭代中的资源申请量为: -34.51465270337276
# agent 14 在 219 次迭代中的资源申请量为: 149.02257131437088
# agent 15 在 219 次迭代中的资源申请量为: -34.93125887802816
# agent 16 在 219 次迭代中的资源申请量为: 139.19630906726903
# agent 17 在 219 次迭代中的资源申请量为: -35.043417640795425
# agent 18 在 219 次迭代中的资源申请量为: -38.55773678573529
# agent 19 在 219 次迭代中的资源申请量为: 151.98327886383606
# agent 20 在 219 次迭代中的资源申请量为: 1690.9619925652028
# agent 21 在 219 次迭代中的资源申请量为: 1273.4653267471474
# agent 22 在 219 次迭代中的资源申请量为: 34.13845703772766
# agent 23 在 219 次迭代中的资源申请量为: 48.225283618419425
# agent 24 在 219 次迭代中的资源申请量为: 675.8884085128162
# agent 25 在 219 次迭代中的资源申请量为: 723.1850999076838
# agent 26 在 219 次迭代中的资源申请量为: 68.86406831687556
# agent 27 在 219 次迭代中的资源申请量为: 630.7291555979438
# agent 28 在 219 次迭代中的资源申请量为: 569.5690437217216
# agent 29 在 219 次迭代中的资源申请量为: 489.4638324689815
# agent 30 在 219 次迭代中的资源申请量为: 89.55635883827095
# agent 31 在 219 次迭代中的资源申请量为: -22.11394400894302
# agent 32 在 219 次迭代中的资源申请量为: -20.167670257391286
# agent 33 在 219 次迭代中的资源申请量为: -239.62855477444072
# agent 34 在 219 次迭代中的资源申请量为: 247.36480194196244
# agent 35 在 219 次迭代中的资源申请量为: 283.403784875911
# agent 36 在 219 次迭代中的资源申请量为: 637.2731498465417
# agent 37 在 219 次迭代中的资源申请量为: 393.36057124954846
# agent 38 在 219 次迭代中的资源申请量为: -4.253213083039018
# agent 39 在 219 次迭代中的资源申请量为: 1799.0912610549656
# agent 40 在 219 次迭代中的资源申请量为: 672.0260089392248
# agent 41 在 219 次迭代中的资源申请量为: -168.79064062935802
# agent 42 在 219 次迭代中的资源申请量为: 287.69390497181905
# agent 43 在 219 次迭代中的资源申请量为: 706.3931963221909
# agent 44 在 219 次迭代中的资源申请量为: 775.863883560637
# agent 45 在 219 次迭代中的资源申请量为: 928.2389939123757
# agent 46 在 219 次迭代中的资源申请量为: -14.357131448840754
# agent 47 在 219 次迭代中的资源申请量为: 720.6906398545125
# agent 48 在 219 次迭代中的资源申请量为: 742.1535868929099
# agent 49 在 219 次迭代中的资源申请量为: -14174.30118485477
# agent 50 在 219 次迭代中的资源申请量为: 896.75608663314
# agent 51 在 219 次迭代中的资源申请量为: 970.5602127043765
# agent 52 在 219 次迭代中的资源申请量为: 970.5602127043765
# agent 53 在 219 次迭代中的资源申请量为: 140.0259793309728
# agent 54 在 219 次迭代中的资源申请量为: 57.198966072304415
# 资源申请量总和为: 5999.999999999988
# ****************************************************************************
# 成本总和为: 5556630.440435568
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 239 次迭代中的结果：
# agent 1 在 239 次迭代中的资源申请量为: -33.97669874145457
# agent 2 在 239 次迭代中的资源申请量为: -33.97669874145457
# agent 3 在 239 次迭代中的资源申请量为: -33.95768170229773
# agent 4 在 239 次迭代中的资源申请量为: 376.17238568523953
# agent 5 在 239 次迭代中的资源申请量为: 397.1012708617153
# agent 6 在 239 次迭代中的资源申请量为: -33.719489161233845
# agent 7 在 239 次迭代中的资源申请量为: 146.20721266907242
# agent 8 在 239 次迭代中的资源申请量为: -31.879805896741736
# agent 9 在 239 次迭代中的资源申请量为: -27.392851985971138
# agent 10 在 239 次迭代中的资源申请量为: 408.53053003735994
# agent 11 在 239 次迭代中的资源申请量为: 1783.911013883964
# agent 12 在 239 次迭代中的资源申请量为: -32.68498987040686
# agent 13 在 239 次迭代中的资源申请量为: -33.48090945536365
# agent 14 在 239 次迭代中的资源申请量为: 154.05712016171975
# agent 15 在 239 次迭代中的资源申请量为: -33.873172659481185
# agent 16 在 239 次迭代中的资源申请量为: 144.98607471413692
# agent 17 在 239 次迭代中的资源申请量为: -33.97340851360572
# agent 18 在 239 次迭代中的资源申请量为: -37.2579799521957
# agent 19 在 239 次迭代中的资源申请量为: 156.42956416751647
# agent 20 在 239 次迭代中的资源申请量为: 1734.1209879536616
# agent 21 在 239 次迭代中的资源申请量为: 1344.307696740558
# agent 22 在 239 次迭代中的资源申请量为: 46.83005721593139
# agent 23 在 239 次迭代中的资源申请量为: 59.98599484300814
# agent 24 在 239 次迭代中的资源申请量为: 708.7876054081645
# agent 25 在 239 次迭代中的资源申请量为: 753.2132127229617
# agent 26 在 239 次迭代中的资源申请量为: 79.38004032798722
# agent 27 在 239 次迭代中的资源申请量为: 636.3763337768261
# agent 28 在 239 次迭代中的资源申请量为: 579.6163985359245
# agent 29 在 239 次迭代中的资源申请量为: 488.1958074781041
# agent 30 在 239 次迭代中的资源申请量为: 89.12431377959662
# agent 31 在 239 次迭代中的资源申请量为: -22.09669188556555
# agent 32 在 239 次迭代中的资源申请量为: -20.3133167936453
# agent 33 在 239 次迭代中的资源申请量为: -240.96290925375138
# agent 34 在 239 次迭代中的资源申请量为: 244.25851961572147
# agent 35 在 239 次迭代中的资源申请量为: 277.93522006101415
# agent 36 在 239 次迭代中的资源申请量为: 625.4040145466273
# agent 37 在 239 次迭代中的资源申请量为: 381.23714686622236
# agent 38 在 239 次迭代中的资源申请量为: -4.362986741483542
# agent 39 在 239 次迭代中的资源申请量为: 1876.3825018917714
# agent 40 在 239 次迭代中的资源申请量为: 662.8188260577111
# agent 41 在 239 次迭代中的资源申请量为: -173.10580576308143
# agent 42 在 239 次迭代中的资源申请量为: 272.9461741963032
# agent 43 在 239 次迭代中的资源申请量为: 691.424314621026
# agent 44 在 239 次迭代中的资源申请量为: 753.2502289387185
# agent 45 在 239 次迭代中的资源申请量为: 894.6958266585872
# agent 46 在 239 次迭代中的资源申请量为: -31.40504813577281
# agent 47 在 239 次迭代中的资源申请量为: 682.6222918523783
# agent 48 在 239 次迭代中的资源申请量为: 703.9993952694947
# agent 49 在 239 次迭代中的资源申请量为: -14190.312575301472
# agent 50 在 239 次迭代中的资源申请量为: 841.2556964864796
# agent 51 在 239 次迭代中的资源申请量为: 926.9062301840535
# agent 52 在 239 次迭代中的资源申请量为: 926.9062301840535
# agent 53 在 239 次迭代中的资源申请量为: 145.75191004204453
# agent 54 在 239 次迭代中的资源申请量为: 53.6048721193152
# 资源申请量总和为: 5999.999999999997
# ****************************************************************************
# 成本总和为: 5563580.441079045
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 259 次迭代中的结果：
# agent 1 在 259 次迭代中的资源申请量为: -32.99068571305064
# agent 2 在 259 次迭代中的资源申请量为: -32.99068571305064
# agent 3 在 259 次迭代中的资源申请量为: -32.97306560098207
# agent 4 在 259 次迭代中的资源申请量为: 384.5763051727139
# agent 5 在 259 次迭代中的资源申请量为: 403.3498740476924
# agent 6 在 259 次迭代中的资源申请量为: -32.75718550740066
# agent 7 在 259 次迭代中的资源申请量为: 151.39039557594748
# agent 8 在 259 次迭代中的资源申请量为: -31.060191370894703
# agent 9 在 259 次迭代中的资源申请量为: -26.919915155709543
# agent 10 在 259 次迭代中的资源申请量为: 413.9244321505938
# agent 11 在 259 次迭代中的资源申请量为: 1807.5400961319724
# agent 12 在 259 次迭代中的资源申请量为: -31.798929589190084
# agent 13 在 259 次迭代中的资源申请量为: -32.53663739490078
# agent 14 在 259 次迭代中的资源申请量为: 158.65213591533615
# agent 15 在 259 次迭代中的资源申请量为: -32.905544789764605
# agent 16 在 259 次迭代中的资源申请量为: 150.2695446518698
# agent 17 在 259 次迭代中的资源申请量为: -32.99528217048622
# agent 18 在 259 次迭代中的资源申请量为: -36.06564281815017
# agent 19 在 259 次迭代中的资源申请量为: 160.6010352243494
# agent 20 在 259 次迭代中的资源申请量为: 1773.9166923340013
# agent 21 在 259 次迭代中的资源申请量为: 1410.4847890393432
# agent 22 在 259 次迭代中的资源申请量为: 58.66474475327374
# agent 23 在 259 次迭代中的资源申请量为: 70.92856072380292
# agent 24 在 259 次迭代中的资源申请量为: 739.4043572773111
# agent 25 在 259 次迭代中的资源申请量为: 781.0474786314134
# agent 26 在 259 次迭代中的资源申请量为: 89.11365866801266
# agent 27 在 259 次迭代中的资源申请量为: 641.6465293078444
# agent 28 在 259 次迭代中的资源申请量为: 588.8757542884258
# agent 29 在 259 次迭代中的资源申请量为: 487.39093653780805
# agent 30 在 259 次迭代中的资源申请量为: 88.81175629337542
# agent 31 在 259 次迭代中的资源申请量为: -22.040209537218324
# agent 32 在 259 次迭代中的资源申请量为: -20.397969115827742
# agent 33 在 259 次迭代中的资源申请量为: -242.01837767696847
# agent 34 在 259 次迭代中的资源申请量为: 241.7965203639267
# agent 35 在 259 次迭代中的资源申请量为: 273.35344480067977
# agent 36 在 259 次迭代中的资源申请量为: 615.139178077038
# agent 37 在 259 次迭代中的资源申请量为: 370.60593201279744
# agent 38 在 259 次迭代中的资源申请量为: -4.49119626797474
# agent 39 在 259 次迭代中的资源申请量为: 1944.595778054477
# agent 40 在 259 次迭代中的资源申请量为: 654.010721739785
# agent 41 在 259 次迭代中的资源申请量为: -177.345102427756
# agent 42 在 259 次迭代中的资源申请量为: 258.5667338956133
# agent 43 在 259 次迭代中的资源申请量为: 677.9410925810629
# agent 44 在 259 次迭代中的资源申请量为: 733.5290070058153
# agent 45 在 259 次迭代中的资源申请量为: 865.1281380092306
# agent 46 在 259 次迭代中的资源申请量为: -46.75363179561303
# agent 47 在 259 次迭代中的资源申请量为: 649.0163015008925
# agent 48 在 259 次迭代中的资源申请量为: 669.8496658642001
# agent 49 在 259 次迭代中的资源申请量为: -14204.442125462268
# agent 50 在 259 次迭代中的资源申请量为: 788.9996155745952
# agent 51 在 259 次迭代中的资源申请量为: 884.2881408369013
# agent 52 在 259 次迭代中的资源申请量为: 884.2881408369013
# agent 53 在 259 次迭代中的资源申请量为: 150.9771096996896
# agent 54 在 259 次迭代中的资源申请量为: 50.80778052850363
# 资源申请量总和为: 5999.999999999985
# ****************************************************************************
# 成本总和为: 5569823.061922997
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 279 次迭代中的结果：
# agent 1 在 279 次迭代中的资源申请量为: -32.084486200818446
# agent 2 在 279 次迭代中的资源申请量为: -32.084486200818446
# agent 3 在 279 次迭代中的资源申请量为: -32.067086914556285
# agent 4 在 279 次迭代中的资源申请量为: 392.1455561459464
# agent 5 在 279 次迭代中的资源申请量为: 409.0982871449725
# agent 6 在 279 次迭代中的资源申请量为: -31.87073851251315
# agent 7 在 279 次迭代中的资源申请量为: 156.16577792658362
# agent 8 在 279 次迭代中的资源申请量为: -30.30143443262517
# agent 9 在 279 次迭代中的资源申请量为: -26.46688832510687
# agent 10 在 279 次迭代中的资源申请量为: 418.8897657454344
# agent 11 在 279 次迭代中的资源申请量为: 1829.1590454809832
# agent 12 在 279 次迭代中的资源申请量为: -30.983399429159377
# agent 13 在 279 次迭代中的资源申请量为: -31.666658903763114
# agent 14 在 279 次迭代中的资源申请量为: 162.8900941529162
# agent 15 在 279 次迭代中的资源申请量为: -32.012908419540366
# agent 16 在 279 次迭代中的资源申请量为: 155.132118696494
# agent 17 在 279 次迭代中的资源申请量为: -32.093801328827766
# agent 18 在 279 次迭代中的资源申请量为: -34.96369068057422
# agent 19 在 279 次迭代中的资源申请量为: 164.54070012002026
# agent 20 在 279 次迭代中的资源申请量为: 1810.8402486600512
# agent 21 在 279 次迭代中的资源申请量为: 1472.229733623598
# agent 22 在 279 次迭代中的资源申请量为: 69.69289923082947
# agent 23 在 279 次迭代中的资源申请量为: 81.11520918085706
# agent 24 在 279 次迭代中的资源申请量为: 767.8985377390959
# agent 25 在 279 次迭代中的资源申请量为: 806.877443616992
# agent 26 在 279 次迭代中的资源申请量为: 98.14015516059503
# agent 27 在 279 次迭代中的资源申请量为: 646.5838744909407
# agent 28 在 279 次迭代中的资源申请量为: 597.4511847196434
# agent 29 在 279 次迭代中的资源申请量为: 486.9474543214914
# agent 30 在 279 次迭代中的资源申请量为: 88.59517947269927
# agent 31 在 279 次迭代中的资源申请量为: -21.951820892223672
# agent 32 在 279 次迭代中的资源申请量为: -20.43301048095384
# agent 33 在 279 次迭代中的资源申请量为: -242.84993066102365
# agent 34 在 279 次迭代中的资源申请量为: 239.8550796177843
# agent 35 在 279 次迭代中的资源申请量为: 269.4806249440922
# agent 36 在 279 次迭代中的资源申请量为: 606.1501176708948
# agent 37 在 279 次迭代中的资源申请量为: 361.1683585081558
# agent 38 在 279 次迭代中的资源申请量为: -4.63612087718861
# agent 39 在 279 次迭代中的资源申请量为: 2004.7144435023959
# agent 40 在 279 次迭代中的资源申请量为: 645.7122081638734
# agent 41 在 279 次迭代中的资源申请量为: -181.39879137127602
# agent 42 在 279 次迭代中的资源申请量为: 244.88874574817154
# agent 43 在 279 次迭代中的资源申请量为: 665.7595885905482
# agent 44 在 279 次迭代中的资源申请量为: 716.098711626981
# agent 45 在 279 次迭代中的资源申请量为: 838.6972224181857
# agent 46 在 279 次迭代中的资源申请量为: -60.70894239996569
# agent 47 在 279 次迭代中的资源申请量为: 618.9118269936091
# agent 48 在 279 次迭代中的资源申请量为: 638.9352686804122
# agent 49 在 279 次迭代中的资源申请量为: -14217.092579092114
# agent 50 在 279 次迭代中的资源申请量为: 739.9230300896884
# agent 51 在 279 次迭代中的资源申请量为: 843.2802273604278
# agent 52 在 279 次迭代中的资源申请量为: 843.2802273604278
# agent 53 在 279 次迭代中的资源申请量为: 155.78678960443474
# agent 54 在 279 次迭代中的资源申请量为: 48.63103861281303
# 资源申请量总和为: 5999.999999999995
# ****************************************************************************
# 成本总和为: 5575564.49481426
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 299 次迭代中的结果：
# agent 1 在 299 次迭代中的资源申请量为: -31.245773316227506
# agent 2 在 299 次迭代中的资源申请量为: -31.245773316227506
# agent 3 在 299 次迭代中的资源申请量为: -31.228148012720485
# agent 4 在 299 次迭代中的资源申请量为: 399.00971656541503
# agent 5 在 299 次迭代中的资源申请量为: 414.42336161283083
# agent 6 在 299 次迭代中的资源申请量为: -31.048723395321012
# agent 7 在 299 次迭代中的资源申请量为: 160.59538773331994
# agent 8 在 299 次迭代中的资源申请量为: -29.59398926530026
# agent 9 在 299 次迭代中的资源申请量为: -26.031453343229156
# agent 10 在 299 次迭代中的资源申请量为: 423.5002778822001
# agent 11 在 299 次迭代中的资源申请量为: 1849.1000674505456
# agent 12 在 299 次迭代中的资源申请量为: -30.226723066317458
# agent 13 在 299 次迭代中的资源申请量为: -30.859610600190386
# agent 14 在 299 次迭代中的资源申请量为: 166.8300893948978
# agent 15 在 299 次迭代中的资源申请量为: -31.183911063729894
# agent 16 在 299 次迭代中的资源申请量为: 159.6382200377514
# agent 17 在 299 次迭代中的资源申请量为: -31.257504430777853
# agent 18 在 299 次迭代中的资源申请量为: -33.93962218436285
# agent 19 在 299 次迭代中的资源申请量为: 168.27423932910904
# agent 20 在 299 次迭代中的资源申请量为: 1845.2461664410837
# agent 21 在 299 次迭代中的资源申请量为: 1529.8058405989245
# agent 22 在 299 次迭代中的资源申请量为: 79.96778878926544
# agent 23 在 299 次迭代中的资源申请量为: 90.60394736610654
# agent 24 在 299 次迭代中的资源申请量为: 794.4279747884565
# agent 25 在 299 次迭代中的资源申请量为: 830.8772632276562
# agent 26 在 299 次迭代中的资源申请量为: 106.52538712793648
# agent 27 在 299 次迭代中的资源申请量为: 651.222775450798
# agent 28 在 299 次迭代中的资源申请量为: 605.423001907826
# agent 29 在 299 次迭代中的资源申请量为: 486.77996339297545
# agent 30 在 299 次迭代中的资源申请量为: 88.45396504956292
# agent 31 在 299 次迭代中的资源申请量为: -21.83892945009294
# agent 32 在 299 次迭代中的资源申请量为: -20.429169308159906
# agent 33 在 299 次迭代中的资源申请量为: -243.50427649161088
# agent 34 在 299 次迭代中的资源申请量为: 238.32696329389734
# agent 35 在 299 次迭代中的资源申请量为: 266.1749367365559
# agent 36 在 299 次迭代中的资源申请量为: 598.1930797383778
# agent 37 在 299 次迭代中的资源申请量为: 352.7034159965662
# agent 38 在 299 次迭代中的资源申请量为: -4.7968005026542855
# agent 39 在 299 次迭代中的资源申请量为: 2057.61372820528
# agent 40 在 299 次迭代中的资源申请量为: 637.9594982081126
# agent 41 在 299 次迭代中的资源申请量为: -185.21347661539315
# agent 42 在 299 次迭代中的资源申请量为: 232.07087723304383
# agent 43 在 299 次迭代中的资源申请量为: 654.7176638242219
# agent 44 在 299 次迭代中的资源申请量为: 700.5244267668712
# agent 45 在 299 次迭代中的资源申请量为: 814.8181502213234
# agent 46 在 299 次迭代中的资源申请量为: -73.48714411841046
# agent 47 在 299 次迭代中的资源申请量为: 591.6502835490671
# agent 48 在 299 次迭代中的资源申请量为: 610.7192405386185
# agent 49 在 299 次迭代中的资源申请量为: -14228.541379502787
# agent 50 在 299 次迭代中的资源申请量为: 693.9199818217517
# agent 51 在 299 次迭代中的资源申请量为: 804.1972539440804
# agent 52 在 299 次迭代中的资源申请量为: 804.1972539440804
# agent 53 在 299 次迭代中的资源申请量为: 160.24495098812417
# agent 54 在 299 次迭代中的资源申请量为: 46.935268826870285
# 资源申请量总和为: 5999.999999999993
# ****************************************************************************
# 成本总和为: 5580929.957954852
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 319 次迭代中的结果：
# agent 1 在 319 次迭代中的资源申请量为: -30.465181482254383
# agent 2 在 319 次迭代中的资源申请量为: -30.465181482254383
# agent 3 在 319 次迭代中的资源申请量为: -30.447262467018177
# agent 4 在 319 次迭代中的资源申请量为: 405.2764357909614
# agent 5 在 319 次迭代中的资源申请量为: 419.3833161962266
# agent 6 在 319 次迭代中的资源申请量为: -30.282464949689203
# agent 7 在 319 次迭代中的资源申请量为: 164.72602880369655
# agent 8 在 319 次迭代中的资源申请量为: -28.930943334118684
# agent 9 在 319 次迭代中的资源申请量为: -25.61248680920565
# agent 10 在 319 次迭代中的资源申请量为: 427.80894605308777
# agent 11 在 319 次迭代中的资源申请量为: 1867.6135107202779
# agent 12 在 319 次迭代中的资源申请量为: -29.520369246923007
# agent 13 在 319 次迭代中的资源申请量为: -30.106938141061367
# agent 14 在 319 次迭代中的资源申请量为: 170.51484859248552
# agent 15 在 319 次迭代中的资源申请量为: -30.410112286333035
# agent 16 在 319 次迭代中的资源申请量为: 163.83662143272383
# agent 17 在 319 次迭代中的资源申请量为: -30.47771622896566
# agent 18 在 319 次迭代中的资源申请量为: -32.984068995818596
# agent 19 在 319 次迭代中的资源申请量为: 171.81792017784662
# agent 20 在 319 次迭代中的资源申请量为: 1877.3998954780648
# agent 21 在 319 次迭代中的资源申请量为: 1583.4858606539515
# agent 22 在 319 次迭代中的资源申请量为: 89.54243121080282
# agent 23 在 319 次迭代中的资源申请量为: 99.44834935546898
# agent 24 在 319 次迭代中的资源申请量为: 819.14309545868
# agent 25 在 319 次迭代中的资源申请量为: 853.2051312440251
# agent 26 在 319 次迭代中的资源申请量为: 114.32709479149777
# agent 27 在 319 次迭代中的资源申请量为: 655.5906365725789
# agent 28 在 319 次迭代中的资源申请量为: 612.8546863372096
# agent 29 在 319 次迭代中的资源申请量为: 486.82004001236993
# agent 30 在 319 次迭代中的资源申请量为: 88.37110910242082
# agent 31 在 319 次迭代中的资源申请量为: -21.708088178916615
# agent 32 在 319 次迭代中的资源申请量为: -20.395632046764632
# agent 33 在 319 次迭代中的资源申请量为: -244.01923521185853
# agent 34 在 319 次迭代中的资源申请量为: 237.12440074000415
# agent 35 在 319 次迭代中的资源申请量为: 263.3255003621872
# agent 36 在 319 次迭代中的资源申请量为: 591.0855805883513
# agent 37 在 319 次迭代中的资源申请量为: 345.04566707045063
# agent 38 在 319 次迭代中的资源申请量为: -4.9724866732379205
# agent 39 在 319 次迭代中的资源申请量为: 2104.0717908513475
# agent 40 在 319 次迭代中的资源申请量为: 630.7469160674897
# agent 41 在 319 次迭代中的资源申请量为: -188.76992923810235
# agent 42 在 319 次迭代中的资源申请量为: 220.1652310296703
# agent 43 在 319 次迭代中的资源申请量为: 644.674692325969
# agent 44 在 319 次迭代中的资源申请量为: 686.4865664192698
# agent 45 在 319 次迭代中的资源申请量为: 793.0728175561254
# agent 46 在 319 次迭代中的资源申请量为: -85.24613409364281
# agent 47 在 319 次迭代中的资源申请量为: 566.7676946422988
# agent 48 在 319 次迭代中的资源申请量为: 584.8146521855783
# agent 49 在 319 次迭代中的资源申请量为: -14238.98479936044
# agent 50 在 319 次迭代中的资源申请量为: 650.8596263457259
# agent 51 在 319 次迭代中的资源申请量为: 767.1895321826545
# agent 52 在 319 次迭代中的资源申请量为: 767.1895321826545
# agent 53 在 319 次迭代中的资源申请量为: 164.3998669700788
# agent 54 在 319 次迭代中的资源申请量为: 45.61300472236647
# 资源申请量总和为: 5999.999999999992
# ****************************************************************************
# 成本总和为: 5585994.743503617
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 339 次迭代中的结果：
# agent 1 在 339 次迭代中的资源申请量为: -29.735532095060368
# agent 2 在 339 次迭代中的资源申请量为: -29.735532095060368
# agent 3 在 339 次迭代中的资源申请量为: -29.71742812382849
# agent 4 在 339 次迭代中的资源申请量为: 411.0336675283531
# agent 5 在 339 次迭代中的资源申请量为: 424.02268229625724
# agent 6 在 339 次迭代中的资源申请量为: -29.56530739853329
# agent 7 在 339 次迭代中的资源申请量为: 168.5934313710736
# agent 8 在 339 次迭代中的资源申请量为: -28.30719140592431
# agent 9 在 339 次迭代中的资源申请量为: -25.209449244451235
# agent 10 在 339 次迭代中的资源申请量为: 431.85437416737165
# agent 11 在 339 次迭代中的资源申请量为: 1884.8889805070487
# agent 12 在 339 次迭代中的资源申请量为: -28.858019420268835
# agent 13 在 339 次迭代中的资源申请量为: -29.40212527934416
# agent 14 在 339 次迭代中的资源申请量为: 173.97576376767634
# agent 15 在 339 次迭代中的资源申请量为: -29.68512041816074
# agent 16 在 339 次迭代中的资源申请量为: 167.76462111521033
# agent 17 在 339 次迭代中的资源申请量为: -29.747788198535943
# ...
# agent 88 在 1969 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1969 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1969 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1969 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1969 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1969 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1969 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1969 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1969 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1969 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1969 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1969 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1969 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1979 次迭代中的结果：
# agent 1 在 1979 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1979 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1979 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1979 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1979 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1979 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1979 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1979 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1979 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1979 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1979 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1979 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1979 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1979 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1979 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1979 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1979 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1979 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1979 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1979 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1979 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1979 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1979 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1979 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1979 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1979 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1979 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1979 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1979 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1979 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1979 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1979 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1979 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1979 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1979 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1979 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1979 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1979 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1979 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1979 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1979 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1979 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1979 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1979 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1979 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1979 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1979 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1979 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1979 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1979 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1979 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1979 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1979 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1979 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1979 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1979 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1979 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1979 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1979 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1979 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1979 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1979 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1979 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1979 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1979 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1979 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1979 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1979 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1979 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1979 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1979 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1979 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1979 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1979 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1979 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1979 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1979 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1979 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1979 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1979 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1979 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1979 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1979 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1979 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1979 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1979 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1979 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1979 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1979 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1979 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1979 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1979 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1979 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1979 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1979 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1979 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1979 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1989 次迭代中的结果：
# agent 1 在 1989 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1989 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1989 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1989 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1989 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1989 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1989 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1989 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1989 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1989 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1989 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1989 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1989 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1989 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1989 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1989 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1989 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1989 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1989 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1989 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1989 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1989 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1989 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1989 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1989 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1989 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1989 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1989 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1989 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1989 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1989 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1989 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1989 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1989 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1989 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1989 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1989 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1989 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1989 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1989 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1989 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1989 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1989 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1989 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1989 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1989 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1989 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1989 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1989 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1989 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1989 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1989 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1989 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1989 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1989 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1989 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1989 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1989 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1989 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1989 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1989 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1989 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1989 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1989 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1989 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1989 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1989 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1989 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1989 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1989 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1989 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1989 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1989 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1989 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1989 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1989 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1989 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1989 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1989 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1989 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1989 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1989 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1989 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1989 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1989 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1989 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1989 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1989 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1989 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1989 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1989 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1989 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1989 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1989 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1989 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1989 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1989 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1999 次迭代中的结果：
# agent 1 在 1999 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1999 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1999 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1999 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1999 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1999 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1999 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1999 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1999 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1999 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1999 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1999 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1999 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1999 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1999 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1999 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1999 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1999 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1999 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1999 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1999 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1999 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1999 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1999 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1999 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1999 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1999 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1999 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1999 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1999 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1999 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1999 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1999 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1999 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1999 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1999 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1999 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1999 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1999 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1999 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1999 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1999 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1999 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1999 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1999 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1999 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1999 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1999 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1999 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1999 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1999 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1999 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1999 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1999 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1999 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1999 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1999 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1999 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1999 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1999 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1999 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1999 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1999 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1999 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1999 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1999 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1999 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1999 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1999 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1999 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1999 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1999 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1999 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1999 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1999 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1999 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1999 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1999 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1999 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1999 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1999 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1999 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1999 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1999 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1999 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1999 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1999 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1999 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1999 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1999 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1999 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1999 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1999 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1999 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1999 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1999 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1999 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 2025-01-21 17:21:01.305

# %%
np.savetxt('../data/01-agent_resource_quantity_large_value_deterministic_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/01-sum_cost_large_value_deterministic_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/01-sum_resource_large_value_deterministic_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
np.savetxt('../data/01-agent_gradient_large_value_deterministic_bias.txt',agent_gradient,fmt='%0.8f')#用户迭代梯度

# %%
agent_gradient[0][1999]
# Out:
# np.float64(23.83893433214638)

# %%
agent_gradient[10][1999]
# Out:
# np.float64(23.83853304919703)
