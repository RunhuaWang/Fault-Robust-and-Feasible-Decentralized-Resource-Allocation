# %% [raw]
# 基于初始化的权重梯度下降无中心资源分配算法+部分用户的梯度计算有误差（设备损坏导致的计算误差）

# %% [raw]
# 无界的噪声 设计噪声递增

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(54,2000), dtype=np.float64) #100个agent的资源量 定义成一个矩阵
sum_resource=np.zeros(shape=(1,2000), dtype=np.float64)#存放每一次迭代后所有用户资源量的总和
sum_cost=np.zeros(shape=(1,2000), dtype=np.float64)#存放每一次迭代后所有用户成本的总和
iteration_update = 1 #迭代步长 
A=np.loadtxt("Adjacency_Matrix_generator_zero.txt") #网络拓扑的邻接矩阵 对角元素要为0
D=np.zeros(shape=(54,54))# 网络的度矩阵
L=np.zeros(shape=(54,54))# 网络的拉普拉斯矩阵 L=D-A
W=np.zeros(shape=(54,54)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
iteration=[]#绘图横坐标
generator_a_values= np.loadtxt("generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("generator_b_values.txt")#每个agent的成本函数中的超参数a
generator_c_values= np.loadtxt("generator_c_values.txt")#每个agent的成本函数中的超参数a
agent_gradient=np.zeros(shape=(54,2000), dtype=np.float64) 
bias=0

# %%
#根据邻接矩阵生成网络对应的度矩阵
for i in range(0,54):
    d=0
    for j in range(0,54):
        if A[i][j]==1:
            d=d+1
    D[i][i]=d

#根据邻接矩阵和度矩阵计算拉普拉斯矩阵
L=D-A

#选择用拉普拉斯矩阵作为聚合矩阵
W=L
    
#资源量的初始化 需要给定可行的初始化 即满足平均资源约束
for i in range (0,54):
    agent_resource_quantity[i][0]=6000/54
    
#总资源量 初始化
sum=0
for i in range (0,54):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

iteration.append(0)

#初始梯度计算 随机选择一个用户作为biased 用户
for i in range (0,54):
    if i==48:
        agent_gradient[i][0]=2*generator_c_values[i]*agent_resource_quantity[i][0]+generator_b_values[i]+bias
    else:
        agent_gradient[i][0]=2*generator_c_values[i]*agent_resource_quantity[i][0]+generator_b_values[i]
        

#用户总成本初始化
sum=0
for i in range(0,54):
    sum=sum+(generator_c_values[i]*(agent_resource_quantity[i][0])*(agent_resource_quantity[i][0])+generator_b_values[i]*agent_resource_quantity[i][0]+generator_a_values[i])
sum_cost[0][0]=sum

# %%
#基于初始化的权重梯度下降无中心资源分配算法
def IWDGD_unbounded_bias(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias):
    
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************IWDGD算法+计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,54):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,2000):#迭代次数
        iteration.append(k)
 
        #所有用户资源申请量基于可行初始化权重梯度下降的迭代  假设部分用户因为设备损坏 导致梯度的计算有误差     
        for i in range (0,54):
            weight_gradient_sum = np.float64(0)
            for j in range (0,54):        
                weight_gradient_sum=weight_gradient_sum+W[i][j]*agent_gradient[j][k-1]
            #weight_gradient_sum = np.round(weight_gradient_sum, decimals=3)
            agent_resource_quantity[i][k]=agent_resource_quantity[i][k-1]-iteration_update*weight_gradient_sum
                #agent_resource_quantity[i][k] = np.round(agent_resource_quantity[i][k], decimals=3)
        
        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,54):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,54):
            sum2=sum2+(generator_c_values[i]*(agent_resource_quantity[i][k])*(agent_resource_quantity[i][k])+generator_b_values[i]*agent_resource_quantity[i][k]+generator_a_values[i])
        sum_cost[0][k]=sum2

        #设计递增的噪声
        bias=k
        #计算当前迭代的用户梯度
        for i in range (0,54): 
            if i==48:
                agent_gradient[i][k]=2*generator_c_values[i]*agent_resource_quantity[i][k]+generator_b_values[i]+bias
            else:
                agent_gradient[i][k]=2*generator_c_values[i]*agent_resource_quantity[i][k]+generator_b_values[i]
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%20==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,54):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=1/(pow(k+1,0.5)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
IWDGD_unbounded_bias(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias)
# Out:
# ****************************IWDGD算法+计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 111.11111111111111
# agent 2 的初始资源申请量为: 111.11111111111111
# agent 3 的初始资源申请量为: 111.11111111111111
# agent 4 的初始资源申请量为: 111.11111111111111
# agent 5 的初始资源申请量为: 111.11111111111111
# agent 6 的初始资源申请量为: 111.11111111111111
# agent 7 的初始资源申请量为: 111.11111111111111
# agent 8 的初始资源申请量为: 111.11111111111111
# agent 9 的初始资源申请量为: 111.11111111111111
# agent 10 的初始资源申请量为: 111.11111111111111
# agent 11 的初始资源申请量为: 111.11111111111111
# agent 12 的初始资源申请量为: 111.11111111111111
# agent 13 的初始资源申请量为: 111.11111111111111
# agent 14 的初始资源申请量为: 111.11111111111111
# agent 15 的初始资源申请量为: 111.11111111111111
# agent 16 的初始资源申请量为: 111.11111111111111
# agent 17 的初始资源申请量为: 111.11111111111111
# agent 18 的初始资源申请量为: 111.11111111111111
# agent 19 的初始资源申请量为: 111.11111111111111
# agent 20 的初始资源申请量为: 111.11111111111111
# agent 21 的初始资源申请量为: 111.11111111111111
# agent 22 的初始资源申请量为: 111.11111111111111
# agent 23 的初始资源申请量为: 111.11111111111111
# agent 24 的初始资源申请量为: 111.11111111111111
# agent 25 的初始资源申请量为: 111.11111111111111
# agent 26 的初始资源申请量为: 111.11111111111111
# agent 27 的初始资源申请量为: 111.11111111111111
# agent 28 的初始资源申请量为: 111.11111111111111
# agent 29 的初始资源申请量为: 111.11111111111111
# agent 30 的初始资源申请量为: 111.11111111111111
# agent 31 的初始资源申请量为: 111.11111111111111
# agent 32 的初始资源申请量为: 111.11111111111111
# agent 33 的初始资源申请量为: 111.11111111111111
# agent 34 的初始资源申请量为: 111.11111111111111
# agent 35 的初始资源申请量为: 111.11111111111111
# agent 36 的初始资源申请量为: 111.11111111111111
# agent 37 的初始资源申请量为: 111.11111111111111
# agent 38 的初始资源申请量为: 111.11111111111111
# agent 39 的初始资源申请量为: 111.11111111111111
# agent 40 的初始资源申请量为: 111.11111111111111
# agent 41 的初始资源申请量为: 111.11111111111111
# agent 42 的初始资源申请量为: 111.11111111111111
# agent 43 的初始资源申请量为: 111.11111111111111
# agent 44 的初始资源申请量为: 111.11111111111111
# agent 45 的初始资源申请量为: 111.11111111111111
# agent 46 的初始资源申请量为: 111.11111111111111
# agent 47 的初始资源申请量为: 111.11111111111111
# agent 48 的初始资源申请量为: 111.11111111111111
# agent 49 的初始资源申请量为: 111.11111111111111
# agent 50 的初始资源申请量为: 111.11111111111111
# agent 51 的初始资源申请量为: 111.11111111111111
# agent 52 的初始资源申请量为: 111.11111111111111
# agent 53 的初始资源申请量为: 111.11111111111111
# agent 54 的初始资源申请量为: 111.11111111111111
# *************************
# 初始资源申请量总和为: 6000.000000000006
# *************************
# 初始成本总和为: 139226.02283950621
# *************************
# 迭代步长为: 1
# *****************************************************************************
# 19 次迭代中的结果：
# agent 1 在 19 次迭代中的资源申请量为: -54.16843944811558
# agent 2 在 19 次迭代中的资源申请量为: -54.16843944811558
# agent 3 在 19 次迭代中的资源申请量为: -57.524429239313335
# agent 4 在 19 次迭代中的资源申请量为: 188.98339595941513
# agent 5 在 19 次迭代中的资源申请量为: 268.5438140580182
# agent 6 在 19 次迭代中的资源申请量为: -53.19914534403577
# agent 7 在 19 次迭代中的资源申请量为: 46.89881238902453
# agent 8 在 19 次迭代中的资源申请量为: -43.19593393203587
# agent 9 在 19 次迭代中的资源申请量为: -33.093544960523424
# agent 10 在 19 次迭代中的资源申请量为: 338.4754982400077
# agent 11 在 19 次迭代中的资源申请量为: 1053.7806865636912
# agent 12 在 19 次迭代中的资源申请量为: -44.38818467424848
# agent 13 在 19 次迭代中的资源申请量为: -51.11814295288066
# agent 14 在 19 次迭代中的资源申请量为: 113.09554763771854
# agent 15 在 19 次迭代中的资源申请量为: -62.417188434690615
# agent 16 在 19 次迭代中的资源申请量为: 32.87980168502749
# agent 17 在 19 次迭代中的资源申请量为: -55.67995770601249
# agent 18 在 19 次迭代中的资源申请量为: -67.76090244105012
# agent 19 在 19 次迭代中的资源申请量为: 30.655394625994585
# agent 20 在 19 次迭代中的资源申请量为: 598.1303380031192
# agent 21 在 19 次迭代中的资源申请量为: 332.53366839016576
# agent 22 在 19 次迭代中的资源申请量为: -50.96593763524759
# agent 23 在 19 次迭代中的资源申请量为: -71.27802597012291
# agent 24 在 19 次迭代中的资源申请量为: 271.8470641704962
# agent 25 在 19 次迭代中的资源申请量为: 226.2310630561575
# agent 26 在 19 次迭代中的资源申请量为: -73.79119686269318
# agent 27 在 19 次迭代中的资源申请量为: 470.8663643898379
# agent 28 在 19 次迭代中的资源申请量为: 308.04405811933805
# agent 29 在 19 次迭代中的资源申请量为: 350.2299601789205
# agent 30 在 19 次迭代中的资源申请量为: 77.92369653023015
# agent 31 在 19 次迭代中的资源申请量为: -20.18629928995822
# agent 32 在 19 次迭代中的资源申请量为: -15.028745395655335
# agent 33 在 19 次迭代中的资源申请量为: -269.58052374818004
# agent 34 在 19 次迭代中的资源申请量为: 189.57177716642238
# agent 35 在 19 次迭代中的资源申请量为: 153.53984460285244
# agent 36 在 19 次迭代中的资源申请量为: 325.30371920593643
# agent 37 在 19 次迭代中的资源申请量为: 85.88715977534949
# agent 38 在 19 次迭代中的资源申请量为: -63.14886697174067
# agent 39 在 19 次迭代中的资源申请量为: 264.7279910748433
# agent 40 在 19 次迭代中的资源申请量为: 337.18875328291784
# agent 41 在 19 次迭代中的资源申请量为: -231.96251778317918
# agent 42 在 19 次迭代中的资源申请量为: 81.27160202371695
# agent 43 在 19 次迭代中的资源申请量为: 308.72974728842826
# agent 44 在 19 次迭代中的资源申请量为: 251.0118961426453
# agent 45 在 19 次迭代中的资源申请量为: 470.1102700513841
# agent 46 在 19 次迭代中的资源申请量为: -242.2302148766
# agent 47 在 19 次迭代中的资源申请量为: 220.911237706097
# agent 48 在 19 次迭代中的资源申请量为: 300.9319996534673
# agent 49 在 19 次迭代中的资源申请量为: -408.35319299712626
# agent 50 在 19 次迭代中的资源申请量为: 50.03219191436284
# agent 51 在 19 次迭代中的资源申请量为: 170.41920701182949
# agent 52 在 19 次迭代中的资源申请量为: 170.41920701182949
# agent 53 在 19 次迭代中的资源申请量为: 40.1859848109176
# agent 54 在 19 次迭代中的资源申请量为: -106.12192260863816
# 资源申请量总和为: 5999.999999999999
# ****************************************************************************
# 成本总和为: 77078.58502396877
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 39 次迭代中的结果：
# agent 1 在 39 次迭代中的资源申请量为: -57.93304358128121
# agent 2 在 39 次迭代中的资源申请量为: -57.93304358128121
# agent 3 在 39 次迭代中的资源申请量为: -57.3083997777959
# agent 4 在 39 次迭代中的资源申请量为: 208.76761103932645
# agent 5 在 39 次迭代中的资源申请量为: 244.57665096296256
# agent 6 在 39 次迭代中的资源申请量为: -57.38476433071415
# agent 7 在 39 次迭代中的资源申请量为: 19.241991237701754
# agent 8 在 39 次迭代中的资源申请量为: -51.57158280361209
# agent 9 在 39 次迭代中的资源申请量为: -45.83466374427182
# agent 10 在 39 次迭代中的资源申请量为: 299.19028868561134
# agent 11 在 39 次迭代中的资源申请量为: 1213.0191716975853
# agent 12 在 39 次迭代中的资源申请量为: -51.47810959019719
# agent 13 在 39 次迭代中的资源申请量为: -56.41221541755246
# agent 14 在 39 次迭代中的资源申请量为: 56.308930637941
# agent 15 在 39 次迭代中的资源申请量为: -60.47382303414838
# agent 16 在 39 次迭代中的资源申请量为: 14.98575985205322
# agent 17 在 39 次迭代中的资源申请量为: -58.42584466288184
# agent 18 在 39 次迭代中的资源申请量为: -66.12679175952057
# agent 19 在 39 次迭代中的资源申请量为: 11.11818368210935
# agent 20 在 39 次迭代中的资源申请量为: 781.942378713651
# agent 21 在 39 次迭代中的资源申请量为: 453.4977781919374
# agent 22 在 39 次迭代中的资源申请量为: -91.43767807529406
# agent 23 在 39 次迭代中的资源申请量为: -91.57849296586302
# agent 24 在 39 次迭代中的资源申请量为: 285.38417438479814
# agent 25 在 39 次迭代中的资源申请量为: 286.4745329826135
# agent 26 在 39 次迭代中的资源申请量为: -80.84592427839783
# agent 27 在 39 次迭代中的资源申请量为: 461.6999618154229
# agent 28 在 39 次迭代中的资源申请量为: 366.3659506664662
# agent 29 在 39 次迭代中的资源申请量为: 313.5542591365011
# agent 30 在 39 次迭代中的资源申请量为: 56.17715321929118
# agent 31 在 39 次迭代中的资源申请量为: -40.282001886480444
# agent 32 在 39 次迭代中的资源申请量为: -38.31226740971862
# agent 33 在 39 次迭代中的资源申请量为: -298.610497205718
# agent 34 在 39 次迭代中的资源申请量为: 127.6132027414238
# agent 35 在 39 次迭代中的资源申请量为: 116.4931896823366
# agent 36 在 39 次迭代中的资源申请量为: 351.5442001985894
# agent 37 在 39 次迭代中的资源申请量为: 111.89448553675642
# agent 38 在 39 次迭代中的资源申请量为: -59.55708705272383
# agent 39 在 39 次迭代中的资源申请量为: 366.24651553051854
# agent 40 在 39 次迭代中的资源申请量为: 341.5542724979078
# agent 41 在 39 次迭代中的资源申请量为: -275.25533446205554
# agent 42 在 39 次迭代中的资源申请量为: 0.6811423856016638
# agent 43 在 39 次迭代中的资源申请量为: 363.9582330359528
# agent 44 在 39 次迭代中的资源申请量为: 358.7494157498638
# agent 45 在 39 次迭代中的资源申请量为: 514.0176172228931
# agent 46 在 39 次迭代中的资源申请量为: -234.88968209623135
# agent 47 在 39 次迭代中的资源申请量为: 254.37738026459036
# agent 48 在 39 次迭代中的资源申请量为: 313.9337678717266
# agent 49 在 39 次迭代中的资源申请量为: -761.60631579605
# agent 50 在 39 次迭代中的资源申请量为: 44.28144760494671
# agent 51 在 39 次迭代中的资源申请量为: 195.69871163124208
# agent 52 在 39 次迭代中的资源申请量为: 195.69871163124208
# agent 53 在 39 次迭代中的资源申请量为: 18.85189291702386
# agent 54 在 39 次迭代中的资源申请量为: -154.64139989679893
# 资源申请量总和为: 6000.0
# ****************************************************************************
# 成本总和为: 79377.07966689896
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 59 次迭代中的结果：
# agent 1 在 59 次迭代中的资源申请量为: -58.27978209208484
# agent 2 在 59 次迭代中的资源申请量为: -58.27978209208484
# agent 3 在 59 次迭代中的资源申请量为: -57.61078551032616
# agent 4 在 59 次迭代中的资源申请量为: 220.0119458525633
# agent 5 在 59 次迭代中的资源申请量为: 241.82440415652235
# agent 6 在 59 次迭代中的资源申请量为: -57.99400661846567
# agent 7 在 59 次迭代中的资源申请量为: 14.572999335592286
# agent 8 在 59 次迭代中的资源申请量为: -54.65402405167835
# agent 9 在 59 次迭代中的资源申请量为: -50.77700027294245
# agent 10 在 59 次迭代中的资源申请量为: 273.61000392480975
# agent 11 在 59 次迭代中的资源申请量为: 1236.8020377786843
# agent 12 在 59 次迭代中的资源申请量为: -54.645906303643045
# agent 13 在 59 次迭代中的资源申请量为: -57.51918007289219
# agent 14 在 59 次迭代中的资源申请量为: 35.24600875224321
# agent 15 在 59 次迭代中的资源申请量为: -59.72035753377971
# agent 16 在 59 次迭代中的资源申请量为: 12.816371332194826
# agent 17 在 59 次迭代中的资源申请量为: -58.652079676930946
# agent 18 在 59 次迭代中的资源申请量为: -64.31272420114011
# agent 19 在 59 次迭代中的资源申请量为: 6.839538692087405
# agent 20 在 59 次迭代中的资源申请量为: 882.0822299177116
# agent 21 在 59 次迭代中的资源申请量为: 538.5873838269063
# agent 22 在 59 次迭代中的资源申请量为: -94.48112694497897
# agent 23 在 59 次迭代中的资源申请量为: -86.91285398202486
# agent 24 在 59 次迭代中的资源申请量为: 296.4178960443946
# agent 25 在 59 次迭代中的资源申请量为: 324.3032532440613
# agent 26 在 59 次迭代中的资源申请量为: -69.86658796854658
# agent 27 在 59 次迭代中的资源申请量为: 460.98317719921624
# agent 28 在 59 次迭代中的资源申请量为: 390.5659419084227
# agent 29 在 59 次迭代中的资源申请量为: 295.06242940834244
# agent 30 在 59 次迭代中的资源申请量为: 47.406667405335796
# agent 31 在 59 次迭代中的资源申请量为: -47.004053494444
# agent 32 在 59 次迭代中的资源申请量为: -45.70420250007049
# agent 33 在 59 次迭代中的资源申请量为: -312.5039310024177
# agent 34 在 59 次迭代中的资源申请量为: 91.50055865751622
# agent 35 在 59 次迭代中的资源申请量为: 95.68491347545012
# agent 36 在 59 次迭代中的资源申请量为: 357.8397655614853
# agent 37 在 59 次迭代中的资源申请量为: 121.10788190779516
# agent 38 在 59 次迭代中的资源申请量为: -57.62489543993961
# agent 39 在 59 次迭代中的资源申请量为: 463.1779923438806
# agent 40 在 59 次迭代中的资源申请量为: 339.2055913774641
# agent 41 在 59 次迭代中的资源申请量为: -288.29779261576977
# agent 42 在 59 次迭代中的资源申请量为: -45.16935754812952
# agent 43 在 59 次迭代中的资源申请量为: 376.2445930294777
# agent 44 在 59 次迭代中的资源申请量为: 403.835533525462
# agent 45 在 59 次迭代中的资源申请量为: 540.6256734170092
# agent 46 在 59 次迭代中的资源申请量为: -225.66937420879006
# agent 47 在 59 次迭代中的资源申请量为: 278.405818332032
# agent 48 在 59 次迭代中的资源申请量为: 333.65404220652
# agent 49 在 59 次迭代中的资源申请量为: -1105.7382815297199
# agent 50 在 59 次迭代中的资源申请量为: 63.59599014723481
# agent 51 在 59 次迭代中的资源申请量为: 214.01866259816646
# agent 52 在 59 次迭代中的资源申请量为: 214.01866259816646
# agent 53 在 59 次迭代中的资源申请量为: 14.873511212926388
# agent 54 在 59 次迭代中的资源申请量为: -173.50339350887484
# 资源申请量总和为: 6000.000000000002
# ****************************************************************************
# 成本总和为: 90159.78765094555
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 79 次迭代中的结果：
# agent 1 在 79 次迭代中的资源申请量为: -58.35680759995166
# agent 2 在 79 次迭代中的资源申请量为: -58.35680759995166
# agent 3 在 79 次迭代中的资源申请量为: -57.92827500867547
# agent 4 在 79 次迭代中的资源申请量为: 227.09971383068347
# agent 5 在 79 次迭代中的资源申请量为: 240.9303705111689
# agent 6 在 79 次迭代中的资源申请量为: -58.194109814732315
# agent 7 在 79 次迭代中的资源申请量为: 13.015948653626793
# agent 8 在 79 次迭代中的资源申请量为: -56.03165211364801
# agent 9 在 79 次迭代中的资源申请量为: -53.05066973352571
# agent 10 在 79 次迭代中的资源申请量为: 260.83444489406145
# agent 11 在 79 次迭代中的资源申请量为: 1236.352280514383
# agent 12 在 79 次迭代中的资源申请量为: -56.12232276856993
# agent 13 在 79 次迭代中的资源申请量为: -57.90687371444487
# agent 14 在 79 次迭代中的资源申请量为: 25.98089684108529
# agent 15 在 79 次迭代中的资源申请量为: -59.34774838977184
# agent 16 在 79 次迭代中的资源申请量为: 12.05165473780086
# agent 17 在 79 次迭代中的资源申请量为: -58.67907156553888
# agent 18 在 79 次迭代中的资源申请量为: -63.1570829725438
# agent 19 在 79 次迭代中的资源申请量为: 6.911334809911249
# agent 20 在 79 次迭代中的资源申请量为: 944.6405525866616
# agent 21 在 79 次迭代中的资源申请量为: 609.3801178438767
# agent 22 在 79 次迭代中的资源申请量为: -87.77027639185252
# agent 23 在 79 次迭代中的资源申请量为: -78.00562831666
# agent 24 在 79 次迭代中的资源申请量为: 315.41599623921644
# agent 25 在 79 次迭代中的资源申请量为: 353.045083517531
# agent 26 在 79 次迭代中的资源申请量为: -59.45670524193016
# agent 27 在 79 次迭代中的资源申请量为: 461.5772136696447
# agent 28 在 79 次迭代中的资源申请量为: 404.5421749862131
# agent 29 在 79 次迭代中的资源申请量为: 286.76371862380614
# agent 30 在 79 次迭代中的资源申请量为: 43.27712215833045
# agent 31 在 79 次迭代中的资源申请量为: -50.047848299604425
# agent 32 在 79 次迭代中的资源申请量为: -49.02796845277273
# agent 33 在 79 次迭代中的资源申请量为: -319.29872787644604
# agent 34 在 79 次迭代中的资源申请量为: 73.40275264724617
# agent 35 在 79 次迭代中的资源申请量为: 85.11710879657213
# agent 36 在 79 次迭代中的资源申请量为: 360.42696524076604
# agent 37 在 79 次迭代中的资源申请量为: 125.29611848907152
# agent 38 在 79 次迭代中的资源申请量为: -56.17190183584846
# agent 39 在 79 次迭代中的资源申请量为: 553.4607082898201
# agent 40 在 79 次迭代中的资源申请量为: 336.78334431098676
# agent 41 在 79 次迭代中的资源申请量为: -294.92254421944466
# agent 42 在 79 次迭代中的资源申请量为: -71.28943817807685
# agent 43 在 79 次迭代中的资源申请量为: 378.33423351645223
# agent 44 在 79 次迭代中的资源申请量为: 423.0194727870108
# agent 45 在 79 次迭代中的资源申请量为: 559.2180387875792
# agent 46 在 79 次迭代中的资源申请量为: -217.18561185471856
# agent 47 在 79 次迭代中的资源申请量为: 298.5239123380713
# agent 48 在 79 次迭代中的资源申请量为: 352.7793559246284
# agent 49 在 79 次迭代中的资源申请量为: -1450.542391774755
# agent 50 在 79 次迭代中的资源申请量为: 87.09118565427849
# agent 51 在 79 次迭代中的资源申请量为: 231.77339456093202
# agent 52 在 79 次迭代中的资源申请量为: 231.77339456093202
# agent 53 在 79 次迭代中的资源申请量为: 13.298629967709587
# agent 54 在 79 次迭代中的资源申请量为: -181.26677656659433
# 资源申请量总和为: 6000.000000000001
# ****************************************************************************
# 成本总和为: 108176.9234284213
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: -58.36488201719265
# agent 2 在 99 次迭代中的资源申请量为: -58.36488201719265
# agent 3 在 99 次迭代中的资源申请量为: -58.1012193756298
# agent 4 在 99 次迭代中的资源申请量为: 231.64841280114138
# agent 5 在 99 次迭代中的资源申请量为: 240.6360317468494
# agent 6 在 99 次迭代中的资源申请量为: -58.25658830048686
# agent 7 在 99 次迭代中的资源申请量为: 12.48158036428341
# agent 8 在 99 次迭代中的资源申请量为: -56.67362960337306
# agent 9 在 99 次迭代中的资源申请量为: -54.12648353082002
# agent 10 在 99 次迭代中的资源申请量为: 254.504666834693
# agent 11 在 99 次迭代中的资源申请量为: 1233.18856440291
# agent 12 在 99 次迭代中的资源申请量为: -56.83192584372337
# agent 13 在 99 次迭代中的资源申请量为: -58.049618374217125
# agent 14 在 99 次迭代中的资源申请量为: 21.60052016796151
# agent 15 在 99 次迭代中的资源申请量为: -59.070470142208926
# agent 16 在 99 次迭代中的资源申请量为: 11.802324191629694
# agent 17 在 99 次迭代中的资源申请量为: -58.63654773980502
# agent 18 在 99 次迭代中的资源申请量为: -62.34084178869537
# agent 19 在 99 次迭代中的资源申请量为: 8.349153815256106
# agent 20 在 99 次迭代中的资源申请量为: 988.587651981294
# agent 21 在 99 次迭代中的资源申请量为: 672.1598790075076
# agent 22 在 99 次迭代中的资源申请量为: -78.72560265880529
# agent 23 在 99 次迭代中的资源申请量为: -68.70242812751948
# agent 24 在 99 次迭代中的资源申请量为: 337.6091576689496
# agent 25 在 99 次迭代中的资源申请量为: 376.9375125979133
# agent 26 在 99 次迭代中的资源申请量为: -50.63146822570925
# agent 27 在 99 次迭代中的资源申请量为: 462.8527135416795
# agent 28 在 99 次迭代中的资源申请量为: 414.1345169588228
# agent 29 在 99 次迭代中的资源申请量为: 283.6569979895258
# agent 30 在 99 次迭代中的资源申请量为: 41.3673919386604
# agent 31 在 99 次迭代中的资源申请量为: -51.47730629663045
# agent 32 在 99 次迭代中的资源申请量为: -50.58614200069561
# agent 33 在 99 次迭代中的资源申请量为: -322.4369736980083
# agent 34 在 99 次迭代中的资源申请量为: 64.85229126720583
# agent 35 在 99 次迭代中的资源申请量为: 80.4211713512727
# agent 36 在 99 次迭代中的资源申请量为: 362.61679988483536
# agent 37 在 99 次迭代中的资源申请量为: 128.65728471473085
# agent 38 在 99 次迭代中的资源申请量为: -54.83479915838008
# agent 39 在 99 次迭代中的资源申请量为: 637.1423856375533
# agent 40 在 99 次迭代中的资源申请量为: 335.3565245535989
# agent 41 在 99 次迭代中的资源申请量为: -298.77173618947035
# agent 42 在 99 次迭代中的资源申请量为: -86.79670834213852
# agent 43 在 99 次迭代中的资源申请量为: 378.514899790607
# agent 44 在 99 次迭代中的资源申请量为: 432.6254966326767
# agent 45 在 99 次迭代中的资源申请量为: 573.5340609769834
# agent 46 在 99 次迭代中的资源申请量为: -209.77293993686357
# agent 47 在 99 次迭代中的资源申请量为: 315.47714118640226
# agent 48 在 99 次迭代中的资源申请量为: 369.5089654446364
# agent 49 在 99 次迭代中的资源申请量为: -1796.7682608222017
# agent 50 在 99 次迭代中的资源申请量为: 110.29296083911449
# agent 51 在 99 次迭代中的资源申请量为: 249.60526830736555
# agent 52 在 99 次迭代中的资源申请量为: 249.60526830736555
# agent 53 在 99 次迭代中的资源申请量为: 12.66249017341039
# agent 54 在 99 次迭代中的资源申请量为: -184.06863088706766
# 资源申请量总和为: 6000.000000000002
# ****************************************************************************
# 成本总和为: 133278.41893349608
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 119 次迭代中的结果：
# agent 1 在 119 次迭代中的资源申请量为: -58.280788633491895
# agent 2 在 119 次迭代中的资源申请量为: -58.280788633491895
# agent 3 在 119 次迭代中的资源申请量为: -58.11190500192072
# agent 4 在 119 次迭代中的资源申请量为: 234.72776493167686
# agent 5 在 119 次迭代中的资源申请量为: 241.04168041138945
# agent 6 在 119 次迭代中的资源申请量为: -58.19309070690299
# agent 7 在 119 次迭代中的资源申请量为: 12.73033543944101
# agent 8 在 119 次迭代中的资源申请量为: -56.919910196741185
# agent 9 在 119 次迭代中的资源申请量为: -54.58420436856612
# agent 10 在 119 次迭代中的资源申请量为: 251.57525501600915
# agent 11 在 119 次迭代中的资源申请量为: 1232.0361483820332
# agent 12 在 119 次迭代中的资源申请量为: -57.13062813240352
# agent 13 在 119 次迭代中的资源申请量为: -58.026444092103304
# agent 14 在 119 次迭代中的资源申请量为: 19.724253996610848
# agent 15 在 119 次迭代中的资源申请量为: -58.78460583315041
# agent 16 在 119 次迭代中的资源申请量为: 12.158662335071096
# agent 17 在 119 次迭代中的资源申请量为: -58.502407398393444
# agent 18 在 119 次迭代中的资源申请量为: -61.66818260956944
# agent 19 在 119 次迭代中的资源申请量为: 10.401355284630927
# agent 20 在 119 次迭代中的资源申请量为: 1022.943922917796
# agent 21 在 119 次迭代中的资源申请量为: 729.0153707241769
# agent 22 在 119 次迭代中的资源申请量为: -69.48845210049893
# agent 23 在 119 次迭代中的资源申请量为: -59.88288538582881
# agent 24 在 119 次迭代中的资源申请量为: 360.041682954947
# agent 25 在 119 次迭代中的资源申请量为: 397.85643370041663
# agent 26 在 119 次迭代中的资源申请量为: -42.97864227851178
# agent 27 在 119 次迭代中的资源申请量为: 464.77154303336323
# agent 28 在 119 次迭代中的资源申请量为: 421.59792318996716
# agent 29 在 119 次迭代中的资源申请量为: 283.40088095493036
# agent 30 在 119 次迭代中的资源申请量为: 40.62197675371051
# agent 31 在 119 次迭代中的资源申请量为: -52.08583809387447
# agent 32 在 119 次迭代中的资源申请量为: -51.25016233758314
# agent 33 在 119 次迭代中的资源申请量为: -323.62063652904084
# agent 34 在 119 次迭代中的资源申请量为: 61.36799712485885
# agent 35 在 119 次迭代中的资源申请量为: 79.08906195404339
# agent 36 在 119 次迭代中的资源申请量为: 365.3151702920677
# agent 37 在 119 次迭代中的资源申请量为: 132.2694508747823
# agent 38 在 119 次迭代中的资源申请量为: -53.500437772203895
# agent 39 在 119 次迭代中的资源申请量为: 714.8394684474038
# agent 40 在 119 次迭代中的资源申请量为: 335.3627846466613
# agent 41 在 119 次迭代中的资源申请量为: -300.95405596974246
# agent 42 在 119 次迭代中的资源申请量为: -95.98473412199453
# agent 43 在 119 次迭代中的资源申请量为: 379.1189993821205
# agent 44 在 119 次迭代中的资源申请量为: 438.9750202986919
# agent 45 在 119 次迭代中的资源申请量为: 585.5046847267329
# agent 46 在 119 次迭代中的资源申请量为: -203.28137558241124
# agent 47 在 119 次迭代中的资源申请量为: 329.9027149567814
# agent 48 在 119 次迭代中的资源申请量为: 384.0422468178003
# agent 49 在 119 次迭代中的资源申请量为: -2144.108751146127
# agent 50 在 119 次迭代中的资源申请量为: 132.18978901194492
# agent 51 在 119 次迭代中的资源申请量为: 267.19140005541294
# agent 52 在 119 次迭代中的资源申请量为: 267.19140005541294
# agent 53 在 119 次迭代中的资源申请量为: 12.81372183668941
# agent 54 在 119 次迭代中的资源申请量为: -184.20017358302175
# 资源申请量总和为: 6000.000000000003
# ****************************************************************************
# 成本总和为: 165436.8959594448
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 139 次迭代中的结果：
# agent 1 在 139 次迭代中的资源申请量为: -58.09446923330677
# agent 2 在 139 次迭代中的资源申请量为: -58.09446923330677
# agent 3 在 139 次迭代中的资源申请量为: -57.97845572528064
# agent 4 在 139 次迭代中的资源申请量为: 237.0724077464909
# agent 5 在 139 次迭代中的资源申请量为: 242.17084665761573
# agent 6 在 139 次迭代中的资源申请量为: -58.01020042547488
# agent 7 在 139 次迭代中的资源申请量为: 13.667680502681474
# agent 8 在 139 次迭代中的资源申请量为: -56.91735991789923
# agent 9 在 139 次迭代中的资源申请量为: -54.68403160155297
# agent 10 在 139 次迭代中的资源申请量为: 250.6793279977192
# agent 11 在 139 次迭代中的资源申请量为: 1233.7829956072999
# agent 12 在 139 次迭代中的资源申请量为: -57.172238852621945
# agent 13 在 139 次迭代中的资源申请量为: -57.867104395511845
# agent 14 在 139 次迭代中的资源申请量为: 19.36698028704176
# agent 15 在 139 次迭代中的资源申请量为: -58.45109540084998
# agent 16 在 139 次迭代中的资源申请量为: 13.134682497422116
# agent 17 在 139 次迭代中的资源申请量为: -58.269518967482185
# agent 18 在 139 次迭代中的资源申请量为: -61.04336595065907
# agent 19 在 139 次迭代中的资源申请量为: 12.87014104298876
# agent 20 在 139 次迭代中的资源申请量为: 1052.2918431257576
# agent 21 在 139 次迭代中的资源申请量为: 780.8830741961508
# agent 22 在 139 次迭代中的资源申请量为: -60.69069788878497
# agent 23 在 139 次迭代中的资源申请量为: -51.71073310487697
# agent 24 在 139 次迭代中的资源申请量为: 381.55923445317126
# agent 25 在 139 次迭代中的资源申请量为: 416.7831871191745
# agent 26 在 139 次迭代中的资源申请量为: -36.14255103268843
# agent 27 在 139 次迭代中的资源申请量为: 467.2805692040855
# agent 28 在 139 次迭代中的资源申请量为: 427.9880071970486
# agent 29 在 139 次迭代中的资源申请量为: 284.8428362329106
# agent 30 在 139 次迭代中的资源申请量为: 40.53349328689279
# agent 31 在 139 次迭代中的资源申请量为: -52.2369075910414
# agent 32 在 139 次迭代中的资源申请量为: -51.42079771785544
# agent 33 在 139 次迭代中的资源申请量为: -323.70103122420767
# agent 34 在 139 次迭代中的资源申请量为: 60.69767835822226
# agent 35 在 139 次迭代中的资源申请量为: 79.75752030513866
# agent 36 在 139 次迭代中的资源申请量为: 368.6948961916335
# agent 37 在 139 次迭代中的资源申请量为: 136.3560331911377
# agent 38 在 139 次迭代中的资源申请量为: -52.13715537629487
# agent 39 在 139 次迭代中的资源申请量为: 787.27367148476
# agent 40 在 139 次迭代中的资源申请量为: 336.84609570862926
# agent 41 在 139 次迭代中的资源申请量为: -301.9709790488266
# agent 42 在 139 次迭代中的资源申请量为: -100.98618782619424
# agent 43 在 139 次迭代中的资源申请量为: 380.7434389724247
# agent 44 在 139 次迭代中的资源申请量为: 444.4274736458984
# agent 45 在 139 次迭代中的资源申请量为: 596.1506485685649
# agent 46 在 139 次迭代中的资源申请量为: -197.4864234366017
# agent 47 在 139 次迭代中的资源申请量为: 342.4769797520817
# agent 48 在 139 次迭代中的资源申请量为: 396.91030838158906
# agent 49 在 139 次迭代中的资源申请量为: -2492.2140200237277
# agent 50 在 139 次迭代中的资源申请量为: 152.6384801168692
# agent 51 在 139 次迭代中的资源申请量为: 284.1946490784908
# agent 52 在 139 次迭代中的资源申请量为: 284.1946490784908
# agent 53 在 139 次迭代中的资源申请量为: 13.66924932285366
# agent 54 在 139 次迭代中的资源申请量为: -182.6592853361888
# 资源申请量总和为: 5999.999999999999
# ****************************************************************************
# 成本总和为: 204638.1456625758
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 159 次迭代中的结果：
# agent 1 在 159 次迭代中的资源申请量为: -57.81054860313492
# agent 2 在 159 次迭代中的资源申请量为: -57.81054860313492
# agent 3 在 159 次迭代中的资源申请量为: -57.723915683849015
# agent 4 在 159 次迭代中的资源申请量为: 239.15931943241216
# agent 5 在 159 次迭代中的资源申请量为: 243.96644252576144
# agent 6 在 159 次迭代中的资源申请量为: -57.721040068730744
# agent 7 在 159 次迭代中的资源申请量为: 15.201219706380872
# agent 8 在 159 次迭代中的资源申请量为: -56.74106342087369
# agent 9 在 159 次迭代中的资源申请量为: -54.554676530498504
# agent 10 在 159 次迭代中的资源申请量为: 251.14396995458745
# agent 11 在 159 次迭代中的资源申请量为: 1238.3306906566318
# agent 12 在 159 次迭代中的资源申请量为: -57.034209255297355
# agent 13 在 159 次迭代中的资源申请量为: -57.59342104375402
# agent 14 在 159 次迭代中的资源申请量为: 20.046710406213386
# agent 15 在 159 次迭代中的资源申请量为: -58.05706813177238
# agent 16 在 159 次迭代中的资源申请量为: 14.67827618201552
# agent 17 在 159 次迭代中的资源申请量为: -57.943615509496766
# agent 18 在 159 次迭代中的资源申请量为: -60.42186021344553
# agent 19 在 159 次迭代中的资源申请量为: 15.684623506041895
# agent 20 在 159 次迭代中的资源申请量为: 1079.0293187823559
# agent 21 在 159 次迭代中的资源申请量为: 828.404106618411
# agent 22 在 159 次迭代中的资源申请量为: -52.483759941357455
# agent 23 在 159 次迭代中的资源申请量为: -44.152360789165826
# agent 24 在 159 次迭代中的资源申请量为: 401.8584542556091
# agent 25 在 159 次迭代中的资源申请量为: 434.2978609675576
# agent 26 在 159 次迭代中的资源申请量为: -29.883825016711484
# agent 27 在 159 次迭代中的资源申请量为: 470.3058807410478
# agent 28 在 159 次迭代中的资源申请量为: 433.83269901412626
# agent 29 在 159 次迭代中的资源申请量为: 287.38124100319516
# agent 30 在 159 次迭代中的资源申请量为: 40.845327088715706
# agent 31 在 159 次迭代中的资源申请量为: -52.110047494523236
# agent 32 在 159 次迭代中的资源申请量为: -51.29594049449634
# agent 33 在 159 次迭代中的资源申请量为: -323.11504819554995
# agent 34 在 159 次迭代中的资源申请量为: 61.69375576496237
# agent 35 在 159 次迭代中的资源申请量为: 81.6861859219024
# agent 36 在 159 次迭代中的资源申请量为: 372.71392406820854
# agent 37 在 159 次迭代中的资源申请量为: 140.90945416274462
# agent 38 在 159 次迭代中的资源申请量为: -50.741391102459716
# agent 39 在 159 次迭代中的资源申请量为: 855.1258348312367
# agent 40 在 159 次迭代中的资源申请量为: 339.66142914151857
# agent 41 在 159 次迭代中的资源申请量为: -302.1115673301449
# agent 42 在 159 次迭代中的资源申请量为: -102.98058323881266
# agent 43 在 159 次迭代中的资源申请量为: 383.43649631632354
# agent 44 在 159 次迭代中的资源申请量为: 449.8357561480654
# agent 45 在 159 次迭代中的资源申请量为: 606.0284173417427
# agent 46 在 159 次迭代中的资源申请量为: -192.20061630522727
# agent 47 在 159 次迭代中的资源申请量为: 353.752803615637
# agent 48 在 159 次迭代中的资源申请量为: 408.57566846658415
# agent 49 在 159 次迭代中的资源申请量为: -2840.829297937704
# agent 50 在 159 次迭代中的资源申请量为: 171.7278400451646
# agent 51 在 159 次迭代中的资源申请量为: 300.4149022113896
# agent 52 在 159 次迭代中的资源申请量为: 300.4149022113896
# agent 53 在 159 次迭代中的资源申请量为: 15.135765767731385
# agent 54 在 159 次迭代中的资源申请量为: -179.96287194552144
# 资源申请量总和为: 6000.000000000003
# ****************************************************************************
# 成本总和为: 250868.89435746326
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 179 次迭代中的结果：
# agent 1 在 179 次迭代中的资源申请量为: -57.439022142393554
# agent 2 在 179 次迭代中的资源申请量为: -57.439022142393554
# agent 3 在 179 次迭代中的资源申请量为: -57.36872575437616
# agent 4 在 179 次迭代中的资源申请量为: 241.28018945464635
# agent 5 在 179 次迭代中的资源申请量为: 246.34700760489355
# agent 6 在 179 次迭代中的资源申请量为: -57.34015883175995
# agent 7 在 179 次迭代中的资源申请量为: 17.243763641694038
# agent 8 在 179 次迭代中的资源申请量为: -56.43483747453417
# agent 9 在 179 次迭代中的资源申请量为: -54.26591304797467
# agent 10 在 179 次迭代中的资源申请量为: 252.595752001555
# agent 11 在 179 次迭代中的资源申请量为: 1245.3449860697206
# agent 12 在 179 次迭代中的资源申请量为: -56.761407345532454
# agent 13 在 179 次迭代中的资源申请量为: -57.22354946670315
# agent 14 在 179 次迭代中的资源申请量为: 21.49167675032683
# agent 15 在 179 次迭代中的资源申请量为: -57.60098178886679
# agent 16 在 179 次迭代中的资源申请量为: 16.718497013613778
# agent 17 在 179 次迭代中的资源申请量为: -57.53487451730358
# agent 18 在 179 次迭代中的资源申请量为: -59.7839436512404
# agent 19 在 179 次迭代中的资源申请量为: 18.801907396682864
# agent 20 在 179 次迭代中的资源申请量为: 1104.4302430739588
# agent 21 在 179 次迭代中的资源申请量为: 872.1443785388124
# agent 22 在 179 次迭代中的资源申请量为: -44.85717262977845
# agent 23 在 179 次迭代中的资源申请量为: -37.12456509043811
# agent 24 在 179 次迭代中的资源申请量为: 420.97184381797484
# agent 25 在 179 次迭代中的资源申请量为: 450.78013637604636
# agent 26 在 179 次迭代中的资源申请量为: -24.04055603327494
# agent 27 在 179 次迭代中的资源申请量为: 473.77423184704975
# agent 28 在 179 次迭代中的资源申请量为: 439.40533247054725
# agent 29 在 179 次迭代中的资源申请量为: 290.6816838077074
# agent 30 在 179 次迭代中的资源申请量为: 41.4205993154937
# agent 31 在 179 次迭代中的资源申请量为: -51.79995814821024
# agent 32 在 179 次迭代中的资源申请量为: -50.97928660116362
# agent 33 在 179 次迭代中的资源申请量为: -322.0960992663316
# agent 34 在 179 次迭代中的资源申请量为: 63.7507359605618
# agent 35 在 179 次迭代中的资源申请量为: 84.46117462046524
# agent 36 在 179 次迭代中的资源申请量为: 377.28081174235297
# agent 37 在 179 次迭代中的资源申请量为: 145.86632014069562
# agent 38 在 179 次迭代中的资源申请量为: -49.31857104242994
# agent 39 在 179 次迭代中的资源申请量为: 918.9950909680952
# agent 40 在 179 次迭代中的资源申请量为: 343.60424173764585
# agent 41 在 179 次迭代中的资源申请量为: -301.5707235163447
# agent 42 在 179 次迭代中的资源申请量为: -102.70195254604369
# agent 43 在 179 次迭代中的资源申请量为: 387.082777831809
# agent 44 在 179 次迭代中的资源申请量为: 455.48485561484944
# agent 45 在 179 次迭代中的资源申请量为: 615.4483704704729
# agent 46 在 179 次迭代中的资源申请量为: -187.2884762896242
# agent 47 在 179 次迭代中的资源申请量为: 364.12552209901094
# agent 48 在 179 次迭代中的资源申请量为: 419.3734032602046
# agent 49 在 179 次迭代中的资源申请量为: -3189.7868496934216
# agent 50 在 179 次迭代中的资源申请量为: 189.60167466135084
# agent 51 在 179 次迭代中的资源申请量为: 315.77153848155945
# agent 52 在 179 次迭代中的资源申请量为: 315.77153848155945
# agent 53 在 179 次迭代中的资源申请量为: 17.123370534462765
# agent 54 在 179 次迭代中的资源申请量为: -176.41700876567705
# 资源申请量总和为: 6000.000000000003
# ****************************************************************************
# 成本总和为: 304117.11761278205
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: -56.99077377617012
# agent 2 在 199 次迭代中的资源申请量为: -56.99077377617012
# agent 3 在 199 次迭代中的资源申请量为: -56.92956535601728
# agent 4 在 199 次迭代中的资源申请量为: 243.60156799907543
# agent 5 在 199 次迭代中的资源申请量为: 249.23203306015375
# agent 6 在 199 次迭代中的资源申请量为: -56.88092388986391
# agent 7 在 199 次迭代中的资源申请量为: 19.71917726535895
# agent 8 在 199 次迭代中的资源申请量为: -56.026930728556465
# agent 9 在 199 次迭代中的资源申请量为: -53.858987813251034
# agent 10 在 199 次迭代中的资源申请量为: 254.8041068490304
# agent 11 在 199 次迭代中的资源申请量为: 1254.4713163736642
# agent 12 在 199 次迭代中的资源申请量为: -56.382793304065956
# agent 13 在 199 次迭代中的资源申请量为: -56.772522942170625
# agent 14 在 199 次迭代中的资源申请量为: 23.530726166113627
# agent 15 在 199 次迭代中的资源申请量为: -57.08614549444166
# agent 16 在 199 次迭代中的资源申请量为: 19.18616668902778
# agent 17 在 199 次迭代中的资源申请量为: -57.05397694362308
# agent 18 在 199 次迭代中的资源申请量为: -59.121821233375144
# agent 19 在 199 次迭代中的资源申请量为: 22.186183803561345
# agent 20 在 199 次迭代中的资源申请量为: 1129.178776038488
# agent 21 在 199 次迭代中的资源申请量为: 912.6341042121402
# agent 22 在 199 次迭代中的资源申请量为: -37.74818586888402
# agent 23 在 199 次迭代中的资源申请量为: -30.53970484554786
# agent 24 在 199 次迭代中的资源申请量为: 439.0444848904926
# agent 25 在 199 次迭代中的资源申请量为: 466.49763097671956
# agent 26 在 199 次迭代中的资源申请量为: -18.500073052150803
# agent 27 在 199 次迭代中的资源申请量为: 477.6213524955973
# agent 28 在 199 次迭代中的资源申请量为: 444.8512906923312
# agent 29 在 199 次迭代中的资源申请量为: 294.5451565106169
# agent 30 在 199 次迭代中的资源申请量为: 42.18166803808688
# agent 31 在 199 次迭代中的资源申请量为: -51.36016735843021
# agent 32 在 199 次迭代中的资源申请量为: -50.52878451835102
# agent 33 在 199 次迭代中的资源申请量为: -320.7757235253439
# agent 34 在 199 次迭代中的资源申请量为: 66.53289669941869
# agent 35 在 199 次迭代中的资源申请量为: 87.83968700749882
# agent 36 在 199 次迭代中的资源申请量为: 382.30414242271223
# agent 37 在 199 次迭代中的资源申请量为: 151.15730366954793
# agent 38 在 199 次迭代中的资源申请量为: -47.876118769802645
# agent 39 在 199 次迭代中的资源申请量为: 979.3949342836305
# agent 40 在 199 次迭代中的资源申请量为: 348.4711207729891
# agent 41 在 199 次迭代中的资源申请量为: -300.4920796285495
# agent 42 在 199 次迭代中的资源申请量为: -100.65490670302961
# agent 43 在 199 次迭代中的资源申请量为: 391.5326765217453
# agent 44 在 199 次迭代中的资源申请量为: 461.4463889024807
# agent 45 在 199 次迭代中的资源申请量为: 624.585747853113
# agent 46 在 199 次迭代中的资源申请量为: -182.65682565839768
# agent 47 在 199 次迭代中的资源申请量为: 373.86075962813123
# agent 48 在 199 次迭代中的资源申请量为: 429.53214847207687
# agent 49 在 199 次迭代中的资源申请量为: -3538.9798920780377
# agent 50 在 199 次迭代中的资源申请量为: 206.4062120859675
# agent 51 在 199 次迭代中的资源申请量为: 330.26206514582327
# agent 52 在 199 次迭代中的资源申请量为: 330.26206514582327
# agent 53 在 199 次迭代中的资源申请量为: 19.55339976385119
# agent 54 在 199 次迭代中的资源申请量为: -172.21961317103464
# 资源申请量总和为: 6000.000000000004
# ****************************************************************************
# 成本总和为: 364372.9912014066
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 219 次迭代中的结果：
# agent 1 在 219 次迭代中的资源申请量为: -56.47593190017457
# agent 2 在 219 次迭代中的资源申请量为: -56.47593190017457
# agent 3 在 219 次迭代中的资源申请量为: -56.4197767806245
# agent 4 在 219 次迭代中的资源申请量为: 246.20917687225347
# agent 5 在 219 次迭代中的资源申请量为: 252.5500928778149
# agent 6 在 219 次迭代中的资源申请量为: -56.35480712580954
# agent 7 在 219 次迭代中的资源申请量为: 22.563355007110236
# agent 8 在 219 次迭代中的资源申请量为: -55.53694230708365
# agent 9 在 219 次迭代中的资源申请量为: -53.360289152468766
# agent 10 在 219 次迭代中的资源申请量为: 257.6142852591389
# agent 11 在 219 次迭代中的资源申请量为: 1265.3937780327592
# agent 12 在 219 次迭代中的资源申请量为: -55.91855847288022
# agent 13 在 219 次迭代中的资源申请量为: -56.252678610344304
# agent 14 在 219 次迭代中的资源申请量为: 26.04689048189507
# agent 15 在 219 次迭代中的资源申请量为: -56.51772099171193
# agent 16 在 219 次迭代中的资源申请量为: 22.020298115748243
# agent 17 在 219 次迭代中的资源申请量为: -56.51069270816296
# agent 18 在 219 次迭代中的资源申请量为: -58.43335574977414
# agent 19 在 219 次迭代中的资源申请量为: 25.80517868348547
# agent 20 在 219 次迭代中的资源申请量为: 1153.6465680180086
# agent 21 在 219 次迭代中的资源申请量为: 950.3640270318249
# agent 22 在 219 次迭代中的资源申请量为: -31.081814913260708
# agent 23 在 219 次迭代中的资源申请量为: -24.31875722128848
# agent 24 在 219 次迭代中的资源申请量为: 456.2451156416801
# agent 25 在 219 次迭代中的资源申请量为: 481.6479385468042
# agent 26 在 219 次迭代中的资源申请量为: -13.181805223331114
# agent 27 在 219 次迭代中的资源申请量为: 481.7932115975232
# agent 28 在 219 次迭代中的资源申请量为: 450.24974015434293
# agent 29 在 219 次迭代中的资源申请量为: 298.8445257999826
# agent 30 在 219 次迭代中的资源申请量为: 43.081397149842175
# agent 31 在 219 次迭代中的资源申请量为: -50.82319195585397
# agent 32 在 219 次迭代中的资源申请量为: -49.979148693611705
# agent 33 在 219 次迭代中的资源申请量为: -319.2329067824903
# agent 34 在 219 次迭代中的资源申请量为: 69.8423668937746
# agent 35 在 219 次迭代中的资源申请量为: 91.67045532602259
# agent 36 在 219 次迭代中的资源申请量为: 387.70461957804963
# agent 37 在 219 次迭代中的资源申请量为: 156.72018400426708
# agent 38 在 219 次迭代中的资源申请量为: -46.42105400137248
# agent 39 在 219 次迭代中的资源申请量为: 1036.7613265130253
# agent 40 在 219 次迭代中的资源申请量为: 354.0822420860675
# agent 41 在 219 次迭代中的资源申请量为: -298.98633133050174
# agent 42 在 219 次迭代中的资源申请量为: -97.2110523131069
# agent 43 在 219 次迭代中的资源申请量为: 396.6440891620084
# agent 44 在 219 次迭代中的资源申请量为: 467.7131890008268
# agent 45 在 219 次迭代中的资源申请量为: 633.5397268126454
# agent 46 在 219 次迭代中的资源申请量为: -178.24228471185106
# agent 47 在 219 次迭代中的资源申请量为: 383.1324723889071
# agent 48 在 219 次迭代中的资源申请量为: 439.20537773186345
# agent 49 在 219 次迭代中的资源申请量为: -3888.3411013168097
# agent 50 在 219 次迭代中的资源申请量为: 222.27489986837676
# agent 51 在 219 次迭代中的资源申请量为: 343.9283162545965
# agent 52 在 219 次迭代中的资源申请量为: 343.9283162545965
# agent 53 在 219 次迭代中的资源申请量为: 22.359727719946363
# agent 54 在 219 次迭代中的资源申请量为: -167.50675470249948
# 资源申请量总和为: 6000.000000000002
# ****************************************************************************
# 成本总和为: 431629.1595062437
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 239 次迭代中的结果：
# agent 1 在 239 次迭代中的资源申请量为: -55.90340413593928
# agent 2 在 239 次迭代中的资源申请量为: -55.90340413593928
# agent 3 在 239 次迭代中的资源申请量为: -55.850053643986776
# agent 4 在 239 次迭代中的资源申请量为: 249.13843267697698
# agent 5 在 239 次迭代中的资源申请量为: 256.2402435722852
# agent 6 在 239 次迭代中的资源申请量为: -55.7714181837972
# agent 7 在 239 次迭代中的资源申请量为: 25.723005286285098
# agent 8 在 239 次迭代中的资源申请量为: -54.979227895904245
# agent 9 在 239 次迭代中的资源申请量为: -52.78790214804589
# agent 10 在 239 次迭代中的资源申请量为: 260.9157252146947
# agent 11 在 239 次迭代中的资源申请量为: 1277.845611732266
# agent 12 在 239 次迭代中的资源申请量为: -55.38356906321313
# agent 13 在 239 次迭代中的资源申请量为: -55.674131509386775
# agent 14 在 239 次迭代中的资源申请量为: 28.95532705478811
# agent 15 在 239 次迭代中的资源申请量为: -55.9013190544852
# agent 16 在 239 次迭代中的资源申请量为: 25.169046719913855
# agent 17 在 239 次迭代中的资源申请量为: -55.913515194212366
# agent 18 在 239 次迭代中的资源申请量为: -57.718999040056396
# agent 19 在 239 次迭代中的资源申请量为: 29.629935663900707
# agent 20 在 239 次迭代中的资源申请量为: 1178.0384484912856
# agent 21 在 239 次迭代中的资源申请量为: 985.777205184732
# agent 22 在 239 次迭代中的资源申请量为: -24.785557965415357
# agent 23 在 239 次迭代中的资源申请量为: -18.393991584523693
# agent 24 在 239 次迭代中的资源申请量为: 472.7333684717706
# agent 25 在 239 次迭代中的资源申请量为: 496.38088598090997
# agent 26 在 239 次迭代中的资源申请量为: -8.026728214261432
# agent 27 在 239 次迭代中的资源申请量为: 486.24490757452065
# agent 28 在 239 次迭代中的资源申请量为: 455.64469238245925
# agent 29 在 239 次迭代中的资源申请量为: 303.4928569334831
# agent 30 在 239 次迭代中的资源申请量为: 44.08911166745742
# agent 31 在 239 次迭代中的资源申请量为: -50.210237563242956
# agent 32 在 239 次迭代中的资源申请量为: -49.35269834131997
# agent 33 在 239 次迭代中的资源申请量为: -317.5184264322249
# agent 34 在 239 次迭代中的资源申请量为: 73.55435534680791
# agent 35 在 239 次迭代中的资源申请量为: 95.85295766962734
# agent 36 在 239 次迭代中的资源申请量为: 393.41603826641705
# agent 37 在 239 次迭代中的资源申请量为: 162.50207480250108
# agent 38 在 239 次迭代中的资源申请量为: -44.959318603528544
# agent 39 在 239 次迭代中的资源申请量为: 1091.4636287059016
# agent 40 在 239 次迭代中的资源申请量为: 360.28644449230285
# agent 41 在 239 次迭代中的资源申请量为: -297.14066361710127
# agent 42 在 239 次迭代中的资源申请量为: -92.65571080462641
# agent 43 在 239 次迭代中的资源申请量为: 402.29368169266854
# agent 44 在 239 次迭代中的资源申请量为: 474.25101144891886
# agent 45 在 239 次迭代中的资源申请量为: 642.366067719498
# agent 46 在 239 次迭代中的资源申请量为: -174.00134082473613
# agent 47 在 239 次迭代中的资源申请量为: 392.05407555324246
# agent 48 在 239 次迭代中的资源申请量为: 448.49667197519517
# agent 49 在 239 次迭代中的资源申请量为: -4237.827910515349
# agent 50 在 239 次迭代中的资源申请量为: 237.32510151265174
# agent 51 在 239 次迭代中的资源申请量为: 356.83387505978567
# agent 52 在 239 次迭代中的资源申请量为: 356.83387505978567
# agent 53 在 239 次迭代中的资源申请量为: 25.487516818791164
# agent 54 在 239 次迭代中的资源申请量为: -162.37665226052644
# 资源申请量总和为: 6000.000000000002
# ****************************************************************************
# 成本总和为: 505880.52906136954
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 259 次迭代中的结果：
# agent 1 在 259 次迭代中的资源申请量为: -55.28085322276211
# agent 2 在 259 次迭代中的资源申请量为: -55.28085322276211
# agent 3 在 259 次迭代中的资源申请量为: -55.229052282376166
# agent 4 在 259 次迭代中的资源申请量为: 252.39464491948675
# agent 5 在 259 次迭代中的资源申请量为: 260.251165538643
# agent 6 在 259 次迭代中的资源申请量为: -55.13875868633934
# agent 7 在 259 次迭代中的资源申请量为: 29.153888569742996
# agent 8 在 259 次迭代中的资源申请量为: -54.364737793163755
# agent 9 在 259 次迭代中的资源申请量为: -52.15494791819714
# agent 10 在 259 次迭代中的资源申请量为: 264.62566043021314
# agent 11 在 259 次迭代中的资源申请量为: 1291.6052362566875
# agent 12 在 259 次迭代中的资源申请量为: -54.789210991614866
# agent 13 在 259 次迭代中的资源申请量为: -55.04521115259774
# agent 14 在 259 次迭代中的资源申请量为: 32.19174133502544
# agent 15 在 259 次迭代中的资源申请量为: -55.24236195521697
# agent 16 在 259 次迭代中的资源申请量为: 28.588861499878732
# agent 17 在 259 次迭代中的资源申请量为: -55.269684774814245
# agent 18 在 259 次迭代中的资源申请量为: -56.98029295400194
# agent 19 在 259 次迭代中的资源申请量为: 33.63490886804688
# agent 20 在 259 次迭代中的资源申请量为: 1202.4694468539583
# agent 21 在 259 次迭代中的资源申请量为: 1019.2649913288063
# agent 22 在 259 次迭代中的资源申请量为: -18.794379868818446
# agent 23 在 259 次迭代中的资源申请量为: -12.70842498214111
# agent 24 在 259 次迭代中的资源申请量为: 488.649515107008
# agent 25 在 259 次迭代中的资源申请量为: 510.8117787406737
# agent 26 在 259 次迭代中的资源申请量为: -2.990685654208395
# agent 27 在 259 次迭代中的资源申请量为: 490.9390811329939
# agent 28 在 259 次迭代中的资源申请量为: 461.06104518304426
# agent 29 在 259 次迭代中的资源申请量为: 308.4270618868739
# agent 30 在 259 次迭代中的资源申请量为: 45.18350955673533
# agent 31 在 259 次迭代中的资源申请量为: -49.53605873600074
# agent 32 在 259 次迭代中的资源申请量为: -48.664767611595366
# agent 33 在 259 次迭代中的资源申请量为: -315.66715544276946
# agent 34 在 259 次迭代中的资源申请量为: 77.58466158767298
# agent 35 在 259 次迭代中的资源申请量为: 100.31619139018794
# agent 36 在 259 次迭代中的资源申请量为: 399.38353231853745
# agent 37 在 259 次迭代中的资源申请量为: 168.4587454416861
# agent 38 在 259 次迭代中的资源申请量为: -43.495717298398816
# agent 39 在 259 次迭代中的资源申请量为: 1143.8151396840792
# agent 40 在 259 次迭代中的资源申请量为: 366.9595132214829
# agent 41 在 259 次迭代中的资源申请量为: -295.0245064636544
# agent 42 在 259 次迭代中的资源申请量为: -87.21322153262847
# agent 43 在 259 次迭代中的资源申请量为: 408.37793609895886
# agent 44 在 259 次迭代中的资源申请量为: 481.0186374618399
# agent 45 在 259 次迭代中的资源申请量为: 651.0956328733774
# agent 46 在 259 次迭代中的资源申请量为: -169.90347314635105
# agent 47 在 259 次迭代中的资源申请量为: 400.7002273236814
# agent 48 在 259 次迭代中的资源申请量为: 457.47725491433243
# agent 49 在 259 次迭代中的资源申请量为: -4587.4130818314225
# agent 50 在 259 次迭代中的资源申请量为: 251.65858945416747
# agent 51 在 259 次迭代中的资源申请量为: 369.0503314597356
# agent 52 在 259 次迭代中的资源申请量为: 369.0503314597356
# agent 53 在 259 次迭代中的资源申请量为: 28.89135455434726
# agent 54 在 259 次迭代中的资源申请量为: -156.90317892980562
# 资源申请量总和为: 6000.0
# ****************************************************************************
# 成本总和为: 587123.8689730745
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 279 次迭代中的结果：
# agent 1 在 279 次迭代中的资源申请量为: -54.61481917040921
# agent 2 在 279 次迭代中的资源申请量为: -54.61481917040921
# agent 3 在 279 次迭代中的资源申请量为: -54.563865411007455
# agent 4 在 279 次迭代中的资源申请量为: 255.96601131435355
# agent 5 在 279 次迭代中的资源申请量为: 264.5397404150459
# agent 6 在 279 次迭代中的资源申请量为: -54.46350337768067
# agent 7 在 279 次迭代中的资源申请量为: 32.81914399821456
# agent 8 在 279 次迭代中的资源申请量为: -53.70208484538175
# agent 9 在 279 次迭代中的资源申请量为: -51.47138419425658
# agent 10 在 279 次迭代中的资源申请量为: 268.67991636378576
# agent 11 在 279 次迭代中的资源申请量为: 1306.4889715917536
# agent 12 在 279 次迭代中的资源申请量为: -54.14446442779925
# agent 13 在 279 次迭代中的资源申请量为: -54.372823361606265
# agent 14 在 279 次迭代中的资源申请量为: 35.705794338338336
# agent 15 在 279 次迭代中的资源申请量为: -54.54581932266122
# agent 16 在 279 次迭代中的资源申请量为: 32.24321424098446
# agent 17 在 279 次迭代中的资源申请量为: -54.58533540533753
# agent 18 在 279 次迭代中的资源申请量为: -56.219148144525036
# agent 19 在 279 次迭代中的资源申请量为: 37.79786338613795
# agent 20 在 279 次迭代中的资源申请量为: 1227.0056539466075
# agent 21 在 279 次迭代中的资源申请量为: 1051.167390198855
# agent 22 在 279 次迭代中的资源申请量为: -13.051876471650253
# agent 23 在 279 次迭代中的资源申请量为: -7.21445114330978
# agent 24 在 279 次迭代中的资源申请量为: 504.11289015376616
# agent 25 在 279 次迭代中的资源申请量为: 525.0301022117734
# agent 26 在 279 次迭代中的资源申请量为: 1.9599391694102373
# agent 27 在 279 次迭代中的资源申请量为: 495.8444640876238
# agent 28 在 279 次迭代中的资源申请量为: 466.51305318949665
# agent 29 在 279 次迭代中的资源申请量为: 313.5991291244713
# agent 30 在 279 次迭代中的资源申请量为: 46.348954687289535
# agent 31 在 279 次迭代中的资源申请量为: -48.81149839061206
# agent 32 在 279 次迭代中的资源申请量为: -47.926511577205765
# agent 33 在 279 次迭代中的资源申请量为: -313.70446752558837
# agent 34 在 279 次迭代中的资源申请量为: 81.87292074020571
# agent 35 在 279 次迭代中的资源申请量为: 105.00734809950254
# agent 36 在 279 次迭代中的资源申请量为: 405.56156026734925
# agent 37 在 279 次迭代中的资源申请量为: 174.55337851435496
# agent 38 在 279 次迭代中的资源申请量为: -42.03404891589744
# agent 39 在 279 次迭代中的资源申请量为: 1194.082298904658
# agent 40 在 279 次迭代中的资源申请量为: 374.00038786857044
# agent 41 在 279 次迭代中的资源申请量为: -292.6934995107594
# agent 42 在 279 次迭代中的资源申请量为: -81.06236405648656
# agent 43 在 279 次迭代中的资源申请量为: 414.811116172458
# agent 44 在 279 次迭代中的资源申请量为: 487.97568151345956
# agent 45 在 279 次迭代中的资源申请量为: 659.7450697475705
# agent 46 在 279 次迭代中的资源申请量为: -165.92665065920863
# agent 47 在 279 次迭代中的资源申请量为: 409.1210763472116
# agent 48 在 279 次迭代中的资源申请量为: 466.19745065426673
# agent 49 在 279 次迭代中的资源申请量为: -4937.078829258137
# agent 50 在 279 次迭代中的资源申请量为: 265.3631386901849
# agent 51 在 279 次迭代中的资源申请量为: 380.6494668858244
# agent 52 在 279 次迭代中的资源申请量为: 380.6494668858244
# agent 53 在 279 次迭代中的资源申请量为: 32.53348494036504
# agent 54 在 279 次迭代中的资源申请量为: -151.1438143097837
# 资源申请量总和为: 6000.000000000002
# ****************************************************************************
# 成本总和为: 675357.3851052686
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 299 次迭代中的结果：
# agent 1 在 299 次迭代中的资源申请量为: -53.910874841075554
# agent 2 在 299 次迭代中的资源申请量为: -53.910874841075554
# agent 3 在 299 次迭代中的资源申请量为: -53.86037309154365
# agent 4 在 299 次迭代中的资源申请量为: 259.8317817804568
# agent 5 在 299 次迭代中的资源申请量为: 269.06965389403007
# agent 6 在 299 次迭代中的资源申请量为: -53.75124749298723
# agent 7 在 299 次迭代中的资源申请量为: 36.687885246557684
# agent 8 在 299 次迭代中的资源申请量为: -52.99820310676907
# agent 9 在 299 次迭代中的资源申请量为: -50.74503064572235
# agent 10 在 299 次迭代中的资源申请量为: 273.0273910919271
# agent 11 在 299 次迭代中的资源申请量为: 1322.3439723291283
# agent 12 在 299 次迭代中的资源申请量为: -53.45657144335199
# agent 13 在 299 次迭代中的资源申请量为: -53.662736060758746
# agent 14 在 299 次迭代中的资源申请量为: 39.45709410819839
# agent 15 在 299 次迭代中的资源申请量为: -53.816124791091696
# agent 16 在 299 次迭代中的资源申请量为: 36.10137941553366
# agent 17 在 299 次迭代中的资源申请量为: -53.8656627838721
# agent 18 在 299 次迭代中的资源申请量为: -55.437509025418166
# agent 19 在 299 次迭代中的资源申请量为: 42.09960655104453
# agent 20 在 299 次迭代中的资源申请量为: 1251.685973518184
# agent 21 在 299 次迭代中的资源申请量为: 1081.7762545692024
# agent 22 在 299 次迭代中的资源申请量为: -7.50996616750875
# agent 23 在 299 次迭代中的资源申请量为: -1.87241078553253
# agent 24 在 299 次迭代中的资源申请量为: 519.2234252651302
# agent 25 在 299 次迭代中的资源申请量为: 539.1056369880567
# agent 26 在 299 次迭代中的资源申请量为: 6.851094223207628
# agent 27 在 299 次迭代中的资源申请量为: 500.93470118273626
# agent 28 在 299 次迭代中的资源申请量为: 472.00888971352265
# agent 29 在 299 次迭代中的资源申请量为: 318.97120733775176
# agent 30 在 299 次迭代中的资源申请量为: 47.573458194486186
# agent 31 在 299 次迭代中的资源申请量为: -48.04487499846135
# agent 32 在 299 次迭代中的资源申请量为: -47.1464235694518
# agent 33 在 299 次迭代中的资源申请量为: -311.64969382702293
# agent 34 在 299 次迭代中的资源申请量为: 86.37366230129689
# agent 35 在 299 次迭代中的资源申请量为: 109.88556065746982
# agent 36 在 299 次迭代中的资源申请量为: 411.91220778554197
# agent 37 在 299 次迭代中的资源申请量为: 180.75538788257995
# agent 38 在 299 次迭代中的资源申请量为: -40.57727484937085
# agent 39 在 299 次迭代中的资源申请量为: 1242.4924342953698
# agent 40 在 299 次迭代中的资源申请量为: 381.3271755941377
# agent 41 在 299 次迭代中的资源申请量为: -290.1924137919089
# agent 42 在 299 次迭代中的资源申请量为: -74.34673860772182
# agent 43 在 299 次迭代中的资源申请量为: 421.5225997567525
# agent 44 在 299 次迭代中的资源申请量为: 495.08548542879225
# agent 45 在 299 次迭代中的资源申请量为: 668.3230296293085
# agent 46 在 299 次迭代中的资源申请量为: -162.0544508073001
# agent 47 在 299 次迭代中的资源申请量为: 417.3512866212376
# agent 48 在 299 次迭代中的资源申请量为: 474.693981585187
# agent 49 在 299 次迭代中的资源申请量为: -5286.813201742117
# agent 50 在 299 次迭代中的资源申请量为: 278.51431537693674
# agent 51 在 299 次迭代中的资源申请量为: 391.6991379882546
# agent 52 在 299 次迭代中的资源申请量为: 391.6991379882546
# agent 53 在 299 次迭代中的资源申请量为: 36.38232999042819
# agent 54 在 299 次迭代中的资源申请量为: -145.1444810206406
# 资源申请量总和为: 5999.999999999999
# ****************************************************************************
# 成本总和为: 770580.3426906068
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 319 次迭代中的结果：
# agent 1 在 319 次迭代中的资源申请量为: -53.17377457674823
# agent 2 在 319 次迭代中的资源申请量为: -53.17377457674823
# agent 3 在 319 次迭代中的资源申请量为: -53.12350028054882
# agent 4 在 319 次迭代中的资源申请量为: 263.96726206034174
# agent 5 在 319 次迭代中的资源申请量为: 273.81019506101626
# agent 6 在 319 次迭代中的资源申请量为: -53.006708501103596
# agent 7 在 319 次迭代中的资源申请量为: 40.73407617025753
# agent 8 在 319 次迭代中的资源申请量为: -52.258774843652446
# agent 9 在 319 次迭代中的资源申请量为: -49.98218474214936
# agent 10 在 319 次迭代中的资源申请量为: 277.62656122587623
# agent 11 在 319 次迭代中的资源申请量为: 1339.0422952797178
# agent 12 在 319 次迭代中的资源申请量为: -52.73147257389451
# agent 13 在 319 次迭代中的资源申请量为: -52.91980087239943
# agent 14 在 319 次迭代中的资源申请量为: 43.41262357403356
# agent 15 在 319 次迭代中的资源申请量为: -53.05717754580186
# agent 16 在 319 次迭代中的资源申请量为: 40.13739645757084
# agent 17 在 319 次迭代中的资源申请量为: -53.11507879751902
# agent 18 在 319 次迭代中的资源申请量为: -54.63720906134628
# agent 19 在 319 次迭代中的资源申请量为: 46.52363997745596
# agent 20 在 319 次迭代中的资源申请量为: 1276.5337613073868
# agent 21 在 319 次迭代中的资源申请量为: 1111.339905128621
# agent 22 在 319 次迭代中的资源申请量为: -2.1280636278145586
# agent 23 在 319 次迭代中的资源申请量为: 3.350680969716457
# agent 24 在 319 次迭代中的资源申请量为: 534.0640926100667
# agent 25 在 319 次迭代中的资源申请量为: 553.0929338149226
# agent 26 在 319 次迭代中的资源申请量为: 11.703010624148227
# agent 27 在 319 次迭代中的资源申请量为: 506.1874290200573
# agent 28 在 319 次迭代中的资源申请量为: 477.5531508416972
# agent 29 在 319 次迭代中的资源申请量为: 324.51270433383223
# agent 30 在 319 次迭代中的资源申请量为: 48.84752721743262
# agent 31 在 319 次迭代中的资源申请量为: -47.242777751063656
# agent 32 在 319 次迭代中的资源申请量为: -46.33119457510077
# agent 33 在 319 次迭代中的资源申请量为: -309.5180713815069
# agent 34 在 319 次迭代中的资源申请量为: 91.05133658495231
# agent 35 在 319 次迭代中的资源申请量为: 114.91829404066601
# agent 36 在 319 次迭代中的资源申请量为: 418.403847180082
# agent 37 在 319 次迭代中的资源申请量为: 187.03941618246
# agent 38 在 319 次迭代中的资源申请量为: -39.12767496718825
# agent 39 在 319 次迭代中的资源申请量为: 1289.2401986792836
# agent 40 在 319 次迭代中的资源申请量为: 388.873610379688
# agent 41 在 319 次迭代中的资源申请量为: -287.5573792335902
# agent 42 在 319 次迭代中的资源申请量为: -67.1822524448918
# agent 43 在 319 次迭代中的资源申请量为: 428.4543567469015
# agent 44 在 319 次迭代中的资源申请量为: 502.3159908706949
# agent 45 在 319 次迭代中的资源申请量为: 676.8337949056247
# agent 46 在 319 次迭代中的资源申请量为: -158.27422617174548
# agent 47 在 319 次迭代中的资源申请量为: 425.41567294112735
# agent 48 在 319 次迭代中的资源申请量为: 482.9945782513314
# agent 49 在 319 次迭代中的资源申请量为: -5636.607868852993
# agent 50 在 319 次迭代中的资源申请量为: 291.17716612358214
# agent 51 在 319 次迭代中的资源申请量为: 402.2613667819837
# agent 52 在 319 次迭代中的资源申请量为: 402.2613667819837
# agent 53 在 319 次迭代中的资源申请量为: 40.41131096305429
# agent 54 在 319 次迭代中的资源申请量为: -138.94258770975898
# 资源申请量总和为: 5999.999999999999
# ****************************************************************************
# 成本总和为: 872792.7604046072
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 339 次迭代中的结果：
# agent 1 在 339 次迭代中的资源申请量为: -52.40758380219193
# agent 2 在 339 次迭代中的资源申请量为: -52.40758380219193
# agent 3 在 339 次迭代中的资源申请量为: -52.357407197672146
# agent 4 在 339 次迭代中的资源申请量为: 268.34678803701655
# agent 5 在 339 次迭代中的资源申请量为: 278.7352731881815
# agent 6 在 339 次迭代中的资源申请量为: -52.233886294832445
# agent 7 在 339 次迭代中的资源申请量为: 44.935644456579865
# agent 8 在 339 次迭代中的资源申请量为: -51.48851964237522
# agent 9 在 339 次迭代中的资源申请量为: -49.188011609088385
# agent 10 在 339 次迭代中的资源申请量为: 282.44316472673444
# agent 11 在 339 次迭代中的资源申请量为: 1356.4761657220909
# agent 12 在 339 次迭代中的资源申请量为: -51.974104680773834
# agent 13 在 339 次迭代中的资源申请量为: -52.14812450258209
# agent 14 在 339 次迭代中的资源申请量为: 47.545012582187454
# agent 15 在 339 次迭代中的资源申请量为: -52.272380924873346
# ...
# agent 88 在 1969 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1969 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1969 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1969 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1969 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1969 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1969 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1969 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1969 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1969 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1969 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1969 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1969 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1979 次迭代中的结果：
# agent 1 在 1979 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1979 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1979 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1979 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1979 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1979 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1979 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1979 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1979 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1979 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1979 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1979 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1979 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1979 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1979 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1979 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1979 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1979 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1979 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1979 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1979 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1979 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1979 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1979 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1979 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1979 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1979 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1979 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1979 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1979 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1979 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1979 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1979 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1979 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1979 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1979 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1979 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1979 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1979 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1979 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1979 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1979 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1979 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1979 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1979 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1979 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1979 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1979 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1979 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1979 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1979 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1979 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1979 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1979 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1979 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1979 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1979 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1979 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1979 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1979 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1979 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1979 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1979 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1979 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1979 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1979 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1979 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1979 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1979 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1979 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1979 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1979 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1979 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1979 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1979 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1979 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1979 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1979 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1979 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1979 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1979 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1979 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1979 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1979 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1979 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1979 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1979 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1979 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1979 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1979 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1979 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1979 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1979 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1979 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1979 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1979 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1979 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1989 次迭代中的结果：
# agent 1 在 1989 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1989 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1989 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1989 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1989 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1989 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1989 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1989 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1989 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1989 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1989 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1989 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1989 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1989 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1989 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1989 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1989 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1989 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1989 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1989 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1989 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1989 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1989 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1989 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1989 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1989 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1989 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1989 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1989 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1989 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1989 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1989 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1989 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1989 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1989 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1989 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1989 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1989 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1989 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1989 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1989 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1989 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1989 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1989 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1989 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1989 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1989 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1989 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1989 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1989 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1989 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1989 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1989 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1989 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1989 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1989 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1989 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1989 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1989 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1989 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1989 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1989 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1989 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1989 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1989 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1989 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1989 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1989 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1989 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1989 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1989 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1989 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1989 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1989 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1989 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1989 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1989 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1989 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1989 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1989 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1989 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1989 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1989 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1989 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1989 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1989 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1989 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1989 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1989 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1989 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1989 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1989 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1989 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1989 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1989 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1989 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1989 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1999 次迭代中的结果：
# agent 1 在 1999 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1999 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1999 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1999 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1999 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1999 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1999 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1999 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1999 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1999 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1999 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1999 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1999 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1999 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1999 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1999 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1999 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1999 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1999 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1999 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1999 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1999 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1999 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1999 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1999 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1999 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1999 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1999 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1999 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1999 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1999 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1999 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1999 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1999 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1999 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1999 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1999 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1999 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1999 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1999 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1999 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1999 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1999 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1999 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1999 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1999 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1999 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1999 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1999 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1999 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1999 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1999 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1999 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1999 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1999 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1999 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1999 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1999 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1999 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1999 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1999 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1999 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1999 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1999 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1999 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1999 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1999 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1999 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1999 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1999 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1999 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1999 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1999 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1999 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1999 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1999 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1999 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1999 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1999 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1999 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1999 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1999 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1999 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1999 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1999 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1999 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1999 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1999 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1999 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1999 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1999 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1999 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1999 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1999 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1999 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1999 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1999 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 2025-01-21 17:21:01.305

# %%
np.savetxt('../data/02-agent_resource_quantity_unbounded_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/02-sum_cost_unbounded_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/02-sum_resource_unbounded_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
np.savetxt('../data/02-agent_gradient_unbounded_bias.txt',agent_gradient,fmt='%0.8f')#用户迭代梯度
