# %% [markdown]
# IWDGD中大值的确定性噪声 对应到DGD算法中是固定的对偶攻击值为-24 这样两个算法各自迭代2000次 所有用户的对偶迭代值均在-23.83附近

# %% [markdown]
# 鲁棒聚合器CTM 每个用户剔除2个用户对偶信息（包含自身的信息）
# 考虑到网络中可能有部分的用户其邻居数量是1 所以这样的用户不必做CTM操作

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(54,2000)) 
dual_variable = np.zeros(shape=(54,2000))#对偶变量
sum_resource=np.zeros(shape=(1,2000), dtype=np.float64)
sum_cost=np.zeros(shape=(1,2000), dtype=np.float64)
iteration_update = 0.01 #迭代步长
#W=np.zeros(shape=(54,54)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
W=np.loadtxt("double_stochastic_weight_1.txt") #双随机的网络拓扑矩阵W（对角线处非零）
iteration=[]#绘图横坐标
generator_a_values= np.loadtxt("generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("generator_b_values.txt")#每个agent的成本函数中的超参数a
generator_c_values= np.loadtxt("generator_c_values.txt")#每个agent的成本函数中的超参数a
A=np.loadtxt("Adjacency_Matrix_generator_zero.txt") #网络拓扑邻接矩阵（对角线处为0）
D=np.loadtxt("degree_generator.txt") #用户的度
neighbor=np.zeros(shape=(54,17))#定义矩阵存放54个用户的邻居
neighbor_help=[]#辅助求用户邻居的列表

# %%
#对偶变量的初始化 初始化一致
for i in range (0,54):
    dual_variable[i][0]=0
    
#资源量的初始化 资源量的初始化需要和对偶变量的初始值满足某种关系
for i in range (0,54):
    agent_resource_quantity[i][0]=6000/54

iteration.append(0)

#总资源量 初始化
sum=0
for i in range (0,54):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

#用户总成本初始化
sum=0
for i in range(0,54):
    sum=sum+(generator_c_values[i]*(agent_resource_quantity[i][0])*(agent_resource_quantity[i][0])+generator_b_values[i]*agent_resource_quantity[i][0]+generator_a_values[i])
sum_cost[0][0]=sum

#对用户邻居进行初始化
for i in range(0,54):
    for j in range(0,17):
        neighbor[i][j]=99 #先将矩阵中的所有数字设定为一个不可能的数字
#根据邻接矩阵求每个用户的邻居集合
for i in range(0,54):
    for j in range(0,54):
        if A[i][j]!=0:
            neighbor_help.append(j)
l=0
for i in range(0,54):
    g=0
    for j in range(l,l+int(D[i])):
        neighbor[i][g]=neighbor_help[j]  
        g=g+1
    l=l+int(D[i])

# %%
#DGD算法 
def DGD_CTM_determinitic_bias(D,neighbor,generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,dual_variable,iteration_update,W,iteration):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************DGD算法+无计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,54):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    for i in range(0,54):
        print("agent",(i+1),"的初始对偶变量为:",dual_variable[i][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,2000):#迭代次数
        iteration.append(k)
        
        #所有用户对偶变量的迭代 
        #阶段一：梯度下降
        dual_variable_intermediate=[] #存放当前迭代中54个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,54):
            #每个用户对对偶变量先进行一次梯度下降
            if i==48:
                dual_variable_intermediate.append(-24)
            else:
                dual_variable_intermediate.append(dual_variable[i][k-1]-iteration_update*((6000/54)-agent_resource_quantity[i][k-1]))             
        #阶段二：鲁棒聚合 CTM       
        for i in range(0,54):
            #先根据用户的度来判断其是否需要做CTM操作 
            if int(D[i])>3: 
            #if i==44 or i==47 or i==48:
                u_neighbor_help=[]
                sort_list=[] 
                mix_sum_dual=0
                for j in range(0,int(D[i])):
                    u_neighbor_help.append(neighbor[i][j])                               
                for j in range(0,int(D[i])):
                    sort_list.append(dual_variable_intermediate[int(u_neighbor_help[j])])
                sort_list.append(dual_variable_intermediate[i])
                sort_list.sort()
                #剔除一个最大的数据和一个最小的数据  
                del sort_list[-1]
                del sort_list[0]
                #剩下的数据进行平均操作     
                #用户基于TM鲁棒聚合后的值进行自身的对偶变量的更新 平均值
                for j in range(0,len(sort_list)):
                    mix_sum_dual=mix_sum_dual+sort_list[j]                      
                dual_variable[i][k]=(1/(len(sort_list)))*mix_sum_dual
            else:
                mix_sum_dual=0           
                for j in range(0,54):
                    mix_sum_dual=mix_sum_dual+W[i][j]*dual_variable_intermediate[j]
                dual_variable[i][k]=mix_sum_dual                    
        
        #用户资源申请量的迭代
        for i in range (0,54):
            agent_resource_quantity[i][k]=(-dual_variable[i][k]-generator_b_values[i])/(2*generator_c_values[i]) 

        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,54):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,54):
            sum2=sum2+(generator_a_values[i]+(generator_b_values[i]*agent_resource_quantity[i][k])+(generator_c_values[i]*agent_resource_quantity[i][k]*agent_resource_quantity[i][k]))
        sum_cost[0][k]=sum2
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%20==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,54):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            for i in range(0,54):
                print("agent",(i+1),"在",k,"次迭代中的对偶变量为:",dual_variable[i][k])   
            print("*************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=(1/(pow(k+1,1.3)))*(1/26.511) #递减步长
        iteration_update=(1/(pow(k+1,1.5)))*(1/18.8468) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
DGD_CTM_determinitic_bias(D,neighbor,generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,dual_variable,iteration_update,W,iteration)
# Out:
# ****************************DGD算法+无计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 111.11111111111111
# agent 2 的初始资源申请量为: 111.11111111111111
# agent 3 的初始资源申请量为: 111.11111111111111
# agent 4 的初始资源申请量为: 111.11111111111111
# agent 5 的初始资源申请量为: 111.11111111111111
# agent 6 的初始资源申请量为: 111.11111111111111
# agent 7 的初始资源申请量为: 111.11111111111111
# agent 8 的初始资源申请量为: 111.11111111111111
# agent 9 的初始资源申请量为: 111.11111111111111
# agent 10 的初始资源申请量为: 111.11111111111111
# agent 11 的初始资源申请量为: 111.11111111111111
# agent 12 的初始资源申请量为: 111.11111111111111
# agent 13 的初始资源申请量为: 111.11111111111111
# agent 14 的初始资源申请量为: 111.11111111111111
# agent 15 的初始资源申请量为: 111.11111111111111
# agent 16 的初始资源申请量为: 111.11111111111111
# agent 17 的初始资源申请量为: 111.11111111111111
# agent 18 的初始资源申请量为: 111.11111111111111
# agent 19 的初始资源申请量为: 111.11111111111111
# agent 20 的初始资源申请量为: 111.11111111111111
# agent 21 的初始资源申请量为: 111.11111111111111
# agent 22 的初始资源申请量为: 111.11111111111111
# agent 23 的初始资源申请量为: 111.11111111111111
# agent 24 的初始资源申请量为: 111.11111111111111
# agent 25 的初始资源申请量为: 111.11111111111111
# agent 26 的初始资源申请量为: 111.11111111111111
# agent 27 的初始资源申请量为: 111.11111111111111
# agent 28 的初始资源申请量为: 111.11111111111111
# agent 29 的初始资源申请量为: 111.11111111111111
# agent 30 的初始资源申请量为: 111.11111111111111
# agent 31 的初始资源申请量为: 111.11111111111111
# agent 32 的初始资源申请量为: 111.11111111111111
# agent 33 的初始资源申请量为: 111.11111111111111
# agent 34 的初始资源申请量为: 111.11111111111111
# agent 35 的初始资源申请量为: 111.11111111111111
# agent 36 的初始资源申请量为: 111.11111111111111
# agent 37 的初始资源申请量为: 111.11111111111111
# agent 38 的初始资源申请量为: 111.11111111111111
# agent 39 的初始资源申请量为: 111.11111111111111
# agent 40 的初始资源申请量为: 111.11111111111111
# agent 41 的初始资源申请量为: 111.11111111111111
# agent 42 的初始资源申请量为: 111.11111111111111
# agent 43 的初始资源申请量为: 111.11111111111111
# agent 44 的初始资源申请量为: 111.11111111111111
# agent 45 的初始资源申请量为: 111.11111111111111
# agent 46 的初始资源申请量为: 111.11111111111111
# agent 47 的初始资源申请量为: 111.11111111111111
# agent 48 的初始资源申请量为: 111.11111111111111
# agent 49 的初始资源申请量为: 111.11111111111111
# agent 50 的初始资源申请量为: 111.11111111111111
# agent 51 的初始资源申请量为: 111.11111111111111
# agent 52 的初始资源申请量为: 111.11111111111111
# agent 53 的初始资源申请量为: 111.11111111111111
# agent 54 的初始资源申请量为: 111.11111111111111
# *************************
# 初始资源申请量总和为: 6000.000000000006
# *************************
# 初始成本总和为: 139226.02283950621
# *************************
# agent 1 的初始对偶变量为: 0.0
# agent 2 的初始对偶变量为: 0.0
# agent 3 的初始对偶变量为: 0.0
# agent 4 的初始对偶变量为: 0.0
# agent 5 的初始对偶变量为: 0.0
# agent 6 的初始对偶变量为: 0.0
# agent 7 的初始对偶变量为: 0.0
# agent 8 的初始对偶变量为: 0.0
# agent 9 的初始对偶变量为: 0.0
# agent 10 的初始对偶变量为: 0.0
# agent 11 的初始对偶变量为: 0.0
# agent 12 的初始对偶变量为: 0.0
# agent 13 的初始对偶变量为: 0.0
# agent 14 的初始对偶变量为: 0.0
# agent 15 的初始对偶变量为: 0.0
# agent 16 的初始对偶变量为: 0.0
# agent 17 的初始对偶变量为: 0.0
# agent 18 的初始对偶变量为: 0.0
# agent 19 的初始对偶变量为: 0.0
# agent 20 的初始对偶变量为: 0.0
# agent 21 的初始对偶变量为: 0.0
# agent 22 的初始对偶变量为: 0.0
# agent 23 的初始对偶变量为: 0.0
# agent 24 的初始对偶变量为: 0.0
# agent 25 的初始对偶变量为: 0.0
# agent 26 的初始对偶变量为: 0.0
# agent 27 的初始对偶变量为: 0.0
# agent 28 的初始对偶变量为: 0.0
# agent 29 的初始对偶变量为: 0.0
# agent 30 的初始对偶变量为: 0.0
# agent 31 的初始对偶变量为: 0.0
# agent 32 的初始对偶变量为: 0.0
# agent 33 的初始对偶变量为: 0.0
# agent 34 的初始对偶变量为: 0.0
# agent 35 的初始对偶变量为: 0.0
# agent 36 的初始对偶变量为: 0.0
# agent 37 的初始对偶变量为: 0.0
# agent 38 的初始对偶变量为: 0.0
# agent 39 的初始对偶变量为: 0.0
# agent 40 的初始对偶变量为: 0.0
# agent 41 的初始对偶变量为: 0.0
# agent 42 的初始对偶变量为: 0.0
# agent 43 的初始对偶变量为: 0.0
# agent 44 的初始对偶变量为: 0.0
# agent 45 的初始对偶变量为: 0.0
# agent 46 的初始对偶变量为: 0.0
# agent 47 的初始对偶变量为: 0.0
# agent 48 的初始对偶变量为: 0.0
# agent 49 的初始对偶变量为: 0.0
# agent 50 的初始对偶变量为: 0.0
# agent 51 的初始对偶变量为: 0.0
# agent 52 的初始对偶变量为: 0.0
# agent 53 的初始对偶变量为: 0.0
# agent 54 的初始对偶变量为: 0.0
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 19 次迭代中的结果：
# agent 1 在 19 次迭代中的资源申请量为: -66.369485040752
# agent 2 在 19 次迭代中的资源申请量为: -66.369485040752
# agent 3 在 19 次迭代中的资源申请量为: -67.37614627171416
# agent 4 在 19 次迭代中的资源申请量为: 164.90894461645243
# agent 5 在 19 次迭代中的资源申请量为: 184.51021513226647
# agent 6 在 19 次迭代中的资源申请量为: -67.06000904980553
# agent 7 在 19 次迭代中的资源申请量为: -34.823436952234744
# agent 8 在 19 次迭代中的资源申请量为: -65.35679087663284
# agent 9 在 19 次迭代中的资源申请量为: -63.04422568344047
# agent 10 在 19 次迭代中的资源申请量为: 198.51737149503577
# agent 11 在 19 次迭代中的资源申请量为: 1018.474449704932
# agent 12 在 19 次迭代中的资源申请量为: -65.09217670323444
# agent 13 在 19 次迭代中的资源申请量为: -66.96813631850658
# agent 14 在 19 次迭代中的资源申请量为: -25.685820531124307
# agent 15 在 19 次迭代中的资源申请量为: -67.71219400215598
# agent 16 在 19 次迭代中的资源申请量为: -37.0879411498802
# agent 17 在 19 次迭代中的资源申请量为: -67.62496057797524
# agent 18 在 19 次迭代中的资源申请量为: -71.2319394091798
# agent 19 在 19 次迭代中的资源申请量为: -48.16394398394319
# agent 20 在 19 次迭代中的资源申请量为: 765.3609780741301
# agent 21 在 19 次迭代中的资源申请量为: 611.8146705304309
# agent 22 在 19 次迭代中的资源申请量为: -102.92674241601233
# agent 23 在 19 次迭代中的资源申请量为: -99.69398250440901
# agent 24 在 19 次迭代中的资源申请量为: 225.34889618992082
# agent 25 在 19 次迭代中的资源申请量为: 237.72757575770987
# agent 26 在 19 次迭代中的资源申请量为: -100.67114247854377
# agent 27 在 19 次迭代中的资源申请量为: 394.62119970879695
# agent 28 在 19 次迭代中的资源申请量为: 335.47123824609145
# agent 29 在 19 次迭代中的资源申请量为: 207.56672330749578
# agent 30 在 19 次迭代中的资源申请量为: 25.837083832676615
# agent 31 在 19 次迭代中的资源申请量为: -60.0837546553179
# agent 32 在 19 次迭代中的资源申请量为: -59.42208643876946
# agent 33 在 19 次迭代中的资源申请量为: -350.60530601406606
# agent 34 在 19 次迭代中的资源申请量为: 1.2162991554612312
# agent 35 在 19 次迭代中的资源申请量为: -1.361690827651335
# agent 36 在 19 次迭代中的资源申请量为: 221.97776272439367
# agent 37 在 19 次迭代中的资源申请量为: -3.2607601217019
# agent 38 在 19 次迭代中的资源申请量为: -69.23760964891541
# agent 39 在 19 次迭代中的资源申请量为: 814.0343719355541
# agent 40 在 19 次迭代中的资源申请量为: 230.10103621741848
# agent 41 在 19 次迭代中的资源申请量为: -336.50253581733773
# agent 42 在 19 次迭代中的资源申请量为: -215.40269842975218
# agent 43 在 19 次迭代中的资源申请量为: 228.87570525662406
# agent 44 在 19 次迭代中的资源申请量为: 246.20925588905544
# agent 45 在 19 次迭代中的资源申请量为: 330.46464257174426
# agent 46 在 19 次迭代中的资源申请量为: -285.19739194261166
# agent 47 在 19 次迭代中的资源申请量为: 135.20520357882813
# agent 48 在 19 次迭代中的资源申请量为: 148.36886456421644
# agent 49 在 19 次迭代中的资源申请量为: -267.11555217049545
# agent 50 在 19 次迭代中的资源申请量为: -62.84195297991679
# agent 51 在 19 次迭代中的资源申请量为: 151.98136699267963
# agent 52 在 19 次迭代中的资源申请量为: 151.98136699267963
# agent 53 在 19 次迭代中的资源申请量为: -36.6166327694703
# agent 54 在 19 次迭代中的资源申请量为: -281.5854418555662
# 资源申请量总和为: 3818.0832498127256
# ****************************************************************************
# 成本总和为: 28507.693677485044
# ****************************************************************************
# agent 1 在 19 次迭代中的对偶变量为: -16.996805127212188
# agent 2 在 19 次迭代中的对偶变量为: -16.996805127212188
# agent 3 在 19 次迭代中的对偶变量为: -16.856551044547153
# agent 4 在 19 次迭代中的对偶变量为: -16.47426954540784
# agent 5 在 19 次迭代中的对偶变量为: -16.900597179126795
# agent 6 在 19 次迭代中的对偶变量为: -16.900597179126795
# agent 7 在 19 次迭代中的对偶变量为: -16.92852001402279
# agent 8 在 19 次迭代中的对偶变量为: -17.13789975432225
# agent 9 在 19 次迭代中的对偶变量为: -17.460100212428973
# agent 10 在 19 次迭代中的对偶变量为: -17.205252830017027
# agent 11 在 19 次迭代中的对偶变量为: -16.87084669822959
# agent 12 在 19 次迭代中的对偶变量为: -17.174767388645158
# agent 13 在 19 次迭代中的对偶变量为: -16.913397439287753
# agent 14 在 19 次迭代中的对偶变量为: -17.162442994403218
# agent 15 在 19 次迭代中的对偶变量为: -16.809730858455616
# agent 16 在 19 次迭代中的对偶变量为: -16.870548706563067
# agent 17 在 19 次迭代中的对偶变量为: -16.82188474251302
# agent 18 在 19 次迭代中的对偶变量为: -16.319338809876616
# agent 19 在 19 次迭代中的对偶变量为: -16.587003034011055
# agent 20 在 19 次迭代中的对偶变量为: -16.005163416711973
# agent 21 在 19 次迭代中的对偶变量为: -15.26783404788713
# agent 22 在 19 次迭代中的对偶变量为: -15.185075394150084
# agent 23 在 19 次迭代中的对偶变量为: -15.26783404788713
# agent 24 在 19 次迭代中的对偶变量为: -15.273070286471302
# agent 25 在 19 次迭代中的对偶变量为: -15.382002666667846
# agent 26 在 19 次迭代中的对偶变量为: -15.24281875254928
# agent 27 在 19 次迭代中的对偶变量为: -16.69717700983232
# agent 28 在 19 次迭代中的对偶变量为: -15.444380826052218
# agent 29 在 19 次迭代中的对偶变量为: -17.402076231938032
# agent 30 在 19 次迭代中的对偶变量为: -17.843832801696017
# agent 31 在 19 次迭代中的对偶变量为: -17.87257079889318
# agent 32 在 19 次迭代中的对偶变量为: -17.964758384832006
# agent 33 在 19 次迭代中的对偶变量为: -17.851137258379808
# agent 34 在 19 次迭代中的对偶变量为: -17.851137258379808
# agent 35 在 19 次迭代中的对偶变量为: -17.785140714812126
# agent 36 在 19 次迭代中的对偶变量为: -17.71551633925556
# agent 37 在 19 次迭代中的对偶变量为: -17.73652454088443
# agent 38 在 19 次迭代中的对偶变量为: -16.597200798055212
# agent 39 在 19 次迭代中的对偶变量为: -15.644206231613325
# agent 40 在 19 次迭代中的对偶变量为: -17.89219753772885
# agent 41 在 19 次迭代中的对偶变量为: -18.64941046259542
# agent 42 在 19 次迭代中的对偶变量为: -18.731608051095204
# agent 43 在 19 次迭代中的对偶变量为: -17.865546589331572
# agent 44 在 19 次迭代中的对偶变量为: -18.242551315586955
# agent 45 在 19 次迭代中的对偶变量为: -20.075105975935436
# agent 46 在 19 次迭代中的对偶变量为: -21.553486826480412
# agent 47 在 19 次迭代中的对偶变量为: -21.281253211618
# agent 48 在 19 次迭代中的对偶变量为: -21.61824293284394
# agent 49 在 19 次迭代中的对偶变量为: -22.57699128494128
# agent 50 在 19 次迭代中的对偶变量为: -21.713865503148586
# agent 51 在 19 次迭代中的对偶变量为: -21.7107229950126
# agent 52 在 19 次迭代中的对偶变量为: -21.7107229950126
# agent 53 在 19 次迭代中的对偶变量为: -16.88261420110156
# agent 54 在 19 次迭代中的对偶变量为: -17.43786778260739
# *************************
# 迭代步长为: 0.0006406664425248283
# ****************************************************************************
# 39 次迭代中的结果：
# agent 1 在 39 次迭代中的资源申请量为: -64.38971961163007
# agent 2 在 39 次迭代中的资源申请量为: -64.38971961163007
# agent 3 在 39 次迭代中的资源申请量为: -64.75657905499828
# agent 4 在 39 次迭代中的资源申请量为: 193.86500927923154
# agent 5 在 39 次迭代中的资源申请量为: 199.89297146130622
# agent 6 在 39 次迭代中的资源申请量为: -64.658627038145
# agent 7 在 39 次迭代中的资源申请量为: -22.428268038272996
# agent 8 在 39 次迭代中的资源申请量为: -63.87045209745032
# agent 9 在 39 次迭代中的资源申请量为: -62.0581000213922
# agent 10 在 39 次迭代中的资源申请量为: 206.45639418374319
# agent 11 在 39 次迭代中的资源申请量为: 1077.3565283419293
# agent 12 在 39 次迭代中的资源申请量为: -63.735774829728435
# agent 13 在 39 次迭代中的资源申请量为: -64.60799620984609
# agent 14 在 39 次迭代中的资源申请量为: -18.09776154208964
# agent 15 在 39 次迭代中的资源申请量为: -64.88574648041346
# agent 16 在 39 次迭代中的资源申请量为: -23.299302716756063
# agent 17 在 39 次迭代中的资源申请量为: -64.89934620873525
# agent 18 在 39 次迭代中的资源申请量为: -67.19500602911644
# agent 19 在 39 次迭代中的资源申请量为: -26.60676487880792
# agent 20 在 39 次迭代中的资源申请量为: 900.1029932804412
# agent 21 在 39 次迭代中的资源申请量为: 741.4451951772564
# agent 22 在 39 次迭代中的资源申请量为: -77.1889962324377
# agent 23 在 39 次迭代中的资源申请量为: -75.3781317483912
# agent 24 在 39 次迭代中的资源申请量为: 306.08481884588684
# agent 25 在 39 次迭代中的资源申请量为: 328.6646541395812
# agent 26 在 39 次迭代中的资源申请量为: -65.93897138966561
# agent 27 在 39 次迭代中的资源申请量为: 415.98987084235023
# agent 28 在 39 次迭代中的资源申请量为: 378.09439429384645
# agent 29 在 39 次迭代中的资源申请量为: 224.25333937072796
# agent 30 在 39 次迭代中的资源申请量为: 27.620271295776828
# agent 31 在 39 次迭代中的资源申请量为: -59.506840328087456
# agent 32 在 39 次迭代中的资源申请量为: -58.87458304556374
# agent 33 在 39 次迭代中的资源申请量为: -346.60064296857337
# agent 34 在 39 次迭代中的资源申请量为: 10.070984586206116
# agent 35 在 39 次迭代中的资源申请量为: 10.512241693285684
# agent 36 在 39 次迭代中的资源申请量为: 239.8303086715554
# agent 37 在 39 次迭代中的资源申请量为: 11.904409786477194
# agent 38 在 39 次迭代中的资源申请量为: -62.58891815143407
# agent 39 在 39 次迭代中的资源申请量为: 1054.9255396061978
# agent 40 在 39 次迭代中的资源申请量为: 237.17931966899513
# agent 41 在 39 次迭代中的资源申请量为: -342.67356289492005
# agent 42 在 39 次迭代中的资源申请量为: -233.8125932341621
# agent 43 在 39 次迭代中的资源申请量为: 244.7242374938739
# agent 44 在 39 次迭代中的资源申请量为: 266.07782947414194
# agent 45 在 39 次迭代中的资源申请量为: 332.704480647634
# agent 46 在 39 次迭代中的资源申请量为: -289.7854988964099
# agent 47 在 39 次迭代中的资源申请量为: 127.72334719968636
# agent 48 在 39 次迭代中的资源申请量为: 138.66929801729736
# agent 49 在 39 次迭代中的资源申请量为: -267.53360738973595
# agent 50 在 39 次迭代中的资源申请量为: -71.7006703725015
# agent 51 在 39 次迭代中的资源申请量为: 148.33967693429622
# agent 52 在 39 次迭代中的资源申请量为: 148.33967693429622
# agent 53 在 39 次迭代中的资源申请量为: -23.110855927006845
# agent 54 在 39 次迭代中的资源申请量为: -263.9767558615188
# 资源申请量总和为: 4932.277998416602
# ****************************************************************************
# 成本总和为: 46562.04548418035
# ****************************************************************************
# agent 1 在 39 次迭代中的对偶变量为: -17.27263792539003
# agent 2 在 39 次迭代中的对偶变量为: -17.27263792539003
# agent 3 在 39 次迭代中的对偶变量为: -17.22152486658331
# agent 4 在 39 次迭代中的对偶变量为: -17.104063951823285
# agent 5 在 39 次迭代中的对偶变量为: -17.23517212928341
# agent 6 在 39 次迭代中的对偶变量为: -17.23517212928341
# agent 7 在 39 次迭代中的对偶变量为: -17.24583633822021
# agent 8 在 39 次迭代中的对偶变量为: -17.344985391070637
# agent 9 在 39 次迭代中的对偶变量为: -17.59749315641951
# agent 10 在 39 次迭代中的对偶变量为: -17.377926573496413
# agent 11 在 39 次迭代中的对偶变量为: -17.224139170051576
# agent 12 在 39 次迭代中的对偶变量为: -17.363749436073256
# agent 13 在 39 次迭代中的对偶变量为: -17.242226320066983
# agent 14 在 39 次迭代中的对偶变量为: -17.356697304522505
# agent 15 在 39 次迭代中的对偶变量为: -17.203528485869914
# agent 16 在 39 次迭代中的对偶变量为: -17.223537850451045
# agent 17 在 39 次迭代中的对偶变量为: -17.201633690121753
# agent 18 在 39 次迭代中的对偶变量为: -16.881788589987323
# agent 19 在 39 次迭代中的对偶变量为: -17.138866819102518
# agent 20 在 39 次迭代中的对偶变量为: -16.65219457373268
# agent 21 在 39 次迭代中的对偶变量为: -15.890319827241186
# agent 22 在 39 次迭代中的对偶变量为: -15.843961696449595
# agent 23 在 39 次迭代中的对偶变量为: -15.890319827241186
# agent 24 在 39 次迭代中的对偶变量为: -15.983546405843803
# agent 25 在 39 次迭代中的对偶变量为: -16.182248956428314
# agent 26 在 39 次迭代中的对偶变量为: -16.13196233242456
# agent 27 在 39 次迭代中的对偶变量为: -17.14976546444098
# agent 28 在 39 次迭代中的对偶变量为: -16.347139271143668
# agent 29 在 39 次迭代中的对偶变量为: -17.765010131313332
# agent 30 在 39 次迭代中的对偶变量为: -18.00761143743192
# agent 31 在 39 次迭代中的对偶变量为: -17.952949964448887
# agent 32 在 39 次迭代中的对偶变量为: -18.041039842593786
# agent 33 在 39 次迭代中的对偶变量为: -18.077817205406877
# agent 34 在 39 次迭代中的对偶变量为: -18.077817205406877
# agent 35 在 39 次迭代中的对偶变量为: -18.089113387348114
# agent 36 在 39 次迭代中的对偶变量为: -18.10380921360633
# agent 37 在 39 次迭代中的对偶变量为: -18.124752890533816
# agent 38 在 39 次迭代中的对偶变量为: -17.523536389633296
# agent 39 在 39 次迭代中的对偶变量为: -17.089553237637187
# agent 40 在 39 次迭代中的对偶变量为: -18.046150202800643
# agent 41 在 39 次迭代中的对偶变量为: -18.300105645895947
# agent 42 在 39 次迭代中的对偶变量为: -18.3717314274586
# agent 43 在 39 次迭代中的对偶变量为: -18.210252165491756
# agent 44 在 39 次迭代中的对偶变量为: -18.674692791062586
# agent 45 在 39 次迭代中的对偶变量为: -20.12382245408604
# agent 46 在 39 次迭代中的对偶变量为: -21.29378162046762
# agent 47 在 39 次迭代中的对偶变量为: -21.08971768831197
# agent 48 在 39 次迭代中的对偶变量为: -21.369934029242813
# agent 49 在 39 次迭代中的对偶变量为: -22.553327687311388
# agent 50 在 39 次迭代中的对偶变量为: -21.54069529555834
# agent 51 在 39 次迭代中的对偶变量为: -21.617495729517984
# agent 52 在 39 次迭代中的对偶变量为: -21.617495729517984
# agent 53 在 39 次迭代中的对偶变量为: -17.228362088268625
# agent 54 在 39 次迭代中的对偶变量为: -17.78208237641903
# *************************
# 迭代步长为: 0.000217853964469636
# ****************************************************************************
# 59 次迭代中的结果：
# agent 1 在 59 次迭代中的资源申请量为: -63.58910752917668
# agent 2 在 59 次迭代中的资源申请量为: -63.58910752917668
# agent 3 在 59 次迭代中的资源申请量为: -63.78407984894636
# agent 4 在 59 次迭代中的资源申请量为: 202.6394471430866
# agent 5 在 59 次迭代中的资源申请量为: 205.82707996107277
# agent 6 在 59 次迭代中的资源申请量为: -63.73226110594339
# agent 7 在 59 次迭代中的资源申请量为: -17.5865854162581
# agent 8 在 59 次迭代中的资源申请量为: -63.35313385328827
# agent 9 在 59 次迭代中的资源申请量为: -62.08357751113838
# agent 10 在 59 次迭代中的资源申请量为: 208.9872546254966
# agent 11 在 59 次迭代中的资源申请量为: 1099.7442614979543
# agent 12 在 59 次迭代中的资源申请量为: -63.28738181544683
# agent 13 在 59 次迭代中的资源申请量为: -63.7097075414753
# agent 14 在 59 次迭代中的资源申请量为: -15.508010117568915
# agent 15 在 59 次迭代中的资源申请量为: -63.84220671129109
# agent 16 在 59 次迭代中的资源申请量为: -18.041453023128206
# agent 17 在 59 次迭代中的资源申请量为: -63.86244169362957
# agent 18 在 59 次迭代中的资源申请量为: -65.43026840509722
# agent 19 在 59 次迭代中的资源申请量为: -18.97344675380247
# agent 20 在 59 次迭代中的资源申请量为: 965.6066665167448
# agent 21 在 59 次迭代中的资源申请量为: 843.8981923939674
# agent 22 在 59 次迭代中的资源申请量为: -57.41672293027494
# agent 23 在 59 次迭代中的资源申请量为: -56.160190629850334
# agent 24 在 59 次迭代中的资源申请量为: 360.9657470785606
# agent 25 在 59 次迭代中的资源申请量为: 379.64441324680666
# agent 26 在 59 次迭代中的资源申请量为: -47.51026972568198
# agent 27 在 59 次迭代中的资源申请量为: 424.07886133085816
# agent 28 在 59 次迭代中的资源申请量为: 397.9794020560094
# agent 29 在 59 次迭代中的资源申请量为: 226.18971549985008
# agent 30 在 59 次迭代中的资源申请量为: 27.04831703414369
# agent 31 在 59 次迭代中的资源申请量为: -60.111230177639335
# agent 32 在 59 次迭代中的资源申请量为: -59.6037059172348
# agent 33 在 59 次迭代中的资源申请量为: -347.50653828738814
# agent 34 在 59 次迭代中的资源申请量为: 8.067965108620456
# agent 35 在 59 次迭代中的资源申请量为: 9.078209840319568
# agent 36 在 59 次迭代中的资源申请量为: 240.15559992394137
# agent 37 在 59 次迭代中的资源申请量为: 11.677862567145146
# agent 38 在 59 次迭代中的资源申请量为: -60.38228578106825
# agent 39 在 59 次迭代中的资源申请量为: 1140.489075594539
# agent 40 在 59 次迭代中的资源申请量为: 240.64921755835184
# agent 41 在 59 次迭代中的资源申请量为: -343.3218633776287
# agent 42 在 59 次迭代中的资源申请量为: -237.6096703481171
# agent 43 在 59 次迭代中的资源申请量为: 243.77194174595647
# agent 44 在 59 次迭代中的资源申请量为: 264.5805581255564
# agent 45 在 59 次迭代中的资源申请量为: 322.2367474825517
# agent 46 在 59 次迭代中的资源申请量为: -296.5617289762647
# agent 47 在 59 次迭代中的资源申请量为: 113.93407814937444
# agent 48 在 59 次迭代中的资源申请量为: 123.43897574678894
# agent 49 在 59 次迭代中的资源申请量为: -270.00163442500406
# agent 50 在 59 次迭代中的资源申请量为: -91.9038043219645
# agent 51 在 59 次迭代中的资源申请量为: 133.28142081488068
# agent 52 在 59 次迭代中的资源申请量为: 133.28142081488068
# agent 53 在 59 次迭代中的资源申请量为: -17.944012593733433
# agent 54 在 59 次迭代中的资源申请量为: -261.32506060662627
# 资源申请量总和为: 5349.520944903614
# ****************************************************************************
# 成本总和为: 53060.470853652376
# ****************************************************************************
# agent 1 在 59 次迭代中的对偶变量为: -17.38418400438993
# agent 2 在 59 次迭代中的对偶变量为: -17.38418400438993
# agent 3 在 59 次迭代中的对偶变量为: -17.3570192909657
# agent 4 在 59 次迭代中的对偶变量为: -17.294907975362133
# agent 5 在 59 次迭代中的对偶变量为: -17.364238989153332
# agent 6 在 59 次迭代中的对偶变量为: -17.364238989153332
# agent 7 在 59 次迭代中的对偶变量为: -17.369783413343793
# agent 8 在 59 次迭代中的对偶变量为: -17.417061272756758
# agent 9 在 59 次迭代中的对偶变量为: -17.593943479683134
# agent 10 在 59 次迭代中的对偶变量为: -17.43297278810455
# agent 11 在 59 次迭代中的对偶变量为: -17.358465568987725
# agent 12 在 59 次迭代中的对偶变量为: -17.426222241181055
# agent 13 在 59 次迭代中的对偶变量为: -17.367381287076412
# agent 14 在 59 次迭代中的对偶变量为: -17.422994940990236
# agent 15 在 59 次迭代中的对偶变量为: -17.348920707742657
# agent 16 在 59 次迭代中的对偶变量为: -17.358138802607918
# agent 17 在 59 次迭代中的对偶变量为: -17.346101448593366
# agent 18 在 59 次迭代中的对偶变量为: -17.127662424191424
# agent 19 在 59 次迭代中的对偶变量为: -17.334279763102657
# agent 20 在 59 次迭代中的对偶变量为: -16.96674321261341
# agent 21 在 59 次迭代中的对偶变量为: -16.38229911987583
# agent 22 在 59 次迭代中的对偶变量为: -16.35013189298496
# agent 23 在 59 次迭代中的对偶变量为: -16.38229911987583
# agent 24 在 59 次迭代中的对偶变量为: -16.466498574291332
# agent 25 在 59 次迭代中的对偶变量为: -16.630870836571898
# agent 26 在 59 次迭代中的对偶变量为: -16.60373709502254
# agent 27 在 59 次迭代中的对偶变量为: -17.321090282987576
# agent 28 在 59 次迭代中的对偶变量为: -16.76830373554628
# agent 29 在 59 次迭代中的对偶变量为: -17.80712631212174
# agent 30 在 59 次迭代中的对偶变量为: -17.955079726317962
# agent 31 在 59 次迭代中的对偶变量为: -17.86874274427022
# agent 32 在 59 次迭代中的对偶变量为: -17.939454069375344
# agent 33 在 59 次迭代中的对偶变量为: -18.026539906780684
# agent 34 在 59 次迭代中的对偶变量为: -18.026539906780684
# agent 35 在 59 次迭代中的对偶变量为: -18.05240217191218
# agent 36 在 59 次迭代中的对偶变量为: -18.110884298345724
# agent 37 在 59 次迭代中的对偶变量为: -18.118953281718916
# agent 38 在 59 次迭代中的对偶变量为: -17.830977651266885
# agent 39 在 59 次迭代中的对偶变量为: -17.602934453567233
# agent 40 在 59 次迭代中的对偶变量为: -18.12162048189415
# agent 41 在 59 次迭代中的对偶变量为: -18.26340924537271
# agent 42 在 59 次迭代中的对偶变量为: -18.297506164035006
# agent 43 在 59 次迭代中的对偶变量为: -18.189539732974552
# agent 44 在 59 次迭代中的对偶变量为: -18.64212713923085
# agent 45 在 59 次迭代中的对偶变量为: -19.8961492577455
# agent 46 在 59 次迭代中的对偶变量为: -20.910219893027516
# agent 47 在 59 次迭代中的对偶变量为: -20.736712400623986
# agent 48 在 59 次迭代中的对偶变量为: -20.980037779117797
# agent 49 在 59 次迭代中的对偶变量为: -22.413627485007073
# agent 50 在 59 次迭代中的对偶变量为: -21.145764433114238
# agent 51 在 59 次迭代中的对偶变量为: -21.232004372860946
# agent 52 在 59 次迭代中的对偶变量为: -21.232004372860946
# agent 53 在 59 次迭代中的对偶变量为: -17.360633277600424
# agent 54 在 59 次迭代中的对偶变量为: -17.83391771526167
# *************************
# 迭代步长为: 0.00011708044397666381
# ****************************************************************************
# 79 次迭代中的结果：
# agent 1 在 79 次迭代中的资源申请量为: -63.0759967907562
# agent 2 在 79 次迭代中的资源申请量为: -63.0759967907562
# agent 3 在 79 次迭代中的资源申请量为: -63.20006810896801
# agent 4 在 79 次迭代中的资源申请量为: 207.34359647985914
# agent 5 在 79 次迭代中的资源申请量为: 209.45574116802618
# agent 6 在 79 次迭代中的资源申请量为: -63.165795541359344
# agent 7 在 79 次迭代中的资源申请量为: -14.589366328799091
# agent 8 在 79 次迭代中的资源申请量为: -62.949818845220136
# agent 9 在 79 次迭代中的资源申请量为: -62.030970619151
# agent 10 在 79 次迭代中的资源申请量为: 211.2590698246674
# agent 11 在 79 次迭代中的资源申请量为: 1113.262580414068
# agent 12 在 79 次迭代中的资源申请量为: -62.911595795457394
# agent 13 在 79 次迭代中的资源申请量为: -63.15404362011045
# agent 14 在 79 次迭代中的资源申请量为: -13.404213233836199
# agent 15 在 79 次迭代中的资源申请量为: -63.23131585669862
# agent 16 在 79 次迭代中的资源申请量为: -14.86866505210363
# agent 17 在 79 次迭代中的资源申请量为: -63.24966220281162
# agent 18 在 79 次迭代中的资源申请量为: -64.36191700558467
# agent 19 在 79 次迭代中的资源申请量为: -15.10623402678532
# agent 20 在 79 次迭代中的资源申请量为: 1006.2762666916566
# agent 21 在 79 次迭代中的资源申请量为: 916.6278590466493
# agent 22 在 79 次迭代中的资源申请量为: -43.4266798076191
# agent 23 在 79 次迭代中的资源申请量为: -42.517696127265246
# agent 24 在 79 次迭代中的资源申请量为: 398.43991177390234
# agent 25 在 79 次迭代中的资源申请量为: 412.48917136557475
# agent 26 在 79 次迭代中的资源申请量为: -35.844882247459545
# agent 27 在 79 次迭代中的资源申请量为: 428.6689199688158
# agent 28 在 79 次迭代中的资源申请量为: 410.03611210583944
# agent 29 在 79 次迭代中的资源申请量为: 225.20139112567847
# agent 30 在 79 次迭代中的资源申请量为: 26.303534749417526
# agent 31 在 79 次迭代中的资源申请量为: -60.545529919072344
# agent 32 在 79 次迭代中的资源申请量为: -60.15804987443374
# agent 33 在 79 次迭代中的资源申请量为: -348.9175815919658
# agent 34 在 79 次迭代中的资源申请量为: 4.948016076889439
# agent 35 在 79 次迭代中的资源申请量为: 6.066175326917139
# agent 36 在 79 次迭代中的资源申请量为: 237.64814736223025
# agent 37 在 79 次迭代中的资源申请量为: 9.293122218164001
# agent 38 在 79 次迭代中的资源申请量为: -59.84916403894898
# agent 39 在 79 次迭代中的资源申请量为: 1167.6520862553448
# agent 40 在 79 次迭代中的资源申请量为: 239.63431223371515
# agent 41 在 79 次迭代中的资源申请量为: -344.5346474142565
# agent 42 在 79 次迭代中的资源申请量为: -241.85255238369336
# agent 43 在 79 次迭代中的资源申请量为: 241.17665150017075
# agent 44 在 79 次迭代中的资源申请量为: 259.8696263197844
# agent 45 在 79 次迭代中的资源申请量为: 310.30172496818295
# agent 46 在 79 次迭代中的资源申请量为: -303.322734423178
# agent 47 在 79 次迭代中的资源申请量为: 99.84629576748532
# agent 48 在 79 次迭代中的资源申请量为: 108.27902276112272
# agent 49 在 79 次迭代中的资源申请量为: -272.66438291617334
# agent 50 在 79 次迭代中的资源申请量为: -112.19973709641744
# agent 51 在 79 次迭代中的资源申请量为: 117.64957980495136
# agent 52 在 79 次迭代中的资源申请量为: 117.64957980495136
# agent 53 在 79 次迭代中的资源申请量为: -14.808667174538297
# agent 54 在 79 次迭代中的资源申请量为: -261.94775893963686
# 资源申请量总和为: 5530.412771341008
# ****************************************************************************
# 成本总和为: 55686.52980049087
# ****************************************************************************
# agent 1 在 79 次迭代中的对偶变量为: -17.455673671131102
# agent 2 在 79 次迭代中的对偶变量为: -17.455673671131102
# agent 3 在 79 次迭代中的对偶变量为: -17.438387310649922
# agent 4 在 79 次迭代中的对偶变量为: -17.397223223436935
# agent 5 在 79 次迭代中的对偶变量为: -17.44316237040457
# agent 6 在 79 次迭代中的对偶变量为: -17.44316237040457
# agent 7 在 79 次迭代中的对偶变量为: -17.446512221982744
# agent 8 在 79 次迭代中的对偶变量为: -17.47325353957086
# agent 9 在 79 次迭代中的对偶变量为: -17.601272987516168
# agent 10 在 79 次迭代中的对偶变量为: -17.482384768686515
# agent 11 在 79 次迭代中的对偶变量为: -17.439575482484408
# agent 12 在 79 次迭代中的对偶变量为: -17.478579004202103
# agent 13 在 79 次迭代中的对偶变量为: -17.44479971858449
# agent 14 在 79 次迭代中的对偶变量为: -17.476852141213794
# agent 15 在 79 次迭代中的对偶变量为: -17.434033686949608
# agent 16 在 79 次迭代中的对偶变量为: -17.439362174666147
# agent 17 在 79 次迭代中的对偶变量为: -17.431477563931068
# agent 18 在 79 次迭代中的对偶变量为: -17.27651155127991
# agent 19 在 79 次迭代中的对偶变量为: -17.433280408914296
# agent 20 在 79 次迭代中的对偶变量为: -17.162038632653335
# agent 21 在 79 次迭代中的对偶变量为: -16.73154697914201
# agent 22 在 79 次迭代中的对偶变量为: -16.70827699692495
# agent 23 在 79 次迭代中的对偶变量为: -16.73154697914201
# agent 24 在 79 次迭代中的对偶变量为: -16.79627122361034
# agent 25 在 79 次迭代中的对偶变量为: -16.919904708017057
# agent 26 在 79 次迭代中的对偶变量为: -16.902371014465036
# agent 27 在 79 次迭代中的对偶变量为: -17.41830772493952
# agent 28 在 79 次迭代中的对偶变量为: -17.02366485440168
# agent 29 在 79 次迭代中的对偶变量为: -17.785630256983506
# agent 30 在 79 次迭代中的对偶变量为: -17.886674452595003
# agent 31 在 79 次迭代中的对偶变量为: -17.808233498495326
# agent 32 在 79 次迭代中的对偶变量为: -17.862219543194644
# agent 33 在 79 次迭代中的对偶变量为: -17.94666921156837
# agent 34 在 79 次迭代中的对偶变量为: -17.94666921156837
# agent 35 在 79 次迭代中的对偶变量为: -17.97529408836908
# agent 36 在 79 次迭代中的对偶变量为: -18.056347205128507
# agent 37 在 79 次迭代中的对偶变量为: -18.057903928785
# agent 38 在 79 次迭代中的对偶变量为: -17.905255371109394
# agent 39 在 79 次迭代中的对偶变量为: -17.76591251753207
# agent 40 在 79 次迭代中的对偶变量为: -18.099546291083303
# agent 41 在 79 次迭代中的对偶变量为: -18.194760817763427
# agent 42 在 79 次迭代中的对偶变量为: -18.21456630600356
# agent 43 在 79 次迭代中的对偶变量为: -18.133092170128712
# agent 44 在 79 次迭代中的对偶变量为: -18.53966437245531
# agent 45 在 79 次迭代中的对偶变量为: -19.63656251805798
# agent 46 在 79 次迭代中的对偶变量为: -20.527519940710434
# agent 47 在 79 次迭代中的对偶变量为: -20.376065171647625
# agent 48 在 79 次迭代中的对偶变量为: -20.591942982684742
# agent 49 在 79 次迭代中的对偶变量为: -22.262905269412926
# agent 50 在 79 次迭代中的对偶变量为: -20.74901953923923
# agent 51 在 79 次迭代中的对偶变量为: -20.831829243006755
# agent 52 在 79 次迭代中的对偶变量为: -20.831829243006755
# agent 53 在 79 次迭代中的对偶变量为: -17.44089812033182
# agent 54 在 79 次迭代中的对偶变量为: -17.82174520824798
# *************************
# 迭代步长为: 7.556518347445504e-05
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: -62.69913950362856
# agent 2 在 99 次迭代中的资源申请量为: -62.69913950362856
# agent 3 在 99 次迭代中的资源申请量为: -62.78664740652531
# agent 4 在 99 次迭代中的资源申请量为: 210.49496441738185
# agent 5 在 99 次迭代中的资源申请量为: 212.04534153723077
# agent 6 在 99 次迭代中的资源申请量为: -62.761536407886766
# agent 7 在 99 次迭代中的资源申请量为: -12.432605460863249
# agent 8 在 99 次迭代中的资源申请量为: -62.62263973914374
# agent 9 在 99 次迭代中的资源申请量为: -61.946291957107626
# agent 10 在 99 次迭代中的资源申请量为: 213.20766611152465
# agent 11 在 99 次迭代中的资源申请量为: 1122.8353358307415
# agent 12 在 99 次迭代中的资源申请量为: -62.597495272764405
# agent 13 在 99 次迭代中的资源申请量为: -62.754589077838304
# agent 14 在 99 次迭代中的资源申请量为: -11.66815625955317
# agent 15 在 99 次迭代中的资源申请量为: -62.80644271295948
# agent 16 在 99 次迭代中的资源申请量为: -12.62287304002546
# agent 17 在 99 次迭代中的资源申请量为: -62.821187155452414
# agent 18 在 99 次迭代中的资源申请量为: -63.63808836457563
# agent 19 在 99 次迭代中的资源申请量为: -12.677541391117458
# agent 20 在 99 次迭代中的资源申请量为: 1033.669421412634
# agent 21 在 99 次迭代中的资源申请量为: 967.1230147480646
# agent 22 在 99 次迭代中的资源申请量为: -33.72619085287409
# agent 23 在 99 次迭代中的资源申请量为: -33.04590949921068
# agent 24 在 99 次迭代中的资源申请量为: 424.16473053112827
# agent 25 在 99 次迭代中的资源申请量为: 434.65621027917274
# agent 26 在 99 次迭代中的资源申请量为: -28.02729278279556
# agent 27 在 99 次迭代中的资源申请量为: 431.75058567144265
# agent 28 在 99 次迭代中的资源申请量为: 418.0167042069791
# agent 29 在 99 次迭代中的资源申请量为: 223.97271036659367
# agent 30 在 99 次迭代中的资源申请量为: 25.66902784924452
# agent 31 在 99 次迭代中的资源申请量为: -60.8379606962723
# agent 32 在 99 次迭代中的资源申请量为: -60.54755715363499
# agent 33 在 99 次迭代中的资源申请量为: -350.22316190591306
# agent 34 在 99 次迭代中的资源申请量为: 2.061255604597634
# agent 35 在 99 次迭代中的资源申请量为: 3.318113597381156
# agent 36 在 99 次迭代中的资源申请量为: 234.88168232734427
# agent 37 在 99 次迭代中的资源申请量为: 6.770487904058098
# agent 38 在 99 次迭代中的资源申请量为: -59.84239966444744
# agent 39 在 99 次迭代中的资源申请量为: 1175.3480662309194
# agent 40 在 99 次迭代中的资源申请量为: 237.32450156837058
# agent 41 在 99 次迭代中的资源申请量为: -345.85609339830194
# agent 42 在 99 次迭代中的资源申请量为: -246.0406412079618
# agent 43 在 99 次迭代中的资源申请量为: 238.11324601048807
# agent 44 在 99 次迭代中的资源申请量为: 254.7642332648364
# agent 45 在 99 次迭代中的资源申请量为: 299.00888172009746
# agent 46 在 99 次迭代中的资源申请量为: -309.54993463000875
# agent 47 在 99 次迭代中的资源申请量为: 86.80503140221701
# agent 48 在 99 次迭代中的资源申请量为: 94.26543764670433
# agent 49 在 99 次迭代中的资源申请量为: -275.16817855953946
# agent 50 在 99 次迭代中的资源申请量为: -131.23929234019036
# agent 51 在 99 次迭代中的资源申请量为: 102.85299863894342
# agent 52 在 99 次迭代中的资源申请量为: 102.85299863894342
# agent 53 在 99 次迭代中的资源申请量为: -12.581644145887859
# agent 54 在 99 次迭代中的资源申请量为: -263.0368793361304
# 资源申请量总和为: 5606.7151380908
# ****************************************************************************
# 成本总和为: 56638.774830183305
# ****************************************************************************
# agent 1 在 99 次迭代中的对偶变量为: -17.508179689517448
# agent 2 在 99 次迭代中的对偶变量为: -17.508179689517448
# agent 3 在 99 次迭代中的对偶变量为: -17.495987563438455
# agent 4 在 99 次迭代中的对偶变量为: -17.465765476078055
# agent 5 在 99 次迭代中的对偶变量为: -17.49948617843477
# agent 6 在 99 次迭代中的对偶变量为: -17.49948617843477
# agent 7 在 99 次迭代中的对偶变量为: -17.5017253002019
# agent 8 在 99 次迭代中的对偶变量为: -17.51883809570406
# agent 9 在 99 次迭代中的对偶变量为: -17.613070926784022
# agent 10 在 99 次迭代中的对偶变量为: -17.52476673792566
# agent 11 在 99 次迭代中的对偶变量为: -17.49701201498445
# agent 12 在 99 次迭代中的对偶变量为: -17.522341373626826
# agent 13 在 99 次迭代中的对偶变量为: -17.5004541221411
# agent 14 在 99 次迭代中的对偶变量为: -17.52129519975544
# agent 15 在 99 次迭代中的对偶变量为: -17.493229562574207
# agent 16 在 99 次迭代中的对偶变量为: -17.49685445017535
# agent 17 在 99 次迭代中的对偶变量为: -17.491175278379437
# agent 18 在 99 次迭代中的对偶变量为: -17.377359700517136
# agent 19 在 99 次迭代中的对偶变量为: -17.495454940387393
# agent 20 在 99 次迭代中的对偶变量为: -17.293580561623468
# agent 21 在 99 次迭代中的对偶变量为: -16.974024716820207
# agent 22 在 99 次迭代中的对偶变量为: -16.956609514166423
# agent 23 在 99 次迭代中的对偶变量为: -16.974024716820207
# agent 24 在 99 次迭代中的对偶变量为: -17.02264962867393
# agent 25 在 99 次迭代中的对偶变量为: -17.11497465045672
# agent 26 在 99 次迭代中的对偶变量为: -17.102501304760434
# agent 27 在 99 次迭代中的对偶变量为: -17.483577404521156
# agent 28 在 99 次迭代中的对偶变量为: -17.192693795103818
# agent 29 在 99 次迭代中的对偶变量为: -17.75890645047341
# agent 30 在 99 次迭代中的对偶变量为: -17.828397531841713
# agent 31 在 99 次迭代中的对偶变量为: -17.767490288031166
# agent 32 在 99 次迭代中的对偶变量为: -17.80795105201265
# agent 33 在 99 次迭代中的对偶变量为: -17.8727681434777
# agent 34 在 99 次迭代中的对偶变量为: -17.8727681434777
# agent 35 在 99 次迭代中的对偶变量为: -17.904943708092958
# agent 36 在 99 次迭代中的对偶变量为: -17.996176590619736
# agent 37 在 99 次迭代中的对偶变量为: -17.993324490343888
# agent 38 在 99 次迭代中的对偶变量为: -17.906197824351196
# agent 39 在 99 次迭代中的对偶变量为: -17.812088397385516
# agent 40 在 99 次迭代中的对偶变量为: -18.04930790911206
# agent 41 在 99 次迭代中的对偶变量为: -18.11996168928252
# agent 42 在 99 次迭代中的对偶变量为: -18.132697545666762
# agent 43 在 99 次迭代中的对偶变量为: -18.066463100728114
# agent 44 在 99 次迭代中的对偶变量为: -18.42862207351019
# agent 45 在 99 次迭代中的对偶变量为: -19.39094317741212
# agent 46 在 99 次迭代中的对偶变量为: -20.175035500202988
# agent 47 在 99 次迭代中的对偶变量为: -20.042208803896756
# agent 48 在 99 次迭代中的对偶变量为: -20.23319520375563
# agent 49 在 99 次迭代中的对偶变量为: -22.121180420815833
# agent 50 在 99 次迭代中的对偶变量为: -20.37683431333396
# agent 51 在 99 次迭代中的对偶变量为: -20.453036765156952
# agent 52 在 99 次迭代中的对偶变量为: -20.453036765156952
# agent 53 在 99 次迭代中的对偶变量为: -17.49790990986527
# agent 54 在 99 次迭代中的对偶变量为: -17.800455082737322
# *************************
# 迭代步长为: 5.3865362416062276e-05
# ****************************************************************************
# 119 次迭代中的结果：
# agent 1 在 119 次迭代中的资源申请量为: -62.41133309305253
# agent 2 在 119 次迭代中的资源申请量为: -62.41133309305253
# agent 3 在 119 次迭代中的资源申请量为: -62.47750916489251
# agent 4 在 119 次迭代中的资源申请量为: 212.7949667921729
# agent 5 在 119 次迭代中的资源申请量为: 213.98847367464555
# agent 6 在 119 次迭代中的资源申请量为: -62.45819658625425
# agent 7 在 119 次迭代中的资源申请量为: -10.805599690831556
# agent 8 在 119 次迭代中的资源申请量为: -62.35903636423511
# agent 9 在 119 次迭代中的资源申请量为: -61.85582639416673
# agent 10 在 119 次迭代中的资源申请量为: 214.8197109511132
# agent 11 在 119 次迭代中的资源申请量为: 1129.9837596746108
# agent 12 在 119 次迭代中的资源申请量为: -62.34080796928059
# agent 13 在 119 次迭代中的资源申请量为: -62.45354281208335
# agent 14 在 119 次迭代中的资源申请量为: -10.25815221213741
# agent 15 在 119 次迭代中的资源申请量为: -62.49250994081241
# agent 16 在 119 次迭代中的资源申请量为: -10.946155910208365
# agent 17 在 119 次迭代中的资源申请量为: -62.50348898184407
# agent 18 在 119 次迭代中的资源申请量为: -63.12355355984269
# agent 19 在 119 次迭代中的资源申请量为: -10.99734525826762
# agent 20 在 119 次迭代中的资源申请量为: 1052.8531887412748
# agent 21 在 119 次迭代中的资源申请量为: 1002.474274398858
# agent 22 在 119 次迭代中的资源申请量为: -26.93967434281269
# agent 23 在 119 次迭代中的资源申请量为: -26.41478649752671
# agent 24 在 119 次迭代中的资源申请量为: 442.1139105661442
# agent 25 在 119 次迭代中的资源申请量为: 450.0584056730701
# agent 26 在 119 次迭代中的资源申请量为: -22.614036111856528
# agent 27 在 119 次迭代中的资源申请量为: 433.9656234667336
# agent 28 在 119 次迭代中的资源申请量为: 423.53197844485726
# agent 29 在 119 次迭代中的资源申请量为: 223.03820476057535
# agent 30 在 119 次迭代中的资源申请量为: 25.220205492604556
# agent 31 在 119 次迭代中的资源申请量为: -61.0293188335571
# agent 32 在 119 次迭代中的资源申请量为: -60.81260255880631
# agent 33 在 119 次迭代中的资源申请量为: -351.15594321279957
# agent 34 在 119 次迭代中的资源申请量为: -0.0012113131760138618
# agent 35 在 119 次迭代中的资源申请量为: 1.277061791000872
# agent 36 在 119 次迭代中的资源申请量为: 232.62424392596006
# agent 37 在 119 次迭代中的资源申请量为: 5.147971945528851
# agent 38 在 119 次迭代中的资源申请量为: -59.962134933747315
# agent 39 在 119 次迭代中的资源申请量为: 1176.5558399464248
# agent 40 在 119 次迭代中的资源申请量为: 234.98124267739198
# agent 41 在 119 次迭代中的资源申请量为: -347.05228705239045
# agent 42 在 119 次迭代中的资源申请量为: -249.67767608886186
# agent 43 在 119 次迭代中的资源申请量为: 235.5231393995108
# agent 44 在 119 次迭代中的资源申请量为: 250.18485251724337
# agent 45 在 119 次迭代中的资源申请量为: 288.9901575826256
# agent 46 在 119 次迭代中的资源申请量为: -315.1369168893926
# agent 47 在 119 次迭代中的资源申请量为: 75.10850161308008
# agent 48 在 119 次迭代中的资源申请量为: 81.66242153123461
# agent 49 在 119 次迭代中的资源申请量为: -277.4211363398244
# agent 50 在 119 次迭代中的资源申请量为: -148.50562659822202
# agent 51 在 119 次迭代中的资源申请量为: 89.37090154557985
# agent 52 在 119 次迭代中的资源申请量为: 89.37090154557985
# agent 53 在 119 次迭代中的资源申请量为: -10.915440068798576
# agent 54 在 119 次迭代中的资源申请量为: -263.9965291681303
# 资源申请量总和为: 5634.110227616959
# ****************************************************************************
# 成本总和为: 56840.84291378464
# ****************************************************************************
# agent 1 在 119 次迭代中的对偶变量为: -17.548278605477364
# agent 2 在 119 次迭代中的对偶变量为: -17.548278605477364
# agent 3 在 119 次迭代中的对偶变量为: -17.539058558092187
# agent 4 在 119 次迭代中的对偶变量为: -17.51579052772976
# agent 5 在 119 次迭代中的对偶变量为: -17.54174930242354
# agent 6 在 119 次迭代中的对偶变量为: -17.54174930242354
# agent 7 在 119 次迭代中的对偶变量为: -17.543376647914712
# agent 8 在 119 次迭代中的对偶变量为: -17.55556489951658
# agent 9 在 119 次迭代中的对偶变量为: -17.625675131806325
# agent 10 在 119 次迭代中的对偶变量为: -17.55982871318671
# agent 11 在 119 次迭代中的对偶变量为: -17.539902558047665
# agent 12 在 119 次迭代中的对偶变量为: -17.558104588872013
# agent 13 在 119 次迭代中的对偶变量为: -17.542397694163675
# agent 14 在 119 次迭代中的对偶变量为: -17.557391303369283
# agent 15 在 119 次迭代中的对偶变量为: -17.53696855998637
# agent 16 在 119 次迭代中的对偶变量为: -17.539778408698666
# agent 17 在 119 次迭代中的对偶变量为: -17.535438894115593
# agent 18 在 119 次迭代中的对偶变量为: -17.449047776721358
# agent 19 在 119 次迭代中的对偶变量为: -17.53846796138835
# agent 20 在 119 次迭代中的对偶变量为: -17.385701012335602
# agent 21 在 119 次迭代中的对偶变量为: -17.143781465663317
# agent 22 在 119 次迭代中的对偶变量为: -17.130344336823995
# agent 23 在 119 次迭代中的对偶变量为: -17.143781465663317
# agent 24 在 119 次迭代中的对偶变量为: -17.18060241298207
# agent 25 在 119 次迭代中的对偶变量为: -17.250513969923016
# agent 26 在 119 次迭代中的对偶变量为: -17.241080675536473
# agent 27 在 119 次迭代中的对偶变量为: -17.530491905025418
# agent 28 在 119 次迭代中的对偶变量为: -17.309507303462077
# agent 29 在 119 次迭代中的对偶变量为: -17.738580953542513
# agent 30 在 119 次迭代中的对偶变量为: -17.78717499367376
# agent 31 在 119 次迭代中的对偶变量为: -17.740829124195823
# agent 32 在 119 次迭代中的对偶变量为: -17.77102333589175
# agent 33 在 119 次迭代中的对偶变量为: -17.819968990382694
# agent 34 在 119 次迭代中的对偶变量为: -17.819968990382694
# agent 35 在 119 次迭代中的对偶变量为: -17.852692781849623
# agent 36 在 119 次迭代中的对偶变量为: -17.94707730538963
# agent 37 在 119 次迭代中的对偶变量为: -17.95178808180554
# agent 38 在 119 次迭代中的对偶变量为: -17.88951558822072
# agent 39 在 119 次迭代中的对偶变量为: -17.81933503967855
# agent 40 在 119 次迭代中的对偶变量为: -17.998342028233274
# agent 41 在 119 次迭代中的对偶变量为: -18.052252343686494
# agent 42 在 119 次迭代中的对偶变量为: -18.06160078781493
# agent 43 在 119 次迭代中的对偶变量为: -18.01012828193936
# agent 44 在 119 次迭代中的对偶变量为: -18.329020542250042
# agent 45 在 119 次迭代中的对偶变量为: -19.173035927422106
# agent 46 在 119 次迭代中的对偶变量为: -19.858789956392826
# agent 47 在 119 次迭代中的对偶变量为: -19.74277764129485
# agent 48 在 119 次迭代中的对偶变量为: -19.910557991199607
# agent 49 在 119 次迭代中的对偶变量为: -21.993653998620584
# agent 50 在 119 次迭代中的对偶变量为: -20.039312011257955
# agent 51 在 119 次迭代中的对偶变量为: -20.107895079566845
# agent 52 在 119 次迭代中的对偶变量为: -20.107895079566845
# agent 53 在 119 次迭代中的对偶变量为: -17.540564734238757
# agent 54 在 119 次迭代中的对偶变量为: -17.78169584782139
# *************************
# 迭代步长为: 4.087351016895592e-05
# ****************************************************************************
# 139 次迭代中的结果：
# agent 1 在 139 次迭代中的资源申请量为: -62.18449008297551
# agent 2 在 139 次迭代中的资源申请量为: -62.18449008297551
# agent 3 在 139 次迭代中的资源申请量为: -62.23682529619882
# agent 4 在 139 次迭代中的资源申请量为: 214.55102035959052
# agent 5 在 139 次迭代中的资源申请量为: 215.50538715066324
# agent 6 在 139 次迭代中的资源申请量为: -62.22139320351604
# agent 7 在 139 次迭代中的资源申请量为: -9.531753125018998
# agent 8 在 139 次迭代中的资源申请量为: -62.14597086448125
# agent 9 在 139 次迭代中的资源申请量为: -61.76182541601864
# agent 10 在 139 次迭代中的资源申请量为: 216.13865258775564
# agent 11 在 139 次迭代中的资源申请量为: 1135.5492555420878
# agent 12 在 139 次迭代中的资源申请量为: -62.13193521720951
# agent 13 在 139 次迭代中的资源申请量为: -62.218017334916695
# agent 14 在 139 次迭代中的资源申请量为: -9.113943273619112
# agent 15 在 139 次迭代中的资源申请量为: -62.24908201208343
# agent 16 在 139 次迭代中的资源申请量为: -9.640891417383168
# agent 17 在 139 次迭代中的资源申请量为: -62.25731156935879
# agent 18 在 139 次迭代中的资源申请量为: -62.742483588031625
# agent 19 在 139 次迭代中的资源申请量为: -9.709202659316794
# agent 20 在 139 次迭代中的资源申请量为: 1066.829149827921
# agent 21 在 139 次迭代中的资源申请量为: 1027.7040692195153
# agent 22 在 139 次迭代中的资源申请量为: -22.098898034288577
# agent 23 在 139 次迭代中的资源申请量为: -21.682228890933104
# agent 24 在 139 次迭代中的资源申请量为: 454.931138389619
# agent 25 在 139 次迭代中的资源申请量为: 461.08693415850735
# agent 26 在 139 次迭代中的资源申请量为: -18.745417988805244
# agent 27 在 139 次迭代中的资源申请量为: 435.6564654497174
# agent 28 在 139 次迭代中的资源申请量为: 427.49175122898407
# agent 29 在 139 次迭代中的资源申请量为: 222.52714330616462
# agent 30 在 139 次迭代中的资源申请量为: 24.950862465277407
# agent 31 在 139 次迭代中的资源申请量为: -61.13177165409696
# agent 32 在 139 次迭代中的资源申请量为: -60.966643374390884
# agent 33 在 139 次迭代中的资源申请量为: -351.7333620937494
# agent 34 在 139 次迭代中的资源申请量为: -1.2779385919761688
# agent 35 在 139 次迭代中的资源申请量为: -0.05447230192592856
# agent 36 在 139 次迭代中的资源申请量为: 230.91296233359046
# agent 37 在 139 次迭代中的资源申请量为: 3.8301086899042436
# agent 38 在 139 次迭代中的资源申请量为: -60.09376072473503
# agent 39 在 139 次迭代中的资源申请量为: 1176.0747241936208
# agent 40 在 139 次迭代中的资源申请量为: 233.09255200516503
# agent 41 在 139 次迭代中的资源申请量为: -347.97624999522424
# agent 42 在 139 次迭代中的资源申请量为: -252.46194357734916
# agent 43 在 139 次迭代中的资源申请量为: 233.4883766800496
# agent 44 在 139 次迭代中的资源申请量为: 246.3296815330777
# agent 45 在 139 次迭代中的资源申请量为: 280.232730594888
# agent 46 在 139 次迭代中的资源申请量为: -320.0523251802024
# agent 47 在 139 次迭代中的资源申请量为: 64.8239645604616
# agent 48 在 139 次迭代中的资源申请量为: 70.55353158731764
# agent 49 在 139 次迭代中的资源申请量为: -279.4053450876364
# agent 50 在 139 次迭代中的资源申请量为: -163.8137269560687
# agent 51 在 139 次迭代中的资源申请量为: 77.37822529909066
# agent 52 在 139 次迭代中的资源申请量为: 77.37822529909066
# agent 53 在 139 次迭代中的资源申请量为: -9.616831627824451
# agent 54 在 139 次迭代中的资源申请量为: -264.6296275687954
# 资源申请量总和为: 5638.946753670953
# ****************************************************************************
# 成本总和为: 56722.42184495674
# ****************************************************************************
# agent 1 在 139 次迭代中的对偶变量为: -17.579883734699354
# agent 2 在 139 次迭代中的对偶变量为: -17.579883734699354
# agent 3 在 139 次迭代中的对偶变量为: -17.572592078781803
# agent 4 在 139 次迭代中的对偶变量为: -17.553984692821093
# agent 5 在 139 次迭代中的对偶变量为: -17.574742170526925
# agent 6 在 139 次迭代中的对偶变量为: -17.574742170526925
# agent 7 在 139 次迭代中的对偶变量为: -17.575987119999514
# agent 8 在 139 次迭代中的对偶变量为: -17.585250463335285
# agent 9 在 139 次迭代中的对偶变量为: -17.638771912087787
# agent 10 在 139 次迭代中的对偶变量为: -17.588515693783684
# agent 11 在 139 次迭代中的对偶变量为: -17.573295533252526
# agent 12 在 139 次迭代中的对偶变量为: -17.587205993927068
# agent 13 在 139 次迭代中的对偶变量为: -17.575212516795396
# agent 14 在 139 次迭代中的对偶变量为: -17.58668305219535
# agent 15 在 139 次迭代中的对偶变量为: -17.570884399584465
# agent 16 在 139 次迭代中的对偶变量为: -17.57319317971499
# agent 17 在 139 次迭代中的对偶变量为: -17.569737808287517
# agent 18 在 139 次迭代中的对偶变量为: -17.502140731613906
# agent 19 在 139 次迭代中的对偶变量为: -17.57144441192149
# agent 20 在 139 次迭代中的对偶变量为: -17.452813577473677
# agent 21 在 139 次迭代中的对偶变量为: -17.264934940392113
# agent 22 在 139 次迭代中的对偶变量为: -17.254268210322213
# agent 23 在 139 次迭代中的对偶变量为: -17.264934940392113
# agent 24 在 139 次迭代中的对偶变量为: -17.293394017828646
# agent 25 在 139 次迭代中的对偶变量为: -17.347565020594864
# agent 26 在 139 次迭代中的对偶变量为: -17.340117299486586
# agent 27 在 139 次迭代中的对偶变量为: -17.566303938225015
# agent 28 在 139 次迭代中的对偶变量为: -17.393375291029884
# agent 29 在 139 次迭代中的对偶变量为: -17.72746536690908
# agent 30 在 139 次迭代中的对偶变量为: -17.76243691398587
# agent 31 在 139 次迭代中的对偶变量为: -17.726554782521287
# agent 32 在 139 次迭代中的对偶变量为: -17.749561445219616
# agent 33 在 139 次迭代中的对偶变量为: -17.78728477204541
# agent 34 在 139 次迭代中的对偶变量为: -17.78728477204541
# agent 35 在 139 次迭代中的对偶变量为: -17.818605509070697
# agent 36 在 139 次迭代中的对偶变量为: -17.90985693075559
# agent 37 在 139 次迭代中的对偶变量为: -17.91805078246155
# agent 38 在 139 次迭代中的对偶变量为: -17.871176693265568
# agent 39 在 139 次迭代中的对偶变量为: -17.816448345161724
# agent 40 在 139 次迭代中的对偶变量为: -17.95726300611234
# agent 41 在 139 次迭代中的对偶变量为: -17.99995234527033
# agent 42 在 139 次迭代中的对偶变量为: -18.007173926949978
# agent 43 在 139 次迭代中的对偶变量为: -17.96587219279108
# agent 44 在 139 次迭代中的对偶变量为: -18.24517057334444
# agent 45 在 139 次迭代中的对偶变量为: -18.982561890438813
# agent 46 在 139 次迭代中的对偶变量为: -19.580558185499825
# agent 47 在 139 次迭代中的对偶变量为: -19.479493492747817
# agent 48 在 139 次迭代中的对偶变量为: -19.626170408635332
# agent 49 在 139 次迭代中的对偶变量为: -21.88133984665943
# agent 50 在 139 次迭代中的对偶变量为: -19.74006926546277
# agent 51 在 139 次迭代中的对偶变量为: -19.80088256765672
# agent 52 在 139 次迭代中的对偶变量为: -19.80088256765672
# agent 53 在 139 次迭代中的对偶变量为: -17.573809110327694
# agent 54 在 139 次迭代中的对偶变量为: -17.769320040285187
# *************************
# 迭代步长为: 3.237726633057685e-05
# ****************************************************************************
# 159 次迭代中的结果：
# agent 1 在 159 次迭代中的资源申请量为: -62.00054467871541
# agent 2 在 159 次迭代中的资源申请量为: -62.00054467871541
# agent 3 在 159 次迭代中的资源申请量为: -62.04331704486171
# agent 4 在 159 次迭代中的资源申请量为: 215.94233058170832
# agent 5 在 159 次迭代中的资源申请量为: 216.72737788644582
# agent 6 在 159 次迭代中的资源申请量为: -62.03062982479799
# agent 7 在 159 次迭代中的资源申请量为: -8.503409732028565
# agent 8 在 159 次迭代中的资源申请量为: -61.97066338559023
# agent 9 在 159 次迭代中的资源申请量为: -61.66867240119642
# agent 10 在 159 次迭代中的资源申请量为: 217.23149039335053
# agent 11 在 159 次迭代中的资源申请量为: 1140.0243396616809
# agent 12 在 159 次迭代中的资源申请量为: -61.95941466927135
# agent 13 在 159 次迭代中的资源申请量为: -62.028043013799866
# agent 14 在 159 次迭代中的资源申请量为: -8.170306200433325
# agent 15 在 159 次迭代中的资源申请量为: -62.05371277023179
# agent 16 在 159 次迭代中的资源申请量为: -8.591420567560236
# agent 17 在 159 次迭代中的资源申请量为: -62.06003163618502
# agent 18 在 159 次迭代中的资源申请量为: -62.4500966419272
# agent 19 在 159 次迭代中的资源申请量为: -8.672392300284049
# agent 20 在 159 次迭代中的资源申请量为: 1077.365057727064
# agent 21 在 159 次迭代中的资源申请量为: 1046.1801923808473
# agent 22 在 159 次迭代中的资源申请量为: -18.555791645690906
# agent 23 在 159 次迭代中的资源申请量为: -18.216512351061365
# agent 24 在 159 次迭代中的资源申请量为: 464.339521322563
# agent 25 在 159 次迭代中的资源申请量为: 469.22935039619455
# agent 26 在 159 次迭代中的资源申请量为: -15.89246023835214
# agent 27 在 159 次迭代中的资源申请量为: 436.99651299106495
# agent 28 在 159 次迭代中的资源申请量为: 430.43375441774646
# agent 29 在 159 次迭代中的资源申请量为: 222.3150698633201
# agent 30 在 159 次迭代中的资源申请量为: 24.804780683262283
# agent 31 在 159 次迭代中的资源申请量为: -61.17474467853579
# agent 32 在 159 次迭代中的资源申请量为: -61.04540885668321
# agent 33 在 159 次迭代中的资源申请量为: -352.0664381570775
# agent 34 在 159 次迭代中的资源申请量为: -2.014400993875509
# agent 35 在 159 次迭代中的资源申请量为: -0.8931493628060172
# agent 36 在 159 次迭代中的资源申请量为: 229.6006432392721
# agent 37 在 159 次迭代中的资源申请量为: 2.7453936980569025
# agent 38 在 159 次迭代中的资源申请量为: -60.22200484009796
# agent 39 在 159 次迭代中的资源申请量为: 1174.8488445848404
# agent 40 在 159 次迭代中的资源申请量为: 231.54120485143142
# agent 41 在 159 次迭代中的资源申请量为: -348.7109043766118
# agent 42 在 159 次迭代中的资源申请量为: -254.66211628291015
# agent 43 在 159 次迭代中的资源申请量为: 231.84636710142573
# agent 44 在 159 次迭代中的资源申请量为: 243.06674885946174
# agent 45 在 159 次迭代中的资源申请量为: 272.62442502519946
# agent 46 在 159 次迭代中的资源申请量为: -324.3399792235484
# agent 47 在 159 次迭代中的资源申请量为: 55.85548363757839
# agent 48 在 159 次迭代中的资源申请量为: 60.85378356927156
# agent 49 在 159 次迭代中的资源申请量为: -281.1372575773013
# agent 50 在 159 次迭代中的资源申请量为: -177.22178408853185
# agent 51 在 159 次迭代中的资源申请量为: 66.85560957935459
# agent 52 在 159 次迭代中的资源申请量为: 66.85560957935459
# agent 53 在 159 次迭代中的资源申请量为: -8.57188342438614
# agent 54 在 159 次迭代中的资源申请量为: -265.02653513901043
# 资源申请量总和为: 5632.329321248417
# ****************************************************************************
# 成本总和为: 56455.970289127006
# ****************************************************************************
# agent 1 在 159 次迭代中的对偶变量为: -17.605512112093297
# agent 2 在 159 次迭代中的对偶变量为: -17.605512112093297
# agent 3 在 159 次迭代中的对偶变量为: -17.599552809407598
# agent 4 在 159 次迭代中的对偶变量为: -17.584245690152155
# agent 5 在 159 次迭代中的对偶变量为: -17.601320469030195
# agent 6 在 159 次迭代中的对偶变量为: -17.601320469030195
# agent 7 在 159 次迭代中的对偶变量为: -17.60231271086007
# agent 8 在 159 次迭代中的对偶变量为: -17.609675353139256
# agent 9 在 159 次迭代中的对偶变量为: -17.651750549030908
# agent 10 在 159 次迭代中的对偶变量为: -17.612284916055373
# agent 11 在 159 次迭代中的对偶变量为: -17.600146037970084
# agent 12 在 159 次迭代中的对偶变量为: -17.6112425917891
# agent 13 在 159 次迭代中的对偶变量为: -17.60168087905932
# agent 14 在 159 次迭代中的对偶变量为: -17.610840161268907
# agent 15 在 159 次迭代中的对偶变量为: -17.598104414574685
# agent 16 在 159 次迭代中的对偶变量为: -17.600059633470458
# agent 17 在 159 次迭代中的对偶变量为: -17.597224032256886
# agent 18 在 159 次迭代中的对偶变量为: -17.54287783526685
# agent 19 在 159 次迭代中的对偶变量为: -17.59798675711273
# agent 20 在 159 次迭代中的对偶变量为: -17.50340700720536
# agent 21 在 159 次迭代中的对偶变量为: -17.35365728381283
# agent 22 在 159 次迭代中的对偶变量为: -17.344971733870313
# agent 23 在 159 次迭代中的对偶变量为: -17.35365728381283
# agent 24 在 159 次迭代中的对偶变量为: -17.376187787638553
# agent 25 在 159 次迭代中的对偶变量为: -17.41921828348651
# agent 26 在 159 次迭代中的对偶变量为: -17.413153017898185
# agent 27 在 159 次迭代中的对偶变量为: -17.594686145150757
# agent 28 在 159 次迭代中的对偶变量为: -17.45568691856787
# agent 29 在 159 次迭代中的对偶变量为: -17.72285276952721
# agent 30 在 159 次迭代中的对偶变量为: -17.74901988663491
# agent 31 在 159 次迭代中的对偶变量为: -17.720567522918323
# agent 32 在 159 次迭代中的对偶变量为: -17.738587365633755
# agent 33 在 159 次迭代中的对偶变量为: -17.768431334556787
# agent 34 在 159 次迭代中的对偶变量为: -17.768431334556787
# agent 35 在 159 次迭代中的对偶变量为: -17.797135376312166
# agent 36 在 159 次迭代中的对偶变量为: -17.881313990454167
# agent 37 在 159 次迭代中的对偶变量为: -17.890282078670257
# agent 38 在 159 次迭代中的对偶变量为: -17.85330895364851
# agent 39 在 159 次迭代中的对偶变量为: -17.809093067509043
# agent 40 在 159 次迭代中的对偶变量为: -17.923521205518632
# agent 41 在 159 次迭代中的对偶变量为: -17.95836796866627
# agent 42 在 159 次迭代中的对偶变量为: -17.964164950901672
# agent 43 在 159 次迭代中的对偶变量为: -17.93015848445601
# agent 44 在 159 次迭代中的对偶变量为: -18.174201787693292
# agent 45 在 159 次迭代中的对偶变量为: -18.817081244298087
# agent 46 在 159 次迭代中的对偶变量为: -19.337859816030267
# agent 47 在 159 次迭代中的对偶变量为: -19.249900381122007
# agent 48 在 159 次迭代中的对偶变量为: -19.377856859373352
# agent 49 在 159 次迭代中的对偶变量为: -21.78330667209444
# agent 50 在 159 次迭代中的对偶变量为: -19.47796856463738
# agent 51 在 159 次迭代中的对偶变量为: -19.531503605231478
# agent 52 在 159 次迭代中的对偶变量为: -19.531503605231478
# agent 53 在 159 次迭代中的对偶变量为: -17.600559784335715
# agent 54 在 159 次迭代中的对偶变量为: -17.761561291102623
# *************************
# 迭代步长为: 2.6464682716040347e-05
# ****************************************************************************
# 179 次迭代中的结果：
# agent 1 在 179 次迭代中的资源申请量为: -61.8482379585388
# agent 2 在 179 次迭代中的资源申请量为: -61.8482379585388
# agent 3 在 179 次迭代中的资源申请量为: -61.88409027722142
# agent 4 在 179 次迭代中的资源申请量为: 217.0746895049101
# agent 5 在 179 次迭代中的资源申请量为: 217.7343416549183
# agent 6 在 179 次迭代中的资源申请量为: -61.87343402527546
# agent 7 在 179 次迭代中的资源申请量为: -7.654685751205397
# agent 8 在 179 次迭代中的资源申请量为: -61.82409553764863
# agent 9 在 179 次迭代中的资源申请量为: -61.58002184620051
# agent 10 在 179 次迭代中的资源申请量为: 218.1494284031607
# agent 11 在 179 次迭代中的资源申请量为: 1143.7069243519165
# agent 12 在 179 次迭代中的资源申请量为: -61.814808381713284
# agent 13 在 179 次迭代中的资源申请量为: -61.87136460640092
# agent 14 在 179 次迭代中的资源申请量为: -7.380131868754829
# agent 15 在 179 次迭代中的资源申请量为: -61.893111980349026
# agent 16 在 179 次迭代中的资源申请量为: -7.727831710407362
# agent 17 在 179 次迭代中的资源申请量为: -61.8980924417379
# agent 18 在 179 次迭代中的资源申请量为: -62.2191855308574
# agent 19 在 179 次迭代中的资源申请量为: -7.815331428674965
# agent 20 在 179 次迭代中的资源申请量为: 1085.545539436678
# agent 21 在 179 次迭代中的资源申请量为: 1060.0865778838315
# agent 22 在 179 次迭代中的资源申请量为: -15.890384680488783
# agent 23 在 179 次迭代中的资源申请量为: -15.607978632884434
# agent 24 在 179 次迭代中的资源申请量为: 471.44275590394557
# agent 25 在 179 次迭代中的资源申请量为: 475.4194802468287
# agent 26 在 179 次迭代中的资源申请量为: -13.725216703162069
# agent 27 在 179 次迭代中的资源申请量为: 438.0871480311181
# agent 28 在 179 次迭代中的资源申请量为: 432.68729980791005
# agent 29 在 179 次迭代中的资源申请量为: 222.28638906727824
# agent 30 在 179 次迭代中的资源申请量为: 24.73522984960648
# agent 31 在 179 次迭代中的资源申请量为: -61.18212910270188
# agent 32 在 179 次迭代中的资源申请量为: -61.07804874866029
# agent 33 在 179 次迭代中的资源申请量为: -352.24627055145
# agent 34 在 179 次迭代中的资源申请量为: -2.412027277119977
# agent 35 在 179 次迭代中的资源申请量为: -1.412788731700726
# agent 36 在 179 次迭代中的资源申请量为: 228.58301061604288
# agent 37 在 179 次迭代中的资源申请量为: 1.8537742368229804
# agent 38 在 179 次迭代中的资源申请量为: -60.338514723109974
# ...
# agent 13 在 1959 次迭代中的资源申请量为: -60.54064290381012
# agent 14 在 1959 次迭代中的资源申请量为: -0.42343027443048076
# agent 15 在 1959 次迭代中的资源申请量为: -60.54143150428355
# agent 16 在 1959 次迭代中的资源申请量为: -0.4347449907171619
# agent 17 在 1959 次迭代中的资源申请量为: -60.54143256825066
# agent 18 在 1959 次迭代中的资源申请量为: -60.54980309409974
# agent 19 在 1959 次迭代中的资源申请量为: -0.4473571219906769
# agent 20 在 1959 次迭代中的资源申请量为: 1140.5576087447917
# agent 21 在 1959 次迭代中的资源申请量为: 1139.9718540462404
# agent 22 在 1959 次迭代中的资源申请量为: -0.6316269092733473
# agent 23 在 1959 次迭代中的资源申请量为: -0.6232483152325552
# agent 24 在 1959 次迭代中的资源申请量为: 513.0017658149075
# agent 25 在 1959 次迭代中的资源申请量为: 513.084617008171
# agent 26 在 1959 次迭代中的资源申请量为: -0.5856991167950409
# agent 27 在 1959 次迭代中的资源申请量为: 447.0977777220196
# agent 28 在 1959 次迭代中的资源申请量为: 446.96523991057046
# agent 29 在 1959 次迭代中的资源申请量为: 226.35649364554595
# agent 30 在 1959 次迭代中的资源申请量为: 25.483434270725464
# agent 31 在 1959 次迭代中的资源申请量为: -60.526181321298274
# agent 32 在 1959 次迭代中的资源申请量为: -60.524185241899026
# agent 33 在 1959 次迭代中的资源申请量为: -351.30195978976116
# agent 34 在 1959 次迭代中的资源申请量为: -0.3240676538920906
# agent 35 在 1959 次迭代中的资源申请量为: -0.3164558397401873
# agent 36 在 1959 次迭代中的资源申请量为: 226.43614976283257
# agent 37 在 1959 次迭代中的资源申请量为: -0.2918539477375637
# agent 38 在 1959 次迭代中的资源申请量为: -60.521379654465996
# agent 39 在 1959 次迭代中的资源申请量为: 1175.10059780243
# agent 40 在 1959 次迭代中的资源申请量为: 226.4647169862688
# agent 41 在 1959 次迭代中的资源申请量为: -351.2638563272822
# agent 42 在 1959 次迭代中的资源申请量为: -262.34473562842464
# agent 43 在 1959 次迭代中的资源申请量为: 226.4710694392737
# agent 44 在 1959 次迭代中的资源申请量为: 226.57209055702685
# agent 45 在 1959 次迭代中的资源申请量为: 226.8659852008855
# agent 46 在 1959 次迭代中的资源申请量为: -351.029961937084
# agent 47 在 1959 次迭代中的资源申请量为: 0.24453974864030448
# agent 48 在 1959 次迭代中的资源申请量为: 0.2938768359189714
# agent 49 在 1959 次迭代中的资源申请量为: -291.8439382582477
# agent 50 在 1959 次迭代中的资源申请量为: -261.5989140417623
# agent 51 在 1959 次迭代中的资源申请量为: 0.36098069417248024
# agent 52 在 1959 次迭代中的资源申请量为: 0.36098069417248024
# agent 53 在 1959 次迭代中的资源申请量为: -0.4342113469306408
# agent 54 在 1959 次迭代中的资源申请量为: -262.4956108393
# 资源申请量总和为: 5630.964165321091
# ****************************************************************************
# 成本总和为: 55989.017237327855
# ****************************************************************************
# agent 1 在 1959 次迭代中的对偶变量为: -17.809019611063878
# agent 2 在 1959 次迭代中的对偶变量为: -17.809019611063878
# agent 3 在 1959 次迭代中的对偶变量为: -17.808855981012943
# agent 4 在 1959 次迭代中的对偶变量为: -17.80840043009681
# agent 5 在 1959 次迭代中的对偶变量为: -17.80890494020404
# agent 6 在 1959 次迭代中的对偶变量为: -17.80890494020404
# agent 7 在 1959 次迭代中的对偶变量为: -17.808936563617085
# agent 8 在 1959 次迭代中的对偶变量为: -17.809139256896824
# agent 9 在 1959 次迭代中的对偶变量为: -17.809855163821418
# agent 10 在 1959 次迭代中的对偶变量为: -17.809198445956476
# agent 11 在 1959 次迭代中的对偶变量为: -17.808872149419646
# agent 12 在 1959 次迭代中的对偶变量为: -17.809136334277714
# agent 13 在 1959 次迭代中的对偶变量为: -17.80891438678375
# agent 14 在 1959 次迭代中的对偶变量为: -17.80916018497458
# agent 15 在 1959 次迭代中的对偶变量为: -17.80880451423419
# agent 16 在 1959 次迭代中的对偶变量为: -17.80887052823764
# agent 17 在 1959 次迭代中的对偶变量为: -17.808804365995908
# agent 18 在 1959 次迭代中的对偶变量为: -17.80763813411146
# agent 19 在 1959 次迭代中的对偶变量为: -17.80854765767704
# agent 20 在 1959 次迭代中的对偶变量为: -17.80685763719249
# agent 21 在 1959 次迭代中的对偶变量为: -17.804044843130047
# agent 22 在 1959 次迭代中的对偶变量为: -17.803830351122603
# agent 23 在 1959 次迭代中的对偶变量为: -17.804044843130047
# agent 24 在 1959 次迭代中的对偶变量为: -17.804415539171185
# agent 25 在 1959 次迭代中的对偶变量为: -17.805144629671904
# agent 26 在 1959 次迭代中的对偶变量为: -17.805006102610047
# agent 27 在 1959 次迭代中的对偶变量为: -17.808630932152376
# agent 28 在 1959 次迭代中的对偶变量为: -17.805823781305882
# agent 29 在 1959 次迭代中的对偶变量为: -17.810753736790623
# agent 30 在 1959 次迭代中的对偶变量为: -17.81135150402905
# agent 31 在 1959 次迭代中的对偶变量为: -17.810929261228797
# agent 32 在 1959 次迭代中的对偶变量为: -17.811207366987176
# agent 33 在 1959 次迭代中的对偶变量为: -17.811703868060363
# agent 34 在 1959 次迭代中的对偶变量为: -17.811703868060363
# agent 35 在 1959 次迭代中的对偶变量为: -17.81189873050265
# agent 36 在 1959 次迭代中的对偶变量为: -17.812486257341607
# agent 37 在 1959 次迭代中的对偶变量为: -17.81252853893792
# agent 38 在 1959 次迭代中的对偶变量为: -17.81159825826187
# agent 39 在 1959 次迭代中的对偶变量为: -17.81060358681458
# agent 40 在 1959 次迭代中的对偶变量为: -17.813107594451346
# agent 41 在 1959 次迭代中的对偶变量为: -17.81386067645052
# agent 42 在 1959 次迭代中的对偶变量为: -17.813985107935554
# agent 43 在 1959 次迭代中的对偶变量为: -17.813245760304202
# agent 44 在 1959 次迭代中的对偶变量为: -17.815442969615333
# agent 45 在 1959 次迭代中的对偶变量为: -17.821835178119258
# agent 46 在 1959 次迭代中的对偶变量为: -17.8271000345133
# agent 47 在 1959 次迭代中的对偶变量为: -17.826260217565192
# agent 48 在 1959 次迭代中的对偶变量为: -17.827523246999526
# agent 49 在 1959 次迭代中的对偶变量为: -21.17726571883015
# agent 50 在 1959 次迭代中的对偶变量为: -17.82856442831163
# agent 51 在 1959 次迭代中的对偶变量为: -17.829241105770816
# agent 52 在 1959 次迭代中的对偶变量为: -17.829241105770816
# agent 53 在 1959 次迭代中的对偶变量为: -17.808884189518576
# agent 54 在 1959 次迭代中的对偶变量为: -17.811035799313363
# *************************
# 迭代步长为: 6.119426517433285e-07
# ****************************************************************************
# 1979 次迭代中的结果：
# agent 1 在 1979 次迭代中的资源申请量为: -60.53815215384604
# agent 2 在 1979 次迭代中的资源申请量为: -60.53815215384604
# agent 3 在 1979 次迭代中的资源申请量为: -60.53930999598085
# agent 4 在 1979 次迭代中的资源申请量为: 226.25972014346542
# agent 5 在 1979 次迭代中的资源申请量为: 226.2826915311338
# agent 6 在 1979 次迭代中的资源申请量为: -60.53896228412386
# agent 7 在 1979 次迭代中的资源申请量为: -0.42266846624727794
# agent 8 在 1979 次迭代中的资源申请量为: -60.537307963205414
# agent 9 在 1979 次迭代中的资源申请量为: -60.53224347131747
# agent 10 在 1979 次迭代中的资源申请量为: 226.29595745938423
# agent 11 在 1979 次迭代中的资源申请量为: 1174.852707718954
# agent 12 在 1979 次迭代中的资源申请量为: -60.53733377607171
# agent 13 在 1979 次迭代中的资源申请量为: -60.538895747673756
# agent 14 在 1979 次迭代中的资源申请量为: -0.4140820765241582
# agent 15 在 1979 次迭代中的资源申请量为: -60.53967230262972
# agent 16 在 1979 次迭代中的资源申请量为: -0.4252088685370581
# agent 17 在 1979 次迭代中的资源申请量为: -60.53967319993357
# agent 18 在 1979 次迭代中的资源申请量为: -60.54793262855174
# agent 19 在 1979 次迭代中的资源申请量为: -0.43764106444771356
# agent 20 在 1979 次迭代中的资源申请量为: 1140.614273400849
# agent 21 在 1979 次迭代中的资源申请量为: 1140.0366470976755
# agent 22 在 1979 次迭代中的资源申请量为: -0.6193657127337437
# agent 23 在 1979 次迭代中的资源申请量为: -0.6110945561313419
# agent 24 在 1979 次迭代中的资源申请量为: 513.0365220325668
# agent 25 在 1979 次迭代中的资源申请量为: 513.1181820589393
# agent 26 在 1979 次迭代中的资源申请量为: -0.5740874225061698
# agent 27 在 1979 次迭代中的资源申请量为: 447.10947448468863
# agent 28 在 1979 次迭代中的资源申请量为: 446.9787473051013
# agent 29 在 1979 次迭代中的资源申请量为: 226.36656562066207
# agent 30 在 1979 次迭代中的资源申请量为: 25.48572102142856
# agent 31 在 1979 次迭代中的资源申请量为: -60.52464282137969
# agent 32 在 1979 次迭代中的资源申请量为: -60.52267412474475
# agent 33 在 1979 次迭代中的资源申请量为: -351.298321707483
# agent 34 在 1979 次迭代中的资源申请量为: -0.31602351290488384
# agent 35 在 1979 次迭代中的资源申请量为: -0.30847991228405425
# agent 36 在 1979 次迭代中的资源申请量为: 226.4453491515401
# agent 37 在 1979 次迭代中的资源申请量为: -0.2840374290066783
# agent 38 在 1979 次迭代中的资源申请量为: -60.51979128193016
# agent 39 在 1979 次迭代中的资源申请量为: 1175.140244455668
# agent 40 在 1979 次迭代中的资源申请量为: 226.47391958980833
# agent 41 在 1979 次迭代中的资源申请量为: -351.2605008950527
# agent 42 在 1979 次迭代中的资源申请量为: -262.33514326427564
# agent 43 在 1979 次迭代中的资源申请量为: 226.4800506037663
# agent 44 在 1979 次迭代中的资源申请量为: 226.57968072389923
# agent 45 在 1979 次迭代中的资源申请量为: 226.86966392303205
# agent 46 在 1979 次迭代中的资源申请量为: -351.0297646470482
# agent 47 在 1979 次迭代中的资源申请量为: 0.24543958583103653
# agent 48 在 1979 次迭代中的资源申请量为: 0.29410757322337333
# agent 49 在 1979 次迭代中的资源申请量为: -291.8436403939248
# agent 50 在 1979 次迭代中的资源申请量为: -261.5992366325104
# agent 51 在 1979 次迭代中的资源申请量为: 0.36048585849199344
# agent 52 在 1979 次迭代中的资源申请量为: 0.36048585849199344
# agent 53 在 1979 次迭代中的资源申请量为: -0.424683312783003
# agent 54 在 1979 次迭代中的资源申请量为: -262.48451512715894
# 资源申请量总和为: 5631.503398291807
# ****************************************************************************
# 成本总和为: 55998.621010241666
# ****************************************************************************
# agent 1 在 1979 次迭代中的对偶变量为: -17.809261413013246
# agent 2 在 1979 次迭代中的对偶变量为: -17.809261413013246
# agent 3 在 1979 次迭代中的对偶变量为: -17.80910009549997
# agent 4 在 1979 次迭代中的对偶变量为: -17.808648913120372
# agent 5 在 1979 次迭代中的对偶变量为: -17.80914854080216
# agent 6 在 1979 次迭代中的对偶变量为: -17.80914854080216
# agent 7 在 1979 次迭代中的对偶变量为: -17.80917968726407
# agent 8 在 1979 次迭代中的对偶变量为: -17.809379030718443
# agent 9 在 1979 次迭代中的对偶变量为: -17.81008464611522
# agent 10 在 1979 次迭代中的对偶变量为: -17.809437074741606
# agent 11 在 1979 次迭代中的对偶变量为: -17.809116246313724
# agent 12 在 1979 次迭代中的对偶变量为: -17.809375434315033
# agent 13 在 1979 次迭代中的对偶变量为: -17.809157811059606
# agent 14 在 1979 次迭代中的对偶变量为: -17.809399498840982
# agent 15 在 1979 次迭代中的对偶变量为: -17.80904961676381
# agent 16 在 1979 次迭代中的对偶变量为: -17.80911465296545
# agent 17 在 1979 次迭代中的对偶变量为: -17.809049491746055
# agent 18 在 1979 次迭代中的对偶变量为: -17.8078987385944
# agent 19 在 1979 次迭代中的对偶变量为: -17.80879638875014
# agent 20 在 1979 次迭代中的对偶变量为: -17.807129740870877
# agent 21 在 1979 次迭代中的对偶变量为: -17.804355979363038
# agent 22 在 1979 次迭代中的对偶变量为: -17.804144237754016
# agent 23 在 1979 次迭代中的对偶变量为: -17.804355979363038
# agent 24 在 1979 次迭代中的对偶变量为: -17.804721393886588
# agent 25 在 1979 次迭代中的对偶变量为: -17.805440002118665
# agent 26 在 1979 次迭代中的对偶变量为: -17.805303361983842
# agent 27 在 1979 次迭代中的对偶变量为: -17.808878669585706
# agent 28 在 1979 次迭代中的对偶变量为: -17.806109867922046
# agent 29 在 1979 次迭代中的对偶变量为: -17.8109728022494
# agent 30 在 1979 次迭代中的对偶变量为: -17.811561532934128
# agent 31 在 1979 次迭代中的对偶变量为: -17.811143614268452
# agent 32 在 1979 次迭代中的对偶变量为: -17.811417904895812
# agent 33 在 1979 次迭代中的对偶变量为: -17.811909798069635
# agent 34 在 1979 次迭代中的对偶变量为: -17.811909798069635
# agent 35 在 1979 次迭代中的对偶变量为: -17.81210291424553
# agent 36 在 1979 次迭代中的对偶变量为: -17.812686344045996
# agent 37 在 1979 次迭代中的对偶变量为: -17.81272864181743
# agent 38 在 1979 次迭代中的对偶变量为: -17.8118195598538
# agent 39 在 1979 次迭代中的对偶变量为: -17.810841466734008
# agent 40 在 1979 次迭代中的对偶变量为: -17.81330775107833
# agent 41 在 1979 次迭代中的对偶变量为: -17.81405060733644
# agent 42 在 1979 次迭代中的对偶变量为: -17.81417261946994
# agent 43 在 1979 次迭代中的对偶变量为: -17.813441100631916
# agent 44 在 1979 次迭代中的对偶变量为: -17.815608055744807
# agent 45 在 1979 次迭代中的对偶变量为: -17.821915190325946
# agent 46 在 1979 次迭代中的对偶变量为: -17.827111201918488
# agent 47 在 1979 次迭代中的对偶变量为: -17.826283253397275
# agent 48 在 1979 次迭代中的对偶变量为: -17.82752915387452
# agent 49 在 1979 次迭代中的对偶变量为: -21.177282579142286
# agent 50 在 1979 次迭代中的对偶变量为: -17.828558122307687
# agent 51 在 1979 次迭代中的对偶变量为: -17.829228437977395
# agent 52 在 1979 次迭代中的对偶变量为: -17.829228437977395
# agent 53 在 1979 次迭代中的对偶变量为: -17.809128107192755
# agent 54 在 1979 次迭代中的对偶变量为: -17.811252698294297
# *************************
# 迭代步长为: 6.0268958533986e-07
# ****************************************************************************
# 1999 次迭代中的结果：
# agent 1 在 1999 次迭代中的资源申请量为: -60.53644739487693
# agent 2 在 1999 次迭代中的资源申请量为: -60.53644739487693
# agent 3 在 1999 次迭代中的资源申请量为: -60.537589050812365
# agent 4 在 1999 次迭代中的资源申请量为: 226.27093995162207
# agent 5 在 1999 次迭代中的资源申请量为: 226.2936925177144
# agent 6 在 1999 次迭代中的资源申请量为: -60.53724493446818
# agent 7 在 1999 次迭代中的资源申请量为: -0.4133400968732437
# agent 8 在 1999 次迭代中的资源申请量为: -60.53561740196548
# agent 9 在 1999 次迭代中的资源申请量为: -60.530624889938245
# agent 10 在 1999 次迭代中的资源申请量为: 226.3067355007378
# agent 11 在 1999 次迭代中的资源申请量为: 1174.8926669655064
# agent 12 在 1999 次迭代中的资源申请量为: -60.5356479312078
# agent 13 在 1999 次迭代中的资源申请量为: -60.537179632322776
# agent 14 在 1999 次迭代中的资源申请量为: -0.40489885051203656
# agent 15 在 1999 次迭代中的资源申请量为: -60.53794443794581
# agent 16 在 1999 次迭代中的资源申请量为: -0.415842359974411
# agent 17 在 1999 次迭代中的资源申请量为: -60.537945175782376
# agent 18 在 1999 次迭代中的资源申请量为: -60.54609630660683
# agent 19 在 1999 次迭代中的资源申请量为: -0.4280988856641965
# agent 20 在 1999 次迭代中的资源申请量为: 1140.6698871607325
# agent 21 在 1999 次迭代中的资源申请量为: 1140.1001832495879
# agent 22 在 1999 次迭代中的资源申请量为: -0.6073429759075044
# agent 23 在 1999 次迭代中的资源申请量为: -0.5991765638858892
# agent 24 在 1999 次迭代中的资源申请量为: 513.0706076913198
# agent 25 在 1999 次迭代中的资源申请量为: 513.1511068588156
# agent 26 在 1999 次迭代中的资源申请量为: -0.5626976631525893
# agent 27 在 1999 次迭代中的资源申请量为: 447.12096208038827
# agent 28 在 1999 次迭代中的资源申请量为: 446.99199981229714
# agent 29 在 1999 次迭代中的资源申请量为: 226.3764678038606
# agent 30 在 1999 次迭代中的资源申请量为: 25.487970046467716
# agent 31 在 1999 次迭代中的资源申请量为: -60.523130029974794
# agent 32 在 1999 次迭代中的资源申请量为: -60.521188007879616
# agent 33 在 1999 次迭代中的资源申请量为: -351.2947429348693
# agent 34 在 1999 次迭代中的资源申请量为: -0.3081105111460425
# agent 35 在 1999 次迭代中的资源申请量为: -0.3006332458586891
# agent 36 在 1999 次迭代中的资源申请量为: 226.45440189025075
# agent 37 在 1999 次迭代中的资源申请量为: -0.2763456726152802
# agent 38 在 1999 次迭代中的资源申请量为: -60.51822958074871
# agent 39 在 1999 次迭代中的资源申请量为: 1175.1792030021754
# agent 40 在 1999 次迭代中的资源申请量为: 226.48297571853928
# agent 41 在 1999 次迭代中的资源申请量为: -351.2571972089766
# agent 42 在 1999 次迭代中的资源申请量为: -262.3256976648558
# agent 43 在 1999 次迭代中的资源申请量为: 226.48889072965062
# agent 44 在 1999 次迭代中的资源申请量为: 226.58716744087548
# agent 45 在 1999 次迭代中的资源申请量为: 226.87334362104633
# agent 46 在 1999 次迭代中的资源申请量为: -351.02953449580934
# agent 47 在 1999 次迭代中的资源申请量为: 0.24639972421372502
# agent 48 在 1999 次迭代中的资源申请量为: 0.2944164722065712
# agent 49 在 1999 次迭代中的资源申请量为: -291.84333303000153
# agent 50 在 1999 次迭代中的资源申请量为: -261.59943999666234
# agent 51 在 1999 次迭代中的资源申请量为: 0.3600887914337325
# agent 52 在 1999 次迭代中的资源申请量为: 0.3600887914337325
# agent 53 在 1999 次迭代中的资源申请量为: -0.4153246920617082
# agent 54 在 1999 次迭代中的资源申请量为: -262.47360519887224
# 资源申请量总和为: 5632.03350160377
# ****************************************************************************
# 成本总和为: 56008.06238018176
# ****************************************************************************
# agent 1 在 1999 次迭代中的对偶变量为: -17.809498930261377
# agent 2 在 1999 次迭代中的对偶变量为: -17.809498930261377
# agent 3 在 1999 次迭代中的对偶变量为: -17.809339867906516
# agent 4 在 1999 次迭代中的对偶变量为: -17.80889294394778
# agent 5 在 1999 次迭代中的对偶变量为: -17.809387812260287
# agent 6 在 1999 次迭代中的对偶变量为: -17.809387812260287
# agent 7 在 1999 次迭代中的对偶变量为: -17.809418493520045
# agent 8 在 1999 次迭代中的对偶变量为: -17.809614569853757
# agent 9 在 1999 次迭代中的对偶变量为: -17.810310156584464
# agent 10 在 1999 次迭代中的对偶变量为: -17.809671497141046
# agent 11 在 1999 次迭代中的对偶变量为: -17.809356001793038
# agent 12 在 1999 次迭代中的对偶变量为: -17.809610316336542
# agent 13 在 1999 次迭代中的对偶变量为: -17.809396910546997
# agent 14 在 1999 次迭代中的对偶变量为: -17.809634589426892
# agent 15 在 1999 次迭代中的对偶变量为: -17.80929035323876
# agent 16 在 1999 次迭代中的对偶变量为: -17.809354435584655
# agent 17 在 1999 次迭代中的对偶变量为: -17.809290250438945
# agent 18 在 1999 次迭代中的对偶变量为: -17.808154585985697
# agent 19 在 1999 次迭代中的对偶变量为: -17.809040668526997
# agent 20 在 1999 次迭代中的对偶变量为: -17.807396798145838
# agent 21 在 1999 次迭代中的对偶变量为: -17.80466107996452
# agent 22 在 1999 次迭代中的对偶变量为: -17.804452019816768
# agent 23 在 1999 次迭代中的对偶变量为: -17.80466107996452
# agent 24 在 1999 次迭代中的对偶变量为: -17.805021347683613
# agent 25 在 1999 次迭代中的对偶变量为: -17.805729740357577
# agent 26 在 1999 次迭代中的对偶变量为: -17.805594939823294
# agent 27 在 1999 次迭代中的对偶变量为: -17.809121976862624
# agent 28 在 1999 次迭代中的对偶变量为: -17.806390556024454
# agent 29 在 1999 次迭代中的对偶变量为: -17.811188174733967
# agent 30 在 1999 次迭代中的对偶变量为: -17.811768096887874
# agent 31 在 1999 次迭代中的对偶变量为: -17.81135438544373
# agent 32 在 1999 次迭代中的对偶变量为: -17.811624959614164
# agent 33 在 1999 次迭代中的对偶变量为: -17.81211237091466
# agent 34 在 1999 次迭代中的对偶变量为: -17.81211237091466
# agent 35 在 1999 次迭代中的对偶变量为: -17.812303788906018
# agent 36 在 1999 次迭代中的对偶变量为: -17.812883241112953
# agent 37 在 1999 次迭代中的对偶变量为: -17.81292555078105
# agent 38 在 1999 次迭代中的对偶变量为: -17.812037145432605
# agent 39 在 1999 次迭代中的对偶变量为: -17.811075218013052
# agent 40 在 1999 次迭代中的对偶变量为: -17.81350472187823
# agent 41 在 1999 次迭代中的对偶变量为: -17.814237609183092
# agent 42 在 1999 次迭代中的对偶变量为: -17.814357262047398
# agent 43 在 1999 次迭代中的对偶变量为: -17.8136333733699
# agent 44 在 1999 次迭代中的对偶变量为: -17.81577089183904
# agent 45 在 1999 次迭代中的对偶变量为: -17.821995223757757
# agent 46 在 1999 次迭代中的对偶变量为: -17.82712422939921
# agent 47 在 1999 次迭代中的对偶变量为: -17.82630783293987
# agent 48 在 1999 次迭代中的对偶变量为: -17.82753706168849
# agent 49 在 1999 次迭代中的对偶变量为: -21.177299977169795
# agent 50 在 1999 次迭代中的对偶变量为: -17.828554146945244
# agent 51 在 1999 次迭代中的对偶变量为: -17.829218273060704
# agent 52 在 1999 次迭代中的对偶变量为: -17.829218273060704
# agent 53 在 1999 次迭代中的对偶变量为: -17.80936768788322
# agent 54 在 1999 次迭代中的对偶变量为: -17.811465965572445
# *************************
# 迭代步长为: 5.936673804708353e-07
# ****************************************************************************
# 2025-06-25 20:25:18.931

# %%
np.savetxt('../data/01-DGD-CTM-robust-agent_resource_quantity_large_value_deterministic_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/01-DGD-CTM-robust-sum_cost_large_value_deterministic_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/01-DGD-CTM-robust-sum_resource_large_value_deterministic_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
