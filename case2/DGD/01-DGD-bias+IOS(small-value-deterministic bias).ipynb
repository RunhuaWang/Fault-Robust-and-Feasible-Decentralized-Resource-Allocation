# %% [markdown]
# IWDGD中小值的确定性噪声 对应到DGD算法中是固定的对偶攻击值为-18.6 这样两个算法各自迭代2000次 所有用户的对偶迭代值均在-18.57附近

# %% [markdown]
# 鲁棒聚合器IOS

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(54,2000)) 
dual_variable = np.zeros(shape=(54,2000))#对偶变量
sum_resource=np.zeros(shape=(1,2000), dtype=np.float64)
sum_cost=np.zeros(shape=(1,2000), dtype=np.float64)
iteration_update = 0.01 #迭代步长
#W=np.zeros(shape=(54,54)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
W=np.loadtxt("double_stochastic_weight_1.txt") #双随机的网络拓扑矩阵W（对角线处非零）
iteration=[]#绘图横坐标
generator_a_values= np.loadtxt("generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("generator_b_values.txt")#每个agent的成本函数中的超参数a
generator_c_values= np.loadtxt("generator_c_values.txt")#每个agent的成本函数中的超参数a
A=np.loadtxt("Adjacency_Matrix_generator_zero.txt") #网络拓扑邻接矩阵（对角线处为0）
D=np.loadtxt("degree_generator.txt") #用户的度
neighbor=np.zeros(shape=(54,17))#定义矩阵存放54个用户的邻居
neighbor_help=[]#辅助求用户邻居的列表
q=1

# %%
#对偶变量的初始化 初始化一致
for i in range (0,54):
    dual_variable[i][0]=0
    
#资源量的初始化 资源量的初始化需要和对偶变量的初始值满足某种关系
for i in range (0,54):
    agent_resource_quantity[i][0]=6000/54

iteration.append(0)

#总资源量 初始化
sum=0
for i in range (0,54):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

#用户总成本初始化
sum=0
for i in range(0,54):
    sum=sum+(generator_c_values[i]*(agent_resource_quantity[i][0])*(agent_resource_quantity[i][0])+generator_b_values[i]*agent_resource_quantity[i][0]+generator_a_values[i])
sum_cost[0][0]=sum

#对用户邻居进行初始化
for i in range(0,54):
    for j in range(0,17):
        neighbor[i][j]=99 #先将矩阵中的所有数字设定为一个不可能的数字
#根据邻接矩阵求每个用户的邻居集合
for i in range(0,54):
    for j in range(0,54):
        if A[i][j]!=0:
            neighbor_help.append(j)
l=0
for i in range(0,54):
    g=0
    for j in range(l,l+int(D[i])):
        neighbor[i][g]=neighbor_help[j]  
        g=g+1
    l=l+int(D[i])

# %%
#DGD算法 
def DGD_IOS_determinitic_bias(D,neighbor,generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,dual_variable,iteration_update,W,iteration):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************DGD算法+无计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,54):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    for i in range(0,54):
        print("agent",(i+1),"的初始对偶变量为:",dual_variable[i][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,2000):#迭代次数
        iteration.append(k)
        
        #所有用户对偶变量的迭代 
        #阶段一：梯度下降
        dual_variable_intermediate=[] #存放当前迭代中54个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,54):
            #每个用户对对偶变量先进行一次梯度下降
            if i==48:
                dual_variable_intermediate.append(-18.6)
            else:
                dual_variable_intermediate.append(dual_variable[i][k-1]-iteration_update*((6000/54)-agent_resource_quantity[i][k-1]))             
        #阶段二：鲁棒聚合 IOS       
        for i in range(0,54):
            #先根据用户的度来判断其是否需要做IOS操作 
            if int(D[i])>=2: 
            #if i==44 or i==47 or i==48:
                u_neighbor_help=[]
                for j in range(0,int(D[i])):
                    u_neighbor_help.append(int(neighbor[i][j])) 
                u_neighbor_help.append(i)
                for q_help in range(0, int(q)):#剔除q个邻居的信息
                    dual_variable_weight_average=0
                    h=0
                    for j in range(0,len(u_neighbor_help)):#计算当前循环中的h值
                        h=h+W[i][u_neighbor_help[j]]
                    for j in range(0,len(u_neighbor_help)):#计算当前循环中的对偶权重平均值
                        dual_variable_weight_average=dual_variable_weight_average+(1/h)*(W[i][u_neighbor_help[j]]*dual_variable_intermediate[u_neighbor_help[j]])
                    #剔除一个对偶值离权重平均对偶值最远的用户 保留自身的值
                    neighbor_index=u_neighbor_help[0]
                    max_distance=abs(dual_variable_intermediate[u_neighbor_help[0]]-dual_variable_weight_average)
                    for j in range(1,len(u_neighbor_help)):
                        if abs(dual_variable_intermediate[u_neighbor_help[j]]-dual_variable_weight_average)>=max_distance:
                            max_distance=abs(dual_variable_intermediate[u_neighbor_help[j]]-dual_variable_weight_average)
                            neighbor_index=u_neighbor_help[j]
                    u_neighbor_help.remove(neighbor_index)
                dual_variable_weight_average=0
                h=0  
                for j in range(0,len(u_neighbor_help)):
                    h=h+W[i][u_neighbor_help[j]]
                for j in range(0,len(u_neighbor_help)):
                    dual_variable_weight_average=dual_variable_weight_average+(1/h)*(W[i][u_neighbor_help[j]]*dual_variable_intermediate[u_neighbor_help[j]]) 
                dual_variable[i][k]=dual_variable_weight_average
            else:
                mix_sum_dual=0           
                for j in range(0,54):
                    mix_sum_dual=mix_sum_dual+W[i][j]*dual_variable_intermediate[j]
                dual_variable[i][k]=mix_sum_dual                    
        
        #用户资源申请量的迭代
        for i in range (0,54):
            agent_resource_quantity[i][k]=(-dual_variable[i][k]-generator_b_values[i])/(2*generator_c_values[i]) 

        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,54):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,54):
            sum2=sum2+(generator_a_values[i]+(generator_b_values[i]*agent_resource_quantity[i][k])+(generator_c_values[i]*agent_resource_quantity[i][k]*agent_resource_quantity[i][k]))
        sum_cost[0][k]=sum2
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%20==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,54):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            for i in range(0,54):
                print("agent",(i+1),"在",k,"次迭代中的对偶变量为:",dual_variable[i][k])   
            print("*************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=(1/(pow(k+1,1.3)))*(1/26.511) #递减步长
        iteration_update=(1/(pow(k+1,1.5)))*(1/18.8468) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
DGD_IOS_determinitic_bias(D,neighbor,generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,dual_variable,iteration_update,W,iteration)
# Out:
# ****************************DGD算法+无计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 111.11111111111111
# agent 2 的初始资源申请量为: 111.11111111111111
# agent 3 的初始资源申请量为: 111.11111111111111
# agent 4 的初始资源申请量为: 111.11111111111111
# agent 5 的初始资源申请量为: 111.11111111111111
# agent 6 的初始资源申请量为: 111.11111111111111
# agent 7 的初始资源申请量为: 111.11111111111111
# agent 8 的初始资源申请量为: 111.11111111111111
# agent 9 的初始资源申请量为: 111.11111111111111
# agent 10 的初始资源申请量为: 111.11111111111111
# agent 11 的初始资源申请量为: 111.11111111111111
# agent 12 的初始资源申请量为: 111.11111111111111
# agent 13 的初始资源申请量为: 111.11111111111111
# agent 14 的初始资源申请量为: 111.11111111111111
# agent 15 的初始资源申请量为: 111.11111111111111
# agent 16 的初始资源申请量为: 111.11111111111111
# agent 17 的初始资源申请量为: 111.11111111111111
# agent 18 的初始资源申请量为: 111.11111111111111
# agent 19 的初始资源申请量为: 111.11111111111111
# agent 20 的初始资源申请量为: 111.11111111111111
# agent 21 的初始资源申请量为: 111.11111111111111
# agent 22 的初始资源申请量为: 111.11111111111111
# agent 23 的初始资源申请量为: 111.11111111111111
# agent 24 的初始资源申请量为: 111.11111111111111
# agent 25 的初始资源申请量为: 111.11111111111111
# agent 26 的初始资源申请量为: 111.11111111111111
# agent 27 的初始资源申请量为: 111.11111111111111
# agent 28 的初始资源申请量为: 111.11111111111111
# agent 29 的初始资源申请量为: 111.11111111111111
# agent 30 的初始资源申请量为: 111.11111111111111
# agent 31 的初始资源申请量为: 111.11111111111111
# agent 32 的初始资源申请量为: 111.11111111111111
# agent 33 的初始资源申请量为: 111.11111111111111
# agent 34 的初始资源申请量为: 111.11111111111111
# agent 35 的初始资源申请量为: 111.11111111111111
# agent 36 的初始资源申请量为: 111.11111111111111
# agent 37 的初始资源申请量为: 111.11111111111111
# agent 38 的初始资源申请量为: 111.11111111111111
# agent 39 的初始资源申请量为: 111.11111111111111
# agent 40 的初始资源申请量为: 111.11111111111111
# agent 41 的初始资源申请量为: 111.11111111111111
# agent 42 的初始资源申请量为: 111.11111111111111
# agent 43 的初始资源申请量为: 111.11111111111111
# agent 44 的初始资源申请量为: 111.11111111111111
# agent 45 的初始资源申请量为: 111.11111111111111
# agent 46 的初始资源申请量为: 111.11111111111111
# agent 47 的初始资源申请量为: 111.11111111111111
# agent 48 的初始资源申请量为: 111.11111111111111
# agent 49 的初始资源申请量为: 111.11111111111111
# agent 50 的初始资源申请量为: 111.11111111111111
# agent 51 的初始资源申请量为: 111.11111111111111
# agent 52 的初始资源申请量为: 111.11111111111111
# agent 53 的初始资源申请量为: 111.11111111111111
# agent 54 的初始资源申请量为: 111.11111111111111
# *************************
# 初始资源申请量总和为: 6000.000000000006
# *************************
# 初始成本总和为: 139226.02283950621
# *************************
# agent 1 的初始对偶变量为: 0.0
# agent 2 的初始对偶变量为: 0.0
# agent 3 的初始对偶变量为: 0.0
# agent 4 的初始对偶变量为: 0.0
# agent 5 的初始对偶变量为: 0.0
# agent 6 的初始对偶变量为: 0.0
# agent 7 的初始对偶变量为: 0.0
# agent 8 的初始对偶变量为: 0.0
# agent 9 的初始对偶变量为: 0.0
# agent 10 的初始对偶变量为: 0.0
# agent 11 的初始对偶变量为: 0.0
# agent 12 的初始对偶变量为: 0.0
# agent 13 的初始对偶变量为: 0.0
# agent 14 的初始对偶变量为: 0.0
# agent 15 的初始对偶变量为: 0.0
# agent 16 的初始对偶变量为: 0.0
# agent 17 的初始对偶变量为: 0.0
# agent 18 的初始对偶变量为: 0.0
# agent 19 的初始对偶变量为: 0.0
# agent 20 的初始对偶变量为: 0.0
# agent 21 的初始对偶变量为: 0.0
# agent 22 的初始对偶变量为: 0.0
# agent 23 的初始对偶变量为: 0.0
# agent 24 的初始对偶变量为: 0.0
# agent 25 的初始对偶变量为: 0.0
# agent 26 的初始对偶变量为: 0.0
# agent 27 的初始对偶变量为: 0.0
# agent 28 的初始对偶变量为: 0.0
# agent 29 的初始对偶变量为: 0.0
# agent 30 的初始对偶变量为: 0.0
# agent 31 的初始对偶变量为: 0.0
# agent 32 的初始对偶变量为: 0.0
# agent 33 的初始对偶变量为: 0.0
# agent 34 的初始对偶变量为: 0.0
# agent 35 的初始对偶变量为: 0.0
# agent 36 的初始对偶变量为: 0.0
# agent 37 的初始对偶变量为: 0.0
# agent 38 的初始对偶变量为: 0.0
# agent 39 的初始对偶变量为: 0.0
# agent 40 的初始对偶变量为: 0.0
# agent 41 的初始对偶变量为: 0.0
# agent 42 的初始对偶变量为: 0.0
# agent 43 的初始对偶变量为: 0.0
# agent 44 的初始对偶变量为: 0.0
# agent 45 的初始对偶变量为: 0.0
# agent 46 的初始对偶变量为: 0.0
# agent 47 的初始对偶变量为: 0.0
# agent 48 的初始对偶变量为: 0.0
# agent 49 的初始对偶变量为: 0.0
# agent 50 的初始对偶变量为: 0.0
# agent 51 的初始对偶变量为: 0.0
# agent 52 的初始对偶变量为: 0.0
# agent 53 的初始对偶变量为: 0.0
# agent 54 的初始对偶变量为: 0.0
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 19 次迭代中的结果：
# agent 1 在 19 次迭代中的资源申请量为: -65.01735716898321
# agent 2 在 19 次迭代中的资源申请量为: -65.01735716898321
# agent 3 在 19 次迭代中的资源申请量为: -66.97196272544689
# agent 4 在 19 次迭代中的资源申请量为: 162.8314616632182
# agent 5 在 19 次迭代中的资源申请量为: 191.54238490981737
# agent 6 在 19 次迭代中的资源申请量为: -65.9622262048108
# agent 7 在 19 次迭代中的资源申请量为: -27.890908386775656
# agent 8 在 19 次迭代中的资源申请量为: -64.35565318123832
# agent 9 在 19 次迭代中的资源申请量为: -64.35710688758503
# agent 10 在 19 次迭代中的资源申请量为: 203.14314153632142
# agent 11 在 19 次迭代中的资源申请量为: 1037.7526758674974
# agent 12 在 19 次迭代中的资源申请量为: -64.20719127701715
# agent 13 在 19 次迭代中的资源申请量为: -65.82816825336064
# agent 14 在 19 次迭代中的资源申请量为: -20.77346390262358
# agent 15 在 19 次迭代中的资源申请量为: -65.26996605274599
# agent 16 在 19 次迭代中的资源申请量为: -32.92935710735273
# agent 17 在 19 次迭代中的资源申请量为: -66.82587596282167
# agent 18 在 19 次迭代中的资源申请量为: -75.92709769220168
# agent 19 在 19 次迭代中的资源申请量为: 2.958397247723593
# agent 20 在 19 次迭代中的资源申请量为: 762.2324710380716
# agent 21 在 19 次迭代中的资源申请量为: 658.0038331562763
# agent 22 在 19 次迭代中的资源申请量为: -91.33024783604975
# agent 23 在 19 次迭代中的资源申请量为: -91.02990598373286
# agent 24 在 19 次迭代中的资源申请量为: 222.2322312728982
# agent 25 在 19 次迭代中的资源申请量为: 199.52401767450388
# agent 26 在 19 次迭代中的资源申请量为: -111.0994788252781
# agent 27 在 19 次迭代中的资源申请量为: 383.31169583415306
# agent 28 在 19 次迭代中的资源申请量为: 318.5263628979549
# agent 29 在 19 次迭代中的资源申请量为: 256.6247640632923
# agent 30 在 19 次迭代中的资源申请量为: 26.3657209727533
# agent 31 在 19 次迭代中的资源申请量为: -64.54529356868282
# agent 32 在 19 次迭代中的资源申请量为: -64.69055709607672
# agent 33 在 19 次迭代中的资源申请量为: -331.15919127739886
# agent 34 在 19 次迭代中的资源申请量为: 44.213481911488934
# agent 35 在 19 次迭代中的资源申请量为: 34.02437043854581
# agent 36 在 19 次迭代中的资源申请量为: 246.37995008399642
# agent 37 在 19 次迭代中的资源申请量为: 10.261248375105364
# agent 38 在 19 次迭代中的资源申请量为: -60.60840762410332
# agent 39 在 19 次迭代中的资源申请量为: 979.4877345177478
# agent 40 在 19 次迭代中的资源申请量为: 218.53394072921097
# agent 41 在 19 次迭代中的资源申请量为: -195.22020858118262
# agent 42 在 19 次迭代中的资源申请量为: 189.4953607850801
# agent 43 在 19 次迭代中的资源申请量为: 222.73463916314736
# agent 44 在 19 次迭代中的资源申请量为: 221.0594582114356
# agent 45 在 19 次迭代中的资源申请量为: 284.03871422630425
# agent 46 在 19 次迭代中的资源申请量为: -287.41802000052013
# agent 47 在 19 次迭代中的资源申请量为: 139.49599324251076
# agent 48 在 19 次迭代中的资源申请量为: 128.42479377255717
# agent 49 在 19 次迭代中的资源申请量为: -335.89901166385243
# agent 50 在 19 次迭代中的资源申请量为: -74.5346758889219
# agent 51 在 19 次迭代中的资源申请量为: 142.2677600131246
# agent 52 在 19 次迭代中的资源申请量为: 142.2677600131246
# agent 53 在 19 次迭代中的资源申请量为: -31.413835565822083
# agent 54 在 19 次迭代中的资源申请量为: -224.88397051510404
# 资源申请量总和为: 4652.56786721919
# ****************************************************************************
# 成本总和为: 45331.874041144605
# ****************************************************************************
# agent 1 在 19 次迭代中的对偶变量为: -17.185191695074245
# agent 2 在 19 次迭代中的对偶变量为: -17.185191695074245
# agent 3 在 19 次迭代中的对偶变量为: -16.912864321314387
# agent 4 在 19 次迭代中的对偶变量为: -16.429084291174995
# agent 5 在 19 次迭代中的对偶变量为: -17.053546871788527
# agent 6 在 19 次迭代中的对偶变量为: -17.05354687178853
# agent 7 在 19 次迭代中的对偶变量为: -17.105992745298543
# agent 8 在 19 次迭代中的对偶变量为: -17.27738426487079
# agent 9 在 19 次迭代中的对偶变量为: -17.277181725780327
# agent 10 在 19 次迭代中的对偶变量为: -17.30586332841499
# agent 11 在 19 次迭代中的对偶变量为: -16.986516055204984
# agent 12 在 19 次迭代中的对偶变量为: -17.29806886813831
# agent 13 在 19 次迭代中的对偶变量为: -17.072224629932276
# agent 14 在 19 次迭代中的对偶变量为: -17.288199324092837
# agent 15 在 19 次迭代中的对偶变量为: -17.149996709735113
# agent 16 在 19 次迭代中的对偶变量为: -16.97700845805177
# agent 17 在 19 次迭代中的对偶变量为: -16.93321800560391
# agent 18 在 19 次迭代中的对偶变量为: -15.665181186936309
# agent 19 在 19 次迭代中的对偶变量为: -17.895734969541724
# agent 20 在 19 次迭代中的对偶变量为: -15.99014032592482
# agent 21 在 19 次迭代中的对偶变量为: -15.489634406816439
# agent 22 在 19 次迭代中的对偶变量为: -15.481945655397126
# agent 23 在 19 次迭代中的对偶变量为: -15.489634406816439
# agent 24 在 19 次迭代中的对偶变量为: -15.245643635201503
# agent 25 在 19 次迭代中的对偶变量为: -15.045811355535633
# agent 26 在 19 次迭代中的对偶变量为: -14.975853342072881
# agent 27 在 19 次迭代中的对偶变量为: -16.457641717767363
# agent 28 在 19 次迭代中的对偶变量为: -15.085488366178685
# agent 29 在 19 次迭代中的对偶变量为: -18.469088618376606
# agent 30 在 19 次迭代中的对偶变量为: -17.8923860084635
# agent 31 在 19 次迭代中的对偶变量为: -17.250962428249697
# agent 32 在 19 次迭代中的对偶变量为: -17.230723442032016
# agent 33 在 19 次迭代中的对偶变量为: -18.951865136934117
# agent 34 在 19 次迭代中的对偶变量为: -18.951865136934117
# agent 35 在 19 次迭代中的对偶变量为: -18.691023883226773
# agent 36 在 19 次迭代中的对偶变量为: -18.24626391432692
# agent 37 在 19 次迭代中的对偶变量为: -18.082687958402698
# agent 38 在 19 次迭代中的对偶变量为: -17.79947299936418
# agent 39 在 19 次迭代中的对偶变量为: -16.636926407106486
# agent 40 在 19 次迭代中的对偶变量为: -17.640613210860337
# agent 41 在 19 次迭代中的对偶变量为: -26.646555313470742
# agent 42 在 19 次迭代中的对偶变量为: -26.646555312626745
# agent 43 在 19 次迭代中的对偶变量为: -17.731978401798454
# agent 44 在 19 次迭代中的对偶变量为: -17.695543216098724
# agent 45 在 19 次迭代中的对偶变量为: -19.065342034422116
# agent 46 在 19 次迭代中的对偶变量为: -21.42779039589056
# agent 47 在 19 次迭代中的对偶变量为: -21.391097427008276
# agent 48 在 19 次迭代中的对偶变量为: -21.107674720577464
# agent 49 在 19 次迭代中的对偶变量为: -18.6835723437793
# agent 50 在 19 次迭代中的对偶变量为: -21.485296155723354
# agent 51 在 19 次迭代中的对偶变量为: -21.46205465633599
# agent 52 在 19 次迭代中的对偶变量为: -21.46205465633599
# agent 53 在 19 次迭代中的对偶变量为: -17.015805809514955
# agent 54 在 19 次迭代中的对偶变量为: -18.546268144370746
# *************************
# 迭代步长为: 0.0006406664425248283
# ****************************************************************************
# 39 次迭代中的结果：
# agent 1 在 39 次迭代中的资源申请量为: -60.311791175022876
# agent 2 在 39 次迭代中的资源申请量为: -60.311791175022876
# agent 3 在 39 次迭代中的资源申请量为: -61.04894338685075
# agent 4 在 39 次迭代中的资源申请量为: 213.6463152693756
# agent 5 在 39 次迭代中的资源申请量为: 225.7362887640974
# agent 6 在 39 次迭代中的资源申请量为: -60.62426050687509
# agent 7 在 39 次迭代中的资源申请量为: 0.6534613980803405
# agent 8 在 39 次迭代中的资源申请量为: -59.192687735859685
# agent 9 在 39 次迭代中的资源申请量为: -58.721924743984154
# agent 10 在 39 次迭代中的资源申请量为: 235.6460577027188
# agent 11 在 39 次迭代中的资源申请量为: 1171.6226653956203
# agent 12 在 39 次迭代中的资源申请量为: -59.22016628135261
# agent 13 在 39 次迭代中的资源申请量为: -60.37434984947508
# agent 14 在 39 次迭代中的资源申请量为: 6.873642768264743
# agent 15 在 39 次迭代中的资源申请量为: -60.235479949045505
# agent 16 在 39 次迭代中的资源申请量为: -1.9042589025006218
# agent 17 在 39 次迭代中的资源申请量为: -60.99233321204329
# agent 18 在 39 次迭代中的资源申请量为: -71.25796774699698
# agent 19 在 39 次迭代中的资源申请量为: 13.981074251767089
# agent 20 在 39 次迭代中的资源申请量为: 853.5113580155707
# agent 21 在 39 次迭代中的资源申请量为: 648.755752330105
# agent 22 在 39 次迭代中的资源申请量为: -91.0260633423618
# agent 23 在 39 次迭代中的资源申请量为: -92.76464364495452
# agent 24 在 39 次迭代中的资源申请量为: 248.99407966647436
# agent 25 在 39 次迭代中的资源申请量为: 253.15481380843605
# agent 26 在 39 次迭代中的资源申请量为: -86.54854011223483
# agent 27 在 39 次迭代中的资源申请量为: 429.21629958351605
# agent 28 在 39 次迭代中的资源申请量为: 351.64765778596524
# agent 29 在 39 次迭代中的资源申请量为: 256.38466343758375
# agent 30 在 39 次迭代中的资源申请量为: 32.539094044459354
# agent 31 在 39 次迭代中的资源申请量为: -57.793472241642405
# agent 32 在 39 次迭代中的资源申请量为: -57.51488746580033
# agent 33 在 39 次迭代中的资源申请量为: -336.91667958369874
# agent 34 在 39 次迭代中的资源申请量为: 31.48313550173115
# agent 35 在 39 次迭代中的资源申请量为: 27.4966822200709
# agent 36 在 39 次迭代中的资源申请量为: 259.0124462984188
# agent 37 在 39 次迭代中的资源申请量为: 24.16768633415306
# agent 38 在 39 次迭代中的资源申请量为: -56.47501772757261
# agent 39 在 39 次迭代中的资源申请量为: 1193.9057872424692
# agent 40 在 39 次迭代中的资源申请量为: 250.15601783077102
# agent 41 在 39 次迭代中的资源申请量为: -183.63579365683665
# agent 42 在 39 次迭代中的资源申请量为: 223.0396733959326
# agent 43 在 39 次迭代中的资源申请量为: 251.23637240074447
# agent 44 在 39 次迭代中的资源申请量为: 250.77689484950724
# agent 45 在 39 次迭代中的资源申请量为: 295.7456390041981
# agent 46 在 39 次迭代中的资源申请量为: -287.925650047894
# agent 47 在 39 次迭代中的资源申请量为: 137.51523829475005
# agent 48 在 39 次迭代中的资源申请量为: 129.22233629147934
# agent 49 在 39 次迭代中的资源申请量为: -334.25173197860704
# agent 50 在 39 次迭代中的资源申请量为: -68.70835520363946
# agent 51 在 39 次迭代中的资源申请量为: 148.72373269915263
# agent 52 在 39 次迭代中的资源申请量为: 148.72373269915263
# agent 53 在 39 次迭代中的资源申请量为: -0.8892475007891976
# agent 54 在 39 次迭代中的资源申请量为: -224.4622939643054
# 资源申请量总和为: 5760.460268149199
# ****************************************************************************
# 成本总和为: 64774.14398472061
# ****************************************************************************
# agent 1 在 39 次迭代中的对偶变量为: -17.840799382748763
# agent 2 在 39 次迭代中的对偶变量为: -17.840799382748763
# agent 3 在 39 次迭代中的对偶变量为: -17.738094913683632
# agent 4 在 39 次迭代中的对偶变量为: -17.53430735710892
# agent 5 在 39 次迭代中的对偶变量为: -17.797264280619117
# agent 6 在 39 次迭代中的对偶变量为: -17.79726428061912
# agent 7 在 39 次迭代中的对偶变量为: -17.836728611790857
# agent 8 在 39 次迭代中的对偶变量为: -17.996719588513614
# agent 9 在 39 次迭代中的对偶变量为: -18.062309113119664
# agent 10 在 39 次迭代中的对偶变量为: -18.012801755034133
# agent 11 在 39 次迭代中的对偶变量为: -17.78973599237372
# agent 12 在 39 次迭代中的对偶变量为: -17.992891112684266
# agent 13 在 39 次迭代中的对偶变量为: -17.832083332872035
# agent 14 在 39 次迭代中的对偶变量为: -17.995965254867578
# agent 15 在 39 次迭代中的对偶变量为: -17.851431520619286
# agent 16 在 39 次迭代中的对偶变量为: -17.771250972095984
# agent 17 在 39 次迭代中的对偶变量为: -17.745982182898857
# agent 18 在 39 次迭代中的对偶变量为: -16.3157123856819
# agent 19 在 39 次迭代中的对偶变量为: -18.177915500845238
# agent 20 在 39 次迭代中的对偶变量为: -16.42846154119077
# agent 21 在 39 次迭代中的对偶变量为: -15.445225122689164
# agent 22 在 39 次迭代中的对偶变量为: -15.489732778435538
# agent 23 在 39 次迭代中的对偶变量为: -15.445225122689164
# agent 24 在 39 次迭代中的对偶变量为: -15.481147901064974
# agent 25 在 39 次迭代中的对偶变量为: -15.517762361514237
# agent 26 在 39 次迭代中的对偶变量为: -15.604357373126788
# agent 27 在 39 次迭代中的对偶变量为: -17.42990122517887
# agent 28 在 39 次迭代中的对偶变量为: -15.786997391906745
# agent 29 在 39 次迭代中的对偶变量为: -18.463866429767446
# agent 30 在 39 次迭代中的对偶变量为: -18.459385631607415
# agent 31 在 39 次迭代中的对偶变量为: -18.19166668646093
# agent 32 在 39 次迭代中的对偶变量为: -18.230480788939904
# agent 33 在 39 次迭代中的对偶变量为: -18.625968268844318
# agent 34 在 39 次迭代中的对偶变量为: -18.625968268844318
# agent 35 在 39 次迭代中的对偶变量为: -18.523915064833815
# agent 36 在 39 次迭代中的对偶变量为: -18.52102070699061
# agent 37 在 39 次迭代中的对偶变量为: -18.43869277015432
# agent 38 在 39 次迭代中的对偶变量为: -18.37536168008822
# agent 39 在 39 次迭代中的对偶变量为: -17.923434723454815
# agent 40 在 39 次迭代中的对偶变量为: -18.32839338781927
# agent 41 在 39 次迭代中的对偶变量为: -27.30227953584842
# agent 42 在 39 次迭代中的对偶变量为: -27.30227953554369
# agent 43 在 39 次迭代中的对偶变量为: -18.35189109971619
# agent 44 在 39 次迭代中的对偶变量为: -18.34189746297678
# agent 45 在 39 次迭代中的对偶变量为: -19.319967648341308
# agent 46 在 39 次迭代中的对偶变量为: -21.39905650468901
# agent 47 在 39 次迭代中的对偶变量为: -21.3403901003456
# agent 48 在 39 次迭代中的对偶变量为: -21.12809180906187
# agent 49 在 39 次迭代中的对偶变量为: -18.77681496308293
# agent 50 在 39 次迭代中的对偶变量为: -21.599189072479255
# agent 51 在 39 次迭代中的对偶变量为: -21.627327557098308
# agent 52 在 39 次迭代中的对偶变量为: -21.627327557098308
# agent 53 在 39 次迭代中的对偶变量为: -17.797235263979797
# agent 54 在 39 次迭代中的对偶变量为: -18.554511077585758
# *************************
# 迭代步长为: 0.000217853964469636
# ****************************************************************************
# 59 次迭代中的结果：
# agent 1 在 59 次迭代中的资源申请量为: -58.45333119423779
# agent 2 在 59 次迭代中的资源申请量为: -58.45333119423779
# agent 3 在 59 次迭代中的资源申请量为: -58.78375497484621
# agent 4 在 59 次迭代中的资源申请量为: 231.87638932712724
# agent 5 在 59 次迭代中的资源申请量为: 239.16004201693954
# agent 6 在 59 次迭代中的资源申请量为: -58.52869590838441
# agent 7 在 59 次迭代中的资源申请量为: 12.012087749985744
# agent 8 在 59 次迭代中的资源申请量为: -57.2208216895538
# agent 9 在 59 次迭代中的资源申请量为: -56.82893468407787
# agent 10 在 59 次迭代中的资源申请量为: 248.3907805800323
# agent 11 在 59 次迭代中的资源申请量为: 1223.5603682679227
# agent 12 在 59 次迭代中的资源申请量为: -57.16957037058188
# agent 13 在 59 次迭代中的资源申请量为: -58.20445940011275
# agent 14 在 59 次迭代中的资源申请量为: 17.76917448675072
# agent 15 在 59 次迭代中的资源申请量为: -58.24737880804198
# agent 16 在 59 次迭代中的资源申请量为: 10.214231854902694
# agent 17 在 59 次迭代中的资源申请量为: -58.77260021527328
# agent 18 在 59 次迭代中的资源申请量为: -69.17212183289864
# agent 19 在 59 次迭代中的资源申请量为: 20.019464050173436
# agent 20 在 59 次迭代中的资源申请量为: 907.7086755822568
# agent 21 在 59 次迭代中的资源申请量为: 695.4274228507235
# agent 22 在 59 次迭代中的资源申请量为: -82.88886833447417
# agent 23 在 59 次迭代中的资源申请量为: -84.01005919807906
# agent 24 在 59 次迭代中的资源申请量为: 278.50376644630444
# agent 25 在 59 次迭代中的资源申请量为: 288.0404849439542
# agent 26 在 59 次迭代中的资源申请量为: -73.33687136906907
# agent 27 在 59 次迭代中的资源申请量为: 441.41409285419945
# agent 28 在 59 次迭代中的资源申请量为: 367.9860080600568
# agent 29 在 59 次迭代中的资源申请量为: 259.3775135467369
# agent 30 在 59 次迭代中的资源申请量为: 33.6396864893453
# agent 31 在 59 次迭代中的资源申请量为: -56.136546941350346
# agent 32 在 59 次迭代中的资源申请量为: -55.92627318445299
# agent 33 在 59 次迭代中的资源申请量为: -336.5689210046888
# agent 34 在 59 次迭代中的资源申请量为: 32.25206232228897
# agent 35 在 59 次迭代中的资源申请量为: 31.4848691760608
# agent 36 在 59 次迭代中的资源申请量为: 263.7958183022807
# agent 37 在 59 次迭代中的资源申请量为: 29.122788124976566
# agent 38 在 59 次迭代中的资源申请量为: -55.39116097245433
# agent 39 在 59 次迭代中的资源申请量为: 1252.8414302584508
# agent 40 在 59 次迭代中的资源申请量为: 258.1862456610334
# agent 41 在 59 次迭代中的资源申请量为: -179.4381260345733
# agent 42 在 59 次迭代中的资源申请量为: 235.19461396418635
# agent 43 在 59 次迭代中的资源申请量为: 258.90768761297767
# agent 44 在 59 次迭代中的资源申请量为: 258.8397875421614
# agent 45 在 59 次迭代中的资源申请量为: 296.76635688951217
# agent 46 在 59 次迭代中的资源申请量为: -290.8886525878583
# agent 47 在 59 次迭代中的资源申请量为: 130.75843150427755
# agent 48 在 59 次迭代中的资源申请量为: 123.72597252456207
# agent 49 在 59 次迭代中的资源申请量为: -334.0486740061321
# agent 50 在 59 次迭代中的资源申请量为: -75.55017135045406
# agent 51 在 59 次迭代中的资源申请量为: 144.00786471189363
# agent 52 在 59 次迭代中的资源申请量为: 144.00786471189363
# agent 53 在 59 次迭代中的资源申请量为: 11.087870181553937
# agent 54 在 59 次迭代中的资源申请量为: -221.95258832631467
# 资源申请量总和为: 6250.107939013373
# ****************************************************************************
# 成本总和为: 73205.0722140466
# ****************************************************************************
# agent 1 在 59 次迭代中的对偶变量为: -18.099731178031625
# agent 2 在 59 次迭代中的对偶变量为: -18.099731178031625
# agent 3 在 59 次迭代中的对偶变量为: -18.053694554374577
# agent 4 在 59 次迭代中的对偶变量为: -17.930811467865016
# agent 5 在 59 次迭代中的对偶变量为: -18.089230913868434
# agent 6 在 59 次迭代中的对偶变量为: -18.089230913868434
# agent 7 在 59 次迭代中的对偶变量为: -18.127509446399635
# agent 8 在 59 次迭代中的对偶变量为: -18.271451797281227
# agent 9 在 59 次迭代中的对偶变量为: -18.326051846206166
# agent 10 在 59 次迭代中的对偶变量为: -18.2899994776157
# agent 11 在 59 次迭代中的对偶变量为: -18.101362209607537
# agent 12 在 59 次迭代中的对偶变量为: -18.27859243854831
# agent 13 在 59 次迭代中的对偶变量为: -18.13440548961989
# agent 14 在 59 次迭代中的对偶变量为: -18.27489086686082
# agent 15 在 59 次迭代中的对偶变量为: -18.128425700190743
# agent 16 在 59 次迭代中的对偶变量为: -18.08148433548551
# agent 17 在 59 次迭代中的对偶变量为: -18.055248702406836
# agent 18 在 59 次迭代中的对偶变量为: -16.606324953509564
# agent 19 在 59 次迭代中的对偶变量为: -18.33249827968444
# agent 20 在 59 次迭代中的对偶变量为: -16.688717060145997
# agent 21 在 59 次迭代中的对偶变量为: -15.669342484529174
# agent 22 在 59 次迭代中的对偶变量为: -15.698044970637461
# agent 23 在 59 次迭代中的对偶变量为: -15.669342484529176
# agent 24 在 59 次迭代中的对偶变量为: -15.740833144727478
# agent 25 在 59 次迭代中的对偶变量为: -15.824756267506796
# agent 26 在 59 次迭代中的对偶变量为: -15.942576092951832
# agent 27 在 59 次迭代中的对偶变量为: -17.688250486651945
# agent 28 在 59 次迭代中的对偶变量为: -16.133043650712004
# agent 29 在 59 次迭代中的对偶变量为: -18.528960919641527
# agent 30 在 59 次迭代中的对偶变量为: -18.56047064530041
# agent 31 在 59 次迭代中的对偶变量为: -18.422519460849422
# agent 32 在 59 次迭代中的对偶变量为: -18.451816062302903
# agent 33 在 59 次迭代中的对偶变量为: -18.645652795450598
# agent 34 在 59 次迭代中的对偶变量为: -18.645652795450598
# agent 35 在 59 次迭代中的对偶变量为: -18.626012650907157
# agent 36 在 59 次迭代中的对偶变量为: -18.625059048074604
# agent 37 在 59 次迭代中的对偶变量为: -18.5655433759994
# agent 38 在 59 次迭代中的对偶变量为: -18.526371106351828
# agent 39 在 59 次迭代中的对偶变量为: -18.277048581550705
# agent 40 在 59 次迭代中的对偶变量为: -18.503050843127475
# agent 41 在 59 次迭代中的对偶变量为: -27.539884313939016
# agent 42 在 59 次迭代中的对偶变量为: -27.539884313771914
# agent 43 在 59 次迭代中的对偶变量为: -18.518742205582264
# agent 44 在 59 次迭代中的对偶变量为: -18.51726537904201
# agent 45 在 59 次迭代中的对偶变量为: -19.34216826234689
# agent 46 在 59 次迭代中的对偶变量为: -21.231338708916873
# agent 47 在 59 次迭代中的对偶变量为: -21.167415846509506
# agent 48 在 59 次迭代中的对偶变量为: -20.98738489662879
# agent 49 在 59 次迭代中的对偶变量为: -18.788308856556903
# agent 50 在 59 次迭代中的对偶变量为: -21.465445250441324
# agent 51 在 59 次迭代中的对偶变量为: -21.506601336624477
# agent 52 在 59 次迭代中的对偶变量为: -21.506601336624477
# agent 53 在 59 次迭代中的对偶变量为: -18.10384947664778
# agent 54 在 59 次迭代中的对偶变量为: -18.6035708033972
# *************************
# 迭代步长为: 0.00011708044397666381
# ****************************************************************************
# 79 次迭代中的结果：
# agent 1 在 79 次迭代中的资源申请量为: -57.14993725265963
# agent 2 在 79 次迭代中的资源申请量为: -57.14993725265963
# agent 3 在 79 次迭代中的资源申请量为: -57.360584121678684
# agent 4 在 79 次迭代中的资源申请量为: 242.8495614261759
# agent 5 在 79 次迭代中的资源申请量为: 247.73886338306482
# agent 6 在 79 次迭代中的资源申请量为: -57.18946730271695
# agent 7 在 79 次迭代中的资源申请量为: 18.91633107954968
# agent 8 在 79 次迭代中的资源申请量为: -56.20329784112935
# agent 9 在 79 次迭代中的资源申请量为: -55.91541141283581
# agent 10 在 79 次迭代中的资源申请量为: 254.74271903297662
# agent 11 在 79 次迭代中的资源申请量为: 1254.5143015463086
# agent 12 在 79 次迭代中的资源申请量为: -56.14875354616653
# agent 13 在 79 次迭代中的资源申请量为: -56.93412817784628
# agent 14 在 79 次迭代中的资源申请量为: 23.31038820904338
# agent 15 在 79 次迭代中的资源申请量为: -57.002141358736296
# agent 16 在 79 次迭代中的资源申请量为: 17.636234359004742
# agent 17 在 79 次迭代中的资源申请量为: -57.40224801802455
# agent 18 在 79 次迭代中的资源申请量为: -67.39312330083158
# agent 19 在 79 次迭代中的资源申请量为: 24.878539539380792
# agent 20 在 79 次迭代中的资源申请量为: 956.5888680653147
# agent 21 在 79 次迭代中的资源申请量为: 750.9968411002019
# agent 22 在 79 次迭代中的资源申请量为: -72.73009297792967
# agent 23 在 79 次迭代中的资源申请量为: -73.5864519155012
# agent 24 在 79 次迭代中的资源申请量为: 309.98591234342393
# agent 25 在 79 次迭代中的资源申请量为: 321.1160251543112
# agent 26 在 79 次迭代中的资源申请量为: -61.72580383414797
# agent 27 在 79 次迭代中的资源申请量为: 450.3598645468999
# agent 28 在 79 次迭代中的资源申请量为: 381.7476105765214
# agent 29 在 79 次迭代中的资源申请量为: 262.9372141182021
# agent 30 在 79 次迭代中的资源申请量为: 34.37341565380682
# agent 31 在 79 次迭代中的资源申请量为: -55.426048889090914
# agent 32 在 79 次迭代中的资源申请量为: -55.27745025309374
# agent 33 在 79 次迭代中的资源申请量为: -335.7135415901514
# agent 34 在 79 次迭代中的资源申请量为: 34.143386399651256
# agent 35 在 79 次迭代中的资源申请量为: 33.929397242895284
# agent 36 在 79 次迭代中的资源申请量为: 267.7502469436925
# agent 37 在 79 次迭代中的资源申请量为: 32.88529140181198
# agent 38 在 79 次迭代中的资源申请量为: -54.59579874543788
# agent 39 在 79 次迭代中的资源申请量为: 1285.5048648176632
# agent 40 在 79 次迭代中的资源申请量为: 263.7124374989235
# agent 41 在 79 次迭代中的资源申请量为: -177.16128960458119
# agent 42 在 79 次迭代中的资源申请量为: 241.78751601766345
# agent 43 在 79 次迭代中的资源申请量为: 264.28714422386184
# agent 44 在 79 次迭代中的资源申请量为: 264.3662786243329
# agent 45 在 79 次迭代中的资源申请量为: 296.71315697773
# agent 46 在 79 次迭代中的资源申请量为: -294.0816296474676
# agent 47 在 79 次迭代中的资源申请量为: 123.78506730031214
# agent 48 在 79 次迭代中的资源申请量为: 117.60604828790322
# agent 49 在 79 次迭代中的资源申请量为: -334.012464990682
# agent 50 在 79 次迭代中的资源申请量为: -84.95845491169594
# agent 51 在 79 次迭代中的资源申请量为: 136.89520892511018
# agent 52 在 79 次迭代中的资源申请量为: 136.89520892511018
# agent 53 在 79 次迭代中的资源申请量为: 18.292835973509472
# agent 54 在 79 次迭代中的资源申请量为: -218.20132920257672
# 资源申请量总和为: 6617.927393546716
# ****************************************************************************
# 成本总和为: 79429.24051063808
# ****************************************************************************
# agent 1 在 79 次迭代中的对偶变量为: -18.281327842335944
# agent 2 在 79 次迭代中的对偶变量为: -18.281327842335944
# agent 3 在 79 次迭代中的对偶变量为: -18.251979256662995
# agent 4 在 79 次迭代中的对偶变量为: -18.169477961019325
# agent 5 在 79 次迭代中的对偶变量为: -18.27582027858166
# agent 6 在 79 次迭代中的对偶变量为: -18.27582027858166
# agent 7 在 79 次迭代中的对偶变量为: -18.304258075636472
# agent 8 在 79 次迭代中的对偶变量为: -18.413219324986812
# agent 9 在 79 次迭代中的对偶变量为: -18.453329389495238
# agent 10 在 79 次迭代中的对偶变量为: -18.42815413896724
# agent 11 在 79 次迭代中的对偶变量为: -18.28708580927785
# agent 12 在 79 次迭代中的对偶变量为: -18.4208187634268
# agent 13 在 79 次迭代中的对偶变量为: -18.31139565749339
# agent 14 在 79 次迭代中的对偶变量为: -18.41674593815151
# agent 15 在 79 次迭代中的对偶变量为: -18.301919653052707
# agent 16 在 79 次迭代中的对偶变量为: -18.27148759959052
# agent 17 在 79 次迭代中的对偶变量为: -18.24617439264071
# agent 18 在 79 次迭代中的对偶变量为: -16.85418570298834
# agent 19 在 79 次迭代中的对偶变量为: -18.45689061220815
# agent 20 在 79 次迭代中的对偶变量为: -16.92343974444964
# agent 21 在 79 次迭代中的对偶变量为: -15.93618683096317
# agent 22 在 79 次迭代中的对偶变量为: -15.958109619765
# agent 23 在 79 次迭代中的对偶变量为: -15.93618683096317
# agent 24 在 79 次迭代中的对偶变量为: -16.01787602862213
# agent 25 在 79 次迭代中的对偶变量为: -16.115821021357938
# agent 26 在 79 次迭代中的对偶变量为: -16.239819421845812
# agent 27 在 79 次迭代中的对偶变量为: -17.87772193110334
# agent 28 在 79 次迭代中的对偶变量为: -16.424514392010725
# agent 29 在 79 次迭代中的对偶变量为: -18.606384407070895
# agent 30 在 79 次迭代中的对偶变量为: -18.627860734139542
# agent 31 在 79 次迭代中的对偶变量为: -18.52151031247852
# agent 32 在 79 次迭代中的对偶变量为: -18.542213966037462
# agent 33 在 79 次迭代中的对偶变量为: -18.694070691831072
# agent 34 在 79 次迭代中的对偶变量为: -18.694070691831072
# agent 35 在 79 次迭代中的对偶变量为: -18.68859256941812
# agent 36 在 79 次迭代中的对偶变量为: -18.71106787102531
# agent 37 在 79 次迭代中的对偶变量为: -18.661863459886387
# agent 38 在 79 次迭代中的对偶变量为: -18.637185743993122
# agent 39 在 79 次迭代中的对偶变量为: -18.47302918890598
# agent 40 在 79 次迭代中的对偶变量为: -18.623245515601585
# agent 41 在 79 次迭代中的对偶变量为: -27.66876236322229
# agent 42 在 79 次迭代中的对偶变量为: -27.668762363113284
# agent 43 在 79 次迭代中的对偶变量为: -18.635745386868994
# agent 44 在 79 次迭代中的对偶变量为: -18.63746656007924
# agent 45 在 79 次迭代中的对偶变量为: -19.341011164265627
# agent 46 在 79 次迭代中的对偶变量为: -21.05060343543475
# agent 47 在 79 次迭代中的对偶变量为: -20.98889772288799
# agent 48 在 79 次迭代中的对偶变量为: -20.830714836170323
# agent 49 在 79 次迭代中的对偶变量为: -18.79035843166744
# agent 50 在 79 次迭代中的对偶变量为: -21.281532123386167
# agent 51 在 79 次迭代中的对偶变量为: -21.32451734848282
# agent 52 在 79 次迭代中的对偶变量为: -21.32451734848282
# agent 53 在 79 次迭代中的对偶变量为: -18.288296600921843
# agent 54 在 79 次迭代中的对偶变量为: -18.67690041674803
# *************************
# 迭代步长为: 7.556518347445504e-05
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: -56.280642573596126
# agent 2 在 99 次迭代中的资源申请量为: -56.280642573596126
# agent 3 在 99 次迭代中的资源申请量为: -56.434438344509005
# agent 4 在 99 次迭代中的资源申请量为: 249.91927460357573
# agent 5 在 99 次迭代中的资源申请量为: 253.34386041514932
# agent 6 在 99 次迭代中的资源申请量为: -56.314478532151206
# agent 7 在 99 次迭代中的资源申请量为: 23.378959247686016
# agent 8 在 99 次迭代中的资源申请量为: -55.57416663346823
# agent 9 在 99 次迭代中的资源申请量为: -55.35889208502929
# agent 10 在 99 次迭代中的资源申请量为: 258.6273703858676
# agent 11 在 99 次迭代中的资源申请量为: 1274.360015562953
# agent 12 在 99 次迭代中的资源申请量为: -55.52627123127648
# agent 13 在 99 次迭代中的资源申请量为: -56.122586049906495
# agent 14 在 99 次迭代中的资源申请量为: 26.720263021497573
# agent 15 在 99 次迭代中的资源申请量为: -56.19443955040993
# agent 16 在 99 次迭代中的资源申请量为: 22.43032502565689
# agent 17 在 99 次迭代中的资源申请量为: -56.51125668888916
# agent 18 在 99 次迭代中的资源申请量为: -65.94305842721832
# agent 19 在 99 次迭代中的资源申请量为: 28.069765491573747
# agent 20 在 99 次迭代中的资源申请量为: 994.341734056553
# agent 21 在 99 次迭代中的资源申请量为: 790.6163611394808
# agent 22 在 99 次迭代中的资源申请量为: -66.87311832554055
# agent 23 在 99 次迭代中的资源申请量为: -66.15469663313333
# agent 24 在 99 次迭代中的资源申请量为: 334.35684193235403
# agent 25 在 99 次迭代中的资源申请量为: 349.22919506036783
# agent 26 在 99 次迭代中的资源申请量为: -51.81212436808038
# agent 27 在 99 次迭代中的资源申请量为: 456.82376087586783
# agent 28 在 99 次迭代中的资源申请量为: 393.239054320559
# agent 29 在 99 次迭代中的资源申请量为: 265.2916625017581
# agent 30 在 99 次迭代中的资源申请量为: 34.82874355517038
# agent 31 在 99 次迭代中的资源申请量为: -55.001522610248905
# agent 32 在 99 次迭代中的资源申请量为: -54.89326721266514
# agent 33 在 99 次迭代中的资源申请量为: -335.1567959757441
# agent 34 在 99 次迭代中的资源申请量为: 35.37440314800716
# agent 35 在 99 次迭代中的资源申请量为: 35.48373116644396
# agent 36 在 99 次迭代中的资源申请量为: 270.15148147328387
# agent 37 在 99 次迭代中的资源申请量为: 35.229407860318666
# agent 38 在 99 次迭代中的资源申请量为: -54.09759438860775
# agent 39 在 99 次迭代中的资源申请量为: 1304.9137333932679
# agent 40 在 99 次迭代中的资源申请量为: 267.1470781428467
# agent 41 在 99 次迭代中的资源申请量为: -175.69552436703728
# agent 42 在 99 次迭代中的资源申请量为: 246.03184666717814
# agent 43 在 99 次迭代中的资源申请量为: 267.58162125384814
# agent 44 在 99 次迭代中的资源申请量为: 267.7089108642095
# agent 45 在 99 次迭代中的资源申请量为: 295.76518265562004
# agent 46 在 99 次迭代中的资源申请量为: -297.23010467777783
# agent 47 在 99 次迭代中的资源申请量为: 116.98013017653302
# agent 48 在 99 次迭代中的资源申请量为: 111.4539182014293
# agent 49 在 99 次迭代中的资源申请量为: -334.08570248532857
# agent 50 在 99 次迭代中的资源申请量为: -94.73071795321778
# agent 51 在 99 次迭代中的资源申请量为: 129.38023755281026
# agent 52 在 99 次迭代中的资源申请量为: 129.38023755281026
# agent 53 在 99 次迭代中的资源申请量为: 22.92709267002868
# agent 54 在 99 次迭代中的资源申请量为: -215.75677431474094
# 资源申请量总和为: 6863.057383972535
# ****************************************************************************
# 成本总和为: 83549.03228049641
# ****************************************************************************
# agent 1 在 99 次迭代中的对偶变量为: -18.402443192791146
# agent 2 在 99 次迭代中的对偶变量为: -18.402443192791146
# agent 3 在 99 次迭代中的对偶变量为: -18.381015443212938
# agent 4 在 99 次迭代中的对偶变量为: -18.32324422262777
# agent 5 在 99 次迭代中的对偶变量为: -18.397728964029497
# agent 6 在 99 次迭代中的对偶变量为: -18.3977289640295
# agent 7 在 99 次迭代中的对偶变量为: -18.418501356740762
# agent 8 在 99 次迭代中的对偶变量为: -18.500873659625405
# agent 9 在 99 次迭代中的对偶变量为: -18.53086700136121
# agent 10 在 99 次迭代中的对偶变量为: -18.51264530589262
# agent 11 在 99 次迭代中的对偶变量为: -18.406160093377718
# agent 12 在 99 次迭代中的对偶变量为: -18.507546734431173
# agent 13 在 99 次迭代中的对偶变量为: -18.424464576010728
# agent 14 在 99 次迭代中的对偶变量为: -18.504038733350338
# agent 15 在 99 次迭代中的对偶变量为: -18.414453515199586
# agent 16 在 99 次迭代中的对偶变量为: -18.394216320656817
# agent 17 在 99 次迭代中的对偶变量为: -18.37031265056383
# agent 18 在 99 次迭代中的对偶变量为: -17.05621744156938
# agent 19 在 99 次迭代中的对偶变量为: -18.53858599658429
# agent 20 在 99 次迭代中的对偶变量为: -17.104729006939568
# agent 21 在 99 次迭代中的对偶变量为: -16.126439766191787
# agent 22 在 99 次迭代中的对偶变量为: -16.108048170866162
# agent 23 在 99 次迭代中的对偶变量为: -16.126439766191787
# agent 24 在 99 次迭代中的对偶变量为: -16.232340209004715
# agent 25 在 99 次迭代中的对偶变量为: -16.363216916531236
# agent 26 在 99 次迭代中的对偶变量为: -16.493609616177142
# agent 27 在 99 次迭代中的对偶变量为: -18.01462725535088
# agent 28 在 99 次迭代中的对偶变量为: -16.66790317050944
# agent 29 在 99 次迭代中的对偶变量为: -18.657593659413237
# agent 30 在 99 次迭代中的对偶变量为: -18.66968078056818
# agent 31 在 99 次迭代中的对偶变量为: -18.58065786080446
# agent 32 在 99 次迭代中的对偶变量为: -18.595740652328217
# agent 33 在 99 次迭代中的对偶变量为: -18.725584720588984
# agent 34 在 99 次迭代中的对偶变量为: -18.725584720588984
# agent 35 在 99 次迭代中的对偶变量为: -18.728383517860966
# agent 36 在 99 次迭代中的对偶变量为: -18.763294722043923
# agent 37 在 99 次迭代中的对偶变量为: -18.721872841224158
# agent 38 在 99 次迭代中的对偶变量为: -18.706598564212836
# agent 39 在 99 次迭代中的对偶变量为: -18.589482400359607
# agent 40 在 99 次迭代中的对偶变量为: -18.697948949606914
# agent 41 在 99 次迭代中的对偶变量为: -27.751730538728225
# agent 42 在 99 次迭代中的对偶变量为: -27.751730538649998
# agent 43 在 99 次迭代中的对偶变量为: -18.707400262271197
# agent 44 在 99 次迭代中的对偶变量为: -18.710168811296555
# agent 45 在 99 次迭代中的对偶变量为: -19.320392722759735
# agent 46 在 99 次迭代中的对偶变量为: -20.872387154819066
# agent 47 在 99 次迭代中的对偶变量为: -20.814691332519246
# agent 48 在 99 次迭代中的对偶变量为: -20.67322030595659
# agent 49 在 99 次迭代中的对偶变量为: -18.786212896520464
# agent 50 在 99 次迭代中的对偶变量为: -21.0905039254505
# agent 51 在 99 次迭代中的对偶变量为: -21.132134081351943
# agent 52 在 99 次迭代中的对偶变量为: -21.132134081351943
# agent 53 在 99 次迭代中的对偶变量为: -18.406933572352735
# agent 54 在 99 次迭代中的对偶变量为: -18.724686575695443
# *************************
# 迭代步长为: 5.3865362416062276e-05
# ****************************************************************************
# 119 次迭代中的结果：
# agent 1 在 119 次迭代中的资源申请量为: -55.686886158940496
# agent 2 在 119 次迭代中的资源申请量为: -55.686886158940496
# agent 3 在 119 次迭代中的资源申请量为: -55.8210130880422
# agent 4 在 119 次迭代中的资源申请量为: 254.5928308929261
# agent 5 在 119 次迭代中的资源申请量为: 257.05947272532165
# agent 6 在 119 次迭代中的资源申请量为: -55.734439144339596
# agent 7 在 119 次迭代中的资源申请量为: 26.260392448699402
# agent 8 在 119 次迭代中的资源申请量为: -55.21462116116571
# agent 9 在 119 次迭代中的资源申请量为: -55.02354769606234
# agent 10 在 119 次迭代中的资源申请量为: 260.95673964895656
# agent 11 在 119 次迭代中的资源申请量为: 1287.2463179411513
# agent 12 在 119 次迭代中的资源申请量为: -55.14823226994908
# agent 13 在 119 次迭代中的资源申请量为: -55.599021933293415
# agent 14 在 119 次迭代中的资源申请量为: 28.786370640040275
# agent 15 在 119 次迭代中的资源申请量为: -55.67054319456521
# agent 16 在 119 次迭代中的资源申请量为: 25.565573827360105
# agent 17 在 119 次迭代中的资源申请量为: -55.92809925100633
# agent 18 在 119 次迭代中的资源申请量为: -64.97279329047696
# agent 19 在 119 次迭代中的资源申请量为: 30.178546110716933
# agent 20 在 119 次迭代中的资源申请量为: 1020.9232745617863
# agent 21 在 119 次迭代中的资源申请量为: 823.3413901789603
# agent 22 在 119 次迭代中的资源申请量为: -60.80327477725494
# agent 23 在 119 次迭代中的资源申请量为: -60.01619704533722
# agent 24 在 119 次迭代中的资源申请量为: 352.94812438335003
# agent 25 在 119 次迭代中的资源申请量为: 368.80349063304504
# agent 26 在 119 次迭代中的资源申请量为: -45.06407169182505
# agent 27 在 119 次迭代中的资源申请量为: 461.12464511973224
# agent 28 在 119 次迭代中的资源申请量为: 401.02471842057514
# agent 29 在 119 次迭代中的资源申请量为: 266.864635911675
# agent 30 在 119 次迭代中的资源申请量为: 35.132650719762296
# agent 31 在 119 次迭代中的资源申请量为: -54.7345075562312
# agent 32 在 119 次迭代中的资源申请量为: -54.647174707093804
# agent 33 在 119 次迭代中的资源申请量为: -334.7669357105382
# agent 34 在 119 次迭代中的资源申请量为: 36.236420743777366
# agent 35 在 119 次迭代中的资源申请量为: 36.51857561784488
# agent 36 在 119 次迭代中的资源申请量为: 271.61017506667247
# agent 37 在 119 次迭代中的资源申请量为: 36.70796343546056
# agent 38 在 119 次迭代中的资源申请量为: -53.78446417807021
# agent 39 在 119 次迭代中的资源申请量为: 1316.9762711441513
# agent 40 在 119 次迭代中的资源申请量为: 269.2946926410033
# agent 41 在 119 次迭代中的资源申请量为: -174.6567053068078
# agent 42 在 119 次迭代中的资源申请量为: 249.03989424768875
# agent 43 在 119 次迭代中的资源申请量为: 269.6277693133176
# agent 44 在 119 次迭代中的资源申请量为: 269.76801853631264
# agent 45 在 119 次迭代中的资源申请量为: 294.3710872139706
# agent 46 在 119 次迭代中的资源申请量为: -300.2375983852988
# agent 47 在 119 次迭代中的资源申请量为: 110.49918426522336
# agent 48 在 119 次迭代中的资源申请量为: 105.51550341733453
# agent 49 在 119 次迭代中的资源申请量为: -334.2129236835262
# agent 50 在 119 次迭代中的资源申请量为: -104.21596043351667
# agent 51 在 119 次迭代中的资源申请量为: 122.04535354318243
# agent 52 在 119 次迭代中的资源申请量为: 122.04535354318243
# agent 53 在 119 次迭代中的资源申请量为: 25.940133497985155
# agent 54 在 119 次迭代中的资源申请量为: -214.17768651377082
# 资源申请量总和为: 7025.201987055114
# ****************************************************************************
# 成本总和为: 86244.30949842933
# ****************************************************************************
# agent 1 在 119 次迭代中的对偶变量为: -18.485168899019456
# agent 2 在 119 次迭代中的对偶变量为: -18.485168899019456
# agent 3 在 119 次迭代中的对偶变量为: -18.466481530495432
# agent 4 在 119 次迭代中的对偶变量为: -18.42489407192114
# agent 5 在 119 次迭代中的对偶变量为: -18.478543531775745
# agent 6 在 119 次迭代中的对偶变量为: -18.478543531775742
# agent 7 在 119 次迭代中的对偶变量为: -18.492266046686705
# agent 8 在 119 次迭代中的对偶变量为: -18.550967692099427
# agent 9 在 119 次迭代中的对偶变量为: -18.57758919369842
# agent 10 在 119 次迭代中的对偶变量为: -18.563309087364804
# agent 11 在 119 次迭代中的对偶变量为: -18.483477907646908
# agent 12 在 119 次迭代中的对偶变量为: -18.560217390757074
# agent 13 在 119 次迭代中的对偶变量为: -18.497410670121962
# agent 14 在 119 次迭代中的对偶变量为: -18.55693108838503
# agent 15 在 119 次迭代中的对偶变量为: -18.487445898874007
# agent 16 在 119 次迭代中的对偶变量为: -18.47447868998042
# agent 17 在 119 次迭代中的对偶变量为: -18.451561643754292
# agent 18 在 119 次迭代中的对偶变量为: -17.191400602011008
# agent 19 在 119 次迭代中的对偶变量为: -18.592570780434354
# agent 20 在 119 次迭代中的对偶变量为: -17.232373564445698
# agent 21 在 119 次迭代中的对偶变量为: -16.283585355639367
# agent 22 在 119 次迭代中的对偶变量为: -16.263436165702274
# agent 23 在 119 次迭代中的对偶变量为: -16.283585355639367
# agent 24 在 119 次迭代中的对偶变量为: -16.39594349457348
# agent 25 在 119 次迭代中的对偶变量为: -16.535470717570796
# agent 26 在 119 次迭代中的对偶变量为: -16.66635976468928
# agent 27 在 119 次迭代中的对偶变量为: -18.10571998363593
# agent 28 在 119 次迭代中的对偶变量为: -16.832803536147782
# agent 29 在 119 次迭代中的对偶变量为: -18.69180583107893
# agent 30 在 119 次迭代中的对偶变量为: -18.69759343800729
# agent 31 在 119 次迭代中的对偶变量为: -18.61786000022053
# agent 32 在 119 次迭代中的对偶变量为: -18.63002773675945
# agent 33 在 119 次迭代中的对偶变量为: -18.7476523710407
# agent 34 在 119 次迭代中的对偶变量为: -18.7476523710407
# agent 35 在 119 次迭代中的对偶变量为: -18.75487553581683
# agent 36 在 119 次迭代中的对偶变量为: -18.795021307700125
# agent 37 在 119 次迭代中的对偶变量为: -18.75972386394779
# agent 38 在 119 次迭代中的对偶变量为: -18.75022574392619
# agent 39 在 119 次迭代中的对偶变量为: -18.661857626864908
# agent 40 在 119 次迭代中的对偶变量为: -18.74465956494182
# agent 41 在 119 次迭代中的对偶变量为: -27.810531852813455
# agent 42 在 119 次迭代中的对偶变量为: -27.81053185275382
# agent 43 在 119 次迭代中的对偶变量为: -18.751903982564656
# agent 44 在 119 次迭代中的对偶变量为: -18.7549544031648
# agent 45 在 119 次迭代中的对偶变量为: -19.29007114690386
# agent 46 在 119 次迭代中的对偶变量为: -20.70215098099855
# agent 47 在 119 次迭代中的对偶变量为: -20.64877911718972
# agent 48 在 119 次迭代中的对偶变量为: -20.521196887483764
# agent 49 在 119 次迭代中的对偶变量为: -18.779011667817688
# agent 50 在 119 次迭代中的对偶变量为: -20.905086405445616
# agent 51 在 119 次迭代中的对偶变量为: -20.94436105070547
# agent 52 在 119 次迭代中的对偶变量为: -20.94436105070547
# agent 53 在 119 次迭代中的对偶变量为: -18.48406741754842
# agent 54 在 119 次迭代中的对偶变量为: -18.755554584028808
# *************************
# 迭代步长为: 4.087351016895592e-05
# ****************************************************************************
# 139 次迭代中的结果：
# agent 1 在 139 次迭代中的资源申请量为: -55.29318998448688
# agent 2 在 139 次迭代中的资源申请量为: -55.29318998448688
# agent 3 在 139 次迭代中的资源申请量为: -55.404992380362465
# agent 4 在 139 次迭代中的资源申请量为: 257.73355838018676
# agent 5 在 139 次迭代中的资源申请量为: 259.58735822036687
# agent 6 在 139 次迭代中的资源申请量为: -55.339814239316574
# agent 7 在 139 次迭代中的资源申请量为: 28.27992028037421
# agent 8 在 139 次迭代中的资源申请量为: -54.92389552647031
# agent 9 在 139 次迭代中的资源申请量为: -54.771309707813344
# agent 10 在 139 次迭代中的资源申请量为: 262.7106094195139
# agent 11 在 139 次迭代中的资源申请量为: 1296.160769761161
# agent 12 在 139 次迭代中的资源申请量为: -54.86958228762057
# agent 13 在 139 次迭代中的资源申请量为: -55.23430305030273
# agent 14 在 139 次迭代中的资源申请量为: 30.324938456956495
# agent 15 在 139 次迭代中的资源申请量为: -55.30339191262991
# agent 16 在 139 次迭代中的资源申请量为: 27.721935446220897
# agent 17 在 139 次迭代中的资源申请量为: -55.52357111677795
# agent 18 在 139 次迭代中的资源申请量为: -64.08633419750066
# agent 19 在 139 次迭代中的资源申请量为: 31.6193192244546
# agent 20 在 139 次迭代中的资源申请量为: 1045.7953443309696
# agent 21 在 139 次迭代中的资源申请量为: 858.6516344726499
# agent 22 在 139 次迭代中的资源申请量为: -54.16200729523465
# agent 23 在 139 次迭代中的资源申请量为: -53.39276762743497
# agent 24 在 139 次迭代中的资源申请量为: 371.8024567431585
# agent 25 在 139 次迭代中的资源申请量为: 387.16743193801864
# agent 26 在 139 次迭代中的资源申请量为: -38.95544407699764
# agent 27 在 139 次迭代中的资源申请量为: 464.4856201117664
# agent 28 在 139 次迭代中的资源申请量为: 407.99154782487875
# agent 29 在 139 次迭代中的资源申请量为: 267.90363210195795
# agent 30 在 139 次迭代中的资源申请量为: 35.337101439368226
# agent 31 在 139 次迭代中的资源申请量为: -54.54232925706867
# agent 32 在 139 次迭代中的资源申请量为: -54.47326324188787
# agent 33 在 139 次迭代中的资源申请量为: -334.51804122626
# agent 34 在 139 次迭代中的资源申请量为: 36.78674978237428
# agent 35 在 139 次迭代中的资源申请量为: 37.16137171208777
# agent 36 在 139 次迭代中的资源申请量为: 272.4419813998886
# agent 37 在 139 次迭代中的资源申请量为: 37.6072286691892
# agent 38 在 139 次迭代中的资源申请量为: -53.59205516559567
# agent 39 在 139 次迭代中的资源申请量为: 1324.623527966266
# agent 40 在 139 次迭代中的资源申请量为: 270.6163537180645
# agent 41 在 139 次迭代中的资源申请量为: -173.8736065565124
# agent 42 在 139 次迭代中的资源申请量为: 251.30746748658504
# agent 43 在 139 次迭代中的资源申请量为: 270.87263861673983
# agent 44 在 139 次迭代中的资源申请量为: 271.01082262559714
# agent 45 在 139 次迭代中的资源申请量为: 292.75792056605917
# agent 46 在 139 次迭代中的资源申请量为: -303.0635083637752
# agent 47 在 139 次迭代中的资源申请量为: 104.41542664636593
# agent 48 在 139 次迭代中的资源申请量为: 99.89845069182017
# agent 49 在 139 次迭代中的资源申请量为: -334.36693700357836
# agent 50 在 139 次迭代中的资源申请量为: -113.18340539254368
# agent 51 在 139 次迭代中的资源申请量为: 115.09435410471558
# agent 52 在 139 次迭代中的资源申请量为: 115.09435410471558
# agent 53 在 139 次迭代中的资源申请量为: 28.024728778540812
# agent 54 在 139 次迭代中的资源申请量为: -213.21096805561274
# 资源申请量总和为: 7163.60864737074
# ****************************************************************************
# 成本总和为: 88522.83504696704
# ****************************************************************************
# agent 1 在 139 次迭代中的对偶变量为: -18.54002101222138
# agent 2 在 139 次迭代中的对偶变量为: -18.54002101222138
# agent 3 在 139 次迭代中的对偶变量为: -18.52444403161362
# agent 4 在 139 次迭代中的对偶变量为: -18.49320489476906
# agent 5 在 139 次迭代中的对偶变量为: -18.53352504129298
# agent 6 在 139 次迭代中的对偶变量为: -18.53352504129298
# agent 7 在 139 次迭代中的对偶变量为: -18.54396595917758
# agent 8 在 139 次迭代中的对偶变量为: -18.591473331878998
# agent 9 在 139 次迭代中的对偶变量为: -18.612732503649198
# agent 10 在 139 次迭代中的对偶变量为: -18.601455754874426
# agent 11 在 139 次迭代中的对偶变量为: -18.536964618566966
# agent 12 在 139 次迭代中的对偶变量为: -18.599040578194977
# agent 13 在 139 次迭代中的对偶变量为: -18.548225493213522
# agent 14 在 139 次迭代中的对偶变量为: -18.596318424498087
# agent 15 在 139 次迭代中的对偶变量为: -18.538599618380925
# agent 16 在 139 次迭代中的对偶变量为: -18.529681547423255
# agent 17 在 139 次迭代中的对偶变量为: -18.507922930583796
# agent 18 在 139 次迭代中的对偶变量为: -17.314907401599022
# agent 19 在 139 次迭代中的对偶变量为: -18.629454572146038
# agent 20 在 139 次迭代中的对偶变量为: -17.351809243477316
# agent 21 在 139 次迭代中的对偶变量为: -16.453145148737665
# agent 22 在 139 次迭代中的对偶变量为: -16.433452613241993
# agent 23 在 139 次迭代中的对偶变量为: -16.453145148737665
# agent 24 在 139 次迭代中的对偶变量为: -16.561861619339794
# agent 25 在 139 次迭代中的对偶变量为: -16.697073401054563
# agent 26 在 139 次迭代中的对偶变量为: -16.82274063162886
# agent 27 在 139 次迭代中的对偶变量为: -18.176905433967214
# agent 28 在 139 次迭代中的对偶变量为: -16.980360982930932
# agent 29 在 139 次迭代中的对偶变量为: -18.714403998217584
# agent 30 在 139 次迭代中的对偶变量为: -18.716371418800215
# agent 31 在 139 次迭代中的对偶变量为: -18.64463543392965
# agent 32 在 139 次迭代中的对偶变量为: -18.65425812556073
# agent 33 在 139 次迭代中的对偶变量为: -18.761740794428782
# agent 34 在 139 次迭代中的对偶变量为: -18.761740794428782
# agent 35 在 139 次迭代中的对偶变量为: -18.771331115829447
# agent 36 在 139 次迭代中的对偶变量为: -18.813113095447576
# agent 37 在 139 次迭代中的对偶变量为: -18.782745053931244
# agent 38 在 139 次迭代中的对偶变量为: -18.777033321998218
# agent 39 在 139 次迭代中的对偶变量为: -18.707741167797597
# agent 40 在 139 次迭代中的对偶变量为: -18.773405693367902
# agent 41 在 139 次迭代中的对偶变量为: -27.854858374475175
# agent 42 在 139 次迭代中的对偶变量为: -27.854858374427764
# agent 43 在 139 次迭代中的对偶变量为: -18.77897988991409
# agent 44 在 139 次迭代中的对偶变量为: -18.781985392106737
# agent 45 在 139 次迭代中的对偶变量为: -19.254984772311786
# agent 46 在 139 次迭代中的对偶变量为: -20.54219317257687
# agent 47 在 139 次迭代中的对偶变量为: -20.49303492214697
# agent 48 在 139 次迭代中的对偶变量为: -20.377400337710597
# agent 49 在 139 次迭代中的对偶变量为: -18.770293897849452
# agent 50 在 139 次迭代中的对偶变量为: -20.729790791386556
# agent 51 在 139 次迭代中的对偶变量为: -20.76641546508072
# agent 52 在 139 次迭代中的对偶变量为: -20.76641546508072
# agent 53 在 139 次迭代中的对偶变量为: -18.537433056730645
# agent 54 在 139 次迭代中的对偶变量为: -18.77445199644888
# *************************
# 迭代步长为: 3.237726633057685e-05
# ****************************************************************************
# 159 次迭代中的结果：
# agent 1 在 159 次迭代中的资源申请量为: -55.009529775254414
# agent 2 在 159 次迭代中的资源申请量为: -55.009529775254414
# agent 3 在 159 次迭代中的资源申请量为: -55.10403187495131
# agent 4 在 159 次迭代中的资源申请量为: 259.96805759717074
# agent 5 在 159 次迭代中的资源申请量为: 261.42666381848744
# agent 6 在 159 次迭代中的资源申请量为: -55.05268264321016
# agent 7 在 159 次迭代中的资源申请量为: 29.76374569142209
# agent 8 在 159 次迭代中的资源申请量为: -54.70410813788347
# agent 9 在 159 次迭代中的资源申请量为: -54.57731575289843
# agent 10 在 159 次迭代中的资源申请量为: 264.048219147737
# agent 11 在 159 次迭代中的资源申请量为: 1302.702000268216
# agent 12 在 159 次迭代中的资源申请量为: -54.65721710128728
# agent 13 在 159 次迭代中的资源申请量为: -54.96538849590181
# agent 14 在 159 次迭代中的资源申请量为: 31.493162353930234
# agent 15 在 159 次迭代中的资源申请量为: -55.03227041807334
# agent 16 在 159 次迭代中的资源申请量为: 29.298373210225186
# agent 17 在 159 次迭代中的资源申请量为: -55.22465689533019
# agent 18 在 159 次迭代中的资源申请量为: -63.259440240584006
# agent 19 在 159 次迭代中的资源申请量为: 32.66087694996062
# agent 20 在 159 次迭代中的资源申请量为: 1069.0785603355182
# agent 21 在 159 次迭代中的资源申请量为: 893.5013615979711
# agent 22 在 159 次迭代中的资源申请量为: -47.58987802217826
# agent 23 在 159 次迭代中的资源申请量为: -46.85572115650543
# agent 24 在 159 次迭代中的资源申请量为: 390.18848770393964
# agent 25 在 159 次迭代中的资源申请量为: 404.7817456987717
# agent 26 在 159 次迭代中的资源申请量为: -33.16527520909024
# agent 27 在 159 次迭代中的资源申请量为: 467.30166307753615
# agent 28 在 159 次迭代中的资源申请量为: 414.53477991211344
# agent 29 在 159 次迭代中的资源申请量为: 268.63033698131716
# agent 30 在 159 次迭代中的资源申请量为: 35.49015669632977
# agent 31 在 159 次迭代中的资源申请量为: -54.38928165825214
# agent 32 在 159 次迭代中的资源申请量为: -54.33267562865212
# agent 33 在 159 次迭代中的资源申请量为: -334.3467581609598
# agent 34 在 159 次迭代中的资源申请量为: 37.16547269754039
# agent 35 在 159 次迭代中的资源申请量为: 37.57543667423341
# agent 36 在 159 次迭代中的资源申请量为: 272.89068766050485
# agent 37 在 159 次迭代中的资源申请量为: 38.14398597267801
# agent 38 在 159 次迭代中的资源申请量为: -53.47672805887036
# agent 39 在 159 次迭代中的资源申请量为: 1329.5067287388754
# agent 40 在 159 次迭代中的资源申请量为: 271.4104985344305
# agent 41 在 159 次迭代中的资源申请量为: -173.2573330135664
# agent 42 在 159 次迭代中的资源申请量为: 253.091974732005
# agent 43 在 159 次迭代中的资源申请量为: 271.61305024557544
# agent 44 在 159 次迭代中的资源申请量为: 271.7435671695899
# agent 45 在 159 次迭代中的资源申请量为: 291.06974872976286
# agent 46 在 159 次迭代中的资源申请量为: -305.6946177497614
# agent 47 在 159 次迭代中的资源申请量为: 98.75277022696332
# agent 48 在 159 次迭代中的资源申请量为: 94.64593304967836
# agent 49 在 159 次迭代中的资源申请量为: -334.531351554598
# agent 50 在 159 次迭代中的资源申请量为: -121.55480212498259
# agent 51 在 159 次迭代中的资源申请量为: 108.59768318897358
# agent 52 在 159 次迭代中的资源申请量为: 108.59768318897358
# agent 53 在 159 次迭代中的资源申请量为: 29.553823386503918
# agent 54 在 159 次迭代中的资源申请量为: -212.618137168682
# 资源申请量总和为: 7284.81850462021
# ****************************************************************************
# 成本总和为: 90513.85445678941
# ****************************************************************************
# agent 1 在 159 次迭代中的对偶变量为: -18.579542254532903
# agent 2 在 159 次迭代中的对偶变量为: -18.579542254532903
# agent 3 在 159 次迭代中的对偶变量为: -18.566375654990534
# agent 4 在 159 次迭代中的对偶变量为: -18.541805252738463
# agent 5 在 159 次迭代中的对偶变量为: -18.5735299380521
# agent 6 在 159 次迭代中的对偶变量为: -18.5735299380521
# agent 7 在 159 次迭代中的对偶变量为: -18.581951889700406
# agent 8 在 159 次迭代中的对偶变量为: -18.622095429581247
# agent 9 在 159 次迭代中的对偶变量为: -18.639760905411674
# agent 10 在 159 次迭代中的对偶变量为: -18.630548766463278
# agent 11 在 159 次迭代中的对偶变量为: -18.576212001609296
# agent 12 在 159 次迭代中的对偶变量为: -18.62862857014605
# agent 13 在 159 次迭代中的对偶变量为: -18.585692282419984
# agent 14 在 159 次迭代中的对偶变量为: -18.626224956260614
# agent 15 在 159 次迭代中的对偶变量为: -18.576373891731514
# agent 16 在 159 次迭代中的对偶变量为: -18.570038354181765
# agent 17 在 159 次迭代中的对偶变量为: -18.549569453401226
# agent 18 在 159 次迭代中的对偶变量为: -17.430115229040393
# agent 19 在 159 次迭代中的对偶变量为: -18.656118449918992
# agent 20 在 159 次迭代中的对偶变量为: -17.46361524673116
# agent 21 在 159 次迭代中的对偶变量为: -16.620493538393458
# agent 22 在 159 次迭代中的对偶变量为: -16.601699122632237
# agent 23 在 159 次迭代中的对偶变量为: -16.62049353839346
# agent 24 在 159 次迭代中的对偶变量为: -16.723658691794668
# agent 25 在 159 次迭代中的对偶变量为: -16.85207936214919
# agent 26 在 159 次迭代中的对偶变量为: -16.97096895464729
# agent 27 在 159 次迭代中的对偶变量为: -18.236549223982216
# agent 28 在 159 次迭代中的对偶变量为: -17.118946638538564
# agent 29 在 159 次迭代中的对偶变量为: -18.730209829343647
# agent 30 在 159 次迭代中的对偶变量为: -18.730428931931105
# agent 31 在 159 次迭代中的对偶变量为: -18.665958943682362
# agent 32 在 159 次迭代中的对偶变量为: -18.673845635362415
# agent 33 在 159 次迭代中的对偶变量为: -18.771436101057034
# agent 34 在 159 次迭代中的对偶变量为: -18.771436101057034
# agent 35 在 159 次迭代中的对偶变量为: -18.781931178860376
# agent 36 在 159 次迭代中的对偶变量为: -18.82287245661598
# agent 37 在 159 次迭代中的对偶变量为: -18.796486040900557
# agent 38 在 159 次迭代中的对偶变量为: -18.79310138646983
# agent 39 在 159 次迭代中的对偶变量为: -18.737040372433253
# agent 40 在 159 次迭代中的对偶变量为: -18.79067834312386
# agent 41 在 159 次迭代中的对偶变量为: -27.88974192210009
# agent 42 在 159 次迭代中的对偶变量为: -27.889741922061233
# agent 43 在 159 次迭代中的对偶变量为: -18.795083842841265
# agent 44 在 159 次迭代中的对偶变量为: -18.79792258593858
# agent 45 在 159 次迭代中的对偶变量为: -19.21826703487234
# agent 46 在 159 次迭代中的对偶变量为: -20.393261856892508
# agent 47 在 159 次迭代中的对偶变量为: -20.34807091781026
# agent 48 在 159 次迭代中的对偶变量为: -20.242935886071766
# agent 49 在 159 次迭代中的对偶变量为: -18.760987376603538
# agent 50 在 159 次迭代中的对偶变量为: -20.56614672806084
# agent 51 在 159 次迭代中的对偶变量为: -20.600100689637724
# agent 52 在 159 次迭代中的对偶变量为: -20.600100689637724
# agent 53 在 159 次迭代中的对偶变量为: -18.5765778786945
# agent 54 在 159 次迭代中的对偶变量为: -18.786040654626603
# *************************
# 迭代步长为: 2.6464682716040347e-05
# ****************************************************************************
# 179 次迭代中的结果：
# agent 1 在 179 次迭代中的资源申请量为: -54.79473123265221
# agent 2 在 179 次迭代中的资源申请量为: -54.79473123265221
# agent 3 在 179 次迭代中的资源申请量为: -54.87584905494396
# agent 4 在 179 次迭代中的资源申请量为: 261.6412443681584
# agent 5 在 179 次迭代中的资源申请量为: 262.8271122831537
# agent 6 在 179 次迭代中的资源申请量为: -54.8340604613741
# agent 7 在 179 次迭代中的资源申请量为: 30.899663364603313
# agent 8 在 179 次迭代中的资源申请量为: -54.53369828329794
# agent 9 在 179 次迭代中的资源申请量为: -54.42536737485416
# agent 10 在 179 次迭代中的资源申请量为: 265.088853361754
# agent 11 在 179 次迭代中的资源申请量为: 1307.7028929759438
# agent 12 在 179 次迭代中的资源申请量为: -54.492226725581475
# agent 13 在 179 次迭代中的资源申请量为: -54.7593491991169
# agent 14 在 179 次迭代中的资源申请量为: 32.40022303961559
# agent 15 在 179 次迭代中的资源申请量为: -54.823593826668514
# agent 16 在 179 次迭代中的资源申请量为: 30.501736035479368
# agent 17 在 179 次迭代中的资源申请量为: -54.9940136843359
# agent 18 在 179 次迭代中的资源申请量为: -62.49149447741535
# agent 19 在 179 次迭代中的资源申请量为: 33.44502534562893
# agent 20 在 179 次迭代中的资源申请量为: 1090.7397813617968
# agent 21 在 179 次迭代中的资源申请量为: 926.9326413236809
# agent 22 在 179 次迭代中的资源申请量为: -41.277573916783105
# agent 23 在 179 次迭代中的资源申请量为: -40.58474438920642
# agent 24 在 179 次迭代中的资源申请量为: 407.72959328078457
# agent 25 在 179 次迭代中的资源申请量为: 421.4573450093932
# agent 26 在 179 次迭代中的资源申请量为: -27.71929669991985
# agent 27 在 179 次迭代中的资源申请量为: 469.7285306447802
# agent 28 在 179 次迭代中的资源申请量为: 420.6523888986501
# agent 29 在 179 次迭代中的资源申请量为: 269.1544215400867
# agent 30 在 179 次迭代中的资源申请量为: 35.6063519938686
# agent 31 在 179 次迭代中的资源申请量为: -54.26646519910491
# agent 32 在 179 次迭代中的资源申请量为: -54.218695368663234
# agent 33 在 179 次迭代中的资源申请量为: -334.22776546719484
# agent 34 在 179 次迭代中的资源申请量为: 37.42857669901969
# agent 35 在 179 次迭代中的资源申请量为: 37.842244294040846
# agent 36 在 179 次迭代中的资源申请量为: 273.10779048413775
# agent 37 在 179 次迭代中的资源申请量为: 38.45752601875224
# agent 38 在 179 次迭代中的资源申请量为: -53.40873693973423
# agent 39 在 179 次迭代中的资源申请量为: 1332.6795699720064
# ...
# agent 61 在 57999 次迭代中的资源申请量为: 45.35594989347403
# agent 62 在 57999 次迭代中的资源申请量为: 37.777916501990724
# agent 63 在 57999 次迭代中的资源申请量为: 44.36024833408177
# agent 64 在 57999 次迭代中的资源申请量为: 50.59248382563158
# agent 65 在 57999 次迭代中的资源申请量为: 48.719342447654434
# agent 66 在 57999 次迭代中的资源申请量为: 53.47780999250294
# agent 67 在 57999 次迭代中的资源申请量为: 44.62937911116489
# agent 68 在 57999 次迭代中的资源申请量为: 38.64566746179317
# agent 69 在 57999 次迭代中的资源申请量为: 49.892139157742264
# agent 70 在 57999 次迭代中的资源申请量为: 43.38409217370307
# agent 71 在 57999 次迭代中的资源申请量为: 51.072439614453316
# agent 72 在 57999 次迭代中的资源申请量为: 51.63101181607402
# agent 73 在 57999 次迭代中的资源申请量为: 68.52493850742536
# agent 74 在 57999 次迭代中的资源申请量为: 63.033563690013715
# agent 75 在 57999 次迭代中的资源申请量为: 68.784860310892
# agent 76 在 57999 次迭代中的资源申请量为: 65.84231131075826
# agent 77 在 57999 次迭代中的资源申请量为: 37.33178559067635
# agent 78 在 57999 次迭代中的资源申请量为: 56.51515954674519
# agent 79 在 57999 次迭代中的资源申请量为: 35.71319766839764
# agent 80 在 57999 次迭代中的资源申请量为: 41.69438982489503
# agent 81 在 57999 次迭代中的资源申请量为: 64.43288578237497
# agent 82 在 57999 次迭代中的资源申请量为: 45.64920279686928
# agent 83 在 57999 次迭代中的资源申请量为: 54.00548947849253
# agent 84 在 57999 次迭代中的资源申请量为: 52.98642785861979
# agent 85 在 57999 次迭代中的资源申请量为: 58.685757530611916
# agent 86 在 57999 次迭代中的资源申请量为: 54.16278250297388
# agent 87 在 57999 次迭代中的资源申请量为: 50.183947875573004
# agent 88 在 57999 次迭代中的资源申请量为: 53.40486804038364
# agent 89 在 57999 次迭代中的资源申请量为: 44.037016821613456
# agent 90 在 57999 次迭代中的资源申请量为: 38.995841039652966
# agent 91 在 57999 次迭代中的资源申请量为: 43.58677066582213
# agent 92 在 57999 次迭代中的资源申请量为: 45.25809138455365
# agent 93 在 57999 次迭代中的资源申请量为: 35.68321481266967
# agent 94 在 57999 次迭代中的资源申请量为: 37.48060785879904
# 资源申请量平均值avg为: 49.99999999999654
# ****************************************************************************
# 平均成本为: 3240.481984531225
# ****************************************************************************
# agent 1 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 2 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 3 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 4 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 5 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 6 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 7 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 8 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 9 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 10 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 11 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 12 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 13 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 14 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 15 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 16 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 17 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 18 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 19 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 20 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 21 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 22 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 23 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 24 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 25 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 26 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 27 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 28 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 29 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 30 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 31 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 32 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 33 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 34 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 35 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 36 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 37 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 38 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 39 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 40 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 41 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 42 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 43 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 44 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 45 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 46 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 47 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 48 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 49 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 50 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 51 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 52 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 53 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 54 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 55 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 56 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 57 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 58 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 59 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 60 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 61 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 62 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 63 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 64 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 65 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 66 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 67 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 68 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 69 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 70 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 71 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 72 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 73 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 74 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 75 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 76 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 77 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 78 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 79 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 80 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 81 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 82 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 83 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 84 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 85 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 86 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 87 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 88 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 89 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 90 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 91 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 92 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 93 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 94 在 57999 次迭代中的对偶变量为: -135.14386653834575
# *************************
# 迭代步长为: 0.11151053484837568
# ****************************************************************************
# 59999 次迭代中的结果：
# agent 1 在 59999 次迭代中的资源申请量为: 56.19880558172988
# agent 2 在 59999 次迭代中的资源申请量为: 56.03871203978166
# agent 3 在 59999 次迭代中的资源申请量为: 60.64796214442871
# agent 4 在 59999 次迭代中的资源申请量为: 37.93333499802675
# agent 5 在 59999 次迭代中的资源申请量为: 57.56693686702461
# agent 6 在 59999 次迭代中的资源申请量为: 55.34212747123894
# agent 7 在 59999 次迭代中的资源申请量为: 65.6236567946489
# agent 8 在 59999 次迭代中的资源申请量为: 46.330946703602365
# agent 9 在 59999 次迭代中的资源申请量为: 65.64268770463663
# agent 10 在 59999 次迭代中的资源申请量为: 54.23914303693835
# agent 11 在 59999 次迭代中的资源申请量为: 65.4520437985654
# agent 12 在 59999 次迭代中的资源申请量为: 38.406222330358624
# agent 13 在 59999 次迭代中的资源申请量为: 49.70058714461363
# agent 14 在 59999 次迭代中的资源申请量为: 41.3659905551611
# agent 15 在 59999 次迭代中的资源申请量为: 42.48853939614691
# agent 16 在 59999 次迭代中的资源申请量为: 49.24530133808371
# agent 17 在 59999 次迭代中的资源申请量为: 50.11852704992918
# agent 18 在 59999 次迭代中的资源申请量为: 46.537297422347486
# agent 19 在 59999 次迭代中的资源申请量为: 44.77392156663175
# agent 20 在 59999 次迭代中的资源申请量为: 50.80339666473046
# agent 21 在 59999 次迭代中的资源申请量为: 69.93387670557085
# agent 22 在 59999 次迭代中的资源申请量为: 61.24199691647269
# agent 23 在 59999 次迭代中的资源申请量为: 61.627787986086716
# agent 24 在 59999 次迭代中的资源申请量为: 39.861352301782716
# agent 25 在 59999 次迭代中的资源申请量为: 52.95065687328203
# agent 26 在 59999 次迭代中的资源申请量为: 49.39633437684004
# agent 27 在 59999 次迭代中的资源申请量为: 47.51919637207136
# agent 28 在 59999 次迭代中的资源申请量为: 40.7413613830987
# agent 29 在 59999 次迭代中的资源申请量为: 44.38273034135506
# agent 30 在 59999 次迭代中的资源申请量为: 39.891745956789116
# agent 31 在 59999 次迭代中的资源申请量为: 65.76280653244551
# agent 32 在 59999 次迭代中的资源申请量为: 59.51901541924079
# agent 33 在 59999 次迭代中的资源申请量为: 48.23750867799392
# agent 34 在 59999 次迭代中的资源申请量为: 36.76532342510125
# agent 35 在 59999 次迭代中的资源申请量为: 41.086702696803464
# agent 36 在 59999 次迭代中的资源申请量为: 62.20889044924783
# agent 37 在 59999 次迭代中的资源申请量为: 40.47023795026076
# agent 38 在 59999 次迭代中的资源申请量为: 58.24733429492913
# agent 39 在 59999 次迭代中的资源申请量为: 37.39554726071002
# agent 40 在 59999 次迭代中的资源申请量为: 50.45313221045784
# agent 41 在 59999 次迭代中的资源申请量为: 36.73569742369616
# agent 42 在 59999 次迭代中的资源申请量为: 56.24242387150355
# agent 43 在 59999 次迭代中的资源申请量为: 61.52373322591861
# agent 44 在 59999 次迭代中的资源申请量为: 47.51525622305313
# agent 45 在 59999 次迭代中的资源申请量为: 41.36197014706921
# agent 46 在 59999 次迭代中的资源申请量为: 67.10436077257359
# agent 47 在 59999 次迭代中的资源申请量为: 65.57090570810219
# agent 48 在 59999 次迭代中的资源申请量为: 40.83836334458436
# agent 49 在 59999 次迭代中的资源申请量为: 39.16390664937778
# agent 50 在 59999 次迭代中的资源申请量为: 63.292999181236645
# agent 51 在 59999 次迭代中的资源申请量为: 36.39727688961264
# agent 52 在 59999 次迭代中的资源申请量为: 46.86937779818014
# agent 53 在 59999 次迭代中的资源申请量为: 43.572511920796444
# agent 54 在 59999 次迭代中的资源申请量为: 49.58201107681077
# agent 55 在 59999 次迭代中的资源申请量为: 47.173391517077015
# agent 56 在 59999 次迭代中的资源申请量为: 42.97971616155657
# agent 57 在 59999 次迭代中的资源申请量为: 36.90486251978384
# agent 58 在 59999 次迭代中的资源申请量为: 59.2566799113546
# agent 59 在 59999 次迭代中的资源申请量为: 59.891586060534515
# agent 60 在 59999 次迭代中的资源申请量为: 40.34169962872796
# agent 61 在 59999 次迭代中的资源申请量为: 45.35594989347582
# agent 62 在 59999 次迭代中的资源申请量为: 37.77791650199216
# agent 63 在 59999 次迭代中的资源申请量为: 44.360248334083515
# agent 64 在 59999 次迭代中的资源申请量为: 50.59248382563358
# agent 65 在 59999 次迭代中的资源申请量为: 48.71934244765636
# agent 66 在 59999 次迭代中的资源申请量为: 53.47780999250507
# agent 67 在 59999 次迭代中的资源申请量为: 44.62937911116663
# agent 68 在 59999 次迭代中的资源申请量为: 38.64566746179467
# agent 69 在 59999 次迭代中的资源申请量为: 49.89213915774424
# agent 70 在 59999 次迭代中的资源申请量为: 43.384092173704765
# agent 71 在 59999 次迭代中的资源申请量为: 51.07243961445531
# agent 72 在 59999 次迭代中的资源申请量为: 51.63101181607605
# agent 73 在 59999 次迭代中的资源申请量为: 68.52493850742809
# agent 74 在 59999 次迭代中的资源申请量为: 63.033563690016244
# agent 75 在 59999 次迭代中的资源申请量为: 68.78486031089474
# agent 76 在 59999 次迭代中的资源申请量为: 65.84231131076093
# agent 77 在 59999 次迭代中的资源申请量为: 37.33178559067781
# agent 78 在 59999 次迭代中的资源申请量为: 56.51515954674745
# agent 79 在 59999 次迭代中的资源申请量为: 35.713197668399026
# agent 80 在 59999 次迭代中的资源申请量为: 41.69438982489667
# agent 81 在 59999 次迭代中的资源申请量为: 64.43288578237754
# agent 82 在 59999 次迭代中的资源申请量为: 45.64920279687104
# agent 83 在 59999 次迭代中的资源申请量为: 54.00548947849467
# agent 84 在 59999 次迭代中的资源申请量为: 52.98642785862186
# agent 85 在 59999 次迭代中的资源申请量为: 58.685757530614225
# agent 86 在 59999 次迭代中的资源申请量为: 54.16278250297603
# agent 87 在 59999 次迭代中的资源申请量为: 50.18394787557497
# agent 88 在 59999 次迭代中的资源申请量为: 53.40486804038577
# agent 89 在 59999 次迭代中的资源申请量为: 44.03701682161516
# agent 90 在 59999 次迭代中的资源申请量为: 38.99584103965445
# agent 91 在 59999 次迭代中的资源申请量为: 43.58677066582381
# agent 92 在 59999 次迭代中的资源申请量为: 45.258091384555385
# agent 93 在 59999 次迭代中的资源申请量为: 35.68321481267107
# agent 94 在 59999 次迭代中的资源申请量为: 37.4806078588005
# 资源申请量平均值avg为: 49.9999999999985
# ****************************************************************************
# 平均成本为: 3240.4819845314896
# ****************************************************************************
# agent 1 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 2 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 3 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 4 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 5 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 6 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 7 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 8 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 9 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 10 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 11 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 12 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 13 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 14 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 15 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 16 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 17 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 18 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 19 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 20 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 21 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 22 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 23 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 24 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 25 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 26 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 27 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 28 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 29 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 30 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 31 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 32 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 33 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 34 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 35 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 36 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 37 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 38 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 39 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 40 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 41 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 42 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 43 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 44 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 45 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 46 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 47 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 48 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 49 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 50 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 51 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 52 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 53 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 54 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 55 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 56 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 57 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 58 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 59 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 60 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 61 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 62 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 63 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 64 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 65 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 66 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 67 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 68 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 69 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 70 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 71 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 72 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 73 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 74 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 75 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 76 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 77 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 78 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 79 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 80 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 81 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 82 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 83 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 84 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 85 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 86 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 87 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 88 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 89 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 90 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 91 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 92 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 93 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 94 在 59999 次迭代中的对偶变量为: -135.1438665383513
# *************************
# 迭代步长为: 0.11075700351730201
# ****************************************************************************
# 2023-05-29 15:40:13.737

# %%
np.savetxt('../data/01-DGD-IOS-robust-agent_resource_quantity_small_value_deterministic_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/01-DGD-IOS-robust-sum_cost_small_value_deterministic_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/01-DGD-IOS-robust-sum_resource_small_value_deterministic_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
