# %% [markdown]
# IWDGD中大值的确定性噪声 对应到DGD算法中是固定的对偶攻击值为-24 这样两个算法各自迭代2000次 所有用户的对偶迭代值均在-23.83附近

# %% [markdown]
# 鲁棒聚合器ARC 该鲁棒聚合器跟IWDGD使用鲁棒聚合器的完全相同

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(54,2000)) 
dual_variable = np.zeros(shape=(54,2000))#对偶变量
sum_resource=np.zeros(shape=(1,2000), dtype=np.float64)
sum_cost=np.zeros(shape=(1,2000), dtype=np.float64)
iteration_update = 0.01 #迭代步长
#W=np.zeros(shape=(54,54)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
W=np.loadtxt("double_stochastic_weight_1.txt") #双随机的网络拓扑矩阵W（对角线处非零）
iteration=[]#绘图横坐标
generator_a_values= np.loadtxt("generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("generator_b_values.txt")#每个agent的成本函数中的超参数a
generator_c_values= np.loadtxt("generator_c_values.txt")#每个agent的成本函数中的超参数a
C=np.zeros(shape=(1,2000), dtype=np.float64)#adaptive robust clipping的裁剪参数 
#设置为全局第b大的梯度信息 b为网络中设备损坏的用户上界 每一次迭代就需要计算一次新的C值

# %%
'''for i in range(0,54):
    for j in range(0,54):
        W[i][j]=1/54'''

#对偶变量的初始化 初始化一致
for i in range (0,54):
    dual_variable[i][0]=0
    
#资源量的初始化 资源量的初始化需要和对偶变量的初始值满足某种关系
for i in range (0,54):
    agent_resource_quantity[i][0]=6000/54

iteration.append(0)

#总资源量 初始化
sum=0
for i in range (0,54):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

#用户总成本初始化
sum=0
for i in range(0,54):
    sum=sum+(generator_c_values[i]*(agent_resource_quantity[i][0])*(agent_resource_quantity[i][0])+generator_b_values[i]*agent_resource_quantity[i][0]+generator_a_values[i])
sum_cost[0][0]=sum

# %%
#DGD算法 
def DGD_ARC_determinitic_bias(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,dual_variable,iteration_update,W,iteration,C):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************DGD算法+无计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,54):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    for i in range(0,54):
        print("agent",(i+1),"的初始对偶变量为:",dual_variable[i][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,2000):#迭代次数
        iteration.append(k)
        
        #所有用户对偶变量的迭代 
        #阶段一：梯度下降
        dual_variable_intermediate=[] #存放当前迭代中100个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,54):
            #每个用户对对偶变量先进行一次梯度下降
            if i==48:
                dual_variable_intermediate.append(-24)
            else:
                dual_variable_intermediate.append(dual_variable[i][k-1]-iteration_update*((6000/54)-agent_resource_quantity[i][k-1]))       
       
        #阶段二：鲁棒聚合 ARC  
        #先计算当前的clipping阈值C 
        column_data = dual_variable_intermediate
        second_largest = np.partition(np.abs(column_data), -2)[-2]
        C[0][k]=second_largest        
        for i in range(0,54):
            mix_sum_dual=0
            for j in range(0,54):
                if W[i][j]!=0 and np.abs(dual_variable_intermediate[j])>C[0][k]:
                    mix_sum_dual=mix_sum_dual+W[i][j]*(C[0][k]/np.abs(dual_variable_intermediate[j]))*dual_variable_intermediate[j]                  
                elif W[i][j]!=0 and np.abs(dual_variable_intermediate[j])<=C[0][k]:
                    mix_sum_dual=mix_sum_dual+W[i][j]*dual_variable_intermediate[j]
            dual_variable[i][k]=mix_sum_dual                    
        
        #用户资源申请量的迭代
        for i in range (0,54):
            agent_resource_quantity[i][k]=(-dual_variable[i][k]-generator_b_values[i])/(2*generator_c_values[i]) 

        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,54):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,54):
            sum2=sum2+(generator_a_values[i]+(generator_b_values[i]*agent_resource_quantity[i][k])+(generator_c_values[i]*agent_resource_quantity[i][k]*agent_resource_quantity[i][k]))
        sum_cost[0][k]=sum2
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%20==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,54):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            for i in range(0,54):
                print("agent",(i+1),"在",k,"次迭代中的对偶变量为:",dual_variable[i][k])   
            print("*************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=(1/(pow(k+1,1.3)))*(1/26.511) #递减步长
        iteration_update=(1/(pow(k+1,1.5)))*(1/18.8468) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
DGD_ARC_determinitic_bias(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,dual_variable,iteration_update,W,iteration,C)
# Out:
# ****************************DGD算法+无计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 111.11111111111111
# agent 2 的初始资源申请量为: 111.11111111111111
# agent 3 的初始资源申请量为: 111.11111111111111
# agent 4 的初始资源申请量为: 111.11111111111111
# agent 5 的初始资源申请量为: 111.11111111111111
# agent 6 的初始资源申请量为: 111.11111111111111
# agent 7 的初始资源申请量为: 111.11111111111111
# agent 8 的初始资源申请量为: 111.11111111111111
# agent 9 的初始资源申请量为: 111.11111111111111
# agent 10 的初始资源申请量为: 111.11111111111111
# agent 11 的初始资源申请量为: 111.11111111111111
# agent 12 的初始资源申请量为: 111.11111111111111
# agent 13 的初始资源申请量为: 111.11111111111111
# agent 14 的初始资源申请量为: 111.11111111111111
# agent 15 的初始资源申请量为: 111.11111111111111
# agent 16 的初始资源申请量为: 111.11111111111111
# agent 17 的初始资源申请量为: 111.11111111111111
# agent 18 的初始资源申请量为: 111.11111111111111
# agent 19 的初始资源申请量为: 111.11111111111111
# agent 20 的初始资源申请量为: 111.11111111111111
# agent 21 的初始资源申请量为: 111.11111111111111
# agent 22 的初始资源申请量为: 111.11111111111111
# agent 23 的初始资源申请量为: 111.11111111111111
# agent 24 的初始资源申请量为: 111.11111111111111
# agent 25 的初始资源申请量为: 111.11111111111111
# agent 26 的初始资源申请量为: 111.11111111111111
# agent 27 的初始资源申请量为: 111.11111111111111
# agent 28 的初始资源申请量为: 111.11111111111111
# agent 29 的初始资源申请量为: 111.11111111111111
# agent 30 的初始资源申请量为: 111.11111111111111
# agent 31 的初始资源申请量为: 111.11111111111111
# agent 32 的初始资源申请量为: 111.11111111111111
# agent 33 的初始资源申请量为: 111.11111111111111
# agent 34 的初始资源申请量为: 111.11111111111111
# agent 35 的初始资源申请量为: 111.11111111111111
# agent 36 的初始资源申请量为: 111.11111111111111
# agent 37 的初始资源申请量为: 111.11111111111111
# agent 38 的初始资源申请量为: 111.11111111111111
# agent 39 的初始资源申请量为: 111.11111111111111
# agent 40 的初始资源申请量为: 111.11111111111111
# agent 41 的初始资源申请量为: 111.11111111111111
# agent 42 的初始资源申请量为: 111.11111111111111
# agent 43 的初始资源申请量为: 111.11111111111111
# agent 44 的初始资源申请量为: 111.11111111111111
# agent 45 的初始资源申请量为: 111.11111111111111
# agent 46 的初始资源申请量为: 111.11111111111111
# agent 47 的初始资源申请量为: 111.11111111111111
# agent 48 的初始资源申请量为: 111.11111111111111
# agent 49 的初始资源申请量为: 111.11111111111111
# agent 50 的初始资源申请量为: 111.11111111111111
# agent 51 的初始资源申请量为: 111.11111111111111
# agent 52 的初始资源申请量为: 111.11111111111111
# agent 53 的初始资源申请量为: 111.11111111111111
# agent 54 的初始资源申请量为: 111.11111111111111
# *************************
# 初始资源申请量总和为: 6000.000000000006
# *************************
# 初始成本总和为: 139226.02283950621
# *************************
# agent 1 的初始对偶变量为: 0.0
# agent 2 的初始对偶变量为: 0.0
# agent 3 的初始对偶变量为: 0.0
# agent 4 的初始对偶变量为: 0.0
# agent 5 的初始对偶变量为: 0.0
# agent 6 的初始对偶变量为: 0.0
# agent 7 的初始对偶变量为: 0.0
# agent 8 的初始对偶变量为: 0.0
# agent 9 的初始对偶变量为: 0.0
# agent 10 的初始对偶变量为: 0.0
# agent 11 的初始对偶变量为: 0.0
# agent 12 的初始对偶变量为: 0.0
# agent 13 的初始对偶变量为: 0.0
# agent 14 的初始对偶变量为: 0.0
# agent 15 的初始对偶变量为: 0.0
# agent 16 的初始对偶变量为: 0.0
# agent 17 的初始对偶变量为: 0.0
# agent 18 的初始对偶变量为: 0.0
# agent 19 的初始对偶变量为: 0.0
# agent 20 的初始对偶变量为: 0.0
# agent 21 的初始对偶变量为: 0.0
# agent 22 的初始对偶变量为: 0.0
# agent 23 的初始对偶变量为: 0.0
# agent 24 的初始对偶变量为: 0.0
# agent 25 的初始对偶变量为: 0.0
# agent 26 的初始对偶变量为: 0.0
# agent 27 的初始对偶变量为: 0.0
# agent 28 的初始对偶变量为: 0.0
# agent 29 的初始对偶变量为: 0.0
# agent 30 的初始对偶变量为: 0.0
# agent 31 的初始对偶变量为: 0.0
# agent 32 的初始对偶变量为: 0.0
# agent 33 的初始对偶变量为: 0.0
# agent 34 的初始对偶变量为: 0.0
# agent 35 的初始对偶变量为: 0.0
# agent 36 的初始对偶变量为: 0.0
# agent 37 的初始对偶变量为: 0.0
# agent 38 的初始对偶变量为: 0.0
# agent 39 的初始对偶变量为: 0.0
# agent 40 的初始对偶变量为: 0.0
# agent 41 的初始对偶变量为: 0.0
# agent 42 的初始对偶变量为: 0.0
# agent 43 的初始对偶变量为: 0.0
# agent 44 的初始对偶变量为: 0.0
# agent 45 的初始对偶变量为: 0.0
# agent 46 的初始对偶变量为: 0.0
# agent 47 的初始对偶变量为: 0.0
# agent 48 的初始对偶变量为: 0.0
# agent 49 的初始对偶变量为: 0.0
# agent 50 的初始对偶变量为: 0.0
# agent 51 的初始对偶变量为: 0.0
# agent 52 的初始对偶变量为: 0.0
# agent 53 的初始对偶变量为: 0.0
# agent 54 的初始对偶变量为: 0.0
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 19 次迭代中的结果：
# agent 1 在 19 次迭代中的资源申请量为: -67.39997525681459
# agent 2 在 19 次迭代中的资源申请量为: -67.39997525681459
# agent 3 在 19 次迭代中的资源申请量为: -69.03724004476919
# agent 4 在 19 次迭代中的资源申请量为: 156.87541415996714
# agent 5 在 19 次迭代中的资源申请量为: 176.11098325677722
# agent 6 在 19 次迭代中的资源申请量为: -68.37120217450509
# agent 7 在 19 次迭代中的资源申请量为: -40.42892761833699
# agent 8 在 19 次迭代中的资源申请量为: -65.26329754774474
# agent 9 在 19 次迭代中的资源申请量为: -61.95243024665605
# agent 10 在 19 次迭代中的资源申请量为: 192.88019573273155
# agent 11 在 19 次迭代中的资源申请量为: 982.5844379949252
# agent 12 在 19 次迭代中的资源申请量为: -65.88950125317949
# agent 13 在 19 次迭代中的资源申请量为: -68.04260265274318
# agent 14 在 19 次迭代中的资源申请量为: -26.297004286223167
# agent 15 在 19 次迭代中的资源申请量为: -68.94899191264052
# agent 16 在 19 次迭代中的资源申请量为: -46.35489939175327
# agent 17 在 19 次迭代中的资源申请量为: -69.57403471979045
# agent 18 在 19 次迭代中的资源申请量为: -72.39571143065558
# agent 19 在 19 次迭代中的资源申请量为: -45.68767459485229
# agent 20 在 19 次迭代中的资源申请量为: 742.8661716461497
# agent 21 在 19 次迭代中的资源申请量为: 576.5991106596354
# agent 22 在 19 次迭代中的资源申请量为: -108.29660231545023
# agent 23 在 19 次迭代中的资源申请量为: -106.29965119579809
# agent 24 在 19 次迭代中的资源申请量为: 215.16446340504223
# agent 25 在 19 次迭代中的资源申请量为: 230.3254373369429
# agent 26 在 19 次迭代中的资源申请量为: -102.75047964196835
# agent 27 在 19 次迭代中的资源申请量为: 386.91875014876774
# agent 28 在 19 次迭代中的资源申请量为: 332.4472731863103
# agent 29 在 19 次迭代中的资源申请量为: 224.61695193232987
# agent 30 在 19 次迭代中的资源申请量为: 30.82379645130163
# agent 31 在 19 次迭代中的资源申请量为: -57.760073117417825
# agent 32 在 19 次迭代中的资源申请量为: -56.732688598336416
# agent 33 在 19 次迭代中的资源申请量为: -340.73697609272796
# agent 34 在 19 次迭代中的资源申请量为: 23.036101767469894
# agent 35 在 19 次迭代中的资源申请量为: 23.094429900249178
# agent 36 在 19 次迭代中的资源申请量为: 255.18883360139864
# agent 37 在 19 次迭代中的资源申请量为: 24.25057584246673
# agent 38 在 19 次迭代中的资源申请量为: -65.25820465486471
# agent 39 在 19 次迭代中的资源申请量为: 886.0329007284629
# agent 40 在 19 次迭代中的资源申请量为: 264.0944245785429
# agent 41 在 19 次迭代中的资源申请量为: -323.09467535464785
# agent 42 在 19 次迭代中的资源申请量为: -172.89602960097824
# agent 43 在 19 次迭代中的资源申请量为: 275.5220117990361
# agent 44 在 19 次迭代中的资源申请量为: 278.82858070677725
# agent 45 在 19 次迭代中的资源申请量为: 342.7516430447355
# agent 46 在 19 次迭代中的资源申请量为: -290.28306366451466
# agent 47 在 19 次迭代中的资源申请量为: 130.91630624197478
# agent 48 在 19 次迭代中的资源申请量为: 139.35488008377794
# agent 49 在 19 次迭代中的资源申请量为: -288.9681096525617
# agent 50 在 19 次迭代中的资源申请量为: -68.46660643609613
# agent 51 在 19 次迭代中的资源申请量为: 150.34312231365823
# agent 52 在 19 次迭代中的资源申请量为: 150.34312231365823
# agent 53 在 19 次迭代中的资源申请量为: -43.973333682098826
# agent 54 在 19 次迭代中的资源申请量为: -261.0453794328351
# 资源申请量总和为: 4002.3645770053135
# ****************************************************************************
# 成本总和为: 31978.75331884546
# ****************************************************************************
# agent 1 在 19 次迭代中的对偶变量为: -16.85323104736905
# agent 2 在 19 次迭代中的对偶变量为: -16.85323104736905
# agent 3 在 19 次迭代中的对偶变量为: -16.625117493522488
# agent 4 在 19 次迭代中的对偶变量为: -16.299540257979285
# agent 5 在 19 次迭代中的对偶变量为: -16.717913885834903
# agent 6 在 19 次迭代中的对偶变量为: -16.717913885834903
# agent 7 在 19 次迭代中的对偶变量为: -16.785019452970573
# agent 8 在 19 次迭代中的对偶变量为: -17.150925805862915
# agent 9 在 19 次迭代中的对偶变量为: -17.6122157034544
# agent 10 在 19 次迭代中的对偶变量为: -17.08264425718691
# agent 11 在 19 次迭代中的对偶变量为: -16.65550662796955
# agent 12 在 19 次迭代中的对偶变量为: -17.063679348399514
# agent 13 在 19 次迭代中的对偶变量为: -16.763696342803904
# agent 14 在 19 次迭代中的对偶变量为: -17.146796690272687
# agent 15 在 19 次迭代中的对偶变量为: -16.637412752779447
# agent 16 在 19 次迭代中的对偶变量为: -16.633314575571116
# agent 17 在 19 次迭代中的对偶变量为: -16.550328038630475
# agent 18 在 19 次迭代中的对偶变量为: -16.15719510921248
# agent 19 在 19 次迭代中的对偶变量为: -16.65039553037178
# agent 20 在 19 次迭代中的对偶变量为: -15.897143356244811
# agent 21 在 19 次迭代中的对偶变量为: -15.098728929387569
# agent 22 在 19 次迭代中的对偶变量为: -15.047606980724474
# agent 23 在 19 次迭代中的对偶变量为: -15.098728929387569
# agent 24 在 19 次迭代中的对偶变量为: -15.18344727796437
# agent 25 在 19 次迭代中的对偶变量为: -15.316863848565097
# agent 26 在 19 次迭代中的对偶变量为: -15.18958772116561
# agent 27 在 19 次迭代中的对偶变量为: -16.5340391281509
# agent 28 在 19 次迭代中的对偶变量为: -15.380333246086053
# agent 29 在 19 次迭代中的对偶变量为: -17.772918704528173
# agent 30 在 19 次迭代中的对偶变量为: -18.30184240886625
# agent 31 在 19 次迭代中的对偶变量为: -18.196320052842644
# agent 32 在 19 次迭代中的对偶变量为: -18.33946142834818
# agent 33 在 19 次迭代中的对偶变量为: -18.40972420524723
# agent 34 在 19 次迭代中的对偶变量为: -18.40972420524723
# agent 35 在 19 次迭代中的对偶变量为: -18.41121740544638
# agent 36 在 19 次迭代中的对偶变量为: -18.43785713083042
# agent 37 在 19 次迭代中的对偶变量为: -18.44081474156715
# agent 38 在 19 次迭代中的对偶变量为: -17.15163537825632
# agent 39 在 19 次迭代中的对偶变量为: -16.076197404370777
# agent 40 在 19 次迭代中的对偶变量为: -18.631553734583306
# agent 41 在 19 次迭代中的对偶变量为: -19.408348996225516
# agent 42 在 19 次迭代中的对偶变量为: -19.562528413360077
# agent 43 在 19 次迭代中的对偶变量为: -18.880103756629033
# agent 44 在 19 次迭代中的对偶变量为: -18.952021630372403
# agent 45 在 19 次迭代中的对偶变量为: -20.342348236222996
# agent 46 在 19 次迭代中的对偶变量为: -21.265617464333815
# agent 47 在 19 次迭代中的对偶变量为: -21.171457439794555
# agent 48 在 19 次迭代中的对偶变量为: -21.387484930144716
# agent 49 在 19 次迭代中的对偶变量为: -21.3400491212264
# agent 50 在 19 次迭代中的对偶变量为: -21.603914777387192
# agent 51 在 19 次迭代中的对偶变量为: -21.66878393122965
# agent 52 在 19 次迭代中的对偶变量为: -21.66878393122965
# agent 53 在 19 次迭代中的对偶变量为: -16.69428265773827
# agent 54 在 19 次迭代中的对偶变量为: -17.83938492284694
# *************************
# 迭代步长为: 0.0006406664425248283
# ****************************************************************************
# 39 次迭代中的结果：
# agent 1 在 39 次迭代中的资源申请量为: -65.17925558085953
# agent 2 在 39 次迭代中的资源申请量为: -65.17925558085953
# agent 3 在 39 次迭代中的资源申请量为: -65.72071911776112
# agent 4 在 39 次迭代中的资源申请量为: 186.97716151998077
# agent 5 在 39 次迭代中的资源申请量为: 194.81883661162718
# agent 6 在 39 次迭代中的资源申请量为: -65.45074360634132
# agent 7 在 39 次迭代中的资源申请量为: -25.077165334289745
# agent 8 在 39 次迭代中的资源申请量为: -63.13742005587294
# agent 9 在 39 次迭代中的资源申请量为: -60.81139458859647
# agent 10 在 39 次迭代中的资源申请量为: 209.0298605167833
# agent 11 在 39 次迭代中的资源申请量为: 1061.5813593627404
# agent 12 在 39 次迭代中的资源申请量为: -63.487071412907405
# agent 13 在 39 次迭代中的资源申请量为: -65.01198695864329
# agent 14 在 39 次迭代中的资源申请量为: -14.601432532092007
# agent 15 在 39 次迭代中的资源申请量为: -65.62664179850957
# agent 16 在 39 次迭代中的资源申请量为: -28.11916161763281
# agent 17 在 39 次迭代中的资源申请量为: -66.13552314416395
# agent 18 在 39 次迭代中的资源申请量为: -68.20012169595881
# agent 19 在 39 次迭代中的资源申请量为: -27.67591985079462
# agent 20 在 39 次迭代中的资源申请量为: 881.6003976753306
# agent 21 在 39 次迭代中的资源申请量为: 749.2509631824566
# agent 22 在 39 次迭代中的资源申请量为: -76.40678802922851
# agent 23 在 39 次迭代中的资源申请量为: -73.91394042179076
# agent 24 在 39 次迭代中的资源申请量为: 307.5783568634366
# agent 25 在 39 次迭代中的资源申请量为: 323.00036034460885
# agent 26 在 39 次迭代中的资源申请量为: -68.08777398649754
# agent 27 在 39 次迭代中的资源申请量为: 410.69827640812986
# agent 28 在 39 次迭代中的资源申请量为: 374.2707561072697
# agent 29 在 39 次迭代中的资源申请量为: 229.4513481570823
# agent 30 在 39 次迭代中的资源申请量为: 29.944970095563928
# agent 31 在 39 次迭代中的资源申请量为: -57.96474392188211
# agent 32 在 39 次迭代中的资源申请量为: -57.252056176419764
# agent 33 在 39 次迭代中的资源申请量为: -343.0789972260684
# agent 34 在 39 次迭代中的资源申请量为: 17.85767347717293
# agent 35 在 39 次迭代中的资源申请量为: 21.720279389584594
# agent 36 在 39 次迭代中的资源申请量为: 260.8166207529572
# agent 37 在 39 次迭代中的资源申请量为: 33.88508804529525
# agent 38 在 39 次迭代中的资源申请量为: -58.77115767179133
# agent 39 在 39 次迭代中的资源申请量为: 1138.6562625429108
# agent 40 在 39 次迭代中的资源申请量为: 263.88846974607344
# agent 41 在 39 次迭代中的资源申请量为: -332.1642696083192
# agent 42 在 39 次迭代中的资源申请量为: -202.89055356932434
# agent 43 在 39 次迭代中的资源申请量为: 273.1824835280863
# agent 44 在 39 次迭代中的资源申请量为: 284.9840046775867
# agent 45 在 39 次迭代中的资源申请量为: 337.1559202466633
# agent 46 在 39 次迭代中的资源申请量为: -295.98885507565893
# agent 47 在 39 次迭代中的资源申请量为: 118.72972845477753
# agent 48 在 39 次迭代中的资源申请量为: 126.62024947043216
# agent 49 在 39 次迭代中的资源申请量为: -293.6580630848159
# agent 50 在 39 次迭代中的资源申请量为: -84.60969278507102
# agent 51 在 39 次迭代中的资源申请量为: 139.02607153172096
# agent 52 在 39 次迭代中的资源申请量为: 139.02607153172096
# agent 53 在 39 次迭代中的资源申请量为: -26.555945491649744
# agent 54 在 39 次迭代中的资源申请量为: -253.95839155563664
# 资源申请量总和为: 5079.036528760553
# ****************************************************************************
# 成本总和为: 49012.68248314312
# ****************************************************************************
# agent 1 在 39 次迭代中的对偶变量为: -17.162635036941165
# agent 2 在 39 次迭代中的对偶变量为: -17.162635036941165
# agent 3 在 39 次迭代中的对偶变量为: -17.087195088198815
# agent 4 在 39 次迭代中的对偶变量为: -16.95425326305958
# agent 5 在 39 次迭代中的对偶变量为: -17.12480969630289
# agent 6 在 39 次迭代中的对偶变量为: -17.12480969630289
# agent 7 在 39 次迭代中的对偶变量为: -17.178024567442183
# agent 8 在 39 次迭代中的对偶变量为: -17.447115813295447
# agent 9 在 39 次迭代中的对偶变量为: -17.771191637549208
# agent 10 在 39 次迭代中的对偶变量为: -17.433899466240035
# agent 11 在 39 次迭代中的对偶变量为: -17.129488156176443
# agent 12 在 39 次迭代中的对偶变量为: -17.398400288325263
# agent 13 在 39 次迭代中的对偶变量为: -17.185939905000065
# agent 14 在 39 次迭代中的对偶变量为: -17.446203327178445
# agent 15 在 39 次迭代中的对偶变量为: -17.100302504780856
# agent 16 在 39 次迭代中的对偶变量为: -17.1001494625886
# agent 17 在 39 次迭代中的对偶变量为: -17.029402102416213
# agent 18 在 39 次迭代中的对偶变量为: -16.741749844588842
# agent 19 在 39 次迭代中的对偶变量为: -17.111496451819658
# agent 20 在 39 次迭代中的对偶变量为: -16.563345109636938
# agent 21 在 39 次迭代中的对偶变量为: -15.927803125202157
# agent 22 在 39 次迭代中的对偶变量为: -15.86398622645175
# agent 23 在 39 次迭代中的对偶变量为: -15.927803125202157
# agent 24 在 39 次迭代中的对偶变量为: -15.996689540398242
# agent 25 在 39 次迭代中的对偶变量为: -16.132403171032557
# agent 26 在 39 次迭代中的对偶变量为: -16.076952985945663
# agent 27 在 39 次迭代中的对偶变量为: -17.03768949432419
# agent 28 在 39 次迭代中的对偶变量为: -16.266154614351972
# agent 29 在 39 次迭代中的对偶变量为: -17.87806682241654
# agent 30 在 39 次迭代中的对偶变量为: -18.221125723397165
# agent 31 在 39 次迭代中的对偶变量为: -18.167804088339853
# agent 32 在 39 次迭代中的对偶变量为: -18.26710002116414
# agent 33 在 39 次迭代中的对偶变量为: -18.277156441015627
# agent 34 在 39 次迭代中的对偶变量为: -18.277156441015627
# agent 35 在 39 次迭代中的对偶变量为: -18.376039152373366
# agent 36 在 39 次迭代中的对偶变量为: -18.560261501376818
# agent 37 在 39 次迭代中的对偶变量为: -18.68745825395956
# agent 38 在 39 次迭代中的对偶变量为: -18.05544968622
# agent 39 在 39 次迭代中的对偶变量为: -17.591937575257464
# agent 40 在 39 次迭代中的对偶变量为: -18.627074216977096
# agent 41 在 39 次迭代中的对偶变量为: -18.8949736830907
# agent 42 在 39 次迭代中的对偶变量为: -18.976195458826847
# agent 43 在 39 次迭代中的对偶变量为: -18.829219016735877
# agent 44 在 39 次迭代中的对偶变量为: -19.08590210173751
# agent 45 在 39 次迭代中的对偶变量为: -20.220641265364925
# agent 46 在 39 次迭代中的对偶变量为: -20.942646847297404
# agent 47 在 39 次迭代中的对偶变量为: -20.859481048442305
# agent 48 在 39 次迭代中的对偶变量为: -21.061478386443063
# agent 49 在 39 次迭代中的对偶变量为: -21.074578997147082
# agent 50 在 39 次迭代中的对偶变量为: -21.28834972543743
# agent 51 在 39 次迭代中的对偶变量为: -21.379067431212057
# agent 52 在 39 次迭代中的对偶变量为: -21.379067431212057
# agent 53 在 39 次迭代中的对偶变量为: -17.140167795413767
# agent 54 在 39 次迭代中的对偶变量为: -17.977921361870415
# *************************
# 迭代步长为: 0.000217853964469636
# ****************************************************************************
# 59 次迭代中的结果：
# agent 1 在 59 次迭代中的资源申请量为: -63.903982017478334
# agent 2 在 59 次迭代中的资源申请量为: -63.903982017478334
# agent 3 在 59 次迭代中的资源申请量为: -64.17084069582211
# agent 4 在 59 次迭代中的资源申请量为: 199.31510974866447
# agent 5 在 59 次迭代中的资源申请量为: 204.05810623731932
# agent 6 在 59 次迭代中的资源申请量为: -64.00841328494542
# agent 7 在 59 次迭代中的资源申请量为: -17.88667555014778
# agent 8 在 59 次迭代中的资源申请量为: -62.51297219905202
# agent 9 在 59 次迭代中的资源申请量为: -60.91373417830409
# agent 10 在 59 次迭代中的资源申请量为: 213.2705962461575
# agent 11 在 59 次迭代中的资源申请量为: 1095.8014653915131
# agent 12 在 59 次迭代中的资源申请量为: -62.775455394285586
# agent 13 在 59 次迭代中的资源申请量为: -63.70999616631457
# agent 14 在 59 次迭代中的资源申请量为: -11.29301720173642
# agent 15 在 59 次迭代中的资源申请量为: -64.04110764452905
# agent 16 在 59 次迭代中的资源申请量为: -19.709537557116157
# agent 17 在 59 次迭代中的资源申请量为: -64.42143213624392
# agent 18 在 59 次迭代中的资源申请量为: -65.76346712061388
# agent 19 在 59 次迭代中的资源申请量为: -17.78753046087905
# agent 20 在 59 次迭代中的资源申请量为: 967.3766268882144
# agent 21 在 59 次迭代中的资源申请量为: 873.6840859951838
# agent 22 在 59 次迭代中的资源申请量为: -52.44702033015719
# agent 23 在 59 次迭代中的资源申请量为: -50.57300855668467
# agent 24 在 59 次迭代中的资源申请量为: 373.4219452634344
# agent 25 在 59 次迭代中的资源申请量为: 384.97423776065716
# agent 26 在 59 次迭代中的资源申请量为: -45.93743993229149
# agent 27 在 59 次迭代中的资源申请量为: 423.814854020059
# agent 28 在 59 次迭代中的资源申请量为: 398.664801131155
# agent 29 在 59 次迭代中的资源申请量为: 232.3083618740497
# agent 30 在 59 次迭代中的资源申请量为: 28.792552226301986
# agent 31 在 59 次迭代中的资源申请量为: -58.960997272720725
# agent 32 在 59 次迭代中的资源申请量为: -58.45764021925148
# agent 33 在 59 次迭代中的资源申请量为: -344.41405613221895
# agent 34 在 59 次迭代中的资源申请量为: 14.905733073901638
# agent 35 在 59 次迭代中的资源申请量为: 20.17799155195357
# agent 36 在 59 次迭代中的资源申请量为: 262.1423195059734
# agent 37 在 59 次迭代中的资源申请量为: 36.38488357445693
# agent 38 在 59 次迭代中的资源申请量为: -56.323783183393395
# agent 39 在 59 次迭代中的资源申请量为: 1229.7814059014102
# agent 40 在 59 次迭代中的资源申请量为: 267.76891757698445
# agent 41 在 59 次迭代中的资源申请量为: -332.9232951373937
# agent 42 在 59 次迭代中的资源申请量为: -206.76608846917262
# agent 43 在 59 次迭代中的资源申请量为: 273.7573378256876
# agent 44 在 59 次迭代中的资源申请量为: 284.5765378261447
# agent 45 在 59 次迭代中的资源申请量为: 328.39637541996547
# agent 46 在 59 次迭代中的资源申请量为: -301.5173012509743
# agent 47 在 59 次迭代中的资源申请量为: 107.02294350597566
# agent 48 在 59 次迭代中的资源申请量为: 113.8656177484211
# agent 49 在 59 次迭代中的资源申请量为: -299.232416599356
# agent 50 在 59 次迭代中的资源申请量为: -102.98509254944828
# agent 51 在 59 次迭代中的资源申请量为: 124.6449582731797
# agent 52 在 59 次迭代中的资源申请量为: 124.6449582731797
# agent 53 在 59 次迭代中的资源申请量为: -18.751350664747424
# agent 54 在 59 次迭代中的资源申请量为: -249.65050506353222
# 资源申请量总和为: 5637.810583853656
# ****************************************************************************
# 成本总和为: 57998.08024686741
# ****************************************************************************
# agent 1 在 59 次迭代中的对偶变量为: -17.340313801432814
# agent 2 在 59 次迭代中的对偶变量为: -17.340313801432814
# agent 3 在 59 次迭代中的对偶变量为: -17.303133449213888
# agent 4 在 59 次迭代中的对偶变量为: -17.22260363703345
# agent 5 在 59 次迭代中的对偶变量为: -17.325763810661694
# agent 6 在 59 次迭代中的对偶变量为: -17.325763810661694
# agent 7 在 59 次迭代中的对偶变量为: -17.362101105916217
# agent 8 在 59 次迭代中的对偶变量为: -17.534117635394878
# agent 9 在 59 次迭代中的对偶变量为: -17.756933071873604
# agent 10 在 59 次迭代中的对偶变量为: -17.526135468353925
# agent 11 在 59 次迭代中的对偶变量为: -17.33480879234908
# agent 12 在 59 次迭代中的对偶变量为: -17.497546901735767
# agent 13 在 59 次迭代中的对偶变量为: -17.367341074132057
# agent 14 在 59 次迭代中的对偶变量为: -17.530898759635548
# agent 15 在 59 次迭代中的对偶变量为: -17.321208636318346
# agent 16 在 59 次迭代中的对偶变量为: -17.315435838537827
# agent 17 在 59 次迭代中的对偶变量为: -17.26821954618568
# agent 18 在 59 次迭代中的对偶变量为: -17.08123917995335
# agent 19 在 59 次迭代中的对偶变量为: -17.364639220201497
# agent 20 在 59 次迭代中的对偶变量为: -16.975242562317206
# agent 21 在 59 次迭代中的对偶变量为: -16.525330980948873
# agent 22 在 59 次迭代中的对偶变量为: -16.477356279547976
# agent 23 在 59 次迭代中的对偶变量为: -16.525330980948873
# agent 24 在 59 次迭代中的对偶变量为: -16.576113118318222
# agent 25 在 59 次迭代中的对偶变量为: -16.677773292293782
# agent 26 在 59 次迭代中的对偶变量为: -16.644001537733338
# agent 27 在 59 次迭代中的对偶变量为: -17.31549860814485
# agent 28 在 59 次迭代中的对偶变量为: -16.782820487957864
# agent 29 在 59 次迭代中的对偶变量为: -17.94020687076058
# agent 30 在 59 次迭代中的对偶变量为: -18.115280751776933
# agent 31 在 59 次迭代中的对偶变量为: -18.029000093980912
# agent 32 在 59 次迭代中的对偶变量为: -18.09913081881257
# agent 33 在 59 次迭代中的对偶变量为: -18.201586766691882
# agent 34 在 59 次迭代中的对偶变量为: -18.201586766691882
# agent 35 在 59 次迭代中的对偶变量为: -18.33655658373001
# agent 36 在 59 次迭代中的对偶变量为: -18.58909544925492
# agent 37 在 59 次迭代中的对偶变量为: -18.751453019506098
# agent 38 在 59 次迭代中的对偶变量为: -18.39643258419053
# agent 39 在 59 次迭代中的对偶变量为: -18.13868843540846
# agent 40 在 59 次迭代中的对偶变量为: -18.71147395729941
# agent 41 在 59 次迭代中的对偶变量为: -18.852009802042968
# agent 42 在 59 次迭代中的对偶变量为: -18.900436502604613
# agent 43 在 59 次迭代中的对偶变量为: -18.841722097708704
# agent 44 在 59 次迭代中的对偶变量为: -19.077039697718646
# agent 45 在 59 次迭代中的对偶变量为: -20.030121165384248
# agent 46 在 59 次迭代中的对偶变量为: -20.629714679989853
# agent 47 在 59 次迭代中的对偶变量为: -20.559787353752977
# agent 48 在 59 次迭代中的对偶变量为: -20.73495981435958
# agent 49 在 59 次迭代中的对偶变量为: -20.759048290810057
# agent 50 在 59 次迭代中的对偶变量为: -20.929147410843385
# agent 51 在 59 次迭代中的对偶变量为: -21.0109109317934
# agent 52 在 59 次迭代中的对偶变量为: -21.0109109317934
# agent 53 在 59 次迭代中的对偶变量为: -17.339965422982466
# agent 54 在 59 次迭代中的对偶变量为: -18.062131927018072
# *************************
# 迭代步长为: 0.00011708044397666381
# ****************************************************************************
# 79 次迭代中的结果：
# agent 1 在 79 次迭代中的资源申请量为: -62.88307587971035
# agent 2 在 79 次迭代中的资源申请量为: -62.88307587971035
# agent 3 在 79 次迭代中的资源申请量为: -63.033962284080275
# agent 4 在 79 次迭代中的资源申请量为: 207.44508606297074
# agent 5 在 79 次迭代中的资源申请量为: 211.09534372727424
# agent 6 在 79 次迭代中的资源申请量为: -62.90983932598213
# agent 7 在 79 次迭代中的资源申请量为: -12.24020646876947
# agent 8 在 79 次迭代中的资源申请量为: -61.85023843319482
# agent 9 在 79 次迭代中的资源申请量为: -60.63561069303323
# agent 10 在 79 次迭代中的资源申请量为: 217.53827517645115
# agent 11 在 79 次迭代中的资源申请量为: 1121.3832884644316
# agent 12 在 79 次迭代中的资源申请量为: -62.077612233797474
# agent 13 在 79 次迭代中的资源申请量为: -62.69347482345557
# agent 14 在 79 次迭代中的资源申请量为: -7.756873287116384
# agent 15 在 79 次迭代中的资源申请量为: -62.858146651294845
# agent 16 在 79 次迭代中的资源申请量为: -13.476419649690873
# agent 17 在 79 次迭代中的资源申请量为: -63.16548744604003
# agent 18 在 79 次迭代中的资源申请量为: -64.0569033676228
# agent 19 在 79 次迭代中的资源申请量为: -10.555584657325477
# agent 20 在 79 次迭代中的资源申请量为: 1026.466056782842
# agent 21 在 79 次迭代中的资源申请量为: 958.1713208107631
# agent 22 在 79 次迭代中的资源申请量为: -36.11340147646677
# agent 23 在 79 次迭代中的资源申请量为: -34.7250514635436
# agent 24 在 79 次迭代中的资源申请量为: 418.0802833077044
# agent 25 在 79 次迭代中的资源申请量为: 426.71084603656305
# agent 26 在 79 次迭代中的资源申请量为: -31.189236727561934
# agent 27 在 79 次迭代中的资源申请量为: 433.10126112840226
# agent 28 在 79 次迭代中的资源申请量为: 414.7759821593121
# agent 29 在 79 次迭代中的资源申请量为: 235.59650987305187
# agent 30 在 79 次迭代中的资源申请量为: 28.65384615999074
# agent 31 在 79 次迭代中的资源申请量为: -59.13960545453882
# agent 32 在 79 次迭代中的资源申请量为: -58.74438792359947
# agent 33 在 79 次迭代中的资源申请量为: -344.44608917901417
# agent 34 在 79 次迭代中的资源申请量为: 14.834905004339204
# agent 35 在 79 次迭代中的资源申请量为: 20.32478540743482
# agent 36 在 79 次迭代中的资源申请量为: 262.79398198905545
# agent 37 在 79 次迭代中的资源申请量为: 37.097651152107886
# agent 38 在 79 次迭代中的资源申请量为: -55.210650004945734
# agent 39 在 79 次迭代中的资源申请量为: 1271.0846399204358
# agent 40 在 79 次迭代中的资源申请量为: 270.0003973817631
# agent 41 在 79 次迭代中的资源申请量为: -332.9293754499388
# agent 42 在 79 次迭代中的资源申请量为: -207.6462786297865
# agent 43 在 79 次迭代中的资源申请量为: 273.91840630343495
# agent 44 在 79 次迭代中的资源申请量为: 282.97361678682273
# agent 45 在 79 次迭代中的资源申请量为: 319.8716650582774
# agent 46 在 79 次迭代中的资源申请量为: -306.48326954694727
# agent 47 在 79 次迭代中的资源申请量为: 96.46901403594615
# agent 48 在 79 次迭代中的资源申请量为: 102.31617220059705
# agent 49 在 79 次迭代中的资源申请量为: -304.4426184812225
# agent 50 在 79 次迭代中的资源申请量为: -119.5992876853642
# agent 51 在 79 次迭代中的资源申请量为: 111.53440180584505
# agent 52 在 79 次迭代中的资源申请量为: 111.53440180584505
# agent 53 在 79 次迭代中的资源申请量为: -12.837008093793678
# agent 54 在 79 次迭代中的资源申请量为: -245.95110908873588
# 资源申请量总和为: 5991.238258255378
# ****************************************************************************
# 成本总和为: 63760.89134694874
# ****************************************************************************
# agent 1 在 79 次迭代中的对偶变量为: -17.482552569983476
# agent 2 在 79 次迭代中的对偶变量为: -17.482552569983476
# agent 3 在 79 次迭代中的对偶变量为: -17.46153017080823
# agent 4 在 79 次迭代中的对偶变量为: -17.399430621869612
# agent 5 在 79 次迭代中的对偶变量为: -17.478823726068214
# agent 6 在 79 次迭代中的对偶变量为: -17.478823726068214
# agent 7 在 79 次迭代中的对偶变量为: -17.506650714399502
# agent 8 在 79 次迭代中的对偶变量为: -17.6264536800567
# agent 9 在 79 次迭代中的对偶变量为: -17.795682904582453
# agent 10 在 79 次迭代中的对偶变量为: -17.61895748508781
# agent 11 在 79 次迭代中的对偶变量为: -17.48829973078659
# agent 12 在 79 次迭代中的对偶变量为: -17.594774597913933
# agent 13 在 79 次迭代中的对偶变量为: -17.50896892674723
# agent 14 在 79 次迭代中的对偶变量为: -17.62142404384982
# agent 15 在 79 次迭代中的对偶变量为: -17.486025859661694
# agent 16 在 79 次迭代中的对偶变量为: -17.475003656967914
# agent 17 在 79 次迭代中的对偶变量为: -17.443205296093026
# agent 18 在 79 次迭代中的对偶变量为: -17.319007881402587
# agent 19 在 79 次迭代中的对偶变量为: -17.549777032772468
# agent 20 在 79 次迭代中的对偶变量为: -17.258990004671208
# agent 21 在 79 次迭代中的对偶变量为: -16.931038682533284
# agent 22 在 79 次迭代中的对偶变量为: -16.89549692220245
# agent 23 在 79 次迭代中的对偶变量为: -16.931038682533284
# agent 24 在 79 次迭代中的对偶变量为: -16.969106493107798
# agent 25 在 79 次迭代中的对偶变量为: -17.045055445121754
# agent 26 在 79 次迭代中的对偶变量为: -17.021555539774415
# agent 27 在 79 次迭代中的对偶变量为: -17.51218471069956
# agent 28 在 79 次迭代中的对偶变量为: -17.12405530213423
# agent 29 在 79 次迭代中的对偶变量为: -18.011724089738877
# agent 30 在 79 次迭代中的对偶变量为: -18.10254115441051
# agent 31 在 79 次迭代中的对偶变量为: -18.004115330440925
# agent 32 在 79 次迭代中的对偶变量为: -18.05917940815658
# agent 33 在 79 次迭代中的对偶变量为: -18.199773568111084
# agent 34 在 79 次迭代中的对偶变量为: -18.199773568111084
# agent 35 在 79 次迭代中的对偶变量为: -18.34031450643033
# agent 36 在 79 次迭代中的对偶变量为: -18.603269108261955
# agent 37 在 79 次迭代中的对偶变量为: -18.769699869493962
# agent 38 在 79 次迭代中的对偶变量为: -18.55152097741093
# agent 39 在 79 次迭代中的对偶变量为: -18.386507839522615
# agent 40 在 79 次迭代中的对偶变量为: -18.760008643053347
# agent 41 在 79 次迭代中的对偶变量为: -18.85166563203167
# agent 42 在 79 次迭代中的对偶变量为: -18.883230545344933
# agent 43 在 79 次迭代中的对偶变量为: -18.84522533709971
# agent 44 在 79 次迭代中的对偶变量为: -19.042176165113393
# agent 45 在 79 次迭代中的对偶变量为: -19.844708715017532
# agent 46 在 79 次迭代中的对偶变量为: -20.3486210105646
# agent 47 在 79 次迭代中的对偶变量为: -20.289606759320222
# agent 48 在 79 次迭代中的对偶变量为: -20.439294008335285
# agent 49 在 79 次迭代中的对偶变量为: -20.464130023488885
# agent 50 在 79 次迭代中的对偶变量为: -20.6043731243265
# agent 51 在 79 次迭代中的对偶变量为: -20.675280686229634
# agent 52 在 79 次迭代中的对偶变量为: -20.675280686229634
# agent 53 在 79 次迭代中的对偶变量为: -17.491372592798882
# agent 54 在 79 次迭代中的对偶变量为: -18.13444771953339
# *************************
# 迭代步长为: 7.556518347445504e-05
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: -61.95761819704778
# agent 2 在 99 次迭代中的资源申请量为: -61.95761819704778
# agent 3 在 99 次迭代中的资源申请量为: -62.04979736717607
# agent 4 在 99 次迭代中的资源申请量为: 214.1777943637501
# agent 5 在 99 次迭代中的资源申请量为: 217.27547837156018
# agent 6 在 99 次迭代中的资源申请量为: -61.945066573493584
# agent 7 在 99 次迭代中的资源申请量为: -7.181665812899252
# agent 8 在 99 次迭代中的资源申请量为: -61.132509904816565
# agent 9 在 99 次迭代中的资源申请量为: -60.150291279897694
# agent 10 在 99 次迭代中的资源申请量为: 222.14991852333532
# agent 11 在 99 次迭代中的资源申请量为: 1143.7601702448362
# agent 12 在 99 次迭代中的资源申请量为: -61.33539648087891
# agent 13 在 99 次迭代中的资源申请量为: -61.77554364323318
# agent 14 在 99 次迭代中的资源申请量为: -3.879987429174503
# agent 15 在 99 次迭代中的资源申请量为: -61.85058268106257
# agent 16 在 99 次迭代中的资源申请量为: -8.096531512738618
# agent 17 在 99 次迭代中的资源申请量为: -62.10996127592925
# agent 18 在 99 次迭代中的资源申请量为: -62.732654501800006
# agent 19 在 99 次迭代中的资源申请量为: -4.773562968734546
# agent 20 在 99 次迭代中的资源申请量为: 1070.3600255837957
# agent 21 在 99 次迭代中的资源申请量为: 1018.1662687794264
# agent 22 在 99 次迭代中的资源申请量为: -24.538706262900305
# agent 23 在 99 次迭代中的资源申请量为: -23.471311614109148
# agent 24 在 99 次迭代中的资源申请量为: 449.8572290347798
# agent 25 在 99 次迭代中的资源申请量为: 456.54002178636404
# agent 26 在 99 次迭代中的资源申请量为: -20.706724819252173
# agent 27 在 99 次迭代中的资源申请量为: 440.3896861141427
# agent 28 在 99 次迭代中的资源申请量为: 426.3297169002139
# agent 29 在 99 次迭代中的资源申请量为: 238.83576263287117
# agent 30 在 99 次迭代中的资源申请量为: 28.96604187591452
# agent 31 在 99 次迭代中的资源申请量为: -58.929547167543106
# agent 32 在 99 次迭代中的资源申请量为: -58.601591959115495
# agent 33 在 99 次迭代中的资源申请量为: -343.9575695990085
# agent 34 在 99 次迭代中的资源申请量为: 15.9150675944425
# agent 35 在 99 次迭代中的资源申请量为: 21.12461712614949
# agent 36 在 99 次迭代中的资源申请量为: 263.08089258833223
# agent 37 在 99 次迭代中的资源申请量为: 37.0120312976821
# agent 38 在 99 次迭代中的资源申请量为: -54.68843906905212
# agent 39 在 99 次迭代中的资源申请量为: 1291.5319355848967
# agent 40 在 99 次迭代中的资源申请量为: 270.7470939108422
# agent 41 在 99 次迭代中的资源申请量为: -333.08131396997754
# agent 42 在 99 次迭代中的资源申请量为: -208.5783501057459
# agent 43 在 99 次迭代中的资源申请量为: 273.4125257547406
# agent 44 在 99 次迭代中的资源申请量为: 280.92977998758556
# agent 45 在 99 次迭代中的资源申请量为: 312.1664385209923
# agent 46 在 99 次迭代中的资源申请量为: -310.80961214465816
# agent 47 在 99 次迭代中的资源申请量为: 87.25355359776948
# agent 48 在 99 次迭代中的资源申请量为: 92.24311188300055
# agent 49 在 99 次迭代中的资源申请量为: -309.0306889472823
# agent 50 在 99 次迭代中的资源申请量为: -134.0483089793855
# agent 51 在 99 次迭代中的资源申请量为: 100.11241774969898
# agent 52 在 99 次迭代中的资源申请量为: 100.11241774969898
# agent 53 在 99 次迭代中的资源申请量为: -7.633173052360858
# agent 54 在 99 次迭代中的资源申请量为: -242.77312117937754
# 资源申请量总和为: 6238.672750861124
# ****************************************************************************
# 成本总和为: 67841.23871600111
# ****************************************************************************
# agent 1 在 99 次迭代中的对偶变量为: -17.61149288707812
# agent 2 在 99 次迭代中的对偶变量为: -17.61149288707812
# agent 3 在 99 次迭代中的对偶变量为: -17.598649932020827
# agent 4 在 99 次迭代中的对偶变量为: -17.545867027411564
# agent 5 在 99 次迭代中的对偶变量为: -17.613241654581433
# agent 6 在 99 次迭代中的对偶变量为: -17.613241654581433
# agent 7 在 99 次迭代中的对偶变量为: -17.63614935518978
# agent 8 在 99 次迭代中的对偶变量为: -17.726451925001527
# agent 9 在 99 次迭代中的对偶变量为: -17.863300517136974
# agent 10 在 99 次迭代中的对偶变量为: -17.719260727882542
# agent 11 在 99 次迭代中的对偶变量为: -17.622561021469018
# agent 12 在 99 次迭代中的对偶变量为: -17.698184549905065
# agent 13 在 99 次迭代中的对偶变量为: -17.636860606362895
# agent 14 在 99 次迭代中的对偶变量为: -17.720672321813133
# agent 15 在 99 次迭代中的对偶变量为: -17.626405717378276
# agent 16 在 99 次迭代中的对偶变量为: -17.61272879327389
# agent 17 在 99 次迭代中的对偶变量为: -17.59026753526988
# agent 18 在 99 次迭代中的对偶变量为: -17.503510178882213
# agent 19 在 99 次迭代中的对偶变量为: -17.697796788000396
# agent 20 在 99 次迭代中的对偶变量为: -17.469768842853387
# agent 21 在 99 次迭代中的对偶变量为: -17.219134422678806
# agent 22 在 99 次迭代中的对偶变量为: -17.191809119669752
# agent 23 在 99 次迭代中的对偶变量为: -17.219134422678806
# agent 24 在 99 次迭代中的对偶变量为: -17.24874361550606
# agent 25 在 99 次迭代中的对偶变量为: -17.307552191720003
# agent 26 在 99 次迭代中的对偶变量为: -17.289907844627145
# agent 27 在 99 次迭代中的对偶变量为: -17.666553551897543
# agent 28 在 99 次迭代中的对偶变量为: -17.36876340394653
# agent 29 在 99 次迭代中的对偶变量为: -18.082177837264947
# agent 30 在 99 次迭代中的对偶变量为: -18.131215082135245
# agent 31 在 99 次迭代中的对偶变量为: -18.03338191133489
# agent 32 在 99 次迭代中的对偶变量为: -18.079074598704274
# agent 33 在 99 次迭代中的对偶变量为: -18.22742573041773
# agent 34 在 99 次迭代中的对偶变量为: -18.22742573041773
# agent 35 在 99 次迭代中的对偶变量为: -18.360790198429427
# agent 36 在 99 次迭代中的对偶变量为: -18.609509413796225
# agent 37 在 99 次迭代中的对偶变量为: -18.767508001220662
# agent 38 在 99 次迭代中的对偶变量为: -18.624278538265244
# agent 39 在 99 次迭代中的对偶变量为: -18.50919161350938
# agent 40 在 99 次迭代中的对偶变量为: -18.776249292560816
# agent 41 在 99 次迭代中的对偶变量为: -18.843065304043392
# agent 42 在 99 次迭代中的对偶变量为: -18.86501041213288
# agent 43 在 99 次迭代中的对偶变量为: -18.834222435165607
# agent 44 在 99 次迭代中的对偶变量为: -18.997722714729985
# agent 45 在 99 次迭代中的对偶变量为: -19.677120037831582
# agent 46 在 99 次迭代中的对偶变量为: -20.103732714163772
# agent 47 在 99 次迭代中的对偶变量为: -20.0536909721029
# agent 48 在 99 次迭代中的对偶变量为: -20.181423664204814
# agent 49 在 99 次迭代中的对偶变量为: -20.204426882828038
# agent 50 在 99 次迭代中的对偶变量为: -20.32192365607097
# agent 51 在 99 次迭代中的对偶变量为: -20.382877894392294
# agent 52 在 99 次迭代中的对偶变量为: -20.382877894392294
# agent 53 在 99 次迭代中的对偶变量为: -17.624590769859562
# agent 54 在 99 次迭代中的对偶变量为: -18.196571027185527
# *************************
# 迭代步长为: 5.3865362416062276e-05
# ****************************************************************************
# 119 次迭代中的结果：
# agent 1 在 119 次迭代中的资源申请量为: -61.11154411324222
# agent 2 在 119 次迭代中的资源申请量为: -61.11154411324222
# agent 3 在 119 次迭代中的资源申请量为: -61.1716374149079
# agent 4 在 119 次迭代中的资源申请量为: 220.11380565009972
# agent 5 在 119 次迭代中的资源申请量为: 222.81208040798452
# agent 6 在 119 次迭代中的资源申请量为: -61.080754856425486
# agent 7 在 119 次迭代中的资源申请量为: -2.6129768891725025
# agent 8 在 119 次迭代中的资源申请量为: -60.42610767035171
# agent 9 在 119 次迭代中的资源申请量为: -59.60569776953139
# agent 10 在 119 次迭代中的资源申请量为: 226.69893474345872
# agent 11 在 119 次迭代中的资源申请量为: 1163.7425438662292
# agent 12 在 119 次迭代中的资源申请量为: -60.60668391597388
# agent 13 在 119 次迭代中的资源申请量为: -60.941716761846905
# agent 14 在 119 次迭代中的资源申请量为: -0.037224165130023135
# agent 15 在 119 次迭代中的资源申请量为: -60.97020018385989
# agent 16 在 119 次迭代中的资源申请量为: -3.3298131531772635
# agent 17 在 119 次迭代中的资源申请量为: -61.192901761324975
# agent 18 在 119 次迭代中的资源申请量为: -61.65200778609532
# agent 19 在 119 次迭代中的资源申请量为: 0.006126666675654313
# agent 20 在 119 次迭代中的资源申请量为: 1104.739706528257
# agent 21 在 119 次迭代中的资源申请量为: 1063.2004042741864
# agent 22 在 119 次迭代中的资源申请量为: -15.875977609689784
# agent 23 在 119 次迭代中的资源申请量为: -15.023892917006147
# agent 24 在 119 次迭代中的资源申请量为: 473.77419461385665
# agent 25 在 119 次迭代中的资源申请量为: 479.134417211248
# agent 26 在 119 次迭代中的资源申请量为: -12.794096502385804
# agent 27 在 119 次迭代中的资源申请量为: 446.37641294147096
# agent 28 在 119 次迭代中的资源申请量为: 435.14598553993244
# agent 29 在 119 次迭代中的资源申请量为: 241.76826289872196
# agent 30 在 119 次迭代中的资源申请量为: 29.4275868279521
# agent 31 在 119 次迭代中的资源申请量为: -58.57913712611417
# agent 32 在 119 次迭代中的资源申请量为: -58.300398532647385
# agent 33 在 119 次迭代中的资源申请量为: -343.3235844542427
# agent 34 在 119 次迭代中的资源申请量为: 17.316868185626998
# agent 35 在 119 次迭代中的资源申请量为: 22.063176636887977
# agent 36 在 119 次迭代中的资源申请量为: 263.130397855398
# agent 37 在 119 次迭代中的资源申请量为: 36.53128249445025
# agent 38 在 119 次迭代中的资源申请量为: -54.460993741437925
# agent 39 在 119 次迭代中的资源申请量为: 1301.8018019077304
# agent 40 在 119 次迭代中的资源申请量为: 270.61274065383475
# agent 41 在 119 次迭代中的资源申请量为: -333.3969758711697
# agent 42 在 119 次迭代中的资源申请量为: -209.79414960115392
# agent 43 在 119 次迭代中的资源申请量为: 272.5011003805437
# agent 44 在 119 次迭代中的资源申请量为: 278.77958910355596
# agent 45 在 119 次迭代中的资源申请量为: 305.36907125653005
# agent 46 在 119 次迭代中的资源申请量为: -314.53993988480613
# agent 47 在 119 次迭代中的资源申请量为: 79.29436353452625
# agent 48 在 119 次迭代中的资源申请量为: 83.56170758495429
# agent 49 在 119 次迭代中的资源申请量为: -313.00036085943657
# agent 50 在 119 次迭代中的资源申请量为: -146.46698208163676
# agent 51 在 119 次迭代中的资源申请量为: 90.2935152129808
# agent 52 在 119 次迭代中的资源申请量为: 90.2935152129808
# agent 53 在 119 次迭代中的资源申请量为: -2.973010851274327
# agent 54 在 119 次迭代中的资源申请量为: -240.0889771615812
# 资源申请量总和为: 6424.020304441212
# ****************************************************************************
# 成本总和为: 70930.43604848592
# ****************************************************************************
# agent 1 在 119 次迭代中的对偶变量为: -17.729373004878415
# agent 2 在 119 次迭代中的对偶变量为: -17.729373004878415
# agent 3 在 119 次迭代中的对偶变量为: -17.721000445530542
# agent 4 在 119 次迭代中的对偶变量为: -17.674975272889668
# agent 5 在 119 次迭代中的对偶变量为: -17.733662748873662
# agent 6 在 119 次迭代中的对偶变量为: -17.733662748873662
# agent 7 在 119 次迭代中的对偶变量为: -17.753107791637184
# agent 8 在 119 次迭代中的对偶变量为: -17.824872122720578
# agent 9 在 119 次迭代中的对偶变量为: -17.93917655256227
# agent 10 在 119 次迭代中的对偶变量为: -17.818201830670226
# agent 11 在 119 次迭代中的对偶变量为: -17.742455263197375
# agent 12 在 119 次迭代中的对偶变量为: -17.799713156723023
# agent 13 在 119 次迭代中的对偶变量为: -17.753034370438918
# agent 14 在 119 次迭代中的对偶变量为: -17.81904706137267
# agent 15 在 119 次迭代中的对偶变量为: -17.749065889183537
# agent 16 在 119 次迭代中的对偶变量为: -17.734756783278662
# agent 17 在 119 次迭代中的对偶变量为: -17.718037769201636
# agent 18 在 119 次迭代中的对偶变量为: -17.654072363194484
# agent 19 在 119 次迭代中的对偶变量为: -17.820156842666897
# agent 20 在 119 次迭代中的对偶变量为: -17.63486007074869
# agent 21 在 119 次迭代中的对偶变量为: -17.435388341324643
# agent 22 在 119 次迭代中的对偶变量为: -17.413574973191942
# agent 23 在 119 次迭代中的对偶变量为: -17.435388341324643
# agent 24 在 119 次迭代中的对偶变量为: -17.459212912601938
# agent 25 在 119 次迭代中的对偶变量为: -17.50638287145898
# agent 26 在 119 次迭代中的对偶变量为: -17.492471129538924
# agent 27 在 119 次迭代中的对偶变量为: -17.793352426100356
# agent 28 在 119 次迭代中的对偶变量为: -17.55549197373577
# agent 29 在 119 次迭代中的对偶变量为: -18.1459597180472
# agent 30 在 119 次迭代中的对偶变量为: -18.17360613980009
# agent 31 在 119 次迭代中的对偶变量为: -18.082203140767017
# agent 32 在 119 次迭代中的对偶变量为: -18.12103867404037
# agent 33 在 119 次迭代中的对偶变量为: -18.26331182555205
# agent 34 在 119 次迭代中的对偶变量为: -18.26331182555205
# agent 35 在 119 次迭代中的对偶变量为: -18.384817321904332
# agent 36 在 119 次迭代中的对偶变量为: -18.610586153354905
# agent 37 在 119 次迭代中的对偶变量为: -18.755200831857927
# agent 38 在 119 次迭代中的对偶变量为: -18.65596758598042
# agent 39 在 119 次迭代中的对偶变量为: -18.570810811446382
# agent 40 在 119 次迭代中的对偶变量为: -18.773327109220904
# agent 41 在 119 次迭代中的对偶变量为: -18.825197577788316
# agent 42 在 119 次迭代中的对偶变量为: -18.841243963596643
# agent 43 在 119 次迭代中的对偶变量为: -18.814398933276824
# agent 44 在 119 次迭代中的对偶变量为: -18.95095606300234
# agent 45 在 119 次迭代中的对偶变量为: -19.529277299829527
# agent 46 在 119 次迭代中的对偶变量为: -19.892581242760436
# agent 47 在 119 次迭代中的对偶变量为: -19.849935706483873
# agent 48 在 119 次迭代中的对偶变量为: -19.95917971417483
# agent 49 在 119 次迭代中的对偶变量为: -19.979727573912456
# agent 50 在 119 次迭代中的对偶变量为: -20.079163434268164
# agent 51 在 119 次迭代中的对偶变量为: -20.13151398945231
# agent 52 在 119 次迭代中的对偶变量为: -20.13151398945231
# agent 53 在 119 次迭代中的对偶变量为: -17.743890922207378
# agent 54 在 119 次迭代中的对偶变量为: -18.24904067444541
# *************************
# 迭代步长为: 4.087351016895592e-05
# ****************************************************************************
# 139 次迭代中的结果：
# agent 1 在 139 次迭代中的资源申请量为: -60.35073469310531
# agent 2 在 139 次迭代中的资源申请量为: -60.35073469310531
# agent 3 在 139 次迭代中的资源申请量为: -60.392469824363765
# agent 4 在 139 次迭代中的资源申请量为: 225.36954175423907
# agent 5 在 139 次迭代中的资源申请量为: 227.7289699980203
# agent 6 在 139 次迭代中的资源申请量为: -60.313185640462365
# agent 7 在 139 次迭代中的资源申请量为: 1.4574758539610821
# agent 8 在 139 次迭代中的资源申请量为: -59.770064870370284
# agent 9 在 139 次迭代中的资源申请量为: -59.07324533013122
# agent 10 在 139 次迭代中的资源申请量为: 230.9308915069842
# agent 11 在 139 次迭代中的资源申请量为: 1181.4415767407302
# agent 12 在 139 次迭代中的资源申请量为: -59.929593918232186
# agent 13 在 139 次迭代中的资源申请量为: -60.19634513651071
# agent 14 在 139 次迭代中的资源申请量为: 3.54592389756464
# agent 15 在 139 次迭代中的资源申请量为: -60.20147535694313
# agent 16 在 139 次迭代中的资源申请量为: 0.8745147966227051
# agent 17 在 139 次迭代中的资源申请量为: -60.39389312824121
# agent 18 在 139 次迭代中的资源申请量为: -60.74894444004867
# agent 19 在 139 次迭代中的资源申请量为: 4.018776143416836
# agent 20 在 139 次迭代中的资源申请量为: 1132.59836531863
# agent 21 在 139 次迭代中的资源申请量为: 1098.527548504869
# agent 22 在 139 次迭代中的资源申请量为: -9.097441523938098
# agent 23 在 139 次迭代中的资源申请量为: -8.397293440610131
# agent 24 在 139 次迭代中的资源申请量为: 492.5808890276485
# agent 25 在 139 次迭代中的资源申请量为: 496.9995542625134
# agent 26 在 139 次迭代中的资源申请量为: -6.552221075242781
# agent 27 在 139 次迭代中的资源申请量为: 451.3956672003084
# agent 28 在 139 次迭代中的资源申请量为: 442.1622840798341
# agent 29 在 139 次迭代中的资源申请量为: 244.33566559111412
# agent 30 在 139 次迭代中的资源申请量为: 29.91253477534822
# agent 31 在 139 次迭代中的资源申请量为: -58.19736652169964
# agent 32 在 139 次迭代中的资源申请量为: -57.95796771630655
# agent 33 在 139 次迭代中的资源申请量为: -342.6881485830233
# agent 34 在 139 次迭代中的资源申请量为: 18.721876469006
# agent 35 在 139 次迭代中的资源申请量为: 22.958695971693476
# agent 36 在 139 次迭代中的资源申请量为: 263.04039368806076
# agent 37 在 139 次迭代中的资源申请量为: 35.873912395977534
# agent 38 在 139 次迭代中的资源申请量为: -54.3869198727494
# agent 39 在 139 次迭代中的资源申请量为: 1306.7374147481141
# agent 40 在 139 次迭代中的资源申请量为: 270.0200779532568
# agent 41 在 139 次迭代中的资源申请量为: -333.8012358279284
# agent 42 在 139 次迭代中的资源申请量为: -211.1599959786916
# agent 43 在 139 次迭代中的资源申请量为: 271.411100586104
# agent 44 在 139 次迭代中的资源申请量为: 276.6983933977975
# agent 45 在 139 次迭代中的资源申请量为: 299.44286923207005
# agent 46 在 139 次迭代中的资源申请量为: -317.7426852624814
# agent 47 在 139 次迭代中的资源申请量为: 72.45247222371798
# agent 48 在 139 次迭代中的资源申请量为: 76.11361429617047
# agent 49 在 139 次迭代中的资源申请量为: -316.4124691219529
# agent 50 在 139 次迭代中的资源申请量为: -157.09776128149923
# agent 51 在 139 次迭代中的资源申请量为: 81.88995527436529
# agent 52 在 139 次迭代中的资源申请量为: 81.88995527436529
# agent 53 在 139 次迭代中的资源申请量为: 1.1610158492106337
# agent 54 在 139 次迭代中的资源申请量为: -237.83149634609825
# 资源申请量总和为: 6569.248237227978
# ****************************************************************************
# 成本总和为: 73376.8882286739
# ****************************************************************************
# agent 1 在 139 次迭代中的对偶变量为: -17.83537353814841
# agent 2 在 139 次迭代中的对偶变量为: -17.83537353814841
# agent 3 在 139 次迭代中的对偶变量为: -17.829558749250694
# agent 4 在 139 次迭代中的对偶变量为: -17.7892875331547
# agent 5 在 139 次迭代中的对偶变量为: -17.84060509745694
# agent 6 在 139 次迭代中的对偶变量为: -17.84060509745694
# agent 7 在 139 次迭代中的对偶变量为: -17.857311381861404
# agent 8 在 139 次迭代中的对偶变量为: -17.91627594187079
# agent 9 在 139 次迭代中的对偶变量为: -18.013361021134138
# agent 10 在 139 次迭代中的对偶变量为: -17.910246890276905
# agent 11 在 139 次迭代中的对偶变量为: -17.84864946044438
# agent 12 在 139 次迭代中的对偶变量为: -17.894049397748383
# agent 13 在 139 次迭代中的对偶变量为: -17.85688401751051
# agent 14 在 139 次迭代中的对偶变量为: -17.910775651777655
# agent 15 在 139 次迭代中的对偶变量为: -17.856169244418542
# agent 16 在 139 次迭代中的对偶变量为: -17.84238757879354
# agent 17 在 139 次迭代中的对偶变量为: -17.829360446014665
# agent 18 在 139 次迭代中的对偶变量为: -17.77989256694578
# agent 19 在 139 次迭代中的对偶变量为: -17.92288066927147
# agent 20 在 139 次迭代中的对偶变量为: -17.76863735026006
# agent 21 在 139 次迭代中的对偶变量为: -17.60502928792038
# agent 22 在 139 次迭代中的对偶变量为: -17.587105496987185
# agent 23 在 139 次迭代中的对偶变量为: -17.60502928792038
# agent 24 在 139 次迭代中的对偶变量为: -17.624711823443306
# agent 25 在 139 次迭代中的对偶变量为: -17.663596077510118
# agent 26 在 139 次迭代中的对偶变量为: -17.652263140473785
# agent 27 在 139 次迭代中的对偶变量为: -17.899660231302533
# agent 28 在 139 次迭代中的对偶变量为: -17.704097176810887
# agent 29 在 139 次迭代中的对偶变量为: -18.20180072660673
# agent 30 在 139 次迭代中的对偶变量为: -18.218146668976633
# agent 31 在 139 次迭代中的对偶变量为: -18.135393711997676
# agent 32 在 139 次迭代中的对偶变量为: -18.168748189957874
# agent 33 在 139 次迭代中的对偶变量为: -18.299280037606554
# agent 34 在 139 次迭代中的对偶变量为: -18.299280037606554
# agent 35 在 139 次迭代中的对偶变量为: -18.407742616875353
# agent 36 在 139 次迭代中的对偶变量为: -18.60862856271532
# agent 37 在 139 次迭代中的对偶变量为: -18.738372157337025
# agent 38 在 139 次迭代中的对偶变量为: -18.666288001809317
# agent 39 在 139 次迭代中的对偶变量为: -18.600424488488684
# agent 40 在 139 次迭代中的对偶变量为: -18.760436695483335
# agent 41 在 139 次迭代中的对偶变量为: -18.802314847195944
# agent 42 在 139 次迭代中的对偶变量为: -18.814544398608536
# agent 43 在 139 次迭代中的对偶变量为: -18.79069143774776
# agent 44 在 139 次迭代中的对偶变量为: -18.905690056402094
# agent 45 在 139 次迭代中的对偶变量为: -19.400382405797522
# agent 46 在 139 次迭代中的对偶变量为: -19.711293043402506
# agent 47 在 139 次迭代中的对偶变量为: -19.67478328892718
# agent 48 在 139 次迭代中的对偶变量为: -19.768508525981964
# agent 49 在 139 次迭代中的对偶变量为: -19.78658859782098
# agent 50 在 139 次迭代中的对偶变量为: -19.871352962469253
# agent 51 在 139 次迭代中的对偶变量为: -19.916382855023752
# agent 52 在 139 次迭代中的对偶变量为: -19.916382855023752
# agent 53 在 139 次迭代中的对偶变量为: -17.849722005739793
# agent 54 在 139 次迭代中的对偶变量为: -18.29316990942647
# *************************
# 迭代步长为: 3.237726633057685e-05
# ****************************************************************************
# 159 次迭代中的结果：
# agent 1 在 159 次迭代中的资源申请量为: -59.67724594732652
# agent 2 在 159 次迭代中的资源申请量为: -59.67724594732652
# agent 3 在 159 次迭代中的资源申请量为: -59.708129531041585
# agent 4 在 159 次迭代中的资源申请量为: 229.9867585934584
# agent 5 在 159 次迭代中的资源申请量为: 232.04789033383906
# agent 6 在 159 次迭代中的资源申请量为: -59.63896462425535
# agent 7 在 159 次迭代中的资源申请量为: 5.037904951437355
# agent 8 在 159 次迭代中的资源申请量为: -59.18013578221161
# agent 9 在 159 次迭代中的资源申请量为: -58.58263225246736
# agent 10 在 159 次迭代中的资源申请量为: 234.74036403369013
# agent 11 在 159 次迭代中的资源申请量为: 1196.9578849396585
# agent 12 在 159 次迭代中的资源申请量为: -59.320226611637075
# agent 13 在 159 次迭代中的资源申请量为: -59.539450724299016
# agent 14 在 159 次迭代中的资源申请量为: 6.775635462478863
# agent 15 在 159 次迭代中的资源申请量为: -59.53362378992876
# agent 16 在 159 次迭代中的资源申请量为: 4.551761195803889
# agent 17 在 159 次迭代中的资源申请量为: -59.70029425486102
# agent 18 在 159 次迭代中的资源申请量为: -59.985771602645066
# agent 19 在 159 次迭代中的资源申请量为: 7.41413936030777
# agent 20 在 159 次迭代中的资源申请量为: 1155.6419991294197
# agent 21 在 159 次迭代中的资源申请量为: 1127.086548064564
# agent 22 在 159 次迭代中的资源申请量为: -3.6276012307606686
# agent 23 在 159 次迭代中的资源申请量为: -3.0402498513266982
# agent 24 在 159 次迭代中的资源申请量为: 507.8128345612312
# agent 25 在 159 次迭代中的资源申请量为: 511.52900733098454
# agent 26 在 159 次迭代中的资源申请量为: -1.4838806518847891
# agent 27 在 159 次迭代中的资源申请量为: 455.64393849075736
# agent 28 在 159 次迭代中的资源申请量为: 447.89577835538927
# agent 29 在 159 次迭代中的资源申请量为: 246.55375288169117
# agent 30 在 159 次迭代中的资源申请量为: 30.371509188856447
# agent 31 在 159 次迭代中的资源申请量为: -57.82942300041392
# agent 32 在 159 次迭代中的资源申请量为: -57.622727160878206
# agent 33 在 159 次迭代中的资源申请量为: -342.1018929757002
# agent 34 在 159 次迭代中的资源申请量为: 20.018142578260427
# agent 35 在 159 次迭代中的资源申请量为: 23.75851305680798
# agent 36 在 159 次迭代中的资源申请量为: 262.87851428415337
# agent 37 在 159 次迭代中的资源申请量为: 35.16231676082504
# agent 38 在 159 次迭代中的资源申请量为: -54.392600965907604
# agent 39 在 159 次迭代中的资源申请量为: 1308.7929198061786
# agent 40 在 159 次迭代中的资源申请量为: 269.2225910593716
# agent 41 在 159 次迭代中的资源申请量为: -334.23413327441983
# agent 42 在 159 次迭代中的资源申请量为: -212.5454758599977
# agent 43 在 159 次迭代中的资源申请量为: 270.2853987592392
# agent 44 在 159 次迭代中的资源申请量为: 274.7724786184044
# agent 45 在 159 次迭代中的资源申请量为: 294.310819463521
# agent 46 在 159 次迭代中的资源申请量为: -320.487095495107
# agent 47 在 159 次迭代中的资源申请量为: 66.58451511148091
# agent 48 在 159 次迭代中的资源申请量为: 69.73568817494017
# agent 49 在 159 次迭代中的资源申请量为: -319.3372773338123
# agent 50 在 159 次迭代中的资源申请量为: -166.18577023584885
# agent 51 在 159 次迭代中的资源申请量为: 74.70788911186715
# agent 52 在 159 次迭代中的资源申请量为: 74.70788911186715
# agent 53 在 159 次迭代中的资源申请量为: 4.78855737019862
# agent 54 在 159 次迭代中的资源申请量为: -235.92983749734307
# 资源申请量总和为: 6686.412253539281
# ****************************************************************************
# 成本总和为: 75371.3626162226
# ****************************************************************************
# agent 1 在 159 次迭代中的对偶变量为: -17.929208031142785
# agent 2 在 159 次迭代中的对偶变量为: -17.929208031142785
# agent 3 在 159 次迭代中的对偶变量为: -17.9249051449581
# agent 4 在 159 次迭代中的对偶变量为: -17.88971199940772
# agent 5 在 159 次迭代中的对偶变量为: -17.934541614761
# agent 6 在 159 次迭代中的对偶变量为: -17.934541614761
# agent 7 在 159 次迭代中的对偶变量为: -17.948970366756797
# agent 8 在 159 次迭代中的对偶变量为: -17.998468402007585
# agent 9 在 159 次迭代中的对偶变量为: -18.081716178792732
# agent 10 在 159 次迭代中的对偶变量为: -17.99310291773276
# agent 11 在 159 次迭代中的对偶变量为: -17.94174730963795
# agent 12 在 159 次迭代中的对偶变量为: -17.978950107107053
# agent 13 在 159 次迭代中的对偶变量为: -17.948406488386315
# agent 14 在 159 次迭代中的对偶变量为: -17.99345626783946
# agent 15 在 159 次迭代中的对偶变量为: -17.949218331844385
# agent 16 在 159 次迭代中的对偶变量为: -17.93652508661258
# agent 17 在 159 次迭代中的对偶变量为: -17.925996802647234
# agent 18 在 159 次迭代中的对偶变量为: -17.886222385689873
# agent 19 在 159 次迭代中的对偶变量为: -18.00980196762388
# agent 20 在 159 次迭代中的对偶变量为: -17.879292879819474
# agent 21 在 159 次迭代中的对偶变量为: -17.742169603806037
# agent 22 在 159 次迭代中的对偶变量为: -17.727133408492527
# agent 23 在 159 次迭代中的对偶变量为: -17.742169603806037
# agent 24 在 159 次迭代中的对偶变量为: -17.758752944138834
# agent 25 在 159 次迭代中的对偶变量为: -17.791455264512663
# agent 26 在 159 次迭代中的对偶变量为: -17.78201265531175
# agent 27 在 159 次迭代中的对偶变量为: -17.98963861723424
# agent 28 在 159 次迭代中的对偶变量为: -17.825532585567146
# agent 29 在 159 次迭代中的对偶变量为: -18.25004412517678
# agent 30 在 159 次迭代中的对偶变量为: -18.26030163295971
# agent 31 在 159 次迭代中的对偶变量为: -18.18665781104433
# agent 32 在 159 次迭代中的对偶变量为: -18.215455915583483
# agent 33 在 159 次迭代中的对偶变量为: -18.332464450003467
# agent 34 在 159 次迭代中的对偶变量为: -18.332464450003467
# agent 35 在 159 次迭代中的对偶变量为: -18.428217934254285
# agent 36 在 159 次迭代中的对偶变量为: -18.605107685680334
# agent 37 在 159 次迭代中的对偶变量为: -18.72015530907712
# agent 38 在 159 次迭代中的对偶变量为: -18.665496477823957
# agent 39 在 159 次迭代中的对偶变量为: -18.61275751883707
# agent 40 在 159 次迭代中的对偶变量为: -18.74309135554133
# agent 41 在 159 次迭代中的对偶变量为: -18.777811120134743
# agent 42 在 159 次迭代中的对偶变量为: -18.787461037888765
# agent 43 在 159 次迭代中的对偶变量为: -18.76620742301345
# agent 44 在 159 次迭代中的对偶变量为: -18.863801409950295
# agent 45 在 159 次迭代中的对偶变量为: -19.28876032333158
# agent 46 在 159 次迭代中的对偶变量为: -19.555948446594968
# agent 47 在 159 次迭代中的对偶变量为: -19.524563586853912
# agent 48 在 159 次迭代中的对偶变量为: -19.60523361727847
# agent 49 在 159 次迭代中的对偶变量为: -19.62103275379689
# agent 50 在 159 次迭代中的对偶变量为: -19.693700563429626
# agent 51 在 159 次迭代中的对偶变量为: -19.7325219612638
# agent 52 在 159 次迭代中的对偶变量为: -19.7325219612638
# agent 53 在 159 次迭代中的对偶变量为: -17.942587068677085
# agent 54 在 159 次迭代中的对偶变量为: -18.330343536601937
# *************************
# 迭代步长为: 2.6464682716040347e-05
# ****************************************************************************
# 179 次迭代中的结果：
# agent 1 在 179 次迭代中的资源申请量为: -59.08763774696149
# agent 2 在 179 次迭代中的资源申请量为: -59.08763774696149
# agent 3 在 179 次迭代中的资源申请量为: -59.11194340247541
# agent 4 在 179 次迭代中的资源申请量为: 234.01162524654652
# agent 5 在 179 次迭代中的资源申请量为: 235.81021125501897
# agent 6 在 179 次迭代中的资源申请量为: -59.0516336161473
# agent 7 在 179 次迭代中的资源申请量为: 8.159020472574552
# agent 8 在 179 次迭代中的资源申请量为: -58.65929895138262
# agent 9 在 179 次迭代中的资源申请量为: -58.14374986062037
# agent 10 在 179 次迭代中的资源申请量为: 238.10578068675514
# agent 11 在 179 次迭代中的资源申请量为: 1210.4558683670102
# agent 12 在 179 次迭代中的资源申请量为: -58.781850102562395
# agent 13 在 179 次迭代中的资源申请量为: -58.96617385758175
# agent 14 在 179 次迭代中的资源申请量为: 9.631280104685501
# agent 15 在 179 次迭代中的资源申请量为: -58.95600356814724
# agent 16 在 179 次迭代中的资源申请量为: 7.746307784466527
# agent 17 在 179 次迭代中的资源申请量为: -59.10058164842771
# agent 18 在 179 次迭代中的资源申请量为: -59.33727692785727
# agent 19 在 179 次迭代中的资源申请量为: 10.29951856596753
# agent 20 在 179 次迭代中的资源申请量为: 1174.9382593425667
# agent 21 在 179 次迭代中的资源申请量为: 1150.6260010937933
# agent 22 在 179 次迭代中的资源申请量为: 0.8751007561558222
# agent 23 在 179 次迭代中的资源申请量为: 1.375236611421693
# agent 24 在 179 次迭代中的资源申请量为: 520.3847911743565
# agent 25 在 179 次迭代中的资源申请量为: 523.5565807045866
# agent 26 在 179 次迭代中的资源申请量为: 2.7070918876703765
# agent 27 在 179 次迭代中的资源申请量为: 459.2564179047894
# agent 28 在 179 次迭代中的资源申请量为: 452.6576879171234
# agent 29 在 179 次迭代中的资源申请量为: 248.45971121871526
# agent 30 在 179 次迭代中的资源申请量为: 30.78702808247257
# agent 31 在 179 次迭代中的资源申请量为: -57.49272879295374
# agent 32 在 179 次迭代中的资源申请量为: -57.31366510389433
# agent 33 在 179 次迭代中的资源申请量为: -341.5794155905391
# agent 34 在 179 次迭代中的资源申请量为: 21.173389059106484
# agent 35 在 179 次迭代中的资源申请量为: 24.45514852783326
# agent 36 在 179 次迭代中的资源申请量为: 262.6869537724988
# agent 37 在 179 次迭代中的资源申请量为: 34.46283935404568
# agent 38 在 179 次迭代中的资源申请量为: -54.43809170370311
# ...
# agent 61 在 57999 次迭代中的资源申请量为: 45.35594989347403
# agent 62 在 57999 次迭代中的资源申请量为: 37.777916501990724
# agent 63 在 57999 次迭代中的资源申请量为: 44.36024833408177
# agent 64 在 57999 次迭代中的资源申请量为: 50.59248382563158
# agent 65 在 57999 次迭代中的资源申请量为: 48.719342447654434
# agent 66 在 57999 次迭代中的资源申请量为: 53.47780999250294
# agent 67 在 57999 次迭代中的资源申请量为: 44.62937911116489
# agent 68 在 57999 次迭代中的资源申请量为: 38.64566746179317
# agent 69 在 57999 次迭代中的资源申请量为: 49.892139157742264
# agent 70 在 57999 次迭代中的资源申请量为: 43.38409217370307
# agent 71 在 57999 次迭代中的资源申请量为: 51.072439614453316
# agent 72 在 57999 次迭代中的资源申请量为: 51.63101181607402
# agent 73 在 57999 次迭代中的资源申请量为: 68.52493850742536
# agent 74 在 57999 次迭代中的资源申请量为: 63.033563690013715
# agent 75 在 57999 次迭代中的资源申请量为: 68.784860310892
# agent 76 在 57999 次迭代中的资源申请量为: 65.84231131075826
# agent 77 在 57999 次迭代中的资源申请量为: 37.33178559067635
# agent 78 在 57999 次迭代中的资源申请量为: 56.51515954674519
# agent 79 在 57999 次迭代中的资源申请量为: 35.71319766839764
# agent 80 在 57999 次迭代中的资源申请量为: 41.69438982489503
# agent 81 在 57999 次迭代中的资源申请量为: 64.43288578237497
# agent 82 在 57999 次迭代中的资源申请量为: 45.64920279686928
# agent 83 在 57999 次迭代中的资源申请量为: 54.00548947849253
# agent 84 在 57999 次迭代中的资源申请量为: 52.98642785861979
# agent 85 在 57999 次迭代中的资源申请量为: 58.685757530611916
# agent 86 在 57999 次迭代中的资源申请量为: 54.16278250297388
# agent 87 在 57999 次迭代中的资源申请量为: 50.183947875573004
# agent 88 在 57999 次迭代中的资源申请量为: 53.40486804038364
# agent 89 在 57999 次迭代中的资源申请量为: 44.037016821613456
# agent 90 在 57999 次迭代中的资源申请量为: 38.995841039652966
# agent 91 在 57999 次迭代中的资源申请量为: 43.58677066582213
# agent 92 在 57999 次迭代中的资源申请量为: 45.25809138455365
# agent 93 在 57999 次迭代中的资源申请量为: 35.68321481266967
# agent 94 在 57999 次迭代中的资源申请量为: 37.48060785879904
# 资源申请量平均值avg为: 49.99999999999654
# ****************************************************************************
# 平均成本为: 3240.481984531225
# ****************************************************************************
# agent 1 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 2 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 3 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 4 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 5 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 6 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 7 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 8 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 9 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 10 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 11 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 12 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 13 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 14 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 15 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 16 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 17 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 18 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 19 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 20 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 21 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 22 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 23 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 24 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 25 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 26 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 27 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 28 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 29 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 30 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 31 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 32 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 33 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 34 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 35 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 36 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 37 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 38 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 39 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 40 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 41 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 42 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 43 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 44 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 45 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 46 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 47 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 48 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 49 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 50 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 51 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 52 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 53 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 54 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 55 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 56 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 57 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 58 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 59 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 60 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 61 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 62 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 63 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 64 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 65 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 66 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 67 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 68 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 69 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 70 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 71 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 72 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 73 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 74 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 75 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 76 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 77 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 78 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 79 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 80 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 81 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 82 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 83 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 84 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 85 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 86 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 87 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 88 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 89 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 90 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 91 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 92 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 93 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 94 在 57999 次迭代中的对偶变量为: -135.14386653834575
# *************************
# 迭代步长为: 0.11151053484837568
# ****************************************************************************
# 59999 次迭代中的结果：
# agent 1 在 59999 次迭代中的资源申请量为: 56.19880558172988
# agent 2 在 59999 次迭代中的资源申请量为: 56.03871203978166
# agent 3 在 59999 次迭代中的资源申请量为: 60.64796214442871
# agent 4 在 59999 次迭代中的资源申请量为: 37.93333499802675
# agent 5 在 59999 次迭代中的资源申请量为: 57.56693686702461
# agent 6 在 59999 次迭代中的资源申请量为: 55.34212747123894
# agent 7 在 59999 次迭代中的资源申请量为: 65.6236567946489
# agent 8 在 59999 次迭代中的资源申请量为: 46.330946703602365
# agent 9 在 59999 次迭代中的资源申请量为: 65.64268770463663
# agent 10 在 59999 次迭代中的资源申请量为: 54.23914303693835
# agent 11 在 59999 次迭代中的资源申请量为: 65.4520437985654
# agent 12 在 59999 次迭代中的资源申请量为: 38.406222330358624
# agent 13 在 59999 次迭代中的资源申请量为: 49.70058714461363
# agent 14 在 59999 次迭代中的资源申请量为: 41.3659905551611
# agent 15 在 59999 次迭代中的资源申请量为: 42.48853939614691
# agent 16 在 59999 次迭代中的资源申请量为: 49.24530133808371
# agent 17 在 59999 次迭代中的资源申请量为: 50.11852704992918
# agent 18 在 59999 次迭代中的资源申请量为: 46.537297422347486
# agent 19 在 59999 次迭代中的资源申请量为: 44.77392156663175
# agent 20 在 59999 次迭代中的资源申请量为: 50.80339666473046
# agent 21 在 59999 次迭代中的资源申请量为: 69.93387670557085
# agent 22 在 59999 次迭代中的资源申请量为: 61.24199691647269
# agent 23 在 59999 次迭代中的资源申请量为: 61.627787986086716
# agent 24 在 59999 次迭代中的资源申请量为: 39.861352301782716
# agent 25 在 59999 次迭代中的资源申请量为: 52.95065687328203
# agent 26 在 59999 次迭代中的资源申请量为: 49.39633437684004
# agent 27 在 59999 次迭代中的资源申请量为: 47.51919637207136
# agent 28 在 59999 次迭代中的资源申请量为: 40.7413613830987
# agent 29 在 59999 次迭代中的资源申请量为: 44.38273034135506
# agent 30 在 59999 次迭代中的资源申请量为: 39.891745956789116
# agent 31 在 59999 次迭代中的资源申请量为: 65.76280653244551
# agent 32 在 59999 次迭代中的资源申请量为: 59.51901541924079
# agent 33 在 59999 次迭代中的资源申请量为: 48.23750867799392
# agent 34 在 59999 次迭代中的资源申请量为: 36.76532342510125
# agent 35 在 59999 次迭代中的资源申请量为: 41.086702696803464
# agent 36 在 59999 次迭代中的资源申请量为: 62.20889044924783
# agent 37 在 59999 次迭代中的资源申请量为: 40.47023795026076
# agent 38 在 59999 次迭代中的资源申请量为: 58.24733429492913
# agent 39 在 59999 次迭代中的资源申请量为: 37.39554726071002
# agent 40 在 59999 次迭代中的资源申请量为: 50.45313221045784
# agent 41 在 59999 次迭代中的资源申请量为: 36.73569742369616
# agent 42 在 59999 次迭代中的资源申请量为: 56.24242387150355
# agent 43 在 59999 次迭代中的资源申请量为: 61.52373322591861
# agent 44 在 59999 次迭代中的资源申请量为: 47.51525622305313
# agent 45 在 59999 次迭代中的资源申请量为: 41.36197014706921
# agent 46 在 59999 次迭代中的资源申请量为: 67.10436077257359
# agent 47 在 59999 次迭代中的资源申请量为: 65.57090570810219
# agent 48 在 59999 次迭代中的资源申请量为: 40.83836334458436
# agent 49 在 59999 次迭代中的资源申请量为: 39.16390664937778
# agent 50 在 59999 次迭代中的资源申请量为: 63.292999181236645
# agent 51 在 59999 次迭代中的资源申请量为: 36.39727688961264
# agent 52 在 59999 次迭代中的资源申请量为: 46.86937779818014
# agent 53 在 59999 次迭代中的资源申请量为: 43.572511920796444
# agent 54 在 59999 次迭代中的资源申请量为: 49.58201107681077
# agent 55 在 59999 次迭代中的资源申请量为: 47.173391517077015
# agent 56 在 59999 次迭代中的资源申请量为: 42.97971616155657
# agent 57 在 59999 次迭代中的资源申请量为: 36.90486251978384
# agent 58 在 59999 次迭代中的资源申请量为: 59.2566799113546
# agent 59 在 59999 次迭代中的资源申请量为: 59.891586060534515
# agent 60 在 59999 次迭代中的资源申请量为: 40.34169962872796
# agent 61 在 59999 次迭代中的资源申请量为: 45.35594989347582
# agent 62 在 59999 次迭代中的资源申请量为: 37.77791650199216
# agent 63 在 59999 次迭代中的资源申请量为: 44.360248334083515
# agent 64 在 59999 次迭代中的资源申请量为: 50.59248382563358
# agent 65 在 59999 次迭代中的资源申请量为: 48.71934244765636
# agent 66 在 59999 次迭代中的资源申请量为: 53.47780999250507
# agent 67 在 59999 次迭代中的资源申请量为: 44.62937911116663
# agent 68 在 59999 次迭代中的资源申请量为: 38.64566746179467
# agent 69 在 59999 次迭代中的资源申请量为: 49.89213915774424
# agent 70 在 59999 次迭代中的资源申请量为: 43.384092173704765
# agent 71 在 59999 次迭代中的资源申请量为: 51.07243961445531
# agent 72 在 59999 次迭代中的资源申请量为: 51.63101181607605
# agent 73 在 59999 次迭代中的资源申请量为: 68.52493850742809
# agent 74 在 59999 次迭代中的资源申请量为: 63.033563690016244
# agent 75 在 59999 次迭代中的资源申请量为: 68.78486031089474
# agent 76 在 59999 次迭代中的资源申请量为: 65.84231131076093
# agent 77 在 59999 次迭代中的资源申请量为: 37.33178559067781
# agent 78 在 59999 次迭代中的资源申请量为: 56.51515954674745
# agent 79 在 59999 次迭代中的资源申请量为: 35.713197668399026
# agent 80 在 59999 次迭代中的资源申请量为: 41.69438982489667
# agent 81 在 59999 次迭代中的资源申请量为: 64.43288578237754
# agent 82 在 59999 次迭代中的资源申请量为: 45.64920279687104
# agent 83 在 59999 次迭代中的资源申请量为: 54.00548947849467
# agent 84 在 59999 次迭代中的资源申请量为: 52.98642785862186
# agent 85 在 59999 次迭代中的资源申请量为: 58.685757530614225
# agent 86 在 59999 次迭代中的资源申请量为: 54.16278250297603
# agent 87 在 59999 次迭代中的资源申请量为: 50.18394787557497
# agent 88 在 59999 次迭代中的资源申请量为: 53.40486804038577
# agent 89 在 59999 次迭代中的资源申请量为: 44.03701682161516
# agent 90 在 59999 次迭代中的资源申请量为: 38.99584103965445
# agent 91 在 59999 次迭代中的资源申请量为: 43.58677066582381
# agent 92 在 59999 次迭代中的资源申请量为: 45.258091384555385
# agent 93 在 59999 次迭代中的资源申请量为: 35.68321481267107
# agent 94 在 59999 次迭代中的资源申请量为: 37.4806078588005
# 资源申请量平均值avg为: 49.9999999999985
# ****************************************************************************
# 平均成本为: 3240.4819845314896
# ****************************************************************************
# agent 1 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 2 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 3 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 4 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 5 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 6 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 7 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 8 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 9 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 10 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 11 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 12 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 13 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 14 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 15 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 16 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 17 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 18 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 19 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 20 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 21 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 22 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 23 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 24 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 25 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 26 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 27 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 28 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 29 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 30 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 31 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 32 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 33 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 34 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 35 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 36 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 37 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 38 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 39 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 40 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 41 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 42 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 43 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 44 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 45 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 46 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 47 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 48 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 49 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 50 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 51 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 52 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 53 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 54 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 55 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 56 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 57 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 58 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 59 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 60 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 61 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 62 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 63 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 64 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 65 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 66 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 67 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 68 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 69 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 70 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 71 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 72 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 73 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 74 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 75 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 76 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 77 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 78 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 79 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 80 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 81 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 82 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 83 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 84 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 85 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 86 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 87 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 88 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 89 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 90 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 91 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 92 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 93 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 94 在 59999 次迭代中的对偶变量为: -135.1438665383513
# *************************
# 迭代步长为: 0.11075700351730201
# ****************************************************************************
# 2023-05-29 15:40:13.737

# %%
np.savetxt('../data/01-DGD-ARC-robust-agent_resource_quantity_large_value_deterministic_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/01-DGD-ARC-robust-sum_cost_large_value_deterministic_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/01-DGD-ARC-robust-sum_resource_large_value_deterministic_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
