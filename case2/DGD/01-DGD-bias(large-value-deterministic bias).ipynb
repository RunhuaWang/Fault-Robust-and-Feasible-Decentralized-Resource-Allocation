# %% [markdown]
# DGD+部分用户的对偶计算有误差
# 为了对比实验的公平性 要保证噪声的效果和IWDGD算法中噪声的效果尽可能一致
# 主要是观察噪声对对偶变量的影响是否一致

# %% [markdown]
# IWDGD中大值的确定性噪声 对应到DGD算法中是固定的对偶攻击值为-24 这样两个算法各自迭代2000次 所有用户的对偶迭代值均在-23.83附近

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(54,2000)) 
dual_variable = np.zeros(shape=(54,2000))#对偶变量
sum_resource=np.zeros(shape=(1,2000), dtype=np.float64)
sum_cost=np.zeros(shape=(1,2000), dtype=np.float64)
iteration_update = 0.01 #迭代步长
#W=np.zeros(shape=(54,54)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
W=np.loadtxt("double_stochastic_weight_1.txt") #双随机的网络拓扑矩阵W（对角线处非零）
iteration=[]#绘图横坐标
generator_a_values= np.loadtxt("generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("generator_b_values.txt")#每个agent的成本函数中的超参数a
generator_c_values= np.loadtxt("generator_c_values.txt")#每个agent的成本函数中的超参数a

# %%
'''for i in range(0,54):
    for j in range(0,54):
        W[i][j]=1/54'''

#对偶变量的初始化 初始化一致
for i in range (0,54):
    dual_variable[i][0]=0
    
#资源量的初始化 资源量的初始化需要和对偶变量的初始值满足某种关系
for i in range (0,54):
    agent_resource_quantity[i][0]=6000/54

iteration.append(0)

#总资源量 初始化
sum=0
for i in range (0,54):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

#用户总成本初始化
sum=0
for i in range(0,54):
    sum=sum+(generator_c_values[i]*(agent_resource_quantity[i][0])*(agent_resource_quantity[i][0])+generator_b_values[i]*agent_resource_quantity[i][0]+generator_a_values[i])
sum_cost[0][0]=sum

# %%
#DGD算法 
def DGD_determinitic_bias(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,dual_variable,iteration_update,W,iteration):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************DGD算法+无计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,54):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    for i in range(0,54):
        print("agent",(i+1),"的初始对偶变量为:",dual_variable[i][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,2000):#迭代次数
        iteration.append(k)
        
        #所有用户对偶变量的迭代 
        #阶段一：梯度下降
        dual_variable_intermediate=[] #存放当前迭代中100个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,54):
            #每个用户对对偶变量先进行一次梯度下降
            if i==48:
                dual_variable_intermediate.append(-24)
            else:
                dual_variable_intermediate.append(dual_variable[i][k-1]-iteration_update*((6000/54)-agent_resource_quantity[i][k-1]))       
        #阶段二：聚合 每个用户聚合自身以及邻居的对偶值   
        for i in range(0,54):
            mix_sum_dual=0
            for j in range(0,54):
                if W[i][j]!=0:
                    mix_sum_dual=mix_sum_dual+W[i][j]*dual_variable_intermediate[j]
            dual_variable[i][k]=mix_sum_dual                    
        
        #用户资源申请量的迭代
        for i in range (0,54):
            agent_resource_quantity[i][k]=(-dual_variable[i][k]-generator_b_values[i])/(2*generator_c_values[i]) 

        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,54):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,54):
            sum2=sum2+(generator_a_values[i]+(generator_b_values[i]*agent_resource_quantity[i][k])+(generator_c_values[i]*agent_resource_quantity[i][k]*agent_resource_quantity[i][k]))
        sum_cost[0][k]=sum2
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%20==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,54):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            for i in range(0,54):
                print("agent",(i+1),"在",k,"次迭代中的对偶变量为:",dual_variable[i][k])   
            print("*************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=(1/(pow(k+1,1.3)))*(1/26.511) #递减步长
        iteration_update=(1/(pow(k+1,1.5)))*(1/18.8468) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
DGD_determinitic_bias(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,dual_variable,iteration_update,W,iteration)
# Out:
# ****************************DGD算法+无计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 111.11111111111111
# agent 2 的初始资源申请量为: 111.11111111111111
# agent 3 的初始资源申请量为: 111.11111111111111
# agent 4 的初始资源申请量为: 111.11111111111111
# agent 5 的初始资源申请量为: 111.11111111111111
# agent 6 的初始资源申请量为: 111.11111111111111
# agent 7 的初始资源申请量为: 111.11111111111111
# agent 8 的初始资源申请量为: 111.11111111111111
# agent 9 的初始资源申请量为: 111.11111111111111
# agent 10 的初始资源申请量为: 111.11111111111111
# agent 11 的初始资源申请量为: 111.11111111111111
# agent 12 的初始资源申请量为: 111.11111111111111
# agent 13 的初始资源申请量为: 111.11111111111111
# agent 14 的初始资源申请量为: 111.11111111111111
# agent 15 的初始资源申请量为: 111.11111111111111
# agent 16 的初始资源申请量为: 111.11111111111111
# agent 17 的初始资源申请量为: 111.11111111111111
# agent 18 的初始资源申请量为: 111.11111111111111
# agent 19 的初始资源申请量为: 111.11111111111111
# agent 20 的初始资源申请量为: 111.11111111111111
# agent 21 的初始资源申请量为: 111.11111111111111
# agent 22 的初始资源申请量为: 111.11111111111111
# agent 23 的初始资源申请量为: 111.11111111111111
# agent 24 的初始资源申请量为: 111.11111111111111
# agent 25 的初始资源申请量为: 111.11111111111111
# agent 26 的初始资源申请量为: 111.11111111111111
# agent 27 的初始资源申请量为: 111.11111111111111
# agent 28 的初始资源申请量为: 111.11111111111111
# agent 29 的初始资源申请量为: 111.11111111111111
# agent 30 的初始资源申请量为: 111.11111111111111
# agent 31 的初始资源申请量为: 111.11111111111111
# agent 32 的初始资源申请量为: 111.11111111111111
# agent 33 的初始资源申请量为: 111.11111111111111
# agent 34 的初始资源申请量为: 111.11111111111111
# agent 35 的初始资源申请量为: 111.11111111111111
# agent 36 的初始资源申请量为: 111.11111111111111
# agent 37 的初始资源申请量为: 111.11111111111111
# agent 38 的初始资源申请量为: 111.11111111111111
# agent 39 的初始资源申请量为: 111.11111111111111
# agent 40 的初始资源申请量为: 111.11111111111111
# agent 41 的初始资源申请量为: 111.11111111111111
# agent 42 的初始资源申请量为: 111.11111111111111
# agent 43 的初始资源申请量为: 111.11111111111111
# agent 44 的初始资源申请量为: 111.11111111111111
# agent 45 的初始资源申请量为: 111.11111111111111
# agent 46 的初始资源申请量为: 111.11111111111111
# agent 47 的初始资源申请量为: 111.11111111111111
# agent 48 的初始资源申请量为: 111.11111111111111
# agent 49 的初始资源申请量为: 111.11111111111111
# agent 50 的初始资源申请量为: 111.11111111111111
# agent 51 的初始资源申请量为: 111.11111111111111
# agent 52 的初始资源申请量为: 111.11111111111111
# agent 53 的初始资源申请量为: 111.11111111111111
# agent 54 的初始资源申请量为: 111.11111111111111
# *************************
# 初始资源申请量总和为: 6000.000000000006
# *************************
# 初始成本总和为: 139226.02283950621
# *************************
# agent 1 的初始对偶变量为: 0.0
# agent 2 的初始对偶变量为: 0.0
# agent 3 的初始对偶变量为: 0.0
# agent 4 的初始对偶变量为: 0.0
# agent 5 的初始对偶变量为: 0.0
# agent 6 的初始对偶变量为: 0.0
# agent 7 的初始对偶变量为: 0.0
# agent 8 的初始对偶变量为: 0.0
# agent 9 的初始对偶变量为: 0.0
# agent 10 的初始对偶变量为: 0.0
# agent 11 的初始对偶变量为: 0.0
# agent 12 的初始对偶变量为: 0.0
# agent 13 的初始对偶变量为: 0.0
# agent 14 的初始对偶变量为: 0.0
# agent 15 的初始对偶变量为: 0.0
# agent 16 的初始对偶变量为: 0.0
# agent 17 的初始对偶变量为: 0.0
# agent 18 的初始对偶变量为: 0.0
# agent 19 的初始对偶变量为: 0.0
# agent 20 的初始对偶变量为: 0.0
# agent 21 的初始对偶变量为: 0.0
# agent 22 的初始对偶变量为: 0.0
# agent 23 的初始对偶变量为: 0.0
# agent 24 的初始对偶变量为: 0.0
# agent 25 的初始对偶变量为: 0.0
# agent 26 的初始对偶变量为: 0.0
# agent 27 的初始对偶变量为: 0.0
# agent 28 的初始对偶变量为: 0.0
# agent 29 的初始对偶变量为: 0.0
# agent 30 的初始对偶变量为: 0.0
# agent 31 的初始对偶变量为: 0.0
# agent 32 的初始对偶变量为: 0.0
# agent 33 的初始对偶变量为: 0.0
# agent 34 的初始对偶变量为: 0.0
# agent 35 的初始对偶变量为: 0.0
# agent 36 的初始对偶变量为: 0.0
# agent 37 的初始对偶变量为: 0.0
# agent 38 的初始对偶变量为: 0.0
# agent 39 的初始对偶变量为: 0.0
# agent 40 的初始对偶变量为: 0.0
# agent 41 的初始对偶变量为: 0.0
# agent 42 的初始对偶变量为: 0.0
# agent 43 的初始对偶变量为: 0.0
# agent 44 的初始对偶变量为: 0.0
# agent 45 的初始对偶变量为: 0.0
# agent 46 的初始对偶变量为: 0.0
# agent 47 的初始对偶变量为: 0.0
# agent 48 的初始对偶变量为: 0.0
# agent 49 的初始对偶变量为: 0.0
# agent 50 的初始对偶变量为: 0.0
# agent 51 的初始对偶变量为: 0.0
# agent 52 的初始对偶变量为: 0.0
# agent 53 的初始对偶变量为: 0.0
# agent 54 的初始对偶变量为: 0.0
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 19 次迭代中的结果：
# agent 1 在 19 次迭代中的资源申请量为: -67.37912474301444
# agent 2 在 19 次迭代中的资源申请量为: -67.37912474301444
# agent 3 在 19 次迭代中的资源申请量为: -69.00789599388895
# agent 4 在 19 次迭代中的资源申请量为: 156.9526978137157
# agent 5 在 19 次迭代中的资源申请量为: 176.3277409721723
# agent 6 在 19 次迭代中的资源申请量为: -68.33736441048514
# agent 7 在 19 次迭代中的资源申请量为: -40.21446104520612
# agent 8 在 19 次迭代中的资源申请量为: -65.23035244538355
# agent 9 在 19 次迭代中的资源申请量为: -61.888374808670484
# agent 10 在 19 次迭代中的资源申请量为: 193.05620506822842
# agent 11 在 19 次迭代中的资源申请量为: 983.4813109127039
# agent 12 在 19 次迭代中的资源申请量为: -65.86855630631025
# agent 13 在 19 次迭代中的资源申请量为: -68.0077782931388
# agent 14 在 19 次迭代中的资源申请量为: -26.145270626834332
# agent 15 在 19 次迭代中的资源申请量为: -68.89612979855484
# agent 16 在 19 次迭代中的资源申请量为: -46.1358992360808
# agent 17 在 19 次迭代中的资源申请量为: -69.53551024939348
# agent 18 在 19 次迭代中的资源申请量为: -72.35803667872275
# agent 19 在 19 次迭代中的资源申请量为: -44.92224608926676
# agent 20 在 19 次迭代中的资源申请量为: 745.1084205296769
# agent 21 在 19 次迭代中的资源申请量为: 577.6304218555034
# agent 22 在 19 次迭代中的资源申请量为: -108.12184601448268
# agent 23 在 19 次迭代中的资源申请量为: -106.10619977538565
# agent 24 在 19 次迭代中的资源申请量为: 215.8931811067354
# agent 25 在 19 次迭代中的资源申请量为: 231.28507152381945
# agent 26 在 19 次迭代中的资源申请量为: -102.47632893535751
# agent 27 在 19 次迭代中的资源申请量为: 388.23410152959843
# agent 28 在 19 次迭代中的资源申请量为: 332.8934742454426
# agent 29 在 19 次迭代中的资源申请量为: 227.32951164404975
# agent 30 在 19 次迭代中的资源申请量为: 31.192390344982435
# agent 31 在 19 次迭代中的资源申请量为: -57.658780624909696
# agent 32 在 19 次迭代中的资源申请量为: -56.61812491590823
# agent 33 在 19 次迭代中的资源申请量为: -339.807926146309
# agent 34 在 19 次迭代中的资源申请量为: 25.09031829743463
# agent 35 在 19 次迭代中的资源申请量为: 26.931840217364055
# agent 36 在 19 次迭代中的资源申请量为: 265.4864821601526
# agent 37 在 19 次迭代中的资源申请量为: 33.70730472504482
# agent 38 在 19 次迭代中的资源申请量为: -64.51319012301731
# agent 39 在 19 次迭代中的资源申请量为: 897.3767946923745
# agent 40 在 19 次迭代中的资源申请量为: 268.5300173672161
# agent 41 在 19 次迭代中的资源申请量为: -321.7149857556466
# agent 42 在 19 次迭代中的资源申请量为: -167.99595715271082
# agent 43 在 19 次迭代中的资源申请量为: 284.038251615158
# agent 44 在 19 次迭代中的资源申请量为: 295.8537410307263
# agent 45 在 19 次迭代中的资源申请量为: 385.8449498222563
# agent 46 在 19 次迭代中的资源申请量为: -275.5981465798206
# agent 47 在 19 次迭代中的资源申请量为: 166.12668034850645
# agent 48 在 19 次迭代中的资源申请量为: 186.75114646484357
# agent 49 在 19 次迭代中的资源申请量为: -258.73806928682137
# agent 50 在 19 次迭代中的资源申请量为: -40.93308002133027
# agent 51 在 19 次迭代中的资源申请量为: 165.4265520550574
# agent 52 在 19 次迭代中的资源申请量为: 165.4265520550574
# agent 53 在 19 次迭代中的资源申请量为: -43.76513173754426
# agent 54 在 19 次迭代中的资源申请量为: -256.0945531541959
# 资源申请量总和为: 4324.526712706417
# ****************************************************************************
# 成本总和为: 38629.891112940975
# ****************************************************************************
# agent 1 在 19 次迭代中的对偶变量为: -16.85613606605477
# agent 2 在 19 次迭代中的对偶变量为: -16.85613606605477
# agent 3 在 19 次迭代中的对偶变量为: -16.62920588275543
# agent 4 在 19 次迭代中的对偶变量为: -16.301221177448316
# agent 5 在 19 次迭代中的对偶变量为: -16.722628366144747
# agent 6 在 19 次迭代中的对偶变量为: -16.722628366144747
# agent 7 在 19 次迭代中的对偶变量为: -16.790509797242724
# agent 8 在 19 次迭代中的对偶变量为: -17.155515915194492
# agent 9 在 19 次迭代中的对偶变量为: -17.621140291407176
# agent 10 在 19 次迭代中的对偶变量为: -17.086472460233967
# agent 11 在 19 次迭代中的对偶变量为: -16.660887865476223
# agent 12 在 19 次迭代中的对偶变量为: -17.066597524067017
# agent 13 在 19 次迭代中的对偶变量为: -16.768548281530144
# agent 14 在 19 次迭代中的对偶变量为: -17.15068107195304
# agent 15 在 19 次迭代中的对偶变量为: -16.64477781968655
# agent 16 在 19 次迭代中的对偶变量为: -16.63892097955633
# agent 17 在 19 次迭代中的对偶变量为: -16.555695498993003
# agent 18 在 19 次迭代中的对偶变量为: -16.162444181700273
# agent 19 在 19 次迭代中的对偶变量为: -16.66999050011477
# agent 20 在 19 次迭代中的对偶变量为: -15.907910635383509
# agent 21 在 19 次迭代中的对偶变量为: -15.103681285750127
# agent 22 在 19 次迭代中的对偶变量为: -15.052080742029244
# agent 23 在 19 次迭代中的对偶变量为: -15.103681285750127
# agent 24 在 19 次迭代中的对偶变量为: -15.18985999373927
# agent 25 在 19 次迭代中的对偶变量为: -15.32530862940961
# agent 26 在 19 次迭代中的对偶变量为: -15.196605979254848
# agent 27 在 19 次迭代中的对偶变量为: -16.561898270396895
# agent 28 在 19 次迭代中的对偶变量为: -15.389783784518475
# agent 29 在 19 次迭代中的对偶变量为: -17.83191687825808
# agent 30 在 19 次迭代中的对偶变量为: -18.335696283625257
# agent 31 在 19 次迭代中的对偶变量为: -18.21043273065383
# agent 32 在 19 次迭代中的对偶变量为: -18.35542312796617
# agent 33 在 19 次迭代中的对偶变量为: -18.462312148414327
# agent 34 在 19 次迭代中的对偶变量为: -18.462312148414327
# agent 35 在 19 次迭代中的对偶变量为: -18.50945510956452
# agent 36 在 19 次迭代中的对偶变量为: -18.66183098698332
# agent 37 在 19 次迭代中的对偶变量为: -18.682907000961148
# agent 38 在 19 次迭代中的对偶变量为: -17.25543527292049
# agent 39 在 19 次迭代中的对偶变量为: -16.144260768154247
# agent 40 在 19 次迭代中的对偶变量为: -18.72802787773695
# agent 41 在 19 次迭代中的对偶变量为: -19.486444946287385
# agent 42 在 19 次迭代中的对偶变量为: -19.65831502957881
# agent 43 在 19 次迭代中的对偶变量为: -19.065331972629686
# agent 44 在 19 次迭代中的对偶变量为: -19.322318867418296
# agent 45 在 19 次迭代中的对偶变量为: -21.279627658634073
# agent 46 在 19 次迭代中的对偶变量为: -22.096842510995838
# agent 47 在 19 次迭代中的对偶变量为: -22.072843016921766
# agent 48 在 19 次迭代中的对偶变量为: -22.600829349499996
# agent 49 在 19 次迭代中的对偶变量为: -23.051190326088765
# agent 50 在 19 次迭代中的对偶变量为: -22.142140151743035
# agent 51 在 19 次迭代中的对偶变量为: -22.05491973260947
# agent 52 在 19 次迭代中的对偶变量为: -22.05491973260947
# agent 53 在 19 次迭代中的对偶变量为: -16.699612627518867
# agent 54 在 19 次迭代中的对偶变量为: -17.936163674941778
# *************************
# 迭代步长为: 0.0006406664425248283
# ****************************************************************************
# 39 次迭代中的结果：
# agent 1 在 39 次迭代中的资源申请量为: -64.98615198384996
# agent 2 在 39 次迭代中的资源申请量为: -64.98615198384996
# agent 3 在 39 次迭代中的资源申请量为: -65.5041898898838
# agent 4 在 39 次迭代中的资源申请量为: 187.92103270908015
# agent 5 在 39 次迭代中的资源申请量为: 196.32270891143182
# agent 6 在 39 次迭代中的资源申请量为: -65.21597606459927
# agent 7 在 39 次迭代中的资源申请量为: -23.666421610457483
# agent 8 在 39 次迭代中的资源申请量为: -62.85716384710835
# agent 9 在 39 次迭代中的资源申请量为: -60.39302635953604
# agent 10 在 39 次迭代中的资源申请量为: 210.7082697370918
# agent 11 在 39 次迭代中的资源申请量为: 1067.5115198169165
# agent 12 在 39 次迭代中的资源申请量为: -63.25735914005797
# agent 13 在 39 次迭代中的资源申请量为: -64.76434020486948
# agent 14 在 39 次迭代中的资源申请量为: -13.185413584218402
# agent 15 在 39 次迭代中的资源申请量为: -65.31952811365173
# agent 16 在 39 次迭代中的资源申请量为: -26.728443917332783
# agent 17 在 39 次迭代中的资源申请量为: -65.88247430333725
# agent 18 在 39 次迭代中的资源申请量为: -67.94054168941516
# agent 19 在 39 次迭代中的资源申请量为: -24.544112235640874
# agent 20 在 39 次迭代中的资源申请量为: 892.1383316270916
# agent 21 在 39 次迭代中的资源申请量为: 755.1740104228492
# agent 22 在 39 次迭代中的资源申请量为: -75.39363658838282
# agent 23 在 39 次迭代中的资源申请量为: -72.80290632615149
# agent 24 在 39 次迭代中的资源申请量为: 311.22768087051526
# agent 25 在 39 次迭代中的资源申请量为: 327.3885586158192
# agent 26 在 39 次迭代中的资源申请量为: -66.68486522355576
# agent 27 在 39 次迭代中的资源申请量为: 414.6980456201485
# agent 28 在 39 次迭代中的资源申请量为: 376.34943181146514
# agent 29 在 39 次迭代中的资源申请量为: 237.4242868857075
# agent 30 在 39 次迭代中的资源申请量为: 31.366819330940373
# agent 31 在 39 次迭代中的资源申请量为: -57.36713980859919
# agent 32 在 39 次迭代中的资源申请量为: -56.59816276243187
# agent 33 在 39 次迭代中的资源申请量为: -339.9672372943094
# agent 34 在 39 次迭代中的资源申请量为: 24.738066413785564
# agent 35 在 39 次迭代中的资源申请量为: 31.57086716444546
# agent 36 在 39 次迭代中的资源申请量为: 281.02043963011386
# agent 37 在 39 次迭代中的资源申请量为: 52.631361169083455
# agent 38 在 39 次迭代中的资源申请量为: -56.48437086918618
# agent 39 在 39 次迭代中的资源申请量为: 1183.6559869072992
# agent 40 在 39 次迭代中的资源申请量为: 278.65074035492336
# agent 41 在 39 次迭代中的资源申请量为: -326.82363092027583
# agent 42 在 39 次迭代中的资源申请量为: -186.22289855772792
# agent 43 在 39 次迭代中的资源申请量为: 293.0128165446772
# agent 44 在 39 次迭代中的资源申请量为: 315.3259961038082
# agent 45 在 39 次迭代中的资源申请量为: 397.7915635513742
# agent 46 在 39 次迭代中的资源申请量为: -272.1839655435044
# agent 47 在 39 次迭代中的资源申请量为: 173.4503054468063
# agent 48 在 39 次迭代中的资源申请量为: 192.30119187743367
# agent 49 在 39 次迭代中的资源申请量为: -256.56003244792294
# agent 50 在 39 次迭代中的资源申请量为: -27.075810882697752
# agent 51 在 39 次迭代中的资源申请量为: 178.0897059302941
# agent 52 在 39 次迭代中的资源申请量为: 178.0897059302941
# agent 53 在 39 次迭代中的资源申请量为: -25.173596188484275
# agent 54 在 39 次迭代中的资源申请量为: -241.67482815058762
# 资源申请量总和为: 5728.315066891769
# ****************************************************************************
# 成本总和为: 62146.548616976295
# ****************************************************************************
# agent 1 在 39 次迭代中的对偶变量为: -17.18953938869812
# agent 2 在 39 次迭代中的对偶变量为: -17.18953938869812
# agent 3 在 39 次迭代中的对偶变量为: -17.11736323940205
# agent 4 在 39 次迭代中的对偶变量为: -16.974782461422492
# agent 5 在 39 次迭代中的对偶变量为: -17.15751891882364
# agent 6 在 39 次迭代中的对偶变量为: -17.15751891882364
# agent 7 在 39 次迭代中的对偶变量为: -17.21413960677229
# agent 8 在 39 次迭代中的对偶变量为: -17.48616278983778
# agent 9 在 39 次迭代中的对偶变量为: -17.829481209431282
# agent 10 在 39 次迭代中的对偶变量为: -17.470404866781745
# agent 11 在 39 次迭代中的对偶变量为: -17.1650691189015
# agent 12 在 39 次迭代中的对偶变量为: -17.430405180452283
# agent 13 在 39 次迭代中的对偶变量为: -17.220443536616354
# agent 14 在 39 次迭代中的对偶变量为: -17.48245341224401
# agent 15 在 39 次迭代中的对偶变量为: -17.14309142603736
# agent 16 在 39 次迭代中的对偶变量为: -17.13575183571628
# agent 17 在 39 次迭代中的对偶变量为: -17.064658385213235
# agent 18 在 39 次迭代中的对偶变量为: -16.777916088580543
# agent 19 在 39 次迭代中的对偶变量为: -17.191670726767594
# agent 20 在 39 次迭代中的对偶变量为: -16.613948268473294
# agent 21 在 39 次迭代中的对偶变量为: -15.956245598050522
# agent 22 在 39 次迭代中的对偶变量为: -15.8899229033374
# agent 23 在 39 次迭代中的对偶变量为: -15.956245598050522
# agent 24 在 39 次迭代中的对偶变量为: -16.028803591660534
# agent 25 在 39 次迭代中的对偶变量为: -16.17101931581921
# agent 26 在 39 次迭代中的对偶变量为: -16.112867450276973
# agent 27 在 39 次迭代中的对偶变量为: -17.122404606234745
# agent 28 在 39 次迭代中的对偶变量为: -16.310180965766833
# agent 29 在 39 次迭代中的对偶变量为: -18.051478239764137
# agent 30 在 39 次迭代中的对偶变量为: -18.35171688826955
# agent 31 在 39 次迭代中的对偶变量为: -18.25106587902711
# agent 32 在 39 次迭代中的对偶变量为: -18.358204374961417
# agent 33 在 39 次迭代中的对偶变量为: -18.45329450019291
# agent 34 在 39 次迭代中的对偶变量为: -18.45329450019291
# agent 35 在 39 次迭代中的对偶变量为: -18.628214199409804
# agent 36 在 39 次迭代中的对偶变量为: -18.999694561954975
# agent 37 在 39 次迭代中的对偶变量为: -19.167362845928537
# agent 38 在 39 次迭代中的对偶变量为: -18.374058544279766
# agent 39 在 39 次迭代中的对偶变量为: -17.861935921443795
# agent 40 在 39 次迭代中的对偶变量为: -18.948153602719582
# agent 41 在 39 次迭代中的对偶变量为: -19.19727519538871
# agent 42 在 39 次迭代中的对偶变量为: -19.302014778993534
# agent 43 在 39 次迭代中的对偶变量为: -19.26052875984673
# agent 44 在 39 次迭代中的对偶变量为: -19.745840415257828
# agent 45 在 39 次迭代中的对偶变量为: -21.539466507242388
# agent 46 在 39 次迭代中的对偶变量为: -22.29009881437548
# agent 47 在 39 次迭代中的对偶变量为: -22.260327819438242
# agent 48 在 39 次迭代中的对偶变量为: -22.742910512062302
# agent 49 在 39 次迭代中的对偶变量为: -23.17447592331777
# agent 50 在 39 次迭代中的对偶变量为: -22.413022048865024
# agent 51 在 39 次迭代中的对偶变量为: -22.37909647181553
# agent 52 在 39 次迭代中的对偶变量为: -22.37909647181553
# agent 53 在 39 次迭代中的对偶变量为: -17.175555937574803
# agent 54 在 39 次迭代中的对偶变量为: -18.218040459312313
# *************************
# 迭代步长为: 0.000217853964469636
# ****************************************************************************
# 59 次迭代中的结果：
# agent 1 在 59 次迭代中的资源申请量为: -63.358149256111346
# agent 2 在 59 次迭代中的资源申请量为: -63.358149256111346
# agent 3 在 59 次迭代中的资源申请量为: -63.58863152574718
# agent 4 在 59 次迭代中的资源申请量为: 202.26535097374176
# agent 5 在 59 次迭代中的资源申请量为: 207.99369026051986
# agent 6 在 59 次迭代中的资源申请量为: -63.39403440013848
# agent 7 在 59 次迭代中的资源申请量为: -14.301959184721824
# agent 8 在 59 次迭代中的资源申请量为: -61.79483648366083
# agent 9 在 59 次迭代中的资源申请量为: -59.955831943126604
# agent 10 在 59 次迭代中的资源申请量为: 217.6940404383109
# agent 11 在 59 次迭代中的资源申请量为: 1110.9447613622854
# agent 12 在 59 次迭代中的资源申请量为: -62.14131663007353
# agent 13 在 59 次迭代中的资源申请量为: -63.06675258299791
# agent 14 在 59 次迭代中的资源申请量为: -7.5620051635841286
# agent 15 在 59 次迭代中的资源申请量为: -63.305961340918905
# agent 16 在 59 次迭代中的资源申请量为: -16.17950124570333
# agent 17 在 59 次迭代中的资源申请量为: -63.77547958174453
# agent 18 在 59 次迭代中的资源申请量为: -65.10330868955329
# agent 19 在 59 次迭代中的资源申请量为: -11.51971251684286
# agent 20 在 59 次迭代中的资源申请量为: 991.0550561934857
# agent 21 在 59 次迭代中的资源申请量为: 889.9421541160415
# agent 22 在 59 次迭代中的资源申请量为: -49.562154154405846
# agent 23 在 59 次迭代中的资源申请量为: -47.523350622451915
# agent 24 在 59 次迭代中的资源申请量为: 382.8872362277404
# agent 25 在 59 次迭代中的资源申请量为: 395.5672448733685
# agent 26 在 59 次迭代中的资源申请量为: -42.436486545703445
# agent 27 在 59 次迭代中的资源申请量为: 431.3927162021978
# agent 28 在 59 次迭代中的资源申请量为: 403.5015563958876
# agent 29 在 59 次迭代中的资源申请量为: 245.97749439371376
# agent 30 在 59 次迭代中的资源申请量为: 31.457489034267027
# agent 31 在 59 次迭代中的资源申请量为: -57.68958319045568
# agent 32 在 59 次迭代中的资源申请量为: -57.09052909107646
# agent 33 在 59 次迭代中的资源申请量为: -338.93583397785534
# agent 34 在 59 次迭代中的资源申请量为: 27.018595840526544
# agent 35 在 59 次迭代中的资源申请量为: 36.18758785223025
# agent 36 在 59 次迭代中的资源申请量为: 291.6272829074899
# agent 37 在 59 次迭代中的资源申请量为: 64.04918675233267
# agent 38 在 59 次迭代中的资源申请量为: -52.38191416023398
# agent 39 在 59 次迭代中的资源申请量为: 1312.99229333959
# agent 40 在 59 次迭代中的资源申请量为: 293.3275964166578
# agent 41 在 59 次迭代中的资源申请量为: -323.4100752590529
# agent 42 在 59 次迭代中的资源申请量为: -177.96961431481617
# agent 43 在 59 次迭代中的资源申请量为: 304.50526869776485
# agent 44 在 59 次迭代中的资源申请量为: 326.7814857004286
# agent 45 在 59 次迭代中的资源申请量为: 404.3491021095225
# agent 46 在 59 次迭代中的资源申请量为: -270.4453340444737
# agent 47 在 59 次迭代中的资源申请量为: 177.27558535524975
# agent 48 在 59 次迭代中的资源申请量为: 195.12748716625103
# agent 49 在 59 次迭代中的资源申请量为: -255.59218467694384
# agent 50 在 59 次迭代中的资源申请量为: -21.336993417522297
# agent 51 在 59 次迭代中的资源申请量为: 182.99714956134042
# agent 52 在 59 次迭代中的资源申请量为: 182.99714956134042
# agent 53 在 59 次迭代中的资源申请量为: -15.216096254921096
# agent 54 在 59 次迭代中的资源申请量为: -230.0189913308347
# 资源申请量总和为: 6627.8997908905
# ****************************************************************************
# 成本总和为: 77770.19180255239
# ****************************************************************************
# agent 1 在 59 次迭代中的对偶变量为: -17.41636249674303
# agent 2 在 59 次迭代中的对偶变量为: -17.41636249674303
# agent 3 在 59 次迭代中的对偶变量为: -17.384250324043748
# agent 4 在 59 次迭代中的对偶变量为: -17.286771383678882
# agent 5 在 59 次迭代中的对偶变量为: -17.411362763166306
# agent 6 在 59 次迭代中的对偶变量为: -17.411362763166306
# agent 7 在 59 次迭代中的对偶变量为: -17.45386984487112
# agent 8 在 59 次迭代中的对偶变量为: -17.63417261207747
# agent 9 在 59 次迭代中的对偶变量为: -17.890393758691943
# agent 10 在 59 次迭代中的对偶变量为: -17.62234537953326
# agent 11 在 59 次迭代中的对偶变量为: -17.425668568173712
# agent 12 在 59 次迭代中的对偶变量为: -17.585898919198375
# agent 13 在 59 次迭代中的对偶变量为: -17.456961629621233
# agent 14 在 59 次迭代中的对偶变量为: -17.626412667812247
# agent 15 在 59 次迭代中的对偶变量为: -17.423633630215132
# agent 16 在 59 次迭代中的对偶变量为: -17.405804768109995
# agent 17 在 59 次迭代中的对偶变量为: -17.358217531793862
# agent 18 在 59 次迭代中的对偶变量为: -17.1732164135193
# agent 19 在 59 次迭代中的对偶变量为: -17.525095359568823
# agent 20 在 59 次迭代中的对偶变量为: -17.08894637984112
# agent 21 在 59 次迭代中的对偶变量为: -16.60340222406523
# agent 22 在 59 次迭代中的对偶变量为: -16.55120885364721
# agent 23 在 59 次迭代中的对偶变量为: -16.60340222406523
# agent 24 在 59 次迭代中的对偶变量为: -16.659407678804115
# agent 25 在 59 次迭代中的对偶变量为: -16.770991754885642
# agent 26 在 59 次迭代中的对偶变量为: -16.733625944429992
# agent 27 在 59 次迭代中的对偶变量为: -17.47599772916255
# agent 28 在 59 次迭代中的对偶变量为: -16.8852629644649
# agent 29 在 59 次迭代中的对偶变量为: -18.237510503063273
# agent 30 在 59 次迭代中的对偶变量为: -18.36004453784129
# agent 31 在 59 次迭代中的对偶变量为: -18.20614113240657
# agent 32 在 59 次迭代中的对偶变量为: -18.28960494385668
# agent 33 在 59 次迭代中的对偶变量为: -18.51167605351748
# agent 34 在 59 次迭代中的对偶变量为: -18.51167605351748
# agent 35 在 59 次迭代中的对偶变量为: -18.746402249017095
# agent 36 在 59 次迭代中的对偶变量为: -19.230393403237905
# agent 37 在 59 次迭代中的对偶变量为: -19.459659180859717
# agent 38 在 59 次迭代中的对偶变量为: -18.94563742771124
# agent 39 在 59 次迭代中的对偶变量为: -18.63795376003754
# agent 40 在 59 次迭代中的对偶变量为: -19.267375222062306
# agent 41 在 59 次迭代中的对偶变量为: -19.39049610003657
# agent 42 在 59 次迭代中的对偶变量为: -19.463349979373973
# agent 43 在 59 次迭代中的对偶变量为: -19.510489594176384
# agent 44 在 59 次迭代中的对偶变量为: -19.99499731398432
# agent 45 在 59 次迭代中的对偶变量为: -21.682092970882113
# agent 46 在 59 次迭代中的对偶变量为: -22.388512311746613
# agent 47 在 59 次迭代中的对偶变量为: -22.358254985094394
# agent 48 在 59 次迭代中的对偶变量为: -22.815263671456027
# agent 49 在 59 次迭代中的对偶变量为: -23.229259978546274
# agent 50 在 59 次迭代中的对偶变量为: -22.525204452674274
# agent 51 在 59 次迭代中的对偶变量为: -22.504727028770315
# agent 52 在 59 次迭代中的对偶变量为: -22.504727028770315
# agent 53 在 59 次迭代中的对偶变量为: -17.43046793587402
# agent 54 在 59 次迭代中的对偶变量为: -18.445888757464843
# *************************
# 迭代步长为: 0.00011708044397666381
# ****************************************************************************
# 79 次迭代中的结果：
# agent 1 在 79 次迭代中的资源申请量为: -61.82476582941427
# agent 2 在 79 次迭代中的资源申请量为: -61.82476582941427
# agent 3 在 79 次迭代中的资源申请量为: -61.928295162875365
# agent 4 在 79 次迭代中的资源申请量为: 213.45783683159115
# agent 5 在 79 次迭代中的资源申请量为: 218.4612845996476
# agent 6 在 79 次迭代中的资源申请量为: -61.759951911040766
# agent 7 在 79 次迭代中的资源申请量为: -5.647612045322353
# agent 8 在 79 次迭代中的资源申请量为: -60.54521967267612
# agent 9 在 79 次迭代中的资源申请量为: -59.00410052766695
# agent 10 在 79 次迭代中的资源申请量为: 225.6726607094883
# agent 11 在 79 次迭代中的资源申请量为: 1149.3092517958012
# agent 12 在 79 次迭代中的资源申请量为: -60.884632476538044
# agent 13 在 79 次迭代中的资源申请量为: -61.500449152230296
# agent 14 在 79 次迭代中的资源申请量为: -0.8885709925667007
# agent 15 在 79 次迭代中的资源申请量为: -61.546385365449396
# agent 16 在 79 次迭代中的资源申请量为: -6.969080967702129
# agent 17 在 79 次迭代中的资源申请量为: -61.9727787829409
# agent 18 在 79 次迭代中的资源申请量为: -62.84395657145952
# agent 19 在 79 次迭代中的资源申请量为: -0.4737722532240085
# agent 20 在 79 次迭代中的资源申请量为: 1067.4508691447807
# agent 21 在 79 次迭代中的资源申请量为: 989.3615746676728
# agent 22 在 79 次迭代中的资源申请量为: -30.484569870723455
# agent 23 在 79 次迭代中的资源申请量为: -28.874442126790438
# agent 24 在 79 次迭代中的资源申请量为: 435.8375534123946
# agent 25 在 79 次迭代中的资源申请量为: 445.919939171674
# agent 26 在 79 次迭代中的资源申请量为: -24.75569144642489
# agent 27 在 79 次迭代中的资源申请量为: 445.10308564601615
# agent 28 在 79 次迭代中的资源申请量为: 423.3459254349409
# agent 29 在 79 次迭代中的资源申请量为: 255.44049968763588
# agent 30 在 79 次迭代中的资源申请量为: 32.697708056944435
# agent 31 在 79 次迭代中的资源申请量为: -57.08044448847952
# agent 32 在 79 次迭代中的资源申请量为: -56.556124307908526
# agent 33 在 79 次迭代中的资源申请量为: -336.43942082256626
# agent 34 在 79 次迭代中的资源申请量为: 32.53839936560393
# agent 35 在 79 次迭代中的资源申请量为: 42.70375228176637
# agent 36 在 79 次迭代中的资源申请量为: 301.43337369024323
# agent 37 在 79 次迭代中的资源申请量为: 73.48014887190695
# agent 38 在 79 次迭代中的资源申请量为: -49.61297301216554
# agent 39 在 79 次迭代中的资源申请量为: 1392.949974501115
# agent 40 在 79 次迭代中的资源申请量为: 306.27935865064734
# agent 41 在 79 次迭代中的资源申请量为: -319.2739091352792
# agent 42 在 79 次迭代中的资源申请量为: -166.86061676509627
# agent 43 在 79 次迭代中的资源申请量为: 315.3279566620844
# agent 44 在 79 次迭代中的资源申请量为: 336.4532000078602
# agent 45 在 79 次迭代中的资源申请量为: 409.79727734857266
# agent 46 在 79 次迭代中的资源申请量为: -269.04234380114207
# agent 47 在 79 次迭代中的资源申请量为: 180.43133047573045
# agent 48 在 79 次迭代中的资源申请量为: 197.40816867730604
# agent 49 在 79 次迭代中的资源申请量为: -254.85628251064517
# agent 50 在 79 次迭代中的资源申请量为: -17.36648479335233
# agent 51 在 79 次迭代中的资源申请量为: 186.2017301854449
# agent 52 在 79 次迭代中的资源申请量为: 186.2017301854449
# agent 53 在 79 次迭代中的资源申请量为: -6.311513701249272
# agent 54 在 79 次迭代中的资源申请量为: -218.62483979988647
# 资源申请量总和为: 7337.5105959400835
# ****************************************************************************
# 成本总和为: 90424.22226982754
# ****************************************************************************
# agent 1 在 79 次迭代中的对偶变量为: -17.630002676051028
# agent 2 在 79 次迭代中的对偶变量为: -17.630002676051028
# agent 3 在 79 次迭代中的对偶变量为: -17.615578348137227
# agent 4 在 79 次迭代中的对偶变量为: -17.530207951087107
# agent 5 在 79 次迭代中的对偶变量为: -17.639032940042334
# agent 6 在 79 次迭代中的对偶变量为: -17.639032940042334
# agent 7 在 79 次迭代中的对偶变量为: -17.675421131639748
# agent 8 在 79 次迭代中的对偶变量为: -17.808276723884727
# agent 9 在 79 次迭代中的对偶变量为: -18.022994689882275
# agent 10 在 79 次迭代中的对偶变量为: -17.79588037043137
# agent 11 在 79 次迭代中的对偶变量为: -17.655855510774806
# agent 12 在 79 次迭代中的对偶变量为: -17.76098769557386
# agent 13 在 79 次迭代中的对偶变量为: -17.67518842141636
# agent 14 在 79 次迭代中的对偶变量为: -17.797252582590293
# agent 15 在 79 次迭代中的对偶变量为: -17.668788312573398
# agent 16 在 79 次迭代中的对偶变量为: -17.641591527226826
# agent 17 在 79 次迭代中的对偶变量为: -17.609380623287976
# agent 18 在 79 次迭代中的对偶变量为: -17.48800290672483
# agent 19 在 79 次迭代中的对偶变量为: -17.807871430317466
# agent 20 在 79 次迭代中的对偶变量为: -17.455799073633237
# agent 21 在 79 次迭代中的对偶变量为: -17.080814281554165
# agent 22 在 79 次迭代中的对偶变量为: -17.03959501130948
# agent 23 在 79 次迭代中的对偶变量为: -17.080814281554165
# agent 24 在 79 次迭代中的对偶变量为: -17.125370470029072
# agent 25 在 79 次迭代中的对偶变量为: -17.21409546471073
# agent 26 在 79 次迭代中的对偶变量为: -17.186254298971523
# agent 27 在 79 次迭代中的对偶变量为: -17.766383353982622
# agent 28 在 79 次迭代中的对偶变量为: -17.30556670071205
# agent 29 在 79 次迭代中的对偶变量为: -18.44333086820608
# agent 30 在 79 次迭代中的对偶变量为: -18.47395369419812
# agent 31 在 79 次迭代中的对偶变量为: -18.291009991198102
# agent 32 在 79 次迭代中的对偶变量为: -18.364061424676336
# agent 33 在 79 次迭代中的对偶变量为: -18.65298302375946
# agent 34 在 79 次迭代中的对偶变量为: -18.65298302375946
# agent 35 在 79 次迭代中的对偶变量为: -18.91321605841322
# agent 36 在 79 次迭代中的对偶变量为: -19.44367587776279
# agent 37 在 79 次迭代中的对偶变量为: -19.70109181112082
# agent 38 在 79 次迭代中的对偶变量为: -19.331422922107024
# agent 39 在 79 次迭代中的对偶变量为: -19.11769984700669
# agent 40 在 79 次迭代中的对偶变量为: -19.54907605065158
# agent 41 在 79 次迭代中的对偶变量为: -19.62461964730666
# agent 42 在 79 次迭代中的对偶变量为: -19.680508663475898
# agent 43 在 79 次迭代中的对偶变量为: -19.745883057400334
# agent 44 在 79 次迭代中的对偶变量为: -20.205357100170957
# agent 45 在 79 次迭代中的对偶变量为: -21.800590782331454
# agent 46 在 79 次迭代中的对偶变量为: -22.467927171480156
# agent 47 在 79 次迭代中的对偶变量为: -22.4390420601787
# agent 48 在 79 次迭代中的对偶变量为: -22.873649118139035
# agent 49 在 79 次迭代中的对偶变量为: -23.270914984767444
# agent 50 在 79 次迭代中的对偶变量为: -22.602819955259548
# agent 51 在 79 次迭代中的对偶变量为: -22.58676429274739
# agent 52 在 79 次迭代中的对偶变量为: -22.58676429274739
# agent 53 在 79 次迭代中的对偶变量为: -17.65842524924802
# agent 54 在 79 次迭代中的对偶变量为: -18.66862163159182
# *************************
# 迭代步长为: 7.556518347445504e-05
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: -60.25134954641685
# agent 2 在 99 次迭代中的资源申请量为: -60.25134954641685
# agent 3 在 99 次迭代中的资源申请量为: -60.28704192782158
# agent 4 在 99 次迭代中的资源申请量为: 224.1571121678431
# agent 5 在 99 次迭代中的资源申请量为: 228.9150263942584
# agent 6 在 99 次迭代中的资源申请量为: -60.12803192458608
# agent 7 在 99 次迭代中的资源申请量为: 3.120071876755448
# agent 8 在 99 次迭代中的资源申请量为: -59.11685782709331
# agent 9 在 99 次迭代中的资源申请量为: -57.735844861991424
# agent 10 在 99 次迭代中的资源申请量为: 234.79691422445526
# agent 11 在 99 次迭代中的资源申请量为: 1187.4702716381373
# agent 12 在 99 次迭代中的资源申请量为: -59.45502863515681
# agent 13 在 99 次迭代中的资源申请量为: -59.90325708906463
# agent 14 在 99 次迭代中的资源申请量为: 6.808920994117173
# agent 15 在 99 次迭代中的资源申请量为: -59.83748784482758
# agent 16 在 99 次迭代中的资源申请量为: 2.0940891204243584
# agent 17 在 99 次迭代中的资源申请量为: -60.24071618170842
# agent 18 在 99 次迭代中的资源申请量为: -60.83812106440492
# agent 19 在 99 次迭代中的资源申请量为: 9.682408181088396
# agent 20 在 99 次迭代中的资源申请量为: 1132.1646743138042
# agent 21 在 99 次迭代中的资源申请量为: 1068.2173939030733
# agent 22 在 99 次迭代中的资源申请量为: -15.419220161838469
# agent 23 在 99 次迭代中的资源申请量为: -14.082815409275083
# agent 24 在 99 次迭代中的资源申请量为: 478.02203535688443
# agent 25 在 99 次迭代中的资源申请量为: 486.42132763157025
# agent 26 在 99 次迭代中的资源申请量为: -10.628194653988231
# agent 27 在 99 次迭代中的资源申请量为: 457.51683514467834
# agent 28 在 99 次迭代中的资源申请量为: 439.4609162801976
# agent 29 在 99 次迭代中的资源申请量为: 265.2112325742841
# agent 30 在 99 次迭代中的资源申请量为: 34.492100724430614
# agent 31 在 99 次迭代中的资源申请量为: -55.9923281034668
# agent 32 在 99 次迭代中的资源申请量为: -55.50748261305086
# agent 33 在 99 次迭代中的资源申请量为: -333.3080995745541
# agent 34 在 99 次迭代中的资源申请量为: 39.46204420632593
# agent 35 在 99 次迭代中的资源申请量为: 49.977080250393904
# agent 36 在 99 次迭代中的资源申请量为: 310.6441888270623
# agent 37 在 99 次迭代中的资源申请量为: 81.77999104202138
# agent 38 在 99 次迭代中的资源申请量为: -47.481382757328866
# agent 39 在 99 次迭代中的资源申请量为: 1451.1317779725123
# agent 40 在 99 次迭代中的资源申请量为: 317.41908813229617
# agent 41 在 99 次迭代中的资源申请量为: -315.4081187127142
# agent 42 在 99 次迭代中的资源申请量为: -156.1890759662027
# agent 43 在 99 次迭代中的资源申请量为: 325.06545598949964
# agent 44 在 99 次迭代中的资源申请量为: 345.01487220267626
# agent 45 在 99 次迭代中的资源申请量为: 414.6512655360927
# agent 46 在 99 次迭代中的资源申请量为: -267.78310850532324
# agent 47 在 99 次迭代中的资源申请量为: 183.27613880010418
# agent 48 在 99 次迭代中的资源申请量为: 199.45516413686636
# agent 49 在 99 次迭代中的资源申请量为: -254.22013196768626
# agent 50 在 99 次迭代中的资源申请量为: -13.97452246971819
# agent 51 在 99 次迭代中的资源申请量为: 188.8716335387565
# agent 52 在 99 次迭代中的资源申请量为: 188.8716335387565
# agent 53 在 99 次迭代中的资源申请量为: 2.58690661486205
# agent 54 在 99 次迭代中的资源申请量为: -207.52388782718975
# 资源申请量总和为: 7951.195116142402
# ****************************************************************************
# 成本总和为: 101576.9172935768
# ****************************************************************************
# agent 1 在 99 次迭代中的对偶变量为: -17.849220473095926
# agent 2 在 99 次迭代中的对偶变量为: -17.849220473095926
# agent 3 在 99 次迭代中的对偶变量为: -17.84424759636433
# agent 4 在 99 次迭代中的对偶变量为: -17.762917189650587
# agent 5 在 99 次迭代中的对偶变量为: -17.86640182407512
# agent 6 在 99 次迭代中的对偶变量为: -17.86640182407512
# agent 7 在 99 次迭代中的对偶变量为: -17.89987384004494
# agent 8 在 99 次迭代中的对偶变量为: -18.007284666382397
# agent 9 在 99 次迭代中的对偶变量为: -18.199695678758182
# agent 10 在 99 次迭代中的对偶变量为: -17.9943328843819
# agent 11 在 99 次迭代中的对偶变量为: -17.884821629828824
# agent 12 在 99 次迭代中的对偶变量为: -17.960168680378143
# agent 13 在 99 次迭代中的对偶变量为: -17.89771880280898
# agent 14 在 99 次迭代中的对偶变量为: -17.9943083774494
# agent 15 在 99 次迭代中的对偶变量为: -17.906882168531553
# agent 16 在 99 次迭代中的对偶变量为: -17.873608681482864
# agent 17 在 99 次迭代中的对偶变量为: -17.850701977267292
# agent 18 在 99 次迭代中的对偶变量为: -17.76746794458072
# agent 19 在 99 次迭代中的对偶变量为: -18.067869649435863
# agent 20 在 99 次迭代中的对偶变量为: -17.766554766054888
# agent 21 在 99 次迭代中的对偶变量为: -17.459479925522558
# agent 22 在 99 次迭代中的对偶变量为: -17.425267963856935
# agent 23 在 99 次迭代中的对偶变量为: -17.459479925522558
# agent 24 在 99 次迭代中的对偶变量为: -17.496593911140582
# agent 25 在 99 次迭代中的对偶变量为: -17.570507683157818
# agent 26 在 99 次迭代中的对偶变量为: -17.5479182168579
# agent 27 在 99 次迭代中的对偶变量为: -18.029306568364287
# agent 28 在 99 次迭代中的对偶变量为: -17.646882206814585
# agent 29 在 99 次迭代中的对偶变量为: -18.65584430849068
# agent 30 在 99 次迭代中的对偶变量为: -18.638761483136054
# agent 31 在 99 次迭代中的对偶变量为: -18.442612894656385
# agent 32 在 99 次迭代中的对偶变量为: -18.510164477454076
# agent 33 在 99 次迭代中的对偶变量为: -18.830228331681944
# agent 34 在 99 次迭代中的对偶变量为: -18.830228331681944
# agent 35 在 99 次迭代中的对偶变量为: -19.099413254410084
# agent 36 在 99 次迭代中的对偶变量为: -19.644011106988604
# agent 37 在 99 次迭代中的对偶变量为: -19.913567770675748
# agent 38 在 99 次迭代中的对偶变量为: -19.628408865952398
# agent 39 在 99 次迭代中的对偶变量为: -19.466790667835074
# agent 40 在 99 次迭代中的对偶变量为: -19.79136516687744
# agent 41 在 99 次迭代中的对偶变量为: -19.843438848385528
# agent 42 在 99 次迭代中的对偶变量为: -19.88911594301267
# agent 43 在 99 次迭代中的对偶变量为: -19.957673667771616
# agent 44 在 99 次迭代中的对偶变量为: -20.391573470408208
# agent 45 在 99 次迭代中的对偶变量为: -21.906165025410015
# agent 46 在 99 次迭代中的对偶变量为: -22.539204926164686
# agent 47 在 99 次迭代中的对偶变量为: -22.511869153282667
# agent 48 在 99 次迭代中的对偶变量为: -22.92605220190378
# agent 49 在 99 次迭代中的对偶变量为: -23.30692365010109
# agent 50 在 99 次迭代中的对偶变量为: -22.66912603476195
# agent 51 在 99 次迭代中的对偶变量为: -22.655113818592167
# agent 52 在 99 次迭代中的对偶变量为: -22.655113818592167
# agent 53 在 99 次迭代中的对偶变量为: -17.88622480934047
# agent 54 在 99 次迭代中的对偶变量为: -18.885623040754094
# *************************
# 迭代步长为: 5.3865362416062276e-05
# ****************************************************************************
# 119 次迭代中的结果：
# agent 1 在 119 次迭代中的资源申请量为: -58.64574875394789
# agent 2 在 119 次迭代中的资源申请量为: -58.64574875394789
# agent 3 在 119 次迭代中的资源申请量为: -58.64200099791325
# agent 4 在 119 次迭代中的资源申请量为: 234.80888534187665
# agent 5 在 119 次迭代中的资源申请量为: 239.41636324206732
# agent 6 在 119 次迭代中的资源申请量为: -58.488681936501706
# agent 7 在 119 次迭代中的资源申请量为: 11.970515192449293
# agent 8 在 119 次迭代中的资源申请量为: -57.599663839717905
# agent 9 在 119 次迭代中的资源申请量为: -56.321902193134235
# agent 10 在 119 次迭代中的资源申请量为: 244.50830804704032
# agent 11 在 119 次迭代中的资源申请量为: 1225.688271986929
# agent 12 在 119 次迭代中的资源申请量为: -57.93425258400189
# agent 13 在 119 次迭代中的资源申请量为: -58.284416510500385
# agent 14 在 119 次迭代中的资源申请量为: 15.026613316292819
# agent 15 在 119 次迭代中的资源申请量为: -58.15445928149235
# agent 16 在 119 次迭代中的资源申请量为: 11.121259183902303
# agent 17 在 119 次迭代中的资源申请量为: -58.540999531866724
# agent 18 在 119 次迭代中的资源申请量为: -58.97067397721192
# agent 19 在 119 次迭代中的资源申请量为: 19.27638341547952
# agent 20 在 119 次迭代中的资源申请量为: 1190.2076388863845
# agent 21 在 119 次迭代中的资源申请量为: 1135.3464743211382
# agent 22 在 119 次迭代中的资源申请量为: -2.6499247303155005
# agent 23 在 119 次迭代中的资源申请量为: -1.4908683714802418
# agent 24 在 119 次迭代中的资源申请量为: 514.0860409781999
# agent 25 在 119 次迭代中的资源申请量为: 521.3726735498927
# agent 26 在 119 次迭代中的资源申请量为: 1.5137133499718014
# agent 27 在 119 次迭代中的资源申请量为: 469.1859997481894
# agent 28 在 119 次迭代中的资源申请量为: 453.51354103569804
# agent 29 在 119 次迭代中的资源申请量为: 274.91032680837804
# agent 30 在 119 次迭代中的资源申请量为: 36.50806174740185
# agent 31 在 119 次迭代中的资源申请量为: -54.6955261045277
# agent 32 在 119 次迭代中的资源申请量为: -54.237440282029446
# agent 33 在 119 次迭代中的资源申请量为: -329.96376621969085
# agent 34 在 119 次迭代中的资源申请量为: 46.85667878518054
# agent 35 在 119 次迭代中的资源申请量为: 57.40019063037241
# agent 36 在 119 次迭代中的资源申请量为: 319.3151709491549
# agent 37 在 119 次迭代中的资源申请量为: 89.28277256646577
# agent 38 在 119 次迭代中的资源申请量为: -45.71469900560575
# agent 39 在 119 次迭代中的资源申请量为: 1497.5643060095806
# agent 40 在 119 次迭代中的资源申请量为: 327.20934264991587
# agent 41 在 119 次迭代中的资源申请量为: -311.88624183037325
# agent 42 在 119 次迭代中的资源申请量为: -146.33529312333644
# agent 43 在 119 次迭代中的资源申请量为: 333.88524018138304
# agent 44 在 119 次迭代中的资源申请量为: 352.7730145152974
# agent 45 在 119 次迭代中的资源申请量为: 419.08408173660183
# agent 46 在 119 次迭代中的资源申请量为: -266.6191659652289
# agent 47 在 119 次迭代中的资源申请量为: 185.90435944496565
# agent 48 在 119 次迭代中的资源申请量为: 201.34725301276856
# agent 49 在 119 次迭代中的资源申请量为: -253.6459633611785
# agent 50 在 119 次迭代中的资源申请量为: -10.876132498350842
# agent 51 在 119 次迭代中的资源申请量为: 191.288471004509
# agent 52 在 119 次迭代中的资源申请量为: 191.288471004509
# agent 53 在 119 次迭代中的资源申请量为: 11.517094983101577
# agent 54 在 119 次迭代中的资源申请量为: -196.80643125405274
# 资源申请量总和为: 8508.027516518692
# ****************************************************************************
# 成本总和为: 111848.87963180643
# ****************************************************************************
# agent 1 在 119 次迭代中的对偶变量为: -18.072922409107456
# agent 2 在 119 次迭代中的对偶变量为: -18.072922409107456
# agent 3 在 119 次迭代中的对偶变量为: -18.07344456896474
# agent 4 在 119 次迭代中的对偶变量为: -17.994593256185816
# agent 5 在 119 次迭代中的对偶变量为: -18.094805900514963
# agent 6 在 119 次迭代中的对偶变量为: -18.094805900514963
# agent 7 在 119 次迭代中的对偶变量为: -18.126445188926702
# agent 8 在 119 次迭代中的对偶变量为: -18.218669235867463
# agent 9 在 119 次迭代中的对偶变量为: -18.39669465503938
# agent 10 在 119 次迭代中的对偶变量为: -18.205555700023126
# agent 11 在 119 次迭代中的对偶变量为: -18.114129631921575
# agent 12 在 119 次迭代中的对偶变量为: -18.172052324481353
# agent 13 在 119 次迭代中的对偶变量为: -18.123265385258023
# agent 14 在 119 次迭代中的对偶变量为: -18.204681300897096
# agent 15 在 119 次迭代中的对偶变量为: -18.141371806146797
# agent 16 在 119 次迭代中的对偶变量为: -18.1047042351079
# agent 17 在 119 次迭代中的对偶变量为: -18.087516699223137
# agent 18 在 119 次迭代中的对偶变量为: -18.02765187745097
# agent 19 在 119 次迭代中的对偶变量为: -18.313475415436276
# agent 20 在 119 次迭代中的对偶变量为: -18.04527708193242
# agent 21 在 119 次迭代中的对偶变量为: -17.781833769690106
# agent 22 在 119 次迭代中的对偶变量为: -17.752161926903923
# agent 23 在 119 次迭代中的对偶变量为: -17.781833769690106
# agent 24 在 119 次迭代中的对偶变量为: -17.813957160608158
# agent 25 在 119 次迭代中的对偶变量为: -17.878079527239056
# agent 26 在 119 次迭代中的对偶变量为: -17.85875106175928
# agent 27 在 119 次迭代中的对偶变量为: -18.27645947466665
# agent 28 在 119 次迭代中的对偶变量为: -17.944516799136085
# agent 29 在 119 次迭代中的对偶变量为: -18.86679960808222
# agent 30 在 119 次迭代中的对偶变量为: -18.82391943925187
# agent 31 在 119 次迭代中的对偶变量为: -18.623291129960574
# agent 32 在 119 次迭代中的对偶变量为: -18.687114395265965
# agent 33 在 119 次迭代中的对偶变量为: -19.019530976900622
# agent 34 在 119 次迭代中的对偶变量为: -19.019530976900622
# agent 35 在 119 次迭代中的对偶变量为: -19.289444880137534
# agent 36 在 119 次迭代中的对偶变量为: -19.832604968144118
# agent 37 在 119 次迭代中的对偶变量为: -20.105638977701524
# agent 38 在 119 次迭代中的对偶变量为: -19.874553846344973
# agent 39 在 119 次迭代中的对偶变量为: -19.745385836057483
# agent 40 在 119 次迭代中的对偶变量为: -20.00430320263567
# agent 41 在 119 次迭代中的对偶变量为: -20.042791167433556
# agent 42 在 119 次迭代中的对偶变量为: -20.08173769002502
# agent 43 在 119 次迭代中的对偶变量为: -20.14950397394508
# agent 44 在 119 次迭代中的对偶变量为: -20.560313065707717
# agent 45 在 119 次迭代中的对偶变量为: -22.002578777771088
# agent 46 在 119 次迭代中的对偶变量为: -22.605088729704185
# agent 47 在 119 次迭代中的对偶变量为: -22.57915160179112
# agent 48 在 119 次迭代中的对偶变量为: -22.974489677126876
# agent 49 在 119 次迭代中的对偶变量为: -23.339423889903856
# agent 50 在 119 次迭代中的对偶变量为: -22.729693361922237
# agent 51 在 119 次迭代中的对偶变量为: -22.71698485771543
# agent 52 在 119 次迭代中的对偶变量为: -22.71698485771543
# agent 53 在 119 次迭代中的对偶变量为: -18.1148376315674
# agent 54 在 119 次迭代中的对偶变量为: -19.095127881845777
# *************************
# 迭代步长为: 4.087351016895592e-05
# ****************************************************************************
# 139 次迭代中的结果：
# agent 1 在 139 次迭代中的资源申请量为: -57.03646978345286
# agent 2 在 139 次迭代中的资源申请量为: -57.03646978345286
# agent 3 在 139 次迭代中的资源申请量为: -57.00864244797658
# agent 4 在 139 次迭代中的资源申请量为: 245.38179101013313
# agent 5 在 139 次迭代中的资源申请量为: 249.846096931074
# agent 6 在 139 次迭代中的资源申请量为: -56.86050982407549
# agent 7 在 139 次迭代中的资源申请量为: 20.774933692552093
# agent 8 在 139 次迭代中的资源申请量为: -56.05450699259691
# agent 9 在 139 次迭代中的资源申请量为: -54.85438298043599
# agent 10 在 139 次迭代中的资源申请量为: 254.4116554030395
# agent 11 在 139 次迭代中的资源申请量为: 1263.559759294839
# agent 12 在 139 次迭代中的资源申请量为: -56.38266155560865
# agent 13 在 139 次迭代中的资源申请量为: -56.67047910341854
# agent 14 在 139 次迭代中的资源申请量为: 23.419334147813384
# agent 15 在 139 次迭代中的资源申请量为: -56.50354856121891
# agent 16 在 139 次迭代中的资源申请量为: 20.0425030937805
# agent 17 在 139 次迭代中的资源申请量为: -56.87540845919646
# agent 18 在 139 次迭代中的资源申请量为: -57.19775349179366
# agent 19 在 139 次迭代中的资源申请量为: 28.435561791535083
# agent 20 在 139 次迭代中的资源申请量为: 1243.9495102822323
# agent 21 在 139 次迭代中的资源申请量为: 1195.3395462682438
# agent 22 在 139 次迭代中的资源申请量为: 8.725815995054841
# agent 23 在 139 次迭代中的资源申请量为: 9.762519577347916
# agent 24 在 139 次迭代中的资源申请量为: 546.4207514690767
# agent 25 在 139 次迭代中的资源申请量为: 552.9271952899368
# agent 26 在 139 次迭代中的资源申请量为: 12.447452982529278
# agent 27 在 139 次迭代中的资源申请量为: 480.3138208772066
# agent 28 在 139 次迭代中的资源申请量为: 466.29732931974814
# agent 29 在 139 次迭代中的资源申请量为: 284.3813326041353
# agent 30 在 139 次迭代中的资源申请量为: 38.5938884122408
# agent 31 在 139 次迭代中的资源申请量为: -53.31822143387462
# agent 32 在 139 次迭代中的资源申请量为: -52.881893818277106
# agent 33 在 139 次迭代中的资源申请量为: -326.5869591825859
# agent 34 在 139 次迭代中的资源申请量为: 54.32311571987938
# agent 35 在 139 次迭代中的资源申请量为: 64.72635015379382
# agent 36 在 139 次迭代中的资源申请量为: 327.51130126742015
# agent 37 在 139 次迭代中的资源申请量为: 96.18615606716202
# agent 38 在 139 次迭代中的资源申请量为: -44.181056051311224
# agent 39 在 139 次迭代中的资源申请量为: 1536.8209158093396
# agent 40 在 139 次迭代中的资源申请量为: 336.0156942563446
# agent 41 在 139 次迭代中的资源申请量为: -308.6563216365586
# agent 42 在 139 次迭代中的资源申请量为: -137.2255626752782
# agent 43 在 139 次迭代中的资源申请量为: 341.98421737879124
# agent 44 在 139 次迭代中的资源申请量为: 359.92196651350804
# agent 45 在 139 次迭代中的资源申请量为: 423.19208111210526
# agent 46 在 139 次迭代中的资源申请量为: -265.531013639537
# agent 47 在 139 次迭代中的资源申请量为: 188.35886855114057
# agent 48 在 139 次迭代中的资源申请量为: 203.11613836592772
# agent 49 在 139 次迭代中的资源申请量为: -253.1170084480687
# agent 50 在 139 次迭代中的资源申请量为: -7.98726409800466
# agent 51 在 139 次迭代中的资源申请量为: 193.5333611866506
# agent 52 在 139 次迭代中的资源申请量为: 193.5333611866506
# agent 53 在 139 次迭代中的资源申请量为: 20.375911834760867
# agent 54 在 139 次迭代中的资源申请量为: -186.49445072590063
# 资源申请量总和为: 9026.169653153369
# ****************************************************************************
# 成本总和为: 121531.54230127893
# ****************************************************************************
# agent 1 在 139 次迭代中的对偶变量为: -18.297136810950647
# agent 2 在 139 次迭代中的对偶变量为: -18.297136810950647
# agent 3 在 139 次迭代中的对偶变量为: -18.301013882293216
# agent 4 在 139 次迭代中的对偶变量为: -18.224553954470395
# agent 5 在 139 次迭代中的对偶变量为: -18.321652608250858
# agent 6 在 139 次迭代中的对偶变量为: -18.321652608250858
# agent 7 在 139 次迭代中的对偶变量为: -18.351838302529334
# agent 8 在 139 次迭代中的对偶变量为: -18.433949758749442
# agent 9 在 139 次迭代中的对偶变量为: -18.601158236867775
# agent 10 在 139 次迭代中的对偶变量为: -18.420953505016108
# agent 11 在 139 次迭代中的对偶变量为: -18.341358555769034
# agent 12 在 139 次迭代中的对偶变量为: -18.38822929610327
# agent 13 在 139 次迭代中的对偶变量为: -18.34812882843711
# agent 14 在 139 次迭代中的对偶变量为: -18.419534954184023
# agent 15 在 139 次迭代中的对偶变量为: -18.371386593159613
# agent 16 在 139 次迭代中的对偶变量为: -18.33308807920078
# agent 17 在 139 次迭代中的对偶变量为: -18.319576841013994
# agent 18 在 139 次迭代中的对偶变量为: -18.274665797002356
# agent 19 在 139 次迭代中的对偶变量为: -18.5479503818633
# agent 20 在 139 次迭代中的对偶变量为: -18.30334554837528
# agent 21 在 139 次迭代中的对偶变量为: -18.069920501180107
# agent 22 在 139 次迭代中的对偶变量为: -18.043380889473404
# agent 23 在 139 次迭代中的对偶变量为: -18.069920501180107
# agent 24 在 139 次迭代中的对偶变量为: -18.098502612927874
# agent 25 在 139 次迭代中的对偶变量为: -18.155759318551443
# agent 26 在 139 次迭代中的对偶变量为: -18.13865479635275
# agent 27 在 139 次迭代中的对偶变量为: -18.512146726179235
# agent 28 在 139 次迭代中的对偶变量为: -18.215277434992267
# agent 29 在 139 次迭代中的对偶变量为: -19.072793984139942
# agent 30 在 139 次迭代中的对偶变量为: -19.01549427511067
# agent 31 在 139 次迭代中的对偶变量为: -18.815185480503985
# agent 32 在 139 次迭代中的对偶变量为: -18.875977261874723
# agent 33 在 139 次迭代中的对偶变量为: -19.210671762428913
# agent 34 在 139 次迭代中的对偶变量为: -19.210671762428913
# agent 35 在 139 次迭代中的对偶变量为: -19.476994563937122
# agent 36 在 139 次迭代中的对偶变量为: -20.010870802566387
# agent 37 在 139 次迭代中的对偶变量为: -20.282365595319348
# agent 38 在 139 次迭代中的对偶变量为: -20.088230184595012
# agent 39 在 139 次迭代中的对偶变量为: -19.980925494856038
# agent 40 在 139 次迭代中的对偶变量为: -20.195841350075494
# agent 41 在 139 次迭代中的对偶变量为: -20.225617570084243
# agent 42 在 139 次迭代中的对偶变量为: -20.25981470082366
# agent 43 在 139 次迭代中的对偶变量为: -20.325656727988708
# agent 44 在 139 次迭代中的对偶变量为: -20.7158027716688
# agent 45 在 139 次迭代中的对偶变量为: -22.091927764188288
# agent 46 在 139 次迭代中的对偶变量为: -22.66668250394765
# agent 47 在 139 次迭代中的对偶变量为: -22.6419870349092
# agent 48 在 139 次迭代中的对偶变量为: -23.01977314216775
# agent 49 在 139 次迭代中的对偶变量为: -23.36936485380552
# agent 50 在 139 次迭代中的对偶变量为: -22.786164961412204
# agent 51 在 139 次迭代中的对偶变量为: -22.774454046378256
# agent 52 在 139 次迭代中的对偶变量为: -22.774454046378256
# agent 53 在 139 次迭代中的对偶变量为: -18.34162334296988
# agent 54 在 139 次迭代中的对偶变量为: -19.296706477210094
# *************************
# 迭代步长为: 3.237726633057685e-05
# ****************************************************************************
# 159 次迭代中的结果：
# agent 1 在 159 次迭代中的资源申请量为: -55.44607259565914
# agent 2 在 159 次迭代中的资源申请量为: -55.44607259565914
# agent 3 在 159 次迭代中的资源申请量为: -55.40311809545952
# agent 4 在 159 次迭代中的资源申请量为: 255.78266828812107
# agent 5 在 159 次迭代中的资源申请量为: 260.09709131313593
# agent 6 在 159 次迭代中的资源申请量为: -55.26024047155086
# agent 7 在 159 次迭代中的资源申请量为: 29.433519462396667
# agent 8 在 159 次迭代中的资源申请量为: -54.51652830503516
# agent 9 在 159 次迭代中的资源申请量为: -53.38092389925975
# agent 10 在 159 次迭代中的资源申请量为: 264.27638340010276
# agent 11 在 159 次迭代中的资源申请量为: 1300.7234861881284
# agent 12 在 159 次迭代中的资源申请量为: -54.8362321718128
# agent 13 在 159 次迭代中的资源申请量为: -55.08138841235786
# agent 14 在 159 次迭代中的资源申请量为: 31.786740487546176
# agent 15 在 159 次迭代中的资源申请量为: -54.89339284939981
# agent 16 在 159 次迭代中的资源申请量为: 28.78467665018855
# agent 17 在 159 次迭代中的资源申请量为: -55.25124391605055
# agent 18 在 159 次迭代中的资源申请量为: -55.50153629737992
# agent 19 在 159 次迭代中的资源申请量为: 37.21646564867106
# agent 20 在 159 次迭代中的资源申请量为: 1294.5428323653423
# agent 21 在 159 次迭代中的资源申请量为: 1250.5368288379823
# agent 22 在 159 次迭代中的资源申请量为: 19.170156151729067
# agent 23 在 159 次迭代中的资源申请量为: 20.116322346874632
# agent 24 在 159 次迭代中的资源申请量为: 576.2382876747204
# agent 25 在 159 次迭代中的资源申请量为: 582.1617079601368
# agent 26 在 159 次迭代中的资源申请量为: 22.560716568547356
# agent 27 在 159 次迭代中的资源申请量为: 490.9821870770787
# agent 28 在 159 次迭代中的资源申请量为: 478.2006688076346
# agent 29 在 159 次迭代中的资源申请量为: 293.56303965032953
# agent 30 在 159 次迭代中的资源申请量为: 40.67962022713591
# agent 31 在 159 次迭代中的资源申请量为: -51.921636454816465
# agent 32 在 159 次迭代中的资源申请量为: -51.50473706703984
# agent 33 在 159 次迭代中的资源申请量为: -323.25582076076404
# agent 34 在 159 次迭代中的资源申请量为: 61.688575064754446
# agent 35 在 159 次迭代中的资源申请量为: 71.85910597637623
# agent 36 在 159 次迭代中的资源申请量为: 335.29086030900476
# agent 37 在 159 次迭代中的资源申请量为: 102.61849048486579
# agent 38 在 159 次迭代中的资源申请量为: -42.8084029219609
# agent 39 在 159 次迭代中的资源申请量为: 1571.29606158049
# agent 40 在 159 次迭代中的资源申请量为: 344.0840463996996
# agent 41 在 159 次迭代中的资源申请量为: -305.66190539480635
# agent 42 在 159 次迭代中的资源申请量为: -128.73576444806105
# agent 43 在 159 次迭代中的资源申请量为: 349.5123808471511
# agent 44 在 159 次迭代中的资源申请量为: 366.590101231719
# agent 45 在 159 次迭代中的资源申请量为: 427.03805341030517
# agent 46 在 159 次迭代中的资源申请量为: -264.50688248329425
# agent 47 在 159 次迭代中的资源申请量为: 190.66729564496313
# agent 48 在 159 次迭代中的资源申请量为: 204.78095179270267
# agent 49 在 159 次迭代中的资源申请量为: -252.6236621447729
# agent 50 在 159 次迭代中的资源申请量为: -5.271555081536149
# agent 51 在 159 次迭代中的资源申请量为: 195.63918470818106
# agent 52 在 159 次迭代中的资源申请量为: 195.63918470818106
# agent 53 在 159 次迭代中的资源申请量为: 29.07467474813949
# agent 54 在 159 次迭代中的资源申请量为: -176.58303920543216
# 资源申请量总和为: 9514.742210440227
# ****************************************************************************
# 成本总和为: 130770.07287219111
# ****************************************************************************
# agent 1 在 159 次迭代中的对偶变量为: -18.518720489537195
# agent 2 在 159 次迭代中的对偶变量为: -18.518720489537195
# agent 3 在 159 次迭代中的对偶变量为: -18.524705168232007
# agent 4 在 159 次迭代中的对偶变量为: -18.450773035266632
# agent 5 在 159 次迭代中的对偶变量为: -18.544611736060705
# agent 6 在 159 次迭代中的对偶变量为: -18.544611736060705
# agent 7 在 159 次迭代中的对偶变量为: -18.573498098237355
# agent 8 在 159 次迭代中的对偶变量为: -18.64823017737267
# agent 9 在 159 次迭代中的对偶变量为: -18.806449396811736
# agent 10 在 159 次迭代中的对偶变量为: -18.635511338952234
# agent 11 在 159 次迭代中的对偶变量为: -18.56434091712877
# agent 12 在 159 次迭代中的对偶变量为: -18.60368711643001
# agent 13 在 159 次迭代中的对偶变量为: -18.56953047805983
# agent 14 在 159 次迭代中的对偶变量为: -18.633740556481182
# agent 15 在 159 次迭代中的对偶变量为: -18.595723147864522
# agent 16 在 159 次迭代中的对偶变量为: -18.556887722244827
# agent 17 在 159 次迭代中的对偶变量为: -18.54586519015234
# agent 18 在 159 次迭代中的对偶变量为: -18.510992953831245
# agent 19 在 159 次迭代中的对偶变量为: -18.77274152060598
# agent 20 在 159 次迭代中的对偶变量为: -18.546294681018374
# agent 21 在 159 次迭代中的对偶变量为: -18.33497785207999
# agent 22 在 159 次迭代中的对偶变量为: -18.310755997484264
# agent 23 在 159 次迭代中的对偶变量为: -18.33497785207999
# agent 24 在 159 次迭代中的对偶变量为: -18.36089693153754
# agent 25 在 159 次迭代中的对偶变量为: -18.413023030049203
# agent 26 在 159 次迭代中的对偶变量为: -18.397554344154813
# agent 27 在 159 次迭代中的对偶变量为: -18.738102722292528
# agent 28 在 159 次迭代中的对偶变量为: -18.4673901653457
# agent 29 在 159 次迭代中的对偶变量为: -19.272496112394666
# agent 30 在 159 次迭代中的对偶变量为: -19.207060399381525
# agent 31 在 159 次迭代中的对偶变量为: -19.00976607929624
# agent 32 在 159 次迭代中的对偶变量为: -19.067851003397607
# agent 33 在 159 次迭代中的对偶变量为: -19.399227521657714
# agent 34 在 159 次迭代中的对偶变量为: -19.399227521657714
# agent 35 在 159 次迭代中的对偶变量为: -19.659593112995232
# agent 36 在 159 次迭代中的对偶变量为: -20.180076211720852
# agent 37 在 159 次迭代中的对偶变量为: -20.447033356412565
# agent 38 在 159 次迭代中的对偶变量为: -20.279476454494876
# agent 39 在 159 次迭代中的对偶变量为: -20.18777636948294
# agent 40 在 159 次迭代中的对偶变量为: -20.371328009193466
# agent 41 在 159 次迭代中的对偶变量为: -20.395113507032384
# agent 42 在 159 次迭代中的对偶变量为: -20.425773276569302
# agent 43 在 159 次迭代中的对偶变量为: -20.489394283425536
# agent 44 在 159 次迭代中的对偶变量为: -20.860834701789887
# agent 45 在 159 次迭代中的对偶变量为: -22.175577661674136
# agent 46 在 159 次迭代中的对偶变量为: -22.724652423915614
# agent 47 在 159 次迭代中的对偶变量为: -22.701082768511057
# agent 48 在 159 次迭代中的对偶变量为: -23.06239236589319
# agent 49 在 159 次迭代中的对偶变量为: -23.397290227957278
# agent 50 在 159 次迭代中的对偶变量为: -22.83925164126613
# agent 51 在 159 次迭代中的对偶变量为: -22.828363128529435
# agent 52 在 159 次迭代中的对偶变量为: -22.828363128529435
# agent 53 在 159 次迭代中的对偶变量为: -18.56431167355237
# agent 54 在 159 次迭代中的对偶变量为: -19.490454749612212
# *************************
# 迭代步长为: 2.6464682716040347e-05
# ****************************************************************************
# 179 次迭代中的结果：
# agent 1 在 179 次迭代中的资源申请量为: -53.88909300602562
# agent 2 在 179 次迭代中的资源申请量为: -53.88909300602562
# agent 3 在 179 次迭代中的资源申请量为: -53.83653175433723
# agent 4 在 179 次迭代中的资源申请量为: 265.93873229718326
# agent 5 在 179 次迭代中的资源申请量为: 270.09818870566255
# agent 6 在 179 次迭代中的资源申请量为: -53.698982211876036
# agent 7 在 179 次迭代中的资源申请量为: 37.882981605168034
# agent 8 在 179 次迭代中的资源申请量为: -53.005439034118524
# agent 9 在 179 次迭代中的资源申请量为: -51.92661646776067
# agent 10 在 179 次迭代中的资源申请量为: 273.9727910014736
# agent 11 在 179 次迭代中的资源申请量为: 1336.9418331882127
# agent 12 在 179 次迭代中的资源申请量为: -53.31547348979091
# agent 13 在 179 次迭代中的资源申请量为: -53.52962227006874
# agent 14 在 179 次迭代中的资源申请量为: 40.01609363385061
# agent 15 在 179 次迭代中的资源申请量为: -53.330181503792694
# agent 16 在 179 次迭代中的资源申请量为: 37.2976716455603
# agent 17 在 179 次迭代中的资源申请量为: -53.67435466610676
# agent 18 在 179 次迭代中的资源申请量为: -53.87408904611053
# agent 19 在 179 次迭代中的资源申请量为: 45.647453237121354
# agent 20 在 179 次迭代中的资源申请量为: 1342.5775913202956
# agent 21 在 179 次迭代中的资源申请量为: 1302.1643655030955
# agent 22 在 179 次迭代中的资源申请量为: 28.92557288876024
# agent 23 在 179 次迭代中的资源申请量为: 29.800518872885316
# agent 24 在 179 次迭代中的资源申请量为: 604.171256954125
# agent 25 在 179 次迭代中的资源申请量为: 609.6342418157824
# agent 26 在 179 次迭代中的资源申请量为: 32.05426619810769
# agent 27 在 179 次迭代中的资源申请量为: 501.2282954294877
# agent 28 在 179 次迭代中的资源申请量为: 489.42304596065514
# agent 29 在 179 次迭代中的资源申请量为: 302.4322541735256
# agent 30 在 179 次迭代中的资源申请量为: 42.73143060021301
# agent 31 在 179 次迭代中的资源申请量为: -50.536379102947286
# agent 32 在 179 次迭代中的资源申请量为: -50.1375472962587
# agent 33 在 179 次迭代中的资源申请量为: -320.00570085935857
# agent 34 在 179 次迭代中的资源申请量为: 68.87489486550268
# agent 35 在 179 次迭代中的资源申请量为: 78.7614025115696
# agent 36 在 179 次迭代中的资源申请量为: 342.69931504669
# agent 37 在 179 次迭代中的资源申请量为: 108.665043139108
# agent 38 在 179 次迭代中的资源申请量为: -41.554288182751044
# ...
# agent 61 在 57999 次迭代中的资源申请量为: 45.35594989347403
# agent 62 在 57999 次迭代中的资源申请量为: 37.777916501990724
# agent 63 在 57999 次迭代中的资源申请量为: 44.36024833408177
# agent 64 在 57999 次迭代中的资源申请量为: 50.59248382563158
# agent 65 在 57999 次迭代中的资源申请量为: 48.719342447654434
# agent 66 在 57999 次迭代中的资源申请量为: 53.47780999250294
# agent 67 在 57999 次迭代中的资源申请量为: 44.62937911116489
# agent 68 在 57999 次迭代中的资源申请量为: 38.64566746179317
# agent 69 在 57999 次迭代中的资源申请量为: 49.892139157742264
# agent 70 在 57999 次迭代中的资源申请量为: 43.38409217370307
# agent 71 在 57999 次迭代中的资源申请量为: 51.072439614453316
# agent 72 在 57999 次迭代中的资源申请量为: 51.63101181607402
# agent 73 在 57999 次迭代中的资源申请量为: 68.52493850742536
# agent 74 在 57999 次迭代中的资源申请量为: 63.033563690013715
# agent 75 在 57999 次迭代中的资源申请量为: 68.784860310892
# agent 76 在 57999 次迭代中的资源申请量为: 65.84231131075826
# agent 77 在 57999 次迭代中的资源申请量为: 37.33178559067635
# agent 78 在 57999 次迭代中的资源申请量为: 56.51515954674519
# agent 79 在 57999 次迭代中的资源申请量为: 35.71319766839764
# agent 80 在 57999 次迭代中的资源申请量为: 41.69438982489503
# agent 81 在 57999 次迭代中的资源申请量为: 64.43288578237497
# agent 82 在 57999 次迭代中的资源申请量为: 45.64920279686928
# agent 83 在 57999 次迭代中的资源申请量为: 54.00548947849253
# agent 84 在 57999 次迭代中的资源申请量为: 52.98642785861979
# agent 85 在 57999 次迭代中的资源申请量为: 58.685757530611916
# agent 86 在 57999 次迭代中的资源申请量为: 54.16278250297388
# agent 87 在 57999 次迭代中的资源申请量为: 50.183947875573004
# agent 88 在 57999 次迭代中的资源申请量为: 53.40486804038364
# agent 89 在 57999 次迭代中的资源申请量为: 44.037016821613456
# agent 90 在 57999 次迭代中的资源申请量为: 38.995841039652966
# agent 91 在 57999 次迭代中的资源申请量为: 43.58677066582213
# agent 92 在 57999 次迭代中的资源申请量为: 45.25809138455365
# agent 93 在 57999 次迭代中的资源申请量为: 35.68321481266967
# agent 94 在 57999 次迭代中的资源申请量为: 37.48060785879904
# 资源申请量平均值avg为: 49.99999999999654
# ****************************************************************************
# 平均成本为: 3240.481984531225
# ****************************************************************************
# agent 1 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 2 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 3 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 4 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 5 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 6 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 7 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 8 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 9 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 10 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 11 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 12 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 13 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 14 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 15 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 16 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 17 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 18 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 19 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 20 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 21 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 22 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 23 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 24 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 25 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 26 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 27 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 28 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 29 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 30 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 31 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 32 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 33 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 34 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 35 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 36 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 37 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 38 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 39 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 40 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 41 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 42 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 43 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 44 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 45 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 46 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 47 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 48 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 49 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 50 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 51 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 52 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 53 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 54 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 55 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 56 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 57 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 58 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 59 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 60 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 61 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 62 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 63 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 64 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 65 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 66 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 67 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 68 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 69 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 70 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 71 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 72 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 73 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 74 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 75 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 76 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 77 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 78 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 79 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 80 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 81 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 82 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 83 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 84 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 85 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 86 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 87 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 88 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 89 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 90 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 91 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 92 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 93 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 94 在 57999 次迭代中的对偶变量为: -135.14386653834575
# *************************
# 迭代步长为: 0.11151053484837568
# ****************************************************************************
# 59999 次迭代中的结果：
# agent 1 在 59999 次迭代中的资源申请量为: 56.19880558172988
# agent 2 在 59999 次迭代中的资源申请量为: 56.03871203978166
# agent 3 在 59999 次迭代中的资源申请量为: 60.64796214442871
# agent 4 在 59999 次迭代中的资源申请量为: 37.93333499802675
# agent 5 在 59999 次迭代中的资源申请量为: 57.56693686702461
# agent 6 在 59999 次迭代中的资源申请量为: 55.34212747123894
# agent 7 在 59999 次迭代中的资源申请量为: 65.6236567946489
# agent 8 在 59999 次迭代中的资源申请量为: 46.330946703602365
# agent 9 在 59999 次迭代中的资源申请量为: 65.64268770463663
# agent 10 在 59999 次迭代中的资源申请量为: 54.23914303693835
# agent 11 在 59999 次迭代中的资源申请量为: 65.4520437985654
# agent 12 在 59999 次迭代中的资源申请量为: 38.406222330358624
# agent 13 在 59999 次迭代中的资源申请量为: 49.70058714461363
# agent 14 在 59999 次迭代中的资源申请量为: 41.3659905551611
# agent 15 在 59999 次迭代中的资源申请量为: 42.48853939614691
# agent 16 在 59999 次迭代中的资源申请量为: 49.24530133808371
# agent 17 在 59999 次迭代中的资源申请量为: 50.11852704992918
# agent 18 在 59999 次迭代中的资源申请量为: 46.537297422347486
# agent 19 在 59999 次迭代中的资源申请量为: 44.77392156663175
# agent 20 在 59999 次迭代中的资源申请量为: 50.80339666473046
# agent 21 在 59999 次迭代中的资源申请量为: 69.93387670557085
# agent 22 在 59999 次迭代中的资源申请量为: 61.24199691647269
# agent 23 在 59999 次迭代中的资源申请量为: 61.627787986086716
# agent 24 在 59999 次迭代中的资源申请量为: 39.861352301782716
# agent 25 在 59999 次迭代中的资源申请量为: 52.95065687328203
# agent 26 在 59999 次迭代中的资源申请量为: 49.39633437684004
# agent 27 在 59999 次迭代中的资源申请量为: 47.51919637207136
# agent 28 在 59999 次迭代中的资源申请量为: 40.7413613830987
# agent 29 在 59999 次迭代中的资源申请量为: 44.38273034135506
# agent 30 在 59999 次迭代中的资源申请量为: 39.891745956789116
# agent 31 在 59999 次迭代中的资源申请量为: 65.76280653244551
# agent 32 在 59999 次迭代中的资源申请量为: 59.51901541924079
# agent 33 在 59999 次迭代中的资源申请量为: 48.23750867799392
# agent 34 在 59999 次迭代中的资源申请量为: 36.76532342510125
# agent 35 在 59999 次迭代中的资源申请量为: 41.086702696803464
# agent 36 在 59999 次迭代中的资源申请量为: 62.20889044924783
# agent 37 在 59999 次迭代中的资源申请量为: 40.47023795026076
# agent 38 在 59999 次迭代中的资源申请量为: 58.24733429492913
# agent 39 在 59999 次迭代中的资源申请量为: 37.39554726071002
# agent 40 在 59999 次迭代中的资源申请量为: 50.45313221045784
# agent 41 在 59999 次迭代中的资源申请量为: 36.73569742369616
# agent 42 在 59999 次迭代中的资源申请量为: 56.24242387150355
# agent 43 在 59999 次迭代中的资源申请量为: 61.52373322591861
# agent 44 在 59999 次迭代中的资源申请量为: 47.51525622305313
# agent 45 在 59999 次迭代中的资源申请量为: 41.36197014706921
# agent 46 在 59999 次迭代中的资源申请量为: 67.10436077257359
# agent 47 在 59999 次迭代中的资源申请量为: 65.57090570810219
# agent 48 在 59999 次迭代中的资源申请量为: 40.83836334458436
# agent 49 在 59999 次迭代中的资源申请量为: 39.16390664937778
# agent 50 在 59999 次迭代中的资源申请量为: 63.292999181236645
# agent 51 在 59999 次迭代中的资源申请量为: 36.39727688961264
# agent 52 在 59999 次迭代中的资源申请量为: 46.86937779818014
# agent 53 在 59999 次迭代中的资源申请量为: 43.572511920796444
# agent 54 在 59999 次迭代中的资源申请量为: 49.58201107681077
# agent 55 在 59999 次迭代中的资源申请量为: 47.173391517077015
# agent 56 在 59999 次迭代中的资源申请量为: 42.97971616155657
# agent 57 在 59999 次迭代中的资源申请量为: 36.90486251978384
# agent 58 在 59999 次迭代中的资源申请量为: 59.2566799113546
# agent 59 在 59999 次迭代中的资源申请量为: 59.891586060534515
# agent 60 在 59999 次迭代中的资源申请量为: 40.34169962872796
# agent 61 在 59999 次迭代中的资源申请量为: 45.35594989347582
# agent 62 在 59999 次迭代中的资源申请量为: 37.77791650199216
# agent 63 在 59999 次迭代中的资源申请量为: 44.360248334083515
# agent 64 在 59999 次迭代中的资源申请量为: 50.59248382563358
# agent 65 在 59999 次迭代中的资源申请量为: 48.71934244765636
# agent 66 在 59999 次迭代中的资源申请量为: 53.47780999250507
# agent 67 在 59999 次迭代中的资源申请量为: 44.62937911116663
# agent 68 在 59999 次迭代中的资源申请量为: 38.64566746179467
# agent 69 在 59999 次迭代中的资源申请量为: 49.89213915774424
# agent 70 在 59999 次迭代中的资源申请量为: 43.384092173704765
# agent 71 在 59999 次迭代中的资源申请量为: 51.07243961445531
# agent 72 在 59999 次迭代中的资源申请量为: 51.63101181607605
# agent 73 在 59999 次迭代中的资源申请量为: 68.52493850742809
# agent 74 在 59999 次迭代中的资源申请量为: 63.033563690016244
# agent 75 在 59999 次迭代中的资源申请量为: 68.78486031089474
# agent 76 在 59999 次迭代中的资源申请量为: 65.84231131076093
# agent 77 在 59999 次迭代中的资源申请量为: 37.33178559067781
# agent 78 在 59999 次迭代中的资源申请量为: 56.51515954674745
# agent 79 在 59999 次迭代中的资源申请量为: 35.713197668399026
# agent 80 在 59999 次迭代中的资源申请量为: 41.69438982489667
# agent 81 在 59999 次迭代中的资源申请量为: 64.43288578237754
# agent 82 在 59999 次迭代中的资源申请量为: 45.64920279687104
# agent 83 在 59999 次迭代中的资源申请量为: 54.00548947849467
# agent 84 在 59999 次迭代中的资源申请量为: 52.98642785862186
# agent 85 在 59999 次迭代中的资源申请量为: 58.685757530614225
# agent 86 在 59999 次迭代中的资源申请量为: 54.16278250297603
# agent 87 在 59999 次迭代中的资源申请量为: 50.18394787557497
# agent 88 在 59999 次迭代中的资源申请量为: 53.40486804038577
# agent 89 在 59999 次迭代中的资源申请量为: 44.03701682161516
# agent 90 在 59999 次迭代中的资源申请量为: 38.99584103965445
# agent 91 在 59999 次迭代中的资源申请量为: 43.58677066582381
# agent 92 在 59999 次迭代中的资源申请量为: 45.258091384555385
# agent 93 在 59999 次迭代中的资源申请量为: 35.68321481267107
# agent 94 在 59999 次迭代中的资源申请量为: 37.4806078588005
# 资源申请量平均值avg为: 49.9999999999985
# ****************************************************************************
# 平均成本为: 3240.4819845314896
# ****************************************************************************
# agent 1 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 2 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 3 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 4 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 5 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 6 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 7 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 8 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 9 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 10 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 11 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 12 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 13 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 14 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 15 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 16 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 17 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 18 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 19 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 20 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 21 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 22 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 23 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 24 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 25 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 26 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 27 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 28 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 29 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 30 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 31 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 32 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 33 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 34 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 35 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 36 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 37 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 38 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 39 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 40 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 41 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 42 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 43 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 44 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 45 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 46 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 47 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 48 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 49 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 50 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 51 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 52 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 53 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 54 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 55 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 56 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 57 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 58 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 59 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 60 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 61 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 62 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 63 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 64 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 65 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 66 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 67 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 68 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 69 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 70 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 71 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 72 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 73 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 74 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 75 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 76 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 77 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 78 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 79 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 80 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 81 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 82 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 83 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 84 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 85 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 86 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 87 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 88 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 89 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 90 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 91 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 92 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 93 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 94 在 59999 次迭代中的对偶变量为: -135.1438665383513
# *************************
# 迭代步长为: 0.11075700351730201
# ****************************************************************************
# 2023-05-29 15:40:13.737

# %%
np.savetxt('../data/01-DGD-agent_resource_quantity_large_value_deterministic_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/01-DGD-sum_cost_large_value_deterministic_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/01-DGD-sum_resource_large_value_deterministic_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
