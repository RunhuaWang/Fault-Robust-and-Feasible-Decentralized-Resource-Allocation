# %% [markdown]
# DGD+部分用户的对偶计算有误差
# 为了对比实验的公平性 要保证噪声的效果和IWDGD算法中噪声的效果尽可能一致
# 主要是观察噪声对对偶变量的影响是否一致

# %% [markdown]
# IWDGD中小值的确定性噪声 对应到DGD算法中是固定的对偶攻击值为-18.6 这样两个算法各自迭代2000次 所有用户的对偶迭代值均在-18.57附近

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(54,2000)) 
dual_variable = np.zeros(shape=(54,2000))#对偶变量
sum_resource=np.zeros(shape=(1,2000), dtype=np.float64)
sum_cost=np.zeros(shape=(1,2000), dtype=np.float64)
iteration_update = 0.01 #迭代步长
#W=np.zeros(shape=(54,54)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
W=np.loadtxt("double_stochastic_weight_1.txt") #双随机的网络拓扑矩阵W（对角线处非零）
iteration=[]#绘图横坐标
generator_a_values= np.loadtxt("generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("generator_b_values.txt")#每个agent的成本函数中的超参数a
generator_c_values= np.loadtxt("generator_c_values.txt")#每个agent的成本函数中的超参数a

# %%
'''for i in range(0,54):
    for j in range(0,54):
        W[i][j]=1/54'''

#对偶变量的初始化 初始化一致
for i in range (0,54):
    dual_variable[i][0]=0
    
#资源量的初始化 资源量的初始化需要和对偶变量的初始值满足某种关系
for i in range (0,54):
    agent_resource_quantity[i][0]=6000/54

iteration.append(0)

#总资源量 初始化
sum=0
for i in range (0,54):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

#用户总成本初始化
sum=0
for i in range(0,54):
    sum=sum+(generator_c_values[i]*(agent_resource_quantity[i][0])*(agent_resource_quantity[i][0])+generator_b_values[i]*agent_resource_quantity[i][0]+generator_a_values[i])
sum_cost[0][0]=sum

# %%
#DGD算法 
def DGD_determinitic_bias(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,dual_variable,iteration_update,W,iteration):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************DGD算法+无计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,54):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    for i in range(0,54):
        print("agent",(i+1),"的初始对偶变量为:",dual_variable[i][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,2000):#迭代次数
        iteration.append(k)
        
        #所有用户对偶变量的迭代 
        #阶段一：梯度下降
        dual_variable_intermediate=[] #存放当前迭代中100个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,54):
            #每个用户对对偶变量先进行一次梯度下降
            if i==48:
                dual_variable_intermediate.append(-18.6)
            else:
                dual_variable_intermediate.append(dual_variable[i][k-1]-iteration_update*((6000/54)-agent_resource_quantity[i][k-1]))       
        #阶段二：聚合 每个用户聚合自身以及邻居的对偶值   
        for i in range(0,54):
            mix_sum_dual=0
            for j in range(0,54):
                if W[i][j]!=0:
                    mix_sum_dual=mix_sum_dual+W[i][j]*dual_variable_intermediate[j]
            dual_variable[i][k]=mix_sum_dual                    
        
        #用户资源申请量的迭代
        for i in range (0,54):
            agent_resource_quantity[i][k]=(-dual_variable[i][k]-generator_b_values[i])/(2*generator_c_values[i]) 

        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,54):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,54):
            sum2=sum2+(generator_a_values[i]+(generator_b_values[i]*agent_resource_quantity[i][k])+(generator_c_values[i]*agent_resource_quantity[i][k]*agent_resource_quantity[i][k]))
        sum_cost[0][k]=sum2
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%20==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,54):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            for i in range(0,54):
                print("agent",(i+1),"在",k,"次迭代中的对偶变量为:",dual_variable[i][k])   
            print("*************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=(1/(pow(k+1,1.3)))*(1/26.511) #递减步长
        iteration_update=(1/(pow(k+1,1.5)))*(1/18.8468) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
DGD_determinitic_bias(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,dual_variable,iteration_update,W,iteration)
# Out:
# ****************************DGD算法+无计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 111.11111111111111
# agent 2 的初始资源申请量为: 111.11111111111111
# agent 3 的初始资源申请量为: 111.11111111111111
# agent 4 的初始资源申请量为: 111.11111111111111
# agent 5 的初始资源申请量为: 111.11111111111111
# agent 6 的初始资源申请量为: 111.11111111111111
# agent 7 的初始资源申请量为: 111.11111111111111
# agent 8 的初始资源申请量为: 111.11111111111111
# agent 9 的初始资源申请量为: 111.11111111111111
# agent 10 的初始资源申请量为: 111.11111111111111
# agent 11 的初始资源申请量为: 111.11111111111111
# agent 12 的初始资源申请量为: 111.11111111111111
# agent 13 的初始资源申请量为: 111.11111111111111
# agent 14 的初始资源申请量为: 111.11111111111111
# agent 15 的初始资源申请量为: 111.11111111111111
# agent 16 的初始资源申请量为: 111.11111111111111
# agent 17 的初始资源申请量为: 111.11111111111111
# agent 18 的初始资源申请量为: 111.11111111111111
# agent 19 的初始资源申请量为: 111.11111111111111
# agent 20 的初始资源申请量为: 111.11111111111111
# agent 21 的初始资源申请量为: 111.11111111111111
# agent 22 的初始资源申请量为: 111.11111111111111
# agent 23 的初始资源申请量为: 111.11111111111111
# agent 24 的初始资源申请量为: 111.11111111111111
# agent 25 的初始资源申请量为: 111.11111111111111
# agent 26 的初始资源申请量为: 111.11111111111111
# agent 27 的初始资源申请量为: 111.11111111111111
# agent 28 的初始资源申请量为: 111.11111111111111
# agent 29 的初始资源申请量为: 111.11111111111111
# agent 30 的初始资源申请量为: 111.11111111111111
# agent 31 的初始资源申请量为: 111.11111111111111
# agent 32 的初始资源申请量为: 111.11111111111111
# agent 33 的初始资源申请量为: 111.11111111111111
# agent 34 的初始资源申请量为: 111.11111111111111
# agent 35 的初始资源申请量为: 111.11111111111111
# agent 36 的初始资源申请量为: 111.11111111111111
# agent 37 的初始资源申请量为: 111.11111111111111
# agent 38 的初始资源申请量为: 111.11111111111111
# agent 39 的初始资源申请量为: 111.11111111111111
# agent 40 的初始资源申请量为: 111.11111111111111
# agent 41 的初始资源申请量为: 111.11111111111111
# agent 42 的初始资源申请量为: 111.11111111111111
# agent 43 的初始资源申请量为: 111.11111111111111
# agent 44 的初始资源申请量为: 111.11111111111111
# agent 45 的初始资源申请量为: 111.11111111111111
# agent 46 的初始资源申请量为: 111.11111111111111
# agent 47 的初始资源申请量为: 111.11111111111111
# agent 48 的初始资源申请量为: 111.11111111111111
# agent 49 的初始资源申请量为: 111.11111111111111
# agent 50 的初始资源申请量为: 111.11111111111111
# agent 51 的初始资源申请量为: 111.11111111111111
# agent 52 的初始资源申请量为: 111.11111111111111
# agent 53 的初始资源申请量为: 111.11111111111111
# agent 54 的初始资源申请量为: 111.11111111111111
# *************************
# 初始资源申请量总和为: 6000.000000000006
# *************************
# 初始成本总和为: 139226.02283950621
# *************************
# agent 1 的初始对偶变量为: 0.0
# agent 2 的初始对偶变量为: 0.0
# agent 3 的初始对偶变量为: 0.0
# agent 4 的初始对偶变量为: 0.0
# agent 5 的初始对偶变量为: 0.0
# agent 6 的初始对偶变量为: 0.0
# agent 7 的初始对偶变量为: 0.0
# agent 8 的初始对偶变量为: 0.0
# agent 9 的初始对偶变量为: 0.0
# agent 10 的初始对偶变量为: 0.0
# agent 11 的初始对偶变量为: 0.0
# agent 12 的初始对偶变量为: 0.0
# agent 13 的初始对偶变量为: 0.0
# agent 14 的初始对偶变量为: 0.0
# agent 15 的初始对偶变量为: 0.0
# agent 16 的初始对偶变量为: 0.0
# agent 17 的初始对偶变量为: 0.0
# agent 18 的初始对偶变量为: 0.0
# agent 19 的初始对偶变量为: 0.0
# agent 20 的初始对偶变量为: 0.0
# agent 21 的初始对偶变量为: 0.0
# agent 22 的初始对偶变量为: 0.0
# agent 23 的初始对偶变量为: 0.0
# agent 24 的初始对偶变量为: 0.0
# agent 25 的初始对偶变量为: 0.0
# agent 26 的初始对偶变量为: 0.0
# agent 27 的初始对偶变量为: 0.0
# agent 28 的初始对偶变量为: 0.0
# agent 29 的初始对偶变量为: 0.0
# agent 30 的初始对偶变量为: 0.0
# agent 31 的初始对偶变量为: 0.0
# agent 32 的初始对偶变量为: 0.0
# agent 33 的初始对偶变量为: 0.0
# agent 34 的初始对偶变量为: 0.0
# agent 35 的初始对偶变量为: 0.0
# agent 36 的初始对偶变量为: 0.0
# agent 37 的初始对偶变量为: 0.0
# agent 38 的初始对偶变量为: 0.0
# agent 39 的初始对偶变量为: 0.0
# agent 40 的初始对偶变量为: 0.0
# agent 41 的初始对偶变量为: 0.0
# agent 42 的初始对偶变量为: 0.0
# agent 43 的初始对偶变量为: 0.0
# agent 44 的初始对偶变量为: 0.0
# agent 45 的初始对偶变量为: 0.0
# agent 46 的初始对偶变量为: 0.0
# agent 47 的初始对偶变量为: 0.0
# agent 48 的初始对偶变量为: 0.0
# agent 49 的初始对偶变量为: 0.0
# agent 50 的初始对偶变量为: 0.0
# agent 51 的初始对偶变量为: 0.0
# agent 52 的初始对偶变量为: 0.0
# agent 53 的初始对偶变量为: 0.0
# agent 54 的初始对偶变量为: 0.0
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 19 次迭代中的结果：
# agent 1 在 19 次迭代中的资源申请量为: -67.43945290530323
# agent 2 在 19 次迭代中的资源申请量为: -67.43945290530323
# agent 3 在 19 次迭代中的资源申请量为: -69.09019282658431
# agent 4 在 19 次迭代中的资源申请量为: 156.72088722055
# agent 5 在 19 次迭代中的资源申请量为: 175.72364312014142
# agent 6 在 19 次迭代中的资源申请量为: -68.43166933764643
# agent 7 在 19 次迭代中的资源申请量为: -40.810965895822086
# agent 8 在 19 次迭代中的资源申请量为: -65.3276814048742
# agent 9 在 19 次迭代中的资源申请量为: -62.076870023691306
# agent 10 在 19 次迭代中的资源申请量为: 192.52799841299847
# agent 11 在 19 次迭代中的资源申请量为: 980.9906910285551
# agent 12 在 19 次迭代中的资源申请量为: -65.9317763003548
# agent 13 在 19 次迭代中的资源申请量为: -68.10532939360289
# agent 14 在 19 次迭代中的资源申请量为: -26.59829610268713
# agent 15 在 19 次迭代中的资源申请量为: -69.04155146850339
# agent 16 在 19 次迭代中的资源申请量为: -46.740295247796325
# agent 17 在 19 次迭代中的资源申请量为: -69.64003215619809
# agent 18 在 19 次迭代中的资源申请量为: -72.45348669131315
# agent 19 在 19 次迭代中的资源申请量为: -47.00316472373539
# agent 20 在 19 次迭代中的资源申请量为: 739.4495094948687
# agent 21 在 19 次迭代中的资源申请量为: 575.8613883422389
# agent 22 在 19 次迭代中的资源申请量为: -108.38539920931477
# agent 23 在 19 次迭代中的资源申请量为: -106.43803176486595
# agent 24 在 19 次迭代中的资源申请量为: 214.46298222912824
# agent 25 在 19 次迭代中的资源申请量为: 229.15757301052452
# agent 26 在 19 次迭代中的资源申请量为: -103.05811202179042
# agent 27 在 19 次迭代中的资源申请量为: 384.79183371185184
# agent 28 在 19 次迭代中的资源申请量为: 331.8382729334148
# agent 29 在 19 次迭代中的资源申请量为: 220.04165789016662
# agent 30 在 19 次迭代中的资源申请量为: 30.164238383044314
# agent 31 在 19 次迭代中的资源申请量为: -57.957185196153226
# agent 32 在 19 次迭代中的资源申请量为: -56.95484337130115
# agent 33 在 19 次迭代中的资源申请量为: -342.3645227684944
# agent 34 在 19 次迭代中的资源申请量为: 19.437443484849464
# agent 35 在 19 次迭代中的资源申请量为: 16.77324157482632
# agent 36 在 19 次迭代中的资源申请量为: 239.1279092035314
# agent 37 在 19 次迭代中的资源申请量为: 9.541008916566506
# agent 38 在 19 次迭代中的资源申请量为: -66.51196391155896
# agent 39 在 19 次迭代中的资源申请量为: 866.0917625937628
# agent 40 在 19 次迭代中的资源申请量为: 256.379588999351
# agent 41 在 19 次迭代中的资源申请量为: -325.590129826118
# agent 42 在 19 次迭代中的资源申请量为: -181.49203272295642
# agent 43 在 19 次迭代中的资源申请量为: 261.7641606669108
# agent 44 在 19 次迭代中的资源申请量为: 252.733264333365
# agent 45 在 19 次迭代中的资源申请量为: 280.2602474382206
# agent 46 在 19 次迭代中的资源申请量为: -312.5316547128083
# agent 47 在 19 次迭代中的资源申请量为: 77.97116661735492
# agent 48 在 19 次迭代中的资源申请量为: 70.85515151124113
# agent 49 在 19 次迭代中的资源申请量为: -331.28052432953365
# agent 50 在 19 次迭代中的资源申请量为: -112.29164175358532
# agent 51 在 19 次迭代中的资源申请量为: 125.04823222645913
# agent 52 在 19 次迭代中的资源申请量为: 125.04823222645913
# agent 53 在 19 次迭代中的资源申请量为: -44.343483080071245
# agent 54 在 19 次迭代中的资源申请量为: -269.1619048307218
# 资源申请量总和为: 3508.270438687692
# ****************************************************************************
# 成本总和为: 22231.73969264278
# ****************************************************************************
# agent 1 在 19 次迭代中的对偶变量为: -16.847730784515722
# agent 2 在 19 次迭代中的对偶变量为: -16.847730784515722
# agent 3 在 19 次迭代中的对偶变量为: -16.617739794243313
# agent 4 在 19 次迭代中的对偶变量为: -16.29617929704696
# agent 5 在 19 次迭代中的对偶变量为: -16.709489237863075
# agent 6 在 19 次迭代中的对偶变量为: -16.709489237863075
# agent 7 在 19 次迭代中的对偶变量为: -16.775239273066955
# agent 8 在 19 次迭代中的对偶变量为: -17.141955460584498
# agent 9 在 19 次迭代中的对偶变量为: -17.594878007079185
# agent 10 在 19 次迭代中的对偶变量为: -17.074983965482716
# agent 11 在 19 次迭代中的对偶变量为: -16.64594414617133
# agent 12 在 19 次迭代中的对偶变量为: -17.057789335176768
# agent 13 在 19 次迭代中的对偶变量为: -16.754956876906885
# agent 14 在 19 次迭代中的对偶变量为: -17.13908361977121
# agent 15 在 19 次迭代中的对偶变量为: -16.624516800099297
# agent 16 在 19 次迭代中的对偶变量为: -16.623448441656414
# agent 17 在 19 次迭代中的对偶变量为: -16.541132879805545
# agent 18 在 19 次迭代中的对偶变量为: -16.149145513246104
# agent 19 在 19 次迭代中的对偶变量为: -16.616718983072374
# agent 20 在 19 次迭代中的对偶变量为: -15.88073654459436
# agent 21 在 19 次迭代中的对偶变量为: -15.095186386819432
# agent 22 在 19 次迭代中的对偶变量为: -15.045333780241542
# agent 23 在 19 次迭代中的对偶变量为: -15.095186386819432
# agent 24 在 19 次迭代中的对偶变量为: -15.177274243616328
# agent 25 在 19 次迭代中的对偶变量为: -15.306586642492615
# agent 26 在 19 次迭代中的对偶变量为: -15.181712332242165
# agent 27 在 19 次迭代中的对偶变量为: -16.488991038017023
# agent 28 在 19 次迭代中的对偶变量为: -15.367434620729727
# agent 29 在 19 次迭代中的对偶变量为: -17.673406059111123
# agent 30 在 19 次迭代中的对偶变量为: -18.24126463852909
# agent 31 在 19 次迭代中的对偶变量为: -18.168857215360756
# agent 32 在 19 次迭代中的对偶变量为: -18.308509492450096
# agent 33 在 19 次迭代中的对偶变量为: -18.317598553212147
# agent 34 在 19 次迭代中的对偶变量为: -18.317598553212147
# agent 35 在 19 次迭代中的对偶变量为: -18.249394984315554
# agent 36 在 19 次迭代中的对偶变量为: -18.088532025176807
# agent 37 在 19 次迭代中的对偶变量为: -18.064249828264103
# agent 38 在 19 次迭代中的对偶变量为: -16.976954116058135
# agent 39 在 19 次迭代中的对偶变量为: -15.956550575562577
# agent 40 在 19 次迭代中的对偶变量为: -18.463756060735882
# agent 41 在 19 次迭代中的对偶变量为: -19.267096291322417
# agent 42 在 19 次迭代中的对偶变量为: -19.394493744331648
# agent 43 在 19 次迭代中的对偶变量为: -18.58087049450531
# agent 44 在 19 次迭代中的对偶变量为: -18.384448499250688
# agent 45 在 19 次迭代中的对偶变量为: -18.983160381781296
# agent 46 在 19 次迭代中的对偶变量为: -20.0062582166362
# agent 47 在 19 次迭代中的对偶变量为: -19.816061865404286
# agent 48 在 19 次迭代中的对偶变量为: -19.633891878687773
# agent 49 在 19 次迭代中的对偶变量为: -18.94499720085108
# agent 50 在 19 次迭代中的对偶变量为: -20.747222987000914
# agent 51 在 19 次迭代中的对偶变量为: -21.021234744997354
# agent 52 在 19 次迭代中的对偶变量为: -21.021234744997354
# agent 53 在 19 次迭代中的对偶变量为: -16.684806833150176
# agent 54 在 19 次迭代中的对偶变量为: -17.68072308436905
# *************************
# 迭代步长为: 0.0006406664425248283
# ****************************************************************************
# 39 次迭代中的结果：
# agent 1 在 39 次迭代中的资源申请量为: -65.46803365142635
# agent 2 在 39 次迭代中的资源申请量为: -65.46803365142635
# agent 3 在 39 次迭代中的资源申请量为: -66.04014028042211
# agent 4 在 39 次迭代中的资源申请量为: 185.54274121742517
# agent 5 在 39 次迭代中的资源申请量为: 192.61115984204204
# agent 6 在 39 次迭代中的资源申请量为: -65.79538114519606
# agent 7 在 39 次迭代中的资源申请量为: -27.140762268861582
# agent 8 在 39 次迭代中的资源申请量为: -63.55451150110459
# agent 9 在 39 次迭代中的资源申请量为: -61.42283872576287
# agent 10 在 39 次迭代中的资源申请量为: 206.5141812787076
# agent 11 在 39 次迭代中的资源申请量为: 1052.9068362254857
# agent 12 在 39 次迭代中的资源申请量为: -63.83427425681415
# agent 13 在 39 次迭代中的资源申请量为: -65.3764193074926
# agent 14 在 39 次迭代中的资源申请量为: -16.722280303122645
# agent 15 在 39 次迭代中的资源申请量为: -66.06970797284201
# agent 16 在 39 次迭代中的资源申请量为: -30.146460175203558
# agent 17 在 39 次迭代中的资源申请量为: -66.50473744294256
# agent 18 在 39 次迭代中的资源申请量为: -68.57757816618344
# agent 19 在 39 次迭代中的资源申请量为: -32.023839890490954
# agent 20 在 39 次迭代中的资源申请量为: 866.736803997935
# agent 21 在 39 次迭代中的资源申请量为: 740.7170387764276
# agent 22 在 39 次迭代中的资源申请量为: -77.87179534916297
# agent 23 在 39 次迭代中的资源申请量为: -75.51471796076542
# agent 24 在 39 次迭代中的资源申请量为: 302.37673266475025
# agent 25 在 39 次迭代中的资源申请量为: 316.8100278863983
# agent 26 在 39 次迭代中的资源申请量为: -70.08450232415197
# agent 27 在 39 次迭代中的资源申请量为: 405.3022368879026
# agent 28 在 39 次迭代中的资源申请量为: 371.3399120063284
# agent 29 在 39 次迭代中的资源申请量为: 218.78617938167278
# agent 30 在 39 次迭代中的资源申请量为: 27.972828158128905
# agent 31 在 39 次迭代中的资源申请量为: -58.82974891440293
# agent 32 在 39 次迭代中的资源申请量为: -58.195575511127714
# agent 33 在 39 次迭代中的资源申请量为: -347.31198107727096
# agent 34 在 39 次迭代中的资源申请量为: 8.498149339928041
# agent 35 在 39 次迭代中的资源申请量为: 8.772624592428556
# agent 36 在 39 次迭代中的资源申请量为: 235.48171574207586
# agent 37 在 39 次迭代中的资源申请量为: 10.32558407502382
# agent 38 在 39 次迭代中的资源申请量为: -61.831242347177366
# agent 39 在 39 次迭代中的资源申请量为: 1077.069676454191
# agent 40 在 39 次迭代中的资源申请量为: 243.90041246100162
# agent 41 在 39 次迭代中的资源申请量为: -339.5047131502133
# agent 42 在 39 次迭代中的资源申请量为: -225.51282352899062
# agent 43 在 39 次迭代中的资源申请量为: 247.55723010186895
# agent 44 在 39 次迭代中的资源申请量为: 247.68633471656304
# agent 45 在 39 次迭代中的资源申请量为: 267.08058540847856
# agent 46 在 39 次迭代中的资源申请量为: -324.6952530740084
# agent 47 在 39 次迭代中的资源申请量为: 53.38938547728281
# agent 48 在 39 次迭代中的资源申请量为: 51.08217425195044
# agent 49 在 39 次迭代中的资源申请量为: -334.5049286326249
# agent 50 在 39 次迭代中的资源申请量为: -157.54081061129293
# agent 51 在 39 次迭代中的资源申请量为: 87.89887251897416
# agent 52 在 39 次迭代中的资源申请量为: 87.89887251897416
# agent 53 在 39 次迭代中的资源申请量为: -28.57860762041239
# agent 54 在 39 次迭代中的资源申请量为: -269.97312647617827
# 资源申请量总和为: 4260.163470664875
# ****************************************************************************
# 成本总和为: 33335.190104142515
# ****************************************************************************
# agent 1 在 39 次迭代中的对偶变量为: -17.12240074348137
# agent 2 在 39 次迭代中的对偶变量为: -17.12240074348137
# agent 3 在 39 次迭代中的对偶变量为: -17.04269141528991
# agent 4 在 39 次迭代中的对偶变量为: -16.923054621478997
# agent 5 在 39 次迭代中的对偶变量为: -17.076792726564413
# agent 6 在 39 次迭代中的对偶变量为: -17.076792726564413
# agent 7 在 39 次迭代中的对偶变量为: -17.125196485917144
# agent 8 在 39 次迭代中的对偶变量为: -17.3890041305971
# agent 9 在 39 次迭代中的对偶变量为: -17.686001571694362
# agent 10 在 39 次迭代中的对偶变量为: -17.37918344281189
# agent 11 在 39 次迭代中的对偶变量为: -17.077441017352914
# agent 12 在 39 次迭代中的对偶变量为: -17.350025904895112
# agent 13 在 39 次迭代中的对偶变量为: -17.135165003564286
# agent 14 在 39 次迭代中的对偶变量为: -17.39190962424006
# agent 15 在 39 次迭代中的对偶变量为: -17.038571866975815
# agent 16 在 39 次迭代中的对偶变量为: -17.04825061951479
# agent 17 在 39 次迭代中的对偶变量为: -16.977960951024585
# agent 18 在 39 次迭代中的对偶变量为: -16.689160344418326
# agent 19 在 39 次迭代中的对偶变量为: -17.000189698803432
# agent 20 在 39 次迭代中的对偶变量为: -16.491970132798084
# agent 21 在 39 次迭代中的对偶变量为: -15.886823220204406
# agent 22 在 39 次迭代中的对偶变量为: -15.826482039061428
# agent 23 在 39 次迭代中的对偶变量为: -15.886823220204406
# agent 24 在 39 次迭代中的对偶变量为: -15.950915247449801
# agent 25 在 39 次迭代中的对偶变量为: -16.077928245400305
# agent 26 在 39 次迭代中的对偶变量为: -16.02583674050171
# agent 27 在 39 次迭代中的对偶变量为: -16.923401377285778
# agent 28 在 39 次迭代中的对偶变量为: -16.204079336294036
# agent 29 在 39 次迭代中的对偶变量为: -17.646099401551382
# agent 30 在 39 次迭代中的对偶变量为: -18.039992375011508
# agent 31 在 39 次迭代中的对偶变量为: -18.047286402751897
# agent 32 在 39 次迭代中的对偶变量为: -18.13564324633662
# agent 33 在 39 次迭代中的对偶变量为: -18.037552623102158
# agent 34 在 39 次迭代中的对偶变量为: -18.037552623102158
# agent 35 在 39 次迭代中的对偶变量为: -18.04457918956617
# agent 36 在 39 次迭代中的对偶变量为: -18.00922731739015
# agent 37 在 39 次迭代中的对偶变量为: -18.08433495232061
# agent 38 在 39 次迭代中的对偶变量为: -17.629100328737167
# agent 39 在 39 次迭代中的对偶变量为: -17.222418058725147
# agent 40 在 39 次迭代中的对偶变量为: -18.192333971026784
# agent 41 在 39 次迭代中的对偶变量为: -18.479475216845326
# agent 42 在 39 次迭代中的对偶变量为: -18.53397532565529
# agent 43 在 39 次迭代中的对偶变量为: -18.27186975471565
# agent 44 在 39 次迭代中的对偶变量为: -18.274677780085245
# agent 45 在 39 次迭代中的对偶变量为: -18.696502732634407
# agent 46 在 39 次迭代中的对偶变量为: -19.31774989499883
# agent 47 在 39 次迭代中的对偶变量为: -19.18676826821844
# agent 48 在 39 次迭代中的对偶变量为: -19.12770366084993
# agent 49 在 39 次迭代中的对偶变量为: -18.762483019678903
# agent 50 在 39 次迭代中的对偶变量为: -19.862692234170446
# agent 51 在 39 次迭代中的对偶变量为: -20.07021113648574
# agent 52 在 39 次迭代中的对偶变量为: -20.07021113648574
# agent 53 在 39 次迭代中的对偶变量为: -17.088387644917443
# agent 54 在 39 次迭代中的对偶变量为: -17.664865323643667
# *************************
# 迭代步长为: 0.000217853964469636
# ****************************************************************************
# 59 次迭代中的结果：
# agent 1 在 59 次迭代中的资源申请量为: -64.61627282802586
# agent 2 在 59 次迭代中的资源申请量为: -64.61627282802586
# agent 3 在 59 次迭代中的资源申请量为: -64.92162413823715
# agent 4 在 59 次迭代中的资源申请量为: 195.39655284922338
# agent 5 在 59 次迭代中的资源申请量为: 199.01271895093666
# agent 6 在 59 次迭代中的资源申请量为: -64.79604210855926
# agent 7 在 59 次迭代中的资源申请量为: -22.45417794815185
# agent 8 在 59 次迭代中的资源申请量为: -63.43348639251787
# agent 9 在 59 次迭代中的资源申请量为: -62.111451463613754
# agent 10 在 59 次迭代中的资源申请量为: 207.56517670261277
# agent 11 在 59 次迭代中的资源申请量为: 1076.4973858858093
# agent 12 在 59 次迭代中的资源申请量为: -63.60103581513143
# agent 13 在 59 次迭代中的资源申请量为: -64.53375541301641
# agent 14 在 59 次迭代中的资源申请量为: -16.105563549366902
# agent 15 在 59 次迭代中的资源申请量为: -64.96317232029472
# agent 16 在 59 次迭代中的资源申请量为: -24.200988412515223
# agent 17 在 59 次迭代中的资源申请量为: -65.24385334825662
# agent 18 在 59 次迭代中的资源申请量为: -66.60043642130073
# agent 19 在 59 次迭代中的资源申请量为: -25.25135198275144
# agent 20 在 59 次迭代中的资源申请量为: 938.3240950434123
# agent 21 在 59 次迭代中的资源申请量为: 852.9651929148467
# agent 22 在 59 次迭代中的资源申请量为: -56.146890242290134
# agent 23 在 59 次迭代中的资源申请量为: -54.45941967276976
# agent 24 在 59 次迭代中的资源申请量为: 361.48658766708826
# agent 25 在 59 次迭代中的资源申请量为: 371.8081450323965
# agent 26 在 59 次迭代中的资源申请量为: -50.32459448205975
# agent 27 在 59 次迭代中的资源申请量为: 414.99220679399775
# agent 28 在 59 次迭代中的资源申请量为: 392.6933602237709
# agent 29 在 59 次迭代中的资源申请量为: 216.90550418365572
# agent 30 在 59 次迭代中的资源申请量为: 25.665118179147438
# agent 31 在 59 次迭代中的资源申请量为: -60.52270074381396
# agent 32 在 59 次迭代中的资源申请量为: -60.128822276074
# agent 33 在 59 次迭代中的资源申请量为: -350.6810320746393
# agent 34 在 59 次迭代中的资源申请量为: 1.0488617362156005
# agent 35 在 59 次迭代中的资源申请量为: 2.5769616394648307
# agent 36 在 59 次迭代中的资源申请量为: 231.68723065282265
# agent 37 在 59 次迭代中的资源申请量为: 7.687528370636243
# agent 38 在 59 次迭代中的资源申请量为: -60.73279654449093
# agent 39 在 59 次迭代中的资源申请量为: 1134.4869877398542
# agent 40 在 59 次迭代中的资源申请量为: 238.90299521040797
# agent 41 在 59 次迭代中的资源申请量为: -343.82260030135757
# agent 42 在 59 次迭代中的资源申请量为: -239.3361785455235
# agent 43 在 59 次迭代中的资源申请量为: 240.83557994450632
# agent 44 在 59 次迭代中的资源申请量为: 242.3143494151906
# agent 45 在 59 次迭代中的资源申请量为: 258.76135533085295
# agent 46 在 59 次迭代中的资源申请量为: -331.44220832117304
# agent 47 在 59 次迭代中的资源申请量为: 40.310644040138094
# agent 48 在 59 次迭代中的资源申请量为: 40.114417120041125
# agent 49 在 59 次迭代中的资源申请量为: -336.45384087612337
# agent 50 在 59 次迭代中的资源申请量为: -186.88595066101897
# agent 51 在 59 次迭代中的资源申请量为: 62.51472375319353
# agent 52 在 59 次迭代中的资源申请量为: 62.51472375319353
# agent 53 在 59 次迭代中的资源申请量为: -23.259801480690204
# agent 54 在 59 次迭代中的资源申请量为: -271.0275185711548
# 资源申请量总和为: 4594.394563370472
# ****************************************************************************
# 成本总和为: 38413.266679808854
# ****************************************************************************
# agent 1 在 59 次迭代中的对偶变量为: -17.24107317196247
# agent 2 在 59 次迭代中的对偶变量为: -17.24107317196247
# agent 3 在 59 次迭代中的对偶变量为: -17.19852979531597
# agent 4 在 59 次迭代中的对偶变量为: -17.137375024470607
# agent 5 在 59 次迭代中的对偶变量为: -17.21602663718287
# agent 6 在 59 次迭代中的对偶变量为: -17.21602663718287
# agent 7 在 59 次迭代中的对偶变量为: -17.245173044527313
# agent 8 在 59 次迭代中的对偶变量为: -17.405866074876055
# agent 9 在 59 次迭代中的对偶变量为: -17.59005991338055
# agent 10 在 59 次迭代中的对偶变量为: -17.402042593281827
# agent 11 在 59 次迭代中的对偶变量为: -17.218984315314856
# agent 12 在 59 次迭代中的对偶变量为: -17.382522084020998
# agent 13 在 59 次迭代中的对偶变量为: -17.252569993326077
# agent 14 在 59 次迭代中的对偶变量为: -17.407697573136208
# agent 15 在 59 次迭代中的对偶变量为: -17.19274105330262
# agent 16 在 59 次迭代中的对偶变量为: -17.20045469663961
# agent 17 在 59 次迭代中的对偶变量为: -17.1536348884008
# agent 18 在 59 次迭代中的对偶变量为: -16.964627595165855
# agent 19 在 59 次迭代中的对偶变量为: -17.173565389241563
# agent 20 在 59 次迭代中的对偶变量为: -16.835732304398466
# agent 21 在 59 次迭代中的对偶变量为: -16.425838856377094
# agent 22 在 59 次迭代中的对偶变量为: -16.382639609797373
# agent 23 在 59 次迭代中的对偶变量为: -16.425838856377094
# agent 24 在 59 次迭代中的对偶变量为: -16.471081971470376
# agent 25 在 59 次迭代中的对偶变量为: -16.56191167628509
# agent 26 在 59 次迭代中的对偶变量为: -16.53169038125927
# agent 27 在 59 次迭代中的对偶变量为: -17.128634939896873
# agent 28 在 59 次迭代中的对偶变量为: -16.65634536953947
# agent 29 在 59 次迭代中的对偶变量为: -17.60519471599451
# agent 30 在 59 次迭代中的对偶变量为: -17.828038444281976
# agent 31 在 59 次迭代中的对偶变量为: -17.811414196167377
# agent 32 在 59 次迭代中的对偶变量为: -17.866291707563715
# agent 33 在 59 次迭代中的对偶变量为: -17.84685086044712
# agent 34 在 59 次迭代中的对偶变量为: -17.84685086044712
# agent 35 在 59 次迭代中的对偶变量为: -17.8859702179703
# agent 36 在 59 次迭代中的对偶变量为: -17.92669726669889
# agent 37 在 59 次迭代中的对偶变量为: -18.016800726288288
# agent 38 在 59 次迭代中的对偶变量为: -17.782142388642256
# agent 39 在 59 次迭代中的对偶变量为: -17.566921926439125
# agent 40 在 59 次迭代中的对偶变量为: -18.083640145826372
# agent 41 在 59 次迭代中的对偶变量为: -18.23506553254196
# agent 42 在 59 次迭代中的对偶变量为: -18.263756381792106
# agent 43 在 59 次迭代中的对偶变量为: -18.12567386379301
# agent 44 在 59 次迭代中的对偶变量为: -18.157837099780394
# agent 45 在 59 次迭代中的对偶变量为: -18.51555947844605
# agent 46 在 59 次迭代中的对偶变量为: -18.935845240188325
# agent 47 在 59 次迭代中的对偶变量为: -18.851952487427535
# agent 48 在 59 次迭代中的对偶变量为: -18.846929078273053
# agent 49 在 59 次迭代中的对偶变量为: -18.652166791047915
# agent 50 在 59 次迭代中的对偶变量为: -19.2890534364784
# agent 51 在 59 次迭代中的对偶变量为: -19.420376928081755
# agent 52 在 59 次迭代中的对偶变量为: -19.420376928081755
# agent 53 在 59 次迭代中的对偶变量为: -17.22454908209433
# agent 54 在 59 次迭代中的对偶变量为: -17.644254066971065
# *************************
# 迭代步长为: 0.00011708044397666381
# ****************************************************************************
# 79 次迭代中的结果：
# agent 1 在 79 次迭代中的资源申请量为: -64.09402566856531
# agent 2 在 79 次迭代中的资源申请量为: -64.09402566856531
# agent 3 在 79 次迭代中的资源申请量为: -64.2846606836836
# agent 4 在 79 次迭代中的资源申请量为: 200.4268019936913
# agent 5 在 79 次迭代中的资源申请量为: 202.82000695744523
# agent 6 在 79 次迭代中的资源申请量为: -64.20169134745538
# agent 7 在 79 次迭代中的资源申请量为: -19.588602875781625
# agent 8 在 79 次迭代中的资源申请量为: -63.304923376619314
# agent 9 在 79 次迭代中的资源申请量为: -62.397316449354875
# agent 10 在 79 次迭代中的资源申请量为: 208.41305159196895
# agent 11 在 79 次迭代中的资源申请量为: 1090.2329106085083
# agent 12 在 79 次迭代中的资源申请量为: -63.43029702747173
# agent 13 在 79 次迭代中的资源申请量为: -64.02962093830988
# agent 14 在 79 次迭代中的资源申请量为: -15.465386974241046
# agent 15 在 79 次迭代中的资源申请量为: -64.29469710496612
# agent 16 在 79 次迭代中的资源申请量为: -20.727259536455904
# agent 17 在 79 次迭代中的资源申请量为: -64.49467815821595
# agent 18 在 79 次迭代中的资源申请量为: -65.40040553029775
# agent 19 在 79 次迭代中的资源申请量为: -20.911195306810153
# agent 20 在 79 次迭代中的资源申请量为: 982.6602618867233
# agent 21 在 79 次迭代中的资源申请量为: 923.3460936896493
# agent 22 在 79 次迭代中的资源申请量为: -42.441211969481415
# agent 23 在 79 次迭代中的资源申请量为: -41.25750226962127
# agent 24 在 79 次迭代中的资源申请量为: 398.4455126198308
# agent 25 在 79 次迭代中的资源申请量为: 405.789870966351
# agent 26 在 79 次迭代中的资源申请量为: -38.24827100446251
# agent 27 在 79 次迭代中的资源申请量为: 420.9737229951955
# agent 28 在 79 次迭代中的资源申请量为: 405.52897407638926
# agent 29 在 79 次迭代中的资源申请量为: 216.670862372232
# agent 30 在 79 次迭代中的资源申请量为: 24.618677256913088
# agent 31 在 79 次迭代中的资源申请量为: -61.3046997330725
# agent 32 在 79 次迭代中的资源申请量为: -61.02919779880178
# agent 33 在 79 次迭代中的资源申请量为: -352.1769337929486
# agent 34 在 79 次迭代中的资源申请量为: -2.2587172037523415
# agent 35 在 79 次迭代中的资源申请量为: -0.31145341555197104
# agent 36 在 79 次迭代中的资源申请量为: 229.78828064849213
# agent 37 在 79 次迭代中的资源申请量为: 5.899311139880569
# agent 38 在 79 次迭代中的资源申请量为: -60.42432437180471
# agent 39 在 79 次迭代中的资源申请量为: 1154.762007303756
# agent 40 在 79 次迭代中的资源申请量为: 235.93040969862943
# agent 41 在 79 次迭代中的资源申请量为: -345.9358348354222
# agent 42 在 79 次迭代中的资源申请量为: -245.9777540816995
# agent 43 在 79 次迭代中的资源申请量为: 237.21756530483867
# agent 44 在 79 次迭代中的资源申请量为: 239.20668619455353
# agent 45 在 79 次迭代中的资源申请量为: 254.05750367831612
# agent 46 在 79 次迭代中的资源申请量为: -335.23266550809853
# agent 47 在 79 次迭代中的资源申请量为: 33.042825588124046
# agent 48 在 79 次迭代中的资源申请量为: 33.95270234255371
# agent 49 在 79 次迭代中的资源申请量为: -337.5605254335438
# agent 50 在 79 次迭代中的资源申请量为: -203.94713620731744
# agent 51 在 79 次迭代中的资源申请量为: 47.61398323567395
# agent 52 在 79 次迭代中的资源申请量为: 47.61398323567395
# agent 53 在 79 次迭代中的资源申请量为: -20.11958241594336
# agent 54 在 79 次迭代中的资源申请量为: -270.93181973017
# 资源申请量总和为: 4799.135588966904
# ****************************************************************************
# 成本总和为: 41671.42732906052
# ****************************************************************************
# agent 1 在 79 次迭代中的对偶变量为: -17.31383577970147
# agent 2 在 79 次迭代中的对偶变量为: -17.31383577970147
# agent 3 在 79 次迭代中的对偶变量为: -17.2872753655851
# agent 4 在 79 次迭代中的对偶变量为: -17.246782943362785
# agent 5 在 79 次迭代中的对偶变量为: -17.298835151324433
# agent 6 在 79 次迭代中的对偶变量为: -17.298835151324433
# agent 7 在 79 次迭代中的对偶变量为: -17.31853176637999
# agent 8 在 79 次迭代中的对偶变量为: -17.423778245629137
# agent 9 在 79 次迭代中的对偶变量为: -17.550231488377182
# agent 10 在 79 次迭代中的对偶变量为: -17.420483872125324
# agent 11 在 79 次迭代中的对偶变量为: -17.30139746365105
# agent 12 在 79 次迭代中的对偶变量为: -17.406310436350473
# agent 13 在 79 次迭代中的对偶变量为: -17.32280903314904
# agent 14 在 79 次迭代中的对偶变量为: -17.42408609345943
# agent 15 在 79 次迭代中的对偶变量为: -17.28587703115349
# agent 16 在 79 次迭代中的对偶变量为: -17.28938215586673
# agent 17 在 79 次迭代中的对偶变量为: -17.258014470928405
# agent 18 在 79 次迭代中的对偶变量为: -17.131823099085736
# agent 19 在 79 次迭代中的对偶变量为: -17.28467340014566
# agent 20 在 79 次迭代中的对偶变量为: -17.048634577580046
# agent 21 在 79 次迭代中的对偶变量为: -16.763807941897696
# agent 22 在 79 次迭代中的对偶变量为: -16.733504973581276
# agent 23 在 79 次迭代中的对偶变量为: -16.763807941897696
# agent 24 在 79 次迭代中的对偶变量为: -16.79632051105451
# agent 25 在 79 次迭代中的对偶变量为: -16.860950864503888
# agent 26 在 79 次迭代中的对偶变量为: -16.84084426228576
# agent 27 在 79 次迭代中的对偶变量为: -17.25532345303824
# agent 28 在 79 次迭代中的对偶变量为: -16.928203670937926
# agent 29 在 79 次迭代中的对偶变量为: -17.600091256596045
# agent 30 在 79 次迭代中的对偶变量为: -17.73192703133844
# agent 31 在 79 次迭代中的对偶变量为: -17.70246140498994
# agent 32 在 79 次迭代中的对偶变量为: -17.740845987484143
# agent 33 在 79 次迭代中的对偶变量为: -17.76217683958394
# agent 34 在 79 次迭代中的对偶变量为: -17.76217683958394
# agent 35 在 79 次迭代中的对偶变量为: -17.81202679256187
# agent 36 在 79 次迭代中的对偶变量为: -17.885395104104703
# agent 37 在 79 次迭代中的对偶变量为: -17.971022365180943
# agent 38 在 79 次迭代中的对偶变量为: -17.825120582573938
# agent 39 在 79 次迭代中的对偶变量为: -17.688572043822536
# agent 40 在 79 次迭代中的对偶变量为: -18.01898641094519
# agent 41 在 79 次迭代中的对偶变量为: -18.115448004975764
# agent 42 在 79 次迭代中的对偶变量为: -18.133926863210938
# agent 43 在 79 次迭代中的对偶变量为: -18.04698204538024
# agent 44 在 79 次迭代中的对偶变量为: -18.09024542473154
# agent 45 在 79 次迭代中的对偶变量为: -18.413250705003374
# agent 46 在 79 次迭代中的对偶变量为: -18.721290201579592
# agent 47 在 79 次迭代中的对偶变量为: -18.665896335055976
# agent 48 在 79 次迭代中的对偶变量为: -18.689189179969375
# agent 49 在 79 次迭代中的对偶变量为: -18.58952401835969
# agent 50 在 79 次迭代中的对偶变量为: -18.95554138141936
# agent 51 在 79 次迭代中的对偶变量为: -19.038917970833253
# agent 52 在 79 次迭代中的对偶变量为: -19.038917970833253
# agent 53 在 79 次迭代中的对偶变量为: -17.30493869015185
# agent 54 在 79 次迭代中的对偶变量为: -17.646124787914637
# *************************
# 迭代步长为: 7.556518347445504e-05
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: -63.67005819435805
# agent 2 在 99 次迭代中的资源申请量为: -63.67005819435805
# agent 3 在 99 次迭代中的资源申请量为: -63.79940264293244
# agent 4 在 99 次迭代中的资源申请量为: 203.94661668289513
# agent 5 在 99 次迭代中的资源申请量为: 205.80851250252928
# agent 6 在 99 次迭代中的资源申请量为: -63.7351596476608
# agent 7 在 99 次迭代中的资源申请量为: -17.239172983743305
# agent 8 在 99 次迭代中的资源申请量为: -63.091502023776016
# agent 9 在 99 次迭代中的资源申请量为: -62.41092189547912
# agent 10 在 99 次迭代中的资源申请量为: 209.7795650634965
# agent 11 在 99 次迭代中的资源申请量为: 1101.0479987567066
# agent 12 在 99 次迭代中的资源申请量为: -63.19621710803542
# agent 13 在 99 次迭代中的资源申请量为: -63.611522508404875
# agent 14 在 99 次迭代中的资源申请量为: -14.343324829328429
# agent 15 在 99 次迭代中的资源申请量为: -63.77971845074999
# agent 16 在 99 次迭代中的资源申请量为: -18.050136159861175
# agent 17 在 99 次迭代中的资源申请量为: -63.93542695325368
# agent 18 在 99 次迭代中的资源申请量为: -64.56948711501015
# agent 19 在 99 次迭代中的资源申请量为: -17.66217763333064
# agent 20 在 99 次迭代中的资源申请量为: 1012.6172343775517
# agent 21 在 99 次迭代中的资源申请量为: 969.1751569751597
# agent 22 在 99 次迭代中的资源申请量为: -33.527189232847306
# agent 23 在 99 次迭代中的资源申请量为: -32.66097250801889
# agent 24 在 99 次迭代中的资源申请量为: 422.5342186017852
# agent 25 在 99 次迭代中的资源申请量为: 427.9863706965627
# agent 26 在 99 次迭代中的资源申请量为: -30.40260222769833
# agent 27 在 99 次迭代中的资源申请量为: 425.27870466148397
# agent 28 在 99 次迭代中的资源申请量为: 413.9172767084401
# agent 29 在 99 次迭代中的资源申请量为: 217.36104873637527
# agent 30 在 99 次迭代中的资源申请量为: 24.24766640959903
# agent 31 在 99 次迭代中的资源申请量为: -61.58633799385976
# agent 32 在 99 次迭代中的资源申请量为: -61.37503552768369
# agent 33 在 99 次迭代中的资源申请量为: -352.69992105895477
# agent 34 在 99 次迭代中的资源申请量为: -3.415091078948218
# agent 35 在 99 次迭代中的资源申请量为: -1.3688074085754787
# agent 36 在 99 次迭代中的资源申请量为: 229.1333265602806
# agent 37 在 99 次迭代中的资源申请量为: 5.037036214966123
# agent 38 在 99 次迭代中的资源申请量为: -60.28849183276431
# agent 39 在 99 次迭代中的资源申请量为: 1164.4692506960548
# agent 40 在 99 次迭代中的资源申请量为: 234.23047285207247
# agent 41 在 99 次迭代中的资源申请量为: -347.0969528525985
# agent 42 在 99 次迭代中的资源申请量为: -249.57654564903189
# agent 43 在 99 次迭代中的资源申请量为: 235.31363131411044
# agent 44 在 99 次迭代中的资源申请量为: 237.62478621345744
# agent 45 在 99 次迭代中的资源申请量为: 251.4798034902999
# agent 46 在 99 次迭代中的资源申请量为: -337.38282839687764
# agent 47 在 99 次迭代中的资源申请量为: 28.945413715683873
# agent 48 在 99 次迭代中的资源申请量为: 30.457427288638343
# agent 49 在 99 次迭代中的资源申请量为: -338.18340998279
# agent 50 在 99 次迭代中的资源申请量为: -213.78400919784258
# agent 51 在 99 次迭代中的资源申请量为: 38.99069280542969
# agent 52 在 99 次迭代中的资源申请量为: 38.99069280542969
# agent 53 在 99 次迭代中的资源申请量为: -17.625554143253783
# agent 54 在 99 次迭代中的资源申请量为: -270.10797236299123
# 资源申请量总和为: 4950.526896333989
# ****************************************************************************
# 成本总和为: 44171.109274756374
# ****************************************************************************
# agent 1 在 99 次迭代中的对偶变量为: -17.37290547201287
# agent 2 在 99 次迭代中的对偶变量为: -17.37290547201287
# agent 3 在 99 次迭代中的对偶变量为: -17.354884427370795
# agent 4 在 99 次迭代中的对偶变量为: -17.323338912852968
# agent 5 在 99 次迭代中的对偶变量为: -17.36383514693001
# agent 6 在 99 次迭代中的对偶变量为: -17.36383514693001
# agent 7 在 99 次迭代中的对偶变量为: -17.37867717161617
# agent 8 在 99 次迭代中的对偶变量为: -17.453513389035383
# agent 9 在 99 次迭代中的对偶变量为: -17.548335895990476
# agent 10 在 99 次迭代中的对偶变量为: -17.450205540131048
# agent 11 在 99 次迭代中的对偶变量为: -17.36628799254024
# agent 12 在 99 次迭代中的对偶变量为: -17.438923855205857
# agent 13 在 99 次迭代中的对偶变量为: -17.381061014993982
# agent 14 在 99 次迭代中的对偶变量为: -17.452810884369192
# agent 15 在 99 次迭代中的对偶变量为: -17.357626947130807
# agent 16 在 99 次迭代中的对偶变量为: -17.357916514307554
# agent 17 在 99 次迭代中的对偶变量为: -17.335932704310977
# agent 18 在 99 次迭代中的对偶变量为: -17.247591638214097
# agent 19 在 99 次迭代中的对偶变量为: -17.367848252586736
# agent 20 在 99 次迭代中的对偶变量为: -17.192487959481003
# agent 21 在 99 次迭代中的对偶变量为: -16.983879103794717
# agent 22 在 99 次迭代中的对偶变量为: -16.96170395563911
# agent 23 在 99 次迭代中的对偶变量为: -16.983879103794717
# agent 24 在 99 次迭代中的对偶变量为: -17.00830112369571
# agent 25 在 99 次迭代中的对偶变量为: -17.05628006212975
# agent 26 在 99 次迭代中的对偶变量为: -17.041693382970923
# agent 27 在 99 次迭代中的对偶变量为: -17.34650296473023
# agent 28 在 99 次迭代中的对偶变量为: -17.105867920684762
# agent 29 在 99 次迭代中的对偶变量为: -17.61510281001616
# agent 30 在 99 次迭代中的对偶变量为: -17.697851169056033
# agent 31 在 99 次迭代中的对偶变量为: -17.663221872667496
# agent 32 在 99 次迭代中的对偶变量为: -17.692661800069942
# agent 33 在 99 次迭代中的对偶变量为: -17.732573668378926
# agent 34 在 99 次迭代中的对偶变量为: -17.732573668378926
# agent 35 在 99 次迭代中的对偶变量为: -17.784958530340468
# agent 36 在 99 次迭代中的对偶变量为: -17.871149852686102
# agent 37 在 99 次迭代中的对偶变量为: -17.948948127103133
# agent 38 在 99 次迭代中的对偶变量为: -17.84404558690828
# agent 39 在 99 次迭代中的对偶变量为: -17.74681550417633
# agent 40 在 99 次迭代中的对偶变量为: -17.982012784532575
# agent 41 在 99 次迭代中的对偶变量为: -18.049724080731515
# agent 42 在 99 次迭代中的对偶变量为: -18.063577685652724
# agent 43 在 99 次迭代中的对偶变量为: -18.0055714810819
# agent 44 在 99 次迭代中的对偶变量为: -18.0558391001427
# agent 45 在 99 次迭代中的对偶变量为: -18.35718572591402
# agent 46 在 99 次迭代中的对偶变量为: -18.59958238142314
# agent 47 在 99 次迭代中的对偶变量为: -18.561002591121508
# agent 48 在 99 次迭代中的对偶变量为: -18.599710138589142
# agent 49 在 99 次迭代中的对偶变量为: -18.554266261334156
# agent 50 在 99 次迭代中的对偶变量为: -18.763250188200573
# agent 51 在 99 次迭代中的对偶变量为: -18.818161735819
# agent 52 在 99 次迭代中的对偶变量为: -18.818161735819
# agent 53 在 99 次迭代中的对偶变量为: -17.368785813932703
# agent 54 在 99 次迭代中的对偶变量为: -17.662229356248247
# *************************
# 迭代步长为: 5.3865362416062276e-05
# ****************************************************************************
# 119 次迭代中的结果：
# agent 1 在 119 次迭代中的资源申请量为: -63.286172046574954
# agent 2 在 119 次迭代中的资源申请量为: -63.286172046574954
# agent 3 在 119 次迭代中的资源申请量为: -63.378908467904495
# agent 4 在 119 次迭代中的资源申请量为: 206.86669037433765
# agent 5 在 119 次迭代中的资源申请量为: 208.43560002883783
# agent 6 在 119 次迭代中的资源申请量为: -63.325048443024116
# agent 7 在 119 次迭代中的资源申请量为: -15.11731892932147
# agent 8 在 119 次迭代中的资源申请量为: -62.83062811612467
# agent 9 在 119 次迭代中的资源申请量为: -62.28658284447069
# agent 10 在 119 次迭代中的资源申请量为: 211.45242006543793
# agent 11 在 119 次迭代中的资源申请量为: 1110.5756487047881
# agent 12 在 119 次迭代中的资源申请量为: -62.92266358624002
# agent 13 在 119 次迭代中的资源申请量为: -63.22941880212227
# agent 14 在 119 次迭代中的资源申请量为: -12.946478881346728
# agent 15 在 119 次迭代中的资源申请量为: -63.339395072991906
# agent 16 在 119 次迭代中的资源申请量为: -15.733559714924265
# agent 17 在 119 次迭代中的资源申请量为: -63.46833339525203
# agent 18 在 119 次迭代中的资源申请量为: -63.935050450079984
# agent 19 在 119 次迭代中的资源申请量为: -15.00857000112321
# agent 20 在 119 次迭代中的资源申请量为: 1034.6302427669477
# agent 21 在 119 次迭代中的资源申请量为: 1001.1174484918889
# agent 22 在 119 次迭代中的资源申请量为: -27.33608026036796
# agent 23 在 119 次迭代中的资源申请量为: -26.669297357107407
# agent 24 在 119 次迭代中的资源申请量为: 439.37029545726705
# agent 25 在 119 次迭代中的资源申请量为: 443.61511964894993
# agent 26 在 119 次迭代中的资源申请量为: -24.900543312322693
# agent 27 在 119 次迭代中的资源申请量为: 428.7032934524899
# agent 28 在 119 次迭代中的资源申请量为: 419.8798032174519
# agent 29 在 119 次迭代中的资源申请量为: 218.5025094365818
# agent 30 在 119 次迭代中的资源申请量为: 24.21041226563299
# agent 31 在 119 次迭代中的资源申请量为: -61.62275125208518
# agent 32 在 119 次迭代中的资源申请量为: -61.45024367918237
# agent 33 在 119 次迭代中的资源申请量为: -352.73747566030335
# agent 34 在 119 次迭代中的资源申请量为: -3.4981278232737445
# agent 35 在 119 次迭代中的资源申请量为: -1.4641420499232616
# agent 36 在 119 次迭代中的资源申请量为: 229.22965983343767
# agent 37 在 119 次迭代中的资源申请量为: 4.839125677875283
# agent 38 在 119 次迭代中的资源申请量为: -60.16773049038812
# agent 39 在 119 次迭代中的资源申请量为: 1171.040872892532
# agent 40 在 119 次迭代中的资源申请量为: 233.47414194055355
# agent 41 在 119 次迭代中的资源申请量为: -347.69236491237297
# agent 42 在 119 次迭代中的资源申请量为: -251.42542253294073
# agent 43 在 119 次迭代中的资源申请量为: 234.49642735759073
# agent 44 在 119 次迭代中的资源申请量为: 237.0118337178773
# agent 45 在 119 次迭代中的资源申请量为: 250.13750928991453
# agent 46 在 119 次迭代中的资源申请量为: -338.61575451625566
# agent 47 在 119 次迭代中的资源申请量为: 26.615456323171582
# agent 48 在 119 次迭代中的资源申请量为: 28.453199640258024
# agent 49 在 119 次迭代中的资源申请量为: -338.53096032485166
# agent 50 在 119 次迭代中的资源申请量为: -219.53271085996258
# agent 51 在 119 次迭代中的资源申请量为: 33.934676279297605
# agent 52 在 119 次迭代中的资源申请量为: 33.934676279297605
# agent 53 在 119 次迭代中的资源申请量为: -15.417136484916353
# agent 54 在 119 次迭代中的资源申请量为: -268.8847125215476
# 资源申请量总和为: 5076.48730830654
# ****************************************************************************
# 成本总和为: 46302.30556049824
# ****************************************************************************
# agent 1 在 119 次迭代中的对偶变量为: -17.426390793438898
# agent 2 在 119 次迭代中的对偶变量为: -17.426390793438898
# agent 3 在 119 次迭代中的对偶变量为: -17.413470198800738
# agent 4 在 119 次迭代中的对偶变量为: -17.386850515641843
# agent 5 在 119 次迭代中的对偶变量为: -17.420974300627222
# agent 6 在 119 次迭代中的对偶变量为: -17.420974300627222
# agent 7 在 119 次迭代中的对偶变量为: -17.43299663540937
# agent 8 在 119 次迭代中的对偶变量为: -17.489859907092814
# agent 9 在 119 次迭代中的对偶变量为: -17.565659558611276
# agent 10 在 119 次迭代中的对偶变量为: -17.486590136423274
# agent 11 在 119 次迭代中的对偶变量为: -17.42345389222873
# agent 12 在 119 次迭代中的对偶变量为: -17.477036973183523
# agent 13 在 119 次迭代中的对偶变量为: -17.434297995975513
# agent 14 在 119 次迭代中的对偶变量为: -17.488570140637524
# agent 15 在 119 次迭代中的对偶变量为: -17.41897544206033
# agent 16 在 119 次迭代中的对偶变量为: -17.41722087129794
# agent 17 在 119 次迭代中的对偶变量为: -17.401010981373116
# agent 18 在 119 次迭代中的对偶变量为: -17.335985160992156
# agent 19 在 119 次迭代中的对偶变量为: -17.435780607971246
# agent 20 在 119 次迭代中的对偶变量为: -17.298194425766884
# agent 21 在 119 次迭代中的对偶变量为: -17.13726598765805
# agent 22 在 119 次迭代中的对偶变量为: -17.12019634533458
# agent 23 在 119 次迭代中的对偶变量为: -17.13726598765805
# agent 24 在 119 次迭代中的对偶变量为: -17.15645860002395
# agent 25 在 119 次迭代中的对偶变量为: -17.19381305291076
# agent 26 在 119 次迭代中的对偶变量为: -17.18254609120454
# agent 27 在 119 次迭代中的对偶变量为: -17.419035755323737
# agent 28 在 119 次迭代中的对偶变量为: -17.232154232145632
# agent 29 在 119 次迭代中的对偶变量为: -17.639929580245653
# agent 30 在 119 次迭代中的对偶变量为: -17.694429524949328
# agent 31 在 119 次迭代中的对偶变量为: -17.65814855905198
# agent 32 在 119 次迭代中的对偶变量为: -17.682183349154236
# agent 33 在 119 次迭代中的对偶变量为: -17.730447927724192
# agent 34 在 119 次迭代中的对偶变量为: -17.730447927724192
# agent 35 在 119 次迭代中的对偶变量为: -17.782517963521965
# agent 36 在 119 次迭代中的对偶变量为: -17.873245101377268
# agent 37 在 119 次迭代中的对偶变量为: -17.943881617353608
# agent 38 在 119 次迭代中的对偶变量为: -17.860870781696185
# agent 39 在 119 次迭代中的对偶变量为: -17.786245237355192
# agent 40 在 119 次迭代中的对偶变量为: -17.96556258720704
# agent 41 在 119 次迭代中的对偶变量为: -18.016021376500042
# agent 42 在 119 次迭代中的对偶变量为: -18.027435840326074
# agent 43 在 119 次迭代中的对偶变量为: -17.987797295027597
# agent 44 在 119 次迭代中的对偶变量为: -18.04250738336383
# agent 45 在 119 次迭代中的对偶变量为: -18.32799082705564
# agent 46 在 119 次迭代中的对偶变量为: -18.529793831361868
# agent 47 在 119 次迭代中的对偶变量为: -18.501355681873193
# agent 48 在 119 次迭代中的对偶变量为: -18.548401910790606
# agent 49 在 119 次迭代中的对偶变量为: -18.5345935217721
# agent 50 在 119 次迭代中的对偶变量为: -18.65087456810945
# agent 51 在 119 次迭代中的对偶变量为: -18.68872771275002
# agent 52 在 119 次迭代中的对偶变量为: -18.68872771275002
# agent 53 在 119 次迭代中的对偶变量为: -17.42532130598614
# agent 54 在 119 次迭代中的对偶变量为: -17.686141639628786
# *************************
# 迭代步长为: 4.087351016895592e-05
# ****************************************************************************
# 139 次迭代中的结果：
# agent 1 在 139 次迭代中的资源申请量为: -62.92753040489221
# agent 2 在 139 次迭代中的资源申请量为: -62.92753040489221
# agent 3 在 139 次迭代中的资源申请量为: -62.99663634489947
# agent 4 在 139 次迭代中的资源申请量为: 209.46419496932802
# agent 5 在 139 次迭代中的资源申请量为: 210.84070050095593
# agent 6 在 139 次迭代中的资源申请量为: -62.94959134766095
# agent 7 在 139 次迭代中的资源申请量为: -13.14481864476774
# agent 8 在 139 次迭代中的资源申请量为: -62.55020401044424
# agent 9 在 139 次迭代中的资源申请量为: -62.09501898868888
# agent 10 在 139 次迭代中的资源申请量为: 213.25358557262314
# agent 11 在 139 次迭代中的资源申请量为: 1119.3028743953694
# agent 12 在 139 次迭代中的资源申请量为: -62.633366359581885
# agent 13 在 139 次迭代中的资源申请量为: -62.871529245460216
# agent 14 在 139 次迭代中的资源申请量为: -11.433319503934557
# agent 15 在 139 次迭代中的资源申请量为: -62.9449472885966
# agent 16 在 139 次迭代中的资源申请量为: -13.635819015425653
# agent 17 在 139 次迭代中的资源申请量为: -63.0563011226275
# agent 18 在 139 次迭代中的资源申请量为: -63.41523884312142
# agent 19 在 139 次迭代中的资源申请量为: -12.716208619305835
# agent 20 在 139 次迭代中的资源申请量为: 1052.0166340154187
# agent 21 在 139 次迭代中的资源申请量为: 1025.0110988081196
# agent 22 在 139 次迭代中的资源申请量为: -22.724144523753875
# agent 23 在 139 次迭代中的资源申请量为: -22.187371231383175
# agent 24 在 139 次迭代中的资源申请量为: 452.008820352613
# agent 25 在 139 次迭代中的资源申请量为: 455.45360648957694
# agent 26 在 139 次迭代中的资源申请量为: -20.74709510796066
# agent 27 在 139 次迭代中的资源申请量为: 431.6110563340094
# agent 28 在 139 次迭代中的资源申请量为: 424.4496440279834
# agent 29 在 139 次迭代中的资源申请量为: 219.8639840678412
# agent 30 在 139 次迭代中的资源申请量为: 24.34357728240435
# agent 31 在 139 次迭代中的资源申请量为: -61.53603986108175
# agent 32 在 139 次迭代中的资源申请量为: -61.389049393890176
# agent 33 在 139 次迭代中的资源申请量为: -352.52218181154774
# agent 34 在 139 次迭代中的资源申请量为: -3.0220929398767913
# agent 35 在 139 次迭代中的资源申请量为: -1.0370264221219727
# agent 36 在 139 次迭代中的资源申请量为: 229.77516538372828
# agent 37 在 139 次迭代中的资源申请量为: 5.076341118994132
# agent 38 在 139 次迭代中的资源申请量为: -60.02732198791281
# agent 39 在 139 次迭代中的资源申请量为: 1176.7079903406482
# agent 40 在 139 次迭代中的资源申请量为: 233.37937352792846
# agent 41 在 139 次迭代中的资源申请量为: -347.9271965371914
# agent 42 在 139 次迭代中的资源申请量为: -252.18258318422028
# agent 43 在 139 次迭代中的资源申请量为: 234.37579468021804
# agent 44 在 139 次迭代中的资源申请量为: 237.00243850736305
# agent 45 在 139 次迭代中的资源申请量为: 249.5186931356635
# agent 46 在 139 次迭代中的资源申请量为: -339.3266193880978
# agent 47 在 139 次迭代中的资源申请量为: 25.292272590455436
# agent 48 在 139 次迭代中的资源申请量为: 27.297627534848267
# agent 49 在 139 次迭代中的资源申请量为: -338.7200292357045
# agent 50 在 139 次迭代中的资源申请量为: -222.95631937636423
# agent 51 在 139 次迭代中的资源申请量为: 30.908645990802007
# agent 52 在 139 次迭代中的资源申请量为: 30.908645990802007
# agent 53 在 139 次迭代中的资源申请量为: -13.387999164648917
# agent 54 在 139 次迭代中的资源申请量为: -267.4472054311198
# 资源申请量总和为: 5188.424429876519
# ****************************************************************************
# 成本总和为: 48225.64670200962
# ****************************************************************************
# agent 1 在 139 次迭代中的对偶变量为: -17.476358898807987
# agent 2 在 139 次迭代中的对偶变量为: -17.476358898807987
# agent 3 在 139 次迭代中的对偶变量为: -17.466730644610536
# agent 4 在 139 次迭代中的对偶变量为: -17.443346240582883
# agent 5 在 139 次迭代中的对偶变量为: -17.47328523589579
# agent 6 在 139 次迭代中的对偶变量为: -17.47328523589579
# agent 7 在 139 次迭代中的对偶变量为: -17.483492642693946
# agent 8 在 139 次迭代中的对偶变量为: -17.528930276040846
# agent 9 在 139 次迭代中的对偶变量为: -17.592349384381933
# agent 10 在 139 次迭代中的对偶变量为: -17.525765486204552
# agent 11 在 139 次迭代中的对偶变量为: -17.475817246372216
# agent 12 在 139 次迭代中的对偶变量为: -17.517343598584894
# agent 13 在 139 次迭代中的对偶变量为: -17.48416131634701
# agent 14 在 139 次迭代中的对偶变量为: -17.527307020699276
# agent 15 在 139 次迭代中的对偶变量为: -17.47393227406899
# agent 16 在 139 次迭代中的对偶变量为: -17.470923033205104
# agent 17 在 139 次迭代中的对偶变量为: -17.4584177897888
# agent 18 在 139 次迭代中的对偶变量为: -17.408408432943265
# agent 19 在 139 次迭代中的对偶变量为: -17.49446505934577
# agent 20 在 139 次迭代中的对偶变量为: -17.38168387654204
# agent 21 在 139 次迭代中的对偶变量为: -17.25200329647659
# agent 22 在 139 次迭代中的对偶变量为: -17.2382619001919
# agent 23 在 139 次迭代中的对偶变量为: -17.25200329647659
# agent 24 在 139 次迭代中的对偶变量为: -17.267677619102994
# agent 25 在 139 次迭代中的对偶变量为: -17.297991737108276
# agent 26 在 139 次迭代中的对偶变量为: -17.288874365236207
# agent 27 在 139 次迭代中的对偶变量为: -17.48062217315432
# agent 28 在 139 次迭代中的对偶变量为: -17.32894346051269
# agent 29 在 139 次迭代中的对偶变量为: -17.669541653475545
# agent 30 在 139 次迭代中的对偶变量为: -17.70666019907971
# agent 31 在 139 次迭代中的对偶变量为: -17.670229710314924
# agent 32 在 139 次迭代中的对偶变量为: -17.690709304146857
# agent 33 在 139 次迭代中的对偶变量为: -17.742634420739154
# agent 34 在 139 次迭代中的对偶变量为: -17.742634420739154
# agent 35 在 139 次迭代中的对偶变量为: -17.793452123593678
# agent 36 在 139 次迭代中的对偶变量为: -17.88510984709609
# agent 37 在 139 次迭代中的对偶变量为: -17.94995433264625
# agent 38 在 139 次迭代中的对偶变量为: -17.88043333671206
# agent 39 在 139 次迭代中的对偶变量为: -17.82024794204389
# agent 40 在 139 次迭代中的对偶变量为: -17.963501374232443
# agent 41 在 139 次迭代中的对偶变量为: -18.00272896720882
# agent 42 在 139 次迭代中的对偶变量为: -18.01263486391486
# agent 43 在 139 次迭代中的对偶变量为: -17.98517353429474
# agent 44 在 139 次迭代中的对偶变量为: -18.042303037535145
# agent 45 在 139 次迭代中的对偶变量为: -18.31453157570068
# agent 46 在 139 次迭代中的对偶变量为: -18.489556036156113
# agent 47 在 139 次迭代中的对偶变量为: -18.46748217831566
# agent 48 在 139 次迭代中的对偶变量为: -18.518819264892116
# agent 49 在 139 次迭代中的对偶变量为: -18.523891465142185
# agent 50 在 139 次迭代中的对偶变量为: -18.58394986883083
# agent 51 在 139 次迭代中的对偶变量为: -18.61126133736453
# agent 52 在 139 次迭代中的对偶变量为: -18.61126133736453
# agent 53 在 139 次迭代中的对偶变量为: -17.477267221384988
# agent 54 在 139 次迭代中的对偶变量为: -17.71424202823247
# *************************
# 迭代步长为: 3.237726633057685e-05
# ****************************************************************************
# 159 次迭代中的结果：
# agent 1 在 159 次迭代中的资源申请量为: -62.58889317343172
# agent 2 在 159 次迭代中的资源申请量为: -62.58889317343172
# agent 3 在 159 次迭代中的资源申请量为: -62.641820458738124
# agent 4 在 159 次迭代中的资源申请量为: 211.84505191592817
# agent 5 在 159 次迭代中的资源申请量为: 213.0820114282258
# agent 6 在 159 次迭代中的资源申请量为: -62.59970322435217
# agent 7 在 159 次迭代中的资源申请量为: -11.289758544013733
# agent 8 在 159 次迭代中的资源申请量为: -62.26481920130448
# agent 9 在 159 次迭代中的资源申请量为: -61.87124001085438
# agent 10 在 159 次迭代中的资源申请量为: 215.08789083013338
# agent 11 在 159 次迭代中的资源申请量为: 1127.435244004558
# agent 12 在 159 次迭代中的资源申请量为: -62.34131110150629
# agent 13 在 159 次迭代中的资源申请量为: -62.53344039579136
# agent 14 在 159 次迭代中的资源申请量为: -9.887552726719205
# agent 15 在 159 次迭代中的资源申请量为: -62.582762579636345
# agent 16 在 159 次迭代中的资源申请量为: -11.695017432610117
# agent 17 在 159 次迭代中的资源申请量为: -62.6817786878852
# agent 18 在 159 次迭代中的资源申请量为: -62.967794315898644
# agent 19 在 159 次迭代中的资源申请量为: -10.662596142638897
# agent 20 在 159 次迭代中的资源申请量为: 1066.5393627374756
# agent 21 在 159 次迭代中的资源申请量为: 1044.0153388537867
# agent 22 在 159 次迭代中的资源申请量为: -19.070514873820997
# agent 23 在 159 次迭代中的资源申请量为: -18.62259151656706
# agent 24 在 159 次迭代中的资源申请量为: 462.0977595373702
# agent 25 在 159 次迭代中的资源申请量为: 464.9874827061907
# agent 26 在 159 次迭代中的资源申请量为: -17.4120491227496
# agent 27 在 159 次迭代中的资源申请量为: 434.18570988079523
# agent 28 在 159 次迭代中的资源申请量为: 428.17113090255776
# agent 29 在 159 次迭代中的资源申请量为: 221.3282306302564
# agent 30 在 159 次迭代中的资源申请量为: 24.566971537365237
# agent 31 在 159 次迭代中的资源申请量为: -61.38523361073207
# agent 32 在 159 次迭代中的资源申请量为: -61.25614736047711
# agent 33 在 159 次迭代中的资源申请量为: -352.1703559804799
# agent 34 在 159 次迭代中的资源申请量为: -2.244173043714076
# agent 35 在 159 次迭代中的资源申请量为: -0.31912222824545533
# agent 36 在 159 次迭代中的资源申请量为: 230.58486562746617
# agent 37 在 159 次迭代中的资源申请量为: 5.585146465998252
# agent 38 在 159 次迭代中的资源申请量为: -59.86654963944018
# agent 39 在 159 次迭代中的资源申请量为: 1182.1052399675607
# agent 40 在 159 次迭代中的资源申请量为: 233.72184168804753
# agent 41 在 159 次迭代中的资源申请量为: -347.93212790203256
# agent 42 在 159 次迭代中的资源申请量为: -252.25156668520586
# agent 43 在 159 次迭代中的资源申请量为: 234.69384144871944
# agent 44 在 159 次迭代中的资源申请量为: 237.36243090488728
# agent 45 在 159 次迭代中的资源申请量为: 249.32811135218788
# agent 46 在 159 次迭代中的资源申请量为: -339.7332461031474
# agent 47 在 159 次迭代中的资源申请量为: 24.556618111109678
# agent 48 在 159 次迭代中的资源申请量为: 26.636620768930722
# agent 49 在 159 次迭代中的资源申请量为: -338.816218558419
# agent 50 在 159 次迭代中的资源申请量为: -225.02979965814444
# agent 51 在 159 次迭代中的资源申请量为: 29.060811922522465
# agent 52 在 159 次迭代中的资源申请量为: 29.060811922522465
# agent 53 在 159 次迭代中的资源申请量为: -11.493441945981536
# agent 54 在 159 次迭代中的资源申请量为: -265.90207473150076
# 资源申请量总和为: 5291.335931015125
# ****************************************************************************
# 成本总和为: 50011.61207586061
# ****************************************************************************
# agent 1 在 159 次迭代中的对偶变量为: -17.52353986971845
# agent 2 在 159 次迭代中的对偶变量为: -17.52353986971845
# agent 3 在 159 次迭代中的对偶变量为: -17.51616572276585
# agent 4 在 159 次迭代中的对偶变量为: -17.495129879171436
# agent 5 在 159 次迭代中的对偶变量为: -17.52203374856391
# agent 6 在 159 次迭代中的对偶变量为: -17.52203374856391
# agent 7 在 159 次迭代中的对偶变量为: -17.53098218127325
# agent 8 在 159 次迭代中的对偶变量为: -17.56869179995905
# agent 9 在 159 次迭代中的对偶变量为: -17.623527614247703
# agent 10 在 159 次迭代中的对偶变量为: -17.5656616255554
# agent 11 在 159 次迭代中的对偶变量为: -17.52461146402735
# agent 12 在 159 次迭代中的对偶变量为: -17.558034489471535
# agent 13 在 159 次迭代中的对偶变量为: -17.531265883415973
# agent 14 在 159 次迭代中的对偶变量为: -17.56687865019599
# agent 15 在 159 次迭代中的对偶变量为: -17.524394020829586
# agent 16 在 159 次迭代中的对偶变量为: -17.52060755372518
# agent 17 在 159 次迭代中的对偶变量为: -17.510598502531707
# agent 18 在 159 次迭代中的对偶变量为: -17.470749089143105
# agent 19 在 159 次迭代中的对偶变量为: -17.547037538748445
# agent 20 在 159 次迭代中的对偶变量为: -17.45142201986536
# agent 21 在 159 次迭代中的对偶变量为: -17.343261657175884
# agent 22 在 159 次迭代中的对偶变量为: -17.331794819230183
# agent 23 在 159 次迭代中的对偶变量为: -17.343261657175884
# agent 24 在 159 次迭代中的对偶变量为: -17.356460283928858
# agent 25 在 159 次迭代中的对偶变量为: -17.381889847814477
# agent 26 在 159 次迭代中的对偶变量为: -17.37425154245761
# agent 27 在 159 次迭代中的对偶变量为: -17.535153335275243
# agent 28 在 159 次迭代中的对偶变量为: -17.407764552516173
# agent 29 在 159 次迭代中的对偶变量为: -17.701389016208076
# agent 30 在 159 次迭代中的对偶变量为: -17.727178067820848
# agent 31 在 159 次迭代中的对偶变量为: -17.691240941951143
# agent 32 在 159 次迭代中的对偶变量为: -17.709226012854167
# agent 33 在 159 次迭代中的对偶变量为: -17.76254917008092
# agent 34 在 159 次迭代中的对偶变量为: -17.76254917008092
# agent 35 在 159 次迭代中的对偶变量为: -17.811830470956917
# agent 36 在 159 次迭代中的对偶变量为: -17.90272082739739
# agent 37 在 159 次迭代中的对偶变量为: -17.962979749529556
# agent 38 在 159 次迭代中的对偶变量为: -17.902833104935358
# agent 39 在 159 次迭代中的对偶变量为: -17.852631439805364
# agent 40 在 159 次迭代中的对偶变量为: -17.970950056715033
# agent 41 在 159 次迭代中的对偶变量为: -18.002449832233353
# agent 42 在 159 次迭代中的对偶变量为: -18.011286374437596
# agent 43 在 159 次迭代中的对偶变量为: -17.992091051509647
# agent 44 在 159 次迭代中的对偶变量为: -18.050132872181297
# agent 45 在 159 次迭代中的对偶变量为: -18.310386421910085
# agent 46 在 159 次迭代中的对偶变量为: -18.466539337577448
# agent 47 在 159 次迭代中的对偶变量为: -18.448649423644408
# agent 48 在 159 次迭代中的对偶变量为: -18.501897491684627
# agent 49 在 159 次迭代中的对偶变量为: -18.518446764719254
# agent 50 在 159 次迭代中的对偶变量为: -18.543417476282592
# agent 51 在 159 次迭代中的对偶变量为: -18.563956785216575
# agent 52 在 159 次迭代中的对偶变量为: -18.563956785216575
# agent 53 在 159 次迭代中的对偶变量为: -17.525767886182873
# agent 54 在 159 次迭代中的对偶变量为: -17.744446243148623
# *************************
# 迭代步长为: 2.6464682716040347e-05
# ****************************************************************************
# 179 次迭代中的结果：
# agent 1 在 179 次迭代中的资源申请量为: -62.2673087026174
# agent 2 在 179 次迭代中的资源申请量为: -62.2673087026174
# agent 3 在 179 次迭代中的资源申请量为: -62.30865205010176
# agent 4 在 179 次迭代中的资源申请量为: 214.06236835163352
# agent 5 在 179 次迭代中的资源申请量为: 215.19204017015727
# agent 6 在 179 次迭代中的资源申请量为: -62.27030939163602
# agent 7 在 179 次迭代中的资源申请量为: -9.533174069671912
# agent 8 在 179 次迭代中的资源申请量为: -61.98156365364739
# agent 9 在 179 次迭代中的资源申请量为: -61.63297941003605
# agent 10 在 179 次迭代中的资源申请量为: 216.9088526475692
# agent 11 在 179 次迭代中的资源申请量为: 1135.0892232633412
# agent 12 在 179 次迭代中的资源申请量为: -62.05278974818497
# agent 13 在 179 次迭代中的资源申请量为: -62.21243183495812
# agent 14 在 179 次迭代中的资源申请量为: -8.35012074622471
# agent 15 在 179 次迭代中的资源申请量为: -62.245173528294146
# agent 16 在 179 次迭代中的资源申请量为: -9.87674698359059
# agent 17 在 179 次迭代中的资源申请量为: -62.33504147122299
# agent 18 在 179 次迭代中的资源申请量为: -62.56941668109668
# agent 19 在 179 次迭代中的资源申请量为: -8.779689866987017
# agent 20 在 179 次迭代中的资源申请量为: 1079.1717096338998
# agent 21 在 179 次迭代中的资源申请量为: 1059.8794840800444
# agent 22 在 179 次迭代中的资源申请量为: -16.03113469747841
# agent 23 在 179 次迭代中的资源申请量为: -15.646824900297922
# agent 24 在 179 次迭代中的资源申请量为: 470.548043659548
# agent 25 在 179 次迭代中的资源申请量为: 473.03517468242427
# agent 26 在 179 次迭代中的资源申请量为: -14.603845994930753
# agent 27 在 179 次迭代中的资源申请量为: 436.5273615561389
# agent 28 在 179 次迭代中的资源申请量为: 431.3425462809137
# agent 29 在 179 次迭代中的资源申请量为: 222.83135944534192
# agent 30 在 179 次迭代中的资源申请量为: 24.83871754078518
# agent 31 在 179 次迭代中的资源申请量为: -61.2004969172196
# agent 32 在 179 次迭代中的资源申请量为: -61.084649303647424
# agent 33 在 179 次迭代中的资源申请量为: -351.7443071446449
# agent 34 在 179 次迭代中的资源申请量为: -1.3021391256046178
# agent 35 在 179 次迭代中的资源申请量为: 0.5601853296453851
# agent 36 在 179 次迭代中的资源申请量为: 231.54440812513
# agent 37 在 179 次迭代中的资源申请量为: 6.256156645911975
# ...
# agent 61 在 57999 次迭代中的资源申请量为: 45.35594989347403
# agent 62 在 57999 次迭代中的资源申请量为: 37.777916501990724
# agent 63 在 57999 次迭代中的资源申请量为: 44.36024833408177
# agent 64 在 57999 次迭代中的资源申请量为: 50.59248382563158
# agent 65 在 57999 次迭代中的资源申请量为: 48.719342447654434
# agent 66 在 57999 次迭代中的资源申请量为: 53.47780999250294
# agent 67 在 57999 次迭代中的资源申请量为: 44.62937911116489
# agent 68 在 57999 次迭代中的资源申请量为: 38.64566746179317
# agent 69 在 57999 次迭代中的资源申请量为: 49.892139157742264
# agent 70 在 57999 次迭代中的资源申请量为: 43.38409217370307
# agent 71 在 57999 次迭代中的资源申请量为: 51.072439614453316
# agent 72 在 57999 次迭代中的资源申请量为: 51.63101181607402
# agent 73 在 57999 次迭代中的资源申请量为: 68.52493850742536
# agent 74 在 57999 次迭代中的资源申请量为: 63.033563690013715
# agent 75 在 57999 次迭代中的资源申请量为: 68.784860310892
# agent 76 在 57999 次迭代中的资源申请量为: 65.84231131075826
# agent 77 在 57999 次迭代中的资源申请量为: 37.33178559067635
# agent 78 在 57999 次迭代中的资源申请量为: 56.51515954674519
# agent 79 在 57999 次迭代中的资源申请量为: 35.71319766839764
# agent 80 在 57999 次迭代中的资源申请量为: 41.69438982489503
# agent 81 在 57999 次迭代中的资源申请量为: 64.43288578237497
# agent 82 在 57999 次迭代中的资源申请量为: 45.64920279686928
# agent 83 在 57999 次迭代中的资源申请量为: 54.00548947849253
# agent 84 在 57999 次迭代中的资源申请量为: 52.98642785861979
# agent 85 在 57999 次迭代中的资源申请量为: 58.685757530611916
# agent 86 在 57999 次迭代中的资源申请量为: 54.16278250297388
# agent 87 在 57999 次迭代中的资源申请量为: 50.183947875573004
# agent 88 在 57999 次迭代中的资源申请量为: 53.40486804038364
# agent 89 在 57999 次迭代中的资源申请量为: 44.037016821613456
# agent 90 在 57999 次迭代中的资源申请量为: 38.995841039652966
# agent 91 在 57999 次迭代中的资源申请量为: 43.58677066582213
# agent 92 在 57999 次迭代中的资源申请量为: 45.25809138455365
# agent 93 在 57999 次迭代中的资源申请量为: 35.68321481266967
# agent 94 在 57999 次迭代中的资源申请量为: 37.48060785879904
# 资源申请量平均值avg为: 49.99999999999654
# ****************************************************************************
# 平均成本为: 3240.481984531225
# ****************************************************************************
# agent 1 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 2 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 3 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 4 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 5 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 6 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 7 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 8 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 9 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 10 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 11 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 12 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 13 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 14 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 15 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 16 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 17 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 18 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 19 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 20 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 21 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 22 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 23 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 24 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 25 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 26 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 27 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 28 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 29 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 30 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 31 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 32 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 33 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 34 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 35 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 36 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 37 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 38 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 39 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 40 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 41 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 42 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 43 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 44 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 45 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 46 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 47 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 48 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 49 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 50 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 51 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 52 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 53 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 54 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 55 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 56 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 57 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 58 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 59 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 60 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 61 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 62 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 63 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 64 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 65 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 66 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 67 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 68 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 69 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 70 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 71 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 72 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 73 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 74 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 75 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 76 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 77 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 78 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 79 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 80 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 81 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 82 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 83 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 84 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 85 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 86 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 87 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 88 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 89 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 90 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 91 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 92 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 93 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 94 在 57999 次迭代中的对偶变量为: -135.14386653834575
# *************************
# 迭代步长为: 0.11151053484837568
# ****************************************************************************
# 59999 次迭代中的结果：
# agent 1 在 59999 次迭代中的资源申请量为: 56.19880558172988
# agent 2 在 59999 次迭代中的资源申请量为: 56.03871203978166
# agent 3 在 59999 次迭代中的资源申请量为: 60.64796214442871
# agent 4 在 59999 次迭代中的资源申请量为: 37.93333499802675
# agent 5 在 59999 次迭代中的资源申请量为: 57.56693686702461
# agent 6 在 59999 次迭代中的资源申请量为: 55.34212747123894
# agent 7 在 59999 次迭代中的资源申请量为: 65.6236567946489
# agent 8 在 59999 次迭代中的资源申请量为: 46.330946703602365
# agent 9 在 59999 次迭代中的资源申请量为: 65.64268770463663
# agent 10 在 59999 次迭代中的资源申请量为: 54.23914303693835
# agent 11 在 59999 次迭代中的资源申请量为: 65.4520437985654
# agent 12 在 59999 次迭代中的资源申请量为: 38.406222330358624
# agent 13 在 59999 次迭代中的资源申请量为: 49.70058714461363
# agent 14 在 59999 次迭代中的资源申请量为: 41.3659905551611
# agent 15 在 59999 次迭代中的资源申请量为: 42.48853939614691
# agent 16 在 59999 次迭代中的资源申请量为: 49.24530133808371
# agent 17 在 59999 次迭代中的资源申请量为: 50.11852704992918
# agent 18 在 59999 次迭代中的资源申请量为: 46.537297422347486
# agent 19 在 59999 次迭代中的资源申请量为: 44.77392156663175
# agent 20 在 59999 次迭代中的资源申请量为: 50.80339666473046
# agent 21 在 59999 次迭代中的资源申请量为: 69.93387670557085
# agent 22 在 59999 次迭代中的资源申请量为: 61.24199691647269
# agent 23 在 59999 次迭代中的资源申请量为: 61.627787986086716
# agent 24 在 59999 次迭代中的资源申请量为: 39.861352301782716
# agent 25 在 59999 次迭代中的资源申请量为: 52.95065687328203
# agent 26 在 59999 次迭代中的资源申请量为: 49.39633437684004
# agent 27 在 59999 次迭代中的资源申请量为: 47.51919637207136
# agent 28 在 59999 次迭代中的资源申请量为: 40.7413613830987
# agent 29 在 59999 次迭代中的资源申请量为: 44.38273034135506
# agent 30 在 59999 次迭代中的资源申请量为: 39.891745956789116
# agent 31 在 59999 次迭代中的资源申请量为: 65.76280653244551
# agent 32 在 59999 次迭代中的资源申请量为: 59.51901541924079
# agent 33 在 59999 次迭代中的资源申请量为: 48.23750867799392
# agent 34 在 59999 次迭代中的资源申请量为: 36.76532342510125
# agent 35 在 59999 次迭代中的资源申请量为: 41.086702696803464
# agent 36 在 59999 次迭代中的资源申请量为: 62.20889044924783
# agent 37 在 59999 次迭代中的资源申请量为: 40.47023795026076
# agent 38 在 59999 次迭代中的资源申请量为: 58.24733429492913
# agent 39 在 59999 次迭代中的资源申请量为: 37.39554726071002
# agent 40 在 59999 次迭代中的资源申请量为: 50.45313221045784
# agent 41 在 59999 次迭代中的资源申请量为: 36.73569742369616
# agent 42 在 59999 次迭代中的资源申请量为: 56.24242387150355
# agent 43 在 59999 次迭代中的资源申请量为: 61.52373322591861
# agent 44 在 59999 次迭代中的资源申请量为: 47.51525622305313
# agent 45 在 59999 次迭代中的资源申请量为: 41.36197014706921
# agent 46 在 59999 次迭代中的资源申请量为: 67.10436077257359
# agent 47 在 59999 次迭代中的资源申请量为: 65.57090570810219
# agent 48 在 59999 次迭代中的资源申请量为: 40.83836334458436
# agent 49 在 59999 次迭代中的资源申请量为: 39.16390664937778
# agent 50 在 59999 次迭代中的资源申请量为: 63.292999181236645
# agent 51 在 59999 次迭代中的资源申请量为: 36.39727688961264
# agent 52 在 59999 次迭代中的资源申请量为: 46.86937779818014
# agent 53 在 59999 次迭代中的资源申请量为: 43.572511920796444
# agent 54 在 59999 次迭代中的资源申请量为: 49.58201107681077
# agent 55 在 59999 次迭代中的资源申请量为: 47.173391517077015
# agent 56 在 59999 次迭代中的资源申请量为: 42.97971616155657
# agent 57 在 59999 次迭代中的资源申请量为: 36.90486251978384
# agent 58 在 59999 次迭代中的资源申请量为: 59.2566799113546
# agent 59 在 59999 次迭代中的资源申请量为: 59.891586060534515
# agent 60 在 59999 次迭代中的资源申请量为: 40.34169962872796
# agent 61 在 59999 次迭代中的资源申请量为: 45.35594989347582
# agent 62 在 59999 次迭代中的资源申请量为: 37.77791650199216
# agent 63 在 59999 次迭代中的资源申请量为: 44.360248334083515
# agent 64 在 59999 次迭代中的资源申请量为: 50.59248382563358
# agent 65 在 59999 次迭代中的资源申请量为: 48.71934244765636
# agent 66 在 59999 次迭代中的资源申请量为: 53.47780999250507
# agent 67 在 59999 次迭代中的资源申请量为: 44.62937911116663
# agent 68 在 59999 次迭代中的资源申请量为: 38.64566746179467
# agent 69 在 59999 次迭代中的资源申请量为: 49.89213915774424
# agent 70 在 59999 次迭代中的资源申请量为: 43.384092173704765
# agent 71 在 59999 次迭代中的资源申请量为: 51.07243961445531
# agent 72 在 59999 次迭代中的资源申请量为: 51.63101181607605
# agent 73 在 59999 次迭代中的资源申请量为: 68.52493850742809
# agent 74 在 59999 次迭代中的资源申请量为: 63.033563690016244
# agent 75 在 59999 次迭代中的资源申请量为: 68.78486031089474
# agent 76 在 59999 次迭代中的资源申请量为: 65.84231131076093
# agent 77 在 59999 次迭代中的资源申请量为: 37.33178559067781
# agent 78 在 59999 次迭代中的资源申请量为: 56.51515954674745
# agent 79 在 59999 次迭代中的资源申请量为: 35.713197668399026
# agent 80 在 59999 次迭代中的资源申请量为: 41.69438982489667
# agent 81 在 59999 次迭代中的资源申请量为: 64.43288578237754
# agent 82 在 59999 次迭代中的资源申请量为: 45.64920279687104
# agent 83 在 59999 次迭代中的资源申请量为: 54.00548947849467
# agent 84 在 59999 次迭代中的资源申请量为: 52.98642785862186
# agent 85 在 59999 次迭代中的资源申请量为: 58.685757530614225
# agent 86 在 59999 次迭代中的资源申请量为: 54.16278250297603
# agent 87 在 59999 次迭代中的资源申请量为: 50.18394787557497
# agent 88 在 59999 次迭代中的资源申请量为: 53.40486804038577
# agent 89 在 59999 次迭代中的资源申请量为: 44.03701682161516
# agent 90 在 59999 次迭代中的资源申请量为: 38.99584103965445
# agent 91 在 59999 次迭代中的资源申请量为: 43.58677066582381
# agent 92 在 59999 次迭代中的资源申请量为: 45.258091384555385
# agent 93 在 59999 次迭代中的资源申请量为: 35.68321481267107
# agent 94 在 59999 次迭代中的资源申请量为: 37.4806078588005
# 资源申请量平均值avg为: 49.9999999999985
# ****************************************************************************
# 平均成本为: 3240.4819845314896
# ****************************************************************************
# agent 1 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 2 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 3 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 4 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 5 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 6 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 7 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 8 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 9 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 10 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 11 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 12 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 13 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 14 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 15 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 16 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 17 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 18 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 19 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 20 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 21 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 22 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 23 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 24 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 25 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 26 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 27 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 28 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 29 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 30 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 31 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 32 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 33 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 34 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 35 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 36 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 37 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 38 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 39 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 40 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 41 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 42 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 43 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 44 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 45 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 46 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 47 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 48 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 49 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 50 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 51 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 52 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 53 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 54 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 55 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 56 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 57 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 58 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 59 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 60 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 61 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 62 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 63 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 64 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 65 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 66 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 67 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 68 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 69 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 70 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 71 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 72 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 73 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 74 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 75 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 76 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 77 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 78 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 79 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 80 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 81 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 82 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 83 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 84 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 85 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 86 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 87 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 88 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 89 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 90 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 91 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 92 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 93 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 94 在 59999 次迭代中的对偶变量为: -135.1438665383513
# *************************
# 迭代步长为: 0.11075700351730201
# ****************************************************************************
# 2023-05-29 15:40:13.737

# %%
np.savetxt('../data/01-DGD-agent_resource_quantity_small_value_deterministic_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/01-DGD-sum_cost_small_value_deterministic_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/01-DGD-sum_resource_small_value_deterministic_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
