# %% [markdown]
# IWDGD中小值的确定性噪声 对应到DGD算法中是固定的对偶攻击值为-18.6 这样两个算法各自迭代2000次 所有用户的对偶迭代值均在-18.57附近

# %% [markdown]
# 鲁棒聚合器ARC 该鲁棒聚合器跟IWDGD使用鲁棒聚合器的完全相同

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(54,2000)) 
dual_variable = np.zeros(shape=(54,2000))#对偶变量
sum_resource=np.zeros(shape=(1,2000), dtype=np.float64)
sum_cost=np.zeros(shape=(1,2000), dtype=np.float64)
iteration_update = 0.01 #迭代步长
#W=np.zeros(shape=(54,54)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
W=np.loadtxt("double_stochastic_weight_1.txt") #双随机的网络拓扑矩阵W（对角线处非零）
iteration=[]#绘图横坐标
generator_a_values= np.loadtxt("generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("generator_b_values.txt")#每个agent的成本函数中的超参数a
generator_c_values= np.loadtxt("generator_c_values.txt")#每个agent的成本函数中的超参数a
C=np.zeros(shape=(1,2000), dtype=np.float64)#adaptive robust clipping的裁剪参数 
#设置为全局第b大的梯度信息 b为网络中设备损坏的用户上界 每一次迭代就需要计算一次新的C值

# %%
'''for i in range(0,54):
    for j in range(0,54):
        W[i][j]=1/54'''

#对偶变量的初始化 初始化一致
for i in range (0,54):
    dual_variable[i][0]=0
    
#资源量的初始化 资源量的初始化需要和对偶变量的初始值满足某种关系
for i in range (0,54):
    agent_resource_quantity[i][0]=6000/54

iteration.append(0)

#总资源量 初始化
sum=0
for i in range (0,54):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

#用户总成本初始化
sum=0
for i in range(0,54):
    sum=sum+(generator_c_values[i]*(agent_resource_quantity[i][0])*(agent_resource_quantity[i][0])+generator_b_values[i]*agent_resource_quantity[i][0]+generator_a_values[i])
sum_cost[0][0]=sum

# %%
#DGD算法 
def DGD_ARC_determinitic_bias(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,dual_variable,iteration_update,W,iteration,C):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************DGD算法+无计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,54):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    for i in range(0,54):
        print("agent",(i+1),"的初始对偶变量为:",dual_variable[i][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,2000):#迭代次数
        iteration.append(k)
        
        #所有用户对偶变量的迭代 
        #阶段一：梯度下降
        dual_variable_intermediate=[] #存放当前迭代中100个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,54):
            #每个用户对对偶变量先进行一次梯度下降
            if i==48:
                dual_variable_intermediate.append(-18.6)
            else:
                dual_variable_intermediate.append(dual_variable[i][k-1]-iteration_update*((6000/54)-agent_resource_quantity[i][k-1]))       
       
        #阶段二：鲁棒聚合 ARC  
        #先计算当前的clipping阈值C 
        column_data = dual_variable_intermediate
        second_largest = np.partition(np.abs(column_data), -2)[-2]
        C[0][k]=second_largest        
        for i in range(0,54):
            mix_sum_dual=0
            for j in range(0,54):
                if W[i][j]!=0 and np.abs(dual_variable_intermediate[j])>C[0][k]:
                    mix_sum_dual=mix_sum_dual+W[i][j]*(C[0][k]/np.abs(dual_variable_intermediate[j]))*dual_variable_intermediate[j]                  
                elif W[i][j]!=0 and np.abs(dual_variable_intermediate[j])<=C[0][k]:
                    mix_sum_dual=mix_sum_dual+W[i][j]*dual_variable_intermediate[j]
            dual_variable[i][k]=mix_sum_dual                    
        
        #用户资源申请量的迭代
        for i in range (0,54):
            agent_resource_quantity[i][k]=(-dual_variable[i][k]-generator_b_values[i])/(2*generator_c_values[i]) 

        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,54):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,54):
            sum2=sum2+(generator_a_values[i]+(generator_b_values[i]*agent_resource_quantity[i][k])+(generator_c_values[i]*agent_resource_quantity[i][k]*agent_resource_quantity[i][k]))
        sum_cost[0][k]=sum2
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%20==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,54):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            for i in range(0,54):
                print("agent",(i+1),"在",k,"次迭代中的对偶变量为:",dual_variable[i][k])   
            print("*************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=(1/(pow(k+1,1.3)))*(1/26.511) #递减步长
        iteration_update=(1/(pow(k+1,1.5)))*(1/18.8468) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
DGD_ARC_determinitic_bias(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,dual_variable,iteration_update,W,iteration,C)
# Out:
# ****************************DGD算法+无计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 111.11111111111111
# agent 2 的初始资源申请量为: 111.11111111111111
# agent 3 的初始资源申请量为: 111.11111111111111
# agent 4 的初始资源申请量为: 111.11111111111111
# agent 5 的初始资源申请量为: 111.11111111111111
# agent 6 的初始资源申请量为: 111.11111111111111
# agent 7 的初始资源申请量为: 111.11111111111111
# agent 8 的初始资源申请量为: 111.11111111111111
# agent 9 的初始资源申请量为: 111.11111111111111
# agent 10 的初始资源申请量为: 111.11111111111111
# agent 11 的初始资源申请量为: 111.11111111111111
# agent 12 的初始资源申请量为: 111.11111111111111
# agent 13 的初始资源申请量为: 111.11111111111111
# agent 14 的初始资源申请量为: 111.11111111111111
# agent 15 的初始资源申请量为: 111.11111111111111
# agent 16 的初始资源申请量为: 111.11111111111111
# agent 17 的初始资源申请量为: 111.11111111111111
# agent 18 的初始资源申请量为: 111.11111111111111
# agent 19 的初始资源申请量为: 111.11111111111111
# agent 20 的初始资源申请量为: 111.11111111111111
# agent 21 的初始资源申请量为: 111.11111111111111
# agent 22 的初始资源申请量为: 111.11111111111111
# agent 23 的初始资源申请量为: 111.11111111111111
# agent 24 的初始资源申请量为: 111.11111111111111
# agent 25 的初始资源申请量为: 111.11111111111111
# agent 26 的初始资源申请量为: 111.11111111111111
# agent 27 的初始资源申请量为: 111.11111111111111
# agent 28 的初始资源申请量为: 111.11111111111111
# agent 29 的初始资源申请量为: 111.11111111111111
# agent 30 的初始资源申请量为: 111.11111111111111
# agent 31 的初始资源申请量为: 111.11111111111111
# agent 32 的初始资源申请量为: 111.11111111111111
# agent 33 的初始资源申请量为: 111.11111111111111
# agent 34 的初始资源申请量为: 111.11111111111111
# agent 35 的初始资源申请量为: 111.11111111111111
# agent 36 的初始资源申请量为: 111.11111111111111
# agent 37 的初始资源申请量为: 111.11111111111111
# agent 38 的初始资源申请量为: 111.11111111111111
# agent 39 的初始资源申请量为: 111.11111111111111
# agent 40 的初始资源申请量为: 111.11111111111111
# agent 41 的初始资源申请量为: 111.11111111111111
# agent 42 的初始资源申请量为: 111.11111111111111
# agent 43 的初始资源申请量为: 111.11111111111111
# agent 44 的初始资源申请量为: 111.11111111111111
# agent 45 的初始资源申请量为: 111.11111111111111
# agent 46 的初始资源申请量为: 111.11111111111111
# agent 47 的初始资源申请量为: 111.11111111111111
# agent 48 的初始资源申请量为: 111.11111111111111
# agent 49 的初始资源申请量为: 111.11111111111111
# agent 50 的初始资源申请量为: 111.11111111111111
# agent 51 的初始资源申请量为: 111.11111111111111
# agent 52 的初始资源申请量为: 111.11111111111111
# agent 53 的初始资源申请量为: 111.11111111111111
# agent 54 的初始资源申请量为: 111.11111111111111
# *************************
# 初始资源申请量总和为: 6000.000000000006
# *************************
# 初始成本总和为: 139226.02283950621
# *************************
# agent 1 的初始对偶变量为: 0.0
# agent 2 的初始对偶变量为: 0.0
# agent 3 的初始对偶变量为: 0.0
# agent 4 的初始对偶变量为: 0.0
# agent 5 的初始对偶变量为: 0.0
# agent 6 的初始对偶变量为: 0.0
# agent 7 的初始对偶变量为: 0.0
# agent 8 的初始对偶变量为: 0.0
# agent 9 的初始对偶变量为: 0.0
# agent 10 的初始对偶变量为: 0.0
# agent 11 的初始对偶变量为: 0.0
# agent 12 的初始对偶变量为: 0.0
# agent 13 的初始对偶变量为: 0.0
# agent 14 的初始对偶变量为: 0.0
# agent 15 的初始对偶变量为: 0.0
# agent 16 的初始对偶变量为: 0.0
# agent 17 的初始对偶变量为: 0.0
# agent 18 的初始对偶变量为: 0.0
# agent 19 的初始对偶变量为: 0.0
# agent 20 的初始对偶变量为: 0.0
# agent 21 的初始对偶变量为: 0.0
# agent 22 的初始对偶变量为: 0.0
# agent 23 的初始对偶变量为: 0.0
# agent 24 的初始对偶变量为: 0.0
# agent 25 的初始对偶变量为: 0.0
# agent 26 的初始对偶变量为: 0.0
# agent 27 的初始对偶变量为: 0.0
# agent 28 的初始对偶变量为: 0.0
# agent 29 的初始对偶变量为: 0.0
# agent 30 的初始对偶变量为: 0.0
# agent 31 的初始对偶变量为: 0.0
# agent 32 的初始对偶变量为: 0.0
# agent 33 的初始对偶变量为: 0.0
# agent 34 的初始对偶变量为: 0.0
# agent 35 的初始对偶变量为: 0.0
# agent 36 的初始对偶变量为: 0.0
# agent 37 的初始对偶变量为: 0.0
# agent 38 的初始对偶变量为: 0.0
# agent 39 的初始对偶变量为: 0.0
# agent 40 的初始对偶变量为: 0.0
# agent 41 的初始对偶变量为: 0.0
# agent 42 的初始对偶变量为: 0.0
# agent 43 的初始对偶变量为: 0.0
# agent 44 的初始对偶变量为: 0.0
# agent 45 的初始对偶变量为: 0.0
# agent 46 的初始对偶变量为: 0.0
# agent 47 的初始对偶变量为: 0.0
# agent 48 的初始对偶变量为: 0.0
# agent 49 的初始对偶变量为: 0.0
# agent 50 的初始对偶变量为: 0.0
# agent 51 的初始对偶变量为: 0.0
# agent 52 的初始对偶变量为: 0.0
# agent 53 的初始对偶变量为: 0.0
# agent 54 的初始对偶变量为: 0.0
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 19 次迭代中的结果：
# agent 1 在 19 次迭代中的资源申请量为: -67.44587985788642
# agent 2 在 19 次迭代中的资源申请量为: -67.44587985788642
# agent 3 在 19 次迭代中的资源申请量为: -69.09858637559334
# agent 4 在 19 次迭代中的资源申请量为: 156.69738857841241
# agent 5 在 19 次迭代中的资源申请量为: 175.66192185113857
# agent 6 在 19 次迭代中的资源申请量为: -68.44130456438667
# agent 7 在 19 次迭代中的资源申请量为: -40.87188865530375
# agent 8 在 19 次迭代中的资源申请量为: -65.338312168231
# agent 9 在 19 次迭代中的资源申请量为: -62.096262033226104
# agent 10 在 19 次迭代中的资源申请量为: 192.47036339727327
# agent 11 在 19 次迭代中的资源申请量为: 980.7376813631417
# agent 12 在 19 次迭代中的资源申请量为: -65.93872316082677
# agent 13 在 19 次迭代中的资源申请量为: -68.11534260205987
# agent 14 在 19 次迭代中的资源申请量为: -26.64763209837259
# agent 15 在 19 次迭代中的资源申请量为: -69.05683144400672
# agent 16 在 19 次迭代中的资源申请量为: -46.80150230395002
# agent 17 在 19 次迭代中的资源申请量为: -69.65172675577394
# agent 18 在 19 次迭代中的资源申请量为: -72.46796025829403
# agent 19 在 19 次迭代中的资源申请量为: -47.20249225389952
# agent 20 在 19 次迭代中的资源申请量为: 738.707605120278
# agent 21 在 19 次迭代中的资源申请量为: 575.2604677835568
# agent 22 在 19 次迭代中的资源申请量为: -108.49740981184235
# agent 23 在 19 次迭代中的资源申请量为: -106.5507513165375
# agent 24 在 19 次迭代中的资源申请量为: 214.10989597726237
# agent 25 在 19 次迭代中的资源申请量为: 228.77625036536824
# agent 26 在 19 次迭代中的资源申请量为: -103.18222900364299
# agent 27 在 19 次迭代中的资源申请量为: 384.528492942022
# agent 28 在 19 次迭代中的资源申请量为: 331.6760063922917
# agent 29 在 19 次迭代中的资源申请量为: 219.49335591579973
# agent 30 在 19 次迭代中的资源申请量为: 30.073300191688634
# agent 31 在 19 次迭代中的资源申请量为: -57.9879060567579
# agent 32 在 19 次迭代中的资源申请量为: -56.98934437197376
# agent 33 在 19 次迭代中的资源申请量为: -342.58129931711716
# agent 34 在 19 次迭代中的资源申请量为: 18.958130213043017
# agent 35 在 19 次迭代中的资源申请量为: 16.050999681883475
# agent 36 在 19 次迭代中的资源申请量为: 237.77863057696254
# agent 37 在 19 次迭代中的资源申请量为: 8.075896492717172
# agent 38 在 19 次迭代中的资源申请量为: -66.83458030472381
# agent 39 在 19 次迭代中的资源申请量为: 859.37731539627
# agent 40 在 19 次迭代中的资源申请量为: 253.6210236494328
# agent 41 在 19 次迭代中的资源申请量为: -326.8028387862425
# agent 42 在 19 次迭代中的资源申请量为: -184.93470305744225
# agent 43 在 19 次迭代中的资源申请量为: 259.4141883165857
# agent 44 在 19 次迭代中的资源申请量为: 250.83621139066676
# agent 45 在 19 次迭代中的资源申请量为: 278.51274920585956
# agent 46 在 19 次迭代中的资源申请量为: -313.6545237316999
# agent 47 在 19 次迭代中的资源申请量为: 75.83913327548083
# agent 48 在 19 次迭代中的资源申请量为: 69.02983116585811
# agent 49 在 19 次迭代中的资源申请量为: -331.63642249770226
# agent 50 在 19 次迭代中的资源申请量为: -117.6065849168185
# agent 51 在 19 次迭代中的资源申请量为: 120.3383537583716
# agent 52 在 19 次迭代中的资源申请量为: 120.3383537583716
# agent 53 在 19 次迭代中的资源申请量为: -44.40243756827264
# agent 54 在 19 次迭代中的资源申请量为: -270.0087766386484
# 资源申请量总和为: 3458.0734149906184
# ****************************************************************************
# 成本总和为: 21288.066683546574
# ****************************************************************************
# agent 1 在 19 次迭代中的对偶变量为: -16.846835342920116
# agent 2 在 19 次迭代中的对偶变量为: -16.846835342920116
# agent 3 在 19 次迭代中的对偶变量为: -16.61657035463408
# agent 4 在 19 次迭代中的对偶变量为: -16.29566820158047
# agent 5 在 19 次迭代中的对偶变量为: -16.708146800262263
# agent 6 在 19 次迭代中的对偶变量为: -16.708146800262263
# agent 7 在 19 次迭代中的对偶变量为: -16.773679650424224
# agent 8 在 19 次迭代中的对偶变量为: -17.140474318849048
# agent 9 在 19 次迭代中的对偶变量为: -17.59217619595874
# agent 10 在 19 次迭代中的对偶变量为: -17.073730403890693
# agent 11 在 19 次迭代中的对偶变量为: -16.64442608817885
# agent 12 在 19 次迭代中的对偶变量为: -17.05682145689465
# agent 13 在 19 次迭代中的对偶变量为: -16.753561776625407
# agent 14 在 19 次迭代中的对偶变量为: -17.137820618281662
# agent 15 在 19 次迭代中的对偶变量为: -16.62238790223232
# agent 16 在 19 次迭代中的对偶变量为: -16.62188154101888
# agent 17 在 19 次迭代中的对偶变量为: -16.53950351802504
# agent 18 在 19 次迭代中的对偶变量为: -16.147128969052925
# agent 19 在 19 次迭代中的对偶变量为: -16.611616198300172
# agent 20 在 19 次迭代中的对偶变量为: -15.877173919787575
# agent 21 在 19 次迭代中的对偶变量为: -15.09230076629664
# agent 22 在 19 次迭代中的对偶变量为: -15.042466308816836
# agent 23 在 19 次迭代中的对偶变量为: -15.09230076629664
# agent 24 在 19 次迭代中的对偶变量为: -15.174167084599908
# agent 25 在 19 次迭代中的对偶变量为: -15.30323100321524
# agent 26 在 19 次迭代中的对偶变量为: -15.17853493750674
# agent 27 在 19 次迭代中的对偶变量为: -16.483413480512027
# agent 28 在 19 次迭代中的对偶变量为: -15.363997815388739
# agent 29 在 19 次迭代中的对偶变量为: -17.661480491168643
# agent 30 在 19 次迭代中的对偶变量为: -18.232912329405835
# agent 31 在 19 次迭代中的对偶变量为: -18.16457700073615
# agent 32 在 19 次迭代中的对偶变量为: -18.303702606030384
# agent 33 在 19 次迭代中的对偶变量为: -18.3053281334539
# agent 34 在 19 次迭代中的对偶变量为: -18.3053281334539
# agent 35 在 19 次迭代中的对偶变量为: -18.230905591856217
# agent 36 在 19 次迭代中的对偶变量为: -18.059185215048934
# agent 37 在 19 次迭代中的对偶变量为: -18.02674295021356
# agent 38 在 19 次迭代中的对偶变量为: -16.93200526446405
# agent 39 在 19 次迭代中的对偶变量为: -15.91626389237762
# agent 40 在 19 次迭代中的对偶变量为: -18.403757264375162
# agent 41 在 19 次迭代中的对偶变量为: -19.19845211334353
# agent 42 在 19 次迭代中的对偶变量为: -19.32719642463312
# agent 43 在 19 次迭代中的对偶变量为: -18.52975859588574
# agent 44 在 19 次迭代中的对偶变量为: -18.343187597747
# agent 45 在 19 次迭代中的对偶变量为: -18.945152295227444
# agent 46 在 19 次迭代中的对偶变量为: -19.94269933869086
# agent 47 在 19 次迭代中的对偶变量为: -19.76148181185231
# agent 48 在 19 次迭代中的对偶变量为: -19.587163677845968
# agent 49 在 19 次迭代中的对偶变量为: -18.924851940940066
# agent 50 在 19 次迭代中的对偶变量为: -20.64332647804603
# agent 51 在 19 次迭代中的对偶变量为: -20.900661856214313
# agent 52 在 19 次迭代中的对偶变量为: -20.900661856214313
# agent 53 在 19 次迭代中的对偶变量为: -16.68329759825222
# agent 54 在 19 次迭代中的对偶变量为: -17.6641684342677
# *************************
# 迭代步长为: 0.0006406664425248283
# ****************************************************************************
# 39 次迭代中的结果：
# agent 1 在 39 次迭代中的资源申请量为: -65.49301575150838
# agent 2 在 39 次迭代中的资源申请量为: -65.49301575150838
# agent 3 在 39 次迭代中的资源申请量为: -66.0661973325845
# agent 4 在 39 次迭代中的资源申请量为: 185.40920176181106
# agent 5 在 39 次迭代中的资源申请量为: 192.43534477292957
# agent 6 在 39 次迭代中的资源申请量为: -65.82282740614662
# agent 7 在 39 次迭代中的资源申请量为: -27.30126484792511
# agent 8 在 39 次迭代中的资源申请量为: -63.58844229349005
# agent 9 在 39 次迭代中的资源申请量为: -61.467737278368816
# agent 10 在 39 次迭代中的资源申请量为: 206.3033958453134
# agent 11 在 39 次迭代中的资源申请量为: 1052.2312325158323
# agent 12 在 39 次迭代中的资源申请量为: -63.86460979903628
# agent 13 在 39 次迭代中的资源申请量为: -65.40549019049696
# agent 14 在 39 次迭代中的资源申请量为: -16.899817501947883
# agent 15 在 39 次迭代中的资源申请量为: -66.1018635665508
# agent 16 在 39 次迭代中的资源申请量为: -30.302519869485206
# agent 17 在 39 次迭代中的资源申请量为: -66.53346889371014
# agent 18 在 39 次迭代中的资源申请量为: -68.60710331961553
# agent 19 在 39 次迭代中的资源申请量为: -32.27597046884439
# agent 20 在 39 次迭代中的资源申请量为: 865.7341785563714
# agent 21 在 39 次迭代中的资源申请量为: 739.9863124986261
# agent 22 在 39 次迭代中的资源申请量为: -78.00296135528656
# agent 23 在 39 次迭代中的资源申请量为: -75.65178622584365
# agent 24 在 39 次迭代中的资源申请量为: 301.9605022809985
# agent 25 在 39 次迭代中的资源申请量为: 316.35760388121355
# agent 26 在 39 次迭代中的资源申请量为: -70.23745768136705
# agent 27 在 39 次迭代中的资源申请量为: 405.0262436464271
# agent 28 在 39 次迭代中的资源申请量为: 371.13474329355194
# agent 29 在 39 次迭代中的资源申请量为: 218.30216859900563
# agent 30 在 39 次迭代中的资源申请量为: 27.862748751736135
# agent 31 在 39 次迭代中的资源申请量为: -58.88933157540753
# agent 32 在 39 次迭代中的资源申请量为: -58.259392559888994
# agent 33 在 39 次迭代中的资源申请量为: -347.5220051327607
# agent 34 在 39 次迭代中的资源申请量为: 8.03376646348497
# agent 35 在 39 次迭代中的资源申请量为: 8.236586664036594
# agent 36 在 39 次迭代中的资源申请量为: 234.74254536196537
# agent 37 在 39 次迭代中的资源申请量为: 9.567529462783941
# agent 38 在 39 次迭代中的资源申请量为: -62.00000551656384
# agent 39 在 39 次迭代中的资源申请量为: 1073.12191623207
# agent 40 在 39 次迭代中的资源申请量为: 242.7154183711687
# agent 41 在 39 次迭代中的资源申请量为: -339.9859837599034
# agent 42 在 39 次迭代中的资源申请量为: -226.8766009838058
# agent 43 在 39 次迭代中的资源申请量为: 246.51275993652473
# agent 44 在 39 次迭代中的资源申请量为: 246.791577617893
# agent 45 在 39 次迭代中的资源申请量为: 266.32660327588394
# agent 46 在 39 次迭代中的资源申请量为: -325.1187174292333
# agent 47 在 39 次迭代中的资源申请量为: 52.55875629811404
# agent 48 在 39 次迭代中的资源申请量为: 50.393796454338
# agent 49 在 39 次迭代中的资源申请量为: -334.64758142516627
# agent 50 在 39 次迭代中的资源申请量为: -159.37837852211248
# agent 51 在 39 次迭代中的资源申请量为: 86.2959209866855
# agent 52 在 39 次迭代中的资源申请量为: 86.2959209866855
# agent 53 在 39 次迭代中的资源申请量为: -28.736400501594566
# agent 54 在 39 次迭代中的资源申请量为: -270.5775776601951
# 资源申请量总和为: 4233.229249915104
# ****************************************************************************
# 成本总和为: 32847.73660378122
# ****************************************************************************
# agent 1 在 39 次迭代中的对偶变量为: -17.118920087405343
# agent 2 在 39 次迭代中的对偶变量为: -17.118920087405343
# agent 3 在 39 次迭代中的对偶变量为: -17.039060990440333
# agent 4 在 39 次迭代中的对偶变量为: -16.92015013831939
# agent 5 在 39 次迭代中的对偶变量为: -17.072968748811217
# agent 6 在 39 次迭代中的对偶变量为: -17.072968748811217
# agent 7 在 39 次迭代中的对偶变量为: -17.121087619893117
# agent 8 在 39 次迭代中的对偶变量为: -17.384276689017206
# agent 9 在 39 次迭代中的对偶变量为: -17.679746035953986
# agent 10 在 39 次迭代中的对偶变量为: -17.374598859635565
# agent 11 在 39 次迭代中的对偶变量为: -17.073387395094993
# agent 12 在 39 次迭代中的对偶变量为: -17.34579937513947
# agent 13 在 39 次迭代中的对偶变量为: -17.13111467371882
# agent 14 在 39 次迭代中的对偶变量为: -17.387364671950134
# agent 15 在 39 次迭代中的对偶变量为: -17.034091756726742
# agent 16 在 39 次迭代中的对偶变量为: -17.04425549134118
# agent 17 在 39 次迭代中的对偶变量为: -16.97395791291494
# agent 18 在 39 次迭代中的对偶变量为: -16.685046722891247
# agent 19 在 39 次迭代中的对偶变量为: -16.993735155997584
# agent 20 在 39 次迭代中的对偶变量为: -16.487155525427696
# agent 21 在 39 次迭代中的对偶变量为: -15.883314272618403
# agent 22 在 39 次迭代中的对偶变量为: -15.823124189304664
# agent 23 在 39 次迭代中的对偶变量为: -15.883314272618403
# agent 24 在 39 次迭代中的对偶变量为: -15.947252420072786
# agent 25 在 39 次迭代中的对偶变量为: -16.07394691415468
# agent 26 在 39 次迭代中的对偶变量为: -16.021921083357004
# agent 27 在 39 次迭代中的对偶变量为: -16.917555840431326
# agent 28 在 39 次迭代中的对偶变量为: -16.19973386295743
# agent 29 在 39 次迭代中的对偶变量为: -17.63557216702837
# agent 30 在 39 次迭代中的对偶变量为: -18.029882021851957
# agent 31 在 39 次迭代中的对偶变量为: -18.03898498892477
# agent 32 在 39 次迭代中的对偶变量为: -18.126751872200906
# agent 33 在 39 次迭代中的对偶变量为: -18.025664421465216
# agent 34 在 39 次迭代中的对偶变量为: -18.025664421465216
# agent 35 在 39 次迭代中的对偶变量为: -18.030856618599337
# agent 36 在 39 次迭代中的对偶变量为: -17.993150361622746
# agent 37 在 39 次迭代中的对偶变量为: -18.06492875424727
# agent 38 在 39 次迭代中的对偶变量为: -17.605587231399227
# agent 39 在 39 次迭代中的对偶变量为: -17.19873149739242
# agent 40 在 39 次迭代中的对偶变量为: -18.16656034957292
# agent 41 在 39 次迭代中的对偶变量为: -18.452233375254433
# agent 42 在 39 次迭代中的对偶变量为: -18.507316203968564
# agent 43 在 39 次迭代中的对偶变量为: -18.249152528619412
# agent 44 在 39 次迭代中的对偶变量为: -18.255216813189172
# agent 45 在 39 次迭代中的对偶变量为: -18.680103621250474
# agent 46 在 39 次迭代中的对偶变量为: -19.29378011863568
# agent 47 在 39 次迭代中的对偶变量为: -19.16550416123172
# agent 48 在 39 次迭代中的对偶变量为: -19.110081189231053
# agent 49 在 39 次迭代中的对偶变量为: -18.754408301009892
# agent 50 在 39 次迭代中的对偶变量为: -19.826771456649745
# agent 51 在 39 次迭代中的对偶变量为: -20.02917557725915
# agent 52 在 39 次迭代中的对偶变量为: -20.02917557725915
# agent 53 在 39 次迭代中的对偶变量为: -17.08434814715918
# agent 54 在 39 次迭代中的对偶变量为: -17.653049511898505
# *************************
# 迭代步长为: 0.000217853964469636
# ****************************************************************************
# 59 次迭代中的结果：
# agent 1 在 59 次迭代中的资源申请量为: -64.65167560256018
# agent 2 在 59 次迭代中的资源申请量为: -64.65167560256018
# agent 3 在 59 次迭代中的资源申请量为: -64.95741768570872
# agent 4 在 59 次迭代中的资源申请量为: 195.18635472526438
# agent 5 在 59 次迭代中的资源申请量为: 198.77831587905774
# agent 6 在 59 次迭代中的资源申请量为: -64.83263446614771
# agent 7 在 59 次迭代中的资源申请量为: -22.660070475312015
# agent 8 在 59 次迭代中的资源申请量为: -63.474782389030466
# agent 9 在 59 次迭代中的资源申请量为: -62.159065531530835
# agent 10 在 59 次迭代中的资源申请量为: 207.3029391705412
# agent 11 在 59 次迭代中的资源申请量为: 1075.6245097329524
# agent 12 在 59 次迭代中的资源申请量为: -63.64057680628242
# agent 13 在 59 次迭代中的资源申请量为: -64.57155699918421
# agent 14 在 59 次迭代中的资源申请量为: -16.327203438062377
# agent 15 在 59 次迭代中的资源申请量为: -65.00198366996402
# agent 16 在 59 次迭代中的资源申请量为: -24.403334727713666
# agent 17 在 59 次迭代中的资源申请量为: -65.28085668378392
# agent 18 在 59 次迭代中的资源申请量为: -66.63701523311869
# agent 19 在 59 次迭代中的资源申请量为: -25.495671510120804
# agent 20 在 59 次迭代中的资源申请量为: 937.2161463304493
# agent 21 在 59 次迭代中的资源申请量为: 852.0338275350728
# agent 22 在 59 次迭代中的资源申请量为: -56.31763271725071
# agent 23 在 59 次迭代中的资源申请量为: -54.63412344439769
# agent 24 在 59 次迭代中的资源申请量为: 360.96853194111003
# agent 25 在 59 次迭代中的资源申请量为: 371.2678908095574
# agent 26 在 59 次迭代中的资源申请量为: -50.50915278288895
# agent 27 在 59 次迭代中的资源申请量为: 414.7150490838631
# agent 28 在 59 次迭代中的资源申请量为: 392.457140279976
# agent 29 在 59 次迭代中的资源申请量为: 216.5278240802049
# agent 30 在 59 次迭代中的资源申请量为: 25.573222108941675
# agent 31 在 59 次迭代中的资源申请量为: -60.57862353702027
# agent 32 在 59 次迭代中的资源申请量为: -60.187048109885176
# agent 33 在 59 次迭代中的资源申请量为: -350.8415575896492
# agent 34 在 59 次迭代中的资源申请量为: 0.6939247732616616
# agent 35 在 59 次迭代中的资源申请量为: 2.19755485444853
# agent 36 在 59 次迭代中的资源申请量为: 231.2194283381495
# agent 37 在 59 次迭代中的资源申请量为: 7.228284706991411
# agent 38 在 59 次迭代中的资源申请量为: -60.834725747063786
# agent 39 在 59 次迭代中的资源申请量为: 1132.054858745609
# agent 40 在 59 次迭代中的资源申请量为: 238.2159920879898
# agent 41 在 59 次迭代中的资源申请量为: -344.09704896928696
# agent 42 在 59 次迭代中的资源申请量为: -240.11301997795087
# agent 43 在 59 次迭代中的资源申请量为: 240.2272884884475
# agent 44 在 59 次迭代中的资源申请量为: 241.79817536724138
# agent 45 在 59 次迭代中的资源申请量为: 258.36943050933286
# agent 46 在 59 次迭代中的资源申请量为: -331.63502715241447
# agent 47 在 59 次迭代中的资源申请量为: 39.92501100183343
# agent 48 在 59 次迭代中的资源申请量为: 39.80097349575759
# agent 49 在 59 次迭代中的资源申请量为: -336.5222300938727
# agent 50 在 59 次迭代中的资源申请量为: -187.67830203617348
# agent 51 在 59 次迭代中的资源申请量为: 61.83041912418946
# agent 52 在 59 次迭代中的资源申请量为: 61.83041912418946
# agent 53 在 59 次迭代中的资源申请量为: -23.46402621171875
# agent 54 在 59 次迭代中的资源申请量为: -271.465803554338
# 资源申请量总和为: 4575.419669549442
# ****************************************************************************
# 成本总和为: 38076.93224330674
# ****************************************************************************
# agent 1 在 59 次迭代中的对偶变量为: -17.2361406449977
# agent 2 在 59 次迭代中的对偶变量为: -17.2361406449977
# agent 3 在 59 次迭代中的对偶变量为: -17.193542823520946
# agent 4 在 59 次迭代中的对偶变量为: -17.1328032152745
# agent 5 在 59 次迭代中的对偶变量为: -17.210928370369505
# agent 6 在 59 次迭代中的对偶变量为: -17.210928370369505
# agent 7 在 59 次迭代中的对偶变量为: -17.239902195832013
# agent 8 在 59 次迭代中的对偶变量为: -17.40011246886594
# agent 9 在 59 次迭代中的对偶变量为: -17.583426035753934
# agent 10 在 59 次迭代中的对偶变量为: -17.39633892695927
# agent 11 在 59 次迭代中的对偶变量为: -17.213747058397715
# agent 12 在 59 次迭代中的对偶变量为: -17.377012995887895
# agent 13 在 59 次迭代中的对偶变量为: -17.24730324953166
# agent 14 在 59 次迭代中的对偶变量为: -17.402023591985603
# agent 15 在 59 次迭代中的对偶变量为: -17.187333623198594
# agent 16 在 59 次迭代中的对偶变量为: -17.19527463097053
# agent 17 在 59 次迭代中的对偶变量为: -17.148479361675122
# agent 18 在 59 次迭代中的对偶变量为: -16.959531215630506
# agent 19 在 59 次迭代中的对偶变量为: -17.167310809340908
# agent 20 在 59 次迭代中的对偶变量为: -16.830411934678818
# agent 21 在 59 次迭代中的对偶变量为: -16.42136643982342
# agent 22 在 59 次迭代中的对偶变量为: -16.378268602438382
# agent 23 在 59 次迭代中的对偶变量为: -16.42136643982342
# agent 24 在 59 次迭代中的对偶变量为: -16.466523081081768
# agent 25 在 59 次迭代中的对偶变量为: -16.557157439124104
# agent 26 在 59 次迭代中的对偶变量为: -16.526965688758043
# agent 27 在 59 次迭代中的对偶变量为: -17.12276473959622
# agent 28 在 59 次迭代中的对偶变量为: -16.65134223112989
# agent 29 在 59 次迭代中的对偶变量为: -17.596980173744456
# agent 30 在 59 次迭代中的对偶变量为: -17.819598157817857
# agent 31 在 59 次迭代中的对偶变量为: -17.803622697081114
# agent 32 在 59 次迭代中的对偶变量为: -17.858179335042138
# agent 33 在 59 次迭代中的对偶变量为: -17.8377644741955
# agent 34 在 59 次迭代中的对偶变量为: -17.8377644741955
# agent 35 在 59 次迭代中的对偶变量为: -17.876257404273883
# agent 36 在 59 次迭代中的对偶变量为: -17.91652256635475
# agent 37 在 59 次迭代中的对偶变量为: -18.00504408849898
# agent 38 在 59 次迭代中的对偶变量为: -17.76794100056459
# agent 39 在 59 次迭代中的对偶变量为: -17.552329152473654
# agent 40 在 59 次迭代中的对偶变量为: -18.068697827913777
# agent 41 在 59 次迭代中的对偶变量为: -18.219530640142484
# agent 42 在 59 次迭代中的对偶变量为: -18.248570685471016
# agent 43 在 59 次迭代中的对偶变量为: -18.112443524623732
# agent 44 在 59 次迭代中的对偶变量为: -18.1466103142375
# agent 45 在 59 次迭代中的对偶变量为: -18.507035113577988
# agent 46 在 59 次迭代中的对偶变量为: -18.924930923064736
# agent 47 在 59 次迭代中的对偶变量为: -18.842080281646936
# agent 48 在 59 次迭代中的对偶变量为: -18.838904921491395
# agent 49 在 59 次迭代中的对偶变量为: -18.648295687766435
# agent 50 在 59 次迭代中的对偶变量为: -19.27356455179688
# agent 51 在 59 次迭代中的对偶变量为: -19.40285872957925
# agent 52 在 59 次迭代中的对偶变量为: -19.40285872957925
# agent 53 在 59 次迭代中的对偶变量为: -17.21932092898
# agent 54 在 59 次迭代中的对偶变量为: -17.6356864721198
# *************************
# 迭代步长为: 0.00011708044397666381
# ****************************************************************************
# 79 次迭代中的结果：
# agent 1 在 79 次迭代中的资源申请量为: -64.13325818808579
# agent 2 在 79 次迭代中的资源申请量为: -64.13325818808579
# agent 3 在 79 次迭代中的资源申请量为: -64.32394317264574
# agent 4 在 79 次迭代中的资源申请量为: 200.1835606834269
# agent 5 在 79 次迭代中的资源申请量为: 202.5661047111935
# agent 6 在 79 次迭代中的资源申请量为: -64.24132769570319
# agent 7 在 79 次迭代中的资源申请量为: -19.807479422494776
# agent 8 在 79 次迭代中的资源申请量为: -63.347108787225466
# agent 9 在 79 次迭代中的资源申请量为: -62.4425342483805
# agent 10 在 79 次迭代中的资源申请量为: 208.14341270345147
# agent 11 在 79 次迭代中的资源申请量为: 1089.3021591636034
# agent 12 在 79 次迭代中的资源申请量为: -63.47176498790602
# agent 13 在 79 次迭代中的资源申请量为: -64.0698923540122
# agent 14 在 79 次迭代中的资源申请量为: -15.693897505343195
# agent 15 在 79 次迭代中的资源申请量为: -64.33510940948203
# agent 16 在 79 次迭代中的资源申请量为: -20.944032393099693
# agent 17 在 79 次迭代中的资源申请量为: -64.53430230982153
# agent 18 在 79 次迭代中的资源申请量为: -65.43930699522946
# agent 19 在 79 次迭代中的资源申请量为: -21.14216495726545
# agent 20 在 79 次迭代中的资源申请量为: 981.5279611917763
# agent 21 在 79 次迭代中的资源申请量为: 922.316738279003
# agent 22 在 79 次迭代中的资源申请量为: -42.631993968496595
# agent 23 在 79 次迭代中的资源申请量为: -41.45058682750891
# agent 24 在 79 次迭代中的资源申请量为: 397.8781101243916
# agent 25 在 79 次迭代中的资源申请量为: 405.2095959965437
# agent 26 在 79 次迭代中的资源申请量为: -38.44726789324418
# agent 27 在 79 次迭代中的资源申请量为: 420.70359763096405
# agent 28 在 79 次迭代中的资源申请量为: 405.2808598607671
# agent 29 在 79 次迭代中的资源申请量为: 216.360885598676
# agent 30 在 79 次迭代中的资源申请量为: 24.54217029839682
# agent 31 在 79 次迭代中的资源申请量为: -61.353837566894704
# agent 32 在 79 次迭代中的资源申请量为: -61.07938866767631
# agent 33 在 79 次迭代中的资源申请量为: -352.304339562574
# agent 34 在 79 次迭代中的资源申请量为: -2.540423304684958
# agent 35 在 79 次迭代中的资源申请量为: -0.5991693112231133
# agent 36 在 79 次迭代中的资源申请量为: 229.45614394011673
# agent 37 在 79 次迭代中的资源申请量为: 5.589470554899639
# agent 38 在 79 次迭代中的资源申请量为: -60.49152738705189
# agent 39 在 79 次迭代中的资源申请量为: 1153.1540839265456
# agent 40 在 79 次迭代中的资源申请量为: 235.48535724449036
# agent 41 在 79 次迭代中的资源申请量为: -346.1121259983764
# agent 42 在 79 次迭代中的资源申请量为: -246.47749257782235
# agent 43 在 79 次迭代中的资源申请量为: 236.81869691211844
# agent 44 在 79 次迭代中的资源申请量为: 238.86844950665667
# agent 45 在 79 次迭代中的资源申请量为: 253.8221544165105
# agent 46 在 79 次迭代中的资源申请量为: -335.3333924580311
# agent 47 在 79 次迭代中的资源申请量为: 32.83664532296906
# agent 48 在 79 次迭代中的资源申请量为: 33.78896200656664
# agent 49 在 79 次迭代中的资源申请量为: -337.5983899116368
# agent 50 在 79 次迭代中的资源申请量为: -204.33314653012093
# agent 51 在 79 次迭代中的资源申请量为: 47.28529363544134
# agent 52 在 79 次迭代中的资源申请量为: 47.28529363544134
# agent 53 在 79 次迭代中的资源申请量为: -20.33756690624902
# agent 54 在 79 次迭代中的资源申请量为: -271.278258418921
# 资源申请量总和为: 4783.977419438657
# ****************************************************************************
# 成本总和为: 41405.0868024137
# ****************************************************************************
# agent 1 在 79 次迭代中的对偶变量为: -17.30836966968676
# agent 2 在 79 次迭代中的对偶变量为: -17.30836966968676
# agent 3 在 79 次迭代中的对偶变量为: -17.28180229352796
# agent 4 在 79 次迭代中的对偶变量为: -17.241492444864534
# agent 5 在 79 次迭代中的对偶变量为: -17.293312777468458
# agent 6 在 79 次迭代中的对偶变量为: -17.293312777468458
# agent 7 在 79 次迭代中的对偶变量为: -17.312928526784134
# agent 8 在 79 次迭代中的对偶变量为: -17.417900721111025
# agent 9 在 79 次迭代中的对偶变量为: -17.54393147331014
# agent 10 在 79 次迭代中的对偶变量为: -17.41461922630007
# agent 11 在 79 次迭代中的对偶变量为: -17.29581295498162
# agent 12 在 79 次迭代中的对偶变量为: -17.400532871295006
# agent 13 在 79 次迭代中的对偶变量为: -17.317198177884897
# agent 14 在 79 次迭代中的对偶变量为: -17.418236223863214
# agent 15 在 79 次迭代中的对偶变量为: -17.280246546414507
# agent 16 在 79 次迭代中的对偶变量为: -17.283832770736648
# agent 17 在 79 次迭代中的对偶变量为: -17.252493796381806
# agent 18 在 79 次迭代中的对偶变量为: -17.12640311358266
# agent 19 在 79 次迭代中的对偶变量为: -17.278760577094005
# agent 20 在 79 次迭代中的对偶变量为: -17.04319726964291
# agent 21 在 79 次迭代中的对偶变量为: -16.758864977215772
# agent 22 在 79 次迭代中的对偶变量为: -16.728620954406487
# agent 23 在 79 次迭代中的对偶变量为: -16.758864977215772
# agent 24 在 79 次迭代中的对偶变量为: -16.791327369094645
# agent 25 在 79 次迭代中的对偶变量为: -16.855844444769584
# agent 26 在 79 次迭代中的对偶变量为: -16.83574994193295
# agent 27 在 79 次迭代中的对偶变量为: -17.24960219782382
# agent 28 在 79 次迭代中的对偶变量为: -16.922948611851048
# agent 29 在 79 次迭代中的对偶变量为: -17.593349261771202
# agent 30 在 79 次迭代中的对偶变量为: -17.724900173226555
# agent 31 在 79 次迭代中的对偶变量为: -17.69561522715483
# agent 32 在 79 次迭代中的对偶变量为: -17.73385309448733
# agent 33 在 79 次迭代中的对偶变量为: -17.754965163400065
# agent 34 在 79 次迭代中的对偶变量为: -17.754965163400065
# agent 35 在 79 次迭代中的对偶变量为: -17.80466126563269
# agent 36 在 79 次迭代中的对偶变量为: -17.878171130697538
# agent 37 在 79 次迭代中的对偶变量为: -17.96309044620543
# agent 38 在 79 次迭代中的对偶变量为: -17.81575745527161
# agent 39 在 79 次迭代中的对偶变量为: -17.678924503559273
# agent 40 在 79 次迭代中的对偶变量为: -18.009306520067664
# agent 41 在 79 次迭代中的对偶变量为: -18.105469219987903
# agent 42 在 79 次迭代中的对偶变量为: -18.12415797508873
# agent 43 在 79 次迭代中的对偶变量为: -18.038306657838575
# agent 44 在 79 次迭代中的对偶变量为: -18.08288877676978
# agent 45 在 79 次迭代中的对偶变量为: -18.408131858559102
# agent 46 在 79 次迭代中的对偶变量为: -18.715588653305613
# agent 47 在 79 次迭代中的对偶变量为: -18.66061812026801
# agent 48 在 79 次迭代中的对偶变量为: -18.684997427368106
# agent 49 在 79 次迭代中的对偶变量为: -18.587380737441713
# agent 50 在 79 次迭代中的对偶变量为: -18.947995651629196
# agent 51 在 79 次迭代中的对偶变量为: -19.0305035170673
# agent 52 在 79 次迭代中的对偶变量为: -19.0305035170673
# agent 53 在 79 次迭代中的对偶变量为: -17.299358287200025
# agent 54 在 79 次迭代中的对偶变量为: -17.639352604426932
# *************************
# 迭代步长为: 7.556518347445504e-05
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: -63.709655841151836
# agent 2 在 99 次迭代中的资源申请量为: -63.709655841151836
# agent 3 在 99 次迭代中的资源申请量为: -63.838901697915475
# agent 4 在 99 次迭代中的资源申请量为: 203.69616641907677
# agent 5 在 99 次迭代中的资源申请量为: 205.5547791355058
# agent 6 在 99 次迭代中的资源申请量为: -63.77476963239273
# agent 7 在 99 次迭代中的资源申请量为: -17.455897864483703
# agent 8 在 99 次迭代中的资源申请量为: -63.13232676083319
# agent 9 在 99 次迭代中的资源申请量为: -62.45295849691995
# agent 10 在 99 次迭代中的资源申请量为: 209.51794453281502
# agent 11 在 99 次迭代中的资源申请量为: 1100.1250229729455
# agent 12 在 99 次迭代中的资源申请量为: -63.236844479334415
# agent 13 在 99 次迭代中的资源申请量为: -63.65141113576553
# agent 14 在 99 次迭代中的资源申请量为: -14.565383952772764
# agent 15 在 99 次迭代中的资源申请量为: -63.819397099547686
# agent 16 在 99 次迭代中的资源申请量为: -18.26570527537555
# agent 17 在 99 次迭代中的资源申请量为: -63.974861281477985
# agent 18 在 99 次迭代中的资源申请量为: -64.60822560943538
# agent 19 在 99 次迭代中的资源申请量为: -17.87870258976157
# agent 20 在 99 次迭代中的资源申请量为: 1011.5067601917244
# agent 21 在 99 次迭代中的资源申请量为: 968.1204251510478
# agent 22 在 99 次迭代中的资源申请量为: -33.72381675124186
# agent 23 在 99 次迭代中的资源申请量为: -32.85881712596361
# agent 24 在 99 次迭代中的资源申请量为: 421.9554625220022
# agent 25 在 99 次迭代中的资源申请量为: 427.4006211589725
# agent 26 在 99 次迭代中的资源申请量为: -30.60384940017466
# agent 27 在 99 次迭代中的资源申请量为: 425.02091391883135
# agent 28 在 99 次迭代中的资源申请量为: 413.6700139981697
# agent 29 在 99 次迭代中的资源申请量为: 217.0950559479127
# agent 30 在 99 次迭代中的资源申请量为: 24.18190010805734
# agent 31 在 99 次迭代中的资源申请量为: -61.62989879508112
# agent 32 在 99 次迭代中的资源申请量为: -61.418979676094324
# agent 33 在 99 次迭代中的资源申请量为: -352.8062331201874
# agent 34 在 99 次迭代中的资源申请量为: -3.650157013089239
# agent 35 在 99 次迭代中的资源申请量为: -1.6015118207160506
# agent 36 在 99 次迭代中的资源申请量为: 228.87648783159813
# agent 37 在 99 次迭代中的资源申请量为: 4.80905846611937
# agent 38 在 99 次迭代中的资源申请量为: -60.33632796108698
# agent 39 在 99 次迭代中的资源申请量为: 1163.328555747552
# agent 40 在 99 次迭代中的资源申请量为: 233.91716714546675
# agent 41 在 99 次迭代中的资源申请量为: -347.2202001343883
# agent 42 在 99 次迭代中的资源申请量为: -249.92694613447384
# agent 43 在 99 次迭代中的资源申请量为: 235.02785233599081
# agent 44 在 99 次迭代中的资源申请量为: 237.38052187073765
# agent 45 在 99 次迭代中的资源申请量为: 251.3205928011185
# agent 46 在 99 次迭代中的资源申请量为: -337.44254444104394
# agent 47 在 99 次迭代中的资源申请量为: 28.82016475773061
# agent 48 在 99 次迭代中的资源申请量为: 30.360353713695662
# agent 49 在 99 次迭代中的资源申请量为: -338.20722222373615
# agent 50 在 99 次迭代中的资源申请量为: -213.99512899479421
# agent 51 在 99 次迭代中的资源申请量为: 38.814125254783
# agent 52 在 99 次迭代中的资源申请量为: 38.814125254783
# agent 53 在 99 次迭代中的资源申请量为: -17.841829747345244
# agent 54 在 99 次迭代中的资源申请量为: -270.3986174763683
# 资源申请量总和为: 4937.577292862531
# ****************************************************************************
# 成本总和为: 43944.141084953975
# ****************************************************************************
# agent 1 在 99 次迭代中的对偶变量为: -17.36738849027568
# agent 2 在 99 次迭代中的对偶变量为: -17.36738849027568
# agent 3 在 99 次迭代中的对偶变量为: -17.34938118203623
# agent 4 在 99 次迭代中的对偶变量为: -17.31789161961492
# agent 5 在 99 次迭代中的对偶变量为: -17.35831644619725
# agent 6 在 99 次迭代中的对偶变量为: -17.35831644619725
# agent 7 在 99 次迭代中的对偶变量为: -17.373129014669217
# agent 8 在 99 次迭代中的对偶变量为: -17.447825441720155
# agent 9 在 99 次迭代中的对偶变量为: -17.54247910445813
# agent 10 在 99 次迭代中的对偶变量为: -17.444515293588726
# agent 11 在 99 次迭代中的对偶变量为: -17.360750137837673
# agent 12 在 99 次迭代中的对偶变量为: -17.433263406072253
# agent 13 在 99 次迭代中的对偶变量为: -17.375503492098332
# agent 14 在 99 次迭代中的对偶变量为: -17.447126170809018
# agent 15 在 99 次迭代中的对偶变量为: -17.35209867970842
# agent 16 在 99 次迭代中的对偶变量为: -17.352397944950386
# agent 17 在 99 次迭代中的对偶变量为: -17.3304384770968
# agent 18 在 99 次迭代中的对偶变量为: -17.242194358739805
# agent 19 在 99 次迭代中的对偶变量为: -17.362305213702104
# agent 20 在 99 次迭代中的对偶变量为: -17.18715546244066
# agent 21 在 99 次迭代中的对偶变量为: -16.978814281575332
# agent 22 在 99 次迭代中的对偶变量为: -16.95667029116821
# agent 23 在 99 次迭代中的对偶变量为: -16.978814281575332
# agent 24 在 99 次迭代中的对偶变量为: -17.00320807019362
# agent 25 在 99 次迭代中的对偶变量为: -17.051125466198958
# agent 26 在 99 次迭代中的对偶变量为: -17.03654145535553
# agent 27 在 99 次迭代中的对偶变量为: -17.341042956800848
# agent 28 在 99 次迭代中的对偶变量为: -17.100630896481235
# agent 29 在 99 次迭代中的对偶变量为: -17.6093174668671
# agent 30 在 99 次迭代中的对偶变量为: -17.691810797324635
# agent 31 在 99 次迭代中的对偶变量为: -17.657152720476528
# agent 32 在 99 次迭代中的对偶变量为: -17.686539237648482
# agent 33 在 99 次迭代中的对偶变量为: -17.726555980464916
# agent 34 在 99 次迭代中的对偶变量为: -17.726555980464916
# agent 35 在 99 次迭代中的对偶变量为: -17.77900129738967
# agent 36 在 99 次迭代中的对偶变量为: -17.865563610337258
# agent 37 在 99 次迭代中的对偶变量为: -17.943111896732656
# agent 38 在 99 次迭代中的对偶变量为: -17.837380770493596
# agent 39 在 99 次迭代中的对偶变量为: -17.73997133448531
# agent 40 在 99 次迭代中的对偶变量为: -17.9751983854139
# agent 41 在 99 次迭代中的对偶变量为: -18.04274779159309
# agent 42 在 99 次迭代中的对偶变量为: -18.056728056963305
# agent 43 在 99 次迭代中的对偶变量为: -17.9993557883078
# agent 44 在 99 次迭代中的对偶变量为: -18.050526350688543
# agent 45 在 99 次迭代中的对偶变量为: -18.353722893424326
# agent 46 在 99 次迭代中的对偶变量为: -18.59620221445915
# agent 47 在 99 次迭代中的对偶变量为: -18.557796217797904
# agent 48 在 99 次迭代中的对偶变量为: -18.59722505507061
# agent 49 在 99 次迭代中的对偶变量为: -18.55291839324764
# agent 50 在 99 次迭代中的对偶变量为: -18.759123218409762
# agent 51 在 99 次迭代中的对偶变量为: -18.813641606522445
# agent 52 在 99 次迭代中的对偶变量为: -18.813641606522445
# agent 53 在 99 次迭代中的对偶变量为: -17.363249158467962
# agent 54 在 99 次迭代中的对偶变量为: -17.656547825571952
# *************************
# 迭代步长为: 5.3865362416062276e-05
# ****************************************************************************
# 119 次迭代中的结果：
# agent 1 在 119 次迭代中的资源申请量为: -63.32455062025261
# agent 2 在 119 次迭代中的资源申请量为: -63.32455062025261
# agent 3 在 119 次迭代中的资源申请量为: -63.41712947049173
# agent 4 在 119 次迭代中的资源申请量为: 206.62152257631863
# agent 5 在 119 次迭代中的资源申请量为: 208.19083199137222
# agent 6 在 119 次迭代中的资源申请量为: -63.36325886186107
# agent 7 在 119 次迭代中的资源申请量为: -15.32539136942429
# agent 8 在 119 次迭代中的资源申请量为: -62.86931508916402
# agent 9 在 119 次迭代中的资源申请量为: -62.325524269488994
# agent 10 在 119 次迭代中的资源申请量为: 211.20420231626645
# agent 11 在 119 次迭代中的资源申请量为: 1109.6888040418291
# agent 12 在 119 次迭代中的资源申请量为: -62.96140798058312
# agent 13 在 119 次迭代中的资源申请量为: -63.26771435323217
# agent 14 在 119 次迭代中的资源申请量为: -13.157344121186991
# agent 15 在 119 次迭代中的资源申请量为: -63.37734659304723
# agent 16 在 119 次迭代中的资源申请量为: -15.941026721364437
# agent 17 在 119 次迭代中的资源申请量为: -63.506317329922666
# agent 18 在 119 次迭代中的资源申请量为: -63.97244155762918
# agent 19 在 119 次迭代中的资源申请量为: -15.210865824382413
# agent 20 在 119 次迭代中的资源申请量为: 1033.564948326474
# agent 21 在 119 次迭代中的资源申请量为: 1000.0794640706077
# agent 22 在 119 次迭代中的资源申请量为: -27.530221711109665
# agent 23 在 119 次迭代中的资源申请量为: -26.864000528630527
# agent 24 在 119 次迭代中的资源申请量为: 438.80219598081715
# agent 25 在 119 次迭代中的资源申请量为: 443.0435879679738
# agent 26 在 119 次迭代中的资源申请量为: -25.09709974462454
# agent 27 在 119 次迭代中的资源申请量为: 428.4600149454042
# agent 28 在 119 次迭代中的资源申请量为: 419.6403570423457
# agent 29 在 119 次迭代中的资源申请量为: 218.2670538969938
# agent 30 在 119 次迭代中的资源申请量为: 24.15227401249656
# agent 31 在 119 次迭代中的资源申请量为: -61.66196974380827
# agent 32 在 119 次迭代中的资源申请量为: -61.48950092721226
# agent 33 在 119 次迭代中的资源申请量为: -352.82972966368095
# agent 34 在 119 次迭代中的资源申请量为: -3.7021100735544485
# agent 35 在 119 次迭代中的资源申请量为: -1.661888637660841
# agent 36 在 119 次迭代中的资源申请量为: 229.017912443686
# agent 37 在 119 次迭代中的资源申请量为: 4.65880720076306
# agent 38 在 119 次迭代中的资源申请量为: -60.20430649841038
# agent 39 在 119 次迭代中的资源申请量为: 1170.1734158022682
# agent 40 在 119 次迭代中的资源申请量为: 233.23649402356193
# agent 41 在 119 次迭代中的资源申请量为: -347.7852874564076
# agent 42 在 119 次迭代中的资源申请量为: -251.6905039702285
# agent 43 在 119 次迭代中的资源申请量为: 234.27558728891523
# agent 44 在 119 次迭代中的资源申请量为: 236.8208986596938
# agent 45 在 119 次迭代中的资源申请量为: 250.01848578637257
# agent 46 在 119 次迭代中的资源申请量为: -338.65573050918414
# agent 47 在 119 次迭代中的资源申请量为: 26.52973281039403
# agent 48 在 119 次迭代中的资源申请量为: 28.388215219489197
# agent 49 在 119 次迭代中的资源申请量为: -338.54775737985847
# agent 50 在 119 次迭代中的资源申请量为: -219.66301898002072
# agent 51 在 119 次迭代中的资源申请量为: 33.82785044576675
# agent 52 在 119 次迭代中的资源申请量为: 33.82785044576675
# agent 53 在 119 次迭代中的资源申请量为: -15.625002410841887
# agent 54 在 119 次迭代中的资源申请量为: -269.1384578567926
# 资源申请量总和为: 5064.999736421269
# ****************************************************************************
# 成本总和为: 46100.88604203948
# ****************************************************************************
# agent 1 在 119 次迭代中的对偶变量为: -17.421043660282685
# agent 2 在 119 次迭代中的对偶变量为: -17.421043660282685
# agent 3 在 119 次迭代中的对偶变量为: -17.40814501939427
# agent 4 在 119 次迭代中的对偶变量为: -17.38151811603493
# agent 5 在 119 次迭代中的对偶变量为: -17.415650595812345
# agent 6 在 119 次迭代中的对偶变量为: -17.415650595812345
# agent 7 在 119 次迭代中的对偶变量为: -17.42766998094274
# agent 8 在 119 次迭代中的对偶变量为: -17.484469805887134
# agent 9 在 119 次迭代中的对偶变量为: -17.560234005629177
# agent 10 在 119 次迭代中的对偶变量为: -17.481191400378794
# agent 11 在 119 次迭代中的对偶变量为: -17.418132824250975
# agent 12 在 119 次迭代中的对偶变量为: -17.471638871697277
# agent 13 在 119 次迭代中的对偶变量为: -17.428962430021574
# agent 14 在 119 次迭代中的对偶变量为: -17.483171990497613
# agent 15 在 119 次迭代中的对偶变量为: -17.4136878085771
# agent 16 在 119 次迭代中的对偶变量为: -17.41190971593307
# agent 17 在 119 次迭代中的对偶变量为: -17.395718831691195
# agent 18 在 119 次迭代中的对偶变量为: -17.330775607541757
# agent 19 在 119 次迭代中的对偶变量为: -17.43060183489581
# agent 20 在 119 次迭代中的对偶变量为: -17.293078881863728
# agent 21 在 119 次迭代中的对偶变量为: -17.13228158646706
# agent 22 在 119 次迭代中的对偶变量为: -17.115226324195593
# agent 23 在 119 次迭代中的对偶变量为: -17.13228158646706
# agent 24 在 119 次迭代中的对偶变量为: -17.15145932463119
# agent 25 在 119 次迭代中的对偶变量为: -17.18878357411817
# agent 26 在 119 次迭代中的对偶变量为: -17.177514246537612
# agent 27 在 119 次迭代中的对偶变量为: -17.413883116543662
# agent 28 在 119 次迭代中的对偶变量为: -17.227082762156883
# agent 29 在 119 次迭代中的对偶变量为: -17.634808422259614
# agent 30 在 119 次迭代中的对偶变量为: -17.68908975895176
# agent 31 在 119 次迭代中的对偶变量为: -17.65268440347417
# agent 32 在 119 次迭代中的对偶变量为: -17.676713793815225
# agent 33 在 119 次迭代中的对偶变量为: -17.725225982117006
# agent 34 在 119 次迭代中的对偶变量为: -17.725225982117006
# agent 35 在 119 次迭代中的对偶变量为: -17.777455650875883
# agent 36 在 119 次迭代中的对偶变量为: -17.86863959565017
# agent 37 在 119 次迭代中的对偶变量为: -17.939265464339535
# agent 38 在 119 次迭代中的对偶变量为: -17.855774792802475
# agent 39 在 119 次迭代中的对偶变量为: -17.78104049481361
# agent 40 在 119 次迭代中的对偶变量为: -17.96039374501247
# agent 41 在 119 次迭代中的对偶变量为: -18.010761588817505
# agent 42 在 119 次迭代中的对偶变量为: -18.022254028389973
# agent 43 在 119 次迭代中的对偶变量为: -17.982994023533905
# agent 44 在 119 次迭代中的对偶变量为: -18.03835454584834
# agent 45 在 119 次迭代中的对偶变量为: -18.325402065853602
# agent 46 在 119 次迭代中的对偶变量为: -18.527531030258142
# agent 47 在 119 次迭代中的对偶变量为: -18.499161159946087
# agent 48 在 119 次迭代中的对偶变量为: -18.546738309618924
# agent 49 在 119 次迭代中的对偶变量为: -18.533642741270494
# agent 50 在 119 次迭代中的对偶变量为: -18.648327304978555
# agent 51 在 119 次迭代中的对偶变量为: -18.68599297141163
# agent 52 在 119 次迭代中的对偶变量为: -18.68599297141163
# agent 53 在 119 次迭代中的对偶变量为: -17.419999938282448
# agent 54 在 119 次迭代中的对偶变量为: -17.681181425815417
# *************************
# 迭代步长为: 4.087351016895592e-05
# ****************************************************************************
# 139 次迭代中的结果：
# agent 1 在 139 次迭代中的资源申请量为: -62.96403969651206
# agent 2 在 139 次迭代中的资源申请量为: -62.96403969651206
# agent 3 在 139 次迭代中的资源申请量为: -63.032970033697275
# agent 4 在 139 次迭代中的资源申请量为: 209.22973341410201
# agent 5 在 139 次迭代中的资源申请量为: 210.6083943786205
# agent 6 在 139 次迭代中的资源申请量为: -62.98585635319327
# agent 7 在 139 次迭代中的资源申请量为: -13.341789550622707
# agent 8 在 139 次迭代中的资源申请量为: -62.586550080257354
# agent 9 在 139 次迭代中的资源申请量为: -62.13112858842554
# agent 10 在 139 次迭代中的资源申请量为: 213.02024983186
# agent 11 在 139 次迭代中的资源申请量为: 1118.462949518227
# agent 12 在 139 次迭代中的资源申请量为: -62.669890822077555
# agent 13 在 139 次迭代中的资源申请量为: -62.907778755682656
# agent 14 在 139 次迭代中的资源申请量为: -11.631637909928493
# agent 15 在 139 次迭代中的资源申请量为: -62.98081226744757
# agent 16 在 139 次迭代中的资源申请量为: -13.83249653027524
# agent 17 在 139 次迭代中的资源申请量为: -63.092334193944374
# agent 18 在 139 次迭代中的资源申请量为: -63.45078221952894
# agent 19 在 139 次迭代中的资源申请量为: -12.905051118252963
# agent 20 在 139 次迭代中的资源申请量为: 1051.0064092047223
# agent 21 在 139 次迭代中的资源申请量为: 1024.0115213736663
# agent 22 在 139 次迭代中的资源申请量为: -22.91146312474082
# agent 23 在 139 次迭代中的资源申请量为: -22.374870092330273
# agent 24 在 139 次迭代中的资源申请量为: 451.4625961943099
# agent 25 在 139 次迭代中的资源申请量为: 454.9060577640418
# agent 26 在 139 次迭代中的资源申请量为: -20.93550795374835
# agent 27 在 139 次迭代中的资源申请量为: 431.38267182359453
# agent 28 在 139 次迭代中的资源申请量为: 424.2212919810714
# agent 29 在 139 次迭代中的资源申请量为: 219.65121520500998
# agent 30 在 139 次迭代中的资源申请量为: 24.291142368548105
# agent 31 在 139 次迭代中的资源申请量为: -61.57179312403207
# agent 32 在 139 次迭代中的资源申请量为: -61.424668640350724
# agent 33 在 139 次迭代中的资源申请量为: -352.60445515633126
# agent 34 在 139 次迭代中的资源申请量为: -3.2040070183192437
# agent 35 在 139 次迭代中的资源申请量为: -1.2110278619921477
# agent 36 在 139 次迭代中的资源申请量为: 229.59242957893304
# agent 37 在 139 次迭代中的资源申请量为: 4.925429153958826
# agent 38 在 139 次迭代中的资源申请量为: -60.05707546935881
# agent 39 在 139 次迭代中的资源申请量为: 1176.0060648115452
# agent 40 在 139 次迭代中的资源申请量为: 233.18717771096124
# agent 41 在 139 次迭代中的资源申请量为: -348.0019802062624
# agent 42 在 139 次迭代中的资源申请量为: -252.39657525790554
# agent 43 在 139 次迭代中的资源申请量为: 234.19429061038417
# agent 44 在 139 次迭代中的资源申请量为: 236.84378075086872
# agent 45 在 139 次迭代中的资源申请量为: 249.4225315973566
# agent 46 在 139 次迭代中的资源申请量为: -339.35638582576985
# agent 47 在 139 次迭代中的资源申请量为: 25.227321646333344
# agent 48 在 139 次迭代中的资源申请量为: 27.249239625834058
# agent 49 在 139 次迭代中的资源申请量为: -338.7330520629786
# agent 50 在 139 次迭代中的资源申请量为: -223.04677402253736
# agent 51 在 139 次迭代中的资源申请量为: 30.835883402601514
# agent 52 在 139 次迭代中的资源申请量为: 30.835883402601514
# agent 53 在 139 次迭代中的资源申请量为: -13.584896518895327
# agent 54 在 139 次迭代中的资源申请量为: -267.67460267880904
# 资源申请量总和为: 5178.007972518431
# ****************************************************************************
# 成本总和为: 48042.71272999441
# ****************************************************************************
# agent 1 在 139 次迭代中的对偶变量为: -17.47127220524376
# agent 2 在 139 次迭代中的对偶变量为: -17.47127220524376
# agent 3 在 139 次迭代中的对偶变量为: -17.461668417085093
# agent 4 在 139 次迭代中的对偶变量为: -17.438246701756718
# agent 5 在 139 次迭代中的对偶变量为: -17.468232577734994
# agent 6 在 139 次迭代中的对偶变量为: -17.468232577734994
# agent 7 在 139 次迭代中的对偶变量为: -17.47845018750406
# agent 8 在 139 次迭代中的对偶变量为: -17.523866323518064
# agent 9 在 139 次迭代中的对偶变量为: -17.587318378289023
# agent 10 在 139 次迭代中的对偶变量为: -17.520690433842955
# agent 11 在 139 次迭代中的对偶变量为: -17.470777697109362
# agent 12 在 139 次迭代中的对偶变量为: -17.512254791323222
# agent 13 在 139 次迭代中的对偶变量为: -17.479110817085758
# agent 14 在 139 次迭代中的对偶变量为: -17.52223006950583
# agent 15 在 139 次迭代中的对偶变量为: -17.4689353500256
# agent 16 在 139 次迭代中的对偶变量为: -17.465888088824954
# agent 17 在 139 次迭代中的对偶变量为: -17.453397446094506
# agent 18 在 139 次迭代中的对偶变量为: -17.40345631648191
# agent 19 在 139 次迭代中的对偶变量为: -17.489630691372724
# agent 20 在 139 次迭代中的对偶变量为: -17.376832777001077
# agent 21 在 139 次迭代中的对偶变量为: -17.247203325636345
# agent 22 在 139 次迭代中的对偶变量为: -17.233466544006635
# agent 23 在 139 次迭代中的对偶变量为: -17.247203325636345
# agent 24 在 139 次迭代中的对偶变量为: -17.262870846509927
# agent 25 在 139 次迭代中的对偶变量为: -17.293173308323567
# agent 26 在 139 次迭代中的对偶变量为: -17.284050996384043
# agent 27 在 139 次迭代中的对偶变量为: -17.475784989223733
# agent 28 在 139 次迭代中的对偶变量为: -17.324106964159093
# agent 29 在 139 次迭代中的对偶变量为: -17.664913930708966
# agent 30 在 139 次迭代中的对偶变量为: -17.70184426198167
# agent 31 在 139 次迭代中的对偶变量为: -17.665248351201107
# agent 32 在 139 次迭代中的对偶变量为: -17.685746617014495
# agent 33 在 139 次迭代中的对偶变量为: -17.737977420331028
# agent 34 在 139 次迭代中的对偶变量为: -17.737977420331028
# agent 35 在 139 次迭代中的对偶变量为: -17.788997686733
# agent 36 在 139 次迭代中的对偶变量为: -17.881135343341793
# agent 37 在 139 次迭代中的对偶变量为: -17.946090986341346
# agent 38 在 139 次迭代中的对偶变量为: -17.876287903156115
# agent 39 在 139 次迭代中的对偶变量为: -17.81603638886927
# agent 40 在 139 次迭代中的对偶变量为: -17.959321115213406
# agent 41 在 139 次迭代中的对偶变量为: -17.998495912404728
# agent 42 在 139 次迭代中的对偶变量为: -18.008451746858462
# agent 43 在 139 次迭代中的对偶变量为: -17.981225820775855
# agent 44 在 139 次迭代中的对偶变量为: -18.038852231331393
# agent 45 在 139 次迭代中的对偶变量为: -18.312440062242505
# agent 46 在 139 次迭代中的对偶变量为: -18.487871136718127
# agent 47 在 139 次迭代中的对偶变量为: -18.465819434146134
# agent 48 在 139 次迭代中的对偶变量为: -18.517580534421352
# agent 49 在 139 次迭代中的对偶变量为: -18.523154321027164
# agent 50 在 139 次迭代中的对偶变量为: -18.58218166140744
# agent 51 在 139 次迭代中的对偶变量为: -18.6093986151066
# agent 52 在 139 次迭代中的对偶变量为: -18.6093986151066
# agent 53 在 139 次迭代中的对偶变量为: -17.47222664911628
# agent 54 在 139 次迭代中的对偶变量为: -17.70979686683464
# *************************
# 迭代步长为: 3.237726633057685e-05
# ****************************************************************************
# 159 次迭代中的结果：
# agent 1 在 159 次迭代中的资源申请量为: -62.623465232160264
# agent 2 在 159 次迭代中的资源申请量为: -62.623465232160264
# agent 3 在 159 次迭代中的资源申请量为: -62.676304149452065
# agent 4 在 159 次迭代中的资源申请量为: 211.62277504265163
# agent 5 在 159 次迭代中的资源申请量为: 212.86147915863805
# agent 6 在 159 次迭代中的资源申请量为: -62.634130229100265
# agent 7 在 159 次迭代中的资源申请量为: -11.476727609376901
# agent 8 在 159 次迭代中的资源申请量为: -62.29906785660257
# agent 9 在 159 次迭代中的资源申请量为: -61.90524546286506
# agent 10 在 159 次迭代中的资源申请量为: 214.86821712442156
# agent 11 在 159 次迭代中的资源申请量为: 1126.6377523638816
# agent 12 在 159 次迭代中的资源申请量为: -62.37570415029445
# agent 13 在 159 次迭代中的资源申请量为: -62.56780683374223
# agent 14 在 159 次迭代中的资源申请量为: -10.074321950856445
# agent 15 在 159 次迭代中的资源申请量为: -62.616900954668644
# agent 16 在 159 次迭代中的资源申请量为: -11.881957527952457
# agent 17 在 159 次迭代中的资源申请量为: -62.71601961483909
# agent 18 在 159 次迭代中的资源申请量为: -63.00159530369275
# agent 19 在 159 次迭代中的资源申请量为: -10.845780260445164
# agent 20 在 159 次迭代中的资源申请量为: 1065.5689244023692
# agent 21 在 159 次迭代中的资源申请量为: 1043.0584083852189
# agent 22 在 159 次迭代中的资源申请量为: -19.249817038265864
# agent 23 在 159 次迭代中的资源申请量为: -18.80209073961636
# agent 24 在 159 次迭代中的资源申请量为: 461.5736622338495
# agent 25 在 159 次迭代中的资源申请量为: 464.4607917868872
# agent 26 在 159 次迭代中的资源申请量为: -17.592685285395813
# agent 27 在 159 次迭代中的资源申请量为: 433.95807368914063
# agent 28 在 159 次迭代中的资源申请量为: 427.95161018243624
# agent 29 在 159 次迭代中的资源申请量为: 221.10567979049947
# agent 30 在 159 次迭代中的资源申请量为: 24.515740616970746
# agent 31 在 159 次迭代中的资源申请量为: -61.41883168381522
# agent 32 在 159 次迭代中的资源申请量为: -61.28963014407375
# agent 33 在 159 次迭代中的资源申请量为: -352.25380370138083
# agent 34 在 159 次迭代中的资源申请量为: -2.42868377784991
# agent 35 在 159 次迭代中的资源申请量为: -0.517607826225619
# agent 36 在 159 次迭代中的资源申请量为: 230.29623083316628
# agent 37 在 159 次迭代中的资源申请量为: 5.336611468862995
# agent 38 在 159 次迭代中的资源申请量为: -59.900036609363696
# agent 39 在 159 次迭代中的资源申请量为: 1181.389997638843
# agent 40 在 159 次迭代中的资源申请量为: 233.5149562766972
# agent 41 在 159 次迭代中的资源申请量为: -348.007868784385
# agent 42 在 159 次迭代中的资源申请量为: -252.48049129292014
# agent 43 在 159 次迭代中的资源申请量为: 234.44046336123506
# agent 44 在 159 次迭代中的资源申请量为: 237.00899900860682
# agent 45 在 159 次迭代中的资源申请量为: 248.6299009828443
# agent 46 在 159 次迭代中的资源申请量为: -339.9431743385781
# agent 47 在 159 次迭代中的资源申请量为: 24.05151881956266
# agent 48 在 159 次迭代中的资源申请量为: 25.915384522101625
# agent 49 在 159 次迭代中的资源申请量为: -339.29568797262056
# agent 50 在 159 次迭代中的资源申请量为: -225.415036375002
# agent 51 在 159 次迭代中的资源申请量为: 28.85301871999507
# agent 52 在 159 次迭代中的资源申请量为: 28.85301871999507
# agent 53 在 159 次迭代中的资源申请量为: -11.68038105263308
# agent 54 在 159 次迭代中的资源申请量为: -266.16354642811325
# 资源申请量总和为: 5277.7153497104255
# ****************************************************************************
# 成本总和为: 49769.006370269686
# ****************************************************************************
# agent 1 在 159 次迭代中的对偶变量为: -17.51872308306404
# agent 2 在 159 次迭代中的对偶变量为: -17.51872308306404
# agent 3 在 159 次迭代中的对偶变量为: -17.51136124807344
# agent 4 在 159 次迭代中的对偶变量为: -17.490295357177672
# agent 5 在 159 次迭代中的对偶变量为: -17.517237171700376
# agent 6 在 159 次迭代中的对偶变量为: -17.517237171700376
# agent 7 在 159 次迭代中的对偶变量为: -17.52619577319995
# agent 8 在 159 次迭代中的对偶变量为: -17.56392007181099
# agent 9 在 159 次迭代中的对偶变量为: -17.618789770640863
# agent 10 在 159 次迭代中的对偶变量为: -17.56088372245617
# agent 11 在 159 次迭代中的对偶变量为: -17.51982651418329
# agent 12 在 159 次迭代中的对偶变量为: -17.553242643556075
# agent 13 在 159 次迭代中的对偶变量为: -17.52647774508203
# agent 14 在 159 次迭代中的对偶变量为: -17.562097358058075
# agent 15 在 159 次迭代中的对偶变量为: -17.519637657589836
# agent 16 在 159 次迭代中的对偶变量为: -17.515821887284417
# agent 17 在 159 次迭代中的对偶变量为: -17.50582785114293
# agent 18 在 159 次迭代中的对偶变量为: -17.466039732717704
# agent 19 在 159 次迭代中的对偶变量为: -17.542348025332604
# agent 20 在 159 次迭代中的对偶变量为: -17.446761974980177
# agent 21 在 159 次迭代中的对偶变量为: -17.33866647706582
# agent 22 在 159 次迭代中的对偶变量为: -17.327204683820394
# agent 23 在 159 次迭代中的对偶变量为: -17.33866647706582
# agent 24 在 159 次迭代中的对偶变量为: -17.351848227657875
# agent 25 在 159 次迭代中的对偶变量为: -17.377254967724607
# agent 26 在 159 次迭代中的对偶变量为: -17.369627256693867
# agent 27 在 159 次迭代中的对偶变量为: -17.530332000736
# agent 28 在 159 次迭代中的对偶变量为: -17.403115103664
# agent 29 在 159 次迭代中的对偶变量为: -17.696548535443362
# agent 30 在 159 次迭代中的对偶变量为: -17.722472712706296
# agent 31 在 159 次迭代中的对偶变量为: -17.68655985682076
# agent 32 在 159 次迭代中的对偶变量为: -17.70456099054678
# agent 33 在 159 次迭代中的对偶变量为: -17.757825695287043
# agent 34 在 159 次迭代中的对偶变量为: -17.757825695287043
# agent 35 在 159 次迭代中的对偶变量为: -17.806749239648624
# agent 36 在 159 次迭代中的对偶变量为: -17.896443020621366
# agent 37 在 159 次迭代中的对偶变量为: -17.956617253602893
# agent 38 在 159 次迭代中的对偶变量为: -17.898167499363794
# agent 39 在 159 次迭代中的对偶变量为: -17.848339985833057
# agent 40 在 159 次迭代中的对偶变量为: -17.966450299018163
# agent 41 在 159 次迭代中的对偶变量为: -17.998162595328676
# agent 42 在 159 次迭代中的对偶变量为: -18.006811356205997
# agent 43 在 159 次迭代中的对偶变量为: -17.98658007810686
# agent 44 在 159 次迭代中的对偶变量为: -18.042445728437198
# agent 45 在 159 次迭代中的对偶变量为: -18.295200346376863
# agent 46 在 159 次迭代中的对偶变量为: -18.454656559739128
# agent 47 在 159 次迭代中的对偶变量为: -18.435718881780804
# agent 48 在 159 次迭代中的对偶变量为: -18.483433843765802
# agent 49 在 159 次迭代中的对偶变量为: -18.49130687799779
# agent 50 在 159 次迭代中的对偶变量为: -18.53588686894146
# agent 51 在 159 次迭代中的对偶变量为: -18.558637279231874
# agent 52 在 159 次迭代中的对偶变量为: -18.558637279231874
# agent 53 在 159 次迭代中的对偶变量为: -17.520982245052593
# agent 54 在 159 次迭代中的对偶变量为: -17.739334994423242
# *************************
# 迭代步长为: 2.6464682716040347e-05
# ****************************************************************************
# 179 次迭代中的结果：
# agent 1 在 179 次迭代中的资源申请量为: -62.30312688582405
# agent 2 在 179 次迭代中的资源申请量为: -62.30312688582405
# agent 3 在 179 次迭代中的资源申请量为: -62.344920834532125
# agent 4 在 179 次迭代中的资源申请量为: 213.83728091665355
# agent 5 在 179 次迭代中的资源申请量为: 214.9578120423374
# agent 6 在 179 次迭代中的资源申请量为: -62.30687443893575
# agent 7 在 179 次迭代中的资源申请量为: -9.734188347664679
# agent 8 在 179 次迭代中的资源申请量为: -62.018493333150225
# agent 9 在 179 次迭代中的资源申请量为: -61.67213450016749
# agent 10 在 179 次迭代中的资源申请量为: 216.6744164713089
# agent 11 在 179 次迭代中的资源申请量为: 1134.2327971114712
# agent 12 在 179 次迭代中的资源申请量为: -62.088884686910404
# agent 13 在 179 次迭代中的资源申请量为: -62.249124026646136
# agent 14 在 179 次迭代中的资源申请量为: -8.549249827454751
# agent 15 在 179 次迭代中的资源申请量为: -62.282977426435444
# agent 16 在 179 次迭代中的资源申请量为: -10.077757441427082
# agent 17 在 179 次迭代中的资源申请量为: -62.37186012596607
# agent 18 在 179 次迭代中的资源申请量为: -62.60614888488788
# agent 19 在 179 次迭代中的资源申请量为: -9.013809575663112
# agent 20 在 179 次迭代中的资源申请量为: 1078.0492308726168
# agent 21 在 179 次迭代中的资源申请量为: 1058.8536510696074
# agent 22 在 179 次迭代中的资源申请量为: -16.221477769175344
# agent 23 在 179 次迭代中的资源申请量为: -15.839248732958804
# agent 24 在 179 次迭代中的资源申请量为: 469.978624128697
# agent 25 在 179 次迭代中的资源申请量为: 472.4492082383934
# agent 26 在 179 次迭代中的资源申请量为: -14.802655611346054
# agent 27 在 179 次迭代中的资源申请量为: 436.2331180329041
# agent 28 在 179 次迭代中的资源申请量为: 431.09387276651046
# agent 29 在 179 次迭代中的资源申请量为: 222.46233211985938
# agent 30 在 179 次迭代中的资源申请量为: 24.763690358615932
# agent 31 在 179 次迭代中的资源申请量为: -61.24243710682843
# agent 32 在 179 次迭代中的资源申请量为: -61.127515323802214
# agent 33 在 179 次迭代中的资源申请量为: -351.883726123944
# agent 34 在 179 次迭代中的资源申请量为: -1.6104075593641187
# agent 35 在 179 次迭代中的资源申请量为: 0.17560640863042987
# agent 36 在 179 次迭代中的资源申请量为: 230.85685682187696
# agent 37 在 179 次迭代中的资源申请量为: 5.637789068153875
# agent 38 在 179 次迭代中的资源申请量为: -59.770985995094144
# ...
# agent 61 在 57999 次迭代中的资源申请量为: 45.35594989347403
# agent 62 在 57999 次迭代中的资源申请量为: 37.777916501990724
# agent 63 在 57999 次迭代中的资源申请量为: 44.36024833408177
# agent 64 在 57999 次迭代中的资源申请量为: 50.59248382563158
# agent 65 在 57999 次迭代中的资源申请量为: 48.719342447654434
# agent 66 在 57999 次迭代中的资源申请量为: 53.47780999250294
# agent 67 在 57999 次迭代中的资源申请量为: 44.62937911116489
# agent 68 在 57999 次迭代中的资源申请量为: 38.64566746179317
# agent 69 在 57999 次迭代中的资源申请量为: 49.892139157742264
# agent 70 在 57999 次迭代中的资源申请量为: 43.38409217370307
# agent 71 在 57999 次迭代中的资源申请量为: 51.072439614453316
# agent 72 在 57999 次迭代中的资源申请量为: 51.63101181607402
# agent 73 在 57999 次迭代中的资源申请量为: 68.52493850742536
# agent 74 在 57999 次迭代中的资源申请量为: 63.033563690013715
# agent 75 在 57999 次迭代中的资源申请量为: 68.784860310892
# agent 76 在 57999 次迭代中的资源申请量为: 65.84231131075826
# agent 77 在 57999 次迭代中的资源申请量为: 37.33178559067635
# agent 78 在 57999 次迭代中的资源申请量为: 56.51515954674519
# agent 79 在 57999 次迭代中的资源申请量为: 35.71319766839764
# agent 80 在 57999 次迭代中的资源申请量为: 41.69438982489503
# agent 81 在 57999 次迭代中的资源申请量为: 64.43288578237497
# agent 82 在 57999 次迭代中的资源申请量为: 45.64920279686928
# agent 83 在 57999 次迭代中的资源申请量为: 54.00548947849253
# agent 84 在 57999 次迭代中的资源申请量为: 52.98642785861979
# agent 85 在 57999 次迭代中的资源申请量为: 58.685757530611916
# agent 86 在 57999 次迭代中的资源申请量为: 54.16278250297388
# agent 87 在 57999 次迭代中的资源申请量为: 50.183947875573004
# agent 88 在 57999 次迭代中的资源申请量为: 53.40486804038364
# agent 89 在 57999 次迭代中的资源申请量为: 44.037016821613456
# agent 90 在 57999 次迭代中的资源申请量为: 38.995841039652966
# agent 91 在 57999 次迭代中的资源申请量为: 43.58677066582213
# agent 92 在 57999 次迭代中的资源申请量为: 45.25809138455365
# agent 93 在 57999 次迭代中的资源申请量为: 35.68321481266967
# agent 94 在 57999 次迭代中的资源申请量为: 37.48060785879904
# 资源申请量平均值avg为: 49.99999999999654
# ****************************************************************************
# 平均成本为: 3240.481984531225
# ****************************************************************************
# agent 1 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 2 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 3 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 4 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 5 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 6 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 7 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 8 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 9 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 10 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 11 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 12 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 13 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 14 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 15 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 16 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 17 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 18 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 19 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 20 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 21 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 22 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 23 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 24 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 25 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 26 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 27 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 28 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 29 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 30 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 31 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 32 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 33 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 34 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 35 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 36 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 37 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 38 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 39 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 40 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 41 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 42 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 43 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 44 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 45 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 46 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 47 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 48 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 49 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 50 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 51 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 52 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 53 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 54 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 55 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 56 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 57 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 58 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 59 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 60 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 61 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 62 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 63 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 64 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 65 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 66 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 67 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 68 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 69 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 70 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 71 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 72 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 73 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 74 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 75 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 76 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 77 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 78 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 79 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 80 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 81 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 82 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 83 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 84 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 85 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 86 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 87 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 88 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 89 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 90 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 91 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 92 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 93 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 94 在 57999 次迭代中的对偶变量为: -135.14386653834575
# *************************
# 迭代步长为: 0.11151053484837568
# ****************************************************************************
# 59999 次迭代中的结果：
# agent 1 在 59999 次迭代中的资源申请量为: 56.19880558172988
# agent 2 在 59999 次迭代中的资源申请量为: 56.03871203978166
# agent 3 在 59999 次迭代中的资源申请量为: 60.64796214442871
# agent 4 在 59999 次迭代中的资源申请量为: 37.93333499802675
# agent 5 在 59999 次迭代中的资源申请量为: 57.56693686702461
# agent 6 在 59999 次迭代中的资源申请量为: 55.34212747123894
# agent 7 在 59999 次迭代中的资源申请量为: 65.6236567946489
# agent 8 在 59999 次迭代中的资源申请量为: 46.330946703602365
# agent 9 在 59999 次迭代中的资源申请量为: 65.64268770463663
# agent 10 在 59999 次迭代中的资源申请量为: 54.23914303693835
# agent 11 在 59999 次迭代中的资源申请量为: 65.4520437985654
# agent 12 在 59999 次迭代中的资源申请量为: 38.406222330358624
# agent 13 在 59999 次迭代中的资源申请量为: 49.70058714461363
# agent 14 在 59999 次迭代中的资源申请量为: 41.3659905551611
# agent 15 在 59999 次迭代中的资源申请量为: 42.48853939614691
# agent 16 在 59999 次迭代中的资源申请量为: 49.24530133808371
# agent 17 在 59999 次迭代中的资源申请量为: 50.11852704992918
# agent 18 在 59999 次迭代中的资源申请量为: 46.537297422347486
# agent 19 在 59999 次迭代中的资源申请量为: 44.77392156663175
# agent 20 在 59999 次迭代中的资源申请量为: 50.80339666473046
# agent 21 在 59999 次迭代中的资源申请量为: 69.93387670557085
# agent 22 在 59999 次迭代中的资源申请量为: 61.24199691647269
# agent 23 在 59999 次迭代中的资源申请量为: 61.627787986086716
# agent 24 在 59999 次迭代中的资源申请量为: 39.861352301782716
# agent 25 在 59999 次迭代中的资源申请量为: 52.95065687328203
# agent 26 在 59999 次迭代中的资源申请量为: 49.39633437684004
# agent 27 在 59999 次迭代中的资源申请量为: 47.51919637207136
# agent 28 在 59999 次迭代中的资源申请量为: 40.7413613830987
# agent 29 在 59999 次迭代中的资源申请量为: 44.38273034135506
# agent 30 在 59999 次迭代中的资源申请量为: 39.891745956789116
# agent 31 在 59999 次迭代中的资源申请量为: 65.76280653244551
# agent 32 在 59999 次迭代中的资源申请量为: 59.51901541924079
# agent 33 在 59999 次迭代中的资源申请量为: 48.23750867799392
# agent 34 在 59999 次迭代中的资源申请量为: 36.76532342510125
# agent 35 在 59999 次迭代中的资源申请量为: 41.086702696803464
# agent 36 在 59999 次迭代中的资源申请量为: 62.20889044924783
# agent 37 在 59999 次迭代中的资源申请量为: 40.47023795026076
# agent 38 在 59999 次迭代中的资源申请量为: 58.24733429492913
# agent 39 在 59999 次迭代中的资源申请量为: 37.39554726071002
# agent 40 在 59999 次迭代中的资源申请量为: 50.45313221045784
# agent 41 在 59999 次迭代中的资源申请量为: 36.73569742369616
# agent 42 在 59999 次迭代中的资源申请量为: 56.24242387150355
# agent 43 在 59999 次迭代中的资源申请量为: 61.52373322591861
# agent 44 在 59999 次迭代中的资源申请量为: 47.51525622305313
# agent 45 在 59999 次迭代中的资源申请量为: 41.36197014706921
# agent 46 在 59999 次迭代中的资源申请量为: 67.10436077257359
# agent 47 在 59999 次迭代中的资源申请量为: 65.57090570810219
# agent 48 在 59999 次迭代中的资源申请量为: 40.83836334458436
# agent 49 在 59999 次迭代中的资源申请量为: 39.16390664937778
# agent 50 在 59999 次迭代中的资源申请量为: 63.292999181236645
# agent 51 在 59999 次迭代中的资源申请量为: 36.39727688961264
# agent 52 在 59999 次迭代中的资源申请量为: 46.86937779818014
# agent 53 在 59999 次迭代中的资源申请量为: 43.572511920796444
# agent 54 在 59999 次迭代中的资源申请量为: 49.58201107681077
# agent 55 在 59999 次迭代中的资源申请量为: 47.173391517077015
# agent 56 在 59999 次迭代中的资源申请量为: 42.97971616155657
# agent 57 在 59999 次迭代中的资源申请量为: 36.90486251978384
# agent 58 在 59999 次迭代中的资源申请量为: 59.2566799113546
# agent 59 在 59999 次迭代中的资源申请量为: 59.891586060534515
# agent 60 在 59999 次迭代中的资源申请量为: 40.34169962872796
# agent 61 在 59999 次迭代中的资源申请量为: 45.35594989347582
# agent 62 在 59999 次迭代中的资源申请量为: 37.77791650199216
# agent 63 在 59999 次迭代中的资源申请量为: 44.360248334083515
# agent 64 在 59999 次迭代中的资源申请量为: 50.59248382563358
# agent 65 在 59999 次迭代中的资源申请量为: 48.71934244765636
# agent 66 在 59999 次迭代中的资源申请量为: 53.47780999250507
# agent 67 在 59999 次迭代中的资源申请量为: 44.62937911116663
# agent 68 在 59999 次迭代中的资源申请量为: 38.64566746179467
# agent 69 在 59999 次迭代中的资源申请量为: 49.89213915774424
# agent 70 在 59999 次迭代中的资源申请量为: 43.384092173704765
# agent 71 在 59999 次迭代中的资源申请量为: 51.07243961445531
# agent 72 在 59999 次迭代中的资源申请量为: 51.63101181607605
# agent 73 在 59999 次迭代中的资源申请量为: 68.52493850742809
# agent 74 在 59999 次迭代中的资源申请量为: 63.033563690016244
# agent 75 在 59999 次迭代中的资源申请量为: 68.78486031089474
# agent 76 在 59999 次迭代中的资源申请量为: 65.84231131076093
# agent 77 在 59999 次迭代中的资源申请量为: 37.33178559067781
# agent 78 在 59999 次迭代中的资源申请量为: 56.51515954674745
# agent 79 在 59999 次迭代中的资源申请量为: 35.713197668399026
# agent 80 在 59999 次迭代中的资源申请量为: 41.69438982489667
# agent 81 在 59999 次迭代中的资源申请量为: 64.43288578237754
# agent 82 在 59999 次迭代中的资源申请量为: 45.64920279687104
# agent 83 在 59999 次迭代中的资源申请量为: 54.00548947849467
# agent 84 在 59999 次迭代中的资源申请量为: 52.98642785862186
# agent 85 在 59999 次迭代中的资源申请量为: 58.685757530614225
# agent 86 在 59999 次迭代中的资源申请量为: 54.16278250297603
# agent 87 在 59999 次迭代中的资源申请量为: 50.18394787557497
# agent 88 在 59999 次迭代中的资源申请量为: 53.40486804038577
# agent 89 在 59999 次迭代中的资源申请量为: 44.03701682161516
# agent 90 在 59999 次迭代中的资源申请量为: 38.99584103965445
# agent 91 在 59999 次迭代中的资源申请量为: 43.58677066582381
# agent 92 在 59999 次迭代中的资源申请量为: 45.258091384555385
# agent 93 在 59999 次迭代中的资源申请量为: 35.68321481267107
# agent 94 在 59999 次迭代中的资源申请量为: 37.4806078588005
# 资源申请量平均值avg为: 49.9999999999985
# ****************************************************************************
# 平均成本为: 3240.4819845314896
# ****************************************************************************
# agent 1 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 2 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 3 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 4 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 5 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 6 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 7 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 8 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 9 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 10 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 11 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 12 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 13 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 14 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 15 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 16 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 17 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 18 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 19 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 20 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 21 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 22 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 23 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 24 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 25 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 26 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 27 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 28 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 29 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 30 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 31 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 32 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 33 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 34 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 35 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 36 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 37 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 38 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 39 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 40 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 41 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 42 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 43 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 44 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 45 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 46 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 47 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 48 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 49 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 50 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 51 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 52 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 53 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 54 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 55 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 56 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 57 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 58 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 59 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 60 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 61 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 62 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 63 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 64 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 65 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 66 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 67 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 68 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 69 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 70 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 71 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 72 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 73 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 74 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 75 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 76 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 77 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 78 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 79 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 80 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 81 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 82 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 83 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 84 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 85 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 86 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 87 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 88 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 89 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 90 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 91 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 92 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 93 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 94 在 59999 次迭代中的对偶变量为: -135.1438665383513
# *************************
# 迭代步长为: 0.11075700351730201
# ****************************************************************************
# 2023-05-29 15:40:13.737

# %%
np.savetxt('../data/01-DGD-ARC-robust-agent_resource_quantity_small_value_deterministic_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/01-DGD-ARC-robust-sum_cost_small_value_deterministic_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/01-DGD-ARC-robust-sum_resource_small_value_deterministic_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
