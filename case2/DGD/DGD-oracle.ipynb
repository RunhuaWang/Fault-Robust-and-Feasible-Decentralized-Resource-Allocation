# %% [markdown]
# 测试DGD算法的性能
# 与邻居交换本地的对偶信息
#
# IEEE118bus

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(54,2000)) 
dual_variable = np.zeros(shape=(54,2000))#对偶变量
sum_resource=np.zeros(shape=(1,2000), dtype=np.float64)
sum_cost=np.zeros(shape=(1,2000), dtype=np.float64)
iteration_update = 0.01 #迭代步长
#W=np.zeros(shape=(54,54)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
W=np.loadtxt("double_stochastic_weight_1.txt") #双随机的网络拓扑矩阵W（对角线处非零）
iteration=[]#绘图横坐标
generator_a_values= np.loadtxt("generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("generator_b_values.txt")#每个agent的成本函数中的超参数a
generator_c_values= np.loadtxt("generator_c_values.txt")#每个agent的成本函数中的超参数a

# %%
'''for i in range(0,54):
    for j in range(0,54):
        W[i][j]=1/54'''

#对偶变量的初始化 初始化一致
for i in range (0,54):
    dual_variable[i][0]=0
    
#资源量的初始化 资源量的初始化需要和对偶变量的初始值满足某种关系
for i in range (0,54):
    agent_resource_quantity[i][0]=6000/54

iteration.append(0)

#总资源量 初始化
sum=0
for i in range (0,54):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

#用户总成本初始化
sum=0
for i in range(0,54):
    sum=sum+(generator_c_values[i]*(agent_resource_quantity[i][0])*(agent_resource_quantity[i][0])+generator_b_values[i]*agent_resource_quantity[i][0]+generator_a_values[i])
sum_cost[0][0]=sum

# %%
#DGD算法 
def DGD(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,dual_variable,iteration_update,W,iteration):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************DGD算法+无计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,54):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    for i in range(0,54):
        print("agent",(i+1),"的初始对偶变量为:",dual_variable[i][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,2000):#迭代次数
        iteration.append(k)
        
        #所有用户对偶变量的迭代 
        #阶段一：梯度下降
        dual_variable_intermediate=[] #存放当前迭代中100个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,54):
            #每个用户对对偶变量先进行一次梯度下降
            dual_variable_intermediate.append(dual_variable[i][k-1]-iteration_update*((6000/54)-agent_resource_quantity[i][k-1]))       
        #阶段二：聚合 每个用户聚合自身以及邻居的对偶值   
        for i in range(0,54):
            mix_sum_dual=0
            for j in range(0,54):
                if W[i][j]!=0:
                    mix_sum_dual=mix_sum_dual+W[i][j]*dual_variable_intermediate[j]
            dual_variable[i][k]=mix_sum_dual                    
        
        #用户资源申请量的迭代
        for i in range (0,54):
            agent_resource_quantity[i][k]=(-dual_variable[i][k]-generator_b_values[i])/(2*generator_c_values[i]) 

        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,54):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,54):
            sum2=sum2+(generator_a_values[i]+(generator_b_values[i]*agent_resource_quantity[i][k])+(generator_c_values[i]*agent_resource_quantity[i][k]*agent_resource_quantity[i][k]))
        sum_cost[0][k]=sum2
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%20==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,54):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            for i in range(0,54):
                print("agent",(i+1),"在",k,"次迭代中的对偶变量为:",dual_variable[i][k])   
            print("*************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=(1/(pow(k+1,1.3)))*(1/26.511) #递减步长
        iteration_update=(1/(pow(k+1,1.5)))*(1/18.8468) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
DGD(generator_a_values,generator_b_values,generator_c_values,agent_resource_quantity,sum_resource,dual_variable,iteration_update,W,iteration)
# Out:
# ****************************DGD算法+无计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 111.11111111111111
# agent 2 的初始资源申请量为: 111.11111111111111
# agent 3 的初始资源申请量为: 111.11111111111111
# agent 4 的初始资源申请量为: 111.11111111111111
# agent 5 的初始资源申请量为: 111.11111111111111
# agent 6 的初始资源申请量为: 111.11111111111111
# agent 7 的初始资源申请量为: 111.11111111111111
# agent 8 的初始资源申请量为: 111.11111111111111
# agent 9 的初始资源申请量为: 111.11111111111111
# agent 10 的初始资源申请量为: 111.11111111111111
# agent 11 的初始资源申请量为: 111.11111111111111
# agent 12 的初始资源申请量为: 111.11111111111111
# agent 13 的初始资源申请量为: 111.11111111111111
# agent 14 的初始资源申请量为: 111.11111111111111
# agent 15 的初始资源申请量为: 111.11111111111111
# agent 16 的初始资源申请量为: 111.11111111111111
# agent 17 的初始资源申请量为: 111.11111111111111
# agent 18 的初始资源申请量为: 111.11111111111111
# agent 19 的初始资源申请量为: 111.11111111111111
# agent 20 的初始资源申请量为: 111.11111111111111
# agent 21 的初始资源申请量为: 111.11111111111111
# agent 22 的初始资源申请量为: 111.11111111111111
# agent 23 的初始资源申请量为: 111.11111111111111
# agent 24 的初始资源申请量为: 111.11111111111111
# agent 25 的初始资源申请量为: 111.11111111111111
# agent 26 的初始资源申请量为: 111.11111111111111
# agent 27 的初始资源申请量为: 111.11111111111111
# agent 28 的初始资源申请量为: 111.11111111111111
# agent 29 的初始资源申请量为: 111.11111111111111
# agent 30 的初始资源申请量为: 111.11111111111111
# agent 31 的初始资源申请量为: 111.11111111111111
# agent 32 的初始资源申请量为: 111.11111111111111
# agent 33 的初始资源申请量为: 111.11111111111111
# agent 34 的初始资源申请量为: 111.11111111111111
# agent 35 的初始资源申请量为: 111.11111111111111
# agent 36 的初始资源申请量为: 111.11111111111111
# agent 37 的初始资源申请量为: 111.11111111111111
# agent 38 的初始资源申请量为: 111.11111111111111
# agent 39 的初始资源申请量为: 111.11111111111111
# agent 40 的初始资源申请量为: 111.11111111111111
# agent 41 的初始资源申请量为: 111.11111111111111
# agent 42 的初始资源申请量为: 111.11111111111111
# agent 43 的初始资源申请量为: 111.11111111111111
# agent 44 的初始资源申请量为: 111.11111111111111
# agent 45 的初始资源申请量为: 111.11111111111111
# agent 46 的初始资源申请量为: 111.11111111111111
# agent 47 的初始资源申请量为: 111.11111111111111
# agent 48 的初始资源申请量为: 111.11111111111111
# agent 49 的初始资源申请量为: 111.11111111111111
# agent 50 的初始资源申请量为: 111.11111111111111
# agent 51 的初始资源申请量为: 111.11111111111111
# agent 52 的初始资源申请量为: 111.11111111111111
# agent 53 的初始资源申请量为: 111.11111111111111
# agent 54 的初始资源申请量为: 111.11111111111111
# *************************
# 初始资源申请量总和为: 6000.000000000006
# *************************
# 初始成本总和为: 139226.02283950621
# *************************
# agent 1 的初始对偶变量为: 0.0
# agent 2 的初始对偶变量为: 0.0
# agent 3 的初始对偶变量为: 0.0
# agent 4 的初始对偶变量为: 0.0
# agent 5 的初始对偶变量为: 0.0
# agent 6 的初始对偶变量为: 0.0
# agent 7 的初始对偶变量为: 0.0
# agent 8 的初始对偶变量为: 0.0
# agent 9 的初始对偶变量为: 0.0
# agent 10 的初始对偶变量为: 0.0
# agent 11 的初始对偶变量为: 0.0
# agent 12 的初始对偶变量为: 0.0
# agent 13 的初始对偶变量为: 0.0
# agent 14 的初始对偶变量为: 0.0
# agent 15 的初始对偶变量为: 0.0
# agent 16 的初始对偶变量为: 0.0
# agent 17 的初始对偶变量为: 0.0
# agent 18 的初始对偶变量为: 0.0
# agent 19 的初始对偶变量为: 0.0
# agent 20 的初始对偶变量为: 0.0
# agent 21 的初始对偶变量为: 0.0
# agent 22 的初始对偶变量为: 0.0
# agent 23 的初始对偶变量为: 0.0
# agent 24 的初始对偶变量为: 0.0
# agent 25 的初始对偶变量为: 0.0
# agent 26 的初始对偶变量为: 0.0
# agent 27 的初始对偶变量为: 0.0
# agent 28 的初始对偶变量为: 0.0
# agent 29 的初始对偶变量为: 0.0
# agent 30 的初始对偶变量为: 0.0
# agent 31 的初始对偶变量为: 0.0
# agent 32 的初始对偶变量为: 0.0
# agent 33 的初始对偶变量为: 0.0
# agent 34 的初始对偶变量为: 0.0
# agent 35 的初始对偶变量为: 0.0
# agent 36 的初始对偶变量为: 0.0
# agent 37 的初始对偶变量为: 0.0
# agent 38 的初始对偶变量为: 0.0
# agent 39 的初始对偶变量为: 0.0
# agent 40 的初始对偶变量为: 0.0
# agent 41 的初始对偶变量为: 0.0
# agent 42 的初始对偶变量为: 0.0
# agent 43 的初始对偶变量为: 0.0
# agent 44 的初始对偶变量为: 0.0
# agent 45 的初始对偶变量为: 0.0
# agent 46 的初始对偶变量为: 0.0
# agent 47 的初始对偶变量为: 0.0
# agent 48 的初始对偶变量为: 0.0
# agent 49 的初始对偶变量为: 0.0
# agent 50 的初始对偶变量为: 0.0
# agent 51 的初始对偶变量为: 0.0
# agent 52 的初始对偶变量为: 0.0
# agent 53 的初始对偶变量为: 0.0
# agent 54 的初始对偶变量为: 0.0
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 19 次迭代中的结果：
# agent 1 在 19 次迭代中的资源申请量为: -67.40948479228372
# agent 2 在 19 次迭代中的资源申请量为: -67.40948479228372
# agent 3 在 19 次迭代中的资源申请量为: -69.04737646428514
# agent 4 在 19 次迭代中的资源申请量为: 156.83110610324886
# agent 5 在 19 次迭代中的资源申请量为: 176.04055155603433
# agent 6 在 19 次迭代中的资源申请量为: -68.3821971753747
# agent 7 在 19 次迭代中的资源申请量为: -40.49681906438021
# agent 8 在 19 次迭代中的资源申请量为: -65.27982771418561
# agent 9 在 19 次迭代中的资源申请量为: -61.98005014204379
# agent 10 在 19 次迭代中的资源申请量为: 192.78089995032656
# agent 11 在 19 次迭代中的资源申请量为: 982.3045841971884
# agent 12 在 19 次迭代中的资源申请量为: -65.90245363900155
# agent 13 在 19 次迭代中的资源申请量为: -68.05459936035251
# agent 14 在 19 次迭代中的资源申请量为: -26.380158855415363
# agent 15 在 19 次迭代中的资源申请量为: -68.96332347971682
# agent 16 在 19 次迭代中的资源申请量为: -46.41868179160541
# agent 17 在 19 次迭代中的资源申请量为: -69.58486447145508
# agent 18 在 19 次迭代中的资源申请量为: -72.4038770248476
# agent 19 在 19 次迭代中的资源申请量为: -45.83545610579387
# agent 20 在 19 次迭代中的资源申请量为: 742.5697667470993
# agent 21 在 19 次迭代中的资源申请量为: 576.782700869734
# agent 22 在 19 次迭代中的资源申请量为: -108.25085290027985
# agent 23 在 19 次迭代中的资源申请量为: -106.26521368841942
# agent 24 在 19 次迭代中的资源申请量为: 215.2362559183401
# agent 25 在 19 次迭代中的资源申请量为: 230.33242850549246
# agent 26 在 19 次迭代中的资源申请量为: -102.74289928100907
# agent 27 在 19 次迭代中的资源申请量为: 386.7610107076262
# agent 28 在 19 次迭代中的资源申请量为: 332.4206353368063
# agent 29 在 19 次迭代中的资源申请量为: 224.21752438916204
# agent 30 在 19 次迭代中的资源申请量为: 30.737227200559737
# agent 31 在 19 次迭代中的资源申请量为: -57.80239675783249
# agent 32 在 19 次迭代中的资源申请量为: -56.7792952575976
# agent 33 在 19 次迭代中的资源申请量为: -340.91307954044714
# agent 34 在 19 次迭代中的资源申请量为: 22.646720534864606
# agent 35 在 19 次迭代中的资源申请量为: 22.592935276322113
# agent 36 在 19 次迭代中的资源申请量为: 254.22729006307247
# agent 37 在 19 次迭代中的资源申请量为: 23.304138950144825
# agent 38 在 19 次迭代中的资源申请量为: -65.36986925451365
# agent 39 在 19 次迭代中的资源申请量为: 883.8965657646555
# agent 40 在 19 次迭代中的资源申请量为: 263.3035566095755
# agent 41 在 19 次迭代中的资源申请量为: -323.40551205349453
# agent 42 在 19 次迭代中的资源申请量为: -173.82348283822063
# agent 43 在 19 次迭代中的资源申请量为: 274.58039848369924
# agent 44 在 19 次迭代中的资源申请量为: 277.3698704922245
# agent 45 在 19 次迭代中的资源申请量为: 338.5127356644122
# agent 46 在 19 次迭代中的资源申请量为: -291.4536316450677
# agent 47 在 19 次迭代中的资源申请量为: 128.2636665801093
# agent 48 在 19 次迭代中的资源申请量为: 134.57097464020543
# agent 49 在 19 次迭代中的资源申请量为: -292.36203858597844
# agent 50 在 19 次迭代中的资源申请量为: -71.6696396482892
# agent 51 在 19 次迭代中的资源申请量为: 148.09050094002907
# agent 52 在 19 次迭代中的资源申请量为: 148.09050094002907
# agent 53 在 19 次迭代中的资源申请量为: -44.03855160680009
# agent 54 在 19 次迭代中的资源申请量为: -261.59548984820344
# 资源申请量总和为: 3966.4439386417835
# ****************************************************************************
# 成本总和为: 31255.355082232487
# ****************************************************************************
# agent 1 在 19 次迭代中的对偶变量为: -16.85190612183028
# agent 2 在 19 次迭代中的对偶变量为: -16.85190612183028
# agent 3 在 19 次迭代中的对偶变量为: -16.62370522673701
# agent 4 在 19 次迭代中的对偶变量为: -16.298576557745662
# agent 5 在 19 次迭代中的对偶变量为: -16.716381996343745
# agent 6 在 19 次迭代中的对偶变量为: -16.716381996343745
# agent 7 在 19 次迭代中的对偶变量为: -16.783281431951867
# agent 8 在 19 次迭代中的对偶变量为: -17.148622723893375
# agent 9 在 19 次迭代中的对偶变量为: -17.608367533909608
# agent 10 在 19 次迭代中的对偶变量为: -17.080484573919602
# agent 11 在 19 次迭代中的对偶变量为: -16.65382750518313
# agent 12 在 19 次迭代中的对偶变量为: -17.06187474429247
# agent 13 在 19 次迭代中的对偶变量为: -16.762024889519527
# agent 14 在 19 次迭代中的对偶变量为: -17.144667933301367
# agent 15 在 19 次迭代中的对偶变量为: -16.635415992864974
# agent 16 在 19 次迭代中的对偶变量为: -16.631681746134902
# agent 17 在 19 次迭代中的对偶变量为: -16.54881917265005
# agent 18 在 19 次迭代中的对偶变量为: -16.156057429636082
# agent 19 在 19 次迭代中的对偶变量为: -16.646612323691677
# agent 20 在 19 次迭代中的对偶变量为: -15.89572001991957
# agent 21 在 19 次迭代中的对偶变量为: -15.099610529576463
# agent 22 在 19 次迭代中的对偶变量为: -15.048778165752836
# agent 23 在 19 次迭代中的对偶变量为: -15.099610529576463
# agent 24 在 19 次迭代中的对偶变量为: -15.184079052081392
# agent 25 在 19 次迭代中的对偶变量为: -15.316925370848333
# agent 26 在 19 次迭代中的对偶变量为: -15.189781778406168
# agent 27 在 19 次迭代中的对偶变量为: -16.530698206787523
# agent 28 在 19 次迭代中的对偶变量为: -15.379769056433558
# agent 29 在 19 次迭代中的对偶变量为: -17.764231155464273
# agent 30 在 19 次迭代中的对偶变量为: -18.29389136946261
# agent 31 在 19 次迭代中的对偶变量为: -18.19042326931823
# agent 32 在 19 次迭代中的对偶变量为: -18.332967908939956
# agent 33 在 19 次迭代中的对偶变量为: -18.399756045692534
# agent 34 在 19 次迭代中的对偶变量为: -18.399756045692534
# agent 35 在 19 次迭代中的对偶变量为: -18.398379143073846
# agent 36 在 19 次迭代中的对偶变量为: -18.416943558871825
# agent 37 在 19 次迭代中的对偶变量为: -18.416585957123708
# agent 38 在 19 次迭代中的对偶变量为: -17.13607759624563
# agent 39 在 19 次迭代中的对偶变量为: -16.063379394587933
# agent 40 在 19 次迭代中的对偶变量为: -18.614352356258266
# agent 41 在 19 次迭代中的对偶变量为: -19.390754395724
# agent 42 在 19 次迭代中的对偶变量为: -19.544398557478463
# agent 43 在 19 次迭代中的对偶变量为: -18.859623667020458
# agent 44 在 19 次迭代中的对偶变量为: -18.92029468320588
# agent 45 在 19 次迭代中的对偶变量为: -20.250152000700965
# agent 46 在 19 次迭代中的对偶变量为: -21.199358634362593
# agent 47 在 19 次迭代中的对偶变量为: -21.103549864450798
# agent 48 在 19 次迭代中的对偶变量为: -21.26501695078926
# agent 49 在 19 次迭代中的对偶变量为: -21.14793916787928
# agent 50 在 19 次迭代中的对偶变量为: -21.541301884155242
# agent 51 在 19 次迭代中的对偶变量为: -21.611116824064744
# agent 52 在 19 次迭代中的对偶变量为: -21.611116824064744
# agent 53 在 19 次迭代中的对偶变量为: -16.692613078865918
# agent 54 在 19 次迭代中的对偶变量为: -17.828631364447318
# *************************
# 迭代步长为: 0.0006406664425248283
# ****************************************************************************
# 39 次迭代中的结果：
# agent 1 在 39 次迭代中的资源申请量为: -65.21280379619594
# agent 2 在 39 次迭代中的资源申请量为: -65.21280379619594
# agent 3 在 39 次迭代中的资源申请量为: -65.75908730537105
# agent 4 在 39 次迭代中的资源申请量为: 186.81141971644095
# agent 5 在 39 次迭代中的资源申请量为: 194.55205775374776
# agent 6 在 39 次迭代中的资源申请量为: -65.49239010562269
# agent 7 在 39 次迭代中的资源申请量为: -25.327876857150347
# agent 8 在 39 次迭代中的资源申请量为: -63.18564134699277
# agent 9 在 39 次迭代中的资源申请量为: -60.88454269883169
# agent 10 在 39 次迭代中的资源申请量为: 208.742014004775
# agent 11 在 39 次迭代中的资源申请量为: 1060.5258342205686
# agent 12 在 39 次迭代中的资源申请量为: -63.52640725601904
# agent 13 在 39 次迭代中的资源申请量为: -65.05578852955952
# agent 14 在 39 次迭代中的资源申请量为: -14.8446150958699
# agent 15 在 39 次迭代中的资源申请量为: -65.68146010734856
# agent 16 在 39 次迭代中的资源申请量为: -28.367670916527864
# agent 17 在 39 次迭代中的资源申请量为: -66.18003027540526
# agent 18 在 39 次迭代中的资源申请量为: -68.24377697158016
# agent 19 在 39 次迭代中的资源申请量为: -28.262246701641207
# agent 20 在 39 次迭代中的资源申请量为: 879.7382158434534
# agent 21 在 39 次迭代中的资源申请量为: 748.3391946967105
# agent 22 在 39 次迭代中的资源申请量为: -76.55808010566395
# agent 23 在 39 次迭代中的资源申请量为: -74.08496824478111
# agent 24 在 39 次迭代中的资源申请量为: 306.9878721520538
# agent 25 在 39 次迭代中的资源申请量为: 322.25164909800225
# agent 26 在 39 次迭代中的资源申请量为: -68.31833487408304
# agent 27 在 39 次迭代中的资源申请量为: 409.87686072843104
# agent 28 在 39 次迭代中的资源申请量为: 373.90986414719066
# agent 29 在 39 次迭代中的资源申请量为: 227.8039029946539
# agent 30 在 39 次迭代中的资源申请量为: 29.673850999716887
# agent 31 在 39 次迭代中的资源申请量为: -58.06924766697212
# agent 32 在 39 次迭代中的资源申请量为: -57.36670247370579
# agent 33 在 39 次迭代中的资源申请量为: -343.6935802967563
# agent 34 在 39 次迭代中的资源申请量为: 16.498772690719115
# agent 35 在 39 次迭代中的资源申请量为: 19.584605233236157
# agent 36 在 39 次迭代中的资源申请量为: 255.91211900667213
# agent 37 在 39 次迭代中的资源申请量为: 29.35533830709033
# agent 38 在 39 次迭代中的资源申请量为: -59.239485941969384
# agent 39 在 39 次迭代中的资源申请量为: 1130.0494373904928
# agent 40 在 39 次迭代中的资源申请量为: 260.97599503567045
# agent 41 在 39 次迭代中的资源申请量为: -333.1683537424481
# agent 42 在 39 次迭代中的资源申请量为: -206.1519800244029
# agent 43 在 39 次迭代中的资源申请量为: 268.71789379434836
# agent 44 在 39 次迭代中的资源申请量为: 277.28299643243173
# agent 45 在 39 次迭代中的资源申请量为: 319.75508293523876
# agent 46 在 39 次迭代中的资源申请量为: -302.2603885968231
# agent 47 在 39 次迭代中的资源申请量为: 103.98943285178902
# agent 48 在 39 次迭代中的资源申请量为: 107.62815856231899
# agent 49 在 39 次迭代中的资源申请量为: -305.2344322491898
# agent 50 在 39 次迭代中的资源申请量为: -97.98183966179775
# agent 51 在 39 次迭代中的资源申请量为: 130.750112478836
# agent 52 在 39 次迭代中的资源申请量为: 130.750112478836
# agent 53 在 39 次迭代中的资源申请量为: -26.801794059939237
# agent 54 在 39 次迭代中的资源申请量为: -256.66279935956834
# 资源申请量总和为: 4923.633664495012
# ****************************************************************************
# 成本总和为: 45935.02988830042
# ****************************************************************************
# agent 1 在 39 次迭代中的对偶变量为: -17.157960898291204
# agent 2 在 39 次迭代中的对偶变量为: -17.157960898291204
# agent 3 在 39 次迭代中的对偶变量为: -17.081849402091873
# agent 4 在 39 次迭代中的对偶变量为: -16.95064837883259
# agent 5 在 39 次迭代中的对偶变量为: -17.119007256144013
# agent 6 在 39 次迭代中的对偶变量为: -17.119007256144013
# agent 7 在 39 次迭代中的对偶变量为: -17.17160635245695
# agent 8 在 39 次迭代中的对偶变量为: -17.440397333688885
# agent 9 在 39 次迭代中的对偶变量为: -17.761000203942576
# agent 10 在 39 次迭代中的对偶变量为: -17.427638804603856
# agent 11 在 39 次迭代中的对偶变量为: -17.12315500532341
# agent 12 在 39 次迭代中的对偶变量为: -17.39291978264789
# agent 13 在 39 次迭代中的对偶变量为: -17.17983720733059
# agent 14 在 39 次迭代中的对偶变量为: -17.43997785354573
# agent 15 在 39 次迭代中的对偶变量为: -17.092664889083554
# agent 16 在 39 次迭代中的对偶变量为: -17.093787624536887
# agent 17 在 39 次迭代中的对偶变量为: -17.023201101848887
# agent 18 在 39 次迭代中的对偶变量为: -16.735667529657622
# agent 19 在 39 次迭代中的对偶变量为: -17.096486484437985
# agent 20 在 39 次迭代中的对偶变量为: -16.554402912480263
# agent 21 在 39 次迭代中的对偶变量为: -15.923424812933604
# agent 22 在 39 次迭代中的对偶变量为: -15.860113149295003
# agent 23 在 39 次迭代中的对偶变量为: -15.923424812933604
# agent 24 在 39 次迭代中的对偶变量为: -15.991493274938072
# agent 25 在 39 次迭代中的对偶变量为: -16.12581451206242
# agent 26 在 39 次迭代中的对偶变量为: -16.071050627223475
# agent 27 在 39 次迭代中的对偶变量为: -17.02029191022817
# agent 28 在 39 次迭代中的对偶变量为: -16.258510922637498
# agent 29 在 39 次迭代中的对偶变量为: -17.84223489013372
# agent 30 在 39 次迭代中的对偶变量为: -18.196224518919998
# agent 31 在 39 次迭代中的对偶变量为: -18.153243999551442
# agent 32 在 39 次迭代中的对偶变量为: -18.251126811148467
# agent 33 在 39 次迭代中的对偶变量为: -18.24236858088241
# agent 34 在 39 次迭代中的对偶变量为: -18.24236858088241
# agent 35 在 39 次迭代中的对偶变量为: -18.321365893970846
# agent 36 在 39 次迭代中的对偶变量为: -18.453588588395117
# agent 37 在 39 次迭代中的对偶变量为: -18.571496660661513
# agent 38 在 39 次迭代中的对偶变量为: -17.990199381649173
# agent 39 在 39 次迭代中的对偶变量为: -17.540296624342957
# agent 40 在 39 次迭代中的对偶变量为: -18.56372789202583
# agent 41 在 39 次迭代中的对偶变量为: -18.83813850476247
# agent 42 在 39 次迭代中的对偶变量为: -18.912441094482972
# agent 43 在 39 次迭代中的对偶变量为: -18.732114190027076
# agent 44 在 39 次迭代中的对偶变量为: -18.91840517240539
# agent 45 在 39 次迭代中的对偶变量为: -19.842173053841442
# agent 46 在 39 次迭代中的对偶变量为: -20.58765296386543
# agent 47 在 39 次迭代中的对偶变量为: -20.4821294810058
# agent 48 在 39 次迭代中的对偶变量为: -20.575280859195367
# agent 49 在 39 次迭代中的对偶变量为: -20.419310196966862
# agent 50 在 39 次迭代中的对偶变量为: -21.026950998291177
# agent 51 在 39 次迭代中的对偶变量为: -21.167202879458202
# agent 52 在 39 次迭代中的对偶变量为: -21.167202879458202
# agent 53 在 39 次迭代中的对偶变量为: -17.133874072065556
# agent 54 在 39 次迭代中的对偶变量为: -17.925055598119158
# *************************
# 迭代步长为: 0.000217853964469636
# ****************************************************************************
# 59 次迭代中的结果：
# agent 1 在 59 次迭代中的资源申请量为: -64.02768922949068
# agent 2 在 59 次迭代中的资源申请量为: -64.02768922949068
# agent 3 在 59 次迭代中的资源申请量为: -64.30574543478849
# agent 4 在 59 次迭代中的资源申请量为: 198.668290237639
# agent 5 在 59 次迭代中的资源申请量为: 203.13660687588188
# agent 6 在 59 次迭代中的资源申请量为: -64.15226734744104
# agent 7 在 59 次迭代中的资源申请量为: -18.735162912364988
# agent 8 在 59 次迭代中的资源申请量为: -62.68117356735986
# agent 9 在 59 次迭代中的资源申请量为: -61.14832837750144
# agent 10 在 59 次迭代中的资源申请量为: 212.24659334063043
# agent 11 在 59 次迭代中的资源申请量为: 1092.2203109524244
# agent 12 在 59 次迭代中的资源申请量为: -62.91964076933932
# agent 13 在 59 次迭代中的资源申请量为: -63.860844810377074
# agent 14 在 59 次迭代中的资源申请量为: -12.156649723827488
# agent 15 在 59 次迭代中的资源申请量为: -64.22003824515278
# agent 16 在 59 次迭代中的资源申请量为: -20.547220783014158
# agent 17 在 59 次迭代中的资源申请量为: -64.57446049776863
# agent 18 在 59 次迭代中的资源申请量为: -65.92078823982527
# agent 19 在 59 次迭代中的资源申请量为: -19.44614038188422
# agent 20 在 59 次迭代中的资源申请量为: 961.4162713343842
# agent 21 在 59 次迭代中的资源申请量为: 869.8816546603623
# agent 22 在 59 次迭代中的资源申请量为: -53.11264985024155
# agent 23 在 59 次迭代中的资源申请量为: -51.286261496911735
# agent 24 在 59 次迭代中的资源申请量为: 371.163308317153
# agent 25 在 59 次迭代中的资源申请量为: 382.3764118525688
# agent 26 在 59 次迭代中的资源申请量为: -46.784186006385006
# agent 27 在 59 次迭代中的资源申请量为: 421.7531229430178
# agent 28 在 59 次迭代中的资源申请量为: 397.4622593867704
# agent 29 在 59 次迭代中的资源申请量为: 228.4104842902745
# agent 30 在 59 次迭代中的资源申请量为: 28.071700440494187
# agent 31 在 59 次迭代中的资源申请量为: -59.281931458346925
# agent 32 在 59 次迭代中的资源申请量为: -58.80546976159122
# agent 33 在 59 次迭代中的资源申请量为: -345.9495122709713
# agent 34 在 59 次迭代中的资源申请量为: 11.510695602107157
# agent 35 在 59 次迭代中的资源申请量为: 15.48536535970285
# agent 36 在 59 次迭代中的资源申请量为: 252.95406996571032
# agent 37 在 59 次迭代中的资源申请量为: 27.8137218050456
# agent 38 在 59 次迭代中的资源申请量为: -57.456626700556555
# agent 39 在 59 次迭代中的资源申请量为: 1206.5210379263845
# agent 40 在 59 次迭代中的资源申请量为: 260.49457839033136
# agent 41 在 59 次迭代中的资源申请量为: -335.58562901929514
# agent 42 在 59 次迭代中的资源申请量为: -214.95113876723704
# agent 43 在 59 次迭代中的资源申请量为: 264.4853761999736
# agent 44 在 59 次迭代中的资源申请量为: 271.06460590044696
# agent 45 在 59 次迭代中的资源申请量为: 302.65180763315254
# agent 46 在 59 次迭代中的资源申请量为: -311.80745372657327
# agent 47 在 59 次迭代中的资源申请量为: 83.52469977855061
# agent 48 在 59 次迭代中的资源申请量为: 86.14154118204459
# agent 49 在 59 次迭代中的资源申请量为: -314.561979541097
# agent 50 在 59 次迭代中的资源申请量为: -128.7044822076548
# agent 51 在 59 次迭代中的资源申请量为: 106.7936607928345
# agent 52 在 59 次迭代中的资源申请量为: 106.7936607928345
# agent 53 在 59 次迭代中的资源申请量为: -19.58679827050086
# agent 54 在 59 次迭代中的资源申请量为: -255.4761097497308
# 资源申请量总和为: 5336.967767583998
# ****************************************************************************
# 成本总和为: 52177.30798238387
# ****************************************************************************
# agent 1 在 59 次迭代中的对偶变量为: -17.323078170411982
# agent 2 在 59 次迭代中的对偶变量为: -17.323078170411982
# agent 3 在 59 次迭代中的对偶变量为: -17.28433771155266
# agent 4 在 59 次迭代中的对偶变量为: -17.208535312668648
# agent 5 在 59 次迭代中的对偶变量为: -17.30572119955043
# agent 6 在 59 次迭代中的对偶变量为: -17.30572119955043
# agent 7 在 59 次迭代中的对偶变量为: -17.340379829443457
# agent 8 在 59 次迭代中的对偶变量为: -17.51068281155402
# agent 9 在 59 次迭代中的对偶变量为: -17.724248000476233
# agent 10 在 59 次迭代中的对偶变量为: -17.50386340515871
# agent 11 在 59 次迭代中的对偶变量为: -17.313321865714546
# agent 12 在 59 次迭代中的对偶变量为: -17.47745813017103
# agent 13 在 59 次迭代中的对偶变量为: -17.346323935949403
# agent 14 在 59 次迭代中的对偶变量为: -17.508789767070017
# agent 15 在 59 次迭代中的对偶变量为: -17.296278951455843
# agent 16 在 59 次迭代中的对偶变量为: -17.293991147954838
# agent 17 在 59 次迭代中的对偶变量为: -17.246898716687888
# agent 18 在 59 次迭代中的对偶变量为: -17.059320257698104
# agent 19 在 59 次迭代中的对偶变量为: -17.322178806223764
# agent 20 在 59 次迭代中的对偶变量为: -16.946620934947713
# agent 21 在 59 次迭代中的对偶变量为: -16.50707170567906
# agent 22 在 59 次迭代中的对偶变量为: -16.460316163833816
# agent 23 在 59 次迭代中的对偶变量为: -16.50707170567906
# agent 24 在 59 次迭代中的对偶变量为: -16.556237113190946
# agent 25 在 59 次迭代中的对偶变量为: -16.654912424302605
# agent 26 在 59 次迭代中的对偶变量为: -16.622324838236544
# agent 27 在 59 次迭代中的对偶变量为: -17.271831143933117
# agent 28 在 59 次迭代中的对偶变量为: -16.7573506538118
# agent 29 在 59 次迭代中的对偶变量为: -17.85542803331347
# agent 30 在 59 次迭代中的对偶变量为: -18.04907339865763
# agent 31 在 59 次迭代中的对偶变量为: -17.984285617634356
# agent 32 在 59 次迭代中的对偶变量为: -18.05066911999654
# agent 33 在 59 次迭代中的对偶变量为: -18.114673807413944
# agent 34 在 59 次迭代中的对偶变量为: -18.114673807413944
# agent 35 在 59 次迭代中的对偶变量为: -18.216425353208393
# agent 36 在 59 次迭代中的对偶变量为: -18.3892510217542
# agent 37 在 59 次迭代中的对偶变量为: -18.532031278209168
# agent 38 在 59 次迭代中的对偶变量为: -18.238598028318258
# agent 39 在 59 次迭代中的对偶变量为: -17.999126227558307
# agent 40 在 59 次迭代中的对偶变量为: -18.553257079989706
# agent 41 在 59 次迭代中的对偶变量为: -18.70131105499182
# agent 42 在 59 次迭代中的对偶变量为: -18.74043513937805
# agent 43 在 59 次迭代中的对偶变量为: -18.640056932349424
# agent 44 在 59 次迭代中的对偶变量为: -18.78315517833472
# agent 45 在 59 次迭代中的对偶变量为: -19.470176816021066
# agent 46 在 59 次迭代中的对偶变量为: -20.04725088926105
# agent 47 在 59 次迭代中的对偶变量为: -19.958232314330896
# agent 48 在 59 次迭代中的对偶变量为: -20.025223454260342
# agent 49 在 59 次迭代中的对偶变量为: -19.891333710055747
# agent 50 在 59 次迭代中的对偶变量为: -20.426384781804764
# agent 51 在 59 次迭代中的对偶变量为: -20.553917716296564
# agent 52 在 59 次迭代中的对偶变量为: -20.553917716296564
# agent 53 在 59 次迭代中的对偶变量为: -17.31857796427518
# agent 54 在 59 次迭代中的对偶变量为: -17.948253006612262
# *************************
# 迭代步长为: 0.00011708044397666381
# ****************************************************************************
# 79 次迭代中的结果：
# agent 1 在 79 次迭代中的资源申请量为: -63.17237946953011
# agent 2 在 79 次迭代中的资源申请量为: -63.17237946953011
# agent 3 在 79 次迭代中的资源申请量为: -63.33955513372074
# agent 4 在 79 次迭代中的资源申请量为: 205.83816318438284
# agent 5 在 79 次迭代中的资源申请量为: 209.04505018782876
# agent 6 在 79 次迭代中的资源申请量为: -63.22990797420959
# agent 7 在 79 次迭代中的资源申请量为: -14.0904951044854
# agent 8 在 79 次迭代中的资源申请量为: -62.217904640607614
# agent 9 在 79 次迭代中的资源申请量为: -61.10963555755884
# agent 10 在 79 次迭代中的资源申请量为: 215.26022094174772
# agent 11 在 79 次迭代中的资源申请量为: 1113.5521779688283
# agent 12 在 79 次迭代中的资源申请量为: -62.40801917908017
# agent 13 在 79 次迭代中的资源申请量为: -63.02690961496587
# agent 14 在 79 次迭代中的资源申请量为: -9.67902582669905
# agent 15 在 79 次迭代中的资源申请量为: -63.23250615469234
# agent 16 在 79 次迭代中的资源申请量为: -15.30215242124655
# agent 17 在 79 次迭代中的资源申请量为: -63.50026292143731
# agent 18 在 79 次迭代中的资源申请量为: -64.39989805060726
# agent 19 在 79 次迭代中的资源申请量为: -13.591410125532999
# agent 20 在 79 次迭代中的资源申请量为: 1014.5149794432511
# agent 21 在 79 次迭代中的资源申请量为: 949.4188447005499
# agent 22 在 79 次迭代中的资源申请量为: -37.68272601599995
# agent 23 在 79 次迭代中的资源申请量为: -36.36682452140466
# agent 24 在 79 次迭代中的资源申请量为: 413.0577586069916
# agent 25 在 79 次迭代中的资源申请量为: 421.2077766336828
# agent 26 在 79 次迭代中的资源申请量为: -33.022542693724176
# agent 27 在 79 次迭代中的资源申请量为: 429.47199470729555
# agent 28 在 79 次迭代中的资源申请量为: 412.2991920172762
# agent 29 在 79 次迭代中的资源申请量为: 229.3267917433006
# agent 30 在 79 次迭代中的资源申请量为: 27.406262554799167
# agent 31 在 79 次迭代中的资源申请量为: -59.75298791781655
# agent 32 在 79 次迭代中的资源申请量为: -59.40017885311532
# agent 33 在 79 次迭代中的资源申请量为: -346.96795881016124
# agent 34 在 79 次迭代中的资源申请量为: 9.258814824595202
# agent 35 在 79 次迭代中的资源申请量为: 13.129561326972045
# agent 36 在 79 次迭代中的资源申请量为: 250.01465429927742
# agent 37 在 79 次迭代中的资源申请量为: 25.072261994871223
# agent 38 在 79 次迭代中的资源申请量为: -57.01535396921379
# agent 39 在 79 次迭代中的资源申请量为: 1232.1432987105854
# agent 40 在 79 次迭代中的资源申请量为: 258.3249976947342
# agent 41 在 79 次迭代中的资源申请量为: -337.30282933324946
# agent 42 在 79 次迭代中的资源申请量为: -220.77372183863622
# agent 43 在 79 次迭代中的资源申请量为: 260.3322317732716
# agent 44 在 79 次迭代中的资源申请量为: 265.0304652093821
# agent 45 在 79 次迭代中的资源申请量为: 289.05892474931693
# agent 46 在 79 次迭代中的资源申请量为: -319.32489498433085
# agent 47 在 79 次迭代中的资源申请量为: 67.61000509855896
# agent 48 在 79 次迭代中的资源申请量为: 69.57619282629501
# agent 49 在 79 次迭代中的资源申请量为: -321.5848747898433
# agent 50 在 79 次迭代中的资源申请量为: -154.3054083729109
# agent 51 在 79 次迭代中的资源申请量为: 86.32484455696753
# agent 52 在 79 次迭代中的资源申请量为: 86.32484455696753
# agent 53 在 79 次迭代中的资源申请量为: -14.66601474291479
# agent 54 在 79 次迭代中的资源申请量为: -254.760878077449
# 资源申请量总和为: 5554.200673747056
# ****************************************************************************
# 成本总和为: 55450.01874546445
# ****************************************************************************
# agent 1 在 79 次迭代中的对偶变量为: -17.44224505802825
# agent 2 在 79 次迭代中的对偶变量为: -17.44224505802825
# agent 3 在 79 次迭代中的对偶变量为: -17.418953141439225
# agent 4 在 79 次迭代中的对偶变量为: -17.364480049260326
# agent 5 在 79 次迭代中的对偶变量为: -17.434229841585275
# agent 6 在 79 次迭代中的对偶变量为: -17.434229841585275
# agent 7 在 79 次迭代中的对偶变量为: -17.459283325325174
# agent 8 在 79 次迭代中的对偶变量为: -17.575228218042703
# agent 9 在 79 次迭代中的对偶变量为: -17.729638916307557
# agent 10 在 79 次迭代中的对偶变量为: -17.569409805483012
# agent 11 在 79 次迭代中的对偶变量为: -17.44131306781297
# agent 12 在 79 次迭代中的对偶变量为: -17.548740319855476
# agent 13 在 79 次迭代中的对偶变量为: -17.462512790985265
# agent 14 在 79 次迭代中的对偶变量为: -17.572216938836505
# agent 15 在 79 次迭代中的对偶变量为: -17.433867847491335
# agent 16 在 79 次迭代中的对偶变量为: -17.42826489801609
# agent 17 在 79 次迭代中的对偶变量为: -17.396562368207825
# agent 18 在 79 次迭代中的对偶变量为: -17.271219804201092
# agent 19 在 79 次迭代中的对偶变量为: -17.472059900786356
# agent 20 在 79 次迭代中的对偶变量为: -17.201600931286492
# agent 21 在 79 次迭代中的对偶变量为: -16.88900929225204
# agent 22 在 79 次迭代中的对偶变量为: -16.8553222139904
# agent 23 在 79 次迭代中的对偶变量为: -16.88900929225204
# agent 24 在 79 次迭代中的对偶变量为: -16.924908275741526
# agent 25 在 79 次迭代中的对偶变量为: -16.996628434376408
# agent 26 在 79 次迭代中的对偶变量为: -16.97462290704066
# agent 27 在 79 次迭代中的对偶变量为: -17.43531684790052
# agent 28 在 79 次迭代中的对偶变量为: -17.07159688692591
# agent 29 在 79 次迭代中的对偶变量为: -17.875357720416787
# agent 30 在 79 次迭代中的对偶变量为: -17.987955590608085
# agent 31 在 79 次迭代中的对偶变量为: -17.918655205362292
# agent 32 在 79 次迭代中的对偶变量为: -17.967810681110855
# agent 33 在 79 次迭代中的对偶变量为: -18.057025659509637
# agent 34 在 79 次迭代中的对偶变量为: -18.057025659509637
# agent 35 在 79 次迭代中的对偶变量为: -18.156116769970485
# agent 36 在 79 次迭代中的对偶变量为: -18.325318731009283
# agent 37 在 79 次迭代中的对偶变量为: -18.461849907068704
# agent 38 在 79 次迭代中的对偶变量为: -18.30007879288532
# agent 39 在 79 次迭代中的对偶变量为: -18.152859792263513
# agent 40 在 79 次迭代中的对偶变量为: -18.506068699860467
# agent 41 在 79 次迭代中的对偶变量为: -18.60411064842075
# agent 42 在 79 次迭代中的对偶变量为: -18.62661528549834
# agent 43 在 79 次迭代中的对偶变量为: -18.549726041068656
# agent 44 在 79 次迭代中的对偶变量为: -18.65191261830406
# agent 45 在 79 次迭代中的对偶变量为: -19.174531613297642
# agent 46 在 79 次迭代中的对偶变量为: -19.62173364430694
# agent 47 在 79 次迭代中的对偶变量为: -19.55081613052311
# agent 48 在 79 次迭代中的对偶变量为: -19.601150536353153
# agent 49 在 79 次迭代中的对偶变量为: -19.493809747395712
# agent 50 在 79 次迭代中的对偶变量为: -19.925937877126337
# agent 51 在 79 次迭代中的对偶变量为: -20.02991602065837
# agent 52 在 79 次迭代中的对偶变量为: -20.02991602065837
# agent 53 在 79 次迭代中的对偶变量为: -17.44455002258138
# agent 54 在 79 次迭代中的对偶变量为: -17.962234355342027
# *************************
# 迭代步长为: 7.556518347445504e-05
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: -62.469919057343816
# agent 2 在 99 次迭代中的资源申请量为: -62.469919057343816
# agent 3 在 99 次迭代中的资源申请量为: -62.58162996876507
# agent 4 在 99 次迭代中的资源申请量为: 211.21758078057002
# agent 5 在 99 次迭代中的资源申请量为: 213.75040138586812
# agent 6 在 99 次迭代中的资源申请量为: -62.49536174050335
# agent 7 在 99 次迭代中的资源申请量为: -10.316509485893409
# agent 8 在 99 次迭代中的资源申请量为: -61.74924277324823
# agent 9 在 99 次迭代中的资源申请量为: -60.90205630201991
# agent 10 在 99 次迭代中的资源申请量为: 218.29049732447018
# agent 11 在 99 次迭代中的资源申请量为: 1130.4658379127864
# agent 12 在 99 次迭代中的资源申请量为: -61.90591370718678
# agent 13 在 99 次迭代中的资源申请量为: -62.34438521721419
# agent 14 在 99 次迭代中的资源申请量为: -7.139974326736964
# agent 15 在 99 次迭代中的资源申请量为: -62.46817960377444
# agent 16 在 99 次迭代中的资源申请量为: -11.195000697654667
# agent 17 在 99 次迭代中的资源申请量为: -62.67858638672811
# agent 18 在 99 次迭代中的资源申请量为: -63.311496732890696
# agent 19 在 99 次迭代中的资源申请量为: -9.333765497675921
# agent 20 在 99 次迭代中的资源申请量为: 1051.1985456803218
# agent 21 在 99 次迭代中的资源申请量为: 1002.9314346303132
# agent 22 在 99 次迭代中的资源申请量为: -27.306319518919096
# agent 23 在 99 次迭代中的资源申请量为: -26.32903323848579
# agent 24 在 99 次迭代中的资源申请量为: 441.25918565350923
# agent 25 在 99 次迭代中的资源申请量为: 447.3678989337015
# agent 26 在 99 次迭代中的资源申请量为: -23.794551681701886
# agent 27 在 99 次迭代中的资源申请量为: 435.0016426548105
# agent 28 在 99 次迭代中的资源申请量为: 422.279976827248
# agent 29 在 99 次迭代中的资源申请量为: 230.2971428707362
# agent 30 在 99 次迭代中的资源申请量为: 27.191034808781485
# agent 31 在 99 次迭代中的资源申请量为: -59.85858191305985
# agent 32 在 99 次迭代中的资源申请量为: -59.583915702998276
# agent 33 在 99 次迭代中的资源申请量为: -347.4126916723678
# agent 34 在 99 次迭代中的资源申请量为: 8.275468772550587
# agent 35 在 99 次迭代中的资源申请量为: 11.694468551294717
# agent 36 在 99 次迭代中的资源申请量为: 247.40875090803564
# agent 37 在 99 次迭代中的资源申请量为: 22.228473259377488
# agent 38 在 99 次迭代中的资源申请量为: -57.069562240843645
# agent 39 在 99 次迭代中的资源申请量为: 1238.8276573143478
# agent 40 在 99 次迭代中的资源申请量为: 255.31577465335434
# agent 41 在 99 次迭代中的资源申请量为: -338.92467547822963
# agent 42 在 99 次迭代中的资源申请量为: -225.90582798102852
# agent 43 在 99 次迭代中的资源申请量为: 256.3222352057762
# agent 44 在 99 次迭代中的资源申请量为: 259.7108923322643
# agent 45 在 99 次迭代中的资源申请量为: 278.32186405109104
# agent 46 在 99 次迭代中的资源申请量为: -325.1720828167205
# agent 47 在 99 次迭代中的资源申请量为: 55.2622583258662
# agent 48 在 99 次迭代中的资源申请量为: 56.776712920530294
# agent 49 在 99 次迭代中的资源申请量为: -326.98062315800576
# agent 50 在 99 次迭代中的资源申请量为: -174.46702150028827
# agent 51 在 99 次迭代中的资源申请量为: 70.10765371558702
# agent 52 在 99 次迭代中的资源申请量为: 70.10765371558702
# agent 53 在 99 次迭代中的资源申请量为: -10.740715387403121
# agent 54 在 99 次迭代中的资源申请量为: -254.2728001739682
# 资源申请量总和为: 5680.430700169778
# ****************************************************************************
# 成本总和为: 57357.23152641428
# ****************************************************************************
# agent 1 在 99 次迭代中的对偶变量为: -17.540116057416515
# agent 2 在 99 次迭代中的对偶变量为: -17.540116057416515
# agent 3 在 99 次迭代中的对偶变量为: -17.524551822971837
# agent 4 在 99 次迭代中的对偶变量为: -17.481482381977397
# agent 5 在 99 次迭代中的对偶变量为: -17.53657123014263
# agent 6 在 99 次迭代中的对偶变量为: -17.53657123014263
# agent 7 在 99 次迭代中的对偶变量为: -17.55589735716113
# agent 8 在 99 次迭代中的对偶变量为: -17.640525001374417
# agent 9 在 99 次迭代中的对偶变量为: -17.758560103664774
# agent 10 在 99 次迭代中的对偶变量为: -17.635318316807226
# agent 11 在 99 次迭代中的对偶变量为: -17.542795027476718
# agent 12 在 99 次迭代中的对偶变量为: -17.618696666832495
# agent 13 在 99 次迭代中的对偶变量为: -17.557606185226415
# agent 14 在 99 次迭代中的对偶变量为: -17.637216657235534
# agent 15 在 99 次迭代中的对偶变量为: -17.540358408524522
# agent 16 在 99 次迭代中的对偶变量为: -17.53340798214004
# agent 17 在 99 次迭代中的对偶变量为: -17.51104327308272
# agent 18 在 99 次迭代中的对偶变量为: -17.42286240619327
# agent 19 在 99 次迭代中的对偶变量为: -17.581055603259497
# agent 20 在 99 次迭代中的对偶变量为: -17.377755416356905
# agent 21 在 99 次迭代中的对偶变量为: -17.145976749094764
# agent 22 在 99 次迭代中的对偶变量为: -17.12095822031567
# agent 23 在 99 次迭代中的对偶变量为: -17.145976749094764
# agent 24 在 99 次迭代中的对偶变量为: -17.17308083375088
# agent 25 在 99 次迭代中的对偶变量为: -17.226837510616573
# agent 26 在 99 次迭代中的对偶变量为: -17.210859476948432
# agent 27 在 99 次迭代中的对偶变量为: -17.552434791428887
# agent 28 在 99 次迭代中的对偶变量为: -17.282989909201113
# agent 29 在 99 次迭代中的对偶变量为: -17.89646285743851
# agent 30 在 99 次迭代中的对偶变量为: -17.968187783047345
# agent 31 在 99 次迭代中的对偶变量为: -17.903943216381023
# agent 32 在 99 次迭代中的对偶变量为: -17.942211360764063
# agent 33 在 99 次迭代中的对偶变量为: -18.031852000577295
# agent 34 在 99 次迭代中的对偶变量为: -18.031852000577295
# agent 35 在 99 次迭代中的对偶变量为: -18.119378394913145
# agent 36 在 99 次迭代中的对偶变量为: -18.268640332249774
# agent 37 在 99 次迭代中的对偶变量为: -18.389048915440064
# agent 38 在 99 次迭代中的对偶变量为: -18.29252617123222
# agent 39 在 99 次迭代中的对偶变量为: -18.192965943886087
# agent 40 在 99 次迭代中的对偶变量为: -18.440618098710456
# agent 41 在 99 次迭代中的对偶变量为: -18.512307669230292
# agent 42 在 99 次迭代中的对偶变量为: -18.526292874626854
# agent 43 在 99 次迭代中的对偶变量为: -18.462508615725632
# agent 44 在 99 次迭代中的对偶变量为: -18.536211908226747
# agent 45 在 99 次迭代中的对偶变量为: -18.94100054311123
# agent 46 在 99 次迭代中的对偶变量为: -19.290759424242356
# agent 47 在 99 次迭代中的对偶变量为: -19.234713813142175
# agent 48 在 99 次迭代中的对偶变量为: -19.273483850765576
# agent 49 在 99 次迭代中的对偶变量为: -19.188388806764245
# agent 50 在 99 次迭代中的对偶变量为: -19.531818663712365
# agent 51 在 99 次迭代中的对偶变量为: -19.614755935119028
# agent 52 在 99 次迭代中的对偶变量为: -19.614755935119028
# agent 53 在 99 次迭代中的对偶变量为: -17.54503768608248
# agent 54 在 99 次迭代中的对偶变量为: -17.97177530219927
# *************************
# 迭代步长为: 5.3865362416062276e-05
# ****************************************************************************
# 119 次迭代中的结果：
# agent 1 在 119 次迭代中的资源申请量为: -61.882104738534
# agent 2 在 119 次迭代中的资源申请量为: -61.882104738534
# agent 3 在 119 次迭代中的资源申请量为: -61.96336854199064
# agent 4 在 119 次迭代中的资源申请量为: 215.54514577766733
# agent 5 在 119 次迭代中的资源申请量为: 217.60709885282432
# agent 6 在 119 次迭代中的资源申请量为: -61.89329773302235
# agent 7 在 119 次迭代中的资源申请量为: -7.194143191700391
# agent 8 在 119 次迭代中的资源申请量为: -61.31749723743365
# agent 9 在 119 次迭代中的资源申请量为: -60.64908601872282
# agent 10 在 119 次迭代中的资源申请量为: 221.08679706991032
# agent 11 在 119 次迭代中的资源申请量为: 1144.2878026558285
# agent 12 在 119 次迭代中的资源申请量为: -61.44687293884728
# agent 13 在 119 次迭代中的资源申请量为: -61.77620265132517
# agent 14 在 119 次迭代中的资源申请量为: -4.7825483565382125
# agent 15 在 119 次迭代中的资源申请量为: -61.85722865757375
# agent 16 在 119 次迭代中的资源申请量为: -7.86643161405226
# agent 17 在 119 次迭代中的资源申请量为: -62.02567234996158
# agent 18 在 119 次迭代中的资源申请量为: -62.49562743731725
# agent 19 在 119 次迭代中的资源申请量为: -6.123889756205619
# agent 20 在 119 次迭代中的资源申请量为: 1077.7217577527488
# agent 21 在 119 次迭代中的资源申请量为: 1040.5343145716515
# agent 22 在 119 次迭代中的资源申请量为: -20.02703016484114
# agent 23 在 119 次迭代中的资源申请量为: -19.27555552448945
# agent 24 在 119 次迭代中的资源申请量为: 461.10222451129084
# agent 25 在 119 次迭代中的资源申请量为: 465.8370024277726
# agent 26 在 119 次迭代中的资源申请量为: -17.297358481319495
# agent 27 在 119 次迭代中的资源申请量为: 439.1507517227097
# agent 28 在 119 次迭代中的资源申请量为: 429.35285190884025
# agent 29 在 119 次迭代中的资源申请量为: 231.1425062172867
# agent 30 在 119 次迭代中的资源申请量为: 27.15435477480791
# agent 31 在 119 次迭代中的资源申请量为: -59.82217534090375
# agent 32 在 119 次迭代中的资源申请量为: -59.603018689507444
# agent 33 在 119 次迭代中的资源申请量为: -347.6223774575918
# agent 34 在 119 次迭代中的资源申请量为: 7.811833843377885
# agent 35 在 119 次迭代中的资源申请量为: 10.70724769634726
# agent 36 在 119 次迭代中的资源申请量为: 245.1770761133534
# agent 37 在 119 次迭代中的资源申请量为: 19.626986827145362
# agent 38 在 119 次迭代中的资源申请量为: -57.302795645057046
# agent 39 在 119 次迭代中的资源申请量为: 1237.9637611788855
# agent 40 在 119 次迭代中的资源申请量为: 252.19368102950028
# agent 41 在 119 次迭代中的资源申请量为: -340.4129764210919
# agent 42 在 119 次迭代中的资源申请量为: -230.45214341428843
# agent 43 在 119 次迭代中的资源申请量为: 252.70163788449744
# agent 44 在 119 次迭代中的资源申请量为: 255.2084290561001
# agent 45 在 119 次迭代中的资源申请量为: 269.8510676676227
# agent 46 在 119 次迭代中的资源申请量为: -329.7189377211426
# agent 47 在 119 次迭代中的资源申请量为: 45.65936704106696
# agent 48 在 119 次迭代中的资源申请量为: 46.848439602280855
# agent 49 在 119 次迭代中的资源申请量为: -331.1631491232552
# agent 50 在 119 次迭代中的资源申请量为: -190.16316200242008
# agent 51 在 119 次迭代中的资源申请量为: 57.46511550441618
# agent 52 在 119 次迭代中的资源申请量为: 57.46511550441618
# agent 53 在 119 次迭代中的资源申请量为: -7.523230483760801
# agent 54 在 119 次迭代中的资源申请量为: -253.95418457430088
# 资源申请量总和为: 5759.708196186618
# ****************************************************************************
# 成本总和为: 58565.22998151089
# ****************************************************************************
# agent 1 在 119 次迭代中的对偶变量为: -17.622013875199013
# agent 2 在 119 次迭代中的对偶变量为: -17.622013875199013
# agent 3 在 119 次迭代中的对偶变量为: -17.610691714518612
# agent 4 在 119 次迭代中的对偶变量为: -17.575606920664264
# agent 5 在 119 次迭代中的对偶变量为: -17.620454400048928
# agent 6 在 119 次迭代中的对偶变量为: -17.620454400048928
# agent 7 在 119 次迭代中的对偶变量为: -17.63582993429247
# agent 8 在 119 次迭代中的对偶变量为: -17.70067837989732
# agent 9 在 119 次迭代中的对偶变量为: -17.793805441355424
# agent 10 在 119 次迭代中的对偶变量为: -17.696137836270548
# agent 11 在 119 次迭代中的对偶变量为: -17.62572681593497
# agent 12 在 119 次迭代中的对偶变量为: -17.682652980922164
# agent 13 在 119 次迭代中的对偶变量为: -17.63676878940147
# agent 14 在 119 次迭代中的对偶变量为: -17.697566762072622
# agent 15 在 119 次迭代中的对偶变量为: -17.62547976005488
# agent 16 在 119 次迭代中的对偶变量为: -17.618619350680262
# agent 17 在 119 次迭代中的对偶变量为: -17.602011174169252
# agent 18 在 119 次迭代中的对偶变量为: -17.536534211668336
# agent 19 在 119 次迭代中的对偶变量为: -17.663228422241136
# agent 20 在 119 次迭代中的对偶变量为: -17.5051198807287
# agent 21 在 119 次迭代中的对偶变量为: -17.32654577857307
# agent 22 在 119 次迭代中的对偶变量为: -17.307308027780067
# agent 23 在 119 次迭代中的对偶变量为: -17.32654577857307
# agent 24 在 119 次迭代中的对偶变量为: -17.34769957569936
# agent 25 在 119 次迭代中的对偶变量为: -17.389365621364398
# agent 26 在 119 次迭代中的对偶变量为: -17.37718762287822
# agent 27 在 119 次迭代中的对偶变量为: -17.64031292148699
# agent 28 在 119 次迭代中的对偶变量为: -17.432793403429237
# agent 29 在 119 次迭代中的对偶变量为: -17.914849510225984
# agent 30 在 119 次迭代中的对偶变量为: -17.964818868647008
# agent 31 在 119 次迭代中的对偶变量为: -17.909015598453244
# agent 32 在 119 次迭代中的对偶变量为: -17.939549818065686
# agent 33 在 119 次迭代中的对偶变量为: -18.019982946390474
# agent 34 在 119 次迭代中的对偶变量为: -18.019982946390474
# agent 35 在 119 次迭代中的对偶变量为: -18.09410554102649
# agent 36 在 119 次迭代中的对偶变量为: -18.220101405465435
# agent 37 在 119 次迭代中的对偶变量为: -18.32245086277492
# agent 38 在 119 次迭代中的对偶变量为: -18.260030693956782
# agent 39 在 119 次迭代中的对偶变量为: -18.187782567073313
# agent 40 在 119 次迭代中的对偶变量为: -18.37271256239163
# agent 41 在 119 次迭代中的对偶变量为: -18.428063882660517
# agent 42 在 119 次迭代中的对偶变量为: -18.43742150053749
# agent 43 在 119 次迭代中的对偶变量为: -18.38376062398782
# agent 44 在 119 次迭代中的对偶变量为: -18.438283331970176
# agent 45 在 119 次迭代中的对偶变量为: -18.756760721770792
# agent 46 在 119 次迭代中的对偶变量为: -19.033389249232446
# agent 47 在 119 次迭代中的对偶变量为: -18.988879796251315
# agent 48 在 119 次迭代中的对偶变量为: -19.01932005381839
# agent 49 在 119 次迭代中的对偶变量为: -18.951641107027264
# agent 50 在 119 次迭代中的对偶变量为: -19.224990509176692
# agent 51 在 119 次迭代中的对偶变量为: -19.291106956913055
# agent 52 在 119 次迭代中的对偶变量为: -19.291106956913055
# agent 53 在 119 次迭代中的对偶变量为: -17.627405299615724
# agent 54 在 119 次迭代中的对偶变量为: -17.978003599941566
# *************************
# 迭代步长为: 4.087351016895592e-05
# ****************************************************************************
# 139 次迭代中的结果：
# agent 1 在 139 次迭代中的资源申请量为: -61.39595640278499
# agent 2 在 139 次迭代中的资源申请量为: -61.39595640278499
# agent 3 在 139 次迭代中的资源申请量为: -61.45928114518414
# agent 4 在 139 次迭代中的资源申请量为: 219.06270021604846
# agent 5 在 139 次迭代中的资源申请量为: 220.7554624900332
# agent 6 在 139 次迭代中的资源申请量为: -61.40181079512639
# agent 7 在 139 次迭代中的资源申请量为: -4.634820128258249
# agent 8 在 139 次迭代中的资源申请量为: -60.94412507286828
# agent 9 在 139 次迭代中的资源申请量为: -60.406639438245385
# agent 10 在 139 次迭代中的资源申请量为: 223.50934482289352
# agent 11 在 139 次迭代中的资源申请量为: 1155.5442333491146
# agent 12 在 139 次迭代中的资源申请量为: -61.05059184140134
# agent 13 在 139 次迭代中的资源申请量为: -61.308691777442874
# agent 14 在 139 次迭代中的资源申请量为: -2.7346752306056654
# agent 15 在 139 次迭代中的资源申请量为: -61.36718294398619
# agent 16 在 139 次迭代中的资源申请量为: -5.168532493983052
# agent 17 在 139 次迭代中的资源申请量为: -61.50333075658215
# agent 18 在 139 次迭代中的资源申请量为: -61.86900523066687
# agent 19 在 139 次迭代中的资源申请量为: -3.657538620699535
# agent 20 在 139 次迭代中的资源申请量为: 1097.527541994529
# agent 21 在 139 次迭代中的资源申请量为: 1067.9861012903862
# agent 22 在 139 次迭代中的资源申请量为: -14.721168379297904
# agent 23 在 139 次迭代中的资源申请量为: -14.126200843889297
# agent 24 在 139 次迭代中的资源申请量为: 475.6071148711656
# agent 25 在 139 次迭代中的资源申请量为: 479.3821566252696
# agent 26 在 139 次迭代中的资源申请量为: -12.540783082595485
# agent 27 在 139 次迭代中的资源申请量为: 442.3380745217339
# agent 28 在 139 次迭代中的资源申请量为: 434.56086918269966
# agent 29 在 139 次迭代中的资源申请量为: 231.82954781449945
# agent 30 在 139 次迭代中的资源申请量为: 27.18222868171005
# agent 31 在 139 次迭代中的资源申请量为: -59.74006152294325
# agent 32 在 139 次迭代中的资源申请量为: -59.56282798904436
# agent 33 在 139 次迭代中的资源申请量为: -347.7331100823729
# agent 34 在 139 次迭代中的资源申请量为: 7.566993628803364
# agent 35 在 139 次迭代中的资源申请量为: 9.970920794041687
# agent 36 在 139 次迭代中的资源申请量为: 243.3105072930198
# agent 37 在 139 次迭代中的资源申请量为: 17.379029949596557
# agent 38 在 139 次迭代中的资源申请量为: -57.58269059658358
# agent 39 在 139 次迭代中的资源申请量为: 1234.2764773209499
# agent 40 在 139 次迭代中的资源申请量为: 249.31602779417761
# agent 41 在 139 次迭代中的资源申请量为: -341.7153290731681
# agent 42 在 139 次迭代中的资源申请量为: -234.35798347130125
# agent 43 在 139 次迭代中的资源申请量为: 249.58134206605945
# agent 44 在 139 次迭代中的资源申请量为: 251.48688421419843
# agent 45 在 139 次迭代中的资源申请量为: 263.1673102818732
# agent 46 在 139 次迭代中的资源申请量为: -333.26550706272525
# agent 47 在 139 次迭代中的资源申请量为: 38.16366221090078
# agent 48 在 139 次迭代中的资源申请量为: 39.112313119105124
# agent 49 在 139 次迭代中的资源申请量为: -334.4243317021706
# agent 50 在 139 次迭代中的资源申请量为: -202.38495594481606
# agent 51 在 139 次迭代中的资源申请量为: 47.62080261208668
# agent 52 在 139 次迭代中的资源申请量为: 47.62080261208668
# agent 53 在 139 次迭代中的资源申请量为: -4.898654560204496
# agent 54 在 139 次迭代中的资源申请量为: -253.75053956876664
# 资源申请量总和为: 5812.756167596483
# ****************************************************************************
# 成本总和为: 59384.61376382226
# ****************************************************************************
# agent 1 在 139 次迭代中的对偶变量为: -17.68974697822558
# agent 2 在 139 次迭代中的对偶变量为: -17.68974697822558
# agent 3 在 139 次迭代中的对偶变量为: -17.680924195166074
# agent 4 在 139 次迭代中的对偶变量为: -17.652113729699053
# agent 5 在 139 次迭代中的对偶变量为: -17.68893130915822
# agent 6 在 139 次迭代中的对偶变量为: -17.68893130915822
# agent 7 在 139 次迭代中的对偶变量为: -17.70134860471659
# agent 8 在 139 次迭代中的对偶变量为: -17.752698830097554
# agent 9 在 139 次迭代中的对偶变量为: -17.827584553627023
# agent 10 在 139 次迭代中的对偶变量为: -17.748828249897933
# agent 11 在 139 次迭代中的对偶变量为: -17.69326540009469
# agent 12 在 139 次迭代中的对偶变量为: -17.737865241104917
# agent 13 在 139 次迭代中的对偶变量为: -17.701905209415994
# agent 14 在 139 次迭代中的对偶变量为: -17.749992314096495
# agent 15 在 139 次迭代中的对偶变量为: -17.69375586914618
# agent 16 在 139 次迭代中的对偶变量为: -17.687685568154034
# agent 17 在 139 次迭代中的对偶变量为: -17.674786939008435
# agent 18 在 139 次迭代中的对偶变量为: -17.623838977232108
# agent 19 在 139 次迭代中的对偶变量为: -17.726367011310092
# agent 20 在 139 次迭代中的对偶变量为: -17.60022725665773
# agent 21 在 139 次迭代中的对偶变量为: -17.458369258396434
# agent 22 在 139 次迭代中的对偶变量为: -17.443138089489974
# agent 23 在 139 次迭代中的对偶变量为: -17.458369258396434
# agent 24 在 139 次迭代中的对偶变量为: -17.475342610866257
# agent 25 在 139 次迭代中的对偶变量为: -17.508562978302372
# agent 26 在 139 次迭代中的对偶变量为: -17.498955953085556
# agent 27 在 139 次迭代中的对偶变量为: -17.707820418370325
# agent 28 在 139 次迭代中的对偶变量为: -17.54309920928958
# agent 29 在 139 次迭代中的对偶变量为: -17.929792664965362
# agent 30 在 139 次迭代中的对偶变量为: -17.967378975500342
# agent 31 在 139 次迭代中的对偶变量为: -17.92045618825441
# agent 32 在 139 次迭代中的对偶变量为: -17.945149427598405
# agent 33 在 139 次迭代中的对偶变量为: -18.013715036897366
# agent 34 在 139 次迭代中的对偶变量为: -18.013715036897366
# agent 35 在 139 次迭代中的对偶变量为: -18.075255572327467
# agent 36 在 139 次迭代中的对偶变量为: -18.17950353362318
# agent 37 在 139 次迭代中的对偶变量为: -18.264903166709672
# agent 38 在 139 次迭代中的对偶变量为: -18.221034049940396
# agent 39 在 139 次迭代中的对偶变量为: -18.1656588639257
# agent 40 在 139 次迭代中的对偶变量为: -18.310123604523362
# agent 41 在 139 次迭代中的对偶变量为: -18.354345513142395
# agent 42 在 139 次迭代中的对偶变量为: -18.361070139103003
# agent 43 在 139 次迭代中的对偶变量为: -18.31589418993679
# agent 44 在 139 次迭代中的对偶变量为: -18.357339731658815
# agent 45 在 139 次迭代中的对偶变量为: -18.61138899863074
# agent 46 在 139 次迭代中的对偶变量为: -18.832639238221503
# agent 47 在 139 次迭代中的对偶变量为: -18.79698975259906
# agent 48 在 139 次迭代中的对偶变量为: -18.82127521584909
# agent 49 在 139 次迭代中的对偶变量为: -18.767045128330338
# agent 50 在 139 次迭代中的对偶变量为: -18.986078881190736
# agent 51 在 139 次迭代中的对偶变量为: -19.03909254686942
# agent 52 在 139 次迭代中的对偶变量为: -19.03909254686942
# agent 53 在 139 次迭代中的对偶变量为: -17.694594443258765
# agent 54 在 139 次迭代中的对偶变量为: -17.98198445250975
# *************************
# 迭代步长为: 3.237726633057685e-05
# ****************************************************************************
# 159 次迭代中的结果：
# agent 1 在 159 次迭代中的资源申请量为: -60.999331312822996
# agent 2 在 159 次迭代中的资源申请量为: -60.999331312822996
# agent 3 在 159 次迭代中的资源申请量为: -61.05136331949195
# agent 4 在 159 次迭代中的资源申请量为: 221.90911017556422
# agent 5 在 159 次迭代中的资源申请量为: 223.30364629458288
# agent 6 在 159 次迭代中的资源申请量为: -61.00401714750171
# agent 7 在 159 次迭代中的资源申请量为: -2.559536424888292
# agent 8 在 159 次迭代中的资源申请量为: -60.63265912713476
# agent 9 在 159 次迭代中的资源申请量为: -60.19466345350795
# agent 10 在 159 次迭代中的资源申请量为: 225.5327003736468
# agent 11 在 159 次迭代中的资源申请量为: 1164.6392587750377
# agent 12 在 159 次迭代中的资源申请量为: -60.720085968039534
# agent 13 在 159 次迭代中的资源申请量为: -60.92873901947276
# agent 14 在 159 次迭代中的资源申请量为: -1.0218450858615058
# agent 15 在 159 次迭代中的资源申请量为: -60.97504355899492
# agent 16 在 159 次迭代中的资源申请量为: -2.9945182633336898
# agent 17 在 159 次迭代中的资源申请量为: -61.08582130095798
# agent 18 在 159 次迭代中的资源申请量为: -61.381188697392574
# agent 19 在 159 次迭代中的资源申请量为: -1.7401297482440292
# agent 20 在 159 次迭代中的资源申请量为: 1112.647396826319
# agent 21 在 159 次迭代中的资源申请量为: 1088.6142848082648
# agent 22 在 159 次迭代中的资源申请量为: -10.738858101805443
# agent 23 在 159 次迭代中的资源申请量为: -10.25680485744973
# agent 24 在 159 次迭代中的资源申请量为: 486.5171623389106
# agent 25 在 159 次迭代中的资源申请量为: 489.5956954319714
# agent 26 在 159 次迭代中的资源申请量为: -8.958340156571264
# agent 27 在 159 次迭代中的资源申请量为: 444.8186626017586
# agent 28 在 159 次迭代中的资源申请量为: 438.4998700622311
# agent 29 在 159 次迭代中的资源申请量为: 232.37445862933794
# agent 30 在 159 次迭代中的资源申请量为: 27.228987042393445
# agent 31 在 159 次迭代中的资源申请量为: -59.65096143947073
# agent 32 在 159 次迭代中的资源申请量为: -59.50628374766668
# agent 33 在 159 次迭代中的资源申请量为: -347.79913540188556
# agent 34 在 159 次迭代中的资源申请量为: 7.421005457487195
# agent 35 在 159 次迭代中的资源申请量为: 9.398710319374892
# agent 36 在 159 次迭代中的资源申请量为: 241.7747520363849
# agent 37 在 159 次迭代中的资源申请量为: 15.496337178134283
# agent 38 在 159 次迭代中的资源申请量为: -57.85347412977429
# agent 39 在 159 次迭代中的资源申请量为: 1229.8342074858572
# agent 40 在 159 次迭代中的资源申请量为: 246.81604664752467
# agent 41 在 159 次迭代中的资源申请量为: -342.8178123653989
# agent 42 在 159 次迭代中的资源申请量为: -237.63045307594155
# agent 43 在 159 次迭代中的资源申请量为: 246.96880668339114
# agent 44 在 159 次迭代中的资源申请量为: 248.45437095196786
# agent 45 在 159 次迭代中的资源申请量为: 257.8877453924714
# agent 46 在 159 次迭代中的资源申请量为: -336.0430313031107
# agent 47 在 159 次迭代中的资源申请量为: 32.2889622680092
# agent 48 在 159 次迭代中的资源申请量为: 33.05639385910372
# agent 49 在 159 次迭代中的资源申请量为: -336.9795141224035
# agent 50 在 159 次迭代中的资源申请量为: -211.93552486125535
# agent 51 在 159 次迭代中的资源申请量为: 39.93071274495705
# agent 52 在 159 次迭代中的资源申请量为: 39.93071274495705
# agent 53 在 159 次迭代中的资源申请量为: -2.776048765915362
# agent 54 在 159 次迭代中的资源申请量为: -253.62005989234703
# 资源申请量总和为: 5850.085421168175
# ****************************************************************************
# 成本总和为: 59970.9438886928
# ****************************************************************************
# agent 1 在 159 次迭代中的对偶变量为: -17.745007165509623
# agent 2 在 159 次迭代中的对偶变量为: -17.745007165509623
# agent 3 在 159 次迭代中的对偶变量为: -17.737757754148465
# agent 4 在 159 次迭代中的对偶变量为: -17.71402314631852
# agent 5 在 159 次迭代中的对偶变量为: -17.744354306907177
# agent 6 在 159 次迭代中的对偶变量为: -17.744354306907177
# agent 7 在 159 次迭代中的对偶变量为: -17.75447586752286
# agent 8 在 159 次迭代中的对偶变量为: -17.796094134452822
# agent 9 在 159 次迭代中的对偶变量为: -17.85711831967655
# agent 10 在 159 次迭代中的对偶变量为: -17.792836233126817
# agent 11 在 159 次迭代中的对偶变量为: -17.747835552650226
# agent 12 在 159 次迭代中的对偶变量为: -17.783913302416924
# agent 13 在 159 次迭代中的对偶变量为: -17.75484250737294
# agent 14 在 159 次迭代中的对偶变量为: -17.793840765801946
# agent 15 在 159 次迭代中的对偶变量为: -17.748391081099474
# agent 16 在 159 次迭代中的对偶变量为: -17.743340332458658
# agent 17 在 159 次迭代中的对偶变量为: -17.73295686142273
# agent 18 在 159 次迭代中的对偶变量为: -17.691804503547083
# agent 19 在 159 次迭代中的对偶变量为: -17.775452678444953
# agent 20 在 159 次迭代中的对偶变量为: -17.672832799559984
# agent 21 在 159 次迭代中的对偶变量为: -17.557425795649287
# agent 22 在 159 次迭代中的对偶变量为: -17.54508523259378
# agent 23 在 159 次迭代中的对偶变量为: -17.557425795649287
# agent 24 在 159 次迭代中的对偶变量为: -17.571351028582413
# agent 25 在 159 次迭代中的对偶变量为: -17.598442119801348
# agent 26 在 159 次迭代中的对偶变量为: -17.590666491991776
# agent 27 在 159 次迭代中的对偶变量为: -17.760359273905248
# agent 28 在 159 次迭代中的对偶变量为: -17.626527247918055
# agent 29 在 159 次迭代中的对偶变量为: -17.9416444751881
# agent 30 在 159 次迭代中的对偶变量为: -17.97167354389567
# agent 31 在 159 次迭代中的对偶变量为: -17.9328701464843
# agent 32 在 159 次迭代中的对偶变量为: -17.953027510572593
# agent 33 在 159 次迭代中的对偶变量为: -18.009977739711672
# agent 34 在 159 次迭代中的对偶变量为: -18.009977739711672
# agent 35 在 159 次迭代中的对偶变量为: -18.060606984175998
# agent 36 在 159 次迭代中的对偶变量为: -18.14610085679137
# agent 37 在 159 次迭代中的对偶变量为: -18.216706231760238
# agent 38 在 159 次迭代中的对偶变量为: -18.183306863395067
# agent 39 在 159 次迭代中的对偶变量为: -18.139005244915143
# agent 40 在 159 次迭代中的对偶变量为: -18.25574901458366
# agent 41 在 159 次迭代中的对偶变量为: -18.291940548868965
# agent 42 在 159 次迭代中的对偶变量为: -18.297099903271494
# agent 43 在 159 次迭代中的对偶变量为: -18.259071545363756
# agent 44 在 159 次迭代中的对偶变量为: -18.2913825682053
# agent 45 在 159 次迭代中的对偶变量为: -18.496558462286252
# agent 46 在 159 次迭代中的对偶变量为: -18.675420256118723
# agent 47 在 159 次迭代中的对偶变量为: -18.646597434061036
# agent 48 在 159 次迭代中的对偶变量为: -18.666243682793056
# agent 49 在 159 次迭代中的对偶变量为: -18.622411582615477
# agent 50 在 159 次迭代中的对偶变量为: -18.79938436001218
# agent 51 在 159 次迭代中的对偶变量为: -18.8422262462709
# agent 52 在 159 次迭代中的对偶变量为: -18.8422262462709
# agent 53 在 159 次迭代中的对偶变量为: -17.748933151592567
# agent 54 在 159 次迭代中的对偶变量为: -17.9845350692244
# *************************
# 迭代步长为: 2.6464682716040347e-05
# ****************************************************************************
# 179 次迭代中的结果：
# agent 1 在 179 次迭代中的资源申请量为: -60.67888759899994
# agent 2 在 179 次迭代中的资源申请量为: -60.67888759899994
# agent 3 在 179 次迭代中的资源申请量为: -60.72333402486458
# agent 4 在 179 次迭代中的资源申请量为: 224.19958059921032
# agent 5 在 179 次迭代中的资源申请量为: 225.35257852260153
# agent 6 在 179 次迭代中的资源申请量为: -60.684161011824195
# agent 7 在 179 次迭代中的资源申请量为: -0.8893697792444755
# agent 8 在 179 次迭代中的资源申请量为: -60.37805429482065
# agent 9 在 179 次迭代中的资源申请量为: -60.01723029139405
# agent 10 在 179 次迭代中的资源申请量为: 227.18799641677984
# agent 11 在 179 次迭代中的资源申请量为: 1171.9442705563633
# agent 12 在 179 次迭代中的资源申请量为: -60.44986929894767
# agent 13 在 179 次迭代中的资源申请量为: -60.62254305734174
# agent 14 在 179 次迭代中的资源申请量为: 0.3804772989489391
# agent 15 在 179 次迭代中的资源申请量为: -60.66194959785695
# agent 16 在 179 次迭代中的资源申请量为: -1.2510572448211355
# agent 17 在 179 次迭代中的资源申请量为: -60.752638831554556
# agent 18 在 179 次迭代中的资源申请量为: -60.99821525158685
# agent 19 在 179 次迭代中的资源申请量为: -0.23728757332031059
# agent 20 在 179 次迭代中的资源申请量为: 1124.3680605239579
# agent 21 在 179 次迭代中的资源申请量为: 1104.4430183088405
# agent 22 在 179 次迭代中的资源申请量为: -7.685509345243535
# agent 23 在 179 次迭代中的资源申请量为: -7.287680706287019
# agent 24 在 179 次迭代中的资源申请量为: 494.89404185751266
# agent 25 在 179 次迭代中的资源申请量为: 497.45062686801515
# agent 26 在 179 次迭代中的资源申请量为: -6.205277102652034
# agent 27 在 179 次迭代中的资源申请量为: 446.76515825004714
# agent 28 在 179 次迭代中的资源申请量为: 441.5353148073436
# agent 29 在 179 次迭代中的资源申请量为: 232.80338581533078
# agent 30 在 179 次迭代中的资源申请量为: 27.276790701279317
# agent 31 在 179 次迭代中的资源申请量为: -59.56939518995596
# agent 32 在 179 次迭代中的资源申请量为: -59.45032827289354
# agent 33 在 179 次迭代中的资源申请量为: -347.84316148412313
# agent 34 在 179 次迭代中的资源申请量为: 7.323659662214765
# agent 35 在 179 次迭代中的资源申请量为: 8.945341569606274
# agent 36 在 179 次迭代中的资源申请量为: 240.52453893556827
# agent 37 在 179 次迭代中的资源申请量为: 13.94800594553297
# ...
# agent 61 在 57999 次迭代中的资源申请量为: 45.35594989347403
# agent 62 在 57999 次迭代中的资源申请量为: 37.777916501990724
# agent 63 在 57999 次迭代中的资源申请量为: 44.36024833408177
# agent 64 在 57999 次迭代中的资源申请量为: 50.59248382563158
# agent 65 在 57999 次迭代中的资源申请量为: 48.719342447654434
# agent 66 在 57999 次迭代中的资源申请量为: 53.47780999250294
# agent 67 在 57999 次迭代中的资源申请量为: 44.62937911116489
# agent 68 在 57999 次迭代中的资源申请量为: 38.64566746179317
# agent 69 在 57999 次迭代中的资源申请量为: 49.892139157742264
# agent 70 在 57999 次迭代中的资源申请量为: 43.38409217370307
# agent 71 在 57999 次迭代中的资源申请量为: 51.072439614453316
# agent 72 在 57999 次迭代中的资源申请量为: 51.63101181607402
# agent 73 在 57999 次迭代中的资源申请量为: 68.52493850742536
# agent 74 在 57999 次迭代中的资源申请量为: 63.033563690013715
# agent 75 在 57999 次迭代中的资源申请量为: 68.784860310892
# agent 76 在 57999 次迭代中的资源申请量为: 65.84231131075826
# agent 77 在 57999 次迭代中的资源申请量为: 37.33178559067635
# agent 78 在 57999 次迭代中的资源申请量为: 56.51515954674519
# agent 79 在 57999 次迭代中的资源申请量为: 35.71319766839764
# agent 80 在 57999 次迭代中的资源申请量为: 41.69438982489503
# agent 81 在 57999 次迭代中的资源申请量为: 64.43288578237497
# agent 82 在 57999 次迭代中的资源申请量为: 45.64920279686928
# agent 83 在 57999 次迭代中的资源申请量为: 54.00548947849253
# agent 84 在 57999 次迭代中的资源申请量为: 52.98642785861979
# agent 85 在 57999 次迭代中的资源申请量为: 58.685757530611916
# agent 86 在 57999 次迭代中的资源申请量为: 54.16278250297388
# agent 87 在 57999 次迭代中的资源申请量为: 50.183947875573004
# agent 88 在 57999 次迭代中的资源申请量为: 53.40486804038364
# agent 89 在 57999 次迭代中的资源申请量为: 44.037016821613456
# agent 90 在 57999 次迭代中的资源申请量为: 38.995841039652966
# agent 91 在 57999 次迭代中的资源申请量为: 43.58677066582213
# agent 92 在 57999 次迭代中的资源申请量为: 45.25809138455365
# agent 93 在 57999 次迭代中的资源申请量为: 35.68321481266967
# agent 94 在 57999 次迭代中的资源申请量为: 37.48060785879904
# 资源申请量平均值avg为: 49.99999999999654
# ****************************************************************************
# 平均成本为: 3240.481984531225
# ****************************************************************************
# agent 1 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 2 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 3 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 4 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 5 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 6 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 7 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 8 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 9 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 10 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 11 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 12 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 13 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 14 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 15 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 16 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 17 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 18 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 19 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 20 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 21 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 22 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 23 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 24 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 25 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 26 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 27 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 28 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 29 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 30 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 31 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 32 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 33 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 34 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 35 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 36 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 37 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 38 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 39 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 40 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 41 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 42 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 43 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 44 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 45 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 46 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 47 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 48 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 49 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 50 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 51 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 52 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 53 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 54 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 55 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 56 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 57 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 58 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 59 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 60 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 61 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 62 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 63 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 64 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 65 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 66 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 67 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 68 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 69 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 70 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 71 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 72 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 73 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 74 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 75 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 76 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 77 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 78 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 79 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 80 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 81 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 82 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 83 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 84 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 85 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 86 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 87 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 88 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 89 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 90 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 91 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 92 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 93 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 94 在 57999 次迭代中的对偶变量为: -135.14386653834575
# *************************
# 迭代步长为: 0.11151053484837568
# ****************************************************************************
# 59999 次迭代中的结果：
# agent 1 在 59999 次迭代中的资源申请量为: 56.19880558172988
# agent 2 在 59999 次迭代中的资源申请量为: 56.03871203978166
# agent 3 在 59999 次迭代中的资源申请量为: 60.64796214442871
# agent 4 在 59999 次迭代中的资源申请量为: 37.93333499802675
# agent 5 在 59999 次迭代中的资源申请量为: 57.56693686702461
# agent 6 在 59999 次迭代中的资源申请量为: 55.34212747123894
# agent 7 在 59999 次迭代中的资源申请量为: 65.6236567946489
# agent 8 在 59999 次迭代中的资源申请量为: 46.330946703602365
# agent 9 在 59999 次迭代中的资源申请量为: 65.64268770463663
# agent 10 在 59999 次迭代中的资源申请量为: 54.23914303693835
# agent 11 在 59999 次迭代中的资源申请量为: 65.4520437985654
# agent 12 在 59999 次迭代中的资源申请量为: 38.406222330358624
# agent 13 在 59999 次迭代中的资源申请量为: 49.70058714461363
# agent 14 在 59999 次迭代中的资源申请量为: 41.3659905551611
# agent 15 在 59999 次迭代中的资源申请量为: 42.48853939614691
# agent 16 在 59999 次迭代中的资源申请量为: 49.24530133808371
# agent 17 在 59999 次迭代中的资源申请量为: 50.11852704992918
# agent 18 在 59999 次迭代中的资源申请量为: 46.537297422347486
# agent 19 在 59999 次迭代中的资源申请量为: 44.77392156663175
# agent 20 在 59999 次迭代中的资源申请量为: 50.80339666473046
# agent 21 在 59999 次迭代中的资源申请量为: 69.93387670557085
# agent 22 在 59999 次迭代中的资源申请量为: 61.24199691647269
# agent 23 在 59999 次迭代中的资源申请量为: 61.627787986086716
# agent 24 在 59999 次迭代中的资源申请量为: 39.861352301782716
# agent 25 在 59999 次迭代中的资源申请量为: 52.95065687328203
# agent 26 在 59999 次迭代中的资源申请量为: 49.39633437684004
# agent 27 在 59999 次迭代中的资源申请量为: 47.51919637207136
# agent 28 在 59999 次迭代中的资源申请量为: 40.7413613830987
# agent 29 在 59999 次迭代中的资源申请量为: 44.38273034135506
# agent 30 在 59999 次迭代中的资源申请量为: 39.891745956789116
# agent 31 在 59999 次迭代中的资源申请量为: 65.76280653244551
# agent 32 在 59999 次迭代中的资源申请量为: 59.51901541924079
# agent 33 在 59999 次迭代中的资源申请量为: 48.23750867799392
# agent 34 在 59999 次迭代中的资源申请量为: 36.76532342510125
# agent 35 在 59999 次迭代中的资源申请量为: 41.086702696803464
# agent 36 在 59999 次迭代中的资源申请量为: 62.20889044924783
# agent 37 在 59999 次迭代中的资源申请量为: 40.47023795026076
# agent 38 在 59999 次迭代中的资源申请量为: 58.24733429492913
# agent 39 在 59999 次迭代中的资源申请量为: 37.39554726071002
# agent 40 在 59999 次迭代中的资源申请量为: 50.45313221045784
# agent 41 在 59999 次迭代中的资源申请量为: 36.73569742369616
# agent 42 在 59999 次迭代中的资源申请量为: 56.24242387150355
# agent 43 在 59999 次迭代中的资源申请量为: 61.52373322591861
# agent 44 在 59999 次迭代中的资源申请量为: 47.51525622305313
# agent 45 在 59999 次迭代中的资源申请量为: 41.36197014706921
# agent 46 在 59999 次迭代中的资源申请量为: 67.10436077257359
# agent 47 在 59999 次迭代中的资源申请量为: 65.57090570810219
# agent 48 在 59999 次迭代中的资源申请量为: 40.83836334458436
# agent 49 在 59999 次迭代中的资源申请量为: 39.16390664937778
# agent 50 在 59999 次迭代中的资源申请量为: 63.292999181236645
# agent 51 在 59999 次迭代中的资源申请量为: 36.39727688961264
# agent 52 在 59999 次迭代中的资源申请量为: 46.86937779818014
# agent 53 在 59999 次迭代中的资源申请量为: 43.572511920796444
# agent 54 在 59999 次迭代中的资源申请量为: 49.58201107681077
# agent 55 在 59999 次迭代中的资源申请量为: 47.173391517077015
# agent 56 在 59999 次迭代中的资源申请量为: 42.97971616155657
# agent 57 在 59999 次迭代中的资源申请量为: 36.90486251978384
# agent 58 在 59999 次迭代中的资源申请量为: 59.2566799113546
# agent 59 在 59999 次迭代中的资源申请量为: 59.891586060534515
# agent 60 在 59999 次迭代中的资源申请量为: 40.34169962872796
# agent 61 在 59999 次迭代中的资源申请量为: 45.35594989347582
# agent 62 在 59999 次迭代中的资源申请量为: 37.77791650199216
# agent 63 在 59999 次迭代中的资源申请量为: 44.360248334083515
# agent 64 在 59999 次迭代中的资源申请量为: 50.59248382563358
# agent 65 在 59999 次迭代中的资源申请量为: 48.71934244765636
# agent 66 在 59999 次迭代中的资源申请量为: 53.47780999250507
# agent 67 在 59999 次迭代中的资源申请量为: 44.62937911116663
# agent 68 在 59999 次迭代中的资源申请量为: 38.64566746179467
# agent 69 在 59999 次迭代中的资源申请量为: 49.89213915774424
# agent 70 在 59999 次迭代中的资源申请量为: 43.384092173704765
# agent 71 在 59999 次迭代中的资源申请量为: 51.07243961445531
# agent 72 在 59999 次迭代中的资源申请量为: 51.63101181607605
# agent 73 在 59999 次迭代中的资源申请量为: 68.52493850742809
# agent 74 在 59999 次迭代中的资源申请量为: 63.033563690016244
# agent 75 在 59999 次迭代中的资源申请量为: 68.78486031089474
# agent 76 在 59999 次迭代中的资源申请量为: 65.84231131076093
# agent 77 在 59999 次迭代中的资源申请量为: 37.33178559067781
# agent 78 在 59999 次迭代中的资源申请量为: 56.51515954674745
# agent 79 在 59999 次迭代中的资源申请量为: 35.713197668399026
# agent 80 在 59999 次迭代中的资源申请量为: 41.69438982489667
# agent 81 在 59999 次迭代中的资源申请量为: 64.43288578237754
# agent 82 在 59999 次迭代中的资源申请量为: 45.64920279687104
# agent 83 在 59999 次迭代中的资源申请量为: 54.00548947849467
# agent 84 在 59999 次迭代中的资源申请量为: 52.98642785862186
# agent 85 在 59999 次迭代中的资源申请量为: 58.685757530614225
# agent 86 在 59999 次迭代中的资源申请量为: 54.16278250297603
# agent 87 在 59999 次迭代中的资源申请量为: 50.18394787557497
# agent 88 在 59999 次迭代中的资源申请量为: 53.40486804038577
# agent 89 在 59999 次迭代中的资源申请量为: 44.03701682161516
# agent 90 在 59999 次迭代中的资源申请量为: 38.99584103965445
# agent 91 在 59999 次迭代中的资源申请量为: 43.58677066582381
# agent 92 在 59999 次迭代中的资源申请量为: 45.258091384555385
# agent 93 在 59999 次迭代中的资源申请量为: 35.68321481267107
# agent 94 在 59999 次迭代中的资源申请量为: 37.4806078588005
# 资源申请量平均值avg为: 49.9999999999985
# ****************************************************************************
# 平均成本为: 3240.4819845314896
# ****************************************************************************
# agent 1 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 2 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 3 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 4 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 5 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 6 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 7 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 8 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 9 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 10 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 11 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 12 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 13 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 14 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 15 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 16 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 17 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 18 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 19 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 20 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 21 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 22 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 23 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 24 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 25 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 26 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 27 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 28 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 29 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 30 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 31 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 32 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 33 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 34 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 35 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 36 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 37 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 38 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 39 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 40 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 41 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 42 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 43 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 44 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 45 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 46 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 47 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 48 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 49 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 50 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 51 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 52 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 53 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 54 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 55 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 56 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 57 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 58 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 59 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 60 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 61 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 62 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 63 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 64 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 65 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 66 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 67 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 68 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 69 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 70 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 71 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 72 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 73 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 74 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 75 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 76 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 77 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 78 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 79 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 80 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 81 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 82 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 83 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 84 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 85 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 86 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 87 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 88 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 89 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 90 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 91 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 92 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 93 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 94 在 59999 次迭代中的对偶变量为: -135.1438665383513
# *************************
# 迭代步长为: 0.11075700351730201
# ****************************************************************************
# 2023-05-29 15:40:13.737

# %%
np.savetxt('../data/DGD-agent_resource_quantity_oracle.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/DGD-sum_cost_oracle.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/DGD-sum_resource_oracle.txt',sum_resource,fmt='%0.8f')#用户资源总和
