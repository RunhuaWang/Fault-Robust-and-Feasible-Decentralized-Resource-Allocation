# %% [raw]
# 服从小值高斯分布的噪声

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(100,1000), dtype=np.float64) 
sum_resource=np.zeros(shape=(1,1000), dtype=np.float64)
sum_cost=np.zeros(shape=(1,1000), dtype=np.float64)
iteration_update = 0.01
A=np.loadtxt("100_Network_Topology_Double_Random_Adjacency_Matrix_Degree_15.txt") #网络拓扑的邻接矩阵 对角元素要为0
D=np.zeros(shape=(100,100))# 网络的度矩阵
L=np.zeros(shape=(100,100))# 网络的拉普拉斯矩阵 L=D-A
W=np.zeros(shape=(100,100)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
iteration=[]
a=np.loadtxt("100_uniform_distribution_(1,2)_point1.txt")
b=np.loadtxt("100_normal_distribution_(2,0.6)_point1.txt")
agent_gradient=np.zeros(shape=(100,1000), dtype=np.float64) 
bias=np.loadtxt("1000_Gaussian_distribution_(50,10).txt")
C=np.zeros(shape=(1,1000), dtype=np.float64)#adaptive robust clipping的裁剪参数 
#设置为全局第b大的梯度信息 b为网络中设备损坏的用户上界 每一次迭代就需要计算一次新的C值

# %%
#根据邻接矩阵生成网络对应的度矩阵
for i in range(0,100):
    d=0
    for j in range(0,100):
        if A[i][j]==1:
            d=d+1
    D[i][i]=d

#根据邻接矩阵和度矩阵计算拉普拉斯矩阵
L=D-A

#选择用拉普拉斯矩阵作为聚合矩阵
W=L
    
#资源量的初始化 需要给定可行的初始化 即满足平均资源约束
for i in range (0,100):
    agent_resource_quantity[i][0]=50
    
#资源量总和 初始化
sum=0
for i in range (0,100):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

iteration.append(0)

#初始梯度计算
for i in range (0,100):
    if i==7 or i==20 or i==34:
        agent_gradient[i][0]=2*a[i]*agent_resource_quantity[i][0]-2*a[i]*b[i]+bias[0]
    else:
        agent_gradient[i][0]=2*a[i]*agent_resource_quantity[i][0]-2*a[i]*b[i]
    
#计算初始的C值
column_data = agent_gradient[:, 0]
forth_largest = np.partition(np.abs(column_data), -4)[-4]
C[0][0]=forth_largest

#诚实用户成本总和初始化
sum=0
for i in range(0,100):
    sum=sum+a[i]*(agent_resource_quantity[i][0]-b[i])*(agent_resource_quantity[i][0]-b[i])
sum_cost[0][0]=sum

# %%
#基于初始化的权重梯度下降无中心资源分配算法
def IWDGD_Gaussian_bias_C(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias,C):
    
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************IWDGD算法+计算误差+鲁棒****************************")
    print("相关变量初始值为：")
    for i in range (0,100):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):#迭代次数
        iteration.append(k)
 
        #所有用户资源申请量基于可行初始化权重梯度下降的迭代  假设部分用户因为设备损坏 导致梯度的计算有误差     
        for i in range (0,100):
            weight_gradient_sum = np.float64(0)
            for j in range (0,100):  
                if np.abs(agent_gradient[j][k-1])>C[0][k-1]:
                    weight_gradient_sum=weight_gradient_sum+W[i][j]*(C[0][k-1]/np.abs(agent_gradient[j][k-1])*agent_gradient[j][k-1])
                else:
                    weight_gradient_sum=weight_gradient_sum+W[i][j]*agent_gradient[j][k-1]                   
                #weight_gradient_sum = np.round(weight_gradient_sum, decimals=3)
            agent_resource_quantity[i][k]=agent_resource_quantity[i][k-1]-iteration_update*weight_gradient_sum
                #agent_resource_quantity[i][k] = np.round(agent_resource_quantity[i][k], decimals=3)                      
        
        #计算所有诚实用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,100):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有诚实用户的成本总和
        sum2=np.float64(0)
        for i in range(0,100):
            sum2=sum2+a[i]*(agent_resource_quantity[i][k]-b[i])*(agent_resource_quantity[i][k]-b[i])
        sum_cost[0][k]=sum2
        
        #计算当前迭代的用户梯度
        for i in range (0,100): 
            if i==7 or i==20 or i==34:
                agent_gradient[i][k]=2*a[i]*agent_resource_quantity[i][k]-2*a[i]*b[i]+bias[k]
            else:
                agent_gradient[i][k]=2*a[i]*agent_resource_quantity[i][k]-2*a[i]*b[i]
                
        #计算当前迭代的C值
        column_data = agent_gradient[:, k]
        forth_largest = np.partition(np.abs(column_data), -4)[-4]
        C[0][k]=forth_largest
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%50==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,100):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=1/(pow(k+1,0.05)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
IWDGD_Gaussian_bias_C(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias,C)
# Out:
# ****************************IWDGD算法+计算误差+鲁棒****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 50.0
# agent 2 的初始资源申请量为: 50.0
# agent 3 的初始资源申请量为: 50.0
# agent 4 的初始资源申请量为: 50.0
# agent 5 的初始资源申请量为: 50.0
# agent 6 的初始资源申请量为: 50.0
# agent 7 的初始资源申请量为: 50.0
# agent 8 的初始资源申请量为: 50.0
# agent 9 的初始资源申请量为: 50.0
# agent 10 的初始资源申请量为: 50.0
# agent 11 的初始资源申请量为: 50.0
# agent 12 的初始资源申请量为: 50.0
# agent 13 的初始资源申请量为: 50.0
# agent 14 的初始资源申请量为: 50.0
# agent 15 的初始资源申请量为: 50.0
# agent 16 的初始资源申请量为: 50.0
# agent 17 的初始资源申请量为: 50.0
# agent 18 的初始资源申请量为: 50.0
# agent 19 的初始资源申请量为: 50.0
# agent 20 的初始资源申请量为: 50.0
# agent 21 的初始资源申请量为: 50.0
# agent 22 的初始资源申请量为: 50.0
# agent 23 的初始资源申请量为: 50.0
# agent 24 的初始资源申请量为: 50.0
# agent 25 的初始资源申请量为: 50.0
# agent 26 的初始资源申请量为: 50.0
# agent 27 的初始资源申请量为: 50.0
# agent 28 的初始资源申请量为: 50.0
# agent 29 的初始资源申请量为: 50.0
# agent 30 的初始资源申请量为: 50.0
# agent 31 的初始资源申请量为: 50.0
# agent 32 的初始资源申请量为: 50.0
# agent 33 的初始资源申请量为: 50.0
# agent 34 的初始资源申请量为: 50.0
# agent 35 的初始资源申请量为: 50.0
# agent 36 的初始资源申请量为: 50.0
# agent 37 的初始资源申请量为: 50.0
# agent 38 的初始资源申请量为: 50.0
# agent 39 的初始资源申请量为: 50.0
# agent 40 的初始资源申请量为: 50.0
# agent 41 的初始资源申请量为: 50.0
# agent 42 的初始资源申请量为: 50.0
# agent 43 的初始资源申请量为: 50.0
# agent 44 的初始资源申请量为: 50.0
# agent 45 的初始资源申请量为: 50.0
# agent 46 的初始资源申请量为: 50.0
# agent 47 的初始资源申请量为: 50.0
# agent 48 的初始资源申请量为: 50.0
# agent 49 的初始资源申请量为: 50.0
# agent 50 的初始资源申请量为: 50.0
# agent 51 的初始资源申请量为: 50.0
# agent 52 的初始资源申请量为: 50.0
# agent 53 的初始资源申请量为: 50.0
# agent 54 的初始资源申请量为: 50.0
# agent 55 的初始资源申请量为: 50.0
# agent 56 的初始资源申请量为: 50.0
# agent 57 的初始资源申请量为: 50.0
# agent 58 的初始资源申请量为: 50.0
# agent 59 的初始资源申请量为: 50.0
# agent 60 的初始资源申请量为: 50.0
# agent 61 的初始资源申请量为: 50.0
# agent 62 的初始资源申请量为: 50.0
# agent 63 的初始资源申请量为: 50.0
# agent 64 的初始资源申请量为: 50.0
# agent 65 的初始资源申请量为: 50.0
# agent 66 的初始资源申请量为: 50.0
# agent 67 的初始资源申请量为: 50.0
# agent 68 的初始资源申请量为: 50.0
# agent 69 的初始资源申请量为: 50.0
# agent 70 的初始资源申请量为: 50.0
# agent 71 的初始资源申请量为: 50.0
# agent 72 的初始资源申请量为: 50.0
# agent 73 的初始资源申请量为: 50.0
# agent 74 的初始资源申请量为: 50.0
# agent 75 的初始资源申请量为: 50.0
# agent 76 的初始资源申请量为: 50.0
# agent 77 的初始资源申请量为: 50.0
# agent 78 的初始资源申请量为: 50.0
# agent 79 的初始资源申请量为: 50.0
# agent 80 的初始资源申请量为: 50.0
# agent 81 的初始资源申请量为: 50.0
# agent 82 的初始资源申请量为: 50.0
# agent 83 的初始资源申请量为: 50.0
# agent 84 的初始资源申请量为: 50.0
# agent 85 的初始资源申请量为: 50.0
# agent 86 的初始资源申请量为: 50.0
# agent 87 的初始资源申请量为: 50.0
# agent 88 的初始资源申请量为: 50.0
# agent 89 的初始资源申请量为: 50.0
# agent 90 的初始资源申请量为: 50.0
# agent 91 的初始资源申请量为: 50.0
# agent 92 的初始资源申请量为: 50.0
# agent 93 的初始资源申请量为: 50.0
# agent 94 的初始资源申请量为: 50.0
# agent 95 的初始资源申请量为: 50.0
# agent 96 的初始资源申请量为: 50.0
# agent 97 的初始资源申请量为: 50.0
# agent 98 的初始资源申请量为: 50.0
# agent 99 的初始资源申请量为: 50.0
# agent 100 的初始资源申请量为: 50.0
# *************************
# 初始资源申请量总和为: 5000.0
# *************************
# 初始成本总和为: 346654.5889999999
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 49 次迭代中的结果：
# agent 1 在 49 次迭代中的资源申请量为: 48.29747452066209
# agent 2 在 49 次迭代中的资源申请量为: 60.84683216168977
# agent 3 在 49 次迭代中的资源申请量为: 43.71541282604176
# agent 4 在 49 次迭代中的资源申请量为: 64.34198400453862
# agent 5 在 49 次迭代中的资源申请量为: 65.14196757296796
# agent 6 在 49 次迭代中的资源申请量为: 71.89613075122638
# agent 7 在 49 次迭代中的资源申请量为: 39.38746630490117
# agent 8 在 49 次迭代中的资源申请量为: 32.15365517100652
# agent 9 在 49 次迭代中的资源申请量为: 43.01540811751184
# agent 10 在 49 次迭代中的资源申请量为: 55.666307811544876
# agent 11 在 49 次迭代中的资源申请量为: 45.38511637697603
# agent 12 在 49 次迭代中的资源申请量为: 49.197464079871914
# agent 13 在 49 次迭代中的资源申请量为: 65.64201723747301
# agent 14 在 49 次迭代中的资源申请量为: 55.06632081213806
# agent 15 在 49 次迭代中的资源申请量为: 43.4154129501261
# agent 16 在 49 次迭代中的资源申请量为: 43.61540268877958
# agent 17 在 49 次迭代中的资源申请量为: 44.78512674346772
# agent 18 在 49 次迭代中的资源申请量为: 46.38511645808746
# agent 19 在 49 次迭代中的资源申请量为: 41.23122482531584
# agent 20 在 49 次迭代中的资源申请量为: 55.566303791462076
# agent 21 在 49 次迭代中的资源申请量为: 31.354583456474458
# agent 22 在 49 次迭代中的资源申请量为: 38.98746973994556
# agent 23 在 49 次迭代中的资源申请量为: 47.69747157252761
# agent 24 在 49 次迭代中的资源申请量为: 40.43122638794233
# agent 25 在 49 次迭代中的资源申请量为: 45.085123397394575
# agent 26 在 49 次迭代中的资源申请量为: 39.68747322708862
# agent 27 在 49 次迭代中的资源申请量为: 65.34201180500123
# agent 28 在 49 次迭代中的资源申请量为: 51.22585654465116
# agent 29 在 49 次迭代中的资源申请量为: 40.73122532294548
# agent 30 在 49 次迭代中的资源申请量为: 39.08747789464514
# agent 31 在 49 次迭代中的资源申请量为: 60.24684208575094
# agent 32 在 49 次迭代中的资源申请量为: 55.36631882500599
# agent 33 在 49 次迭代中的资源申请量为: 41.53122294881214
# agent 34 在 49 次迭代中的资源申请量为: 52.12585965117477
# agent 35 在 49 次迭代中的资源申请量为: 29.78681033516508
# agent 36 在 49 次迭代中的资源申请量为: 42.71540174239686
# agent 37 在 49 次迭代中的资源申请量为: 52.42584896821934
# agent 38 在 49 次迭代中的资源申请量为: 40.231222967317855
# agent 39 在 49 次迭代中的资源申请量为: 43.21540685516604
# agent 40 在 49 次迭代中的资源申请量为: 49.997459537378
# agent 41 在 49 次迭代中的资源申请量为: 66.04198582724534
# agent 42 在 49 次迭代中的资源申请量为: 42.41540920365226
# agent 43 在 49 次迭代中的资源申请量为: 51.625838429711976
# agent 44 在 49 次迭代中的资源申请量为: 52.82584919906749
# agent 45 在 49 次迭代中的资源申请量为: 48.097468488117684
# agent 46 在 49 次迭代中的资源申请量为: 55.66630453352193
# agent 47 在 49 次迭代中的资源申请量为: 45.78512348365057
# agent 48 在 49 次迭代中的资源申请量为: 43.31540874198764
# agent 49 在 49 次迭代中的资源申请量为: 42.615395771323556
# agent 50 在 49 次迭代中的资源申请量为: 40.83121812366293
# agent 51 在 49 次迭代中的资源申请量为: 48.197457512927976
# agent 52 在 49 次迭代中的资源申请量为: 55.56630938372256
# agent 53 在 49 次迭代中的资源申请量为: 38.887468384012564
# agent 54 在 49 次迭代中的资源申请量为: 56.76631560419893
# agent 55 在 49 次迭代中的资源申请量为: 70.79621603030014
# agent 56 在 49 次迭代中的资源申请量为: 40.831223822023226
# agent 57 在 49 次迭代中的资源申请量为: 60.24684285865335
# agent 58 在 49 次迭代中的资源申请量为: 42.11541865707242
# agent 59 在 49 次迭代中的资源申请量为: 47.79746194022922
# agent 60 在 49 次迭代中的资源申请量为: 55.86629728804871
# agent 61 在 49 次迭代中的资源申请量为: 65.74196754819322
# agent 62 在 49 次迭代中的资源申请量为: 45.985115498514695
# agent 63 在 49 次迭代中的资源申请量为: 38.88746656083233
# agent 64 在 49 次迭代中的资源申请量为: 44.28511759115573
# agent 65 在 49 次迭代中的资源申请量为: 42.61540609869123
# agent 66 在 49 次迭代中的资源申请量为: 65.44196224083912
# agent 67 在 49 次迭代中的资源申请量为: 43.215397600080856
# agent 68 在 49 次迭代中的资源申请量为: 44.7851105556011
# agent 69 在 49 次迭代中的资源申请量为: 45.2851108635442
# agent 70 在 49 次迭代中的资源申请量为: 59.84681335075652
# agent 71 在 49 次迭代中的资源申请量为: 71.79613774504978
# agent 72 在 49 次迭代中的资源申请量为: 60.04682866327381
# agent 73 在 49 次迭代中的资源申请量为: 43.61540451922731
# agent 74 在 49 次迭代中的资源申请量为: 38.88747376962838
# agent 75 在 49 次迭代中的资源申请量为: 51.82585037070515
# agent 76 在 49 次迭代中的资源申请量为: 46.88512298081318
# agent 77 在 49 次迭代中的资源申请量为: 40.73121794930743
# agent 78 在 49 次迭代中的资源申请量为: 49.4974731412176
# agent 79 在 49 次迭代中的资源申请量为: 42.71541115452016
# agent 80 在 49 次迭代中的资源申请量为: 42.915410153863
# agent 81 在 49 次迭代中的资源申请量为: 39.387478539364096
# agent 82 在 49 次迭代中的资源申请量为: 45.58512790249624
# agent 83 在 49 次迭代中的资源申请量为: 41.531222397834284
# agent 84 在 49 次迭代中的资源申请量为: 51.9258575693591
# agent 85 在 49 次迭代中的资源申请量为: 55.56629235778826
# agent 86 在 49 次迭代中的资源申请量为: 48.79746469669956
# agent 87 在 49 次迭代中的资源申请量为: 60.2468267283019
# agent 88 在 49 次迭代中的资源申请量为: 64.94195890688746
# agent 89 在 49 次迭代中的资源申请量为: 40.4312096670003
# agent 90 在 49 次迭代中的资源申请量为: 59.046828412851646
# agent 91 在 49 次迭代中的资源申请量为: 42.81540697175638
# agent 92 在 49 次迭代中的资源申请量为: 56.766311173398705
# agent 93 在 49 次迭代中的资源申请量为: 40.63122242256726
# agent 94 在 49 次迭代中的资源申请量为: 72.99619736789117
# agent 95 在 49 次迭代中的资源申请量为: 60.14682975657572
# agent 96 在 49 次迭代中的资源申请量为: 60.34682121509808
# agent 97 在 49 次迭代中的资源申请量为: 71.99615386809704
# agent 98 在 49 次迭代中的资源申请量为: 72.79620199940709
# agent 99 在 49 次迭代中的资源申请量为: 52.32585442099676
# agent 100 在 49 次迭代中的资源申请量为: 48.39746351589142
# 资源申请量总和为: 5000.000000000002
# ****************************************************************************
# 成本总和为: 334397.3379008167
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: 48.29420470936019
# agent 2 在 99 次迭代中的资源申请量为: 60.84356291397779
# agent 3 在 99 次迭代中的资源申请量为: 43.71262953118023
# agent 4 在 99 次迭代中的资源申请量为: 64.3377289760052
# agent 5 在 99 次迭代中的资源申请量为: 65.13829042760086
# agent 6 在 99 次迭代中的资源申请量为: 71.89161011198713
# agent 7 在 99 次迭代中的资源申请量为: 39.3850250211361
# agent 8 在 99 次迭代中的资源申请量为: 32.14454580268524
# agent 9 在 99 次迭代中的资源申请量为: 43.012958832315256
# agent 10 在 99 次迭代中的资源申请量为: 55.66290166424386
# agent 11 在 99 次迭代中的资源申请量为: 45.38203459697475
# agent 12 在 99 次迭代中的资源申请量为: 49.19374339457632
# agent 13 在 99 次迭代中的资源申请量为: 65.63700177855654
# agent 14 在 99 次迭代中的资源申请量为: 55.06334557868029
# agent 15 在 99 次迭代中的资源申请量为: 43.4123590498993
# agent 16 在 99 次迭代中的资源申请量为: 43.61276134093454
# agent 17 在 99 次迭代中的资源申请量为: 44.78186020808781
# agent 18 在 99 次迭代中的资源申请量为: 46.38252307578813
# agent 19 在 99 次迭代中的资源申请量为: 41.22834450904735
# agent 20 在 99 次迭代中的资源申请量为: 55.56155718849618
# agent 21 在 99 次迭代中的资源申请量为: 31.348702177242522
# agent 22 在 99 次迭代中的资源申请量为: 38.98504658485499
# agent 23 在 99 次迭代中的资源申请量为: 47.694525333920794
# agent 24 在 99 次迭代中的资源申请量为: 40.428870762119374
# agent 25 在 99 次迭代中的资源申请量为: 45.08228548774331
# agent 26 在 99 次迭代中的资源申请量为: 39.685173317921596
# agent 27 在 99 次迭代中的资源申请量为: 65.3386506770121
# agent 28 在 99 次迭代中的资源申请量为: 51.22245228976634
# agent 29 在 99 次迭代中的资源申请量为: 40.728684477238744
# agent 30 在 99 次迭代中的资源申请量为: 39.08488385073094
# agent 31 在 99 次迭代中的资源申请量为: 60.24236062034368
# agent 32 在 99 次迭代中的资源申请量为: 55.36296053551881
# agent 33 在 99 次迭代中的资源申请量为: 41.52861212406505
# agent 34 在 99 次迭代中的资源申请量为: 52.1216805608078
# agent 35 在 99 次迭代中的资源申请量为: 30.108506877928644
# agent 36 在 99 次迭代中的资源申请量为: 42.712188982700155
# agent 37 在 99 次迭代中的资源申请量为: 52.42250825266792
# agent 38 在 99 次迭代中的资源申请量为: 40.22860277127861
# agent 39 在 99 次迭代中的资源申请量为: 43.21282926407266
# agent 40 在 99 次迭代中的资源申请量为: 49.99410215592436
# agent 41 在 99 次迭代中的资源申请量为: 66.03651383651423
# agent 42 在 99 次迭代中的资源申请量为: 42.412707002223236
# agent 43 在 99 次迭代中的资源申请量为: 51.62281262805085
# agent 44 在 99 次迭代中的资源申请量为: 52.82265017085834
# agent 45 在 99 次迭代中的资源申请量为: 48.094409179163925
# agent 46 在 99 次迭代中的资源申请量为: 55.66212727059388
# agent 47 在 99 次迭代中的资源申请量为: 45.78254978639541
# agent 48 在 99 次迭代中的资源申请量为: 43.31303858911428
# agent 49 在 99 次迭代中的资源申请量为: 42.61312181215807
# agent 50 在 99 次迭代中的资源申请量为: 40.828857607218424
# agent 51 在 99 次迭代中的资源申请量为: 48.194389067739074
# agent 52 在 99 次迭代中的资源申请量为: 55.562879436499635
# agent 53 在 99 次迭代中的资源申请量为: 38.88482947107634
# agent 54 在 99 次迭代中的资源申请量为: 56.763176464326314
# agent 55 在 99 次迭代中的资源申请量为: 70.79212601125418
# agent 56 在 99 次迭代中的资源申请量为: 40.82878991260025
# agent 57 在 99 次迭代中的资源申请量为: 60.24164082494818
# agent 58 在 99 次迭代中的资源申请量为: 42.11245816883415
# agent 59 在 99 次迭代中的资源申请量为: 47.79409811162283
# agent 60 在 99 次迭代中的资源申请量为: 55.86340192206184
# agent 61 在 99 次迭代中的资源申请量为: 65.73847805911008
# agent 62 在 99 次迭代中的资源申请量为: 45.98272085717912
# agent 63 在 99 次迭代中的资源申请量为: 38.885300731031705
# agent 64 在 99 次迭代中的资源申请量为: 44.28208318493171
# agent 65 在 99 次迭代中的资源申请量为: 42.61294046872362
# agent 66 在 99 次迭代中的资源申请量为: 65.43799223067523
# agent 67 在 99 次迭代中的资源申请量为: 43.21293065864776
# agent 68 在 99 次迭代中的资源申请量为: 44.7824579477729
# agent 69 在 99 次迭代中的资源申请量为: 45.28259972432341
# agent 70 在 99 次迭代中的资源申请量为: 59.843072252382484
# agent 71 在 99 次迭代中的资源申请量为: 71.79170502622453
# agent 72 在 99 次迭代中的资源申请量为: 60.04333476655043
# agent 73 在 99 次迭代中的资源申请量为: 43.61304780249125
# agent 74 在 99 次迭代中的资源申请量为: 38.885263409396394
# agent 75 在 99 次迭代中的资源申请量为: 51.82311346261234
# agent 76 在 99 次迭代中的资源申请量为: 46.882572454275916
# agent 77 在 99 次迭代中的资源申请量为: 40.729035210006366
# agent 78 在 99 次迭代中的资源申请量为: 49.494385313954766
# agent 79 在 99 次迭代中的资源申请量为: 42.71283810107406
# agent 80 在 99 次迭代中的资源申请量为: 42.912942593531085
# agent 81 在 99 次迭代中的资源申请量为: 39.385158010896376
# agent 82 在 99 次迭代中的资源申请量为: 45.58156282776258
# agent 83 在 99 次迭代中的资源申请量为: 41.52877260043682
# agent 84 在 99 次迭代中的资源申请量为: 51.92279106241933
# agent 85 在 99 次迭代中的资源申请量为: 55.56323417066073
# agent 86 在 99 次迭代中的资源申请量为: 48.79438676116446
# agent 87 在 99 次迭代中的资源申请量为: 60.24235007642875
# agent 88 在 99 次迭代中的资源申请量为: 64.93815160541833
# agent 89 在 99 次迭代中的资源申请量为: 40.42853811352456
# agent 90 在 99 次迭代中的资源申请量为: 59.0436068121811
# agent 91 在 99 次迭代中的资源申请量为: 42.812895177812756
# agent 92 在 99 次迭代中的资源申请量为: 56.762857728334644
# agent 93 在 99 次迭代中的资源申请量为: 40.62854367211553
# agent 94 在 99 次迭代中的资源申请量为: 72.9929925393895
# agent 95 在 99 次迭代中的资源申请量为: 60.143816108046025
# agent 96 在 99 次迭代中的资源申请量为: 60.34329624332793
# agent 97 在 99 次迭代中的资源申请量为: 71.99185413572275
# agent 98 在 99 次迭代中的资源申请量为: 72.79017890491156
# agent 99 在 99 次迭代中的资源申请量为: 52.32277460012309
# agent 100 在 99 次迭代中的资源申请量为: 48.39423150578307
# 资源申请量总和为: 5000.000000000001
# ****************************************************************************
# 成本总和为: 334386.8974387496
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 149 次迭代中的结果：
# agent 1 在 149 次迭代中的资源申请量为: 48.28019402514758
# agent 2 在 149 次迭代中的资源申请量为: 60.82557374566843
# agent 3 在 149 次迭代中的资源申请量为: 43.70021688969933
# agent 4 在 149 次迭代中的资源申请量为: 64.31847940714857
# agent 5 在 149 次迭代中的资源申请量为: 65.11870588441887
# agent 6 在 149 次迭代中的资源申请量为: 71.87038193015682
# agent 7 在 149 次迭代中的资源申请量为: 39.37391964954698
# agent 8 在 149 次迭代中的资源申请量为: 32.09988807193005
# agent 9 在 149 次迭代中的资源申请量为: 43.000331960534254
# agent 10 在 149 次迭代中的资源申请量为: 55.64654625639712
# agent 11 在 149 次迭代中的资源申请量为: 45.369019984020134
# agent 12 在 149 次迭代中的资源申请量为: 49.18015483864335
# agent 13 在 149 次迭代中的资源申请量为: 65.61823152074045
# agent 14 在 149 次迭代中的资源申请量为: 55.04665383436144
# agent 15 在 149 次迭代中的资源申请量为: 43.40014699868562
# agent 16 在 149 次迭代中的资源申请量为: 43.60022952388794
# agent 17 在 149 次迭代中的资源申请量为: 44.76890345858831
# agent 18 在 149 次迭代中的资源申请量为: 46.369110005036205
# agent 19 在 149 次迭代中的资源申请量为: 41.216870995401884
# agent 20 在 149 次迭代中的资源申请量为: 55.54621888674174
# agent 21 在 149 次迭代中的资源申请量为: 31.58131933756949
# agent 22 在 149 次迭代中的资源申请量为: 38.97390640698431
# agent 23 在 149 次迭代中的资源申请量为: 47.680312079652744
# agent 24 在 149 次迭代中的资源申请量为: 40.416962429509105
# agent 25 在 149 次迭代中的资源申请量为: 45.069037720361166
# agent 26 在 149 次迭代中的资源申请量为: 39.67397330031396
# agent 27 在 149 次迭代中的资源申请量为: 65.31892199179919
# agent 28 在 149 次迭代中的资源申请量为: 51.207384779350825
# agent 29 在 149 次迭代中的资源申请量为: 40.7169334365766
# agent 30 在 149 次迭代中的资源申请量为: 39.073895163192965
# agent 31 在 149 次迭代中的资源申请量为: 60.225277730891804
# agent 32 在 149 次迭代中的资源申请量为: 55.34651903656937
# agent 33 在 149 次迭代中的资源申请量为: 41.51687628262557
# agent 34 在 149 次迭代中的资源申请量为: 52.107264702332174
# agent 35 在 149 次迭代中的资源申请量为: 31.349028652157827
# agent 36 在 149 次迭代中的资源申请量为: 42.70019527128428
# agent 37 在 149 次迭代中的资源申请量为: 52.407439777587385
# agent 38 在 149 次迭代中的资源申请量为: 40.21687307259531
# agent 39 在 149 次迭代中的资源申请量为: 43.20027945826021
# agent 40 在 149 次迭代中的资源申请量为: 49.980216995246245
# agent 41 在 149 次迭代中的资源申请量为: 66.01824088130599
# agent 42 在 149 次迭代中的资源申请量为: 42.40027609001231
# agent 43 在 149 次迭代中的资源申请量为: 51.60749581164132
# agent 44 在 149 次迭代中的资源申请量为: 52.807487883510426
# agent 45 在 149 次迭代中的资源申请量为: 48.080266141477274
# agent 46 在 149 次迭代中的资源申请量为: 55.646407878593436
# agent 47 在 149 次迭代中的资源申请量为: 45.769146939609676
# agent 48 在 149 次迭代中的资源申请量为: 43.30037990768613
# agent 49 在 149 次迭代中的资源申请量为: 42.60038126283072
# agent 50 在 149 次迭代中的资源申请量为: 40.81695656260254
# agent 51 在 149 次迭代中的资源申请量为: 48.18029152182602
# agent 52 在 149 次迭代中的资源申请量为: 55.546461016722446
# agent 53 在 149 次迭代中的资源申请量为: 38.873850580685534
# agent 54 在 149 次迭代中的资源申请量为: 56.746638564984394
# agent 55 在 149 次迭代中的资源申请量为: 70.770547911496
# agent 56 在 149 次迭代中的资源申请量为: 40.816914370668925
# agent 57 在 149 次迭代中的资源申请量为: 60.22500741553786
# agent 58 在 149 次迭代中的资源申请量为: 42.10024222318694
# agent 59 在 149 次迭代中的资源申请量为: 47.78026628995783
# agent 60 在 149 次迭代中的资源申请量为: 55.846739803235714
# agent 61 在 149 次迭代中的资源申请量为: 65.71880921852022
# agent 62 在 149 次迭代中的资源申请量为: 45.9692088297519
# agent 63 在 149 次迭代中的资源申请量为: 38.8740050758541
# agent 64 在 149 次迭代中的资源申请量为: 44.26897396684971
# agent 65 在 149 次迭代中的资源申请量为: 42.600290450446444
# agent 66 在 149 次迭代中的资源申请量为: 65.41856760805588
# agent 67 在 149 次迭代中的资源申请量为: 43.200320922172004
# agent 68 在 149 次迭代中的资源申请量为: 44.76909669726746
# agent 69 在 149 次迭代中的资源申请量为: 45.26911529887726
# agent 70 在 149 次迭代中的资源申请量为: 59.8253813056895
# agent 71 在 149 次迭代中的资源申请量为: 71.77043781500319
# agent 72 在 149 次迭代中的资源申请量为: 60.02555162449038
# agent 73 在 149 次迭代中的资源申请量为: 43.600375474303554
# agent 74 在 149 次迭代中的资源申请量为: 38.87398798612705
# agent 75 在 149 次迭代中的资源申请量为: 51.80763643333134
# agent 76 在 149 次迭代中的资源申请量为: 46.86915787829367
# agent 77 在 149 次迭代中的资源申请量为: 40.71704229795997
# agent 78 在 149 次迭代中的资源申请量为: 49.48026466560435
# agent 79 在 149 次迭代中的资源申请量为: 42.7003234235404
# agent 80 在 149 次迭代中的资源申请量为: 42.900322261908954
# agent 81 在 149 次迭代中的资源申请量为: 39.37396110851563
# agent 82 在 149 次迭代中的资源申请量为: 45.56886463311995
# agent 83 在 149 次迭代中的资源申请量为: 41.51694786526786
# agent 84 在 149 次迭代中的资源申请量为: 51.9075168760468
# agent 85 在 149 次迭代中的资源申请量为: 55.54665852424357
# agent 86 在 149 次迭代中的资源申请量为: 48.78029333097784
# agent 87 在 149 次迭代中的资源申请量为: 60.22526970486152
# agent 88 在 149 次迭代中的资源申请量为: 64.91864629563791
# agent 89 在 149 次迭代中的资源申请量为: 40.41689151449725
# agent 90 在 149 次迭代中的资源申请量为: 59.025593250703274
# agent 91 在 149 次迭代中的资源申请量为: 42.80032379917077
# agent 92 在 149 次迭代中的资源申请量为: 56.746483563784906
# agent 93 在 149 次迭代中的资源申请量为: 40.61686764364473
# agent 94 在 149 次迭代中的资源申请量为: 72.9710339457196
# agent 95 在 149 次迭代中的资源申请量为: 60.125714649524205
# agent 96 在 149 次迭代中的资源申请量为: 60.325478415462506
# agent 97 在 149 次迭代中的资源申请量为: 71.97048220097557
# agent 98 在 149 次迭代中的资源申请量为: 72.77000561264447
# agent 99 在 149 次迭代中的资源申请量为: 52.307497969237225
# agent 100 在 149 次迭代中的资源申请量为: 48.38020531272984
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 334343.55491140723
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: 48.273319454949394
# agent 2 在 199 次迭代中的资源申请量为: 60.8166502186728
# agent 3 在 199 次迭代中的资源申请量为: 43.69410552500538
# agent 4 在 199 次迭代中的资源申请量为: 64.30907159585173
# agent 5 在 199 次迭代中的资源申请量为: 65.10907196294104
# agent 6 在 199 次迭代中的资源申请量为: 71.85997883281122
# agent 7 在 199 次迭代中的资源申请量为: 39.36841044115751
# agent 8 在 199 次迭代中的资源申请量为: 32.08197080717217
# agent 9 在 199 次迭代中的资源申请量为: 42.99410577828587
# agent 10 在 199 次迭代中的资源申请量为: 55.63844619763597
# agent 11 在 199 次迭代中的资源申请量为: 45.36248731068348
# agent 12 在 199 次迭代中的资源申请量为: 49.17331978515165
# agent 13 在 199 次迭代中的资源申请量为: 65.60907146792248
# agent 14 在 199 次迭代中的资源申请量为: 55.03844585592694
# agent 15 在 199 次迭代中的资源申请量为: 43.39410544446432
# agent 16 在 199 次迭代中的资源申请量为: 43.594105382749675
# agent 17 在 199 次迭代中的资源申请量为: 44.7624871224761
# agent 18 在 199 次迭代中的资源申请量为: 46.36248725630701
# agent 19 在 199 次迭代中的资源申请量为: 41.21109987480319
# agent 20 在 199 次迭代中的资源申请量为: 55.53844590410801
# agent 21 在 199 次迭代中的资源申请量为: 31.856538380620748
# agent 22 在 199 次迭代中的资源申请量为: 38.9684104086906
# agent 23 在 199 次迭代中的资源申请量为: 47.67331979139584
# agent 24 在 199 次迭代中的资源申请量为: 40.41109976566445
# agent 25 在 199 次迭代中的资源申请量为: 45.06248718746697
# agent 26 在 199 次迭代中的资源申请量为: 39.668410650127576
# agent 27 在 199 次迭代中的资源申请量为: 65.3090735368161
# agent 28 在 199 次迭代中的资源申请量为: 51.19998513071152
# agent 29 在 199 次迭代中的资源申请量为: 40.71109995662765
# agent 30 在 199 次迭代中的资源申请量为: 39.06841066008342
# agent 31 在 199 次迭代中的资源申请量为: 60.216649893647514
# agent 32 在 199 次迭代中的资源申请量为: 55.33844553125063
# agent 33 在 199 次迭代中的资源申请量为: 41.511099599109706
# agent 34 在 199 次迭代中的资源申请量为: 52.09998538108206
# agent 35 在 199 次迭代中的资源申请量为: 31.799211585499524
# agent 36 在 199 次迭代中的资源申请量为: 42.694105719178914
# agent 37 在 199 次迭代中的资源申请量为: 52.399985365828115
# agent 38 在 199 次迭代中的资源申请量为: 40.21109951399816
# agent 39 在 199 次迭代中的资源申请量为: 43.19410559109172
# agent 40 在 199 次迭代中的资源申请量为: 49.97331985004772
# agent 41 在 199 次迭代中的资源申请量为: 66.00907267474811
# agent 42 在 199 次迭代中的资源申请量为: 42.394105933033096
# agent 43 在 199 次迭代中的资源申请量为: 51.5999850070272
# agent 44 在 199 次迭代中的资源申请量为: 52.79998521928379
# agent 45 在 199 次迭代中的资源申请量为: 48.07331954407929
# agent 46 在 199 次迭代中的资源申请量为: 55.63844659827194
# agent 47 在 199 次迭代中的资源申请量为: 45.7624876473411
# agent 48 在 199 次迭代中的资源申请量为: 43.29410607848046
# agent 49 在 199 次迭代中的资源申请量为: 42.594105733188314
# agent 50 在 199 次迭代中的资源申请量为: 40.81109967201929
# agent 51 在 199 次迭代中的资源申请量为: 48.17331993997711
# agent 52 在 199 次迭代中的资源申请量为: 55.53844549850406
# agent 53 在 199 次迭代中的资源申请量为: 38.86841032338365
# agent 54 在 199 次迭代中的资源申请量为: 56.73844623571017
# agent 55 在 199 次迭代中的资源申请量为: 70.75997935745394
# agent 56 在 199 次迭代中的资源申请量为: 40.81109962498386
# agent 57 在 199 次迭代中的资源申请量为: 60.21664984921546
# agent 58 在 199 次迭代中的资源申请量为: 42.094105819982374
# agent 59 在 199 次迭代中的资源申请量为: 47.77331968040263
# agent 60 在 199 次迭代中的资源申请量为: 55.83844615810724
# agent 61 在 199 次迭代中的资源申请量为: 65.70907223049781
# agent 62 在 199 次迭代中的资源申请量为: 45.962487552607364
# agent 63 在 199 次迭代中的资源申请量为: 38.86841059590284
# agent 64 在 199 次迭代中的资源申请量为: 44.26248730619344
# agent 65 在 199 次迭代中的资源申请量为: 42.59410544218292
# agent 66 在 199 次迭代中的资源申请量为: 65.40907229574496
# agent 67 在 199 次迭代中的资源申请量为: 43.19410567505945
# agent 68 在 199 次迭代中的资源申请量为: 44.762487310565106
# agent 69 在 199 次迭代中的资源申请量为: 45.262487257677954
# agent 70 在 199 次迭代中的资源申请量为: 59.81664971059978
# agent 71 在 199 次迭代中的资源申请量为: 71.75997916752287
# agent 72 在 199 次迭代中的资源申请量为: 60.01665080805967
# agent 73 在 199 次迭代中的资源申请量为: 43.59410579794381
# agent 74 在 199 次迭代中的资源申请量为: 38.868410465261086
# agent 75 在 199 次迭代中的资源申请量为: 51.79998581923433
# agent 76 在 199 次迭代中的资源申请量为: 46.862487555524126
# agent 77 在 199 次迭代中的资源申请量为: 40.71110012966177
# agent 78 在 199 次迭代中的资源申请量为: 49.47331948554643
# agent 79 在 199 次迭代中的资源申请量为: 42.694105985815206
# agent 80 在 199 次迭代中的资源申请量为: 42.89410573641366
# agent 81 在 199 次迭代中的资源申请量为: 39.36841048020217
# agent 82 在 199 次迭代中的资源申请量为: 45.56248716881745
# agent 83 在 199 次迭代中的资源申请量为: 41.51109975280176
# agent 84 在 199 次迭代中的资源申请量为: 51.899985361025145
# agent 85 在 199 次迭代中的资源申请量为: 55.53844585569802
# agent 86 在 199 次迭代中的资源申请量为: 48.77331973689005
# agent 87 在 199 次迭代中的资源申请量为: 60.21664996084293
# agent 88 在 199 次迭代中的资源申请量为: 64.90907220032992
# agent 89 在 199 次迭代中的资源申请量为: 40.41109983617362
# agent 90 在 199 次迭代中的资源申请量为: 59.01664999512857
# agent 91 在 199 次迭代中的资源申请量为: 42.794105710245184
# agent 92 在 199 次迭代中的资源申请量为: 56.7384455989315
# agent 93 在 199 次迭代中的资源申请量为: 40.611099769032684
# agent 94 在 199 次迭代中的资源申请量为: 72.95998206772387
# agent 95 在 199 次迭代中的资源申请量为: 60.11665099659773
# agent 96 在 199 次迭代中的资源申请量为: 60.31665004123704
# agent 97 在 199 次迭代中的资源申请量为: 71.9599790209941
# agent 98 在 199 次迭代中的资源申请量为: 72.75997897806216
# agent 99 在 199 次迭代中的资源申请量为: 52.29998539794817
# agent 100 在 199 次迭代中的资源申请量为: 48.373319430095115
# 资源申请量总和为: 5000.000000000001
# ****************************************************************************
# 成本总和为: 334324.36923783337
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 249 次迭代中的结果：
# agent 1 在 249 次迭代中的资源申请量为: 48.261336122698125
# agent 2 在 249 次迭代中的资源申请量为: 60.79045626919428
# agent 3 在 249 次迭代中的资源申请量为: 43.68018088105035
# agent 4 在 249 次迭代中的资源申请量为: 64.29678091607693
# agent 5 在 249 次迭代中的资源申请量为: 65.09896887727557
# agent 6 在 249 次迭代中的资源申请量为: 71.84771964681302
# agent 7 在 249 次迭代中的资源申请量为: 39.35912198433819
# agent 8 在 249 次迭代中的资源申请量为: 32.183720605584305
# agent 9 在 249 次迭代中的资源申请量为: 42.98005434899354
# agent 10 在 249 次迭代中的资源申请量为: 55.61099536806253
# agent 11 在 249 次迭代中的资源申请量为: 45.34154831487584
# agent 12 在 249 次迭代中的资源申请量为: 49.14565512512082
# agent 13 在 249 次迭代中的资源申请量为: 65.5898630588612
# agent 14 在 249 次迭代中的资源申请量为: 55.016824320275994
# agent 15 在 249 次迭代中的资源申请量为: 43.37926583078076
# agent 16 在 249 次迭代中的资源申请量为: 43.58691989975452
# agent 17 在 249 次迭代中的资源申请量为: 44.74770937532563
# agent 18 在 249 次迭代中的资源申请量为: 46.34388447800013
# agent 19 在 249 次迭代中的资源申请量为: 41.18828723680629
# agent 20 在 249 次迭代中的资源申请量为: 55.4871493777796
# agent 21 在 249 次迭代中的资源申请量为: 32.49422436649282
# agent 22 在 249 次迭代中的资源申请量为: 38.95046113879824
# agent 23 在 249 次迭代中的资源申请量为: 47.66371374081014
# agent 24 在 249 次迭代中的资源申请量为: 40.404547499497184
# agent 25 在 249 次迭代中的资源申请量为: 45.05226784429514
# agent 26 在 249 次迭代中的资源申请量为: 39.65656989198877
# agent 27 在 249 次迭代中的资源申请量为: 65.2988853189042
# agent 28 在 249 次迭代中的资源申请量为: 51.187387301462195
# agent 29 在 249 次迭代中的资源申请量为: 40.700217033888
# agent 30 在 249 次迭代中的资源申请量为: 39.04737540428747
# agent 31 在 249 次迭代中的资源申请量为: 60.18545819322526
# agent 32 在 249 次迭代中的资源申请量为: 55.32990268923304
# agent 33 在 249 次迭代中的资源申请量为: 41.50429696591728
# agent 34 在 249 次迭代中的资源申请量为: 52.072899894568614
# agent 35 在 249 次迭代中的资源申请量为: 32.522444685707
# agent 36 在 249 次迭代中的资源申请量为: 42.66992589136353
# agent 37 在 249 次迭代中的资源申请量为: 52.38616056216784
# agent 38 在 249 次迭代中的资源申请量为: 40.2014653678166
# agent 39 在 249 次迭代中的资源申请量为: 43.18661731659543
# agent 40 在 249 次迭代中的资源申请量为: 49.95690737512389
# agent 41 在 249 次迭代中的资源申请量为: 65.97400449722502
# agent 42 在 249 次迭代中的资源申请量为: 42.38225418536058
# agent 43 在 249 次迭代中的资源申请量为: 51.59536991533892
# agent 44 在 249 次迭代中的资源申请量为: 52.78900019905354
# agent 45 在 249 次迭代中的资源申请量为: 48.0646423196819
# agent 46 在 249 次迭代中的资源申请量为: 55.602974986744606
# agent 47 在 249 次迭代中的资源申请量为: 45.75166779528144
# agent 48 在 249 次迭代中的资源申请量为: 43.283960778883745
# agent 49 在 249 次迭代中的资源申请量为: 42.590689204005464
# agent 50 在 249 次迭代中的资源申请量为: 40.80293484265797
# agent 51 在 249 次迭代中的资源申请量为: 48.15002190470635
# agent 52 在 249 次迭代中的资源申请量为: 55.52984099437179
# agent 53 在 249 次迭代中的资源申请量为: 38.85859876510545
# agent 54 在 249 次迭代中的资源申请量为: 56.72940501166991
# agent 55 在 249 次迭代中的资源申请量为: 70.75070470760642
# agent 56 在 249 次迭代中的资源申请量为: 40.803887511336455
# agent 57 在 249 次迭代中的资源申请量为: 60.180407106970506
# agent 58 在 249 次迭代中的资源申请量为: 42.071715539188624
# agent 59 在 249 次迭代中的资源申请量为: 47.748608646570396
# agent 60 在 249 次迭代中的资源申请量为: 55.812668801521205
# agent 61 在 249 次迭代中的资源申请量为: 65.69812211110322
# agent 62 在 249 次迭代中的资源申请量为: 45.95474684248645
# agent 63 在 249 次迭代中的资源申请量为: 38.85235544852794
# agent 64 在 249 次迭代中的资源申请量为: 44.250344218077565
# agent 65 在 249 次迭代中的资源申请量为: 42.58748805483648
# agent 66 在 249 次迭代中的资源申请量为: 65.40070007883453
# agent 67 在 249 次迭代中的资源申请量为: 43.185487619702634
# agent 68 在 249 次迭代中的资源申请量为: 44.7520682762123
# agent 69 在 249 次迭代中的资源申请量为: 45.25603049075393
# agent 70 在 249 次迭代中的资源申请量为: 59.80166213479286
# agent 71 在 249 次迭代中的资源申请量为: 71.747011771717
# agent 72 在 249 次迭代中的资源申请量为: 59.98720456514632
# agent 73 在 249 次迭代中的资源申请量为: 43.58434532178268
# agent 74 在 249 次迭代中的资源申请量为: 38.86256621504254
# agent 75 在 249 次迭代中的资源申请量为: 51.79272571930539
# agent 76 在 249 次迭代中的资源申请量为: 46.8527022451802
# agent 77 在 249 次迭代中的资源申请量为: 40.70606534615245
# agent 78 在 249 次迭代中的资源申请量为: 49.46382772365694
# agent 79 在 249 次迭代中的资源申请量为: 42.67972558107651
# agent 80 在 249 次迭代中的资源申请量为: 42.887591430257196
# agent 81 在 249 次迭代中的资源申请量为: 39.35917827470746
# agent 82 在 249 次迭代中的资源申请量为: 45.536582055299505
# agent 83 在 249 次迭代中的资源申请量为: 41.498798276880166
# agent 84 在 249 次迭代中的资源申请量为: 51.876808296006956
# agent 85 在 249 次迭代中的资源申请量为: 55.52778032160879
# agent 86 在 249 次迭代中的资源申请量为: 48.751355883854224
# agent 87 在 249 次迭代中的资源申请量为: 60.18616259940061
# agent 88 在 249 次迭代中的资源申请量为: 64.90106347747495
# agent 89 在 249 次迭代中的资源申请量为: 40.39897125952025
# agent 90 在 249 次迭代中的资源申请量为: 59.00870603192142
# agent 91 在 249 次迭代中的资源申请量为: 42.784441571852824
# agent 92 在 249 次迭代中的资源申请量为: 56.71018251419088
# agent 93 在 249 次迭代中的资源申请量为: 40.59910595770862
# agent 94 在 249 次迭代中的资源申请量为: 72.94892375068503
# agent 95 在 249 次迭代中的资源申请量为: 60.08959225391184
# agent 96 在 249 次迭代中的资源申请量为: 60.30630988880214
# agent 97 在 249 次迭代中的资源申请量为: 71.95061149669672
# agent 98 在 249 次迭代中的资源申请量为: 72.72337288184005
# agent 99 在 249 次迭代中的资源申请量为: 52.294046981344856
# agent 100 在 249 次迭代中的资源申请量为: 48.3637067985569
# 资源申请量总和为: 5000.000000000002
# ****************************************************************************
# 成本总和为: 334288.2797387915
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 299 次迭代中的结果：
# agent 1 在 299 次迭代中的资源申请量为: 48.25604124221536
# agent 2 在 299 次迭代中的资源申请量为: 60.79506076504232
# agent 3 在 299 次迭代中的资源申请量为: 43.678860179709424
# agent 4 在 299 次迭代中的资源申请量为: 64.28551066960107
# agent 5 在 299 次迭代中的资源申请量为: 65.0855224518868
# agent 6 在 299 次迭代中的资源申请量为: 71.83406963164076
# agent 7 在 299 次迭代中的资源申请量为: 39.35477713003958
# agent 8 在 299 次迭代中的资源申请量为: 32.15741836325411
# agent 9 在 299 次迭代中的资源申请量为: 42.978869056856226
# agent 10 在 299 次迭代中的资源申请量为: 55.618516070437934
# agent 11 在 299 次迭代中的资源申请量为: 45.34629646333641
# agent 12 在 299 次迭代中的资源申请量为: 49.156047688623175
# agent 13 在 299 次迭代中的资源申请量为: 65.58550395742587
# agent 14 在 299 次迭代中的资源申请量为: 55.01852050347628
# agent 15 在 299 次迭代中的资源申请量为: 43.37886051527268
# agent 16 在 299 次迭代中的资源申请量为: 43.57886484976195
# agent 17 在 299 次迭代中的资源申请量为: 44.74629106947592
# agent 18 在 299 次迭代中的资源申请量为: 46.34629718878409
# agent 19 在 299 次迭代中的资源申请量为: 41.19670706868057
# agent 20 在 299 次迭代中的资源申请量为: 55.51850876967386
# agent 21 在 299 次迭代中的资源申请量为: 32.63252654607244
# agent 22 在 299 次迭代中的资源申请量为: 38.954774853094385
# agent 23 在 299 次迭代中的资源申请量为: 47.656046071309945
# agent 24 在 299 次迭代中的资源申请量为: 40.39670620277973
# agent 25 在 299 次迭代中的资源申请量为: 45.0462962252397
# agent 26 在 299 次迭代中的资源申请量为: 39.65477943189439
# agent 27 在 299 次迭代中的资源申请量为: 65.28554377558892
# agent 28 在 299 次迭代中的资源申请量为: 51.18147684682171
# agent 29 在 299 次迭代中的资源申请量为: 40.69670870027889
# agent 30 在 299 次迭代中的资源申请量为: 39.05477738502221
# agent 31 在 299 次迭代中的资源申请量为: 60.19505654648335
# agent 32 在 299 次迭代中的资源申请量为: 55.31851643698745
# agent 33 在 299 次迭代中的资源申请量为: 41.49670747170941
# agent 34 在 299 次迭代中的资源申请量为: 52.08147788259168
# agent 35 在 299 次迭代中的资源申请量为: 32.69521608157326
# agent 36 在 299 次迭代中的资源申请量为: 42.67886533484585
# agent 37 在 299 次迭代中的资源申请量为: 52.38147785416869
# agent 38 在 299 次迭代中的资源申请量为: 40.19670279349288
# agent 39 在 299 次迭代中的资源申请量为: 43.1788658981826
# agent 40 在 299 次迭代中的资源申请量为: 49.95604993705157
# agent 41 在 299 次迭代中的资源申请量为: 65.985520485295
# agent 42 在 299 次迭代中的资源申请量为: 42.37886963200326
# agent 43 在 299 次迭代中的资源申请量为: 51.58147903441321
# agent 44 在 299 次迭代中的资源申请量为: 52.78147799843632
# agent 45 在 299 次迭代中的资源申请量为: 48.05604576967153
# agent 46 在 299 次迭代中的资源申请量为: 55.61852110419677
# agent 47 在 299 次迭代中的资源申请量为: 45.74629922239675
# agent 48 在 299 次迭代中的资源申请量为: 43.27887179714382
# agent 49 在 299 次迭代中的资源申请量为: 42.57887083746881
# agent 50 在 299 次迭代中的资源申请量为: 40.796707763107534
# agent 51 在 299 次迭代中的资源申请量为: 48.1560501155887
# agent 52 在 299 次迭代中的资源申请量为: 55.51851671612652
# agent 53 在 299 次迭代中的资源申请量为: 38.85477490241734
# agent 54 在 299 次迭代中的资源申请量为: 56.71852740362961
# agent 55 在 299 次迭代中的资源申请量为: 70.73408200277532
# agent 56 在 299 次迭代中的资源申请量为: 40.79670732823609
# agent 57 在 299 次迭代中的资源申请量为: 60.19505931522744
# agent 58 在 299 次迭代中的资源申请量为: 42.07886675393185
# agent 59 在 299 次迭代中的资源申请量为: 47.75604705385532
# agent 60 在 299 次迭代中的资源申请量为: 55.818523668951784
# agent 61 在 299 次迭代中的资源申请量为: 65.68552164015773
# agent 62 在 299 次迭代中的资源申请量为: 45.946301851421566
# agent 63 在 299 次迭代中的资源申请量为: 38.85477885212024
# agent 64 在 299 次迭代中的资源申请量为: 44.2462946363983
# agent 65 在 299 次迭代中的资源申请量为: 42.57886458849925
# agent 66 在 299 次迭代中的资源申请量为: 65.38552702206161
# agent 67 在 299 次迭代中的资源申请量为: 43.17886867035181
# agent 68 在 299 次迭代中的资源申请量为: 44.74629804696462
# agent 69 在 299 次迭代中的资源申请量为: 45.24629930047973
# agent 70 在 299 次迭代中的资源申请量为: 59.79506003543695
# agent 71 在 299 次迭代中的资源申请量为: 71.7340715955346
# agent 72 在 299 次迭代中的资源申请量为: 59.99506785981028
# agent 73 在 299 次迭代中的资源申请量为: 43.578868722465785
# agent 74 在 299 次迭代中的资源申请量为: 38.854776423724225
# agent 75 在 299 次迭代中的资源申请量为: 51.781484599462715
# agent 76 在 299 次迭代中的资源申请量为: 46.8462989968439
# agent 77 在 299 次迭代中的资源申请量为: 40.69671342453004
# agent 78 在 299 次迭代中的资源申请量为: 49.45604733958998
# agent 79 在 299 次迭代中的资源申请量为: 42.67887052509374
# agent 80 在 299 次迭代中的资源申请量为: 42.87886815299735
# agent 81 在 299 次迭代中的资源申请量为: 39.354777363377764
# agent 82 在 299 次迭代中的资源申请量为: 45.546289952803114
# agent 83 在 299 次迭代中的资源申请量为: 41.49670729165114
# agent 84 在 299 次迭代中的资源申请量为: 51.88148029957189
# agent 85 在 299 次迭代中的资源申请量为: 55.51852125634838
# agent 86 在 299 次迭代中的资源申请量为: 48.75604829273975
# agent 87 在 299 次迭代中的资源申请量为: 60.19505978598587
# agent 88 在 299 次迭代中的资源申请量为: 64.88552748490797
# agent 89 在 299 次迭代中的资源申请量为: 40.39670769868719
# agent 90 在 299 次迭代中的资源申请量为: 58.99506893146678
# agent 91 在 299 次迭代中的资源申请量为: 42.778867645604485
# agent 92 在 299 次迭代中的资源申请量为: 56.71850928388775
# agent 93 在 299 次迭代中的资源申请量为: 40.59670559051162
# agent 94 在 299 次迭代中的资源申请量为: 72.93410578263313
# agent 95 在 299 次迭代中的资源申请量为: 60.09507447933251
# agent 96 在 299 次迭代中的资源申请量为: 60.295067470715075
# agent 97 在 299 次迭代中的资源申请量为: 71.93407890588634
# agent 98 在 299 次迭代中的资源申请量为: 72.7340589620166
# agent 99 在 299 次迭代中的资源申请量为: 52.28148313019771
# agent 100 在 299 次迭代中的资源申请量为: 48.356043292473814
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 334281.6056292887
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 349 次迭代中的结果：
# agent 1 在 349 次迭代中的资源申请量为: 48.256050579544784
# agent 2 在 349 次迭代中的资源申请量为: 60.795063224448555
# agent 3 在 349 次迭代中的资源申请量为: 43.678868158422425
# agent 4 在 349 次迭代中的资源申请量为: 64.28552351754495
# agent 5 在 349 次迭代中的资源申请量为: 65.08552351753646
# agent 6 在 349 次迭代中的资源申请量为: 71.83407586926627
# agent 7 在 349 次迭代中的资源申请量为: 39.35477677332421
# agent 8 在 349 次迭代中的资源申请量为: 32.15738725833399
# agent 9 在 349 次迭代中的资源申请量为: 42.97886815842148
# agent 10 在 349 次迭代中的资源申请量为: 55.618519899488994
# agent 11 在 349 次迭代中的资源申请量为: 45.3462974183222
# agent 12 在 349 次迭代中的资源申请量为: 49.1560505795455
# agent 13 在 349 次迭代中的资源申请量为: 65.58552351754972
# agent 14 在 349 次迭代中的资源申请量为: 55.01851989947387
# agent 15 在 349 次迭代中的资源申请量为: 43.37886815842033
# agent 16 在 349 次迭代中的资源申请量为: 43.578868158409996
# agent 17 在 349 次迭代中的资源申请量为: 44.74629741832233
# agent 18 在 349 次迭代中的资源申请量为: 46.346297418315224
# agent 19 在 349 次迭代中的资源申请量为: 41.196708816289714
# agent 20 在 349 次迭代中的资源申请量为: 55.51851989948021
# agent 21 在 349 次迭代中的资源申请量为: 32.632487970952454
# agent 22 在 349 次迭代中的资源申请量为: 38.95477677332612
# agent 23 在 349 次迭代中的资源申请量为: 47.65605057955015
# agent 24 在 349 次迭代中的资源申请量为: 40.39670881628881
# agent 25 在 349 次迭代中的资源申请量为: 45.04629741831812
# agent 26 在 349 次迭代中的资源申请量为: 39.65477677333143
# agent 27 在 349 次迭代中的资源申请量为: 65.28552351758196
# agent 28 在 349 次迭代中的资源申请量为: 51.18148276378906
# agent 29 在 349 次迭代中的资源申请量为: 40.6967088162924
# agent 30 在 349 次迭代中的资源申请量为: 39.05477677333504
# agent 31 在 349 次迭代中的资源申请量为: 60.195063224443345
# agent 32 在 349 次迭代中的资源申请量为: 55.31851989946939
# agent 33 在 349 次迭代中的资源申请量为: 41.49670881628085
# agent 34 在 349 次迭代中的资源申请量为: 52.08148276380064
# agent 35 在 349 次迭代中的资源申请量为: 32.69517219195771
# agent 36 在 349 次迭代中的资源申请量为: 42.678868158419
# agent 37 在 349 次迭代中的资源申请量为: 52.381482763792405
# agent 38 在 349 次迭代中的资源申请量为: 40.196708816282
# agent 39 在 349 次迭代中的资源申请量为: 43.17886815841788
# agent 40 在 349 次迭代中的资源申请量为: 49.95605057954338
# agent 41 在 349 次迭代中的资源申请量为: 65.98552351756587
# agent 42 在 349 次迭代中的资源申请量为: 42.3788681584272
# agent 43 在 349 次迭代中的资源申请量为: 51.58148276377887
# agent 44 在 349 次迭代中的资源申请量为: 52.781482763789576
# agent 45 在 349 次迭代中的资源申请量为: 48.05605057954146
# agent 46 在 349 次迭代中的资源申请量为: 55.61851989949264
# agent 47 在 349 次迭代中的资源申请量为: 45.746297418331274
# agent 48 在 349 次迭代中的资源申请量为: 43.278868158429205
# agent 49 在 349 次迭代中的资源申请量为: 42.57886815841542
# agent 50 在 349 次迭代中的资源申请量为: 40.79670881627979
# agent 51 在 349 次迭代中的资源申请量为: 48.15605057954561
# agent 52 在 349 次迭代中的资源申请量为: 55.518519899463236
# agent 53 在 349 次迭代中的资源申请量为: 38.85477677332392
# agent 54 在 349 次迭代中的资源申请量为: 56.71851989947961
# agent 55 在 349 次迭代中的资源申请量为: 70.73407586930486
# agent 56 在 349 次迭代中的资源申请量为: 40.79670881628175
# agent 57 在 349 次迭代中的资源申请量为: 60.195063224442826
# agent 58 在 349 次迭代中的资源申请量为: 42.078868158428584
# agent 59 在 349 次迭代中的资源申请量为: 47.756050579540904
# agent 60 在 349 次迭代中的资源申请量为: 55.81851989946889
# agent 61 在 349 次迭代中的资源申请量为: 65.68552351753952
# agent 62 在 349 次迭代中的资源申请量为: 45.94629741832165
# agent 63 在 349 次迭代中的资源申请量为: 38.85477677332769
# agent 64 在 349 次迭代中的资源申请量为: 44.24629741832364
# agent 65 在 349 次迭代中的资源申请量为: 42.57886815841497
# agent 66 在 349 次迭代中的资源申请量为: 65.38552351754821
# agent 67 在 349 次迭代中的资源申请量为: 43.17886815841705
# agent 68 在 349 次迭代中的资源申请量为: 44.746297418317916
# agent 69 在 349 次迭代中的资源申请量为: 45.246297418313645
# agent 70 在 349 次迭代中的资源申请量为: 59.79506322442694
# agent 71 在 349 次迭代中的资源申请量为: 71.73407586928808
# agent 72 在 349 次迭代中的资源申请量为: 59.995063224460154
# agent 73 在 349 次迭代中的资源申请量为: 43.57886815842162
# agent 74 在 349 次迭代中的资源申请量为: 38.8547767733277
# agent 75 在 349 次迭代中的资源申请量为: 51.78148276380398
# agent 76 在 349 次迭代中的资源申请量为: 46.84629741832921
# agent 77 在 349 次迭代中的资源申请量为: 40.69670881629115
# agent 78 在 349 次迭代中的资源申请量为: 49.45605057953842
# agent 79 在 349 次迭代中的资源申请量为: 42.67886815842674
# agent 80 在 349 次迭代中的资源申请量为: 42.87886815842196
# agent 81 在 349 次迭代中的资源申请量为: 39.35477677332936
# agent 82 在 349 次迭代中的资源申请量为: 45.54629741832441
# agent 83 在 349 次迭代中的资源申请量为: 41.4967088162846
# agent 84 在 349 次迭代中的资源申请量为: 51.881482763791645
# agent 85 在 349 次迭代中的资源申请量为: 55.518519899459314
# agent 86 在 349 次迭代中的资源申请量为: 48.75605057954224
# agent 87 在 349 次迭代中的资源申请量为: 60.19506322443782
# agent 88 在 349 次迭代中的资源申请量为: 64.88552351753493
# agent 89 在 349 次迭代中的资源申请量为: 40.39670881628207
# agent 90 在 349 次迭代中的资源申请量为: 58.99506322443028
# agent 91 在 349 次迭代中的资源申请量为: 42.77886815841959
# agent 92 在 349 次迭代中的资源申请量为: 56.71851989947323
# agent 93 在 349 次迭代中的资源申请量为: 40.59670881628811
# agent 94 在 349 次迭代中的资源申请量为: 72.93407586937154
# agent 95 在 349 次迭代中的资源申请量为: 60.09506322446073
# agent 96 在 349 次迭代中的资源申请量为: 60.295063224430535
# agent 97 在 349 次迭代中的资源申请量为: 71.9340758692716
# agent 98 在 349 次迭代中的资源申请量为: 72.73407586930732
# agent 99 在 349 次迭代中的资源申请量为: 52.28148276379483
# agent 100 在 349 次迭代中的资源申请量为: 48.3560505795408
# 资源申请量总和为: 4999.999999999997
# ****************************************************************************
# 成本总和为: 334281.60820196825
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 399 次迭代中的结果：
# agent 1 在 399 次迭代中的资源申请量为: 48.25605057954502
# agent 2 在 399 次迭代中的资源申请量为: 60.79506322443128
# agent 3 在 399 次迭代中的资源申请量为: 43.67886815842208
# agent 4 在 399 次迭代中的资源申请量为: 64.28552351756137
# agent 5 在 399 次迭代中的资源申请量为: 65.08552351756138
# agent 6 在 399 次迭代中的资源申请量为: 71.83407586931752
# agent 7 在 399 次迭代中的资源申请量为: 39.354776773325014
# agent 8 在 399 次迭代中的资源申请量为: 32.15738725827781
# agent 9 在 399 次迭代中的资源申请量为: 42.97886815842208
# agent 10 在 399 次迭代中的资源申请量为: 55.618519899475025
# agent 11 在 399 次迭代中的资源申请量为: 45.34629741832345
# agent 12 在 399 次迭代中的资源申请量为: 49.156050579545024
# agent 13 在 399 次迭代中的资源申请量为: 65.58552351756137
# agent 14 在 399 次迭代中的资源申请量为: 55.018519899475024
# agent 15 在 399 次迭代中的资源申请量为: 43.37886815842207
# agent 16 在 399 次迭代中的资源申请量为: 43.578868158422075
# agent 17 在 399 次迭代中的资源申请量为: 44.74629741832346
# agent 18 在 399 次迭代中的资源申请量为: 46.34629741832345
# agent 19 在 399 次迭代中的资源申请量为: 41.19670881628752
# agent 20 在 399 次迭代中的资源申请量为: 55.518519899475024
# agent 21 在 399 次迭代中的资源申请量为: 32.63248797089088
# agent 22 在 399 次迭代中的资源申请量为: 38.95477677332502
# agent 23 在 399 次迭代中的资源申请量为: 47.656050579545024
# agent 24 在 399 次迭代中的资源申请量为: 40.396708816287514
# agent 25 在 399 次迭代中的资源申请量为: 45.04629741832345
# agent 26 在 399 次迭代中的资源申请量为: 39.65477677332502
# agent 27 在 399 次迭代中的资源申请量为: 65.2855235175614
# agent 28 在 399 次迭代中的资源申请量为: 51.181482763798236
# agent 29 在 399 次迭代中的资源申请量为: 40.69670881628752
# agent 30 在 399 次迭代中的资源申请量为: 39.05477677332502
# agent 31 在 399 次迭代中的资源申请量为: 60.19506322443129
# agent 32 在 399 次迭代中的资源申请量为: 55.31851989947502
# agent 33 在 399 次迭代中的资源申请量为: 41.496708816287516
# agent 34 在 399 次迭代中的资源申请量为: 52.08148276379824
# agent 35 在 399 次迭代中的资源申请量为: 32.695172191893015
# agent 36 在 399 次迭代中的资源申请量为: 42.67886815842208
# agent 37 在 399 次迭代中的资源申请量为: 52.38148276379824
# agent 38 在 399 次迭代中的资源申请量为: 40.19670881628751
# agent 39 在 399 次迭代中的资源申请量为: 43.17886815842207
# agent 40 在 399 次迭代中的资源申请量为: 49.956050579545014
# agent 41 在 399 次迭代中的资源申请量为: 65.98552351756139
# agent 42 在 399 次迭代中的资源申请量为: 42.37886815842207
# agent 43 在 399 次迭代中的资源申请量为: 51.581482763798235
# agent 44 在 399 次迭代中的资源申请量为: 52.78148276379824
# agent 45 在 399 次迭代中的资源申请量为: 48.056050579545015
# agent 46 在 399 次迭代中的资源申请量为: 55.618519899475025
# agent 47 在 399 次迭代中的资源申请量为: 45.74629741832346
# agent 48 在 399 次迭代中的资源申请量为: 43.27886815842208
# agent 49 在 399 次迭代中的资源申请量为: 42.578868158422075
# agent 50 在 399 次迭代中的资源申请量为: 40.79670881628751
# agent 51 在 399 次迭代中的资源申请量为: 48.156050579545024
# agent 52 在 399 次迭代中的资源申请量为: 55.518519899475024
# agent 53 在 399 次迭代中的资源申请量为: 38.854776773325014
# agent 54 在 399 次迭代中的资源申请量为: 56.71851989947503
# agent 55 在 399 次迭代中的资源申请量为: 70.73407586931752
# agent 56 在 399 次迭代中的资源申请量为: 40.79670881628751
# agent 57 在 399 次迭代中的资源申请量为: 60.19506322443129
# agent 58 在 399 次迭代中的资源申请量为: 42.07886815842208
# agent 59 在 399 次迭代中的资源申请量为: 47.75605057954502
# agent 60 在 399 次迭代中的资源申请量为: 55.81851989947502
# agent 61 在 399 次迭代中的资源申请量为: 65.68552351756138
# agent 62 在 399 次迭代中的资源申请量为: 45.94629741832345
# agent 63 在 399 次迭代中的资源申请量为: 38.854776773325014
# agent 64 在 399 次迭代中的资源申请量为: 44.24629741832345
# agent 65 在 399 次迭代中的资源申请量为: 42.578868158422075
# agent 66 在 399 次迭代中的资源申请量为: 65.38552351756138
# agent 67 在 399 次迭代中的资源申请量为: 43.17886815842207
# agent 68 在 399 次迭代中的资源申请量为: 44.74629741832346
# agent 69 在 399 次迭代中的资源申请量为: 45.24629741832346
# agent 70 在 399 次迭代中的资源申请量为: 59.795063224431274
# agent 71 在 399 次迭代中的资源申请量为: 71.73407586931752
# agent 72 在 399 次迭代中的资源申请量为: 59.99506322443128
# agent 73 在 399 次迭代中的资源申请量为: 43.578868158422075
# agent 74 在 399 次迭代中的资源申请量为: 38.854776773325014
# agent 75 在 399 次迭代中的资源申请量为: 51.78148276379824
# agent 76 在 399 次迭代中的资源申请量为: 46.84629741832346
# agent 77 在 399 次迭代中的资源申请量为: 40.69670881628752
# agent 78 在 399 次迭代中的资源申请量为: 49.456050579545014
# agent 79 在 399 次迭代中的资源申请量为: 42.67886815842208
# agent 80 在 399 次迭代中的资源申请量为: 42.87886815842208
# agent 81 在 399 次迭代中的资源申请量为: 39.354776773325014
# agent 82 在 399 次迭代中的资源申请量为: 45.54629741832346
# agent 83 在 399 次迭代中的资源申请量为: 41.496708816287516
# agent 84 在 399 次迭代中的资源申请量为: 51.88148276379824
# agent 85 在 399 次迭代中的资源申请量为: 55.518519899475024
# agent 86 在 399 次迭代中的资源申请量为: 48.75605057954502
# agent 87 在 399 次迭代中的资源申请量为: 60.19506322443129
# agent 88 在 399 次迭代中的资源申请量为: 64.88552351756138
# agent 89 在 399 次迭代中的资源申请量为: 40.396708816287514
# agent 90 在 399 次迭代中的资源申请量为: 58.99506322443127
# agent 91 在 399 次迭代中的资源申请量为: 42.77886815842208
# agent 92 在 399 次迭代中的资源申请量为: 56.71851989947503
# agent 93 在 399 次迭代中的资源申请量为: 40.59670881628751
# agent 94 在 399 次迭代中的资源申请量为: 72.93407586931754
# agent 95 在 399 次迭代中的资源申请量为: 60.09506322443128
# agent 96 在 399 次迭代中的资源申请量为: 60.295063224431274
# agent 97 在 399 次迭代中的资源申请量为: 71.93407586931751
# agent 98 在 399 次迭代中的资源申请量为: 72.73407586931752
# agent 99 在 399 次迭代中的资源申请量为: 52.28148276379824
# agent 100 在 399 次迭代中的资源申请量为: 48.35605057954502
# 资源申请量总和为: 5000.000000000002
# ****************************************************************************
# 成本总和为: 334281.6082019721
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 449 次迭代中的结果：
# agent 1 在 449 次迭代中的资源申请量为: 48.25605057954502
# agent 2 在 449 次迭代中的资源申请量为: 60.79506322443128
# agent 3 在 449 次迭代中的资源申请量为: 43.67886815842208
# agent 4 在 449 次迭代中的资源申请量为: 64.28552351756137
# agent 5 在 449 次迭代中的资源申请量为: 65.08552351756138
# agent 6 在 449 次迭代中的资源申请量为: 71.83407586931752
# agent 7 在 449 次迭代中的资源申请量为: 39.354776773325014
# agent 8 在 449 次迭代中的资源申请量为: 32.15738725827745
# agent 9 在 449 次迭代中的资源申请量为: 42.97886815842208
# agent 10 在 449 次迭代中的资源申请量为: 55.618519899475025
# agent 11 在 449 次迭代中的资源申请量为: 45.34629741832345
# agent 12 在 449 次迭代中的资源申请量为: 49.156050579545024
# agent 13 在 449 次迭代中的资源申请量为: 65.58552351756137
# agent 14 在 449 次迭代中的资源申请量为: 55.018519899475024
# agent 15 在 449 次迭代中的资源申请量为: 43.37886815842207
# agent 16 在 449 次迭代中的资源申请量为: 43.578868158422075
# agent 17 在 449 次迭代中的资源申请量为: 44.74629741832346
# agent 18 在 449 次迭代中的资源申请量为: 46.34629741832345
# agent 19 在 449 次迭代中的资源申请量为: 41.19670881628752
# agent 20 在 449 次迭代中的资源申请量为: 55.518519899475024
# agent 21 在 449 次迭代中的资源申请量为: 32.63248797089052
# agent 22 在 449 次迭代中的资源申请量为: 38.95477677332502
# agent 23 在 449 次迭代中的资源申请量为: 47.656050579545024
# agent 24 在 449 次迭代中的资源申请量为: 40.396708816287514
# agent 25 在 449 次迭代中的资源申请量为: 45.04629741832345
# agent 26 在 449 次迭代中的资源申请量为: 39.65477677332502
# agent 27 在 449 次迭代中的资源申请量为: 65.2855235175614
# agent 28 在 449 次迭代中的资源申请量为: 51.181482763798236
# agent 29 在 449 次迭代中的资源申请量为: 40.69670881628752
# agent 30 在 449 次迭代中的资源申请量为: 39.05477677332502
# agent 31 在 449 次迭代中的资源申请量为: 60.19506322443129
# agent 32 在 449 次迭代中的资源申请量为: 55.31851989947502
# agent 33 在 449 次迭代中的资源申请量为: 41.496708816287516
# agent 34 在 449 次迭代中的资源申请量为: 52.08148276379824
# agent 35 在 449 次迭代中的资源申请量为: 32.69517219189266
# agent 36 在 449 次迭代中的资源申请量为: 42.67886815842208
# agent 37 在 449 次迭代中的资源申请量为: 52.38148276379824
# agent 38 在 449 次迭代中的资源申请量为: 40.19670881628751
# agent 39 在 449 次迭代中的资源申请量为: 43.17886815842207
# agent 40 在 449 次迭代中的资源申请量为: 49.956050579545014
# agent 41 在 449 次迭代中的资源申请量为: 65.98552351756139
# agent 42 在 449 次迭代中的资源申请量为: 42.37886815842207
# agent 43 在 449 次迭代中的资源申请量为: 51.581482763798235
# agent 44 在 449 次迭代中的资源申请量为: 52.78148276379824
# agent 45 在 449 次迭代中的资源申请量为: 48.056050579545015
# agent 46 在 449 次迭代中的资源申请量为: 55.618519899475025
# agent 47 在 449 次迭代中的资源申请量为: 45.74629741832346
# agent 48 在 449 次迭代中的资源申请量为: 43.27886815842208
# agent 49 在 449 次迭代中的资源申请量为: 42.578868158422075
# agent 50 在 449 次迭代中的资源申请量为: 40.79670881628751
# agent 51 在 449 次迭代中的资源申请量为: 48.156050579545024
# agent 52 在 449 次迭代中的资源申请量为: 55.518519899475024
# agent 53 在 449 次迭代中的资源申请量为: 38.854776773325014
# agent 54 在 449 次迭代中的资源申请量为: 56.71851989947503
# agent 55 在 449 次迭代中的资源申请量为: 70.73407586931752
# agent 56 在 449 次迭代中的资源申请量为: 40.79670881628751
# agent 57 在 449 次迭代中的资源申请量为: 60.19506322443129
# agent 58 在 449 次迭代中的资源申请量为: 42.07886815842208
# agent 59 在 449 次迭代中的资源申请量为: 47.75605057954502
# agent 60 在 449 次迭代中的资源申请量为: 55.81851989947502
# agent 61 在 449 次迭代中的资源申请量为: 65.68552351756138
# agent 62 在 449 次迭代中的资源申请量为: 45.94629741832345
# agent 63 在 449 次迭代中的资源申请量为: 38.854776773325014
# agent 64 在 449 次迭代中的资源申请量为: 44.24629741832345
# agent 65 在 449 次迭代中的资源申请量为: 42.578868158422075
# agent 66 在 449 次迭代中的资源申请量为: 65.38552351756138
# agent 67 在 449 次迭代中的资源申请量为: 43.17886815842207
# agent 68 在 449 次迭代中的资源申请量为: 44.74629741832346
# agent 69 在 449 次迭代中的资源申请量为: 45.24629741832346
# agent 70 在 449 次迭代中的资源申请量为: 59.795063224431274
# agent 71 在 449 次迭代中的资源申请量为: 71.73407586931752
# agent 72 在 449 次迭代中的资源申请量为: 59.99506322443128
# agent 73 在 449 次迭代中的资源申请量为: 43.578868158422075
# agent 74 在 449 次迭代中的资源申请量为: 38.854776773325014
# agent 75 在 449 次迭代中的资源申请量为: 51.78148276379824
# agent 76 在 449 次迭代中的资源申请量为: 46.84629741832346
# agent 77 在 449 次迭代中的资源申请量为: 40.69670881628752
# agent 78 在 449 次迭代中的资源申请量为: 49.456050579545014
# agent 79 在 449 次迭代中的资源申请量为: 42.67886815842208
# agent 80 在 449 次迭代中的资源申请量为: 42.87886815842208
# agent 81 在 449 次迭代中的资源申请量为: 39.354776773325014
# agent 82 在 449 次迭代中的资源申请量为: 45.54629741832346
# agent 83 在 449 次迭代中的资源申请量为: 41.496708816287516
# agent 84 在 449 次迭代中的资源申请量为: 51.88148276379824
# agent 85 在 449 次迭代中的资源申请量为: 55.518519899475024
# agent 86 在 449 次迭代中的资源申请量为: 48.75605057954502
# agent 87 在 449 次迭代中的资源申请量为: 60.19506322443129
# agent 88 在 449 次迭代中的资源申请量为: 64.88552351756138
# agent 89 在 449 次迭代中的资源申请量为: 40.396708816287514
# agent 90 在 449 次迭代中的资源申请量为: 58.99506322443127
# agent 91 在 449 次迭代中的资源申请量为: 42.77886815842208
# agent 92 在 449 次迭代中的资源申请量为: 56.71851989947503
# agent 93 在 449 次迭代中的资源申请量为: 40.59670881628751
# agent 94 在 449 次迭代中的资源申请量为: 72.93407586931754
# agent 95 在 449 次迭代中的资源申请量为: 60.09506322443128
# agent 96 在 449 次迭代中的资源申请量为: 60.295063224431274
# agent 97 在 449 次迭代中的资源申请量为: 71.93407586931751
# agent 98 在 449 次迭代中的资源申请量为: 72.73407586931752
# agent 99 在 449 次迭代中的资源申请量为: 52.28148276379824
# agent 100 在 449 次迭代中的资源申请量为: 48.35605057954502
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 334281.608201972
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 499 次迭代中的结果：
# agent 1 在 499 次迭代中的资源申请量为: 48.25605057954502
# agent 2 在 499 次迭代中的资源申请量为: 60.79506322443128
# agent 3 在 499 次迭代中的资源申请量为: 43.67886815842208
# agent 4 在 499 次迭代中的资源申请量为: 64.28552351756137
# agent 5 在 499 次迭代中的资源申请量为: 65.08552351756138
# agent 6 在 499 次迭代中的资源申请量为: 71.83407586931752
# agent 7 在 499 次迭代中的资源申请量为: 39.354776773325014
# agent 8 在 499 次迭代中的资源申请量为: 32.1573872582771
# agent 9 在 499 次迭代中的资源申请量为: 42.97886815842208
# agent 10 在 499 次迭代中的资源申请量为: 55.618519899475025
# agent 11 在 499 次迭代中的资源申请量为: 45.34629741832345
# agent 12 在 499 次迭代中的资源申请量为: 49.156050579545024
# agent 13 在 499 次迭代中的资源申请量为: 65.58552351756137
# agent 14 在 499 次迭代中的资源申请量为: 55.018519899475024
# agent 15 在 499 次迭代中的资源申请量为: 43.37886815842207
# agent 16 在 499 次迭代中的资源申请量为: 43.578868158422075
# agent 17 在 499 次迭代中的资源申请量为: 44.74629741832346
# agent 18 在 499 次迭代中的资源申请量为: 46.34629741832345
# agent 19 在 499 次迭代中的资源申请量为: 41.19670881628752
# agent 20 在 499 次迭代中的资源申请量为: 55.518519899475024
# agent 21 在 499 次迭代中的资源申请量为: 32.63248797089017
# agent 22 在 499 次迭代中的资源申请量为: 38.95477677332502
# agent 23 在 499 次迭代中的资源申请量为: 47.656050579545024
# agent 24 在 499 次迭代中的资源申请量为: 40.396708816287514
# agent 25 在 499 次迭代中的资源申请量为: 45.04629741832345
# ...
# agent 87 在 1969 次迭代中的资源申请量为: 59.98773721114606
# agent 88 在 1969 次迭代中的资源申请量为: 64.6593496848866
# agent 89 在 1969 次迭代中的资源申请量为: 40.25849147409737
# agent 90 在 1969 次迭代中的资源申请量为: 58.78773721114605
# agent 91 在 1969 次迭代中的资源申请量为: 42.63252038433839
# agent 92 在 1969 次迭代中的资源申请量为: 56.5271420410579
# agent 93 在 1969 次迭代中的资源申请量为: 40.45849147409737
# agent 94 在 1969 次迭代中的资源申请量为: 72.31208127078975
# agent 95 在 1969 次迭代中的资源申请量为: 59.88773721114608
# agent 96 在 1969 次迭代中的资源申请量为: 60.08773721114608
# agent 97 在 1969 次迭代中的资源申请量为: 71.68528465337529
# agent 98 在 1969 次迭代中的资源申请量为: 72.48528465337532
# agent 99 在 1969 次迭代中的资源申请量为: 52.10377475241095
# agent 100 在 1969 次迭代中的资源申请量为: 48.19018976891688
# 资源申请量总和为: 5000.000000000159
# ****************************************************************************
# 成本总和为: 334087.9140803464
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1979 次迭代中的结果：
# agent 1 在 1979 次迭代中的资源申请量为: 48.09018976891687
# agent 2 在 1979 次迭代中的资源申请量为: 60.5877372111461
# agent 3 在 1979 次迭代中的资源申请量为: 43.53252038433841
# agent 4 在 1979 次迭代中的资源申请量为: 64.05934968488663
# agent 5 在 1979 次迭代中的资源申请量为: 64.85934968488662
# agent 6 在 1979 次迭代中的资源申请量为: 71.5852846533753
# agent 7 在 1979 次迭代中的资源申请量为: 39.22383402809225
# agent 8 在 1979 次迭代中的资源申请量为: 37.49264232668764
# agent 9 在 1979 次迭代中的资源申请量为: 42.832520384338395
# agent 10 在 1979 次迭代中的资源申请量为: 55.42714204105789
# agent 11 在 1979 次迭代中的资源申请量为: 45.19080290835954
# agent 12 在 1979 次迭代中的资源申请量为: 48.99018976891685
# agent 13 在 1979 次迭代中的资源申请量为: 65.3593496848866
# agent 14 在 1979 次迭代中的资源申请量为: 54.82714204105789
# agent 15 在 1979 次迭代中的资源申请量为: 43.23252038433839
# agent 16 在 1979 次迭代中的资源申请量为: 43.432520384338396
# agent 17 在 1979 次迭代中的资源申请量为: 44.59080290835954
# agent 18 在 1979 次迭代中的资源申请量为: 46.19080290835954
# agent 19 在 1979 次迭代中的资源申请量为: 41.058491474097366
# agent 20 在 1979 次迭代中的资源申请量为: 55.3271420410579
# agent 21 在 1979 次迭代中的资源申请量为: 38.523834028092246
# agent 22 在 1979 次迭代中的资源申请量为: 38.82383402809224
# agent 23 在 1979 次迭代中的资源申请量为: 47.49018976891685
# agent 24 在 1979 次迭代中的资源申请量为: 40.25849147409737
# agent 25 在 1979 次迭代中的资源申请量为: 44.89080290835954
# agent 26 在 1979 次迭代中的资源申请量为: 39.52383402809225
# agent 27 在 1979 次迭代中的资源申请量为: 65.0593496848866
# agent 28 在 1979 次迭代中的资源申请量为: 51.003774752410905
# agent 29 在 1979 次迭代中的资源申请量为: 40.55849147409737
# agent 30 在 1979 次迭代中的资源申请量为: 38.92383402809225
# agent 31 在 1979 次迭代中的资源申请量为: 59.98773721114606
# agent 32 在 1979 次迭代中的资源申请量为: 55.127142041057894
# agent 33 在 1979 次迭代中的资源申请量为: 41.35849147409737
# agent 34 在 1979 次迭代中的资源申请量为: 51.903774752410904
# agent 35 在 1979 次迭代中的资源申请量为: 38.62383402809225
# agent 36 在 1979 次迭代中的资源申请量为: 42.53252038433839
# agent 37 在 1979 次迭代中的资源申请量为: 52.20377475241091
# agent 38 在 1979 次迭代中的资源申请量为: 40.058491474097366
# agent 39 在 1979 次迭代中的资源申请量为: 43.03252038433839
# agent 40 在 1979 次迭代中的资源申请量为: 49.79018976891684
# agent 41 在 1979 次迭代中的资源申请量为: 65.75934968488659
# agent 42 在 1979 次迭代中的资源申请量为: 42.23252038433839
# agent 43 在 1979 次迭代中的资源申请量为: 51.403774752410904
# agent 44 在 1979 次迭代中的资源申请量为: 52.60377475241091
# agent 45 在 1979 次迭代中的资源申请量为: 47.89018976891685
# agent 46 在 1979 次迭代中的资源申请量为: 55.42714204105789
# agent 47 在 1979 次迭代中的资源申请量为: 45.59080290835954
# agent 48 在 1979 次迭代中的资源申请量为: 43.13252038433839
# agent 49 在 1979 次迭代中的资源申请量为: 42.43252038433839
# agent 50 在 1979 次迭代中的资源申请量为: 40.65849147409737
# agent 51 在 1979 次迭代中的资源申请量为: 47.99018976891685
# agent 52 在 1979 次迭代中的资源申请量为: 55.3271420410579
# agent 53 在 1979 次迭代中的资源申请量为: 38.72383402809225
# agent 54 在 1979 次迭代中的资源申请量为: 56.5271420410579
# agent 55 在 1979 次迭代中的资源申请量为: 70.48528465337529
# agent 56 在 1979 次迭代中的资源申请量为: 40.65849147409737
# agent 57 在 1979 次迭代中的资源申请量为: 59.98773721114606
# agent 58 在 1979 次迭代中的资源申请量为: 41.932520384338396
# agent 59 在 1979 次迭代中的资源申请量为: 47.590189768916844
# agent 60 在 1979 次迭代中的资源申请量为: 55.6271420410579
# agent 61 在 1979 次迭代中的资源申请量为: 65.4593496848866
# agent 62 在 1979 次迭代中的资源申请量为: 45.790802908359545
# agent 63 在 1979 次迭代中的资源申请量为: 38.72383402809225
# agent 64 在 1979 次迭代中的资源申请量为: 44.090802908359535
# agent 65 在 1979 次迭代中的资源申请量为: 42.43252038433839
# agent 66 在 1979 次迭代中的资源申请量为: 65.1593496848866
# agent 67 在 1979 次迭代中的资源申请量为: 43.03252038433839
# agent 68 在 1979 次迭代中的资源申请量为: 44.59080290835954
# agent 69 在 1979 次迭代中的资源申请量为: 45.09080290835954
# agent 70 在 1979 次迭代中的资源申请量为: 59.587737211146056
# agent 71 在 1979 次迭代中的资源申请量为: 71.48528465337529
# agent 72 在 1979 次迭代中的资源申请量为: 59.78773721114605
# agent 73 在 1979 次迭代中的资源申请量为: 43.432520384338396
# agent 74 在 1979 次迭代中的资源申请量为: 38.72383402809225
# agent 75 在 1979 次迭代中的资源申请量为: 51.60377475241091
# agent 76 在 1979 次迭代中的资源申请量为: 46.690802908359544
# agent 77 在 1979 次迭代中的资源申请量为: 40.55849147409737
# agent 78 在 1979 次迭代中的资源申请量为: 49.29018976891684
# agent 79 在 1979 次迭代中的资源申请量为: 42.53252038433839
# agent 80 在 1979 次迭代中的资源申请量为: 42.73252038433839
# agent 81 在 1979 次迭代中的资源申请量为: 39.22383402809225
# agent 82 在 1979 次迭代中的资源申请量为: 45.39080290835955
# agent 83 在 1979 次迭代中的资源申请量为: 41.35849147409737
# agent 84 在 1979 次迭代中的资源申请量为: 51.70377475241091
# agent 85 在 1979 次迭代中的资源申请量为: 55.3271420410579
# agent 86 在 1979 次迭代中的资源申请量为: 48.590189768916844
# agent 87 在 1979 次迭代中的资源申请量为: 59.98773721114606
# agent 88 在 1979 次迭代中的资源申请量为: 64.6593496848866
# agent 89 在 1979 次迭代中的资源申请量为: 40.25849147409737
# agent 90 在 1979 次迭代中的资源申请量为: 58.78773721114605
# agent 91 在 1979 次迭代中的资源申请量为: 42.63252038433839
# agent 92 在 1979 次迭代中的资源申请量为: 56.5271420410579
# agent 93 在 1979 次迭代中的资源申请量为: 40.45849147409737
# agent 94 在 1979 次迭代中的资源申请量为: 72.3120812707896
# agent 95 在 1979 次迭代中的资源申请量为: 59.88773721114608
# agent 96 在 1979 次迭代中的资源申请量为: 60.08773721114608
# agent 97 在 1979 次迭代中的资源申请量为: 71.68528465337529
# agent 98 在 1979 次迭代中的资源申请量为: 72.48528465337532
# agent 99 在 1979 次迭代中的资源申请量为: 52.10377475241095
# agent 100 在 1979 次迭代中的资源申请量为: 48.19018976891688
# 资源申请量总和为: 5000.000000000159
# ****************************************************************************
# 成本总和为: 334087.9140803464
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1989 次迭代中的结果：
# agent 1 在 1989 次迭代中的资源申请量为: 48.09018976891687
# agent 2 在 1989 次迭代中的资源申请量为: 60.5877372111461
# agent 3 在 1989 次迭代中的资源申请量为: 43.53252038433841
# agent 4 在 1989 次迭代中的资源申请量为: 64.05934968488663
# agent 5 在 1989 次迭代中的资源申请量为: 64.85934968488662
# agent 6 在 1989 次迭代中的资源申请量为: 71.5852846533753
# agent 7 在 1989 次迭代中的资源申请量为: 39.22383402809225
# agent 8 在 1989 次迭代中的资源申请量为: 37.49264232668764
# agent 9 在 1989 次迭代中的资源申请量为: 42.832520384338395
# agent 10 在 1989 次迭代中的资源申请量为: 55.42714204105789
# agent 11 在 1989 次迭代中的资源申请量为: 45.19080290835954
# agent 12 在 1989 次迭代中的资源申请量为: 48.99018976891685
# agent 13 在 1989 次迭代中的资源申请量为: 65.3593496848866
# agent 14 在 1989 次迭代中的资源申请量为: 54.82714204105789
# agent 15 在 1989 次迭代中的资源申请量为: 43.23252038433839
# agent 16 在 1989 次迭代中的资源申请量为: 43.432520384338396
# agent 17 在 1989 次迭代中的资源申请量为: 44.59080290835954
# agent 18 在 1989 次迭代中的资源申请量为: 46.19080290835954
# agent 19 在 1989 次迭代中的资源申请量为: 41.058491474097366
# agent 20 在 1989 次迭代中的资源申请量为: 55.3271420410579
# agent 21 在 1989 次迭代中的资源申请量为: 38.523834028092246
# agent 22 在 1989 次迭代中的资源申请量为: 38.82383402809224
# agent 23 在 1989 次迭代中的资源申请量为: 47.49018976891685
# agent 24 在 1989 次迭代中的资源申请量为: 40.25849147409737
# agent 25 在 1989 次迭代中的资源申请量为: 44.89080290835954
# agent 26 在 1989 次迭代中的资源申请量为: 39.52383402809225
# agent 27 在 1989 次迭代中的资源申请量为: 65.0593496848866
# agent 28 在 1989 次迭代中的资源申请量为: 51.003774752410905
# agent 29 在 1989 次迭代中的资源申请量为: 40.55849147409737
# agent 30 在 1989 次迭代中的资源申请量为: 38.92383402809225
# agent 31 在 1989 次迭代中的资源申请量为: 59.98773721114606
# agent 32 在 1989 次迭代中的资源申请量为: 55.127142041057894
# agent 33 在 1989 次迭代中的资源申请量为: 41.35849147409737
# agent 34 在 1989 次迭代中的资源申请量为: 51.903774752410904
# agent 35 在 1989 次迭代中的资源申请量为: 38.62383402809225
# agent 36 在 1989 次迭代中的资源申请量为: 42.53252038433839
# agent 37 在 1989 次迭代中的资源申请量为: 52.20377475241091
# agent 38 在 1989 次迭代中的资源申请量为: 40.058491474097366
# agent 39 在 1989 次迭代中的资源申请量为: 43.03252038433839
# agent 40 在 1989 次迭代中的资源申请量为: 49.79018976891684
# agent 41 在 1989 次迭代中的资源申请量为: 65.75934968488659
# agent 42 在 1989 次迭代中的资源申请量为: 42.23252038433839
# agent 43 在 1989 次迭代中的资源申请量为: 51.403774752410904
# agent 44 在 1989 次迭代中的资源申请量为: 52.60377475241091
# agent 45 在 1989 次迭代中的资源申请量为: 47.89018976891685
# agent 46 在 1989 次迭代中的资源申请量为: 55.42714204105789
# agent 47 在 1989 次迭代中的资源申请量为: 45.59080290835954
# agent 48 在 1989 次迭代中的资源申请量为: 43.13252038433839
# agent 49 在 1989 次迭代中的资源申请量为: 42.43252038433839
# agent 50 在 1989 次迭代中的资源申请量为: 40.65849147409737
# agent 51 在 1989 次迭代中的资源申请量为: 47.99018976891685
# agent 52 在 1989 次迭代中的资源申请量为: 55.3271420410579
# agent 53 在 1989 次迭代中的资源申请量为: 38.72383402809225
# agent 54 在 1989 次迭代中的资源申请量为: 56.5271420410579
# agent 55 在 1989 次迭代中的资源申请量为: 70.48528465337529
# agent 56 在 1989 次迭代中的资源申请量为: 40.65849147409737
# agent 57 在 1989 次迭代中的资源申请量为: 59.98773721114606
# agent 58 在 1989 次迭代中的资源申请量为: 41.932520384338396
# agent 59 在 1989 次迭代中的资源申请量为: 47.590189768916844
# agent 60 在 1989 次迭代中的资源申请量为: 55.6271420410579
# agent 61 在 1989 次迭代中的资源申请量为: 65.4593496848866
# agent 62 在 1989 次迭代中的资源申请量为: 45.790802908359545
# agent 63 在 1989 次迭代中的资源申请量为: 38.72383402809225
# agent 64 在 1989 次迭代中的资源申请量为: 44.090802908359535
# agent 65 在 1989 次迭代中的资源申请量为: 42.43252038433839
# agent 66 在 1989 次迭代中的资源申请量为: 65.1593496848866
# agent 67 在 1989 次迭代中的资源申请量为: 43.03252038433839
# agent 68 在 1989 次迭代中的资源申请量为: 44.59080290835954
# agent 69 在 1989 次迭代中的资源申请量为: 45.09080290835954
# agent 70 在 1989 次迭代中的资源申请量为: 59.587737211146056
# agent 71 在 1989 次迭代中的资源申请量为: 71.48528465337529
# agent 72 在 1989 次迭代中的资源申请量为: 59.78773721114605
# agent 73 在 1989 次迭代中的资源申请量为: 43.432520384338396
# agent 74 在 1989 次迭代中的资源申请量为: 38.72383402809225
# agent 75 在 1989 次迭代中的资源申请量为: 51.60377475241091
# agent 76 在 1989 次迭代中的资源申请量为: 46.690802908359544
# agent 77 在 1989 次迭代中的资源申请量为: 40.55849147409737
# agent 78 在 1989 次迭代中的资源申请量为: 49.29018976891684
# agent 79 在 1989 次迭代中的资源申请量为: 42.53252038433839
# agent 80 在 1989 次迭代中的资源申请量为: 42.73252038433839
# agent 81 在 1989 次迭代中的资源申请量为: 39.22383402809225
# agent 82 在 1989 次迭代中的资源申请量为: 45.39080290835955
# agent 83 在 1989 次迭代中的资源申请量为: 41.35849147409737
# agent 84 在 1989 次迭代中的资源申请量为: 51.70377475241091
# agent 85 在 1989 次迭代中的资源申请量为: 55.3271420410579
# agent 86 在 1989 次迭代中的资源申请量为: 48.590189768916844
# agent 87 在 1989 次迭代中的资源申请量为: 59.98773721114606
# agent 88 在 1989 次迭代中的资源申请量为: 64.6593496848866
# agent 89 在 1989 次迭代中的资源申请量为: 40.25849147409737
# agent 90 在 1989 次迭代中的资源申请量为: 58.78773721114605
# agent 91 在 1989 次迭代中的资源申请量为: 42.63252038433839
# agent 92 在 1989 次迭代中的资源申请量为: 56.5271420410579
# agent 93 在 1989 次迭代中的资源申请量为: 40.45849147409737
# agent 94 在 1989 次迭代中的资源申请量为: 72.31208127078946
# agent 95 在 1989 次迭代中的资源申请量为: 59.88773721114608
# agent 96 在 1989 次迭代中的资源申请量为: 60.08773721114608
# agent 97 在 1989 次迭代中的资源申请量为: 71.68528465337529
# agent 98 在 1989 次迭代中的资源申请量为: 72.48528465337532
# agent 99 在 1989 次迭代中的资源申请量为: 52.10377475241095
# agent 100 在 1989 次迭代中的资源申请量为: 48.19018976891688
# 资源申请量总和为: 5000.000000000159
# ****************************************************************************
# 成本总和为: 334087.91408034635
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1999 次迭代中的结果：
# agent 1 在 1999 次迭代中的资源申请量为: 48.09018976891687
# agent 2 在 1999 次迭代中的资源申请量为: 60.5877372111461
# agent 3 在 1999 次迭代中的资源申请量为: 43.53252038433841
# agent 4 在 1999 次迭代中的资源申请量为: 64.05934968488663
# agent 5 在 1999 次迭代中的资源申请量为: 64.85934968488662
# agent 6 在 1999 次迭代中的资源申请量为: 71.5852846533753
# agent 7 在 1999 次迭代中的资源申请量为: 39.22383402809225
# agent 8 在 1999 次迭代中的资源申请量为: 37.49264232668764
# agent 9 在 1999 次迭代中的资源申请量为: 42.832520384338395
# agent 10 在 1999 次迭代中的资源申请量为: 55.42714204105789
# agent 11 在 1999 次迭代中的资源申请量为: 45.19080290835954
# agent 12 在 1999 次迭代中的资源申请量为: 48.99018976891685
# agent 13 在 1999 次迭代中的资源申请量为: 65.3593496848866
# agent 14 在 1999 次迭代中的资源申请量为: 54.82714204105789
# agent 15 在 1999 次迭代中的资源申请量为: 43.23252038433839
# agent 16 在 1999 次迭代中的资源申请量为: 43.432520384338396
# agent 17 在 1999 次迭代中的资源申请量为: 44.59080290835954
# agent 18 在 1999 次迭代中的资源申请量为: 46.19080290835954
# agent 19 在 1999 次迭代中的资源申请量为: 41.058491474097366
# agent 20 在 1999 次迭代中的资源申请量为: 55.3271420410579
# agent 21 在 1999 次迭代中的资源申请量为: 38.523834028092246
# agent 22 在 1999 次迭代中的资源申请量为: 38.82383402809224
# agent 23 在 1999 次迭代中的资源申请量为: 47.49018976891685
# agent 24 在 1999 次迭代中的资源申请量为: 40.25849147409737
# agent 25 在 1999 次迭代中的资源申请量为: 44.89080290835954
# agent 26 在 1999 次迭代中的资源申请量为: 39.52383402809225
# agent 27 在 1999 次迭代中的资源申请量为: 65.0593496848866
# agent 28 在 1999 次迭代中的资源申请量为: 51.003774752410905
# agent 29 在 1999 次迭代中的资源申请量为: 40.55849147409737
# agent 30 在 1999 次迭代中的资源申请量为: 38.92383402809225
# agent 31 在 1999 次迭代中的资源申请量为: 59.98773721114606
# agent 32 在 1999 次迭代中的资源申请量为: 55.127142041057894
# agent 33 在 1999 次迭代中的资源申请量为: 41.35849147409737
# agent 34 在 1999 次迭代中的资源申请量为: 51.903774752410904
# agent 35 在 1999 次迭代中的资源申请量为: 38.62383402809225
# agent 36 在 1999 次迭代中的资源申请量为: 42.53252038433839
# agent 37 在 1999 次迭代中的资源申请量为: 52.20377475241091
# agent 38 在 1999 次迭代中的资源申请量为: 40.058491474097366
# agent 39 在 1999 次迭代中的资源申请量为: 43.03252038433839
# agent 40 在 1999 次迭代中的资源申请量为: 49.79018976891684
# agent 41 在 1999 次迭代中的资源申请量为: 65.75934968488659
# agent 42 在 1999 次迭代中的资源申请量为: 42.23252038433839
# agent 43 在 1999 次迭代中的资源申请量为: 51.403774752410904
# agent 44 在 1999 次迭代中的资源申请量为: 52.60377475241091
# agent 45 在 1999 次迭代中的资源申请量为: 47.89018976891685
# agent 46 在 1999 次迭代中的资源申请量为: 55.42714204105789
# agent 47 在 1999 次迭代中的资源申请量为: 45.59080290835954
# agent 48 在 1999 次迭代中的资源申请量为: 43.13252038433839
# agent 49 在 1999 次迭代中的资源申请量为: 42.43252038433839
# agent 50 在 1999 次迭代中的资源申请量为: 40.65849147409737
# agent 51 在 1999 次迭代中的资源申请量为: 47.99018976891685
# agent 52 在 1999 次迭代中的资源申请量为: 55.3271420410579
# agent 53 在 1999 次迭代中的资源申请量为: 38.72383402809225
# agent 54 在 1999 次迭代中的资源申请量为: 56.5271420410579
# agent 55 在 1999 次迭代中的资源申请量为: 70.48528465337529
# agent 56 在 1999 次迭代中的资源申请量为: 40.65849147409737
# agent 57 在 1999 次迭代中的资源申请量为: 59.98773721114606
# agent 58 在 1999 次迭代中的资源申请量为: 41.932520384338396
# agent 59 在 1999 次迭代中的资源申请量为: 47.590189768916844
# agent 60 在 1999 次迭代中的资源申请量为: 55.6271420410579
# agent 61 在 1999 次迭代中的资源申请量为: 65.4593496848866
# agent 62 在 1999 次迭代中的资源申请量为: 45.790802908359545
# agent 63 在 1999 次迭代中的资源申请量为: 38.72383402809225
# agent 64 在 1999 次迭代中的资源申请量为: 44.090802908359535
# agent 65 在 1999 次迭代中的资源申请量为: 42.43252038433839
# agent 66 在 1999 次迭代中的资源申请量为: 65.1593496848866
# agent 67 在 1999 次迭代中的资源申请量为: 43.03252038433839
# agent 68 在 1999 次迭代中的资源申请量为: 44.59080290835954
# agent 69 在 1999 次迭代中的资源申请量为: 45.09080290835954
# agent 70 在 1999 次迭代中的资源申请量为: 59.587737211146056
# agent 71 在 1999 次迭代中的资源申请量为: 71.48528465337529
# agent 72 在 1999 次迭代中的资源申请量为: 59.78773721114605
# agent 73 在 1999 次迭代中的资源申请量为: 43.432520384338396
# agent 74 在 1999 次迭代中的资源申请量为: 38.72383402809225
# agent 75 在 1999 次迭代中的资源申请量为: 51.60377475241091
# agent 76 在 1999 次迭代中的资源申请量为: 46.690802908359544
# agent 77 在 1999 次迭代中的资源申请量为: 40.55849147409737
# agent 78 在 1999 次迭代中的资源申请量为: 49.29018976891684
# agent 79 在 1999 次迭代中的资源申请量为: 42.53252038433839
# agent 80 在 1999 次迭代中的资源申请量为: 42.73252038433839
# agent 81 在 1999 次迭代中的资源申请量为: 39.22383402809225
# agent 82 在 1999 次迭代中的资源申请量为: 45.39080290835955
# agent 83 在 1999 次迭代中的资源申请量为: 41.35849147409737
# agent 84 在 1999 次迭代中的资源申请量为: 51.70377475241091
# agent 85 在 1999 次迭代中的资源申请量为: 55.3271420410579
# agent 86 在 1999 次迭代中的资源申请量为: 48.590189768916844
# agent 87 在 1999 次迭代中的资源申请量为: 59.98773721114606
# agent 88 在 1999 次迭代中的资源申请量为: 64.6593496848866
# agent 89 在 1999 次迭代中的资源申请量为: 40.25849147409737
# agent 90 在 1999 次迭代中的资源申请量为: 58.78773721114605
# agent 91 在 1999 次迭代中的资源申请量为: 42.63252038433839
# agent 92 在 1999 次迭代中的资源申请量为: 56.5271420410579
# agent 93 在 1999 次迭代中的资源申请量为: 40.45849147409737
# agent 94 在 1999 次迭代中的资源申请量为: 72.31208127078932
# agent 95 在 1999 次迭代中的资源申请量为: 59.88773721114608
# agent 96 在 1999 次迭代中的资源申请量为: 60.08773721114608
# agent 97 在 1999 次迭代中的资源申请量为: 71.68528465337529
# agent 98 在 1999 次迭代中的资源申请量为: 72.48528465337532
# agent 99 在 1999 次迭代中的资源申请量为: 52.10377475241095
# agent 100 在 1999 次迭代中的资源申请量为: 48.19018976891688
# 资源申请量总和为: 5000.000000000159
# ****************************************************************************
# 成本总和为: 334087.91408034635
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 2025-01-21 17:26:22.343

# %%
np.savetxt('../data/03-robust_agent_resource_quantity_small_value_Gaussian_bias(50,10).txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/03-robust_sum_cost_small_value_Gaussian_bias(50,10).txt',sum_cost,fmt='%0.8f')#用户成本总和 
np.savetxt('../data/03-robust_sum_resource_small_value_Gaussian_bias(50,10).txt',sum_resource,fmt='%0.8f')#用户资源总和 
np.savetxt('../data/03-robust_agent_gradient_small_value_Gaussian_bias(50,10).txt',agent_gradient,fmt='%0.8f')#用户迭代梯度
