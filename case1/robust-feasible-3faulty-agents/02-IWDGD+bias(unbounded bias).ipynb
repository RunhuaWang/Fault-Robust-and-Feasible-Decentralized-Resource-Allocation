# %% [raw]
# 基于初始化的权重梯度下降无中心资源分配算法+部分用户的梯度计算有误差（设备损坏导致的计算误差）

# %% [raw]
# 无界的噪声 设计噪声递增

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(100,1000), dtype=np.float64) 
sum_resource=np.zeros(shape=(1,1000), dtype=np.float64)
sum_cost=np.zeros(shape=(1,1000), dtype=np.float64)
iteration_update = 0.01
A=np.loadtxt("100_Network_Topology_Double_Random_Adjacency_Matrix_Degree_15.txt") #网络拓扑的邻接矩阵 对角元素要为0
D=np.zeros(shape=(100,100))# 网络的度矩阵
L=np.zeros(shape=(100,100))# 网络的拉普拉斯矩阵 L=D-A
W=np.zeros(shape=(100,100)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
iteration=[]
a=np.loadtxt("100_uniform_distribution_(1,2)_point1.txt")
b=np.loadtxt("100_normal_distribution_(2,0.6)_point1.txt")
agent_gradient=np.zeros(shape=(100,1000), dtype=np.float64) 
bias=0

# %%
#根据邻接矩阵生成网络对应的度矩阵
for i in range(0,100):
    d=0
    for j in range(0,100):
        if A[i][j]==1:
            d=d+1
    D[i][i]=d

#根据邻接矩阵和度矩阵计算拉普拉斯矩阵
L=D-A

#选择用拉普拉斯矩阵作为聚合矩阵
W=L
    
#资源量的初始化 需要给定可行的初始化 即满足平均资源约束
for i in range (0,100):
    agent_resource_quantity[i][0]=50
    
#资源量总和 初始化
sum=0
for i in range (0,100):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

iteration.append(0)

#初始梯度计算 选择三个用户作为带有噪声
for i in range (0,100):
    if i==7 or i==20 or i==34:
        agent_gradient[i][0]=2*a[i]*agent_resource_quantity[i][0]-2*a[i]*b[i]+bias
    else:
        agent_gradient[i][0]=2*a[i]*agent_resource_quantity[i][0]-2*a[i]*b[i]

#诚实用户成本总和初始化
sum=0
for i in range(0,100):
    sum=sum+a[i]*(agent_resource_quantity[i][0]-b[i])*(agent_resource_quantity[i][0]-b[i])
sum_cost[0][0]=sum

# %%
#基于初始化的权重梯度下降无中心资源分配算法
def IWDGD_deterministic_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias):
    
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************IWDGD算法+计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,100):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):#迭代次数
        iteration.append(k)
 
        #所有用户资源申请量基于可行初始化权重梯度下降的迭代  假设部分用户因为设备损坏 导致梯度的计算有误差     
        for i in range (0,100):
            weight_gradient_sum = np.float64(0)
            for j in range (0,100):        
                weight_gradient_sum=weight_gradient_sum+W[i][j]*agent_gradient[j][k-1]
            #weight_gradient_sum = np.round(weight_gradient_sum, decimals=3)
            agent_resource_quantity[i][k]=agent_resource_quantity[i][k-1]-iteration_update*weight_gradient_sum
                #agent_resource_quantity[i][k] = np.round(agent_resource_quantity[i][k], decimals=3)
        
        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,100):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,100):
            sum2=sum2+a[i]*(agent_resource_quantity[i][k]-b[i])*(agent_resource_quantity[i][k]-b[i])
        sum_cost[0][k]=sum2

        #设计递增的噪声
        bias=k
        #计算当前迭代的用户梯度
        for i in range (0,100): 
            if i==7 or i==20 or i==34:
                agent_gradient[i][k]=2*a[i]*agent_resource_quantity[i][k]-2*a[i]*b[i]+bias
            else:
                agent_gradient[i][k]=2*a[i]*agent_resource_quantity[i][k]-2*a[i]*b[i]
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%50==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,100):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=1/(pow(k+1,0.5)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
IWDGD_deterministic_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias)
# Out:
# ****************************IWDGD算法+计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 50.0
# agent 2 的初始资源申请量为: 50.0
# agent 3 的初始资源申请量为: 50.0
# agent 4 的初始资源申请量为: 50.0
# agent 5 的初始资源申请量为: 50.0
# agent 6 的初始资源申请量为: 50.0
# agent 7 的初始资源申请量为: 50.0
# agent 8 的初始资源申请量为: 50.0
# agent 9 的初始资源申请量为: 50.0
# agent 10 的初始资源申请量为: 50.0
# agent 11 的初始资源申请量为: 50.0
# agent 12 的初始资源申请量为: 50.0
# agent 13 的初始资源申请量为: 50.0
# agent 14 的初始资源申请量为: 50.0
# agent 15 的初始资源申请量为: 50.0
# agent 16 的初始资源申请量为: 50.0
# agent 17 的初始资源申请量为: 50.0
# agent 18 的初始资源申请量为: 50.0
# agent 19 的初始资源申请量为: 50.0
# agent 20 的初始资源申请量为: 50.0
# agent 21 的初始资源申请量为: 50.0
# agent 22 的初始资源申请量为: 50.0
# agent 23 的初始资源申请量为: 50.0
# agent 24 的初始资源申请量为: 50.0
# agent 25 的初始资源申请量为: 50.0
# agent 26 的初始资源申请量为: 50.0
# agent 27 的初始资源申请量为: 50.0
# agent 28 的初始资源申请量为: 50.0
# agent 29 的初始资源申请量为: 50.0
# agent 30 的初始资源申请量为: 50.0
# agent 31 的初始资源申请量为: 50.0
# agent 32 的初始资源申请量为: 50.0
# agent 33 的初始资源申请量为: 50.0
# agent 34 的初始资源申请量为: 50.0
# agent 35 的初始资源申请量为: 50.0
# agent 36 的初始资源申请量为: 50.0
# agent 37 的初始资源申请量为: 50.0
# agent 38 的初始资源申请量为: 50.0
# agent 39 的初始资源申请量为: 50.0
# agent 40 的初始资源申请量为: 50.0
# agent 41 的初始资源申请量为: 50.0
# agent 42 的初始资源申请量为: 50.0
# agent 43 的初始资源申请量为: 50.0
# agent 44 的初始资源申请量为: 50.0
# agent 45 的初始资源申请量为: 50.0
# agent 46 的初始资源申请量为: 50.0
# agent 47 的初始资源申请量为: 50.0
# agent 48 的初始资源申请量为: 50.0
# agent 49 的初始资源申请量为: 50.0
# agent 50 的初始资源申请量为: 50.0
# agent 51 的初始资源申请量为: 50.0
# agent 52 的初始资源申请量为: 50.0
# agent 53 的初始资源申请量为: 50.0
# agent 54 的初始资源申请量为: 50.0
# agent 55 的初始资源申请量为: 50.0
# agent 56 的初始资源申请量为: 50.0
# agent 57 的初始资源申请量为: 50.0
# agent 58 的初始资源申请量为: 50.0
# agent 59 的初始资源申请量为: 50.0
# agent 60 的初始资源申请量为: 50.0
# agent 61 的初始资源申请量为: 50.0
# agent 62 的初始资源申请量为: 50.0
# agent 63 的初始资源申请量为: 50.0
# agent 64 的初始资源申请量为: 50.0
# agent 65 的初始资源申请量为: 50.0
# agent 66 的初始资源申请量为: 50.0
# agent 67 的初始资源申请量为: 50.0
# agent 68 的初始资源申请量为: 50.0
# agent 69 的初始资源申请量为: 50.0
# agent 70 的初始资源申请量为: 50.0
# agent 71 的初始资源申请量为: 50.0
# agent 72 的初始资源申请量为: 50.0
# agent 73 的初始资源申请量为: 50.0
# agent 74 的初始资源申请量为: 50.0
# agent 75 的初始资源申请量为: 50.0
# agent 76 的初始资源申请量为: 50.0
# agent 77 的初始资源申请量为: 50.0
# agent 78 的初始资源申请量为: 50.0
# agent 79 的初始资源申请量为: 50.0
# agent 80 的初始资源申请量为: 50.0
# agent 81 的初始资源申请量为: 50.0
# agent 82 的初始资源申请量为: 50.0
# agent 83 的初始资源申请量为: 50.0
# agent 84 的初始资源申请量为: 50.0
# agent 85 的初始资源申请量为: 50.0
# agent 86 的初始资源申请量为: 50.0
# agent 87 的初始资源申请量为: 50.0
# agent 88 的初始资源申请量为: 50.0
# agent 89 的初始资源申请量为: 50.0
# agent 90 的初始资源申请量为: 50.0
# agent 91 的初始资源申请量为: 50.0
# agent 92 的初始资源申请量为: 50.0
# agent 93 的初始资源申请量为: 50.0
# agent 94 的初始资源申请量为: 50.0
# agent 95 的初始资源申请量为: 50.0
# agent 96 的初始资源申请量为: 50.0
# agent 97 的初始资源申请量为: 50.0
# agent 98 的初始资源申请量为: 50.0
# agent 99 的初始资源申请量为: 50.0
# agent 100 的初始资源申请量为: 50.0
# *************************
# 初始资源申请量总和为: 5000.0
# *************************
# 初始成本总和为: 346654.5889999999
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 49 次迭代中的结果：
# agent 1 在 49 次迭代中的资源申请量为: 48.42484180427564
# agent 2 在 49 次迭代中的资源申请量为: 61.04572674333488
# agent 3 在 49 次迭代中的资源申请量为: 43.833963138837795
# agent 4 在 49 次迭代中的资源申请量为: 64.5064837517972
# agent 5 在 49 次迭代中的资源申请量为: 65.2979277811578
# agent 6 在 49 次迭代中的资源申请量为: 72.07178749278553
# agent 7 在 49 次迭代中的资源申请量为: 39.521449396004286
# agent 8 在 49 次迭代中的资源申请量为: 25.93957419451396
# agent 9 在 49 次迭代中的资源申请量为: 43.16643939535305
# agent 10 在 49 次迭代中的资源申请量为: 55.8575964095574
# agent 11 在 49 次迭代中的资源申请量为: 45.54250790328713
# agent 12 在 49 次迭代中的资源申请量为: 49.40775203548742
# agent 13 在 49 次迭代中的资源申请量为: 65.82675217356946
# agent 14 在 49 次迭代中的资源申请量为: 55.24591508019799
# agent 15 在 49 次迭代中的资源申请量为: 43.53713835512038
# agent 16 在 49 次迭代中的资源申请量为: 43.71882425184559
# agent 17 在 49 次迭代中的资源申请量为: 44.914779879693945
# agent 18 在 49 次迭代中的资源申请量为: 46.53406146052528
# agent 19 在 49 次迭代中的资源申请量为: 41.378309971760835
# agent 20 在 49 次迭代中的资源申请量为: 55.817080471488104
# agent 21 在 49 次迭代中的资源申请量为: 26.378863561195296
# agent 22 在 49 次迭代中的资源申请量为: 39.127381171300904
# agent 23 在 49 次迭代中的资源申请量为: 47.82928021093402
# agent 24 在 49 次迭代中的资源申请量为: 40.53111789950392
# agent 25 在 49 次迭代中的资源申请量为: 45.20501166414241
# agent 26 在 49 次迭代中的资源申请量为: 39.82666137752709
# agent 27 在 49 次迭代中的资源申请量为: 65.55195447809787
# agent 28 在 49 次迭代中的资源申请量为: 51.36292170010451
# agent 29 在 49 次迭代中的资源申请量为: 40.84176093892016
# agent 30 在 49 次迭代中的资源申请量为: 39.26385670693705
# agent 31 在 49 次迭代中的资源申请量为: 60.45153286289046
# agent 32 在 49 次迭代中的资源申请量为: 55.499401977479366
# agent 33 在 49 次迭代中的资源申请量为: 41.633949989761085
# agent 34 在 49 次迭代中的资源申请量为: 52.30232475787004
# agent 35 在 49 次迭代中的资源申请量为: 26.48629925535671
# agent 36 在 49 次迭代中的资源申请量为: 42.86489844893273
# agent 37 在 49 次迭代中的资源申请量为: 52.55879607155187
# agent 38 在 49 次迭代中的资源申请量为: 40.33667761793023
# agent 39 在 49 次迭代中的资源申请量为: 43.32560674042827
# agent 40 在 49 次迭代中的资源申请量为: 50.17132986803645
# agent 41 在 49 次迭代中的资源申请量为: 66.27286886797201
# agent 42 在 49 次迭代中的资源申请量为: 42.533114875730625
# agent 43 在 49 次迭代中的资源申请量为: 51.74101779481623
# agent 44 在 49 次迭代中的资源申请量为: 52.952643138647694
# agent 45 在 49 次迭代中的资源申请量为: 48.218120517239825
# agent 46 在 49 次迭代中的资源申请量为: 55.918789777886744
# agent 47 在 49 次迭代中的资源申请量为: 45.94275762498266
# agent 48 在 49 次迭代中的资源申请量为: 43.46097545903934
# agent 49 在 49 次迭代中的资源申请量为: 42.71585296527082
# agent 50 在 49 次迭代中的资源申请量为: 40.934496883617605
# agent 51 在 49 次迭代中的资源申请量为: 48.367047126383156
# agent 52 在 49 次迭代中的资源申请量为: 55.70657845548652
# agent 53 在 49 次迭代中的资源申请量为: 38.99587615693669
# agent 54 在 49 次迭代中的资源申请量为: 56.95334633798455
# agent 55 在 49 次迭代中的资源申请量为: 71.02479421685932
# agent 56 在 49 次迭代中的资源申请量为: 40.93592129026498
# agent 57 在 49 次迭代中的资源申请量为: 60.50716566008684
# agent 58 在 49 次迭代中的资源申请量为: 42.2670774772883
# agent 59 在 49 次迭代中的资源申请量为: 47.96191676372635
# agent 60 在 49 次迭代中的资源申请量为: 56.049394750350636
# agent 61 在 49 次迭代中的资源申请量为: 65.90405748531744
# agent 62 在 49 次迭代中的资源申请量为: 46.099093872626725
# agent 63 在 49 次迭代中的资源申请量为: 39.02164245391537
# agent 64 在 49 次迭代中的资源申请量为: 44.40767922056039
# agent 65 在 49 次迭代中的资源申请量为: 42.71771754179409
# agent 66 在 49 次迭代中的资源申请量为: 65.60048922607434
# agent 67 在 49 次迭代中的资源申请量为: 43.322532113380454
# agent 68 在 49 次迭代中的资源申请量为: 44.90162832328337
# agent 69 在 49 次迭代中的资源申请量为: 45.39632515791535
# agent 70 在 49 次迭代中的资源申请量为: 60.007403650161265
# agent 71 在 49 次迭代中的资源申请量为: 71.97022384467948
# agent 72 在 49 次迭代中的资源申请量为: 60.25051161906117
# agent 73 在 49 次迭代中的资源申请量为: 43.726664113351156
# agent 74 在 49 次迭代中的资源申请量为: 38.98270643788757
# agent 75 在 49 次迭代中的资源申请量为: 51.95105195252531
# agent 76 在 49 次迭代中的资源申请量为: 46.99986630101637
# agent 77 在 49 次迭代中的资源申请量为: 40.8337747290281
# agent 78 在 49 次迭代中的资源申请量为: 49.62439110257881
# agent 79 在 49 次迭代中的资源申请量为: 42.87357063157819
# agent 80 在 49 次迭代中的资源申请量为: 43.0195248752654
# agent 81 在 49 次迭代中的资源申请量为: 39.492970306581356
# agent 82 在 49 次迭代中的资源申请量为: 45.75079394564309
# agent 83 在 49 次迭代中的资源申请量为: 41.648427015328686
# agent 84 在 49 次迭代中的资源申请量为: 52.098857736561314
# agent 85 在 49 次迭代中的资源申请量为: 55.700463523872614
# agent 86 在 49 次迭代中的资源申请量为: 48.95852437670346
# agent 87 在 49 次迭代中的资源申请量为: 60.45105237063211
# agent 88 在 49 次迭代中的资源申请量为: 65.09997014881357
# agent 89 在 49 次迭代中的资源申请量为: 40.546204454995895
# agent 90 在 49 次迭代中的资源申请量为: 59.18930767532024
# agent 91 在 49 次迭代中的资源申请量为: 42.925760956954505
# agent 92 在 49 次迭代中的资源申请量为: 56.954232281258896
# agent 93 在 49 次迭代中的资源申请量为: 40.74372272943583
# agent 94 在 49 次迭代中的资源申请量为: 73.22266758573359
# agent 95 在 49 次迭代中的资源申请量为: 60.34419861619159
# agent 96 在 49 次迭代中的资源申请量为: 60.49738041444179
# agent 97 在 49 次迭代中的资源申请量为: 72.15931596946142
# agent 98 在 49 次迭代中的资源申请量为: 73.03683345857702
# agent 99 在 49 次迭代中的资源申请量为: 52.45047629513215
# agent 100 在 49 次迭代中的资源申请量为: 48.519690356295754
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 334933.63426490285
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: 48.79982365262959
# agent 2 在 99 次迭代中的资源申请量为: 61.51446426943995
# agent 3 在 99 次迭代中的资源申请量为: 44.16483559029302
# agent 4 在 99 次迭代中的资源申请量为: 65.01784495897127
# agent 5 在 99 次迭代中的资源申请量为: 65.8093002258988
# agent 6 在 99 次迭代中的资源申请量为: 72.63433039365606
# agent 7 在 99 次迭代中的资源申请量为: 39.817501070842546
# agent 8 在 99 次迭代中的资源申请量为: 13.720816144386015
# agent 9 在 99 次迭代中的资源申请量为: 43.49731667411482
# agent 10 在 99 次迭代中的资源申请量为: 56.29027679915887
# agent 11 在 99 次迭代中的资源申请量为: 45.89406851178206
# agent 12 在 99 次迭代中的资源申请量为: 49.78274837334337
# agent 13 在 99 次迭代中的资源申请量为: 66.33809156328785
# agent 14 在 99 次迭代中的资源申请量为: 55.67858265170905
# agent 15 在 99 次迭代中的资源申请量为: 43.868010906505795
# agent 16 在 99 次迭代中的资源申请量为: 44.04970340351882
# agent 17 在 99 次迭代中的资源申请量为: 45.266331555118214
# agent 18 在 99 次迭代中的资源申请量为: 46.88562112920848
# agent 19 在 99 次迭代中的资源申请量为: 41.690800934076336
# agent 20 在 99 次迭代中的资源申请量为: 56.249771927339
# agent 21 在 99 次迭代中的资源申请量为: 13.517014218181552
# agent 22 在 99 次迭代中的资源申请量为: 39.42343042276731
# agent 23 在 99 次迭代中的资源申请量为: 48.2042641534778
# agent 24 在 99 次迭代中的资源申请量为: 40.84360261322692
# agent 25 在 99 次迭代中的资源申请量为: 45.556563872040094
# agent 26 在 99 次迭代中的资源申请量为: 40.12270651319523
# agent 27 在 99 次迭代中的资源申请量为: 66.06328973725407
# agent 28 在 99 次迭代中的资源申请量为: 51.7646972329837
# agent 29 在 99 次迭代中的资源申请量为: 41.15424878977654
# agent 30 在 99 次迭代中的资源申请量为: 39.55990036124853
# agent 31 在 99 次迭代中的资源申请量为: 60.92026241501294
# agent 32 在 99 次迭代中的资源申请量为: 55.93206814502275
# agent 33 在 99 次迭代中的资源申请量为: 41.94644039685198
# agent 34 在 99 次迭代中的资源申请量为: 52.70409894902351
# agent 35 在 99 次迭代中的资源申请量为: 13.624451997521877
# agent 36 在 99 次迭代中的资源申请量为: 43.19578158202764
# agent 37 在 99 次迭代中的资源申请量为: 52.960575395618456
# agent 38 在 99 次迭代中的资源申请量为: 40.64916809686535
# agent 39 在 99 次迭代中的资源申请量为: 43.65648303722722
# agent 40 在 99 次迭代中的资源申请量为: 50.5463287617492
# agent 41 在 99 次迭代中的资源申请量为: 66.78423825395463
# agent 42 在 99 次迭代中的资源申请量为: 42.8639895625827
# agent 43 在 99 次迭代中的资源申请量为: 52.142805016432014
# agent 44 在 99 次迭代中的资源申请量为: 53.354421442833406
# agent 45 在 99 次迭代中的资源申请量为: 48.593106361666834
# agent 46 在 99 次迭代中的资源申请量为: 56.35147898103616
# agent 47 在 99 次迭代中的资源申请量为: 46.294311184546736
# agent 48 在 99 次迭代中的资源申请量为: 43.79185020944852
# agent 49 在 99 次迭代中的资源申请量为: 43.04673682992519
# agent 50 在 99 次迭代中的资源申请量为: 41.24699063961988
# agent 51 在 99 次迭代中的资源申请量为: 48.742046128504114
# agent 52 在 99 次迭代中的资源申请量为: 56.139258218319995
# agent 53 在 99 次迭代中的资源申请量为: 39.29192573707068
# agent 54 在 99 次迭代中的资源申请量为: 57.38602051158987
# agent 55 在 99 次迭代中的资源申请量为: 71.58727060521133
# agent 56 在 99 次迭代中的资源申请量为: 41.24841106970697
# agent 57 在 99 次迭代中的资源申请量为: 60.97590266111544
# agent 58 在 99 次迭代中的资源申请量为: 42.59794590696347
# agent 59 在 99 次迭代中的资源申请量为: 48.336911466800544
# agent 60 在 99 次迭代中的资源申请量为: 56.48208255350789
# agent 61 在 99 次迭代中的资源申请量为: 66.41543205492422
# agent 62 在 99 次迭代中的资源申请量为: 46.45065149396588
# agent 63 在 99 次迭代中的资源申请量为: 39.31769259188727
# agent 64 在 99 次迭代中的资源申请量为: 44.75923716521041
# agent 65 在 99 次迭代中的资源申请量为: 43.04859310391633
# agent 66 在 99 次迭代中的资源申请量为: 66.11186920700793
# agent 67 在 99 次迭代中的资源申请量为: 43.65341523152041
# agent 68 在 99 次迭代中的资源申请量为: 45.253191248855686
# agent 69 在 99 次迭代中的资源申请量为: 45.747887501127934
# agent 70 在 99 次迭代中的资源申请量为: 60.476157135461584
# agent 71 在 99 次迭代中的资源申请量为: 72.53275959463551
# agent 72 在 99 次迭代中的资源申请量为: 60.719251594257415
# agent 73 在 99 次迭代中的资源申请量为: 44.057542125877426
# agent 74 在 99 次迭代中的资源申请量为: 39.27874840615412
# agent 75 在 99 次迭代中的资源申请量为: 52.352827293616926
# agent 76 在 99 次迭代中的资源申请量为: 47.35141727351264
# agent 77 在 99 次迭代中的资源申请量为: 41.14626662178546
# agent 78 在 99 次迭代中的资源申请量为: 49.999374745479024
# agent 79 在 99 次迭代中的资源申请量为: 43.204445433970854
# agent 80 在 99 次迭代中的资源申请量为: 43.3503960148137
# agent 81 在 99 次迭代中的资源申请量为: 39.78900889934506
# agent 82 在 99 次迭代中的资源申请量为: 46.10234756525435
# agent 83 在 99 次迭代中的资源申请量为: 41.96091817537441
# agent 84 在 99 次迭代中的资源申请量为: 52.50063182710238
# agent 85 在 99 次迭代中的资源申请量为: 56.13315185681512
# agent 86 在 99 次迭代中的资源申请量为: 49.33351575894788
# agent 87 在 99 次迭代中的资源申请量为: 60.91979688347804
# agent 88 在 99 次迭代中的资源申请量为: 65.61135399489496
# agent 89 在 99 次迭代中的资源申请量为: 40.8587071708701
# agent 90 在 99 次迭代中的资源申请量为: 59.6580429216273
# agent 91 在 99 次迭代中的资源申请量为: 43.256636685807386
# agent 92 在 99 次迭代中的资源申请量为: 57.38691109136542
# agent 93 在 99 次迭代中的资源申请量为: 41.056213557499134
# agent 94 在 99 次迭代中的资源申请量为: 73.7851480665182
# agent 95 在 99 次迭代中的资源申请量为: 60.8129340862718
# agent 96 在 99 次迭代中的资源申请量为: 60.96612242768637
# agent 97 在 99 次迭代中的资源申请量为: 72.72183204040414
# agent 98 在 99 次迭代中的资源申请量为: 73.5993197547967
# agent 99 在 99 次迭代中的资源申请量为: 52.852249321025525
# agent 100 在 99 次迭代中的资源申请量为: 48.89468130974598
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 337673.55484227976
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 149 次迭代中的结果：
# agent 1 在 149 次迭代中的资源申请量为: 49.174817277671764
# agent 2 在 149 次迭代中的资源申请量为: 61.98320630078655
# agent 3 在 149 次迭代中的资源申请量为: 44.49571231829619
# agent 4 在 149 次迭代中的资源申请量为: 65.52919990230026
# agent 5 在 149 次迭代中的资源申请量为: 66.32065516926168
# agent 6 在 149 次迭代中的资源申请量为: 73.19682083146584
# agent 7 在 149 次迭代中的资源申请量为: 40.113548669606836
# agent 8 在 149 次迭代中的资源申请量为: 1.5020613631816897
# agent 9 在 149 次迭代中的资源申请量为: 43.82819340212865
# agent 10 在 149 次迭代中的资源申请量为: 56.72296175117249
# agent 11 在 149 次迭代中的资源申请量为: 46.245625035313495
# agent 12 在 149 次迭代中的资源申请量为: 50.157741998426914
# agent 13 在 149 次迭代中的资源申请量为: 66.84944650651758
# agent 14 在 149 次迭代中的资源申请量为: 56.111267603670505
# agent 15 在 149 次迭代中的资源申请量为: 44.19888763451107
# agent 16 在 149 次迭代中的资源申请量为: 44.38058013154161
# agent 17 在 149 次迭代中的资源申请量为: 45.61788807861656
# agent 18 在 149 次迭代中的资源申请量为: 47.237177652739156
# agent 19 在 149 次迭代中的资源申请量为: 42.00329562163242
# agent 20 在 149 次迭代中的资源申请量为: 56.68245687938588
# agent 21 在 149 次迭代中的资源申请量为: 0.6551670800837346
# agent 22 在 149 次迭代中的资源申请量为: 39.71947802152224
# agent 23 在 149 次迭代中的资源申请量为: 48.57925777853391
# agent 24 在 149 次迭代中的资源申请量为: 41.15609730076544
# agent 25 在 149 次迭代中的资源申请量为: 45.90812039554144
# agent 26 在 149 次迭代中的资源申请量为: 40.41875411193748
# agent 27 在 149 次迭代中的资源申请量为: 66.57464468046052
# agent 28 在 149 次迭代中的资源申请量为: 52.16647611697502
# agent 29 在 149 次迭代中的资源申请量为: 41.46674347731693
# agent 30 在 149 次迭代中的资源申请量为: 39.85594795998602
# agent 31 在 149 次迭代中的资源申请量为: 61.38900444633071
# agent 32 在 149 次迭代中的资源申请量为: 56.36475309697729
# agent 33 在 149 次迭代中的资源申请量为: 42.25893508439786
# agent 34 在 149 次迭代中的资源申请量为: 53.10587783302615
# agent 35 在 149 次迭代中的资源申请量为: 0.7626048594288244
# agent 36 在 149 次迭代中的资源申请量为: 43.5266583100674
# agent 37 在 149 次迭代中的资源申请量为: 53.362354279633614
# agent 38 在 149 次迭代中的资源申请量为: 40.9616627844187
# agent 39 在 149 次迭代中的资源申请量为: 43.98735976524306
# agent 40 在 149 次迭代中的资源申请量为: 50.9213223868482
# agent 41 在 149 次迭代中的资源申请量为: 67.29559319729788
# agent 42 在 149 次迭代中的资源申请量为: 43.19486629058764
# agent 43 在 149 次迭代中的资源申请量为: 52.544583900479985
# agent 44 在 149 次迭代中的资源申请量为: 53.75620032685841
# agent 45 在 149 次迭代中的资源申请量为: 48.96809998672844
# agent 46 在 149 次迭代中的资源申请量为: 56.78416393307455
# agent 47 在 149 次迭代中的资源申请量为: 46.645867708053935
# agent 48 在 149 次迭代中的资源申请量为: 44.12272693744689
# agent 49 在 149 次迭代中的资源申请量为: 43.377613557958426
# agent 50 在 149 次迭代中的资源申请量为: 41.559485327183374
# agent 51 在 149 次迭代中的资源申请量为: 49.1170397536008
# agent 52 在 149 次迭代中的资源申请量为: 56.571943170307804
# agent 53 在 149 次迭代中的资源申请量为: 39.587973335826945
# agent 54 在 149 次迭代中的资源申请量为: 57.81870546356636
# agent 55 在 149 次迭代中的资源申请量为: 72.14976104275841
# agent 56 在 149 次迭代中的资源申请量为: 41.56090575725694
# agent 57 在 149 次迭代中的资源申请量为: 61.44464469244738
# agent 58 在 149 次迭代中的资源申请量为: 42.928822634944595
# agent 59 在 149 次迭代中的资源申请量为: 48.71190509188795
# agent 60 在 149 次迭代中的资源申请量为: 56.91476750553895
# agent 61 在 149 次迭代中的资源申请量为: 66.92678699829821
# agent 62 在 149 次迭代中的资源申请量为: 46.80220801748399
# agent 63 在 149 次迭代中的资源申请量为: 39.61374019064769
# agent 64 在 149 次迭代中的资源申请量为: 45.11079368872937
# agent 65 在 149 次迭代中的资源申请量为: 43.37946983192748
# agent 66 在 149 次迭代中的资源申请量为: 66.62322415037877
# agent 67 在 149 次迭代中的资源申请量为: 43.984291959557346
# agent 68 在 149 次迭代中的资源申请量为: 45.604747772393544
# agent 69 在 149 次迭代中的资源申请量为: 46.099444024662226
# agent 70 在 149 次迭代中的资源申请量为: 60.94489916685206
# agent 71 在 149 次迭代中的资源申请量为: 73.095250032417
# agent 72 在 149 次迭代中的资源申请量为: 61.18799362559877
# agent 73 在 149 次迭代中的资源申请量为: 44.3884188538954
# agent 74 在 149 次迭代中的资源申请量为: 39.57479600488284
# agent 75 在 149 次迭代中的资源申请量为: 52.754606177620175
# agent 76 在 149 次迭代中的资源申请量为: 47.702973797005534
# agent 77 在 149 次迭代中的资源申请量为: 41.45876130933773
# agent 78 在 149 次迭代中的资源申请量为: 50.37436837051359
# agent 79 在 149 次迭代中的资源申请量为: 43.53532216197839
# agent 80 在 149 次迭代中的资源申请量为: 43.681272742800886
# agent 81 在 149 次迭代中的资源申请量为: 40.08505649806301
# agent 82 在 149 次迭代中的资源申请量为: 46.45390408875953
# agent 83 在 149 次迭代中的资源申请量为: 42.27341286292878
# agent 84 在 149 次迭代中的资源申请量为: 52.90241071108915
# agent 85 在 149 次迭代中的资源申请量为: 56.565836808839904
# agent 86 在 149 次迭代中的资源申请量为: 49.70850938402185
# agent 87 在 149 次迭代中的资源申请量为: 61.388538914848354
# agent 88 在 149 次迭代中的资源申请量为: 66.12270893828187
# agent 89 在 149 次迭代中的资源申请量为: 41.17120185846586
# agent 90 在 149 次迭代中的资源申请量为: 60.126784952952676
# agent 91 在 149 次迭代中的资源申请量为: 43.58751341381719
# agent 92 在 149 次迭代中的资源申请量为: 57.81959604337036
# agent 93 在 149 次迭代中的资源申请量为: 41.368708245056574
# agent 94 在 149 次迭代中的资源申请量为: 74.34763850407796
# agent 95 在 149 次迭代中的资源申请量为: 61.28167611759388
# agent 96 在 149 次迭代中的资源申请量为: 61.43486445903011
# agent 97 在 149 次迭代中的资源申请量为: 73.28432247808642
# agent 98 在 149 次迭代中的资源申请量为: 74.161810192365
# agent 99 在 149 次迭代中的资源申请量为: 53.25402820501832
# agent 100 在 149 次迭代中的资源申请量为: 49.26967493482512
# 资源申请量总和为: 4999.999999999998
# ****************************************************************************
# 成本总和为: 342310.5976231877
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: 49.54981090275251
# agent 2 在 199 次迭代中的资源申请量为: 62.45194833213747
# agent 3 在 199 次迭代中的资源申请量为: 44.82658904630861
# agent 4 在 199 次迭代中的资源申请量为: 66.04055484559218
# agent 5 在 199 次迭代中的资源申请量为: 66.83201011255362
# agent 6 在 199 次迭代中的资源申请量为: 73.75931126908698
# agent 7 在 199 次迭代中的资源申请量为: 40.40959626835479
# agent 8 在 199 次迭代中的资源申请量为: -10.716693418007752
# agent 9 在 199 次迭代中的资源申请量为: 44.15907013014107
# agent 10 在 199 次迭代中的资源申请量为: 57.155646703188744
# agent 11 在 199 次迭代中的资源申请量为: 46.59718155882669
# agent 12 在 199 次迭代中的资源申请量为: 50.53273562350766
# agent 13 在 199 次迭代中的资源申请量为: 67.36080144980951
# agent 14 在 199 次迭代中的资源申请量为: 56.54395255568675
# agent 15 在 199 次迭代中的资源申请量为: 44.52976436252348
# agent 16 在 199 次迭代中的资源申请量为: 44.71145685955403
# agent 17 在 199 次迭代中的资源申请量为: 45.96944460212976
# agent 18 在 199 次迭代中的资源申请量为: 47.58873417625235
# agent 19 在 199 次迭代中的资源申请量为: 42.315790309199706
# agent 20 在 199 次迭代中的资源申请量为: 57.11514183140213
# agent 21 在 199 次迭代中的资源申请量为: -12.206680058010408
# agent 22 在 199 次迭代中的资源申请量为: 40.0155256202702
# agent 23 在 199 次迭代中的资源申请量为: 48.95425140361465
# agent 24 在 199 次迭代中的资源申请量为: 41.46859198833272
# agent 25 在 199 次迭代中的资源申请量为: 46.25967691905463
# agent 26 在 199 次迭代中的资源申请量为: 40.71480171068544
# agent 27 在 199 次迭代中的资源申请量为: 67.08599962375244
# agent 28 在 199 次迭代中的资源申请量为: 52.568255000990106
# agent 29 在 199 次迭代中的资源申请量为: 41.77923816488422
# agent 30 在 199 次迭代中的资源申请量为: 40.151995558733965
# agent 31 在 199 次迭代中的资源申请量为: 61.85774647768164
# agent 32 在 199 次迭代中的资源申请量为: 56.79743804899353
# agent 33 在 199 次迭代中的资源申请量为: 42.57142977196516
# agent 34 在 199 次迭代中的资源申请量为: 53.507656717041236
# agent 35 在 199 次迭代中的资源申请量为: -12.099242278665328
# agent 36 在 199 次迭代中的资源申请量为: 43.85753503807981
# agent 37 在 199 次迭代中的资源申请量为: 53.764133163648694
# agent 38 在 199 次迭代中的资源申请量为: 41.27415747198599
# agent 39 在 199 次迭代中的资源申请量为: 44.31823649325548
# agent 40 在 199 次迭代中的资源申请量为: 51.296316011928944
# agent 41 在 199 次迭代中的资源申请量为: 67.80694814058978
# agent 42 在 199 次迭代中的资源申请量为: 43.52574301860007
# agent 43 在 199 次迭代中的资源申请量为: 52.94636278449507
# agent 44 在 199 次迭代中的资源申请量为: 54.15797921087349
# agent 45 在 199 次迭代中的资源申请量为: 49.34309361180919
# agent 46 在 199 次迭代中的资源申请量为: 57.21684888509079
# agent 47 在 199 次迭代中的资源申请量为: 46.99742423156714
# agent 48 在 199 次迭代中的资源申请量为: 44.45360366545932
# agent 49 在 199 次迭代中的资源申请量为: 43.70849028597085
# agent 50 在 199 次迭代中的资源申请量为: 41.87198001475066
# agent 51 在 199 次迭代中的资源申请量为: 49.492033378681555
# agent 52 在 199 次迭代中的资源申请量为: 57.00462812232405
# agent 53 在 199 次迭代中的资源申请量为: 39.8840209345749
# agent 54 在 199 次迭代中的资源申请量为: 58.25139041558261
# agent 55 在 199 次迭代中的资源申请量为: 72.71225148037952
# agent 56 在 199 次迭代中的资源申请量为: 41.87340044482422
# agent 57 在 199 次迭代中的资源申请量为: 61.91338672379832
# agent 58 在 199 次迭代中的资源申请量为: 43.259699362957015
# agent 59 在 199 次迭代中的资源申请量为: 49.0868987169687
# agent 60 在 199 次迭代中的资源申请量为: 57.34745245755519
# agent 61 在 199 次迭代中的资源申请量为: 67.43814194159015
# agent 62 在 199 次迭代中的资源申请量为: 47.15376454099719
# agent 63 在 199 次迭代中的资源申请量为: 39.90978778939565
# agent 64 在 199 次迭代中的资源申请量为: 45.46235021224257
# agent 65 在 199 次迭代中的资源申请量为: 43.7103465599399
# agent 66 在 199 次迭代中的资源申请量为: 67.13457909367071
# agent 67 在 199 次迭代中的资源申请量为: 44.31516868756977
# agent 68 在 199 次迭代中的资源申请量为: 45.95630429590674
# agent 69 在 199 次迭代中的资源申请量为: 46.45100054817542
# agent 70 在 199 次迭代中的资源申请量为: 61.413641198203
# agent 71 在 199 次迭代中的资源申请量为: 73.65774047003812
# agent 72 在 199 次迭代中的资源申请量为: 61.656735656949714
# agent 73 在 199 次迭代中的资源申请量为: 44.719295581907815
# agent 74 在 199 次迭代中的资源申请量为: 39.870843603630796
# agent 75 在 199 次迭代中的资源申请量为: 53.15638506163527
# agent 76 在 199 次迭代中的资源申请量为: 48.05453032051873
# agent 77 在 199 次迭代中的资源申请量为: 41.77125599690502
# agent 78 在 199 次迭代中的资源申请量为: 50.749361995594334
# agent 79 在 199 次迭代中的资源申请量为: 43.86619888999081
# agent 80 在 199 次迭代中的资源申请量为: 44.01214947081331
# agent 81 在 199 次迭代中的资源申请量为: 40.38110409681097
# agent 82 在 199 次迭代中的资源申请量为: 46.80546061227272
# agent 83 在 199 次迭代中的资源申请量为: 42.58590755049606
# agent 84 在 199 次迭代中的资源申请量为: 53.30418959510424
# agent 85 在 199 次迭代中的资源申请量为: 56.99852176085616
# agent 86 在 199 次迭代中的资源申请量为: 50.0835030091026
# agent 87 在 199 次迭代中的资源申请量为: 61.85728094619929
# agent 88 在 199 次迭代中的资源申请量为: 66.63406388157381
# agent 89 在 199 次迭代中的资源申请量为: 41.48369654603315
# agent 90 在 199 次迭代中的资源申请量为: 60.5955269843036
# agent 91 在 199 次迭代中的资源申请量为: 43.91839014182961
# agent 92 在 199 次迭代中的资源申请量为: 58.2522809953866
# agent 93 在 199 次迭代中的资源申请量为: 41.681202932623854
# agent 94 在 199 次迭代中的资源申请量为: 74.91012894169909
# agent 95 在 199 次迭代中的资源申请量为: 61.7504181489448
# agent 96 在 199 次迭代中的资源申请量为: 61.90360649038104
# agent 97 在 199 次迭代中的资源申请量为: 73.84681291570753
# agent 98 在 199 次迭代中的资源申请量为: 74.72430062998613
# agent 99 在 199 次迭代中的资源申请量为: 53.65580708903341
# agent 100 在 199 次迭代中的资源申请量为: 49.64466855990587
# 资源申请量总和为: 5000.000000000002
# ****************************************************************************
# 成本总和为: 348844.76285696303
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 249 次迭代中的结果：
# agent 1 在 249 次迭代中的资源申请量为: 49.92480452783326
# agent 2 在 249 次迭代中的资源申请量为: 62.920690363488404
# agent 3 在 249 次迭代中的资源申请量为: 45.15746577432103
# agent 4 在 249 次迭代中的资源申请量为: 66.55190978888412
# agent 5 在 249 次迭代中的资源申请量为: 67.34336505584554
# agent 6 在 249 次迭代中的资源申请量为: 74.32180170670809
# agent 7 在 249 次迭代中的资源申请量为: 40.70564386710274
# agent 8 在 249 次迭代中的资源申请量为: -22.935448199197193
# agent 9 在 249 次迭代中的资源申请量为: 44.489946858153495
# agent 10 在 249 次迭代中的资源申请量为: 57.58833165520499
# agent 11 在 249 次迭代中的资源申请量为: 46.948738082339894
# agent 12 在 249 次迭代中的资源申请量为: 50.90772924858841
# agent 13 在 249 次迭代中的资源申请量为: 67.87215639310145
# agent 14 在 249 次迭代中的资源申请量为: 56.976637507702996
# agent 15 在 249 次迭代中的资源申请量为: 44.860641090535914
# agent 16 在 249 次迭代中的资源申请量为: 45.04233358756646
# agent 17 在 249 次迭代中的资源申请量为: 46.32100112564296
# agent 18 在 249 次迭代中的资源申请量为: 47.94029069976555
# agent 19 在 249 次迭代中的资源申请量为: 42.628284996766986
# agent 20 在 249 次迭代中的资源申请量为: 57.54782678341837
# agent 21 在 249 次迭代中的资源申请量为: -25.068527196104558
# agent 22 在 249 次迭代中的资源申请量为: 40.31157321901816
# agent 23 在 249 次迭代中的资源申请量为: 49.3292450286954
# agent 24 在 249 次迭代中的资源申请量为: 41.78108667590001
# agent 25 在 249 次迭代中的资源申请量为: 46.61123344256784
# agent 26 在 249 次迭代中的资源申请量为: 41.010849309433404
# agent 27 在 249 次迭代中的资源申请量为: 67.59735456704436
# agent 28 在 249 次迭代中的资源申请量为: 52.97003388500519
# agent 29 在 249 次迭代中的资源申请量为: 42.091732852451514
# agent 30 在 249 次迭代中的资源申请量为: 40.44804315748193
# agent 31 在 249 次迭代中的资源申请量为: 62.32648850903257
# agent 32 在 249 次迭代中的资源申请量为: 57.23012300100977
# agent 33 在 249 次迭代中的资源申请量为: 42.883924459532444
# agent 34 在 249 次迭代中的资源申请量为: 53.90943560105632
# agent 35 在 249 次迭代中的资源申请量为: -24.961089416759474
# agent 36 在 249 次迭代中的资源申请量为: 44.188411766092244
# agent 37 在 249 次迭代中的资源申请量为: 54.16591204766378
# agent 38 在 249 次迭代中的资源申请量为: 41.586652159553275
# agent 39 在 249 次迭代中的资源申请量为: 44.64911322126791
# agent 40 在 249 次迭代中的资源申请量为: 51.67130963700969
# agent 41 在 249 次迭代中的资源申请量为: 68.31830308388172
# agent 42 在 249 次迭代中的资源申请量为: 43.85661974661249
# agent 43 在 249 次迭代中的资源申请量为: 53.34814166851016
# agent 44 在 249 次迭代中的资源申请量为: 54.55975809488858
# agent 45 在 249 次迭代中的资源申请量为: 49.718087236889936
# agent 46 在 249 次迭代中的资源申请量为: 57.64953383710704
# agent 47 在 249 次迭代中的资源申请量为: 47.34898075508034
# agent 48 在 249 次迭代中的资源申请量为: 44.78448039347174
# agent 49 在 249 次迭代中的资源申请量为: 44.039367013983274
# agent 50 在 249 次迭代中的资源申请量为: 42.18447470231795
# agent 51 在 249 次迭代中的资源申请量为: 49.86702700376229
# agent 52 在 249 次迭代中的资源申请量为: 57.4373130743403
# agent 53 在 249 次迭代中的资源申请量为: 40.18006853332286
# agent 54 在 249 次迭代中的资源申请量为: 58.68407536759886
# agent 55 在 249 次迭代中的资源申请量为: 73.27474191800064
# agent 56 在 249 次迭代中的资源申请量为: 42.185895132391515
# agent 57 在 249 次迭代中的资源申请量为: 62.38212875514925
# agent 58 在 249 次迭代中的资源申请量为: 43.59057609096944
# agent 59 在 249 次迭代中的资源申请量为: 49.461892342049445
# agent 60 在 249 次迭代中的资源申请量为: 57.78013740957144
# agent 61 在 249 次迭代中的资源申请量为: 67.94949688488207
# agent 62 在 249 次迭代中的资源申请量为: 47.5053210645104
# agent 63 在 249 次迭代中的资源申请量为: 40.205835388143605
# agent 64 在 249 次迭代中的资源申请量为: 45.81390673575577
# agent 65 在 249 次迭代中的资源申请量为: 44.04122328795233
# agent 66 在 249 次迭代中的资源申请量为: 67.64593403696264
# agent 67 在 249 次迭代中的资源申请量为: 44.6460454155822
# agent 68 在 249 次迭代中的资源申请量为: 46.30786081941994
# agent 69 在 249 次迭代中的资源申请量为: 46.802557071688625
# agent 70 在 249 次迭代中的资源申请量为: 61.88238322955393
# agent 71 在 249 次迭代中的资源申请量为: 74.22023090765924
# agent 72 在 249 次迭代中的资源申请量为: 62.12547768830065
# agent 73 在 249 次迭代中的资源申请量为: 45.05017230992024
# agent 74 在 249 次迭代中的资源申请量为: 40.16689120237876
# agent 75 在 249 次迭代中的资源申请量为: 53.55816394565036
# agent 76 在 249 次迭代中的资源申请量为: 48.40608684403193
# agent 77 在 249 次迭代中的资源申请量为: 42.08375068447231
# agent 78 在 249 次迭代中的资源申请量为: 51.12435562067508
# agent 79 在 249 次迭代中的资源申请量为: 44.19707561800324
# agent 80 在 249 次迭代中的资源申请量为: 44.34302619882573
# agent 81 在 249 次迭代中的资源申请量为: 40.677151695558926
# agent 82 在 249 次迭代中的资源申请量为: 47.15701713578592
# agent 83 在 249 次迭代中的资源申请量为: 42.89840223806335
# agent 84 在 249 次迭代中的资源申请量为: 53.70596847911932
# agent 85 在 249 次迭代中的资源申请量为: 57.431206712872395
# agent 86 在 249 次迭代中的资源申请量为: 50.45849663418334
# agent 87 在 249 次迭代中的资源申请量为: 62.326022977550224
# agent 88 在 249 次迭代中的资源申请量为: 67.14541882486573
# agent 89 在 249 次迭代中的资源申请量为: 41.79619123360044
# agent 90 在 249 次迭代中的资源申请量为: 61.06426901565453
# agent 91 在 249 次迭代中的资源申请量为: 44.24926686984203
# agent 92 在 249 次迭代中的资源申请量为: 58.68496594740286
# agent 93 在 249 次迭代中的资源申请量为: 41.99369762019114
# agent 94 在 249 次迭代中的资源申请量为: 75.47261937932021
# agent 95 在 249 次迭代中的资源申请量为: 62.219160180295745
# agent 96 在 249 次迭代中的资源申请量为: 62.37234852173197
# agent 97 在 249 次迭代中的资源申请量为: 74.40930335332865
# agent 98 在 249 次迭代中的资源申请量为: 75.28679106760724
# agent 99 在 249 次迭代中的资源申请量为: 54.057585973048496
# agent 100 在 249 次迭代中的资源申请量为: 50.019662184986615
# 资源申请量总和为: 5000.000000000003
# ****************************************************************************
# 成本总和为: 357276.0505436074
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 299 次迭代中的结果：
# agent 1 在 299 次迭代中的资源申请量为: 50.29979815291401
# agent 2 在 299 次迭代中的资源申请量为: 63.38943239483934
# agent 3 在 299 次迭代中的资源申请量为: 45.48834250233347
# agent 4 在 299 次迭代中的资源申请量为: 67.06326473217604
# agent 5 在 299 次迭代中的资源申请量为: 67.85471999913747
# agent 6 在 299 次迭代中的资源申请量为: 74.88429214432922
# agent 7 在 299 次迭代中的资源申请量为: 41.001691465850705
# agent 8 在 299 次迭代中的资源申请量为: -35.15420298038662
# agent 9 在 299 次迭代中的资源申请量为: 44.82082358616592
# agent 10 在 299 次迭代中的资源申请量为: 58.02101660722123
# agent 11 在 299 次迭代中的资源申请量为: 47.3002946058531
# agent 12 在 299 次迭代中的资源申请量为: 51.28272287366916
# agent 13 在 299 次迭代中的资源申请量为: 68.38351133639335
# agent 14 在 299 次迭代中的资源申请量为: 57.40932245971925
# agent 15 在 299 次迭代中的资源申请量为: 45.191517818548334
# agent 16 在 299 次迭代中的资源申请量为: 45.37321031557888
# agent 17 在 299 次迭代中的资源申请量为: 46.67255764915616
# agent 18 在 299 次迭代中的资源申请量为: 48.291847223278744
# agent 19 在 299 次迭代中的资源申请量为: 42.94077968433429
# agent 20 在 299 次迭代中的资源申请量为: 57.98051173543462
# agent 21 在 299 次迭代中的资源申请量为: -37.9303743341987
# agent 22 在 299 次迭代中的资源申请量为: 40.607620817766126
# agent 23 在 299 次迭代中的资源申请量为: 49.704238653776144
# agent 24 在 299 次迭代中的资源申请量为: 42.09358136346731
# agent 25 在 299 次迭代中的资源申请量为: 46.96278996608103
# agent 26 在 299 次迭代中的资源申请量为: 41.30689690818136
# agent 27 在 299 次迭代中的资源申请量为: 68.10870951033631
# agent 28 在 299 次迭代中的资源申请量为: 53.37181276902028
# agent 29 在 299 次迭代中的资源申请量为: 42.4042275400188
# agent 30 在 299 次迭代中的资源申请量为: 40.74409075622989
# agent 31 在 299 次迭代中的资源申请量为: 62.79523054038351
# agent 32 在 299 次迭代中的资源申请量为: 57.66280795302602
# agent 33 在 299 次迭代中的资源申请量为: 43.19641914709974
# agent 34 在 299 次迭代中的资源申请量为: 54.31121448507141
# agent 35 在 299 次迭代中的资源申请量为: -37.82293655485362
# agent 36 在 299 次迭代中的资源申请量为: 44.519288494104664
# agent 37 在 299 次迭代中的资源申请量为: 54.56769093167887
# agent 38 在 299 次迭代中的资源申请量为: 41.89914684712057
# agent 39 在 299 次迭代中的资源申请量为: 44.97998994928034
# agent 40 在 299 次迭代中的资源申请量为: 52.04630326209044
# agent 41 在 299 次迭代中的资源申请量为: 68.82965802717365
# agent 42 在 299 次迭代中的资源申请量为: 44.18749647462491
# agent 43 在 299 次迭代中的资源申请量为: 53.74992055252525
# agent 44 在 299 次迭代中的资源申请量为: 54.96153697890367
# agent 45 在 299 次迭代中的资源申请量为: 50.093080861970684
# agent 46 在 299 次迭代中的资源申请量为: 58.08221878912329
# agent 47 在 299 次迭代中的资源申请量为: 47.70053727859354
# agent 48 在 299 次迭代中的资源申请量为: 45.115357121484166
# agent 49 在 299 次迭代中的资源申请量为: 44.37024374199571
# agent 50 在 299 次迭代中的资源申请量为: 42.496969389885244
# agent 51 在 299 次迭代中的资源申请量为: 50.24202062884304
# agent 52 在 299 次迭代中的资源申请量为: 57.86999802635654
# agent 53 在 299 次迭代中的资源申请量为: 40.47611613207083
# agent 54 在 299 次迭代中的资源申请量为: 59.11676031961511
# agent 55 在 299 次迭代中的资源申请量为: 73.83723235562177
# agent 56 在 299 次迭代中的资源申请量为: 42.4983898199588
# agent 57 在 299 次迭代中的资源申请量为: 62.85087078650019
# agent 58 在 299 次迭代中的资源申请量为: 43.92145281898186
# agent 59 在 299 次迭代中的资源申请量为: 49.83688596713019
# agent 60 在 299 次迭代中的资源申请量为: 58.21282236158769
# agent 61 在 299 次迭代中的资源申请量为: 68.460851828174
# agent 62 在 299 次迭代中的资源申请量为: 47.856877588023586
# agent 63 在 299 次迭代中的资源申请量为: 40.501882986891566
# agent 64 在 299 次迭代中的资源申请量为: 46.16546325926897
# agent 65 在 299 次迭代中的资源申请量为: 44.37210001596475
# agent 66 在 299 次迭代中的资源申请量为: 68.15728898025456
# agent 67 在 299 次迭代中的资源申请量为: 44.97692214359462
# agent 68 在 299 次迭代中的资源申请量为: 46.659417342933146
# agent 69 在 299 次迭代中的资源申请量为: 47.15411359520183
# agent 70 在 299 次迭代中的资源申请量为: 62.351125260904865
# agent 71 在 299 次迭代中的资源申请量为: 74.78272134528036
# agent 72 在 299 次迭代中的资源申请量为: 62.594219719651576
# agent 73 在 299 次迭代中的资源申请量为: 45.38104903793267
# agent 74 在 299 次迭代中的资源申请量为: 40.46293880112672
# agent 75 在 299 次迭代中的资源申请量为: 53.959942829665444
# agent 76 在 299 次迭代中的资源申请量为: 48.757643367545136
# agent 77 在 299 次迭代中的资源申请量为: 42.3962453720396
# agent 78 在 299 次迭代中的资源申请量为: 51.49934924575583
# agent 79 在 299 次迭代中的资源申请量为: 44.52795234601567
# agent 80 在 299 次迭代中的资源申请量为: 44.67390292683816
# agent 81 在 299 次迭代中的资源申请量为: 40.97319929430689
# agent 82 在 299 次迭代中的资源申请量为: 47.508573659299124
# agent 83 在 299 次迭代中的资源申请量为: 43.21089692563064
# agent 84 在 299 次迭代中的资源申请量为: 54.10774736313441
# agent 85 在 299 次迭代中的资源申请量为: 57.86389166488865
# agent 86 在 299 次迭代中的资源申请量为: 50.8334902592641
# agent 87 在 299 次迭代中的资源申请量为: 62.794765008901166
# agent 88 在 299 次迭代中的资源申请量为: 67.65677376815766
# agent 89 在 299 次迭代中的资源申请量为: 42.108685921167734
# agent 90 在 299 次迭代中的资源申请量为: 61.53301104700547
# agent 91 在 299 次迭代中的资源申请量为: 44.58014359785446
# agent 92 在 299 次迭代中的资源申请量为: 59.1176508994191
# agent 93 在 299 次迭代中的资源申请量为: 42.30619230775844
# agent 94 在 299 次迭代中的资源申请量为: 76.03510981694133
# agent 95 在 299 次迭代中的资源申请量为: 62.687902211646666
# agent 96 在 299 次迭代中的资源申请量为: 62.84109055308291
# agent 97 在 299 次迭代中的资源申请量为: 74.97179379094977
# agent 98 在 299 次迭代中的资源申请量为: 75.84928150522836
# agent 99 在 299 次迭代中的资源申请量为: 54.45936485706358
# agent 100 在 299 次迭代中的资源申请量为: 50.39465581006736
# 资源申请量总和为: 5000.000000000004
# ****************************************************************************
# 成本总和为: 367604.4606831204
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 349 次迭代中的结果：
# agent 1 在 349 次迭代中的资源申请量为: 50.674791777994756
# agent 2 在 349 次迭代中的资源申请量为: 63.858174426190274
# agent 3 在 349 次迭代中的资源申请量为: 45.81921923034589
# agent 4 在 349 次迭代中的资源申请量为: 67.57461967546799
# agent 5 在 349 次迭代中的资源申请量为: 68.3660749424294
# agent 6 在 349 次迭代中的资源申请量为: 75.44678258195033
# agent 7 在 349 次迭代中的资源申请量为: 41.29773906459865
# agent 8 在 349 次迭代中的资源申请量为: -47.37295776157607
# agent 9 在 349 次迭代中的资源申请量为: 45.15170031417835
# agent 10 在 349 次迭代中的资源申请量为: 58.45370155923749
# agent 11 在 349 次迭代中的资源申请量为: 47.6518511293663
# agent 12 在 349 次迭代中的资源申请量为: 51.657716498749906
# agent 13 在 349 次迭代中的资源申请量为: 68.8948662796853
# agent 14 在 349 次迭代中的资源申请量为: 57.8420074117355
# agent 15 在 349 次迭代中的资源申请量为: 45.52239454656076
# agent 16 在 349 次迭代中的资源申请量为: 45.7040870435913
# agent 17 在 349 次迭代中的资源申请量为: 47.024114172669364
# agent 18 在 349 次迭代中的资源申请量为: 48.643403746791954
# agent 19 在 349 次迭代中的资源申请量为: 43.253274371901576
# agent 20 在 349 次迭代中的资源申请量为: 58.41319668745088
# agent 21 在 349 次迭代中的资源申请量为: -50.79222147229285
# agent 22 在 349 次迭代中的资源申请量为: 40.90366841651408
# agent 23 在 349 次迭代中的资源申请量为: 50.07923227885689
# agent 24 在 349 次迭代中的资源申请量为: 42.406076051034596
# agent 25 在 349 次迭代中的资源申请量为: 47.314346489594236
# agent 26 在 349 次迭代中的资源申请量为: 41.60294450692932
# agent 27 在 349 次迭代中的资源申请量为: 68.62006445362823
# agent 28 在 349 次迭代中的资源申请量为: 53.77359165303537
# agent 29 在 349 次迭代中的资源申请量为: 42.71672222758609
# agent 30 在 349 次迭代中的资源申请量为: 41.04013835497785
# agent 31 在 349 次迭代中的资源申请量为: 63.26397257173445
# agent 32 在 349 次迭代中的资源申请量为: 58.09549290504226
# agent 33 在 349 次迭代中的资源申请量为: 43.508913834667034
# agent 34 在 349 次迭代中的资源申请量为: 54.7129933690865
# agent 35 在 349 次迭代中的资源申请量为: -50.68478369294776
# agent 36 在 349 次迭代中的资源申请量为: 44.85016522211709
# agent 37 在 349 次迭代中的资源申请量为: 54.969469815693955
# agent 38 在 349 次迭代中的资源申请量为: 42.21164153468786
# agent 39 在 349 次迭代中的资源申请量为: 45.31086667729276
# agent 40 在 349 次迭代中的资源申请量为: 52.42129688717119
# agent 41 在 349 次迭代中的资源申请量为: 69.34101297046557
# agent 42 在 349 次迭代中的资源申请量为: 44.518373202637335
# agent 43 在 349 次迭代中的资源申请量为: 54.15169943654034
# agent 44 在 349 次迭代中的资源申请量为: 55.36331586291876
# agent 45 在 349 次迭代中的资源申请量为: 50.46807448705143
# agent 46 在 349 次迭代中的资源申请量为: 58.514903741139534
# agent 47 在 349 次迭代中的资源申请量为: 48.05209380210673
# agent 48 在 349 次迭代中的资源申请量为: 45.446233849496586
# agent 49 在 349 次迭代中的资源申请量为: 44.70112047000813
# agent 50 在 349 次迭代中的资源申请量为: 42.80946407745253
# agent 51 在 349 次迭代中的资源申请量为: 50.61701425392379
# agent 52 在 349 次迭代中的资源申请量为: 58.30268297837279
# agent 53 在 349 次迭代中的资源申请量为: 40.77216373081878
# agent 54 在 349 次迭代中的资源申请量为: 59.549445271631356
# agent 55 在 349 次迭代中的资源申请量为: 74.39972279324289
# agent 56 在 349 次迭代中的资源申请量为: 42.81088450752609
# agent 57 在 349 次迭代中的资源申请量为: 63.31961281785112
# agent 58 在 349 次迭代中的资源申请量为: 44.2523295469943
# agent 59 在 349 次迭代中的资源申请量为: 50.21187959221094
# agent 60 在 349 次迭代中的资源申请量为: 58.645507313603936
# agent 61 在 349 次迭代中的资源申请量为: 68.97220677146592
# agent 62 在 349 次迭代中的资源申请量为: 48.20843411153679
# agent 63 在 349 次迭代中的资源申请量为: 40.79793058563953
# agent 64 在 349 次迭代中的资源申请量为: 46.51701978278217
# agent 65 在 349 次迭代中的资源申请量为: 44.702976743977175
# agent 66 在 349 次迭代中的资源申请量为: 68.6686439235465
# agent 67 在 349 次迭代中的资源申请量为: 45.30779887160705
# agent 68 在 349 次迭代中的资源申请量为: 47.010973866446356
# agent 69 在 349 次迭代中的资源申请量为: 47.50567011871503
# agent 70 在 349 次迭代中的资源申请量为: 62.81986729225581
# agent 71 在 349 次迭代中的资源申请量为: 75.34521178290149
# agent 72 在 349 次迭代中的资源申请量为: 63.06296175100252
# agent 73 在 349 次迭代中的资源申请量为: 45.71192576594509
# agent 74 在 349 次迭代中的资源申请量为: 40.75898639987468
# agent 75 在 349 次迭代中的资源申请量为: 54.36172171368053
# agent 76 在 349 次迭代中的资源申请量为: 49.10919989105833
# agent 77 在 349 次迭代中的资源申请量为: 42.70874005960688
# agent 78 在 349 次迭代中的资源申请量为: 51.87434287083658
# agent 79 在 349 次迭代中的资源申请量为: 44.85882907402808
# agent 80 在 349 次迭代中的资源申请量为: 45.00477965485058
# agent 81 在 349 次迭代中的资源申请量为: 41.26924689305484
# agent 82 在 349 次迭代中的资源申请量为: 47.86013018281233
# agent 83 在 349 次迭代中的资源申请量为: 43.52339161319793
# agent 84 在 349 次迭代中的资源申请量为: 54.5095262471495
# agent 85 在 349 次迭代中的资源申请量为: 58.2965766169049
# agent 86 在 349 次迭代中的资源申请量为: 51.208483884344844
# agent 87 在 349 次迭代中的资源申请量为: 63.2635070402521
# agent 88 在 349 次迭代中的资源申请量为: 68.1681287114496
# agent 89 在 349 次迭代中的资源申请量为: 42.42118060873502
# agent 90 在 349 次迭代中的资源申请量为: 62.0017530783564
# agent 91 在 349 次迭代中的资源申请量为: 44.911020325866886
# agent 92 在 349 次迭代中的资源申请量为: 59.55033585143535
# agent 93 在 349 次迭代中的资源申请量为: 42.618686995325724
# agent 94 在 349 次迭代中的资源申请量为: 76.59760025456245
# agent 95 在 349 次迭代中的资源申请量为: 63.156644242997615
# agent 96 在 349 次迭代中的资源申请量为: 63.30983258443384
# agent 97 在 349 次迭代中的资源申请量为: 75.5342842285709
# agent 98 在 349 次迭代中的资源申请量为: 76.4117719428495
# agent 99 在 349 次迭代中的资源申请量为: 54.86114374107867
# agent 100 在 349 次迭代中的资源申请量为: 50.769649435148104
# 资源申请量总和为: 5000.000000000006
# ****************************************************************************
# 成本总和为: 379829.9932755025
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 399 次迭代中的结果：
# agent 1 在 399 次迭代中的资源申请量为: 51.049785403075504
# agent 2 在 399 次迭代中的资源申请量为: 64.32691645754122
# agent 3 在 399 次迭代中的资源申请量为: 46.1500959583583
# agent 4 在 399 次迭代中的资源申请量为: 68.0859746187599
# agent 5 在 399 次迭代中的资源申请量为: 68.87742988572131
# agent 6 在 399 次迭代中的资源申请量为: 76.00927301957144
# agent 7 在 399 次迭代中的资源申请量为: 41.59378666334662
# agent 8 在 399 次迭代中的资源申请量为: -59.59171254276551
# agent 9 在 399 次迭代中的资源申请量为: 45.482577042190776
# agent 10 在 399 次迭代中的资源申请量为: 58.886386511253725
# agent 11 在 399 次迭代中的资源申请量为: 48.003407652879496
# agent 12 在 399 次迭代中的资源申请量为: 52.032710123830654
# agent 13 在 399 次迭代中的资源申请量为: 69.40622122297724
# agent 14 在 399 次迭代中的资源申请量为: 58.27469236375173
# agent 15 在 399 次迭代中的资源申请量为: 45.85327127457318
# agent 16 在 399 次迭代中的资源申请量为: 46.034963771603735
# agent 17 在 399 次迭代中的资源申请量为: 47.37567069618257
# agent 18 在 399 次迭代中的资源申请量为: 48.99496027030516
# agent 19 在 399 次迭代中的资源申请量为: 43.56576905946886
# agent 20 在 399 次迭代中的资源申请量为: 58.845881639467116
# agent 21 在 399 次迭代中的资源申请量为: -63.654068610387
# agent 22 在 399 次迭代中的资源申请量为: 41.19971601526204
# agent 23 在 399 次迭代中的资源申请量为: 50.45422590393764
# agent 24 在 399 次迭代中的资源申请量为: 42.71857073860188
# agent 25 在 399 次迭代中的资源申请量为: 47.66590301310743
# agent 26 在 399 次迭代中的资源申请量为: 41.89899210567728
# agent 27 在 399 次迭代中的资源申请量为: 69.13141939692015
# agent 28 在 399 次迭代中的资源申请量为: 54.17537053705045
# agent 29 在 399 次迭代中的资源申请量为: 43.029216915153384
# agent 30 在 399 次迭代中的资源申请量为: 41.33618595372581
# agent 31 在 399 次迭代中的资源申请量为: 63.732714603085384
# agent 32 在 399 次迭代中的资源申请量为: 58.528177857058516
# agent 33 在 399 次迭代中的资源申请量为: 43.82140852223432
# agent 34 在 399 次迭代中的资源申请量为: 55.11477225310158
# agent 35 在 399 次迭代中的资源申请量为: -63.54663083104191
# agent 36 在 399 次迭代中的资源申请量为: 45.18104195012952
# agent 37 在 399 次迭代中的资源申请量为: 55.37124869970905
# agent 38 在 399 次迭代中的资源申请量为: 42.524136222255144
# agent 39 在 399 次迭代中的资源申请量为: 45.641743405305185
# agent 40 在 399 次迭代中的资源申请量为: 52.796290512251936
# agent 41 在 399 次迭代中的资源申请量为: 69.8523679137575
# agent 42 在 399 次迭代中的资源申请量为: 44.84924993064976
# agent 43 在 399 次迭代中的资源申请量为: 54.55347832055543
# agent 44 在 399 次迭代中的资源申请量为: 55.76509474693384
# agent 45 在 399 次迭代中的资源申请量为: 50.84306811213218
# agent 46 在 399 次迭代中的资源申请量为: 58.94758869315578
# agent 47 在 399 次迭代中的资源申请量为: 48.40365032561994
# agent 48 在 399 次迭代中的资源申请量为: 45.77711057750902
# agent 49 在 399 次迭代中的资源申请量为: 45.03199719802055
# agent 50 在 399 次迭代中的资源申请量为: 43.121958765019826
# agent 51 在 399 次迭代中的资源申请量为: 50.99200787900454
# agent 52 在 399 次迭代中的资源申请量为: 58.73536793038904
# agent 53 在 399 次迭代中的资源申请量为: 41.06821132956674
# agent 54 在 399 次迭代中的资源申请量为: 59.9821302236476
# agent 55 在 399 次迭代中的资源申请量为: 74.96221323086401
# agent 56 在 399 次迭代中的资源申请量为: 43.123379195093385
# agent 57 在 399 次迭代中的资源申请量为: 63.78835484920206
# agent 58 在 399 次迭代中的资源申请量为: 44.58320627500672
# agent 59 在 399 次迭代中的资源申请量为: 50.58687321729169
# agent 60 在 399 次迭代中的资源申请量为: 59.07819226562018
# agent 61 在 399 次迭代中的资源申请量为: 69.48356171475785
# agent 62 在 399 次迭代中的资源申请量为: 48.55999063505
# agent 63 在 399 次迭代中的资源申请量为: 41.09397818438748
# agent 64 在 399 次迭代中的资源申请量为: 46.86857630629537
# agent 65 在 399 次迭代中的资源申请量为: 45.0338534719896
# agent 66 在 399 次迭代中的资源申请量为: 69.17999886683842
# agent 67 在 399 次迭代中的资源申请量为: 45.63867559961947
# agent 68 在 399 次迭代中的资源申请量为: 47.362530389959545
# agent 69 在 399 次迭代中的资源申请量为: 47.857226642228234
# agent 70 在 399 次迭代中的资源申请量为: 63.28860932360674
# agent 71 在 399 次迭代中的资源申请量为: 75.90770222052261
# agent 72 在 399 次迭代中的资源申请量为: 63.53170378235345
# agent 73 在 399 次迭代中的资源申请量为: 46.04280249395752
# agent 74 在 399 次迭代中的资源申请量为: 41.05503399862263
# agent 75 在 399 次迭代中的资源申请量为: 54.76350059769562
# agent 76 在 399 次迭代中的资源申请量为: 49.46075641457154
# agent 77 在 399 次迭代中的资源申请量为: 43.02123474717418
# agent 78 在 399 次迭代中的资源申请量为: 52.249336495917326
# agent 79 在 399 次迭代中的资源申请量为: 45.18970580204051
# agent 80 在 399 次迭代中的资源申请量为: 45.33565638286301
# agent 81 在 399 次迭代中的资源申请量为: 41.56529449180281
# agent 82 在 399 次迭代中的资源申请量为: 48.21168670632553
# agent 83 在 399 次迭代中的资源申请量为: 43.83588630076522
# agent 84 在 399 次迭代中的资源申请量为: 54.91130513116458
# agent 85 在 399 次迭代中的资源申请量为: 58.72926156892114
# agent 86 在 399 次迭代中的资源申请量为: 51.5834775094256
# agent 87 在 399 次迭代中的资源申请量为: 63.73224907160303
# agent 88 在 399 次迭代中的资源申请量为: 68.67948365474152
# agent 89 在 399 次迭代中的资源申请量为: 42.73367529630231
# agent 90 在 399 次迭代中的资源申请量为: 62.47049510970734
# agent 91 在 399 次迭代中的资源申请量为: 45.241897053879306
# agent 92 在 399 次迭代中的资源申请量为: 59.983020803451595
# agent 93 在 399 次迭代中的资源申请量为: 42.93118168289302
# agent 94 在 399 次迭代中的资源申请量为: 77.16009069218357
# agent 95 在 399 次迭代中的资源申请量为: 63.62538627434855
# agent 96 在 399 次迭代中的资源申请量为: 63.77857461578478
# agent 97 在 399 次迭代中的资源申请量为: 76.096774666192
# agent 98 在 399 次迭代中的资源申请量为: 76.9742623804706
# agent 99 在 399 次迭代中的资源申请量为: 55.26292262509375
# agent 100 在 399 次迭代中的资源申请量为: 51.14464306022885
# 资源申请量总和为: 5000.000000000008
# ****************************************************************************
# 成本总和为: 393952.6483207534
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 449 次迭代中的结果：
# agent 1 在 449 次迭代中的资源申请量为: 51.424779028156244
# agent 2 在 449 次迭代中的资源申请量为: 64.79565848889213
# agent 3 在 449 次迭代中的资源申请量为: 46.48097268637073
# agent 4 在 449 次迭代中的资源申请量为: 68.59732956205183
# agent 5 在 449 次迭代中的资源申请量为: 69.38878482901326
# agent 6 在 449 次迭代中的资源申请量为: 76.57176345719257
# agent 7 在 449 次迭代中的资源申请量为: 41.889834262094574
# agent 8 在 449 次迭代中的资源申请量为: -71.81046732395495
# agent 9 在 449 次迭代中的资源申请量为: 45.81345377020319
# agent 10 在 449 次迭代中的资源申请量为: 59.31907146326997
# agent 11 在 449 次迭代中的资源申请量为: 48.35496417639269
# agent 12 在 449 次迭代中的资源申请量为: 52.4077037489114
# agent 13 在 449 次迭代中的资源申请量为: 69.91757616626914
# agent 14 在 449 次迭代中的资源申请量为: 58.707377315767985
# agent 15 在 449 次迭代中的资源申请量为: 46.1841480025856
# agent 16 在 449 次迭代中的资源申请量为: 46.365840499616155
# agent 17 在 449 次迭代中的资源申请量为: 47.72722721969576
# agent 18 在 449 次迭代中的资源申请量为: 49.346516793818346
# agent 19 在 449 次迭代中的资源申请量为: 43.87826374703616
# agent 20 在 449 次迭代中的资源申请量为: 59.27856659148337
# agent 21 在 449 次迭代中的资源申请量为: -76.51591574848115
# agent 22 在 449 次迭代中的资源申请量为: 41.495763614009995
# agent 23 在 449 次迭代中的资源申请量为: 50.82921952901838
# agent 24 在 449 次迭代中的资源申请量为: 43.03106542616918
# agent 25 在 449 次迭代中的资源申请量为: 48.017459536620635
# agent 26 在 449 次迭代中的资源申请量为: 42.195039704425234
# agent 27 在 449 次迭代中的资源申请量为: 69.64277434021209
# agent 28 在 449 次迭代中的资源申请量为: 54.577149421065535
# agent 29 在 449 次迭代中的资源申请量为: 43.341711602720665
# agent 30 在 449 次迭代中的资源申请量为: 41.632233552473764
# agent 31 在 449 次迭代中的资源申请量为: 64.20145663443631
# agent 32 在 449 次迭代中的资源申请量为: 58.96086280907476
# agent 33 在 449 次迭代中的资源申请量为: 44.1339032098016
# agent 34 在 449 次迭代中的资源申请量为: 55.516551137116664
# agent 35 在 449 次迭代中的资源申请量为: -76.40847796913606
# agent 36 在 449 次迭代中的资源申请量为: 45.51191867814194
# agent 37 在 449 次迭代中的资源申请量为: 55.77302758372413
# agent 38 在 449 次迭代中的资源申请量为: 42.836630909822425
# agent 39 在 449 次迭代中的资源申请量为: 45.972620133317605
# agent 40 在 449 次迭代中的资源申请量为: 53.171284137332684
# agent 41 在 449 次迭代中的资源申请量为: 70.36372285704942
# agent 42 在 449 次迭代中的资源申请量为: 45.18012665866218
# agent 43 在 449 次迭代中的资源申请量为: 54.95525720457051
# agent 44 在 449 次迭代中的资源申请量为: 56.16687363094892
# agent 45 在 449 次迭代中的资源申请量为: 51.21806173721293
# agent 46 在 449 次迭代中的资源申请量为: 59.38027364517203
# agent 47 在 449 次迭代中的资源申请量为: 48.75520684913314
# agent 48 在 449 次迭代中的资源申请量为: 46.10798730552144
# agent 49 在 449 次迭代中的资源申请量为: 45.36287392603297
# agent 50 在 449 次迭代中的资源申请量为: 43.43445345258711
# agent 51 在 449 次迭代中的资源申请量为: 51.36700150408528
# agent 52 在 449 次迭代中的资源申请量为: 59.16805288240529
# agent 53 在 449 次迭代中的资源申请量为: 41.3642589283147
# agent 54 在 449 次迭代中的资源申请量为: 60.41481517566385
# agent 55 在 449 次迭代中的资源申请量为: 75.52470366848513
# agent 56 在 449 次迭代中的资源申请量为: 43.43587388266067
# agent 57 在 449 次迭代中的资源申请量为: 64.25709688055298
# agent 58 在 449 次迭代中的资源申请量为: 44.91408300301913
# agent 59 在 449 次迭代中的资源申请量为: 50.96186684237244
# agent 60 在 449 次迭代中的资源申请量为: 59.51087721763643
# agent 61 在 449 次迭代中的资源申请量为: 69.99491665804977
# agent 62 在 449 次迭代中的资源申请量为: 48.911547158563195
# agent 63 在 449 次迭代中的资源申请量为: 41.390025783135435
# agent 64 在 449 次迭代中的资源申请量为: 47.22013282980857
# agent 65 在 449 次迭代中的资源申请量为: 45.36473020000202
# agent 66 在 449 次迭代中的资源申请量为: 69.69135381013034
# agent 67 在 449 次迭代中的资源申请量为: 45.969552327631895
# agent 68 在 449 次迭代中的资源申请量为: 47.71408691347275
# agent 69 在 449 次迭代中的资源申请量为: 48.20878316574142
# agent 70 在 449 次迭代中的资源申请量为: 63.75735135495767
# agent 71 在 449 次迭代中的资源申请量为: 76.47019265814373
# agent 72 在 449 次迭代中的资源申请量为: 64.00044581370437
# agent 73 在 449 次迭代中的资源申请量为: 46.37367922196994
# agent 74 在 449 次迭代中的资源申请量为: 41.351081597370595
# agent 75 在 449 次迭代中的资源申请量为: 55.165279481710705
# agent 76 在 449 次迭代中的资源申请量为: 49.81231293808474
# agent 77 在 449 次迭代中的资源申请量为: 43.333729434741464
# agent 78 在 449 次迭代中的资源申请量为: 52.62433012099807
# agent 79 在 449 次迭代中的资源申请量为: 45.520582530052934
# agent 80 在 449 次迭代中的资源申请量为: 45.66653311087543
# agent 81 在 449 次迭代中的资源申请量为: 41.86134209055076
# agent 82 在 449 次迭代中的资源申请量为: 48.563243229838726
# agent 83 在 449 次迭代中的资源申请量为: 44.148380988332505
# agent 84 在 449 次迭代中的资源申请量为: 55.31308401517966
# agent 85 在 449 次迭代中的资源申请量为: 59.161946520937384
# agent 86 在 449 次迭代中的资源申请量为: 51.95847113450633
# agent 87 在 449 次迭代中的资源申请量为: 64.20099110295396
# agent 88 在 449 次迭代中的资源申请量为: 69.19083859803345
# agent 89 在 449 次迭代中的资源申请量为: 43.046169983869596
# agent 90 在 449 次迭代中的资源申请量为: 62.939237141058264
# agent 91 在 449 次迭代中的资源申请量为: 45.572773781891726
# agent 92 在 449 次迭代中的资源申请量为: 60.41570575546783
# agent 93 在 449 次迭代中的资源申请量为: 43.24367637046031
# agent 94 在 449 次迭代中的资源申请量为: 77.7225811298047
# agent 95 在 449 次迭代中的资源申请量为: 64.09412830569948
# agent 96 在 449 次迭代中的资源申请量为: 64.24731664713572
# agent 97 在 449 次迭代中的资源申请量为: 76.65926510381313
# agent 98 在 449 次迭代中的资源申请量为: 77.53675281809171
# agent 99 在 449 次迭代中的资源申请量为: 55.664701509108845
# agent 100 在 449 次迭代中的资源申请量为: 51.51963668530961
# 资源申请量总和为: 5000.0000000000055
# ****************************************************************************
# 成本总和为: 409972.4258188731
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 499 次迭代中的结果：
# agent 1 在 499 次迭代中的资源申请量为: 51.799772653236985
# agent 2 在 499 次迭代中的资源申请量为: 65.26440052024307
# agent 3 在 499 次迭代中的资源申请量为: 46.81184941438315
# agent 4 在 499 次迭代中的资源申请量为: 69.10868450534376
# agent 5 在 499 次迭代中的资源申请量为: 69.90013977230517
# agent 6 在 499 次迭代中的资源申请量为: 77.1342538948137
# agent 7 在 499 次迭代中的资源申请量为: 42.185881860842535
# agent 8 在 499 次迭代中的资源申请量为: -84.02922210514438
# agent 9 在 499 次迭代中的资源申请量为: 46.14433049821561
# agent 10 在 499 次迭代中的资源申请量为: 59.751756415286216
# agent 11 在 499 次迭代中的资源申请量为: 48.70652069990589
# agent 12 在 499 次迭代中的资源申请量为: 52.78269737399214
# agent 13 在 499 次迭代中的资源申请量为: 70.42893110956108
# agent 14 在 499 次迭代中的资源申请量为: 59.140062267784224
# agent 15 在 499 次迭代中的资源申请量为: 46.51502473059803
# agent 16 在 499 次迭代中的资源申请量为: 46.696717227628575
# agent 17 在 499 次迭代中的资源申请量为: 48.07878374320896
# agent 18 在 499 次迭代中的资源申请量为: 49.69807331733155
# agent 19 在 499 次迭代中的资源申请量为: 44.19075843460344
# agent 20 在 499 次迭代中的资源申请量为: 59.7112515434996
# agent 21 在 499 次迭代中的资源申请量为: -89.37776288657528
# agent 22 在 499 次迭代中的资源申请量为: 41.791811212757956
# agent 23 在 499 次迭代中的资源申请量为: 51.20421315409913
# agent 24 在 499 次迭代中的资源申请量为: 43.34356011373646
# agent 25 在 499 次迭代中的资源申请量为: 48.36901606013384
# ...
# agent 88 在 1969 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1969 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1969 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1969 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1969 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1969 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1969 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1969 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1969 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1969 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1969 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1969 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1969 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1979 次迭代中的结果：
# agent 1 在 1979 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1979 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1979 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1979 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1979 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1979 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1979 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1979 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1979 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1979 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1979 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1979 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1979 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1979 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1979 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1979 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1979 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1979 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1979 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1979 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1979 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1979 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1979 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1979 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1979 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1979 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1979 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1979 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1979 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1979 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1979 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1979 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1979 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1979 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1979 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1979 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1979 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1979 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1979 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1979 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1979 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1979 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1979 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1979 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1979 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1979 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1979 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1979 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1979 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1979 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1979 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1979 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1979 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1979 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1979 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1979 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1979 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1979 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1979 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1979 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1979 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1979 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1979 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1979 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1979 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1979 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1979 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1979 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1979 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1979 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1979 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1979 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1979 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1979 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1979 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1979 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1979 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1979 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1979 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1979 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1979 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1979 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1979 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1979 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1979 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1979 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1979 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1979 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1979 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1979 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1979 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1979 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1979 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1979 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1979 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1979 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1979 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1989 次迭代中的结果：
# agent 1 在 1989 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1989 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1989 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1989 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1989 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1989 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1989 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1989 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1989 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1989 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1989 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1989 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1989 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1989 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1989 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1989 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1989 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1989 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1989 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1989 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1989 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1989 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1989 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1989 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1989 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1989 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1989 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1989 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1989 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1989 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1989 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1989 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1989 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1989 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1989 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1989 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1989 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1989 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1989 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1989 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1989 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1989 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1989 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1989 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1989 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1989 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1989 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1989 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1989 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1989 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1989 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1989 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1989 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1989 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1989 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1989 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1989 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1989 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1989 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1989 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1989 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1989 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1989 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1989 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1989 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1989 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1989 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1989 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1989 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1989 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1989 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1989 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1989 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1989 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1989 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1989 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1989 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1989 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1989 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1989 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1989 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1989 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1989 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1989 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1989 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1989 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1989 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1989 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1989 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1989 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1989 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1989 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1989 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1989 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1989 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1989 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1989 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1999 次迭代中的结果：
# agent 1 在 1999 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1999 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1999 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1999 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1999 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1999 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1999 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1999 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1999 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1999 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1999 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1999 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1999 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1999 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1999 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1999 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1999 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1999 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1999 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1999 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1999 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1999 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1999 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1999 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1999 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1999 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1999 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1999 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1999 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1999 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1999 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1999 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1999 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1999 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1999 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1999 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1999 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1999 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1999 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1999 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1999 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1999 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1999 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1999 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1999 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1999 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1999 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1999 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1999 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1999 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1999 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1999 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1999 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1999 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1999 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1999 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1999 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1999 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1999 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1999 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1999 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1999 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1999 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1999 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1999 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1999 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1999 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1999 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1999 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1999 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1999 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1999 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1999 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1999 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1999 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1999 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1999 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1999 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1999 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1999 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1999 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1999 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1999 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1999 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1999 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1999 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1999 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1999 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1999 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1999 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1999 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1999 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1999 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1999 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1999 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1999 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1999 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 2025-01-21 17:21:01.305

# %%
np.savetxt('../data/02-agent_resource_quantity_unbounded_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/02-sum_cost_unbounded_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/02-sum_resource_unbounded_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
np.savetxt('../data/02-agent_gradient_unbounded_bias.txt',agent_gradient,fmt='%0.8f')#用户迭代梯度
