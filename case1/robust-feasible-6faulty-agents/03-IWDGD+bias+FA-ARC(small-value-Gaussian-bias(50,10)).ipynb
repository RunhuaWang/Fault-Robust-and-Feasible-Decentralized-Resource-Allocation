# %% [raw]
# 服从小值高斯分布的噪声

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(100,1000), dtype=np.float64) 
sum_resource=np.zeros(shape=(1,1000), dtype=np.float64)
sum_cost=np.zeros(shape=(1,1000), dtype=np.float64)
iteration_update = 0.01
A=np.loadtxt("100_Network_Topology_Double_Random_Adjacency_Matrix_Degree_15.txt") #网络拓扑的邻接矩阵 对角元素要为0
D=np.zeros(shape=(100,100))# 网络的度矩阵
L=np.zeros(shape=(100,100))# 网络的拉普拉斯矩阵 L=D-A
W=np.zeros(shape=(100,100)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
iteration=[]
a=np.loadtxt("100_uniform_distribution_(1,2)_point1.txt")
b=np.loadtxt("100_normal_distribution_(2,0.6)_point1.txt")
agent_gradient=np.zeros(shape=(100,1000), dtype=np.float64) 
bias=np.loadtxt("1000_Gaussian_distribution_(50,10).txt")
C=np.zeros(shape=(1,1000), dtype=np.float64)#adaptive robust clipping的裁剪参数 
#设置为全局第b大的梯度信息 b为网络中设备损坏的用户上界 每一次迭代就需要计算一次新的C值

# %%
#根据邻接矩阵生成网络对应的度矩阵
for i in range(0,100):
    d=0
    for j in range(0,100):
        if A[i][j]==1:
            d=d+1
    D[i][i]=d

#根据邻接矩阵和度矩阵计算拉普拉斯矩阵
L=D-A

#选择用拉普拉斯矩阵作为聚合矩阵
W=L
    
#资源量的初始化 需要给定可行的初始化 即满足平均资源约束
for i in range (0,100):
    agent_resource_quantity[i][0]=50
    
#资源量总和 初始化
sum=0
for i in range (0,100):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

iteration.append(0)

#初始梯度计算
for i in range (0,100):
    if i==7 or i==20 or i==34 or i==47 or i==52 or i==88:
        agent_gradient[i][0]=2*a[i]*agent_resource_quantity[i][0]-2*a[i]*b[i]+bias[0]
    else:
        agent_gradient[i][0]=2*a[i]*agent_resource_quantity[i][0]-2*a[i]*b[i]
    
#计算初始的C值
column_data = agent_gradient[:, 0]
forth_largest = np.partition(np.abs(column_data), -7)[-7]
C[0][0]=forth_largest

#诚实用户成本总和初始化
sum=0
for i in range(0,100):
    sum=sum+a[i]*(agent_resource_quantity[i][0]-b[i])*(agent_resource_quantity[i][0]-b[i])
sum_cost[0][0]=sum

# %%
#基于初始化的权重梯度下降无中心资源分配算法
def IWDGD_Gaussian_bias_C(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias,C):
    
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************IWDGD算法+计算误差+鲁棒****************************")
    print("相关变量初始值为：")
    for i in range (0,100):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):#迭代次数
        iteration.append(k)
 
        #所有用户资源申请量基于可行初始化权重梯度下降的迭代  假设部分用户因为设备损坏 导致梯度的计算有误差     
        for i in range (0,100):
            weight_gradient_sum = np.float64(0)
            for j in range (0,100):  
                if np.abs(agent_gradient[j][k-1])>C[0][k-1]:
                    weight_gradient_sum=weight_gradient_sum+W[i][j]*(C[0][k-1]/np.abs(agent_gradient[j][k-1])*agent_gradient[j][k-1])
                else:
                    weight_gradient_sum=weight_gradient_sum+W[i][j]*agent_gradient[j][k-1]                   
                #weight_gradient_sum = np.round(weight_gradient_sum, decimals=3)
            agent_resource_quantity[i][k]=agent_resource_quantity[i][k-1]-iteration_update*weight_gradient_sum
                #agent_resource_quantity[i][k] = np.round(agent_resource_quantity[i][k], decimals=3)                      
        
        #计算所有诚实用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,100):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有诚实用户的成本总和
        sum2=np.float64(0)
        for i in range(0,100):
            sum2=sum2+a[i]*(agent_resource_quantity[i][k]-b[i])*(agent_resource_quantity[i][k]-b[i])
        sum_cost[0][k]=sum2
        
        #计算当前迭代的用户梯度
        for i in range (0,100): 
            if i==7 or i==20 or i==34 or i==47 or i==52 or i==88:
                agent_gradient[i][k]=2*a[i]*agent_resource_quantity[i][k]-2*a[i]*b[i]+bias[k]
            else:
                agent_gradient[i][k]=2*a[i]*agent_resource_quantity[i][k]-2*a[i]*b[i]
                
        #计算当前迭代的C值
        column_data = agent_gradient[:, k]
        forth_largest = np.partition(np.abs(column_data), -7)[-7]
        C[0][k]=forth_largest
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%50==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,100):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=1/(pow(k+1,0.05)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
IWDGD_Gaussian_bias_C(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias,C)
# Out:
# ****************************IWDGD算法+计算误差+鲁棒****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 50.0
# agent 2 的初始资源申请量为: 50.0
# agent 3 的初始资源申请量为: 50.0
# agent 4 的初始资源申请量为: 50.0
# agent 5 的初始资源申请量为: 50.0
# agent 6 的初始资源申请量为: 50.0
# agent 7 的初始资源申请量为: 50.0
# agent 8 的初始资源申请量为: 50.0
# agent 9 的初始资源申请量为: 50.0
# agent 10 的初始资源申请量为: 50.0
# agent 11 的初始资源申请量为: 50.0
# agent 12 的初始资源申请量为: 50.0
# agent 13 的初始资源申请量为: 50.0
# agent 14 的初始资源申请量为: 50.0
# agent 15 的初始资源申请量为: 50.0
# agent 16 的初始资源申请量为: 50.0
# agent 17 的初始资源申请量为: 50.0
# agent 18 的初始资源申请量为: 50.0
# agent 19 的初始资源申请量为: 50.0
# agent 20 的初始资源申请量为: 50.0
# agent 21 的初始资源申请量为: 50.0
# agent 22 的初始资源申请量为: 50.0
# agent 23 的初始资源申请量为: 50.0
# agent 24 的初始资源申请量为: 50.0
# agent 25 的初始资源申请量为: 50.0
# agent 26 的初始资源申请量为: 50.0
# agent 27 的初始资源申请量为: 50.0
# agent 28 的初始资源申请量为: 50.0
# agent 29 的初始资源申请量为: 50.0
# agent 30 的初始资源申请量为: 50.0
# agent 31 的初始资源申请量为: 50.0
# agent 32 的初始资源申请量为: 50.0
# agent 33 的初始资源申请量为: 50.0
# agent 34 的初始资源申请量为: 50.0
# agent 35 的初始资源申请量为: 50.0
# agent 36 的初始资源申请量为: 50.0
# agent 37 的初始资源申请量为: 50.0
# agent 38 的初始资源申请量为: 50.0
# agent 39 的初始资源申请量为: 50.0
# agent 40 的初始资源申请量为: 50.0
# agent 41 的初始资源申请量为: 50.0
# agent 42 的初始资源申请量为: 50.0
# agent 43 的初始资源申请量为: 50.0
# agent 44 的初始资源申请量为: 50.0
# agent 45 的初始资源申请量为: 50.0
# agent 46 的初始资源申请量为: 50.0
# agent 47 的初始资源申请量为: 50.0
# agent 48 的初始资源申请量为: 50.0
# agent 49 的初始资源申请量为: 50.0
# agent 50 的初始资源申请量为: 50.0
# agent 51 的初始资源申请量为: 50.0
# agent 52 的初始资源申请量为: 50.0
# agent 53 的初始资源申请量为: 50.0
# agent 54 的初始资源申请量为: 50.0
# agent 55 的初始资源申请量为: 50.0
# agent 56 的初始资源申请量为: 50.0
# agent 57 的初始资源申请量为: 50.0
# agent 58 的初始资源申请量为: 50.0
# agent 59 的初始资源申请量为: 50.0
# agent 60 的初始资源申请量为: 50.0
# agent 61 的初始资源申请量为: 50.0
# agent 62 的初始资源申请量为: 50.0
# agent 63 的初始资源申请量为: 50.0
# agent 64 的初始资源申请量为: 50.0
# agent 65 的初始资源申请量为: 50.0
# agent 66 的初始资源申请量为: 50.0
# agent 67 的初始资源申请量为: 50.0
# agent 68 的初始资源申请量为: 50.0
# agent 69 的初始资源申请量为: 50.0
# agent 70 的初始资源申请量为: 50.0
# agent 71 的初始资源申请量为: 50.0
# agent 72 的初始资源申请量为: 50.0
# agent 73 的初始资源申请量为: 50.0
# agent 74 的初始资源申请量为: 50.0
# agent 75 的初始资源申请量为: 50.0
# agent 76 的初始资源申请量为: 50.0
# agent 77 的初始资源申请量为: 50.0
# agent 78 的初始资源申请量为: 50.0
# agent 79 的初始资源申请量为: 50.0
# agent 80 的初始资源申请量为: 50.0
# agent 81 的初始资源申请量为: 50.0
# agent 82 的初始资源申请量为: 50.0
# agent 83 的初始资源申请量为: 50.0
# agent 84 的初始资源申请量为: 50.0
# agent 85 的初始资源申请量为: 50.0
# agent 86 的初始资源申请量为: 50.0
# agent 87 的初始资源申请量为: 50.0
# agent 88 的初始资源申请量为: 50.0
# agent 89 的初始资源申请量为: 50.0
# agent 90 的初始资源申请量为: 50.0
# agent 91 的初始资源申请量为: 50.0
# agent 92 的初始资源申请量为: 50.0
# agent 93 的初始资源申请量为: 50.0
# agent 94 的初始资源申请量为: 50.0
# agent 95 的初始资源申请量为: 50.0
# agent 96 的初始资源申请量为: 50.0
# agent 97 的初始资源申请量为: 50.0
# agent 98 的初始资源申请量为: 50.0
# agent 99 的初始资源申请量为: 50.0
# agent 100 的初始资源申请量为: 50.0
# *************************
# 初始资源申请量总和为: 5000.0
# *************************
# 初始成本总和为: 346654.5889999999
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 49 次迭代中的结果：
# agent 1 在 49 次迭代中的资源申请量为: 48.568586534820405
# agent 2 在 49 次迭代中的资源申请量为: 61.18562037779664
# agent 3 在 49 次迭代中的资源申请量为: 43.95456443943868
# agent 4 在 49 次迭代中的资源申请量为: 64.71164027207762
# agent 5 在 49 次迭代中的资源申请量为: 65.51143080326072
# agent 6 在 49 次迭代中的资源申请量为: 72.3021151051054
# agent 7 在 49 次迭代中的资源申请量为: 39.601401432017475
# agent 8 在 49 次迭代中的资源申请量为: 33.31756093806468
# agent 9 在 49 次迭代中的资源申请量为: 43.25452311611115
# agent 10 在 49 次迭代中的资源申请量为: 55.979046666910065
# agent 11 在 49 次迭代中的资源申请量为: 45.63921159273948
# agent 12 在 49 次迭代中的资源申请量为: 49.46852949101411
# agent 13 在 49 次迭代中的资源申请量为: 66.0115356155776
# agent 14 在 49 次迭代中的资源申请量为: 55.37908346032087
# agent 15 在 49 次迭代中的资源申请量为: 43.654599129160815
# agent 16 在 49 次迭代中的资源申请量为: 43.854473073510796
# agent 17 在 49 次迭代中的资源申请量为: 45.03923010924614
# agent 18 在 49 次迭代中的资源申请量为: 46.63908451330787
# agent 19 在 49 次迭代中的资源申请量为: 41.45705155293805
# agent 20 在 49 次迭代中的资源申请量为: 55.87899711711598
# agent 21 在 49 次迭代中的资源申请量为: 31.549115719023977
# agent 22 在 49 次迭代中的资源申请量为: 39.201438145220436
# agent 23 在 49 次迭代中的资源申请量为: 47.968533147428865
# agent 24 在 49 次迭代中的资源申请量为: 40.6570898347084
# agent 25 在 49 次迭代中的资源申请量为: 45.33923984044966
# agent 26 在 49 次迭代中的资源申请量为: 39.90145740386022
# agent 27 在 49 次迭代中的资源申请量为: 65.71166909061043
# agent 28 在 49 次迭代中的资源申请量为: 51.516190347728084
# agent 29 在 49 次迭代中的资源申请量为: 40.95708609198117
# agent 30 在 49 次迭代中的资源申请量为: 39.301480928238654
# agent 31 在 49 次迭代中的资源申请量为: 60.58561769749278
# agent 32 在 49 次迭代中的资源申请量为: 55.679125770078606
# agent 33 在 49 次迭代中的资源申请量为: 41.757050127890054
# agent 34 在 49 次迭代中的资源申请量为: 52.41635638024717
# agent 35 在 49 次迭代中的资源申请量为: 30.095269196926875
# agent 36 在 49 次迭代中的资源申请量为: 42.954451712794224
# agent 37 在 49 次迭代中的资源申请量为: 52.71618520477577
# agent 38 在 49 次迭代中的资源申请量为: 40.457098110707584
# agent 39 在 49 次迭代中的资源申请量为: 43.45447144869482
# agent 40 在 49 次迭代中的资源申请量为: 50.268423201122744
# agent 41 在 49 次迭代中的资源申请量为: 66.41129627374998
# agent 42 在 49 次迭代中的资源申请量为: 42.654535985399704
# agent 43 在 49 次迭代中的资源申请量为: 51.91610884117365
# agent 44 在 49 次迭代中的资源申请量为: 53.11618497153453
# agent 45 在 49 次迭代中的资源申请量为: 48.36850639181048
# agent 46 在 49 次迭代中的资源申请量为: 55.978929174075994
# agent 47 在 49 次迭代中的资源申请量为: 46.03915986129469
# agent 48 在 49 次迭代中的资源申请量为: 32.88484505560815
# agent 49 在 49 次迭代中的资源申请量为: 42.85447376069786
# agent 50 在 49 次迭代中的资源申请量为: 41.057009168135714
# agent 51 在 49 次迭代中的资源申请量为: 48.4683905137663
# agent 52 在 49 次迭代中的资源申请量为: 55.878980260820725
# agent 53 在 49 次迭代中的资源申请量为: 30.86911334709455
# agent 54 在 49 次迭代中的资源申请量为: 57.07904754157766
# agent 55 在 49 次迭代中的资源申请量为: 71.20271117174296
# agent 56 在 49 次迭代中的资源申请量为: 41.05707996595668
# agent 57 在 49 次迭代中的资源申请量为: 60.585750024932956
# agent 58 在 49 次迭代中的资源申请量为: 42.35459002109703
# agent 59 在 49 次迭代中的资源申请量为: 48.06852667317065
# agent 60 在 49 次迭代中的资源申请量为: 56.17883787709387
# agent 61 在 49 次迭代中的资源申请量为: 66.1112173624561
# agent 62 在 49 次迭代中的资源申请量为: 46.239083594455664
# agent 63 在 49 次迭代中的资源申请量为: 39.10138549001507
# agent 64 在 49 次迭代中的资源申请量为: 44.5391542685624
# agent 65 在 49 次迭代中的资源申请量为: 42.85450247908653
# agent 66 在 49 次迭代中的资源申请量为: 65.81142969984715
# agent 67 在 49 次迭代中的资源申请量为: 43.45447737566331
# agent 68 在 49 次迭代中的资源申请量为: 45.03910328211309
# agent 69 在 49 次迭代中的资源申请量为: 45.53908830111105
# agent 70 在 49 次迭代中的资源申请量为: 60.18555554102294
# agent 71 在 49 次迭代中的资源申请量为: 72.20255744490551
# agent 72 在 49 次迭代中的资源申请量为: 60.38557574617669
# agent 73 在 49 次迭代中的资源申请量为: 43.85447730228082
# agent 74 在 49 次迭代中的资源申请量为: 39.10142600920915
# agent 75 在 49 次迭代中的资源申请量为: 52.11617352038544
# agent 76 在 49 次迭代中的资源申请量为: 47.139162936527555
# agent 77 在 49 次迭代中的资源申请量为: 40.95704765434921
# agent 78 在 49 次迭代中的资源申请量为: 49.768479172782214
# agent 79 在 49 次迭代中的资源申请量为: 42.954495767998196
# agent 80 在 49 次迭代中的资源申请量为: 43.154504660393705
# agent 81 在 49 次迭代中的资源申请量为: 39.601472373170544
# agent 82 在 49 次迭代中的资源申请量为: 45.8392198616964
# agent 83 在 49 次迭代中的资源申请量为: 41.75705259841366
# agent 84 在 49 次迭代中的资源申请量为: 52.216160752393506
# agent 85 在 49 次迭代中的资源申请量为: 55.87886150241404
# agent 86 在 49 次迭代中的资源申请量为: 49.06850830734905
# agent 87 在 49 次迭代中的资源申请量为: 60.58560398742981
# agent 88 在 49 次迭代中的资源申请量为: 65.31112412559284
# agent 89 在 49 次迭代中的资源申请量为: 30.473647752802236
# agent 90 在 49 次迭代中的资源申请量为: 59.38542851189055
# agent 91 在 49 次迭代中的资源申请量为: 43.05446535028098
# agent 92 在 49 次迭代中的资源申请量为: 57.07904863243197
# agent 93 在 49 次迭代中的资源申请量为: 40.85710153716246
# agent 94 在 49 次迭代中的资源申请量为: 73.40273009965567
# agent 95 在 49 次迭代中的资源申请量为: 60.485492750171026
# agent 96 在 49 次迭代中的资源申请量为: 60.685528331263406
# agent 97 在 49 次迭代中的资源申请量为: 72.40250687966474
# agent 98 在 49 次迭代中的资源申请量为: 73.2027039396001
# agent 99 在 49 次迭代中的资源申请量为: 52.61619474132114
# agent 100 在 49 次迭代中的资源申请量为: 48.6685387347048
# 资源申请量总和为: 5000.000000000001
# ****************************************************************************
# 成本总和为: 334855.20681663335
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: 48.550757257711915
# agent 2 在 99 次迭代中的资源申请量为: 61.16462996189813
# agent 3 在 99 次迭代中的资源申请量为: 43.93978594958179
# agent 4 在 99 次迭代中的资源申请量为: 64.68991457427259
# agent 5 在 99 次迭代中的资源申请量为: 65.48802016536173
# agent 6 在 99 次迭代中的资源申请量为: 72.27178399439839
# agent 7 在 99 次迭代中的资源申请量为: 39.58766596442469
# agent 8 在 99 次迭代中的资源申请量为: 33.222431788676374
# agent 9 在 99 次迭代中的资源申请量为: 43.238196728659005
# agent 10 在 99 次迭代中的资源申请量为: 55.96003153528833
# agent 11 在 99 次迭代中的资源申请量为: 45.62344243372387
# agent 12 在 99 次迭代中的资源申请量为: 49.450300583674014
# agent 13 在 99 次迭代中的资源申请量为: 65.98552703462612
# agent 14 在 99 次迭代中的资源申请量为: 55.36047557227699
# agent 15 在 99 次迭代中的资源申请量为: 43.64042338098502
# agent 16 在 99 次迭代中的资源申请量为: 43.83947201384948
# agent 17 在 99 次迭代中的资源申请量为: 45.021713437349725
# agent 18 在 99 次迭代中的资源申请量为: 46.62285196963723
# agent 19 在 99 次迭代中的资源申请量为: 41.44221693235477
# agent 20 在 99 次迭代中的资源申请量为: 55.85831150120395
# agent 21 在 99 次迭代中的资源申请量为: 31.516599116826875
# agent 22 在 99 次迭代中的资源申请量为: 39.18769269001108
# agent 23 在 99 次迭代中的资源申请量为: 47.95156310989568
# agent 24 在 99 次迭代中的资源申请量为: 40.64289285613984
# agent 25 在 99 次迭代中的资源申请量为: 45.324200905461176
# agent 26 在 99 次迭代中的资源申请量为: 39.888234128596906
# agent 27 在 99 次迭代中的资源申请量为: 65.68942103276437
# agent 28 在 99 次迭代中的资源申请量为: 51.49715300447171
# agent 29 在 99 次迭代中的资源申请量为: 40.94306689539796
# agent 30 在 99 次迭代中的资源申请量为: 39.28824261884848
# agent 31 在 99 次迭代中的资源申请量为: 60.563992490331096
# agent 32 在 99 次迭代中的资源申请量为: 55.66076798344404
# agent 33 在 99 次迭代中的资源申请量为: 41.74259103891516
# agent 34 在 99 次迭代中的资源申请量为: 52.398463268383
# agent 35 在 99 次迭代中的资源申请量为: 30.325444442847115
# agent 36 在 99 次迭代中的资源申请量为: 42.937685222822374
# agent 37 在 99 次迭代中的资源申请量为: 52.69770699651828
# agent 38 在 99 次迭代中的资源申请量为: 40.44357261715116
# agent 39 在 99 次迭代中的资源申请量为: 43.4389754099137
# agent 40 在 99 次迭代中的资源申请量为: 50.2505799921952
# agent 41 在 99 次迭代中的资源申请量为: 66.38373472235219
# agent 42 在 99 次迭代中的资源申请量为: 42.639700284004704
# agent 43 在 99 次迭代中的资源申请量为: 51.897619596296224
# agent 44 在 99 次迭代中的资源申请量为: 53.09876841755267
# agent 45 在 99 次迭代中的资源申请量为: 48.35202742078622
# agent 46 在 99 次迭代中的资源申请量为: 55.956671336088455
# agent 47 在 99 次迭代中的资源申请量为: 46.021484316752044
# agent 48 在 99 次迭代中的资源申请量为: 33.68192251144097
# agent 49 在 99 次迭代中的资源申请量为: 42.83859990329687
# agent 50 在 99 次迭代中的资源申请量为: 41.04287579474697
# agent 51 在 99 次迭代中的资源申请量为: 48.44917518149828
# agent 52 在 99 次迭代中的资源申请量为: 55.85952305684616
# agent 53 在 99 次迭代中的资源申请量为: 30.845211208225145
# agent 54 在 99 次迭代中的资源申请量为: 57.059704034445424
# agent 55 在 99 次迭代中的资源申请量为: 71.17850236254608
# agent 56 在 99 次迭代中的资源申请量为: 41.0438218345778
# agent 57 在 99 次迭代中的资源申请量为: 60.56524854946531
# agent 58 在 99 次迭代中的资源申请量为: 42.33961273591888
# agent 59 在 99 次迭代中的资源申请量为: 48.052247235944584
# agent 60 在 99 次迭代中的资源申请量为: 56.15659438429774
# agent 61 在 99 次迭代中的资源申请量为: 66.08462583807278
# agent 62 在 99 次迭代中的资源申请量为: 46.22089145484173
# agent 63 在 99 次迭代中的资源申请量为: 39.0871809191121
# agent 64 在 99 次迭代中的资源申请量为: 44.52192276777138
# agent 65 在 99 次迭代中的资源申请量为: 42.83931561386751
# agent 66 在 99 次迭代中的资源申请量为: 65.7875197351522
# agent 67 在 99 次迭代中的资源申请量为: 43.43878779179644
# agent 68 在 99 次迭代中的资源申请量为: 45.02245872754902
# agent 69 在 99 次迭代中的资源申请量为: 45.52277098954065
# agent 70 在 99 次迭代中的资源申请量为: 60.16375128238783
# agent 71 在 99 次迭代中的资源申请量为: 72.17764104858281
# agent 72 在 99 次迭代中的资源申请量为: 60.36411479232905
# agent 73 在 99 次迭代中的资源申请量为: 43.83822700519464
# agent 74 在 99 次迭代中的资源申请量为: 39.08734699802666
# agent 75 在 99 次迭代中的资源申请量为: 52.095898656496225
# agent 76 在 99 次迭代中的资源申请量为: 47.12231484042906
# agent 77 在 99 次迭代中的资源申请量为: 40.94147719456639
# agent 78 在 99 次迭代中的资源申请量为: 49.750860165540125
# agent 79 在 99 次迭代中的资源申请量为: 42.938946942749396
# agent 80 在 99 次迭代中的资源申请量为: 43.13880196707543
# agent 81 在 99 次迭代中的资源申请量为: 39.5876950954162
# agent 82 在 99 次迭代中的资源申请量为: 45.822323365598876
# agent 83 在 99 次迭代中的资源申请量为: 41.74245414255059
# agent 84 在 99 次迭代中的资源申请量为: 52.19546401428893
# agent 85 在 99 次迭代中的资源申请量为: 55.857906141446385
# agent 86 在 99 次迭代中的资源申请量为: 49.05174464067404
# agent 87 在 99 次迭代中的资源申请量为: 60.56416410099401
# agent 88 在 99 次迭代中的资源申请量为: 65.28073818563148
# agent 89 在 99 次迭代中的资源申请量为: 31.34593332146867
# agent 90 在 99 次迭代中的资源申请量为: 59.36037390498298
# agent 91 在 99 次迭代中的资源申请量为: 43.03902561974336
# agent 92 在 99 次迭代中的资源申请量为: 57.059513667091885
# agent 93 在 99 次迭代中的资源申请量为: 40.84303803603105
# agent 94 在 99 次迭代中的资源申请量为: 73.37395360216138
# agent 95 在 99 次迭代中的资源申请量为: 60.46052868407759
# agent 96 在 99 次迭代中的资源申请量为: 60.66118402977172
# agent 97 在 99 次迭代中的资源申请量为: 72.37636802616619
# agent 98 在 99 次迭代中的资源申请量为: 73.17227551868561
# agent 99 在 99 次迭代中的资源申请量为: 52.597957880572544
# agent 100 在 99 次迭代中的资源申请量为: 48.65265980359291
# 资源申请量总和为: 5000.000000000001
# ****************************************************************************
# 成本总和为: 334792.5228912992
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 149 次迭代中的结果：
# agent 1 在 149 次迭代中的资源申请量为: 48.50240709560086
# agent 2 在 149 次迭代中的资源申请量为: 61.103192222557624
# agent 3 在 149 次迭代中的资源申请量为: 43.89626176340999
# agent 4 在 149 次迭代中的资源申请量为: 64.62156059882619
# agent 5 在 149 次迭代中的资源申请量为: 65.42148636526005
# agent 6 在 149 次迭代中的资源申请量为: 72.20294438079829
# agent 7 在 149 次迭代中的资源申请量为: 39.5492262191962
# agent 8 在 149 次迭代中的资源申请量为: 33.00746719010411
# agent 9 在 149 次迭代中的资源申请量为: 43.196260196044726
# agent 10 在 149 次迭代中的资源申请量为: 55.90286588746345
# agent 11 在 149 次迭代中的资源申请量为: 45.57726557861215
# agent 12 在 149 次迭代中的资源申请量为: 49.402314217009724
# agent 13 在 149 次迭代中的资源申请量为: 65.92111847096353
# agent 14 在 149 次迭代中的资源申请量为: 55.303133142739945
# agent 15 在 149 次迭代中的资源申请量为: 43.59626691668019
# agent 16 在 149 次迭代中的资源申请量为: 43.796208617822195
# agent 17 在 149 次迭代中的资源申请量为: 44.97718255280968
# agent 18 在 149 次迭代中的资源申请量为: 46.577237876391365
# agent 19 在 149 次迭代中的资源申请量为: 41.40191165082666
# agent 20 在 149 次迭代中的资源申请量为: 55.80247622765228
# agent 21 在 149 次迭代中的资源申请量为: 31.72315781301152
# agent 22 在 149 次迭代中的资源申请量为: 39.1492373522514
# agent 23 在 149 次迭代中的资源申请量为: 47.902486779260514
# agent 24 在 149 次迭代中的资源申请量为: 40.60211215758751
# agent 25 在 149 次迭代中的资源申请量为: 45.2773440661141
# agent 26 在 149 次迭代中的资源申请量为: 39.84934285221194
# agent 27 在 149 次迭代中的资源申请量为: 65.62188218476906
# agent 28 在 149 次迭代中的资源申请量为: 51.44527068474152
# agent 29 在 149 次迭代中的资源申请量为: 40.90199694725189
# agent 30 在 149 次迭代中的资源申请量为: 39.249290881771856
# agent 31 在 149 次迭代中的资源申请量为: 60.502982419703834
# agent 32 在 149 次迭代中的资源申请量为: 55.60305013960284
# agent 33 在 149 次迭代中的资源申请量为: 41.70191189780967
# agent 34 在 149 次迭代中的资源申请量为: 52.3453316899471
# agent 35 在 149 次迭代中的资源申请量为: 31.510821271478413
# agent 36 在 149 次迭代中的资源申请量为: 42.89608921360968
# agent 37 在 149 次迭代中的资源申请量为: 52.64538464002145
# agent 38 在 149 次迭代中的资源申请量为: 40.40204255955637
# agent 39 在 149 次迭代中的资源申请量为: 43.396187725247785
# agent 40 在 149 次迭代中的资源申请量为: 50.202217099229294
# agent 41 在 149 次迭代中的资源申请量为: 66.32076113810028
# agent 42 在 149 次迭代中的资源申请量为: 42.596227183260496
# agent 43 在 149 次迭代中的资源申请量为: 51.84533770947132
# agent 44 在 149 次迭代中的资源申请量为: 53.045515792335486
# agent 45 在 149 次迭代中的资源申请量为: 48.30246434687918
# agent 46 在 149 次迭代中的资源申请量为: 55.902578038101126
# agent 47 在 149 次迭代中的资源申请量为: 45.97727503922426
# agent 48 在 149 次迭代中的资源申请量为: 35.075139429985626
# agent 49 在 149 次迭代中的资源申请量为: 42.79622254038429
# agent 50 在 149 次迭代中的资源申请量为: 41.00201797067975
# agent 51 在 149 次迭代中的资源申请量为: 48.40222257385541
# agent 52 在 149 次迭代中的资源申请量为: 55.80266711172717
# agent 53 在 149 次迭代中的资源申请量为: 31.713936701424768
# agent 54 在 149 次迭代中的资源申请量为: 57.00290511147593
# agent 55 在 149 次迭代中的资源申请量为: 71.10382225603956
# agent 56 在 149 次迭代中的资源申请量为: 41.00206545112159
# agent 57 在 149 次迭代中的资源申请量为: 60.50281150806988
# agent 58 在 149 次迭代中的资源申请量为: 42.29624260522782
# agent 59 在 149 次迭代中的资源申请量为: 48.00242041757193
# agent 60 在 149 次迭代中的资源申请量为: 56.10273505044451
# agent 61 在 149 次迭代中的资源申请量为: 66.02126133332439
# agent 62 在 149 次迭代中的资源申请量为: 46.17720162318393
# agent 63 在 149 次迭代中的资源申请量为: 39.04921519463121
# agent 64 在 149 次迭代中的资源申请量为: 44.47703155552005
# agent 65 在 149 次迭代中的资源申请量为: 42.79619602581212
# agent 66 在 149 次迭代中的资源申请量为: 65.72106537826863
# agent 67 在 149 次迭代中的资源申请量为: 43.396153697116915
# agent 68 在 149 次迭代中的资源申请量为: 44.97714028892735
# agent 69 在 149 次迭代中的资源申请量为: 45.477185192368424
# agent 70 在 149 次迭代中的资源申请量为: 60.10287006784568
# agent 71 在 149 次迭代中的资源申请量为: 72.10333059734975
# agent 72 在 149 次迭代中的资源申请量为: 60.30301402356137
# agent 73 在 149 次迭代中的资源申请量为: 43.796233843023735
# agent 74 在 149 次迭代中的资源申请量为: 39.04929590756642
# agent 75 在 149 次迭代中的资源申请量为: 52.045465302316636
# agent 76 在 149 次迭代中的资源申请量为: 47.07725905218206
# agent 77 在 149 次迭代中的资源申请量为: 40.90205183226013
# agent 78 在 149 次迭代中的资源申请量为: 49.70235548619444
# agent 79 在 149 次迭代中的资源申请量为: 42.89625594868352
# agent 80 在 149 次迭代中的资源申请量为: 43.09620909742593
# agent 81 在 149 次迭代中的资源申请量为: 39.549348777952964
# agent 82 在 149 次迭代中的资源申请量为: 45.77709707494567
# agent 83 在 149 次迭代中的资源申请量为: 41.70200883721001
# agent 84 在 149 次迭代中的资源申请量为: 52.14531903758257
# agent 85 在 149 次迭代中的资源申请量为: 55.802698996343445
# agent 86 在 149 次迭代中的资源申请量为: 49.00239174264788
# agent 87 在 149 次迭代中的资源申请量为: 60.502842427195326
# agent 88 在 149 次迭代中的资源申请量为: 65.22066004164125
# agent 89 在 149 次迭代中的资源申请量为: 32.68111478396878
# agent 90 在 149 次迭代中的资源申请量为: 59.30282440639162
# agent 91 在 149 次迭代中的资源申请量为: 42.9962136774441
# agent 92 在 149 次迭代中的资源申请量为: 57.00281162959625
# agent 93 在 149 次迭代中的资源申请量为: 40.80197697079049
# agent 94 在 149 次迭代中的资源申请量为: 73.30375302683004
# agent 95 在 149 次迭代中的资源申请量为: 60.402880820198625
# agent 96 在 149 次迭代中的资源申请量为: 60.602717935884364
# agent 97 在 149 次迭代中的资源申请量为: 72.30344768706694
# agent 98 在 149 次迭代中的资源申请量为: 73.10291710943699
# agent 99 在 149 次迭代中的资源申请量为: 52.5454471800383
# agent 100 在 149 次迭代中的资源申请量为: 48.602440867944246
# 资源申请量总和为: 5000.000000000001
# ****************************************************************************
# 成本总和为: 334644.23595484276
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: 48.482137798945075
# agent 2 在 199 次迭代中的资源申请量为: 61.07767189459086
# agent 3 在 199 次迭代中的资源申请量为: 43.87835668730931
# agent 4 在 199 次迭代中的资源申请量为: 64.59382295191259
# agent 5 在 199 次迭代中的资源申请量为: 65.39382281611874
# agent 6 在 199 次迭代中的资源申请量为: 72.17320379522715
# agent 7 在 199 次迭代中的资源申请量为: 39.53326640516194
# agent 8 在 199 次迭代中的资源申请量为: 32.92511233816278
# agent 9 在 199 次迭代中的资源申请量为: 43.178356813235844
# agent 10 在 199 次迭代中的资源申请量为: 55.87938956261348
# agent 11 在 199 次迭代中的资源申请量为: 45.558253644954995
# agent 12 在 199 次迭代中的资源申请量为: 49.38213766570617
# agent 13 在 199 次迭代中的资源申请量为: 65.89382448449992
# agent 14 在 199 次迭代中的资源申请量为: 55.27939004708512
# agent 15 在 199 次迭代中的资源申请量为: 43.57835655179701
# agent 16 在 199 次迭代中的资源申请量为: 43.77835616496776
# agent 17 在 199 次迭代中的资源申请量为: 44.9582542483235
# agent 18 在 199 次迭代中的资源申请量为: 46.558253595415394
# agent 19 在 199 次迭代中的资源申请量为: 41.38511480419076
# agent 20 在 199 次迭代中的资源申请量为: 55.77938916455103
# agent 21 在 199 次迭代中的资源申请量为: 31.99891552291514
# agent 22 在 199 次迭代中的资源申请量为: 39.13326641113418
# agent 23 在 199 次迭代中的资源申请量为: 47.882137823210876
# agent 24 在 199 次迭代中的资源申请量为: 40.58511484474922
# agent 25 在 199 次迭代中的资源申请量为: 45.258253991503814
# agent 26 在 199 次迭代中的资源申请量为: 39.83326676153297
# agent 27 在 199 次迭代中的资源申请量为: 65.5938251877163
# agent 28 在 199 次迭代中的资源申请量为: 51.4237187272849
# agent 29 在 199 次迭代中的资源申请量为: 40.885114896855406
# agent 30 在 199 次迭代中的资源申请量为: 39.23326679006564
# agent 31 在 199 次迭代中的资源申请量为: 60.477672243019235
# agent 32 在 199 次迭代中的资源申请量为: 55.579389808306175
# agent 33 在 199 次迭代中的资源申请量为: 41.68511465907574
# agent 34 在 199 次迭代中的资源申请量为: 52.323719110324376
# agent 35 在 199 次迭代中的资源申请量为: 31.945438885372067
# agent 36 在 199 次迭代中的资源申请量为: 42.87835639864015
# agent 37 在 199 次迭代中的资源申请量为: 52.623718400290485
# agent 38 在 199 次迭代中的资源申请量为: 40.385114429336
# agent 39 在 199 次迭代中的资源申请量为: 43.37835638995773
# agent 40 在 199 次迭代中的资源申请量为: 50.18213742203139
# agent 41 在 199 次迭代中的资源申请量为: 66.29382371367612
# agent 42 在 199 次迭代中的资源申请量为: 42.57835667173705
# agent 43 在 199 次迭代中的资源申请量为: 51.82371789578647
# agent 44 在 199 次迭代中的资源申请量为: 53.02371821365589
# agent 45 在 199 次迭代中的资源申请量为: 48.28213752896484
# agent 46 在 199 次迭代中的资源申请量为: 55.87938993498827
# agent 47 在 199 次迭代中的资源申请量为: 45.95825430377062
# agent 48 在 199 次迭代中的资源申请量为: 35.57739055681123
# agent 49 在 199 次迭代中的资源申请量为: 42.77835625536017
# agent 50 在 199 次迭代中的资源申请量为: 40.98511439379326
# agent 51 在 199 次迭代中的资源申请量为: 48.38213757948272
# agent 52 在 199 次迭代中的资源申请量为: 55.779389627274234
# agent 53 在 199 次迭代中的资源申请量为: 32.10282067780611
# agent 54 在 199 次迭代中的资源申请量为: 56.979390260744985
# agent 55 在 199 次迭代中的资源申请量为: 71.07320665202066
# agent 56 在 199 次迭代中的资源申请量为: 40.9851145769431
# agent 57 在 199 次迭代中的资源申请量为: 60.47767258804807
# agent 58 在 199 次迭代中的资源申请量为: 42.27835704738819
# agent 59 在 199 次迭代中的资源申请量为: 47.982137464398555
# agent 60 在 199 次迭代中的资源申请量为: 56.079389530902645
# agent 61 在 199 次迭代中的资源申请量为: 65.9938229381763
# agent 62 在 199 次迭代中的资源申请量为: 46.158253877782414
# agent 63 在 199 次迭代中的资源申请量为: 39.03326640181377
# agent 64 在 199 次迭代中的资源申请量为: 44.45825383153495
# agent 65 在 199 次迭代中的资源申请量为: 42.77835639819755
# agent 66 在 199 次迭代中的资源申请量为: 65.69382287256859
# agent 67 在 199 次迭代中的资源申请量为: 43.37835634851325
# agent 68 在 199 次迭代中的资源申请量为: 44.958253516829764
# agent 69 在 199 次迭代中的资源申请量为: 45.458253408190636
# agent 70 在 199 次迭代中的资源申请量为: 60.07767111430875
# agent 71 在 199 次迭代中的资源申请量为: 72.07320421634833
# agent 72 在 199 次迭代中的资源申请量为: 60.27767222618161
# agent 73 在 199 次迭代中的资源申请量为: 43.778356484048714
# agent 74 在 199 次迭代中的资源申请量为: 39.03326662309276
# agent 75 在 199 次迭代中的资源申请量为: 52.02371922728234
# agent 76 在 199 次迭代中的资源申请量为: 47.05825412646302
# agent 77 在 199 次迭代中的资源申请量为: 40.88511496144011
# agent 78 在 199 次迭代中的资源申请量为: 49.682137767632064
# agent 79 在 199 次迭代中的资源申请量为: 42.87835697168531
# agent 80 在 199 次迭代中的资源申请量为: 43.078356729909544
# agent 81 在 199 次迭代中的资源申请量为: 39.53326691774663
# agent 82 在 199 次迭代中的资源申请量为: 45.758254036491074
# agent 83 在 199 次迭代中的资源申请量为: 41.68511469841929
# agent 84 在 199 次迭代中的资源申请量为: 52.123718979645126
# agent 85 在 199 次迭代中的资源申请量为: 55.77938900571985
# agent 86 在 199 次迭代中的资源申请量为: 48.98213755435576
# agent 87 在 199 次迭代中的资源申请量为: 60.47767201505175
# agent 88 在 199 次迭代中的资源申请量为: 65.19382294806891
# agent 89 在 199 次迭代中的资源申请量为: 33.15627643330184
# agent 90 在 199 次迭代中的资源申请量为: 59.27767222020587
# agent 91 在 199 次迭代中的资源申请量为: 42.97835648972144
# agent 92 在 199 次迭代中的资源申请量为: 56.97938933850262
# agent 93 在 199 次迭代中的资源申请量为: 40.785114626814924
# agent 94 在 199 次迭代中的资源申请量为: 73.27320767372653
# agent 95 在 199 次迭代中的资源申请量为: 60.37767270770639
# agent 96 在 199 次迭代中的资源申请量为: 60.57767202908544
# agent 97 在 199 次迭代中的资源申请量为: 72.27320448881026
# agent 98 在 199 次迭代中的资源申请量为: 73.07320622954364
# agent 99 在 199 次迭代中的资源申请量为: 52.52371872599672
# agent 100 在 199 次迭代中的资源申请量为: 48.582137227442
# 资源申请量总和为: 4999.999999999999
# ****************************************************************************
# 成本总和为: 334588.99386399216
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 249 次迭代中的结果：
# agent 1 在 249 次迭代中的资源申请量为: 48.443306113922134
# agent 2 在 249 次迭代中的资源申请量为: 61.03583500111313
# agent 3 在 249 次迭代中的资源申请量为: 43.84485434006123
# agent 4 在 249 次迭代中的资源申请量为: 64.56557951138832
# agent 5 在 249 次迭代中的资源申请量为: 65.36472383411015
# agent 6 在 249 次迭代中的资源申请量为: 72.11912556779832
# agent 7 在 249 次迭代中的资源申请量为: 39.504097347297254
# agent 8 在 249 次迭代中的资源申请量为: 32.831889858168324
# agent 9 在 249 次迭代中的资源申请量为: 43.13719220292409
# agent 10 在 249 次迭代中的资源申请量为: 55.837998680200066
# agent 11 在 249 次迭代中的资源申请量为: 45.522364778263686
# agent 12 在 249 次迭代中的资源申请量为: 49.328826356564825
# agent 13 在 249 次迭代中的资源申请量为: 65.83663815626907
# agent 14 在 249 次迭代中的资源申请量为: 55.2469511542741
# agent 15 在 249 次迭代中的资源申请量为: 43.55433423508815
# agent 16 在 249 次迭代中的资源申请量为: 43.760016956312974
# agent 17 在 249 次迭代中的资源申请量为: 44.90419276797091
# agent 18 在 249 次迭代中的资源申请量为: 46.52628369959967
# agent 19 在 249 次迭代中的资源申请量为: 41.34562158902251
# agent 20 在 249 次迭代中的资源申请量为: 55.71182233233841
# agent 21 在 249 次迭代中的资源申请量为: 32.63593983052459
# agent 22 在 249 次迭代中的资源申请量为: 39.09548436969887
# agent 23 在 249 次迭代中的资源申请量为: 47.85488947017259
# agent 24 在 249 次迭代中的资源申请量为: 40.565308546591524
# agent 25 在 249 次迭代中的资源申请量为: 45.23542584463713
# agent 26 在 249 次迭代中的资源申请量为: 39.80370414151505
# agent 27 在 249 次迭代中的资源申请量为: 65.57270732138781
# agent 28 在 249 次迭代中的资源申请量为: 51.39425354902164
# agent 29 在 249 次迭代中的资源申请量为: 40.8620818416019
# agent 30 在 249 次迭代中的资源申请量为: 39.20315317307109
# agent 31 在 249 次迭代中的资源申请量为: 60.4352160150175
# agent 32 在 249 次迭代中的资源申请量为: 55.56159771562123
# agent 33 在 249 次迭代中的资源申请量为: 41.665794293587204
# agent 34 在 249 次迭代中的资源申请量为: 52.26653876090214
# agent 35 在 249 次迭代中的资源申请量为: 32.65945506944353
# agent 36 在 249 次迭代中的资源申请量为: 42.83096147943501
# agent 37 在 249 次迭代中的资源申请量为: 52.5964248605687
# agent 38 在 249 次迭代中的资源申请量为: 40.368838723090875
# agent 39 在 249 次迭代中的资源申请量为: 43.35669888776738
# agent 40 在 249 次迭代中的资源申请量为: 50.13817315657349
# agent 41 在 249 次迭代中的资源申请量为: 66.21802621146918
# agent 42 在 249 次迭代中的资源申请量为: 42.55738994625203
# agent 43 在 249 次迭代中的资源申请量为: 51.80480318782079
# agent 44 在 249 次迭代中的资源申请量为: 53.004321202439755
# agent 45 在 249 次迭代中的资源申请量为: 48.261765849288096
# agent 46 在 249 次迭代中的资源申请量为: 55.81198041802378
# agent 47 在 249 次迭代中的资源申请量为: 45.92019622418103
# agent 48 在 249 次迭代中的资源申请量为: 36.34750790435071
# agent 49 在 249 次迭代中的资源申请量为: 42.751753891742965
# agent 50 在 249 次迭代中的资源申请量为: 40.96756997260435
# agent 51 在 249 次迭代中的资源申请量为: 48.32684491711051
# agent 52 在 249 次迭代中的资源申请量为: 55.740837259313224
# agent 53 在 249 次迭代中的资源申请量为: 32.793373134185195
# agent 54 在 249 次迭代中的资源申请量为: 56.93901837363985
# agent 55 在 249 次迭代中的资源申请量为: 71.05208399089307
# agent 56 在 249 次迭代中的资源申请量为: 40.96942031436199
# agent 57 在 249 次迭代中的资源申请量为: 60.413272719136316
# agent 58 在 249 次迭代中的资源申请量为: 42.24308178689511
# agent 59 在 249 次迭代中的资源申请量为: 47.93273791044666
# agent 60 在 249 次迭代中的资源申请量为: 56.0163151817135
# agent 61 在 249 次迭代中的资源申请量为: 65.94153126625167
# agent 62 在 249 次迭代中的资源申请量为: 46.12121667168686
# agent 63 在 249 次迭代中的资源申请量为: 39.00117710846158
# agent 64 在 249 次迭代中的资源申请量为: 44.42640810998821
# agent 65 在 249 次迭代中的资源申请量为: 42.760642665880525
# agent 66 在 249 次迭代中的资源申请量为: 65.64295727915824
# agent 67 在 249 次迭代中的资源申请量为: 43.344433421385425
# agent 68 在 249 次迭代中的资源申请量为: 44.93127595806967
# agent 69 在 249 次迭代中的资源申请量为: 45.438677008194006
# agent 70 在 249 次迭代中的资源申请量为: 60.044091494550386
# agent 71 在 249 次迭代中的资源申请量为: 72.01825287783849
# agent 72 在 249 次迭代中的资源申请量为: 60.23124360839658
# agent 73 在 249 次迭代中的资源申请量为: 43.74404115072577
# agent 74 在 249 次迭代中的资源申请量为: 39.01089015186635
# agent 75 在 249 次迭代中的资源申请量为: 51.97066103643388
# agent 76 在 249 次迭代中的资源申请量为: 47.033091614260194
# agent 77 在 249 次迭代中的资源申请量为: 40.854824595930324
# agent 78 在 249 次迭代中的资源申请量为: 49.65787148036173
# agent 79 在 249 次迭代中的资源申请量为: 42.84271893300995
# agent 80 在 249 次迭代中的资源申请量为: 43.05760114607253
# agent 81 在 249 次迭代中的资源申请量为: 39.503254275506215
# agent 82 在 249 次迭代中的资源申请量为: 45.71180450932321
# agent 83 在 249 次迭代中的资源申请量为: 41.660301345236334
# agent 84 在 249 次迭代中的资源申请量为: 52.06896924948082
# agent 85 在 249 次迭代中的资源申请量为: 55.7501007691545
# agent 86 在 249 次迭代中的资源申请量为: 48.94289939434136
# agent 87 在 249 次迭代中的资源申请量为: 60.412805823366114
# agent 88 在 249 次迭代中的资源申请量为: 65.11735156841578
# agent 89 在 249 次迭代中的资源申请量为: 33.90261415159172
# agent 90 在 249 次迭代中的资源申请量为: 59.230779269973674
# agent 91 在 249 次迭代中的资源申请量为: 42.954431573506646
# agent 92 在 249 次迭代中的资源申请量为: 56.934685268097525
# agent 93 在 249 次迭代中的资源申请量为: 40.76101428925634
# agent 94 在 249 次迭代中的资源申请量为: 73.22594590965882
# agent 95 在 249 次迭代中的资源申请量为: 60.31032770268852
# agent 96 在 249 次迭代中的资源申请量为: 60.52594399177043
# agent 97 在 249 次迭代中的资源申请量为: 72.2475268510592
# agent 98 在 249 次迭代中的资源申请量为: 72.99831001221196
# agent 99 在 249 次迭代中的资源申请量为: 52.50665442113767
# agent 100 在 249 次迭代中的资源申请量为: 48.564070116915815
# 资源申请量总和为: 4999.999999999999
# ****************************************************************************
# 成本总和为: 334501.34790532925
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 299 次迭代中的结果：
# agent 1 在 299 次迭代中的资源申请量为: 48.439121436717485
# agent 2 在 299 次迭代中的资源申请量为: 61.02389399543259
# agent 3 在 299 次迭代中的资源申请量为: 43.84039694385074
# agent 4 在 299 次迭代中的资源申请量为: 64.53515381221818
# agent 5 在 299 次迭代中的资源申请量为: 65.33515433052503
# agent 6 在 299 次迭代中的资源申请量为: 72.10864526254231
# agent 7 在 299 次迭代中的资源申请量为: 39.499304452566854
# agent 8 在 299 次迭代中的资源申请量为: 32.75688122300526
# agent 9 在 299 次迭代中的资源申请量为: 43.140402580289056
# agent 10 在 299 次迭代中的资源申请量为: 55.82975085112097
# agent 11 在 299 次迭代中的资源申请量为: 45.517922713657235
# agent 12 在 299 次迭代中的资源申请量为: 49.33912331055337
# agent 13 在 299 次迭代中的资源申请量为: 65.83516278527712
# agent 14 在 299 次迭代中的资源申请量为: 55.22976675419542
# agent 15 在 299 次迭代中的资源申请量为: 43.54039744640348
# agent 16 在 299 次迭代中的资源申请量为: 43.740394511525366
# agent 17 在 299 次迭代中的资源申请量为: 44.91792860135568
# agent 18 在 299 次迭代中的资源申请量为: 46.51792048667667
# agent 19 在 299 次迭代中的资源申请量为: 41.3492667770809
# agent 20 在 299 次迭代中的资源申请量为: 55.729743975798804
# agent 21 在 299 次迭代中的资源申请量为: 32.76203548020553
# agent 22 在 299 次迭代中的资源申请量为: 39.09930333773994
# agent 23 在 299 次迭代中的资源申请量为: 47.839122275177786
# agent 24 在 299 次迭代中的资源申请量为: 40.54926968949509
# agent 25 在 299 次迭代中的资源申请量为: 45.217927584583954
# agent 26 在 299 次迭代中的资源申请量为: 39.7993103967043
# agent 27 在 299 次迭代中的资源申请量为: 65.53518919419818
# agent 28 在 299 次迭代中的资源申请量为: 51.37762341951894
# agent 29 在 299 次迭代中的资源申请量为: 40.84926749911597
# agent 30 在 299 次迭代中的资源申请量为: 39.19930972493923
# agent 31 在 299 次迭代中的资源申请量为: 60.42389871286329
# agent 32 在 299 次迭代中的资源申请量为: 55.5297634221842
# agent 33 在 299 次迭代中的资源申请量为: 41.64926630514015
# agent 34 在 299 次迭代中的资源申请量为: 52.27763175628255
# agent 35 在 299 次迭代中的资源申请量为: 32.81900082832041
# agent 36 在 299 次迭代中的资源申请量为: 42.84039449127115
# agent 37 在 299 次迭代中的资源申请量为: 52.57761956353448
# agent 38 在 299 次迭代中的资源申请量为: 40.349263171817505
# agent 39 在 299 次迭代中的资源申请量为: 43.34039466387584
# agent 40 在 299 次迭代中的资源申请量为: 50.13911694640638
# agent 41 在 299 次迭代中的资源申请量为: 66.23515155939495
# agent 42 在 299 次迭代中的资源申请量为: 42.54039806004902
# agent 43 在 299 次迭代中的资源申请量为: 51.77761556808909
# agent 44 在 299 次迭代中的资源申请量为: 52.97762097607062
# agent 45 在 299 次迭代中的资源申请量为: 48.23911974272667
# agent 46 在 299 次迭代中的资源申请量为: 55.82975819936693
# agent 47 在 299 次迭代中的资源申请量为: 45.91792925058532
# agent 48 在 299 次迭代中的资源申请量为: 36.57454354852459
# agent 49 在 299 次迭代中的资源申请量为: 42.74039466948254
# agent 50 在 299 次迭代中的资源申请量为: 40.949263499964246
# agent 51 在 299 次迭代中的资源申请量为: 48.33911697514269
# agent 52 在 299 次迭代中的资源申请量为: 55.72975283901551
# agent 53 在 299 次迭代中的资源申请量为: 32.94345826634804
# agent 54 在 299 次迭代中的资源申请量为: 56.929767918937095
# agent 55 在 299 次迭代中的资源申请量为: 71.00869248451649
# agent 56 在 299 次迭代中的资源申请量为: 40.94926687854622
# agent 57 在 299 次迭代中的资源申请量为: 60.42390809104905
# agent 58 在 299 次迭代中的资源申请量为: 42.24040297786042
# agent 59 在 299 次迭代中的资源申请量为: 47.93911803894416
# agent 60 在 299 次迭代中的资源申请量为: 56.02975264973598
# agent 61 在 299 次迭代中的资源申请量为: 65.93514666086723
# agent 62 在 299 次迭代中的资源申请量为: 46.11792254547501
# agent 63 在 299 次迭代中的资源申请量为: 38.99930277897284
# agent 64 在 299 次迭代中的资源申请量为: 44.417918247986925
# agent 65 在 299 次迭代中的资源申请量为: 42.740394114032775
# agent 66 在 299 次迭代中的资源申请量为: 65.63514670328361
# agent 67 在 299 次迭代中的资源申请量为: 43.340394434508845
# agent 68 在 299 次迭代中的资源申请量为: 44.91791699746439
# agent 69 在 299 次迭代中的资源申请量为: 45.4179174250311
# agent 70 在 299 次迭代中的资源申请量为: 60.02388471533501
# agent 71 在 299 次迭代中的资源申请量为: 72.00865021019591
# agent 72 在 299 次迭代中的资源申请量为: 60.22389335949132
# agent 73 在 299 次迭代中的资源申请量为: 43.74039555436034
# agent 74 在 299 次迭代中的资源申请量为: 38.99930543185434
# agent 75 在 299 次迭代中的资源申请量为: 51.9776312735209
# agent 76 在 299 次迭代中的资源申请量为: 47.01792388644725
# agent 77 在 299 次迭代中的资源申请量为: 40.849271617164085
# agent 78 在 299 次迭代中的资源申请量为: 49.63912224473446
# agent 79 在 299 次迭代中的资源申请量为: 42.840404730227895
# agent 80 在 299 次迭代中的资源申请量为: 43.040398696597876
# agent 81 在 299 次迭代中的资源申请量为: 39.499311737197885
# agent 82 在 299 次迭代中的资源申请量为: 45.71792280045702
# agent 83 在 299 次迭代中的资源申请量为: 41.649267438410384
# agent 84 在 299 次迭代中的资源申请量为: 52.07762793978858
# agent 85 在 299 次迭代中的资源申请量为: 55.72974553022913
# agent 86 在 299 次迭代中的资源申请量为: 48.93911861656836
# agent 87 在 299 次迭代中的资源申请量为: 60.42389499959381
# agent 88 在 299 次迭代中的资源申请量为: 65.13514186538957
# agent 89 在 299 次迭代中的资源申请量为: 34.09508467565137
# agent 90 在 299 次迭代中的资源申请量为: 59.22389773394918
# agent 91 在 299 次迭代中的资源申请量为: 42.94039531476955
# agent 92 在 299 次迭代中的资源申请量为: 56.92974775338317
# agent 93 在 299 次迭代中的资源申请量为: 40.749265177819446
# agent 94 在 299 次迭代中的资源申请量为: 73.20869388383497
# agent 95 在 299 次迭代中的资源申请量为: 60.323899449373
# agent 96 在 299 次迭代中的资源申请量为: 60.52389512193302
# agent 97 在 299 次迭代中的资源申请量为: 72.20866451035505
# agent 98 在 299 次迭代中的资源申请量为: 73.0086679730457
# agent 99 在 299 次迭代中的资源申请量为: 52.477627975530005
# agent 100 在 299 次迭代中的资源申请量为: 48.53911496665197
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 334482.72378626105
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 349 次迭代中的结果：
# agent 1 在 349 次迭代中的资源申请量为: 48.439119523049065
# agent 2 在 349 次迭代中的资源申请量为: 61.023899403793834
# agent 3 在 349 次迭代中的资源申请量为: 43.84039957915406
# agent 4 在 349 次迭代中的资源申请量为: 64.5351629859215
# agent 5 在 349 次迭代中的资源申请量为: 65.33516298590183
# agent 6 在 349 次迭代中的资源申请量为: 72.10867928446092
# agent 7 在 349 次迭代中的资源申请量为: 39.49930488660595
# agent 8 在 349 次迭代中的资源申请量为: 32.7568613044144
# agent 9 在 349 次迭代中的资源申请量为: 43.14039957915766
# agent 10 在 349 次迭代中的资源申请量为: 55.829753295810654
# agent 11 在 349 次迭代中的资源申请量为: 45.51792455283364
# agent 12 在 349 次迭代中的资源申请量为: 49.339119523045724
# agent 13 在 349 次迭代中的资源申请量为: 65.83516298600735
# agent 14 在 349 次迭代中的资源申请量为: 55.2297532958283
# agent 15 在 349 次迭代中的资源申请量为: 43.54039957914762
# agent 16 在 349 次迭代中的资源申请量为: 43.74039957913369
# agent 17 在 349 次迭代中的资源申请量为: 44.91792455285937
# agent 18 在 349 次迭代中的资源申请量为: 46.51792455283551
# agent 19 在 349 次迭代中的资源申请量为: 41.34926626920825
# agent 20 在 349 次迭代中的资源申请量为: 55.729753295808834
# agent 21 在 349 次迭代中的资源申请量为: 32.76200072641494
# agent 22 在 349 次迭代中的资源申请量为: 39.0993048866082
# agent 23 在 349 次迭代中的资源申请量为: 47.839119523042065
# agent 24 在 349 次迭代中的资源申请量为: 40.549266269199784
# agent 25 在 349 次迭代中的资源申请量为: 45.217924552842874
# agent 26 在 349 次迭代中的资源申请量为: 39.79930488661312
# agent 27 在 349 次迭代中的资源申请量为: 65.53516298598518
# agent 28 在 349 次迭代中的资源申请量为: 51.377628060404476
# agent 29 在 349 次迭代中的资源申请量为: 40.84926626920759
# agent 30 在 349 次迭代中的资源申请量为: 39.19930488661811
# agent 31 在 349 次迭代中的资源申请量为: 60.42389940380557
# agent 32 在 349 次迭代中的资源申请量为: 55.52975329581777
# agent 33 在 349 次迭代中的资源申请量为: 41.64926626920506
# agent 34 在 349 次迭代中的资源申请量为: 52.27762806040826
# agent 35 在 349 次迭代中的资源申请量为: 32.81896714426822
# agent 36 在 349 次迭代中的资源申请量为: 42.84039957914215
# agent 37 在 349 次迭代中的资源申请量为: 52.57762806038434
# agent 38 在 349 次迭代中的资源申请量为: 40.34926626919652
# agent 39 在 349 次迭代中的资源申请量为: 43.340399579144425
# agent 40 在 349 次迭代中的资源申请量为: 50.139119523040875
# agent 41 在 349 次迭代中的资源申请量为: 66.23516298597049
# agent 42 在 349 次迭代中的资源申请量为: 42.540399579150105
# agent 43 在 349 次迭代中的资源申请量为: 51.77762806036699
# agent 44 在 349 次迭代中的资源申请量为: 52.97762806037589
# agent 45 在 349 次迭代中的资源申请量为: 48.23911952303475
# agent 46 在 349 次迭代中的资源申请量为: 55.829753295823885
# agent 47 在 349 次迭代中的资源申请量为: 45.91792455285279
# agent 48 在 349 次迭代中的资源申请量为: 36.57451212878041
# agent 49 在 349 次迭代中的资源申请量为: 42.74039957913227
# agent 50 在 349 次迭代中的资源申请量为: 40.94926626919301
# agent 51 在 349 次迭代中的资源申请量为: 48.33911952304018
# agent 52 在 349 次迭代中的资源申请量为: 55.72975329583412
# agent 53 在 349 次迭代中的资源申请量为: 32.943424855538716
# agent 54 在 349 次迭代中的资源申请量为: 56.929753295840825
# agent 55 在 349 次迭代中的资源申请量为: 71.00867928460518
# agent 56 在 349 次迭代中的资源申请量为: 40.949266269201715
# agent 57 在 349 次迭代中的资源申请量为: 60.42389940382931
# agent 58 在 349 次迭代中的资源申请量为: 42.24039957916636
# agent 59 在 349 次迭代中的资源申请量为: 47.939119523036055
# agent 60 在 349 次迭代中的资源申请量为: 56.02975329581108
# agent 61 在 349 次迭代中的资源申请量为: 65.93516298592229
# agent 62 在 349 次迭代中的资源申请量为: 46.11792455284147
# agent 63 在 349 次迭代中的资源申请量为: 38.999304886601095
# agent 64 在 349 次迭代中的资源申请量为: 44.41792455284064
# agent 65 在 349 次迭代中的资源申请量为: 42.74039957914019
# agent 66 在 349 次迭代中的资源申请量为: 65.6351629859235
# agent 67 在 349 次迭代中的资源申请量为: 43.34039957913577
# agent 68 在 349 次迭代中的资源申请量为: 44.91792455282776
# agent 69 在 349 次迭代中的资源申请量为: 45.41792455282747
# agent 70 在 349 次迭代中的资源申请量为: 60.02389940376888
# agent 71 在 349 次迭代中的资源申请量为: 72.00867928447292
# agent 72 在 349 次迭代中的资源申请量为: 60.22389940380128
# agent 73 在 349 次迭代中的资源申请量为: 43.740399579147
# agent 74 在 349 次迭代中的资源申请量为: 38.99930488661034
# agent 75 在 349 次迭代中的资源申请量为: 51.97762806040129
# agent 76 在 349 次迭代中的资源申请量为: 47.01792455284735
# agent 77 在 349 次迭代中的资源申请量为: 40.84926626920068
# agent 78 在 349 次迭代中的资源申请量为: 49.639119523053395
# agent 79 在 349 次迭代中的资源申请量为: 42.84039957915943
# agent 80 在 349 次迭代中的资源申请量为: 43.04039957914999
# agent 81 在 349 次迭代中的资源申请量为: 39.49930488661945
# agent 82 在 349 次迭代中的资源申请量为: 45.71792455285726
# agent 83 在 349 次迭代中的资源申请量为: 41.64926626920115
# agent 84 在 349 次迭代中的资源申请量为: 52.07762806041013
# agent 85 在 349 次迭代中的资源申请量为: 55.72975329579051
# agent 86 在 349 次迭代中的资源申请量为: 48.93911952303814
# agent 87 在 349 次迭代中的资源申请量为: 60.423899403799005
# agent 88 在 349 次迭代中的资源申请量为: 65.13516298593697
# agent 89 在 349 次迭代中的资源申请量为: 34.095046273145904
# agent 90 在 349 次迭代中的资源申请量为: 59.223899403804324
# agent 91 在 349 次迭代中的资源申请量为: 42.94039957914714
# agent 92 在 349 次迭代中的资源申请量为: 56.92975329581488
# agent 93 在 349 次迭代中的资源申请量为: 40.749266269197996
# agent 94 在 349 次迭代中的资源申请量为: 73.20867928457997
# agent 95 在 349 次迭代中的资源申请量为: 60.32389940381063
# agent 96 在 349 次迭代中的资源申请量为: 60.523899403790516
# agent 97 在 349 次迭代中的资源申请量为: 72.20867928448094
# agent 98 在 349 次迭代中的资源申请量为: 73.00867928457481
# agent 99 在 349 次迭代中的资源申请量为: 52.47762806039086
# agent 100 在 349 次迭代中的资源申请量为: 48.53911952302513
# 资源申请量总和为: 5000.000000000004
# ****************************************************************************
# 成本总和为: 334482.7281546186
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 399 次迭代中的结果：
# agent 1 在 399 次迭代中的资源申请量为: 48.43911952303873
# agent 2 在 399 次迭代中的资源申请量为: 61.02389940379842
# agent 3 在 399 次迭代中的资源申请量为: 43.84039957915182
# agent 4 在 399 次迭代中的资源申请量为: 64.53516298596188
# agent 5 在 399 次迭代中的资源申请量为: 65.33516298596189
# agent 6 在 399 次迭代中的资源申请量为: 72.10867928455808
# agent 7 在 399 次迭代中的资源申请量为: 39.49930488660952
# agent 8 在 399 次迭代中的资源申请量为: 32.75686130437207
# agent 9 在 399 次迭代中的资源申请量为: 43.140399579151826
# agent 10 在 399 次迭代中的资源申请量为: 55.829753295813916
# agent 11 在 399 次迭代中的资源申请量为: 45.517924552848804
# agent 12 在 399 次迭代中的资源申请量为: 49.33911952303873
# agent 13 在 399 次迭代中的资源申请量为: 65.83516298596189
# agent 14 在 399 次迭代中的资源申请量为: 55.229753295813914
# agent 15 在 399 次迭代中的资源申请量为: 43.54039957915182
# agent 16 在 399 次迭代中的资源申请量为: 43.74039957915182
# agent 17 在 399 次迭代中的资源申请量为: 44.91792455284881
# agent 18 在 399 次迭代中的资源申请量为: 46.517924552848804
# agent 19 在 399 次迭代中的资源申请量为: 41.349266269198935
# agent 20 在 399 次迭代中的资源申请量为: 55.729753295813914
# agent 21 在 399 次迭代中的资源申请量为: 32.76200072634737
# agent 22 在 399 次迭代中的资源申请量为: 39.099304886609524
# agent 23 在 399 次迭代中的资源申请量为: 47.83911952303873
# agent 24 在 399 次迭代中的资源申请量为: 40.54926626919894
# agent 25 在 399 次迭代中的资源申请量为: 45.2179245528488
# agent 26 在 399 次迭代中的资源申请量为: 39.79930488660953
# agent 27 在 399 次迭代中的资源申请量为: 65.53516298596189
# agent 28 在 399 次迭代中的资源申请量为: 51.377628060398635
# agent 29 在 399 次迭代中的资源申请量为: 40.84926626919894
# agent 30 在 399 次迭代中的资源申请量为: 39.199304886609525
# agent 31 在 399 次迭代中的资源申请量为: 60.423899403798416
# agent 32 在 399 次迭代中的资源申请量为: 55.52975329581391
# agent 33 在 399 次迭代中的资源申请量为: 41.64926626919894
# agent 34 在 399 次迭代中的资源申请量为: 52.27762806039864
# agent 35 在 399 次迭代中的资源申请量为: 32.81896714421022
# agent 36 在 399 次迭代中的资源申请量为: 42.84039957915182
# agent 37 在 399 次迭代中的资源申请量为: 52.57762806039864
# agent 38 在 399 次迭代中的资源申请量为: 40.349266269198935
# agent 39 在 399 次迭代中的资源申请量为: 43.340399579151814
# agent 40 在 399 次迭代中的资源申请量为: 50.13911952303872
# agent 41 在 399 次迭代中的资源申请量为: 66.23516298596188
# agent 42 在 399 次迭代中的资源申请量为: 42.54039957915182
# agent 43 在 399 次迭代中的资源申请量为: 51.777628060398634
# agent 44 在 399 次迭代中的资源申请量为: 52.977628060398644
# agent 45 在 399 次迭代中的资源申请量为: 48.239119523038724
# agent 46 在 399 次迭代中的资源申请量为: 55.829753295813916
# agent 47 在 399 次迭代中的资源申请量为: 45.9179245528488
# agent 48 在 399 次迭代中的资源申请量为: 36.57451212871925
# agent 49 在 399 次迭代中的资源申请量为: 42.74039957915182
# agent 50 在 399 次迭代中的资源申请量为: 40.94926626919894
# agent 51 在 399 次迭代中的资源申请量为: 48.33911952303873
# agent 52 在 399 次迭代中的资源申请量为: 55.729753295813914
# agent 53 在 399 次迭代中的资源申请量为: 32.94342485547046
# agent 54 在 399 次迭代中的资源申请量为: 56.92975329581392
# agent 55 在 399 次迭代中的资源申请量为: 71.00867928455808
# agent 56 在 399 次迭代中的资源申请量为: 40.94926626919894
# agent 57 在 399 次迭代中的资源申请量为: 60.423899403798416
# agent 58 在 399 次迭代中的资源申请量为: 42.24039957915182
# agent 59 在 399 次迭代中的资源申请量为: 47.93911952303873
# agent 60 在 399 次迭代中的资源申请量为: 56.02975329581392
# agent 61 在 399 次迭代中的资源申请量为: 65.93516298596188
# agent 62 在 399 次迭代中的资源申请量为: 46.1179245528488
# agent 63 在 399 次迭代中的资源申请量为: 38.99930488660952
# agent 64 在 399 次迭代中的资源申请量为: 44.4179245528488
# agent 65 在 399 次迭代中的资源申请量为: 42.74039957915182
# agent 66 在 399 次迭代中的资源申请量为: 65.63516298596188
# agent 67 在 399 次迭代中的资源申请量为: 43.340399579151814
# agent 68 在 399 次迭代中的资源申请量为: 44.91792455284881
# agent 69 在 399 次迭代中的资源申请量为: 45.41792455284881
# agent 70 在 399 次迭代中的资源申请量为: 60.02389940379841
# agent 71 在 399 次迭代中的资源申请量为: 72.00867928455808
# agent 72 在 399 次迭代中的资源申请量为: 60.223899403798406
# agent 73 在 399 次迭代中的资源申请量为: 43.74039957915182
# agent 74 在 399 次迭代中的资源申请量为: 38.99930488660952
# agent 75 在 399 次迭代中的资源申请量为: 51.97762806039864
# agent 76 在 399 次迭代中的资源申请量为: 47.01792455284881
# agent 77 在 399 次迭代中的资源申请量为: 40.84926626919894
# agent 78 在 399 次迭代中的资源申请量为: 49.63911952303872
# agent 79 在 399 次迭代中的资源申请量为: 42.84039957915182
# agent 80 在 399 次迭代中的资源申请量为: 43.040399579151824
# agent 81 在 399 次迭代中的资源申请量为: 39.49930488660952
# agent 82 在 399 次迭代中的资源申请量为: 45.71792455284881
# agent 83 在 399 次迭代中的资源申请量为: 41.64926626919894
# agent 84 在 399 次迭代中的资源申请量为: 52.07762806039864
# agent 85 在 399 次迭代中的资源申请量为: 55.729753295813914
# agent 86 在 399 次迭代中的资源申请量为: 48.93911952303873
# agent 87 在 399 次迭代中的资源申请量为: 60.423899403798416
# agent 88 在 399 次迭代中的资源申请量为: 65.13516298596188
# agent 89 在 399 次迭代中的资源申请量为: 34.09504627307008
# agent 90 在 399 次迭代中的资源申请量为: 59.223899403798406
# agent 91 在 399 次迭代中的资源申请量为: 42.94039957915182
# agent 92 在 399 次迭代中的资源申请量为: 56.92975329581392
# agent 93 在 399 次迭代中的资源申请量为: 40.749266269198934
# agent 94 在 399 次迭代中的资源申请量为: 73.20867928455807
# agent 95 在 399 次迭代中的资源申请量为: 60.323899403798414
# agent 96 在 399 次迭代中的资源申请量为: 60.52389940379841
# agent 97 在 399 次迭代中的资源申请量为: 72.20867928455807
# agent 98 在 399 次迭代中的资源申请量为: 73.00867928455808
# agent 99 在 399 次迭代中的资源申请量为: 52.47762806039864
# agent 100 在 399 次迭代中的资源申请量为: 48.53911952303873
# 资源申请量总和为: 5000.000000000006
# ****************************************************************************
# 成本总和为: 334482.72815462755
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 449 次迭代中的结果：
# agent 1 在 449 次迭代中的资源申请量为: 48.43911952303873
# agent 2 在 449 次迭代中的资源申请量为: 61.02389940379842
# agent 3 在 449 次迭代中的资源申请量为: 43.84039957915182
# agent 4 在 449 次迭代中的资源申请量为: 64.53516298596188
# agent 5 在 449 次迭代中的资源申请量为: 65.33516298596189
# agent 6 在 449 次迭代中的资源申请量为: 72.10867928455808
# agent 7 在 449 次迭代中的资源申请量为: 39.49930488660952
# agent 8 在 449 次迭代中的资源申请量为: 32.75686130437207
# agent 9 在 449 次迭代中的资源申请量为: 43.140399579151826
# agent 10 在 449 次迭代中的资源申请量为: 55.829753295813916
# agent 11 在 449 次迭代中的资源申请量为: 45.517924552848804
# agent 12 在 449 次迭代中的资源申请量为: 49.33911952303873
# agent 13 在 449 次迭代中的资源申请量为: 65.83516298596189
# agent 14 在 449 次迭代中的资源申请量为: 55.229753295813914
# agent 15 在 449 次迭代中的资源申请量为: 43.54039957915182
# agent 16 在 449 次迭代中的资源申请量为: 43.74039957915182
# agent 17 在 449 次迭代中的资源申请量为: 44.91792455284881
# agent 18 在 449 次迭代中的资源申请量为: 46.517924552848804
# agent 19 在 449 次迭代中的资源申请量为: 41.349266269198935
# agent 20 在 449 次迭代中的资源申请量为: 55.729753295813914
# agent 21 在 449 次迭代中的资源申请量为: 32.76200072634737
# agent 22 在 449 次迭代中的资源申请量为: 39.099304886609524
# agent 23 在 449 次迭代中的资源申请量为: 47.83911952303873
# agent 24 在 449 次迭代中的资源申请量为: 40.54926626919894
# agent 25 在 449 次迭代中的资源申请量为: 45.2179245528488
# agent 26 在 449 次迭代中的资源申请量为: 39.79930488660953
# agent 27 在 449 次迭代中的资源申请量为: 65.53516298596189
# agent 28 在 449 次迭代中的资源申请量为: 51.377628060398635
# agent 29 在 449 次迭代中的资源申请量为: 40.84926626919894
# agent 30 在 449 次迭代中的资源申请量为: 39.199304886609525
# agent 31 在 449 次迭代中的资源申请量为: 60.423899403798416
# agent 32 在 449 次迭代中的资源申请量为: 55.52975329581391
# agent 33 在 449 次迭代中的资源申请量为: 41.64926626919894
# agent 34 在 449 次迭代中的资源申请量为: 52.27762806039864
# agent 35 在 449 次迭代中的资源申请量为: 32.81896714421022
# agent 36 在 449 次迭代中的资源申请量为: 42.84039957915182
# agent 37 在 449 次迭代中的资源申请量为: 52.57762806039864
# agent 38 在 449 次迭代中的资源申请量为: 40.349266269198935
# agent 39 在 449 次迭代中的资源申请量为: 43.340399579151814
# agent 40 在 449 次迭代中的资源申请量为: 50.13911952303872
# agent 41 在 449 次迭代中的资源申请量为: 66.23516298596188
# agent 42 在 449 次迭代中的资源申请量为: 42.54039957915182
# agent 43 在 449 次迭代中的资源申请量为: 51.777628060398634
# agent 44 在 449 次迭代中的资源申请量为: 52.977628060398644
# agent 45 在 449 次迭代中的资源申请量为: 48.239119523038724
# agent 46 在 449 次迭代中的资源申请量为: 55.829753295813916
# agent 47 在 449 次迭代中的资源申请量为: 45.9179245528488
# agent 48 在 449 次迭代中的资源申请量为: 36.57451212871925
# agent 49 在 449 次迭代中的资源申请量为: 42.74039957915182
# agent 50 在 449 次迭代中的资源申请量为: 40.94926626919894
# agent 51 在 449 次迭代中的资源申请量为: 48.33911952303873
# agent 52 在 449 次迭代中的资源申请量为: 55.729753295813914
# agent 53 在 449 次迭代中的资源申请量为: 32.94342485547046
# agent 54 在 449 次迭代中的资源申请量为: 56.92975329581392
# agent 55 在 449 次迭代中的资源申请量为: 71.00867928455808
# agent 56 在 449 次迭代中的资源申请量为: 40.94926626919894
# agent 57 在 449 次迭代中的资源申请量为: 60.423899403798416
# agent 58 在 449 次迭代中的资源申请量为: 42.24039957915182
# agent 59 在 449 次迭代中的资源申请量为: 47.93911952303873
# agent 60 在 449 次迭代中的资源申请量为: 56.02975329581392
# agent 61 在 449 次迭代中的资源申请量为: 65.93516298596188
# agent 62 在 449 次迭代中的资源申请量为: 46.1179245528488
# agent 63 在 449 次迭代中的资源申请量为: 38.99930488660952
# agent 64 在 449 次迭代中的资源申请量为: 44.4179245528488
# agent 65 在 449 次迭代中的资源申请量为: 42.74039957915182
# agent 66 在 449 次迭代中的资源申请量为: 65.63516298596188
# agent 67 在 449 次迭代中的资源申请量为: 43.340399579151814
# agent 68 在 449 次迭代中的资源申请量为: 44.91792455284881
# agent 69 在 449 次迭代中的资源申请量为: 45.41792455284881
# agent 70 在 449 次迭代中的资源申请量为: 60.02389940379841
# agent 71 在 449 次迭代中的资源申请量为: 72.00867928455808
# agent 72 在 449 次迭代中的资源申请量为: 60.223899403798406
# agent 73 在 449 次迭代中的资源申请量为: 43.74039957915182
# agent 74 在 449 次迭代中的资源申请量为: 38.99930488660952
# agent 75 在 449 次迭代中的资源申请量为: 51.97762806039864
# agent 76 在 449 次迭代中的资源申请量为: 47.01792455284881
# agent 77 在 449 次迭代中的资源申请量为: 40.84926626919894
# agent 78 在 449 次迭代中的资源申请量为: 49.63911952303872
# agent 79 在 449 次迭代中的资源申请量为: 42.84039957915182
# agent 80 在 449 次迭代中的资源申请量为: 43.040399579151824
# agent 81 在 449 次迭代中的资源申请量为: 39.49930488660952
# agent 82 在 449 次迭代中的资源申请量为: 45.71792455284881
# agent 83 在 449 次迭代中的资源申请量为: 41.64926626919894
# agent 84 在 449 次迭代中的资源申请量为: 52.07762806039864
# agent 85 在 449 次迭代中的资源申请量为: 55.729753295813914
# agent 86 在 449 次迭代中的资源申请量为: 48.93911952303873
# agent 87 在 449 次迭代中的资源申请量为: 60.423899403798416
# agent 88 在 449 次迭代中的资源申请量为: 65.13516298596188
# agent 89 在 449 次迭代中的资源申请量为: 34.09504627307008
# agent 90 在 449 次迭代中的资源申请量为: 59.223899403798406
# agent 91 在 449 次迭代中的资源申请量为: 42.94039957915182
# agent 92 在 449 次迭代中的资源申请量为: 56.92975329581392
# agent 93 在 449 次迭代中的资源申请量为: 40.749266269198934
# agent 94 在 449 次迭代中的资源申请量为: 73.20867928455807
# agent 95 在 449 次迭代中的资源申请量为: 60.323899403798414
# agent 96 在 449 次迭代中的资源申请量为: 60.52389940379841
# agent 97 在 449 次迭代中的资源申请量为: 72.20867928455807
# agent 98 在 449 次迭代中的资源申请量为: 73.00867928455808
# agent 99 在 449 次迭代中的资源申请量为: 52.47762806039864
# agent 100 在 449 次迭代中的资源申请量为: 48.53911952303873
# 资源申请量总和为: 5000.000000000006
# ****************************************************************************
# 成本总和为: 334482.72815462755
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 499 次迭代中的结果：
# agent 1 在 499 次迭代中的资源申请量为: 48.43911952303873
# agent 2 在 499 次迭代中的资源申请量为: 61.02389940379842
# agent 3 在 499 次迭代中的资源申请量为: 43.84039957915182
# agent 4 在 499 次迭代中的资源申请量为: 64.53516298596188
# agent 5 在 499 次迭代中的资源申请量为: 65.33516298596189
# agent 6 在 499 次迭代中的资源申请量为: 72.10867928455808
# agent 7 在 499 次迭代中的资源申请量为: 39.49930488660952
# agent 8 在 499 次迭代中的资源申请量为: 32.75686130437207
# agent 9 在 499 次迭代中的资源申请量为: 43.140399579151826
# agent 10 在 499 次迭代中的资源申请量为: 55.829753295813916
# agent 11 在 499 次迭代中的资源申请量为: 45.517924552848804
# agent 12 在 499 次迭代中的资源申请量为: 49.33911952303873
# agent 13 在 499 次迭代中的资源申请量为: 65.83516298596189
# agent 14 在 499 次迭代中的资源申请量为: 55.229753295813914
# agent 15 在 499 次迭代中的资源申请量为: 43.54039957915182
# agent 16 在 499 次迭代中的资源申请量为: 43.74039957915182
# agent 17 在 499 次迭代中的资源申请量为: 44.91792455284881
# agent 18 在 499 次迭代中的资源申请量为: 46.517924552848804
# agent 19 在 499 次迭代中的资源申请量为: 41.349266269198935
# agent 20 在 499 次迭代中的资源申请量为: 55.729753295813914
# agent 21 在 499 次迭代中的资源申请量为: 32.76200072634737
# agent 22 在 499 次迭代中的资源申请量为: 39.099304886609524
# agent 23 在 499 次迭代中的资源申请量为: 47.83911952303873
# agent 24 在 499 次迭代中的资源申请量为: 40.54926626919894
# ...
# agent 87 在 1969 次迭代中的资源申请量为: 59.98773721114606
# agent 88 在 1969 次迭代中的资源申请量为: 64.6593496848866
# agent 89 在 1969 次迭代中的资源申请量为: 40.25849147409737
# agent 90 在 1969 次迭代中的资源申请量为: 58.78773721114605
# agent 91 在 1969 次迭代中的资源申请量为: 42.63252038433839
# agent 92 在 1969 次迭代中的资源申请量为: 56.5271420410579
# agent 93 在 1969 次迭代中的资源申请量为: 40.45849147409737
# agent 94 在 1969 次迭代中的资源申请量为: 72.31208127078975
# agent 95 在 1969 次迭代中的资源申请量为: 59.88773721114608
# agent 96 在 1969 次迭代中的资源申请量为: 60.08773721114608
# agent 97 在 1969 次迭代中的资源申请量为: 71.68528465337529
# agent 98 在 1969 次迭代中的资源申请量为: 72.48528465337532
# agent 99 在 1969 次迭代中的资源申请量为: 52.10377475241095
# agent 100 在 1969 次迭代中的资源申请量为: 48.19018976891688
# 资源申请量总和为: 5000.000000000159
# ****************************************************************************
# 成本总和为: 334087.9140803464
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1979 次迭代中的结果：
# agent 1 在 1979 次迭代中的资源申请量为: 48.09018976891687
# agent 2 在 1979 次迭代中的资源申请量为: 60.5877372111461
# agent 3 在 1979 次迭代中的资源申请量为: 43.53252038433841
# agent 4 在 1979 次迭代中的资源申请量为: 64.05934968488663
# agent 5 在 1979 次迭代中的资源申请量为: 64.85934968488662
# agent 6 在 1979 次迭代中的资源申请量为: 71.5852846533753
# agent 7 在 1979 次迭代中的资源申请量为: 39.22383402809225
# agent 8 在 1979 次迭代中的资源申请量为: 37.49264232668764
# agent 9 在 1979 次迭代中的资源申请量为: 42.832520384338395
# agent 10 在 1979 次迭代中的资源申请量为: 55.42714204105789
# agent 11 在 1979 次迭代中的资源申请量为: 45.19080290835954
# agent 12 在 1979 次迭代中的资源申请量为: 48.99018976891685
# agent 13 在 1979 次迭代中的资源申请量为: 65.3593496848866
# agent 14 在 1979 次迭代中的资源申请量为: 54.82714204105789
# agent 15 在 1979 次迭代中的资源申请量为: 43.23252038433839
# agent 16 在 1979 次迭代中的资源申请量为: 43.432520384338396
# agent 17 在 1979 次迭代中的资源申请量为: 44.59080290835954
# agent 18 在 1979 次迭代中的资源申请量为: 46.19080290835954
# agent 19 在 1979 次迭代中的资源申请量为: 41.058491474097366
# agent 20 在 1979 次迭代中的资源申请量为: 55.3271420410579
# agent 21 在 1979 次迭代中的资源申请量为: 38.523834028092246
# agent 22 在 1979 次迭代中的资源申请量为: 38.82383402809224
# agent 23 在 1979 次迭代中的资源申请量为: 47.49018976891685
# agent 24 在 1979 次迭代中的资源申请量为: 40.25849147409737
# agent 25 在 1979 次迭代中的资源申请量为: 44.89080290835954
# agent 26 在 1979 次迭代中的资源申请量为: 39.52383402809225
# agent 27 在 1979 次迭代中的资源申请量为: 65.0593496848866
# agent 28 在 1979 次迭代中的资源申请量为: 51.003774752410905
# agent 29 在 1979 次迭代中的资源申请量为: 40.55849147409737
# agent 30 在 1979 次迭代中的资源申请量为: 38.92383402809225
# agent 31 在 1979 次迭代中的资源申请量为: 59.98773721114606
# agent 32 在 1979 次迭代中的资源申请量为: 55.127142041057894
# agent 33 在 1979 次迭代中的资源申请量为: 41.35849147409737
# agent 34 在 1979 次迭代中的资源申请量为: 51.903774752410904
# agent 35 在 1979 次迭代中的资源申请量为: 38.62383402809225
# agent 36 在 1979 次迭代中的资源申请量为: 42.53252038433839
# agent 37 在 1979 次迭代中的资源申请量为: 52.20377475241091
# agent 38 在 1979 次迭代中的资源申请量为: 40.058491474097366
# agent 39 在 1979 次迭代中的资源申请量为: 43.03252038433839
# agent 40 在 1979 次迭代中的资源申请量为: 49.79018976891684
# agent 41 在 1979 次迭代中的资源申请量为: 65.75934968488659
# agent 42 在 1979 次迭代中的资源申请量为: 42.23252038433839
# agent 43 在 1979 次迭代中的资源申请量为: 51.403774752410904
# agent 44 在 1979 次迭代中的资源申请量为: 52.60377475241091
# agent 45 在 1979 次迭代中的资源申请量为: 47.89018976891685
# agent 46 在 1979 次迭代中的资源申请量为: 55.42714204105789
# agent 47 在 1979 次迭代中的资源申请量为: 45.59080290835954
# agent 48 在 1979 次迭代中的资源申请量为: 43.13252038433839
# agent 49 在 1979 次迭代中的资源申请量为: 42.43252038433839
# agent 50 在 1979 次迭代中的资源申请量为: 40.65849147409737
# agent 51 在 1979 次迭代中的资源申请量为: 47.99018976891685
# agent 52 在 1979 次迭代中的资源申请量为: 55.3271420410579
# agent 53 在 1979 次迭代中的资源申请量为: 38.72383402809225
# agent 54 在 1979 次迭代中的资源申请量为: 56.5271420410579
# agent 55 在 1979 次迭代中的资源申请量为: 70.48528465337529
# agent 56 在 1979 次迭代中的资源申请量为: 40.65849147409737
# agent 57 在 1979 次迭代中的资源申请量为: 59.98773721114606
# agent 58 在 1979 次迭代中的资源申请量为: 41.932520384338396
# agent 59 在 1979 次迭代中的资源申请量为: 47.590189768916844
# agent 60 在 1979 次迭代中的资源申请量为: 55.6271420410579
# agent 61 在 1979 次迭代中的资源申请量为: 65.4593496848866
# agent 62 在 1979 次迭代中的资源申请量为: 45.790802908359545
# agent 63 在 1979 次迭代中的资源申请量为: 38.72383402809225
# agent 64 在 1979 次迭代中的资源申请量为: 44.090802908359535
# agent 65 在 1979 次迭代中的资源申请量为: 42.43252038433839
# agent 66 在 1979 次迭代中的资源申请量为: 65.1593496848866
# agent 67 在 1979 次迭代中的资源申请量为: 43.03252038433839
# agent 68 在 1979 次迭代中的资源申请量为: 44.59080290835954
# agent 69 在 1979 次迭代中的资源申请量为: 45.09080290835954
# agent 70 在 1979 次迭代中的资源申请量为: 59.587737211146056
# agent 71 在 1979 次迭代中的资源申请量为: 71.48528465337529
# agent 72 在 1979 次迭代中的资源申请量为: 59.78773721114605
# agent 73 在 1979 次迭代中的资源申请量为: 43.432520384338396
# agent 74 在 1979 次迭代中的资源申请量为: 38.72383402809225
# agent 75 在 1979 次迭代中的资源申请量为: 51.60377475241091
# agent 76 在 1979 次迭代中的资源申请量为: 46.690802908359544
# agent 77 在 1979 次迭代中的资源申请量为: 40.55849147409737
# agent 78 在 1979 次迭代中的资源申请量为: 49.29018976891684
# agent 79 在 1979 次迭代中的资源申请量为: 42.53252038433839
# agent 80 在 1979 次迭代中的资源申请量为: 42.73252038433839
# agent 81 在 1979 次迭代中的资源申请量为: 39.22383402809225
# agent 82 在 1979 次迭代中的资源申请量为: 45.39080290835955
# agent 83 在 1979 次迭代中的资源申请量为: 41.35849147409737
# agent 84 在 1979 次迭代中的资源申请量为: 51.70377475241091
# agent 85 在 1979 次迭代中的资源申请量为: 55.3271420410579
# agent 86 在 1979 次迭代中的资源申请量为: 48.590189768916844
# agent 87 在 1979 次迭代中的资源申请量为: 59.98773721114606
# agent 88 在 1979 次迭代中的资源申请量为: 64.6593496848866
# agent 89 在 1979 次迭代中的资源申请量为: 40.25849147409737
# agent 90 在 1979 次迭代中的资源申请量为: 58.78773721114605
# agent 91 在 1979 次迭代中的资源申请量为: 42.63252038433839
# agent 92 在 1979 次迭代中的资源申请量为: 56.5271420410579
# agent 93 在 1979 次迭代中的资源申请量为: 40.45849147409737
# agent 94 在 1979 次迭代中的资源申请量为: 72.3120812707896
# agent 95 在 1979 次迭代中的资源申请量为: 59.88773721114608
# agent 96 在 1979 次迭代中的资源申请量为: 60.08773721114608
# agent 97 在 1979 次迭代中的资源申请量为: 71.68528465337529
# agent 98 在 1979 次迭代中的资源申请量为: 72.48528465337532
# agent 99 在 1979 次迭代中的资源申请量为: 52.10377475241095
# agent 100 在 1979 次迭代中的资源申请量为: 48.19018976891688
# 资源申请量总和为: 5000.000000000159
# ****************************************************************************
# 成本总和为: 334087.9140803464
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1989 次迭代中的结果：
# agent 1 在 1989 次迭代中的资源申请量为: 48.09018976891687
# agent 2 在 1989 次迭代中的资源申请量为: 60.5877372111461
# agent 3 在 1989 次迭代中的资源申请量为: 43.53252038433841
# agent 4 在 1989 次迭代中的资源申请量为: 64.05934968488663
# agent 5 在 1989 次迭代中的资源申请量为: 64.85934968488662
# agent 6 在 1989 次迭代中的资源申请量为: 71.5852846533753
# agent 7 在 1989 次迭代中的资源申请量为: 39.22383402809225
# agent 8 在 1989 次迭代中的资源申请量为: 37.49264232668764
# agent 9 在 1989 次迭代中的资源申请量为: 42.832520384338395
# agent 10 在 1989 次迭代中的资源申请量为: 55.42714204105789
# agent 11 在 1989 次迭代中的资源申请量为: 45.19080290835954
# agent 12 在 1989 次迭代中的资源申请量为: 48.99018976891685
# agent 13 在 1989 次迭代中的资源申请量为: 65.3593496848866
# agent 14 在 1989 次迭代中的资源申请量为: 54.82714204105789
# agent 15 在 1989 次迭代中的资源申请量为: 43.23252038433839
# agent 16 在 1989 次迭代中的资源申请量为: 43.432520384338396
# agent 17 在 1989 次迭代中的资源申请量为: 44.59080290835954
# agent 18 在 1989 次迭代中的资源申请量为: 46.19080290835954
# agent 19 在 1989 次迭代中的资源申请量为: 41.058491474097366
# agent 20 在 1989 次迭代中的资源申请量为: 55.3271420410579
# agent 21 在 1989 次迭代中的资源申请量为: 38.523834028092246
# agent 22 在 1989 次迭代中的资源申请量为: 38.82383402809224
# agent 23 在 1989 次迭代中的资源申请量为: 47.49018976891685
# agent 24 在 1989 次迭代中的资源申请量为: 40.25849147409737
# agent 25 在 1989 次迭代中的资源申请量为: 44.89080290835954
# agent 26 在 1989 次迭代中的资源申请量为: 39.52383402809225
# agent 27 在 1989 次迭代中的资源申请量为: 65.0593496848866
# agent 28 在 1989 次迭代中的资源申请量为: 51.003774752410905
# agent 29 在 1989 次迭代中的资源申请量为: 40.55849147409737
# agent 30 在 1989 次迭代中的资源申请量为: 38.92383402809225
# agent 31 在 1989 次迭代中的资源申请量为: 59.98773721114606
# agent 32 在 1989 次迭代中的资源申请量为: 55.127142041057894
# agent 33 在 1989 次迭代中的资源申请量为: 41.35849147409737
# agent 34 在 1989 次迭代中的资源申请量为: 51.903774752410904
# agent 35 在 1989 次迭代中的资源申请量为: 38.62383402809225
# agent 36 在 1989 次迭代中的资源申请量为: 42.53252038433839
# agent 37 在 1989 次迭代中的资源申请量为: 52.20377475241091
# agent 38 在 1989 次迭代中的资源申请量为: 40.058491474097366
# agent 39 在 1989 次迭代中的资源申请量为: 43.03252038433839
# agent 40 在 1989 次迭代中的资源申请量为: 49.79018976891684
# agent 41 在 1989 次迭代中的资源申请量为: 65.75934968488659
# agent 42 在 1989 次迭代中的资源申请量为: 42.23252038433839
# agent 43 在 1989 次迭代中的资源申请量为: 51.403774752410904
# agent 44 在 1989 次迭代中的资源申请量为: 52.60377475241091
# agent 45 在 1989 次迭代中的资源申请量为: 47.89018976891685
# agent 46 在 1989 次迭代中的资源申请量为: 55.42714204105789
# agent 47 在 1989 次迭代中的资源申请量为: 45.59080290835954
# agent 48 在 1989 次迭代中的资源申请量为: 43.13252038433839
# agent 49 在 1989 次迭代中的资源申请量为: 42.43252038433839
# agent 50 在 1989 次迭代中的资源申请量为: 40.65849147409737
# agent 51 在 1989 次迭代中的资源申请量为: 47.99018976891685
# agent 52 在 1989 次迭代中的资源申请量为: 55.3271420410579
# agent 53 在 1989 次迭代中的资源申请量为: 38.72383402809225
# agent 54 在 1989 次迭代中的资源申请量为: 56.5271420410579
# agent 55 在 1989 次迭代中的资源申请量为: 70.48528465337529
# agent 56 在 1989 次迭代中的资源申请量为: 40.65849147409737
# agent 57 在 1989 次迭代中的资源申请量为: 59.98773721114606
# agent 58 在 1989 次迭代中的资源申请量为: 41.932520384338396
# agent 59 在 1989 次迭代中的资源申请量为: 47.590189768916844
# agent 60 在 1989 次迭代中的资源申请量为: 55.6271420410579
# agent 61 在 1989 次迭代中的资源申请量为: 65.4593496848866
# agent 62 在 1989 次迭代中的资源申请量为: 45.790802908359545
# agent 63 在 1989 次迭代中的资源申请量为: 38.72383402809225
# agent 64 在 1989 次迭代中的资源申请量为: 44.090802908359535
# agent 65 在 1989 次迭代中的资源申请量为: 42.43252038433839
# agent 66 在 1989 次迭代中的资源申请量为: 65.1593496848866
# agent 67 在 1989 次迭代中的资源申请量为: 43.03252038433839
# agent 68 在 1989 次迭代中的资源申请量为: 44.59080290835954
# agent 69 在 1989 次迭代中的资源申请量为: 45.09080290835954
# agent 70 在 1989 次迭代中的资源申请量为: 59.587737211146056
# agent 71 在 1989 次迭代中的资源申请量为: 71.48528465337529
# agent 72 在 1989 次迭代中的资源申请量为: 59.78773721114605
# agent 73 在 1989 次迭代中的资源申请量为: 43.432520384338396
# agent 74 在 1989 次迭代中的资源申请量为: 38.72383402809225
# agent 75 在 1989 次迭代中的资源申请量为: 51.60377475241091
# agent 76 在 1989 次迭代中的资源申请量为: 46.690802908359544
# agent 77 在 1989 次迭代中的资源申请量为: 40.55849147409737
# agent 78 在 1989 次迭代中的资源申请量为: 49.29018976891684
# agent 79 在 1989 次迭代中的资源申请量为: 42.53252038433839
# agent 80 在 1989 次迭代中的资源申请量为: 42.73252038433839
# agent 81 在 1989 次迭代中的资源申请量为: 39.22383402809225
# agent 82 在 1989 次迭代中的资源申请量为: 45.39080290835955
# agent 83 在 1989 次迭代中的资源申请量为: 41.35849147409737
# agent 84 在 1989 次迭代中的资源申请量为: 51.70377475241091
# agent 85 在 1989 次迭代中的资源申请量为: 55.3271420410579
# agent 86 在 1989 次迭代中的资源申请量为: 48.590189768916844
# agent 87 在 1989 次迭代中的资源申请量为: 59.98773721114606
# agent 88 在 1989 次迭代中的资源申请量为: 64.6593496848866
# agent 89 在 1989 次迭代中的资源申请量为: 40.25849147409737
# agent 90 在 1989 次迭代中的资源申请量为: 58.78773721114605
# agent 91 在 1989 次迭代中的资源申请量为: 42.63252038433839
# agent 92 在 1989 次迭代中的资源申请量为: 56.5271420410579
# agent 93 在 1989 次迭代中的资源申请量为: 40.45849147409737
# agent 94 在 1989 次迭代中的资源申请量为: 72.31208127078946
# agent 95 在 1989 次迭代中的资源申请量为: 59.88773721114608
# agent 96 在 1989 次迭代中的资源申请量为: 60.08773721114608
# agent 97 在 1989 次迭代中的资源申请量为: 71.68528465337529
# agent 98 在 1989 次迭代中的资源申请量为: 72.48528465337532
# agent 99 在 1989 次迭代中的资源申请量为: 52.10377475241095
# agent 100 在 1989 次迭代中的资源申请量为: 48.19018976891688
# 资源申请量总和为: 5000.000000000159
# ****************************************************************************
# 成本总和为: 334087.91408034635
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1999 次迭代中的结果：
# agent 1 在 1999 次迭代中的资源申请量为: 48.09018976891687
# agent 2 在 1999 次迭代中的资源申请量为: 60.5877372111461
# agent 3 在 1999 次迭代中的资源申请量为: 43.53252038433841
# agent 4 在 1999 次迭代中的资源申请量为: 64.05934968488663
# agent 5 在 1999 次迭代中的资源申请量为: 64.85934968488662
# agent 6 在 1999 次迭代中的资源申请量为: 71.5852846533753
# agent 7 在 1999 次迭代中的资源申请量为: 39.22383402809225
# agent 8 在 1999 次迭代中的资源申请量为: 37.49264232668764
# agent 9 在 1999 次迭代中的资源申请量为: 42.832520384338395
# agent 10 在 1999 次迭代中的资源申请量为: 55.42714204105789
# agent 11 在 1999 次迭代中的资源申请量为: 45.19080290835954
# agent 12 在 1999 次迭代中的资源申请量为: 48.99018976891685
# agent 13 在 1999 次迭代中的资源申请量为: 65.3593496848866
# agent 14 在 1999 次迭代中的资源申请量为: 54.82714204105789
# agent 15 在 1999 次迭代中的资源申请量为: 43.23252038433839
# agent 16 在 1999 次迭代中的资源申请量为: 43.432520384338396
# agent 17 在 1999 次迭代中的资源申请量为: 44.59080290835954
# agent 18 在 1999 次迭代中的资源申请量为: 46.19080290835954
# agent 19 在 1999 次迭代中的资源申请量为: 41.058491474097366
# agent 20 在 1999 次迭代中的资源申请量为: 55.3271420410579
# agent 21 在 1999 次迭代中的资源申请量为: 38.523834028092246
# agent 22 在 1999 次迭代中的资源申请量为: 38.82383402809224
# agent 23 在 1999 次迭代中的资源申请量为: 47.49018976891685
# agent 24 在 1999 次迭代中的资源申请量为: 40.25849147409737
# agent 25 在 1999 次迭代中的资源申请量为: 44.89080290835954
# agent 26 在 1999 次迭代中的资源申请量为: 39.52383402809225
# agent 27 在 1999 次迭代中的资源申请量为: 65.0593496848866
# agent 28 在 1999 次迭代中的资源申请量为: 51.003774752410905
# agent 29 在 1999 次迭代中的资源申请量为: 40.55849147409737
# agent 30 在 1999 次迭代中的资源申请量为: 38.92383402809225
# agent 31 在 1999 次迭代中的资源申请量为: 59.98773721114606
# agent 32 在 1999 次迭代中的资源申请量为: 55.127142041057894
# agent 33 在 1999 次迭代中的资源申请量为: 41.35849147409737
# agent 34 在 1999 次迭代中的资源申请量为: 51.903774752410904
# agent 35 在 1999 次迭代中的资源申请量为: 38.62383402809225
# agent 36 在 1999 次迭代中的资源申请量为: 42.53252038433839
# agent 37 在 1999 次迭代中的资源申请量为: 52.20377475241091
# agent 38 在 1999 次迭代中的资源申请量为: 40.058491474097366
# agent 39 在 1999 次迭代中的资源申请量为: 43.03252038433839
# agent 40 在 1999 次迭代中的资源申请量为: 49.79018976891684
# agent 41 在 1999 次迭代中的资源申请量为: 65.75934968488659
# agent 42 在 1999 次迭代中的资源申请量为: 42.23252038433839
# agent 43 在 1999 次迭代中的资源申请量为: 51.403774752410904
# agent 44 在 1999 次迭代中的资源申请量为: 52.60377475241091
# agent 45 在 1999 次迭代中的资源申请量为: 47.89018976891685
# agent 46 在 1999 次迭代中的资源申请量为: 55.42714204105789
# agent 47 在 1999 次迭代中的资源申请量为: 45.59080290835954
# agent 48 在 1999 次迭代中的资源申请量为: 43.13252038433839
# agent 49 在 1999 次迭代中的资源申请量为: 42.43252038433839
# agent 50 在 1999 次迭代中的资源申请量为: 40.65849147409737
# agent 51 在 1999 次迭代中的资源申请量为: 47.99018976891685
# agent 52 在 1999 次迭代中的资源申请量为: 55.3271420410579
# agent 53 在 1999 次迭代中的资源申请量为: 38.72383402809225
# agent 54 在 1999 次迭代中的资源申请量为: 56.5271420410579
# agent 55 在 1999 次迭代中的资源申请量为: 70.48528465337529
# agent 56 在 1999 次迭代中的资源申请量为: 40.65849147409737
# agent 57 在 1999 次迭代中的资源申请量为: 59.98773721114606
# agent 58 在 1999 次迭代中的资源申请量为: 41.932520384338396
# agent 59 在 1999 次迭代中的资源申请量为: 47.590189768916844
# agent 60 在 1999 次迭代中的资源申请量为: 55.6271420410579
# agent 61 在 1999 次迭代中的资源申请量为: 65.4593496848866
# agent 62 在 1999 次迭代中的资源申请量为: 45.790802908359545
# agent 63 在 1999 次迭代中的资源申请量为: 38.72383402809225
# agent 64 在 1999 次迭代中的资源申请量为: 44.090802908359535
# agent 65 在 1999 次迭代中的资源申请量为: 42.43252038433839
# agent 66 在 1999 次迭代中的资源申请量为: 65.1593496848866
# agent 67 在 1999 次迭代中的资源申请量为: 43.03252038433839
# agent 68 在 1999 次迭代中的资源申请量为: 44.59080290835954
# agent 69 在 1999 次迭代中的资源申请量为: 45.09080290835954
# agent 70 在 1999 次迭代中的资源申请量为: 59.587737211146056
# agent 71 在 1999 次迭代中的资源申请量为: 71.48528465337529
# agent 72 在 1999 次迭代中的资源申请量为: 59.78773721114605
# agent 73 在 1999 次迭代中的资源申请量为: 43.432520384338396
# agent 74 在 1999 次迭代中的资源申请量为: 38.72383402809225
# agent 75 在 1999 次迭代中的资源申请量为: 51.60377475241091
# agent 76 在 1999 次迭代中的资源申请量为: 46.690802908359544
# agent 77 在 1999 次迭代中的资源申请量为: 40.55849147409737
# agent 78 在 1999 次迭代中的资源申请量为: 49.29018976891684
# agent 79 在 1999 次迭代中的资源申请量为: 42.53252038433839
# agent 80 在 1999 次迭代中的资源申请量为: 42.73252038433839
# agent 81 在 1999 次迭代中的资源申请量为: 39.22383402809225
# agent 82 在 1999 次迭代中的资源申请量为: 45.39080290835955
# agent 83 在 1999 次迭代中的资源申请量为: 41.35849147409737
# agent 84 在 1999 次迭代中的资源申请量为: 51.70377475241091
# agent 85 在 1999 次迭代中的资源申请量为: 55.3271420410579
# agent 86 在 1999 次迭代中的资源申请量为: 48.590189768916844
# agent 87 在 1999 次迭代中的资源申请量为: 59.98773721114606
# agent 88 在 1999 次迭代中的资源申请量为: 64.6593496848866
# agent 89 在 1999 次迭代中的资源申请量为: 40.25849147409737
# agent 90 在 1999 次迭代中的资源申请量为: 58.78773721114605
# agent 91 在 1999 次迭代中的资源申请量为: 42.63252038433839
# agent 92 在 1999 次迭代中的资源申请量为: 56.5271420410579
# agent 93 在 1999 次迭代中的资源申请量为: 40.45849147409737
# agent 94 在 1999 次迭代中的资源申请量为: 72.31208127078932
# agent 95 在 1999 次迭代中的资源申请量为: 59.88773721114608
# agent 96 在 1999 次迭代中的资源申请量为: 60.08773721114608
# agent 97 在 1999 次迭代中的资源申请量为: 71.68528465337529
# agent 98 在 1999 次迭代中的资源申请量为: 72.48528465337532
# agent 99 在 1999 次迭代中的资源申请量为: 52.10377475241095
# agent 100 在 1999 次迭代中的资源申请量为: 48.19018976891688
# 资源申请量总和为: 5000.000000000159
# ****************************************************************************
# 成本总和为: 334087.91408034635
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 2025-01-21 17:26:22.343

# %%
np.savetxt('../data/03-6-bias-agent-robust_agent_resource_quantity_small_value_Gaussian_bias(50,10).txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/03-6-bias-agent-robust_sum_cost_small_value_Gaussian_bias(50,10).txt',sum_cost,fmt='%0.8f')#用户成本总和 
np.savetxt('../data/03-6-bias-agent-robust_sum_resource_small_value_Gaussian_bias(50,10).txt',sum_resource,fmt='%0.8f')#用户资源总和 
np.savetxt('../data/03-6-bias-agent-robust_agent_gradient_small_value_Gaussian_bias(50,10).txt',agent_gradient,fmt='%0.8f')#用户迭代梯度
