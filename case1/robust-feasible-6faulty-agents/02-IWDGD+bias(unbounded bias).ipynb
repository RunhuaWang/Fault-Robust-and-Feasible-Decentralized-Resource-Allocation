# %% [raw]
# 基于初始化的权重梯度下降无中心资源分配算法+部分用户的梯度计算有误差（设备损坏导致的计算误差）

# %% [raw]
# 无界的噪声 设计噪声递增

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(100,1000), dtype=np.float64) 
sum_resource=np.zeros(shape=(1,1000), dtype=np.float64)
sum_cost=np.zeros(shape=(1,1000), dtype=np.float64)
iteration_update = 0.01
A=np.loadtxt("100_Network_Topology_Double_Random_Adjacency_Matrix_Degree_15.txt") #网络拓扑的邻接矩阵 对角元素要为0
D=np.zeros(shape=(100,100))# 网络的度矩阵
L=np.zeros(shape=(100,100))# 网络的拉普拉斯矩阵 L=D-A
W=np.zeros(shape=(100,100)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
iteration=[]
a=np.loadtxt("100_uniform_distribution_(1,2)_point1.txt")
b=np.loadtxt("100_normal_distribution_(2,0.6)_point1.txt")
agent_gradient=np.zeros(shape=(100,1000), dtype=np.float64) 
bias=0

# %%
#根据邻接矩阵生成网络对应的度矩阵
for i in range(0,100):
    d=0
    for j in range(0,100):
        if A[i][j]==1:
            d=d+1
    D[i][i]=d

#根据邻接矩阵和度矩阵计算拉普拉斯矩阵
L=D-A

#选择用拉普拉斯矩阵作为聚合矩阵
W=L
    
#资源量的初始化 需要给定可行的初始化 即满足平均资源约束
for i in range (0,100):
    agent_resource_quantity[i][0]=50
    
#资源量总和 初始化
sum=0
for i in range (0,100):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

iteration.append(0)

#初始梯度计算 选择三个用户作为带有噪声
for i in range (0,100):
    if i==7 or i==20 or i==34 or i==47 or i==52 or i==88:
        agent_gradient[i][0]=2*a[i]*agent_resource_quantity[i][0]-2*a[i]*b[i]+bias
    else:
        agent_gradient[i][0]=2*a[i]*agent_resource_quantity[i][0]-2*a[i]*b[i]

#诚实用户成本总和初始化
sum=0
for i in range(0,100):
    sum=sum+a[i]*(agent_resource_quantity[i][0]-b[i])*(agent_resource_quantity[i][0]-b[i])
sum_cost[0][0]=sum

# %%
#基于初始化的权重梯度下降无中心资源分配算法
def IWDGD_deterministic_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias):
    
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************IWDGD算法+计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,100):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):#迭代次数
        iteration.append(k)
 
        #所有用户资源申请量基于可行初始化权重梯度下降的迭代  假设部分用户因为设备损坏 导致梯度的计算有误差     
        for i in range (0,100):
            weight_gradient_sum = np.float64(0)
            for j in range (0,100):        
                weight_gradient_sum=weight_gradient_sum+W[i][j]*agent_gradient[j][k-1]
            #weight_gradient_sum = np.round(weight_gradient_sum, decimals=3)
            agent_resource_quantity[i][k]=agent_resource_quantity[i][k-1]-iteration_update*weight_gradient_sum
                #agent_resource_quantity[i][k] = np.round(agent_resource_quantity[i][k], decimals=3)
        
        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,100):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,100):
            sum2=sum2+a[i]*(agent_resource_quantity[i][k]-b[i])*(agent_resource_quantity[i][k]-b[i])
        sum_cost[0][k]=sum2

        #设计递增的噪声
        bias=k
        #计算当前迭代的用户梯度
        for i in range (0,100): 
            if i==7 or i==20 or i==34 or i==47 or i==52 or i==88:
                agent_gradient[i][k]=2*a[i]*agent_resource_quantity[i][k]-2*a[i]*b[i]+bias
            else:
                agent_gradient[i][k]=2*a[i]*agent_resource_quantity[i][k]-2*a[i]*b[i]
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%50==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,100):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=1/(pow(k+1,0.5)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
IWDGD_deterministic_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias)
# Out:
# ****************************IWDGD算法+计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 50.0
# agent 2 的初始资源申请量为: 50.0
# agent 3 的初始资源申请量为: 50.0
# agent 4 的初始资源申请量为: 50.0
# agent 5 的初始资源申请量为: 50.0
# agent 6 的初始资源申请量为: 50.0
# agent 7 的初始资源申请量为: 50.0
# agent 8 的初始资源申请量为: 50.0
# agent 9 的初始资源申请量为: 50.0
# agent 10 的初始资源申请量为: 50.0
# agent 11 的初始资源申请量为: 50.0
# agent 12 的初始资源申请量为: 50.0
# agent 13 的初始资源申请量为: 50.0
# agent 14 的初始资源申请量为: 50.0
# agent 15 的初始资源申请量为: 50.0
# agent 16 的初始资源申请量为: 50.0
# agent 17 的初始资源申请量为: 50.0
# agent 18 的初始资源申请量为: 50.0
# agent 19 的初始资源申请量为: 50.0
# agent 20 的初始资源申请量为: 50.0
# agent 21 的初始资源申请量为: 50.0
# agent 22 的初始资源申请量为: 50.0
# agent 23 的初始资源申请量为: 50.0
# agent 24 的初始资源申请量为: 50.0
# agent 25 的初始资源申请量为: 50.0
# agent 26 的初始资源申请量为: 50.0
# agent 27 的初始资源申请量为: 50.0
# agent 28 的初始资源申请量为: 50.0
# agent 29 的初始资源申请量为: 50.0
# agent 30 的初始资源申请量为: 50.0
# agent 31 的初始资源申请量为: 50.0
# agent 32 的初始资源申请量为: 50.0
# agent 33 的初始资源申请量为: 50.0
# agent 34 的初始资源申请量为: 50.0
# agent 35 的初始资源申请量为: 50.0
# agent 36 的初始资源申请量为: 50.0
# agent 37 的初始资源申请量为: 50.0
# agent 38 的初始资源申请量为: 50.0
# agent 39 的初始资源申请量为: 50.0
# agent 40 的初始资源申请量为: 50.0
# agent 41 的初始资源申请量为: 50.0
# agent 42 的初始资源申请量为: 50.0
# agent 43 的初始资源申请量为: 50.0
# agent 44 的初始资源申请量为: 50.0
# agent 45 的初始资源申请量为: 50.0
# agent 46 的初始资源申请量为: 50.0
# agent 47 的初始资源申请量为: 50.0
# agent 48 的初始资源申请量为: 50.0
# agent 49 的初始资源申请量为: 50.0
# agent 50 的初始资源申请量为: 50.0
# agent 51 的初始资源申请量为: 50.0
# agent 52 的初始资源申请量为: 50.0
# agent 53 的初始资源申请量为: 50.0
# agent 54 的初始资源申请量为: 50.0
# agent 55 的初始资源申请量为: 50.0
# agent 56 的初始资源申请量为: 50.0
# agent 57 的初始资源申请量为: 50.0
# agent 58 的初始资源申请量为: 50.0
# agent 59 的初始资源申请量为: 50.0
# agent 60 的初始资源申请量为: 50.0
# agent 61 的初始资源申请量为: 50.0
# agent 62 的初始资源申请量为: 50.0
# agent 63 的初始资源申请量为: 50.0
# agent 64 的初始资源申请量为: 50.0
# agent 65 的初始资源申请量为: 50.0
# agent 66 的初始资源申请量为: 50.0
# agent 67 的初始资源申请量为: 50.0
# agent 68 的初始资源申请量为: 50.0
# agent 69 的初始资源申请量为: 50.0
# agent 70 的初始资源申请量为: 50.0
# agent 71 的初始资源申请量为: 50.0
# agent 72 的初始资源申请量为: 50.0
# agent 73 的初始资源申请量为: 50.0
# agent 74 的初始资源申请量为: 50.0
# agent 75 的初始资源申请量为: 50.0
# agent 76 的初始资源申请量为: 50.0
# agent 77 的初始资源申请量为: 50.0
# agent 78 的初始资源申请量为: 50.0
# agent 79 的初始资源申请量为: 50.0
# agent 80 的初始资源申请量为: 50.0
# agent 81 的初始资源申请量为: 50.0
# agent 82 的初始资源申请量为: 50.0
# agent 83 的初始资源申请量为: 50.0
# agent 84 的初始资源申请量为: 50.0
# agent 85 的初始资源申请量为: 50.0
# agent 86 的初始资源申请量为: 50.0
# agent 87 的初始资源申请量为: 50.0
# agent 88 的初始资源申请量为: 50.0
# agent 89 的初始资源申请量为: 50.0
# agent 90 的初始资源申请量为: 50.0
# agent 91 的初始资源申请量为: 50.0
# agent 92 的初始资源申请量为: 50.0
# agent 93 的初始资源申请量为: 50.0
# agent 94 的初始资源申请量为: 50.0
# agent 95 的初始资源申请量为: 50.0
# agent 96 的初始资源申请量为: 50.0
# agent 97 的初始资源申请量为: 50.0
# agent 98 的初始资源申请量为: 50.0
# agent 99 的初始资源申请量为: 50.0
# agent 100 的初始资源申请量为: 50.0
# *************************
# 初始资源申请量总和为: 5000.0
# *************************
# 初始成本总和为: 346654.5889999999
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 49 次迭代中的结果：
# agent 1 在 49 次迭代中的资源申请量为: 48.82193785748661
# agent 2 在 49 次迭代中的资源申请量为: 61.48947603629795
# agent 3 在 49 次迭代中的资源申请量为: 44.178939126386545
# agent 4 在 49 次迭代中的资源申请量为: 64.98744327748045
# agent 5 在 49 次迭代中的资源申请量为: 65.78610957290513
# agent 6 在 49 次迭代中的资源申请量为: 72.66672468928199
# agent 7 在 49 次迭代中的资源申请量为: 39.84711193958827
# agent 8 在 49 次迭代中的资源申请量为: 26.259906108948343
# agent 9 在 49 次迭代中的资源申请量为: 43.53267206763907
# agent 10 在 49 次迭代中的资源申请量为: 56.26701401652518
# agent 11 在 49 次迭代中的资源申请量为: 45.88284510267365
# agent 12 在 49 次迭代中的资源申请量为: 49.81309135394697
# agent 13 在 49 次迭代中的资源申请量为: 66.36503263718245
# agent 14 在 49 次迭代中的资源申请量为: 55.647349403934946
# agent 15 在 49 次迭代中的资源申请量为: 43.84666061868674
# agent 16 在 49 次迭代中的资源申请量为: 44.03096504619126
# agent 17 在 49 次迭代中的资源申请量为: 45.33178805864464
# agent 18 在 49 次迭代中的资源申请量为: 46.87069401112443
# agent 19 在 49 次迭代中的资源申请量为: 41.68603038356376
# agent 20 在 49 次迭代中的资源申请量为: 56.23120882937047
# agent 21 在 49 次迭代中的资源申请量为: 26.66345596815293
# agent 22 在 49 次迭代中的资源申请量为: 39.44741389918686
# agent 23 在 49 次迭代中的资源申请量为: 48.19403575568141
# agent 24 在 49 次迭代中的资源申请量为: 40.83027628410936
# agent 25 在 49 次迭代中的资源申请量为: 45.54040170363976
# agent 26 在 49 次迭代中的资源申请量为: 40.146974342555815
# agent 27 在 49 次迭代中的资源申请量为: 66.03801724757383
# agent 28 在 49 次迭代中的资源申请量为: 51.75038337151814
# agent 29 在 49 次迭代中的资源申请量为: 41.14266482318047
# agent 30 在 49 次迭代中的资源申请量为: 39.55132738074867
# agent 31 在 49 次迭代中的资源申请量为: 60.88801653179874
# agent 32 在 49 次迭代中的资源申请量为: 55.896446953388946
# agent 33 在 49 次迭代中的资源申请量为: 41.935766499884146
# agent 34 在 49 次迭代中的资源申请量为: 52.729662101142885
# agent 35 在 49 次迭代中的资源申请量为: 26.77862543403055
# agent 36 在 49 次迭代中的资源申请量为: 43.2179404313384
# agent 37 在 49 次迭代中的资源申请量为: 52.93788688747017
# agent 38 在 49 次迭代中的资源申请量为: 40.626249114417654
# agent 39 在 49 次迭代中的资源申请量为: 43.64559552751039
# agent 40 在 49 次迭代中的资源申请量为: 50.580726150185136
# agent 41 在 49 次迭代中的资源申请量为: 66.82236322571171
# agent 42 在 49 次迭代中的资源申请量为: 42.845696726472376
# agent 43 在 49 次迭代中的资源申请量为: 52.12398049366517
# agent 44 在 49 次迭代中的资源申请量为: 53.323379352198494
# agent 45 在 49 次迭代中的资源申请量为: 48.57092272199935
# agent 46 在 49 次迭代中的资源申请量为: 56.3904196335077
# agent 47 在 49 次迭代中的资源申请量为: 46.33167871805414
# agent 48 在 49 次迭代中的资源申请量为: 29.975370370850932
# agent 49 在 49 次迭代中的资源申请量为: 43.07205487195361
# agent 50 在 49 次迭代中的资源申请量为: 41.22945218598846
# agent 51 在 49 次迭代中的资源申请量为: 48.77645880818395
# agent 52 在 49 次迭代中的资源申请量为: 56.16319539462833
# agent 53 在 49 次迭代中的资源申请量为: 26.872390362117468
# agent 54 在 49 次迭代中的资源申请量为: 57.42289072555574
# agent 55 在 49 次迭代中的资源申请量为: 71.56017255446562
# agent 56 在 49 次迭代中的资源申请量为: 41.22978611176444
# agent 57 在 49 次迭代中的资源申请量为: 61.00298246186487
# agent 58 在 49 次迭代中的资源申请量为: 42.58491429213481
# agent 59 在 49 次迭代中的资源申请量为: 48.356181314440896
# agent 60 在 49 次迭代中的资源申请量为: 56.51743146690759
# agent 61 在 49 次迭代中的资源申请量为: 66.45163774570942
# agent 62 在 49 次迭代中的资源申请量为: 46.484207697321615
# agent 63 在 49 次迭代中的资源申请量为: 39.314900869176554
# agent 64 在 49 次迭代中的资源申请量为: 44.75646610750583
# agent 65 在 49 次迭代中的资源申请量为: 43.03199121883428
# agent 66 在 49 次迭代中的资源申请量为: 66.15267055735795
# agent 67 在 49 次迭代中的资源申请量为: 43.680196440284114
# agent 68 在 49 次迭代中的资源申请量为: 45.245006265076306
# agent 69 在 49 次迭代中的资源申请量为: 45.73424273044071
# agent 70 在 49 次迭代中的资源申请量为: 60.459241281105314
# agent 71 在 49 次迭代中的资源申请量为: 72.56475112121973
# agent 72 在 49 次迭代中的资源申请量为: 60.69931969771298
# agent 73 在 49 次迭代中的资源申请量为: 44.084116251975225
# agent 74 在 49 次迭代中的资源申请量为: 39.27327351542194
# agent 75 在 49 次迭代中的资源申请量为: 52.422591194856885
# agent 76 在 49 次迭代中的资源申请量为: 47.33991227070081
# agent 77 在 49 次迭代中的资源申请量为: 41.17554911134225
# agent 78 在 49 次迭代中的资源申请量为: 49.9846667265885
# agent 79 在 49 次迭代中的资源申请量为: 43.232548126419516
# agent 80 在 49 次迭代中的资源申请量为: 43.3384165082061
# agent 81 在 49 次迭代中的资源申请量为: 39.81360471913086
# agent 82 在 49 次迭代中的资源申请量为: 46.09867799787914
# agent 83 在 49 次迭代中的资源申请量为: 41.951115264025084
# agent 84 在 49 次迭代中的资源申请量为: 52.53018364048802
# agent 85 在 49 次迭代中的资源申请量为: 56.11796925776963
# agent 86 在 49 次迭代中的资源申请量为: 49.321765327903634
# agent 87 在 49 次迭代中的资源申请量为: 60.947564297969514
# agent 88 在 49 次迭代中的资源申请量为: 65.71930438677649
# agent 89 在 49 次迭代中的资源申请量为: 27.77931451231479
# agent 90 在 49 次迭代中的资源申请量为: 59.69394001227063
# agent 91 在 49 次迭代中的资源申请量为: 43.2451171146077
# agent 92 在 49 次迭代中的资源申请量为: 57.364971958808546
# agent 93 在 49 次迭代中的资源申请量为: 41.043904344290524
# agent 94 在 49 次迭代中的资源申请量为: 73.82134219104034
# agent 95 在 49 次迭代中的资源申请量为: 60.852934742154865
# agent 96 在 49 次迭代中的资源申请量为: 61.00933480807825
# agent 97 在 49 次迭代中的资源申请量为: 72.68791105692152
# agent 98 在 49 次迭代中的资源申请量为: 73.62284939856286
# agent 99 在 49 次迭代中的资源申请量为: 52.828529361720584
# agent 100 在 49 次迭代中的资源申请量为: 48.86737183219228
# 资源申请量总和为: 5000.000000000002
# ****************************************************************************
# 成本总和为: 335794.61363493494
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: 49.6002859836878
# agent 2 在 99 次迭代中的资源申请量为: 62.462421520989004
# agent 3 在 99 次迭代中的资源申请量为: 44.865723041360994
# agent 4 在 99 次迭代中的资源申请量为: 66.04884951023043
# agent 5 在 99 次迭代中的资源申请量为: 66.84752709869763
# agent 6 在 99 次迭代中的资源申请量为: 73.83431735256684
# agent 7 在 99 次迭代中的资源申请量为: 40.4616107673514
# agent 8 在 99 次迭代中的资源申请量为: 14.343672823974059
# agent 9 在 99 次迭代中的资源申请量为: 44.21946084444761
# agent 10 在 99 次迭代中的资源申请量为: 57.16511711412442
# agent 11 在 99 次迭代中的资源申请量为: 46.612561679712755
# agent 12 在 99 次迭代中的资源申请量为: 50.591454030196516
# agent 13 在 99 次迭代中的资源申请量为: 67.42641694972268
# agent 14 在 99 次迭代中的资源申请量为: 56.54543959453233
# agent 15 在 99 次迭代中的资源申请量为: 44.53344462584967
# agent 16 在 99 次迭代中的资源申请量为: 44.717755691214414
# agent 17 在 99 次迭代中的资源申请量为: 46.06149565656976
# agent 18 在 99 次迭代中的资源申请量为: 47.60040966016923
# agent 19 在 99 次迭代中的资源申请量为: 42.33465995865925
# agent 20 在 99 次迭代中的资源申请量为: 57.12932300729508
# agent 21 在 99 次迭代中的资源申请量为: 14.120053741399499
# agent 22 在 99 次迭代中的资源申请量为: 40.0619102799851
# agent 23 在 99 次迭代中的资源申请量为: 48.97238600789129
# agent 24 在 99 次迭代中的资源申请量为: 41.47889957380032
# agent 25 在 99 次迭代中的资源申请量为: 46.27010983572963
# agent 26 在 99 次迭代中的资源申请量为: 40.761466596363675
# agent 27 在 99 次迭代中的资源申请量为: 67.09939745501528
# agent 28 在 99 次迭代中的资源申请量为: 52.58433710273441
# agent 29 在 99 次迭代中的资源申请量为: 41.791291276006184
# agent 30 在 99 次迭代中的资源申请量为: 40.16581813777127
# agent 31 在 99 次迭代中的资源申请量为: 61.86095395784023
# agent 32 在 99 次迭代中的资源申请量为: 56.79453571711759
# agent 33 在 99 次迭代中的资源申请量为: 42.58439551079143
# agent 34 在 99 次迭代中的资源申请量为: 53.56361449288018
# agent 35 在 99 次迭代中的资源申请量为: 14.23522528692244
# agent 36 在 99 次迭代中的资源申请量为: 43.90473508512274
# agent 37 在 99 次迭代中的资源申请量为: 53.77184444318577
# agent 38 在 99 次迭代中的资源申请量为: 41.27487819250921
# agent 39 在 99 次迭代中的资源申请量为: 44.33238332888415
# agent 40 在 99 次迭代中的资源申请量为: 51.35909144201015
# agent 41 在 99 次迭代中的资源申请量为: 67.88377776786602
# agent 42 在 99 次迭代中的资源申请量为: 43.53248291151242
# agent 43 在 99 次迭代中的资源申请量为: 52.95794599408541
# agent 44 在 99 次迭代中的资源申请量为: 54.15733589887334
# agent 45 在 99 次迭代中的资源申请量为: 49.34927487988696
# agent 46 在 99 次迭代中的资源申请量为: 57.28853159036906
# agent 47 在 99 次迭代中的资源申请量为: 47.0613882315973
# agent 48 在 99 次迭代中的资源申请量为: 15.956274258296798
# agent 49 在 99 次迭代中的资源申请量为: 43.75885026720608
# agent 50 在 99 次迭代中的资源申请量为: 41.87808457001836
# agent 51 在 99 次迭代中的资源申请量为: 49.554824193522585
# agent 52 在 99 次迭代中的资源申请量为: 57.06129785801034
# agent 53 在 99 次迭代中的资源申请量为: 14.32899234372299
# agent 54 在 99 次迭代中的资源申请量为: 58.32098759229862
# agent 55 在 99 次迭代中的资源申请量为: 72.72769844626127
# agent 56 在 99 次迭代中的资源申请量为: 41.87841450175024
# agent 57 在 99 次迭代中的资源申请量为: 61.97592737567151
# agent 58 在 99 次迭代中的资源申请量为: 43.27169416471184
# agent 59 在 99 次迭代中的资源申请量为: 49.13454236706598
# agent 60 在 99 次迭代中的资源申请量为: 57.41554201893577
# agent 61 在 99 次迭代中的资源申请量为: 67.51305747340164
# agent 62 在 99 次迭代中的资源申请量为: 47.21392130952192
# agent 63 在 99 次迭代中的资源申请量为: 39.92939815010314
# agent 64 在 99 次迭代中的资源申请量为: 45.4861800136144
# agent 65 在 99 次迭代中的资源申请量为: 43.7187782571654
# agent 66 在 99 次迭代中的资源申请量为: 67.21409571236882
# agent 67 在 99 次迭代中的资源申请量为: 44.36699108675971
# agent 68 在 99 次迭代中的资源申请量为: 45.97472518414127
# agent 69 在 99 次迭代中的资源申请量为: 46.46396107245339
# agent 70 在 99 次迭代中的资源申请量为: 61.432202774786006
# agent 71 在 99 次迭代中的资源申请量为: 73.7323366148779
# agent 72 在 99 次迭代中的资源申请量为: 61.6722676531296
# agent 73 在 99 次迭代中的资源申请量为: 44.770905785430685
# agent 74 在 99 次迭代中的资源申请量为: 39.88776258561655
# agent 75 在 99 次迭代中的资源申请量为: 53.25654477230449
# agent 76 在 99 次迭代中的资源申请量为: 48.06961918280202
# agent 77 在 99 次迭代中的资源申请量为: 41.82417962354265
# agent 78 在 99 次迭代中的资源申请量为: 50.76301665598884
# agent 79 在 99 次迭代中的资源申请量为: 43.91933442025804
# agent 80 在 99 次迭代中的资源申请量为: 44.02519910254989
# agent 81 在 99 次迭代中的资源申请量为: 40.42809039217593
# agent 82 在 99 次迭代中的资源申请量为: 46.82838754722398
# agent 83 在 99 次迭代中的资源申请量为: 42.59974502898061
# agent 84 在 99 次迭代中的资源申请量为: 53.36413591625686
# agent 85 在 99 次迭代中的资源申请量为: 57.016080316610484
# agent 86 在 99 次迭代中的资源申请量为: 50.10012304443197
# agent 87 在 99 次迭代中的资源申请量为: 61.92051678849464
# agent 88 在 99 次迭代中的资源申请量为: 66.78073345417583
# agent 89 在 99 次迭代中的资源申请量为: 14.539067020118805
# agent 90 在 99 次迭代中的资源申请量为: 60.6668832006671
# agent 91 在 99 次迭代中的资源申请量为: 43.93190434466737
# agent 92 在 99 次迭代中的资源申请量为: 58.26307344481851
# agent 93 在 99 次迭代中的资源申请量为: 41.692533783612305
# agent 94 在 99 次迭代中的资源申请量为: 74.98887224934786
# agent 95 在 99 次迭代中的资源申请量为: 61.82587816482902
# agent 96 在 99 次迭代中的资源申请量为: 61.982284767697216
# agent 97 在 99 次迭代中的资源申请量为: 73.85547669626905
# agent 98 在 99 次迭代中的资源申请量为: 74.79038509535415
# agent 99 在 99 次迭代中的资源申请量为: 53.662480591613374
# agent 100 在 99 次迭代中的资源申请量为: 49.64572911486336
# 资源申请量总和为: 5000.000000000001
# ****************************************************************************
# 成本总和为: 341335.19110991573
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 149 次迭代中的结果：
# agent 1 在 149 次迭代中的资源申请量为: 50.37864596516421
# agent 2 在 149 次迭代中的资源申请量为: 63.43537149787876
# agent 3 在 149 次迭代中的资源申请量为: 45.552511260335685
# agent 4 在 149 次迭代中的资源申请量为: 67.11024948506112
# agent 5 在 149 次迭代中的资源申请量为: 67.90892707356237
# agent 6 在 149 次迭代中的资源申请量为: 75.00185732502919
# agent 7 在 149 次迭代中的资源申请量为: 41.076105489616666
# agent 8 在 149 次迭代中的资源申请量为: 2.427442810095517
# agent 9 在 149 次迭代中的资源申请量为: 44.90624906343303
# agent 10 在 149 次迭代中的资源申请量为: 58.063224785100914
# agent 11 在 149 次迭代中的资源申请量为: 47.34227416240157
# agent 12 在 149 次迭代中的资源申请量为: 51.369814011714475
# agent 13 在 149 次迭代中的资源申请量为: 68.48781692445353
# agent 14 在 149 次迭代中的资源申请量为: 57.44354726545633
# agent 15 在 149 次迭代中的资源申请量为: 45.22023284482647
# agent 16 在 149 次迭代中的资源申请量为: 45.40454391020882
# agent 17 在 149 次迭代中的资源申请量为: 46.79120813922532
# agent 18 在 149 次迭代中的资源申请量为: 48.3301221428573
# agent 19 在 149 次迭代中的资源申请量为: 42.98329327657732
# agent 20 在 149 次迭代中的资源申请量为: 58.02743067830488
# agent 21 在 149 次迭代中的资源申请量为: 1.5766537268025709
# agent 22 在 149 次迭代中的资源申请量为: 40.67640500224095
# agent 23 在 149 次迭代中的资源申请量为: 49.75074598938174
# agent 24 在 149 次迭代中的资源申请量为: 42.127532891700746
# agent 25 在 149 次迭代中的资源申请量为: 46.9998223183882
# agent 26 在 149 次迭代中的资源申请量为: 41.375961318606805
# agent 27 在 149 次迭代中的资源申请量为: 68.16079742972289
# agent 28 在 149 次迭代中的资源申请量为: 53.41829422576248
# agent 29 在 149 次迭代中的资源申请量为: 42.43992459390851
# agent 30 在 149 次迭代中的资源申请量为: 40.78031286000958
# agent 31 在 149 次迭代中的资源申请量为: 62.83390393470091
# agent 32 在 149 次迭代中的资源申请量为: 57.692643388034625
# agent 33 在 149 次迭代中的资源申请量为: 43.23302882869924
# agent 34 在 149 次迭代中的资源申请量为: 54.39757161591966
# agent 35 在 149 次迭代中的资源申请量为: 1.6918252723302458
# agent 36 在 149 次迭代中的资源申请量为: 44.5915233041342
# agent 37 在 149 次迭代中的资源申请量为: 54.605801566237844
# agent 38 在 149 次迭代中的资源申请量为: 41.92351151042452
# agent 39 在 149 次迭代中的资源申请量为: 45.019171547871615
# agent 40 在 149 次迭代中的资源申请量为: 52.137451423543695
# agent 41 在 149 次迭代中的资源申请量为: 68.94517774271104
# agent 42 在 149 次迭代中的资源申请量为: 44.21927113048893
# agent 43 在 149 次迭代中的资源申请量为: 53.79190311717048
# agent 44 在 149 次迭代中的资源申请量为: 54.99129302193535
# agent 45 在 149 次迭代中的资源申请量为: 50.12763486138294
# agent 46 在 149 次迭代中的资源申请量为: 58.186639261370416
# agent 47 在 149 次迭代中的资源申请量为: 47.79110071426181
# agent 48 在 149 次迭代中的资源申请量为: 1.9371801243255327
# agent 49 在 149 次迭代中的资源申请量为: 44.44563848621103
# agent 50 在 149 次迭代中的资源申请量为: 42.52671788794389
# agent 51 在 149 次迭代中的资源申请量为: 50.333184175053816
# agent 52 在 149 次迭代中的资源申请量为: 57.959405528960815
# agent 53 在 149 次迭代中的资源申请量为: 1.7855923291380829
# agent 54 在 149 次迭代中的资源申请量为: 59.21909526323778
# agent 55 在 149 次迭代中的资源申请量为: 73.8952384184596
# agent 56 在 149 次迭代中的资源申请量为: 42.527047819662165
# agent 57 在 149 次迭代中的资源申请量为: 62.94887735254639
# agent 58 在 149 次迭代中的资源申请量为: 43.95848238366438
# agent 59 在 149 次迭代中的资源申请量为: 49.91290234858787
# agent 60 在 149 次迭代中的资源申请量为: 58.31364968992976
# agent 61 在 149 次迭代中的资源申请量为: 68.57445744827766
# agent 62 在 149 次迭代中的资源申请量为: 47.94363379219741
# agent 63 在 149 次迭代中的资源申请量为: 40.54389287236452
# agent 64 在 149 次迭代中的资源申请量为: 46.2158924962907
# agent 65 在 149 次迭代中的资源申请量为: 44.40556647614812
# agent 66 在 149 次迭代中的资源申请量为: 68.27549568724163
# agent 67 在 149 次迭代中的资源申请量为: 45.05377930576837
# agent 68 在 149 次迭代中的资源申请量为: 46.70443766683657
# agent 69 在 149 次迭代中的资源申请量为: 47.1936735551451
# agent 70 在 149 次迭代中的资源申请量为: 62.40515275171979
# agent 71 在 149 次迭代中的资源申请量为: 74.89987658731187
# agent 72 在 149 次迭代中的资源申请量为: 62.645217630014116
# agent 73 在 149 次迭代中的资源申请量为: 45.45769400442031
# agent 74 在 149 次迭代中的资源申请量为: 40.502257307846094
# agent 75 在 149 次迭代中的资源申请量为: 54.090501895344666
# agent 76 在 149 次迭代中的资源申请量为: 48.799331665452165
# agent 77 在 149 次迭代中的资源申请量为: 42.47281294145692
# agent 78 在 149 次迭代中的资源申请量为: 51.5413766374576
# agent 79 在 149 次迭代中的资源申请量为: 44.606122639237135
# agent 80 在 149 次迭代中的资源申请量为: 44.711987321508545
# agent 81 在 149 次迭代中的资源申请量为: 41.042585114394626
# agent 82 在 149 次迭代中的资源申请量为: 47.55810002988637
# agent 83 在 149 次迭代中的资源申请量为: 43.24837834689694
# agent 84 在 149 次迭代中的资源申请量为: 54.19809303928035
# agent 85 在 149 次迭代中的资源申请量为: 57.91418798759816
# agent 86 在 149 次迭代中的资源申请量为: 50.87848302594036
# agent 87 在 149 次迭代中的资源申请量为: 62.89346676540816
# agent 88 在 149 次迭代中的资源申请量为: 67.84213342906479
# agent 89 在 149 次迭代中的资源申请量为: 1.2988114491878744
# agent 90 在 149 次迭代中的资源申请量为: 61.63983317753548
# agent 91 在 149 次迭代中的资源申请量为: 44.618692563648764
# agent 92 在 149 次迭代中的资源申请量为: 59.16118111578621
# agent 93 在 149 次迭代中的资源申请量为: 42.34116710153175
# agent 94 在 149 次迭代中的资源申请量为: 76.15641222155925
# agent 95 在 149 次迭代中的资源申请量为: 62.798828141694145
# agent 96 在 149 次迭代中的资源申请量为: 62.955234744584004
# agent 97 在 149 次迭代中的资源申请量为: 75.02301666860319
# agent 98 在 149 次迭代中的资源申请量为: 75.95792506757368
# agent 99 在 149 次迭代中的资源申请量为: 54.49643771464299
# agent 100 在 149 次迭代中的资源申请量为: 50.42408909637694
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 350716.05768399313
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: 51.15700594667941
# agent 2 在 199 次迭代中的资源申请量为: 64.40832147477275
# agent 3 在 199 次迭代中的资源申请量为: 46.23929947931968
# agent 4 在 199 次迭代中的资源申请量为: 68.17164945985458
# agent 5 在 199 次迭代中的资源申请量为: 68.97032704835583
# agent 6 在 199 次迭代中的资源申请量为: 76.16939729730198
# agent 7 在 199 次迭代中的资源申请量为: 41.6906002118655
# agent 8 在 199 次迭代中的资源申请量为: -9.488787203768073
# agent 9 在 199 次迭代中的资源申请量为: 45.593037282417036
# agent 10 在 199 次迭代中的资源申请量为: 58.961332456079994
# agent 11 在 199 次迭代中的资源申请量为: 48.07198664507207
# agent 12 在 199 次迭代中的资源申请量为: 52.148173993229676
# agent 13 在 199 次迭代中的资源申请量为: 69.54921689924699
# agent 14 在 199 次迭代中的资源申请量为: 58.34165493643541
# agent 15 在 199 次迭代中的资源申请量为: 45.90702106381047
# agent 16 在 199 次迭代中的资源申请量为: 46.09133212919282
# agent 17 在 199 次迭代中的资源申请量为: 47.52092062189582
# agent 18 在 199 次迭代中的资源申请量为: 49.05983462552779
# agent 19 在 199 次迭代中的资源申请量为: 43.631926594506666
# agent 20 在 199 次迭代中的资源申请量为: 58.92553834928396
# agent 21 在 199 次迭代中的资源申请量为: -10.966746287790691
# agent 22 在 199 次迭代中的资源申请量为: 41.29089972448979
# agent 23 在 199 次迭代中的资源申请量为: 50.52910597089695
# agent 24 在 199 次迭代中的资源申请量为: 42.77616620963008
# agent 25 在 199 次迭代中的资源申请量为: 47.729534801058705
# agent 26 在 199 次迭代中的资源申请量为: 41.99045604085565
# agent 27 在 199 次迭代中的资源申请量为: 69.22219740451632
# agent 28 在 199 次迭代中的资源申请量为: 54.252251348814475
# agent 29 在 199 次迭代中的资源申请量为: 43.08855791183784
# agent 30 在 199 次迭代中的资源申请量为: 41.39480758225842
# agent 31 在 199 次迭代中的资源申请量为: 63.806853911594914
# agent 32 在 199 次迭代中的资源申请量为: 58.5907510590137
# agent 33 在 199 次迭代中的资源申请量为: 43.88166214662857
# agent 34 在 199 次迭代中的资源申请量为: 55.23152873897166
# agent 35 在 199 次迭代中的资源申请量为: -10.851574742263018
# agent 36 在 199 次迭代中的资源申请量为: 45.2783115231182
# agent 37 在 199 次迭代中的资源申请量为: 55.43975868928984
# agent 38 在 199 次迭代中的资源申请量为: 42.57214482835385
# agent 39 在 199 次迭代中的资源申请量为: 45.705959766855614
# agent 40 在 199 次迭代中的资源申请量为: 52.915811405058896
# agent 41 在 199 次迭代中的资源申请量为: 70.0065777175045
# agent 42 在 199 次迭代中的资源申请量为: 44.90605934947293
# agent 43 在 199 次迭代中的资源申请量为: 54.62586024022248
# agent 44 在 199 次迭代中的资源申请量为: 55.82525014498734
# agent 45 在 199 次迭代中的资源申请量为: 50.90599484289813
# agent 46 在 199 次迭代中的资源申请量为: 59.08474693234949
# agent 47 在 199 次迭代中的资源申请量为: 48.52081319693231
# agent 48 在 199 次迭代中的资源申请量为: -12.081914009631646
# agent 49 在 199 次迭代中的资源申请量为: 45.13242670519503
# agent 50 在 199 次迭代中的资源申请量为: 43.17535120587322
# agent 51 在 199 次迭代中的资源申请量为: 51.11154415656901
# agent 52 在 199 次迭代中的资源申请量为: 58.857513199939895
# agent 53 在 199 次迭代中的资源申请量为: -10.757807685455177
# agent 54 在 199 次迭代中的资源申请量为: 60.11720293421686
# agent 55 在 199 次迭代中的资源申请量为: 75.0627783907324
# agent 56 在 199 次迭代中的资源申请量为: 43.1756811375915
# agent 57 在 199 次迭代中的资源申请量为: 63.92182732944038
# agent 58 在 199 次迭代中的资源申请量为: 44.64527060264838
# agent 59 在 199 次迭代中的资源申请量为: 50.69126233010307
# agent 60 在 199 次迭代中的资源申请量为: 59.21175736090884
# agent 61 在 199 次迭代中的资源申请量为: 69.6358574230711
# agent 62 在 199 次迭代中的资源申请量为: 48.673346274867924
# agent 63 在 199 次迭代中的资源申请量为: 41.158387594613366
# agent 64 在 199 次迭代中的资源申请量为: 46.94560497896121
# agent 65 在 199 次迭代中的资源申请量为: 45.09235469513212
# agent 66 在 199 次迭代中的资源申请量为: 69.33689566203508
# agent 67 在 199 次迭代中的资源申请量为: 45.74056752475237
# agent 68 在 199 次迭代中的资源申请量为: 47.434150149507076
# agent 69 在 199 次迭代中的资源申请量为: 47.9233860378156
# agent 70 在 199 次迭代中的资源申请量为: 63.37810272861379
# agent 71 在 199 次迭代中的资源申请量为: 76.06741655958469
# agent 72 在 199 次迭代中的资源申请量为: 63.618167606908116
# agent 73 在 199 次迭代中的资源申请量为: 46.14448222340431
# agent 74 在 199 次迭代中的资源申请量为: 41.11675203009493
# agent 75 在 199 次迭代中的资源申请量为: 54.92445901839666
# agent 76 在 199 次迭代中的资源申请量为: 49.529044148122665
# agent 77 在 199 次迭代中的资源申请量为: 43.12144625938625
# agent 78 在 199 次迭代中的资源申请量为: 52.3197366189728
# agent 79 在 199 次迭代中的资源申请量为: 45.292910858221134
# agent 80 在 199 次迭代中的资源申请量为: 45.398775540492544
# agent 81 在 199 次迭代中的资源申请量为: 41.65707983664347
# agent 82 在 199 次迭代中的资源申请量为: 48.28781251255687
# agent 83 在 199 次迭代中的资源申请量为: 43.89701166482628
# agent 84 在 199 次迭代中的资源申请量为: 55.032050162332354
# agent 85 在 199 次迭代中的资源申请量为: 58.812295658577234
# agent 86 在 199 次迭代中的资源申请量为: 51.65684300745556
# agent 87 在 199 次迭代中的资源申请量为: 63.86641674230215
# agent 88 在 199 次迭代中的资源申请量为: 68.90353340385825
# agent 89 在 199 次迭代中的资源申请量为: -11.941444121771678
# agent 90 在 199 次迭代中的资源申请量为: 62.61278315442947
# agent 91 在 199 次迭代中的资源申请量为: 45.30548078263276
# agent 92 在 199 次迭代中的资源申请量为: 60.0592887867653
# agent 93 在 199 次迭代中的资源申请量为: 42.98980041946108
# agent 94 在 199 次迭代中的资源申请量为: 77.32395219383204
# agent 95 在 199 次迭代中的资源申请量为: 63.771778118588145
# agent 96 在 199 次迭代中的资源申请量为: 63.928184721478004
# agent 97 在 199 次迭代中的资源申请量为: 76.19055664087598
# agent 98 在 199 次迭代中的资源申请量为: 77.12546503984649
# agent 99 在 199 次迭代中的资源申请量为: 55.330394837694996
# agent 100 在 199 次迭代中的资源申请量为: 51.20244907789214
# 资源申请量总和为: 5000.000000000001
# ****************************************************************************
# 成本总和为: 363937.2132461988
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 249 次迭代中的结果：
# agent 1 在 249 次迭代中的资源申请量为: 51.935365928194614
# agent 2 在 249 次迭代中的资源申请量为: 65.38127145166675
# agent 3 在 249 次迭代中的资源申请量为: 46.92608769830368
# agent 4 在 249 次迭代中的资源申请量为: 69.23304943464802
# agent 5 在 249 次迭代中的资源申请量为: 70.03172702314929
# agent 6 在 249 次迭代中的资源申请量为: 77.33693726957479
# agent 7 在 249 次迭代中的资源申请量为: 42.305094934114344
# agent 8 在 249 次迭代中的资源申请量为: -21.40501721763168
# agent 9 在 249 次迭代中的资源申请量为: 46.27982550140103
# agent 10 在 249 次迭代中的资源申请量为: 59.85944012705907
# agent 11 在 249 次迭代中的资源申请量为: 48.801699127742566
# agent 12 在 249 次迭代中的资源申请量为: 52.92653397474487
# agent 13 在 249 次迭代中的资源申请量为: 70.61061687404042
# agent 14 在 249 次迭代中的资源申请量为: 59.23976260741449
# agent 15 在 249 次迭代中的资源申请量为: 46.59380928279447
# agent 16 在 249 次迭代中的资源申请量为: 46.77812034817682
# agent 17 在 249 次迭代中的资源申请量为: 48.25063310456632
# agent 18 在 249 次迭代中的资源申请量为: 49.789547108198306
# agent 19 在 249 次迭代中的资源申请量为: 44.28055991243598
# agent 20 在 249 次迭代中的资源申请量为: 59.823646020263034
# agent 21 在 249 次迭代中的资源申请量为: -23.510146302383962
# agent 22 在 249 次迭代中的资源申请量为: 41.905394446738626
# agent 23 在 249 次迭代中的资源申请量为: 51.30746595241214
# agent 24 在 249 次迭代中的资源申请量为: 43.424799527559415
# agent 25 在 249 次迭代中的资源申请量为: 48.4592472837292
# agent 26 在 249 次迭代中的资源申请量为: 42.60495076310448
# agent 27 在 249 次迭代中的资源申请量为: 70.2835973793098
# agent 28 在 249 次迭代中的资源申请量为: 55.08620847186648
# agent 29 在 249 次迭代中的资源申请量为: 43.73719122976717
# agent 30 在 249 次迭代中的资源申请量为: 42.00930230450727
# agent 31 在 249 次迭代中的资源申请量为: 64.77980388848891
# agent 32 在 249 次迭代中的资源申请量为: 59.488858729992785
# agent 33 在 249 次迭代中的资源申请量为: 44.530295464557895
# agent 34 在 249 次迭代中的资源申请量为: 56.06548586202365
# agent 35 在 249 次迭代中的资源申请量为: -23.39497475685629
# agent 36 在 249 次迭代中的资源申请量为: 45.96509974210219
# agent 37 在 249 次迭代中的资源申请量为: 56.27371581234184
# agent 38 在 249 次迭代中的资源申请量为: 43.22077814628319
# agent 39 在 249 次迭代中的资源申请量为: 46.39274798583961
# agent 40 在 249 次迭代中的资源申请量为: 53.6941713865741
# agent 41 在 249 次迭代中的资源申请量为: 71.06797769229796
# agent 42 在 249 次迭代中的资源申请量为: 45.59284756845694
# agent 43 在 249 次迭代中的资源申请量为: 55.459817363274475
# agent 44 在 249 次迭代中的资源申请量为: 56.659207268039346
# agent 45 在 249 次迭代中的资源申请量为: 51.68435482441333
# agent 46 在 249 次迭代中的资源申请量为: 59.98285460332856
# agent 47 在 249 次迭代中的资源申请量为: 49.25052567960281
# agent 48 在 249 次迭代中的资源申请量为: -26.10100814358882
# agent 49 在 249 次迭代中的资源申请量为: 45.81921492417903
# agent 50 在 249 次迭代中的资源申请量为: 43.82398452380255
# agent 51 在 249 次迭代中的资源申请量为: 51.889904138084205
# agent 52 在 249 次迭代中的资源申请量为: 59.755620870918975
# agent 53 在 249 次迭代中的资源申请量为: -23.301207700048447
# agent 54 在 249 次迭代中的资源申请量为: 61.01531060519593
# agent 55 在 249 次迭代中的资源申请量为: 76.2303183630052
# agent 56 在 249 次迭代中的资源申请量为: 43.824314455520835
# agent 57 在 249 次迭代中的资源申请量为: 64.89477730633438
# agent 58 在 249 次迭代中的资源申请量为: 45.33205882163237
# agent 59 在 249 次迭代中的资源申请量为: 51.46962231161827
# agent 60 在 249 次迭代中的资源申请量为: 60.109865031887914
# agent 61 在 249 次迭代中的资源申请量为: 70.69725739786455
# agent 62 在 249 次迭代中的资源申请量为: 49.40305875753842
# agent 63 在 249 次迭代中的资源申请量为: 41.77288231686221
# agent 64 在 249 次迭代中的资源申请量为: 47.6753174616317
# agent 65 在 249 次迭代中的资源申请量为: 45.779142914116115
# agent 66 在 249 次迭代中的资源申请量为: 70.39829563682854
# agent 67 在 249 次迭代中的资源申请量为: 46.42735574373638
# agent 68 在 249 次迭代中的资源申请量为: 48.16386263217757
# agent 69 在 249 次迭代中的资源申请量为: 48.6530985204861
# agent 70 在 249 次迭代中的资源申请量为: 64.35105270550777
# agent 71 在 249 次迭代中的资源申请量为: 77.23495653185748
# agent 72 在 249 次迭代中的资源申请量为: 64.59111758380212
# agent 73 在 249 次迭代中的资源申请量为: 46.83127044238831
# agent 74 在 249 次迭代中的资源申请量为: 41.73124675234377
# agent 75 在 249 次迭代中的资源申请量为: 55.758416141448656
# agent 76 在 249 次迭代中的资源申请量为: 50.258756630793165
# agent 77 在 249 次迭代中的资源申请量为: 43.770079577315585
# agent 78 在 249 次迭代中的资源申请量为: 53.098096600488
# agent 79 在 249 次迭代中的资源申请量为: 45.97969907720513
# agent 80 在 249 次迭代中的资源申请量为: 46.08556375947654
# agent 81 在 249 次迭代中的资源申请量为: 42.27157455889232
# agent 82 在 249 次迭代中的资源申请量为: 49.01752499522737
# agent 83 在 249 次迭代中的资源申请量为: 44.545644982755604
# agent 84 在 249 次迭代中的资源申请量为: 55.866007285384356
# agent 85 在 249 次迭代中的资源申请量为: 59.710403329556314
# agent 86 在 249 次迭代中的资源申请量为: 52.43520298897075
# agent 87 在 249 次迭代中的资源申请量为: 64.83936671919615
# agent 88 在 249 次迭代中的资源申请量为: 69.9649333786517
# agent 89 在 249 次迭代中的资源申请量为: -25.18169969273124
# agent 90 在 249 次迭代中的资源申请量为: 63.585733131323465
# agent 91 在 249 次迭代中的资源申请量为: 45.99226900161676
# agent 92 在 249 次迭代中的资源申请量为: 60.95739645774436
# agent 93 在 249 次迭代中的资源申请量为: 43.638433737390415
# agent 94 在 249 次迭代中的资源申请量为: 78.49149216610483
# agent 95 在 249 次迭代中的资源申请量为: 64.74472809548215
# agent 96 在 249 次迭代中的资源申请量为: 64.901134698372
# agent 97 在 249 次迭代中的资源申请量为: 77.35809661314877
# agent 98 在 249 次迭代中的资源申请量为: 78.29300501211928
# agent 99 在 249 次迭代中的资源申请量为: 56.16435196074698
# agent 100 在 249 次迭代中的资源申请量为: 51.980809059407335
# 资源申请量总和为: 4999.999999999996
# ****************************************************************************
# 成本总和为: 380998.6577965323
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 299 次迭代中的结果：
# agent 1 在 299 次迭代中的资源申请量为: 52.713725909709815
# agent 2 在 299 次迭代中的资源申请量为: 66.35422142856075
# agent 3 在 299 次迭代中的资源申请量为: 47.61287591728768
# agent 4 在 299 次迭代中的资源申请量为: 70.29444940944148
# agent 5 在 299 次迭代中的资源申请量为: 71.09312699794273
# agent 6 在 299 次迭代中的资源申请量为: 78.50447724184758
# agent 7 在 299 次迭代中的资源申请量为: 42.91958965636318
# agent 8 在 299 次迭代中的资源申请量为: -33.321247231495285
# agent 9 在 299 次迭代中的资源申请量为: 46.96661372038503
# agent 10 在 299 次迭代中的资源申请量为: 60.75754779803814
# agent 11 在 299 次迭代中的资源申请量为: 49.531411610413066
# agent 12 在 299 次迭代中的资源申请量为: 53.70489395626007
# agent 13 在 299 次迭代中的资源申请量为: 71.67201684883386
# agent 14 在 299 次迭代中的资源申请量为: 60.13787027839356
# agent 15 在 299 次迭代中的资源申请量为: 47.28059750177846
# agent 16 在 299 次迭代中的资源申请量为: 47.46490856716082
# agent 17 在 299 次迭代中的资源申请量为: 48.98034558723681
# agent 18 在 299 次迭代中的资源申请量为: 50.5192595908688
# agent 19 在 299 次迭代中的资源申请量为: 44.929193230365314
# agent 20 在 299 次迭代中的资源申请量为: 60.72175369124211
# agent 21 在 299 次迭代中的资源申请量为: -36.053546316977226
# agent 22 在 299 次迭代中的资源申请量为: 42.51988916898747
# agent 23 在 299 次迭代中的资源申请量为: 52.08582593392734
# agent 24 在 299 次迭代中的资源申请量为: 44.07343284548874
# agent 25 在 299 次迭代中的资源申请量为: 49.18895976639969
# agent 26 在 299 次迭代中的资源申请量为: 43.219445485353326
# agent 27 在 299 次迭代中的资源申请量为: 71.34499735410324
# agent 28 在 299 次迭代中的资源申请量为: 55.92016559491847
# agent 29 在 299 次迭代中的资源申请量为: 44.38582454769651
# agent 30 在 299 次迭代中的资源申请量为: 42.6237970267561
# agent 31 在 299 次迭代中的资源申请量为: 65.75275386538291
# agent 32 在 299 次迭代中的资源申请量为: 60.38696640097184
# agent 33 在 299 次迭代中的资源申请量为: 45.17892878248723
# agent 34 在 299 次迭代中的资源申请量为: 56.89944298507565
# agent 35 在 299 次迭代中的资源申请量为: -35.93837477144955
# agent 36 在 299 次迭代中的资源申请量为: 46.65188796108619
# agent 37 在 299 次迭代中的资源申请量为: 57.107672935393836
# agent 38 在 299 次迭代中的资源申请量为: 43.86941146421251
# agent 39 在 299 次迭代中的资源申请量为: 47.0795362048236
# agent 40 在 299 次迭代中的资源申请量为: 54.47253136808929
# agent 41 在 299 次迭代中的资源申请量为: 72.12937766709142
# agent 42 在 299 次迭代中的资源申请量为: 46.27963578744093
# agent 43 在 299 次迭代中的资源申请量为: 56.29377448632647
# agent 44 在 299 次迭代中的资源申请量为: 57.493164391091334
# agent 45 在 299 次迭代中的资源申请量为: 52.46271480592853
# agent 46 在 299 次迭代中的资源申请量为: 60.880962274307635
# agent 47 在 299 次迭代中的资源申请量为: 49.9802381622733
# agent 48 在 299 次迭代中的资源申请量为: -40.120102277546
# agent 49 在 299 次迭代中的资源申请量为: 46.50600314316303
# agent 50 在 299 次迭代中的资源申请量为: 44.47261784173188
# agent 51 在 299 次迭代中的资源申请量为: 52.66826411959941
# agent 52 在 299 次迭代中的资源申请量为: 60.65372854189804
# agent 53 在 299 次迭代中的资源申请量为: -35.84460771464172
# agent 54 在 299 次迭代中的资源申请量为: 61.91341827617501
# agent 55 在 299 次迭代中的资源申请量为: 77.397858335278
# agent 56 在 299 次迭代中的资源申请量为: 44.47294777345016
# agent 57 在 299 次迭代中的资源申请量为: 65.86772728322838
# agent 58 在 299 次迭代中的资源申请量为: 46.01884704061637
# agent 59 在 299 次迭代中的资源申请量为: 52.24798229313346
# agent 60 在 299 次迭代中的资源申请量为: 61.00797270286699
# agent 61 在 299 次迭代中的资源申请量为: 71.75865737265799
# agent 62 在 299 次迭代中的资源申请量为: 50.13277124020891
# agent 63 在 299 次迭代中的资源申请量为: 42.387377039111044
# agent 64 在 299 次迭代中的资源申请量为: 48.40502994430219
# agent 65 在 299 次迭代中的资源申请量为: 46.46593113310011
# agent 66 在 299 次迭代中的资源申请量为: 71.45969561162198
# agent 67 在 299 次迭代中的资源申请量为: 47.11414396272037
# agent 68 在 299 次迭代中的资源申请量为: 48.89357511484806
# agent 69 在 299 次迭代中的资源申请量为: 49.38281100315659
# agent 70 在 299 次迭代中的资源申请量为: 65.32400268240177
# agent 71 在 299 次迭代中的资源申请量为: 78.40249650413027
# agent 72 在 299 次迭代中的资源申请量为: 65.5640675606961
# agent 73 在 299 次迭代中的资源申请量为: 47.5180586613723
# agent 74 在 299 次迭代中的资源申请量为: 42.345741474592614
# agent 75 在 299 次迭代中的资源申请量为: 56.59237326450065
# agent 76 在 299 次迭代中的资源申请量为: 50.988469113463665
# agent 77 在 299 次迭代中的资源申请量为: 44.418712895244916
# agent 78 在 299 次迭代中的资源申请量为: 53.87645658200319
# agent 79 在 299 次迭代中的资源申请量为: 46.666487296189125
# agent 80 在 299 次迭代中的资源申请量为: 46.77235197846054
# agent 81 在 299 次迭代中的资源申请量为: 42.886069281141154
# agent 82 在 299 次迭代中的资源申请量为: 49.74723747789787
# agent 83 在 299 次迭代中的资源申请量为: 45.194278300684935
# agent 84 在 299 次迭代中的资源申请量为: 56.699964408436344
# agent 85 在 299 次迭代中的资源申请量为: 60.60851100053538
# agent 86 在 299 次迭代中的资源申请量为: 53.213562970485945
# agent 87 在 299 次迭代中的资源申请量为: 65.81231669609015
# agent 88 在 299 次迭代中的资源申请量为: 71.02633335344514
# agent 89 在 299 次迭代中的资源申请量为: -38.4219552636908
# agent 90 在 299 次迭代中的资源申请量为: 64.55868310821747
# agent 91 在 299 次迭代中的资源申请量为: 46.67905722060076
# agent 92 在 299 次迭代中的资源申请量为: 61.85550412872344
# agent 93 在 299 次迭代中的资源申请量为: 44.287067055319746
# agent 94 在 299 次迭代中的资源申请量为: 79.65903213837763
# agent 95 在 299 次迭代中的资源申请量为: 65.71767807237613
# agent 96 在 299 次迭代中的资源申请量为: 65.87408467526599
# agent 97 在 299 次迭代中的资源申请量为: 78.52563658542158
# agent 98 在 299 次迭代中的资源申请量为: 79.46054498439209
# agent 99 在 299 次迭代中的资源申请量为: 56.99830908379898
# agent 100 在 299 次迭代中的资源申请量为: 52.75916904092253
# 资源申请量总和为: 4999.999999999998
# ****************************************************************************
# 成本总和为: 401900.39133499423
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 349 次迭代中的结果：
# agent 1 在 349 次迭代中的资源申请量为: 53.492085891224995
# agent 2 在 349 次迭代中的资源申请量为: 67.32717140545472
# agent 3 在 349 次迭代中的资源申请量为: 48.29966413627167
# agent 4 在 349 次迭代中的资源申请量为: 71.3558493842349
# agent 5 在 349 次迭代中的资源申请量为: 72.15452697273618
# agent 6 在 349 次迭代中的资源申请量为: 79.67201721412037
# agent 7 在 349 次迭代中的资源申请量为: 43.534084378612015
# agent 8 在 349 次迭代中的资源申请量为: -45.23747724535889
# agent 9 在 349 次迭代中的资源申请量为: 47.65340193936902
# agent 10 在 349 次迭代中的资源申请量为: 61.655655469017205
# agent 11 在 349 次迭代中的资源申请量为: 50.261124093083566
# agent 12 在 349 次迭代中的资源申请量为: 54.48325393777526
# agent 13 在 349 次迭代中的资源申请量为: 72.73341682362732
# agent 14 在 349 次迭代中的资源申请量为: 61.03597794937263
# agent 15 在 349 次迭代中的资源申请量为: 47.96738572076245
# agent 16 在 349 次迭代中的资源申请量为: 48.15169678614481
# agent 17 在 349 次迭代中的资源申请量为: 49.710058069907305
# agent 18 在 349 次迭代中的资源申请量为: 51.24897207353928
# agent 19 在 349 次迭代中的资源申请量为: 45.577826548294645
# agent 20 在 349 次迭代中的资源申请量为: 61.61986136222117
# agent 21 在 349 次迭代中的资源申请量为: -48.5969463315705
# agent 22 在 349 次迭代中的资源申请量为: 43.1343838912363
# agent 23 在 349 次迭代中的资源申请量为: 52.86418591544253
# agent 24 在 349 次迭代中的资源申请量为: 44.72206616341807
# agent 25 在 349 次迭代中的资源申请量为: 49.91867224907019
# agent 26 在 349 次迭代中的资源申请量为: 43.83394020760216
# agent 27 在 349 次迭代中的资源申请量为: 72.40639732889667
# agent 28 在 349 次迭代中的资源申请量为: 56.75412271797046
# agent 29 在 349 次迭代中的资源申请量为: 45.034457865625825
# agent 30 在 349 次迭代中的资源申请量为: 43.23829174900494
# agent 31 在 349 次迭代中的资源申请量为: 66.72570384227689
# agent 32 在 349 次迭代中的资源申请量为: 61.28507407195091
# agent 33 在 349 次迭代中的资源申请量为: 45.82756210041656
# agent 34 在 349 次迭代中的资源申请量为: 57.73340010812765
# agent 35 在 349 次迭代中的资源申请量为: -48.48177478604282
# agent 36 在 349 次迭代中的资源申请量为: 47.33867618007019
# agent 37 在 349 次迭代中的资源申请量为: 57.94163005844583
# agent 38 在 349 次迭代中的资源申请量为: 44.518044782141835
# agent 39 在 349 次迭代中的资源申请量为: 47.7663244238076
# agent 40 在 349 次迭代中的资源申请量为: 55.25089134960449
# agent 41 在 349 次迭代中的资源申请量为: 73.19077764188485
# agent 42 在 349 次迭代中的资源申请量为: 46.96642400642492
# agent 43 在 349 次迭代中的资源申请量为: 57.127731609378465
# agent 44 在 349 次迭代中的资源申请量为: 58.32712151414333
# agent 45 在 349 次迭代中的资源申请量为: 53.241074787443715
# agent 46 在 349 次迭代中的资源申请量为: 61.77906994528671
# agent 47 在 349 次迭代中的资源申请量为: 50.709950644943795
# agent 48 在 349 次迭代中的资源申请量为: -54.13919641150319
# agent 49 在 349 次迭代中的资源申请量为: 47.19279136214702
# agent 50 在 349 次迭代中的资源申请量为: 45.121251159661206
# agent 51 在 349 次迭代中的资源申请量为: 53.446624101114594
# agent 52 在 349 次迭代中的资源申请量为: 61.55183621287712
# agent 53 在 349 次迭代中的资源申请量为: -48.388007729234985
# agent 54 在 349 次迭代中的资源申请量为: 62.811525947154074
# agent 55 在 349 次迭代中的资源申请量为: 78.5653983075508
# agent 56 在 349 次迭代中的资源申请量为: 45.12158109137949
# agent 57 在 349 次迭代中的资源申请量为: 66.84067726012236
# agent 58 在 349 次迭代中的资源申请量为: 46.70563525960036
# agent 59 在 349 次迭代中的资源申请量为: 53.026342274648655
# agent 60 在 349 次迭代中的资源申请量为: 61.90608037384605
# agent 61 在 349 次迭代中的资源申请量为: 72.82005734745144
# agent 62 在 349 次迭代中的资源申请量为: 50.862483722879404
# agent 63 在 349 次迭代中的资源申请量为: 43.00187176135988
# agent 64 在 349 次迭代中的资源申请量为: 49.134742426972686
# agent 65 在 349 次迭代中的资源申请量为: 47.152719352084105
# agent 66 在 349 次迭代中的资源申请量为: 72.52109558641543
# agent 67 在 349 次迭代中的资源申请量为: 47.80093218170437
# agent 68 在 349 次迭代中的资源申请量为: 49.623287597518555
# agent 69 在 349 次迭代中的资源申请量为: 50.11252348582709
# agent 70 在 349 次迭代中的资源申请量为: 66.29695265929577
# agent 71 在 349 次迭代中的资源申请量为: 79.57003647640306
# agent 72 在 349 次迭代中的资源申请量为: 66.5370175375901
# agent 73 在 349 次迭代中的资源申请量为: 48.20484688035629
# agent 74 在 349 次迭代中的资源申请量为: 42.96023619684145
# agent 75 在 349 次迭代中的资源申请量为: 57.42633038755265
# agent 76 在 349 次迭代中的资源申请量为: 51.71818159613415
# agent 77 在 349 次迭代中的资源申请量为: 45.06734621317425
# agent 78 在 349 次迭代中的资源申请量为: 54.654816563518395
# agent 79 在 349 次迭代中的资源申请量为: 47.35327551517312
# agent 80 在 349 次迭代中的资源申请量为: 47.45914019744453
# agent 81 在 349 次迭代中的资源申请量为: 43.50056400338999
# agent 82 在 349 次迭代中的资源申请量为: 50.476949960568355
# agent 83 在 349 次迭代中的资源申请量为: 45.84291161861427
# agent 84 在 349 次迭代中的资源申请量为: 57.53392153148833
# agent 85 在 349 次迭代中的资源申请量为: 61.50661867151445
# agent 86 在 349 次迭代中的资源申请量为: 53.99192295200114
# agent 87 在 349 次迭代中的资源申请量为: 66.78526667298415
# agent 88 在 349 次迭代中的资源申请量为: 72.08773332823858
# agent 89 在 349 次迭代中的资源申请量为: -51.66221083465036
# agent 90 在 349 次迭代中的资源申请量为: 65.53163308511145
# agent 91 在 349 次迭代中的资源申请量为: 47.36584543958475
# agent 92 在 349 次迭代中的资源申请量为: 62.75361179970251
# agent 93 在 349 次迭代中的资源申请量为: 44.93570037324908
# agent 94 在 349 次迭代中的资源申请量为: 80.82657211065043
# agent 95 在 349 次迭代中的资源申请量为: 66.69062804927013
# agent 96 在 349 次迭代中的资源申请量为: 66.84703465215999
# agent 97 在 349 次迭代中的资源申请量为: 79.69317655769436
# agent 98 在 349 次迭代中的资源申请量为: 80.62808495666486
# agent 99 在 349 次迭代中的资源申请量为: 57.832266206850974
# agent 100 在 349 次迭代中的资源申请量为: 53.53752902243774
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 426642.4138615837
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 399 次迭代中的结果：
# agent 1 在 399 次迭代中的资源申请量为: 54.2704458727402
# agent 2 在 399 次迭代中的资源申请量为: 68.30012138234873
# agent 3 在 399 次迭代中的资源申请量为: 48.98645235525567
# agent 4 在 399 次迭代中的资源申请量为: 72.41724935902836
# agent 5 在 399 次迭代中的资源申请量为: 73.21592694752962
# agent 6 在 399 次迭代中的资源申请量为: 80.83955718639317
# agent 7 在 399 次迭代中的资源申请量为: 44.148579100860864
# agent 8 在 399 次迭代中的资源申请量为: -57.15370725922249
# agent 9 在 399 次迭代中的资源申请量为: 48.34019015835302
# agent 10 在 399 次迭代中的资源申请量为: 62.553763139996285
# agent 11 在 399 次迭代中的资源申请量为: 50.99083657575406
# agent 12 在 399 次迭代中的资源申请量为: 55.26161391929046
# agent 13 在 399 次迭代中的资源申请量为: 73.79481679842077
# agent 14 在 399 次迭代中的资源申请量为: 61.9340856203517
# agent 15 在 399 次迭代中的资源申请量为: 48.65417393974645
# agent 16 在 399 次迭代中的资源申请量为: 48.8384850051288
# agent 17 在 399 次迭代中的资源申请量为: 50.439770552577805
# agent 18 在 399 次迭代中的资源申请量为: 51.978684556209785
# agent 19 在 399 次迭代中的资源申请量为: 46.22645986622397
# agent 20 在 399 次迭代中的资源申请量为: 62.51796903320025
# agent 21 在 399 次迭代中的资源申请量为: -61.14034634616376
# agent 22 在 399 次迭代中的资源申请量为: 43.74887861348514
# agent 23 在 399 次迭代中的资源申请量为: 53.642545896957735
# agent 24 在 399 次迭代中的资源申请量为: 45.3706994813474
# agent 25 在 399 次迭代中的资源申请量为: 50.648384731740684
# agent 26 在 399 次迭代中的资源申请量为: 44.448434929851004
# agent 27 在 399 次迭代中的资源申请量为: 73.46779730369013
# agent 28 在 399 次迭代中的资源申请量为: 57.58807984102247
# agent 29 在 399 次迭代中的资源申请量为: 45.683091183555156
# agent 30 在 399 次迭代中的资源申请量为: 43.85278647125378
# agent 31 在 399 次迭代中的资源申请量为: 67.69865381917089
# agent 32 在 399 次迭代中的资源申请量为: 62.18318174292999
# agent 33 在 399 次迭代中的资源申请量为: 46.47619541834589
# agent 34 在 399 次迭代中的资源申请量为: 58.567357231179635
# agent 35 在 399 次迭代中的资源申请量为: -61.02517480063609
# agent 36 在 399 次迭代中的资源申请量为: 48.02546439905418
# agent 37 在 399 次迭代中的资源申请量为: 58.775587181497826
# agent 38 在 399 次迭代中的资源申请量为: 45.16667810007117
# agent 39 在 399 次迭代中的资源申请量为: 48.453112642791595
# agent 40 在 399 次迭代中的资源申请量为: 56.02925133111968
# agent 41 在 399 次迭代中的资源申请量为: 74.2521776166783
# agent 42 在 399 次迭代中的资源申请量为: 47.65321222540892
# agent 43 在 399 次迭代中的资源申请量为: 57.96168873243045
# agent 44 在 399 次迭代中的资源申请量为: 59.161078637195324
# agent 45 在 399 次迭代中的资源申请量为: 54.019434768958924
# agent 46 在 399 次迭代中的资源申请量为: 62.67717761626578
# agent 47 在 399 次迭代中的资源申请量为: 51.43966312761429
# agent 48 在 399 次迭代中的资源申请量为: -68.15829054546037
# agent 49 在 399 次迭代中的资源申请量为: 47.87957958113102
# agent 50 在 399 次迭代中的资源申请量为: 45.76988447759054
# agent 51 在 399 次迭代中的资源申请量为: 54.224984082629796
# agent 52 在 399 次迭代中的资源申请量为: 62.449943883856186
# agent 53 在 399 次迭代中的资源申请量为: -60.93140774382826
# agent 54 在 399 次迭代中的资源申请量为: 63.709633618133154
# agent 55 在 399 次迭代中的资源申请量为: 79.73293827982357
# agent 56 在 399 次迭代中的资源申请量为: 45.77021440930882
# agent 57 在 399 次迭代中的资源申请量为: 67.81362723701636
# agent 58 在 399 次迭代中的资源申请量为: 47.39242347858436
# agent 59 在 399 次迭代中的资源申请量为: 53.80470225616386
# agent 60 在 399 次迭代中的资源申请量为: 62.80418804482513
# agent 61 在 399 次迭代中的资源申请量为: 73.88145732224488
# agent 62 在 399 次迭代中的资源申请量为: 51.59219620554991
# agent 63 在 399 次迭代中的资源申请量为: 43.61636648360872
# agent 64 在 399 次迭代中的资源申请量为: 49.864454909643186
# agent 65 在 399 次迭代中的资源申请量为: 47.839507571068104
# agent 66 在 399 次迭代中的资源申请量为: 73.58249556120887
# agent 67 在 399 次迭代中的资源申请量为: 48.48772040068837
# agent 68 在 399 次迭代中的资源申请量为: 50.353000080189055
# agent 69 在 399 次迭代中的资源申请量为: 50.84223596849758
# agent 70 在 399 次迭代中的资源申请量为: 67.26990263618976
# agent 71 在 399 次迭代中的资源申请量为: 80.73757644867585
# agent 72 在 399 次迭代中的资源申请量为: 67.50996751448409
# agent 73 在 399 次迭代中的资源申请量为: 48.8916350993403
# agent 74 在 399 次迭代中的资源申请量为: 43.574730919090285
# agent 75 在 399 次迭代中的资源申请量为: 58.26028751060464
# agent 76 在 399 次迭代中的资源申请量为: 52.447894078804644
# agent 77 在 399 次迭代中的资源申请量为: 45.71597953110357
# agent 78 在 399 次迭代中的资源申请量为: 55.43317654503359
# agent 79 在 399 次迭代中的资源申请量为: 48.04006373415712
# agent 80 在 399 次迭代中的资源申请量为: 48.14592841642853
# agent 81 在 399 次迭代中的资源申请量为: 44.115058725638825
# agent 82 在 399 次迭代中的资源申请量为: 51.206662443238855
# agent 83 在 399 次迭代中的资源申请量为: 46.4915449365436
# agent 84 在 399 次迭代中的资源申请量为: 58.367878654540334
# agent 85 在 399 次迭代中的资源申请量为: 62.404726342493525
# agent 86 在 399 次迭代中的资源申请量为: 54.770282933516334
# agent 87 在 399 次迭代中的资源申请量为: 67.75821664987814
# agent 88 在 399 次迭代中的资源申请量为: 73.14913330303203
# agent 89 在 399 次迭代中的资源申请量为: -64.90246640560991
# agent 90 在 399 次迭代中的资源申请量为: 66.50458306200545
# agent 91 在 399 次迭代中的资源申请量为: 48.05263365856875
# agent 92 在 399 次迭代中的资源申请量为: 63.651719470681584
# agent 93 在 399 次迭代中的资源申请量为: 45.5843336911784
# agent 94 在 399 次迭代中的资源申请量为: 81.99411208292321
# agent 95 在 399 次迭代中的资源申请量为: 67.66357802616412
# agent 96 在 399 次迭代中的资源申请量为: 67.81998462905399
# agent 97 在 399 次迭代中的资源申请量为: 80.86071652996716
# agent 98 在 399 次迭代中的资源申请量为: 81.79562492893766
# agent 99 在 399 次迭代中的资源申请量为: 58.66622332990297
# agent 100 在 399 次迭代中的资源申请量为: 54.315889003952925
# 资源申请量总和为: 4999.999999999995
# ****************************************************************************
# 成本总和为: 455224.7253763014
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 449 次迭代中的结果：
# agent 1 在 449 次迭代中的资源申请量为: 55.0488058542554
# agent 2 在 449 次迭代中的资源申请量为: 69.27307135924273
# agent 3 在 449 次迭代中的资源申请量为: 49.67324057423967
# agent 4 在 449 次迭代中的资源申请量为: 73.47864933382182
# agent 5 在 449 次迭代中的资源申请量为: 74.27732692232307
# agent 6 在 449 次迭代中的资源申请量为: 82.00709715866596
# agent 7 在 449 次迭代中的资源申请量为: 44.7630738231097
# agent 8 在 449 次迭代中的资源申请量为: -69.06993727308608
# agent 9 在 449 次迭代中的资源申请量为: 49.026978377337024
# agent 10 在 449 次迭代中的资源申请量为: 63.451870810975365
# agent 11 在 449 次迭代中的资源申请量为: 51.72054905842455
# agent 12 在 449 次迭代中的资源申请量为: 56.03997390080566
# agent 13 在 449 次迭代中的资源申请量为: 74.85621677321423
# agent 14 在 449 次迭代中的资源申请量为: 62.83219329133077
# agent 15 在 449 次迭代中的资源申请量为: 49.340962158730456
# agent 16 在 449 次迭代中的资源申请量为: 49.52527322411281
# agent 17 在 449 次迭代中的资源申请量为: 51.169483035248305
# agent 18 在 449 次迭代中的资源申请量为: 52.708397038880285
# agent 19 在 449 次迭代中的资源申请量为: 46.8750931841533
# agent 20 在 449 次迭代中的资源申请量为: 63.416076704179325
# agent 21 在 449 次迭代中的资源申请量为: -73.68374636075703
# agent 22 在 449 次迭代中的资源申请量为: 44.36337333573399
# agent 23 在 449 次迭代中的资源申请量为: 54.42090587847292
# agent 24 在 449 次迭代中的资源申请量为: 46.019332799276725
# agent 25 在 449 次迭代中的资源申请量为: 51.37809721441118
# agent 26 在 449 次迭代中的资源申请量为: 45.06292965209984
# agent 27 在 449 次迭代中的资源申请量为: 74.5291972784836
# agent 28 在 449 次迭代中的资源申请量为: 58.42203696407446
# agent 29 在 449 次迭代中的资源申请量为: 46.331724501484494
# agent 30 在 449 次迭代中的资源申请量为: 44.46728119350262
# agent 31 在 449 次迭代中的资源申请量为: 68.67160379606489
# agent 32 在 449 次迭代中的资源申请量为: 63.08128941390906
# agent 33 在 449 次迭代中的资源申请量为: 47.12482873627522
# agent 34 在 449 次迭代中的资源申请量为: 59.401314354231644
# agent 35 在 449 次迭代中的资源申请量为: -73.56857481522934
# agent 36 在 449 次迭代中的资源申请量为: 48.712252618038185
# agent 37 在 449 次迭代中的资源申请量为: 59.60954430454983
# agent 38 在 449 次迭代中的资源申请量为: 45.815311418000505
# agent 39 在 449 次迭代中的资源申请量为: 49.139900861775594
# agent 40 在 449 次迭代中的资源申请量为: 56.807611312634876
# agent 41 在 449 次迭代中的资源申请量为: 75.31357759147176
# agent 42 在 449 次迭代中的资源申请量为: 48.34000044439291
# agent 43 在 449 次迭代中的资源申请量为: 58.795645855482455
# agent 44 在 449 次迭代中的资源申请量为: 59.99503576024732
# agent 45 在 449 次迭代中的资源申请量为: 54.79779475047411
# agent 46 在 449 次迭代中的资源申请量为: 63.57528528724485
# agent 47 在 449 次迭代中的资源申请量为: 52.16937561028479
# agent 48 在 449 次迭代中的资源申请量为: -82.17738467941754
# agent 49 在 449 次迭代中的资源申请量为: 48.56636780011501
# agent 50 在 449 次迭代中的资源申请量为: 46.418517795519875
# agent 51 在 449 次迭代中的资源申请量为: 55.00334406414499
# agent 52 在 449 次迭代中的资源申请量为: 63.348051554835266
# agent 53 在 449 次迭代中的资源申请量为: -73.4748077584215
# agent 54 在 449 次迭代中的资源申请量为: 64.60774128911223
# agent 55 在 449 次迭代中的资源申请量为: 80.90047825209638
# agent 56 在 449 次迭代中的资源申请量为: 46.41884772723815
# agent 57 在 449 次迭代中的资源申请量为: 68.78657721391036
# agent 58 在 449 次迭代中的资源申请量为: 48.07921169756837
# agent 59 在 449 次迭代中的资源申请量为: 54.58306223767906
# agent 60 在 449 次迭代中的资源申请量为: 63.702295715804205
# agent 61 在 449 次迭代中的资源申请量为: 74.94285729703834
# agent 62 在 449 次迭代中的资源申请量为: 52.3219086882204
# agent 63 在 449 次迭代中的资源申请量为: 44.230861205857565
# agent 64 在 449 次迭代中的资源申请量为: 50.59416739231368
# agent 65 在 449 次迭代中的资源申请量为: 48.5262957900521
# agent 66 在 449 次迭代中的资源申请量为: 74.64389553600232
# agent 67 在 449 次迭代中的资源申请量为: 49.17450861967235
# agent 68 在 449 次迭代中的资源申请量为: 51.082712562859555
# agent 69 在 449 次迭代中的资源申请量为: 51.57194845116808
# agent 70 在 449 次迭代中的资源申请量为: 68.24285261308377
# agent 71 在 449 次迭代中的资源申请量为: 81.90511642094864
# agent 72 在 449 次迭代中的资源申请量为: 68.4829174913781
# agent 73 在 449 次迭代中的资源申请量为: 49.5784233183243
# agent 74 在 449 次迭代中的资源申请量为: 44.18922564133913
# agent 75 在 449 次迭代中的资源申请量为: 59.094244633656636
# agent 76 在 449 次迭代中的资源申请量为: 53.17760656147515
# agent 77 在 449 次迭代中的资源申请量为: 46.3646128490329
# agent 78 在 449 次迭代中的资源申请量为: 56.211536526548784
# agent 79 在 449 次迭代中的资源申请量为: 48.726851953141114
# agent 80 在 449 次迭代中的资源申请量为: 48.83271663541253
# agent 81 在 449 次迭代中的资源申请量为: 44.72955344788767
# agent 82 在 449 次迭代中的资源申请量为: 51.936374925909355
# agent 83 在 449 次迭代中的资源申请量为: 47.14017825447293
# agent 84 在 449 次迭代中的资源申请量为: 59.20183577759233
# agent 85 在 449 次迭代中的资源申请量为: 63.302834013472605
# agent 86 在 449 次迭代中的资源申请量为: 55.54864291503154
# agent 87 在 449 次迭代中的资源申请量为: 68.73116662677212
# agent 88 在 449 次迭代中的资源申请量为: 74.21053327782549
# agent 89 在 449 次迭代中的资源申请量为: -78.14272197656946
# agent 90 在 449 次迭代中的资源申请量为: 67.47753303889945
# agent 91 在 449 次迭代中的资源申请量为: 48.73942187755275
# agent 92 在 449 次迭代中的资源申请量为: 64.54982714166066
# agent 93 在 449 次迭代中的资源申请量为: 46.23296700910774
# agent 94 在 449 次迭代中的资源申请量为: 83.16165205519601
# agent 95 在 449 次迭代中的资源申请量为: 68.63652800305812
# agent 96 在 449 次迭代中的资源申请量为: 68.79293460594798
# agent 97 在 449 次迭代中的资源申请量为: 82.02825650223997
# agent 98 在 449 次迭代中的资源申请量为: 82.96316490121046
# agent 99 在 449 次迭代中的资源申请量为: 59.500180452954964
# agent 100 在 449 次迭代中的资源申请量为: 55.09424898546813
# 资源申请量总和为: 4999.999999999997
# ****************************************************************************
# 成本总和为: 487647.3258791473
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 499 次迭代中的结果：
# agent 1 在 499 次迭代中的资源申请量为: 55.82716583577059
# agent 2 在 499 次迭代中的资源申请量为: 70.24602133613674
# agent 3 在 499 次迭代中的资源申请量为: 50.36002879322367
# agent 4 在 499 次迭代中的资源申请量为: 74.54004930861528
# agent 5 在 499 次迭代中的资源申请量为: 75.33872689711653
# agent 6 在 499 次迭代中的资源申请量为: 83.17463713093875
# agent 7 在 499 次迭代中的资源申请量为: 45.377568545358535
# agent 8 在 499 次迭代中的资源申请量为: -80.9861672869497
# agent 9 在 499 次迭代中的资源申请量为: 49.71376659632102
# agent 10 在 499 次迭代中的资源申请量为: 64.34997848195444
# agent 11 在 499 次迭代中的资源申请量为: 52.45026154109506
# agent 12 在 499 次迭代中的资源申请量为: 56.81833388232086
# agent 13 在 499 次迭代中的资源申请量为: 75.91761674800767
# agent 14 在 499 次迭代中的资源申请量为: 63.730300962309855
# agent 15 在 499 次迭代中的资源申请量为: 50.027750377714455
# agent 16 在 499 次迭代中的资源申请量为: 50.21206144309681
# agent 17 在 499 次迭代中的资源申请量为: 51.899195517918805
# agent 18 在 499 次迭代中的资源申请量为: 53.43810952155078
# agent 19 在 499 次迭代中的资源申请量为: 47.523726502082646
# agent 20 在 499 次迭代中的资源申请量为: 64.3141843751584
# agent 21 在 499 次迭代中的资源申请量为: -86.22714637535029
# agent 22 在 499 次迭代中的资源申请量为: 44.97786805798282
# agent 23 在 499 次迭代中的资源申请量为: 55.199265859988124
# agent 24 在 499 次迭代中的资源申请量为: 46.66796611720606
# ...
# agent 88 在 1969 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1969 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1969 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1969 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1969 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1969 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1969 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1969 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1969 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1969 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1969 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1969 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1969 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1979 次迭代中的结果：
# agent 1 在 1979 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1979 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1979 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1979 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1979 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1979 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1979 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1979 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1979 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1979 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1979 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1979 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1979 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1979 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1979 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1979 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1979 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1979 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1979 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1979 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1979 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1979 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1979 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1979 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1979 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1979 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1979 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1979 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1979 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1979 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1979 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1979 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1979 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1979 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1979 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1979 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1979 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1979 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1979 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1979 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1979 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1979 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1979 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1979 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1979 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1979 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1979 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1979 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1979 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1979 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1979 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1979 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1979 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1979 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1979 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1979 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1979 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1979 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1979 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1979 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1979 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1979 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1979 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1979 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1979 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1979 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1979 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1979 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1979 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1979 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1979 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1979 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1979 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1979 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1979 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1979 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1979 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1979 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1979 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1979 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1979 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1979 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1979 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1979 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1979 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1979 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1979 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1979 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1979 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1979 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1979 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1979 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1979 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1979 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1979 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1979 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1979 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1989 次迭代中的结果：
# agent 1 在 1989 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1989 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1989 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1989 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1989 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1989 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1989 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1989 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1989 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1989 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1989 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1989 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1989 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1989 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1989 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1989 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1989 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1989 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1989 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1989 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1989 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1989 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1989 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1989 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1989 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1989 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1989 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1989 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1989 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1989 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1989 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1989 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1989 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1989 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1989 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1989 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1989 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1989 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1989 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1989 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1989 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1989 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1989 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1989 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1989 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1989 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1989 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1989 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1989 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1989 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1989 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1989 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1989 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1989 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1989 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1989 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1989 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1989 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1989 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1989 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1989 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1989 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1989 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1989 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1989 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1989 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1989 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1989 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1989 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1989 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1989 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1989 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1989 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1989 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1989 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1989 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1989 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1989 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1989 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1989 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1989 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1989 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1989 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1989 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1989 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1989 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1989 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1989 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1989 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1989 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1989 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1989 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1989 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1989 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1989 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1989 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1989 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1999 次迭代中的结果：
# agent 1 在 1999 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1999 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1999 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1999 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1999 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1999 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1999 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1999 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1999 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1999 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1999 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1999 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1999 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1999 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1999 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1999 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1999 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1999 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1999 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1999 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1999 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1999 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1999 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1999 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1999 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1999 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1999 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1999 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1999 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1999 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1999 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1999 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1999 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1999 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1999 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1999 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1999 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1999 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1999 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1999 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1999 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1999 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1999 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1999 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1999 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1999 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1999 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1999 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1999 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1999 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1999 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1999 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1999 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1999 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1999 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1999 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1999 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1999 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1999 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1999 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1999 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1999 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1999 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1999 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1999 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1999 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1999 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1999 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1999 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1999 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1999 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1999 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1999 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1999 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1999 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1999 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1999 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1999 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1999 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1999 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1999 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1999 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1999 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1999 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1999 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1999 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1999 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1999 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1999 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1999 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1999 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1999 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1999 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1999 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1999 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1999 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1999 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 2025-01-21 17:21:01.305

# %%
np.savetxt('../data/02-6-bias-agent-agent_resource_quantity_unbounded_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/02-6-bias-agent-sum_cost_unbounded_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/02-6-bias-agent-sum_resource_unbounded_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
np.savetxt('../data/02-6-bias-agent-agent_gradient_unbounded_bias.txt',agent_gradient,fmt='%0.8f')#用户迭代梯度
