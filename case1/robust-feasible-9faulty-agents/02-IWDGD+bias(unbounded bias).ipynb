# %% [raw]
# 基于初始化的权重梯度下降无中心资源分配算法+部分用户的梯度计算有误差（设备损坏导致的计算误差）

# %% [raw]
# 无界的噪声 设计噪声递增

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(100,1000), dtype=np.float64) 
sum_resource=np.zeros(shape=(1,1000), dtype=np.float64)
sum_cost=np.zeros(shape=(1,1000), dtype=np.float64)
iteration_update = 0.01
A=np.loadtxt("100_Network_Topology_Double_Random_Adjacency_Matrix_Degree_15.txt") #网络拓扑的邻接矩阵 对角元素要为0
D=np.zeros(shape=(100,100))# 网络的度矩阵
L=np.zeros(shape=(100,100))# 网络的拉普拉斯矩阵 L=D-A
W=np.zeros(shape=(100,100)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
iteration=[]
a=np.loadtxt("100_uniform_distribution_(1,2)_point1.txt")
b=np.loadtxt("100_normal_distribution_(2,0.6)_point1.txt")
agent_gradient=np.zeros(shape=(100,1000), dtype=np.float64) 
bias=0

# %%
#根据邻接矩阵生成网络对应的度矩阵
for i in range(0,100):
    d=0
    for j in range(0,100):
        if A[i][j]==1:
            d=d+1
    D[i][i]=d

#根据邻接矩阵和度矩阵计算拉普拉斯矩阵
L=D-A

#选择用拉普拉斯矩阵作为聚合矩阵
W=L
    
#资源量的初始化 需要给定可行的初始化 即满足平均资源约束
for i in range (0,100):
    agent_resource_quantity[i][0]=50
    
#资源量总和 初始化
sum=0
for i in range (0,100):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

iteration.append(0)

#初始梯度计算 选择三个用户作为带有噪声
for i in range (0,100):
    if i==7 or i==20 or i==34 or i==47 or i==52 or i==88 or i==66 or i==71 or i==93:
        agent_gradient[i][0]=2*a[i]*agent_resource_quantity[i][0]-2*a[i]*b[i]+bias
    else:
        agent_gradient[i][0]=2*a[i]*agent_resource_quantity[i][0]-2*a[i]*b[i]

#诚实用户成本总和初始化
sum=0
for i in range(0,100):
    sum=sum+a[i]*(agent_resource_quantity[i][0]-b[i])*(agent_resource_quantity[i][0]-b[i])
sum_cost[0][0]=sum

# %%
#基于初始化的权重梯度下降无中心资源分配算法
def IWDGD_deterministic_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias):
    
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************IWDGD算法+计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,100):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):#迭代次数
        iteration.append(k)
 
        #所有用户资源申请量基于可行初始化权重梯度下降的迭代  假设部分用户因为设备损坏 导致梯度的计算有误差     
        for i in range (0,100):
            weight_gradient_sum = np.float64(0)
            for j in range (0,100):        
                weight_gradient_sum=weight_gradient_sum+W[i][j]*agent_gradient[j][k-1]
            #weight_gradient_sum = np.round(weight_gradient_sum, decimals=3)
            agent_resource_quantity[i][k]=agent_resource_quantity[i][k-1]-iteration_update*weight_gradient_sum
                #agent_resource_quantity[i][k] = np.round(agent_resource_quantity[i][k], decimals=3)
        
        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,100):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,100):
            sum2=sum2+a[i]*(agent_resource_quantity[i][k]-b[i])*(agent_resource_quantity[i][k]-b[i])
        sum_cost[0][k]=sum2

        #设计递增的噪声
        bias=k
        #计算当前迭代的用户梯度
        for i in range (0,100): 
            if i==7 or i==20 or i==34 or i==47 or i==52 or i==88 or i==66 or i==71 or i==93:
                agent_gradient[i][k]=2*a[i]*agent_resource_quantity[i][k]-2*a[i]*b[i]+bias
            else:
                agent_gradient[i][k]=2*a[i]*agent_resource_quantity[i][k]-2*a[i]*b[i]
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%50==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,100):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=1/(pow(k+1,0.5)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
IWDGD_deterministic_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias)
# Out:
# ****************************IWDGD算法+计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 50.0
# agent 2 的初始资源申请量为: 50.0
# agent 3 的初始资源申请量为: 50.0
# agent 4 的初始资源申请量为: 50.0
# agent 5 的初始资源申请量为: 50.0
# agent 6 的初始资源申请量为: 50.0
# agent 7 的初始资源申请量为: 50.0
# agent 8 的初始资源申请量为: 50.0
# agent 9 的初始资源申请量为: 50.0
# agent 10 的初始资源申请量为: 50.0
# agent 11 的初始资源申请量为: 50.0
# agent 12 的初始资源申请量为: 50.0
# agent 13 的初始资源申请量为: 50.0
# agent 14 的初始资源申请量为: 50.0
# agent 15 的初始资源申请量为: 50.0
# agent 16 的初始资源申请量为: 50.0
# agent 17 的初始资源申请量为: 50.0
# agent 18 的初始资源申请量为: 50.0
# agent 19 的初始资源申请量为: 50.0
# agent 20 的初始资源申请量为: 50.0
# agent 21 的初始资源申请量为: 50.0
# agent 22 的初始资源申请量为: 50.0
# agent 23 的初始资源申请量为: 50.0
# agent 24 的初始资源申请量为: 50.0
# agent 25 的初始资源申请量为: 50.0
# agent 26 的初始资源申请量为: 50.0
# agent 27 的初始资源申请量为: 50.0
# agent 28 的初始资源申请量为: 50.0
# agent 29 的初始资源申请量为: 50.0
# agent 30 的初始资源申请量为: 50.0
# agent 31 的初始资源申请量为: 50.0
# agent 32 的初始资源申请量为: 50.0
# agent 33 的初始资源申请量为: 50.0
# agent 34 的初始资源申请量为: 50.0
# agent 35 的初始资源申请量为: 50.0
# agent 36 的初始资源申请量为: 50.0
# agent 37 的初始资源申请量为: 50.0
# agent 38 的初始资源申请量为: 50.0
# agent 39 的初始资源申请量为: 50.0
# agent 40 的初始资源申请量为: 50.0
# agent 41 的初始资源申请量为: 50.0
# agent 42 的初始资源申请量为: 50.0
# agent 43 的初始资源申请量为: 50.0
# agent 44 的初始资源申请量为: 50.0
# agent 45 的初始资源申请量为: 50.0
# agent 46 的初始资源申请量为: 50.0
# agent 47 的初始资源申请量为: 50.0
# agent 48 的初始资源申请量为: 50.0
# agent 49 的初始资源申请量为: 50.0
# agent 50 的初始资源申请量为: 50.0
# agent 51 的初始资源申请量为: 50.0
# agent 52 的初始资源申请量为: 50.0
# agent 53 的初始资源申请量为: 50.0
# agent 54 的初始资源申请量为: 50.0
# agent 55 的初始资源申请量为: 50.0
# agent 56 的初始资源申请量为: 50.0
# agent 57 的初始资源申请量为: 50.0
# agent 58 的初始资源申请量为: 50.0
# agent 59 的初始资源申请量为: 50.0
# agent 60 的初始资源申请量为: 50.0
# agent 61 的初始资源申请量为: 50.0
# agent 62 的初始资源申请量为: 50.0
# agent 63 的初始资源申请量为: 50.0
# agent 64 的初始资源申请量为: 50.0
# agent 65 的初始资源申请量为: 50.0
# agent 66 的初始资源申请量为: 50.0
# agent 67 的初始资源申请量为: 50.0
# agent 68 的初始资源申请量为: 50.0
# agent 69 的初始资源申请量为: 50.0
# agent 70 的初始资源申请量为: 50.0
# agent 71 的初始资源申请量为: 50.0
# agent 72 的初始资源申请量为: 50.0
# agent 73 的初始资源申请量为: 50.0
# agent 74 的初始资源申请量为: 50.0
# agent 75 的初始资源申请量为: 50.0
# agent 76 的初始资源申请量为: 50.0
# agent 77 的初始资源申请量为: 50.0
# agent 78 的初始资源申请量为: 50.0
# agent 79 的初始资源申请量为: 50.0
# agent 80 的初始资源申请量为: 50.0
# agent 81 的初始资源申请量为: 50.0
# agent 82 的初始资源申请量为: 50.0
# agent 83 的初始资源申请量为: 50.0
# agent 84 的初始资源申请量为: 50.0
# agent 85 的初始资源申请量为: 50.0
# agent 86 的初始资源申请量为: 50.0
# agent 87 的初始资源申请量为: 50.0
# agent 88 的初始资源申请量为: 50.0
# agent 89 的初始资源申请量为: 50.0
# agent 90 的初始资源申请量为: 50.0
# agent 91 的初始资源申请量为: 50.0
# agent 92 的初始资源申请量为: 50.0
# agent 93 的初始资源申请量为: 50.0
# agent 94 的初始资源申请量为: 50.0
# agent 95 的初始资源申请量为: 50.0
# agent 96 的初始资源申请量为: 50.0
# agent 97 的初始资源申请量为: 50.0
# agent 98 的初始资源申请量为: 50.0
# agent 99 的初始资源申请量为: 50.0
# agent 100 的初始资源申请量为: 50.0
# *************************
# 初始资源申请量总和为: 5000.0
# *************************
# 初始成本总和为: 346654.5889999999
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 49 次迭代中的结果：
# agent 1 在 49 次迭代中的资源申请量为: 49.33746036699384
# agent 2 在 49 次迭代中的资源申请量为: 62.30954258861368
# agent 3 在 49 次迭代中的资源申请量为: 44.63770212136671
# agent 4 在 49 次迭代中的资源申请量为: 65.68338660316559
# agent 5 在 49 次迭代中的资源申请量为: 66.539399135159
# agent 6 在 49 次迭代中的资源申请量为: 73.38966726572973
# agent 7 在 49 次迭代中的资源申请量为: 40.25058538310277
# agent 8 在 49 次迭代中的资源申请量为: 26.704613772499425
# agent 9 在 49 次迭代中的资源申请量为: 44.023723283020836
# agent 10 在 49 次迭代中的资源申请量为: 56.87907462307752
# agent 11 在 49 次迭代中的资源申请量为: 46.39659770773749
# agent 12 在 49 次迭代中的资源申请量为: 50.30169010852438
# agent 13 在 49 次迭代中的资源申请量为: 67.00571574824973
# agent 14 在 49 次迭代中的资源申请量为: 56.213332143882546
# agent 15 在 49 次迭代中的资源申请量为: 44.292282155861564
# agent 16 在 49 次迭代中的资源申请量为: 44.466995165531486
# agent 17 在 49 次迭代中的资源申请量为: 45.80425633718574
# agent 18 在 49 次迭代中的资源申请量为: 47.33831360029149
# agent 19 在 49 次迭代中的资源申请量为: 42.10691410232265
# agent 20 在 49 次迭代中的资源申请量为: 56.787231409317016
# agent 21 在 49 次迭代中的资源申请量为: 27.13070245095008
# agent 22 在 49 次迭代中的资源申请量为: 39.85563583470802
# agent 23 在 49 次迭代中的资源申请量为: 48.70350307500106
# agent 24 在 49 次迭代中的资源申请量为: 41.258285979216716
# agent 25 在 49 次迭代中的资源申请量为: 46.01085361447195
# agent 26 在 49 次迭代中的资源申请量为: 40.56157088587398
# agent 27 在 49 次迭代中的资源申请量为: 66.8631044533621
# agent 28 在 49 次迭代中的资源申请量为: 52.29475611519905
# agent 29 在 49 次迭代中的资源申请量为: 41.694525536065605
# agent 30 在 49 次迭代中的资源申请量为: 39.97117389241475
# agent 31 在 49 次迭代中的资源申请量为: 61.529476743271005
# agent 32 在 49 次迭代中的资源申请量为: 56.46342560119361
# agent 33 在 49 次迭代中的资源申请量为: 42.35362754091943
# agent 34 在 49 次迭代中的资源申请量为: 53.27116247673358
# agent 35 在 49 次迭代中的资源申请量为: 27.169931328043038
# agent 36 在 49 次迭代中的资源申请量为: 43.664538695162946
# agent 37 在 49 次迭代中的资源申请量为: 53.56316818767035
# agent 38 在 49 次迭代中的资源申请量为: 41.049235023713194
# agent 39 在 49 次迭代中的资源申请量为: 44.097121559891555
# agent 40 在 49 次迭代中的资源申请量为: 51.07389577059273
# agent 41 在 49 次迭代中的资源申请量为: 67.50296575338821
# agent 42 在 49 次迭代中的资源申请量为: 43.431257684865486
# agent 43 在 49 次迭代中的资源申请量为: 52.67526771739873
# agent 44 在 49 次迭代中的资源申请量为: 53.91260960379788
# agent 45 在 49 次迭代中的资源申请量为: 49.07827598001803
# agent 46 在 49 次迭代中的资源申请量为: 57.03624545446671
# agent 47 在 49 次迭代中的资源申请量为: 46.83072034728088
# agent 48 在 49 次迭代中的资源申请量为: 30.519120132359607
# agent 49 在 49 次迭代中的资源申请量为: 43.65076470705036
# agent 50 在 49 次迭代中的资源申请量为: 41.65613401401564
# agent 51 在 49 次迭代中的资源申请量为: 49.29646051356999
# agent 52 在 49 次迭代中的资源申请量为: 56.738467614789194
# agent 53 在 49 次迭代中的资源申请量为: 27.31239892673185
# agent 54 在 49 次迭代中的资源申请量为: 58.005221766598275
# agent 55 在 49 次迭代中的资源申请量为: 72.28393961969307
# agent 56 在 49 次迭代中的资源申请量为: 41.6485116219845
# agent 57 在 49 次迭代中的资源申请量为: 61.62850311527888
# agent 58 在 49 次迭代中的资源申请量为: 43.10228191829812
# agent 59 在 49 次迭代中的资源申请量为: 48.857576930388895
# agent 60 在 49 次迭代中的资源申请量为: 57.103336773640024
# agent 61 在 49 次迭代中的资源申请量为: 67.13742100497957
# agent 62 在 49 次迭代中的资源申请量为: 47.04853638537335
# agent 63 在 49 次迭代中的资源申请量为: 39.77214212114352
# agent 64 在 49 次迭代中的资源申请量为: 45.2884829468206
# agent 65 在 49 次迭代中的资源申请量为: 43.48612565704661
# agent 66 在 49 次迭代中的资源申请量为: 67.00373087152455
# agent 67 在 49 次迭代中的资源申请量为: 30.343071828499152
# agent 68 在 49 次迭代中的资源申请量为: 45.77735718253348
# agent 69 在 49 次迭代中的资源申请量为: 46.22093982769185
# agent 70 在 49 次迭代中的资源申请量为: 61.11819937841147
# agent 71 在 49 次迭代中的资源申请量为: 73.41748815451862
# agent 72 在 49 次迭代中的资源申请量为: 42.26044551811543
# agent 73 在 49 次迭代中的资源申请量为: 44.61462899827022
# agent 74 在 49 次迭代中的资源申请量为: 39.787348271116734
# agent 75 在 49 次迭代中的资源申请量为: 53.07838435663874
# agent 76 在 49 次迭代中的资源申请量为: 47.915716414172635
# agent 77 在 49 次迭代中的资源申请量为: 41.69732711191493
# agent 78 在 49 次迭代中的资源申请量为: 50.47811191337216
# agent 79 在 49 次迭代中的资源申请量为: 43.68254145891008
# agent 80 在 49 次迭代中的资源申请量为: 43.85617400920306
# agent 81 在 49 次迭代中的资源申请量为: 40.22803291512579
# agent 82 在 49 次迭代中的资源申请量为: 46.552809349082736
# agent 83 在 49 次迭代中的资源申请量为: 42.37052977481779
# agent 84 在 49 次迭代中的资源申请量为: 53.06265548970426
# agent 85 在 49 次迭代中的资源申请量为: 56.709490654643524
# agent 86 在 49 次迭代中的资源申请量为: 49.88757091355342
# agent 87 在 49 次迭代中的资源申请量为: 61.67593679293152
# agent 88 在 49 次迭代中的资源申请量为: 66.46867394360773
# agent 89 在 49 次迭代中的资源申请量为: 28.200703197053954
# agent 90 在 49 次迭代中的资源申请量为: 60.342093852977364
# agent 91 在 49 次迭代中的资源申请量为: 43.758114533861374
# agent 92 在 49 次迭代中的资源申请量为: 57.94232038038474
# agent 93 在 49 次迭代中的资源申请量为: 41.52686041648883
# agent 94 在 49 次迭代中的资源申请量为: 51.97531521025983
# agent 95 在 49 次迭代中的资源申请量为: 61.761152782820254
# agent 96 在 49 次迭代中的资源申请量为: 61.65842361837405
# agent 97 在 49 次迭代中的资源申请量为: 73.42722845342564
# agent 98 在 49 次迭代中的资源申请量为: 74.34326450594199
# agent 99 在 49 次迭代中的资源申请量为: 53.38183233649013
# agent 100 在 49 次迭代中的资源申请量为: 49.42457888649606
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 336896.1928736628
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: 50.70066884463511
# agent 2 在 99 次迭代中的资源申请量为: 64.01356474846924
# agent 3 在 99 次迭代中的资源申请量为: 45.84053930006716
# agent 4 在 99 次迭代中的资源申请量为: 67.54232975409666
# agent 5 在 99 次迭代中的资源申请量为: 68.39835391270752
# agent 6 在 99 次迭代中的资源申请量为: 75.43454927939786
# agent 7 在 99 次迭代中的资源申请量为: 41.3268159867442
# agent 8 在 99 次迭代中的资源申请量为: 15.22702583970649
# agent 9 在 99 次迭代中的资源申请量为: 45.2265652159689
# agent 10 在 99 次迭代中的资源申请量为: 58.45201747324331
# agent 11 在 99 次迭代中的资源申请量为: 47.674620921893734
# agent 12 在 99 次迭代中的资源申请量为: 51.664912455932566
# agent 13 在 99 次迭代中的资源申请量为: 68.864634969321
# agent 14 在 99 次迭代中的资源申请量为: 57.78626113441593
# agent 15 在 99 次迭代中的资源申请量为: 45.495119279160896
# agent 16 在 99 次迭代中的资源申请量为: 45.66983881384688
# agent 17 在 99 次迭代中的资源申请量为: 47.0822702938387
# agent 18 在 99 次迭代中的资源申请量为: 48.61633560800183
# agent 19 在 99 次迭代中的资源申请量为: 43.242927005010415
# agent 20 在 99 次迭代中的资源申请量为: 58.360183617445465
# agent 21 在 99 次迭代中的资源申请量为: 15.049032400089747
# agent 22 在 99 次迭代中的资源申请量为: 40.93186401841736
# agent 23 在 99 次迭代中的资源申请量为: 50.066714094674985
# agent 24 在 99 次迭代中的资源申请量为: 42.39429336509734
# agent 25 在 99 次迭代中的资源申请量为: 47.28886837848695
# agent 26 在 99 次迭代中的资源申请量为: 41.63779529583895
# agent 27 在 99 次迭代中的资源申请量为: 68.72202294900566
# agent 28 在 99 次迭代中的资源申请量为: 53.755345309278226
# agent 29 在 99 次迭代中的资源申请量为: 42.83053592820681
# agent 30 在 99 次迭代中的资源申请量为: 41.047396555447314
# agent 31 在 99 次迭代中的资源申请量为: 63.233490073708055
# agent 32 在 99 次迭代中的资源申请量为: 58.03635341747384
# agent 33 在 99 次迭代中的资源申请量为: 43.48963976967947
# agent 34 在 99 次迭代中的资源申请量为: 54.731750784894814
# agent 35 在 99 次迭代中的资源申请量为: 15.088262569707647
# agent 36 在 99 次迭代中的资源申请量为: 44.86738637989859
# agent 37 在 99 次迭代中的资源申请量为: 55.02376203302013
# agent 38 在 99 次迭代中的资源申请量为: 42.18524744433161
# agent 39 在 99 次迭代中的资源申请量为: 45.29996260226913
# agent 40 在 99 次迭代中的资源申请量为: 52.4371208461914
# agent 41 在 99 次迭代中的资源申请量为: 69.36191613819857
# agent 42 在 99 次迭代中的资源申请量为: 44.634097551381814
# agent 43 在 99 次迭代中的资源申请量为: 54.135869229047366
# agent 44 在 99 次迭代中的资源申请量为: 55.37320239822829
# agent 45 在 99 次迭代中的资源申请量为: 50.44148859392923
# agent 46 在 99 次迭代中的资源申请量为: 58.60919622001469
# agent 47 在 99 次迭代中的资源申请量为: 48.10873700609037
# agent 48 在 99 次迭代中的资源申请量为: 17.01607786726691
# agent 49 在 99 次迭代中的资源申请量为: 44.853613874715826
# agent 50 在 99 次迭代中的资源申请量为: 42.792149817819876
# agent 51 在 99 次迭代中的资源申请量为: 50.65968626964676
# agent 52 在 99 次迭代中的资源申请量为: 58.31140798023997
# agent 53 在 99 次迭代中的资源申请量为: 15.230732723281276
# agent 54 在 99 次迭代中的资源申请量为: 59.57815732426063
# agent 55 在 99 次迭代中的资源申请量为: 74.3287536705823
# agent 56 在 99 次迭代中的资源申请量为: 42.784523250439875
# agent 57 在 99 次迭代中的资源申请量为: 63.332522509340066
# agent 58 在 99 次迭代中的资源申请量为: 44.30511503207807
# agent 59 在 99 次迭代中的资源申请量为: 50.22079807303418
# agent 60 在 99 次迭代中的资源申请量为: 58.67628630580645
# agent 61 在 99 次迭代中的资源申请量为: 68.99637757780987
# agent 62 在 99 次迭代中的资源申请量为: 48.32655716064953
# agent 63 在 99 次迭代中的资源申请量为: 40.84837168196564
# agent 64 在 99 次迭代中的资源申请量为: 46.56650381199549
# agent 65 在 99 次迭代中的资源申请量为: 44.68896611050684
# agent 66 在 99 次迭代中的资源申请量为: 68.86269334399357
# agent 67 在 99 次迭代中的资源申请量为: 16.84003782537027
# agent 68 在 99 次迭代中的资源申请量为: 47.0553830713907
# agent 69 在 99 次迭代中的资源申请量为: 47.49896484253719
# agent 70 在 99 次迭代中的资源申请量为: 62.82223664857732
# agent 71 在 99 次迭代中的资源申请量为: 75.4623646404442
# agent 72 在 99 次迭代中的资源申请量为: 23.13113755516205
# agent 73 在 99 次迭代中的资源申请量为: 45.81747211976254
# agent 74 在 99 次迭代中的资源申请量为: 40.86356973049084
# agent 75 在 99 次迭代中的资源申请量为: 54.538975308895886
# agent 76 在 99 次迭代中的资源申请量为: 49.193730839934815
# agent 77 在 99 次迭代中的资源申请量为: 42.83334204042912
# agent 78 在 99 次迭代中的资源申请量为: 51.841321641850016
# agent 79 在 99 次迭代中的资源申请量为: 44.88538104470788
# agent 80 在 99 次迭代中的资源申请量为: 45.05901037177272
# agent 81 在 99 次迭代中的资源申请量为: 41.30425081559623
# agent 82 在 99 次迭代中的资源申请量为: 47.83082487644656
# agent 83 在 99 次迭代中的资源申请量为: 43.50654300082718
# agent 84 在 99 次迭代中的资源申请量为: 54.523243464967315
# agent 85 在 99 次迭代中的资源申请量为: 58.28244078946505
# agent 86 在 99 次迭代中的资源申请量为: 51.25078892904159
# agent 87 在 99 次迭代中的资源申请量为: 63.379964977220794
# agent 88 在 99 次迭代中的资源申请量为: 68.32763929654071
# agent 89 在 99 次迭代中的资源申请量为: 15.447839128531546
# agent 90 在 99 次迭代中的资源申请量为: 62.04611331702041
# agent 91 在 99 次迭代中的资源申请量为: 44.960955154042416
# agent 92 在 99 次迭代中的资源申请量为: 59.51526043436141
# agent 93 在 99 次迭代中的资源申请量为: 42.662873577410636
# agent 94 在 99 次迭代中的资源申请量为: 29.020139905838118
# agent 95 在 99 次迭代中的资源申请量为: 63.465174160030664
# agent 96 在 99 次迭代中的资源申请量为: 63.36245001777982
# agent 97 在 99 次迭代中的资源申请量为: 75.47208419621002
# agent 98 在 99 次迭代中的资源申请量为: 76.388089361177
# agent 99 在 99 次迭代中的资源申请量为: 54.84242006027072
# agent 100 在 99 次迭代中的资源申请量为: 50.787796663951156
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 346166.03660465096
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 149 次迭代中的结果：
# agent 1 在 149 次迭代中的资源申请量为: 52.063889272274125
# agent 2 在 149 次迭代中的资源申请量为: 65.71759028306683
# agent 3 在 149 次迭代中的资源申请量为: 47.04338085389116
# agent 4 在 149 次迭代中的资源申请量为: 69.40126670096801
# agent 5 在 149 次迭代中的资源申请量为: 70.25729085961476
# agent 6 在 149 次迭代中的资源申请量为: 77.47937992109995
# agent 7 在 149 次迭代中的资源申请量为: 42.40304264018989
# agent 8 在 149 次迭代中的资源申请量为: 3.7494411604497215
# agent 9 在 149 次迭代中的资源申请量为: 46.429406769802895
# agent 10 在 149 次迭代中的资源申请量为: 60.02496412056519
# agent 11 在 149 次迭代中的资源申请量为: 48.95264007286043
# agent 12 在 149 次迭代中的资源申请量为: 53.028132883610134
# agent 13 在 149 次迭代中的资源申请量为: 70.72357191608249
# agent 14 在 149 次迭代中的资源申请量为: 59.35920778168109
# agent 15 在 149 次迭代中的资源申请量为: 46.69796083298651
# agent 16 在 149 次迭代中的资源申请量为: 46.872680367689696
# agent 17 在 149 次迭代中的资源申请量为: 48.36028944477076
# agent 18 在 149 次迭代中的资源申请量为: 49.894354758966294
# agent 19 在 149 次迭代中的资源申请量为: 44.37894402806241
# agent 20 在 149 次迭代中的资源申请量为: 59.93313026479337
# agent 21 在 149 次迭代中的资源申请量为: 2.9673643166751167
# agent 22 在 149 次迭代中的资源申请量为: 42.00809067185387
# agent 23 在 149 次迭代中的资源申请量为: 51.42993452232991
# agent 24 在 149 次迭代中的资源申请量为: 43.53031038813556
# agent 25 在 149 次迭代中的资源申请量为: 48.56688752942331
# agent 26 在 149 次迭代中的资源申请量为: 42.71402194926429
# agent 27 在 149 次迭代中的资源申请量为: 70.58095989575858
# agent 28 在 149 次迭代中的资源申请量为: 55.21593862462019
# agent 29 在 149 次迭代中的资源申请量为: 43.96655295124554
# agent 30 在 149 次迭代中的资源申请量为: 42.12362320886668
# agent 31 在 149 次迭代中的资源申请量为: 64.9375156082743
# agent 32 在 149 次迭代中的资源申请量为: 59.60930006473352
# agent 33 在 149 次迭代中的资源申请量为: 44.625656792720505
# agent 34 在 149 次迭代中的资源申请量为: 56.192344100250445
# agent 35 在 149 次迭代中的资源申请量为: 3.0065944862943383
# agent 36 在 149 次迭代中的资源申请量为: 46.070227933758495
# agent 37 在 149 次迭代中的资源申请量为: 56.48435534839008
# agent 38 在 149 次迭代中的资源申请量为: 43.32126446738092
# agent 39 在 149 次迭代中的资源申请量为: 46.50280415610555
# agent 40 在 149 次迭代中的资源申请量为: 53.80034127388449
# agent 41 在 149 次迭代中的资源申请量为: 71.22085308507788
# agent 42 在 149 次迭代中的资源申请量为: 45.836939105208984
# agent 43 在 149 次迭代中的资源申请量为: 55.59646254444897
# agent 44 在 149 次迭代中的资源申请量为: 56.83379571360811
# agent 45 在 149 次迭代中的资源申请量为: 51.804709021588316
# agent 46 在 149 次迭代中的资源申请量为: 60.18214286735715
# agent 47 在 149 次迭代中的资源申请量为: 49.3867561570347
# agent 48 在 149 次迭代中的资源申请量为: 3.513037068147261
# agent 49 在 149 次迭代中的资源申请量为: 46.056455428572114
# agent 50 在 149 次迭代中的资源申请量为: 43.92816684087964
# agent 51 在 149 次迭代中的资源申请量为: 52.02290669734047
# agent 52 在 149 次迭代中的资源申请量为: 59.88435462752658
# agent 53 在 149 次迭代中的资源申请量为: 3.149064639876882
# agent 54 在 149 次迭代中的资源申请量为: 61.151103971539584
# agent 55 在 149 次迭代中的资源申请量为: 76.37358431201137
# agent 56 在 149 次迭代中的资源申请量为: 43.9205402734851
# agent 57 在 149 次迭代中的资源申请量为: 65.03654804391323
# agent 58 在 149 次迭代中的资源申请量为: 45.507956585879604
# agent 59 在 149 次迭代中的资源申请量为: 51.584018500717384
# agent 60 在 149 次迭代中的资源申请量为: 60.2492329531422
# agent 61 在 149 次迭代中的资源申请量为: 70.85531452472532
# agent 62 在 149 次迭代中的资源申请量为: 49.60457631160456
# agent 63 在 149 次迭代中的资源申请量为: 41.92459833540988
# agent 64 在 149 次迭代中的资源申请量为: 47.84452296295098
# agent 65 在 149 次迭代中的资源申请量为: 45.89180766433976
# agent 66 在 149 次迭代中的资源申请量为: 70.7216302909077
# agent 67 在 149 次迭代中的资源申请量为: 3.336997026289027
# agent 68 在 149 次迭代中的资源申请量为: 48.33340222236525
# agent 69 在 149 次迭代中的资源申请量为: 48.776983993506626
# agent 70 在 149 次迭代中的资源申请量为: 64.52626218321555
# agent 71 在 149 次迭代中的资源申请量为: 77.50719528212414
# agent 72 在 149 次迭代中的资源申请量为: 4.001829756424139
# agent 73 在 149 次迭代中的资源申请量为: 47.020313673602416
# agent 74 在 149 次迭代中的资源申请量为: 41.93979638390345
# agent 75 在 149 次迭代中的资源申请量为: 55.99956862425874
# agent 76 在 149 次迭代中的资源申请量为: 50.47174999086633
# agent 77 在 149 次迭代中的资源申请量为: 43.9693590634822
# agent 78 在 149 次迭代中的资源申请量为: 53.204542069478585
# agent 79 在 149 次迭代中的资源申请量为: 46.08822259853621
# agent 80 在 149 次迭代中的资源申请量为: 46.2618519255831
# agent 81 在 149 次迭代中的资源申请量为: 42.38047746899748
# agent 82 在 149 次迭代中的资源申请量为: 49.10884402738363
# agent 83 在 149 次迭代中的资源申请量为: 44.642560023878126
# agent 84 在 149 次迭代中的资源申请量为: 55.9838367803062
# agent 85 在 149 次迭代中的资源申请量为: 59.855387436795276
# agent 86 在 149 次迭代中的资源申请量为: 52.614009356712174
# agent 87 在 149 次迭代中的资源申请量为: 65.08399051183811
# agent 88 在 149 次迭代中的资源申请量为: 70.18657624346609
# agent 89 在 149 次迭代中的资源申请量为: 2.6949672627350263
# agent 90 在 149 次迭代中的资源申请量为: 63.750138851595565
# agent 91 在 149 次迭代中的资源申请量为: 46.163796707873416
# agent 92 在 149 次迭代中的资源申请量为: 61.088207081669196
# agent 93 在 149 次迭代中的资源申请量为: 43.79889060046575
# agent 94 在 149 次迭代中的资源申请量为: 6.064970547308849
# agent 95 在 149 次迭代中的资源申请量为: 65.16919969460974
# agent 96 在 149 次迭代中的资源申请量为: 65.06647555237448
# agent 97 在 149 次迭代中的资源申请量为: 77.51691483778762
# agent 98 在 149 次迭代中的资源申请量为: 78.43292000263507
# agent 99 在 149 次迭代中的资源申请量为: 56.30301337561933
# agent 100 在 149 次迭代中的资源申请量为: 52.15101709162809
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 361914.1814531622
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: 53.42710969995213
# agent 2 在 199 次迭代中的资源申请量为: 67.42161581766433
# agent 3 在 199 次迭代中的资源申请量为: 48.246222407724694
# agent 4 在 199 次迭代中的资源申请量为: 71.26020364780165
# agent 5 在 199 次迭代中的资源申请量为: 72.11622780644839
# agent 6 在 199 次迭代中的资源申请量为: 79.52421056261696
# agent 7 在 199 次迭代中的资源申请量为: 43.479269293619886
# agent 8 在 199 次迭代中的资源申请量为: -7.728143518791772
# agent 9 在 199 次迭代中的资源申请量为: 47.632248323636425
# agent 10 在 199 次迭代中的资源申请量为: 61.59791076788596
# agent 11 在 199 次迭代中的资源申请量为: 50.23065922380856
# agent 12 在 199 次迭代中的资源申请量为: 54.39135331128814
# agent 13 在 199 次迭代中的资源申请量为: 72.58250886291614
# agent 14 在 199 次迭代中的资源申请量为: 60.93215442900187
# agent 15 在 199 次迭代中的资源申请量为: 47.90080238682005
# agent 16 在 199 次迭代中的资源申请量为: 48.075521921523226
# agent 17 在 199 次迭代中的资源申请量为: 49.6383085957189
# agent 18 在 199 次迭代中的资源申请量为: 51.17237390991442
# agent 19 在 199 次迭代中的资源申请量为: 45.51496105112742
# agent 20 在 199 次迭代中的资源申请量为: 61.506076912114146
# agent 21 在 199 次迭代中的资源申请量为: -9.11430376673698
# agent 22 在 199 次迭代中的资源申请量为: 43.08431732528387
# agent 23 在 199 次迭代中的资源申请量为: 52.79315495000792
# agent 24 在 199 次迭代中的资源申请量为: 44.666327411200555
# agent 25 在 199 次迭代中的资源申请量为: 49.84490668037144
# agent 26 在 199 次迭代中的资源申请量为: 43.7902486026943
# agent 27 在 199 次迭代中的资源申请量为: 72.43989684259223
# agent 28 在 199 次迭代中的资源申请量为: 56.67653193998949
# agent 29 在 199 次迭代中的资源申请量为: 45.10256997431055
# agent 30 在 199 次迭代中的资源申请量为: 43.19984986229669
# agent 31 在 199 次迭代中的资源申请量为: 66.6415411428718
# agent 32 在 199 次迭代中的资源申请量为: 61.18224671205429
# agent 33 在 199 次迭代中的资源申请量为: 45.761673815785514
# agent 34 在 199 次迭代中的资源申请量为: 57.65293741561973
# agent 35 在 199 次迭代中的资源申请量为: -9.075073597117763
# agent 36 在 199 次迭代中的资源申请量为: 47.27306948759203
# agent 37 在 199 次迭代中的资源申请量为: 57.94494866375938
# agent 38 在 199 次迭代中的资源申请量为: 44.45728149044593
# agent 39 在 199 次迭代中的资源申请量为: 47.705645709939084
# agent 40 在 199 次迭代中的资源申请量为: 55.1635617015625
# agent 41 在 199 次迭代中的资源申请量为: 73.07979003191151
# agent 42 在 199 次迭代中的资源申请量为: 47.03978065904252
# agent 43 在 199 次迭代中的资源申请量为: 57.05705585981826
# agent 44 在 199 次迭代中的资源申请量为: 58.294389028977406
# agent 45 在 199 次迭代中的资源申请量为: 53.16792944926633
# agent 46 在 199 次迭代中的资源申请量为: 61.75508951467792
# agent 47 在 199 次迭代中的资源申请量为: 50.66477530798282
# agent 48 在 199 次迭代中的资源申请量为: -9.990003730960392
# agent 49 在 199 次迭代中的资源申请量为: 47.259296982405644
# agent 50 在 199 次迭代中的资源申请量为: 45.06418386394465
# agent 51 在 199 次迭代中的资源申请量为: 53.38612712501848
# agent 52 在 199 次迭代中的资源申请量为: 61.45730127484736
# agent 53 在 199 次迭代中的资源申请量为: -8.932603443535214
# agent 54 在 199 次迭代中的资源申请量为: 62.72405061886036
# agent 55 在 199 次迭代中的资源申请量为: 78.41841495352838
# agent 56 在 199 次迭代中的资源申请量为: 45.05655729655011
# agent 57 在 199 次迭代中的资源申请量为: 66.74057357851073
# agent 58 在 199 次迭代中的资源申请量为: 46.71079813971314
# agent 59 在 199 次迭代中的资源申请量为: 52.94723892839539
# agent 60 在 199 次迭代中的资源申请量为: 61.822179600462974
# agent 61 在 199 次迭代中的资源申请量为: 72.71425147155897
# agent 62 在 199 次迭代中的资源申请量为: 50.88259546255269
# agent 63 在 199 次迭代中的资源申请量为: 43.00082498883988
# agent 64 在 199 次迭代中的资源申请量为: 49.12254211389911
# agent 65 在 199 次迭代中的资源申请量为: 47.094649218173295
# agent 66 在 199 次迭代中的资源申请量为: 72.58056723774135
# agent 67 在 199 次迭代中的资源申请量为: -10.166043772818615
# agent 68 在 199 次迭代中的资源申请量为: 49.611421373313384
# agent 69 在 199 次迭代中的资源申请量为: 50.055003144454766
# agent 70 在 199 次迭代中的资源申请量为: 66.23028771781306
# agent 71 在 199 次迭代中的资源申请量为: 79.55202592364114
# agent 72 在 199 次迭代中的资源申请量为: -15.12747804231168
# agent 73 在 199 次迭代中的资源申请量为: 48.22315522743596
# agent 74 在 199 次迭代中的资源申请量为: 43.016023037333454
# agent 75 在 199 次迭代中的资源申请量为: 57.46016193962804
# agent 76 在 199 次迭代中的资源申请量为: 51.74976914181446
# agent 77 在 199 次迭代中的资源申请量为: 45.10537608654722
# agent 78 在 199 次迭代中的资源申请量为: 54.56776249715659
# agent 79 在 199 次迭代中的资源申请量为: 47.29106415236975
# agent 80 在 199 次迭代中的资源申请量为: 47.46469347941664
# agent 81 在 199 次迭代中的资源申请量为: 43.456704122427496
# agent 82 在 199 次迭代中的资源申请量为: 50.386863178331765
# agent 83 在 199 次迭代中的资源申请量为: 45.778577046943134
# agent 84 在 199 次迭代中的资源申请量为: 57.44443009567549
# agent 85 在 199 次迭代中的资源申请量为: 61.42833408411605
# agent 86 在 199 次迭代中的资源申请量为: 53.97722978439019
# agent 87 在 199 次迭代中的资源申请量为: 66.78801604643562
# agent 88 在 199 次迭代中的资源申请量为: 72.04551319029974
# agent 89 在 199 次迭代中的资源申请量为: -10.057904603088852
# agent 90 在 199 次迭代中的资源申请量为: 65.45416438619309
# agent 91 在 199 次迭代中的资源申请量为: 47.36663826170695
# agent 92 在 199 次迭代中的资源申请量为: 62.66115372898998
# agent 93 在 199 次迭代中的资源申请量为: 44.93490762353075
# agent 94 在 199 次迭代中的资源申请量为: -16.89019881117414
# agent 95 在 199 次迭代中的资源申请量为: 66.87322522920726
# agent 96 在 199 次迭代中的资源申请量为: 66.77050108697199
# agent 97 在 199 次迭代中的资源申请量为: 79.56174547930463
# agent 98 在 199 次迭代中的资源申请量为: 80.47775064415208
# agent 99 在 199 次迭代中的资源申请量为: 57.76360669098863
# agent 100 在 199 次迭代中的资源申请量为: 53.51423751930609
# 资源申请量总和为: 5000.000000000001
# ****************************************************************************
# 成本总和为: 384140.6272792084
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 249 次迭代中的结果：
# agent 1 在 249 次迭代中的资源申请量为: 54.79033012763014
# agent 2 在 249 次迭代中的资源申请量为: 69.12564135226185
# agent 3 在 249 次迭代中的资源申请量为: 49.44906396155823
# agent 4 在 249 次迭代中的资源申请量为: 73.11914059463528
# agent 5 在 249 次迭代中的资源申请量为: 73.97516475328206
# agent 6 在 249 次迭代中的资源申请量为: 81.56904120413397
# agent 7 在 249 次迭代中的资源申请量为: 44.55549594704989
# agent 8 在 249 次迭代中的资源申请量为: -19.20572819803327
# agent 9 在 249 次迭代中的资源申请量为: 48.83508987746997
# agent 10 在 249 次迭代中的资源申请量为: 63.17085741520674
# agent 11 在 249 次迭代中的资源申请量为: 51.50867837475669
# agent 12 在 249 次迭代中的资源申请量为: 55.754573738966144
# agent 13 在 249 次迭代中的资源申请量为: 74.44144580974978
# agent 14 在 249 次迭代中的资源申请量为: 62.505101076322646
# agent 15 在 249 次迭代中的资源申请量为: 49.10364394065358
# agent 16 在 249 次迭代中的资源申请量为: 49.27836347535676
# agent 17 在 249 次迭代中的资源申请量为: 50.91632774666703
# agent 18 在 249 次迭代中的资源申请量为: 52.45039306086257
# agent 19 在 249 次迭代中的资源申请量为: 46.65097807419243
# agent 20 在 249 次迭代中的资源申请量为: 63.07902355943492
# agent 21 在 249 次迭代中的资源申请量为: -21.195971850149085
# agent 22 在 249 次迭代中的资源申请量为: 44.160543978713875
# agent 23 在 249 次迭代中的资源申请量为: 54.156375377685926
# agent 24 在 249 次迭代中的资源申请量为: 45.80234443426557
# agent 25 在 249 次迭代中的资源申请量为: 51.12292583131956
# agent 26 在 249 次迭代中的资源申请量为: 44.86647525612431
# agent 27 在 249 次迭代中的资源申请量为: 74.29883378942587
# agent 28 在 249 次迭代中的资源申请量为: 58.13712525535878
# agent 29 在 249 次迭代中的资源申请量为: 46.238586997375556
# agent 30 在 249 次迭代中的资源申请量为: 44.27607651572669
# agent 31 在 249 次迭代中的资源申请量为: 68.34556667746932
# agent 32 在 249 次迭代中的资源申请量为: 62.75519335937507
# agent 33 在 249 次迭代中的资源申请量为: 46.897690838850515
# agent 34 在 249 次迭代中的资源申请量为: 59.113530730989034
# agent 35 在 249 次迭代中的资源申请量为: -21.156741680529862
# agent 36 在 249 次迭代中的资源申请量为: 48.47591104142557
# agent 37 在 249 次迭代中的资源申请量为: 59.40554197912867
# agent 38 在 249 次迭代中的资源申请量为: 45.59329851351093
# agent 39 在 249 次迭代中的资源申请量为: 48.90848726377262
# agent 40 在 249 次迭代中的资源申请量为: 56.52678212924051
# agent 41 在 249 次迭代中的资源申请量为: 74.93872697874517
# agent 42 在 249 次迭代中的资源申请量为: 48.24262221287606
# agent 43 在 249 次迭代中的资源申请量为: 58.51764917518756
# agent 44 在 249 次迭代中的资源申请量为: 59.754982344346686
# agent 45 在 249 次迭代中的资源申请量为: 54.531149876944326
# agent 46 在 249 次迭代中的资源申请量为: 63.328036161998696
# agent 47 在 249 次迭代中的资源申请量为: 51.94279445893096
# agent 48 在 249 次迭代中的资源申请量为: -23.49304453006803
# agent 49 在 249 次迭代中的资源申请量为: 48.46213853623918
# agent 50 在 249 次迭代中的资源申请量为: 46.20020088700965
# agent 51 在 249 次迭代中的资源申请量为: 54.74934755269649
# agent 52 在 249 次迭代中的资源申请量为: 63.03024792216814
# agent 53 在 249 次迭代中的资源申请量为: -21.01427152694732
# agent 54 在 249 次迭代中的资源申请量为: 64.29699726618114
# agent 55 在 249 次迭代中的资源申请量为: 80.46324559504541
# agent 56 在 249 次迭代中的资源申请量为: 46.19257431961511
# agent 57 在 249 次迭代中的资源申请量为: 68.44459911310824
# agent 58 在 249 次迭代中的资源申请量为: 47.91363969354667
# agent 59 在 249 次迭代中的资源申请量为: 54.3104593560734
# agent 60 在 249 次迭代中的资源申请量为: 63.39512624778375
# agent 61 在 249 次迭代中的资源申请量为: 74.5731884183926
# agent 62 在 249 次迭代中的资源申请量为: 52.16061461350083
# agent 63 在 249 次迭代中的资源申请量为: 44.07705164226989
# agent 64 在 249 次迭代中的资源申请量为: 50.40056126484724
# agent 65 在 249 次迭代中的资源申请量为: 48.29749077200683
# agent 66 在 249 次迭代中的资源申请量为: 74.43950418457499
# agent 67 在 249 次迭代中的资源申请量为: -23.66908457192626
# agent 68 在 249 次迭代中的资源申请量为: 50.889440524261516
# agent 69 在 249 次迭代中的资源申请量为: 51.33302229540289
# agent 70 在 249 次迭代中的资源申请量为: 67.93431325241056
# agent 71 在 249 次迭代中的资源申请量为: 81.59685656515815
# agent 72 在 249 次迭代中的资源申请量为: -34.25678584104751
# agent 73 在 249 次迭代中的资源申请量为: 49.4259967812695
# agent 74 在 249 次迭代中的资源申请量为: 44.09224969076346
# agent 75 在 249 次迭代中的资源申请量为: 58.92075525499733
# agent 76 在 249 次迭代中的资源申请量为: 53.027788292762594
# agent 77 在 249 次迭代中的资源申请量为: 46.24139310961222
# agent 78 在 249 次迭代中的资源申请量为: 55.930982924834595
# agent 79 在 249 次迭代中的资源申请量为: 48.49390570620328
# agent 80 在 249 次迭代中的资源申请量为: 48.667535033250175
# agent 81 在 249 次迭代中的资源申请量为: 44.532930775857494
# agent 82 在 249 次迭代中的资源申请量为: 51.6648823292799
# agent 83 在 249 次迭代中的资源申请量为: 46.91459407000814
# agent 84 在 249 次迭代中的资源申请量为: 58.90502341104479
# agent 85 在 249 次迭代中的资源申请量为: 63.00128073143683
# agent 86 在 249 次迭代中的资源申请量为: 55.34045021206819
# agent 87 在 249 次迭代中的资源申请量为: 68.49204158103312
# agent 88 在 249 次迭代中的资源申请量为: 73.90445013713338
# agent 89 在 249 次迭代中的资源申请量为: -22.810776468912742
# agent 90 在 249 次迭代中的资源申请量为: 67.15818992079059
# agent 91 在 249 次迭代中的资源申请量为: 48.56947981554049
# agent 92 在 249 次迭代中的资源申请量为: 64.23410037631076
# agent 93 在 249 次迭代中的资源申请量为: 46.070924646595756
# agent 94 在 249 次迭代中的资源申请量为: -39.84536816965713
# agent 95 在 249 次迭代中的资源申请量为: 68.57725076380477
# agent 96 在 249 次迭代中的资源申请量为: 68.4745266215695
# agent 97 在 249 次迭代中的资源申请量为: 81.60657612082166
# agent 98 在 249 次迭代中的资源申请量为: 82.52258128566909
# agent 99 在 249 次迭代中的资源申请量为: 59.22420000635792
# agent 100 在 249 次迭代中的资源申请量为: 54.8774579469841
# 资源申请量总和为: 4999.999999999998
# ****************************************************************************
# 成本总和为: 412845.37408279156
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 299 次迭代中的结果：
# agent 1 在 299 次迭代中的资源申请量为: 56.15355055530815
# agent 2 在 299 次迭代中的资源申请量为: 70.82966688685936
# agent 3 在 299 次迭代中的资源申请量为: 50.65190551539177
# agent 4 在 299 次迭代中的资源申请量为: 74.97807754146895
# agent 5 在 299 次迭代中的资源申请量为: 75.8341017001157
# agent 6 在 299 次迭代中的资源申请量为: 83.61387184565099
# agent 7 在 299 次迭代中的资源申请量为: 45.63172260047991
# agent 8 在 299 次迭代中的资源申请量为: -30.683312877274755
# agent 9 在 299 次迭代中的资源申请量为: 50.037931431303505
# agent 10 在 299 次迭代中的资源申请量为: 64.74380406252752
# agent 11 在 299 次迭代中的资源申请量为: 52.78669752570483
# agent 12 在 299 次迭代中的资源申请量为: 57.11779416664415
# agent 13 在 299 次迭代中的资源申请量为: 76.30038275658343
# agent 14 在 299 次迭代中的资源申请量为: 64.07804772364342
# agent 15 在 299 次迭代中的资源申请量为: 50.30648549448713
# agent 16 在 299 次迭代中的资源申请量为: 50.481205029190306
# agent 17 在 299 次迭代中的资源申请量为: 52.19434689761516
# agent 18 在 299 次迭代中的资源申请量为: 53.7284122118107
# agent 19 在 299 次迭代中的资源申请量为: 47.78699509725744
# agent 20 在 299 次迭代中的资源申请量为: 64.6519702067557
# agent 21 在 299 次迭代中的资源申请量为: -33.277639933561176
# agent 22 在 299 次迭代中的资源申请量为: 45.23677063214388
# agent 23 在 299 次迭代中的资源申请量为: 55.51959580536394
# agent 24 在 299 次迭代中的资源申请量为: 46.93836145733058
# agent 25 在 299 次迭代中的资源申请量为: 52.40094498226771
# agent 26 在 299 次迭代中的资源申请量为: 45.942701909554316
# agent 27 在 299 次迭代中的资源申请量为: 76.15777073625952
# agent 28 在 299 次迭代中的资源申请量为: 59.59771857072807
# agent 29 在 299 次迭代中的资源申请量为: 47.374604020440565
# agent 30 在 299 次迭代中的资源申请量为: 45.352303169156706
# agent 31 在 299 次迭代中的资源申请量为: 70.04959221206683
# agent 32 在 299 次迭代中的资源申请量为: 64.32814000669585
# agent 33 在 299 次迭代中的资源申请量为: 48.03370786191553
# agent 34 在 299 次迭代中的资源申请量为: 60.57412404635833
# agent 35 在 299 次迭代中的资源申请量为: -33.23840976394196
# agent 36 在 299 次迭代中的资源申请量为: 49.6787525952591
# agent 37 在 299 次迭代中的资源申请量为: 60.866135294497965
# agent 38 在 299 次迭代中的资源申请量为: 46.72931553657594
# agent 39 在 299 次迭代中的资源申请量为: 50.11132881760616
# agent 40 在 299 次迭代中的资源申请量为: 57.89000255691852
# agent 41 在 299 次迭代中的资源申请量为: 76.79766392557882
# agent 42 在 299 次迭代中的资源申请量为: 49.445463766709594
# agent 43 在 299 次迭代中的资源申请量为: 59.97824249055686
# agent 44 在 299 次迭代中的资源申请量为: 61.21557565971599
# agent 45 在 299 次迭代中的资源申请量为: 55.89437030462234
# agent 46 在 299 次迭代中的资源申请量为: 64.90098280931947
# agent 47 在 299 次迭代中的资源申请量为: 53.22081360987909
# agent 48 在 299 次迭代中的资源申请量为: -36.99608532917567
# agent 49 在 299 次迭代中的资源申请量为: 49.66498009007272
# agent 50 在 299 次迭代中的资源申请量为: 47.336217910074666
# agent 51 在 299 次迭代中的资源申请量为: 56.11256798037449
# agent 52 在 299 次迭代中的资源申请量为: 64.60319456948892
# agent 53 在 299 次迭代中的资源申请量为: -33.09593961035941
# agent 54 在 299 次迭代中的资源申请量为: 65.86994391350193
# agent 55 在 299 次迭代中的资源申请量为: 82.50807623656242
# agent 56 在 299 次迭代中的资源申请量为: 47.32859134268012
# agent 57 在 299 次迭代中的资源申请量为: 70.14862464770576
# agent 58 在 299 次迭代中的资源申请量为: 49.11648124738021
# agent 59 在 299 次迭代中的资源申请量为: 55.67367978375141
# agent 60 在 299 次迭代中的资源申请量为: 64.96807289510453
# agent 61 在 299 次迭代中的资源申请量为: 76.43212536522626
# agent 62 在 299 次迭代中的资源申请量为: 53.43863376444897
# agent 63 在 299 次迭代中的资源申请量为: 45.1532782956999
# agent 64 在 299 次迭代中的资源申请量为: 51.67858041579537
# agent 65 在 299 次迭代中的资源申请量为: 49.50033232584037
# agent 66 在 299 次迭代中的资源申请量为: 76.29844113140864
# agent 67 在 299 次迭代中的资源申请量为: -37.1721253710339
# agent 68 在 299 次迭代中的资源申请量为: 52.16745967520965
# agent 69 在 299 次迭代中的资源申请量为: 52.61104144635103
# agent 70 在 299 次迭代中的资源申请量为: 69.63833878700808
# agent 71 在 299 次迭代中的资源申请量为: 83.64168720667517
# agent 72 在 299 次迭代中的资源申请量为: -53.38609363978333
# agent 73 在 299 次迭代中的资源申请量为: 50.62883833510303
# agent 74 在 299 次迭代中的资源申请量为: 45.168476344193465
# agent 75 在 299 次迭代中的资源申请量为: 60.381348570366626
# agent 76 在 299 次迭代中的资源申请量为: 54.30580744371072
# agent 77 在 299 次迭代中的资源申请量为: 47.37741013267723
# agent 78 在 299 次迭代中的资源申请量为: 57.294203352512596
# agent 79 在 299 次迭代中的资源申请量为: 49.69674726003683
# agent 80 在 299 次迭代中的资源申请量为: 49.87037658708372
# agent 81 在 299 次迭代中的资源申请量为: 45.6091574292875
# agent 82 在 299 次迭代中的资源申请量为: 52.94290148022804
# agent 83 在 299 次迭代中的资源申请量为: 48.050611093073144
# agent 84 在 299 次迭代中的资源申请量为: 60.36561672641408
# agent 85 在 299 次迭代中的资源申请量为: 64.57422737875761
# agent 86 在 299 次迭代中的资源申请量为: 56.7036706397462
# agent 87 在 299 次迭代中的资源申请量为: 70.19606711563064
# agent 88 在 299 次迭代中的资源申请量为: 75.76338708396703
# agent 89 在 299 次迭代中的资源申请量为: -35.56364833473661
# agent 90 在 299 次迭代中的资源申请量为: 68.8622154553881
# agent 91 在 299 次迭代中的资源申请量为: 49.77232136937402
# agent 92 在 299 次迭代中的资源申请量为: 65.80704702363154
# agent 93 在 299 次迭代中的资源申请量为: 47.206941669660765
# agent 94 在 299 次迭代中的资源申请量为: -62.80053752814012
# agent 95 在 299 次迭代中的资源申请量为: 70.28127629840228
# agent 96 在 299 次迭代中的资源申请量为: 70.17855215616702
# agent 97 在 299 次迭代中的资源申请量为: 83.65140676233867
# agent 98 在 299 次迭代中的资源申请量为: 84.5674119271861
# agent 99 在 299 次迭代中的资源申请量为: 60.68479332172721
# agent 100 在 299 次迭代中的资源申请量为: 56.24067837466211
# 资源申请量总和为: 4999.999999999999
# ****************************************************************************
# 成本总和为: 448028.4218639115
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 349 次迭代中的结果：
# agent 1 在 349 次迭代中的资源申请量为: 57.51677098298615
# agent 2 在 349 次迭代中的资源申请量为: 72.53369242145688
# agent 3 在 349 次迭代中的资源申请量为: 51.854747069225304
# agent 4 在 349 次迭代中的资源申请量为: 76.8370144883026
# agent 5 在 349 次迭代中的资源申请量为: 77.69303864694935
# agent 6 在 349 次迭代中的资源申请量为: 85.658702487168
# agent 7 在 349 次迭代中的资源申请量为: 46.70794925390991
# agent 8 在 349 次迭代中的资源申请量为: -42.160897556516254
# agent 9 在 349 次迭代中的资源申请量为: 51.24077298513704
# agent 10 在 349 次迭代中的资源申请量为: 66.3167507098483
# agent 11 在 349 次迭代中的资源申请量为: 54.064716676652964
# agent 12 在 349 次迭代中的资源申请量为: 58.48101459432216
# agent 13 在 349 次迭代中的资源申请量为: 78.15931970341708
# agent 14 在 349 次迭代中的资源申请量为: 65.6509943709642
# agent 15 在 349 次迭代中的资源申请量为: 51.509327048320664
# agent 16 在 349 次迭代中的资源申请量为: 51.684046583023836
# agent 17 在 349 次迭代中的资源申请量为: 53.47236604856329
# agent 18 在 349 次迭代中的资源申请量为: 55.00643136275883
# agent 19 在 349 次迭代中的资源申请量为: 48.92301212032244
# agent 20 在 349 次迭代中的资源申请量为: 66.22491685407648
# agent 21 在 349 次迭代中的资源申请量为: -45.35930801697328
# agent 22 在 349 次迭代中的资源申请量为: 46.31299728557389
# agent 23 在 349 次迭代中的资源申请量为: 56.88281623304194
# agent 24 在 349 次迭代中的资源申请量为: 48.07437848039558
# agent 25 在 349 次迭代中的资源申请量为: 53.678964133215835
# agent 26 在 349 次迭代中的资源申请量为: 47.01892856298432
# agent 27 在 349 次迭代中的资源申请量为: 78.01670768309317
# agent 28 在 349 次迭代中的资源申请量为: 61.058311886097364
# agent 29 在 349 次迭代中的资源申请量为: 48.510621043505566
# agent 30 在 349 次迭代中的资源申请量为: 46.428529822586704
# agent 31 在 349 次迭代中的资源申请量为: 71.75361774666433
# agent 32 在 349 次迭代中的资源申请量为: 65.90108665401662
# agent 33 在 349 次迭代中的资源申请量为: 49.16972488498054
# agent 34 在 349 次迭代中的资源申请量为: 62.03471736172762
# agent 35 在 349 次迭代中的资源申请量为: -45.32007784735406
# agent 36 在 349 次迭代中的资源申请量为: 50.88159414909264
# agent 37 在 349 次迭代中的资源申请量为: 62.32672860986727
# agent 38 在 349 次迭代中的资源申请量为: 47.86533255964095
# agent 39 在 349 次迭代中的资源申请量为: 51.3141703714397
# agent 40 在 349 次迭代中的资源申请量为: 59.253222984596526
# agent 41 在 349 次迭代中的资源申请量为: 78.65660087241247
# agent 42 在 349 次迭代中的资源申请量为: 50.64830532054314
# agent 43 在 349 次迭代中的资源申请量为: 61.43883580592615
# agent 44 在 349 次迭代中的资源申请量为: 62.67616897508528
# agent 45 在 349 次迭代中的资源申请量为: 57.25759073230035
# agent 46 在 349 次迭代中的资源申请量为: 66.47392945664026
# agent 47 在 349 次迭代中的资源申请量为: 54.49883276082723
# agent 48 在 349 次迭代中的资源申请量为: -50.499126128283315
# agent 49 在 349 次迭代中的资源申请量为: 50.86782164390626
# agent 50 在 349 次迭代中的资源申请量为: 48.47223493313967
# agent 51 在 349 次迭代中的资源申请量为: 57.4757884080525
# agent 52 在 349 次迭代中的资源申请量为: 66.1761412168097
# agent 53 在 349 次迭代中的资源申请量为: -45.17760769377151
# agent 54 在 349 次迭代中的资源申请量为: 67.44289056082269
# agent 55 在 349 次迭代中的资源申请量为: 84.55290687807943
# agent 56 在 349 次迭代中的资源申请量为: 48.46460836574512
# agent 57 在 349 次迭代中的资源申请量为: 71.85265018230326
# agent 58 在 349 次迭代中的资源申请量为: 50.31932280121375
# agent 59 在 349 次迭代中的资源申请量为: 57.03690021142942
# agent 60 在 349 次迭代中的资源申请量为: 66.54101954242532
# agent 61 在 349 次迭代中的资源申请量为: 78.2910623120599
# agent 62 在 349 次迭代中的资源申请量为: 54.716652915397106
# agent 63 在 349 次迭代中的资源申请量为: 46.22950494912991
# agent 64 在 349 次迭代中的资源申请量为: 52.9565995667435
# agent 65 在 349 次迭代中的资源申请量为: 50.703173879673905
# agent 66 在 349 次迭代中的资源申请量为: 78.15737807824229
# agent 67 在 349 次迭代中的资源申请量为: -50.675166170141544
# agent 68 在 349 次迭代中的资源申请量为: 53.44547882615778
# agent 69 在 349 次迭代中的资源申请量为: 53.889060597299164
# agent 70 在 349 次迭代中的资源申请量为: 71.34236432160559
# agent 71 在 349 次迭代中的资源申请量为: 85.68651784819218
# agent 72 在 349 次迭代中的资源申请量为: -72.51540143851916
# agent 73 在 349 次迭代中的资源申请量为: 51.83167988893657
# agent 74 在 349 次迭代中的资源申请量为: 46.24470299762347
# agent 75 在 349 次迭代中的资源申请量为: 61.84194188573592
# agent 76 在 349 次迭代中的资源申请量为: 55.58382659465886
# agent 77 在 349 次迭代中的资源申请量为: 48.51342715574223
# agent 78 在 349 次迭代中的资源申请量为: 58.657423780190605
# agent 79 在 349 次迭代中的资源申请量为: 50.89958881387036
# agent 80 在 349 次迭代中的资源申请量为: 51.073218140917255
# agent 81 在 349 次迭代中的资源申请量为: 46.685384082717505
# agent 82 在 349 次迭代中的资源申请量为: 54.22092063117617
# agent 83 在 349 次迭代中的资源申请量为: 49.18662811613815
# agent 84 在 349 次迭代中的资源申请量为: 61.826210041783376
# agent 85 在 349 次迭代中的资源申请量为: 66.14717402607839
# agent 86 在 349 次迭代中的资源申请量为: 58.06689106742421
# agent 87 在 349 次迭代中的资源申请量为: 71.90009265022815
# agent 88 在 349 次迭代中的资源申请量为: 77.6223240308007
# agent 89 在 349 次迭代中的资源申请量为: -48.3165202005605
# agent 90 在 349 次迭代中的资源申请量为: 70.5662409899856
# agent 91 在 349 次迭代中的资源申请量为: 50.97516292320756
# agent 92 在 349 次迭代中的资源申请量为: 67.37999367095232
# agent 93 在 349 次迭代中的资源申请量为: 48.34295869272577
# agent 94 在 349 次迭代中的资源申请量为: -85.75570688662312
# agent 95 在 349 次迭代中的资源申请量为: 71.98530183299978
# agent 96 在 349 次迭代中的资源申请量为: 71.88257769076452
# agent 97 在 349 次迭代中的资源申请量为: 85.69623740385568
# agent 98 在 349 次迭代中的资源申请量为: 86.61224256870311
# agent 99 在 349 次迭代中的资源申请量为: 62.14538663709651
# agent 100 在 349 次迭代中的资源申请量为: 57.60389880234012
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 489689.77062256803
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 399 次迭代中的结果：
# agent 1 在 399 次迭代中的资源申请量为: 58.87999141066417
# agent 2 在 399 次迭代中的资源申请量为: 74.23771795605438
# agent 3 在 399 次迭代中的资源申请量为: 53.05758862305885
# agent 4 在 399 次迭代中的资源申请量为: 78.69595143513625
# agent 5 在 399 次迭代中的资源申请量为: 79.551975593783
# agent 6 在 399 次迭代中的资源申请量为: 87.70353312868502
# agent 7 在 399 次迭代中的资源申请量为: 47.78417590733992
# agent 8 在 399 次迭代中的资源申请量为: -53.63848223575774
# agent 9 在 399 次迭代中的资源申请量为: 52.44361453897058
# agent 10 在 399 次迭代中的资源申请量为: 67.88969735716908
# agent 11 在 399 次迭代中的资源申请量为: 55.34273582760109
# agent 12 在 399 次迭代中的资源申请量为: 59.84423502200018
# agent 13 在 399 次迭代中的资源申请量为: 80.01825665025073
# agent 14 在 399 次迭代中的资源申请量为: 67.22394101828499
# agent 15 在 399 次迭代中的资源申请量为: 52.7121686021542
# agent 16 在 399 次迭代中的资源申请量为: 52.88688813685739
# agent 17 在 399 次迭代中的资源申请量为: 54.75038519951143
# agent 18 在 399 次迭代中的资源申请量为: 56.284450513706965
# agent 19 在 399 次迭代中的资源申请量为: 50.05902914338744
# agent 20 在 399 次迭代中的资源申请量为: 67.79786350139726
# agent 21 在 399 次迭代中的资源申请量为: -57.44097610038537
# agent 22 在 399 次迭代中的资源申请量为: 47.3892239390039
# agent 23 在 399 次迭代中的资源申请量为: 58.24603666071995
# agent 24 在 399 次迭代中的资源申请量为: 49.210395503460596
# agent 25 在 399 次迭代中的资源申请量为: 54.956983284163975
# agent 26 在 399 次迭代中的资源申请量为: 48.095155216414334
# agent 27 在 399 次迭代中的资源申请量为: 79.87564462992682
# agent 28 在 399 次迭代中的资源申请量为: 62.51890520146666
# agent 29 在 399 次迭代中的资源申请量为: 49.64663806657058
# agent 30 在 399 次迭代中的资源申请量为: 47.504756476016716
# agent 31 在 399 次迭代中的资源申请量为: 73.45764328126185
# agent 32 在 399 次迭代中的资源申请量为: 67.47403330133741
# agent 33 在 399 次迭代中的资源申请量为: 50.30574190804554
# agent 34 在 399 次迭代中的资源申请量为: 63.49531067709692
# agent 35 在 399 次迭代中的资源申请量为: -57.401745930766154
# agent 36 在 399 次迭代中的资源申请量为: 52.084435702926186
# agent 37 在 399 次迭代中的资源申请量为: 63.78732192523656
# agent 38 在 399 次迭代中的资源申请量为: 49.001349582705956
# agent 39 在 399 次迭代中的资源申请量为: 52.51701192527324
# agent 40 在 399 次迭代中的资源申请量为: 60.616443412274535
# agent 41 在 399 次迭代中的资源申请量为: 80.51553781924612
# agent 42 在 399 次迭代中的资源申请量为: 51.85114687437667
# agent 43 在 399 次迭代中的资源申请量为: 62.89942912129544
# agent 44 在 399 次迭代中的资源申请量为: 64.13676229045458
# agent 45 在 399 次迭代中的资源申请量为: 58.62081115997836
# agent 46 在 399 次迭代中的资源申请量为: 68.04687610396104
# agent 47 在 399 次迭代中的资源申请量为: 55.77685191177537
# agent 48 在 399 次迭代中的资源申请量为: -64.00216692739095
# agent 49 在 399 次迭代中的资源申请量为: 52.07066319773979
# agent 50 在 399 次迭代中的资源申请量为: 49.60825195620468
# agent 51 在 399 次迭代中的资源申请量为: 58.83900883573052
# agent 52 在 399 次迭代中的资源申请量为: 67.74908786413047
# agent 53 在 399 次迭代中的资源申请量为: -57.25927577718361
# agent 54 在 399 次迭代中的资源申请量为: 69.01583720814348
# agent 55 在 399 次迭代中的资源申请量为: 86.59773751959645
# agent 56 在 399 次迭代中的资源申请量为: 49.60062538881014
# agent 57 在 399 次迭代中的资源申请量为: 73.55667571690077
# agent 58 在 399 次迭代中的资源申请量为: 51.52216435504729
# agent 59 在 399 次迭代中的资源申请量为: 58.40012063910743
# agent 60 在 399 次迭代中的资源申请量为: 68.1139661897461
# agent 61 在 399 次迭代中的资源申请量为: 80.14999925889354
# agent 62 在 399 次迭代中的资源申请量为: 55.99467206634523
# agent 63 在 399 次迭代中的资源申请量为: 47.305731602559916
# agent 64 在 399 次迭代中的资源申请量为: 54.23461871769164
# agent 65 在 399 次迭代中的资源申请量为: 51.90601543350745
# agent 66 在 399 次迭代中的资源申请量为: 80.01631502507594
# agent 67 在 399 次迭代中的资源申请量为: -64.17820696924917
# agent 68 在 399 次迭代中的资源申请量为: 54.72349797710592
# agent 69 在 399 次迭代中的资源申请量为: 55.1670797482473
# agent 70 在 399 次迭代中的资源申请量为: 73.0463898562031
# agent 71 在 399 次迭代中的资源申请量为: 87.7313484897092
# agent 72 在 399 次迭代中的资源申请量为: -91.64470923725499
# agent 73 在 399 次迭代中的资源申请量为: 53.03452144277011
# agent 74 在 399 次迭代中的资源申请量为: 47.320929651053476
# agent 75 在 399 次迭代中的资源申请量为: 63.302535201105215
# agent 76 在 399 次迭代中的资源申请量为: 56.86184574560699
# agent 77 在 399 次迭代中的资源申请量为: 49.64944417880725
# agent 78 在 399 次迭代中的资源申请量为: 60.02064420786862
# agent 79 在 399 次迭代中的资源申请量为: 52.1024303677039
# agent 80 在 399 次迭代中的资源申请量为: 52.2760596947508
# agent 81 在 399 次迭代中的资源申请量为: 47.761610736147524
# agent 82 在 399 次迭代中的资源申请量为: 55.498939782124296
# agent 83 在 399 次迭代中的资源申请量为: 50.32264513920317
# agent 84 在 399 次迭代中的资源申请量为: 63.286803357152685
# agent 85 在 399 次迭代中的资源申请量为: 67.72012067339918
# agent 86 在 399 次迭代中的资源申请量为: 59.43011149510222
# agent 87 在 399 次迭代中的资源申请量为: 73.60411818482567
# agent 88 在 399 次迭代中的资源申请量为: 79.48126097763434
# agent 89 在 399 次迭代中的资源申请量为: -61.06939206638437
# agent 90 在 399 次迭代中的资源申请量为: 72.27026652458312
# agent 91 在 399 次迭代中的资源申请量为: 52.17800447704109
# agent 92 在 399 次迭代中的资源申请量为: 68.9529403182731
# agent 93 在 399 次迭代中的资源申请量为: 49.47897571579079
# agent 94 在 399 次迭代中的资源申请量为: -108.71087624510609
# agent 95 在 399 次迭代中的资源申请量为: 73.6893273675973
# agent 96 在 399 次迭代中的资源申请量为: 73.58660322536203
# agent 97 在 399 次迭代中的资源申请量为: 87.7410680453727
# agent 98 在 399 次迭代中的资源申请量为: 88.65707321022013
# agent 99 在 399 次迭代中的资源申请量为: 63.60597995246581
# agent 100 在 399 次迭代中的资源申请量为: 58.96711923001813
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 537829.4203587616
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 449 次迭代中的结果：
# agent 1 在 449 次迭代中的资源申请量为: 60.24321183834218
# agent 2 在 449 次迭代中的资源申请量为: 75.9417434906519
# agent 3 在 449 次迭代中的资源申请量为: 54.26043017689238
# agent 4 在 449 次迭代中的资源申请量为: 80.5548883819699
# agent 5 在 449 次迭代中的资源申请量为: 81.41091254061665
# agent 6 在 449 次迭代中的资源申请量为: 89.74836377020203
# agent 7 在 449 次迭代中的资源申请量为: 48.86040256076993
# agent 8 在 449 次迭代中的资源申请量为: -65.11606691499922
# agent 9 在 449 次迭代中的资源申请量为: 53.64645609280412
# agent 10 在 449 次迭代中的资源申请量为: 69.46264400448986
# agent 11 在 449 次迭代中的资源申请量为: 56.620754978549236
# agent 12 在 449 次迭代中的资源申请量为: 61.20745544967819
# agent 13 在 449 次迭代中的资源申请量为: 81.87719359708439
# agent 14 在 449 次迭代中的资源申请量为: 68.79688766560577
# agent 15 在 449 次迭代中的资源申请量为: 53.915010155987744
# agent 16 在 449 次迭代中的资源申请量为: 54.089729690690916
# agent 17 在 449 次迭代中的资源申请量为: 56.02840435045956
# agent 18 在 449 次迭代中的资源申请量为: 57.5624696646551
# agent 19 在 449 次迭代中的资源申请量为: 51.195046166452464
# agent 20 在 449 次迭代中的资源申请量为: 69.37081014871805
# agent 21 在 449 次迭代中的资源申请量为: -69.52264418379747
# agent 22 在 449 次迭代中的资源申请量为: 48.46545059243391
# agent 23 在 449 次迭代中的资源申请量为: 59.60925708839797
# agent 24 在 449 次迭代中的资源申请量为: 50.346412526525604
# agent 25 在 449 次迭代中的资源申请量为: 56.23500243511211
# agent 26 在 449 次迭代中的资源申请量为: 49.17138186984434
# agent 27 在 449 次迭代中的资源申请量为: 81.73458157676048
# agent 28 在 449 次迭代中的资源申请量为: 63.97949851683596
# agent 29 在 449 次迭代中的资源申请量为: 50.78265508963558
# agent 30 在 449 次迭代中的资源申请量为: 48.58098312944672
# agent 31 在 449 次迭代中的资源申请量为: 75.16166881585937
# agent 32 在 449 次迭代中的资源申请量为: 69.04697994865819
# agent 33 在 449 次迭代中的资源申请量为: 51.441758931110556
# agent 34 在 449 次迭代中的资源申请量为: 64.95590399246622
# agent 35 在 449 次迭代中的资源申请量为: -69.48341401417824
# agent 36 在 449 次迭代中的资源申请量为: 53.28727725675973
# agent 37 在 449 次迭代中的资源申请量为: 65.24791524060586
# agent 38 在 449 次迭代中的资源申请量为: 50.13736660577097
# agent 39 在 449 次迭代中的资源申请量为: 53.719853479106774
# agent 40 在 449 次迭代中的资源申请量为: 61.97966383995255
# agent 41 在 449 次迭代中的资源申请量为: 82.37447476607976
# agent 42 在 449 次迭代中的资源申请量为: 53.05398842821021
# agent 43 在 449 次迭代中的资源申请量为: 64.36002243666475
# agent 44 在 449 次迭代中的资源申请量为: 65.59735560582388
# agent 45 在 449 次迭代中的资源申请量为: 59.984031587656375
# agent 46 在 449 次迭代中的资源申请量为: 69.61982275128183
# agent 47 在 449 次迭代中的资源申请量为: 57.0548710627235
# agent 48 在 449 次迭代中的资源申请量为: -77.50520772649858
# agent 49 在 449 次迭代中的资源申请量为: 53.27350475157333
# agent 50 在 449 次迭代中的资源申请量为: 50.74426897926969
# agent 51 在 449 次迭代中的资源申请量为: 60.202229263408526
# agent 52 在 449 次迭代中的资源申请量为: 69.32203451145126
# agent 53 在 449 次迭代中的资源申请量为: -69.3409438605957
# agent 54 在 449 次迭代中的资源申请量为: 70.58878385546426
# agent 55 在 449 次迭代中的资源申请量为: 88.64256816111346
# agent 56 在 449 次迭代中的资源申请量为: 50.736642411875145
# agent 57 在 449 次迭代中的资源申请量为: 75.26070125149829
# agent 58 在 449 次迭代中的资源申请量为: 52.72500590888083
# agent 59 在 449 次迭代中的资源申请量为: 59.76334106678544
# agent 60 在 449 次迭代中的资源申请量为: 69.68691283706687
# agent 61 在 449 次迭代中的资源申请量为: 82.0089362057272
# agent 62 在 449 次迭代中的资源申请量为: 57.272691217293364
# agent 63 在 449 次迭代中的资源申请量为: 48.38195825598993
# agent 64 在 449 次迭代中的资源申请量为: 55.51263786863978
# agent 65 在 449 次迭代中的资源申请量为: 53.10885698734099
# agent 66 在 449 次迭代中的资源申请量为: 81.87525197190958
# agent 67 在 449 次迭代中的资源申请量为: -77.68124776835681
# agent 68 在 449 次迭代中的资源申请量为: 56.001517128054054
# agent 69 在 449 次迭代中的资源申请量为: 56.445098899195436
# agent 70 在 449 次迭代中的资源申请量为: 74.75041539080061
# agent 71 在 449 次迭代中的资源申请量为: 89.77617913122621
# agent 72 在 449 次迭代中的资源申请量为: -110.7740170359908
# agent 73 在 449 次迭代中的资源申请量为: 54.23736299660364
# agent 74 在 449 次迭代中的资源申请量为: 48.39715630448349
# agent 75 在 449 次迭代中的资源申请量为: 64.76312851647452
# agent 76 在 449 次迭代中的资源申请量为: 58.13986489655513
# agent 77 在 449 次迭代中的资源申请量为: 50.78546120187226
# agent 78 在 449 次迭代中的资源申请量为: 61.38386463554663
# agent 79 在 449 次迭代中的资源申请量为: 53.30527192153744
# agent 80 在 449 次迭代中的资源申请量为: 53.478901248584336
# agent 81 在 449 次迭代中的资源申请量为: 48.83783738957753
# agent 82 在 449 次迭代中的资源申请量为: 56.77695893307244
# agent 83 在 449 次迭代中的资源申请量为: 51.45866216226817
# agent 84 在 449 次迭代中的资源申请量为: 64.74739667252197
# agent 85 在 449 次迭代中的资源申请量为: 69.29306732071996
# agent 86 在 449 次迭代中的资源申请量为: 60.79333192278023
# agent 87 在 449 次迭代中的资源申请量为: 75.30814371942319
# agent 88 在 449 次迭代中的资源申请量为: 81.34019792446799
# agent 89 在 449 次迭代中的资源申请量为: -73.82226393220826
# agent 90 在 449 次迭代中的资源申请量为: 73.97429205918064
# agent 91 在 449 次迭代中的资源申请量为: 53.380846030874636
# agent 92 在 449 次迭代中的资源申请量为: 70.52588696559388
# agent 93 在 449 次迭代中的资源申请量为: 50.6149927388558
# agent 94 在 449 次迭代中的资源申请量为: -131.66604560358905
# agent 95 在 449 次迭代中的资源申请量为: 75.39335290219482
# agent 96 在 449 次迭代中的资源申请量为: 75.29062875995955
# agent 97 在 449 次迭代中的资源申请量为: 89.78589868688971
# agent 98 在 449 次迭代中的资源申请量为: 90.70190385173717
# agent 99 在 449 次迭代中的资源申请量为: 65.0665732678351
# agent 100 在 449 次迭代中的资源申请量为: 60.33033965769614
# 资源申请量总和为: 5000.000000000001
# ****************************************************************************
# 成本总和为: 592447.371072492
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 499 次迭代中的结果：
# agent 1 在 499 次迭代中的资源申请量为: 61.6064322660202
# agent 2 在 499 次迭代中的资源申请量为: 77.64576902524942
# agent 3 在 499 次迭代中的资源申请量为: 55.46327173072592
# agent 4 在 499 次迭代中的资源申请量为: 82.41382532880355
# agent 5 在 499 次迭代中的资源申请量为: 83.26984948745032
# agent 6 在 499 次迭代中的资源申请量为: 91.79319441171906
# agent 7 在 499 次迭代中的资源申请量为: 49.93662921419994
# agent 8 在 499 次迭代中的资源申请量为: -76.59365159424073
# agent 9 在 499 次迭代中的资源申请量为: 54.849297646637666
# agent 10 在 499 次迭代中的资源申请量为: 71.03559065181065
# agent 11 在 499 次迭代中的资源申请量为: 57.89877412949737
# agent 12 在 499 次迭代中的资源申请量为: 62.5706758773562
# agent 13 在 499 次迭代中的资源申请量为: 83.73613054391804
# agent 14 在 499 次迭代中的资源申请量为: 70.36983431292656
# agent 15 在 499 次迭代中的资源申请量为: 55.11785170982129
# agent 16 在 499 次迭代中的资源申请量为: 55.29257124452447
# agent 17 在 499 次迭代中的资源申请量为: 57.30642350140771
# agent 18 在 499 次迭代中的资源申请量为: 58.84048881560324
# agent 19 在 499 次迭代中的资源申请量为: 52.331063189517465
# agent 20 在 499 次迭代中的资源申请量为: 70.94375679603883
# agent 21 在 499 次迭代中的资源申请量为: -81.60431226720955
# agent 22 在 499 次迭代中的资源申请量为: 49.54167724586392
# agent 23 在 499 次迭代中的资源申请量为: 60.97247751607598
# agent 24 在 499 次迭代中的资源申请量为: 51.48242954959062
# agent 25 在 499 次迭代中的资源申请量为: 57.51302158606025
# ...
# agent 88 在 1969 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1969 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1969 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1969 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1969 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1969 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1969 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1969 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1969 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1969 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1969 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1969 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1969 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1979 次迭代中的结果：
# agent 1 在 1979 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1979 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1979 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1979 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1979 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1979 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1979 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1979 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1979 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1979 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1979 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1979 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1979 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1979 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1979 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1979 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1979 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1979 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1979 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1979 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1979 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1979 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1979 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1979 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1979 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1979 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1979 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1979 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1979 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1979 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1979 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1979 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1979 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1979 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1979 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1979 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1979 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1979 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1979 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1979 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1979 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1979 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1979 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1979 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1979 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1979 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1979 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1979 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1979 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1979 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1979 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1979 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1979 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1979 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1979 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1979 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1979 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1979 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1979 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1979 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1979 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1979 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1979 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1979 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1979 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1979 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1979 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1979 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1979 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1979 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1979 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1979 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1979 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1979 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1979 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1979 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1979 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1979 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1979 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1979 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1979 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1979 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1979 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1979 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1979 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1979 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1979 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1979 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1979 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1979 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1979 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1979 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1979 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1979 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1979 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1979 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1979 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1979 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1989 次迭代中的结果：
# agent 1 在 1989 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1989 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1989 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1989 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1989 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1989 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1989 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1989 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1989 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1989 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1989 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1989 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1989 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1989 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1989 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1989 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1989 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1989 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1989 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1989 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1989 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1989 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1989 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1989 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1989 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1989 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1989 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1989 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1989 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1989 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1989 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1989 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1989 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1989 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1989 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1989 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1989 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1989 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1989 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1989 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1989 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1989 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1989 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1989 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1989 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1989 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1989 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1989 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1989 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1989 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1989 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1989 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1989 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1989 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1989 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1989 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1989 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1989 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1989 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1989 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1989 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1989 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1989 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1989 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1989 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1989 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1989 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1989 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1989 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1989 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1989 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1989 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1989 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1989 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1989 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1989 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1989 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1989 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1989 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1989 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1989 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1989 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1989 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1989 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1989 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1989 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1989 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1989 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1989 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1989 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1989 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1989 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1989 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1989 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1989 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1989 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1989 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1989 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1999 次迭代中的结果：
# agent 1 在 1999 次迭代中的资源申请量为: 52.91701066297617
# agent 2 在 1999 次迭代中的资源申请量为: 66.62126332872022
# agent 3 在 1999 次迭代中的资源申请量为: 47.79147999674369
# agent 4 在 1999 次迭代中的资源申请量为: 70.6413781767857
# agent 5 在 1999 次迭代中的资源申请量为: 71.4413781767857
# agent 6 在 1999 次迭代中的资源申请量为: 78.82551599446427
# agent 7 在 1999 次迭代中的资源申请量为: 43.03448210234963
# agent 8 在 1999 次迭代中的资源申请量为: 41.11275799723215
# agent 9 在 1999 次迭代中的资源申请量为: 47.09147999674371
# agent 10 在 1999 次迭代中的资源申请量为: 60.99655076497254
# agent 11 在 1999 次迭代中的资源申请量为: 49.71594749654019
# agent 12 在 1999 次迭代中的资源申请量为: 53.817010662976216
# agent 13 在 1999 次迭代中的资源申请量为: 71.94137817678575
# agent 14 在 1999 次迭代中的资源申请量为: 60.39655076497257
# agent 15 在 1999 次迭代中的资源申请量为: 47.49147999674373
# agent 16 在 1999 次迭代中的资源申请量为: 47.69147999674374
# agent 17 在 1999 次迭代中的资源申请量为: 49.11594749654022
# agent 18 在 1999 次迭代中的资源申请量为: 50.71594749654022
# agent 19 在 1999 次迭代中的资源申请量为: 45.08084221914686
# agent 20 在 1999 次迭代中的资源申请量为: 60.89655076497258
# agent 21 在 1999 次迭代中的资源申请量为: 42.33448210234966
# agent 22 在 1999 次迭代中的资源申请量为: 42.634482102349665
# agent 23 在 1999 次迭代中的资源申请量为: 52.31701066297624
# agent 24 在 1999 次迭代中的资源申请量为: 44.28084221914686
# agent 25 在 1999 次迭代中的资源申请量为: 49.41594749654021
# agent 26 在 1999 次迭代中的资源申请量为: 43.33448210234967
# agent 27 在 1999 次迭代中的资源申请量为: 71.64137817678576
# agent 28 在 1999 次迭代中的资源申请量为: 56.175368567474536
# agent 29 在 1999 次迭代中的资源申请量为: 44.58084221914686
# agent 30 在 1999 次迭代中的资源申请量为: 42.734482102349666
# agent 31 在 1999 次迭代中的资源申请量为: 66.0212633287203
# agent 32 在 1999 次迭代中的资源申请量为: 60.69655076497258
# agent 33 在 1999 次迭代中的资源申请量为: 45.380842219146864
# agent 34 在 1999 次迭代中的资源申请量为: 57.07536856747454
# agent 35 在 1999 次迭代中的资源申请量为: 42.43448210234966
# agent 36 在 1999 次迭代中的资源申请量为: 46.79147999674374
# agent 37 在 1999 次迭代中的资源申请量为: 57.37536856747454
# agent 38 在 1999 次迭代中的资源申请量为: 44.08084221914686
# agent 39 在 1999 次迭代中的资源申请量为: 47.29147999674373
# agent 40 在 1999 次迭代中的资源申请量为: 54.61701066297623
# agent 41 在 1999 次迭代中的资源申请量为: 72.34137817678577
# agent 42 在 1999 次迭代中的资源申请量为: 46.491479996743735
# agent 43 在 1999 次迭代中的资源申请量为: 56.575368567474534
# agent 44 在 1999 次迭代中的资源申请量为: 57.775368567474544
# agent 45 在 1999 次迭代中的资源申请量为: 52.717010662976236
# agent 46 在 1999 次迭代中的资源申请量为: 60.996550764972575
# agent 47 在 1999 次迭代中的资源申请量为: 50.115947496540215
# agent 48 在 1999 次迭代中的资源申请量为: 47.39147999674373
# agent 49 在 1999 次迭代中的资源申请量为: 46.69147999674374
# agent 50 在 1999 次迭代中的资源申请量为: 44.68084221914686
# agent 51 在 1999 次迭代中的资源申请量为: 52.81701066297624
# agent 52 在 1999 次迭代中的资源申请量为: 60.89655076497258
# agent 53 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 54 在 1999 次迭代中的资源申请量为: 62.096550764972584
# agent 55 在 1999 次迭代中的资源申请量为: 77.72551599446435
# agent 56 在 1999 次迭代中的资源申请量为: 44.68084221914686
# agent 57 在 1999 次迭代中的资源申请量为: 66.0212633287203
# agent 58 在 1999 次迭代中的资源申请量为: 46.19147999674374
# agent 59 在 1999 次迭代中的资源申请量为: 52.41701066297623
# agent 60 在 1999 次迭代中的资源申请量为: 61.19655076497258
# agent 61 在 1999 次迭代中的资源申请量为: 72.04137817678577
# agent 62 在 1999 次迭代中的资源申请量为: 50.31594749654021
# agent 63 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 64 在 1999 次迭代中的资源申请量为: 48.615947496540215
# agent 65 在 1999 次迭代中的资源申请量为: 46.69147999674374
# agent 66 在 1999 次迭代中的资源申请量为: 71.74137817678576
# agent 67 在 1999 次迭代中的资源申请量为: 47.29147999674373
# agent 68 在 1999 次迭代中的资源申请量为: 49.11594749654022
# agent 69 在 1999 次迭代中的资源申请量为: 49.615947496540215
# agent 70 在 1999 次迭代中的资源申请量为: 65.6212633287203
# agent 71 在 1999 次迭代中的资源申请量为: 78.72551599446435
# agent 72 在 1999 次迭代中的资源申请量为: 65.82126332872029
# agent 73 在 1999 次迭代中的资源申请量为: 47.69147999674374
# agent 74 在 1999 次迭代中的资源申请量为: 42.534482102349656
# agent 75 在 1999 次迭代中的资源申请量为: 56.775368567474544
# agent 76 在 1999 次迭代中的资源申请量为: 51.215947496540224
# agent 77 在 1999 次迭代中的资源申请量为: 44.58084221914687
# agent 78 在 1999 次迭代中的资源申请量为: 54.117010662976234
# agent 79 在 1999 次迭代中的资源申请量为: 46.79147999674374
# agent 80 在 1999 次迭代中的资源申请量为: 46.99147999674374
# agent 81 在 1999 次迭代中的资源申请量为: 43.03448210234966
# agent 82 在 1999 次迭代中的资源申请量为: 49.91594749654022
# agent 83 在 1999 次迭代中的资源申请量为: 45.380842219146864
# agent 84 在 1999 次迭代中的资源申请量为: 56.87536856747453
# agent 85 在 1999 次迭代中的资源申请量为: 60.896550764972574
# agent 86 在 1999 次迭代中的资源申请量为: 53.41701066297622
# agent 87 在 1999 次迭代中的资源申请量为: 66.02126332872028
# agent 88 在 1999 次迭代中的资源申请量为: 71.24137817678574
# agent 89 在 1999 次迭代中的资源申请量为: 44.280842219146834
# agent 90 在 1999 次迭代中的资源申请量为: 64.82126332872025
# agent 91 在 1999 次迭代中的资源申请量为: 46.891479996743705
# agent 92 在 1999 次迭代中的资源申请量为: 62.09655076497253
# agent 93 在 1999 次迭代中的资源申请量为: 44.48084221914682
# agent 94 在 1999 次迭代中的资源申请量为: -420.0744840055357
# agent 95 在 1999 次迭代中的资源申请量为: 65.92126332872024
# agent 96 在 1999 次迭代中的资源申请量为: 66.12126332872022
# agent 97 在 1999 次迭代中的资源申请量为: 78.92551599446426
# agent 98 在 1999 次迭代中的资源申请量为: 79.72551599446426
# agent 99 在 1999 次迭代中的资源申请量为: 57.27536856747446
# agent 100 在 1999 次迭代中的资源申请量为: 53.01701066297616
# 资源申请量总和为: 5000.000000000025
# ****************************************************************************
# 成本总和为: 580464.9570501903
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 2025-01-21 17:21:01.305

# %%
np.savetxt('../data/02-9-bias-agent-agent_resource_quantity_unbounded_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/02-9-bias-agent-sum_cost_unbounded_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/02-9-bias-agent-sum_resource_unbounded_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
np.savetxt('../data/02-9-bias-agent-agent_gradient_unbounded_bias.txt',agent_gradient,fmt='%0.8f')#用户迭代梯度
