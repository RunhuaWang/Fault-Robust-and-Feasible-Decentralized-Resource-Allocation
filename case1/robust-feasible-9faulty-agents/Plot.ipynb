# %% [markdown]
# # 整理数据 绘图

# %% [raw]
# 噪声方式：大值确定性噪声 小值确定性噪声 无界的递增噪声 大值高斯噪声 小值高斯噪声
# 评价指标：
# 1. 所有用户的资源量和无攻击情况下最优资源量的gap（资源策略的最优性）
# 2. 所有用户成本和与无攻击情况下最优成本的gap （总成本的最优性）
# 3. 所有用户的资源约束违反程度 （总资源量的违反程度）

# %% [markdown]
# # 数据导入

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import random
from sympy import *
import math 
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

#数据导入
#无噪声 oracle
agent_resource_quantity_oracle = np.loadtxt("../data/agent_resource_quantity_oracle.txt")
sum_cost_oracle=np.loadtxt("../data/sum_cost_oracle.txt")
sum_resource_oracle=np.loadtxt("../data/sum_resource_oracle.txt")

#非鲁棒算法+大值确定性噪声
agent_resource_quantity_large_value_deterministic_bias = np.loadtxt("../data/01-agent_resource_quantity_large_value_deterministic_bias.txt")
sum_cost_large_value_deterministic_bias=np.loadtxt("../data/01-sum_cost_large_value_deterministic_bias.txt")
sum_resource_large_value_deterministic_bias=np.loadtxt("../data/01-sum_resource_large_value_deterministic_bias.txt")

#非鲁棒算法+小值确定性噪声
agent_resource_quantity_small_value_deterministic_bias = np.loadtxt("../data/01-agent_resource_quantity_small_value_deterministic_bias.txt")
sum_cost_small_value_deterministic_bias=np.loadtxt("../data/01-sum_cost_small_value_deterministic_bias.txt")
sum_resource_small_value_deterministic_bias=np.loadtxt("../data/01-sum_resource_small_value_deterministic_bias.txt")

#鲁棒算法+大值确定性噪声
robust_agent_resource_quantity_large_value_deterministic_bias = np.loadtxt("../data/01-robust-agent_resource_quantity_large_value_deterministic_bias.txt")
robust_sum_cost_large_value_deterministic_bias=np.loadtxt("../data/01-robust-sum_cost_large_value_deterministic_bias.txt")
robust_sum_resource_large_value_deterministic_bias=np.loadtxt("../data/01-robust-sum_resource_large_value_deterministic_bias.txt")

#鲁棒算法+小值确定性噪声
robust_agent_resource_quantity_small_value_deterministic_bias = np.loadtxt("../data/01-robust-agent_resource_quantity_small_value_deterministic_bias.txt")
robust_sum_cost_small_value_deterministic_bias=np.loadtxt("../data/01-robust-sum_cost_small_value_deterministic_bias.txt")
robust_sum_resource_small_value_deterministic_bias=np.loadtxt("../data/01-robust-sum_resource_small_value_deterministic_bias.txt")

#非鲁棒算法+无界的递增噪声
agent_resource_quantity_unbounded_bias = np.loadtxt("../data/02-agent_resource_quantity_unbounded_bias.txt")
sum_cost_unbounded_bias=np.loadtxt("../data/02-sum_cost_unbounded_bias.txt")
sum_resource_unbounded_bias=np.loadtxt("../data/02-sum_resource_unbounded_bias.txt")

#鲁棒算法+无界的递增噪声
robust_agent_resource_quantity_unbounded_bias = np.loadtxt("../data/02-robust-agent_resource_quantity_unbounded_bias.txt")
robust_sum_cost_unbounded_bias=np.loadtxt("../data/02-robust-sum_cost_unbounded_bias.txt")
robust_sum_resource_unbounded_bias=np.loadtxt("../data/02-robust-sum_resource_unbounded_bias.txt")

#非鲁棒算法+大值高斯分布噪声
agent_resource_quantity_large_value_Gaussian_bias = np.loadtxt("../data/03-agent_resource_quantity_large_value_Gaussian_bias(500,10).txt")
sum_cost_large_value_Gaussian_bias=np.loadtxt("../data/03-sum_cost_large_value_Gaussian_bias(500,10).txt")
sum_resource_large_value_Gaussian_bias=np.loadtxt("../data/03-sum_resource_large_value_Gaussian_bias(500,10).txt")

#鲁棒算法+大值高斯分布噪声
robust_agent_resource_quantity_large_value_Gaussian_bias = np.loadtxt("../data/03-robust_agent_resource_quantity_large_value_Gaussian_bias(500,10).txt")
robust_sum_cost_large_value_Gaussian_bias=np.loadtxt("../data/03-robust_sum_cost_large_value_Gaussian_bias(500,10).txt")
robust_sum_resource_large_value_Gaussian_bias=np.loadtxt("../data/03-robust_sum_resource_large_value_Gaussian_bias(500,10).txt")

#非鲁棒算法+小值高斯分布噪声
agent_resource_quantity_small_value_Gaussian_bias = np.loadtxt("../data/03-agent_resource_quantity_small_value_Gaussian_bias(50,10).txt")
sum_cost_small_value_Gaussian_bias=np.loadtxt("../data/03-sum_cost_small_value_Gaussian_bias(50,10).txt")
sum_resource_small_value_Gaussian_bias=np.loadtxt("../data/03-sum_resource_small_value_Gaussian_bias(50,10).txt") 

#鲁棒算法+小值高斯分布噪声
robust_agent_resource_quantity_small_value_Gaussian_bias = np.loadtxt("../data/03-robust_agent_resource_quantity_small_value_Gaussian_bias(50,10).txt")
robust_sum_cost_small_value_Gaussian_bias=np.loadtxt("../data/03-robust_sum_cost_small_value_Gaussian_bias(50,10).txt")
robust_sum_resource_small_value_Gaussian_bias=np.loadtxt("../data/03-robust_sum_resource_small_value_Gaussian_bias(50,10).txt")

# %% [markdown]
# # 相关数据计算

# %% [markdown]
# 大值确定性误差

# %% [markdown]
# 1. 所有用户的资源量和无攻击情况下最优资源量的gap（资源策略的最优性）

# %%
#非鲁棒 
agent_resource_quantity_large_value_deterministic_bias_gap=[]  
agent_resource_quantity_large_value_deterministic_bias_gap_log2=[] 
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+np.abs(agent_resource_quantity_large_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])    
    agent_resource_quantity_large_value_deterministic_bias_gap.append(sum)
    agent_resource_quantity_large_value_deterministic_bias_gap_log2.append(math.log(sum, 2))

# %%
#鲁棒
robust_agent_resource_quantity_large_value_deterministic_bias_gap=[]  
robust_agent_resource_quantity_large_value_deterministic_bias_gap_log2=[] 
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+np.abs(robust_agent_resource_quantity_large_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])    
    robust_agent_resource_quantity_large_value_deterministic_bias_gap.append(sum)
    robust_agent_resource_quantity_large_value_deterministic_bias_gap_log2.append(math.log(sum, 2))

# %% [markdown]
# 2. 所有用户成本和与无攻击情况下最优成本的gap（总成本的最优性）

# %%
#非鲁棒  
sum_cost_large_value_deterministic_bias_gap=[]
sum_cost_large_value_deterministic_bias_gap_log2=[]
for k in range(0,1000):    
    sum_cost_large_value_deterministic_bias_gap.append(np.abs(sum_cost_large_value_deterministic_bias[k]-sum_cost_oracle[999]))
    sum_cost_large_value_deterministic_bias_gap_log2.append(math.log(np.abs(sum_cost_large_value_deterministic_bias[k]-sum_cost_oracle[999]), 2))

# %%
#鲁棒 
robust_sum_cost_large_value_deterministic_bias_gap=[] 
robust_sum_cost_large_value_deterministic_bias_gap_log2=[]
for k in range(0,1000):    
    robust_sum_cost_large_value_deterministic_bias_gap.append(np.abs(robust_sum_cost_large_value_deterministic_bias[k]-sum_cost_oracle[999]))
    robust_sum_cost_large_value_deterministic_bias_gap_log2.append(math.log(np.abs(robust_sum_cost_large_value_deterministic_bias[k]-sum_cost_oracle[999]), 2))

# %% [raw]
# 3. 所有用户的资源约束违反程度（总资源量的违反程度）

# %%
#非鲁棒 
sum_resource_large_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    sum_resource_large_value_deterministic_bias_gap.append(np.abs(sum_resource_large_value_deterministic_bias[k]-5000))

# %%
#鲁棒 
robust_sum_resource_large_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    robust_sum_resource_large_value_deterministic_bias_gap.append(np.abs(robust_sum_resource_large_value_deterministic_bias[k]-5000))

# %% [markdown]
# 小值确定性误差

# %% [markdown]
# 1. 所有用户的资源量和无攻击情况下最优资源量的gap（资源策略的最优性）

# %%
#非鲁棒 
agent_resource_quantity_small_value_deterministic_bias_gap=[]  
agent_resource_quantity_small_value_deterministic_bias_gap_log2=[] 
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+np.abs(agent_resource_quantity_small_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])    
    agent_resource_quantity_small_value_deterministic_bias_gap.append(sum)
    agent_resource_quantity_small_value_deterministic_bias_gap_log2.append(math.log(sum, 2))

# %%
#鲁棒
robust_agent_resource_quantity_small_value_deterministic_bias_gap=[]  
robust_agent_resource_quantity_small_value_deterministic_bias_gap_log2=[] 
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+np.abs(robust_agent_resource_quantity_small_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])    
    robust_agent_resource_quantity_small_value_deterministic_bias_gap.append(sum)
    robust_agent_resource_quantity_small_value_deterministic_bias_gap_log2.append(math.log(sum, 2))

# %% [markdown]
# 2. 所有用户成本和与无攻击情况下最优成本的gap（总成本的最优性）

# %%
#非鲁棒  
sum_cost_small_value_deterministic_bias_gap=[]
sum_cost_small_value_deterministic_bias_gap_log2=[]
for k in range(0,1000):    
    sum_cost_small_value_deterministic_bias_gap.append(np.abs(sum_cost_small_value_deterministic_bias[k]-sum_cost_oracle[999]))
    sum_cost_small_value_deterministic_bias_gap_log2.append(math.log(np.abs(sum_cost_small_value_deterministic_bias[k]-sum_cost_oracle[999]), 2))

# %%
#鲁棒 
robust_sum_cost_small_value_deterministic_bias_gap=[] 
robust_sum_cost_small_value_deterministic_bias_gap_log2=[]
for k in range(0,1000):    
    robust_sum_cost_small_value_deterministic_bias_gap.append(np.abs(robust_sum_cost_small_value_deterministic_bias[k]-sum_cost_oracle[999]))
    robust_sum_cost_small_value_deterministic_bias_gap_log2.append(math.log(np.abs(robust_sum_cost_small_value_deterministic_bias[k]-sum_cost_oracle[999]), 2))

# %% [markdown]
# 3. 所有用户的资源约束违反程度（总资源量的违反程度）

# %%
#非鲁棒 
sum_resource_small_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    sum_resource_small_value_deterministic_bias_gap.append(np.abs(sum_resource_small_value_deterministic_bias[k]-5000))

# %%
#鲁棒 
robust_sum_resource_small_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    robust_sum_resource_small_value_deterministic_bias_gap.append(np.abs(robust_sum_resource_small_value_deterministic_bias[k]-5000))

# %% [markdown]
# 无界的递增噪声

# %% [markdown]
# 1. 所有用户的资源量和无攻击情况下最优资源量的gap（资源策略的最优性）

# %%
#非鲁棒 
agent_resource_quantity_unbounded_bias_gap=[]  
agent_resource_quantity_unbounded_bias_gap_log2=[] 
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+np.abs(agent_resource_quantity_unbounded_bias[i][k]-agent_resource_quantity_oracle[i][999])    
    agent_resource_quantity_unbounded_bias_gap.append(sum)
    agent_resource_quantity_unbounded_bias_gap_log2.append(math.log(sum, 2))

# %%
#鲁棒
robust_agent_resource_quantity_unbounded_bias_gap=[]  
robust_agent_resource_quantity_unbounded_bias_gap_log2=[] 
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+np.abs(robust_agent_resource_quantity_unbounded_bias[i][k]-agent_resource_quantity_oracle[i][999])    
    robust_agent_resource_quantity_unbounded_bias_gap.append(sum)
    robust_agent_resource_quantity_unbounded_bias_gap_log2.append(math.log(sum, 2))

# %% [markdown]
# 2. 所有用户成本和与无攻击情况下最优成本的gap（总成本的最优性）

# %%
#非鲁棒  
sum_cost_unbounded_bias_gap=[]
sum_cost_unbounded_bias_gap_log2=[]
for k in range(0,1000):    
    sum_cost_unbounded_bias_gap.append(np.abs(sum_cost_unbounded_bias[k]-sum_cost_oracle[999]))
    sum_cost_unbounded_bias_gap_log2.append(math.log(np.abs(sum_cost_unbounded_bias[k]-sum_cost_oracle[999]), 2))

# %%
#鲁棒 
robust_sum_cost_unbounded_bias_gap=[] 
robust_sum_cost_unbounded_bias_gap_log2=[]
for k in range(0,1000):    
    robust_sum_cost_unbounded_bias_gap.append(np.abs(robust_sum_cost_unbounded_bias[k]-sum_cost_oracle[999]))
    robust_sum_cost_unbounded_bias_gap_log2.append(math.log(np.abs(robust_sum_cost_unbounded_bias[k]-sum_cost_oracle[999]), 2))

# %% [markdown]
# 3. 所有用户的资源约束违反程度（总资源量的违反程度）

# %%
#非鲁棒 
sum_resource_unbounded_bias_gap=[]
for k in range(0,1000): 
    sum_resource_unbounded_bias_gap.append(np.abs(sum_resource_unbounded_bias[k]-5000))

# %%
#鲁棒 
robust_sum_resource_unbounded_bias_gap=[]
for k in range(0,1000): 
    robust_sum_resource_unbounded_bias_gap.append(np.abs(robust_sum_resource_unbounded_bias[k]-5000))

# %% [markdown]
# 大值高斯分布噪声

# %% [markdown]
# 1. 所有用户的资源量和无攻击情况下最优资源量的gap（资源策略的最优性）

# %%
#非鲁棒 
agent_resource_quantity_large_value_Gaussian_bias_gap=[]  
agent_resource_quantity_large_value_Gaussian_bias_gap_log2=[] 
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+np.abs(agent_resource_quantity_large_value_Gaussian_bias[i][k]-agent_resource_quantity_oracle[i][999])    
    agent_resource_quantity_large_value_Gaussian_bias_gap.append(sum)
    agent_resource_quantity_large_value_Gaussian_bias_gap_log2.append(math.log(sum, 2))

# %%
#鲁棒
robust_agent_resource_quantity_large_value_Gaussian_bias_gap=[]  
robust_agent_resource_quantity_large_value_Gaussian_bias_gap_log2=[] 
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+np.abs(robust_agent_resource_quantity_large_value_Gaussian_bias[i][k]-agent_resource_quantity_oracle[i][999])    
    robust_agent_resource_quantity_large_value_Gaussian_bias_gap.append(sum)
    robust_agent_resource_quantity_large_value_Gaussian_bias_gap_log2.append(math.log(sum, 2))

# %% [markdown]
# 2. 所有用户成本和与无攻击情况下最优成本的gap（总成本的最优性）

# %%
#非鲁棒  
sum_cost_large_value_Gaussian_bias_gap=[]
sum_cost_large_value_Gaussian_bias_gap_log2=[]
for k in range(0,1000):    
    sum_cost_large_value_Gaussian_bias_gap.append(np.abs(sum_cost_large_value_Gaussian_bias[k]-sum_cost_oracle[999]))
    sum_cost_large_value_Gaussian_bias_gap_log2.append(math.log(np.abs(sum_cost_large_value_Gaussian_bias[k]-sum_cost_oracle[999]), 2))

# %%
#鲁棒 
robust_sum_cost_large_value_Gaussian_bias_gap=[] 
robust_sum_cost_large_value_Gaussian_bias_gap_log2=[]
for k in range(0,1000):    
    robust_sum_cost_large_value_Gaussian_bias_gap.append(np.abs(robust_sum_cost_large_value_Gaussian_bias[k]-sum_cost_oracle[999]))
    robust_sum_cost_large_value_Gaussian_bias_gap_log2.append(math.log(np.abs(robust_sum_cost_large_value_Gaussian_bias[k]-sum_cost_oracle[999]), 2))

# %% [markdown]
# 3. 所有用户的资源约束违反程度（总资源量的违反程度）

# %%
#非鲁棒 
sum_resource_large_value_Gaussian_bias_gap=[]
for k in range(0,1000): 
    sum_resource_large_value_Gaussian_bias_gap.append(np.abs(sum_resource_large_value_Gaussian_bias[k]-5000))

# %%
#鲁棒 
robust_sum_resource_large_value_Gaussian_bias_gap=[]
for k in range(0,1000): 
    robust_sum_resource_large_value_Gaussian_bias_gap.append(np.abs(robust_sum_resource_large_value_Gaussian_bias[k]-5000))

# %% [markdown]
# 小值高斯分布噪声

# %% [markdown]
# 1. 所有用户的资源量和无攻击情况下最优资源量的gap（资源策略的最优性）

# %%
#非鲁棒 
agent_resource_quantity_small_value_Gaussian_bias_gap=[]  
agent_resource_quantity_small_value_Gaussian_bias_gap_log2=[] 
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+np.abs(agent_resource_quantity_small_value_Gaussian_bias[i][k]-agent_resource_quantity_oracle[i][999])    
    agent_resource_quantity_small_value_Gaussian_bias_gap.append(sum)
    agent_resource_quantity_small_value_Gaussian_bias_gap_log2.append(math.log(sum, 2))

# %%
#鲁棒
robust_agent_resource_quantity_small_value_Gaussian_bias_gap=[]  
robust_agent_resource_quantity_small_value_Gaussian_bias_gap_log2=[] 
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+np.abs(robust_agent_resource_quantity_small_value_Gaussian_bias[i][k]-agent_resource_quantity_oracle[i][999])    
    robust_agent_resource_quantity_small_value_Gaussian_bias_gap.append(sum)
    robust_agent_resource_quantity_small_value_Gaussian_bias_gap_log2.append(math.log(sum, 2))

# %% [markdown]
# 2. 所有用户成本和与无攻击情况下最优成本的gap（总成本的最优性）

# %%
#非鲁棒  
sum_cost_small_value_Gaussian_bias_gap=[]
sum_cost_small_value_Gaussian_bias_gap_log2=[]
for k in range(0,1000):    
    sum_cost_small_value_Gaussian_bias_gap.append(np.abs(sum_cost_small_value_Gaussian_bias[k]-sum_cost_oracle[999]))
    sum_cost_small_value_Gaussian_bias_gap_log2.append(math.log(np.abs(sum_cost_small_value_Gaussian_bias[k]-sum_cost_oracle[999]), 2))

# %%
#鲁棒 
robust_sum_cost_small_value_Gaussian_bias_gap=[] 
robust_sum_cost_small_value_Gaussian_bias_gap_log2=[]
for k in range(0,1000):    
    robust_sum_cost_small_value_Gaussian_bias_gap.append(np.abs(robust_sum_cost_small_value_Gaussian_bias[k]-sum_cost_oracle[999]))
    robust_sum_cost_small_value_Gaussian_bias_gap_log2.append(math.log(np.abs(robust_sum_cost_small_value_Gaussian_bias[k]-sum_cost_oracle[999]), 2))

# %% [markdown]
# 3. 所有用户的资源约束违反程度（总资源量的违反程度）

# %%
#非鲁棒 
sum_resource_small_value_Gaussian_bias_gap=[]
for k in range(0,1000): 
    sum_resource_small_value_Gaussian_bias_gap.append(np.abs(sum_resource_small_value_Gaussian_bias[k]-5000))

# %%
#鲁棒 
robust_sum_resource_small_value_Gaussian_bias_gap=[]
for k in range(0,1000): 
    robust_sum_resource_small_value_Gaussian_bias_gap.append(np.abs(robust_sum_resource_small_value_Gaussian_bias[k]-5000))

# %% [markdown]
# # 绘图

# %% [markdown]
# 确定性攻击

# %%
sub1=plt.subplot(2, 3, 1)##############################################################
#大值确定性噪声+资源策略最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],agent_resource_quantity_large_value_deterministic_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_agent_resource_quantity_large_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.ylabel('resource allocation optimality',font)
plt.title('large-value deterministic bias',font) 

sub2=plt.subplot(2, 3, 2)##############################################################
#大值确定性噪声+总成本最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],sum_cost_large_value_deterministic_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_cost_large_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.title('large-value deterministic bias',font) 
plt.ylabel('total cost optimality',font)


sub3=plt.subplot(2, 3, 3)##############################################################
#大值确定性噪声+约束违反
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

#A,=plt.plot(iteration[slice(0,999,20)],sum_resource_large_value_deterministic_bias_gap[slice(0,1000,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_resource_large_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.title('large-value deterministic bias',font) 
plt.ylabel('constraint violation',font)


sub4=plt.subplot(2, 3, 4)##############################################################
#小值确定性噪声+资源策略最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],agent_resource_quantity_small_value_deterministic_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_agent_resource_quantity_small_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.title('small-value deterministic bias',font)
plt.ylabel('resource allocation optimality',font)
plt.xlabel('number of iterations',font)

sub5=plt.subplot(2, 3, 5)##############################################################
#小值确定性噪声+总成本最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],sum_cost_small_value_deterministic_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_cost_small_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.title('small-value deterministic bias',font)
plt.ylabel('total cost optimality',font)
plt.xlabel('number of iterations',font)

sub6=plt.subplot(2, 3, 6)##############################################################
#小值确定性噪声+约束违反
iteration=[]
iteration.append(0)
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画4条折线
#A,=plt.plot(iteration[slice(0,999,20)],sum_resource_small_value_deterministic_bias_gap[slice(0,1000,20)],marker = '*',markersize=10,color = 'magenta',alpha=0.5,linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_resource_small_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',alpha=0.5, linewidth = '3',label='robust')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
plt.xlabel('number of iterations',font)
plt.ylabel('constraint violation',font)
plt.title('small-value deterministic bias',font)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.legend(handles=[A,B],prop={'size':39},loc="upper center", bbox_to_anchor=[-1.06, -0.2],
           ncol=18, shadow=True, fancybox=True)

'''sub1.set_xticklabels([])
sub2.set_xticklabels([])
sub3.set_xticklabels([])
sub4.set_xticklabels([])
sub5.set_xticklabels([])
sub6.set_xticklabels([])
sub7.set_xticklabels([])
sub8.set_xticklabels([])
sub9.set_xticklabels([])
sub10.set_xticklabels([])
sub11.set_xticklabels([])
sub12.set_xticklabels([])

sub2.set_yticklabels([])
sub3.set_yticklabels([])
sub4.set_yticklabels([])

sub6.set_yticklabels([])
sub7.set_yticklabels([])
sub8.set_yticklabels([])

sub10.set_yticklabels([])
sub11.set_yticklabels([])
sub12.set_yticklabels([])'''


plt.subplots_adjust(wspace=0.3,hspace=0.2) 
plt.gcf().set_size_inches((40, 20))

#plt.savefig('./figures/figure1.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/figure1.png',format='png', bbox_inches='tight')

# %% [markdown]
# 无界递增噪声

# %% [markdown]
# 高斯攻击

# %%
sub1=plt.subplot(1, 3, 1)##############################################################
#无界递增噪声+资源策略最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],agent_resource_quantity_unbounded_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_agent_resource_quantity_unbounded_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.xlabel('number of iterations',font)
plt.ylabel('resource allocation optimality',font)
plt.title('unbounded increasing bias',font) 

sub3=plt.subplot(1, 3, 2)##############################################################
#无界递增噪声+总成本最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],sum_cost_unbounded_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_cost_unbounded_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.xlabel('number of iterations',font)
plt.ylabel('total cost optimality',font)
plt.title('unbounded increasing bias',font)  

sub5=plt.subplot(1, 3, 3)##############################################################
#无界递增噪声+约束违反
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],sum_resource_unbounded_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_resource_unbounded_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.xlabel('number of iterations',font)
plt.ylabel('constraint violation',font)
plt.title('unbounded increasing bias',font) 
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.legend(handles=[A,B],prop={'size':39},loc="upper center", bbox_to_anchor=[-1.06, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.3,hspace=0.2) 
plt.gcf().set_size_inches((40, 10))

#plt.savefig('./figures/figure1.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/figure1.png',format='png', bbox_inches='tight')

# %%
sub1=plt.subplot(2, 3, 1)##############################################################
#大值高斯噪声+资源策略最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],agent_resource_quantity_large_value_Gaussian_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_agent_resource_quantity_large_value_Gaussian_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.ylabel('resource allocation optimality',font)
plt.title('large-value Gaussian bias',font) 

sub2=plt.subplot(2, 3, 2)##############################################################
#大值高斯噪声+总成本最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],sum_cost_large_value_Gaussian_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_cost_large_value_Gaussian_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.title('large-value Gaussian bias',font) 
plt.ylabel('total cost optimality',font)


sub3=plt.subplot(2, 3, 3)##############################################################
#大值高斯噪声+约束违反
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

#A,=plt.plot(iteration[slice(0,999,20)],sum_resource_large_value_deterministic_bias_gap[slice(0,1000,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_resource_large_value_Gaussian_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.title('large-value Gaussian bias',font) 
plt.ylabel('constraint violation',font)


sub4=plt.subplot(2, 3, 4)##############################################################
#小值高斯噪声+资源策略最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],agent_resource_quantity_small_value_Gaussian_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_agent_resource_quantity_small_value_Gaussian_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.title('small-value Gaussian bias',font)
plt.ylabel('resource allocation optimality',font)
plt.xlabel('number of iterations',font)

sub5=plt.subplot(2, 3, 5)##############################################################
#小值高斯噪声+总成本最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],sum_cost_small_value_Gaussian_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_cost_small_value_Gaussian_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.title('small-value Gaussian bias',font)
plt.ylabel('total cost optimality',font)
plt.xlabel('number of iterations',font)

sub6=plt.subplot(2, 3, 6)##############################################################
#小值高斯噪声+约束违反
iteration=[]
iteration.append(0)
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画4条折线
#A,=plt.plot(iteration[slice(0,999,20)],sum_resource_small_value_deterministic_bias_gap[slice(0,1000,20)],marker = '*',markersize=10,color = 'magenta',alpha=0.5,linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_resource_small_value_Gaussian_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen', linewidth = '3',label='robust')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
plt.xlabel('number of iterations',font)
plt.ylabel('constraint violation',font)
plt.title('small-value Gaussian bias',font)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.legend(handles=[A,B],prop={'size':39},loc="upper center", bbox_to_anchor=[-1.06, -0.2],
           ncol=18, shadow=True, fancybox=True)

'''sub1.set_xticklabels([])
sub2.set_xticklabels([])
sub3.set_xticklabels([])
sub4.set_xticklabels([])
sub5.set_xticklabels([])
sub6.set_xticklabels([])
sub7.set_xticklabels([])
sub8.set_xticklabels([])
sub9.set_xticklabels([])
sub10.set_xticklabels([])
sub11.set_xticklabels([])
sub12.set_xticklabels([])

sub2.set_yticklabels([])
sub3.set_yticklabels([])
sub4.set_yticklabels([])

sub6.set_yticklabels([])
sub7.set_yticklabels([])
sub8.set_yticklabels([])

sub10.set_yticklabels([])
sub11.set_yticklabels([])
sub12.set_yticklabels([])'''


plt.subplots_adjust(wspace=0.3,hspace=0.2) 
plt.gcf().set_size_inches((40, 20))

#plt.savefig('./figures/figure1.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/figure1.png',format='png', bbox_inches='tight')

# %% [markdown]
# 总绘图

# %% [markdown]
# 把确定性噪声和高斯噪声的结果放在一张图上  无界的噪声图单独放

# %%
sub1=plt.subplot(3, 4, 1)##############################################################
#大值确定性噪声+资源策略最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],agent_resource_quantity_large_value_deterministic_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_agent_resource_quantity_large_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.ylabel('resource allocation optimality',font)
plt.title('large-value deterministic bias',font) 

sub2=plt.subplot(3, 4, 2)##############################################################
#小值确定性噪声+资源策略最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],agent_resource_quantity_small_value_deterministic_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_agent_resource_quantity_small_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.title('small-value deterministic bias',font)
#plt.ylabel('resource allocation optimality',font)
#plt.xlabel('number of iterations',font)


sub3=plt.subplot(3, 4, 3)##############################################################
#大值高斯噪声+资源策略最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],agent_resource_quantity_large_value_Gaussian_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_agent_resource_quantity_large_value_Gaussian_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
#plt.ylabel('resource allocation optimality',font)
plt.title('large-value Gaussian bias',font) 


sub4=plt.subplot(3, 4, 4)##############################################################
#小值高斯噪声+资源策略最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],agent_resource_quantity_small_value_Gaussian_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_agent_resource_quantity_small_value_Gaussian_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.title('small-value Gaussian bias',font)
#plt.ylabel('resource allocation optimality',font)
#plt.xlabel('number of iterations',font)


sub5=plt.subplot(3, 4, 5)##############################################################
#大值确定性噪声+总成本最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],sum_cost_large_value_deterministic_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_cost_large_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
#plt.title('large-value deterministic bias',font) 
plt.ylabel('total cost optimality',font)

sub6=plt.subplot(3, 4, 6)##############################################################
#小值确定性噪声+总成本最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],sum_cost_small_value_deterministic_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_cost_small_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
#plt.title('small-value deterministic bias',font)
#plt.ylabel('total cost optimality',font)
#plt.xlabel('number of iterations',font)

sub7=plt.subplot(3, 4, 7)##############################################################
#大值高斯噪声+总成本最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],sum_cost_large_value_Gaussian_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_cost_large_value_Gaussian_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
#plt.title('large-value Gaussian bias',font) 
#plt.ylabel('total cost optimality',font)

sub8=plt.subplot(3, 4, 8)##############################################################
#小值高斯噪声+总成本最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],sum_cost_small_value_Gaussian_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_cost_small_value_Gaussian_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
#plt.title('small-value Gaussian bias',font)
#plt.ylabel('total cost optimality',font)
#plt.xlabel('number of iterations',font)

sub9=plt.subplot(3, 4, 9)##############################################################
#大值确定性噪声+约束违反
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

#A,=plt.plot(iteration[slice(0,999,20)],sum_resource_large_value_deterministic_bias_gap[slice(0,1000,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_resource_large_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
#plt.title('large-value deterministic bias',font) 
plt.ylabel('constraint violation',font)
plt.xlabel('number of iterations',font)

sub10=plt.subplot(3, 4, 10)##############################################################
#小值确定性噪声+约束违反
iteration=[]
iteration.append(0)
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画4条折线
#A,=plt.plot(iteration[slice(0,999,20)],sum_resource_small_value_deterministic_bias_gap[slice(0,1000,20)],marker = '*',markersize=10,color = 'magenta',alpha=0.5,linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_resource_small_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen', linewidth = '3',label='robust')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}

plt.tick_params(labelsize=30)
plt.xlabel('number of iterations',font)
#plt.ylabel('constraint violation',font)
#plt.title('small-value deterministic bias',font)

sub11=plt.subplot(3, 4, 11)##############################################################
#大值高斯噪声+约束违反
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

#A,=plt.plot(iteration[slice(0,999,20)],sum_resource_large_value_deterministic_bias_gap[slice(0,1000,20)],marker = '*',markersize=10,color = 'magenta',linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_resource_large_value_Gaussian_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='robust')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
#plt.title('large-value Gaussian bias',font) 
#plt.ylabel('constraint violation',font)
plt.xlabel('number of iterations',font)

sub12=plt.subplot(3, 4, 12)##############################################################
#小值高斯噪声+约束违反
iteration=[]
iteration.append(0)
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画4条折线
#A,=plt.plot(iteration[slice(0,999,20)],sum_resource_small_value_deterministic_bias_gap[slice(0,1000,20)],marker = '*',markersize=10,color = 'magenta',alpha=0.5,linewidth = '3',label='non-robust')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_resource_small_value_Gaussian_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'mediumseagreen', linewidth = '3',label='robust')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
plt.xlabel('number of iterations',font)
#plt.ylabel('constraint violation',font)
#plt.title('small-value Gaussian bias',font)

 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.legend(handles=[A,B],prop={'size':39},loc="upper center", bbox_to_anchor=[-1.06, -0.2],
           ncol=18, shadow=True, fancybox=True)

'''sub1.set_xticklabels([])
sub2.set_xticklabels([])
sub3.set_xticklabels([])
sub4.set_xticklabels([])
sub5.set_xticklabels([])
sub6.set_xticklabels([])
sub7.set_xticklabels([])
sub8.set_xticklabels([])
sub9.set_xticklabels([])
sub10.set_xticklabels([])
sub11.set_xticklabels([])
sub12.set_xticklabels([])

sub2.set_yticklabels([])
sub3.set_yticklabels([])
sub4.set_yticklabels([])

sub6.set_yticklabels([])
sub7.set_yticklabels([])
sub8.set_yticklabels([])

sub10.set_yticklabels([])
sub11.set_yticklabels([])
sub12.set_yticklabels([])'''


plt.subplots_adjust(wspace=0.3,hspace=0.2) 
plt.gcf().set_size_inches((40, 25))

#plt.savefig('./figures/figure1.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/figure1.png',format='png', bbox_inches='tight')
