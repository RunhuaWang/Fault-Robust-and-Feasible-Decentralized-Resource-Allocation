# %% [raw]
# 基于初始化的权重梯度下降无中心资源分配算法+部分用户的梯度计算有误差（设备损坏导致的计算误差）

# %% [raw]
# 服从小值高斯分布的噪声

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(100,1000), dtype=np.float64) 
sum_resource=np.zeros(shape=(1,1000), dtype=np.float64)
sum_cost=np.zeros(shape=(1,1000), dtype=np.float64)
iteration_update = 0.01
A=np.loadtxt("100_Network_Topology_Double_Random_Adjacency_Matrix_Degree_15.txt") #网络拓扑的邻接矩阵 对角元素要为0
D=np.zeros(shape=(100,100))# 网络的度矩阵
L=np.zeros(shape=(100,100))# 网络的拉普拉斯矩阵 L=D-A
W=np.zeros(shape=(100,100)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
iteration=[] 
a=np.loadtxt("100_uniform_distribution_(1,2)_point1.txt")
b=np.loadtxt("100_normal_distribution_(2,0.6)_point1.txt")
agent_gradient=np.zeros(shape=(100,1000), dtype=np.float64) 
bias=np.loadtxt("1000_Gaussian_distribution_(50,10).txt")

# %%
#根据邻接矩阵生成网络对应的度矩阵
for i in range(0,100):
    d=0
    for j in range(0,100):
        if A[i][j]==1:
            d=d+1
    D[i][i]=d

#根据邻接矩阵和度矩阵计算拉普拉斯矩阵
L=D-A

#选择用拉普拉斯矩阵作为聚合矩阵
W=L
    
#资源量的初始化 需要给定可行的初始化 即满足平均资源约束
for i in range (0,100):
    agent_resource_quantity[i][0]=50
    
#资源量总和 初始化
sum=0
for i in range (0,100):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

iteration.append(0)

#初始梯度计算
for i in range (0,100):
    if i==7 or i==20 or i==34 or i==47 or i==52 or i==88 or i==66 or i==71 or i==93:
        agent_gradient[i][0]=2*a[i]*agent_resource_quantity[i][0]-2*a[i]*b[i]+bias[0]
    else:
        agent_gradient[i][0]=2*a[i]*agent_resource_quantity[i][0]-2*a[i]*b[i]

#诚实用户成本总和初始化
sum=0
for i in range(0,100):
    sum=sum+a[i]*(agent_resource_quantity[i][0]-b[i])*(agent_resource_quantity[i][0]-b[i])
sum_cost[0][0]=sum

# %%
#基于初始化的权重梯度下降无中心资源分配算法
def IWDGD_Gaussian_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias):
    
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************IWDGD算法+计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,100):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):#迭代次数
        iteration.append(k)
 
        #所有用户资源申请量基于可行初始化权重梯度下降的迭代  假设部分用户因为设备损坏 导致梯度的计算有误差     
        for i in range (0,100):
            weight_gradient_sum = np.float64(0)
            for j in range (0,100):        
                weight_gradient_sum=weight_gradient_sum+W[i][j]*agent_gradient[j][k-1]
            #weight_gradient_sum = np.round(weight_gradient_sum, decimals=3)
            agent_resource_quantity[i][k]=agent_resource_quantity[i][k-1]-iteration_update*weight_gradient_sum
                #agent_resource_quantity[i][k] = np.round(agent_resource_quantity[i][k], decimals=3)
        
        #计算所有诚实用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,100):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有诚实用户的成本总和
        sum2=np.float64(0)
        for i in range(0,100):
            sum2=sum2+a[i]*(agent_resource_quantity[i][k]-b[i])*(agent_resource_quantity[i][k]-b[i])
        sum_cost[0][k]=sum2
        
        #计算当前迭代的用户梯度
        for i in range (0,100): 
            if i==7 or i==20 or i==34 or i==47 or i==52 or i==88 or i==66 or i==71 or i==93:
                agent_gradient[i][k]=2*a[i]*agent_resource_quantity[i][k]-2*a[i]*b[i]+bias[k]
            else:
                agent_gradient[i][k]=2*a[i]*agent_resource_quantity[i][k]-2*a[i]*b[i]
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%50==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,100):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=1/(pow(k+1,0.5)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
IWDGD_Gaussian_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias)
# Out:
# ****************************IWDGD算法+计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 50.0
# agent 2 的初始资源申请量为: 50.0
# agent 3 的初始资源申请量为: 50.0
# agent 4 的初始资源申请量为: 50.0
# agent 5 的初始资源申请量为: 50.0
# agent 6 的初始资源申请量为: 50.0
# agent 7 的初始资源申请量为: 50.0
# agent 8 的初始资源申请量为: 50.0
# agent 9 的初始资源申请量为: 50.0
# agent 10 的初始资源申请量为: 50.0
# agent 11 的初始资源申请量为: 50.0
# agent 12 的初始资源申请量为: 50.0
# agent 13 的初始资源申请量为: 50.0
# agent 14 的初始资源申请量为: 50.0
# agent 15 的初始资源申请量为: 50.0
# agent 16 的初始资源申请量为: 50.0
# agent 17 的初始资源申请量为: 50.0
# agent 18 的初始资源申请量为: 50.0
# agent 19 的初始资源申请量为: 50.0
# agent 20 的初始资源申请量为: 50.0
# agent 21 的初始资源申请量为: 50.0
# agent 22 的初始资源申请量为: 50.0
# agent 23 的初始资源申请量为: 50.0
# agent 24 的初始资源申请量为: 50.0
# agent 25 的初始资源申请量为: 50.0
# agent 26 的初始资源申请量为: 50.0
# agent 27 的初始资源申请量为: 50.0
# agent 28 的初始资源申请量为: 50.0
# agent 29 的初始资源申请量为: 50.0
# agent 30 的初始资源申请量为: 50.0
# agent 31 的初始资源申请量为: 50.0
# agent 32 的初始资源申请量为: 50.0
# agent 33 的初始资源申请量为: 50.0
# agent 34 的初始资源申请量为: 50.0
# agent 35 的初始资源申请量为: 50.0
# agent 36 的初始资源申请量为: 50.0
# agent 37 的初始资源申请量为: 50.0
# agent 38 的初始资源申请量为: 50.0
# agent 39 的初始资源申请量为: 50.0
# agent 40 的初始资源申请量为: 50.0
# agent 41 的初始资源申请量为: 50.0
# agent 42 的初始资源申请量为: 50.0
# agent 43 的初始资源申请量为: 50.0
# agent 44 的初始资源申请量为: 50.0
# agent 45 的初始资源申请量为: 50.0
# agent 46 的初始资源申请量为: 50.0
# agent 47 的初始资源申请量为: 50.0
# agent 48 的初始资源申请量为: 50.0
# agent 49 的初始资源申请量为: 50.0
# agent 50 的初始资源申请量为: 50.0
# agent 51 的初始资源申请量为: 50.0
# agent 52 的初始资源申请量为: 50.0
# agent 53 的初始资源申请量为: 50.0
# agent 54 的初始资源申请量为: 50.0
# agent 55 的初始资源申请量为: 50.0
# agent 56 的初始资源申请量为: 50.0
# agent 57 的初始资源申请量为: 50.0
# agent 58 的初始资源申请量为: 50.0
# agent 59 的初始资源申请量为: 50.0
# agent 60 的初始资源申请量为: 50.0
# agent 61 的初始资源申请量为: 50.0
# agent 62 的初始资源申请量为: 50.0
# agent 63 的初始资源申请量为: 50.0
# agent 64 的初始资源申请量为: 50.0
# agent 65 的初始资源申请量为: 50.0
# agent 66 的初始资源申请量为: 50.0
# agent 67 的初始资源申请量为: 50.0
# agent 68 的初始资源申请量为: 50.0
# agent 69 的初始资源申请量为: 50.0
# agent 70 的初始资源申请量为: 50.0
# agent 71 的初始资源申请量为: 50.0
# agent 72 的初始资源申请量为: 50.0
# agent 73 的初始资源申请量为: 50.0
# agent 74 的初始资源申请量为: 50.0
# agent 75 的初始资源申请量为: 50.0
# agent 76 的初始资源申请量为: 50.0
# agent 77 的初始资源申请量为: 50.0
# agent 78 的初始资源申请量为: 50.0
# agent 79 的初始资源申请量为: 50.0
# agent 80 的初始资源申请量为: 50.0
# agent 81 的初始资源申请量为: 50.0
# agent 82 的初始资源申请量为: 50.0
# agent 83 的初始资源申请量为: 50.0
# agent 84 的初始资源申请量为: 50.0
# agent 85 的初始资源申请量为: 50.0
# agent 86 的初始资源申请量为: 50.0
# agent 87 的初始资源申请量为: 50.0
# agent 88 的初始资源申请量为: 50.0
# agent 89 的初始资源申请量为: 50.0
# agent 90 的初始资源申请量为: 50.0
# agent 91 的初始资源申请量为: 50.0
# agent 92 的初始资源申请量为: 50.0
# agent 93 的初始资源申请量为: 50.0
# agent 94 的初始资源申请量为: 50.0
# agent 95 的初始资源申请量为: 50.0
# agent 96 的初始资源申请量为: 50.0
# agent 97 的初始资源申请量为: 50.0
# agent 98 的初始资源申请量为: 50.0
# agent 99 的初始资源申请量为: 50.0
# agent 100 的初始资源申请量为: 50.0
# *************************
# 初始资源申请量总和为: 5000.0
# *************************
# 初始成本总和为: 346654.5889999999
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 49 次迭代中的结果：
# agent 1 在 49 次迭代中的资源申请量为: 49.58776691259113
# agent 2 在 49 次迭代中的资源申请量为: 62.5228641422403
# agent 3 在 49 次迭代中的资源申请量为: 44.84826871383283
# agent 4 在 49 次迭代中的资源申请量为: 66.0973412871369
# agent 5 在 49 次迭代中的资源申请量为: 66.89927401685006
# agent 6 在 49 次迭代中的资源申请量为: 73.79468237089212
# agent 7 在 49 次迭代中的资源申请量为: 40.37119822171346
# agent 8 在 49 次迭代中的资源申请量为: 24.879501852761848
# agent 9 在 49 次迭代中的资源申请量为: 44.12013378221111
# agent 10 在 49 次迭代中的资源申请量为: 57.16899415401048
# agent 11 在 49 次迭代中的资源申请量为: 46.56780168833633
# agent 12 在 49 次迭代中的资源申请量为: 50.43450478362765
# agent 13 在 49 次迭代中的资源申请量为: 67.37397668408171
# agent 14 在 49 次迭代中的资源申请量为: 56.50057877754099
# agent 15 在 49 次迭代中的资源申请量为: 44.5657051926486
# agent 16 在 49 次迭代中的资源申请量为: 44.73373098960712
# agent 17 在 49 次迭代中的资源申请量为: 45.98089416369535
# agent 18 在 49 次迭代中的资源申请量为: 47.56362104022451
# agent 19 在 49 次迭代中的资源申请量为: 42.30820707255432
# agent 20 在 49 次迭代中的资源申请量为: 57.030176148982775
# agent 21 在 49 次迭代中的资源申请量为: 25.218726366421294
# agent 22 在 49 次迭代中的资源申请量为: 39.97888478958543
# agent 23 在 49 次迭代中的资源申请量为: 49.00914734488886
# agent 24 在 49 次迭代中的资源申请量为: 41.510700756453154
# agent 25 在 49 次迭代中的资源申请量为: 46.29714463765364
# agent 26 在 49 次迭代中的资源申请量为: 40.68307401076726
# agent 27 在 49 次迭代中的资源申请量为: 67.16412396406793
# agent 28 在 49 次迭代中的资源申请量为: 52.626648466042184
# agent 29 在 49 次迭代中的资源申请量为: 41.84252650111621
# agent 30 在 49 次迭代中的资源申请量为: 40.098111293800876
# agent 31 在 49 次迭代中的资源申请量为: 61.84804666226502
# agent 32 在 49 次迭代中的资源申请量为: 56.80543161365283
# agent 33 在 49 次迭代中的资源申请量为: 42.60906402499689
# agent 34 在 49 次迭代中的资源申请量为: 53.48136784239797
# agent 35 在 49 次迭代中的资源申请量为: 25.319226371276994
# agent 36 在 49 次迭代中的资源申请量为: 43.81477232232863
# agent 37 在 49 次迭代中的资源申请量为: 53.83987449333644
# agent 38 在 49 次迭代中的资源申请量为: 41.30258767574849
# agent 39 在 49 次迭代中的资源申请量为: 44.36790623549898
# agent 40 在 49 次迭代中的资源申请量为: 51.26744498250917
# agent 41 在 49 次迭代中的资源申请量为: 67.80915623649985
# agent 42 在 49 次迭代中的资源申请量为: 43.5920974074697
# agent 43 在 49 次迭代中的资源申请量为: 52.996405051401666
# agent 44 在 49 次迭代中的资源申请量为: 54.17690525809689
# agent 45 在 49 次迭代中的资源申请量为: 49.38051929188241
# agent 46 在 49 次迭代中的资源申请量为: 57.173112144646154
# agent 47 在 49 次迭代中的资源申请量为: 47.00132208692275
# agent 48 在 49 次迭代中的资源申请量为: 28.22294146361049
# agent 49 在 49 次迭代中的资源申请量为: 43.74562070031489
# agent 50 在 49 次迭代中的资源申请量为: 41.911807126201744
# agent 51 在 49 次迭代中的资源申请量为: 49.4887544890848
# agent 52 在 49 次迭代中的资源申请量为: 57.03133548310432
# agent 53 在 49 次迭代中的资源申请量为: 25.39673818555859
# agent 54 在 49 次迭代中的资源申请量为: 58.24319540822507
# agent 55 在 49 次迭代中的资源申请量为: 72.68600475353821
# agent 56 在 49 次迭代中的资源申请量为: 41.90239120199805
# agent 57 在 49 次迭代中的资源申请量为: 61.8450114426269
# agent 58 在 49 次迭代中的资源申请量为: 43.26178888662733
# agent 59 在 49 次迭代中的资源申请量为: 49.042841578964534
# agent 60 在 49 次迭代中的资源申请量为: 57.34206196734607
# agent 61 在 49 次迭代中的资源申请量为: 67.4927257812419
# agent 62 在 49 次迭代中的资源申请量为: 47.22537687676107
# agent 63 在 49 次迭代中的资源申请量为: 39.89620254005621
# agent 64 在 49 次迭代中的资源申请量为: 45.521809011985084
# agent 65 在 49 次迭代中的资源申请量为: 43.7520527504731
# agent 66 在 49 次迭代中的资源申请量为: 67.25618621195169
# agent 67 在 49 次迭代中的资源申请量为: 28.099137093110798
# agent 68 在 49 次迭代中的资源申请量为: 46.008574350472635
# agent 69 在 49 次迭代中的资源申请量为: 46.50792113106115
# agent 70 在 49 次迭代中的资源申请量为: 61.50036193241782
# agent 71 在 49 次迭代中的资源申请量为: 73.76460629573418
# agent 72 在 49 次迭代中的资源申请量为: 38.7118891264509
# agent 73 在 49 次迭代中的资源申请量为: 44.77327345223333
# agent 74 在 49 次迭代中的资源申请量为: 39.91373188506722
# agent 75 在 49 次迭代中的资源申请量为: 53.23371287810893
# agent 76 在 49 次迭代中的资源申请量为: 48.14751813942043
# agent 77 在 49 次迭代中的资源申请量为: 41.840598170879225
# agent 78 在 49 次迭代中的资源申请量为: 50.78510234416802
# agent 79 在 49 次迭代中的资源申请量为: 43.835252852652246
# agent 80 在 49 次迭代中的资源申请量为: 44.06968967692216
# agent 81 在 49 次迭代中的资源申请量为: 40.41201523154722
# agent 82 在 49 次迭代中的资源申请量为: 46.78555796899883
# agent 83 在 49 次迭代中的资源申请量为: 42.63236489911232
# agent 84 在 49 次迭代中的资源申请量为: 53.27594686457111
# agent 85 在 49 次迭代中的资源申请量为: 57.06030250564038
# agent 86 在 49 次迭代中的资源申请量为: 50.08106408860395
# agent 87 在 49 次迭代中的资源申请量为: 61.893941280083254
# agent 88 在 49 次迭代中的资源申请量为: 66.72452422331803
# agent 89 在 49 次迭代中的资源申请量为: 26.192501645137675
# agent 90 在 49 次迭代中的资源申请量为: 60.65907073424135
# agent 91 在 49 次迭代中的资源申请量为: 43.97572603751609
# agent 92 在 49 次迭代中的资源申请量为: 58.23828609391405
# agent 93 在 49 次迭代中的资源申请量为: 41.72974868537348
# agent 94 在 49 次迭代中的资源申请量为: 47.52718223955307
# agent 95 在 49 次迭代中的资源申请量为: 61.86710724574532
# agent 96 在 49 次迭代中的资源申请量为: 61.9796029906312
# agent 97 在 49 次迭代中的资源申请量为: 73.88099454477911
# agent 98 在 49 次迭代中的资源申请量为: 74.69380673838467
# agent 99 在 49 次迭代中的资源申请量为: 53.70219214704915
# agent 100 在 49 次迭代中的资源申请量为: 49.668298820163294
# 资源申请量总和为: 5000.000000000002
# ****************************************************************************
# 成本总和为: 338014.9649020798
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: 49.33305105591
# agent 2 在 99 次迭代中的资源申请量为: 62.02226769172358
# agent 3 在 99 次迭代中的资源申请量为: 44.61056169836252
# agent 4 在 99 次迭代中的资源申请量为: 65.8561122218131
# agent 5 在 99 次迭代中的资源申请量为: 66.5813569123724
# agent 6 在 99 次迭代中的资源申请量为: 73.47580042305393
# agent 7 在 99 次迭代中的资源申请量为: 40.08292682391194
# agent 8 在 99 次迭代中的资源申请量为: 27.403266644897627
# agent 9 在 99 次迭代中的资源申请量为: 43.746085535507206
# agent 10 在 99 次迭代中的资源申请量为: 56.87077313336616
# agent 11 在 99 次迭代中的资源申请量为: 46.2634633912589
# agent 12 在 99 次迭代中的资源申请量为: 50.04872479539959
# agent 13 在 99 次迭代中的资源申请量为: 67.07677382660665
# agent 14 在 99 次迭代中的资源申请量为: 56.244135052149076
# agent 15 在 99 次迭代中的资源申请量为: 44.4080867681661
# agent 16 在 99 次迭代中的资源申请量为: 44.58655281732972
# agent 17 在 99 次迭代中的资源申请量为: 45.67143619790787
# agent 18 在 99 次迭代中的资源申请量为: 47.33177289612356
# agent 19 在 99 次迭代中的资源申请量为: 42.08511025006463
# agent 20 在 99 次迭代中的资源申请量为: 56.68540910124908
# agent 21 在 99 次迭代中的资源申请量为: 27.903221074480136
# agent 22 在 99 次迭代中的资源申请量为: 39.691876067725616
# agent 23 在 99 次迭代中的资源申请量为: 48.81905354369314
# agent 24 在 99 次迭代中的资源申请量为: 41.35988799543146
# agent 25 在 99 次迭代中的资源申请量为: 46.12958556392665
# agent 26 在 99 次迭代中的资源申请量为: 40.38997683537035
# agent 27 在 99 次迭代中的资源申请量为: 66.7203511675833
# agent 28 在 99 次迭代中的资源申请量为: 52.426736583214975
# agent 29 在 99 次迭代中的资源申请量为: 41.522141706957065
# agent 30 在 99 次迭代中的资源申请量为: 39.799745245432206
# agent 31 在 99 次迭代中的资源申请量为: 61.54702054021535
# agent 32 在 99 次迭代中的资源申请量为: 56.624642787948765
# agent 33 在 99 次迭代中的资源申请量为: 42.459703346768514
# agent 34 在 99 次迭代中的资源申请量为: 53.1446370394667
# agent 35 在 99 次迭代中的资源申请量为: 28.085855606543486
# agent 36 在 99 次迭代中的资源申请量为: 43.515700528053586
# agent 37 在 99 次迭代中的资源申请量为: 53.55848397145745
# agent 38 在 99 次迭代中的资源申请量为: 41.152831024160385
# agent 39 在 99 次迭代中的资源申请量为: 44.20556990920228
# agent 40 在 99 次迭代中的资源申请量为: 50.94723618946975
# agent 41 在 99 次迭代中的资源申请量为: 67.40289282610412
# agent 42 在 99 次迭代中的资源申请量为: 43.25760323775721
# agent 43 在 99 次迭代中的资源申请量为: 52.8044752569204
# agent 44 在 99 次迭代中的资源申请量为: 53.92340336075234
# agent 45 在 99 次迭代中的资源申请量为: 49.20275876003288
# agent 46 在 99 次迭代中的资源申请量为: 56.6525133093727
# agent 47 在 99 次迭代中的资源申请量为: 46.66762288655463
# agent 48 在 99 次迭代中的资源申请量为: 31.023997949842357
# agent 49 在 99 次迭代中的资源申请量为: 43.35136058685152
# agent 50 在 99 次迭代中的资源申请量为: 41.76277738339162
# agent 51 在 99 次迭代中的资源申请量为: 49.151181012008244
# agent 52 在 99 次迭代中的资源申请量为: 56.75559197812649
# agent 53 在 99 次迭代中的资源申请量为: 28.090978869311023
# agent 54 在 99 次迭代中的资源申请量为: 57.886574433326146
# agent 55 在 99 次迭代中的资源申请量为: 72.36734050072575
# agent 56 在 99 次迭代中的资源申请量为: 41.75464681461444
# agent 57 在 99 次迭代中的资源申请量为: 61.39798402519862
# agent 58 在 99 次迭代中的资源申请量为: 42.94393261779723
# agent 59 在 99 次迭代中的资源申请量为: 48.72778916281535
# agent 60 在 99 次迭代中的资源申请量为: 56.98936191319287
# agent 61 在 99 次迭代中的资源申请量为: 67.17258852730917
# agent 62 在 99 次迭代中的资源申请量为: 46.887624076005594
# agent 63 在 99 次迭代中的资源申请量为: 39.59930794248916
# agent 64 在 99 次迭代中的资源申请量为: 45.26563696085393
# agent 65 在 99 次迭代中的资源申请量为: 43.59005978878185
# agent 66 在 99 次迭代中的资源申请量为: 66.74713734631051
# agent 67 在 99 次迭代中的资源申请量为: 30.992416194463313
# agent 68 在 99 次迭代中的资源申请量为: 45.758700710356145
# agent 69 在 99 次迭代中的资源申请量为: 46.33227184317893
# agent 70 在 99 次迭代中的资源申请量为: 61.25134087539419
# agent 71 在 99 次迭代中的资源申请量为: 73.32161784850618
# agent 72 在 99 次迭代中的资源申请量为: 42.24028298647953
# agent 73 在 99 次迭代中的资源申请量为: 44.45176094187802
# agent 74 在 99 次迭代中的资源申请量为: 39.6085705345981
# agent 75 在 99 次迭代中的资源申请量为: 52.788707300844074
# agent 76 在 99 次迭代中的资源申请量为: 47.86773033062906
# agent 77 在 99 次迭代中的资源申请量为: 41.513250786263306
# agent 78 在 99 次迭代中的资源申请量为: 50.60862732843481
# agent 79 在 99 次迭代中的资源申请量为: 43.52779521266345
# agent 80 在 99 次迭代中的资源申请量为: 43.825425988571745
# agent 81 在 99 次迭代中的资源申请量为: 40.19125493389018
# agent 82 在 99 次迭代中的资源申请量为: 46.54840105368293
# agent 83 在 99 次迭代中的资源申请量为: 42.47832758785013
# agent 84 在 99 次迭代中的资源申请量为: 52.948946110920765
# agent 85 在 99 次迭代中的资源申请量为: 56.84790357702911
# agent 86 在 99 次迭代中的资源申请量为: 49.75148209103322
# agent 87 在 99 次迭代中的资源申请量为: 61.41739962460369
# agent 88 在 99 次迭代中的资源申请量为: 66.24024372775989
# agent 89 在 99 次迭代中的资源申请量为: 29.052622391212303
# agent 90 在 99 次迭代中的资源申请量为: 60.34898445843711
# agent 91 在 99 次迭代中的资源申请量为: 43.735486042874165
# agent 92 在 99 次迭代中的资源申请量为: 57.96590182480682
# agent 93 在 99 次迭代中的资源申请量为: 41.493951734963105
# agent 94 在 99 次迭代中的资源申请量为: 51.404728444196714
# agent 95 在 99 次迭代中的资源申请量为: 61.189400511699084
# agent 96 在 99 次迭代中的资源申请量为: 61.66333039941215
# agent 97 在 99 次迭代中的资源申请量为: 73.64289475240525
# agent 98 在 99 次迭代中的资源申请量为: 74.29805425670224
# agent 99 在 99 次迭代中的资源申请量为: 53.508042808744804
# agent 100 在 99 次迭代中的资源申请量为: 49.41907929479396
# 资源申请量总和为: 4999.999999999998
# ****************************************************************************
# 成本总和为: 336687.6895532022
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 149 次迭代中的结果：
# agent 1 在 149 次迭代中的资源申请量为: 49.48613723417454
# agent 2 在 149 次迭代中的资源申请量为: 62.43679900658304
# agent 3 在 149 次迭代中的资源申请量为: 44.76878409374278
# agent 4 在 149 次迭代中的资源申请量为: 65.9127134008494
# agent 5 在 149 次迭代中的资源申请量为: 66.74880215539355
# agent 6 在 149 次迭代中的资源申请量为: 73.63908194901481
# agent 7 在 149 次迭代中的资源申请量为: 40.358542539858085
# agent 8 在 149 次迭代中的资源申请量为: 25.529404605806025
# agent 9 在 149 次迭代中的资源申请量为: 44.12796199893049
# agent 10 在 149 次迭代中的资源申请量为: 57.046150272680315
# agent 11 在 149 次迭代中的资源申请量为: 46.52571335714842
# agent 12 在 149 次迭代中的资源申请量为: 50.43494607596723
# agent 13 在 149 次迭代中的资源申请量为: 67.22985806312983
# agent 14 在 149 次迭代中的资源申请量为: 56.40775762131356
# agent 15 在 149 次迭代中的资源申请量为: 44.435714578277036
# agent 16 在 149 次迭代中的资源申请量为: 44.62257012709916
# agent 17 在 149 次迭代中的资源申请量为: 45.929338687255175
# agent 18 在 149 次迭代中的资源申请量为: 47.48855286019101
# agent 19 在 149 次迭代中的资源申请量为: 42.22758192362115
# agent 20 在 149 次迭代中的资源申请量为: 56.95469226344709
# agent 21 在 149 次迭代中的资源申请量为: 25.909609756337538
# agent 22 在 149 次迭代中的资源申请量为: 39.96119565281571
# agent 23 在 149 次迭代中的资源申请量为: 48.86189345635607
# agent 24 在 149 次迭代中的资源申请量为: 41.39459539594466
# agent 25 在 149 次迭代中的资源申请量为: 46.166889946812255
# agent 26 在 149 次迭代中的资源申请量为: 40.664060712361845
# agent 27 在 149 次迭代中的资源申请量为: 67.02718476338497
# agent 28 在 149 次迭代中的资源申请量为: 52.468688971579745
# agent 29 在 149 次迭代中的资源申请量为: 41.782764991073385
# agent 30 在 149 次迭代中的资源申请量为: 40.06869031395816
# agent 31 在 149 次迭代中的资源申请量为: 61.723495103417854
# agent 32 在 149 次迭代中的资源申请量为: 56.674026702526
# agent 33 在 149 次迭代中的资源申请量为: 42.4927879507792
# agent 34 在 149 次迭代中的资源申请量为: 53.423662965751205
# agent 35 在 149 次迭代中的资源申请量为: 25.968723341540656
# agent 36 在 149 次迭代中的资源申请量为: 43.790466741769464
# agent 37 在 149 次迭代中的资源申请量为: 53.71138201718797
# agent 38 在 149 次迭代中的资源申请量为: 41.19058430154563
# agent 39 在 149 次迭代中的资源申请量为: 44.23915673733403
# agent 40 在 149 次迭代中的资源申请量为: 51.21192517629007
# agent 41 在 149 次迭代中的资源申请量为: 67.6930115900728
# agent 42 在 149 次迭代中的资源申请量为: 43.52635557864083
# agent 43 在 149 次迭代中的资源申请量为: 52.859327537946434
# agent 44 在 149 次迭代中的资源申请量为: 54.08404807590438
# agent 45 在 149 次迭代中的资源申请量为: 49.247899912020884
# agent 46 在 149 次迭代中的资源申请量为: 57.14853052731381
# agent 47 在 149 次迭代中的资源申请量为: 46.94683470908773
# agent 48 在 149 次迭代中的资源申请量为: 29.11951671535988
# agent 49 在 149 次迭代中的资源申请量为: 43.74475127401801
# agent 50 在 149 次迭代中的资源申请量为: 41.79378262106939
# agent 51 在 149 次迭代中的资源申请量为: 49.4261279396204
# agent 52 在 149 次迭代中的资源申请量为: 56.92392729803412
# agent 53 在 149 次迭代中的资源申请量为: 26.10039080066242
# agent 54 在 149 次迭代中的资源申请量为: 58.16524729916363
# agent 55 在 149 次迭代中的资源申请量为: 72.53710399109312
# agent 56 在 149 次迭代中的资源申请量为: 41.79026950330459
# agent 57 在 149 次迭代中的资源申请量为: 61.78954405265299
# agent 58 在 149 次迭代中的资源申请量为: 43.20972330889082
# agent 59 在 149 次迭代中的资源申请量为: 49.00527828463402
# agent 60 在 149 次迭代中的资源申请量为: 57.2634690429968
# agent 61 在 149 次迭代中的资源申请量为: 67.34962768561067
# agent 62 在 149 次迭代中的资源申请量为: 47.15505279896431
# agent 63 在 149 次迭代中的资源申请量为: 39.87001046332888
# agent 64 在 149 次迭代中的资源申请量为: 45.41567078185669
# agent 65 在 149 次迭代中的资源申请量为: 43.63409790832029
# agent 66 在 149 次迭代中的资源申请量为: 67.15417773565105
# agent 67 在 149 次迭代中的资源申请量为: 28.971070129812958
# agent 68 在 149 次迭代中的资源申请量为: 45.90911503824821
# agent 69 在 149 次迭代中的资源申请量为: 46.372371486170294
# agent 70 在 149 次迭代中的资源申请量为: 61.31118288918085
# agent 71 在 149 次迭代中的资源申请量为: 73.6173202911167
# agent 72 在 149 次迭代中的资源申请量为: 40.15728725505918
# agent 73 在 149 次迭代中的资源申请量为: 44.71656422507525
# agent 74 在 149 次迭代中的资源申请量为: 39.878130317632056
# agent 75 在 149 次迭代中的资源申请量为: 53.18968442409273
# agent 76 在 149 次迭代中的资源申请量为: 48.03239821612002
# agent 77 在 149 次迭代中的资源申请量为: 41.78511490246195
# agent 78 在 149 次迭代中的资源申请量为: 50.647569874016234
# agent 79 在 149 次迭代中的资源申请量为: 43.79993160101774
# agent 80 在 149 次迭代中的资源申请量为: 43.97785609090675
# agent 81 在 149 次迭代中的资源申请量为: 40.3387649008286
# agent 82 在 149 次迭代中的资源申请量为: 46.69604629989127
# agent 83 在 149 次迭代中的资源申请量为: 42.500327612144254
# agent 84 在 149 次迭代中的资源申请量为: 53.21789385466532
# agent 85 在 149 次迭代中的资源申请量为: 56.90034182029821
# agent 86 在 149 次迭代中的资源申请量为: 50.020298696668604
# agent 87 在 149 次迭代中的资源申请量为: 61.81611363304099
# agent 88 在 149 次迭代中的资源申请量为: 66.63300921901308
# agent 89 在 149 次迭代中的资源申请量为: 26.925465393743576
# agent 90 在 149 次迭代中的资源申请量为: 60.530590786411395
# agent 91 在 149 次迭代中的资源申请量为: 43.878229659242606
# agent 92 在 149 次迭代中的资源申请量为: 58.123471551191436
# agent 93 在 149 次迭代中的资源申请量为: 41.63855414406031
# agent 94 在 149 次迭代中的资源申请量为: 49.331393282553854
# agent 95 在 149 次迭代中的资源申请量为: 61.83191040414474
# agent 96 在 149 次迭代中的资源申请量为: 61.83906287945558
# agent 97 在 149 次迭代中的资源申请量为: 73.6985543740026
# agent 98 在 149 次迭代中的资源申请量为: 74.57495482672999
# agent 99 在 149 次迭代中的资源申请量为: 53.562709580797346
# agent 100 在 149 次迭代中的资源申请量为: 49.580045090736704
# 资源申请量总和为: 5000.000000000001
# ****************************************************************************
# 成本总和为: 337564.26448502764
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: 49.385352954386434
# agent 2 在 199 次迭代中的资源申请量为: 62.11415757930005
# agent 3 在 199 次迭代中的资源申请量为: 44.67723647036949
# agent 4 在 199 次迭代中的资源申请量为: 65.91609924682082
# agent 5 在 199 次迭代中的资源申请量为: 66.64845124211406
# agent 6 在 199 次迭代中的资源申请量为: 73.55295231085613
# agent 7 在 199 次迭代中的资源申请量为: 40.182563318017195
# agent 8 在 199 次迭代中的资源申请量为: 26.799696061026363
# agent 9 在 199 次迭代中的资源申请量为: 43.83956626947524
# agent 10 在 199 次迭代中的资源申请量为: 56.94364651776058
# agent 11 在 199 次迭代中的资源申请量为: 46.32992451966312
# agent 12 在 199 次迭代中的资源申请量为: 50.15884826554518
# agent 13 在 199 次迭代中的资源申请量为: 67.1393368232379
# agent 14 在 199 次迭代中的资源申请量为: 56.33254662570662
# agent 15 在 199 次迭代中的资源申请量为: 44.4262984816671
# agent 16 在 199 次迭代中的资源申请量为: 44.63379437855312
# agent 17 在 199 次迭代中的资源申请量为: 45.7290149870218
# agent 18 在 199 次迭代中的资源申请量为: 47.40592650124215
# agent 19 在 199 次迭代中的资源申请量为: 42.1229584612399
# agent 20 在 199 次迭代中的资源申请量为: 56.76406292099733
# agent 21 在 199 次迭代中的资源申请量为: 27.303565842104796
# agent 22 在 199 次迭代中的资源申请量为: 39.775040237954386
# agent 23 在 199 次迭代中的资源申请量为: 48.85333438908147
# agent 24 在 199 次迭代中的资源申请量为: 41.3928002662987
# agent 25 在 199 次迭代中的资源申请量为: 46.166240647172195
# agent 26 在 199 次迭代中的资源申请量为: 40.48075548063479
# agent 27 在 199 次迭代中的资源申请量为: 66.80595256099939
# agent 28 在 199 次迭代中的资源申请量为: 52.46372046039981
# agent 29 在 199 次迭代中的资源申请量为: 41.56170485067051
# agent 30 在 199 次迭代中的资源申请量为: 39.87850463371377
# agent 31 在 199 次迭代中的资源申请量为: 61.633127743881325
# agent 32 在 199 次迭代中的资源申请量为: 56.69638274354608
# agent 33 在 199 次迭代中的资源申请量为: 42.4929100296511
# agent 34 在 199 次迭代中的资源申请量为: 53.23822545535958
# agent 35 在 199 次迭代中的资源申请量为: 27.462879597776574
# agent 36 在 199 次迭代中的资源申请量为: 43.61244915324086
# agent 37 在 199 次迭代中的资源申请量为: 53.59402550329368
# agent 38 在 199 次迭代中的资源申请量为: 41.198129611576235
# agent 39 在 199 次迭代中的资源申请量为: 44.231148102684145
# agent 40 在 199 次迭代中的资源申请量为: 51.017616214553414
# agent 41 在 199 次迭代中的资源申请量为: 67.49343062022429
# agent 42 在 199 次迭代中的资源申请量为: 43.30865306885437
# agent 43 在 199 次迭代中的资源申请量为: 52.87228403022179
# agent 44 在 199 次迭代中的资源申请量为: 53.99738280294507
# agent 45 在 199 次迭代中的资源申请量为: 49.25610261577727
# agent 46 在 199 次迭代中的资源申请量为: 56.73311223548281
# agent 47 在 199 次迭代中的资源申请量为: 46.748745117343546
# agent 48 在 199 次迭代中的资源申请量为: 30.4387029666496
# agent 49 在 199 次迭代中的资源申请量为: 43.45014656568024
# agent 50 在 199 次迭代中的资源申请量为: 41.790192344782376
# agent 51 在 199 次迭代中的资源申请量为: 49.227247747225924
# agent 52 在 199 次迭代中的资源申请量为: 56.84005965970882
# agent 53 在 199 次迭代中的资源申请量为: 27.5050138632848
# agent 54 在 199 次迭代中的资源申请量为: 57.97057906816325
# agent 55 在 199 次迭代中的资源申请量为: 72.45892492030876
# agent 56 在 199 次迭代中的资源申请量为: 41.79523985566922
# agent 57 在 199 次迭代中的资源申请量为: 61.49419485711467
# agent 58 在 199 次迭代中的资源申请量为: 43.00662808897801
# agent 59 在 199 次迭代中的资源申请量为: 48.826930762667985
# agent 60 在 199 次迭代中的资源申请量为: 57.065456299031965
# agent 61 在 199 次迭代中的资源申请量为: 67.25611993389418
# agent 62 在 199 次迭代中的资源申请量为: 46.93750955372624
# agent 63 在 199 次迭代中的资源申请量为: 39.67668601597872
# agent 64 在 199 次迭代中的资源申请量为: 45.29944622439672
# agent 65 在 199 次迭代中的资源申请量为: 43.64194971600655
# agent 66 在 199 次迭代中的资源申请量为: 66.83026193443101
# agent 67 在 199 次迭代中的资源申请量为: 30.398927189081267
# agent 68 在 199 次迭代中的资源申请量为: 45.79958383951266
# agent 69 在 199 次迭代中的资源申请量为: 46.37039952403312
# agent 70 在 199 次迭代中的资源申请量为: 61.29853039573284
# agent 71 在 199 次迭代中的资源申请量为: 73.40354908168254
# agent 72 在 199 次迭代中的资源申请量为: 41.447561632823614
# agent 73 在 199 次迭代中的资源申请量为: 44.5028457669998
# agent 74 在 199 次迭代中的资源申请量为: 39.67625157801603
# agent 75 在 199 次迭代中的资源申请量为: 52.879095565590845
# agent 76 在 199 次迭代中的资源申请量为: 47.91522638787449
# agent 77 在 199 次迭代中的资源申请量为: 41.57281719877872
# agent 78 在 199 次迭代中的资源申请量为: 50.65192138011623
# agent 79 在 199 次迭代中的资源申请量为: 43.60972553207389
# agent 80 在 199 次迭代中的资源申请量为: 43.87098215824723
# agent 81 在 199 次迭代中的资源申请量为: 40.232445551532194
# agent 82 在 199 次迭代中的资源申请量为: 46.59882283135657
# agent 83 在 199 次迭代中的资源申请量为: 42.48320352093664
# agent 84 在 199 次迭代中的资源申请量为: 53.02824117312484
# agent 85 在 199 次迭代中的资源申请量为: 56.90433572953484
# agent 86 在 199 次迭代中的资源申请量为: 49.821215918151225
# agent 87 在 199 次迭代中的资源申请量为: 61.50118572126614
# agent 88 在 199 次迭代中的资源申请量为: 66.31801930008722
# agent 89 在 199 次迭代中的资源申请量为: 28.431750458537465
# agent 90 在 199 次迭代中的资源申请量为: 60.4379044172125
# agent 91 在 199 次迭代中的资源申请量为: 43.76103011940718
# agent 92 在 199 次迭代中的资源申请量为: 58.02976523304636
# agent 93 在 199 次迭代中的资源申请量为: 41.52588917874357
# agent 94 在 199 次迭代中的资源申请量为: 50.459877076743105
# agent 95 在 199 次迭代中的资源申请量为: 61.28367531852116
# agent 96 在 199 次迭代中的资源申请量为: 61.73228602434272
# agent 97 在 199 次迭代中的资源申请量为: 73.72177178740652
# agent 98 在 199 次迭代中的资源申请量为: 74.38792686107968
# agent 99 在 199 次迭代中的资源申请量为: 53.57072437390315
# agent 100 在 199 次迭代中的资源申请量为: 49.49056384636142
# 资源申请量总和为: 5000.000000000001
# ****************************************************************************
# 成本总和为: 336960.20377727906
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 249 次迭代中的结果：
# agent 1 在 249 次迭代中的资源申请量为: 49.454589548973225
# agent 2 在 249 次迭代中的资源申请量为: 62.39651471408635
# agent 3 在 249 次迭代中的资源申请量为: 44.758729849503084
# agent 4 在 249 次迭代中的资源申请量为: 65.78817568217347
# agent 5 在 249 次迭代中的资源申请量为: 66.68612773229623
# agent 6 在 249 次迭代中的资源申请量为: 73.62670619234197
# agent 7 在 249 次迭代中的资源申请量为: 40.477251413390604
# agent 8 在 249 次迭代中的资源申请量为: 25.44008430231904
# agent 9 在 249 次迭代中的资源申请量为: 44.30228852756807
# agent 10 在 249 次迭代中的资源申请量为: 56.975165277332366
# agent 11 在 249 次迭代中的资源申请量为: 46.61680030761993
# agent 12 在 249 次迭代中的资源申请量为: 50.633061154459334
# agent 13 在 249 次迭代中的资源申请量为: 67.21268259731893
# agent 14 在 249 次迭代中的资源申请量为: 56.46241442466246
# agent 15 在 249 次迭代中的资源申请量为: 44.328457907395034
# agent 16 在 249 次迭代中的资源申请量为: 44.573946206673156
# agent 17 在 249 次迭代中的资源申请量为: 45.99527314201239
# agent 18 在 249 次迭代中的资源申请量为: 47.520450473453
# agent 19 在 249 次迭代中的资源申请量为: 42.20925966284666
# agent 20 在 249 次迭代中的资源申请量为: 57.01946815630374
# agent 21 在 249 次迭代中的资源申请量为: 25.84571168749259
# agent 22 在 249 次迭代中的资源申请量为: 40.06671240013666
# agent 23 在 249 次迭代中的资源申请量为: 48.725665050879186
# agent 24 在 249 次迭代中的资源申请量为: 41.30609677780725
# agent 25 在 249 次迭代中的资源申请量为: 46.07163304750136
# agent 26 在 249 次迭代中的资源申请量为: 40.761056488551105
# agent 27 在 249 次迭代中的资源申请量为: 66.9114697345297
# agent 28 在 249 次迭代中的资源申请量为: 52.330193615279015
# agent 29 在 249 次迭代中的资源申请量为: 41.7671212523528
# agent 30 在 249 次迭代中的资源申请量为: 40.13715322396956
# agent 31 在 249 次迭代中的资源申请量为: 61.6899401468854
# agent 32 在 249 次迭代中的资源申请量为: 56.65448567013355
# agent 33 在 249 次迭代中的资源申请量为: 42.40696604712309
# agent 34 在 249 次迭代中的资源申请量为: 53.50082073444978
# agent 35 在 249 次迭代中的资源申请量为: 25.837133451391097
# agent 36 在 249 次迭代中的资源申请量为: 43.908492267171276
# agent 37 在 249 次迭代中的资源申请量为: 53.61470994496086
# agent 38 在 249 次迭代中的资源申请量为: 41.11615923315384
# agent 39 在 249 次迭代中的资源申请量为: 44.12801477841823
# agent 40 在 249 次迭代中的资源申请量为: 51.283424484669226
# agent 41 在 249 次迭代中的资源申请量为: 67.67756540510892
# agent 42 在 249 次迭代中的资源申请量为: 43.50172061581233
# agent 43 在 249 次迭代中的资源申请量为: 52.77744160136331
# agent 44 在 249 次迭代中的资源申请量为: 54.10423023407347
# agent 45 在 249 次迭代中的资源申请量为: 49.16383215889003
# agent 46 在 249 次迭代中的资源申请量为: 57.26553071737819
# agent 47 在 249 次迭代中的资源申请量为: 46.97512260192562
# agent 48 在 249 次迭代中的资源申请量为: 29.29424538294929
# agent 49 在 249 次迭代中的资源申请量为: 43.872322344413874
# agent 50 在 249 次迭代中的资源申请量为: 41.70321820467725
# agent 51 在 249 次迭代中的资源申请量为: 49.45854590702746
# agent 52 在 249 次迭代中的资源申请量为: 56.92140425657087
# agent 53 在 249 次迭代中的资源申请量为: 26.077486057021645
# agent 54 在 249 次迭代中的资源申请量为: 58.20663889714435
# agent 55 在 249 次迭代中的资源申请量为: 72.54062396604766
# agent 56 在 249 次迭代中的资源申请量为: 41.716683115273575
# agent 57 在 249 次迭代中的资源申请量为: 61.89205083265368
# agent 58 在 249 次迭代中的资源申请量为: 43.2404008149682
# agent 59 在 249 次迭代中的资源申请量为: 49.12313198000348
# agent 60 在 249 次迭代中的资源申请量为: 57.307280920208036
# agent 61 在 249 次迭代中的资源申请量为: 67.29950271937702
# agent 62 在 249 次迭代中的资源申请量为: 47.13933941816573
# agent 63 在 249 次迭代中的资源申请量为: 39.94341237351139
# agent 64 在 249 次迭代中的资源申请量为: 45.34099286085736
# agent 65 在 249 次迭代中的资源申请量为: 43.55145203598158
# agent 66 在 249 次迭代中的资源申请量为: 67.1179870144696
# agent 67 在 249 次迭代中的资源申请量为: 29.124665505048135
# agent 68 在 249 次迭代中的资源申请量为: 45.85864292680626
# agent 69 在 249 次迭代中的资源申请量为: 46.25647277777906
# agent 70 在 249 次迭代中的资源申请量为: 61.1149009428479
# agent 71 在 249 次迭代中的资源申请量为: 73.54220589434463
# agent 72 在 249 次迭代中的资源申请量为: 40.6769050560579
# agent 73 在 249 次迭代中的资源申请量为: 44.72729924904661
# agent 74 在 249 次迭代中的资源申请量为: 39.91908993982249
# agent 75 在 249 次迭代中的资源申请量为: 53.236796427360815
# agent 76 在 249 次迭代中的资源申请量为: 47.909486157202075
# agent 77 在 249 次迭代中的资源申请量为: 41.77246162115336
# agent 78 在 249 次迭代中的资源申请量为: 50.554702564315264
# agent 79 在 249 次迭代中的资源申请量为: 43.88044099803524
# agent 80 在 249 次迭代中的资源申请量为: 43.928740334955855
# agent 81 在 249 次迭代中的资源申请量为: 40.31800987999645
# agent 82 在 249 次迭代中的资源申请量为: 46.68747599796192
# agent 83 在 249 次迭代中的资源申请量为: 42.371493391268494
# agent 84 在 249 次迭代中的资源申请量为: 53.305426676053614
# agent 85 在 249 次迭代中的资源申请量为: 56.77820895759875
# agent 86 在 249 次迭代中的资源申请量为: 50.06701367326527
# agent 87 在 249 次迭代中的资源申请量为: 61.82838704404706
# agent 88 在 249 次迭代中的资源申请量为: 66.65469789495707
# agent 89 在 249 次迭代中的资源申请量为: 26.88337786032649
# agent 90 在 249 次迭代中的资源申请量为: 60.476515077545606
# agent 91 在 249 次迭代中的资源申请量为: 43.81865136157242
# agent 92 在 249 次迭代中的资源申请量为: 58.10801472141239
# agent 93 在 249 次迭代中的资源申请量为: 41.58018490612955
# agent 94 在 249 次迭代中的资源申请量为: 49.946395045753505
# agent 95 在 249 次迭代中的资源申请量为: 61.84160381904231
# agent 96 在 249 次迭代中的资源申请量为: 61.747478313653374
# agent 97 在 249 次迭代中的资源申请量为: 73.64618203719195
# agent 98 在 249 次迭代中的资源申请量为: 74.62984555932174
# agent 99 在 249 次迭代中的资源申请量为: 53.4706983374648
# agent 100 在 249 次迭代中的资源申请量为: 49.58495930520224
# 资源申请量总和为: 5000.000000000001
# ****************************************************************************
# 成本总和为: 337509.71136594506
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 299 次迭代中的结果：
# agent 1 在 299 次迭代中的资源申请量为: 49.42879619970036
# agent 2 在 299 次迭代中的资源申请量为: 62.34644886721905
# agent 3 在 299 次迭代中的资源申请量为: 44.7388223154141
# agent 4 在 299 次迭代中的资源申请量为: 65.7836245564809
# agent 5 在 299 次迭代中的资源申请量为: 66.65851856442976
# agent 6 在 299 次迭代中的资源申请量为: 73.58823829415599
# agent 7 在 299 次迭代中的资源申请量为: 40.43328525015898
# agent 8 在 299 次迭代中的资源申请量为: 25.73681104575239
# agent 9 在 299 次迭代中的资源申请量为: 44.225444293825795
# agent 10 在 299 次迭代中的资源申请量为: 56.95649164416165
# agent 11 在 299 次迭代中的资源申请量为: 46.55826479813283
# agent 12 在 299 次迭代中的资源申请量为: 50.554399899116675
# agent 13 在 299 次迭代中的资源申请量为: 67.17604534626874
# agent 14 在 299 次迭代中的资源申请量为: 56.42690723463567
# agent 15 在 299 次迭代中的资源申请量为: 44.32307052514874
# agent 16 在 299 次迭代中的资源申请量为: 44.56855815681584
# agent 17 在 299 次迭代中的资源申请量为: 45.94030520253893
# agent 18 在 299 次迭代中的资源申请量为: 47.4928293878183
# agent 19 在 299 次迭代中的资源申请量为: 42.18112326014901
# agent 20 在 299 次迭代中的资源申请量为: 56.96487503531422
# agent 21 在 299 次迭代中的资源申请量为: 26.17207457080353
# agent 22 在 299 次迭代中的资源申请量为: 40.0170345301373
# agent 23 在 299 次迭代中的资源申请量为: 48.72711076806028
# agent 24 在 299 次迭代中的资源申请量为: 41.3046280067531
# agent 25 在 299 次迭代中的资源申请量为: 46.068618582484575
# agent 26 在 299 次迭代中的资源申请量为: 40.71800273047029
# agent 27 在 299 次迭代中的资源申请量为: 66.88374361344421
# agent 28 在 299 次迭代中的资源申请量为: 52.331755000066956
# agent 29 在 299 次迭代中的资源申请量为: 41.72370228231077
# agent 30 在 299 次迭代中的资源申请量为: 40.09673755764747
# agent 31 在 299 次迭代中的资源申请量为: 61.66601959449994
# agent 32 在 299 次迭代中的资源申请量为: 56.64103704703655
# agent 33 在 299 次迭代中的资源申请量为: 42.40499699777827
# agent 34 在 299 次迭代中的资源申请量为: 53.451192620138244
# agent 35 在 299 次迭代中的资源申请量为: 26.184782497810538
# agent 36 在 299 次迭代中的资源申请量为: 43.85878930155522
# agent 37 在 299 次迭代中的资源申请量为: 53.59267758819939
# agent 38 在 299 次迭代中的资源申请量为: 41.11762950325306
# agent 39 在 299 次迭代中的资源申请量为: 44.12562447317577
# agent 40 在 299 次迭代中的资源申请量为: 51.230094889378265
# agent 41 在 299 次迭代中的资源申请量为: 67.63372858524335
# agent 42 在 299 次迭代中的资源申请量为: 43.463071552087534
# agent 43 在 299 次迭代中的资源申请量为: 52.77780025520952
# agent 44 在 299 次迭代中的资源申请量为: 54.07264385254668
# agent 45 在 299 次迭代中的资源申请量为: 49.1635997541826
# agent 46 在 299 次迭代中的资源申请量为: 57.172595087015864
# agent 47 在 299 次迭代中的资源申请量为: 46.935487118418386
# agent 48 在 299 次迭代中的资源申请量为: 29.603577438588236
# agent 49 在 299 次迭代中的资源申请量为: 43.8054364264829
# agent 50 在 299 次迭代中的资源申请量为: 41.69958275405675
# agent 51 在 299 次迭代中的资源申请量为: 49.413932350478504
# agent 52 在 299 次迭代中的资源申请量为: 56.89497324930955
# agent 53 在 299 次迭代中的资源申请量为: 26.399731999297533
# agent 54 在 299 次迭代中的资源申请量为: 58.15766007594987
# agent 55 在 299 次迭代中的资源申请量为: 72.50434389064374
# agent 56 在 299 次迭代中的资源申请量为: 41.715153071278486
# agent 57 在 299 次迭代中的资源申请量为: 61.81763647220542
# agent 58 在 299 次迭代中的资源申请量为: 43.19668482125069
# agent 59 在 299 次迭代中的资源申请量为: 49.068916732885455
# agent 60 在 299 次迭代中的资源申请量为: 57.254480956763075
# agent 61 在 299 次迭代中的资源申请量为: 67.27397418787271
# agent 62 在 299 次迭代中的资源申请量为: 47.09633331532046
# agent 63 在 299 次迭代中的资源申请量为: 39.89842230679296
# agent 64 在 299 次迭代中的资源申请量为: 45.31767324026937
# agent 65 在 299 次迭代中的资源申请量为: 43.55463626663361
# agent 66 在 299 次迭代中的资源申请量为: 67.06080598139926
# agent 67 在 299 次迭代中的资源申请量为: 29.44851939497738
# agent 68 在 299 次迭代中的资源申请量为: 45.83393979379666
# agent 69 在 299 次迭代中的资源申请量为: 46.25958629875246
# agent 70 在 299 次迭代中的资源申请量为: 61.12341503316501
# agent 71 在 299 次迭代中的资源申请量为: 73.50216168067774
# agent 72 在 299 次迭代中的资源申请量为: 40.99462972040596
# agent 73 在 299 次迭代中的资源申请量为: 44.68080752936529
# agent 74 在 299 次迭代中的资源申请量为: 39.87715718290691
# agent 75 在 299 次迭代中的资源申请量为: 53.175727960886746
# agent 76 在 299 次迭代中的资源申请量为: 47.9018487874522
# agent 77 在 299 次迭代中的资源申请量为: 41.73713149394342
# agent 78 在 299 次迭代中的资源申请量为: 50.55281408038907
# agent 79 在 299 次迭代中的资源申请量为: 43.83221989822965
# agent 80 在 299 次迭代中的资源申请量为: 43.908180444356226
# agent 81 在 299 次迭代中的资源申请量为: 40.2911641152808
# agent 82 在 299 次迭代中的资源申请量为: 46.65866319200666
# agent 83 在 299 次迭代中的资源申请量为: 42.36793956024666
# agent 84 在 299 次迭代中的资源申请量为: 53.24788594773357
# agent 85 在 299 次迭代中的资源申请量为: 56.78095404147562
# agent 86 在 299 次迭代中的资源申请量为: 50.0173459691991
# agent 87 在 299 次迭代中的资源申请量为: 61.766986160705684
# agent 88 在 299 次迭代中的资源申请量为: 66.58557027758746
# agent 89 在 299 次迭代中的资源申请量为: 27.230362695407678
# agent 90 在 299 次迭代中的资源申请量为: 60.458186402354066
# agent 91 在 299 次迭代中的资源申请量为: 43.791295188990226
# agent 92 在 299 次迭代中的资源申请量为: 58.077762750972404
# agent 93 在 299 次迭代中的资源申请量为: 41.55835159941071
# agent 94 在 299 次迭代中的资源申请量为: 50.278136193621904
# agent 95 在 299 次迭代中的资源申请量为: 61.75369433173265
# agent 96 在 299 次迭代中的资源申请量为: 61.728334832826306
# agent 97 在 299 次迭代中的资源申请量为: 73.63038521637147
# agent 98 在 299 次迭代中的资源申请量为: 74.56851140695399
# agent 99 在 299 次迭代中的资源申请量为: 53.47032287543285
# agent 100 在 299 次迭代中的资源申请量为: 49.558014167961026
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 337359.95700332645
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 349 次迭代中的结果：
# agent 1 在 349 次迭代中的资源申请量为: 49.43064989461748
# agent 2 在 349 次迭代中的资源申请量为: 62.44900578705064
# agent 3 在 349 次迭代中的资源申请量为: 44.724423599589926
# agent 4 在 349 次迭代中的资源申请量为: 65.70500668681677
# agent 5 在 349 次迭代中的资源申请量为: 66.64006292221634
# agent 6 在 349 次迭代中的资源申请量为: 73.55315119263052
# agent 7 在 349 次迭代中的资源申请量为: 40.44497845689023
# agent 8 在 349 次迭代中的资源申请量为: 25.599662188533273
# agent 9 在 349 次迭代中的资源申请量为: 44.31106066906114
# agent 10 在 349 次迭代中的资源申请量为: 56.935425872828276
# agent 11 在 349 次迭代中的资源申请量为: 46.60675621156481
# agent 12 在 349 次迭代中的资源申请量为: 50.61816788083548
# agent 13 在 349 次迭代中的资源申请量为: 67.16081367702706
# agent 14 在 349 次迭代中的资源申请量为: 56.37611109436624
# agent 15 在 349 次迭代中的资源申请量为: 44.298335524301464
# agent 16 在 349 次迭代中的资源申请量为: 44.50527013441737
# agent 17 在 349 次迭代中的资源申请量为: 46.00204121774846
# agent 18 在 349 次迭代中的资源申请量为: 47.46483559578521
# agent 19 在 349 次迭代中的资源申请量为: 42.20092891218869
# agent 20 在 349 次迭代中的资源申请量为: 57.00057635711975
# agent 21 在 349 次迭代中的资源申请量为: 25.960813002354158
# agent 22 在 349 次迭代中的资源申请量为: 40.0488758223604
# agent 23 在 349 次迭代中的资源申请量为: 48.68477585372569
# agent 24 在 349 次迭代中的资源申请量为: 41.261273125360944
# agent 25 在 349 次迭代中的资源申请量为: 46.02101257324803
# agent 26 在 349 次迭代中的资源申请量为: 40.74127263873612
# agent 27 在 349 次迭代中的资源申请量为: 66.92364461986513
# agent 28 在 349 次迭代中的资源申请量为: 52.28671879537544
# agent 29 在 349 次迭代中的资源申请量为: 41.81578186366376
# agent 30 在 349 次迭代中的资源申请量为: 40.13692143510775
# agent 31 在 349 次迭代中的资源申请量为: 61.625296731713185
# agent 32 在 349 次迭代中的资源申请量为: 56.54141153390416
# agent 33 在 349 次迭代中的资源申请量为: 42.362374613763485
# agent 34 在 349 次迭代中的资源申请量为: 53.469165818613305
# agent 35 在 349 次迭代中的资源申请量为: 25.93263481379119
# agent 36 在 349 次迭代中的资源申请量为: 43.87266266965501
# agent 37 在 349 次迭代中的资源申请量为: 53.61845172831417
# agent 38 在 349 次迭代中的资源申请量为: 41.06021140544824
# agent 39 在 349 次迭代中的资源申请量为: 44.092688311763055
# agent 40 在 349 次迭代中的资源申请量为: 51.27570137846695
# agent 41 在 349 次迭代中的资源申请量为: 67.66056773057942
# agent 42 在 349 次迭代中的资源申请量为: 43.542020697802954
# agent 43 在 349 次迭代中的资源申请量为: 52.69166308813724
# agent 44 在 349 次迭代中的资源申请量为: 54.04276259487571
# agent 45 在 349 次迭代中的资源申请量为: 49.09475490744242
# agent 46 在 349 次迭代中的资源申请量为: 57.34941210870473
# agent 47 在 349 次迭代中的资源申请量为: 46.97427955216515
# agent 48 在 349 次迭代中的资源申请量为: 29.444656282279244
# agent 49 在 349 次迭代中的资源申请量为: 43.8898473693789
# agent 50 在 349 次迭代中的资源申请量为: 41.66364049698502
# agent 51 在 349 次迭代中的资源申请量为: 49.457279606665196
# agent 52 在 349 次迭代中的资源申请量为: 56.85616122933751
# agent 53 在 349 次迭代中的资源申请量为: 26.16927406985947
# agent 54 在 349 次迭代中的资源申请量为: 58.18821247637734
# agent 55 在 349 次迭代中的资源申请量为: 72.45143462621148
# agent 56 在 349 次迭代中的资源申请量为: 41.66312616735085
# agent 57 在 349 次迭代中的资源申请量为: 61.902776811023045
# agent 58 在 349 次迭代中的资源申请量为: 43.25735564217533
# agent 59 在 349 次迭代中的资源申请量为: 49.0778802162228
# agent 60 在 349 次迭代中的资源申请量为: 57.29347230903966
# agent 61 在 349 次迭代中的资源申请量为: 67.23580228915839
# agent 62 在 349 次迭代中的资源申请量为: 47.1742095050949
# agent 63 在 349 次迭代中的资源申请量为: 39.93947906285796
# agent 64 在 349 次迭代中的资源申请量为: 45.345264602107406
# agent 65 在 349 次迭代中的资源申请量为: 43.48942244365723
# agent 66 在 349 次迭代中的资源申请量为: 67.17110501165037
# agent 67 在 349 次迭代中的资源申请量为: 29.22603746515449
# agent 68 在 349 次迭代中的资源申请量为: 45.85081169352787
# agent 69 在 349 次迭代中的资源申请量为: 46.212209406993104
# agent 70 在 349 次迭代中的资源申请量为: 61.068440654093735
# agent 71 在 349 次迭代中的资源申请量为: 73.54043597571703
# agent 72 在 349 次迭代中的资源申请量为: 41.104334745372235
# agent 73 在 349 次迭代中的资源申请量为: 44.755684266014725
# agent 74 在 349 次迭代中的资源申请量为: 39.93209772991216
# agent 75 在 349 次迭代中的资源申请量为: 53.27371550352438
# agent 76 在 349 次迭代中的资源申请量为: 47.91896377733488
# agent 77 在 349 次迭代中的资源申请量为: 41.8058713791213
# agent 78 在 349 次迭代中的资源申请量为: 50.49701280578948
# agent 79 在 349 次迭代中的资源申请量为: 43.8660966934044
# agent 80 在 349 次迭代中的资源申请量为: 43.9206554336721
# agent 81 在 349 次迭代中的资源申请量为: 40.307789277969206
# agent 82 在 349 次迭代中的资源申请量为: 46.66221354029481
# agent 83 在 349 次迭代中的资源申请量为: 42.36117165489348
# agent 84 在 349 次迭代中的资源申请量为: 53.281103951521054
# agent 85 在 349 次迭代中的资源申请量为: 56.71006900708158
# agent 86 在 349 次迭代中的资源申请量为: 50.066363088649815
# agent 87 在 349 次迭代中的资源申请量为: 61.87425986066522
# agent 88 在 349 次迭代中的资源申请量为: 66.6968735370125
# agent 89 在 349 次迭代中的资源申请量为: 26.975361017186895
# agent 90 在 349 次迭代中的资源申请量为: 60.41565316088694
# agent 91 在 349 次迭代中的资源申请量为: 43.827571305895376
# agent 92 在 349 次迭代中的资源申请量为: 58.06241129313182
# agent 93 在 349 次迭代中的资源申请量为: 41.58853801234544
# agent 94 在 349 次迭代中的资源申请量为: 50.67140244449367
# agent 95 在 349 次迭代中的资源申请量为: 61.99665202932343
# agent 96 在 349 次迭代中的资源申请量为: 61.71194383160944
# agent 97 在 349 次迭代中的资源申请量为: 73.52160433985013
# agent 98 在 349 次迭代中的资源申请量为: 74.5872582823788
# agent 99 在 349 次迭代中的资源申请量为: 53.390414287870975
# agent 100 在 349 次迭代中的资源申请量为: 49.53416503934843
# 资源申请量总和为: 5000.000000000001
# ****************************************************************************
# 成本总和为: 337412.23070775816
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 399 次迭代中的结果：
# agent 1 在 399 次迭代中的资源申请量为: 49.38568066503832
# agent 2 在 399 次迭代中的资源申请量为: 62.14547156597083
# agent 3 在 399 次迭代中的资源申请量为: 44.693493089773604
# agent 4 在 399 次迭代中的资源申请量为: 65.82675036096127
# agent 5 在 399 次迭代中的资源申请量为: 66.6275008042527
# agent 6 在 399 次迭代中的资源申请量为: 73.57064945977287
# agent 7 在 399 次迭代中的资源申请量为: 40.32038459217749
# agent 8 在 399 次迭代中的资源申请量为: 26.427115746721903
# agent 9 在 399 次迭代中的资源申请量为: 44.04262216079302
# agent 10 在 399 次迭代中的资源申请量为: 56.915009821639
# agent 11 在 399 次迭代中的资源申请量为: 46.449007213120574
# agent 12 在 399 次迭代中的资源申请量为: 50.379823565420864
# agent 13 在 399 次迭代中的资源申请量为: 67.15080836831133
# agent 14 在 399 次迭代中的资源申请量为: 56.40551129922619
# agent 15 在 399 次迭代中的资源申请量为: 44.34663425758859
# agent 16 在 399 次迭代中的资源申请量为: 44.60138682363839
# agent 17 在 399 次迭代中的资源申请量为: 45.82614828971506
# agent 18 在 399 次迭代中的资源申请量为: 47.45700735464137
# agent 19 在 399 次迭代中的资源申请量为: 42.13259165150928
# agent 20 在 399 次迭代中的资源申请量为: 56.859651443939406
# agent 21 在 399 次迭代中的资源申请量为: 26.92962493475045
# agent 22 在 399 次迭代中的资源申请量为: 39.90230152398967
# agent 23 在 399 次迭代中的资源申请量为: 48.751531523711165
# agent 24 在 399 次迭代中的资源申请量为: 41.32941157048157
# agent 25 在 399 次迭代中的资源申请量为: 46.096504557144826
# agent 26 在 399 次迭代中的资源申请量为: 40.601988504818415
# agent 27 在 399 次迭代中的资源申请量为: 66.7604844929459
# agent 28 在 399 次迭代中的资源申请量为: 52.35814882145971
# agent 29 在 399 次迭代中的资源申请量为: 41.59150322060098
# agent 30 在 399 次迭代中的资源申请量为: 39.97549193115837
# agent 31 在 399 次迭代中的资源申请量为: 61.634585652264924
# agent 32 在 399 次迭代中的资源申请量为: 56.69220630508827
# agent 33 在 399 次迭代中的资源申请量为: 42.42942196012218
# agent 34 在 399 次迭代中的资源申请量为: 53.34488152209746
# agent 35 在 399 次迭代中的资源申请量为: 27.014851696628394
# agent 36 在 399 次迭代中的资源申请量为: 43.750138937113626
# agent 37 在 399 次迭代中的资源申请量为: 53.54253365975602
# agent 38 在 399 次迭代中的资源申请量为: 41.14359629825211
# agent 39 在 399 次迭代中的资源申请量为: 44.14873399186603
# agent 40 在 399 次迭代中的资源申请量为: 51.11972734105382
# agent 41 在 399 次迭代中的资源申请量为: 67.5252602785111
# agent 42 在 399 次迭代中的资源申请量为: 43.331668907163355
# agent 43 在 399 次迭代中的资源申请量为: 52.813922595908124
# agent 44 在 399 次迭代中的资源申请量为: 54.04204198821505
# agent 45 在 399 次迭代中的资源申请量为: 49.19605547452004
# agent 46 在 399 次迭代中的资源申请量为: 56.90780011309113
# agent 47 在 399 次迭代中的资源申请量为: 46.815050955139824
# agent 48 在 399 次迭代中的资源申请量为: 30.26719053933905
# agent 49 在 399 次迭代中的资源申请量为: 43.61488263095955
# agent 50 在 399 次迭代中的资源申请量为: 41.72356575119291
# agent 51 在 399 次迭代中的资源申请量为: 49.29702959792766
# agent 52 在 399 次迭代中的资源申请量为: 56.86324085893488
# agent 53 在 399 次迭代中的资源申请量为: 27.163958220170915
# agent 54 在 399 次迭代中的资源申请量为: 58.04958963525099
# agent 55 在 399 次迭代中的资源申请量为: 72.48928656000318
# agent 56 在 399 次迭代中的资源申请量为: 41.741377450301854
# agent 57 在 399 次迭代中的资源申请量为: 61.638934836316466
# agent 58 在 399 次迭代中的资源申请量为: 43.07380046358445
# agent 59 在 399 次迭代中的资源申请量为: 48.966126981325935
# agent 60 在 399 次迭代中的资源申请量为: 57.14708423522229
# agent 61 在 399 次迭代中的资源申请量为: 67.24521700286054
# agent 62 在 399 次迭代中的资源申请量为: 46.96936554188256
# agent 63 在 399 次迭代中的资源申请量为: 39.77859712005271
# agent 64 在 399 次迭代中的资源申请量为: 45.265274409281126
# agent 65 在 399 次迭代中的资源申请量为: 43.58174651100726
# agent 66 在 399 次迭代中的资源申请量为: 66.86563740429911
# agent 67 在 399 次迭代中的资源申请量为: 30.193364490448023
# agent 68 在 399 次迭代中的资源申请量为: 45.78553525121164
# agent 69 在 399 次迭代中的资源申请量为: 46.283810883848645
# agent 70 在 399 次迭代中的资源申请量为: 61.14948790014497
# agent 71 在 399 次迭代中的资源申请量为: 73.39130865745578
# agent 72 在 399 次迭代中的资源申请量为: 41.5240012935597
# agent 73 在 399 次迭代中的资源申请量为: 44.555796023759754
# agent 74 在 399 次迭代中的资源申请量为: 39.75223176545741
# agent 75 在 399 次迭代中的资源申请量为: 52.98119524151514
# agent 76 在 399 次迭代中的资源申请量为: 47.84094006146673
# agent 77 在 399 次迭代中的资源申请量为: 41.60532181788286
# agent 78 在 399 次迭代中的资源申请量为: 50.583358352818486
# agent 79 在 399 次迭代中的资源申请量为: 43.71784219821222
# agent 80 在 399 次迭代中的资源申请量为: 43.85719621897452
# agent 81 在 399 次迭代中的资源申请量为: 40.24065788791134
# agent 82 在 399 次迭代中的资源申请量为: 46.61600123428772
# agent 83 在 399 次迭代中的资源申请量为: 42.38563778167693
# agent 84 在 399 次迭代中的资源申请量为: 53.14345369939264
# agent 85 在 399 次迭代中的资源申请量为: 56.81411921250029
# agent 86 在 399 次迭代中的资源申请量为: 49.90287553143746
# agent 87 在 399 次迭代中的资源申请量为: 61.57390884340023
# agent 88 在 399 次迭代中的资源申请量为: 66.39932733871201
# agent 89 在 399 次迭代中的资源申请量为: 28.052389199903192
# agent 90 在 399 次迭代中的资源申请量为: 60.423629468503634
# agent 91 在 399 次迭代中的资源申请量为: 43.73895257813867
# agent 92 在 399 次迭代中的资源申请量为: 58.04440756420368
# agent 93 在 399 次迭代中的资源申请量为: 41.50325835674444
# agent 94 在 399 次迭代中的资源申请量为: 50.60913574824951
# agent 95 在 399 次迭代中的资源申请量为: 61.393030224011454
# agent 96 在 399 次迭代中的资源申请量为: 61.68800205893159
# agent 97 在 399 次迭代中的资源申请量为: 73.69112927379133
# agent 98 在 399 次迭代中的资源申请量为: 74.47750664389852
# agent 99 在 399 次迭代中的资源申请量为: 53.50528980066362
# agent 100 在 399 次迭代中的资源申请量为: 49.521274354907455
# 资源申请量总和为: 4999.999999999998
# ****************************************************************************
# 成本总和为: 337057.1870237237
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 449 次迭代中的结果：
# agent 1 在 449 次迭代中的资源申请量为: 49.40025782102448
# agent 2 在 449 次迭代中的资源申请量为: 61.977417268105214
# agent 3 在 449 次迭代中的资源申请量为: 44.64940877009534
# agent 4 在 449 次迭代中的资源申请量为: 66.09675798736829
# agent 5 在 449 次迭代中的资源申请量为: 66.71159735881221
# agent 6 在 449 次迭代中的资源申请量为: 73.59319217253899
# agent 7 在 449 次迭代中的资源申请量为: 39.96071597647124
# agent 8 在 449 次迭代中的资源申请量为: 27.385463450623064
# agent 9 在 449 次迭代中的资源申请量为: 43.53157157270833
# agent 10 在 449 次迭代中的资源申请量为: 56.98100241968707
# agent 11 在 449 次迭代中的资源申请量为: 46.17958220552993
# agent 12 在 449 次迭代中的资源申请量为: 49.83363088708934
# agent 13 在 449 次迭代中的资源申请量为: 67.17917209156822
# agent 14 在 449 次迭代中的资源申请量为: 56.28034852886447
# agent 15 在 449 次迭代中的资源申请量为: 44.58006836188147
# agent 16 在 449 次迭代中的资源申请量为: 44.722983830362296
# agent 17 在 449 次迭代中的资源申请量为: 45.60062604088927
# agent 18 在 449 次迭代中的资源申请量为: 47.35359422748972
# agent 19 在 449 次迭代中的资源申请量为: 42.124822967203336
# agent 20 在 449 次迭代中的资源申请量为: 56.640822241960194
# agent 21 在 449 次迭代中的资源申请量为: 27.88710377066312
# agent 22 在 449 次迭代中的资源申请量为: 39.579962201095455
# agent 23 在 449 次迭代中的资源申请量为: 49.022003446982175
# agent 24 在 449 次迭代中的资源申请量为: 41.514134203119355
# agent 25 在 449 次迭代中的资源申请量为: 46.30083600799628
# agent 26 在 449 次迭代中的资源申请量为: 40.280771522959995
# agent 27 在 449 次迭代中的资源申请量为: 66.8078025931389
# agent 28 在 449 次迭代中的资源申请量为: 52.63824158736388
# agent 29 在 449 次迭代中的资源申请量为: 41.48688187076731
# agent 30 在 449 次迭代中的资源申请量为: 39.70608766357893
# agent 31 在 449 次迭代中的资源申请量为: 61.64668938841827
# agent 32 在 449 次迭代中的资源申请量为: 56.77896163895802
# agent 33 在 449 次迭代中的资源申请量为: 42.61212046623688
# agent 34 在 449 次迭代中的资源申请量为: 53.0829595255436
# agent 35 在 449 次迭代中的资源申请量为: 28.181680918063833
# agent 36 在 449 次迭代中的资源申请量为: 43.406880151752965
# agent 37 在 449 次迭代中的资源申请量为: 53.67275353060622
# agent 38 在 449 次迭代中的资源申请量为: 41.297154493739185
# agent 39 在 449 次迭代中的资源申请量为: 44.379801416203065
# agent 40 在 449 次迭代中的资源申请量为: 50.880055703273364
# agent 41 在 449 次迭代中的资源申请量为: 67.4308817020272
# agent 42 在 449 次迭代中的资源申请量为: 43.23250645192145
# agent 43 在 449 次迭代中的资源申请量为: 52.9836681248677
# agent 44 在 449 次迭代中的资源申请量为: 53.97003807805202
# agent 45 在 449 次迭代中的资源申请量为: 49.373763325211996
# agent 46 在 449 次迭代中的资源申请量为: 56.42977579230897
# agent 47 在 449 次迭代中的资源申请量为: 46.61764516060383
# agent 48 在 449 次迭代中的资源申请量为: 30.66497847729539
# agent 49 在 449 次迭代中的资源申请量为: 43.164220779417924
# agent 50 在 449 次迭代中的资源申请量为: 41.91868099617606
# agent 51 在 449 次迭代中的资源申请量为: 49.10680589258724
# agent 52 在 449 次迭代中的资源申请量为: 56.82441015913806
# agent 53 在 449 次迭代中的资源申请量为: 28.051641646258048
# agent 54 在 449 次迭代中的资源申请量为: 57.856054696949606
# agent 55 在 449 次迭代中的资源申请量为: 72.47465674693362
# agent 56 在 449 次迭代中的资源申请量为: 41.89968030223745
# agent 57 在 449 次迭代中的资源申请量为: 61.26947507817668
# agent 58 在 449 次迭代中的资源申请量为: 42.8854932657708
# agent 59 在 449 次迭代中的资源申请量为: 48.63470148378999
# agent 60 在 449 次迭代中的资源申请量为: 56.958404467949556
# agent 61 在 449 次迭代中的资源申请量为: 67.29578627524616
# agent 62 在 449 次迭代中的资源申请量为: 46.86477986168039
# agent 63 在 449 次迭代中的资源申请量为: 39.50572824836459
# agent 64 在 449 次迭代中的资源申请量为: 45.35169016109442
# agent 65 在 449 次迭代中的资源申请量为: 43.74550949744525
# agent 66 在 449 次迭代中的资源申请量为: 66.71372023566812
# agent 67 在 449 次迭代中的资源申请量为: 30.72110313404948
# agent 68 在 449 次迭代中的资源申请量为: 45.83009039856277
# agent 69 在 449 次迭代中的资源申请量为: 46.513979357161375
# agent 70 在 449 次迭代中的资源申请量为: 61.51934854847607
# agent 71 在 449 次迭代中的资源申请量为: 73.40164510349895
# agent 72 在 449 次迭代中的资源申请量为: 41.17487618648249
# agent 73 在 449 次迭代中的资源申请量为: 44.407360514433186
# agent 74 在 449 次迭代中的资源申请量为: 39.53367583634415
# agent 75 在 449 次迭代中的资源申请量为: 52.67179543942961
# agent 76 在 449 次迭代中的资源申请量为: 47.97957498079903
# agent 77 在 449 次迭代中的资源申请量为: 41.47420720739238
# agent 78 在 449 次迭代中的资源申请量为: 50.784631642980166
# agent 79 在 449 次迭代中的资源申请量为: 43.44155455857186
# agent 80 在 449 次迭代中的资源申请量为: 43.88825693082507
# agent 81 在 449 次迭代中的资源申请量为: 40.228614521140365
# agent 82 在 449 次迭代中的资源申请量为: 46.594596932190456
# agent 83 在 449 次迭代中的资源申请量为: 42.656516416305415
# agent 84 在 449 次迭代中的资源申请量为: 52.88260600033165
# agent 85 在 449 次迭代中的资源申请量为: 57.05974099653133
# agent 86 在 449 次迭代中的资源申请量为: 49.699304401223934
# agent 87 在 449 次迭代中的资源申请量为: 61.34133582861681
# agent 88 在 449 次迭代中的资源申请量为: 66.1729108591001
# agent 89 在 449 次迭代中的资源申请量为: 29.037035128019628
# agent 90 在 449 次迭代中的资源申请量为: 60.459898005258914
# agent 91 在 449 次迭代中的资源申请量为: 43.806475683752836
# agent 92 在 449 次迭代中的资源申请量为: 58.042633055521634
# agent 93 在 449 次迭代中的资源申请量为: 41.55634301575315
# agent 94 在 449 次迭代中的资源申请量为: 49.864682866734555
# agent 95 在 449 次迭代中的资源申请量为: 60.967911855759816
# agent 96 在 449 次迭代中的资源申请量为: 61.797290165397484
# agent 97 在 449 次迭代中的资源申请量为: 73.85779495296308
# agent 98 在 449 次迭代中的资源申请量为: 74.30200076801913
# agent 99 在 449 次迭代中的资源申请量为: 53.69416462633329
# agent 100 在 449 次迭代中的资源申请量为: 49.46542889413358
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 336844.2246420272
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 499 次迭代中的结果：
# agent 1 在 499 次迭代中的资源申请量为: 49.44981006191546
# agent 2 在 499 次迭代中的资源申请量为: 62.39460906135852
# agent 3 在 499 次迭代中的资源申请量为: 44.75414687634054
# agent 4 在 499 次迭代中的资源申请量为: 65.79211254765013
# agent 5 在 499 次迭代中的资源申请量为: 66.68137520970404
# agent 6 在 499 次迭代中的资源申请量为: 73.61377747678429
# agent 7 在 499 次迭代中的资源申请量为: 40.45492704822324
# agent 8 在 499 次迭代中的资源申请量为: 25.526318966090805
# agent 9 在 499 次迭代中的资源申请量为: 44.266548869351986
# agent 10 在 499 次迭代中的资源申请量为: 56.97368757325894
# agent 11 在 499 次迭代中的资源申请量为: 46.590169470483396
# agent 12 在 499 次迭代中的资源申请量为: 50.59485453378968
# agent 13 在 499 次迭代中的资源申请量为: 67.20376912399607
# agent 14 在 499 次迭代中的资源申请量为: 56.44026737275117
# agent 15 在 499 次迭代中的资源申请量为: 44.334289072984284
# agent 16 在 499 次迭代中的资源申请量为: 44.57216288282606
# agent 17 在 499 次迭代中的资源申请量为: 45.975376210637165
# agent 18 在 499 次迭代中的资源申请量为: 47.507073590249576
# agent 19 在 499 次迭代中的资源申请量为: 42.203231538052684
# agent 20 在 499 次迭代中的资源申请量为: 57.00008323983665
# agent 21 在 499 次迭代中的资源申请量为: 25.935630715145358
# agent 22 在 499 次迭代中的资源申请量为: 40.04338165439524
# agent 23 在 499 次迭代中的资源申请量为: 48.7357458949487
# agent 24 在 499 次迭代中的资源申请量为: 41.309747845532065
# agent 25 在 499 次迭代中的资源申请量为: 46.076030933989685
# ...
# agent 88 在 1969 次迭代中的资源申请量为: 66.65285171711349
# agent 89 在 1969 次迭代中的资源申请量为: 41.46004062658041
# agent 90 在 1969 次迭代中的资源申请量为: 60.61708692359736
# agent 91 在 1969 次迭代中的资源申请量为: 43.90929815427954
# agent 92 在 1969 次迭代中的资源申请量为: 58.21511194208052
# agent 93 在 1969 次迭代中的资源申请量为: 41.66004062658042
# agent 94 在 1969 次迭代中的资源申请量为: -76.0421847926642
# agent 95 在 1969 次迭代中的资源申请量为: 61.71708692359737
# agent 96 在 1969 次迭代中的资源申请量为: 61.917086923597374
# agent 97 在 1969 次迭代中的资源申请量为: 73.87209323482342
# agent 98 在 1969 次迭代中的资源申请量为: 74.67209323482344
# agent 99 在 1969 次迭代中的资源申请量为: 53.66864689596046
# agent 100 在 1969 次迭代中的资源申请量为: 49.647003032737025
# 资源申请量总和为: 5000.00000000061
# ****************************************************************************
# 成本总和为: 356531.27486062166
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1979 次迭代中的结果：
# agent 1 在 1979 次迭代中的资源申请量为: 49.94183214704067
# agent 2 在 1979 次迭代中的资源申请量为: 62.73296293438592
# agent 3 在 1979 次迭代中的资源申请量为: 45.22346870968716
# agent 4 在 1979 次迭代中的资源申请量为: 66.32890861258537
# agent 5 在 1979 次迭代中的资源申请量为: 67.12890861258538
# agent 6 在 1979 次迭代中的资源申请量为: 74.00270692524107
# agent 7 在 1979 次迭代中的资源申请量为: 40.76941250840754
# agent 8 在 1979 次迭代中的资源申请量为: 38.97001760531983
# agent 9 在 1979 次迭代中的资源申请量为: 44.52346870968715
# agent 10 在 1979 次迭代中的资源申请量为: 57.46423499108755
# agent 11 在 1979 次迭代中的资源申请量为: 46.959786042621694
# agent 12 在 1979 次迭代中的资源申请量为: 50.84183214704066
# agent 13 在 1979 次迭代中的资源申请量为: 67.62890861258536
# agent 14 在 1979 次迭代中的资源申请量为: 56.86423499108755
# agent 15 在 1979 次迭代中的资源申请量为: 44.92346870968715
# agent 16 在 1979 次迭代中的资源申请量为: 45.12346870968715
# agent 17 在 1979 次迭代中的资源申请量为: 46.35978604262171
# agent 18 在 1979 次迭代中的资源申请量为: 47.9597860426217
# agent 19 在 1979 次迭代中的资源申请量为: 42.67515233107956
# agent 20 在 1979 次迭代中的资源申请量为: 57.364234991087564
# agent 21 在 1979 次迭代中的资源申请量为: 40.06941250840754
# agent 22 在 1979 次迭代中的资源申请量为: 40.369412508407535
# agent 23 在 1979 次迭代中的资源申请量为: 49.34183214704067
# agent 24 在 1979 次迭代中的资源申请量为: 41.87515233107955
# agent 25 在 1979 次迭代中的资源申请量为: 46.6597860426217
# agent 26 在 1979 次迭代中的资源申请量为: 41.069412508407545
# agent 27 在 1979 次迭代中的资源申请量为: 67.32890861258538
# agent 28 在 1979 次迭代中的资源申请量为: 52.94407982508972
# agent 29 在 1979 次迭代中的资源申请量为: 42.17515233107955
# agent 30 在 1979 次迭代中的资源申请量为: 40.469412508407544
# agent 31 在 1979 次迭代中的资源申请量为: 62.13296293438591
# agent 32 在 1979 次迭代中的资源申请量为: 57.16423499108756
# agent 33 在 1979 次迭代中的资源申请量为: 42.97515233107955
# agent 34 在 1979 次迭代中的资源申请量为: 53.84407982508972
# agent 35 在 1979 次迭代中的资源申请量为: 40.16941250840754
# agent 36 在 1979 次迭代中的资源申请量为: 44.223468709687154
# agent 37 在 1979 次迭代中的资源申请量为: 54.14407982508972
# agent 38 在 1979 次迭代中的资源申请量为: 41.67515233107955
# agent 39 在 1979 次迭代中的资源申请量为: 44.723468709687154
# agent 40 在 1979 次迭代中的资源申请量为: 51.64183214704067
# agent 41 在 1979 次迭代中的资源申请量为: 68.02890861258537
# agent 42 在 1979 次迭代中的资源申请量为: 43.92346870968716
# agent 43 在 1979 次迭代中的资源申请量为: 53.34407982508972
# agent 44 在 1979 次迭代中的资源申请量为: 54.544079825089725
# agent 45 在 1979 次迭代中的资源申请量为: 49.74183214704067
# agent 46 在 1979 次迭代中的资源申请量为: 57.46423499108756
# agent 47 在 1979 次迭代中的资源申请量为: 47.3597860426217
# agent 48 在 1979 次迭代中的资源申请量为: 44.82346870968716
# agent 49 在 1979 次迭代中的资源申请量为: 44.12346870968716
# agent 50 在 1979 次迭代中的资源申请量为: 42.27515233107955
# agent 51 在 1979 次迭代中的资源申请量为: 49.84183214704068
# agent 52 在 1979 次迭代中的资源申请量为: 57.364234991087564
# agent 53 在 1979 次迭代中的资源申请量为: 40.26941250840754
# agent 54 在 1979 次迭代中的资源申请量为: 58.56423499108757
# agent 55 在 1979 次迭代中的资源申请量为: 72.90270692524108
# agent 56 在 1979 次迭代中的资源申请量为: 42.27515233107955
# agent 57 在 1979 次迭代中的资源申请量为: 62.132962934385915
# agent 58 在 1979 次迭代中的资源申请量为: 43.62346870968717
# agent 59 在 1979 次迭代中的资源申请量为: 49.441832147040664
# agent 60 在 1979 次迭代中的资源申请量为: 57.66423499108756
# agent 61 在 1979 次迭代中的资源申请量为: 67.72890861258537
# agent 62 在 1979 次迭代中的资源申请量为: 47.559786042621695
# agent 63 在 1979 次迭代中的资源申请量为: 40.26941250840754
# agent 64 在 1979 次迭代中的资源申请量为: 45.8597860426217
# agent 65 在 1979 次迭代中的资源申请量为: 44.12346870968715
# agent 66 在 1979 次迭代中的资源申请量为: 67.42890861258537
# agent 67 在 1979 次迭代中的资源申请量为: 44.723468709687154
# agent 68 在 1979 次迭代中的资源申请量为: 46.3597860426217
# agent 69 在 1979 次迭代中的资源申请量为: 46.85978604262169
# agent 70 在 1979 次迭代中的资源申请量为: 61.732962934385895
# agent 71 在 1979 次迭代中的资源申请量为: 73.90270692524106
# agent 72 在 1979 次迭代中的资源申请量为: 61.93296293438589
# agent 73 在 1979 次迭代中的资源申请量为: 45.123468709687145
# agent 74 在 1979 次迭代中的资源申请量为: 40.269412508407534
# agent 75 在 1979 次迭代中的资源申请量为: 53.54407982508971
# agent 76 在 1979 次迭代中的资源申请量为: 48.459786042621694
# agent 77 在 1979 次迭代中的资源申请量为: 42.175152331079545
# agent 78 在 1979 次迭代中的资源申请量为: 51.14183214704065
# agent 79 在 1979 次迭代中的资源申请量为: 44.22346870968715
# agent 80 在 1979 次迭代中的资源申请量为: 44.42346870968715
# agent 81 在 1979 次迭代中的资源申请量为: 40.769412508407534
# agent 82 在 1979 次迭代中的资源申请量为: 47.15978604262169
# agent 83 在 1979 次迭代中的资源申请量为: 42.97515233107954
# agent 84 在 1979 次迭代中的资源申请量为: 53.64407982508971
# agent 85 在 1979 次迭代中的资源申请量为: 57.36423499108754
# agent 86 在 1979 次迭代中的资源申请量为: 50.44183214704066
# agent 87 在 1979 次迭代中的资源申请量为: 62.132962934385894
# agent 88 在 1979 次迭代中的资源申请量为: 66.92890861258536
# agent 89 在 1979 次迭代中的资源申请量为: 41.87515233107954
# agent 90 在 1979 次迭代中的资源申请量为: 60.932962934385884
# agent 91 在 1979 次迭代中的资源申请量为: 44.32346870968715
# agent 92 在 1979 次迭代中的资源申请量为: 58.56423499108755
# agent 93 在 1979 次迭代中的资源申请量为: 42.07515233107954
# agent 94 在 1979 次迭代中的资源申请量为: -112.87874407284804
# agent 95 在 1979 次迭代中的资源申请量为: 62.032962934385885
# agent 96 在 1979 次迭代中的资源申请量为: 62.23296293438588
# agent 97 在 1979 次迭代中的资源申请量为: 74.10270692524104
# agent 98 在 1979 次迭代中的资源申请量为: 74.90270692524106
# agent 99 在 1979 次迭代中的资源申请量为: 54.0440798250897
# agent 100 在 1979 次迭代中的资源申请量为: 50.04183214704065
# 资源申请量总和为: 5000.000000000615
# ****************************************************************************
# 成本总和为: 369027.9243088913
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1989 次迭代中的结果：
# agent 1 在 1989 次迭代中的资源申请量为: 49.1741845818357
# agent 2 在 1989 次迭代中的资源申请量为: 61.89972893098601
# agent 3 在 1989 次迭代中的资源申请量为: 44.526185722537335
# agent 4 在 1989 次迭代中的资源申请量为: 65.48547386635371
# agent 5 在 1989 次迭代中的资源申请量为: 66.28547386635373
# agent 6 在 1989 次迭代中的资源申请量为: 73.1535300611212
# agent 7 在 1989 次迭代中的资源申请量为: 40.156801515194765
# agent 8 在 1989 次迭代中的资源申请量为: 38.40299895352136
# agent 9 在 1989 次迭代中的资源申请量为: 43.826185722537346
# agent 10 在 1989 次迭代中的资源申请量为: 56.646901982994045
# agent 11 在 1989 次迭代中的资源申请量为: 46.22510106455892
# agent 12 在 1989 次迭代中的资源申请量为: 50.07418458183571
# agent 13 在 1989 次迭代中的资源申请量为: 66.78547386635373
# agent 14 在 1989 次迭代中的资源申请量为: 56.046901982994044
# agent 15 在 1989 次迭代中的资源申请量为: 44.22618572253734
# agent 16 在 1989 次迭代中的资源申请量为: 44.42618572253734
# agent 17 在 1989 次迭代中的资源申请量为: 45.625101064558926
# agent 18 在 1989 次迭代中的资源申请量为: 47.22510106455892
# agent 19 在 1989 次迭代中的资源申请量为: 42.01884927783489
# agent 20 在 1989 次迭代中的资源申请量为: 56.546901982994044
# agent 21 在 1989 次迭代中的资源申请量为: 39.45680151519476
# agent 22 在 1989 次迭代中的资源申请量为: 39.75680151519475
# agent 23 在 1989 次迭代中的资源申请量为: 48.574184581835716
# agent 24 在 1989 次迭代中的资源申请量为: 41.218849277834885
# agent 25 在 1989 次迭代中的资源申请量为: 45.92510106455892
# agent 26 在 1989 次迭代中的资源申请量为: 40.45680151519477
# agent 27 在 1989 次迭代中的资源申请量为: 66.48547386635373
# agent 28 在 1989 次迭代中的资源申请量为: 52.14868765499258
# agent 29 在 1989 次迭代中的资源申请量为: 41.51884927783489
# agent 30 在 1989 次迭代中的资源申请量为: 39.85680151519477
# agent 31 在 1989 次迭代中的资源申请量为: 61.29972893098601
# agent 32 在 1989 次迭代中的资源申请量为: 56.34690198299405
# agent 33 在 1989 次迭代中的资源申请量为: 42.31884927783489
# agent 34 在 1989 次迭代中的资源申请量为: 53.04868765499259
# agent 35 在 1989 次迭代中的资源申请量为: 39.55680151519477
# agent 36 在 1989 次迭代中的资源申请量为: 43.52618572253735
# agent 37 在 1989 次迭代中的资源申请量为: 53.348687654992595
# agent 38 在 1989 次迭代中的资源申请量为: 41.018849277834896
# agent 39 在 1989 次迭代中的资源申请量为: 44.026185722537356
# agent 40 在 1989 次迭代中的资源申请量为: 50.87418458183573
# agent 41 在 1989 次迭代中的资源申请量为: 67.18547386635373
# agent 42 在 1989 次迭代中的资源申请量为: 43.226185722537345
# agent 43 在 1989 次迭代中的资源申请量为: 52.5486876549926
# agent 44 在 1989 次迭代中的资源申请量为: 53.7486876549926
# agent 45 在 1989 次迭代中的资源申请量为: 48.97418458183573
# agent 46 在 1989 次迭代中的资源申请量为: 56.64690198299406
# agent 47 在 1989 次迭代中的资源申请量为: 46.62510106455894
# agent 48 在 1989 次迭代中的资源申请量为: 44.12618572253736
# agent 49 在 1989 次迭代中的资源申请量为: 43.426185722537355
# agent 50 在 1989 次迭代中的资源申请量为: 41.618849277834904
# agent 51 在 1989 次迭代中的资源申请量为: 49.07418458183573
# agent 52 在 1989 次迭代中的资源申请量为: 56.546901982994065
# agent 53 在 1989 次迭代中的资源申请量为: 39.65680151519478
# agent 54 在 1989 次迭代中的资源申请量为: 57.74690198299407
# agent 55 在 1989 次迭代中的资源申请量为: 72.05353006112122
# agent 56 在 1989 次迭代中的资源申请量为: 41.6188492778349
# agent 57 在 1989 次迭代中的资源申请量为: 61.29972893098602
# agent 58 在 1989 次迭代中的资源申请量为: 42.926185722537355
# agent 59 在 1989 次迭代中的资源申请量为: 48.67418458183572
# agent 60 在 1989 次迭代中的资源申请量为: 56.846901982994055
# agent 61 在 1989 次迭代中的资源申请量为: 66.88547386635375
# agent 62 在 1989 次迭代中的资源申请量为: 46.825101064558936
# agent 63 在 1989 次迭代中的资源申请量为: 39.65680151519478
# agent 64 在 1989 次迭代中的资源申请量为: 45.12510106455894
# agent 65 在 1989 次迭代中的资源申请量为: 43.426185722537355
# agent 66 在 1989 次迭代中的资源申请量为: 66.58547386635374
# agent 67 在 1989 次迭代中的资源申请量为: 44.026185722537356
# agent 68 在 1989 次迭代中的资源申请量为: 45.62510106455895
# agent 69 在 1989 次迭代中的资源申请量为: 46.12510106455895
# agent 70 在 1989 次迭代中的资源申请量为: 60.899728930986015
# agent 71 在 1989 次迭代中的资源申请量为: 73.05353006112122
# agent 72 在 1989 次迭代中的资源申请量为: 61.09972893098601
# agent 73 在 1989 次迭代中的资源申请量为: 44.426185722537355
# agent 74 在 1989 次迭代中的资源申请量为: 39.65680151519477
# agent 75 在 1989 次迭代中的资源申请量为: 52.7486876549926
# agent 76 在 1989 次迭代中的资源申请量为: 47.72510106455894
# agent 77 在 1989 次迭代中的资源申请量为: 41.5188492778349
# agent 78 在 1989 次迭代中的资源申请量为: 50.37418458183572
# agent 79 在 1989 次迭代中的资源申请量为: 43.52618572253735
# agent 80 在 1989 次迭代中的资源申请量为: 43.72618572253735
# agent 81 在 1989 次迭代中的资源申请量为: 40.15680151519477
# agent 82 在 1989 次迭代中的资源申请量为: 46.42510106455894
# agent 83 在 1989 次迭代中的资源申请量为: 42.31884927783489
# agent 84 在 1989 次迭代中的资源申请量为: 52.84868765499259
# agent 85 在 1989 次迭代中的资源申请量为: 56.54690198299405
# agent 86 在 1989 次迭代中的资源申请量为: 49.67418458183571
# agent 87 在 1989 次迭代中的资源申请量为: 61.299728930986014
# agent 88 在 1989 次迭代中的资源申请量为: 66.08547386635374
# agent 89 在 1989 次迭代中的资源申请量为: 41.21884927783489
# agent 90 在 1989 次迭代中的资源申请量为: 60.099728930986004
# agent 91 在 1989 次迭代中的资源申请量为: 43.62618572253734
# agent 92 在 1989 次迭代中的资源申请量为: 57.74690198299406
# agent 93 在 1989 次迭代中的资源申请量为: 41.41884927783489
# agent 94 在 1989 次迭代中的资源申请量为: -39.02280793532596
# agent 95 在 1989 次迭代中的资源申请量为: 61.19972893098601
# agent 96 在 1989 次迭代中的资源申请量为: 61.39972893098601
# agent 97 在 1989 次迭代中的资源申请量为: 73.2535300611212
# agent 98 在 1989 次迭代中的资源申请量为: 74.05353006112121
# agent 99 在 1989 次迭代中的资源申请量为: 53.24868765499259
# agent 100 在 1989 次迭代中的资源申请量为: 49.274184581835705
# 资源申请量总和为: 5000.000000000621
# ****************************************************************************
# 成本总和为: 346749.0476139806
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1999 次迭代中的结果：
# agent 1 在 1999 次迭代中的资源申请量为: 49.61696166004026
# agent 2 在 1999 次迭代中的资源申请量为: 62.298594620604206
# agent 3 在 1999 次迭代中的资源申请量为: 44.983652058533295
# agent 4 在 1999 次迭代中的资源申请量为: 65.86065967892343
# agent 5 在 1999 次迭代中的资源申请量为: 66.66065967892344
# agent 6 在 1999 次迭代中的资源申请量为: 73.49918448162951
# agent 7 在 1999 次迭代中的资源申请量为: 40.62330188250267
# agent 8 在 1999 次迭代中的资源申请量为: 38.872881225300354
# agent 9 在 1999 次迭代中的资源申请量为: 44.2836520585333
# agent 10 在 1999 次迭代中的资源申请量为: 57.064368770705464
# agent 11 在 1999 次迭代中的资源申请量为: 46.67619660991122
# agent 12 在 1999 次迭代中的资源申请量为: 50.51696166004028
# agent 13 在 1999 次迭代中的资源申请量为: 67.16065967892344
# agent 14 在 1999 次迭代中的资源申请量为: 56.46436877070546
# agent 15 在 1999 次迭代中的资源申请量为: 44.68365205853329
# agent 16 在 1999 次迭代中的资源申请量为: 44.88365205853329
# agent 17 在 1999 次迭代中的资源申请量为: 46.07619660991123
# agent 18 在 1999 次迭代中的资源申请量为: 47.67619660991122
# agent 19 在 1999 次迭代中的资源申请量为: 42.48130622031298
# agent 20 在 1999 次迭代中的资源申请量为: 56.96436877070546
# agent 21 在 1999 次迭代中的资源申请量为: 39.92330188250266
# agent 22 在 1999 次迭代中的资源申请量为: 40.22330188250267
# agent 23 在 1999 次迭代中的资源申请量为: 49.01696166004027
# agent 24 在 1999 次迭代中的资源申请量为: 41.68130622031298
# agent 25 在 1999 次迭代中的资源申请量为: 46.37619660991122
# agent 26 在 1999 次迭代中的资源申请量为: 40.92330188250267
# agent 27 在 1999 次迭代中的资源申请量为: 66.86065967892344
# agent 28 在 1999 次迭代中的资源申请量为: 52.58051403666166
# agent 29 在 1999 次迭代中的资源申请量为: 41.98130622031299
# agent 30 在 1999 次迭代中的资源申请量为: 40.32330188250267
# agent 31 在 1999 次迭代中的资源申请量为: 61.69859462060421
# agent 32 在 1999 次迭代中的资源申请量为: 56.76436877070545
# agent 33 在 1999 次迭代中的资源申请量为: 42.78130622031298
# agent 34 在 1999 次迭代中的资源申请量为: 53.48051403666166
# agent 35 在 1999 次迭代中的资源申请量为: 40.02330188250266
# agent 36 在 1999 次迭代中的资源申请量为: 43.98365205853328
# agent 37 在 1999 次迭代中的资源申请量为: 53.78051403666166
# agent 38 在 1999 次迭代中的资源申请量为: 41.48130622031297
# agent 39 在 1999 次迭代中的资源申请量为: 44.48365205853327
# agent 40 在 1999 次迭代中的资源申请量为: 51.31696166004025
# agent 41 在 1999 次迭代中的资源申请量为: 67.56065967892343
# agent 42 在 1999 次迭代中的资源申请量为: 43.683652058533276
# agent 43 在 1999 次迭代中的资源申请量为: 52.98051403666166
# agent 44 在 1999 次迭代中的资源申请量为: 54.180514036661656
# agent 45 在 1999 次迭代中的资源申请量为: 49.41696166004026
# agent 46 在 1999 次迭代中的资源申请量为: 57.06436877070544
# agent 47 在 1999 次迭代中的资源申请量为: 47.07619660991121
# agent 48 在 1999 次迭代中的资源申请量为: 44.58365205853327
# agent 49 在 1999 次迭代中的资源申请量为: 43.88365205853327
# agent 50 在 1999 次迭代中的资源申请量为: 42.08130622031297
# agent 51 在 1999 次迭代中的资源申请量为: 49.51696166004026
# agent 52 在 1999 次迭代中的资源申请量为: 56.96436877070545
# agent 53 在 1999 次迭代中的资源申请量为: 40.123301882502645
# agent 54 在 1999 次迭代中的资源申请量为: 58.16436877070545
# agent 55 在 1999 次迭代中的资源申请量为: 72.39918448162949
# agent 56 在 1999 次迭代中的资源申请量为: 42.08130622031297
# agent 57 在 1999 次迭代中的资源申请量为: 61.698594620604204
# agent 58 在 1999 次迭代中的资源申请量为: 43.38365205853328
# agent 59 在 1999 次迭代中的资源申请量为: 49.11696166004026
# agent 60 在 1999 次迭代中的资源申请量为: 57.26436877070545
# agent 61 在 1999 次迭代中的资源申请量为: 67.26065967892342
# agent 62 在 1999 次迭代中的资源申请量为: 47.27619660991121
# agent 63 在 1999 次迭代中的资源申请量为: 40.123301882502645
# agent 64 在 1999 次迭代中的资源申请量为: 45.57619660991121
# agent 65 在 1999 次迭代中的资源申请量为: 43.88365205853327
# agent 66 在 1999 次迭代中的资源申请量为: 66.96065967892342
# agent 67 在 1999 次迭代中的资源申请量为: 44.483652058533266
# agent 68 在 1999 次迭代中的资源申请量为: 46.076196609911214
# agent 69 在 1999 次迭代中的资源申请量为: 46.576196609911214
# agent 70 在 1999 次迭代中的资源申请量为: 61.29859462060419
# agent 71 在 1999 次迭代中的资源申请量为: 73.3991844816295
# agent 72 在 1999 次迭代中的资源申请量为: 61.498594620604194
# agent 73 在 1999 次迭代中的资源申请量为: 44.88365205853327
# agent 74 在 1999 次迭代中的资源申请量为: 40.12330188250265
# agent 75 在 1999 次迭代中的资源申请量为: 53.18051403666165
# agent 76 在 1999 次迭代中的资源申请量为: 48.176196609911216
# agent 77 在 1999 次迭代中的资源申请量为: 41.98130622031298
# agent 78 在 1999 次迭代中的资源申请量为: 50.816961660040256
# agent 79 在 1999 次迭代中的资源申请量为: 43.98365205853328
# agent 80 在 1999 次迭代中的资源申请量为: 44.18365205853328
# agent 81 在 1999 次迭代中的资源申请量为: 40.62330188250266
# agent 82 在 1999 次迭代中的资源申请量为: 46.876196609911226
# agent 83 在 1999 次迭代中的资源申请量为: 42.78130622031298
# agent 84 在 1999 次迭代中的资源申请量为: 53.280514036661664
# agent 85 在 1999 次迭代中的资源申请量为: 56.964368770705455
# agent 86 在 1999 次迭代中的资源申请量为: 50.11696166004026
# agent 87 在 1999 次迭代中的资源申请量为: 61.69859462060421
# agent 88 在 1999 次迭代中的资源申请量为: 66.46065967892343
# agent 89 在 1999 次迭代中的资源申请量为: 41.681306220312976
# agent 90 在 1999 次迭代中的资源申请量为: 60.4985946206042
# agent 91 在 1999 次迭代中的资源申请量为: 44.08365205853328
# agent 92 在 1999 次迭代中的资源申请量为: 58.16436877070546
# agent 93 在 1999 次迭代中的资源申请量为: 41.88130622031297
# agent 94 在 1999 次迭代中的资源申请量为: -81.90283214442988
# agent 95 在 1999 次迭代中的资源申请量为: 61.5985946206042
# agent 96 在 1999 次迭代中的资源申请量为: 61.7985946206042
# agent 97 在 1999 次迭代中的资源申请量为: 73.59918448162949
# agent 98 在 1999 次迭代中的资源申请量为: 74.3991844816295
# agent 99 在 1999 次迭代中的资源申请量为: 53.68051403666164
# agent 100 在 1999 次迭代中的资源申请量为: 49.71696166004025
# 资源申请量总和为: 5000.0000000006185
# ****************************************************************************
# 成本总和为: 358338.6125334472
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 2025-01-21 17:25:56.462

# %%
np.savetxt('../data/03-9-bias-agent-agent_resource_quantity_small_value_Gaussian_bias(50,10).txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/03-9-bias-agent-sum_cost_small_value_Gaussian_bias(50,10).txt',sum_cost,fmt='%0.8f')#用户成本总和 
np.savetxt('../data/03-9-bias-agent-sum_resource_small_value_Gaussian_bias(50,10).txt',sum_resource,fmt='%0.8f')#用户资源总和 
np.savetxt('../data/03-9-bias-agent-agent_gradient_small_value_Gaussian_bias(50,10).txt',agent_gradient,fmt='%0.8f')#用户迭代梯度
