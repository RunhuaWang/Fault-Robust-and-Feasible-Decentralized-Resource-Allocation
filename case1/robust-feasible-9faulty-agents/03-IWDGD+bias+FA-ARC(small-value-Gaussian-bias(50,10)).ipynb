# %% [raw]
# 服从小值高斯分布的噪声

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(100,1000), dtype=np.float64) 
sum_resource=np.zeros(shape=(1,1000), dtype=np.float64)
sum_cost=np.zeros(shape=(1,1000), dtype=np.float64)
iteration_update = 0.01
A=np.loadtxt("100_Network_Topology_Double_Random_Adjacency_Matrix_Degree_15.txt") #网络拓扑的邻接矩阵 对角元素要为0
D=np.zeros(shape=(100,100))# 网络的度矩阵
L=np.zeros(shape=(100,100))# 网络的拉普拉斯矩阵 L=D-A
W=np.zeros(shape=(100,100)) #可以直接采用网络对应的拉普拉斯矩阵  因为无向图的拉普拉斯矩阵天然满足行和和列和为0
iteration=[]
a=np.loadtxt("100_uniform_distribution_(1,2)_point1.txt")
b=np.loadtxt("100_normal_distribution_(2,0.6)_point1.txt")
agent_gradient=np.zeros(shape=(100,1000), dtype=np.float64) 
bias=np.loadtxt("1000_Gaussian_distribution_(50,10).txt")
C=np.zeros(shape=(1,1000), dtype=np.float64)#adaptive robust clipping的裁剪参数 
#设置为全局第b大的梯度信息 b为网络中设备损坏的用户上界 每一次迭代就需要计算一次新的C值

# %%
#根据邻接矩阵生成网络对应的度矩阵
for i in range(0,100):
    d=0
    for j in range(0,100):
        if A[i][j]==1:
            d=d+1
    D[i][i]=d

#根据邻接矩阵和度矩阵计算拉普拉斯矩阵
L=D-A

#选择用拉普拉斯矩阵作为聚合矩阵
W=L
    
#资源量的初始化 需要给定可行的初始化 即满足平均资源约束
for i in range (0,100):
    agent_resource_quantity[i][0]=50
    
#资源量总和 初始化
sum=0
for i in range (0,100):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

iteration.append(0)

#初始梯度计算
for i in range (0,100):
    if i==7 or i==20 or i==34 or i==47 or i==52 or i==88 or i==66 or i==71 or i==93:
        agent_gradient[i][0]=2*a[i]*agent_resource_quantity[i][0]-2*a[i]*b[i]+bias[0]
    else:
        agent_gradient[i][0]=2*a[i]*agent_resource_quantity[i][0]-2*a[i]*b[i]
    
#计算初始的C值
column_data = agent_gradient[:, 0]
forth_largest = np.partition(np.abs(column_data), -10)[-10]
C[0][0]=forth_largest

#诚实用户成本总和初始化
sum=0
for i in range(0,100):
    sum=sum+a[i]*(agent_resource_quantity[i][0]-b[i])*(agent_resource_quantity[i][0]-b[i])
sum_cost[0][0]=sum

# %%
#基于初始化的权重梯度下降无中心资源分配算法
def IWDGD_Gaussian_bias_C(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias,C):
    
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************IWDGD算法+计算误差+鲁棒****************************")
    print("相关变量初始值为：")
    for i in range (0,100):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):#迭代次数
        iteration.append(k)
 
        #所有用户资源申请量基于可行初始化权重梯度下降的迭代  假设部分用户因为设备损坏 导致梯度的计算有误差     
        for i in range (0,100):
            weight_gradient_sum = np.float64(0)
            for j in range (0,100):  
                if np.abs(agent_gradient[j][k-1])>C[0][k-1]:
                    weight_gradient_sum=weight_gradient_sum+W[i][j]*(C[0][k-1]/np.abs(agent_gradient[j][k-1])*agent_gradient[j][k-1])
                else:
                    weight_gradient_sum=weight_gradient_sum+W[i][j]*agent_gradient[j][k-1]                   
                #weight_gradient_sum = np.round(weight_gradient_sum, decimals=3)
            agent_resource_quantity[i][k]=agent_resource_quantity[i][k-1]-iteration_update*weight_gradient_sum
                #agent_resource_quantity[i][k] = np.round(agent_resource_quantity[i][k], decimals=3)                      
        
        #计算所有诚实用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,100):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有诚实用户的成本总和
        sum2=np.float64(0)
        for i in range(0,100):
            sum2=sum2+a[i]*(agent_resource_quantity[i][k]-b[i])*(agent_resource_quantity[i][k]-b[i])
        sum_cost[0][k]=sum2
        
        #计算当前迭代的用户梯度
        for i in range (0,100): 
            if i==7 or i==20 or i==34 or i==47 or i==52 or i==88 or i==66 or i==71 or i==93:
                agent_gradient[i][k]=2*a[i]*agent_resource_quantity[i][k]-2*a[i]*b[i]+bias[k]
            else:
                agent_gradient[i][k]=2*a[i]*agent_resource_quantity[i][k]-2*a[i]*b[i]
                
        #计算当前迭代的C值
        column_data = agent_gradient[:, k]
        forth_largest = np.partition(np.abs(column_data), -10)[-10]
        C[0][k]=forth_largest
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%50==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,100):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        #iteration_update=1/(pow(k+1,0.05)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
IWDGD_Gaussian_bias_C(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,bias,C)
# Out:
# ****************************IWDGD算法+计算误差+鲁棒****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 50.0
# agent 2 的初始资源申请量为: 50.0
# agent 3 的初始资源申请量为: 50.0
# agent 4 的初始资源申请量为: 50.0
# agent 5 的初始资源申请量为: 50.0
# agent 6 的初始资源申请量为: 50.0
# agent 7 的初始资源申请量为: 50.0
# agent 8 的初始资源申请量为: 50.0
# agent 9 的初始资源申请量为: 50.0
# agent 10 的初始资源申请量为: 50.0
# agent 11 的初始资源申请量为: 50.0
# agent 12 的初始资源申请量为: 50.0
# agent 13 的初始资源申请量为: 50.0
# agent 14 的初始资源申请量为: 50.0
# agent 15 的初始资源申请量为: 50.0
# agent 16 的初始资源申请量为: 50.0
# agent 17 的初始资源申请量为: 50.0
# agent 18 的初始资源申请量为: 50.0
# agent 19 的初始资源申请量为: 50.0
# agent 20 的初始资源申请量为: 50.0
# agent 21 的初始资源申请量为: 50.0
# agent 22 的初始资源申请量为: 50.0
# agent 23 的初始资源申请量为: 50.0
# agent 24 的初始资源申请量为: 50.0
# agent 25 的初始资源申请量为: 50.0
# agent 26 的初始资源申请量为: 50.0
# agent 27 的初始资源申请量为: 50.0
# agent 28 的初始资源申请量为: 50.0
# agent 29 的初始资源申请量为: 50.0
# agent 30 的初始资源申请量为: 50.0
# agent 31 的初始资源申请量为: 50.0
# agent 32 的初始资源申请量为: 50.0
# agent 33 的初始资源申请量为: 50.0
# agent 34 的初始资源申请量为: 50.0
# agent 35 的初始资源申请量为: 50.0
# agent 36 的初始资源申请量为: 50.0
# agent 37 的初始资源申请量为: 50.0
# agent 38 的初始资源申请量为: 50.0
# agent 39 的初始资源申请量为: 50.0
# agent 40 的初始资源申请量为: 50.0
# agent 41 的初始资源申请量为: 50.0
# agent 42 的初始资源申请量为: 50.0
# agent 43 的初始资源申请量为: 50.0
# agent 44 的初始资源申请量为: 50.0
# agent 45 的初始资源申请量为: 50.0
# agent 46 的初始资源申请量为: 50.0
# agent 47 的初始资源申请量为: 50.0
# agent 48 的初始资源申请量为: 50.0
# agent 49 的初始资源申请量为: 50.0
# agent 50 的初始资源申请量为: 50.0
# agent 51 的初始资源申请量为: 50.0
# agent 52 的初始资源申请量为: 50.0
# agent 53 的初始资源申请量为: 50.0
# agent 54 的初始资源申请量为: 50.0
# agent 55 的初始资源申请量为: 50.0
# agent 56 的初始资源申请量为: 50.0
# agent 57 的初始资源申请量为: 50.0
# agent 58 的初始资源申请量为: 50.0
# agent 59 的初始资源申请量为: 50.0
# agent 60 的初始资源申请量为: 50.0
# agent 61 的初始资源申请量为: 50.0
# agent 62 的初始资源申请量为: 50.0
# agent 63 的初始资源申请量为: 50.0
# agent 64 的初始资源申请量为: 50.0
# agent 65 的初始资源申请量为: 50.0
# agent 66 的初始资源申请量为: 50.0
# agent 67 的初始资源申请量为: 50.0
# agent 68 的初始资源申请量为: 50.0
# agent 69 的初始资源申请量为: 50.0
# agent 70 的初始资源申请量为: 50.0
# agent 71 的初始资源申请量为: 50.0
# agent 72 的初始资源申请量为: 50.0
# agent 73 的初始资源申请量为: 50.0
# agent 74 的初始资源申请量为: 50.0
# agent 75 的初始资源申请量为: 50.0
# agent 76 的初始资源申请量为: 50.0
# agent 77 的初始资源申请量为: 50.0
# agent 78 的初始资源申请量为: 50.0
# agent 79 的初始资源申请量为: 50.0
# agent 80 的初始资源申请量为: 50.0
# agent 81 的初始资源申请量为: 50.0
# agent 82 的初始资源申请量为: 50.0
# agent 83 的初始资源申请量为: 50.0
# agent 84 的初始资源申请量为: 50.0
# agent 85 的初始资源申请量为: 50.0
# agent 86 的初始资源申请量为: 50.0
# agent 87 的初始资源申请量为: 50.0
# agent 88 的初始资源申请量为: 50.0
# agent 89 的初始资源申请量为: 50.0
# agent 90 的初始资源申请量为: 50.0
# agent 91 的初始资源申请量为: 50.0
# agent 92 的初始资源申请量为: 50.0
# agent 93 的初始资源申请量为: 50.0
# agent 94 的初始资源申请量为: 50.0
# agent 95 的初始资源申请量为: 50.0
# agent 96 的初始资源申请量为: 50.0
# agent 97 的初始资源申请量为: 50.0
# agent 98 的初始资源申请量为: 50.0
# agent 99 的初始资源申请量为: 50.0
# agent 100 的初始资源申请量为: 50.0
# *************************
# 初始资源申请量总和为: 5000.0
# *************************
# 初始成本总和为: 346654.5889999999
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 49 次迭代中的结果：
# agent 1 在 49 次迭代中的资源申请量为: 48.972150689305266
# agent 2 在 49 次迭代中的资源申请量为: 61.689500587668604
# agent 3 在 49 次迭代中的资源申请量为: 44.310605235750174
# agent 4 在 49 次迭代中的资源申请量为: 65.2618606441399
# agent 5 在 49 次迭代中的资源申请量为: 66.06181235404227
# agent 6 在 49 次迭代中的资源申请量为: 72.90808501102426
# agent 7 在 49 次迭代中的资源申请量为: 39.92004629792294
# agent 8 在 49 次迭代中的资源申请量为: 35.11825276931141
# agent 9 在 49 次迭代中的资源申请量为: 43.61082578548364
# agent 10 在 49 次迭代中的资源申请量为: 56.44422086451037
# agent 11 在 49 次迭代中的资源申请量为: 46.01764556266931
# agent 12 在 49 次迭代中的资源申请量为: 49.872500986659055
# agent 13 在 49 次迭代中的资源申请量为: 66.56257130683512
# agent 14 在 49 次迭代中的资源申请量为: 55.84468587451039
# agent 15 在 49 次迭代中的资源申请量为: 44.01067444849649
# agent 16 在 49 次迭代中的资源申请量为: 44.210542059303364
# agent 17 在 49 次迭代中的资源申请量为: 45.41779802044964
# agent 18 在 49 次迭代中的资源申请量为: 47.0174264784857
# agent 19 在 49 次迭代中的资源申请量为: 41.79342826643499
# agent 20 在 49 次迭代中的资源申请量为: 56.345200908627724
# agent 21 在 49 次迭代中的资源申请量为: 33.35660711963992
# agent 22 在 49 次迭代中的资源申请量为: 39.520175896128016
# agent 23 在 49 次迭代中的资源申请量为: 48.37181295633416
# agent 24 在 49 次迭代中的资源申请量为: 40.99307838667903
# agent 25 在 49 次迭代中的资源申请量为: 45.717465596932115
# agent 26 在 49 次迭代中的资源申请量为: 40.22001056458713
# agent 27 在 49 次迭代中的资源申请量为: 66.26118664368407
# agent 28 在 49 次迭代中的资源申请量为: 51.948713992638474
# agent 29 在 49 次迭代中的资源申请量为: 41.29339222553788
# agent 30 在 49 次迭代中的资源申请量为: 39.6201580011385
# agent 31 在 49 次迭代中的资源申请量为: 61.08976447267044
# agent 32 在 49 次迭代中的资源申请量为: 56.14447019438364
# agent 33 在 49 次迭代中的资源申请量为: 42.09338102270313
# agent 34 在 49 次迭代中的资源申请量为: 52.84875291420188
# agent 35 在 49 次迭代中的资源申请量为: 30.323630260645032
# agent 36 在 49 次迭代中的资源申请量为: 43.31065705600847
# agent 37 在 49 次迭代中的资源申请量为: 53.14847123619437
# agent 38 在 49 次迭代中的资源申请量为: 40.79338460838201
# agent 39 在 49 次迭代中的资源申请量为: 43.81038264649826
# agent 40 在 49 次迭代中的资源申请量为: 50.67235299746895
# agent 41 在 49 次迭代中的资源申请量为: 66.9619343243426
# agent 42 在 49 次迭代中的资源申请量为: 43.01052264260814
# agent 43 在 49 次迭代中的资源申请量为: 52.34826714462569
# agent 44 在 49 次迭代中的资源申请量为: 53.54835352773635
# agent 45 在 49 次迭代中的资源申请量为: 48.77185457114215
# agent 46 在 49 次迭代中的资源申请量为: 56.44493225406646
# agent 47 在 49 次迭代中的资源申请量为: 46.41731936047165
# agent 48 在 49 次迭代中的资源申请量为: 33.34671731751604
# agent 49 在 49 次迭代中的资源申请量为: 43.21055133583534
# agent 50 在 49 次迭代中的资源申请量为: 41.39325481689651
# agent 51 在 49 次迭代中的资源申请量为: 48.87201397518403
# agent 52 在 49 次迭代中的资源申请量为: 56.344870792683935
# agent 53 在 49 次迭代中的资源申请量为: 32.02145877964283
# agent 54 在 49 次迭代中的资源申请量为: 57.54475916362444
# agent 55 在 49 次迭代中的资源申请量为: 71.8086749865132
# agent 56 在 49 次迭代中的资源申请量为: 41.393397109712325
# agent 57 在 49 次迭代中的资源申请量为: 61.09064041440434
# agent 58 在 49 次迭代中的资源申请量为: 42.71072809680914
# agent 59 在 49 次迭代中的资源申请量为: 48.47216126325729
# agent 60 在 49 次迭代中的资源申请量为: 56.64449913512382
# agent 61 在 49 次迭代中的资源申请量为: 66.66114358068477
# agent 62 在 49 次迭代中的资源申请量为: 46.61730462516238
# agent 63 在 49 次迭代中的资源申请量为: 39.41995898491001
# agent 64 在 49 次迭代中的资源申请量为: 44.91745169300702
# agent 65 在 49 次迭代中的资源申请量为: 43.210465595745475
# agent 66 在 49 次迭代中的资源申请量为: 66.3618164017531
# agent 67 在 49 次迭代中的资源申请量为: 33.679902963413085
# agent 68 在 49 次迭代中的资源申请量为: 45.41736259091418
# agent 69 在 49 次迭代中的资源申请量为: 45.917329576759144
# agent 70 在 49 次迭代中的资源申请量为: 60.689685245668926
# agent 71 在 49 次迭代中的资源申请量为: 72.80758356124089
# agent 72 在 49 次迭代中的资源申请量为: 44.900847435016466
# agent 73 在 49 次迭代中的资源申请量为: 44.21045259104754
# agent 74 在 49 次迭代中的资源申请量为: 39.4199001253543
# agent 75 在 49 次迭代中的资源申请量为: 52.54809470742028
# agent 76 在 49 次迭代中的资源申请量为: 47.51710687773878
# agent 77 在 49 次迭代中的资源申请量为: 41.29315635697116
# agent 78 在 49 次迭代中的资源申请量为: 50.172129376892094
# agent 79 在 49 次迭代中的资源申请量为: 43.310530679745966
# agent 80 在 49 次迭代中的资源申请量为: 43.51035423200606
# agent 81 在 49 次迭代中的资源申请量为: 39.91990328011425
# agent 82 在 49 次迭代中的资源申请量为: 46.21780819923958
# agent 83 在 49 次迭代中的资源申请量为: 42.09340304690209
# agent 84 在 49 次迭代中的资源申请量为: 52.648857003682444
# agent 85 在 49 次迭代中的资源申请量为: 56.34429957350322
# agent 86 在 49 次迭代中的资源申请量为: 49.4721760207395
# agent 87 在 49 次迭代中的资源申请量为: 61.08993020527054
# agent 88 在 49 次迭代中的资源申请量为: 65.86207238627783
# agent 89 在 49 次迭代中的资源申请量为: 30.793807952242613
# agent 90 在 49 次迭代中的资源申请量为: 59.889388563299434
# agent 91 在 49 次迭代中的资源申请量为: 43.41044575621855
# agent 92 在 49 次迭代中的资源申请量为: 57.5447984589868
# agent 93 在 49 次迭代中的资源申请量为: 41.19342560325084
# agent 94 在 49 次迭代中的资源申请量为: 54.53641297447562
# agent 95 在 49 次迭代中的资源申请量为: 60.98933596420323
# agent 96 在 49 次迭代中的资源申请量为: 61.18962171119886
# agent 97 在 49 次迭代中的资源申请量为: 73.00797314430375
# agent 98 在 49 次迭代中的资源申请量为: 73.80893643068559
# agent 99 在 49 次迭代中的资源申请量为: 53.04819387995207
# agent 100 在 49 次迭代中的资源申请量为: 49.07203868771915
# 资源申请量总和为: 4999.999999999999
# ****************************************************************************
# 成本总和为: 335544.9510289824
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: 48.923208670622905
# agent 2 在 99 次迭代中的资源申请量为: 61.62113799023729
# agent 3 在 99 次迭代中的资源申请量为: 44.26771546421131
# agent 4 在 99 次迭代中的资源申请量为: 65.19777056323879
# agent 5 在 99 次迭代中的资源申请量为: 65.99547247859613
# agent 6 在 99 次迭代中的资源申请量为: 72.83599464294151
# agent 7 在 99 次迭代中的资源申请量为: 39.88243747869983
# agent 8 在 99 次迭代中的资源申请量为: 34.84801718500934
# agent 9 在 99 次迭代中的资源申请量为: 43.568247091122586
# agent 10 在 99 次迭代中的资源申请量为: 56.38711927856287
# agent 11 在 99 次迭代中的资源申请量为: 45.973783848869196
# agent 12 在 99 次迭代中的资源申请量为: 49.82632367287013
# agent 13 在 99 次迭代中的资源申请量为: 66.50017718285748
# agent 14 在 99 次迭代中的资源申请量为: 55.793585436833624
# agent 15 在 99 次迭代中的资源申请量为: 43.96945178758732
# agent 16 在 99 次迭代中的资源申请量为: 44.16928293114855
# agent 17 在 99 次迭代中的资源申请量为: 45.37300760001362
# agent 18 在 99 次迭代中的资源申请量为: 46.97363198826828
# agent 19 在 99 次迭代中的资源申请量为: 41.75307899734972
# agent 20 在 99 次迭代中的资源申请量为: 56.292677147135414
# agent 21 在 99 次迭代中的资源申请量为: 33.14426039605711
# agent 22 在 99 次迭代中的资源申请量为: 39.48288778666821
# agent 23 在 99 次迭代中的资源申请量为: 48.323438392308454
# agent 24 在 99 次迭代中的资源申请量为: 40.95234029934964
# agent 25 在 99 次迭代中的资源申请量为: 45.673963865226
# agent 26 在 99 次迭代中的资源申请量为: 40.18240765646983
# agent 27 在 99 次迭代中的资源申请量为: 66.1886664934079
# agent 28 在 99 次迭代中的资源申请量为: 51.89629770440857
# agent 29 在 99 次迭代中的资源申请量为: 41.25101914912697
# agent 30 在 99 次迭代中的资源申请量为: 39.58200476594556
# agent 31 在 99 次迭代中的资源申请量为: 61.02820840826786
# agent 32 在 99 次迭代中的资源申请量为: 56.09194930579454
# agent 33 在 99 次迭代中的资源申请量为: 42.05373466630866
# agent 34 在 99 次迭代中的资源申请量为: 52.79773139255818
# agent 35 在 99 次迭代中的资源申请量为: 30.59157849286896
# agent 36 在 99 次迭代中的资源申请量为: 43.26674684702557
# agent 37 在 99 次迭代中的资源申请量为: 53.0933119273768
# agent 38 在 99 次迭代中的资源申请量为: 40.75397918401838
# agent 39 在 99 次迭代中的资源申请量为: 43.766943021678856
# agent 40 在 99 次迭代中的资源申请量为: 50.62683361367605
# agent 41 在 99 次迭代中的资源申请量为: 66.89308867615244
# agent 42 在 99 次迭代中的资源申请量为: 42.96493558845682
# agent 43 在 99 次迭代中的资源申请量为: 52.2951684129204
# agent 44 在 99 次迭代中的资源申请量为: 53.497022031109495
# agent 45 在 99 次迭代中的资源申请量为: 48.724222415021615
# agent 46 在 99 次迭代中的资源申请量为: 56.386992053214264
# agent 47 在 99 次迭代中的资源申请量为: 46.369288966776736
# agent 48 在 99 次迭代中的资源申请量为: 33.92830434652464
# agent 49 在 99 次迭代中的资源申请量为: 43.16473137692346
# agent 50 在 99 次迭代中的资源申请量为: 41.35302794993221
# agent 51 在 99 次迭代中的资源申请量为: 48.82142817455587
# agent 52 在 99 次迭代中的资源申请量为: 56.291371473078534
# agent 53 在 99 次迭代中的资源申请量为: 31.914418822662846
# agent 54 在 99 次迭代中的资源申请量为: 57.491425730659664
# agent 55 在 99 次迭代中的资源申请量为: 71.74387556548852
# agent 56 在 99 次迭代中的资源申请量为: 41.35483316578021
# agent 57 在 99 次迭代中的资源申请量为: 61.033720165792175
# agent 58 在 99 次迭代中的资源申请量为: 42.66639228412999
# agent 59 在 99 次迭代中的资源申请量为: 48.425916196136086
# agent 60 在 99 次迭代中的资源申请量为: 56.587667801879476
# agent 61 在 99 次迭代中的资源申请量为: 66.59223871331943
# agent 62 在 99 次迭代中的资源申请量为: 46.567775182850426
# agent 63 在 99 次迭代中的资源申请量为: 39.38010713435409
# agent 64 在 99 次迭代中的资源申请量为: 44.86969077994188
# agent 65 在 99 次迭代中的资源申请量为: 43.16737651311269
# agent 66 在 99 次迭代中的资源申请量为: 66.29059237181201
# agent 67 在 99 次迭代中的资源申请量为: 33.99933821452581
# agent 68 在 99 次迭代中的资源申请量为: 45.370481481096014
# agent 69 在 99 次迭代中的资源申请量为: 45.871138698217045
# agent 70 在 99 次迭代中的资源申请量为: 60.62600094113437
# agent 71 在 99 次迭代中的资源申请量为: 72.73167319192757
# agent 72 在 99 次迭代中的资源申请量为: 46.36854679674203
# agent 73 在 99 次迭代中的资源申请量为: 44.16406901180722
# agent 74 在 99 次迭代中的资源申请量为: 39.37911759778562
# agent 75 在 99 次迭代中的资源申请量为: 52.487920926454116
# agent 76 在 99 次迭代中的资源申请量为: 47.466129574716405
# agent 77 在 99 次迭代中的资源申请量为: 41.24780304004285
# agent 78 在 99 次迭代中的资源申请量为: 50.124721231495776
# agent 79 在 99 次迭代中的资源申请量为: 43.268252391458034
# agent 80 在 99 次迭代中的资源申请量为: 43.46455410717679
# agent 81 在 99 次迭代中的资源申请量为: 39.880670962724636
# agent 82 在 99 次迭代中的资源申请量为: 46.173973681794486
# agent 83 在 99 次迭代中的资源申请量为: 42.053792717325734
# agent 84 在 99 次迭代中的资源申请量为: 52.59767702938017
# agent 85 在 99 次迭代中的资源申请量为: 56.286496041312375
# agent 86 在 99 次迭代中的资源申请量为: 49.42342690548912
# agent 87 在 99 次迭代中的资源申请量为: 61.02508249238784
# agent 88 在 99 次迭代中的资源申请量为: 65.79003558928385
# agent 89 在 99 次迭代中的资源申请量为: 31.642087304915737
# agent 90 在 99 次迭代中的资源申请量为: 59.823290679314596
# agent 91 在 99 次迭代中的资源申请量为: 43.365848839160726
# agent 92 在 99 次迭代中的资源申请量为: 57.49120251713321
# agent 93 在 99 次迭代中的资源申请量为: 41.15342357833513
# agent 94 在 99 次迭代中的资源申请量为: 56.31519882460384
# agent 95 在 99 次迭代中的资源申请量为: 60.91323212159413
# agent 96 在 99 次迭代中的资源申请量为: 61.1252154782739
# agent 97 在 99 次迭代中的资源申请量为: 72.93725198587809
# agent 98 在 99 次迭代中的资源申请量为: 73.73690678783547
# agent 99 在 99 次迭代中的资源申请量为: 52.99495251969221
# agent 100 在 99 次迭代中的资源申请量为: 49.02445004168069
# 资源申请量总和为: 5000.000000000001
# ****************************************************************************
# 成本总和为: 335366.7098673125
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 149 次迭代中的结果：
# agent 1 在 149 次迭代中的资源申请量为: 48.83935904523791
# agent 2 在 149 次迭代中的资源申请量为: 61.523673555166404
# agent 3 在 149 次迭代中的资源申请量为: 44.19351683877136
# agent 4 在 149 次迭代中的资源申请量为: 65.08048636129818
# agent 5 在 149 次迭代中的资源申请量为: 65.88024915704437
# agent 6 在 149 次迭代中的资源申请量为: 72.70879464604648
# agent 7 在 149 次迭代中的资源申请量为: 39.815244945309196
# agent 8 在 149 次迭代中的资源申请量为: 34.42246008374945
# agent 9 在 149 次迭代中的资源申请量为: 43.493703776554426
# agent 10 在 149 次迭代中的资源申请量为: 56.290788665573565
# agent 11 在 149 次迭代中的资源申请量为: 45.89307484601787
# agent 12 在 149 次迭代中的资源申请量为: 49.73977597331115
# agent 13 在 149 次迭代中的资源申请量为: 66.38184203197895
# agent 14 在 149 次迭代中的资源申请量为: 55.691967936415914
# agent 15 在 149 次迭代中的资源申请量为: 43.89355359603948
# agent 16 在 149 次迭代中的资源申请量为: 44.09346164406427
# agent 17 在 149 次迭代中的资源申请量为: 45.29334590671508
# agent 18 在 149 次迭代中的资源申请量为: 46.89319139255983
# agent 19 在 149 次迭代中的资源申请量为: 41.68286041372692
# agent 20 在 149 次迭代中的资源申请量为: 56.19190292786128
# agent 21 在 149 次迭代中的资源申请量为: 32.82688264712227
# agent 22 在 149 次迭代中的资源申请量为: 39.4153192745172
# agent 23 在 149 次迭代中的资源申请量为: 48.23904187258285
# agent 24 在 149 次迭代中的资源申请量为: 40.88241501216092
# agent 25 在 149 次迭代中的资源申请量为: 45.59300591795352
# agent 26 在 149 次迭代中的资源申请量为: 40.11518133429301
# agent 27 在 149 次迭代中的资源申请量为: 66.0804008653251
# agent 28 在 149 次迭代中的资源申请量为: 51.80645147067932
# agent 29 在 149 次迭代中的资源申请量为: 41.18289093700689
# agent 30 在 149 次迭代中的资源申请量为: 39.51541035775665
# agent 31 在 149 次迭代中的资源申请量为: 60.92345381169313
# agent 32 在 149 次迭代中的资源申请量为: 55.991447251829534
# agent 33 在 149 次迭代中的资源申请量为: 41.982762418496975
# agent 34 在 149 次迭代中的资源申请量为: 52.706488820444065
# agent 35 在 149 次迭代中的资源申请量为: 31.757249554590505
# agent 36 在 149 次迭代中的资源申请量为: 43.19335699025094
# agent 37 在 149 次迭代中的资源申请量为: 53.006029955758265
# agent 38 在 149 次迭代中的资源申请量为: 40.68278454091077
# agent 39 在 149 次迭代中的资源申请量为: 43.69324651489023
# agent 40 在 149 次迭代中的资源申请量为: 50.53953213069863
# agent 41 在 149 次迭代中的资源申请量为: 66.78052730898509
# agent 42 在 149 次迭代中的资源申请量为: 42.89342462520906
# agent 43 在 149 次迭代中的资源申请量为: 52.20601293132556
# agent 44 在 149 次迭代中的资源申请量为: 53.40615979143225
# agent 45 在 149 次迭代中的资源申请量为: 48.639102579456676
# agent 46 在 149 次迭代中的资源申请量为: 56.2917904390635
# agent 47 在 149 次迭代中的资源申请量为: 46.292766599233026
# agent 48 在 149 次迭代中的资源申请量为: 35.19583005449306
# agent 49 在 149 次迭代中的资源申请量为: 43.093307989526444
# agent 50 在 149 次迭代中的资源申请量为: 41.282743580836865
# agent 51 在 149 次迭代中的资源申请量为: 48.739001462237695
# agent 52 在 149 次迭代中的资源申请量为: 56.19182254825976
# agent 53 在 149 次迭代中的资源申请量为: 32.05651107145882
# agent 54 在 149 次迭代中的资源申请量为: 57.391953328342524
# agent 55 在 149 次迭代中的资源申请量为: 71.61040985054196
# agent 56 在 149 次迭代中的资源申请量为: 41.28297795090017
# agent 57 在 149 次迭代中的资源申请量为: 60.92478828709699
# agent 58 在 149 次迭代中的资源申请量为: 42.593677769356376
# agent 59 在 149 次迭代中的资源申请量为: 48.33948574587152
# agent 60 在 149 次迭代中的资源申请量为: 56.49150552516406
# agent 61 在 149 次迭代中的资源申请量为: 66.48043851308199
# agent 62 在 149 次迭代中的资源申请量为: 46.492904313853074
# agent 63 在 149 次迭代中的资源申请量为: 39.315014472031045
# agent 64 在 149 次迭代中的资源申请量为: 44.79258355008813
# agent 65 在 149 次迭代中的资源申请量为: 43.09320482072949
# agent 66 在 149 次迭代中的资源申请量为: 66.18026610248998
# agent 67 在 149 次迭代中的资源申请量为: 35.21673883340548
# agent 68 在 149 次迭代中的资源申请量为: 45.292651611002576
# agent 69 在 149 次迭代中的资源申请量为: 45.79274214389944
# agent 70 在 149 次迭代中的资源申请量为: 60.52340035213085
# agent 71 在 149 次迭代中的资源申请量为: 72.60818698155099
# agent 72 在 149 次迭代中的资源申请量为: 48.04107487863854
# agent 73 在 149 次迭代中的资源申请量为: 44.09338309321058
# agent 74 在 149 次迭代中的资源申请量为: 39.31512759682109
# agent 75 在 149 次迭代中的资源申请量为: 52.40563172036485
# agent 76 在 149 次迭代中的资源申请量为: 47.39249469139805
# agent 77 在 149 次迭代中的资源申请量为: 41.18243075387591
# agent 78 在 149 次迭代中的资源申请量为: 50.039453743892466
# agent 79 在 149 次迭代中的资源申请量为: 43.19356488904374
# agent 80 在 149 次迭代中的资源申请量为: 43.39313883974929
# agent 81 在 149 次迭代中的资源申请量为: 39.815155612924954
# agent 82 在 149 次迭代中的资源申请量为: 46.09331062229815
# agent 83 在 149 次迭代中的资源申请量为: 41.98277780232641
# agent 84 在 149 次迭代中的资源申请量为: 52.50662673160607
# agent 85 在 149 次迭代中的资源申请量为: 56.19095695867305
# agent 86 在 149 次迭代中的资源申请量为: 49.339351765970314
# agent 87 在 149 次迭代中的资源申请量为: 60.92381036017695
# agent 88 在 149 次迭代中的资源申请量为: 65.68032592443289
# agent 89 在 149 次迭代中的资源申请量为: 32.927754333890505
# agent 90 在 149 次迭代中的资源申请量为: 59.72316691110674
# agent 91 在 149 次迭代中的资源申请量为: 43.2933429775355
# agent 92 在 149 次迭代中的资源申请量为: 57.39180534807223
# agent 93 在 149 次迭代中的资源申请量为: 41.08288166846454
# agent 94 在 149 次迭代中的资源申请量为: 58.25536887669955
# agent 95 在 149 次迭代中的资源申请量为: 60.82281766897862
# agent 96 在 149 次迭代中的资源申请量为: 61.023072129404376
# agent 97 在 149 次迭代中的资源申请量为: 72.8086058547311
# agent 98 在 149 次迭代中的资源申请量为: 73.60910578917604
# agent 99 在 149 次迭代中的资源申请量为: 52.90581682975582
# agent 100 在 149 次迭代中的资源申请量为: 48.93910907132405
# 资源申请量总和为: 5000.000000000002
# ****************************************************************************
# 成本总和为: 335103.7833170215
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: 48.803039569750084
# agent 2 在 199 次迭代中的资源申请量为: 61.478799876065175
# agent 3 在 199 次迭代中的资源申请量为: 44.16150554323061
# agent 4 在 199 次迭代中的资源申请量为: 65.03141500384962
# agent 5 在 199 次迭代中的资源申请量为: 65.83141484876572
# agent 6 在 199 次迭代中的资源申请量为: 72.65455577918499
# agent 7 在 199 次迭代中的资源申请量为: 39.786610194146434
# agent 8 在 199 次迭代中的资源申请量为: 34.23875790028548
# agent 9 在 199 次迭代中的资源申请量为: 43.4615066471209
# agent 10 在 199 次迭代中的资源申请量为: 56.24965996862965
# agent 11 在 199 次迭代中的资源申请量为: 45.85909894096239
# agent 12 在 199 次迭代中的资源申请量为: 49.70304036657608
# agent 13 在 199 次迭代中的资源申请量为: 66.33142074502464
# agent 14 在 199 次迭代中的资源申请量为: 55.649660417512
# agent 15 在 199 次迭代中的资源申请量为: 43.86150488250297
# agent 16 在 199 次迭代中的资源申请量为: 44.061503930633556
# agent 17 在 199 次迭代中的资源申请量为: 45.25910008614833
# agent 18 在 199 次迭代中的资源申请量为: 46.859098836805146
# agent 19 在 199 次迭代中的资源申请量为: 41.65253353891119
# agent 20 在 199 次迭代中的资源申请量为: 56.14966149694064
# agent 21 在 199 次迭代中的资源申请量为: 32.6921165702058
# agent 22 在 199 次迭代中的资源申请量为: 39.38661041499378
# agent 23 在 199 次迭代中的资源申请量为: 48.20303871324302
# agent 24 在 199 次迭代中的资源申请量为: 40.85253166055294
# agent 25 在 199 次迭代中的资源申请量为: 45.559098618801414
# agent 26 在 199 次迭代中的资源申请量为: 40.086610178080086
# agent 27 在 199 次迭代中的资源申请量为: 66.03141765782286
# agent 28 在 199 次迭代中的资源申请量为: 51.76754314165247
# agent 29 在 199 次迭代中的资源申请量为: 41.15253356975525
# agent 30 在 199 次迭代中的资源申请量为: 39.48661070704027
# agent 31 在 199 次迭代中的资源申请量为: 60.8787985097928
# agent 32 在 199 次迭代中的资源申请量为: 55.94965884922317
# agent 33 在 199 次迭代中的资源申请量为: 41.95253328031465
# agent 34 在 199 次迭代中的资源申请量为: 52.66754261405144
# agent 35 在 199 次迭代中的资源申请量为: 32.179023354451
# agent 36 在 199 次迭代中的资源申请量为: 43.16150532566069
# agent 37 在 199 次迭代中的资源申请量为: 52.96754184241776
# agent 38 在 199 次迭代中的资源申请量为: 40.652532766134556
# agent 39 在 199 次迭代中的资源申请量为: 43.66150487435094
# agent 40 在 199 次迭代中的资源申请量为: 50.503040344401896
# agent 41 在 199 次迭代中的资源申请量为: 66.73141946517767
# agent 42 在 199 次迭代中的资源申请量为: 42.86150576274401
# agent 43 在 199 次迭代中的资源申请量为: 52.16754053630888
# agent 44 在 199 次迭代中的资源申请量为: 53.36754088224432
# agent 45 在 199 次迭代中的资源申请量为: 48.60303835408138
# agent 46 在 199 次迭代中的资源申请量为: 56.24966245415611
# agent 47 在 199 次迭代中的资源申请量为: 46.2590995980697
# agent 48 在 199 次迭代中的资源申请量为: 35.680985321559575
# agent 49 在 199 次迭代中的资源申请量为: 43.06150525502747
# agent 50 在 199 次迭代中的资源申请量为: 41.252532551272346
# agent 51 在 199 次迭代中的资源申请量为: 48.703040167568936
# agent 52 在 199 次迭代中的资源申请量为: 56.149662952384105
# agent 53 在 199 次迭代中的资源申请量为: 32.334770720754854
# agent 54 在 199 次迭代中的资源申请量为: 57.349662343907085
# agent 55 在 199 次迭代中的资源申请量为: 71.55456364101751
# agent 56 在 199 次迭代中的资源申请量为: 41.25253299843547
# agent 57 在 199 次迭代中的资源申请量为: 60.878801999827786
# agent 58 在 199 次迭代中的资源申请量为: 42.561506484132785
# agent 59 在 199 次迭代中的资源申请量为: 48.30303957509946
# agent 60 在 199 次迭代中的资源申请量为: 56.44966103815239
# agent 61 在 199 次迭代中的资源申请量为: 66.4314161614686
# agent 62 在 199 次迭代中的资源申请量为: 46.459099285694684
# agent 63 在 199 次迭代中的资源申请量为: 39.28661001583845
# agent 64 在 199 次迭代中的资源申请量为: 44.75909924200532
# agent 65 在 199 次迭代中的资源申请量为: 43.061504192751784
# agent 66 在 199 次迭代中的资源申请量为: 66.1314171938195
# agent 67 在 199 次迭代中的资源申请量为: 35.668546629055975
# agent 68 在 199 次迭代中的资源申请量为: 45.25909864466379
# agent 69 在 199 次迭代中的资源申请量为: 45.7590982651983
# agent 70 在 199 次迭代中的资源申请量为: 60.47879799943879
# agent 71 在 199 次迭代中的资源申请量为: 72.55455619158431
# agent 72 在 199 次迭代中的资源申请量为: 48.79549038338694
# agent 73 在 199 次迭代中的资源申请量为: 44.061505737822934
# agent 74 在 199 次迭代中的资源申请量为: 39.286610246484365
# agent 75 在 199 次迭代中的资源申请量为: 52.36754204438684
# agent 76 在 199 次迭代中的资源申请量为: 47.359098921601316
# agent 77 在 199 次迭代中的资源申请量为: 41.15253285575995
# agent 78 在 199 次迭代中的资源申请量为: 50.003039956406305
# agent 79 在 199 次迭代中的资源申请量为: 43.16150586817223
# agent 80 在 199 次迭代中的资源申请量为: 43.361504478870046
# agent 81 在 199 次迭代中的资源申请量为: 39.78660988066506
# agent 82 在 199 次迭代中的资源申请量为: 46.05910027940762
# agent 83 在 199 次迭代中的资源申请量为: 41.95253306681643
# agent 84 在 199 次迭代中的资源申请量为: 52.46754296753477
# agent 85 在 199 次迭代中的资源申请量为: 56.149659264250374
# agent 86 在 199 次迭代中的资源申请量为: 49.30304034654437
# agent 87 在 199 次迭代中的资源申请量为: 60.8788006992332
# agent 88 在 199 次迭代中的资源申请量为: 65.63141913456205
# agent 89 在 199 次迭代中的资源申请量为: 33.38935356004533
# agent 90 在 199 次迭代中的资源申请量为: 59.67879814426784
# agent 91 在 199 次迭代中的资源申请量为: 43.26150527856764
# agent 92 在 199 次迭代中的资源申请量为: 57.3496609726506
# agent 93 在 199 次迭代中的资源申请量为: 41.052532784688054
# agent 94 在 199 次迭代中的资源申请量为: 59.15632461798622
# agent 95 在 199 次迭代中的资源申请量为: 60.77880023249525
# agent 96 在 199 次迭代中的资源申请量为: 60.97879762801733
# agent 97 在 199 次迭代中的资源申请量为: 72.75455398208852
# agent 98 在 199 次迭代中的资源申请量为: 73.55456006548177
# agent 99 在 199 次迭代中的资源申请量为: 52.86754043068035
# agent 100 在 199 次迭代中的资源申请量为: 48.90303868169258
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 335002.0309322838
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 249 次迭代中的结果：
# agent 1 在 249 次迭代中的资源申请量为: 48.74383474265925
# agent 2 在 249 次迭代中的资源申请量为: 61.37355505286015
# agent 3 在 249 次迭代中的资源申请量为: 44.110538551446865
# agent 4 在 249 次迭代中的资源申请量为: 64.9786497506952
# agent 5 在 249 次迭代中的资源申请量为: 65.75782641312813
# agent 6 在 249 次迭代中的资源申请量为: 72.58666381681208
# agent 7 在 249 次迭代中的资源申请量为: 39.744398716450036
# agent 8 在 249 次迭代中的资源申请量为: 34.053265238901275
# agent 9 在 249 次迭代中的资源申请量为: 43.39832350625402
# agent 10 在 249 次迭代中的资源申请量为: 56.189227629622856
# agent 11 在 249 次迭代中的资源申请量为: 45.79689452359577
# agent 12 在 249 次迭代中的资源申请量为: 49.64181359974164
# agent 13 在 249 次迭代中的资源申请量为: 66.26808218429814
# agent 14 在 249 次迭代中的资源申请量为: 55.61478915410464
# agent 15 在 249 次迭代中的资源申请量为: 43.82333266560445
# agent 16 在 249 次迭代中的资源申请量为: 44.03261111644754
# agent 17 在 249 次迭代中的资源申请量为: 45.19190869212594
# agent 18 在 249 次迭代中的资源申请量为: 46.8208076733666
# agent 19 在 249 次迭代中的资源申请量为: 41.59890429264548
# agent 20 在 249 次迭代中的资源申请量为: 56.08257364953808
# agent 21 在 249 次迭代中的资源申请量为: 32.99714300238262
# agent 22 在 249 次迭代中的资源申请量为: 39.33915109831822
# agent 23 在 249 次迭代中的资源申请量为: 48.16081493166188
# agent 24 在 249 次迭代中的资源申请量为: 40.81729959276583
# agent 25 在 249 次迭代中的资源申请量为: 45.52400113909643
# agent 26 在 249 次迭代中的资源申请量为: 40.042392683586655
# agent 27 在 249 次迭代中的资源申请量为: 65.94932962251124
# agent 28 在 249 次迭代中的资源申请量为: 51.717731214916924
# agent 29 在 249 次迭代中的资源申请量为: 41.08779151023206
# agent 30 在 249 次迭代中的资源申请量为: 39.44063871552578
# agent 31 在 249 次迭代中的资源申请量为: 60.81354133075638
# agent 32 在 249 次迭代中的资源申请量为: 55.9209325128963
# agent 33 在 249 次迭代中的资源申请量为: 41.91886102298327
# agent 34 在 249 次迭代中的资源申请量为: 52.5928684190052
# agent 35 在 249 次迭代中的资源申请量为: 32.89042764663583
# agent 36 在 249 次迭代中的资源申请量为: 43.097447606602955
# agent 37 在 249 次迭代中的资源申请量为: 52.89757475658366
# agent 38 在 249 次迭代中的资源申请量为: 40.620702385624206
# agent 39 在 249 次迭代中的资源申请量为: 43.62335060184634
# agent 40 在 249 次迭代中的资源申请量为: 50.45180739462291
# agent 41 在 249 次迭代中的资源申请量为: 66.63526427055776
# agent 42 在 249 次迭代中的资源申请量为: 42.7947579336188
# agent 43 在 249 次迭代中的资源申请量为: 52.12500527536615
# agent 44 在 249 次迭代中的资源申请量为: 53.31564070997649
# agent 45 在 249 次迭代中的资源申请量为: 48.565347770214046
# agent 46 在 249 次迭代中的资源申请量为: 56.151395514544475
# agent 47 在 249 次迭代中的资源申请量为: 46.20096916782219
# agent 48 在 249 次迭代中的资源申请量为: 36.43861788390802
# agent 49 在 249 次迭代中的资源申请量为: 42.98607788935197
# agent 50 在 249 次迭代中的资源申请量为: 41.218128490904455
# agent 51 在 249 次迭代中的资源申请量为: 48.632803859748755
# agent 52 在 249 次迭代中的资源申请量为: 56.095588884893196
# agent 53 在 249 次迭代中的资源申请量为: 32.96641281624213
# agent 54 在 249 次迭代中的资源申请量为: 57.295136099558576
# agent 55 在 249 次迭代中的资源申请量为: 71.52061218682272
# agent 56 在 249 次迭代中的资源申请量为: 41.22365878138949
# agent 57 在 249 次迭代中的资源申请量为: 60.798636172348886
# agent 58 在 249 次迭代中的资源申请量为: 42.49156952025259
# agent 59 在 249 次迭代中的资源申请量为: 48.2411879176916
# agent 60 在 249 次迭代中的资源申请量为: 56.376627939935574
# agent 61 在 249 次迭代中的资源申请量为: 66.3609447802919
# agent 62 在 249 次迭代中的资源申请量为: 46.38425910669721
# agent 63 在 249 次迭代中的资源申请量为: 39.23025269226756
# agent 64 在 249 次迭代中的资源申请量为: 44.69401302125275
# agent 65 在 249 次迭代中的资源申请量为: 43.025904560769604
# agent 66 在 249 次迭代中的资源申请量为: 66.00974436478306
# agent 67 在 249 次迭代中的资源申请量为: 36.40431144487132
# agent 68 在 249 次迭代中的资源申请量为: 45.19864463117328
# agent 69 在 249 次迭代中的资源申请量为: 45.718094271154705
# agent 70 在 249 次迭代中的资源申请量为: 60.41502714326193
# agent 71 在 249 次迭代中的资源申请量为: 72.44873840337566
# agent 72 在 249 次迭代中的资源申请量为: 49.66812497945373
# agent 73 在 249 次迭代中的资源申请量为: 43.99017149085047
# agent 74 在 249 次迭代中的资源申请量为: 39.225853380680704
# agent 75 在 249 次迭代中的资源申请量为: 52.262485810610436
# agent 76 在 249 次迭代中的资源申请量为: 47.291810901018195
# agent 77 在 249 次迭代中的资源申请量为: 41.08013884216943
# agent 78 在 249 次迭代中的资源申请量为: 49.966170761291615
# agent 79 在 249 次迭代中的资源申请量为: 43.11663509903294
# agent 80 在 249 次迭代中的资源申请量为: 43.30768112087698
# agent 81 在 249 次迭代中的资源申请量为: 39.73968917442299
# agent 82 在 249 次迭代中的资源申请量为: 46.00605375251543
# agent 83 在 249 次迭代中的资源申请量为: 41.916293173802494
# agent 84 在 249 次迭代中的资源申请量为: 52.40765951775509
# agent 85 在 249 次迭代中的资源申请量为: 56.0994525865612
# agent 86 在 249 次迭代中的资源申请量为: 49.23297073319529
# agent 87 在 249 次迭代中的资源申请量为: 60.76441605492322
# agent 88 在 249 次迭代中的资源申请量为: 65.51033557583058
# agent 89 在 249 次迭代中的资源申请量为: 34.137100453645054
# agent 90 在 249 次迭代中的资源申请量为: 59.606514504148215
# agent 91 在 249 次迭代中的资源申请量为: 43.20655592098132
# agent 92 在 249 次迭代中的资源申请量为: 57.2973517969186
# agent 93 在 249 次迭代中的资源申请量为: 41.00513553064103
# agent 94 在 249 次迭代中的资源申请量为: 60.10681225693348
# agent 95 在 249 次迭代中的资源申请量为: 60.61847944938113
# agent 96 在 249 次迭代中的资源申请量为: 60.904507662442
# agent 97 在 249 次迭代中的资源申请量为: 72.7092935394065
# agent 98 在 249 次迭代中的资源申请量为: 73.46806659403012
# agent 99 在 249 次迭代中的资源申请量为: 52.82775055659242
# agent 100 在 249 次迭代中的资源申请量为: 48.851307115990124
# 资源申请量总和为: 5000.000000000002
# ****************************************************************************
# 成本总和为: 334855.47727107676
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 299 次迭代中的结果：
# agent 1 在 299 次迭代中的资源申请量为: 48.72716313579519
# agent 2 在 299 次迭代中的资源申请量为: 61.38393918433152
# agent 3 在 299 次迭代中的资源申请量为: 44.09455301091841
# agent 4 在 299 次迭代中的资源申请量为: 64.9278938530518
# agent 5 在 299 次迭代中的资源申请量为: 65.72789437766455
# agent 6 在 299 次迭代中的资源申请量为: 72.5407200295777
# agent 7 在 299 次迭代中的资源申请量为: 39.72670725813332
# agent 8 在 299 次迭代中的资源申请量为: 33.88720332575179
# agent 9 在 299 次迭代中的资源申请量为: 43.39457588515096
# agent 10 在 299 次迭代中的资源申请量为: 56.16206013428112
# agent 11 在 299 次迭代中的资源申请量为: 45.78795337233514
# agent 12 在 299 次迭代中的资源申请量为: 49.627193916829484
# agent 13 在 299 次迭代中的资源申请量为: 66.22802836153335
# agent 14 在 299 次迭代中的资源申请量为: 55.56210418820059
# agent 15 在 299 次迭代中的资源申请量为: 43.79454461578809
# agent 16 在 299 次迭代中的资源申请量为: 43.99453458102305
# agent 17 在 299 次迭代中的资源申请量为: 45.1879819416717
# agent 18 在 299 次迭代中的资源申请量为: 46.78795779098519
# agent 19 在 299 次迭代中的资源申请量为: 41.589313481028924
# agent 20 在 299 次迭代中的资源申请量为: 56.06213661429783
# agent 21 在 299 次迭代中的资源申请量为: 32.980286617536414
# agent 22 在 299 次迭代中的资源申请量为: 39.32671271489704
# agent 23 在 299 次迭代中的资源申请量为: 48.12713394227509
# agent 24 在 299 次迭代中的资源申请量为: 40.78926682874017
# agent 25 在 299 次迭代中的资源申请量为: 45.487943649476925
# agent 26 在 299 次迭代中的资源申请量为: 40.02670246353844
# agent 27 在 299 次迭代中的资源申请量为: 65.92793617063228
# agent 28 在 299 次迭代中的资源申请量为: 51.68626506511883
# agent 29 在 299 次迭代中的资源申请量为: 41.08931361567116
# agent 30 在 299 次迭代中的资源申请量为: 39.426719845980806
# agent 31 在 299 次迭代中的资源申请量为: 60.78391265876089
# agent 32 在 299 次迭代中的资源申请量为: 55.86206885858702
# agent 33 在 299 次迭代中的资源申请量为: 41.8893078159154
# agent 34 在 299 次迭代中的资源申请量为: 52.586247277470505
# agent 35 在 299 次迭代中的资源申请量为: 33.0277164760315
# agent 36 在 299 次迭代中的资源申请量为: 43.094553163135785
# agent 37 在 299 次迭代中的资源申请量为: 52.88623000863151
# agent 38 在 299 次迭代中的资源申请量为: 40.589297825960806
# agent 39 在 299 次迭代中的资源申请量为: 43.59453667823702
# agent 40 在 299 次迭代中的资源申请量为: 50.42717966227724
# agent 41 在 299 次迭代中的资源申请量为: 66.62797502243646
# agent 42 在 299 次迭代中的资源申请量为: 42.79455618435767
# agent 43 在 299 次迭代中的资源申请量为: 52.08620735249313
# agent 44 在 299 次迭代中的资源申请量为: 53.28621420175105
# agent 45 在 299 次迭代中的资源申请量为: 48.52713463236673
# agent 46 在 299 次迭代中的资源申请量为: 56.16215112695789
# agent 47 在 299 次迭代中的资源申请量为: 46.18795285412267
# agent 48 在 299 次迭代中的资源申请量为: 36.65640890642632
# agent 49 在 299 次迭代中的资源申请量为: 42.99454711303281
# agent 50 在 299 次迭代中的资源申请量为: 41.189294179026994
# agent 51 在 299 次迭代中的资源申请量为: 48.6271648415601
# agent 52 在 299 次迭代中的资源申请量为: 56.06214452404151
# agent 53 在 299 次迭代中的资源申请量为: 33.09534718060052
# agent 54 在 299 次迭代中的资源申请量为: 57.262134092790674
# agent 55 在 299 次迭代中的资源申请量为: 71.44084521580399
# agent 56 在 299 次迭代中的资源申请量为: 41.18930620645871
# agent 57 在 299 次迭代中的资源申请量为: 60.784012442022274
# agent 58 在 299 次迭代中的资源申请量为: 42.49457532137135
# agent 59 在 299 次迭代中的资源申请量为: 48.22716314134644
# agent 60 在 299 次迭代中的资源申请量为: 56.36210894120674
# agent 61 在 299 次迭代中的资源申请量为: 66.32791304967304
# agent 62 在 299 次迭代中的资源申请量为: 46.38795432762745
# agent 63 在 299 次迭代中的资源申请量为: 39.22669851005994
# agent 64 在 299 次迭代中的资源申请量为: 44.687945567789555
# agent 65 在 299 次迭代中的资源申请量为: 42.99452494262768
# agent 66 在 299 次迭代中的资源申请量为: 66.02793400696444
# agent 67 在 299 次迭代中的资源申请量为: 36.612451155412124
# agent 68 在 299 次迭代中的资源申请量为: 45.187938511204756
# agent 69 在 299 次迭代中的资源申请量为: 45.687937190696545
# agent 70 在 299 次迭代中的资源申请量为: 60.38390739759578
# agent 71 在 299 次迭代中的资源申请量为: 72.44067166845389
# agent 72 在 299 次迭代中的资源申请量为: 50.071773056284684
# agent 73 在 299 次迭代中的资源申请量为: 43.99455422710127
# agent 74 在 299 次迭代中的资源申请量为: 39.22670326518458
# agent 75 在 299 次迭代中的资源申请量为: 52.28621817782563
# agent 76 在 299 次迭代中的资源申请量为: 47.287936330617896
# agent 77 在 299 次迭代中的资源申请量为: 41.08929285856729
# agent 78 在 299 次迭代中的资源申请量为: 49.92717496359964
# agent 79 在 299 次迭代中的资源申请量为: 43.09456229388756
# agent 80 在 299 次迭代中的资源申请量为: 43.29453165972423
# agent 81 在 299 次迭代中的资源申请量为: 39.72669611649583
# agent 82 在 299 次迭代中的资源申请量为: 45.98798250705217
# agent 83 在 299 次迭代中的资源申请量为: 41.88930280149799
# agent 84 在 299 次迭代中的资源申请量为: 52.38626543363951
# agent 85 在 299 次迭代中的资源申请量为: 56.06207088947242
# agent 86 在 299 次迭代中的资源申请量为: 49.22717593184387
# agent 87 在 299 次迭代中的资源申请量为: 60.783960278500814
# agent 88 在 299 次迭代中的资源申请量为: 65.52796964675245
# agent 89 在 299 次迭代中的资源申请量为: 34.304021061141896
# agent 90 在 299 次迭代中的资源申请量为: 59.583901220271116
# agent 91 在 299 次迭代中的资源申请量为: 43.19454715793186
# agent 92 在 299 次迭代中的资源申请量为: 57.26211391806832
# agent 93 在 299 次迭代中的资源申请量为: 40.989301057784104
# agent 94 在 299 次迭代中的资源申请量为: 60.71240840623947
# agent 95 在 299 次迭代中的资源申请量为: 60.68392857881082
# agent 96 在 299 次迭代中的资源申请量为: 60.88389001165297
# agent 97 在 299 次迭代中的资源申请量为: 72.64068162156141
# agent 98 在 299 次迭代中的资源申请量为: 73.44078511371008
# agent 99 在 299 次迭代中的资源申请量为: 52.78620117765559
# agent 100 在 299 次迭代中的资源申请量为: 48.82714003162141
# 资源申请量总和为: 5000.000000000002
# ****************************************************************************
# 成本总和为: 334811.51531283517
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 349 次迭代中的结果：
# agent 1 在 349 次迭代中的资源申请量为: 48.727166791949706
# agent 2 在 349 次迭代中的资源申请量为: 61.383958490013676
# agent 3 在 349 次迭代中的资源申请量为: 44.09455893409107
# agent 4 在 349 次迭代中的资源申请量为: 64.92795471625533
# agent 5 在 349 次迭代中的资源申请量为: 65.72795471624643
# agent 6 在 349 次迭代中的资源申请量为: 72.54075018781779
# agent 7 在 349 次迭代中的资源申请量为: 39.726710625258704
# agent 8 在 349 次迭代中的资源申请量为: 33.887123179731475
# agent 9 在 349 次迭代中的资源申请量为: 43.39455893415164
# agent 10 在 349 次迭代中的资源申请量为: 56.16211552920925
# agent 11 在 349 次迭代中的资源申请量为: 45.787968867463995
# agent 12 在 349 次迭代中的资源申请量为: 49.62716679198908
# agent 13 在 349 次迭代中的资源申请量为: 66.22795471639236
# agent 14 在 349 次迭代中的资源申请量为: 55.56211552914449
# agent 15 在 349 次迭代中的资源申请量为: 43.7945589340657
# agent 16 在 349 次迭代中的资源申请量为: 43.994558934023445
# agent 17 在 349 次迭代中的资源申请量为: 45.187968867479896
# agent 18 在 349 次迭代中的资源申请量为: 46.787968867438124
# agent 19 在 349 次迭代中的资源申请量为: 41.589305659998125
# agent 20 在 349 次迭代中的资源申请量为: 56.06211552921201
# agent 21 在 349 次迭代中的资源申请量为: 32.98016577981435
# agent 22 在 349 次迭代中的资源申请量为: 39.32671062525984
# agent 23 在 349 次迭代中的资源申请量为: 48.12716679194323
# agent 24 在 349 次迭代中的资源申请量为: 40.789305659923684
# agent 25 在 349 次迭代中的资源申请量为: 45.48796886742795
# agent 26 在 349 次迭代中的资源申请量为: 40.02671062525489
# agent 27 在 349 次迭代中的资源申请量为: 65.92795471631068
# agent 28 在 349 次迭代中的资源申请量为: 51.68625013425338
# agent 29 在 349 次迭代中的资源申请量为: 41.08930565999506
# agent 30 在 349 次迭代中的资源申请量为: 39.42671062526604
# agent 31 在 349 次迭代中的资源申请量为: 60.783958489944965
# agent 32 在 349 次迭代中的资源申请量为: 55.86211552907977
# agent 33 在 349 次迭代中的资源申请量为: 41.88930565997996
# agent 34 在 349 次迭代中的资源申请量为: 52.586250134270585
# agent 35 在 349 次迭代中的资源申请量为: 33.02761429072789
# agent 36 在 349 次迭代中的资源申请量为: 43.09455893409905
# agent 37 在 349 次迭代中的资源申请量为: 52.88625013423208
# agent 38 在 349 次迭代中的资源申请量为: 40.589305659961695
# agent 39 在 349 次迭代中的资源申请量为: 43.59455893408458
# agent 40 在 349 次迭代中的资源申请量为: 50.42716679203173
# agent 41 在 349 次迭代中的资源申请量为: 66.62795471649584
# agent 42 在 349 次迭代中的资源申请量为: 42.794558934119486
# agent 43 在 349 次迭代中的资源申请量为: 52.08625013419476
# agent 44 在 349 次迭代中的资源申请量为: 53.286250134203826
# agent 45 在 349 次迭代中的资源申请量为: 48.5271667919223
# agent 46 在 349 次迭代中的资源申请量为: 56.16211552927121
# agent 47 在 349 次迭代中的资源申请量为: 46.18796886749218
# agent 48 在 349 次迭代中的资源申请量为: 36.656295974505014
# agent 49 在 349 次迭代中的资源申请量为: 42.99455893410314
# agent 50 在 349 次迭代中的资源申请量为: 41.18930565995974
# agent 51 在 349 次迭代中的资源申请量为: 48.62716679202159
# agent 52 在 349 次迭代中的资源申请量为: 56.06211552927469
# agent 53 在 349 次迭代中的资源申请量为: 33.0952372030289
# agent 54 在 349 次迭代中的资源申请量为: 57.262115529257876
# agent 55 在 349 次迭代中的资源申请量为: 71.44075018812708
# agent 56 在 349 次迭代中的资源申请量为: 41.189305659974835
# agent 57 在 349 次迭代中的资源申请量为: 60.78395849007465
# agent 58 在 349 次迭代中的资源申请量为: 42.494558934118565
# agent 59 在 349 次迭代中的资源申请量为: 48.22716679197278
# agent 60 在 349 次迭代中的资源申请量为: 56.36211552919515
# agent 61 在 349 次迭代中的资源申请量为: 66.32795471629142
# agent 62 在 349 次迭代中的资源申请量为: 46.387968867474314
# agent 63 在 349 次迭代中的资源申请量为: 39.226710625253325
# agent 64 在 349 次迭代中的资源申请量为: 44.6879688674798
# agent 65 在 349 次迭代中的资源申请量为: 42.994558934045074
# agent 66 在 349 次迭代中的资源申请量为: 66.02795471639126
# agent 67 在 349 次迭代中的资源申请量为: 36.61231504144392
# agent 68 在 349 次迭代中的资源申请量为: 45.187968867461265
# agent 69 在 349 次迭代中的资源申请量为: 45.68796886743798
# agent 70 在 349 次迭代中的资源申请量为: 60.383958489954615
# agent 71 在 349 次迭代中的资源申请量为: 72.44075018792991
# agent 72 在 349 次迭代中的资源申请量为: 50.07165556851696
# agent 73 在 349 次迭代中的资源申请量为: 43.994558934123276
# agent 74 在 349 次迭代中的资源申请量为: 39.22671062524245
# agent 75 在 349 次迭代中的资源申请量为: 52.28625013426265
# agent 76 在 349 次迭代中的资源申请量为: 47.28796886745667
# agent 77 在 349 次迭代中的资源申请量为: 41.0893056599752
# agent 78 在 349 次迭代中的资源申请量为: 49.92716679195533
# agent 79 在 349 次迭代中的资源申请量为: 43.09455893410911
# agent 80 在 349 次迭代中的资源申请量为: 43.29455893404225
# agent 81 在 349 次迭代中的资源申请量为: 39.72671062522842
# agent 82 在 349 次迭代中的资源申请量为: 45.9879688674927
# agent 83 在 349 次迭代中的资源申请量为: 41.889305659974745
# agent 84 在 349 次迭代中的资源申请量为: 52.38625013423776
# agent 85 在 349 次迭代中的资源申请量为: 56.062115529114074
# agent 86 在 349 次迭代中的资源申请量为: 49.22716679199703
# agent 87 在 349 次迭代中的资源申请量为: 60.78395849005093
# agent 88 在 349 次迭代中的资源申请量为: 65.52795471646607
# agent 89 在 349 次迭代中的资源申请量为: 34.30390273227792
# agent 90 在 349 次迭代中的资源申请量为: 59.58395848993702
# agent 91 在 349 次迭代中的资源申请量为: 43.19455893409491
# agent 92 在 349 次迭代中的资源申请量为: 57.26211552917934
# agent 93 在 349 次迭代中的资源申请量为: 40.98930565996663
# agent 94 在 349 次迭代中的资源申请量为: 60.71229575837032
# agent 95 在 349 次迭代中的资源申请量为: 60.683958490048425
# agent 96 在 349 次迭代中的资源申请量为: 60.8839584899179
# agent 97 在 349 次迭代中的资源申请量为: 72.64075018767564
# agent 98 在 349 次迭代中的资源申请量为: 73.44075018788863
# agent 99 在 349 次迭代中的资源申请量为: 52.786250134177514
# agent 100 在 349 次迭代中的资源申请量为: 48.82716679195028
# 资源申请量总和为: 5000.0
# ****************************************************************************
# 成本总和为: 334811.53890210105
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 399 次迭代中的结果：
# agent 1 在 399 次迭代中的资源申请量为: 48.72716679198696
# agent 2 在 399 次迭代中的资源申请量为: 61.38395848998372
# agent 3 在 399 次迭代中的资源申请量为: 44.09455893410614
# agent 4 在 399 次迭代中的资源申请量为: 64.92795471634584
# agent 5 在 399 次迭代中的资源申请量为: 65.72795471634586
# agent 6 在 399 次迭代中的资源申请量为: 72.54075018798045
# agent 7 在 399 次迭代中的资源申请量为: 39.72671062525287
# agent 8 在 399 次迭代中的资源申请量为: 33.88712317959016
# agent 9 在 399 次迭代中的资源申请量为: 43.39455893410616
# agent 10 在 399 次迭代中的资源申请量为: 56.16211552921573
# agent 11 在 399 次迭代中的资源申请量为: 45.78796886748778
# agent 12 在 399 次迭代中的资源申请量为: 49.62716679198697
# agent 13 在 399 次迭代中的资源申请量为: 66.22795471634585
# agent 14 在 399 次迭代中的资源申请量为: 55.562115529215724
# agent 15 在 399 次迭代中的资源申请量为: 43.79455893410614
# agent 16 在 399 次迭代中的资源申请量为: 43.99455893410614
# agent 17 在 399 次迭代中的资源申请量为: 45.18796886748778
# agent 18 在 399 次迭代中的资源申请量为: 46.78796886748778
# agent 19 在 399 次迭代中的资源申请量为: 41.589305659989144
# agent 20 在 399 次迭代中的资源申请量为: 56.06211552921574
# agent 21 在 399 次迭代中的资源申请量为: 32.980165779604334
# agent 22 在 399 次迭代中的资源申请量为: 39.32671062525287
# agent 23 在 399 次迭代中的资源申请量为: 48.12716679198696
# agent 24 在 399 次迭代中的资源申请量为: 40.789305659989125
# agent 25 在 399 次迭代中的资源申请量为: 45.48796886748777
# agent 26 在 399 次迭代中的资源申请量为: 40.02671062525288
# agent 27 在 399 次迭代中的资源申请量为: 65.92795471634585
# agent 28 在 399 次迭代中的资源申请量为: 51.68625013427174
# agent 29 在 399 次迭代中的资源申请量为: 41.08930565998914
# agent 30 在 399 次迭代中的资源申请量为: 39.42671062525287
# agent 31 在 399 次迭代中的资源申请量为: 60.78395848998371
# agent 32 在 399 次迭代中的资源申请量为: 55.86211552921573
# agent 33 在 399 次迭代中的资源申请量为: 41.889305659989134
# agent 34 在 399 次迭代中的资源申请量为: 52.58625013427175
# agent 35 在 399 次迭代中的资源申请量为: 33.027614290532384
# agent 36 在 399 次迭代中的资源申请量为: 43.09455893410615
# agent 37 在 399 次迭代中的资源申请量为: 52.886250134271755
# agent 38 在 399 次迭代中的资源申请量为: 40.58930565998913
# agent 39 在 399 次迭代中的资源申请量为: 43.594558934106146
# agent 40 在 399 次迭代中的资源申请量为: 50.42716679198697
# agent 41 在 399 次迭代中的资源申请量为: 66.62795471634588
# agent 42 在 399 次迭代中的资源申请量为: 42.79455893410614
# agent 43 在 399 次迭代中的资源申请量为: 52.08625013427174
# agent 44 在 399 次迭代中的资源申请量为: 53.286250134271754
# agent 45 在 399 次迭代中的资源申请量为: 48.52716679198696
# agent 46 在 399 次迭代中的资源申请量为: 56.16211552921574
# agent 47 在 399 次迭代中的资源申请量为: 46.18796886748779
# agent 48 在 399 次迭代中的资源申请量为: 36.65629597430758
# agent 49 在 399 次迭代中的资源申请量为: 42.99455893410615
# agent 50 在 399 次迭代中的资源申请量为: 41.18930565998913
# agent 51 在 399 次迭代中的资源申请量为: 48.62716679198698
# agent 52 在 399 次迭代中的资源申请量为: 56.062115529215745
# agent 53 在 399 次迭代中的资源申请量为: 33.09523720285464
# agent 54 在 399 次迭代中的资源申请量为: 57.26211552921575
# agent 55 在 399 次迭代中的资源申请量为: 71.44075018798048
# agent 56 在 399 次迭代中的资源申请量为: 41.18930565998913
# agent 57 在 399 次迭代中的资源申请量为: 60.78395848998373
# agent 58 在 399 次迭代中的资源申请量为: 42.49455893410616
# agent 59 在 399 次迭代中的资源申请量为: 48.227166791986974
# agent 60 在 399 次迭代中的资源申请量为: 56.36211552921574
# agent 61 在 399 次迭代中的资源申请量为: 66.32795471634586
# agent 62 在 399 次迭代中的资源申请量为: 46.387968867487785
# agent 63 在 399 次迭代中的资源申请量为: 39.22671062525288
# agent 64 在 399 次迭代中的资源申请量为: 44.68796886748778
# agent 65 在 399 次迭代中的资源申请量为: 42.994558934106145
# agent 66 在 399 次迭代中的资源申请量为: 66.02795471634587
# agent 67 在 399 次迭代中的资源申请量为: 36.612315041240656
# agent 68 在 399 次迭代中的资源申请量为: 45.18796886748779
# agent 69 在 399 次迭代中的资源申请量为: 45.68796886748778
# agent 70 在 399 次迭代中的资源申请量为: 60.38395848998371
# agent 71 在 399 次迭代中的资源申请量为: 72.44075018798046
# agent 72 在 399 次迭代中的资源申请量为: 50.07165556833872
# agent 73 在 399 次迭代中的资源申请量为: 43.99455893410616
# agent 74 在 399 次迭代中的资源申请量为: 39.22671062525288
# agent 75 在 399 次迭代中的资源申请量为: 52.28625013427176
# agent 76 在 399 次迭代中的资源申请量为: 47.287968867487784
# agent 77 在 399 次迭代中的资源申请量为: 41.08930565998914
# agent 78 在 399 次迭代中的资源申请量为: 49.92716679198696
# agent 79 在 399 次迭代中的资源申请量为: 43.094558934106146
# agent 80 在 399 次迭代中的资源申请量为: 43.29455893410614
# agent 81 在 399 次迭代中的资源申请量为: 39.72671062525287
# agent 82 在 399 次迭代中的资源申请量为: 45.98796886748779
# agent 83 在 399 次迭代中的资源申请量为: 41.889305659989134
# agent 84 在 399 次迭代中的资源申请量为: 52.38625013427174
# agent 85 在 399 次迭代中的资源申请量为: 56.06211552921573
# agent 86 在 399 次迭代中的资源申请量为: 49.227166791986974
# agent 87 在 399 次迭代中的资源申请量为: 60.78395848998373
# agent 88 在 399 次迭代中的资源申请量为: 65.5279547163459
# agent 89 在 399 次迭代中的资源申请量为: 34.3039027320795
# agent 90 在 399 次迭代中的资源申请量为: 59.5839584899837
# agent 91 在 399 次迭代中的资源申请量为: 43.19455893410615
# agent 92 在 399 次迭代中的资源申请量为: 57.26211552921574
# agent 93 在 399 次迭代中的资源申请量为: 40.989305659989135
# agent 94 在 399 次迭代中的资源申请量为: 60.71229575819693
# agent 95 在 399 次迭代中的资源申请量为: 60.68395848998372
# agent 96 在 399 次迭代中的资源申请量为: 60.883958489983705
# agent 97 在 399 次迭代中的资源申请量为: 72.6407501879804
# agent 98 在 399 次迭代中的资源申请量为: 73.44075018798044
# agent 99 在 399 次迭代中的资源申请量为: 52.78625013427174
# agent 100 在 399 次迭代中的资源申请量为: 48.827166791986976
# 资源申请量总和为: 4999.999999999996
# ****************************************************************************
# 成本总和为: 334811.5389021396
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 449 次迭代中的结果：
# agent 1 在 449 次迭代中的资源申请量为: 48.72360548098339
# agent 2 在 449 次迭代中的资源申请量为: 61.37950686913363
# agent 3 在 449 次迭代中的资源申请量为: 44.091416607345046
# agent 4 在 449 次迭代中的资源申请量为: 64.92309838698195
# agent 5 在 449 次迭代中的资源申请量为: 65.72309838914526
# agent 6 在 449 次迭代中的资源申请量为: 72.53540824153521
# agent 7 在 449 次迭代中的资源申请量为: 39.72389907659138
# agent 8 在 449 次迭代中的资源申请量为: 33.85928990041724
# agent 9 在 449 次迭代中的资源申请量为: 43.39141662059757
# agent 10 在 449 次迭代中的资源申请量为: 56.15800633066539
# agent 11 在 449 次迭代中的资源申请量为: 45.784630147592694
# agent 12 在 449 次迭代中的资源申请量为: 49.623605498912546
# agent 13 在 449 次迭代中的资源申请量为: 66.22309840343252
# agent 14 在 449 次迭代中的资源申请量为: 55.558006313947004
# agent 15 在 449 次迭代中的资源申请量为: 43.7914166022767
# agent 16 在 449 次迭代中的资源申请量为: 43.99141659686265
# agent 17 在 449 次迭代中的资源申请量为: 45.18463014738212
# agent 18 在 449 次迭代中的资源申请量为: 46.7846301416994
# agent 19 在 449 次迭代中的资源申请量为: 41.58633791070977
# agent 20 在 449 次迭代中的资源申请量为: 56.05800634671415
# agent 21 在 449 次迭代中的资源申请量为: 32.95639789127673
# agent 22 在 449 次迭代中的资源申请量为: 39.32389907706569
# agent 23 在 449 次迭代中的资源申请量为: 48.123605477824384
# agent 24 在 449 次迭代中的资源申请量为: 40.78633789068354
# agent 25 在 449 次迭代中的资源申请量为: 45.48463013533665
# agent 26 在 449 次迭代中的资源申请量为: 40.02389907205656
# agent 27 在 449 次迭代中的资源申请量为: 65.9230983813198
# agent 28 在 449 次迭代中的资源申请量为: 51.682434454220605
# agent 29 在 449 次迭代中的资源申请量为: 41.08633790934123
# agent 30 在 449 次迭代中的资源申请量为: 39.423899075509944
# agent 31 在 449 次迭代中的资源申请量为: 60.77950684925145
# agent 32 在 449 次迭代中的资源申请量为: 55.85800629971977
# agent 33 在 449 次迭代中的资源申请量为: 41.886337906302984
# agent 34 在 449 次迭代中的资源申请量为: 52.58243445505184
# agent 35 在 449 次迭代中的资源申请量为: 33.02101553890294
# agent 36 在 449 次迭代中的资源申请量为: 43.09141661373545
# agent 37 在 449 次迭代中的资源申请量为: 52.8824344500256
# agent 38 在 449 次迭代中的资源申请量为: 40.58633790359359
# agent 39 在 449 次迭代中的资源申请量为: 43.5914166048871
# agent 40 在 449 次迭代中的资源申请量为: 50.423605504558
# agent 41 在 449 次迭代中的资源申请量为: 66.62309843230959
# agent 42 在 449 次迭代中的资源申请量为: 42.79141661287855
# agent 43 在 449 次迭代中的资源申请量为: 52.08243444519868
# agent 44 在 449 次迭代中的资源申请量为: 53.28243444111746
# agent 45 在 449 次迭代中的资源申请量为: 48.523605474438945
# agent 46 在 449 次迭代中的资源申请量为: 56.1580063537376
# agent 47 在 449 次迭代中的资源申请量为: 46.18463014803018
# agent 48 在 449 次迭代中的资源申请量为: 36.64354103335594
# agent 49 在 449 次迭代中的资源申请量为: 42.99141661512886
# agent 50 在 449 次迭代中的资源申请量为: 41.186337903599885
# agent 51 在 449 次迭代中的资源申请量为: 48.62360550201001
# agent 52 在 449 次迭代中的资源申请量为: 56.05800634552931
# agent 53 在 449 次迭代中的资源申请量为: 33.086633284966545
# agent 54 在 449 次迭代中的资源申请量为: 57.25800633850039
# agent 55 在 449 次迭代中的资源申请量为: 71.43540825741565
# agent 56 在 449 次迭代中的资源申请量为: 41.186337904725896
# agent 57 在 449 次迭代中的资源申请量为: 60.77950688480512
# agent 58 在 449 次迭代中的资源申请量为: 42.49141661101341
# agent 59 在 449 次迭代中的资源申请量为: 48.223605492042836
# agent 60 在 449 次迭代中的资源申请量为: 56.35800633470232
# agent 61 在 449 次迭代中的资源申请量为: 66.32309839617119
# agent 62 在 449 次迭代中的资源申请量为: 46.384630146633604
# agent 63 在 449 次迭代中的资源申请量为: 39.22389907437855
# agent 64 在 449 次迭代中的资源申请量为: 44.68463014823623
# agent 65 在 449 次迭代中的资源申请量为: 42.99141659854389
# agent 66 在 449 次迭代中的资源申请量为: 66.02309842250999
# agent 67 在 449 次迭代中的资源申请量为: 36.60067924560798
# agent 68 在 449 次迭代中的资源申请量为: 45.18463014620327
# agent 69 在 449 次迭代中的资源申请量为: 45.68463014145243
# agent 70 在 449 次迭代中的资源申请量为: 60.37950686512532
# agent 71 在 449 次迭代中的资源申请量为: 72.43540825301876
# agent 72 在 449 次迭代中的资源申请量为: 50.242331949907445
# agent 73 在 449 次迭代中的资源申请量为: 43.991416614502626
# agent 74 在 449 次迭代中的资源申请量为: 39.223899068189056
# agent 75 在 449 次迭代中的资源申请量为: 52.28243445103557
# agent 76 在 449 次迭代中的资源申请量为: 47.284630139630835
# agent 77 在 449 次迭代中的资源申请量为: 41.08633790644539
# agent 78 在 449 次迭代中的资源申请量为: 49.92360548208296
# agent 79 在 449 次迭代中的资源申请量为: 43.091416611068155
# agent 80 在 449 次迭代中的资源申请量为: 43.29141659579629
# agent 81 在 449 次迭代中的资源申请量为: 39.723899062982184
# agent 82 在 449 次迭代中的资源申请量为: 45.984630151186835
# agent 83 在 449 次迭代中的资源申请量为: 41.88633790618532
# agent 84 在 449 次迭代中的资源申请量为: 52.38243445124093
# agent 85 在 449 次迭代中的资源申请量为: 56.058006319627495
# agent 86 在 449 次迭代中的资源申请量为: 49.22360549497801
# agent 87 在 449 次迭代中的资源申请量为: 60.779506880191654
# agent 88 在 449 次迭代中的资源申请量为: 65.52309843577753
# agent 89 在 449 次迭代中的资源申请量为: 34.295834458430036
# agent 90 在 449 次迭代中的资源申请量为: 59.57950684741106
# agent 91 在 449 次迭代中的资源申请量为: 43.19141660739187
# agent 92 在 449 次迭代中的资源申请量为: 57.25800632967011
# agent 93 在 449 次迭代中的资源申请量为: 40.986337905477775
# agent 94 在 449 次迭代中的资源申请量为: 60.97936290023511
# agent 95 在 449 次迭代中的资源申请量为: 60.67950687270213
# agent 96 在 449 次迭代中的资源申请量为: 60.87950685097963
# agent 97 在 449 次迭代中的资源申请量为: 72.63540820169352
# agent 98 在 449 次迭代中的资源申请量为: 73.43540823074969
# agent 99 在 449 次迭代中的资源申请量为: 52.78243443342637
# agent 100 在 449 次迭代中的资源申请量为: 48.823605484024114
# 资源申请量总和为: 4999.999999999999
# ****************************************************************************
# 成本总和为: 334802.5627936634
# ****************************************************************************
# 迭代步长为: 0.01
# ****************************************************************************
# 499 次迭代中的结果：
# agent 1 在 499 次迭代中的资源申请量为: 48.72212962576173
# agent 2 在 499 次迭代中的资源申请量为: 61.377662104605456
# agent 3 在 499 次迭代中的资源申请量为: 44.090114407375516
# agent 4 在 499 次迭代中的资源申请量为: 64.92108586090781
# agent 5 在 499 次迭代中的资源申请量为: 65.72108587473939
# agent 6 在 499 次迭代中的资源申请量为: 72.53319457586787
# agent 7 在 499 次迭代中的资源申请量为: 39.722733977407074
# agent 8 在 499 次迭代中的资源申请量为: 33.84656940949715
# agent 9 在 499 次迭代中的资源申请量为: 43.390114477863705
# agent 10 在 499 次迭代中的资源申请量为: 56.15630341625966
# agent 11 在 499 次迭代中的资源申请量为: 45.783246565453254
# agent 12 在 499 次迭代中的资源申请量为: 49.62212973382654
# agent 13 在 499 次迭代中的资源申请量为: 66.22108599693694
# agent 14 在 499 次迭代中的资源申请量为: 55.556303351177164
# agent 15 在 499 次迭代中的资源申请量为: 43.79011438008152
# agent 16 在 499 次迭代中的资源申请量为: 43.990114356102914
# agent 17 在 499 次迭代中的资源申请量为: 45.18324657399581
# agent 18 在 499 次迭代中的资源申请量为: 46.783246540722665
# agent 19 在 499 次迭代中的资源申请量为: 41.585108074812084
# agent 20 在 499 次迭代中的资源申请量为: 56.05630355027806
# agent 21 在 499 次迭代中的资源申请量为: 32.947287669167764
# agent 22 在 499 次迭代中的资源申请量为: 39.322733984321786
# agent 23 在 499 次迭代中的资源申请量为: 48.12212959218636
# agent 24 在 499 次迭代中的资源申请量为: 40.785107951378095
# agent 25 在 499 次迭代中的资源申请量为: 45.48324650119092
# ...
# agent 87 在 1969 次迭代中的资源申请量为: 59.98773721114606
# agent 88 在 1969 次迭代中的资源申请量为: 64.6593496848866
# agent 89 在 1969 次迭代中的资源申请量为: 40.25849147409737
# agent 90 在 1969 次迭代中的资源申请量为: 58.78773721114605
# agent 91 在 1969 次迭代中的资源申请量为: 42.63252038433839
# agent 92 在 1969 次迭代中的资源申请量为: 56.5271420410579
# agent 93 在 1969 次迭代中的资源申请量为: 40.45849147409737
# agent 94 在 1969 次迭代中的资源申请量为: 72.31208127078975
# agent 95 在 1969 次迭代中的资源申请量为: 59.88773721114608
# agent 96 在 1969 次迭代中的资源申请量为: 60.08773721114608
# agent 97 在 1969 次迭代中的资源申请量为: 71.68528465337529
# agent 98 在 1969 次迭代中的资源申请量为: 72.48528465337532
# agent 99 在 1969 次迭代中的资源申请量为: 52.10377475241095
# agent 100 在 1969 次迭代中的资源申请量为: 48.19018976891688
# 资源申请量总和为: 5000.000000000159
# ****************************************************************************
# 成本总和为: 334087.9140803464
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1979 次迭代中的结果：
# agent 1 在 1979 次迭代中的资源申请量为: 48.09018976891687
# agent 2 在 1979 次迭代中的资源申请量为: 60.5877372111461
# agent 3 在 1979 次迭代中的资源申请量为: 43.53252038433841
# agent 4 在 1979 次迭代中的资源申请量为: 64.05934968488663
# agent 5 在 1979 次迭代中的资源申请量为: 64.85934968488662
# agent 6 在 1979 次迭代中的资源申请量为: 71.5852846533753
# agent 7 在 1979 次迭代中的资源申请量为: 39.22383402809225
# agent 8 在 1979 次迭代中的资源申请量为: 37.49264232668764
# agent 9 在 1979 次迭代中的资源申请量为: 42.832520384338395
# agent 10 在 1979 次迭代中的资源申请量为: 55.42714204105789
# agent 11 在 1979 次迭代中的资源申请量为: 45.19080290835954
# agent 12 在 1979 次迭代中的资源申请量为: 48.99018976891685
# agent 13 在 1979 次迭代中的资源申请量为: 65.3593496848866
# agent 14 在 1979 次迭代中的资源申请量为: 54.82714204105789
# agent 15 在 1979 次迭代中的资源申请量为: 43.23252038433839
# agent 16 在 1979 次迭代中的资源申请量为: 43.432520384338396
# agent 17 在 1979 次迭代中的资源申请量为: 44.59080290835954
# agent 18 在 1979 次迭代中的资源申请量为: 46.19080290835954
# agent 19 在 1979 次迭代中的资源申请量为: 41.058491474097366
# agent 20 在 1979 次迭代中的资源申请量为: 55.3271420410579
# agent 21 在 1979 次迭代中的资源申请量为: 38.523834028092246
# agent 22 在 1979 次迭代中的资源申请量为: 38.82383402809224
# agent 23 在 1979 次迭代中的资源申请量为: 47.49018976891685
# agent 24 在 1979 次迭代中的资源申请量为: 40.25849147409737
# agent 25 在 1979 次迭代中的资源申请量为: 44.89080290835954
# agent 26 在 1979 次迭代中的资源申请量为: 39.52383402809225
# agent 27 在 1979 次迭代中的资源申请量为: 65.0593496848866
# agent 28 在 1979 次迭代中的资源申请量为: 51.003774752410905
# agent 29 在 1979 次迭代中的资源申请量为: 40.55849147409737
# agent 30 在 1979 次迭代中的资源申请量为: 38.92383402809225
# agent 31 在 1979 次迭代中的资源申请量为: 59.98773721114606
# agent 32 在 1979 次迭代中的资源申请量为: 55.127142041057894
# agent 33 在 1979 次迭代中的资源申请量为: 41.35849147409737
# agent 34 在 1979 次迭代中的资源申请量为: 51.903774752410904
# agent 35 在 1979 次迭代中的资源申请量为: 38.62383402809225
# agent 36 在 1979 次迭代中的资源申请量为: 42.53252038433839
# agent 37 在 1979 次迭代中的资源申请量为: 52.20377475241091
# agent 38 在 1979 次迭代中的资源申请量为: 40.058491474097366
# agent 39 在 1979 次迭代中的资源申请量为: 43.03252038433839
# agent 40 在 1979 次迭代中的资源申请量为: 49.79018976891684
# agent 41 在 1979 次迭代中的资源申请量为: 65.75934968488659
# agent 42 在 1979 次迭代中的资源申请量为: 42.23252038433839
# agent 43 在 1979 次迭代中的资源申请量为: 51.403774752410904
# agent 44 在 1979 次迭代中的资源申请量为: 52.60377475241091
# agent 45 在 1979 次迭代中的资源申请量为: 47.89018976891685
# agent 46 在 1979 次迭代中的资源申请量为: 55.42714204105789
# agent 47 在 1979 次迭代中的资源申请量为: 45.59080290835954
# agent 48 在 1979 次迭代中的资源申请量为: 43.13252038433839
# agent 49 在 1979 次迭代中的资源申请量为: 42.43252038433839
# agent 50 在 1979 次迭代中的资源申请量为: 40.65849147409737
# agent 51 在 1979 次迭代中的资源申请量为: 47.99018976891685
# agent 52 在 1979 次迭代中的资源申请量为: 55.3271420410579
# agent 53 在 1979 次迭代中的资源申请量为: 38.72383402809225
# agent 54 在 1979 次迭代中的资源申请量为: 56.5271420410579
# agent 55 在 1979 次迭代中的资源申请量为: 70.48528465337529
# agent 56 在 1979 次迭代中的资源申请量为: 40.65849147409737
# agent 57 在 1979 次迭代中的资源申请量为: 59.98773721114606
# agent 58 在 1979 次迭代中的资源申请量为: 41.932520384338396
# agent 59 在 1979 次迭代中的资源申请量为: 47.590189768916844
# agent 60 在 1979 次迭代中的资源申请量为: 55.6271420410579
# agent 61 在 1979 次迭代中的资源申请量为: 65.4593496848866
# agent 62 在 1979 次迭代中的资源申请量为: 45.790802908359545
# agent 63 在 1979 次迭代中的资源申请量为: 38.72383402809225
# agent 64 在 1979 次迭代中的资源申请量为: 44.090802908359535
# agent 65 在 1979 次迭代中的资源申请量为: 42.43252038433839
# agent 66 在 1979 次迭代中的资源申请量为: 65.1593496848866
# agent 67 在 1979 次迭代中的资源申请量为: 43.03252038433839
# agent 68 在 1979 次迭代中的资源申请量为: 44.59080290835954
# agent 69 在 1979 次迭代中的资源申请量为: 45.09080290835954
# agent 70 在 1979 次迭代中的资源申请量为: 59.587737211146056
# agent 71 在 1979 次迭代中的资源申请量为: 71.48528465337529
# agent 72 在 1979 次迭代中的资源申请量为: 59.78773721114605
# agent 73 在 1979 次迭代中的资源申请量为: 43.432520384338396
# agent 74 在 1979 次迭代中的资源申请量为: 38.72383402809225
# agent 75 在 1979 次迭代中的资源申请量为: 51.60377475241091
# agent 76 在 1979 次迭代中的资源申请量为: 46.690802908359544
# agent 77 在 1979 次迭代中的资源申请量为: 40.55849147409737
# agent 78 在 1979 次迭代中的资源申请量为: 49.29018976891684
# agent 79 在 1979 次迭代中的资源申请量为: 42.53252038433839
# agent 80 在 1979 次迭代中的资源申请量为: 42.73252038433839
# agent 81 在 1979 次迭代中的资源申请量为: 39.22383402809225
# agent 82 在 1979 次迭代中的资源申请量为: 45.39080290835955
# agent 83 在 1979 次迭代中的资源申请量为: 41.35849147409737
# agent 84 在 1979 次迭代中的资源申请量为: 51.70377475241091
# agent 85 在 1979 次迭代中的资源申请量为: 55.3271420410579
# agent 86 在 1979 次迭代中的资源申请量为: 48.590189768916844
# agent 87 在 1979 次迭代中的资源申请量为: 59.98773721114606
# agent 88 在 1979 次迭代中的资源申请量为: 64.6593496848866
# agent 89 在 1979 次迭代中的资源申请量为: 40.25849147409737
# agent 90 在 1979 次迭代中的资源申请量为: 58.78773721114605
# agent 91 在 1979 次迭代中的资源申请量为: 42.63252038433839
# agent 92 在 1979 次迭代中的资源申请量为: 56.5271420410579
# agent 93 在 1979 次迭代中的资源申请量为: 40.45849147409737
# agent 94 在 1979 次迭代中的资源申请量为: 72.3120812707896
# agent 95 在 1979 次迭代中的资源申请量为: 59.88773721114608
# agent 96 在 1979 次迭代中的资源申请量为: 60.08773721114608
# agent 97 在 1979 次迭代中的资源申请量为: 71.68528465337529
# agent 98 在 1979 次迭代中的资源申请量为: 72.48528465337532
# agent 99 在 1979 次迭代中的资源申请量为: 52.10377475241095
# agent 100 在 1979 次迭代中的资源申请量为: 48.19018976891688
# 资源申请量总和为: 5000.000000000159
# ****************************************************************************
# 成本总和为: 334087.9140803464
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1989 次迭代中的结果：
# agent 1 在 1989 次迭代中的资源申请量为: 48.09018976891687
# agent 2 在 1989 次迭代中的资源申请量为: 60.5877372111461
# agent 3 在 1989 次迭代中的资源申请量为: 43.53252038433841
# agent 4 在 1989 次迭代中的资源申请量为: 64.05934968488663
# agent 5 在 1989 次迭代中的资源申请量为: 64.85934968488662
# agent 6 在 1989 次迭代中的资源申请量为: 71.5852846533753
# agent 7 在 1989 次迭代中的资源申请量为: 39.22383402809225
# agent 8 在 1989 次迭代中的资源申请量为: 37.49264232668764
# agent 9 在 1989 次迭代中的资源申请量为: 42.832520384338395
# agent 10 在 1989 次迭代中的资源申请量为: 55.42714204105789
# agent 11 在 1989 次迭代中的资源申请量为: 45.19080290835954
# agent 12 在 1989 次迭代中的资源申请量为: 48.99018976891685
# agent 13 在 1989 次迭代中的资源申请量为: 65.3593496848866
# agent 14 在 1989 次迭代中的资源申请量为: 54.82714204105789
# agent 15 在 1989 次迭代中的资源申请量为: 43.23252038433839
# agent 16 在 1989 次迭代中的资源申请量为: 43.432520384338396
# agent 17 在 1989 次迭代中的资源申请量为: 44.59080290835954
# agent 18 在 1989 次迭代中的资源申请量为: 46.19080290835954
# agent 19 在 1989 次迭代中的资源申请量为: 41.058491474097366
# agent 20 在 1989 次迭代中的资源申请量为: 55.3271420410579
# agent 21 在 1989 次迭代中的资源申请量为: 38.523834028092246
# agent 22 在 1989 次迭代中的资源申请量为: 38.82383402809224
# agent 23 在 1989 次迭代中的资源申请量为: 47.49018976891685
# agent 24 在 1989 次迭代中的资源申请量为: 40.25849147409737
# agent 25 在 1989 次迭代中的资源申请量为: 44.89080290835954
# agent 26 在 1989 次迭代中的资源申请量为: 39.52383402809225
# agent 27 在 1989 次迭代中的资源申请量为: 65.0593496848866
# agent 28 在 1989 次迭代中的资源申请量为: 51.003774752410905
# agent 29 在 1989 次迭代中的资源申请量为: 40.55849147409737
# agent 30 在 1989 次迭代中的资源申请量为: 38.92383402809225
# agent 31 在 1989 次迭代中的资源申请量为: 59.98773721114606
# agent 32 在 1989 次迭代中的资源申请量为: 55.127142041057894
# agent 33 在 1989 次迭代中的资源申请量为: 41.35849147409737
# agent 34 在 1989 次迭代中的资源申请量为: 51.903774752410904
# agent 35 在 1989 次迭代中的资源申请量为: 38.62383402809225
# agent 36 在 1989 次迭代中的资源申请量为: 42.53252038433839
# agent 37 在 1989 次迭代中的资源申请量为: 52.20377475241091
# agent 38 在 1989 次迭代中的资源申请量为: 40.058491474097366
# agent 39 在 1989 次迭代中的资源申请量为: 43.03252038433839
# agent 40 在 1989 次迭代中的资源申请量为: 49.79018976891684
# agent 41 在 1989 次迭代中的资源申请量为: 65.75934968488659
# agent 42 在 1989 次迭代中的资源申请量为: 42.23252038433839
# agent 43 在 1989 次迭代中的资源申请量为: 51.403774752410904
# agent 44 在 1989 次迭代中的资源申请量为: 52.60377475241091
# agent 45 在 1989 次迭代中的资源申请量为: 47.89018976891685
# agent 46 在 1989 次迭代中的资源申请量为: 55.42714204105789
# agent 47 在 1989 次迭代中的资源申请量为: 45.59080290835954
# agent 48 在 1989 次迭代中的资源申请量为: 43.13252038433839
# agent 49 在 1989 次迭代中的资源申请量为: 42.43252038433839
# agent 50 在 1989 次迭代中的资源申请量为: 40.65849147409737
# agent 51 在 1989 次迭代中的资源申请量为: 47.99018976891685
# agent 52 在 1989 次迭代中的资源申请量为: 55.3271420410579
# agent 53 在 1989 次迭代中的资源申请量为: 38.72383402809225
# agent 54 在 1989 次迭代中的资源申请量为: 56.5271420410579
# agent 55 在 1989 次迭代中的资源申请量为: 70.48528465337529
# agent 56 在 1989 次迭代中的资源申请量为: 40.65849147409737
# agent 57 在 1989 次迭代中的资源申请量为: 59.98773721114606
# agent 58 在 1989 次迭代中的资源申请量为: 41.932520384338396
# agent 59 在 1989 次迭代中的资源申请量为: 47.590189768916844
# agent 60 在 1989 次迭代中的资源申请量为: 55.6271420410579
# agent 61 在 1989 次迭代中的资源申请量为: 65.4593496848866
# agent 62 在 1989 次迭代中的资源申请量为: 45.790802908359545
# agent 63 在 1989 次迭代中的资源申请量为: 38.72383402809225
# agent 64 在 1989 次迭代中的资源申请量为: 44.090802908359535
# agent 65 在 1989 次迭代中的资源申请量为: 42.43252038433839
# agent 66 在 1989 次迭代中的资源申请量为: 65.1593496848866
# agent 67 在 1989 次迭代中的资源申请量为: 43.03252038433839
# agent 68 在 1989 次迭代中的资源申请量为: 44.59080290835954
# agent 69 在 1989 次迭代中的资源申请量为: 45.09080290835954
# agent 70 在 1989 次迭代中的资源申请量为: 59.587737211146056
# agent 71 在 1989 次迭代中的资源申请量为: 71.48528465337529
# agent 72 在 1989 次迭代中的资源申请量为: 59.78773721114605
# agent 73 在 1989 次迭代中的资源申请量为: 43.432520384338396
# agent 74 在 1989 次迭代中的资源申请量为: 38.72383402809225
# agent 75 在 1989 次迭代中的资源申请量为: 51.60377475241091
# agent 76 在 1989 次迭代中的资源申请量为: 46.690802908359544
# agent 77 在 1989 次迭代中的资源申请量为: 40.55849147409737
# agent 78 在 1989 次迭代中的资源申请量为: 49.29018976891684
# agent 79 在 1989 次迭代中的资源申请量为: 42.53252038433839
# agent 80 在 1989 次迭代中的资源申请量为: 42.73252038433839
# agent 81 在 1989 次迭代中的资源申请量为: 39.22383402809225
# agent 82 在 1989 次迭代中的资源申请量为: 45.39080290835955
# agent 83 在 1989 次迭代中的资源申请量为: 41.35849147409737
# agent 84 在 1989 次迭代中的资源申请量为: 51.70377475241091
# agent 85 在 1989 次迭代中的资源申请量为: 55.3271420410579
# agent 86 在 1989 次迭代中的资源申请量为: 48.590189768916844
# agent 87 在 1989 次迭代中的资源申请量为: 59.98773721114606
# agent 88 在 1989 次迭代中的资源申请量为: 64.6593496848866
# agent 89 在 1989 次迭代中的资源申请量为: 40.25849147409737
# agent 90 在 1989 次迭代中的资源申请量为: 58.78773721114605
# agent 91 在 1989 次迭代中的资源申请量为: 42.63252038433839
# agent 92 在 1989 次迭代中的资源申请量为: 56.5271420410579
# agent 93 在 1989 次迭代中的资源申请量为: 40.45849147409737
# agent 94 在 1989 次迭代中的资源申请量为: 72.31208127078946
# agent 95 在 1989 次迭代中的资源申请量为: 59.88773721114608
# agent 96 在 1989 次迭代中的资源申请量为: 60.08773721114608
# agent 97 在 1989 次迭代中的资源申请量为: 71.68528465337529
# agent 98 在 1989 次迭代中的资源申请量为: 72.48528465337532
# agent 99 在 1989 次迭代中的资源申请量为: 52.10377475241095
# agent 100 在 1989 次迭代中的资源申请量为: 48.19018976891688
# 资源申请量总和为: 5000.000000000159
# ****************************************************************************
# 成本总和为: 334087.91408034635
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 1999 次迭代中的结果：
# agent 1 在 1999 次迭代中的资源申请量为: 48.09018976891687
# agent 2 在 1999 次迭代中的资源申请量为: 60.5877372111461
# agent 3 在 1999 次迭代中的资源申请量为: 43.53252038433841
# agent 4 在 1999 次迭代中的资源申请量为: 64.05934968488663
# agent 5 在 1999 次迭代中的资源申请量为: 64.85934968488662
# agent 6 在 1999 次迭代中的资源申请量为: 71.5852846533753
# agent 7 在 1999 次迭代中的资源申请量为: 39.22383402809225
# agent 8 在 1999 次迭代中的资源申请量为: 37.49264232668764
# agent 9 在 1999 次迭代中的资源申请量为: 42.832520384338395
# agent 10 在 1999 次迭代中的资源申请量为: 55.42714204105789
# agent 11 在 1999 次迭代中的资源申请量为: 45.19080290835954
# agent 12 在 1999 次迭代中的资源申请量为: 48.99018976891685
# agent 13 在 1999 次迭代中的资源申请量为: 65.3593496848866
# agent 14 在 1999 次迭代中的资源申请量为: 54.82714204105789
# agent 15 在 1999 次迭代中的资源申请量为: 43.23252038433839
# agent 16 在 1999 次迭代中的资源申请量为: 43.432520384338396
# agent 17 在 1999 次迭代中的资源申请量为: 44.59080290835954
# agent 18 在 1999 次迭代中的资源申请量为: 46.19080290835954
# agent 19 在 1999 次迭代中的资源申请量为: 41.058491474097366
# agent 20 在 1999 次迭代中的资源申请量为: 55.3271420410579
# agent 21 在 1999 次迭代中的资源申请量为: 38.523834028092246
# agent 22 在 1999 次迭代中的资源申请量为: 38.82383402809224
# agent 23 在 1999 次迭代中的资源申请量为: 47.49018976891685
# agent 24 在 1999 次迭代中的资源申请量为: 40.25849147409737
# agent 25 在 1999 次迭代中的资源申请量为: 44.89080290835954
# agent 26 在 1999 次迭代中的资源申请量为: 39.52383402809225
# agent 27 在 1999 次迭代中的资源申请量为: 65.0593496848866
# agent 28 在 1999 次迭代中的资源申请量为: 51.003774752410905
# agent 29 在 1999 次迭代中的资源申请量为: 40.55849147409737
# agent 30 在 1999 次迭代中的资源申请量为: 38.92383402809225
# agent 31 在 1999 次迭代中的资源申请量为: 59.98773721114606
# agent 32 在 1999 次迭代中的资源申请量为: 55.127142041057894
# agent 33 在 1999 次迭代中的资源申请量为: 41.35849147409737
# agent 34 在 1999 次迭代中的资源申请量为: 51.903774752410904
# agent 35 在 1999 次迭代中的资源申请量为: 38.62383402809225
# agent 36 在 1999 次迭代中的资源申请量为: 42.53252038433839
# agent 37 在 1999 次迭代中的资源申请量为: 52.20377475241091
# agent 38 在 1999 次迭代中的资源申请量为: 40.058491474097366
# agent 39 在 1999 次迭代中的资源申请量为: 43.03252038433839
# agent 40 在 1999 次迭代中的资源申请量为: 49.79018976891684
# agent 41 在 1999 次迭代中的资源申请量为: 65.75934968488659
# agent 42 在 1999 次迭代中的资源申请量为: 42.23252038433839
# agent 43 在 1999 次迭代中的资源申请量为: 51.403774752410904
# agent 44 在 1999 次迭代中的资源申请量为: 52.60377475241091
# agent 45 在 1999 次迭代中的资源申请量为: 47.89018976891685
# agent 46 在 1999 次迭代中的资源申请量为: 55.42714204105789
# agent 47 在 1999 次迭代中的资源申请量为: 45.59080290835954
# agent 48 在 1999 次迭代中的资源申请量为: 43.13252038433839
# agent 49 在 1999 次迭代中的资源申请量为: 42.43252038433839
# agent 50 在 1999 次迭代中的资源申请量为: 40.65849147409737
# agent 51 在 1999 次迭代中的资源申请量为: 47.99018976891685
# agent 52 在 1999 次迭代中的资源申请量为: 55.3271420410579
# agent 53 在 1999 次迭代中的资源申请量为: 38.72383402809225
# agent 54 在 1999 次迭代中的资源申请量为: 56.5271420410579
# agent 55 在 1999 次迭代中的资源申请量为: 70.48528465337529
# agent 56 在 1999 次迭代中的资源申请量为: 40.65849147409737
# agent 57 在 1999 次迭代中的资源申请量为: 59.98773721114606
# agent 58 在 1999 次迭代中的资源申请量为: 41.932520384338396
# agent 59 在 1999 次迭代中的资源申请量为: 47.590189768916844
# agent 60 在 1999 次迭代中的资源申请量为: 55.6271420410579
# agent 61 在 1999 次迭代中的资源申请量为: 65.4593496848866
# agent 62 在 1999 次迭代中的资源申请量为: 45.790802908359545
# agent 63 在 1999 次迭代中的资源申请量为: 38.72383402809225
# agent 64 在 1999 次迭代中的资源申请量为: 44.090802908359535
# agent 65 在 1999 次迭代中的资源申请量为: 42.43252038433839
# agent 66 在 1999 次迭代中的资源申请量为: 65.1593496848866
# agent 67 在 1999 次迭代中的资源申请量为: 43.03252038433839
# agent 68 在 1999 次迭代中的资源申请量为: 44.59080290835954
# agent 69 在 1999 次迭代中的资源申请量为: 45.09080290835954
# agent 70 在 1999 次迭代中的资源申请量为: 59.587737211146056
# agent 71 在 1999 次迭代中的资源申请量为: 71.48528465337529
# agent 72 在 1999 次迭代中的资源申请量为: 59.78773721114605
# agent 73 在 1999 次迭代中的资源申请量为: 43.432520384338396
# agent 74 在 1999 次迭代中的资源申请量为: 38.72383402809225
# agent 75 在 1999 次迭代中的资源申请量为: 51.60377475241091
# agent 76 在 1999 次迭代中的资源申请量为: 46.690802908359544
# agent 77 在 1999 次迭代中的资源申请量为: 40.55849147409737
# agent 78 在 1999 次迭代中的资源申请量为: 49.29018976891684
# agent 79 在 1999 次迭代中的资源申请量为: 42.53252038433839
# agent 80 在 1999 次迭代中的资源申请量为: 42.73252038433839
# agent 81 在 1999 次迭代中的资源申请量为: 39.22383402809225
# agent 82 在 1999 次迭代中的资源申请量为: 45.39080290835955
# agent 83 在 1999 次迭代中的资源申请量为: 41.35849147409737
# agent 84 在 1999 次迭代中的资源申请量为: 51.70377475241091
# agent 85 在 1999 次迭代中的资源申请量为: 55.3271420410579
# agent 86 在 1999 次迭代中的资源申请量为: 48.590189768916844
# agent 87 在 1999 次迭代中的资源申请量为: 59.98773721114606
# agent 88 在 1999 次迭代中的资源申请量为: 64.6593496848866
# agent 89 在 1999 次迭代中的资源申请量为: 40.25849147409737
# agent 90 在 1999 次迭代中的资源申请量为: 58.78773721114605
# agent 91 在 1999 次迭代中的资源申请量为: 42.63252038433839
# agent 92 在 1999 次迭代中的资源申请量为: 56.5271420410579
# agent 93 在 1999 次迭代中的资源申请量为: 40.45849147409737
# agent 94 在 1999 次迭代中的资源申请量为: 72.31208127078932
# agent 95 在 1999 次迭代中的资源申请量为: 59.88773721114608
# agent 96 在 1999 次迭代中的资源申请量为: 60.08773721114608
# agent 97 在 1999 次迭代中的资源申请量为: 71.68528465337529
# agent 98 在 1999 次迭代中的资源申请量为: 72.48528465337532
# agent 99 在 1999 次迭代中的资源申请量为: 52.10377475241095
# agent 100 在 1999 次迭代中的资源申请量为: 48.19018976891688
# 资源申请量总和为: 5000.000000000159
# ****************************************************************************
# 成本总和为: 334087.91408034635
# ****************************************************************************
# 迭代步长为: 1
# ****************************************************************************
# 2025-01-21 17:26:22.343

# %%
np.savetxt('../data/03-9-bias-agent-robust_agent_resource_quantity_small_value_Gaussian_bias(50,10).txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/03-9-bias-agent-robust_sum_cost_small_value_Gaussian_bias(50,10).txt',sum_cost,fmt='%0.8f')#用户成本总和 
np.savetxt('../data/03-9-bias-agent-robust_sum_resource_small_value_Gaussian_bias(50,10).txt',sum_resource,fmt='%0.8f')#用户资源总和 
np.savetxt('../data/03-9-bias-agent-robust_agent_gradient_small_value_Gaussian_bias(50,10).txt',agent_gradient,fmt='%0.8f')#用户迭代梯度
