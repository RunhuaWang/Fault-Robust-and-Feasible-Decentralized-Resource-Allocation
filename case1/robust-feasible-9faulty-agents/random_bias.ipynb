# %% [raw]
# 生成服从一定分布的噪声

# %% [raw]
# 均匀分布 [500,1000]

# %%
import random
import numpy as np

# %%
random_bias_uniform_distribution_500_1000 = np.random.uniform(500,1000,[1,2000])

# %%
random_bias_uniform_distribution_500_1000 = np.round(random_bias_uniform_distribution_500_1000, decimals=1)

# %%
random_bias_uniform_distribution_500_1000
# Out:
# array([[650.9, 698.5, 778.2, ..., 640.3, 996.1, 694.3]])

# %%
np.savetxt('2000_random_bias_uniform_distribution_500_1000.txt',random_bias_uniform_distribution_500_1000,fmt='%0.8f')#数据存储

# %%
beta= np.loadtxt("2000_random_bias_uniform_distribution_500_1000.txt")

# %%
beta
# Out:
# array([650.9, 698.5, 778.2, ..., 640.3, 996.1, 694.3])

# %% [raw]
# 均匀分布 [0,500]

# %%
import random
import numpy as np

# %%
random_bias_uniform_distribution_0_500 = np.random.uniform(0,500,[1,2000])

# %%
random_bias_uniform_distribution_0_500 = np.round(random_bias_uniform_distribution_0_500, decimals=1)

# %%
random_bias_uniform_distribution_0_500
# Out:
# array([[259.3,  56.1, 167. , ...,  55.3, 496.8,  81.3]])

# %%
np.savetxt('2000_random_bias_uniform_distribution_0_500.txt',random_bias_uniform_distribution_0_500,fmt='%0.8f')#数据存储

# %%
beta= np.loadtxt("2000_random_bias_uniform_distribution_0_500.txt")

# %%
beta
# Out:
# array([259.3,  56.1, 167. , ...,  55.3, 496.8,  81.3])

# %% [raw]
# 正态分布/高斯分布

# %% [markdown]
# 小值高斯分布

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math

# %%
mu1 = 50  #期望
sigma1 = 10  #标准差
num1 = 1000  #个数

# %%
random_bias_normal_distribution1 = np.random.normal(mu1, sigma1, num1)

# %%
random_bias_normal_distribution1 = np.round(random_bias_normal_distribution1, decimals=1)

# %%
random_bias_normal_distribution1
# Out:
# array([55.3, 39.5, 64.2, 56. , 65. , 64.7, 32.7, 42.5, 64.4, 52.7, 55. ,
#        51.1, 63.6, 54.6, 49. , 57.1, 34.2, 43.7, 46.9, 42.1, 59.7, 45.8,
#        54.5, 69.4, 38.7, 40.3, 35.5, 54.8, 55.8, 60.4, 62.6, 54.6, 53.5,
#        52.8, 45.3, 47. , 52.1, 36. , 49.2, 59.7, 48.9, 39.5, 49.4, 58.6,
#        59.1, 45.4, 65.2, 57.4, 53.2, 41.9, 53.5, 59.4, 35.8, 53. , 55.7,
#        57.7, 47.9, 59.2, 53.1, 46.7, 48.4, 55.7, 53.1, 42. , 58.5, 55.1,
#        50.5, 40. , 52.7, 57.7, 52.4, 39.4, 73.2, 51.2, 54.3, 56.3, 65.4,
#        60.1, 37.3, 41.4, 53.4, 63.4, 50.5, 45. , 45.6, 43.1, 35.9, 52.7,
#        52.9, 32.2, 61.4, 53.5, 53.5, 42.3, 32.8, 48.8, 53.3, 53.1, 38.6,
#        58.1, 51.9, 26. , 55.8, 60.4, 42.8, 47.3, 51.1, 37.5, 54.1, 58.5,
#        43.7, 55.3, 52.4, 50.3, 35.5, 54.3, 58.5, 76.1, 60. , 47.8, 63. ,
#        52.8, 38.5, 58.7, 47.9, 53.5, 53.3, 39.4, 42.3, 40.3, 65.5, 53.7,
#        53. , 47.4, 54.2, 49.6, 59.1, 41.9, 41.1, 66.9, 57.5, 64.9, 41.1,
#        44.2, 69.4, 56.7, 42.5, 43.3, 61.4, 65.6, 56.1, 45.7, 49.9, 48.7,
#        23. , 45.9, 45.2, 59.8, 43.8, 42.8, 66.4, 51.5, 46.1, 61.2, 34.6,
#        59.6, 53.3, 39.1, 48.4, 45.3, 54.5, 60. , 31.5, 70.1, 50.7, 75.8,
#        35.8, 21.4, 63.6, 53.2, 50.1, 51.9, 52.8, 65.9, 36.2, 47.9, 34.2,
#        45.5, 38.3, 28. , 59.6, 45.9, 40.8, 46.4, 64.9, 52.4, 43.2, 59.5,
#        39.9, 54.4, 39.6, 61.5, 51.4, 50.4, 41. , 40.9, 40.9, 63.1, 56.9,
#        59.9, 33.7, 35.2, 35. , 55.2, 55. , 52.7, 40.8, 53.7, 57.4, 40.2,
#        60. , 46.6, 60.1, 38.7, 59.1, 44.2, 49. , 44.8, 63.5, 46.2, 49.3,
#        47.8, 49.1, 44.8, 54.6, 46.8, 31.8, 54.1, 57.6, 44.3, 43.4, 40.2,
#        54.3, 61.8, 45.6, 58.5, 42.1, 60.8, 46.9, 36.1, 29. , 49.6, 59.7,
#        55. , 62.8, 39.5, 46.1, 50.7, 68.8, 49. , 32.4, 30.4, 54. , 41.2,
#        40.4, 53.2, 70.8, 63.9, 45.5, 59.1, 57.2, 56.8, 48.9, 60.9, 61. ,
#        48.5, 50.7, 70.9, 43.8, 35.8, 46.8, 38. , 47.2, 40.8, 57.5, 58.4,
#        44.5, 55.2, 45.3, 41. , 66.4, 38.5, 53.2, 37.2, 57.9, 58.5, 28.3,
#        49.9, 63.2, 59.9, 68.8, 44.3, 44.7, 62.5, 41.7, 67.8, 49.6, 45.1,
#        65. , 51. , 55.1, 58.7, 52.3, 68.6, 48.4, 59.4, 42.7, 53.2, 56.5,
#        56.5, 48.7, 48. , 58.6, 48.7, 50. , 46.4, 39.9, 32.6, 55.4, 53.1,
#        48.7, 22.2, 58.5, 52. , 54.9, 66.4, 61.1, 38.8, 55.4, 65.9, 60.3,
#        56.3, 54.5, 55.1, 39.2, 39.3, 52.4, 43.7, 51.5, 30. , 63.2, 58.5,
#        50.6, 28.7, 59.4, 59.4, 53.4, 39.1, 52.9, 55.8, 56.5, 29.5, 31.9,
#        47.8, 63. , 44.5, 53.6, 63.3, 55.8, 41. , 42.7, 52.2, 63.9, 60.4,
#        48.1, 33.4, 46.9, 58.3, 42.5, 62.1, 42.1, 36.4, 50.4, 55.3, 43.6,
#        37.9, 58.5, 34. , 57.7, 60.2, 51. , 54.8, 47.5, 64. , 70.7, 46.8,
#        43.3, 47.5, 43.4, 37.7, 53.2, 37.2, 39.5, 50.1, 47.1, 45. , 63.2,
#        47.5, 28.3, 69.1, 44. , 52. , 62.5, 45. , 38.4, 47.5, 47.8, 63.6,
#        58.5, 40.1, 45.7, 52.8, 53.6, 49.5, 49.9, 53.2, 54.8, 46.7])

# %%
min(random_bias_normal_distribution1)
# Out:
# np.float64(21.4)

# %%
max(random_bias_normal_distribution1)
# Out:
# np.float64(76.1)

# %%
np.savetxt('1000_Gaussian_distribution_(50,10).txt',random_bias_normal_distribution1,fmt='%0.8f')#数据存储

# %%
beta1= np.loadtxt("1000_normal_distribution_(50,10).txt")

# %% [markdown]
# 大值高斯分布

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math

# %%
mu1 = 500  #期望
sigma1 = 10  #标准差
num1 = 1000  #个数

# %%
random_bias_normal_distribution1 = np.random.normal(mu1, sigma1, num1)

# %%
random_bias_normal_distribution1 = np.round(random_bias_normal_distribution1, decimals=1)

# %%
random_bias_normal_distribution1
# Out:
# array([509.4, 514.2, 495.6, 484.8, 508.6, 523.4, 501.9, 496.3, 499.9,
#        488.7, 491.8, 499.2, 512.2, 501.7, 502.7, 506.8, 505. , 493.8,
#        490.1, 521. , 491. , 519.5, 506.1, 485.9, 514.8, 499.5, 500.6,
#        510.7, 498.5, 499.5, 505.7, 503.5, 492.7, 495.5, 480.6, 502.5,
#        488.8, 495.4, 504.5, 492. , 511. , 505.9, 508.4, 499.9, 491.8,
#        481.1, 499.2, 505.9, 503. , 500.8, 500.8, 492.7, 503.2, 512.3,
#        493.1, 511.5, 508.9, 486.7, 525.1, 499. , 503.2, 504. , 512.7,
#        497.9, 489. , 497.4, 508.4, 512.4, 498.9, 513.2, 500. , 507.4,
#        492.9, 497.4, 500.2, 509.9, 525.2, 495.3, 495.2, 495.1, 505.2,
#        492.3, 494.2, 487.9, 501.3, 502.2, 481.5, 484.6, 500.5, 510.6,
#        498.8, 507.9, 503.8, 496.5, 484.6, 509.8, 502.5, 509.3, 501.3,
#        507.4, 518. , 493.7, 503.8, 495.7, 505.5, 485.4, 490.7, 507.6,
#        508.3, 491.3, 493.9, 512.3, 494.4, 487.6, 492.7, 508.2, 515.6,
#        498.9, 506.9, 473.6, 505.3, 504.4, 495.2, 504. , 490.7, 514.9,
#        495.4, 500.9, 500.1, 490.8, 503. , 498.7, 507.9, 507.9, 505.3,
#        505.3, 506.5, 509.3, 506.8, 499.1, 499.3, 513.2, 481.3, 504.1,
#        492.7, 497.2, 493.4, 503. , 501.5, 499.9, 492. , 491.1, 509.3,
#        499.6, 485.1, 497.3, 479.1, 484.7, 503.2, 498.4, 484.2, 512. ,
#        501.8, 496.2, 494.9, 491.9, 501.3, 494.9, 499.9, 515.9, 522.4,
#        488.6, 497.9, 512.1, 496.8, 507.1, 497.5, 507.1, 506.2, 506.5,
#        515.5, 512. , 515.5, 502.3, 498.6, 515.5, 524.2, 505.1, 506. ,
#        501.1, 504.6, 515.2, 487. , 492.3, 491.4, 481. , 499. , 486.9,
#        514.7, 498.5, 505.6, 511.3, 489.1, 506.6, 507.2, 508.2, 501.7,
#        491.5, 503.4, 482.9, 501.7, 496.8, 485.1, 480.3, 497.8, 499.9,
#        496.5, 496.6, 495.4, 496.1, 509. , 494.4, 489.7, 508.7, 490.2,
#        516.9, 512.8, 480.1, 499. , 495. , 482.7, 528.8, 513.4, 508.1,
#        480.5, 498.5, 509.6, 518.5, 500.9, 509.8, 512.3, 493.9, 476. ,
#        504.2, 502.4, 499.6, 485.3, 480.1, 493.6, 499.2, 496.3, 517.7,
#        508.1, 499.4, 494.7, 496.1, 500.8, 501.2, 509.8, 485.7, 493.7,
#        495.4, 494.9, 500.3, 498. , 496.4, 493.9, 501.5, 488.5, 504.5,
#        504.1, 494.5, 489.9, 496.7, 511.1, 492.1, 501.8, 502.4, 502.2,
#        488.7, 504.8, 509.4, 514.8, 508.6, 511.1, 518.5, 512.8, 502.9,
#        496.3, 502.9, 511.9, 491. , 492.2, 495. , 501.4, 478.6, 503.8,
#        514.4, 501.9, 487.4, 494.4, 491.9, 496.3, 492.6, 513.6, 501.1,
#        493.9, 518.7, 480.9, 513.4, 488.4, 480.7, 493.9, 508.5, 515.2,
#        490.9, 511.1, 491.6, 487.9, 485. , 498.9, 496.4, 489.9, 505.5,
#        490.7, 529.8, 483.4, 493.9, 507.8, 507.9, 501.4, 493.3, 500.5,
#        521.9, 477.8, 496.7, 497.9, 492.2, 497.1, 483.9, 519. , 513.5,
#        508.1, 512.1, 510.4, 493.5, 512.2, 515.5, 502.6, 502.7, 507.2,
#        505.6, 494.2, 508.2, 495.3, 499. , 489.3, 518.4, 496.5, 501.6,
#        495.6, 485.2, 499.4, 491.5, 505.9, 495. , 515.5, 492.9, 519.6,
#        488.2, 494.7, 531.2, 491.5, 498.6, 485.1, 500.1, 495.4, 505.7,
#        479.5, 504.5, 487.2, 497.9, 506. , 500.3, 503.1, 496.9, 494.4,
#        501.5, 500.2, 514.4, 495.7, 486.2, 505.3, 502.4, 518.2, 482.4,
#        503.5, 488.3, 504.4, 514.9, 518.2, 491.9, 482.5, 502.1, 490.6,
#        496.3, 499.7, 501.5, 525.7, 501.4, 500.9, 506.8, 510.9, 492.2,
#        508.3, 499.6, 503.6, 498.9, 501.8, 507.8, 477.7, 497.5, 503.4,
#        484. , 502.3, 496.7, 504.7, 488.8, 486.9, 504.4, 500.2, 486. ,
#        487.5, 488.7, 501.1, 505.9, 496.3, 481.2, 526.8, 493.3, 521.7,
#        511.4, 498.9, 512.9, 488.4, 495.2, 496.8, 479.8, 495.2, 486.6,
#        500.1, 503.3, 503.9, 515.5, 492.3, 493.2, 511.1, 493.3, 496.8,
#        507.5, 490.1, 504. , 490.5, 496. , 501.1, 496.7, 500.5, 484.4,
#        508.5, 491.9, 492.5, 509.4, 495.2, 510. , 468.2, 493.8, 502.8,
#        496.1, 505.2, 504. , 506. , 490.5, 504.2, 513.6, 503. , 504.2,
#        484.3, 511.8, 489. , 486.8, 492.6, 496. , 498.3, 510.9, 512.1,
#        502.9, 487. , 497.2, 515.5, 510.6, 507.3, 509.7, 506.6, 504.4,
#        504.1, 487.4, 482.7, 494.7, 487.6, 501.4, 523.2, 528.6, 510.4,
#        493.1, 510.5, 476.2, 495.3, 500.3, 488.3, 493.6, 502.4, 512.1,
#        483.2, 513.5, 509.9, 509.3, 502.2, 496.2, 496.3, 507.2, 514.8,
#        501.5, 493.4, 515.1, 505.6, 504.3, 507.3, 489.3, 500.9, 498.9,
#        490.8, 501.2, 499. , 503.6, 477.9, 501.6, 516.4, 500.6, 507.5,
#        497.2, 503. , 510.9, 498.4, 495.1, 518.6, 506. , 506.5, 501.2,
#        512.4, 485.1, 504.5, 510.6, 505.4, 499.3, 498.7, 492.1, 490.2,
#        502.9, 506.8, 502.3, 497.9, 482.8, 486.9, 512.8, 508.3, 499.2,
#        499. , 503.2, 490.5, 499.5, 501.5, 499.7, 513.1, 491.5, 503.7,
#        505.5, 512.4, 511.9, 512.7, 499.2, 513.1, 500.1, 511. , 483.5,
#        515.3, 513.5, 503.5, 504.8, 496.7, 504.3, 511.3, 498.8, 508.2,
#        474.8, 507.5, 488.9, 500.6, 493.3, 508.7, 499.6, 497.2, 486. ,
#        495. , 518.2, 496.3, 496.3, 496.3, 516.2, 508.4, 483. , 493.7,
#        513.5, 506.9, 494.9, 506.5, 499.4, 507.9, 515.3, 492.4, 504.6,
#        515.6, 489.8, 505.7, 513.5, 507.6, 477. , 510.4, 509.1, 510.5,
#        502.5, 508.7, 499.1, 509.8, 482.6, 498. , 502.3, 498.3, 481. ,
#        507.5, 499.5, 495.6, 495.7, 497.1, 502.4, 501.9, 511.5, 500.3,
#        515.2, 509. , 496.5, 505.2, 485.9, 488.4, 502.7, 491.4, 508.3,
#        493.3, 501.5, 506.7, 489.1, 524.7, 501.9, 493.6, 514. , 490.5,
#        505.4, 504.6, 488.4, 501. , 502.3, 506.1, 502.3, 504.5, 483.5,
#        501.6, 494.8, 493. , 517.4, 522.6, 507.6, 492.9, 507.3, 485.6,
#        496.4, 498.1, 502.5, 503.6, 495. , 504.6, 493.1, 481.1, 512.4,
#        505.5, 507. , 505.1, 499.9, 505. , 519.1, 510.6, 493.8, 517.9,
#        512.8])

# %%
min(random_bias_normal_distribution1)
# Out:
# np.float64(468.2)

# %%
max(random_bias_normal_distribution1)
# Out:
# np.float64(531.2)

# %%
np.savetxt('1000_Gaussian_distribution_(500,10).txt',random_bias_normal_distribution1,fmt='%0.8f')#数据存储

# %%
beta1= np.loadtxt("1000_normal_distribution_(500,10).txt")
