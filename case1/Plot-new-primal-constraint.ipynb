# %% [markdown]
# # 整理数据 绘图

# %% [raw]
# 噪声方式：大值确定性噪声 小值确定性噪声 无界的递增噪声 大值高斯噪声 小值高斯噪声
# 评价指标：
# 1. 所有用户的资源量和无攻击情况下最优资源量的gap（资源策略的最优性）
# 2. 所有用户的资源约束违反程度 （总资源量的违反程度）

# %% [markdown]
# # 数据导入

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import random
from sympy import *
import math 
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

#数据导入
#IWDGD的所有相关数据
#无噪声 oracle
agent_resource_quantity_oracle = np.loadtxt("./data/agent_resource_quantity_oracle.txt")
sum_resource_oracle=np.loadtxt("./data/sum_resource_oracle.txt")

#非鲁棒算法+大值确定性噪声
agent_resource_quantity_large_value_deterministic_bias = np.loadtxt("./data/01-agent_resource_quantity_large_value_deterministic_bias.txt")
sum_resource_large_value_deterministic_bias=np.loadtxt("./data/01-sum_resource_large_value_deterministic_bias.txt")

#非鲁棒算法+小值确定性噪声
agent_resource_quantity_small_value_deterministic_bias = np.loadtxt("./data/01-agent_resource_quantity_small_value_deterministic_bias.txt")
sum_resource_small_value_deterministic_bias=np.loadtxt("./data/01-sum_resource_small_value_deterministic_bias.txt")

#鲁棒算法+大值确定性噪声
robust_agent_resource_quantity_large_value_deterministic_bias = np.loadtxt("./data/01-robust-agent_resource_quantity_large_value_deterministic_bias.txt")
robust_sum_resource_large_value_deterministic_bias=np.loadtxt("./data/01-robust-sum_resource_large_value_deterministic_bias.txt")

#鲁棒算法+小值确定性噪声
robust_agent_resource_quantity_small_value_deterministic_bias = np.loadtxt("./data/01-robust-agent_resource_quantity_small_value_deterministic_bias.txt")
robust_sum_resource_small_value_deterministic_bias=np.loadtxt("./data/01-robust-sum_resource_small_value_deterministic_bias.txt")

#非鲁棒算法+无界的递增噪声
agent_resource_quantity_unbounded_bias = np.loadtxt("./data/02-agent_resource_quantity_unbounded_bias.txt")
sum_resource_unbounded_bias=np.loadtxt("./data/02-sum_resource_unbounded_bias.txt")

#鲁棒算法+无界的递增噪声
robust_agent_resource_quantity_unbounded_bias = np.loadtxt("./data/02-robust-agent_resource_quantity_unbounded_bias.txt")
robust_sum_resource_unbounded_bias=np.loadtxt("./data/02-robust-sum_resource_unbounded_bias.txt")

#非鲁棒算法+大值高斯分布噪声
agent_resource_quantity_large_value_Gaussian_bias = np.loadtxt("./data/03-agent_resource_quantity_large_value_Gaussian_bias(500,10).txt")
sum_resource_large_value_Gaussian_bias=np.loadtxt("./data/03-sum_resource_large_value_Gaussian_bias(500,10).txt")

#鲁棒算法+大值高斯分布噪声
robust_agent_resource_quantity_large_value_Gaussian_bias = np.loadtxt("./data/03-robust_agent_resource_quantity_large_value_Gaussian_bias(500,10).txt")
robust_sum_resource_large_value_Gaussian_bias=np.loadtxt("./data/03-robust_sum_resource_large_value_Gaussian_bias(500,10).txt")

#非鲁棒算法+小值高斯分布噪声
agent_resource_quantity_small_value_Gaussian_bias = np.loadtxt("./data/03-agent_resource_quantity_small_value_Gaussian_bias(50,10).txt")
sum_resource_small_value_Gaussian_bias=np.loadtxt("./data/03-sum_resource_small_value_Gaussian_bias(50,10).txt") 

#鲁棒算法+小值高斯分布噪声
robust_agent_resource_quantity_small_value_Gaussian_bias = np.loadtxt("./data/03-robust_agent_resource_quantity_small_value_Gaussian_bias(50,10).txt")
robust_sum_resource_small_value_Gaussian_bias=np.loadtxt("./data/03-robust_sum_resource_small_value_Gaussian_bias(50,10).txt") 

#***********************************************************************************************************************
#数据导入
#DGD的所有相关数据
#无噪声 oracle
DGD_agent_resource_quantity_oracle = np.loadtxt("./data/DGD-agent_resource_quantity_oracle.txt")
DGD_sum_resource_oracle=np.loadtxt("./data/DGD-sum_resource_oracle.txt")

#非鲁棒算法+大值确定性噪声
DGD_agent_resource_quantity_large_value_deterministic_bias = np.loadtxt("./data/01-DGD-agent_resource_quantity_large_value_deterministic_bias.txt")
DGD_sum_resource_large_value_deterministic_bias=np.loadtxt("./data/01-DGD-sum_resource_large_value_deterministic_bias.txt")

#非鲁棒算法+小值确定性噪声
DGD_agent_resource_quantity_small_value_deterministic_bias = np.loadtxt("./data/01-DGD-agent_resource_quantity_small_value_deterministic_bias.txt")
DGD_sum_resource_small_value_deterministic_bias=np.loadtxt("./data/01-DGD-sum_resource_small_value_deterministic_bias.txt")

#ARC 
#鲁棒算法+大值确定性噪声
DGD_ARC_robust_agent_resource_quantity_large_value_deterministic_bias = np.loadtxt("./data/01-DGD-ARC-robust-agent_resource_quantity_large_value_deterministic_bias.txt")
DGD_ARC_robust_sum_resource_large_value_deterministic_bias=np.loadtxt("./data/01-DGD-ARC-robust-sum_resource_large_value_deterministic_bias.txt")

#鲁棒算法+小值确定性噪声
DGD_ARC_robust_agent_resource_quantity_small_value_deterministic_bias = np.loadtxt("./data/01-DGD-ARC-robust-agent_resource_quantity_small_value_deterministic_bias.txt")
DGD_ARC_robust_sum_resource_small_value_deterministic_bias=np.loadtxt("./data/01-DGD-ARC-robust-sum_resource_small_value_deterministic_bias.txt")

#CTM 
#鲁棒算法+大值确定性噪声
DGD_CTM_robust_agent_resource_quantity_large_value_deterministic_bias = np.loadtxt("./data/01-DGD-CTM-robust-agent_resource_quantity_large_value_deterministic_bias.txt")
DGD_CTM_robust_sum_resource_large_value_deterministic_bias=np.loadtxt("./data/01-DGD-CTM-robust-sum_resource_large_value_deterministic_bias.txt")

#鲁棒算法+小值确定性噪声
DGD_CTM_robust_agent_resource_quantity_small_value_deterministic_bias = np.loadtxt("./data/01-DGD-CTM-robust-agent_resource_quantity_small_value_deterministic_bias.txt")
DGD_CTM_robust_sum_resource_small_value_deterministic_bias=np.loadtxt("./data/01-DGD-CTM-robust-sum_resource_small_value_deterministic_bias.txt")

#IOS
#鲁棒算法+大值确定性噪声
DGD_IOS_robust_agent_resource_quantity_large_value_deterministic_bias = np.loadtxt("./data/01-DGD-IOS-robust-agent_resource_quantity_large_value_deterministic_bias.txt")
DGD_IOS_robust_sum_resource_large_value_deterministic_bias=np.loadtxt("./data/01-DGD-IOS-robust-sum_resource_large_value_deterministic_bias.txt")

#鲁棒算法+小值确定性噪声
DGD_IOS_robust_agent_resource_quantity_small_value_deterministic_bias = np.loadtxt("./data/01-DGD-IOS-robust-agent_resource_quantity_small_value_deterministic_bias.txt")
DGD_IOS_robust_sum_resource_small_value_deterministic_bias=np.loadtxt("./data/01-DGD-IOS-robust-sum_resource_small_value_deterministic_bias.txt")

# %% [markdown]
# # 相关数据计算

# %% [markdown]
# IWDGD的所有相关数据

# %% [markdown]
# 大值确定性误差

# %% [markdown]
# 1. 所有用户的资源量和无攻击情况下最优资源量的gap（资源策略的最优性）

# %%
#非鲁棒 
agent_resource_quantity_large_value_deterministic_bias_gap=[]  
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(agent_resource_quantity_large_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    agent_resource_quantity_large_value_deterministic_bias_gap.append(np.sqrt(sum))

# %%
#鲁棒
robust_agent_resource_quantity_large_value_deterministic_bias_gap=[]  
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(robust_agent_resource_quantity_large_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    robust_agent_resource_quantity_large_value_deterministic_bias_gap.append(np.sqrt(sum))

# %% [raw]
# 2. 所有用户的资源约束违反程度（总资源量的违反程度）

# %%
#非鲁棒 
sum_resource_large_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    sum_resource_large_value_deterministic_bias_gap.append(np.abs(sum_resource_large_value_deterministic_bias[k]-5000))

# %%
#鲁棒 
robust_sum_resource_large_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    robust_sum_resource_large_value_deterministic_bias_gap.append(np.abs(robust_sum_resource_large_value_deterministic_bias[k]-5000))

# %% [markdown]
# 小值确定性误差

# %% [markdown]
# 1. 所有用户的资源量和无攻击情况下最优资源量的gap（资源策略的最优性）

# %%
#非鲁棒 
agent_resource_quantity_small_value_deterministic_bias_gap=[]  
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(agent_resource_quantity_small_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])**2  
    agent_resource_quantity_small_value_deterministic_bias_gap.append(np.sqrt(sum))

# %%
#鲁棒
robust_agent_resource_quantity_small_value_deterministic_bias_gap=[]  
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(robust_agent_resource_quantity_small_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    robust_agent_resource_quantity_small_value_deterministic_bias_gap.append(np.sqrt(sum))

# %% [markdown]
# 2. 所有用户的资源约束违反程度（总资源量的违反程度）

# %%
#非鲁棒 
sum_resource_small_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    sum_resource_small_value_deterministic_bias_gap.append(np.abs(sum_resource_small_value_deterministic_bias[k]-5000))

# %%
#鲁棒 
robust_sum_resource_small_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    robust_sum_resource_small_value_deterministic_bias_gap.append(np.abs(robust_sum_resource_small_value_deterministic_bias[k]-5000))

# %% [markdown]
# 无界的递增噪声

# %% [markdown]
# 1. 所有用户的资源量和无攻击情况下最优资源量的gap（资源策略的最优性）

# %%
#非鲁棒 
agent_resource_quantity_unbounded_bias_gap=[]  
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(agent_resource_quantity_unbounded_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    agent_resource_quantity_unbounded_bias_gap.append(np.sqrt(sum))

# %%
#鲁棒
robust_agent_resource_quantity_unbounded_bias_gap=[]  
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(robust_agent_resource_quantity_unbounded_bias[i][k]-agent_resource_quantity_oracle[i][999])**2   
    robust_agent_resource_quantity_unbounded_bias_gap.append(np.sqrt(sum))

# %% [markdown]
# 2. 所有用户的资源约束违反程度（总资源量的违反程度）

# %%
#非鲁棒 
sum_resource_unbounded_bias_gap=[]
for k in range(0,1000): 
    sum_resource_unbounded_bias_gap.append(np.abs(sum_resource_unbounded_bias[k]-5000))

# %%
#鲁棒 
robust_sum_resource_unbounded_bias_gap=[]
for k in range(0,1000): 
    robust_sum_resource_unbounded_bias_gap.append(np.abs(robust_sum_resource_unbounded_bias[k]-5000))

# %% [markdown]
# 大值高斯分布噪声

# %% [markdown]
# 1. 所有用户的资源量和无攻击情况下最优资源量的gap（资源策略的最优性）

# %%
#非鲁棒 
agent_resource_quantity_large_value_Gaussian_bias_gap=[]  
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(agent_resource_quantity_large_value_Gaussian_bias[i][k]-agent_resource_quantity_oracle[i][999])**2   
    agent_resource_quantity_large_value_Gaussian_bias_gap.append(np.sqrt(sum))

# %%
#鲁棒
robust_agent_resource_quantity_large_value_Gaussian_bias_gap=[]   
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(robust_agent_resource_quantity_large_value_Gaussian_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    robust_agent_resource_quantity_large_value_Gaussian_bias_gap.append(np.sqrt(sum))

# %% [markdown]
# 2. 所有用户的资源约束违反程度（总资源量的违反程度）

# %%
#非鲁棒 
sum_resource_large_value_Gaussian_bias_gap=[]
for k in range(0,1000): 
    sum_resource_large_value_Gaussian_bias_gap.append(np.abs(sum_resource_large_value_Gaussian_bias[k]-5000))

# %%
#鲁棒 
robust_sum_resource_large_value_Gaussian_bias_gap=[]
for k in range(0,1000): 
    robust_sum_resource_large_value_Gaussian_bias_gap.append(np.abs(robust_sum_resource_large_value_Gaussian_bias[k]-5000))

# %% [markdown]
# 小值高斯分布噪声

# %% [markdown]
# 1. 所有用户的资源量和无攻击情况下最优资源量的gap（资源策略的最优性）

# %%
#非鲁棒 
agent_resource_quantity_small_value_Gaussian_bias_gap=[]  
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(agent_resource_quantity_small_value_Gaussian_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    agent_resource_quantity_small_value_Gaussian_bias_gap.append(np.sqrt(sum))

# %%
#鲁棒
robust_agent_resource_quantity_small_value_Gaussian_bias_gap=[]  
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(robust_agent_resource_quantity_small_value_Gaussian_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    robust_agent_resource_quantity_small_value_Gaussian_bias_gap.append(np.sqrt(sum))

# %% [markdown]
# 2. 所有用户的资源约束违反程度（总资源量的违反程度）

# %%
#非鲁棒 
sum_resource_small_value_Gaussian_bias_gap=[]
for k in range(0,1000): 
    sum_resource_small_value_Gaussian_bias_gap.append(np.abs(sum_resource_small_value_Gaussian_bias[k]-5000))

# %%
#鲁棒 
robust_sum_resource_small_value_Gaussian_bias_gap=[]
for k in range(0,1000): 
    robust_sum_resource_small_value_Gaussian_bias_gap.append(np.abs(robust_sum_resource_small_value_Gaussian_bias[k]-5000))

# %% [markdown]
# DGD的所有相关数据

# %% [markdown]
# 1. 大值确定性误差

# %% [markdown]
# 所有用户的资源量和无攻击情况下最优资源量的gap（资源策略的最优性）

# %%
#非鲁棒 
DGD_agent_resource_quantity_large_value_deterministic_bias_gap=[]  
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(DGD_agent_resource_quantity_large_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    DGD_agent_resource_quantity_large_value_deterministic_bias_gap.append(np.sqrt(sum))

# %%
#鲁棒 ARC
DGD_ARC_robust_agent_resource_quantity_large_value_deterministic_bias_gap=[]  
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(DGD_ARC_robust_agent_resource_quantity_large_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    DGD_ARC_robust_agent_resource_quantity_large_value_deterministic_bias_gap.append(np.sqrt(sum))

# %%
#鲁棒 CTM
DGD_CTM_robust_agent_resource_quantity_large_value_deterministic_bias_gap=[]  
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(DGD_CTM_robust_agent_resource_quantity_large_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    DGD_CTM_robust_agent_resource_quantity_large_value_deterministic_bias_gap.append(np.sqrt(sum))

# %%
#鲁棒 IOS
DGD_IOS_robust_agent_resource_quantity_large_value_deterministic_bias_gap=[]   
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(DGD_IOS_robust_agent_resource_quantity_large_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    DGD_IOS_robust_agent_resource_quantity_large_value_deterministic_bias_gap.append(np.sqrt(sum))

# %% [markdown]
# 2. 所有用户的资源约束违反程度（总资源量的违反程度）

# %%
#非鲁棒 
DGD_sum_resource_large_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    DGD_sum_resource_large_value_deterministic_bias_gap.append(np.abs(DGD_sum_resource_large_value_deterministic_bias[k]-5000))

# %%
#鲁棒 ARC
DGD_ARC_robust_sum_resource_large_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    DGD_ARC_robust_sum_resource_large_value_deterministic_bias_gap.append(np.abs(DGD_ARC_robust_sum_resource_large_value_deterministic_bias[k]-5000))

# %%
#鲁棒 CTM
DGD_CTM_robust_sum_resource_large_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    DGD_CTM_robust_sum_resource_large_value_deterministic_bias_gap.append(np.abs(DGD_CTM_robust_sum_resource_large_value_deterministic_bias[k]-5000))

# %%
#鲁棒 IOS
DGD_IOS_robust_sum_resource_large_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    DGD_IOS_robust_sum_resource_large_value_deterministic_bias_gap.append(np.abs(DGD_IOS_robust_sum_resource_large_value_deterministic_bias[k]-5000))

# %% [markdown]
# 小值确定性误差

# %% [markdown]
# 1. 所有用户的资源量和无攻击情况下最优资源量的gap（资源策略的最优性）

# %%
#非鲁棒 
DGD_agent_resource_quantity_small_value_deterministic_bias_gap=[]  
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(DGD_agent_resource_quantity_small_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    DGD_agent_resource_quantity_small_value_deterministic_bias_gap.append(np.sqrt(sum))

# %%
#鲁棒 ARC
DGD_ARC_robust_agent_resource_quantity_small_value_deterministic_bias_gap=[]   
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(DGD_ARC_robust_agent_resource_quantity_small_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    DGD_ARC_robust_agent_resource_quantity_small_value_deterministic_bias_gap.append(np.sqrt(sum))

# %%
#鲁棒 CTM
DGD_CTM_robust_agent_resource_quantity_small_value_deterministic_bias_gap=[]  
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(DGD_CTM_robust_agent_resource_quantity_small_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    DGD_CTM_robust_agent_resource_quantity_small_value_deterministic_bias_gap.append(np.sqrt(sum))

# %%
#鲁棒 IOS
DGD_IOS_robust_agent_resource_quantity_small_value_deterministic_bias_gap=[]   
for k in range(0,1000):
    sum=0
    for i in range(0,100):
        sum=sum+(DGD_IOS_robust_agent_resource_quantity_small_value_deterministic_bias[i][k]-agent_resource_quantity_oracle[i][999])**2    
    DGD_IOS_robust_agent_resource_quantity_small_value_deterministic_bias_gap.append(np.sqrt(sum))

# %% [markdown]
# 2. 所有用户的资源约束违反程度（总资源量的违反程度）

# %%
#非鲁棒 
DGD_sum_resource_small_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    DGD_sum_resource_small_value_deterministic_bias_gap.append(np.abs(DGD_sum_resource_small_value_deterministic_bias[k]-5000))

# %%
#鲁棒 ARC
DGD_ARC_robust_sum_resource_small_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    DGD_ARC_robust_sum_resource_small_value_deterministic_bias_gap.append(np.abs(DGD_ARC_robust_sum_resource_small_value_deterministic_bias[k]-5000))

# %%
#鲁棒 CTM
DGD_CTM_robust_sum_resource_small_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    DGD_CTM_robust_sum_resource_small_value_deterministic_bias_gap.append(np.abs(DGD_CTM_robust_sum_resource_small_value_deterministic_bias[k]-5000))

# %%
#鲁棒 IOS
DGD_IOS_robust_sum_resource_small_value_deterministic_bias_gap=[]
for k in range(0,1000): 
    DGD_IOS_robust_sum_resource_small_value_deterministic_bias_gap.append(np.abs(DGD_IOS_robust_sum_resource_small_value_deterministic_bias[k]-5000))

# %% [markdown]
# # 绘图

# %%
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

# %%
sub1=plt.subplot(2, 4, 1)##############################################################
#大值确定性噪声+资源策略最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],agent_resource_quantity_large_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'magenta',linewidth = '3',label='fault-free')
B,=plt.plot(iteration[slice(0,499,20)],robust_agent_resource_quantity_large_value_deterministic_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'green',linewidth = '3',label='proposed')
C,=plt.plot(iteration[slice(0,499,20)],DGD_ARC_robust_agent_resource_quantity_large_value_deterministic_bias_gap[slice(0,500,20)],marker = 's',markersize=10,color = 'deepskyblue',linewidth = '3',label='DGD+CRC')
D,=plt.plot(iteration[slice(0,499,20)],DGD_CTM_robust_agent_resource_quantity_large_value_deterministic_bias_gap[slice(0,500,20)],marker = '>',markersize=10,color = 'orange',linewidth = '3',label='DGD+CTM')
E,=plt.plot(iteration[slice(0,499,20)],DGD_IOS_robust_agent_resource_quantity_large_value_deterministic_bias_gap[slice(0,500,20)],marker = 'o',markersize=10,color = 'palevioletred',linewidth = '3',label='DGD+IOS')
#设置图例并且设置图例的字体及大
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.ylabel('resource optimality gap',font)
plt.title('large deterministic errors',font) 
#plt.ylim(-20,250)
#plt.xlabel('number of iterations',font)


sub2=plt.subplot(2, 4, 2)##############################################################
#小值确定性噪声+资源策略最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],agent_resource_quantity_small_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'magenta',linewidth = '3',label='fault-free')
B,=plt.plot(iteration[slice(0,499,20)],robust_agent_resource_quantity_small_value_deterministic_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'green',linewidth = '3',label='proposed')
C,=plt.plot(iteration[slice(0,499,20)],DGD_ARC_robust_agent_resource_quantity_small_value_deterministic_bias_gap[slice(0,500,20)],marker = 's',markersize=10,color = 'deepskyblue',linewidth = '3',label='DGD+CRC')
D,=plt.plot(iteration[slice(0,499,20)],DGD_CTM_robust_agent_resource_quantity_small_value_deterministic_bias_gap[slice(0,500,20)],marker = '>',markersize=10,color = 'orange',linewidth = '3',label='DGD+CTM')
E,=plt.plot(iteration[slice(0,499,20)],DGD_IOS_robust_agent_resource_quantity_small_value_deterministic_bias_gap[slice(0,500,20)],marker = 'o',markersize=10,color = 'palevioletred',linewidth = '3',label='DGD+IOS')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.title('small deterministic errors',font)
#plt.ylim(-20,250)
#plt.ylabel('resource optimality gap',font)
#plt.xlabel('number of iterations',font)


sub3=plt.subplot(2, 4, 3)##############################################################
#大值高斯噪声+资源策略最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],agent_resource_quantity_large_value_Gaussian_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'magenta',linewidth = '3',label='fault-free')
B,=plt.plot(iteration[slice(0,499,20)],robust_agent_resource_quantity_large_value_Gaussian_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'green',linewidth = '3',label='proposed')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
#plt.ylabel('resource optimality gap',font)
plt.title('large Gaussian errors',font) 
#plt.xlabel('number of iterations',font)

sub4=plt.subplot(2, 4, 4)##############################################################
#小值高斯噪声+资源策略最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],agent_resource_quantity_small_value_Gaussian_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'magenta',linewidth = '3',label='fault-free')
B,=plt.plot(iteration[slice(0,499,20)],robust_agent_resource_quantity_small_value_Gaussian_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'green',linewidth = '3',label='proposed')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.title('small Gaussian errors',font)
#plt.ylabel('resource optimality gap',font)
#plt.xlabel('number of iterations',font)

sub5=plt.subplot(2, 4, 5)##############################################################
#大值确定性噪声+约束违反
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

#A,=plt.plot(iteration[slice(0,499,20)],sum_resource_large_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'magenta',linewidth = '3',label='Bias-free IWDGD')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_resource_large_value_deterministic_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'green',linewidth = '3',label='proposed')
C,=plt.plot(iteration[slice(0,499,20)],DGD_ARC_robust_sum_resource_large_value_deterministic_bias_gap[slice(0,500,20)],marker = 's',markersize=10,color = 'deepskyblue',linewidth = '3',label='DGD+CRC')
D,=plt.plot(iteration[slice(0,499,20)],DGD_CTM_robust_sum_resource_large_value_deterministic_bias_gap[slice(0,500,20)],marker = '>',markersize=10,color = 'orange',linewidth = '3',label='DGD+CTM')
E,=plt.plot(iteration[slice(0,499,20)],DGD_IOS_robust_sum_resource_large_value_deterministic_bias_gap[slice(0,500,20)],marker = 'o',markersize=10,color = 'palevioletred',linewidth = '3',label='DGD+IOS')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
#plt.title('large deterministic errors',font) 
plt.ylabel('constraint violation',font)
plt.xlabel('number of iterations',font)

sub6=plt.subplot(2, 4, 6)##############################################################
#小值确定性噪声+约束违反
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

#在同一幅图片上画4条折线
#A,=plt.plot(iteration[slice(0,499,20)],sum_resource_small_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'magenta',linewidth = '3',label='Bias-free IWDGD')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_resource_small_value_deterministic_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'green',linewidth = '3',label='proposed')
C,=plt.plot(iteration[slice(0,499,20)],DGD_ARC_robust_sum_resource_small_value_deterministic_bias_gap[slice(0,500,20)],marker = 's',markersize=10,color = 'deepskyblue',linewidth = '3',label='DGD+CRC')
D,=plt.plot(iteration[slice(0,499,20)],DGD_CTM_robust_sum_resource_small_value_deterministic_bias_gap[slice(0,500,20)],marker = '>',markersize=10,color = 'orange',linewidth = '3',label='DGD+CTM')
E,=plt.plot(iteration[slice(0,499,20)],DGD_IOS_robust_sum_resource_small_value_deterministic_bias_gap[slice(0,500,20)],marker = 'o',markersize=10,color = 'palevioletred',linewidth = '3',label='DGD+IOS')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
plt.tick_params(labelsize=30)
plt.xlabel('number of iterations',font)
#plt.ylabel('constraint violation',font)
#plt.title('small deterministic errors',font)

sub7=plt.subplot(2, 4, 7)##############################################################
#大值高斯噪声+约束违反
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

#A,=plt.plot(iteration[slice(0,499,20)],sum_resource_large_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'magenta',linewidth = '3',label='Bias-free IWDGD')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_resource_large_value_Gaussian_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'green',linewidth = '3',label='proposed')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
#plt.title('large Gaussian errors',font) 
#plt.ylabel('constraint violation',font)
plt.xlabel('number of iterations',font)
plt.ylim(-2,2)

sub8=plt.subplot(2, 4, 8)##############################################################
#小值高斯噪声+约束违反
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

#在同一幅图片上画4条折线
#A,=plt.plot(iteration[slice(0,499,20)],sum_resource_small_value_deterministic_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'magenta',alpha=0.5,linewidth = '3',label='Bias-free IWDGD')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_resource_small_value_Gaussian_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'green', linewidth = '3',label='proposed')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
plt.tick_params(labelsize=30)
plt.xlabel('number of iterations',font)
#plt.ylabel('constraint violation',font)
#plt.title('small Gaussian errors',font)
plt.ylim(-2,2)

#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
plt.legend(handles=[A,B,C,D,E],prop={'size':39},loc="upper center", bbox_to_anchor=[-1.25, -0.2],
           ncol=18, shadow=True, fancybox=True)

sub1.set_xticklabels([])
sub2.set_xticklabels([])
sub3.set_xticklabels([])
sub4.set_xticklabels([])

plt.subplots_adjust(wspace=0.15,hspace=0.02) 
plt.gcf().set_size_inches((38, 15))

plt.savefig('./figures/figure-deterministic-Gaussian-error.pdf',format='pdf', bbox_inches='tight')
plt.savefig('./figures/figure-deterministicG-aussian-error.png',format='png', bbox_inches='tight')

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
#无界递增噪声+资源策略最优性
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

A,=plt.plot(iteration[slice(0,499,20)],agent_resource_quantity_unbounded_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'magenta',linewidth = '3',label='fault-free')
B,=plt.plot(iteration[slice(0,499,20)],robust_agent_resource_quantity_unbounded_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'green',linewidth = '3',label='proposed')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 58,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=40)
plt.xlabel('number of iterations',font)
plt.ylabel('resource optimality gap',font)
plt.title('linearly increasing errors',font) 

sub2=plt.subplot(1, 2, 2)##############################################################
#无界递增噪声+约束违反
iteration=[]
iteration.append(0)
for i in range(0,499):
    iteration.append(i)

#A,=plt.plot(iteration[slice(0,499,20)],sum_resource_unbounded_bias_gap[slice(0,500,20)],marker = 'D',markersize=10,color = 'magenta',linewidth = '3',label='Bias-free IWDGD')
B,=plt.plot(iteration[slice(0,499,20)],robust_sum_resource_unbounded_bias_gap[slice(0,500,20)],marker = '*',markersize=10,color = 'green',linewidth = '3',label='proposed')

#设置图例并且设置图例的字体及大小
font = {
'size'   : 58,
'family': 'Times New Roman'
}
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=40)
plt.xlabel('number of iterations',font)
plt.ylabel('constraint violation',font)
plt.title('linearly increasing errors',font)
plt.ylim(-2,2)


#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=40)
plt.legend(handles=[A,B],prop={'size':55},loc="upper center", bbox_to_anchor=[-0.1, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.2,hspace=0.05) 
plt.gcf().set_size_inches((25, 10))

plt.savefig('./figures/figure-unbounded-error.pdf',format='pdf', bbox_inches='tight')
plt.savefig('./figures/figure-unbounded-error.png',format='png', bbox_inches='tight')
