# %% [markdown]
# DGD+部分用户的对偶计算有误差
# 为了对比实验的公平性 要保证噪声的效果和IWDGD算法中噪声的效果尽可能一致
# 主要是观察噪声对对偶变量的影响是否一致

# %% [markdown]
# IWDGD中小值的确定性噪声 对应到DGD算法中是固定的对偶攻击值为-140.7 这样两个算法各自迭代1000次 所有用户的对偶迭代值均在140.2附近

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(100,1000)) #100个agent的资源量 定义成一个矩阵 100*20000
dual_variable = np.zeros(shape=(100,1000))#对偶变量
sum_resource=np.zeros(shape=(1,1000), dtype=np.float64)#存放每一次迭代后所有用户资源量的总和
sum_cost=np.zeros(shape=(1,1000), dtype=np.float64)#存放每一次迭代后所有用户成本的总和
iteration_update = 0.01#迭代步长
A=np.loadtxt("100_Network_Topology_Double_Random_Adjacency_Matrix_Degree_15.txt") #网络拓扑的邻接矩阵 对角元素要为0
W=np.zeros(shape=(100,100)) #双随机的网络拓扑矩阵W（对角线处非零）
iteration=[]#绘图横坐标
a=np.loadtxt("100_uniform_distribution_(1,2)_point1.txt")#每个agent的成本函数中的超参数
b=np.loadtxt("100_normal_distribution_(2,0.6)_point1.txt")#每个agent的成本函数中的超参数
#bias=-3

# %%
#根据邻接矩阵生成网络对应的双随机的权重混合矩阵
for i in range(0,100):
    for j in range(0,100):
        if A[i][j]!=0 or i==j:
            W[i][j]=1/16

#对偶变量的初始化 初始化一致
for i in range (0,100):
    #if i==7 or i==20 or i==34:
        #dual_variable[i][0]=0+bias
        #dual_variable[i][0]=-152.8
    #else:
    dual_variable[i][0]=0
    
#资源量的初始化 资源量的初始化需要和对偶变量的初始值满足某种关系
for i in range (0,100):
    agent_resource_quantity[i][0]=50

iteration.append(0)

#总资源量 初始化
sum=0
for i in range (0,100):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

#用户总成本初始化
sum=0
for i in range(0,100):
    sum=sum+a[i]*(agent_resource_quantity[i][0]-b[i])*(agent_resource_quantity[i][0]-b[i])
sum_cost[0][0]=sum

# %%
#DGD算法 
def DGD_deterministic_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************DGD算法+计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,100):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    for i in range(0,100):
        print("agent",(i+1),"的初始对偶变量为:",dual_variable[i][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):#迭代次数
        iteration.append(k)
        
        #所有用户对偶变量的迭代 
        #阶段一：梯度下降
        dual_variable_intermediate=[] #存放当前迭代中100个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,100):
            #每个用户对对偶变量先进行一次梯度下降
            if i==7 or i==20 or i==34:
                dual_variable_intermediate.append(-140.7)
            else:
                dual_variable_intermediate.append(dual_variable[i][k-1]-iteration_update*(50-agent_resource_quantity[i][k-1]))       
        #阶段二：聚合 每个用户聚合自身以及邻居的对偶值   
        for i in range(0,100):
            mix_sum_dual=0
            for j in range(0,100):
                if W[i][j]!=0:
                    mix_sum_dual=mix_sum_dual+W[i][j]*dual_variable_intermediate[j]
                dual_variable[i][k]=mix_sum_dual
        
        #用户资源申请量的迭代
        for i in range (0,100):
            agent_resource_quantity[i][k]=(dual_variable[i][k]-2*a[i]*b[i])/(-2*a[i])

        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,100):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,100):
            sum2=sum2+a[i]*(agent_resource_quantity[i][k]-b[i])*(agent_resource_quantity[i][k]-b[i])
        sum_cost[0][k]=sum2
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%50==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,100):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            for i in range(0,100):
                print("agent",(i+1),"在",k,"次迭代中的对偶变量为:",dual_variable[i][k])   
            print("*************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        iteration_update=1/(pow(k+1,0.6)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
DGD_deterministic_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration)
# Out:
# ****************************DGD算法+计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 50.0
# agent 2 的初始资源申请量为: 50.0
# agent 3 的初始资源申请量为: 50.0
# agent 4 的初始资源申请量为: 50.0
# agent 5 的初始资源申请量为: 50.0
# agent 6 的初始资源申请量为: 50.0
# agent 7 的初始资源申请量为: 50.0
# agent 8 的初始资源申请量为: 50.0
# agent 9 的初始资源申请量为: 50.0
# agent 10 的初始资源申请量为: 50.0
# agent 11 的初始资源申请量为: 50.0
# agent 12 的初始资源申请量为: 50.0
# agent 13 的初始资源申请量为: 50.0
# agent 14 的初始资源申请量为: 50.0
# agent 15 的初始资源申请量为: 50.0
# agent 16 的初始资源申请量为: 50.0
# agent 17 的初始资源申请量为: 50.0
# agent 18 的初始资源申请量为: 50.0
# agent 19 的初始资源申请量为: 50.0
# agent 20 的初始资源申请量为: 50.0
# agent 21 的初始资源申请量为: 50.0
# agent 22 的初始资源申请量为: 50.0
# agent 23 的初始资源申请量为: 50.0
# agent 24 的初始资源申请量为: 50.0
# agent 25 的初始资源申请量为: 50.0
# agent 26 的初始资源申请量为: 50.0
# agent 27 的初始资源申请量为: 50.0
# agent 28 的初始资源申请量为: 50.0
# agent 29 的初始资源申请量为: 50.0
# agent 30 的初始资源申请量为: 50.0
# agent 31 的初始资源申请量为: 50.0
# agent 32 的初始资源申请量为: 50.0
# agent 33 的初始资源申请量为: 50.0
# agent 34 的初始资源申请量为: 50.0
# agent 35 的初始资源申请量为: 50.0
# agent 36 的初始资源申请量为: 50.0
# agent 37 的初始资源申请量为: 50.0
# agent 38 的初始资源申请量为: 50.0
# agent 39 的初始资源申请量为: 50.0
# agent 40 的初始资源申请量为: 50.0
# agent 41 的初始资源申请量为: 50.0
# agent 42 的初始资源申请量为: 50.0
# agent 43 的初始资源申请量为: 50.0
# agent 44 的初始资源申请量为: 50.0
# agent 45 的初始资源申请量为: 50.0
# agent 46 的初始资源申请量为: 50.0
# agent 47 的初始资源申请量为: 50.0
# agent 48 的初始资源申请量为: 50.0
# agent 49 的初始资源申请量为: 50.0
# agent 50 的初始资源申请量为: 50.0
# agent 51 的初始资源申请量为: 50.0
# agent 52 的初始资源申请量为: 50.0
# agent 53 的初始资源申请量为: 50.0
# agent 54 的初始资源申请量为: 50.0
# agent 55 的初始资源申请量为: 50.0
# agent 56 的初始资源申请量为: 50.0
# agent 57 的初始资源申请量为: 50.0
# agent 58 的初始资源申请量为: 50.0
# agent 59 的初始资源申请量为: 50.0
# agent 60 的初始资源申请量为: 50.0
# agent 61 的初始资源申请量为: 50.0
# agent 62 的初始资源申请量为: 50.0
# agent 63 的初始资源申请量为: 50.0
# agent 64 的初始资源申请量为: 50.0
# agent 65 的初始资源申请量为: 50.0
# agent 66 的初始资源申请量为: 50.0
# agent 67 的初始资源申请量为: 50.0
# agent 68 的初始资源申请量为: 50.0
# agent 69 的初始资源申请量为: 50.0
# agent 70 的初始资源申请量为: 50.0
# agent 71 的初始资源申请量为: 50.0
# agent 72 的初始资源申请量为: 50.0
# agent 73 的初始资源申请量为: 50.0
# agent 74 的初始资源申请量为: 50.0
# agent 75 的初始资源申请量为: 50.0
# agent 76 的初始资源申请量为: 50.0
# agent 77 的初始资源申请量为: 50.0
# agent 78 的初始资源申请量为: 50.0
# agent 79 的初始资源申请量为: 50.0
# agent 80 的初始资源申请量为: 50.0
# agent 81 的初始资源申请量为: 50.0
# agent 82 的初始资源申请量为: 50.0
# agent 83 的初始资源申请量为: 50.0
# agent 84 的初始资源申请量为: 50.0
# agent 85 的初始资源申请量为: 50.0
# agent 86 的初始资源申请量为: 50.0
# agent 87 的初始资源申请量为: 50.0
# agent 88 的初始资源申请量为: 50.0
# agent 89 的初始资源申请量为: 50.0
# agent 90 的初始资源申请量为: 50.0
# agent 91 的初始资源申请量为: 50.0
# agent 92 的初始资源申请量为: 50.0
# agent 93 的初始资源申请量为: 50.0
# agent 94 的初始资源申请量为: 50.0
# agent 95 的初始资源申请量为: 50.0
# agent 96 的初始资源申请量为: 50.0
# agent 97 的初始资源申请量为: 50.0
# agent 98 的初始资源申请量为: 50.0
# agent 99 的初始资源申请量为: 50.0
# agent 100 的初始资源申请量为: 50.0
# *************************
# 初始资源申请量总和为: 5000.0
# *************************
# 初始成本总和为: 346654.5889999999
# *************************
# agent 1 的初始对偶变量为: 0.0
# agent 2 的初始对偶变量为: 0.0
# agent 3 的初始对偶变量为: 0.0
# agent 4 的初始对偶变量为: 0.0
# agent 5 的初始对偶变量为: 0.0
# agent 6 的初始对偶变量为: 0.0
# agent 7 的初始对偶变量为: 0.0
# agent 8 的初始对偶变量为: 0.0
# agent 9 的初始对偶变量为: 0.0
# agent 10 的初始对偶变量为: 0.0
# agent 11 的初始对偶变量为: 0.0
# agent 12 的初始对偶变量为: 0.0
# agent 13 的初始对偶变量为: 0.0
# agent 14 的初始对偶变量为: 0.0
# agent 15 的初始对偶变量为: 0.0
# agent 16 的初始对偶变量为: 0.0
# agent 17 的初始对偶变量为: 0.0
# agent 18 的初始对偶变量为: 0.0
# agent 19 的初始对偶变量为: 0.0
# agent 20 的初始对偶变量为: 0.0
# agent 21 的初始对偶变量为: 0.0
# agent 22 的初始对偶变量为: 0.0
# agent 23 的初始对偶变量为: 0.0
# agent 24 的初始对偶变量为: 0.0
# agent 25 的初始对偶变量为: 0.0
# agent 26 的初始对偶变量为: 0.0
# agent 27 的初始对偶变量为: 0.0
# agent 28 的初始对偶变量为: 0.0
# agent 29 的初始对偶变量为: 0.0
# agent 30 的初始对偶变量为: 0.0
# agent 31 的初始对偶变量为: 0.0
# agent 32 的初始对偶变量为: 0.0
# agent 33 的初始对偶变量为: 0.0
# agent 34 的初始对偶变量为: 0.0
# agent 35 的初始对偶变量为: 0.0
# agent 36 的初始对偶变量为: 0.0
# agent 37 的初始对偶变量为: 0.0
# agent 38 的初始对偶变量为: 0.0
# agent 39 的初始对偶变量为: 0.0
# agent 40 的初始对偶变量为: 0.0
# agent 41 的初始对偶变量为: 0.0
# agent 42 的初始对偶变量为: 0.0
# agent 43 的初始对偶变量为: 0.0
# agent 44 的初始对偶变量为: 0.0
# agent 45 的初始对偶变量为: 0.0
# agent 46 的初始对偶变量为: 0.0
# agent 47 的初始对偶变量为: 0.0
# agent 48 的初始对偶变量为: 0.0
# agent 49 的初始对偶变量为: 0.0
# agent 50 的初始对偶变量为: 0.0
# agent 51 的初始对偶变量为: 0.0
# agent 52 的初始对偶变量为: 0.0
# agent 53 的初始对偶变量为: 0.0
# agent 54 的初始对偶变量为: 0.0
# agent 55 的初始对偶变量为: 0.0
# agent 56 的初始对偶变量为: 0.0
# agent 57 的初始对偶变量为: 0.0
# agent 58 的初始对偶变量为: 0.0
# agent 59 的初始对偶变量为: 0.0
# agent 60 的初始对偶变量为: 0.0
# agent 61 的初始对偶变量为: 0.0
# agent 62 的初始对偶变量为: 0.0
# agent 63 的初始对偶变量为: 0.0
# agent 64 的初始对偶变量为: 0.0
# agent 65 的初始对偶变量为: 0.0
# agent 66 的初始对偶变量为: 0.0
# agent 67 的初始对偶变量为: 0.0
# agent 68 的初始对偶变量为: 0.0
# agent 69 的初始对偶变量为: 0.0
# agent 70 的初始对偶变量为: 0.0
# agent 71 的初始对偶变量为: 0.0
# agent 72 的初始对偶变量为: 0.0
# agent 73 的初始对偶变量为: 0.0
# agent 74 的初始对偶变量为: 0.0
# agent 75 的初始对偶变量为: 0.0
# agent 76 的初始对偶变量为: 0.0
# agent 77 的初始对偶变量为: 0.0
# agent 78 的初始对偶变量为: 0.0
# agent 79 的初始对偶变量为: 0.0
# agent 80 的初始对偶变量为: 0.0
# agent 81 的初始对偶变量为: 0.0
# agent 82 的初始对偶变量为: 0.0
# agent 83 的初始对偶变量为: 0.0
# agent 84 的初始对偶变量为: 0.0
# agent 85 的初始对偶变量为: 0.0
# agent 86 的初始对偶变量为: 0.0
# agent 87 的初始对偶变量为: 0.0
# agent 88 的初始对偶变量为: 0.0
# agent 89 的初始对偶变量为: 0.0
# agent 90 的初始对偶变量为: 0.0
# agent 91 的初始对偶变量为: 0.0
# agent 92 的初始对偶变量为: 0.0
# agent 93 的初始对偶变量为: 0.0
# agent 94 的初始对偶变量为: 0.0
# agent 95 的初始对偶变量为: 0.0
# agent 96 的初始对偶变量为: 0.0
# agent 97 的初始对偶变量为: 0.0
# agent 98 的初始对偶变量为: 0.0
# agent 99 的初始对偶变量为: 0.0
# agent 100 的初始对偶变量为: 0.0
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 49 次迭代中的结果：
# agent 1 在 49 次迭代中的资源申请量为: 47.691565757649805
# agent 2 在 49 次迭代中的资源申请量为: 59.98375296175613
# agent 3 在 49 次迭代中的资源申请量为: 43.17804943525918
# agent 4 在 49 次迭代中的资源申请量为: 63.44570152212359
# agent 5 在 49 次迭代中的资源申请量为: 64.14478541895934
# agent 6 在 49 次迭代中的资源申请量为: 70.58147958960318
# agent 7 在 49 次迭代中的资源申请量为: 38.90539920427917
# agent 8 在 49 次迭代中的资源申请量为: 37.22517368114488
# agent 9 在 49 次迭代中的资源申请量为: 42.44892940927485
# agent 10 在 49 次迭代中的资源申请量为: 54.9436078754681
# agent 11 在 49 次迭代中的资源申请量为: 44.83395782825973
# agent 12 在 49 次迭代中的资源申请量为: 48.54332820499328
# agent 13 在 49 次迭代中的资源申请量为: 64.65192912415522
# agent 14 在 49 次迭代中的资源申请量为: 54.477594924359664
# agent 15 在 49 次迭代中的资源申请量为: 42.93311928078952
# agent 16 在 49 次迭代中的资源申请量为: 43.03871968095055
# agent 17 在 49 次迭代中的资源申请量为: 44.26661192610908
# agent 18 在 49 次迭代中的资源申请量为: 45.88289161868165
# agent 19 在 49 次迭代中的资源申请量为: 40.76880347266876
# agent 20 在 49 次迭代中的资源申请量为: 54.89030352033202
# agent 21 在 49 次迭代中的资源申请量为: 38.21894510634315
# agent 22 在 49 次迭代中的资源申请量为: 38.56244621702373
# agent 23 在 49 次迭代中的资源申请量为: 47.31031619342205
# agent 24 在 49 次迭代中的资源申请量为: 39.97580620331034
# agent 25 在 49 次迭代中的资源申请量为: 44.470142603856196
# agent 26 在 49 次迭代中的资源申请量为: 39.356787947814496
# agent 27 在 49 次迭代中的资源申请量为: 64.52840856899346
# agent 28 在 49 次迭代中的资源申请量为: 50.397470311934605
# agent 29 在 49 次迭代中的资源申请量为: 40.24415251578389
# agent 30 在 49 次迭代中的资源申请量为: 38.79494528017195
# agent 31 在 49 次迭代中的资源申请量为: 59.58607272801743
# agent 32 在 49 次迭代中的资源申请量为: 54.5939169093658
# agent 33 在 49 次迭代中的资源申请量为: 40.83459147073605
# agent 34 在 49 次迭代中的资源申请量为: 51.47688810852138
# agent 35 在 49 次迭代中的资源申请量为: 38.283869659760526
# agent 36 在 49 次迭代中的资源申请量为: 42.121640311848985
# agent 37 在 49 次迭代中的资源申请量为: 51.70898790762791
# agent 38 在 49 次迭代中的资源申请量为: 39.687021452032276
# agent 39 在 49 次迭代中的资源申请量为: 42.667253357862656
# agent 40 在 49 次迭代中的资源申请量为: 49.40691309925153
# agent 41 在 49 次迭代中的资源申请量为: 65.07742031641774
# agent 42 在 49 次迭代中的资源申请量为: 41.81644566695994
# agent 43 在 49 次迭代中的资源申请量为: 50.725214376935796
# agent 44 在 49 次迭代中的资源申请量为: 52.261336404745116
# agent 45 在 49 次迭代中的资源申请量为: 47.4612634392284
# agent 46 在 49 次迭代中的资源申请量为: 55.08345409940714
# agent 47 在 49 次迭代中的资源申请量为: 45.22058738996547
# agent 48 在 49 次迭代中的资源申请量为: 42.72591149828309
# agent 49 在 49 次迭代中的资源申请量为: 41.83364490307549
# agent 50 在 49 次迭代中的资源申请量为: 40.2648281110452
# agent 51 在 49 次迭代中的资源申请量为: 47.48876308734925
# agent 52 在 49 次迭代中的资源申请量为: 54.76133738013847
# agent 53 在 49 次迭代中的资源申请量为: 38.35230576372196
# agent 54 在 49 次迭代中的资源申请量为: 56.25489297022906
# agent 55 在 49 次迭代中的资源申请量为: 69.84353448804254
# agent 56 在 49 次迭代中的资源申请量为: 40.35592853928325
# agent 57 在 49 次迭代中的资源申请量为: 59.596428479708614
# agent 58 在 49 次迭代中的资源申请量为: 41.593402607696575
# agent 59 在 49 次迭代中的资源申请量为: 47.2005649468253
# agent 60 在 49 次迭代中的资源申请量为: 55.181590144864366
# agent 61 在 49 次迭代中的资源申请量为: 64.65789759446551
# agent 62 在 49 次迭代中的资源申请量为: 45.369920242391096
# agent 63 在 49 次迭代中的资源申请量为: 38.46811236270499
# agent 64 在 49 次迭代中的资源申请量为: 43.68426863765589
# agent 65 在 49 次迭代中的资源申请量为: 41.97538748301888
# agent 66 在 49 次迭代中的资源申请量为: 64.24481151845595
# agent 67 在 49 次迭代中的资源申请量为: 42.63959511197591
# agent 68 在 49 次迭代中的资源申请量为: 44.165963116640945
# agent 69 在 49 次迭代中的资源申请量为: 44.68710393530292
# agent 70 在 49 次迭代中的资源申请量为: 58.99952132262601
# agent 71 在 49 次迭代中的资源申请量为: 70.40283118695558
# agent 72 在 49 次迭代中的资源申请量为: 59.139173750044144
# agent 73 在 49 次迭代中的资源申请量为: 42.95771638893569
# agent 74 在 49 次迭代中的资源申请量为: 38.39736112505123
# agent 75 在 49 次迭代中的资源申请量为: 51.15974107020524
# agent 76 在 49 次迭代中的资源申请量为: 46.25294883043875
# agent 77 在 49 次迭代中的资源申请量为: 40.1313136700853
# agent 78 在 49 次迭代中的资源申请量为: 48.848874829159705
# agent 79 在 49 次迭代中的资源申请量为: 42.28596463190902
# agent 80 在 49 次迭代中的资源申请量为: 42.26020615296997
# agent 81 在 49 次迭代中的资源申请量为: 39.019596188532766
# agent 82 在 49 次迭代中的资源申请量为: 45.14559215750233
# agent 83 在 49 次迭代中的资源申请量为: 41.01456428451201
# agent 84 在 49 次迭代中的资源申请量为: 51.174697503049224
# agent 85 在 49 次迭代中的资源申请量为: 54.77786070685265
# agent 86 在 49 次迭代中的资源申请量为: 48.20700500875799
# agent 87 在 49 次迭代中的资源申请量为: 59.464940573667505
# agent 88 在 49 次迭代中的资源申请量为: 63.817003344711395
# agent 89 在 49 次迭代中的资源申请量为: 39.747373654889635
# agent 90 在 49 次迭代中的资源申请量为: 58.285764877584036
# agent 91 在 49 次迭代中的资源申请量为: 42.18811101379524
# agent 92 在 49 次迭代中的资源申请量为: 56.13975004392966
# agent 93 在 49 次迭代中的资源申请量为: 40.16839278619179
# agent 94 在 49 次迭代中的资源申请量为: 71.99602038361984
# agent 95 在 49 次迭代中的资源申请量为: 59.27371970527856
# agent 96 在 49 次迭代中的资源申请量为: 59.40259423342299
# agent 97 在 49 次迭代中的资源申请量为: 70.70114311080361
# agent 98 在 49 次迭代中的资源申请量为: 71.79277367898399
# agent 99 在 49 次迭代中的资源申请量为: 51.56461969027502
# agent 100 在 49 次迭代中的资源申请量为: 47.79003092575963
# 资源申请量总和为: 4954.561401837532
# ****************************************************************************
# 成本总和为: 327796.29455842025
# ****************************************************************************
# agent 1 在 49 次迭代中的对偶变量为: -137.9746972729494
# agent 2 在 49 次迭代中的对偶变量为: -137.7210071082147
# agent 3 在 49 次迭代中的对偶变量为: -137.96536807988122
# agent 4 在 49 次迭代中的对偶变量为: -137.82054334867192
# agent 5 在 49 次迭代中的对偶变量为: -137.59852792171057
# agent 6 在 49 次迭代中的对偶变量为: -137.16295917920635
# agent 7 在 49 次迭代中的对偶变量为: -137.96051697626083
# agent 8 在 49 次迭代中的对偶变量为: -138.1006947245795
# agent 9 在 49 次迭代中的对偶变量为: -137.86635999153447
# agent 10 在 49 次迭代中的对偶变量为: -137.91338047621707
# agent 11 在 49 次迭代中的对偶变量为: -138.02866505043113
# agent 12 在 49 次迭代中的对偶变量为: -137.82998461497982
# agent 13 在 49 次迭代中的对偶变量为: -137.6142440731415
# agent 14 在 49 次迭代中的对偶变量为: -138.26174680333514
# agent 15 在 49 次迭代中的对偶变量为: -138.15260555468436
# agent 16 在 49 次迭代中的对偶变量为: -137.83164691523186
# agent 17 在 49 次迭代中的对偶变量为: -138.13315816354904
# agent 18 在 49 次迭代中的对偶变量为: -138.18525317978128
# agent 19 在 49 次迭代中的对偶变量为: -138.12769250160753
# agent 20 在 49 次迭代中的对偶变量为: -138.03478915286325
# agent 21 在 49 次迭代中的对偶变量为: -138.01199140410395
# agent 22 在 49 次迭代中的对偶变量为: -138.17729562469017
# agent 23 在 49 次迭代中的对偶变量为: -138.63094858026614
# agent 24 在 49 次迭代中的对偶变量为: -138.15290233191723
# agent 25 在 49 次迭代中的对偶变量为: -137.82445633233985
# agent 26 在 49 次迭代中的对偶变量为: -138.53579420169507
# agent 27 在 49 次迭代中的对偶变量为: -138.00249885178562
# agent 28 在 49 次迭代中的对偶变量为: -137.4729168734169
# agent 29 在 49 次迭代中的对偶变量为: -138.038949056822
# agent 30 在 49 次迭代中的对偶变量为: -138.6807920646534
# agent 31 在 49 次迭代中的对偶变量为: -138.20657454724181
# agent 32 在 49 次迭代中的对偶变量为: -137.7841839643511
# agent 33 在 49 次迭代中的对偶变量为: -137.2845292946498
# agent 34 在 49 次迭代中的对偶变量为: -137.97528670385987
# agent 35 在 49 次迭代中的对偶变量为: -137.87870470709
# agent 36 在 49 次迭代中的对偶变量为: -137.77357706028656
# agent 37 在 49 次迭代中的对偶变量为: -137.78516614135813
# agent 38 在 49 次迭代中的对偶变量为: -137.83327722731622
# agent 39 在 49 次迭代中的对偶变量为: -137.92866141673304
# agent 40 在 49 次迭代中的对偶变量为: -138.0207392977546
# agent 41 在 49 次迭代中的对偶变量为: -137.67032469611905
# agent 42 在 49 次迭代中的对偶变量为: -137.75591526766382
# agent 43 在 49 次迭代中的对偶变量为: -137.27060025542022
# agent 44 在 49 次迭代中的对偶变量为: -138.2117419332863
# agent 45 在 49 次迭代中的对偶变量为: -137.8837903176852
# agent 46 在 49 次迭代中的对偶变量为: -138.27698065845857
# agent 47 在 49 次迭代中的对偶变量为: -137.98587964788953
# agent 48 在 49 次迭代中的对偶变量为: -137.7880990941625
# agent 49 在 49 次迭代中的对偶变量为: -137.13439267045666
# agent 50 在 49 次迭代中的对偶变量为: -137.7533811997627
# agent 51 在 49 次迭代中的对偶变量为: -137.66628926204774
# agent 52 在 49 次迭代中的对偶变量为: -137.69947718836002
# agent 53 在 49 次迭代中的对偶变量为: -137.75876190214345
# agent 54 在 49 次迭代中的对偶变量为: -138.46272172259555
# agent 55 在 49 次迭代中的对偶变量为: -137.88706897608506
# agent 56 在 49 次迭代中的对偶变量为: -138.08134274141972
# agent 57 在 49 次迭代中的对偶变量为: -138.23142835130065
# agent 58 在 49 次迭代中的对偶变量为: -138.01756886616835
# agent 59 在 49 次迭代中的对偶变量为: -138.00169484047592
# agent 60 在 49 次迭代中的对偶变量为: -138.01213437664734
# agent 61 在 49 次迭代中的对偶变量为: -137.40737470782412
# agent 62 在 49 次迭代中的对偶变量为: -137.8237447756515
# agent 63 在 49 次迭代中的对偶变量为: -138.198826978279
# agent 64 在 49 次迭代中的对偶变量为: -137.86965964049887
# agent 65 在 49 次迭代中的对偶变量为: -137.61631744226418
# agent 66 在 49 次迭代中的对偶变量为: -137.15858534060308
# agent 67 在 49 次迭代中的对偶变量为: -137.83462338071809
# agent 68 在 49 次迭代中的对偶变量为: -137.81108197325102
# agent 69 在 49 次迭代中的对偶变量为: -137.87873259296936
# agent 70 在 49 次迭代中的对偶变量为: -137.7588511743024
# agent 71 在 49 次迭代中的对偶变量为: -137.00566237391115
# agent 72 在 49 次迭代中的对偶变量为: -137.61401700010595
# agent 73 在 49 次迭代中的对偶变量为: -137.55623572238133
# agent 74 在 49 次迭代中的对偶变量为: -137.9299722751947
# agent 75 在 49 次迭代中的对偶变量为: -137.92727499657468
# agent 76 在 49 次迭代中的对偶变量为: -137.76943625740398
# agent 77 在 49 次迭代中的对偶变量为: -137.63272921230708
# agent 78 在 49 次迭代中的对偶变量为: -137.84662448747912
# agent 79 在 49 次迭代中的对偶变量为: -138.33227974849066
# agent 80 在 49 次迭代中的对偶变量为: -137.5647009200979
# agent 81 在 49 次迭代中的对偶变量为: -138.3944655164245
# agent 82 在 49 次迭代中的对偶变量为: -138.38589490400744
# agent 83 在 49 次迭代中的对偶变量为: -137.93243142424325
# agent 84 在 49 次迭代中的对偶变量为: -137.68915300853783
# agent 85 在 49 次迭代中的对偶变量为: -137.74243783781688
# agent 86 在 49 次迭代中的对偶变量为: -138.02101502627397
# agent 87 在 49 次迭代中的对偶变量为: -137.915857376802
# agent 88 在 49 次迭代中的对偶变量为: -137.31740735836507
# agent 89 在 49 次迭代中的对偶变量为: -137.3305451576027
# agent 90 在 49 次迭代中的对偶变量为: -137.9658357062017
# agent 91 在 49 次迭代中的对偶变量为: -137.65957744690382
# agent 92 在 49 次迭代中的对偶变量为: -138.1633501142171
# agent 93 在 49 次迭代中的对偶变量为: -138.12621403029044
# agent 94 在 49 次迭代中的对偶变量为: -137.79204076723968
# agent 95 在 49 次迭代中的对偶变量为: -137.69692729266853
# agent 96 在 49 次迭代中的对偶变量为: -137.52622616021517
# agent 97 在 49 次迭代中的对偶变量为: -137.20228622160724
# agent 98 在 49 次迭代中的对偶变量为: -137.78554735796797
# agent 99 在 49 次迭代中的对偶变量为: -137.66093513277005
# agent 100 在 49 次迭代中的对偶变量为: -137.9700927772789
# *************************
# 迭代步长为: 0.09680155905721156
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: 48.213596682647285
# agent 2 在 99 次迭代中的资源申请量为: 60.6546147450911
# agent 3 在 99 次迭代中的资源申请量为: 43.63767958504459
# agent 4 在 99 次迭代中的资源申请量为: 64.18041227946512
# agent 5 在 99 次迭代中的资源申请量为: 64.91587165009223
# agent 6 在 99 次迭代中的资源申请量为: 71.49877970938941
# agent 7 在 99 次迭代中的资源申请量为: 39.306532478149755
# agent 8 在 99 次迭代中的资源申请量为: 37.58581737773609
# agent 9 在 99 次迭代中的资源申请量为: 42.905345093736884
# agent 10 在 99 次迭代中的资源申请量为: 55.53603922211646
# agent 11 在 99 次迭代中的资源申请量为: 45.3038244063863
# agent 12 在 99 次迭代中的资源申请量为: 49.04974623114138
# agent 13 在 99 次迭代中的资源申请量为: 65.41032651823208
# agent 14 在 99 次迭代中的资源申请量为: 55.030173961870034
# agent 15 在 99 次迭代中的资源申请量为: 43.37329604416002
# agent 16 在 99 次迭代中的资源申请量为: 43.51702281573106
# agent 17 在 99 次迭代中的资源申请量为: 44.735678417289364
# agent 18 在 99 次迭代中的资源申请量为: 46.339727634852764
# agent 19 在 99 次迭代中的资源申请量为: 41.17537031952343
# agent 20 在 99 次迭代中的资源申请量为: 55.44533864864298
# agent 21 在 99 次迭代中的资源申请量为: 38.60885330384036
# agent 22 在 99 次迭代中的资源申请量为: 38.94284937805123
# agent 23 在 99 次迭代中的资源申请量为: 47.75797325161184
# agent 24 在 99 次迭代中的资源申请量为: 40.39766397394272
# agent 25 在 99 次迭代中的资源申请量为: 44.97503631748423
# agent 26 在 99 次迭代中的资源申请量为: 39.70596789281428
# agent 27 在 99 次迭代中的资源申请量为: 65.21862942146903
# agent 28 在 99 次迭代中的资源申请量为: 51.0148952847979
# agent 29 在 99 次迭代中的资源申请量为: 40.67208752674831
# agent 30 在 99 次迭代中的资源申请量为: 39.11765772726391
# agent 31 在 99 次迭代中的资源申请量为: 60.187862289370024
# agent 32 在 99 次迭代中的资源申请量为: 55.22484625020672
# agent 33 在 99 次迭代中的资源申请量为: 41.33494993798436
# agent 34 在 99 次迭代中的资源申请量为: 52.020830907335295
# agent 35 在 99 次迭代中的资源申请量为: 38.682823436439655
# agent 36 在 99 次迭代中的资源申请量为: 42.58858246167055
# agent 37 在 99 次迭代中的资源申请量为: 52.29122066076205
# agent 38 在 99 次迭代中的资源申请量为: 40.136025886715494
# agent 39 在 99 次迭代中的资源申请量为: 43.13356267196884
# agent 40 在 99 次迭代中的资源申请量为: 49.90555450301864
# agent 41 在 99 次迭代中的资源申请量为: 65.81032893519576
# agent 42 在 99 次迭代中的资源申请量为: 42.29662431231509
# agent 43 在 99 次迭代中的资源申请量为: 51.374801225447534
# agent 44 在 99 次迭代中的资源申请量为: 52.79570644105203
# agent 45 在 99 次迭代中的资源申请量为: 47.99568900074337
# agent 46 在 99 次迭代中的资源申请量为: 55.605975466345015
# agent 47 在 99 次迭代中的资源申请量为: 45.69422446963699
# agent 48 在 99 次迭代中的资源申请量为: 43.192188255549944
# agent 49 在 99 次迭代中的资源申请量为: 42.38051577481088
# agent 50 在 99 次迭代中的资源申请量为: 40.72176743439578
# agent 51 在 99 次迭代中的资源申请量为: 48.028403852061906
# agent 52 在 99 次迭代中的资源申请量为: 55.399704093231975
# agent 53 在 99 次迭代中的资源申请量为: 38.78082297241058
# agent 54 在 99 次迭代中的资源申请量为: 56.77832727767534
# agent 55 在 99 次迭代中的资源申请量为: 70.62161713625511
# agent 56 在 99 次迭代中的资源申请量为: 40.782359103762715
# agent 57 在 99 次迭代中的资源申请量为: 60.17334594743161
# agent 58 在 99 次迭代中的资源申请量为: 42.03584432542953
# agent 59 在 99 次迭代中的资源申请量为: 47.705620972460586
# agent 60 在 99 次迭代中的资源申请量为: 55.76438859461547
# agent 61 在 99 次迭代中的资源申请量为: 65.45569504294777
# agent 62 在 99 次迭代中的资源申请量为: 45.877046161808806
# agent 63 在 99 次迭代中的资源申请量为: 38.848812246682044
# agent 64 在 99 次迭代中的资源申请量为: 44.183155497692205
# agent 65 在 99 次迭代中的资源申请量为: 42.47500578756716
# agent 66 在 99 次迭代中的资源申请量为: 65.0811390845161
# agent 67 在 99 次迭代中的资源申请量为: 43.115792264908286
# agent 68 在 99 次迭代中的资源申请量为: 44.67307176953473
# agent 69 在 99 次迭代中的资源申请量为: 45.189466497860046
# agent 70 在 99 次迭代中的资源申请量为: 59.6784626756426
# agent 71 在 99 次迭代中的资源申请量为: 71.34671919715488
# agent 72 在 99 次迭代中的资源申请量为: 59.822647274746146
# agent 73 在 99 次迭代中的资源申请量为: 43.45973152611449
# agent 74 在 99 次迭代中的资源申请量为: 38.816356958616275
# agent 75 在 99 次迭代中的资源申请量为: 51.727921398429416
# agent 76 在 99 次迭代中的资源申请量为: 46.76547271239981
# agent 77 在 99 次迭代中的资源申请量为: 40.59949221798593
# agent 78 在 99 次迭代中的资源申请量为: 49.38480038893176
# agent 79 在 99 次迭代中的资源申请量为: 42.694488171066304
# agent 80 在 99 次迭代中的资源申请量为: 42.76429967945215
# agent 81 在 99 次迭代中的资源申请量为: 39.39413271519894
# agent 82 在 99 次迭代中的资源申请量为: 45.575431176203146
# agent 83 在 99 次迭代中的资源申请量为: 41.44969001016512
# agent 84 在 99 次迭代中的资源申请量为: 51.75335497507865
# agent 85 在 99 次迭代中的资源申请量为: 55.41306018068997
# agent 86 在 99 次迭代中的资源申请量为: 48.71100216497766
# agent 87 在 99 次迭代中的资源申请量为: 60.106660835519534
# agent 88 在 99 次迭代中的资源申请量为: 64.62947814507001
# agent 89 在 99 次迭代中的资源申请量为: 40.238328687546435
# agent 90 在 99 次迭代中的资源申请量为: 58.94354000049299
# agent 91 在 99 次迭代中的资源申请量为: 42.68058009551233
# agent 92 在 99 次迭代中的资源申请量为: 56.70156740744424
# agent 93 在 99 次迭代中的资源申请量为: 40.587773183367524
# agent 94 在 99 次迭代中的资源申请量为: 72.79056559623602
# agent 95 在 99 次迭代中的资源申请量为: 59.94824700103535
# agent 96 在 99 次迭代中的资源申请量为: 60.11774343140354
# agent 97 在 99 次迭代中的资源申请量为: 71.61720855482176
# agent 98 在 99 次迭代中的资源申请量为: 72.58393361634297
# agent 99 在 99 次迭代中的资源申请量为: 52.16482278926121
# agent 100 在 99 次迭代中的资源申请量为: 48.31410694262319
# 资源申请量总和为: 5009.352126558667
# ****************************************************************************
# 成本总和为: 335391.20382547565
# ****************************************************************************
# agent 1 在 99 次迭代中的对偶变量为: -139.54079004794187
# agent 2 在 99 次迭代中的对偶变量为: -139.33107538821864
# agent 3 在 99 次迭代中的对偶变量为: -139.5281105891516
# agent 4 在 99 次迭代中的对偶变量为: -139.43690701482328
# agent 5 在 99 次迭代中的对偶变量为: -139.29491763020292
# agent 6 在 99 次迭代中的对偶变量为: -138.99755941877882
# agent 7 在 99 次迭代中的对偶变量为: -139.48482341696908
# agent 8 在 99 次迭代中的对偶变量为: -139.54326951094436
# agent 9 在 99 次迭代中的对偶变量为: -139.41817331870539
# agent 10 在 99 次迭代中的对偶变量为: -139.4537019775028
# agent 11 在 99 次迭代中的对偶变量为: -139.53223810043616
# agent 12 在 99 次迭代中的对偶变量为: -139.34923869342413
# agent 13 在 99 次迭代中的对偶变量为: -139.2827183401106
# agent 14 在 99 次迭代中的对偶变量为: -139.6984523008621
# agent 15 在 99 次迭代中的对偶变量为: -139.64920655014407
# agent 16 在 99 次迭代中的对偶变量为: -139.4578775734856
# agent 17 在 99 次迭代中的对偶变量为: -139.63417093532595
# agent 18 在 99 次迭代中的对偶变量为: -139.64712843152884
# agent 19 在 99 次迭代中的对偶变量为: -139.59133315028436
# agent 20 在 99 次迭代中的对偶变量为: -139.47788048647175
# agent 21 在 99 次迭代中的对偶变量为: -139.49364255459338
# agent 22 在 99 次迭代中的对偶变量为: -139.62282763659465
# agent 23 在 99 次迭代中的对偶变量为: -139.9739197548355
# agent 24 在 99 次迭代中的对偶变量为: -139.6715903061938
# agent 25 在 99 次迭代中的对偶变量为: -139.44011621594956
# agent 26 在 99 次迭代中的对偶变量为: -139.86267799269424
# agent 27 在 99 次迭代中的对偶变量为: -139.52098472723188
# agent 28 在 99 次迭代中的对偶变量为: -139.20170679743413
# agent 29 在 99 次迭代中的对偶变量为: -139.5795150962939
# agent 30 在 99 次迭代中的对偶变量为: -139.90709936360284
# agent 31 在 99 次迭代中的对偶变量为: -139.65086949448803
# agent 32 在 99 次迭代中的对偶变量为: -139.42460025053748
# agent 33 在 99 次迭代中的对偶变量为: -139.0858197767437
# agent 34 在 99 次迭代中的对偶变量为: -139.4983265405388
# agent 35 在 99 次迭代中的对偶变量为: -139.3947290584707
# agent 36 在 99 次迭代中的对偶变量为: -139.36118036967986
# agent 37 在 99 次迭代中的对偶变量为: -139.41541785013374
# agent 38 在 99 次迭代中的对偶变量为: -139.4496931921758
# agent 39 在 99 次迭代中的对偶变量为: -139.51411308469406
# agent 40 在 99 次迭代中的对偶变量为: -139.51666350905595
# agent 41 在 99 次迭代中的对偶变量为: -139.28272365743067
# agent 42 在 99 次迭代中的对偶变量为: -139.38852266187132
# agent 43 在 99 次迭代中的对偶变量为: -139.0894434312531
# agent 44 在 99 次迭代中的对偶变量为: -139.70797803494568
# agent 45 在 99 次迭代中的对偶变量为: -139.4870670022301
# agent 46 在 99 次迭代中的对偶变量为: -139.63553621249704
# agent 47 在 99 次迭代中的对偶变量为: -139.50151830283838
# agent 48 在 99 次迭代中的对偶变量为: -139.37344006886983
# agent 49 在 99 次迭代中的对偶变量为: -138.993753634357
# agent 50 在 99 次迭代中的对偶变量为: -139.39836276382482
# agent 51 在 99 次迭代中的对偶变量为: -139.28521155618571
# agent 52 在 99 次迭代中的对偶变量为: -139.35923064240313
# agent 53 在 99 次迭代中的对偶变量为: -139.3871272951602
# agent 54 在 99 次迭代中的对偶变量为: -139.82365092195587
# agent 55 在 99 次迭代中的对偶变量为: -139.4432342725102
# agent 56 在 99 次迭代中的对偶变量为: -139.6164927735458
# agent 57 在 99 次迭代中的对偶变量为: -139.61603027383586
# agent 58 在 99 次迭代中的对偶变量为: -139.5218707064604
# agent 59 在 99 次迭代中的对偶变量为: -139.51686291738176
# agent 60 在 99 次迭代中的对偶变量为: -139.5274103460002
# agent 61 在 99 次迭代中的对偶变量为: -139.16252909448508
# agent 62 在 99 次迭代中的对偶变量为: -139.44654771778818
# agent 63 在 99 次迭代中的对偶变量为: -139.64548653739178
# agent 64 在 99 次迭代中的对偶变量为: -139.46609759261509
# agent 65 在 99 次迭代中的对偶变量为: -139.31501967772834
# agent 66 在 99 次迭代中的对偶变量为: -138.99850598593542
# agent 67 在 99 次迭代中的对偶变量为: -139.45369370068818
# agent 68 在 99 次迭代中的对偶变量为: -139.43382966251113
# agent 69 在 99 次迭代中的对偶变量为: -139.48629279315216
# agent 70 在 99 次迭代中的对偶变量为: -139.38831042154223
# agent 71 在 99 次迭代中的对偶变量为: -138.89343839430975
# agent 72 在 99 次迭代中的对偶变量为: -139.25435345939076
# agent 73 在 99 次迭代中的对偶变量为: -139.26308718878926
# agent 74 在 99 次迭代中的对偶变量为: -139.52215644274185
# agent 75 在 99 次迭代中的对偶变量为: -139.51817991560236
# agent 76 在 99 次迭代中的对偶变量为: -139.4095126796794
# agent 77 在 99 次迭代中的对偶变量为: -139.31817198474937
# agent 78 在 99 次迭代中的对偶变量为: -139.4544011667953
# agent 79 在 99 次迭代中的对偶变量为: -139.72125978162543
# agent 80 在 99 次迭代中的对偶变量为: -139.2786189101373
# agent 81 在 99 次迭代中的对偶变量为: -139.81770431775598
# agent 82 在 99 次迭代中的对偶变量为: -139.76137976385007
# agent 83 在 99 次迭代中的对偶变量为: -139.49888403659443
# agent 84 在 99 次迭代中的对偶变量为: -139.3093939302202
# agent 85 在 99 次迭代中的对偶变量为: -139.39395646979392
# agent 86 在 99 次迭代中的对偶变量为: -139.53300649493298
# agent 87 在 99 次迭代中的对偶变量为: -139.45598600524687
# agent 88 在 99 次迭代中的对偶变量为: -139.10485191915402
# agent 89 在 99 次迭代中的对偶变量为: -139.09798327516717
# agent 90 在 99 次迭代中的对偶变量为: -139.54449600118318
# agent 91 在 99 次迭代中的对偶变量为: -139.33397232474192
# agent 92 在 99 次迭代中的对偶变量为: -139.624075259355
# agent 93 在 99 次迭代中的对偶变量为: -139.6359834601231
# agent 94 在 99 次迭代中的对偶变量为: -139.38113119247205
# agent 95 在 99 次迭代中的对偶变量为: -139.31579280248482
# agent 96 在 99 次迭代中的对偶变量为: -139.2425842353685
# agent 97 在 99 次迭代中的对偶变量为: -139.03441710964353
# agent 98 在 99 次迭代中的对偶变量为: -139.36786723268594
# agent 99 在 99 次迭代中的对偶变量为: -139.34150380993137
# agent 100 在 99 次迭代中的对偶变量为: -139.54232082786956
# *************************
# 迭代步长为: 0.06347736393621072
# ****************************************************************************
# 149 次迭代中的结果：
# agent 1 在 149 次迭代中的资源申请量为: 48.29032541459777
# agent 2 在 149 次迭代中的资源申请量为: 60.76978312715653
# agent 3 在 149 次迭代中的资源申请量为: 43.706195235559726
# agent 4 在 149 次迭代中的资源申请量为: 64.29499969958886
# agent 5 在 149 次迭代中的资源申请量为: 65.04419926036799
# agent 6 在 149 次迭代中的资源申请量为: 71.67198202414781
# agent 7 在 149 次迭代中的资源申请量为: 39.37055025586985
# agent 8 在 149 次迭代中的资源申请量为: 37.64381355803922
# agent 9 在 149 次迭代中的资源申请量为: 42.98111891423117
# agent 10 在 149 次迭代中的资源申请量为: 55.632254981548584
# agent 11 在 149 次迭代中的资源申请量为: 45.37664752493386
# agent 12 在 149 次迭代中的资源申请量为: 49.14102316939405
# agent 13 在 149 次迭代中的资源申请量为: 65.54036255189655
# agent 14 在 149 次迭代中的资源申请量为: 55.10600524432621
# agent 15 在 149 次迭代中的资源申请量为: 43.434176401716144
# agent 16 在 149 次迭代中的资源申请量为: 43.589767289762165
# agent 17 在 149 次迭代中的资源申请量为: 44.801345151012846
# agent 18 在 149 次迭代中的资源申请量为: 46.404721089706676
# agent 19 在 149 次迭代中的资源申请量为: 41.2366803052003
# agent 20 在 149 次迭代中的资源申请量为: 55.54017215523278
# agent 21 在 149 次迭代中的资源申请量为: 38.67260494122209
# agent 22 在 149 次迭代中的资源申请量为: 38.99909250465238
# agent 23 在 149 次迭代中的资源申请量为: 47.803617216497805
# agent 24 在 149 次迭代中的资源申请量为: 40.453706622008404
# agent 25 在 149 次迭代中的资源申请量为: 45.05373951961845
# agent 26 在 149 次迭代中的资源申请量为: 39.7486736514712
# agent 27 在 149 次迭代中的资源申请量为: 65.3255873450975
# agent 28 在 149 次迭代中的资源申请量为: 51.123090690658266
# agent 29 在 149 次迭代中的资源申请量为: 40.733657380853465
# agent 30 在 149 次迭代中的资源申请量为: 39.15824302837536
# agent 31 在 149 次迭代中的资源申请量为: 60.27435338607457
# agent 32 在 149 次迭代中的资源申请量为: 55.32291140319209
# agent 33 在 149 次迭代中的资源申请量为: 41.42601541042774
# agent 34 在 149 次迭代中的资源申请量为: 52.10667322778817
# agent 35 在 149 次迭代中的资源申请量为: 38.752268699542775
# agent 36 在 149 次迭代中的资源申请量为: 42.66794612910619
# agent 37 在 149 次迭代中的资源申请量为: 52.38291669682104
# agent 38 在 149 次迭代中的资源申请量为: 40.20535666527587
# agent 39 在 149 次迭代中的资源申请量为: 43.20284866195796
# agent 40 在 149 次迭代中的资源申请量为: 49.984412042343116
# agent 41 在 149 次迭代中的资源申请量为: 65.94073641508332
# agent 42 在 149 次迭代中的资源申请量为: 42.37395199170209
# agent 43 在 149 次迭代中的资源申请量为: 51.49135763267456
# agent 44 在 149 次迭代中的资源申请量为: 52.86486745427424
# agent 45 在 149 次迭代中的资源申请量为: 48.07616605523341
# agent 46 在 149 次迭代中的资源申请量为: 55.687720454158104
# agent 47 在 149 次迭代中的资源申请量为: 45.76919136772722
# agent 48 在 149 次迭代中的资源申请量为: 43.270751775430725
# agent 49 在 149 次迭代中的资源申请量为: 42.48258577197413
# agent 50 在 149 次迭代中的资源申请量为: 40.79408438211491
# agent 51 在 149 次迭代中的资源申请量为: 48.12378062031157
# agent 52 在 149 次迭代中的资源申请量为: 55.50313918690297
# agent 53 在 149 次迭代中的资源申请量为: 38.85009994881353
# agent 54 在 149 次迭代中的资源申请量为: 56.843868014367374
# agent 55 在 149 次迭代中的资源申请量为: 70.74764731111993
# agent 56 在 149 次迭代中的资源申请量为: 40.841696078883025
# agent 57 在 149 次迭代中的资源申请量为: 60.26353743919427
# agent 58 在 149 次迭代中的资源申请量为: 42.105116879007205
# agent 59 在 149 次迭代中的资源申请量为: 47.7843309107279
# agent 60 在 149 次迭代中的资源申请量为: 55.854322908684615
# agent 61 在 149 次迭代中的资源申请量为: 65.59708038331348
# agent 62 在 149 次迭代中的资源申请量为: 45.95517249858361
# agent 63 在 149 次迭代中的资源申请量为: 38.90371040309992
# agent 64 在 149 次迭代中的资源申请量为: 44.26001811799909
# agent 65 在 149 次迭代中的资源申请量为: 42.55682035779473
# agent 66 在 149 次迭代中的资源申请量为: 65.23853582162972
# agent 67 在 149 次迭代中的资源申请量为: 43.18876817605517
# agent 68 在 149 次迭代中的资源申请量为: 44.751995936478565
# agent 69 在 149 次迭代中的资源申请量为: 45.264854402924115
# agent 70 在 149 次迭代中的资源申请量为: 59.78787462070167
# agent 71 在 149 次迭代中的资源申请量为: 71.53110985785833
# agent 72 在 149 次迭代中的资源申请量为: 59.9446665253243
# agent 73 在 149 次迭代中的资源申请量为: 43.54490420353422
# agent 74 在 149 次迭代中的资源申请量为: 38.87787505807165
# agent 75 在 149 次迭代中的资源申请量为: 51.81160501673343
# agent 76 在 149 次迭代中的资源申请量为: 46.84611881016213
# agent 77 在 149 次迭代中的资源申请量为: 40.676604896972904
# agent 78 在 149 次迭代中的资源申请量为: 49.46762877066963
# agent 79 在 149 次迭代中的资源申请量为: 42.75118729676325
# agent 80 在 149 次迭代中的资源申请量为: 42.84845883011546
# agent 81 在 149 次迭代中的资源申请量为: 39.43903880754833
# agent 82 在 149 次迭代中的资源申请量为: 45.632902992596684
# agent 83 在 149 次迭代中的资源申请量为: 41.51618332943839
# agent 84 在 149 次迭代中的资源申请量为: 51.853666155323374
# agent 85 在 149 次迭代中的资源申请量为: 55.51347813769007
# agent 86 在 149 次迭代中的资源申请量为: 48.78854557373503
# agent 87 在 149 次迭代中的资源申请量为: 60.210554402207116
# agent 88 在 149 次迭代中的资源申请量为: 64.77637904709363
# agent 89 在 149 次迭代中的资源申请量为: 40.32868564920593
# agent 90 在 149 次迭代中的资源申请量为: 59.03884574421056
# agent 91 在 149 次迭代中的资源申请量为: 42.76129560156388
# agent 92 在 149 次迭代中的资源申请量为: 56.78356858397781
# agent 93 在 149 次迭代中的资源申请量为: 40.646044169035335
# agent 94 在 149 次迭代中的资源申请量为: 72.92320714843983
# agent 95 在 149 次迭代中的资源申请量为: 60.064718813446625
# agent 96 在 149 次迭代中的资源申请量为: 60.24027133222283
# agent 97 在 149 次迭代中的资源申请量为: 71.7863876131967
# agent 98 在 149 次迭代中的资源申请量为: 72.7180749486535
# agent 99 在 149 次迭代中的资源申请量为: 52.262197276429816
# agent 100 在 149 次迭代中的资源申请量为: 48.39058383650851
# 资源申请量总和为: 5018.122410322967
# ****************************************************************************
# 成本总和为: 336614.8918752391
# ****************************************************************************
# agent 1 在 149 次迭代中的对偶变量为: -139.7709762437933
# agent 2 在 149 次迭代中的对偶变量为: -139.60747950517566
# agent 3 在 149 次迭代中的对偶变量为: -139.76106380090306
# agent 4 在 149 次迭代中的对偶变量为: -139.68899933909552
# agent 5 在 149 次迭代中的对偶变量为: -139.57723837280957
# agent 6 在 149 次迭代中的对偶变量为: -139.34396404829562
# agent 7 在 149 次迭代中的对偶变量为: -139.72809097230544
# agent 8 在 149 次迭代中的对偶变量为: -139.77525423215687
# agent 9 在 149 次迭代中的对偶变量为: -139.67580430838595
# agent 10 在 149 次迭代中的对偶变量为: -139.70386295202633
# agent 11 在 149 次迭代中的对偶变量为: -139.76527207978836
# agent 12 在 149 次迭代中的对偶变量为: -139.62306950818214
# agent 13 在 149 次迭代中的对偶变量为: -139.5687976141724
# agent 14 在 149 次迭代中的对偶变量为: -139.89561363524817
# agent 15 在 149 次迭代中的对偶变量为: -139.8561997658349
# agent 16 在 149 次迭代中的对偶变量为: -139.70520878519136
# agent 17 在 149 次迭代中的对偶变量为: -139.8443044832411
# agent 18 在 149 次迭代中的对偶变量为: -139.85510748706136
# agent 19 在 149 次迭代中的对偶变量为: -139.81204909872108
# agent 20 在 149 次迭代中的对偶变量为: -139.72444760360523
# agent 21 在 149 次迭代中的对偶变量为: -139.73589877664395
# agent 22 在 149 次迭代中的对偶变量为: -139.83655151767906
# agent 23 在 149 次迭代中的对偶变量为: -140.1108516494934
# agent 24 在 149 次迭代中的对偶变量为: -139.87334383923027
# agent 25 在 149 次迭代中的对偶变量为: -139.69196646277908
# agent 26 在 149 次迭代中的对偶变量为: -140.02495987559055
# agent 27 在 149 次迭代中的对偶变量为: -139.7562921592145
# agent 28 在 149 次迭代中的对偶变量为: -139.50465393384314
# agent 29 在 149 次迭代中的对偶变量为: -139.80116657107249
# agent 30 在 149 次迭代中的对偶变量为: -140.06132350782636
# agent 31 在 149 次迭代中的对偶变量为: -139.85844812657896
# agent 32 在 149 次迭代中的对偶变量为: -139.67956964829943
# agent 33 在 149 次迭代中的对偶变量为: -139.41365547753986
# agent 34 在 149 次迭代中的对偶变量为: -139.73868503780687
# agent 35 在 149 次迭代中的对偶变量为: -139.65862105826255
# agent 36 在 149 次迭代中的对偶变量为: -139.63101683896105
# agent 37 在 149 次迭代中的对偶变量为: -139.6721667510989
# agent 38 在 149 次迭代中的对偶变量为: -139.69928399499315
# agent 39 在 149 次迭代中的对偶变量为: -139.74968545065707
# agent 40 在 149 次迭代中的对偶变量为: -139.75323612702937
# agent 41 在 149 次迭代中的对偶变量为: -139.5696201131833
# agent 42 在 149 次迭代中的对偶变量为: -139.65143677178713
# agent 43 在 149 次迭代中的对偶变量为: -139.41580137148875
# agent 44 在 149 次迭代中的对偶变量为: -139.90162887196786
# agent 45 在 149 次迭代中的对偶变量为: -139.72849816570022
# agent 46 在 149 次迭代中的对偶变量为: -139.84807318081107
# agent 47 在 149 次迭代中的对偶变量为: -139.7414123767271
# agent 48 在 149 次迭代中的对偶变量为: -139.64055603646446
# agent 49 在 149 次迭代中的对偶变量为: -139.34079162471204
# agent 50 在 149 次迭代中的对偶变量为: -139.6587037756137
# agent 51 在 149 次迭代中的对偶变量为: -139.5713418609347
# agent 52 在 149 次迭代中的对偶变量为: -139.62816188594772
# agent 53 在 149 次迭代中的对偶变量为: -139.6503798054914
# agent 54 在 149 次迭代中的对偶变量为: -139.99405683735517
# agent 55 在 149 次迭代中的对偶变量为: -139.69529462223986
# agent 56 在 149 次迭代中的对偶变量为: -139.83010588397892
# agent 57 在 149 次迭代中的对偶变量为: -139.83248985406624
# agent 58 在 149 次迭代中的对偶变量为: -139.7573973886245
# agent 59 在 149 次迭代中的对偶变量为: -139.7529927321837
# agent 60 在 149 次迭代中的对偶变量为: -139.76123956258
# agent 61 在 149 次迭代中的对偶变量为: -139.47357684328966
# agent 62 在 149 次迭代中的对偶变量为: -139.69655199546756
# agent 63 在 149 次迭代中的对偶变量为: -139.8540995317797
# agent 64 在 149 次迭代中的对偶变量为: -139.7120579775971
# agent 65 在 149 次迭代中的对偶变量为: -139.59318921650208
# agent 66 在 149 次迭代中的对偶变量为: -139.34477880758539
# agent 67 在 149 次迭代中的对偶变量为: -139.70181179858758
# agent 68 在 149 次迭代中的对偶变量为: -139.68638699673141
# agent 69 在 149 次迭代中的对偶变量为: -139.72753408935716
# agent 70 在 149 次迭代中的对偶变量为: -139.650899089684
# agent 71 在 149 次迭代中的对偶变量为: -139.26221971571664
# agent 72 在 149 次迭代中的对偶变量为: -139.54719966077832
# agent 73 在 149 次迭代中的对偶变量为: -139.55267429201635
# agent 74 在 149 次迭代中的对偶变量为: -139.75592522067228
# agent 75 在 149 次迭代中的对偶变量为: -139.7524940468536
# agent 76 在 149 次迭代中的对偶变量为: -139.6675801925188
# agent 77 在 149 次迭代中的对偶变量为: -139.59577762910246
# agent 78 在 149 次迭代中的对偶变量为: -139.7028863120089
# agent 79 在 149 次迭代中的对偶变量为: -139.91403680899504
# agent 80 在 149 次迭代中的对偶变量为: -139.56476002239256
# agent 81 在 149 次迭代中的对偶变量为: -139.98834746868366
# agent 82 在 149 次迭代中的对偶变量为: -139.9452895763094
# agent 83 在 149 次迭代中的对偶变量为: -139.7382599859782
# agent 84 在 149 次迭代中的对偶变量为: -139.59026523490544
# agent 85 在 149 次迭代中的对偶变量为: -139.65504315799419
# agent 86 在 149 次迭代中的对偶变量为: -139.76563672120508
# agent 87 在 149 次迭代中的对偶变量为: -139.70533056529706
# agent 88 在 149 次迭代中的对偶变量为: -139.42803390360598
# agent 89 在 149 次迭代中的对偶变量为: -139.42326833714137
# agent 90 在 149 次迭代中的对偶变量为: -139.77322978610536
# agent 91 在 149 次迭代中的对偶变量为: -139.6084050453172
# agent 92 在 149 次迭代中的对偶变量为: -139.8372783183423
# agent 93 在 149 次迭代中的对偶变量为: -139.8457590085272
# agent 94 在 149 次迭代中的对偶变量为: -139.64641429687967
# agent 95 在 149 次迭代中的对偶变量为: -139.5953251522719
# agent 96 在 149 次迭代中的对偶变量为: -139.5366511973348
# agent 97 在 149 次迭代中的对偶变量为: -139.3727752263934
# agent 98 在 149 次迭代中的对偶变量为: -139.63614989730698
# agent 99 在 149 次迭代中的对偶变量为: -139.61415237400348
# agent 100 在 149 次迭代中的对偶变量为: -139.77175150952553
# *************************
# 迭代步长为: 0.04966932281851884
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: 48.32607513257958
# agent 2 在 199 次迭代中的资源申请量为: 60.826240071569565
# agent 3 在 199 次迭代中的资源申请量为: 43.738286552665116
# agent 4 在 199 次迭代中的资源申请量为: 64.34953090940174
# agent 5 在 199 次迭代中的资源申请量为: 65.10655599785645
# agent 6 在 199 次迭代中的资源申请量为: 71.75920005826927
# agent 7 在 199 次迭代中的资源申请量为: 39.40124235621872
# agent 8 在 199 次迭代中的资源申请量为: 37.67167793041265
# agent 9 在 199 次迭代中的资源申请量为: 43.017904084476626
# agent 10 在 199 次迭代中的资源申请量为: 55.678630974795645
# agent 11 在 199 次迭代中的资源申请量为: 45.41122457290895
# agent 12 在 199 次迭代中的资源申请量为: 49.18640652693609
# agent 13 在 199 次迭代中的资源申请量为: 65.60408520348591
# agent 14 在 199 次迭代中的资源申请量为: 55.14043369425358
# agent 15 在 199 次迭代中的资源申请量为: 43.461906009179934
# agent 16 在 199 次迭代中的资源申请量为: 43.62408789642578
# agent 17 在 199 次迭代中的资源申请量为: 44.83140340819922
# agent 18 在 199 次迭代中的资源申请量为: 46.43465619087138
# agent 19 在 199 次迭代中的资源申请量为: 41.26551093228157
# agent 20 在 199 次迭代中的资源申请量为: 55.58659990425635
# agent 21 在 199 次迭代中的资源申请量为: 38.70340074322324
# agent 22 在 199 次迭代中的资源申请量为: 39.02536774835704
# agent 23 在 199 次迭代中的资源申请量为: 47.8214990425491
# agent 24 在 199 次迭代中的资源申请量为: 40.478810505631095
# agent 25 在 199 次迭代中的资源申请量为: 45.09116538388655
# agent 26 在 199 次迭代中的资源申请量为: 39.76712629708262
# agent 27 在 199 次迭代中的资源申请量为: 65.37636640120162
# agent 28 在 199 次迭代中的资源申请量为: 51.17645790670302
# agent 29 在 199 次迭代中的资源申请量为: 40.762134007807305
# agent 30 在 199 次迭代中的资源申请量为: 39.17600736483247
# agent 31 在 199 次迭代中的资源申请量为: 60.314334551672914
# agent 32 在 199 次迭代中的资源申请量为: 55.369493776268385
# agent 33 在 199 次迭代中的资源申请量为: 41.47140030400679
# agent 34 在 199 次迭代中的资源申请量为: 52.14767364491568
# agent 35 在 199 次迭代中的资源申请量为: 38.78645012205449
# agent 36 在 199 次迭代中的资源申请量为: 42.706745259150054
# agent 37 在 199 次迭代中的资源申请量为: 52.426690927431586
# agent 38 在 199 次迭代中的资源申请量为: 40.23822577842536
# agent 39 在 199 次迭代中的资源申请量为: 43.235267438300966
# agent 40 在 199 次迭代中的资源申请量为: 50.022112122584694
# agent 41 在 199 次迭代中的资源申请量为: 66.00534737238469
# agent 42 在 199 次迭代中的资源申请量为: 42.411128158116036
# agent 43 在 199 次迭代中的资源申请量为: 51.54923673218615
# agent 44 在 199 次迭代中的资源申请量为: 52.89552690161676
# agent 45 在 199 次迭代中的资源申请量为: 48.113991365387704
# agent 46 在 199 次迭代中的资源申请量为: 55.72666301304284
# agent 47 在 199 次迭代中的资源申请量为: 45.80502597712308
# agent 48 在 199 次迭代中的资源申请量为: 43.30906102922358
# agent 49 在 199 次迭代中的资源申请量为: 42.533815390922086
# agent 50 在 199 次迭代中的资源申请量为: 40.8286609613846
# agent 51 在 199 次迭代中的资源申请量为: 48.17094918882885
# agent 52 在 199 次迭代中的资源申请量为: 55.552965392711236
# agent 53 在 199 次迭代中的资源申请量为: 38.88344927936205
# agent 54 在 199 次迭代中的资源申请量为: 56.872495207775486
# agent 55 在 199 次迭代中的资源申请量为: 70.80835339281786
# agent 56 在 199 次迭代中的资源申请量为: 40.8687866171835
# agent 57 在 199 次迭代中的资源申请量为: 60.306490943020485
# agent 58 在 199 次迭代中的资源申请量为: 42.13811174077322
# agent 59 在 199 次迭代中的资源申请量为: 47.82177906727252
# agent 60 在 199 次迭代中的资源申请量为: 55.89696573299021
# agent 61 在 199 次迭代中的资源申请量为: 65.66705618475326
# agent 62 在 199 次迭代中的资源申请量为: 45.992190729144845
# agent 63 在 199 次迭代中的资源申请量为: 38.92912400528998
# agent 64 在 199 次迭代中的资源申请量为: 44.2964457812783
# agent 65 在 199 次迭代中的资源申请量为: 42.596359514993836
# agent 66 在 199 次迭代中的资源申请量为: 65.31771523348877
# agent 67 在 199 次迭代中的资源申请量为: 43.22329857110255
# agent 68 在 199 次迭代中的资源申请量为: 44.7895347501444
# agent 69 在 199 次迭代中的资源申请量为: 45.30025944371232
# agent 70 在 199 次迭代中的资源申请量为: 59.84051408746998
# agent 71 在 199 次迭代中的资源申请量为: 71.62476698088341
# agent 72 在 199 次迭代中的资源申请量为: 60.00517091780505
# agent 73 在 199 次迭代中的资源申请量为: 43.58652029142059
# agent 74 在 199 次迭代中的资源申请量为: 38.90653111239341
# agent 75 在 199 次迭代中的资源申请量为: 51.85064903626937
# agent 76 在 199 次迭代中的资源申请量为: 46.88459832173019
# agent 77 在 199 次迭代中的资源申请量为: 40.713944750521804
# agent 78 在 199 次迭代中的资源申请量为: 49.50691998967185
# agent 79 在 199 次迭代中的资源申请量为: 42.77705325745213
# agent 80 在 199 次迭代中的资源申请量为: 42.8893721865188
# agent 81 在 199 次迭代中的资源申请量为: 39.458254424554255
# agent 82 在 199 次迭代中的资源申请量为: 45.65873765532797
# agent 83 在 199 次迭代中的资源申请量为: 41.54760039619719
# agent 84 在 199 次迭代中的资源申请量为: 51.902989270479544
# agent 85 在 199 次迭代中的资源申请量为: 55.56147925188585
# agent 86 在 199 次迭代中的资源申请量为: 48.825274437210055
# agent 87 在 199 次迭代中的资源申请量为: 60.26059926715902
# agent 88 在 199 次迭代中的资源申请量为: 64.84950342284712
# agent 89 在 199 次迭代中的资源申请量为: 40.3738731873982
# agent 90 在 199 次迭代中的资源申请量为: 59.083042150727564
# agent 91 在 199 次迭代中的资源申请量为: 42.80031267184491
# agent 92 在 199 次迭代中的资源申请量为: 56.821695675617235
# agent 93 在 199 次迭代中的资源申请量为: 40.67263101265376
# agent 94 在 199 次迭代中的资源申请量为: 72.98770874697014
# agent 95 在 199 次迭代中的资源申请量为: 60.121918443377034
# agent 96 在 199 次迭代中的资源申请量为: 60.30030709627885
# agent 97 在 199 次迭代中的资源申请量为: 71.87106977272639
# agent 98 在 199 次迭代中的资源申请量为: 72.78361891811862
# agent 99 在 199 次迭代中的资源申请量为: 52.309115217036215
# agent 100 在 199 次迭代中的资源申请量为: 48.426136147993496
# 资源申请量总和为: 5022.331083509701
# ****************************************************************************
# 成本总和为: 337202.91051845136
# ****************************************************************************
# agent 1 在 199 次迭代中的对偶变量为: -139.87822539773876
# agent 2 在 199 次迭代中的对偶变量为: -139.74297617176694
# agent 3 在 199 次迭代中的对偶变量为: -139.8701742790614
# agent 4 在 199 次迭代中的对偶变量为: -139.80896800068385
# agent 5 在 199 次迭代中的对偶变量为: -139.71442319528418
# agent 6 在 199 次迭代中的对偶变量为: -139.51840011653854
# agent 7 在 199 次迭代中的对偶变量为: -139.8447209536311
# agent 8 在 199 次迭代中的对偶变量为: -139.88671172165058
# agent 9 在 199 次迭代中的对偶变量为: -139.80087388722052
# agent 10 在 199 次迭代中的对偶变量为: -139.8244405344687
# agent 11 在 199 次迭代中的对偶变量为: -139.87591863330866
# agent 12 在 199 次迭代中的对偶变量为: -139.75921958080826
# agent 13 在 199 次迭代中的对偶变量为: -139.70898744766902
# agent 14 在 199 次迭代中的对偶变量为: -139.98512760505932
# agent 15 在 199 次迭代中的对偶变量为: -139.9504804312118
# agent 16 在 199 次迭代中的对偶变量为: -139.82189884784765
# agent 17 在 199 次迭代中的对偶变量为: -139.9404909062375
# agent 18 在 199 次迭代中的对偶变量为: -139.9508998107884
# agent 19 在 199 次迭代中的对偶变量为: -139.91583935621364
# agent 20 在 199 次迭代中的对偶变量为: -139.84515975106652
# agent 21 在 199 次迭代中的对偶变量为: -139.8529228242483
# agent 22 在 199 次迭代中的对偶变量为: -139.93639744375676
# agent 23 在 199 次迭代中的对偶变量为: -140.16449712764728
# agent 24 在 199 次迭代中的对偶变量为: -139.96371782027197
# agent 25 在 199 次迭代中的对偶变量为: -139.81172922843697
# agent 26 在 199 次迭代中的对偶变量为: -140.09507992891395
# agent 27 在 199 次迭代中的对偶变量为: -139.86800608264357
# agent 28 在 199 次迭代中的对偶变量为: -139.65408213876847
# agent 29 在 199 次迭代中的对偶变量为: -139.9036824281063
# agent 30 在 199 次迭代中的对偶变量为: -140.12882798636338
# agent 31 在 199 次迭代中的对偶变量为: -139.95440292401497
# agent 32 在 199 次迭代中的对偶变量为: -139.8006838182978
# agent 33 在 199 次迭代中的对偶变量为: -139.57704109442446
# agent 34 在 199 次迭代中的对偶变量为: -139.8534862057639
# agent 35 在 199 次迭代中的对偶变量为: -139.78851046380706
# agent 36 在 199 次迭代中的对偶变量为: -139.76293388111017
# agent 37 在 199 次迭代中的对偶变量为: -139.79473459680844
# agent 38 在 199 次迭代中的对偶变量为: -139.8176128023313
# agent 39 在 199 次迭代中的对偶变量为: -139.8599092902233
# agent 40 在 199 次迭代中的对偶变量为: -139.8663363677541
# agent 41 在 199 次迭代中的对偶变量为: -139.71176421924633
# agent 42 在 199 次迭代中的对偶变量为: -139.77783573759453
# agent 43 在 199 次迭代中的对偶变量为: -139.57786285012122
# agent 44 在 199 次迭代中的对偶变量为: -139.9874753245269
# agent 45 在 199 次迭代中的对偶变量为: -139.8419740961631
# agent 46 在 199 次迭代中的对偶变量为: -139.9493238339114
# agent 47 在 199 次迭代中的对偶变量为: -139.85608312679386
# agent 48 在 199 次迭代中的对偶变量为: -139.77080749936016
# agent 49 在 199 次迭代中的对偶变量为: -139.5149723291351
# agent 50 在 199 次迭代中的对偶变量为: -139.78317946098457
# agent 51 在 199 次迭代中的对偶变量为: -139.71284756648654
# agent 52 在 199 次迭代中的对偶变量为: -139.7577100210492
# agent 53 在 199 次迭代中的对偶变量为: -139.7771072615758
# agent 54 在 199 次迭代中的对偶变量为: -140.06848754021627
# agent 55 在 199 次迭代中的对偶变量为: -139.81670678563572
# agent 56 在 199 次迭代中的对偶变量为: -139.92763182186061
# agent 57 在 199 次迭代中的对偶变量为: -139.93557826324914
# agent 58 在 199 次迭代中的对偶变量为: -139.86957991862894
# agent 59 在 199 次迭代中的对偶变量为: -139.86533720181757
# agent 60 在 199 次迭代中的对偶变量为: -139.87211090577455
# agent 61 在 199 次迭代中的对偶变量为: -139.62752360645717
# agent 62 在 199 次迭代中的对偶变量为: -139.8150103332635
# agent 63 在 199 次迭代中的对偶变量为: -139.95067122010192
# agent 64 在 199 次迭代中的对偶变量为: -139.8286265000906
# agent 65 在 199 次迭代中的对偶变量为: -139.72762235097903
# agent 66 在 199 次迭代中的对偶变量为: -139.5189735136753
# agent 67 在 199 次迭代中的对偶变量为: -139.81921514174869
# agent 68 在 199 次迭代中的对偶变量为: -139.80651120046207
# agent 69 在 199 次迭代中的对偶变量为: -139.84083021987942
# agent 70 在 199 次迭代中的对偶变量为: -139.77723380992794
# agent 71 在 199 次迭代中的对偶变量为: -139.4495339617668
# agent 72 在 199 次迭代中的对偶变量为: -139.69241020273213
# agent 73 在 199 次迭代中的对偶变量为: -139.69416899083
# agent 74 在 199 次迭代中的对偶变量为: -139.86481822709496
# agent 75 在 199 次迭代中的对偶变量为: -139.86181730155423
# agent 76 在 199 次迭代中的对偶变量为: -139.7907146295366
# agent 77 在 199 次迭代中的对偶变量为: -139.7302011018785
# agent 78 在 199 次迭代中的对偶变量为: -139.82075996901557
# agent 79 在 199 次迭代中的对偶变量为: -140.00198107533726
# agent 80 在 199 次迭代中的对偶变量为: -139.7038654341639
# agent 81 在 199 次迭代中的对偶变量为: -140.06136681330617
# agent 82 在 199 次迭代中的对偶变量为: -140.0279604970495
# agent 83 在 199 次迭代中的对偶变量为: -139.8513614263099
# agent 84 在 199 次迭代中的对偶变量为: -139.72836995734272
# agent 85 在 199 次迭代中的对偶变量为: -139.7798460549032
# agent 86 在 199 次迭代中的对偶变量为: -139.87582331163017
# agent 87 在 199 次迭代中的对偶变量为: -139.82543824118164
# agent 88 在 199 次迭代中的对偶变量为: -139.58890753026367
# agent 89 在 199 次迭代中的对偶变量为: -139.58594347463355
# agent 90 在 199 次迭代中的对偶变量为: -139.87930116174616
# agent 91 在 199 次迭代中的对偶变量为: -139.74106308427267
# agent 92 在 199 次迭代中的对偶变量为: -139.9364087566048
# agent 93 在 199 次迭代中的对偶变量为: -139.94147164555355
# agent 94 在 199 次迭代中的对偶变量为: -139.7754174939403
# agent 95 在 199 次迭代中的对偶变量为: -139.73260426410488
# agent 96 在 199 次迭代中的对偶变量为: -139.68073703106924
# agent 97 在 199 次迭代中的对偶变量为: -139.54213954545278
# agent 98 在 199 次迭代中的对偶变量为: -139.76723783623723
# agent 99 在 199 次迭代中的对偶变量为: -139.7455226077014
# agent 100 在 199 次迭代中的对偶变量为: -139.87840844398048
# *************************
# 迭代步长为: 0.04175304505755262
# ****************************************************************************
# 249 次迭代中的结果：
# agent 1 在 249 次迭代中的资源申请量为: 48.3507520854144
# agent 2 在 249 次迭代中的资源申请量为: 60.86485115302801
# agent 3 在 249 次迭代中的资源申请量为: 43.76042106884203
# agent 4 在 249 次迭代中的资源申请量为: 64.38704637309553
# agent 5 在 249 次迭代中的资源申请量为: 65.14929510706587
# agent 6 在 249 次迭代中的资源申请量为: 71.8185951577525
# agent 7 在 249 次迭代中的资源申请量为: 39.42232474995941
# agent 8 在 249 次迭代中的资源申请量为: 37.6908037460659
# agent 9 在 249 次迭代中的资源申请量为: 43.0431157267029
# agent 10 在 249 次迭代中的资源申请量为: 55.71044676893272
# agent 11 在 249 次迭代中的资源申请量为: 45.435017701418
# agent 12 在 249 次迭代中的资源申请量为: 49.217374649580755
# agent 13 在 249 次迭代中的资源申请量为: 65.64767008104435
# agent 14 在 249 次迭代中的资源申请量为: 55.16431952165204
# agent 15 在 249 次迭代中的资源申请量为: 43.48113476671683
# agent 16 在 249 次迭代中的资源申请量为: 43.64773356715502
# agent 17 在 249 次迭代中的资源申请量为: 44.85223217612729
# agent 18 在 249 次迭代中的资源申请量为: 46.455375553728295
# agent 19 在 249 次迭代中的资源申请量为: 41.28538015022807
# agent 20 在 249 次迭代中的资源申请量为: 55.61836290112928
# agent 21 在 249 次迭代中的资源申请量为: 38.72452117439658
# agent 22 在 249 次迭代中的资源申请量为: 39.04350585067644
# agent 23 在 249 次迭代中的资源申请量为: 47.834289499468355
# agent 24 在 249 次迭代中的资源申请量为: 40.496268067845875
# agent 25 在 249 次迭代中的资源申请量为: 45.116901208165494
# agent 26 在 249 次迭代中的资源申请量为: 39.78005639266577
# agent 27 在 249 次迭代中的资源申请量为: 65.41130711170129
# agent 28 在 249 次迭代中的资源申请量为: 51.21292373499975
# agent 29 在 249 次迭代中的资源申请量为: 40.7818274461709
# agent 30 在 249 次迭代中的资源申请量为: 39.188424232396144
# agent 31 在 249 次迭代中的资源申请量为: 60.34198337214677
# agent 32 在 249 次迭代中的资源申请量为: 55.40152796493703
# agent 33 在 249 次迭代中的资源申请量为: 41.50234645576457
# agent 34 在 249 次迭代中的资源申请量为: 52.17585277509445
# agent 35 在 249 次迭代中的资源申请量为: 38.80981055397322
# agent 36 在 249 次迭代中的资源申请量为: 42.73330031254062
# agent 37 在 249 次迭代中的资源申请量为: 52.456784746652914
# agent 38 在 249 次迭代中的资源申请量为: 40.26084373800948
# agent 39 在 249 次迭代中的资源申请量为: 43.25763480863622
# agent 40 在 249 次迭代中的资源申请量为: 50.04802528543058
# agent 41 在 249 次迭代中的资源申请量为: 66.04946641593175
# agent 42 在 249 次迭代中的资源申请量为: 42.43664764498332
# agent 43 在 249 次迭代中的资源申请量为: 51.588740134972085
# agent 44 在 249 次迭代中的资源申请量为: 52.91690489656895
# agent 45 在 249 次迭代中的资源申请量为: 48.1400619714
# agent 46 在 249 次迭代中的资源申请量为: 55.75344869627007
# agent 47 在 249 次迭代中的资源申请量为: 45.829647180544804
# agent 48 在 249 次迭代中的资源申请量为: 43.33529360049028
# agent 49 在 249 次迭代中的资源申请量为: 42.568714236866555
# agent 50 在 249 次迭代中的资源申请量为: 40.85242332026655
# agent 51 在 249 次迭代中的资源申请量为: 48.203171112827725
# agent 52 在 249 次迭代中的资源申请量为: 55.5871571483116
# agent 53 在 249 次迭代中的资源申请量为: 38.90633801102845
# agent 54 在 249 次迭代中的资源申请量为: 56.892510766110014
# agent 55 在 249 次迭代中的资源申请量为: 70.8500125592682
# agent 56 在 249 次迭代中的资源申请量为: 40.88756319166707
# agent 57 在 249 次迭代中的资源申请量为: 60.3360348237941
# agent 58 在 249 次迭代中的资源申请量为: 42.16079714223329
# agent 59 在 249 次迭代中的资源申请量为: 47.84754287212376
# agent 60 在 249 次迭代中的资源申请量为: 55.92631904308596
# agent 61 在 249 次迭代中的资源申请量为: 65.7148508921142
# agent 62 在 249 次迭代中的资源申请量为: 46.017672051793284
# agent 63 在 249 次迭代中的资源申请量为: 38.94669752639015
# agent 64 在 249 次迭代中的资源申请量为: 44.32152504281416
# agent 65 在 249 次迭代中的资源申请量为: 42.62347399221345
# agent 66 在 249 次迭代中的资源申请量为: 65.37163689322684
# agent 67 在 249 次迭代中的资源申请量为: 43.247084386128044
# agent 68 在 249 次迭代中的资源申请量为: 44.815366360806884
# agent 69 在 249 次迭代中的资源申请量为: 45.32467534270799
# agent 70 在 249 次迭代中的资源申请量为: 59.876662598407364
# agent 71 在 249 次迭代中的资源申请量为: 71.68844741295753
# agent 72 在 249 次迭代中的资源申请量为: 60.04647446415393
# agent 73 在 249 次迭代中的资源申请量为: 43.61500523202175
# agent 74 在 249 次迭代中的资源申请量为: 38.926315230721826
# agent 75 在 249 次迭代中的资源申请量为: 51.87761075906156
# agent 76 在 249 次迭代中的资源申请量为: 46.91104861590722
# agent 77 在 249 次迭代中的资源申请量为: 40.739545286805146
# agent 78 在 249 次迭代中的资源申请量为: 49.53396173957763
# agent 79 在 249 次迭代中的资源申请量为: 42.79498806283772
# agent 80 在 249 次迭代中的资源申请量为: 42.91739629004193
# agent 81 在 249 次迭代中的资源申请量为: 39.47174171876671
# agent 82 在 249 次迭代中的资源申请量为: 45.67670593264798
# agent 83 在 249 次迭代中的资源申请量为: 41.56923645713464
# agent 84 在 249 次迭代中的资源申请量为: 51.936710505082395
# agent 85 在 249 次迭代中的资源申请量为: 55.59447354982475
# agent 86 在 249 次迭代中的资源申请量为: 48.850561573058144
# agent 87 在 249 次迭代中的资源申请量为: 60.29494926532631
# agent 88 在 249 次迭代中的资源申请量为: 64.89940595856056
# agent 89 在 249 次迭代中的资源申请量为: 40.4046798003113
# agent 90 在 249 次迭代中的资源申请量为: 59.11359307246407
# agent 91 在 249 次迭代中的资源申请量为: 42.8270663452948
# agent 92 在 249 次迭代中的资源申请量为: 56.84803650053001
# agent 93 在 249 次迭代中的资源申请量为: 40.69105946397913
# agent 94 在 249 次迭代中的资源申请量为: 73.03190080660934
# agent 95 在 249 次迭代中的资源申请量为: 60.161030140453114
# agent 96 在 249 次迭代中的资源申请量为: 60.34137566912232
# agent 97 在 249 次迭代中的资源申请量为: 71.92879005240556
# agent 98 在 249 次迭代中的资源申请量为: 72.82849154957186
# agent 99 在 249 次迭代中的资源申请量为: 52.3413046117464
# agent 100 在 249 次迭代中的资源申请量为: 48.450697250178614
# 资源申请量总和为: 5025.221430909812
# ****************************************************************************
# 成本总和为: 337607.04963552125
# ...
# agent 61 在 57999 次迭代中的资源申请量为: 45.35594989347403
# agent 62 在 57999 次迭代中的资源申请量为: 37.777916501990724
# agent 63 在 57999 次迭代中的资源申请量为: 44.36024833408177
# agent 64 在 57999 次迭代中的资源申请量为: 50.59248382563158
# agent 65 在 57999 次迭代中的资源申请量为: 48.719342447654434
# agent 66 在 57999 次迭代中的资源申请量为: 53.47780999250294
# agent 67 在 57999 次迭代中的资源申请量为: 44.62937911116489
# agent 68 在 57999 次迭代中的资源申请量为: 38.64566746179317
# agent 69 在 57999 次迭代中的资源申请量为: 49.892139157742264
# agent 70 在 57999 次迭代中的资源申请量为: 43.38409217370307
# agent 71 在 57999 次迭代中的资源申请量为: 51.072439614453316
# agent 72 在 57999 次迭代中的资源申请量为: 51.63101181607402
# agent 73 在 57999 次迭代中的资源申请量为: 68.52493850742536
# agent 74 在 57999 次迭代中的资源申请量为: 63.033563690013715
# agent 75 在 57999 次迭代中的资源申请量为: 68.784860310892
# agent 76 在 57999 次迭代中的资源申请量为: 65.84231131075826
# agent 77 在 57999 次迭代中的资源申请量为: 37.33178559067635
# agent 78 在 57999 次迭代中的资源申请量为: 56.51515954674519
# agent 79 在 57999 次迭代中的资源申请量为: 35.71319766839764
# agent 80 在 57999 次迭代中的资源申请量为: 41.69438982489503
# agent 81 在 57999 次迭代中的资源申请量为: 64.43288578237497
# agent 82 在 57999 次迭代中的资源申请量为: 45.64920279686928
# agent 83 在 57999 次迭代中的资源申请量为: 54.00548947849253
# agent 84 在 57999 次迭代中的资源申请量为: 52.98642785861979
# agent 85 在 57999 次迭代中的资源申请量为: 58.685757530611916
# agent 86 在 57999 次迭代中的资源申请量为: 54.16278250297388
# agent 87 在 57999 次迭代中的资源申请量为: 50.183947875573004
# agent 88 在 57999 次迭代中的资源申请量为: 53.40486804038364
# agent 89 在 57999 次迭代中的资源申请量为: 44.037016821613456
# agent 90 在 57999 次迭代中的资源申请量为: 38.995841039652966
# agent 91 在 57999 次迭代中的资源申请量为: 43.58677066582213
# agent 92 在 57999 次迭代中的资源申请量为: 45.25809138455365
# agent 93 在 57999 次迭代中的资源申请量为: 35.68321481266967
# agent 94 在 57999 次迭代中的资源申请量为: 37.48060785879904
# 资源申请量平均值avg为: 49.99999999999654
# ****************************************************************************
# 平均成本为: 3240.481984531225
# ****************************************************************************
# agent 1 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 2 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 3 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 4 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 5 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 6 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 7 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 8 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 9 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 10 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 11 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 12 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 13 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 14 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 15 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 16 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 17 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 18 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 19 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 20 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 21 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 22 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 23 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 24 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 25 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 26 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 27 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 28 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 29 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 30 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 31 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 32 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 33 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 34 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 35 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 36 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 37 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 38 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 39 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 40 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 41 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 42 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 43 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 44 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 45 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 46 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 47 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 48 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 49 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 50 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 51 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 52 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 53 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 54 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 55 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 56 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 57 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 58 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 59 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 60 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 61 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 62 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 63 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 64 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 65 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 66 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 67 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 68 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 69 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 70 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 71 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 72 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 73 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 74 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 75 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 76 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 77 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 78 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 79 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 80 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 81 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 82 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 83 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 84 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 85 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 86 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 87 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 88 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 89 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 90 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 91 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 92 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 93 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 94 在 57999 次迭代中的对偶变量为: -135.14386653834575
# *************************
# 迭代步长为: 0.11151053484837568
# ****************************************************************************
# 59999 次迭代中的结果：
# agent 1 在 59999 次迭代中的资源申请量为: 56.19880558172988
# agent 2 在 59999 次迭代中的资源申请量为: 56.03871203978166
# agent 3 在 59999 次迭代中的资源申请量为: 60.64796214442871
# agent 4 在 59999 次迭代中的资源申请量为: 37.93333499802675
# agent 5 在 59999 次迭代中的资源申请量为: 57.56693686702461
# agent 6 在 59999 次迭代中的资源申请量为: 55.34212747123894
# agent 7 在 59999 次迭代中的资源申请量为: 65.6236567946489
# agent 8 在 59999 次迭代中的资源申请量为: 46.330946703602365
# agent 9 在 59999 次迭代中的资源申请量为: 65.64268770463663
# agent 10 在 59999 次迭代中的资源申请量为: 54.23914303693835
# agent 11 在 59999 次迭代中的资源申请量为: 65.4520437985654
# agent 12 在 59999 次迭代中的资源申请量为: 38.406222330358624
# agent 13 在 59999 次迭代中的资源申请量为: 49.70058714461363
# agent 14 在 59999 次迭代中的资源申请量为: 41.3659905551611
# agent 15 在 59999 次迭代中的资源申请量为: 42.48853939614691
# agent 16 在 59999 次迭代中的资源申请量为: 49.24530133808371
# agent 17 在 59999 次迭代中的资源申请量为: 50.11852704992918
# agent 18 在 59999 次迭代中的资源申请量为: 46.537297422347486
# agent 19 在 59999 次迭代中的资源申请量为: 44.77392156663175
# agent 20 在 59999 次迭代中的资源申请量为: 50.80339666473046
# agent 21 在 59999 次迭代中的资源申请量为: 69.93387670557085
# agent 22 在 59999 次迭代中的资源申请量为: 61.24199691647269
# agent 23 在 59999 次迭代中的资源申请量为: 61.627787986086716
# agent 24 在 59999 次迭代中的资源申请量为: 39.861352301782716
# agent 25 在 59999 次迭代中的资源申请量为: 52.95065687328203
# agent 26 在 59999 次迭代中的资源申请量为: 49.39633437684004
# agent 27 在 59999 次迭代中的资源申请量为: 47.51919637207136
# agent 28 在 59999 次迭代中的资源申请量为: 40.7413613830987
# agent 29 在 59999 次迭代中的资源申请量为: 44.38273034135506
# agent 30 在 59999 次迭代中的资源申请量为: 39.891745956789116
# agent 31 在 59999 次迭代中的资源申请量为: 65.76280653244551
# agent 32 在 59999 次迭代中的资源申请量为: 59.51901541924079
# agent 33 在 59999 次迭代中的资源申请量为: 48.23750867799392
# agent 34 在 59999 次迭代中的资源申请量为: 36.76532342510125
# agent 35 在 59999 次迭代中的资源申请量为: 41.086702696803464
# agent 36 在 59999 次迭代中的资源申请量为: 62.20889044924783
# agent 37 在 59999 次迭代中的资源申请量为: 40.47023795026076
# agent 38 在 59999 次迭代中的资源申请量为: 58.24733429492913
# agent 39 在 59999 次迭代中的资源申请量为: 37.39554726071002
# agent 40 在 59999 次迭代中的资源申请量为: 50.45313221045784
# agent 41 在 59999 次迭代中的资源申请量为: 36.73569742369616
# agent 42 在 59999 次迭代中的资源申请量为: 56.24242387150355
# agent 43 在 59999 次迭代中的资源申请量为: 61.52373322591861
# agent 44 在 59999 次迭代中的资源申请量为: 47.51525622305313
# agent 45 在 59999 次迭代中的资源申请量为: 41.36197014706921
# agent 46 在 59999 次迭代中的资源申请量为: 67.10436077257359
# agent 47 在 59999 次迭代中的资源申请量为: 65.57090570810219
# agent 48 在 59999 次迭代中的资源申请量为: 40.83836334458436
# agent 49 在 59999 次迭代中的资源申请量为: 39.16390664937778
# agent 50 在 59999 次迭代中的资源申请量为: 63.292999181236645
# agent 51 在 59999 次迭代中的资源申请量为: 36.39727688961264
# agent 52 在 59999 次迭代中的资源申请量为: 46.86937779818014
# agent 53 在 59999 次迭代中的资源申请量为: 43.572511920796444
# agent 54 在 59999 次迭代中的资源申请量为: 49.58201107681077
# agent 55 在 59999 次迭代中的资源申请量为: 47.173391517077015
# agent 56 在 59999 次迭代中的资源申请量为: 42.97971616155657
# agent 57 在 59999 次迭代中的资源申请量为: 36.90486251978384
# agent 58 在 59999 次迭代中的资源申请量为: 59.2566799113546
# agent 59 在 59999 次迭代中的资源申请量为: 59.891586060534515
# agent 60 在 59999 次迭代中的资源申请量为: 40.34169962872796
# agent 61 在 59999 次迭代中的资源申请量为: 45.35594989347582
# agent 62 在 59999 次迭代中的资源申请量为: 37.77791650199216
# agent 63 在 59999 次迭代中的资源申请量为: 44.360248334083515
# agent 64 在 59999 次迭代中的资源申请量为: 50.59248382563358
# agent 65 在 59999 次迭代中的资源申请量为: 48.71934244765636
# agent 66 在 59999 次迭代中的资源申请量为: 53.47780999250507
# agent 67 在 59999 次迭代中的资源申请量为: 44.62937911116663
# agent 68 在 59999 次迭代中的资源申请量为: 38.64566746179467
# agent 69 在 59999 次迭代中的资源申请量为: 49.89213915774424
# agent 70 在 59999 次迭代中的资源申请量为: 43.384092173704765
# agent 71 在 59999 次迭代中的资源申请量为: 51.07243961445531
# agent 72 在 59999 次迭代中的资源申请量为: 51.63101181607605
# agent 73 在 59999 次迭代中的资源申请量为: 68.52493850742809
# agent 74 在 59999 次迭代中的资源申请量为: 63.033563690016244
# agent 75 在 59999 次迭代中的资源申请量为: 68.78486031089474
# agent 76 在 59999 次迭代中的资源申请量为: 65.84231131076093
# agent 77 在 59999 次迭代中的资源申请量为: 37.33178559067781
# agent 78 在 59999 次迭代中的资源申请量为: 56.51515954674745
# agent 79 在 59999 次迭代中的资源申请量为: 35.713197668399026
# agent 80 在 59999 次迭代中的资源申请量为: 41.69438982489667
# agent 81 在 59999 次迭代中的资源申请量为: 64.43288578237754
# agent 82 在 59999 次迭代中的资源申请量为: 45.64920279687104
# agent 83 在 59999 次迭代中的资源申请量为: 54.00548947849467
# agent 84 在 59999 次迭代中的资源申请量为: 52.98642785862186
# agent 85 在 59999 次迭代中的资源申请量为: 58.685757530614225
# agent 86 在 59999 次迭代中的资源申请量为: 54.16278250297603
# agent 87 在 59999 次迭代中的资源申请量为: 50.18394787557497
# agent 88 在 59999 次迭代中的资源申请量为: 53.40486804038577
# agent 89 在 59999 次迭代中的资源申请量为: 44.03701682161516
# agent 90 在 59999 次迭代中的资源申请量为: 38.99584103965445
# agent 91 在 59999 次迭代中的资源申请量为: 43.58677066582381
# agent 92 在 59999 次迭代中的资源申请量为: 45.258091384555385
# agent 93 在 59999 次迭代中的资源申请量为: 35.68321481267107
# agent 94 在 59999 次迭代中的资源申请量为: 37.4806078588005
# 资源申请量平均值avg为: 49.9999999999985
# ****************************************************************************
# 平均成本为: 3240.4819845314896
# ****************************************************************************
# agent 1 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 2 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 3 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 4 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 5 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 6 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 7 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 8 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 9 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 10 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 11 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 12 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 13 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 14 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 15 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 16 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 17 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 18 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 19 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 20 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 21 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 22 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 23 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 24 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 25 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 26 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 27 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 28 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 29 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 30 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 31 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 32 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 33 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 34 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 35 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 36 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 37 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 38 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 39 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 40 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 41 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 42 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 43 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 44 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 45 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 46 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 47 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 48 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 49 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 50 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 51 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 52 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 53 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 54 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 55 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 56 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 57 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 58 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 59 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 60 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 61 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 62 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 63 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 64 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 65 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 66 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 67 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 68 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 69 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 70 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 71 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 72 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 73 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 74 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 75 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 76 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 77 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 78 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 79 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 80 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 81 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 82 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 83 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 84 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 85 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 86 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 87 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 88 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 89 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 90 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 91 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 92 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 93 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 94 在 59999 次迭代中的对偶变量为: -135.1438665383513
# *************************
# 迭代步长为: 0.11075700351730201
# ****************************************************************************
# 2023-05-29 15:40:13.737

# %%
np.savetxt('../data/01-DGD-agent_resource_quantity_small_value_deterministic_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/01-DGD-sum_cost_small_value_deterministic_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/01-DGD-sum_resource_small_value_deterministic_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
