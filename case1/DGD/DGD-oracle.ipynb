# %% [markdown]
# 测试DGD算法的性能
# 与邻居交换本地的对偶信息
#
# 我们考虑的是100个用户构成的随机无向图网络，每个用户与网络中任意的15个用户建立通信链路

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(100,1000)) #100个agent的资源量 定义成一个矩阵 100*20000
dual_variable = np.zeros(shape=(100,1000))#对偶变量
sum_resource=np.zeros(shape=(1,1000), dtype=np.float64)#存放每一次迭代后所有用户资源量的总和
sum_cost=np.zeros(shape=(1,1000), dtype=np.float64)#存放每一次迭代后所有用户成本的总和
iteration_update = 0.01#迭代步长
A=np.loadtxt("100_Network_Topology_Double_Random_Adjacency_Matrix_Degree_15.txt") #网络拓扑的邻接矩阵 对角元素要为0
W=np.zeros(shape=(100,100)) #双随机的网络拓扑矩阵W（对角线处非零）
iteration=[]#绘图横坐标
a=np.loadtxt("100_uniform_distribution_(1,2)_point1.txt")#每个agent的成本函数中的超参数
b=np.loadtxt("100_normal_distribution_(2,0.6)_point1.txt")#每个agent的成本函数中的超参数

# %%
#根据邻接矩阵生成网络对应的双随机的权重混合矩阵
for i in range(0,100):
    for j in range(0,100):
        if A[i][j]!=0 or i==j:
            W[i][j]=1/16

#对偶变量的初始化 初始化一致
for i in range (0,100):
    dual_variable[i][0]=0
    
#资源量的初始化 资源量的初始化需要和对偶变量的初始值满足某种关系
for i in range (0,100):
    agent_resource_quantity[i][0]=50

iteration.append(0)

#总资源量 初始化
sum=0
for i in range (0,100):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

#用户总成本初始化
sum=0
for i in range(0,100):
    sum=sum+a[i]*(agent_resource_quantity[i][0]-b[i])*(agent_resource_quantity[i][0]-b[i])
sum_cost[0][0]=sum

# %%
#DGD算法 
def DGD(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************DGD算法+无计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,100):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    for i in range(0,100):
        print("agent",(i+1),"的初始对偶变量为:",dual_variable[i][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):#迭代次数
        iteration.append(k)
        
        #所有用户对偶变量的迭代 
        #阶段一：梯度下降
        dual_variable_intermediate=[] #存放当前迭代中100个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,100):
            #每个用户对对偶变量先进行一次梯度下降
            dual_variable_intermediate.append(dual_variable[i][k-1]-iteration_update*(50-agent_resource_quantity[i][k-1]))       
        #阶段二：聚合 每个用户聚合自身以及邻居的对偶值   
        for i in range(0,100):
            mix_sum_dual=0
            for j in range(0,100):
                if W[i][j]!=0:
                    mix_sum_dual=mix_sum_dual+W[i][j]*dual_variable_intermediate[j]
            dual_variable[i][k]=mix_sum_dual                    
        
        #用户资源申请量的迭代
        for i in range (0,100):
            agent_resource_quantity[i][k]=(dual_variable[i][k]-2*a[i]*b[i])/(-2*a[i])

        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,100):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,100):
            sum2=sum2+a[i]*(agent_resource_quantity[i][k]-b[i])*(agent_resource_quantity[i][k]-b[i])
        sum_cost[0][k]=sum2
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%50==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,100):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            for i in range(0,100):
                print("agent",(i+1),"在",k,"次迭代中的对偶变量为:",dual_variable[i][k])   
            print("*************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        iteration_update=1/(pow(k+1,0.6)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
DGD(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration)
# Out:
# ****************************DGD算法+无计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 50.0
# agent 2 的初始资源申请量为: 50.0
# agent 3 的初始资源申请量为: 50.0
# agent 4 的初始资源申请量为: 50.0
# agent 5 的初始资源申请量为: 50.0
# agent 6 的初始资源申请量为: 50.0
# agent 7 的初始资源申请量为: 50.0
# agent 8 的初始资源申请量为: 50.0
# agent 9 的初始资源申请量为: 50.0
# agent 10 的初始资源申请量为: 50.0
# agent 11 的初始资源申请量为: 50.0
# agent 12 的初始资源申请量为: 50.0
# agent 13 的初始资源申请量为: 50.0
# agent 14 的初始资源申请量为: 50.0
# agent 15 的初始资源申请量为: 50.0
# agent 16 的初始资源申请量为: 50.0
# agent 17 的初始资源申请量为: 50.0
# agent 18 的初始资源申请量为: 50.0
# agent 19 的初始资源申请量为: 50.0
# agent 20 的初始资源申请量为: 50.0
# agent 21 的初始资源申请量为: 50.0
# agent 22 的初始资源申请量为: 50.0
# agent 23 的初始资源申请量为: 50.0
# agent 24 的初始资源申请量为: 50.0
# agent 25 的初始资源申请量为: 50.0
# agent 26 的初始资源申请量为: 50.0
# agent 27 的初始资源申请量为: 50.0
# agent 28 的初始资源申请量为: 50.0
# agent 29 的初始资源申请量为: 50.0
# agent 30 的初始资源申请量为: 50.0
# agent 31 的初始资源申请量为: 50.0
# agent 32 的初始资源申请量为: 50.0
# agent 33 的初始资源申请量为: 50.0
# agent 34 的初始资源申请量为: 50.0
# agent 35 的初始资源申请量为: 50.0
# agent 36 的初始资源申请量为: 50.0
# agent 37 的初始资源申请量为: 50.0
# agent 38 的初始资源申请量为: 50.0
# agent 39 的初始资源申请量为: 50.0
# agent 40 的初始资源申请量为: 50.0
# agent 41 的初始资源申请量为: 50.0
# agent 42 的初始资源申请量为: 50.0
# agent 43 的初始资源申请量为: 50.0
# agent 44 的初始资源申请量为: 50.0
# agent 45 的初始资源申请量为: 50.0
# agent 46 的初始资源申请量为: 50.0
# agent 47 的初始资源申请量为: 50.0
# agent 48 的初始资源申请量为: 50.0
# agent 49 的初始资源申请量为: 50.0
# agent 50 的初始资源申请量为: 50.0
# agent 51 的初始资源申请量为: 50.0
# agent 52 的初始资源申请量为: 50.0
# agent 53 的初始资源申请量为: 50.0
# agent 54 的初始资源申请量为: 50.0
# agent 55 的初始资源申请量为: 50.0
# agent 56 的初始资源申请量为: 50.0
# agent 57 的初始资源申请量为: 50.0
# agent 58 的初始资源申请量为: 50.0
# agent 59 的初始资源申请量为: 50.0
# agent 60 的初始资源申请量为: 50.0
# agent 61 的初始资源申请量为: 50.0
# agent 62 的初始资源申请量为: 50.0
# agent 63 的初始资源申请量为: 50.0
# agent 64 的初始资源申请量为: 50.0
# agent 65 的初始资源申请量为: 50.0
# agent 66 的初始资源申请量为: 50.0
# agent 67 的初始资源申请量为: 50.0
# agent 68 的初始资源申请量为: 50.0
# agent 69 的初始资源申请量为: 50.0
# agent 70 的初始资源申请量为: 50.0
# agent 71 的初始资源申请量为: 50.0
# agent 72 的初始资源申请量为: 50.0
# agent 73 的初始资源申请量为: 50.0
# agent 74 的初始资源申请量为: 50.0
# agent 75 的初始资源申请量为: 50.0
# agent 76 的初始资源申请量为: 50.0
# agent 77 的初始资源申请量为: 50.0
# agent 78 的初始资源申请量为: 50.0
# agent 79 的初始资源申请量为: 50.0
# agent 80 的初始资源申请量为: 50.0
# agent 81 的初始资源申请量为: 50.0
# agent 82 的初始资源申请量为: 50.0
# agent 83 的初始资源申请量为: 50.0
# agent 84 的初始资源申请量为: 50.0
# agent 85 的初始资源申请量为: 50.0
# agent 86 的初始资源申请量为: 50.0
# agent 87 的初始资源申请量为: 50.0
# agent 88 的初始资源申请量为: 50.0
# agent 89 的初始资源申请量为: 50.0
# agent 90 的初始资源申请量为: 50.0
# agent 91 的初始资源申请量为: 50.0
# agent 92 的初始资源申请量为: 50.0
# agent 93 的初始资源申请量为: 50.0
# agent 94 的初始资源申请量为: 50.0
# agent 95 的初始资源申请量为: 50.0
# agent 96 的初始资源申请量为: 50.0
# agent 97 的初始资源申请量为: 50.0
# agent 98 的初始资源申请量为: 50.0
# agent 99 的初始资源申请量为: 50.0
# agent 100 的初始资源申请量为: 50.0
# *************************
# 初始资源申请量总和为: 5000.0
# *************************
# 初始成本总和为: 346654.5889999999
# *************************
# agent 1 的初始对偶变量为: 0.0
# agent 2 的初始对偶变量为: 0.0
# agent 3 的初始对偶变量为: 0.0
# agent 4 的初始对偶变量为: 0.0
# agent 5 的初始对偶变量为: 0.0
# agent 6 的初始对偶变量为: 0.0
# agent 7 的初始对偶变量为: 0.0
# agent 8 的初始对偶变量为: 0.0
# agent 9 的初始对偶变量为: 0.0
# agent 10 的初始对偶变量为: 0.0
# agent 11 的初始对偶变量为: 0.0
# agent 12 的初始对偶变量为: 0.0
# agent 13 的初始对偶变量为: 0.0
# agent 14 的初始对偶变量为: 0.0
# agent 15 的初始对偶变量为: 0.0
# agent 16 的初始对偶变量为: 0.0
# agent 17 的初始对偶变量为: 0.0
# agent 18 的初始对偶变量为: 0.0
# agent 19 的初始对偶变量为: 0.0
# agent 20 的初始对偶变量为: 0.0
# agent 21 的初始对偶变量为: 0.0
# agent 22 的初始对偶变量为: 0.0
# agent 23 的初始对偶变量为: 0.0
# agent 24 的初始对偶变量为: 0.0
# agent 25 的初始对偶变量为: 0.0
# agent 26 的初始对偶变量为: 0.0
# agent 27 的初始对偶变量为: 0.0
# agent 28 的初始对偶变量为: 0.0
# agent 29 的初始对偶变量为: 0.0
# agent 30 的初始对偶变量为: 0.0
# agent 31 的初始对偶变量为: 0.0
# agent 32 的初始对偶变量为: 0.0
# agent 33 的初始对偶变量为: 0.0
# agent 34 的初始对偶变量为: 0.0
# agent 35 的初始对偶变量为: 0.0
# agent 36 的初始对偶变量为: 0.0
# agent 37 的初始对偶变量为: 0.0
# agent 38 的初始对偶变量为: 0.0
# agent 39 的初始对偶变量为: 0.0
# agent 40 的初始对偶变量为: 0.0
# agent 41 的初始对偶变量为: 0.0
# agent 42 的初始对偶变量为: 0.0
# agent 43 的初始对偶变量为: 0.0
# agent 44 的初始对偶变量为: 0.0
# agent 45 的初始对偶变量为: 0.0
# agent 46 的初始对偶变量为: 0.0
# agent 47 的初始对偶变量为: 0.0
# agent 48 的初始对偶变量为: 0.0
# agent 49 的初始对偶变量为: 0.0
# agent 50 的初始对偶变量为: 0.0
# agent 51 的初始对偶变量为: 0.0
# agent 52 的初始对偶变量为: 0.0
# agent 53 的初始对偶变量为: 0.0
# agent 54 的初始对偶变量为: 0.0
# agent 55 的初始对偶变量为: 0.0
# agent 56 的初始对偶变量为: 0.0
# agent 57 的初始对偶变量为: 0.0
# agent 58 的初始对偶变量为: 0.0
# agent 59 的初始对偶变量为: 0.0
# agent 60 的初始对偶变量为: 0.0
# agent 61 的初始对偶变量为: 0.0
# agent 62 的初始对偶变量为: 0.0
# agent 63 的初始对偶变量为: 0.0
# agent 64 的初始对偶变量为: 0.0
# agent 65 的初始对偶变量为: 0.0
# agent 66 的初始对偶变量为: 0.0
# agent 67 的初始对偶变量为: 0.0
# agent 68 的初始对偶变量为: 0.0
# agent 69 的初始对偶变量为: 0.0
# agent 70 的初始对偶变量为: 0.0
# agent 71 的初始对偶变量为: 0.0
# agent 72 的初始对偶变量为: 0.0
# agent 73 的初始对偶变量为: 0.0
# agent 74 的初始对偶变量为: 0.0
# agent 75 的初始对偶变量为: 0.0
# agent 76 的初始对偶变量为: 0.0
# agent 77 的初始对偶变量为: 0.0
# agent 78 的初始对偶变量为: 0.0
# agent 79 的初始对偶变量为: 0.0
# agent 80 的初始对偶变量为: 0.0
# agent 81 的初始对偶变量为: 0.0
# agent 82 的初始对偶变量为: 0.0
# agent 83 的初始对偶变量为: 0.0
# agent 84 的初始对偶变量为: 0.0
# agent 85 的初始对偶变量为: 0.0
# agent 86 的初始对偶变量为: 0.0
# agent 87 的初始对偶变量为: 0.0
# agent 88 的初始对偶变量为: 0.0
# agent 89 的初始对偶变量为: 0.0
# agent 90 的初始对偶变量为: 0.0
# agent 91 的初始对偶变量为: 0.0
# agent 92 的初始对偶变量为: 0.0
# agent 93 的初始对偶变量为: 0.0
# agent 94 的初始对偶变量为: 0.0
# agent 95 的初始对偶变量为: 0.0
# agent 96 的初始对偶变量为: 0.0
# agent 97 的初始对偶变量为: 0.0
# agent 98 的初始对偶变量为: 0.0
# agent 99 的初始对偶变量为: 0.0
# agent 100 的初始对偶变量为: 0.0
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 49 次迭代中的结果：
# agent 1 在 49 次迭代中的资源申请量为: 46.33069078262059
# agent 2 在 49 次迭代中的资源申请量为: 58.24216650173156
# agent 3 在 49 次迭代中的资源申请量为: 41.97289155226493
# agent 4 在 49 次迭代中的资源申请量为: 61.59323677469602
# agent 5 在 49 次迭代中的资源申请量为: 62.3034221187481
# agent 6 在 49 次迭代中的资源申请量为: 68.55227097874159
# agent 7 在 49 次迭代中的资源申请量为: 37.803193695011686
# agent 8 在 49 次迭代中的资源申请量为: 36.155691166571856
# agent 9 在 49 次迭代中的资源申请量为: 41.2155539776026
# agent 10 在 49 次迭代中的资源申请量为: 53.32826655813603
# agent 11 在 49 次迭代中的资源申请量为: 43.51900599650604
# agent 12 在 49 次迭代中的资源申请量为: 47.10122102506262
# agent 13 在 49 次迭代中的资源申请量为: 62.78049382701603
# agent 14 在 49 次迭代中的资源申请量为: 52.87213075152199
# agent 15 在 49 次迭代中的资源申请量为: 41.72350973511458
# agent 16 在 49 次迭代中的资源申请量为: 41.84958463962711
# agent 17 在 49 次迭代中的资源申请量为: 42.98044180873753
# agent 18 在 49 次迭代中的资源申请量为: 44.57836010713416
# agent 19 在 49 次迭代中的资源申请量为: 39.59302728399559
# agent 20 在 49 次迭代中的资源申请量为: 53.21042022613777
# agent 21 在 49 次迭代中的资源申请量为: 37.09550338913594
# agent 22 在 49 次迭代中的资源申请量为: 37.451396523271505
# agent 23 在 49 次迭代中的资源申请量为: 45.94154655887417
# agent 24 在 49 次迭代中的资源申请量为: 38.84990515654719
# agent 25 在 49 次迭代中的资源申请量为: 43.19642514670594
# agent 26 在 49 次迭代中的资源申请量为: 38.24681307732678
# agent 27 在 49 次迭代中的资源申请量为: 62.63473341384796
# agent 28 在 49 次迭代中的资源申请量为: 48.941529047295255
# agent 29 在 49 次迭代中的资源申请量为: 39.107968839264956
# agent 30 在 49 次迭代中的资源申请量为: 37.64725518356946
# agent 31 在 49 次迭代中的资源申请量为: 57.83038260728787
# agent 32 在 49 次迭代中的资源申请量为: 53.03677767003832
# agent 33 在 49 次迭代中的资源申请量为: 39.71052654343396
# agent 34 在 49 次迭代中的资源申请量为: 49.97458566991064
# agent 35 在 49 次迭代中的资源申请量为: 37.14896868812553
# agent 36 在 49 次迭代中的资源申请量为: 40.883707594823214
# agent 37 在 49 次迭代中的资源申请量为: 50.25441206241
# agent 38 在 49 次迭代中的资源申请量为: 38.55679911941419
# agent 39 在 49 次迭代中的资源申请量为: 41.47121938459999
# agent 40 在 49 次迭代中的资源申请量为: 48.00248326128119
# agent 41 在 49 次迭代中的资源申请量为: 63.15702905887098
# agent 42 在 49 次迭代中的资源申请量为: 40.613843003621696
# agent 43 在 49 次迭代中的资源申请量为: 49.292579642044764
# agent 44 在 49 次迭代中的资源申请量为: 50.809950117409585
# agent 45 在 49 次迭代中的资源申请量为: 46.10823557378402
# agent 46 在 49 次迭代中的资源申请量为: 53.40447743753528
# agent 47 在 49 次迭代中的资源申请量为: 43.91148225564774
# agent 48 在 49 次迭代中的资源申请量为: 41.49844838458861
# agent 49 在 49 次迭代中的资源申请量为: 40.652552562316124
# agent 50 在 49 次迭代中的资源申请量为: 39.13778552597196
# agent 51 在 49 次迭代中的资源申请量为: 46.08916899529671
# agent 52 在 49 次迭代中的资源申请量为: 53.197821984047714
# agent 53 在 49 次迭代中的资源申请量为: 37.27414447908031
# agent 54 在 49 次迭代中的资源申请量为: 54.64316073276038
# agent 55 在 49 次迭代中的资源申请量为: 67.76019332598946
# agent 56 在 49 次迭代中的资源申请量为: 39.22579388912281
# agent 57 在 49 次迭代中的资源申请量为: 57.78813750686746
# agent 58 在 49 次迭代中的资源申请量为: 40.35300861820506
# agent 59 在 49 次迭代中的资源申请量为: 45.8002873095451
# agent 60 在 49 次迭代中的资源申请量为: 53.57401556038342
# agent 61 在 49 次迭代中的资源申请量为: 62.81217725591027
# agent 62 在 49 次迭代中的资源申请量为: 44.10236831322736
# agent 63 在 49 次迭代中的资源申请量为: 37.36302574816579
# agent 64 在 49 次迭代中的资源申请量为: 42.40715372985646
# agent 65 在 49 次迭代中的资源申请量为: 40.78907530118303
# agent 66 在 49 次迭代中的资源申请量为: 62.40489852874878
# agent 67 在 49 次迭代中的资源申请量为: 41.447246270670455
# agent 68 在 49 次迭代中的资源申请量为: 42.89554912532134
# agent 69 在 49 次迭代中的资源申请量为: 43.4218319042869
# agent 70 在 49 次迭代中的资源申请量为: 57.294462878400815
# agent 71 在 49 次迭代中的资源申请量为: 68.37679106046129
# agent 72 在 49 次迭代中的资源申请量为: 57.39358778496644
# agent 73 在 49 次迭代中的资源申请量为: 41.762965913789174
# agent 74 在 49 次迭代中的资源申请量为: 37.33176823537731
# agent 75 在 49 次迭代中的资源申请量为: 49.71325285978496
# agent 76 在 49 次迭代中的资源申请量为: 44.98461211502514
# agent 77 在 49 次迭代中的资源申请量为: 39.006160524344914
# agent 78 在 49 次迭代中的资源申请量为: 47.48993370442286
# agent 79 在 49 次迭代中的资源申请量为: 41.04263179883492
# agent 80 在 49 次迭代中的资源申请量为: 41.07237525085754
# agent 81 在 49 次迭代中的资源申请量为: 37.94143945849665
# agent 82 在 49 次迭代中的资源申请量为: 43.81921676230213
# agent 83 在 49 次迭代中的资源申请量为: 39.87267855705296
# agent 84 在 49 次迭代中的资源申请量为: 49.682425317293166
# agent 85 在 49 次迭代中的资源申请量为: 53.21995879598735
# agent 86 在 49 次迭代中的资源申请量为: 46.81326377339053
# agent 87 在 49 次迭代中的资源申请量为: 57.71219540936206
# agent 88 在 49 次迭代中的资源申请量为: 61.976315371246834
# agent 89 在 49 次迭代中的资源申请量为: 38.61062964600081
# agent 90 在 49 次迭代中的资源申请量为: 56.59761141059839
# agent 91 在 49 次迭代中的资源申请量为: 40.993460518972476
# agent 92 在 49 次迭代中的资源申请量为: 54.525433572860685
# agent 93 在 49 次迭代中的资源申请量为: 39.02961238321295
# agent 94 在 49 次迭代中的资源申请量为: 69.91639943138334
# agent 95 在 49 次迭代中的资源申请量为: 57.534453645164
# agent 96 在 49 次迭代中的资源申请量为: 57.710062156245485
# agent 97 在 49 次迭代中的资源申请量为: 68.68395558049666
# agent 98 在 49 次迭代中的资源申请量为: 69.68890935271119
# agent 99 在 49 次迭代中的资源申请量为: 50.12038606924978
# agent 100 在 49 次迭代中的资源申请量为: 46.43464312328562
# 资源申请量总和为: 4811.97555304618
# ****************************************************************************
# 成本总和为: 308436.0832085496
# ****************************************************************************
# agent 1 在 49 次迭代中的对偶变量为: -133.89207234786178
# agent 2 在 49 次迭代中的对偶变量为: -133.54119960415574
# agent 3 在 49 次迭代中的对偶变量为: -133.86783127770076
# agent 4 在 49 次迭代中的对偶变量为: -133.74512090433126
# agent 5 在 49 次迭代中的对偶变量为: -133.54752866124582
# agent 6 在 49 次迭代中的对偶变量为: -133.10454195748318
# agent 7 在 49 次迭代中的对偶变量为: -133.7721360410444
# agent 8 在 49 次迭代中的对偶变量为: -133.8227646662874
# agent 9 在 49 次迭代中的对偶变量为: -133.67288352384884
# agent 10 在 49 次迭代中的对偶变量为: -133.71349305115368
# agent 11 在 49 次迭代中的对偶变量为: -133.82081918881934
# agent 12 在 49 次迭代中的对偶变量为: -133.50366307518786
# agent 13 在 49 次迭代中的对偶变量为: -133.49708641943528
# agent 14 在 49 次迭代中的对偶变量为: -134.0875399539572
# agent 15 在 49 次迭代中的对偶变量为: -134.03993309938957
# agent 16 在 49 次迭代中的对偶变量为: -133.78858777473218
# agent 17 在 49 次迭代中的对偶变量为: -134.0174137879601
# agent 18 在 49 次迭代中的对偶变量为: -134.01075234282933
# agent 19 在 49 次迭代中的对偶变量为: -133.8948982223841
# agent 20 在 49 次迭代中的对偶变量为: -133.6670925879582
# agent 21 在 49 次迭代中的对偶变量为: -133.74291287871657
# agent 22 在 49 次迭代中的对偶变量为: -133.9553067884317
# agent 23 在 49 次迭代中的对偶变量为: -134.5246396766225
# agent 24 在 49 次迭代中的对偶变量为: -134.09965856356988
# agent 25 在 49 次迭代中的对偶变量为: -133.74856046945902
# agent 26 在 49 次迭代中的对偶变量为: -134.31788969384175
# agent 27 在 49 次迭代中的对偶变量为: -133.83641351046552
# agent 28 在 49 次迭代中的对偶变量为: -133.39628133242672
# agent 29 在 49 次迭代中的对偶变量为: -133.94868782135384
# agent 30 在 49 次迭代中的对偶变量为: -134.31956969756394
# agent 31 在 49 次迭代中的对偶变量为: -133.99291825749089
# agent 32 在 49 次迭代中的对偶变量为: -133.73562194209964
# agent 33 在 49 次迭代中的对偶变量为: -133.23789555636225
# agent 34 在 49 次迭代中的对偶变量为: -133.7688398757498
# agent 35 在 49 次迭代中的对偶变量为: -133.566081014877
# agent 36 在 49 次迭代中的对偶变量为: -133.56460582239893
# agent 37 在 49 次迭代中的对偶变量为: -133.71235377474798
# agent 38 在 49 次迭代中的对偶变量为: -133.7644768298911
# agent 39 在 49 次迭代中的对偶变量为: -133.86214590763998
# agent 40 在 49 次迭代中的对偶变量为: -133.8074497838436
# agent 41 在 49 次迭代中的对偶变量为: -133.44546392951617
# agent 42 在 49 次迭代中的对偶变量为: -133.66706621231378
# agent 43 在 49 次迭代中的对偶变量为: -133.25922299772535
# agent 44 在 49 次迭代中的对偶变量为: -134.14786032874682
# agent 45 在 49 次迭代中的对偶变量为: -133.82470672135207
# agent 46 在 49 次迭代中的对偶变量为: -133.91164133759173
# agent 47 在 49 次迭代中的对偶变量为: -133.79674321807278
# agent 48 在 49 次迭代中的对偶变量为: -133.6147245076013
# agent 49 在 49 次迭代中的对偶变量为: -133.11867871187482
# agent 50 在 49 次迭代中的对偶变量为: -133.69602789349906
# agent 51 在 49 次迭代中的对偶变量为: -133.4675069858901
# agent 52 在 49 次迭代中的对偶变量为: -133.63433715852406
# agent 53 在 49 次迭代中的对偶变量为: -133.6617490205052
# agent 54 在 49 次迭代中的对偶变量为: -134.27221790517697
# agent 55 在 49 次迭代中的对偶变量为: -133.7203866519789
# agent 56 在 49 次迭代中的对偶变量为: -134.01285800084213
# agent 57 在 49 次迭代中的对偶变量为: -133.89153001648188
# agent 58 在 49 次迭代中的对偶变量为: -133.8002293018972
# agent 59 在 49 次迭代中的对偶变量为: -133.8008619286353
# agent 60 在 49 次迭代中的对偶变量为: -133.8324404569969
# agent 61 在 49 次迭代中的对偶变量为: -133.3467899630026
# agent 62 在 49 次迭代中的对偶变量为: -133.76757860232755
# agent 63 在 49 次迭代中的对偶变量为: -133.99949784303
# agent 64 在 49 次迭代中的对偶变量为: -133.7828919355407
# agent 65 在 49 次迭代中的对偶变量为: -133.5828560240223
# agent 66 在 49 次迭代中的对偶变量为: -133.11077676324732
# agent 67 在 49 次迭代中的对偶变量为: -133.78063732027957
# agent 68 在 49 次迭代中的对偶变量为: -133.74575720102828
# agent 69 在 49 次迭代中的对偶变量为: -133.82986209371808
# agent 70 在 49 次迭代中的对偶变量为: -133.66671090816195
# agent 71 在 49 次迭代中的对偶变量为: -132.95358212092256
# agent 72 在 49 次迭代中的对偶变量为: -133.42461068391947
# agent 73 在 49 次迭代中的对偶变量为: -133.49408410688318
# agent 74 在 49 次迭代中的对偶变量为: -133.8807192944338
# agent 75 在 49 次迭代中的对偶变量为: -133.87710800739788
# agent 76 在 49 次迭代中的对偶变量为: -133.71075876808047
# agent 77 在 49 次迭代中的对偶变量为: -133.58217788764168
# agent 78 在 49 次迭代中的对偶变量为: -133.76980111326858
# agent 79 在 49 次迭代中的对偶变量为: -134.1049481160387
# agent 80 在 49 次迭代中的对偶变量为: -133.52607585291562
# agent 81 在 49 次迭代中的对偶变量为: -134.29746994228728
# agent 82 在 49 次迭代中的对偶变量为: -134.14149363936681
# agent 83 在 49 次迭代中的对偶变量为: -133.82164280539064
# agent 84 在 49 次迭代中的对偶变量为: -133.51079088842087
# agent 85 在 49 次迭代中的对偶变量为: -133.6918928695671
# agent 86 在 49 次迭代中的对偶变量为: -133.8397913201716
# agent 87 在 49 次迭代中的对偶变量为: -133.70926898246893
# agent 88 在 49 次迭代中的对偶变量为: -133.26789381674303
# agent 89 在 49 次迭代中的对偶变量为: -133.23826672560293
# agent 90 在 49 次迭代中的对偶变量为: -133.91426738543615
# agent 91 在 49 次迭代中的对偶变量为: -133.59776576450642
# agent 92 在 49 次迭代中的对偶变量为: -133.96612728943776
# agent 93 在 49 次迭代中的对偶变量为: -134.02660457956662
# agent 94 在 49 次迭代中的对偶变量为: -133.6327988627667
# agent 95 在 49 次迭代中的对偶变量为: -133.5226887483936
# agent 96 在 49 次迭代中的对偶变量为: -133.46414917498916
# agent 97 在 49 次迭代中的对偶变量为: -133.16791116099333
# agent 98 在 49 次迭代中的对偶变量为: -133.57781870542237
# agent 99 在 49 次迭代中的对偶变量为: -133.61708099389938
# agent 100 在 49 次迭代中的对偶变量为: -133.90392936985685
# *************************
# 迭代步长为: 0.09680155905721156
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: 47.65443094727488
# agent 2 在 99 次迭代中的资源申请量为: 59.94387723891419
# agent 3 在 99 次迭代中的资源申请量为: 43.143050268167926
# agent 4 在 99 次迭代中的资源申请量为: 63.41895333291367
# agent 5 在 99 次迭代中的资源申请量为: 64.1578098428427
# agent 6 在 99 次迭代中的资源申请量为: 70.66342003968468
# agent 7 在 99 次迭代中的资源申请量为: 38.85823638052366
# agent 8 在 99 次迭代中的资源申请量为: 37.15427003953988
# agent 9 在 99 次迭代中的资源申请量为: 42.40382822264218
# agent 10 在 99 次迭代中的资源申请量为: 54.877550774764565
# agent 11 在 99 次迭代中的资源申请量为: 44.76690736533055
# agent 12 在 99 次迭代中的资源申请量为: 48.46633243035297
# agent 13 在 99 次迭代中的资源申请量为: 64.64301562471537
# agent 14 在 99 次迭代中的资源申请量为: 54.375004688797745
# agent 15 在 99 次迭代中的资源申请量为: 42.8772984002306
# agent 16 在 99 次迭代中的资源申请量为: 43.02711913622529
# agent 17 在 99 次迭代中的资源申请量为: 44.20852175141823
# agent 18 在 99 次迭代中的资源申请量为: 45.807134609525534
# agent 19 在 99 次迭代中的资源申请量为: 40.695778533873685
# agent 20 在 99 次迭代中的资源申请量为: 54.7654862137104
# agent 21 在 99 次迭代中的资源申请量为: 38.1530821557825
# agent 22 在 99 次迭代中的资源申请量为: 38.49086715678208
# agent 23 在 99 次迭代中的资源申请量为: 47.19732404547642
# agent 24 在 99 次迭代中的资源申请量为: 39.93435730837215
# agent 25 在 99 次迭代中的资源申请量为: 44.45167344334899
# agent 26 在 99 次迭代中的资源申请量为: 39.25566250248538
# agent 27 在 99 次迭代中的资源申请量为: 64.44753319129353
# agent 28 在 99 次迭代中的资源申请量为: 50.41643738996639
# agent 29 在 99 次迭代中的资源申请量为: 40.20576736273973
# agent 30 在 99 次迭代中的资源申请量为: 38.655973746004705
# agent 31 在 99 次迭代中的资源申请量为: 59.47104644212334
# agent 32 在 99 次迭代中的资源申请量为: 54.58357369210619
# agent 33 在 99 次迭代中的资源申请量为: 40.871971032238136
# agent 34 在 99 次迭代中的资源申请量为: 51.40671452047854
# agent 35 在 99 次迭代中的资源申请量为: 38.221512237175766
# agent 36 在 99 次迭代中的资源申请量为: 42.08236222881102
# agent 37 在 99 次迭代中的资源申请量为: 51.692948548983104
# agent 38 在 99 次迭代中的资源申请量为: 39.67118544388095
# agent 39 在 99 次迭代中的资源申请量为: 42.64196608710625
# agent 40 在 99 次迭代中的资源申请量为: 49.334963578102254
# agent 41 在 99 次迭代中的资源申请量为: 65.02678262629205
# agent 42 在 99 次迭代中的资源申请量为: 41.80294739001405
# agent 43 在 99 次迭代中的资源申请量为: 50.78305314025189
# agent 44 在 99 次迭代中的资源申请量为: 52.19852300775559
# agent 45 在 99 次迭代中的资源申请量为: 47.43892391119717
# agent 46 在 99 次迭代中的资源申请量为: 54.9290148202694
# agent 47 在 99 次迭代中的资源申请量为: 45.16195894016538
# agent 48 在 99 次迭代中的资源申请量为: 42.69247894983478
# agent 49 在 99 次迭代中的资源申请量为: 41.89318180895947
# agent 50 在 99 次迭代中的资源申请量为: 40.25810212041713
# agent 51 在 99 次迭代中的资源申请量为: 47.45786260111904
# agent 52 在 99 次迭代中的资源申请量为: 54.7569049581
# agent 53 在 99 次迭代中的资源申请量为: 38.33855067551908
# agent 54 在 99 次迭代中的资源申请量为: 56.12345884183271
# agent 55 在 99 次迭代中的资源申请量为: 69.77317590551176
# agent 56 在 99 次迭代中的资源申请量为: 40.31795981477136
# agent 57 在 99 次迭代中的资源申请量为: 59.44242043644813
# agent 58 在 99 次迭代中的资源申请量为: 41.52943598641283
# agent 59 在 99 次迭代中的资源申请量为: 47.13324235456788
# agent 60 在 99 次迭代中的资源申请量为: 55.10832836171155
# agent 61 在 99 次迭代中的资源申请量为: 64.69649666608083
# agent 62 在 99 次迭代中的资源申请量为: 45.35570987425771
# agent 63 在 99 次迭代中的资源申请量为: 38.39865424052302
# agent 64 在 99 次迭代中的资源申请量为: 43.658642803506034
# agent 65 在 99 次迭代中的资源申请量为: 41.985954364227865
# agent 66 在 99 次迭代中的资源申请量为: 64.32350914234551
# agent 67 在 99 次迭代中的资源申请量为: 42.62509456400147
# agent 68 在 99 次迭代中的资源申请量为: 44.15065849498018
# agent 69 在 99 次迭代中的资源申请量为: 44.66877975158118
# agent 70 在 99 次迭代中的资源申请量为: 58.97861318808855
# agent 71 在 99 次迭代中的资源申请量为: 70.51213064330851
# agent 72 在 99 次迭代中的资源申请量为: 59.11046140347789
# agent 73 在 99 次迭代中的资源申请量为: 42.968395336750305
# agent 74 在 99 次迭代中的资源申请量为: 38.377732834166295
# agent 75 在 99 次迭代中的资源申请量为: 51.13266000867265
# agent 76 在 99 次迭代中的资源申请量为: 46.24361111755668
# agent 77 在 99 次迭代中的资源申请量为: 40.136694038475156
# agent 78 在 99 次迭代中的资源申请量为: 48.82652037278626
# agent 79 在 99 次迭代中的资源申请量为: 42.190391968948354
# agent 80 在 99 次迭代中的资源申请量为: 42.2748677534658
# agent 81 在 99 次迭代中的资源申请量为: 38.952135935968315
# agent 82 在 99 次迭代中的资源申请量为: 45.03486521865985
# agent 83 在 99 次迭代中的资源申请量为: 40.981978144734676
# agent 84 在 99 次迭代中的资源申请量为: 51.14413679609436
# agent 85 在 99 次迭代中的资源申请量为: 54.77156668183451
# agent 86 在 99 次迭代中的资源申请量为: 48.14195518223723
# agent 87 在 99 次迭代中的资源申请量为: 59.39068927361365
# agent 88 在 99 次迭代中的资源申请量为: 63.87172366420678
# agent 89 在 99 次迭代中的资源申请量为: 39.771715063705734
# agent 90 在 99 次迭代中的资源申请量为: 58.24881231229113
# agent 91 在 99 次迭代中的资源申请量为: 42.1891435493825
# agent 92 在 99 次迭代中的资源申请量为: 56.04322719679358
# agent 93 在 99 次迭代中的资源申请量为: 40.12064057522364
# agent 94 在 99 次迭代中的资源申请量为: 71.94327724015375
# agent 95 在 99 次迭代中的资源申请量为: 59.23821307284946
# agent 96 在 99 次迭代中的资源申请量为: 59.42157849980898
# agent 97 在 99 次迭代中的资源申请量为: 70.78527443134459
# agent 98 在 99 次迭代中的资源申请量为: 71.72431638788615
# agent 99 在 99 次迭代中的资源申请量为: 51.57006080873175
# agent 100 在 99 次迭代中的资源申请量为: 47.75653403561956
# 资源申请量总和为: 4950.978677244199
# ****************************************************************************
# 成本总和为: 327301.46486390027
# ****************************************************************************
# agent 1 在 99 次迭代中的对偶变量为: -137.86329284182466
# agent 2 在 99 次迭代中的对偶变量为: -137.62530537339404
# agent 3 在 99 次迭代中的对偶变量为: -137.84637091177095
# agent 4 在 99 次迭代中的对偶变量为: -137.76169733241008
# agent 5 在 99 次迭代中的对偶变量为: -137.62718165425392
# agent 6 在 99 次迭代中的对偶变量为: -137.32684007936936
# agent 7 在 99 次迭代中的对偶变量为: -137.7812982459899
# agent 8 在 99 次迭代中的对偶变量为: -137.8170801581595
# agent 9 在 99 次迭代中的对偶变量为: -137.7130159569834
# agent 10 在 99 次迭代中的对偶变量为: -137.74163201438787
# agent 11 在 99 次迭代中的对偶变量为: -137.81410356905778
# agent 12 在 99 次迭代中的对偶变量为: -137.5989972910589
# agent 13 在 99 次迭代中的对偶变量为: -137.59463437437384
# agent 14 在 99 次迭代中的对偶变量为: -137.99501219087415
# agent 15 在 99 次迭代中的对偶变量为: -137.96281456078404
# agent 16 在 99 次迭代中的对偶变量为: -137.79220506316597
# agent 17 在 99 次迭代中的对偶变量为: -137.94726960453835
# agent 18 在 99 次迭代中的对偶变量为: -137.94283075048173
# agent 19 在 99 次迭代中的对偶变量为: -137.8648027219453
# agent 20 在 99 次迭代中的对偶变量为: -137.71026415564705
# agent 21 在 99 次迭代中的对偶变量为: -137.7617121919735
# agent 22 在 99 次迭代中的对偶变量为: -137.9052951957719
# agent 23 在 99 次迭代中的对偶变量为: -138.29197213642925
# agent 24 在 99 次迭代中的对偶变量为: -138.00368631013976
# agent 25 在 99 次迭代中的对偶变量为: -137.76535501871678
# agent 26 在 99 次迭代中的对偶变量为: -138.15151750944443
# agent 27 在 99 次迭代中的对偶变量为: -137.82457302084578
# agent 28 在 99 次迭代中的对偶变量为: -137.5260246919059
# agent 29 在 99 次迭代中的对偶变量为: -137.900762505863
# agent 30 在 99 次迭代中的对偶变量为: -138.15270023481787
# agent 31 在 99 次迭代中的对偶变量为: -137.930511461096
# agent 32 在 99 次迭代中的对偶变量为: -137.7572915994761
# agent 33 在 99 次迭代中的对偶变量为: -137.41909571605729
# agent 34 在 99 次迭代中的对偶变量为: -137.7788006573399
# agent 35 在 99 次迭代中的对偶变量为: -137.6417465012679
# agent 36 在 99 次迭代中的对偶变量为: -137.64003157795747
# agent 37 在 99 次迭代中的对偶变量为: -137.74025593715268
# agent 38 在 99 次迭代中的对偶变量为: -137.77626759797144
# agent 39 在 99 次迭代中的对偶变量为: -137.84268469616126
# agent 40 在 99 次迭代中的对偶变量为: -137.80489073430678
# agent 41 在 99 次迭代中的对偶变量为: -137.55892177784253
# agent 42 在 99 次迭代中的对偶变量为: -137.71002112604776
# agent 43 在 99 次迭代中的对偶变量为: -137.4325487927053
# agent 44 在 99 次迭代中的对偶变量为: -138.03586442171564
# agent 45 在 99 次迭代中的对偶变量为: -137.8167717335915
# agent 46 在 99 次迭代中的对偶变量为: -137.87543853270046
# agent 47 在 99 次迭代中的对偶变量为: -137.7982686085292
# agent 48 在 99 次迭代中的对偶变量为: -137.67442842943825
# agent 49 在 99 次迭代中的对偶变量为: -137.3368181504622
# agent 50 在 99 次迭代中的对偶变量为: -137.72916763350167
# agent 51 在 99 次迭代中的对偶变量为: -137.5735878033571
# agent 52 在 99 次迭代中的对偶变量为: -137.68795289106
# agent 53 在 99 次迭代中的对偶变量为: -137.7064925669725
# agent 54 在 99 次迭代中的对偶变量为: -138.12099298876504
# agent 55 在 99 次迭代中的对偶变量为: -137.74635181102352
# agent 56 在 99 次迭代中的对偶变量为: -137.9446553331769
# agent 57 在 99 次迭代中的对偶变量为: -137.8618090474755
# agent 58 在 99 次迭代中的对偶变量为: -137.80008235380362
# agent 59 在 99 次迭代中的对偶变量为: -137.79972706370364
# agent 60 在 99 次迭代中的对偶变量为: -137.82165374045002
# agent 61 在 99 次迭代中的对偶变量为: -137.49229266537785
# agent 62 在 99 次迭代中的对偶变量为: -137.77827159762467
# agent 63 在 99 次迭代中的对偶变量为: -137.9348861139875
# agent 64 在 99 次迭代中的对偶变量为: -137.78765697121932
# agent 65 在 99 次迭代中的对偶变量为: -137.65224483837474
# agent 66 在 99 次迭代中的对偶变量为: -137.33172011316015
# agent 67 在 99 次迭代中的对偶变量为: -137.785321517605
# agent 68 在 99 次迭代中的对偶变量为: -137.76210718393656
# agent 69 在 99 次迭代中的对偶变量为: -137.82009520505977
# agent 70 在 99 次迭代中的对偶变量为: -137.70867165141252
# agent 71 在 99 次迭代中的对偶变量为: -137.224261286617
# agent 72 在 99 次迭代中的对偶变量为: -137.54510736834695
# agent 73 在 99 次迭代中的对偶变量为: -137.59254414495103
# agent 74 在 99 次迭代中的对偶变量为: -137.85538476983191
# agent 75 在 99 次迭代中的对偶变量为: -137.85144802428343
# agent 76 在 99 次迭代中的对偶变量为: -137.73955557618137
# agent 77 在 99 次迭代中的对偶变量为: -137.65209853851056
# agent 78 在 99 次迭代中的对偶变量为: -137.7795611183588
# agent 79 在 99 次迭代中的对偶变量为: -138.0073326944244
# agent 80 在 99 次迭代中的对偶变量为: -137.6145503617837
# agent 81 在 99 次迭代中的对偶变量为: -138.1381165566796
# agent 82 在 99 次迭代中的对偶变量为: -138.03156869971153
# agent 83 在 99 次迭代中的对偶变量为: -137.81512132104484
# agent 84 在 99 次迭代中的对偶变量为: -137.6035830290642
# agent 85 在 99 次迭代中的对偶变量为: -137.72607337276972
# agent 86 在 99 次迭代中的对偶变量为: -137.8258655467117
# agent 87 在 99 次迭代中的对偶变量为: -137.73765425667276
# agent 88 在 99 次迭代中的对偶变量为: -137.43779206125492
# agent 89 在 99 次迭代中的对偶变量为: -137.41817422934065
# agent 90 在 99 次迭代中的对偶变量为: -137.8771495494987
# agent 91 在 99 次迭代中的对偶变量为: -137.6630880679005
# agent 92 在 99 次迭代中的对偶变量为: -137.9123907116633
# agent 93 在 99 次迭代中的对偶变量为: -137.9543060708051
# agent 94 在 99 次迭代中的对偶变量为: -137.6865544803075
# agent 95 在 99 次迭代中的对偶变量为: -137.6117113748387
# agent 96 在 99 次迭代中的对偶变量为: -137.57178839954156
# agent 97 在 99 次迭代中的对偶变量为: -137.3705488626892
# agent 98 在 99 次迭代中的对偶变量为: -137.64863277577228
# agent 99 在 99 次迭代中的对偶变量为: -137.6761702644489
# agent 100 在 99 次迭代中的对偶变量为: -137.86960210685868
# *************************
# 迭代步长为: 0.06347736393621072
# ****************************************************************************
# 149 次迭代中的结果：
# agent 1 在 149 次迭代中的资源申请量为: 47.940539848044544
# agent 2 在 149 次迭代中的资源申请量为: 60.32244064213926
# agent 3 在 149 次迭代中的资源申请量为: 43.39651066761011
# agent 4 在 149 次迭代中的资源申请量为: 63.818626920508365
# agent 5 在 149 次迭代中的资源申请量为: 64.57033863847902
# agent 6 在 149 次迭代中的资源申请量为: 71.14892923512568
# agent 7 在 149 次迭代中的资源申请量为: 39.08860434924721
# agent 8 在 149 次迭代中的资源申请量为: 37.37132789404508
# agent 9 在 149 次迭代中的资源申请量为: 42.66548746201106
# agent 10 在 149 次迭代中的资源申请量为: 55.21750803568791
# agent 11 在 149 次迭代中的资源申请量为: 45.03829108672093
# agent 12 在 149 次迭代中的资源申请量为: 48.77095236585398
# agent 13 在 149 次迭代中的资源申请量为: 65.05890368741775
# agent 14 在 149 次迭代中的资源申请量为: 54.694344943827375
# agent 15 在 149 次迭代中的资源申请量为: 43.12350627355906
# agent 16 在 149 次迭代中的资源申请量为: 43.283893878145086
# agent 17 在 149 次迭代中的资源申请量为: 44.47110859684205
# agent 18 在 149 次迭代中的资源申请量为: 46.06999993832884
# agent 19 在 149 次迭代中的资源申请量为: 40.93407934643887
# agent 20 在 149 次迭代中的资源申请量为: 55.107982691399464
# agent 21 在 149 次迭代中的资源申请量为: 38.38456853039607
# agent 22 在 149 次迭代中的资源申请量为: 38.71432115453098
# agent 23 在 149 次迭代中的资源申请量为: 47.45318547054993
# agent 24 在 149 次迭代中的资源申请量为: 40.164529091950534
# agent 25 在 149 次迭代中的资源申请量为: 44.72634593696062
# agent 26 在 149 次迭代中的资源申请量为: 39.46546291802173
# agent 27 在 149 次迭代中的资源申请量为: 64.84126611580207
# agent 28 在 149 次迭代中的资源申请量为: 50.74833220067159
# agent 29 在 149 次迭代中的资源申请量为: 40.44190835219819
# agent 30 在 149 次迭代中的资源申请量为: 38.865700598592554
# agent 31 在 149 次迭代中的资源申请量为: 59.82263188065365
# agent 32 在 149 次迭代中的资源申请量为: 54.92233757373185
# agent 33 在 149 次迭代中的资源申请量为: 41.136441391918396
# agent 34 在 149 次迭代中的资源申请量为: 51.71954178458692
# agent 35 在 149 次迭代中的资源申请量为: 38.459678441676004
# agent 36 在 149 次迭代中的资源申请量为: 42.34858265451128
# agent 37 在 149 次迭代中的资源申请量为: 52.00864736097481
# agent 38 在 149 次迭代中的资源申请量为: 39.91468311423118
# agent 39 在 149 次迭代中的资源申请量为: 42.89564356481481
# agent 40 在 149 次迭代中的资源申请量为: 49.62506657389778
# agent 41 在 149 次迭代中的资源申请量为: 65.4459686206891
# agent 42 在 149 次迭代中的资源申请量为: 42.06486639984687
# agent 43 在 149 次迭代中的资源申请量为: 51.12195680143472
# agent 44 在 149 次迭代中的资源申请量为: 52.491930121361406
# agent 45 在 149 次迭代中的资源申请量为: 47.72824869559543
# agent 46 在 149 次迭代中的资源申请量为: 55.25800870729517
# agent 47 在 149 次迭代中的资源申请量为: 45.43444716599134
# agent 48 在 149 次迭代中的资源申请量为: 42.95658049774544
# agent 49 在 149 次迭代中的资源申请量为: 42.17820728090376
# agent 50 在 149 次迭代中的资源申请量为: 40.504301865611545
# agent 51 在 149 次迭代中的资源申请量为: 47.76420677448365
# agent 52 在 149 次迭代中的资源申请量为: 55.10120544276502
# agent 53 在 149 次迭代中的资源申请量为: 38.573094553622816
# agent 54 在 149 次迭代中的资源申请量为: 56.4325926091185
# agent 55 在 149 次迭代中的资源申请量为: 70.21458135958176
# agent 56 在 149 次迭代中的资源申请量为: 40.551559524234136
# agent 57 在 149 次迭代中的资源申请量为: 59.800030170696324
# agent 58 在 149 次迭代中的资源申请量为: 41.785751501182894
# agent 59 在 149 次迭代中的资源申请量为: 47.42366308515412
# agent 60 在 149 次迭代中的资源申请量为: 55.44168670455595
# agent 61 在 149 次迭代中的资源申请量为: 65.12208666972593
# agent 62 在 149 次迭代中的资源申请量为: 45.629478290177175
# agent 63 在 149 次迭代中的资源申请量为: 38.62044725723377
# agent 64 在 149 次迭代中的资源申请量为: 43.93172615360698
# agent 65 在 149 次迭代中的资源申请量为: 42.2514356386996
# agent 66 在 149 次迭代中的资源申请量为: 64.76449753252108
# agent 67 在 149 次迭代中的资源申请量为: 42.882191858003246
# agent 68 在 149 次迭代中的资源申请量为: 44.42538725389426
# agent 69 在 149 次迭代中的资源申请量为: 44.939747976069576
# agent 70 在 149 次迭代中的资源申请量为: 59.34962096184449
# agent 71 在 149 次迭代中的资源申请量为: 71.00846594680318
# agent 72 在 149 次迭代中的资源申请量为: 59.49597239706524
# agent 73 在 149 次迭代中的资源申请量为: 43.23759301342761
# agent 74 在 149 次迭代中的资源申请量为: 38.604020104278135
# agent 75 在 149 次迭代中的资源申请量为: 51.439917742118524
# agent 76 在 149 次迭代中的资源申请量为: 46.519941739080686
# agent 77 在 149 次迭代中的资源申请量为: 40.38743203850582
# agent 78 在 149 次迭代中的资源申请量为: 49.11843264987031
# agent 79 在 149 次迭代中的资源申请量为: 42.4338324752597
# agent 80 在 149 次迭代中的资源申请量为: 42.54273711783369
# agent 81 在 149 次迭代中的资源申请量为: 39.16271736700116
# agent 82 在 149 次迭代中的资源申请量为: 45.29186909265542
# agent 83 在 149 次迭代中的资源申请量为: 41.22318935564498
# agent 84 在 149 次迭代中的资源申请量为: 51.47016487957002
# agent 85 在 149 次迭代中的资源申请量为: 55.11266791839112
# agent 86 在 149 次迭代中的资源申请量为: 48.43053543248261
# agent 87 在 149 次迭代中的资源申请量为: 59.759189600956454
# agent 88 在 149 次迭代中的资源申请量为: 64.30243412345156
# agent 89 在 149 次迭代中的资源申请量为: 40.03613147164038
# agent 90 在 149 次迭代中的资源申请量为: 58.60506719793569
# agent 91 在 149 次迭代中的资源申请量为: 42.45398744323097
# agent 92 在 149 次迭代中的资源申请量为: 56.36922547835156
# agent 93 在 149 次迭代中的资源申请量为: 40.353699794896364
# agent 94 在 149 次迭代中的资源申请量为: 72.39094332935042
# agent 95 在 149 次迭代中的资源申请量为: 59.61787930191304
# agent 96 在 149 次迭代中的资源申请量为: 59.8047615542824
# agent 97 在 149 次迭代中的资源申请量为: 71.26625559704578
# agent 98 在 149 次迭代中的资源申请量为: 72.1759111880287
# agent 99 在 149 次迭代中的资源申请量为: 51.8906723713111
# agent 100 在 149 次迭代中的资源申请量为: 48.04206461806201
# 资源申请量总和为: 4981.489471026193
# ****************************************************************************
# 成本总和为: 331517.23201336473
# ****************************************************************************
# agent 1 在 149 次迭代中的对偶变量为: -138.72161954413363
# agent 2 在 149 次迭代中的对偶变量为: -138.5338575411342
# agent 3 在 149 次迭代中的对偶变量为: -138.70813626987436
# agent 4 在 149 次迭代中的对偶变量为: -138.64097922511843
# agent 5 在 149 次迭代中的对偶变量为: -138.53474500465384
# agent 6 在 149 次迭代中的对偶变量为: -138.29785847025136
# agent 7 在 149 次迭代中的对偶变量为: -138.65669652713942
# agent 8 在 149 次迭代中的对偶变量为: -138.6853115761803
# agent 9 在 149 次迭代中的对偶变量为: -138.6026573708376
# agent 10 在 149 次迭代中的对偶变量为: -138.6255208927886
# agent 11 在 149 次迭代中的对偶变量为: -138.68253147750698
# agent 12 在 149 次迭代中的对偶变量为: -138.51285709756192
# agent 13 在 149 次迭代中的对偶变量为: -138.50958811231905
# agent 14 在 149 次迭代中的对偶变量为: -138.8252968539512
# agent 15 在 149 次迭代中的对偶变量为: -138.7999213301008
# agent 16 在 149 次迭代中的对偶变量为: -138.66523918569328
# agent 17 在 149 次迭代中的对偶变量为: -138.78754750989455
# agent 18 在 149 次迭代中的对偶变量为: -138.78399980265232
# agent 19 在 149 次迭代中的对偶变量为: -138.72268564717993
# agent 20 在 149 次迭代中的对偶变量为: -138.6007549976386
# agent 21 在 149 次迭代中的对偶变量为: -138.64136041550506
# agent 22 在 149 次迭代中的对偶变量为: -138.7544203872177
# agent 23 在 149 次迭代中的对偶变量为: -139.0595564116498
# agent 24 在 149 次迭代中的对偶变量为: -138.83230473102194
# agent 25 在 149 次迭代中的对偶变量为: -138.644306998274
# agent 26 在 149 次迭代中的对偶变量为: -138.94875908848255
# agent 27 在 149 次迭代中的对偶变量为: -138.69078545476455
# agent 28 在 149 次迭代中的对偶变量为: -138.45533016188045
# agent 29 在 149 次迭代中的对偶变量为: -138.7508700679135
# agent 30 在 149 次迭代中的对偶变量为: -138.9496622746517
# agent 31 在 149 次迭代中的对偶变量为: -138.77431651356875
# agent 32 在 149 次迭代中的对偶变量为: -138.63807769170282
# agent 33 在 149 次迭代中的对偶变量为: -138.37118901090622
# agent 34 在 149 次迭代中的对偶变量为: -138.65471699684338
# agent 35 在 149 次迭代中的对偶变量为: -138.54677807836882
# agent 36 在 149 次迭代中的对偶变量为: -138.54518102533837
# agent 37 在 149 次迭代中的对偶变量为: -138.62421261072947
# agent 38 在 149 次迭代中的对偶变量为: -138.65285921123225
# agent 39 在 149 次迭代中的对偶变量为: -138.70518812037037
# agent 40 在 149 次迭代中的对偶变量为: -138.67519972169336
# agent 41 在 149 次迭代中的对偶变量为: -138.48113096551603
# agent 42 在 149 次迭代中的对偶变量为: -138.60054575947936
# agent 43 在 149 次迭代中的对偶变量为: -138.38147904401723
# agent 44 在 149 次迭代中的对偶变量为: -138.85740433981192
# agent 45 在 149 次迭代中的对偶变量为: -138.6847460867863
# agent 46 在 149 次迭代中的对偶变量为: -138.73082263896745
# agent 47 在 149 次迭代中的对偶变量为: -138.67023093117228
# agent 48 在 149 次迭代中的对偶变量为: -138.5723736923345
# agent 49 在 149 次迭代中的对偶变量为: -138.3059047550728
# agent 50 在 149 次迭代中的对偶变量为: -138.6154867162016
# agent 51 在 149 次迭代中的对偶变量为: -138.49262032345092
# agent 52 在 149 次迭代中的对偶变量为: -138.58313415118906
# agent 53 在 149 次迭代中的对偶变量为: -138.5977593037667
# agent 54 在 149 次迭代中的对偶变量为: -138.9247407837081
# agent 55 在 149 次迭代中的对偶变量为: -138.6291627191635
# agent 56 在 149 次迭代中的对偶变量为: -138.7856142872429
# agent 57 在 149 次迭代中的对偶变量为: -138.72007240967116
# agent 58 在 149 次迭代中的对偶变量为: -138.67155510402182
# agent 59 在 149 次迭代中的对偶变量为: -138.67098925546236
# agent 60 在 149 次迭代中的对偶变量为: -138.68838543184546
# agent 61 在 149 次迭代中的对偶变量为: -138.42859067339705
# agent 62 在 149 次迭代中的对偶变量为: -138.654330528567
# agent 63 在 149 次迭代中的对偶变量为: -138.77769957748833
# agent 64 在 149 次迭代中的对偶变量为: -138.66152369154236
# agent 65 在 149 次迭代中的对偶变量为: -138.55488117157864
# agent 66 在 149 次迭代中的对偶变量为: -138.30189457154637
# agent 67 在 149 次迭代中的对偶变量为: -138.65945231721105
# agent 68 在 149 次迭代中的对偶变量为: -138.6412392124616
# agent 69 在 149 次迭代中的对偶变量为: -138.68719352342265
# agent 70 在 149 次迭代中的对偶变量为: -138.59909030842675
# agent 71 在 149 次迭代中的对偶变量为: -138.21693189360636
# agent 72 在 149 次迭代中的对偶变量为: -138.47033375295658
# agent 73 在 149 次迭代中的对偶变量为: -138.50781624565388
# agent 74 在 149 次迭代中的对偶变量为: -138.7152763962569
# agent 75 在 149 次迭代中的对偶变量为: -138.71176967793187
# agent 76 在 149 次迭代中的对偶变量为: -138.62381356505819
# agent 77 在 149 次迭代中的对偶变量为: -138.55475533862096
# agent 78 在 149 次迭代中的对偶变量为: -138.65529794961094
# agent 79 在 149 次迭代中的对偶变量为: -138.83503041588298
# agent 80 在 149 次迭代中的对偶变量为: -138.52530620063453
# agent 81 在 149 次迭代中的对偶变量为: -138.93832599460438
# agent 82 在 149 次迭代中的对偶变量为: -138.85398109649734
# agent 83 在 149 次迭代中的对偶变量为: -138.68348168032193
# agent 84 在 149 次迭代中的对偶变量为: -138.51646166279605
# agent 85 在 149 次迭代中的对偶变量为: -138.6129365878169
# agent 86 在 149 次迭代中的对偶变量为: -138.69160629744783
# agent 87 在 149 次迭代中的对偶变量为: -138.62205504229547
# agent 88 在 149 次迭代中的对偶变量为: -138.38535507159344
# agent 89 在 149 次迭代中的对偶变量为: -138.37007329790538
# agent 90 在 149 次迭代中的对偶变量为: -138.73216127504566
# agent 91 在 149 次迭代中的对偶变量为: -138.5635573069853
# agent 92 在 149 次迭代中的对偶变量为: -138.75998624371405
# agent 93 在 149 次迭代中的对偶变量为: -138.79331926162692
# agent 94 在 149 次迭代中的对偶变量为: -138.58188665870085
# agent 95 在 149 次迭代中的对偶变量为: -138.5229103245913
# agent 96 在 149 次迭代中的对偶变量为: -138.49142773027776
# agent 97 在 149 次迭代中的对偶变量为: -138.33251119409158
# agent 98 在 149 次迭代中的对偶变量为: -138.5518223760574
# agent 99 在 149 次迭代中的对偶变量为: -138.57388263967107
# agent 100 在 149 次迭代中的对偶变量为: -138.72619385418602
# *************************
# 迭代步长为: 0.04966932281851884
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: 48.033407472624106
# agent 2 在 199 次迭代中的资源申请量为: 60.45077783939724
# agent 3 在 199 次迭代中的资源申请量为: 43.47905600794498
# agent 4 在 199 次迭代中的资源申请量为: 63.9509100964165
# agent 5 在 199 次迭代中的资源申请量为: 64.71016590472279
# agent 6 在 199 次迭代中的资源申请量为: 71.32131063446177
# agent 7 在 199 次迭代中的资源申请量为: 39.164565217677286
# agent 8 在 199 次迭代中的资源申请量为: 37.44241315063233
# agent 9 在 199 次迭代中的资源申请量为: 42.75285876970597
# agent 10 在 199 次迭代中的资源申请量为: 55.33043566728596
# agent 11 在 199 次迭代中的资源申请量为: 45.12722438660181
# agent 12 在 199 次迭代中的资源申请量为: 48.87468078576419
# agent 13 在 199 次迭代中的资源申请量为: 65.20063663534421
# agent 14 在 199 次迭代中的资源申请量为: 54.79521141695754
# agent 15 在 199 次迭代中的资源申请量为: 43.20181219148593
# agent 16 在 199 次迭代中的资源申请量为: 43.36839021194259
# agent 17 在 199 次迭代中的资源申请量为: 44.55489575902362
# agent 18 在 199 次迭代中的资源申请量为: 46.15394890860834
# agent 19 在 199 次迭代中的资源申请量为: 41.01140577572198
# agent 20 在 199 次迭代中的资源申请量为: 55.2223940145169
# agent 21 在 199 次迭代中的资源申请量为: 38.46117883620604
# agent 22 在 199 次迭代中的资源申请量为: 38.78623923490047
# agent 23 在 199 次迭代中的资源申请量为: 47.52835532750968
# agent 24 在 199 次迭代中的资源申请量为: 40.23709595083651
# agent 25 在 199 次迭代中的资源申请量为: 44.817197093557446
# agent 26 在 199 次迭代中的资源申请量为: 39.529381051033795
# agent 27 在 199 次迭代中的资源申请量为: 64.97003711359699
# agent 28 在 199 次迭代中的资源申请量为: 50.862702164799245
# agent 29 在 199 次迭代中的资源申请量为: 40.517982070720024
# agent 30 在 199 次迭代中的资源申请量为: 38.92957501892319
# agent 31 在 199 次迭代中的资源申请量为: 59.93521284896004
# agent 32 在 199 次迭代中的资源申请量为: 55.03454589346108
# agent 33 在 199 次迭代中的资源申请量为: 41.229090335402915
# agent 34 在 199 次迭代中的资源申请量为: 51.822746636267084
# agent 35 在 199 次迭代中的资源申请量为: 38.54019957760205
# agent 36 在 199 次迭代中的资源申请量为: 42.43861411681873
# agent 37 在 199 次迭代中的资源申请量为: 52.11353985285284
# agent 38 在 199 次迭代中的资源申请量为: 39.99505358362047
# agent 39 在 199 次迭代中的资源申请量为: 42.97831257648175
# agent 40 在 199 次迭代中的资源申请量为: 49.72029985621046
# agent 41 在 199 次迭代中的资源申请量为: 65.58965876596302
# agent 42 在 199 次迭代中的资源申请量为: 42.152368173452174
# agent 43 在 199 次迭代中的资源申请量为: 51.240445138791976
# agent 44 在 199 次迭代中的资源申请量为: 52.583765999501836
# agent 45 在 199 次迭代中的资源申请量为: 47.82302039657471
# agent 46 在 199 次迭代中的资源申请量为: 55.36453646345465
# agent 47 在 199 次迭代中的资源申请量为: 45.524014356956485
# agent 48 在 199 次迭代中的资源申请量为: 43.045362561445444
# agent 49 在 199 次迭代中的资源申请量为: 42.2792653097715
# agent 50 在 199 次迭代中的资源申请量为: 40.586269190821845
# agent 51 在 199 次迭代中的资源申请量为: 47.86896727265653
# agent 52 在 199 次迭代中的资源申请量为: 55.2166753306359
# agent 53 在 199 次迭代中的资源申请量为: 38.651498660599415
# agent 54 在 199 次迭代中的资源申请量为: 56.527463042049476
# agent 55 在 199 次迭代中的资源申请量为: 70.36106994457754
# agent 56 在 199 次迭代中的资源申请量为: 40.626137121934136
# agent 57 在 199 次迭代中的资源申请量为: 59.91613690693903
# agent 58 在 199 次迭代中的资源申请量为: 41.86997801300307
# agent 59 在 199 次迭代中的资源申请量为: 47.519100244919166
# agent 60 在 199 次迭代中的资源申请量为: 55.55077106251554
# agent 61 在 199 次迭代中的资源申请量为: 65.26951653483371
# agent 62 在 199 次迭代中的资源申请量为: 45.71980071548143
# agent 63 在 199 次迭代中的资源申请量为: 38.691400530372164
# agent 64 在 199 次迭代中的资源申请量为: 44.021671916452206
# agent 65 在 199 次迭代中的资源申请量为: 42.34103774473243
# agent 66 在 199 次迭代中的资源申请量为: 64.92095972061122
# agent 67 在 199 次迭代中的资源申请量为: 42.96691085296523
# agent 68 在 199 次迭代中的资源申请量为: 44.51630568413422
# agent 69 在 199 次迭代中的资源申请量为: 45.02844184816052
# agent 70 在 199 次迭代中的资源申请量为: 59.47359325859276
# agent 71 在 199 次迭代中的资源申请量为: 71.18719247345831
# agent 72 在 199 次迭代中的资源申请量为: 59.62841363737642
# agent 73 在 199 次迭代中的资源申请量为: 43.329359699242886
# agent 74 在 199 次迭代中的资源申请量为: 38.67758214160461
# agent 75 在 199 次迭代中的资源申请量为: 51.53988385708581
# agent 76 在 199 次迭代中的资源申请量为: 46.61176812611602
# agent 77 在 199 次迭代中的资源申请量为: 40.47205308715866
# agent 78 在 199 次迭代中的资源申请量为: 49.214719112373274
# agent 79 在 199 次迭代中的资源申请量为: 42.51050938021472
# agent 80 在 199 次迭代中的资源申请量为: 42.63371885113795
# agent 81 在 199 次迭代中的资源申请量为: 39.22708323426611
# agent 82 在 199 次迭代中的资源申请量为: 45.37238487247213
# agent 83 在 199 次迭代中的资源申请量为: 41.302219777398825
# agent 84 在 199 次迭代中的资源申请量为: 51.58110329075099
# agent 85 在 199 次迭代中的资源申请量为: 55.226292740145155
# agent 86 在 199 次迭代中的资源申请量为: 48.524901147707176
# agent 87 在 199 次迭代中的资源申请量为: 59.881689145876
# agent 88 在 199 次迭代中的资源申请量为: 64.45289667899026
# agent 89 在 199 次迭代中的资源申请量为: 40.12877515236719
# agent 90 在 199 次迭代中的资源申请量为: 58.72038274051542
# agent 91 在 199 次迭代中的资源申请量为: 42.54319947953669
# agent 92 在 199 次迭代中的资源申请量为: 56.47399889698896
# agent 93 在 199 次迭代中的资源申请量为: 40.42795415370937
# agent 94 在 199 次迭代中的资源申请量为: 72.5411132281709
# agent 95 在 199 次迭代中的资源申请量为: 59.74689539585501
# agent 96 在 199 次迭代中的资源申请量为: 59.93584346810779
# agent 97 在 199 次迭代中的资源申请量为: 71.43595720998252
# agent 98 在 199 次迭代中的资源申请量为: 72.32840557449717
# agent 99 在 199 次迭代中的资源申请量为: 51.998425535024765
# agent 100 在 199 次迭代中的资源申请量为: 48.1346386465601
# 资源申请量总和为: 4991.629363484187
# ****************************************************************************
# 成本总和为: 332924.22848014935
# ****************************************************************************
# agent 1 在 199 次迭代中的对偶变量为: -139.00022241787232
# agent 2 在 199 次迭代中的对偶变量为: -138.84186681455336
# agent 3 在 199 次迭代中的对偶变量为: -138.98879042701293
# agent 4 在 199 次迭代中的对偶变量为: -138.93200221211632
# agent 5 在 199 次迭代中的对偶变量为: -138.84236499039014
# agent 6 在 199 次迭代中的对偶变量为: -138.64262126892353
# agent 7 在 199 次迭代中的对偶变量为: -138.9453478271737
# agent 8 在 199 次迭代中的对偶变量为: -138.96965260252932
# agent 9 在 199 次迭代中的对偶变量为: -138.8997198170003
# agent 10 在 199 次迭代中的对偶变量为: -138.9191327349435
# agent 11 在 199 次迭代中的对偶变量为: -138.9671180371258
# agent 12 在 199 次迭代中的对偶变量为: -138.82404235729257
# agent 13 在 199 次迭代中的对偶变量为: -138.82140059775728
# agent 14 在 199 次迭代中的对偶变量为: -139.08754968408962
# agent 15 在 199 次迭代中的对偶变量为: -139.06616145105215
# agent 16 在 199 次迭代中的对偶变量为: -138.9525267206048
# agent 17 在 199 次迭代中的对偶变量为: -139.05566642887558
# agent 18 在 199 次迭代中的对偶变量为: -139.0526365075467
# agent 19 在 199 次迭代中的对偶变量为: -139.00106079259916
# agent 20 在 199 次迭代中的对偶变量为: -138.89822443774395
# agent 21 在 199 次迭代中的对偶变量为: -138.93247957758294
# agent 22 在 199 次迭代中的对偶变量为: -139.0277090926218
# agent 23 在 199 次迭代中的对偶变量为: -139.28506598252903
# agent 24 在 199 次迭代中的对偶变量为: -139.09354542301145
# agent 25 在 199 次迭代中的对偶变量为: -138.93503069938384
# agent 26 在 199 次迭代中的对偶变量为: -139.1916479939284
# agent 27 在 199 次迭代中的对偶变量为: -138.9740816499134
# agent 28 在 199 次迭代中的对偶变量为: -138.7755660614379
# agent 29 在 199 次迭代中的对偶变量为: -139.02473545459208
# agent 30 在 199 次迭代中的对偶变量为: -139.1923850719081
# agent 31 在 199 次迭代中的对偶变量为: -139.04451083750408
# agent 32 在 199 次迭代中的对偶变量为: -138.9298193229988
# agent 33 在 199 次迭代中的对偶变量为: -138.7047252074505
# agent 34 在 199 次迭代中的对偶变量为: -138.94369058154783
# agent 35 在 199 次迭代中的对偶变量为: -138.8527583948878
# agent 36 在 199 次迭代中的对偶变量为: -138.85128799718368
# agent 37 在 199 次迭代中的对偶变量为: -138.91791158798793
# agent 38 在 199 次迭代中的对偶变量为: -138.9421929010337
# agent 39 在 199 次迭代中的对偶变量为: -138.98626276003796
# agent 40 在 199 次迭代中的对偶变量为: -138.9608995686314
# agent 41 在 199 次迭代中的对偶变量为: -138.79724928511865
# agent 42 在 199 次迭代中的对偶变量为: -138.8980517897374
# agent 43 在 199 次迭代中的对偶变量为: -138.71324638861753
# agent 44 在 199 次迭代中的对偶变量为: -139.11454479860512
# agent 45 在 199 次迭代中的对偶变量为: -138.96906118972413
# agent 46 在 199 次迭代中的对偶变量为: -139.0077948049821
# agent 47 在 199 次迭代中的对偶变量为: -138.95684594226077
# agent 48 在 199 次迭代中的对偶变量为: -138.87423270891452
# agent 49 在 199 次迭代中的对偶变量为: -138.6495020532231
# agent 50 在 199 次迭代中的对偶变量为: -138.91056908695865
# agent 51 在 199 次迭代中的对偶变量为: -138.8069018179696
# agent 52 在 199 次迭代中的对偶变量为: -138.88335585965334
# agent 53 在 199 次迭代中的对偶变量为: -138.89569491027777
# agent 54 在 199 次迭代中的对偶变量为: -139.17140390932863
# agent 55 在 199 次迭代中的对偶变量为: -138.92213988915506
# agent 56 在 199 次迭代中的对偶变量为: -139.0540936389629
# agent 57 在 199 次迭代中的对偶变量为: -138.99872857665366
# agent 58 在 199 次迭代中的对偶变量为: -138.95792524421043
# agent 59 在 199 次迭代中的对偶变量为: -138.9573007347575
# agent 60 在 199 次迭代中的对偶变量为: -138.9720047625404
# agent 61 在 199 次迭代中的对偶变量为: -138.75293637663418
# agent 62 在 199 次迭代中的对偶变量为: -138.9433622895406
# agent 63 在 199 次迭代中的对偶变量为: -139.04732201541424
# agent 64 在 199 次迭代中的对偶变量为: -138.94935013264708
# agent 65 在 199 次迭代中的对偶变量为: -138.85952833209026
# agent 66 在 199 次迭代中的对偶变量为: -138.64611138534468
# agent 67 在 199 次迭代中的对偶变量为: -138.94749690008177
# agent 68 在 199 次迭代中的对偶变量为: -138.9321781892295
# agent 69 在 199 次迭代中的对偶变量为: -138.97101391411366
# agent 70 在 199 次迭代中的对偶变量为: -138.8966238206226
# agent 71 在 199 次迭代中的对偶变量为: -138.5743849469166
# agent 72 在 199 次迭代中的对偶变量为: -138.7881927297034
# agent 73 在 199 次迭代中的对偶变量为: -138.81982297742582
# agent 74 在 199 次迭代中的对偶变量为: -138.99481213809753
# agent 75 在 199 次迭代中的对偶变量为: -138.99167479984027
# agent 76 在 199 次迭代中的对偶变量为: -138.91765800357126
# agent 77 在 199 次迭代中的对偶变量为: -138.85939111377118
# agent 78 在 199 次迭代中的对偶变量为: -138.94415733711983
# agent 79 在 199 次迭代中的对偶变量为: -139.09573189273004
# agent 80 在 199 次迭代中的对偶变量为: -138.83464409386903
# agent 81 在 199 次迭代中的对偶变量为: -139.1829162902112
# agent 82 在 199 次迭代中的对偶变量为: -139.11163159191082
# agent 83 在 199 次迭代中的对偶变量为: -138.9679911986358
# agent 84 在 199 次迭代中的对偶变量为: -138.82708921410276
# agent 85 在 199 次迭代中的对偶变量为: -138.9083611243774
# agent 86 在 199 次迭代中的对偶变量为: -138.97470344312154
# agent 87 在 199 次迭代中的对偶变量为: -138.9160539501024
# agent 88 在 199 次迭代中的对偶变量为: -138.71637269377857
# agent 89 在 199 次迭代中的对偶变量为: -138.7035905485219
# agent 90 在 199 次迭代中的对偶变量为: -139.008918577237
# agent 91 在 199 次迭代中的对偶变量为: -138.86687823042473
# agent 92 在 199 次迭代中的对偶变量为: -139.0323971321713
# agent 93 在 199 次迭代中的对偶变量为: -139.06063495335374
# agent 94 在 199 次迭代中的对偶变量为: -138.8822264563418
# agent 95 在 199 次迭代中的对偶变量为: -138.83254895005203
# agent 96 在 199 次迭代中的对偶变量为: -138.8060243234587
# agent 97 在 199 次迭代中的对偶变量为: -138.67191441996505
# agent 98 在 199 次迭代中的对偶变量为: -138.85681114899432
# agent 99 在 199 次迭代中的对偶变量为: -138.87559149806933
# agent 100 在 199 次迭代中的对偶变量为: -139.0039159396803
# *************************
# 迭代步长为: 0.04175304505755262
# ****************************************************************************
# 249 次迭代中的结果：
# agent 1 在 249 次迭代中的资源申请量为: 48.07003143460084
# agent 2 在 249 次迭代中的资源申请量为: 60.5047632669125
# agent 3 在 249 次迭代中的资源申请量为: 43.51177929762396
# agent 4 在 249 次迭代中的资源申请量为: 64.0046557872107
# agent 5 在 249 次迭代中的资源申请量为: 64.76896916771716
# agent 6 在 249 次迭代中的资源申请量为: 71.39842842121878
# agent 7 在 249 次迭代中的资源申请量为: 39.19525570842485
# agent 8 在 249 次迭代中的资源申请量为: 37.470837505079615
# agent 9 在 249 次迭代中的资源申请量为: 42.788822267399574
# agent 10 在 249 次迭代中的资源申请量为: 55.3765649728338
# agent 11 在 249 次迭代中的资源申请量为: 45.162820260655685
# agent 12 在 249 次迭代中的资源申请量为: 48.91858648866749
# agent 13 在 249 次迭代中的资源申请量为: 65.26069238209145
# agent 14 在 249 次迭代中的资源申请量为: 54.833268042168164
# agent 15 在 249 次迭代中的资源申请量为: 43.231698922972726
# agent 16 在 249 次迭代中的资源申请量为: 43.40242474440804
# agent 17 在 249 次迭代中的资源申请量为: 44.58704679736379
# agent 18 在 249 次迭代中的资源申请量为: 46.186209271873665
# agent 19 在 249 次迭代中的资源申请量为: 41.04188679917575
# agent 20 在 249 次迭代中的资源申请量为: 55.26951705573457
# agent 21 在 249 次迭代中的资源申请量为: 38.49230142864393
# agent 22 在 249 次迭代中的资源申请量为: 38.814224855502985
# agent 23 在 249 次迭代中的资源申请量为: 47.55313526502747
# agent 24 在 249 次迭代中的资源申请量为: 40.26438865509926
# agent 25 在 249 次迭代中的资源申请量为: 44.85407117882756
# agent 26 在 249 次迭代中的资源申请量为: 39.552007084772114
# agent 27 在 249 次迭代中的资源申请量为: 65.02142050066105
# agent 28 在 249 次迭代中的资源申请量为: 50.911907624948114
# agent 29 在 249 次迭代中的资源申请量为: 40.547629173954576
# agent 30 在 249 次迭代中的资源申请量为: 38.952172282997466
# agent 31 在 249 次迭代中的资源申请量为: 59.978660713811124
# agent 32 在 249 次迭代中的资源申请量为: 55.0801855315482
# agent 33 在 249 次迭代中的资源申请量为: 41.26982974486049
# agent 34 在 249 次迭代中的资源申请量为: 51.864476017064725
# agent 35 在 249 次迭代中的资源申请量为: 38.57393988613808
# agent 36 在 249 次迭代中的资源申请量为: 42.47635580020851
# agent 37 在 249 次迭代中的资源申请量为: 52.156402432953044
# agent 38 在 249 次迭代中的资源申请量为: 40.02757282895417
# agent 39 在 249 次迭代中的资源申请量为: 43.011119166071204
# agent 40 在 249 次迭代中的资源申请量为: 49.75851923553913
# agent 41 在 249 次迭代中的资源申请量为: 65.65103731220437
# agent 42 在 249 次迭代中的资源申请量为: 42.18841154037111
# agent 43 在 249 次迭代中的资源申请量为: 51.292412982684155
# agent 44 在 249 次迭代中的资源申请量为: 52.61788503965809
# agent 45 在 249 次迭代中的资源申请量为: 47.86092577489583
# agent 46 在 249 次迭代中的资源申请量为: 55.40638926794088
# agent 47 在 249 次迭代中的资源申请量为: 45.56002899878895
# agent 48 在 249 次迭代中的资源申请量为: 43.082265485038675
# agent 49 在 249 次迭代中的资源申请量为: 42.324394218292234
# agent 50 在 249 次迭代中的资源申请量为: 40.61986362748246
# agent 51 在 249 次迭代中的资源申请量为: 47.913570989877655
# agent 52 在 249 次迭代中的资源申请量为: 55.26450791479992
# agent 53 在 249 次迭代中的资源申请量为: 38.68382365739044
# agent 54 在 249 次迭代中的资源申请量为: 56.56150073122178
# agent 55 在 249 次迭代中的资源申请量为: 70.42082800841602
# agent 56 在 249 次迭代中的资源申请量为: 40.654779101228854
# agent 57 在 249 次迭代中的资源申请量为: 59.96194708928456
# agent 58 在 249 次迭代中的资源申请量为: 41.903829419704884
# agent 59 在 249 次迭代中的资源申请量为: 47.557461313449885
# agent 60 在 249 次迭代中的资源申请量为: 55.59433606867899
# agent 61 在 249 次迭代中的资源申请量为: 65.33339772936907
# agent 62 在 249 次迭代中的资源申请量为: 45.756324500734316
# agent 63 在 249 次迭代中的资源申请量为: 38.71874209408526
# agent 64 在 249 次迭代中的资源申请量为: 44.05795084759303
# agent 65 在 249 次迭代中的资源申请量为: 42.37849095868562
# agent 66 在 249 次迭代中的资源申请量为: 64.99089198881022
# agent 67 在 249 次迭代中的资源申请量为: 43.00110549590325
# agent 68 在 249 次迭代中的资源申请量为: 44.5532398799079
# agent 69 在 249 次迭代中的资源申请量为: 45.063879289817415
# agent 70 在 249 次迭代中的资源申请量为: 59.524678044315316
# agent 71 在 249 次迭代中的资源申请量为: 71.26856002819561
# agent 72 在 249 次迭代中的资源申请量为: 59.68515886785642
# agent 73 在 249 次迭代中的资源申请量为: 43.368260502962436
# agent 74 在 249 次迭代中的资源申请量为: 38.7066625821696
# agent 75 在 249 次迭代中的资源申请量为: 51.57945329174365
# agent 76 在 249 次迭代中的资源申请量为: 46.64929886418486
# agent 77 在 249 次迭代中的资源申请量为: 40.507422924650754
# agent 78 在 249 次迭代中的资源申请量为: 49.2536410387919
# agent 79 在 249 次迭代中的资源申请量为: 42.53930459077406
# agent 80 在 249 次迭代中的资源申请量为: 42.67209054959426
# agent 81 在 249 次迭代中的资源申请量为: 39.25000542528763
# agent 82 在 249 次迭代中的资源申请量为: 45.40234652370112
# agent 83 在 249 次迭代中的资源申请量为: 41.333842114823895
# agent 84 在 249 次迭代中的资源申请量为: 51.62801254360057
# agent 85 在 249 次迭代中的资源申请量为: 55.27290023692918
# agent 86 在 249 次迭代中的资源申请量为: 48.562545350370385
# agent 87 在 249 次迭代中的资源申请量为: 59.931784131140304
# agent 88 在 249 次迭代中的资源申请量为: 64.51882016493914
# agent 89 在 249 次迭代中的资源申请量为: 40.16952165003902
# agent 90 在 249 次迭代中的资源申请量为: 58.76566356400569
# agent 91 在 249 次迭代中的资源申请量为: 42.580386998694756
# agent 92 在 249 次迭代中的资源申请量为: 56.51467639585639
# agent 93 在 249 次迭代中的资源申请量为: 40.45637722970227
# agent 94 在 249 次迭代中的资源申请量为: 72.60334198137562
# agent 95 在 249 次迭代中的资源申请量为: 59.801345548789314
# agent 96 在 249 次迭代中的资源申请量为: 59.99167741296513
# agent 97 在 249 次迭代中的资源申请量为: 71.511271204821
# agent 98 在 249 次迭代中的资源申请量为: 72.39219873958127
# agent 99 在 249 次迭代中的资源申请量为: 52.04319628655958
# agent 100 在 249 次迭代中的资源申请量为: 48.17108040620676
# 资源申请量总和为: 4995.774324522661
# ****************************************************************************
# 成本总和为: 333500.2154876685
# ****************************************************************************
# ...
# agent 61 在 57999 次迭代中的资源申请量为: 45.35594989347403
# agent 62 在 57999 次迭代中的资源申请量为: 37.777916501990724
# agent 63 在 57999 次迭代中的资源申请量为: 44.36024833408177
# agent 64 在 57999 次迭代中的资源申请量为: 50.59248382563158
# agent 65 在 57999 次迭代中的资源申请量为: 48.719342447654434
# agent 66 在 57999 次迭代中的资源申请量为: 53.47780999250294
# agent 67 在 57999 次迭代中的资源申请量为: 44.62937911116489
# agent 68 在 57999 次迭代中的资源申请量为: 38.64566746179317
# agent 69 在 57999 次迭代中的资源申请量为: 49.892139157742264
# agent 70 在 57999 次迭代中的资源申请量为: 43.38409217370307
# agent 71 在 57999 次迭代中的资源申请量为: 51.072439614453316
# agent 72 在 57999 次迭代中的资源申请量为: 51.63101181607402
# agent 73 在 57999 次迭代中的资源申请量为: 68.52493850742536
# agent 74 在 57999 次迭代中的资源申请量为: 63.033563690013715
# agent 75 在 57999 次迭代中的资源申请量为: 68.784860310892
# agent 76 在 57999 次迭代中的资源申请量为: 65.84231131075826
# agent 77 在 57999 次迭代中的资源申请量为: 37.33178559067635
# agent 78 在 57999 次迭代中的资源申请量为: 56.51515954674519
# agent 79 在 57999 次迭代中的资源申请量为: 35.71319766839764
# agent 80 在 57999 次迭代中的资源申请量为: 41.69438982489503
# agent 81 在 57999 次迭代中的资源申请量为: 64.43288578237497
# agent 82 在 57999 次迭代中的资源申请量为: 45.64920279686928
# agent 83 在 57999 次迭代中的资源申请量为: 54.00548947849253
# agent 84 在 57999 次迭代中的资源申请量为: 52.98642785861979
# agent 85 在 57999 次迭代中的资源申请量为: 58.685757530611916
# agent 86 在 57999 次迭代中的资源申请量为: 54.16278250297388
# agent 87 在 57999 次迭代中的资源申请量为: 50.183947875573004
# agent 88 在 57999 次迭代中的资源申请量为: 53.40486804038364
# agent 89 在 57999 次迭代中的资源申请量为: 44.037016821613456
# agent 90 在 57999 次迭代中的资源申请量为: 38.995841039652966
# agent 91 在 57999 次迭代中的资源申请量为: 43.58677066582213
# agent 92 在 57999 次迭代中的资源申请量为: 45.25809138455365
# agent 93 在 57999 次迭代中的资源申请量为: 35.68321481266967
# agent 94 在 57999 次迭代中的资源申请量为: 37.48060785879904
# 资源申请量平均值avg为: 49.99999999999654
# ****************************************************************************
# 平均成本为: 3240.481984531225
# ****************************************************************************
# agent 1 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 2 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 3 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 4 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 5 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 6 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 7 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 8 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 9 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 10 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 11 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 12 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 13 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 14 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 15 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 16 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 17 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 18 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 19 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 20 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 21 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 22 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 23 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 24 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 25 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 26 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 27 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 28 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 29 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 30 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 31 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 32 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 33 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 34 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 35 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 36 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 37 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 38 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 39 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 40 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 41 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 42 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 43 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 44 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 45 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 46 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 47 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 48 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 49 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 50 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 51 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 52 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 53 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 54 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 55 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 56 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 57 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 58 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 59 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 60 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 61 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 62 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 63 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 64 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 65 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 66 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 67 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 68 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 69 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 70 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 71 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 72 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 73 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 74 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 75 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 76 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 77 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 78 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 79 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 80 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 81 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 82 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 83 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 84 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 85 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 86 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 87 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 88 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 89 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 90 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 91 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 92 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 93 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 94 在 57999 次迭代中的对偶变量为: -135.14386653834575
# *************************
# 迭代步长为: 0.11151053484837568
# ****************************************************************************
# 59999 次迭代中的结果：
# agent 1 在 59999 次迭代中的资源申请量为: 56.19880558172988
# agent 2 在 59999 次迭代中的资源申请量为: 56.03871203978166
# agent 3 在 59999 次迭代中的资源申请量为: 60.64796214442871
# agent 4 在 59999 次迭代中的资源申请量为: 37.93333499802675
# agent 5 在 59999 次迭代中的资源申请量为: 57.56693686702461
# agent 6 在 59999 次迭代中的资源申请量为: 55.34212747123894
# agent 7 在 59999 次迭代中的资源申请量为: 65.6236567946489
# agent 8 在 59999 次迭代中的资源申请量为: 46.330946703602365
# agent 9 在 59999 次迭代中的资源申请量为: 65.64268770463663
# agent 10 在 59999 次迭代中的资源申请量为: 54.23914303693835
# agent 11 在 59999 次迭代中的资源申请量为: 65.4520437985654
# agent 12 在 59999 次迭代中的资源申请量为: 38.406222330358624
# agent 13 在 59999 次迭代中的资源申请量为: 49.70058714461363
# agent 14 在 59999 次迭代中的资源申请量为: 41.3659905551611
# agent 15 在 59999 次迭代中的资源申请量为: 42.48853939614691
# agent 16 在 59999 次迭代中的资源申请量为: 49.24530133808371
# agent 17 在 59999 次迭代中的资源申请量为: 50.11852704992918
# agent 18 在 59999 次迭代中的资源申请量为: 46.537297422347486
# agent 19 在 59999 次迭代中的资源申请量为: 44.77392156663175
# agent 20 在 59999 次迭代中的资源申请量为: 50.80339666473046
# agent 21 在 59999 次迭代中的资源申请量为: 69.93387670557085
# agent 22 在 59999 次迭代中的资源申请量为: 61.24199691647269
# agent 23 在 59999 次迭代中的资源申请量为: 61.627787986086716
# agent 24 在 59999 次迭代中的资源申请量为: 39.861352301782716
# agent 25 在 59999 次迭代中的资源申请量为: 52.95065687328203
# agent 26 在 59999 次迭代中的资源申请量为: 49.39633437684004
# agent 27 在 59999 次迭代中的资源申请量为: 47.51919637207136
# agent 28 在 59999 次迭代中的资源申请量为: 40.7413613830987
# agent 29 在 59999 次迭代中的资源申请量为: 44.38273034135506
# agent 30 在 59999 次迭代中的资源申请量为: 39.891745956789116
# agent 31 在 59999 次迭代中的资源申请量为: 65.76280653244551
# agent 32 在 59999 次迭代中的资源申请量为: 59.51901541924079
# agent 33 在 59999 次迭代中的资源申请量为: 48.23750867799392
# agent 34 在 59999 次迭代中的资源申请量为: 36.76532342510125
# agent 35 在 59999 次迭代中的资源申请量为: 41.086702696803464
# agent 36 在 59999 次迭代中的资源申请量为: 62.20889044924783
# agent 37 在 59999 次迭代中的资源申请量为: 40.47023795026076
# agent 38 在 59999 次迭代中的资源申请量为: 58.24733429492913
# agent 39 在 59999 次迭代中的资源申请量为: 37.39554726071002
# agent 40 在 59999 次迭代中的资源申请量为: 50.45313221045784
# agent 41 在 59999 次迭代中的资源申请量为: 36.73569742369616
# agent 42 在 59999 次迭代中的资源申请量为: 56.24242387150355
# agent 43 在 59999 次迭代中的资源申请量为: 61.52373322591861
# agent 44 在 59999 次迭代中的资源申请量为: 47.51525622305313
# agent 45 在 59999 次迭代中的资源申请量为: 41.36197014706921
# agent 46 在 59999 次迭代中的资源申请量为: 67.10436077257359
# agent 47 在 59999 次迭代中的资源申请量为: 65.57090570810219
# agent 48 在 59999 次迭代中的资源申请量为: 40.83836334458436
# agent 49 在 59999 次迭代中的资源申请量为: 39.16390664937778
# agent 50 在 59999 次迭代中的资源申请量为: 63.292999181236645
# agent 51 在 59999 次迭代中的资源申请量为: 36.39727688961264
# agent 52 在 59999 次迭代中的资源申请量为: 46.86937779818014
# agent 53 在 59999 次迭代中的资源申请量为: 43.572511920796444
# agent 54 在 59999 次迭代中的资源申请量为: 49.58201107681077
# agent 55 在 59999 次迭代中的资源申请量为: 47.173391517077015
# agent 56 在 59999 次迭代中的资源申请量为: 42.97971616155657
# agent 57 在 59999 次迭代中的资源申请量为: 36.90486251978384
# agent 58 在 59999 次迭代中的资源申请量为: 59.2566799113546
# agent 59 在 59999 次迭代中的资源申请量为: 59.891586060534515
# agent 60 在 59999 次迭代中的资源申请量为: 40.34169962872796
# agent 61 在 59999 次迭代中的资源申请量为: 45.35594989347582
# agent 62 在 59999 次迭代中的资源申请量为: 37.77791650199216
# agent 63 在 59999 次迭代中的资源申请量为: 44.360248334083515
# agent 64 在 59999 次迭代中的资源申请量为: 50.59248382563358
# agent 65 在 59999 次迭代中的资源申请量为: 48.71934244765636
# agent 66 在 59999 次迭代中的资源申请量为: 53.47780999250507
# agent 67 在 59999 次迭代中的资源申请量为: 44.62937911116663
# agent 68 在 59999 次迭代中的资源申请量为: 38.64566746179467
# agent 69 在 59999 次迭代中的资源申请量为: 49.89213915774424
# agent 70 在 59999 次迭代中的资源申请量为: 43.384092173704765
# agent 71 在 59999 次迭代中的资源申请量为: 51.07243961445531
# agent 72 在 59999 次迭代中的资源申请量为: 51.63101181607605
# agent 73 在 59999 次迭代中的资源申请量为: 68.52493850742809
# agent 74 在 59999 次迭代中的资源申请量为: 63.033563690016244
# agent 75 在 59999 次迭代中的资源申请量为: 68.78486031089474
# agent 76 在 59999 次迭代中的资源申请量为: 65.84231131076093
# agent 77 在 59999 次迭代中的资源申请量为: 37.33178559067781
# agent 78 在 59999 次迭代中的资源申请量为: 56.51515954674745
# agent 79 在 59999 次迭代中的资源申请量为: 35.713197668399026
# agent 80 在 59999 次迭代中的资源申请量为: 41.69438982489667
# agent 81 在 59999 次迭代中的资源申请量为: 64.43288578237754
# agent 82 在 59999 次迭代中的资源申请量为: 45.64920279687104
# agent 83 在 59999 次迭代中的资源申请量为: 54.00548947849467
# agent 84 在 59999 次迭代中的资源申请量为: 52.98642785862186
# agent 85 在 59999 次迭代中的资源申请量为: 58.685757530614225
# agent 86 在 59999 次迭代中的资源申请量为: 54.16278250297603
# agent 87 在 59999 次迭代中的资源申请量为: 50.18394787557497
# agent 88 在 59999 次迭代中的资源申请量为: 53.40486804038577
# agent 89 在 59999 次迭代中的资源申请量为: 44.03701682161516
# agent 90 在 59999 次迭代中的资源申请量为: 38.99584103965445
# agent 91 在 59999 次迭代中的资源申请量为: 43.58677066582381
# agent 92 在 59999 次迭代中的资源申请量为: 45.258091384555385
# agent 93 在 59999 次迭代中的资源申请量为: 35.68321481267107
# agent 94 在 59999 次迭代中的资源申请量为: 37.4806078588005
# 资源申请量平均值avg为: 49.9999999999985
# ****************************************************************************
# 平均成本为: 3240.4819845314896
# ****************************************************************************
# agent 1 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 2 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 3 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 4 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 5 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 6 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 7 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 8 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 9 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 10 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 11 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 12 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 13 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 14 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 15 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 16 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 17 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 18 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 19 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 20 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 21 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 22 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 23 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 24 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 25 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 26 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 27 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 28 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 29 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 30 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 31 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 32 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 33 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 34 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 35 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 36 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 37 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 38 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 39 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 40 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 41 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 42 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 43 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 44 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 45 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 46 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 47 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 48 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 49 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 50 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 51 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 52 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 53 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 54 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 55 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 56 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 57 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 58 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 59 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 60 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 61 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 62 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 63 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 64 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 65 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 66 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 67 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 68 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 69 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 70 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 71 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 72 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 73 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 74 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 75 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 76 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 77 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 78 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 79 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 80 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 81 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 82 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 83 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 84 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 85 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 86 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 87 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 88 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 89 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 90 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 91 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 92 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 93 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 94 在 59999 次迭代中的对偶变量为: -135.1438665383513
# *************************
# 迭代步长为: 0.11075700351730201
# ****************************************************************************
# 2023-05-29 15:40:13.737

# %% [markdown]
# np.savetxt('./data/agent_resource_quantity_oracle.txt',agent_resource_quantity,fmt='%0.8f')#用户资源
# np.savetxt('./data/average_cost_oracle.txt',average_cost,fmt='%0.8f')#用户平均成本
# np.savetxt('./data/average_resource_oracle.txt',average_resource,fmt='%0.8f')#用户平均资源
# np.savetxt('./data/dual_variable_oracle.txt',dual_variable,fmt='%0.8f')#用户对偶变量

# %%
np.savetxt('../data/DGD-agent_resource_quantity_oracle.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/DGD-sum_cost_oracle.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/DGD-sum_resource_oracle.txt',sum_resource,fmt='%0.8f')#用户资源总和
