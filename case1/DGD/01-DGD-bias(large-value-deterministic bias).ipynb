# %% [markdown]
# DGD+部分用户的对偶计算有误差
# 为了对比实验的公平性 要保证噪声的效果和IWDGD算法中噪声的效果尽可能一致
# 主要是观察噪声对对偶变量的影响是否一致

# %% [markdown]
# IWDGD中大值的确定性噪声 对应到DGD算法中是固定的对偶攻击值为-152.8 这样两个算法各自迭代1000次 所有用户的对偶迭代值均在150附近

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(100,1000)) #100个agent的资源量 定义成一个矩阵 100*20000
dual_variable = np.zeros(shape=(100,1000))#对偶变量
sum_resource=np.zeros(shape=(1,1000), dtype=np.float64)#存放每一次迭代后所有用户资源量的总和
sum_cost=np.zeros(shape=(1,1000), dtype=np.float64)#存放每一次迭代后所有用户成本的总和
iteration_update = 0.01#迭代步长
A=np.loadtxt("100_Network_Topology_Double_Random_Adjacency_Matrix_Degree_15.txt") #网络拓扑的邻接矩阵 对角元素要为0
W=np.zeros(shape=(100,100)) #双随机的网络拓扑矩阵W（对角线处非零）
iteration=[]#绘图横坐标
a=np.loadtxt("100_uniform_distribution_(1,2)_point1.txt")#每个agent的成本函数中的超参数
b=np.loadtxt("100_normal_distribution_(2,0.6)_point1.txt")#每个agent的成本函数中的超参数
#bias=-3

# %%
#根据邻接矩阵生成网络对应的双随机的权重混合矩阵
for i in range(0,100):
    for j in range(0,100):
        if A[i][j]!=0 or i==j:
            W[i][j]=1/16

#对偶变量的初始化 初始化一致
for i in range (0,100):
    #if i==7 or i==20 or i==34:
        #dual_variable[i][0]=0+bias
        #dual_variable[i][0]=-152.8
    #else:
    dual_variable[i][0]=0
    
#资源量的初始化 资源量的初始化需要和对偶变量的初始值满足某种关系
for i in range (0,100):
    agent_resource_quantity[i][0]=50

iteration.append(0)

#总资源量 初始化
sum=0
for i in range (0,100):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

#用户总成本初始化
sum=0
for i in range(0,100):
    sum=sum+a[i]*(agent_resource_quantity[i][0]-b[i])*(agent_resource_quantity[i][0]-b[i])
sum_cost[0][0]=sum

# %%
#DGD算法 
def DGD_deterministic_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************DGD算法+计算误差****************************")
    print("相关变量初始值为：")
    for i in range (0,100):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    for i in range(0,100):
        print("agent",(i+1),"的初始对偶变量为:",dual_variable[i][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):#迭代次数
        iteration.append(k)
        
        #所有用户对偶变量的迭代 
        #阶段一：梯度下降
        dual_variable_intermediate=[] #存放当前迭代中100个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,100):
            #每个用户对对偶变量先进行一次梯度下降
            if i==7 or i==20 or i==34:
                dual_variable_intermediate.append(-152.8)
            else:
                dual_variable_intermediate.append(dual_variable[i][k-1]-iteration_update*(50-agent_resource_quantity[i][k-1]))       
        #阶段二：聚合 每个用户聚合自身以及邻居的对偶值   
        for i in range(0,100):
            mix_sum_dual=0
            for j in range(0,100):
                if W[i][j]!=0:
                    mix_sum_dual=mix_sum_dual+W[i][j]*dual_variable_intermediate[j]
                dual_variable[i][k]=mix_sum_dual
        
        #用户资源申请量的迭代
        for i in range (0,100):
            agent_resource_quantity[i][k]=(dual_variable[i][k]-2*a[i]*b[i])/(-2*a[i])

        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,100):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,100):
            sum2=sum2+a[i]*(agent_resource_quantity[i][k]-b[i])*(agent_resource_quantity[i][k]-b[i])
        sum_cost[0][k]=sum2
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%50==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,100):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            for i in range(0,100):
                print("agent",(i+1),"在",k,"次迭代中的对偶变量为:",dual_variable[i][k])   
            print("*************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        iteration_update=1/(pow(k+1,0.6)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
DGD_deterministic_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration)
# Out:
# ****************************DGD算法+计算误差****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 50.0
# agent 2 的初始资源申请量为: 50.0
# agent 3 的初始资源申请量为: 50.0
# agent 4 的初始资源申请量为: 50.0
# agent 5 的初始资源申请量为: 50.0
# agent 6 的初始资源申请量为: 50.0
# agent 7 的初始资源申请量为: 50.0
# agent 8 的初始资源申请量为: 50.0
# agent 9 的初始资源申请量为: 50.0
# agent 10 的初始资源申请量为: 50.0
# agent 11 的初始资源申请量为: 50.0
# agent 12 的初始资源申请量为: 50.0
# agent 13 的初始资源申请量为: 50.0
# agent 14 的初始资源申请量为: 50.0
# agent 15 的初始资源申请量为: 50.0
# agent 16 的初始资源申请量为: 50.0
# agent 17 的初始资源申请量为: 50.0
# agent 18 的初始资源申请量为: 50.0
# agent 19 的初始资源申请量为: 50.0
# agent 20 的初始资源申请量为: 50.0
# agent 21 的初始资源申请量为: 50.0
# agent 22 的初始资源申请量为: 50.0
# agent 23 的初始资源申请量为: 50.0
# agent 24 的初始资源申请量为: 50.0
# agent 25 的初始资源申请量为: 50.0
# agent 26 的初始资源申请量为: 50.0
# agent 27 的初始资源申请量为: 50.0
# agent 28 的初始资源申请量为: 50.0
# agent 29 的初始资源申请量为: 50.0
# agent 30 的初始资源申请量为: 50.0
# agent 31 的初始资源申请量为: 50.0
# agent 32 的初始资源申请量为: 50.0
# agent 33 的初始资源申请量为: 50.0
# agent 34 的初始资源申请量为: 50.0
# agent 35 的初始资源申请量为: 50.0
# agent 36 的初始资源申请量为: 50.0
# agent 37 的初始资源申请量为: 50.0
# agent 38 的初始资源申请量为: 50.0
# agent 39 的初始资源申请量为: 50.0
# agent 40 的初始资源申请量为: 50.0
# agent 41 的初始资源申请量为: 50.0
# agent 42 的初始资源申请量为: 50.0
# agent 43 的初始资源申请量为: 50.0
# agent 44 的初始资源申请量为: 50.0
# agent 45 的初始资源申请量为: 50.0
# agent 46 的初始资源申请量为: 50.0
# agent 47 的初始资源申请量为: 50.0
# agent 48 的初始资源申请量为: 50.0
# agent 49 的初始资源申请量为: 50.0
# agent 50 的初始资源申请量为: 50.0
# agent 51 的初始资源申请量为: 50.0
# agent 52 的初始资源申请量为: 50.0
# agent 53 的初始资源申请量为: 50.0
# agent 54 的初始资源申请量为: 50.0
# agent 55 的初始资源申请量为: 50.0
# agent 56 的初始资源申请量为: 50.0
# agent 57 的初始资源申请量为: 50.0
# agent 58 的初始资源申请量为: 50.0
# agent 59 的初始资源申请量为: 50.0
# agent 60 的初始资源申请量为: 50.0
# agent 61 的初始资源申请量为: 50.0
# agent 62 的初始资源申请量为: 50.0
# agent 63 的初始资源申请量为: 50.0
# agent 64 的初始资源申请量为: 50.0
# agent 65 的初始资源申请量为: 50.0
# agent 66 的初始资源申请量为: 50.0
# agent 67 的初始资源申请量为: 50.0
# agent 68 的初始资源申请量为: 50.0
# agent 69 的初始资源申请量为: 50.0
# agent 70 的初始资源申请量为: 50.0
# agent 71 的初始资源申请量为: 50.0
# agent 72 的初始资源申请量为: 50.0
# agent 73 的初始资源申请量为: 50.0
# agent 74 的初始资源申请量为: 50.0
# agent 75 的初始资源申请量为: 50.0
# agent 76 的初始资源申请量为: 50.0
# agent 77 的初始资源申请量为: 50.0
# agent 78 的初始资源申请量为: 50.0
# agent 79 的初始资源申请量为: 50.0
# agent 80 的初始资源申请量为: 50.0
# agent 81 的初始资源申请量为: 50.0
# agent 82 的初始资源申请量为: 50.0
# agent 83 的初始资源申请量为: 50.0
# agent 84 的初始资源申请量为: 50.0
# agent 85 的初始资源申请量为: 50.0
# agent 86 的初始资源申请量为: 50.0
# agent 87 的初始资源申请量为: 50.0
# agent 88 的初始资源申请量为: 50.0
# agent 89 的初始资源申请量为: 50.0
# agent 90 的初始资源申请量为: 50.0
# agent 91 的初始资源申请量为: 50.0
# agent 92 的初始资源申请量为: 50.0
# agent 93 的初始资源申请量为: 50.0
# agent 94 的初始资源申请量为: 50.0
# agent 95 的初始资源申请量为: 50.0
# agent 96 的初始资源申请量为: 50.0
# agent 97 的初始资源申请量为: 50.0
# agent 98 的初始资源申请量为: 50.0
# agent 99 的初始资源申请量为: 50.0
# agent 100 的初始资源申请量为: 50.0
# *************************
# 初始资源申请量总和为: 5000.0
# *************************
# 初始成本总和为: 346654.5889999999
# *************************
# agent 1 的初始对偶变量为: 0.0
# agent 2 的初始对偶变量为: 0.0
# agent 3 的初始对偶变量为: 0.0
# agent 4 的初始对偶变量为: 0.0
# agent 5 的初始对偶变量为: 0.0
# agent 6 的初始对偶变量为: 0.0
# agent 7 的初始对偶变量为: 0.0
# agent 8 的初始对偶变量为: 0.0
# agent 9 的初始对偶变量为: 0.0
# agent 10 的初始对偶变量为: 0.0
# agent 11 的初始对偶变量为: 0.0
# agent 12 的初始对偶变量为: 0.0
# agent 13 的初始对偶变量为: 0.0
# agent 14 的初始对偶变量为: 0.0
# agent 15 的初始对偶变量为: 0.0
# agent 16 的初始对偶变量为: 0.0
# agent 17 的初始对偶变量为: 0.0
# agent 18 的初始对偶变量为: 0.0
# agent 19 的初始对偶变量为: 0.0
# agent 20 的初始对偶变量为: 0.0
# agent 21 的初始对偶变量为: 0.0
# agent 22 的初始对偶变量为: 0.0
# agent 23 的初始对偶变量为: 0.0
# agent 24 的初始对偶变量为: 0.0
# agent 25 的初始对偶变量为: 0.0
# agent 26 的初始对偶变量为: 0.0
# agent 27 的初始对偶变量为: 0.0
# agent 28 的初始对偶变量为: 0.0
# agent 29 的初始对偶变量为: 0.0
# agent 30 的初始对偶变量为: 0.0
# agent 31 的初始对偶变量为: 0.0
# agent 32 的初始对偶变量为: 0.0
# agent 33 的初始对偶变量为: 0.0
# agent 34 的初始对偶变量为: 0.0
# agent 35 的初始对偶变量为: 0.0
# agent 36 的初始对偶变量为: 0.0
# agent 37 的初始对偶变量为: 0.0
# agent 38 的初始对偶变量为: 0.0
# agent 39 的初始对偶变量为: 0.0
# agent 40 的初始对偶变量为: 0.0
# agent 41 的初始对偶变量为: 0.0
# agent 42 的初始对偶变量为: 0.0
# agent 43 的初始对偶变量为: 0.0
# agent 44 的初始对偶变量为: 0.0
# agent 45 的初始对偶变量为: 0.0
# agent 46 的初始对偶变量为: 0.0
# agent 47 的初始对偶变量为: 0.0
# agent 48 的初始对偶变量为: 0.0
# agent 49 的初始对偶变量为: 0.0
# agent 50 的初始对偶变量为: 0.0
# agent 51 的初始对偶变量为: 0.0
# agent 52 的初始对偶变量为: 0.0
# agent 53 的初始对偶变量为: 0.0
# agent 54 的初始对偶变量为: 0.0
# agent 55 的初始对偶变量为: 0.0
# agent 56 的初始对偶变量为: 0.0
# agent 57 的初始对偶变量为: 0.0
# agent 58 的初始对偶变量为: 0.0
# agent 59 的初始对偶变量为: 0.0
# agent 60 的初始对偶变量为: 0.0
# agent 61 的初始对偶变量为: 0.0
# agent 62 的初始对偶变量为: 0.0
# agent 63 的初始对偶变量为: 0.0
# agent 64 的初始对偶变量为: 0.0
# agent 65 的初始对偶变量为: 0.0
# agent 66 的初始对偶变量为: 0.0
# agent 67 的初始对偶变量为: 0.0
# agent 68 的初始对偶变量为: 0.0
# agent 69 的初始对偶变量为: 0.0
# agent 70 的初始对偶变量为: 0.0
# agent 71 的初始对偶变量为: 0.0
# agent 72 的初始对偶变量为: 0.0
# agent 73 的初始对偶变量为: 0.0
# agent 74 的初始对偶变量为: 0.0
# agent 75 的初始对偶变量为: 0.0
# agent 76 的初始对偶变量为: 0.0
# agent 77 的初始对偶变量为: 0.0
# agent 78 的初始对偶变量为: 0.0
# agent 79 的初始对偶变量为: 0.0
# agent 80 的初始对偶变量为: 0.0
# agent 81 的初始对偶变量为: 0.0
# agent 82 的初始对偶变量为: 0.0
# agent 83 的初始对偶变量为: 0.0
# agent 84 的初始对偶变量为: 0.0
# agent 85 的初始对偶变量为: 0.0
# agent 86 的初始对偶变量为: 0.0
# agent 87 的初始对偶变量为: 0.0
# agent 88 的初始对偶变量为: 0.0
# agent 89 的初始对偶变量为: 0.0
# agent 90 的初始对偶变量为: 0.0
# agent 91 的初始对偶变量为: 0.0
# agent 92 的初始对偶变量为: 0.0
# agent 93 的初始对偶变量为: 0.0
# agent 94 的初始对偶变量为: 0.0
# agent 95 的初始对偶变量为: 0.0
# agent 96 的初始对偶变量为: 0.0
# agent 97 的初始对偶变量为: 0.0
# agent 98 的初始对偶变量为: 0.0
# agent 99 的初始对偶变量为: 0.0
# agent 100 的初始对偶变量为: 0.0
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 49 次迭代中的结果：
# agent 1 在 49 次迭代中的资源申请量为: 49.220500548615824
# agent 2 在 49 次迭代中的资源申请量为: 62.08380644234211
# agent 3 在 49 次迭代中的资源申请量为: 44.54509980057813
# agent 4 在 49 次迭代中的资源申请量为: 65.52677306870697
# agent 5 在 49 次迭代中的资源申请量为: 66.19284291859871
# agent 6 在 49 次迭代中的资源申请量为: 72.86527145483613
# agent 7 在 49 次迭代中的资源申请量为: 40.24703494334656
# agent 8 在 49 次迭代中的资源申请量为: 38.595843165907766
# agent 9 在 49 次迭代中的资源申请量为: 43.95879395758734
# agent 10 在 49 次迭代中的资源申请量为: 56.905592026952654
# agent 11 在 49 次迭代中的资源申请量为: 46.42176176487015
# agent 12 在 49 次迭代中的资源申请量为: 50.422403501550754
# agent 13 在 49 次迭代中的资源申请量为: 66.81467939708868
# agent 14 在 49 次迭代中的资源申请量为: 56.39171652597885
# agent 15 在 49 次迭代中的资源申请量为: 44.31307498345286
# agent 16 在 49 次迭代中的资源申请量为: 44.34575599760741
# agent 17 在 49 次迭代中的资源申请量为: 45.737995747420506
# agent 18 在 49 次迭代中的资源申请量为: 47.43744070010853
# agent 19 在 49 次迭代中的资源申请量为: 42.20227445184237
# agent 20 在 49 次迭代中的资源申请量为: 57.094704347390035
# agent 21 在 49 次迭代中的资源申请量为: 39.63405246029164
# agent 22 在 49 次迭代中的资源申请量为: 39.92325221465643
# agent 23 在 49 次迭代中的资源申请量为: 48.85716763916481
# agent 24 在 49 次迭代中的资源申请量为: 41.216245759238795
# agent 25 在 49 次迭代中的资源申请量为: 45.90365168481609
# agent 26 在 49 次迭代中的资源申请量为: 40.718400012624066
# agent 27 在 49 次迭代中的资源申请量为: 66.80895760213303
# agent 28 在 49 次迭代中的资源申请量为: 52.044998857472265
# agent 29 在 49 次迭代中的资源申请量为: 41.52806927384354
# agent 30 在 49 次迭代中的资源申请量为: 40.3104709215209
# agent 31 在 49 次迭代中的资源申请量为: 61.70493104693063
# agent 32 在 49 次迭代中的资源申请量为: 56.3145787281258
# agent 33 在 49 次迭代中的资源申请量为: 42.088592329216574
# agent 34 在 49 次迭代中的资源申请量为: 53.28468231175257
# agent 35 在 49 次迭代中的资源申请量为: 39.72546331207107
# agent 36 在 49 次迭代中的资源申请量为: 43.61687876895713
# agent 37 在 49 次迭代中的资源申请量为: 53.33852098216112
# agent 38 在 49 次迭代中的资源申请量为: 40.94991094150766
# agent 39 在 49 次迭代中的资源申请量为: 44.00243488604894
# agent 40 在 49 次迭代中的资源申请量为: 51.13539491426718
# agent 41 在 49 次迭代中的资源申请量为: 67.43182212907472
# agent 42 在 49 次迭代中的资源申请量为: 43.18215452962707
# agent 43 在 49 次迭代中的资源申请量为: 52.284979601379305
# agent 44 在 49 次迭代中的资源申请量为: 53.864862842179825
# agent 45 在 49 次迭代中的资源申请量为: 48.963842393395105
# agent 46 在 49 次迭代中的资源申请量为: 57.30270201137773
# agent 47 在 49 次迭代中的资源申请量为: 46.81673275442024
# agent 48 在 49 次迭代中的资源申请量为: 44.21412937428351
# agent 49 在 49 次迭代中的资源申请量为: 43.131957621777275
# agent 50 在 49 次迭代中的资源申请量为: 41.520215550803115
# agent 51 在 49 次迭代中的资源申请量为: 49.196029377919736
# agent 52 在 49 次迭代中的资源申请量为: 56.511545492089894
# agent 53 在 49 次迭代中的资源申请量为: 39.58234716745451
# agent 54 在 49 次迭代中的资源申请量为: 58.20583375705591
# agent 55 在 49 次迭代中的资源申请量为: 72.35440784873008
# agent 56 在 49 次迭代中的资源申请量为: 41.616187305312266
# agent 57 在 49 次迭代中的资源申请量为: 61.95309299000708
# agent 58 在 49 次迭代中的资源申请量为: 43.09772905584074
# agent 59 在 49 次迭代中的资源申请量为: 48.88292875077743
# agent 60 在 49 次迭代中的资源申请量为: 57.110749044343734
# agent 61 在 49 次迭代中的资源申请量为: 66.73155586017911
# agent 62 在 49 次迭代中的资源申请量为: 46.780069371499394
# agent 63 在 49 次迭代中的资源申请量为: 39.80608144916724
# agent 64 在 49 次迭代中的资源申请量为: 45.127844090631086
# agent 65 在 49 次迭代中的资源申请量为: 43.27866924044169
# agent 66 在 49 次迭代中的资源申请量为: 66.3052235772767
# agent 67 在 49 次迭代中的资源申请量为: 43.962542895868076
# agent 68 在 49 次迭代中的资源申请量为: 45.585760791465134
# agent 69 在 49 次迭代中的资源申请量为: 46.085636927256104
# agent 70 在 49 次迭代中的资源申请量为: 60.93851145670243
# agent 71 在 49 次迭代中的资源申请量为: 72.68064036715623
# agent 72 在 49 次迭代中的资源申请量为: 61.25898094902998
# agent 73 在 49 次迭代中的资源申请量为: 44.29802216766076
# agent 74 在 49 次迭代中的资源申请量为: 39.573072748447444
# agent 75 在 49 次迭代中的资源申请量为: 52.758740522057565
# agent 76 在 49 次迭代中的资源申请量为: 47.66527413274197
# agent 77 在 49 次迭代中的资源申请量为: 41.3849810561036
# agent 78 在 49 次迭代中的资源申请量为: 50.37753184636363
# agent 79 在 49 次迭代中的资源申请量为: 43.82430699995656
# agent 80 在 49 次迭代中的资源申请量为: 43.57122782086066
# agent 81 在 49 次迭代中的资源申请量为: 40.23691676514075
# agent 82 在 49 次迭代中的资源申请量为: 46.76391122235055
# agent 83 在 49 次迭代中的资源申请量为: 42.32681153212993
# agent 84 在 49 次迭代中的资源申请量为: 52.973222671095414
# agent 85 在 49 次迭代中的资源申请量为: 56.50346222265577
# agent 86 在 49 次迭代中的资源申请量为: 49.87797585029448
# agent 87 在 49 次迭代中的资源申请量为: 61.58312949607196
# agent 88 在 49 次迭代中的资源申请量为: 65.87491578091465
# agent 89 在 49 次迭代中的资源申请量为: 41.0514446297354
# agent 90 在 49 次迭代中的资源申请量为: 60.15062421360489
# agent 91 在 49 次迭代中的资源申请量为: 43.524286697850705
# agent 92 在 49 次迭代中的资源申请量为: 58.08622012385049
# agent 93 在 49 次迭代中的资源申请量为: 41.45987364331288
# agent 94 在 49 次迭代中的资源申请量为: 74.49968374687498
# agent 95 在 49 次迭代中的资源申请量为: 61.368768364363035
# agent 96 在 49 次迭代中的资源申请量为: 61.30250041378008
# agent 97 在 49 次迭代中的资源申请量为: 72.9341239911404
# agent 98 在 49 次迭代中的资源申请量为: 74.34049931856241
# agent 99 在 49 次迭代中的资源申请量为: 53.162402780815796
# agent 100 在 49 次迭代中的资源申请量为: 49.29844922086618
# 资源申请量总和为: 5120.968166945707
# ****************************************************************************
# 成本总和为: 351139.5131811607
# ****************************************************************************
# agent 1 在 49 次迭代中的对偶变量为: -142.56150164584747
# agent 2 在 49 次迭代中的对偶变量为: -142.76113546162105
# agent 3 在 49 次迭代中的对偶变量为: -142.61333932196564
# agent 4 在 49 次迭代中的对偶变量为: -142.39890075115537
# agent 5 在 49 次迭代中的对偶变量为: -142.10425442091716
# agent 6 在 49 次迭代中的对偶变量为: -141.73054290967227
# agent 7 在 49 次迭代中的对偶变量为: -143.05873278471694
# agent 8 在 49 次迭代中的对偶变量为: -143.58337266363105
# agent 9 在 49 次迭代中的对偶变量为: -142.99989945579694
# agent 10 在 49 次迭代中的对偶变量为: -143.0145392700769
# agent 11 在 49 次迭代中的对偶变量为: -143.1096376475845
# agent 12 在 49 次迭代中的对偶变量为: -143.46721050465226
# agent 13 在 49 次迭代中的对偶变量为: -142.3722946735951
# agent 14 在 49 次迭代中的对偶变量为: -143.23846296754502
# agent 15 在 49 次迭代中的对偶变量为: -142.84445494373972
# agent 16 在 49 次迭代中的对偶变量为: -142.2755703918652
# agent 17 在 49 次迭代中的对偶变量为: -142.8415863917456
# agent 18 在 49 次迭代中的对偶变量为: -143.15981024034733
# agent 19 在 49 次迭代中的对偶变量为: -143.28818802663253
# agent 20 在 49 次迭代中的对偶变量为: -143.76623130321408
# agent 21 在 49 次迭代中的对偶变量为: -143.38939934910823
# agent 22 在 49 次迭代中的对偶变量为: -143.34835841569443
# agent 23 在 49 次迭代中的对偶变量为: -143.27150291749442
# agent 24 在 49 次迭代中的对偶变量为: -142.61848473325966
# agent 25 在 49 次迭代中的对偶变量为: -142.4116853914115
# agent 26 在 49 次迭代中的对偶变量为: -143.70992004797142
# agent 27 在 49 次迭代中的对偶变量为: -143.01970672469267
# agent 28 在 49 次迭代中的对偶变量为: -142.08599680092235
# agent 29 在 49 次迭代中的对偶变量为: -142.66104938583675
# agent 30 在 49 次迭代中的对偶变量为: -144.43978950177942
# agent 31 在 49 次迭代中的对偶变量为: -143.2918345126335
# agent 32 在 49 次迭代中的对偶变量为: -142.2579046931271
# agent 33 在 49 次迭代中的对偶变量为: -141.79893238517968
# agent 34 在 49 次迭代中的对偶变量为: -143.0371104729072
# agent 35 在 49 次迭代中的对偶变量为: -143.35676058587006
# agent 36 在 49 次迭代中的对偶变量为: -142.85738781445423
# agent 37 在 49 次迭代中的对偶变量为: -142.34785875005113
# agent 38 在 49 次迭代中的对偶变量为: -142.3796793894276
# agent 39 在 49 次迭代中的对偶变量为: -142.4682786125664
# agent 40 在 49 次迭代中的对偶变量为: -143.20618474280155
# agent 41 在 49 次迭代中的对偶变量为: -142.85000868396438
# agent 42 在 49 次迭代中的对偶变量为: -142.39932540073204
# agent 43 在 49 次迭代中的对偶变量为: -141.63794288386205
# agent 44 在 49 次迭代中的对偶变量为: -142.7016159581035
# agent 45 在 49 次迭代中的对偶变量为: -142.3915271801853
# agent 46 在 49 次迭代中的对偶变量为: -144.04702522958212
# agent 47 在 49 次迭代中的对偶变量为: -143.09354481414476
# agent 48 在 49 次迭代中的对偶变量为: -142.84803987256393
# agent 49 在 49 次迭代中的对偶变量为: -141.54865591404274
# agent 50 在 49 次迭代中的对偶变量为: -142.27277598289123
# agent 51 在 49 次迭代中的对偶变量为: -142.7880881337592
# agent 52 在 49 次迭代中的对偶变量为: -142.25001827943373
# agent 53 在 49 次迭代中的对偶变量为: -142.43291923632714
# agent 54 在 49 次迭代中的对偶变量为: -143.53516776834536
# agent 55 在 49 次迭代中的对偶变量为: -142.90881569746014
# agent 56 在 49 次迭代中的对偶变量为: -142.61827429912418
# agent 57 在 49 次迭代中的对偶变量为: -143.88742317601697
# agent 58 在 49 次迭代中的对偶变量为: -143.1322787898585
# agent 59 在 49 次迭代中的对偶变量为: -143.0487862523323
# agent 60 在 49 次迭代中的对偶变量为: -143.0279475152937
# agent 61 在 49 次迭代中的对偶变量为: -141.96942289239405
# agent 62 在 49 次迭代中的对偶变量为: -142.33622198879806
# agent 63 在 49 次迭代中的对偶变量为: -143.2831095068355
# agent 64 在 49 次迭代中的对偶变量为: -142.4891010900195
# agent 65 在 49 次迭代中的对偶变量为: -142.04747541750174
# agent 66 在 49 次迭代中的对偶变量为: -141.69149187000875
# agent 67 在 49 次迭代中的对偶变量为: -142.33264584595148
# agent 68 在 49 次迭代中的对偶变量为: -142.35443453268843
# agent 69 在 49 次迭代中的对偶变量为: -142.35403816721953
# agent 70 在 49 次迭代中的对偶变量为: -142.41242749608583
# agent 71 在 49 次迭代中的对偶变量为: -141.56128073431245
# agent 72 在 49 次迭代中的对偶变量为: -142.70155427767196
# agent 73 在 49 次迭代中的对偶变量为: -142.11327537004658
# agent 74 在 49 次迭代中的对偶变量为: -142.39767644410028
# agent 75 在 49 次迭代中的对偶变量为: -142.40447346176117
# agent 76 在 49 次迭代中的对偶变量为: -142.2888772247743
# agent 77 在 49 次迭代中的对偶变量为: -142.14593180197295
# agent 78 在 49 次迭代中的对偶变量为: -142.4325955390909
# agent 79 在 49 次迭代中的对偶变量为: -143.5626437998523
# agent 80 在 49 次迭代中的对偶变量为: -142.02217459092626
# agent 81 在 49 次迭代中的对偶变量为: -143.02028370753484
# agent 82 在 49 次迭代中的对偶变量为: -143.56451591152177
# agent 83 在 49 次迭代中的对偶变量为: -142.65652151566775
# agent 84 在 49 次迭代中的对偶变量为: -142.72502347906715
# agent 85 在 49 次迭代中的对偶变量为: -142.229001778905
# agent 86 在 49 次迭代中的对偶变量为: -143.03392755088345
# agent 87 在 49 次迭代中的对偶变量为: -142.99951079057269
# agent 88 在 49 次迭代中的对偶变量为: -141.84481471801223
# agent 89 在 49 次迭代中的对偶变量为: -142.02520066704744
# agent 90 在 49 次迭代中的对偶变量为: -142.44149811265174
# agent 91 在 49 次迭代中的对偶变量为: -142.2025747726924
# agent 92 在 49 次迭代中的对偶变量为: -143.22417232201127
# agent 93 在 49 次迭代中的对偶变量为: -142.77554511592638
# agent 94 在 49 次迭代中的对偶变量为: -142.79936749374997
# agent 95 在 49 次迭代中的对偶变量为: -142.72504407447127
# agent 96 在 49 次迭代中的对偶变量为: -142.0860009930722
# agent 97 在 49 次迭代中的对偶变量为: -141.6682479822808
# agent 98 在 49 次迭代中的对偶变量为: -142.8809986371248
# agent 99 在 49 次迭代中的对偶变量为: -142.13472778628423
# agent 100 在 49 次迭代中的对偶变量为: -142.49534766259853
# *************************
# 迭代步长为: 0.09680155905721156
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: 50.27642118435287
# agent 2 在 99 次迭代中的资源申请量为: 63.381275478144765
# agent 3 在 99 次迭代中的资源申请量为: 45.47219749249266
# agent 4 在 99 次迭代中的资源申请量为: 66.9898353676536
# agent 5 在 99 次迭代中的资源申请量为: 67.69864473106803
# agent 6 在 99 次迭代中的资源申请量为: 74.58387038739086
# agent 7 在 99 次迭代中的资源申请量为: 41.04087170070107
# agent 8 在 99 次迭代中的资源申请量为: 39.30998320643923
# agent 9 在 99 次迭代中的资源申请量为: 44.85185716589802
# agent 10 在 99 次迭代中的资源申请量为: 58.07173261256667
# agent 11 在 99 次迭代中的资源申请量为: 47.35903653124297
# agent 12 在 99 次迭代中的资源申请量为: 51.38796576966638
# agent 13 在 99 次迭代中的资源申请量为: 68.28471689197275
# agent 14 在 99 次迭代中的资源申请量为: 57.528188516240824
# agent 15 在 99 次迭代中的资源申请量为: 45.21812239967255
# agent 16 在 99 次迭代中的资源申请量为: 45.30352130050048
# agent 17 在 99 次迭代中的资源申请量为: 46.69988175872974
# agent 18 在 99 次迭代中的资源申请量为: 48.36866444791134
# agent 19 在 99 次迭代中的资源申请量为: 43.019978302540885
# agent 20 在 99 次迭代中的资源申请量为: 58.172349823130126
# agent 21 在 99 次迭代中的资源申请量为: 40.401559675300945
# agent 22 在 99 次迭代中的资源申请量为: 40.69260391072094
# agent 23 在 99 次迭代中的资源申请量为: 49.8356349585915
# agent 24 在 99 次迭代中的资源申请量为: 42.08995701002989
# agent 25 在 99 次迭代中的资源申请量为: 46.90874525559399
# agent 26 在 99 次迭代中的资源申请量为: 41.456640649673744
# agent 27 在 99 次迭代中的资源申请量为: 68.18500807221447
# agent 28 在 99 次迭代中的资源申请量为: 53.23201184917077
# agent 29 在 99 次迭代中的资源申请量为: 42.39891833558022
# agent 30 在 99 次迭代中的资源申请量为: 40.9897558400996
# agent 31 在 99 次迭代中的资源申请量为: 62.92989130057528
# agent 32 在 99 次迭代中的资源申请量为: 57.57010579543952
# agent 33 在 99 次迭代中的资源申请量为: 43.03743907408414
# agent 34 在 99 次迭代中的资源申请量为: 54.36434923299458
# agent 35 在 99 次迭代中的资源申请量为: 40.4966851996586
# agent 36 在 99 次迭代中的资源申请量为: 44.52343806327822
# agent 37 在 99 次迭代中的资源申请量为: 54.49415349374181
# agent 38 在 99 次迭代中的资源申请量为: 41.84604146739494
# agent 39 在 99 次迭代中的资源申请量为: 44.94254089063809
# agent 40 在 99 次迭代中的资源申请量为: 52.125596625503924
# agent 41 在 99 次迭代中的资源申请量为: 68.83524842763053
# agent 42 在 99 次迭代中的资源申请量为: 44.12977389684323
# agent 43 在 99 次迭代中的资源申请量为: 53.52172447713006
# agent 44 在 99 次迭代中的资源申请量为: 54.97836246376754
# agent 45 在 99 次迭代中的资源申请量为: 50.037400677317315
# agent 46 在 99 次迭代中的资源申请量为: 58.34496663209223
# agent 47 在 99 次迭代中的资源申请量为: 47.756135991110824
# agent 48 在 99 次迭代中的资源申请量为: 45.12144850004923
# agent 49 在 99 次迭代中的资源申请量为: 44.159388056611284
# agent 50 在 99 次迭代中的资源申请量为: 42.42562098423844
# agent 51 在 99 次迭代中的资源申请量为: 50.231213057159415
# agent 52 在 99 次迭代中的资源申请量为: 57.768579306620616
# agent 53 在 99 次迭代中的资源申请量为: 40.42748357207658
# agent 54 在 99 次迭代中的资源申请量为: 59.305876271785785
# agent 55 在 99 次迭代中的资源申请量为: 73.88665250697244
# agent 56 在 99 次迭代中的资源申请量为: 42.49047128146556
# agent 57 在 99 次迭代中的资源申请量为: 63.1028437940045
# agent 58 在 99 次迭代中的资源申请量为: 43.97821063243224
# agent 59 在 99 次迭代中的资源申请量为: 49.88891561237484
# agent 60 在 99 次迭代中的资源申请量为: 58.27390529138275
# agent 61 在 99 次迭代中的资源申请量为: 68.25873756309794
# agent 62 在 99 次迭代中的资源申请量为: 47.79212925253956
# agent 63 在 99 次迭代中的资源申请量为: 40.58032376407936
# agent 64 在 99 次迭代中的资源申请量为: 46.12495604785105
# agent 65 在 99 次迭代中的资源申请量为: 44.25830888623655
# agent 66 在 99 次迭代中的资源申请量为: 67.8733596742771
# agent 67 在 99 次迭代中的资源申请量为: 44.914817319776006
# agent 68 在 99 次迭代中的资源申请量为: 46.59580172101472
# agent 69 在 99 次迭代中的资源申请量为: 47.09537639318496
# agent 70 在 99 次迭代中的资源申请量为: 62.27865103568423
# agent 71 在 99 次迭代中的资源申请量为: 74.4268215714557
# agent 72 在 99 次迭代中的资源申请量为: 62.56479370533023
# agent 73 在 99 次迭代中的资源申请量为: 45.27244903413893
# agent 74 在 99 次迭代中的资源申请量为: 40.41995021705334
# agent 75 在 99 次迭代中的资源申请量为: 53.906769078315186
# agent 76 在 99 次迭代中的资源申请量为: 48.68231083241861
# agent 77 在 99 次迭代中的资源申请量为: 42.30189961251762
# agent 78 在 99 次迭代中的资源申请量为: 51.44728296360305
# agent 79 在 99 次迭代中的资源申请量为: 44.664060678903006
# agent 80 在 99 次迭代中的资源申请量为: 44.55373844837527
# agent 81 在 99 次迭代中的资源申请量为: 41.031050448230104
# agent 82 在 99 次迭代中的资源申请量为: 47.655486794634854
# agent 83 在 99 次迭代中的资源申请量为: 43.19888497190101
# agent 84 在 99 次迭代中的资源申请量为: 54.08908300255821
# agent 85 在 99 次迭代中的资源申请量为: 57.76200884152708
# agent 86 在 99 次迭代中的资源申请量为: 50.8852126830881
# agent 87 在 99 次迭代中的资源申请量为: 62.84783504264752
# agent 88 在 99 次迭代中的资源申请量为: 67.41987745331423
# agent 89 在 99 次迭代中的资源申请量为: 41.98057135387972
# agent 90 在 99 次迭代中的资源申请量为: 61.48505711845439
# agent 91 在 99 次迭代中的资源申请量为: 44.49007170516948
# agent 92 在 99 次迭代中的资源申请量为: 59.22522341084846
# agent 93 在 99 次迭代中的资源申请量为: 42.32068455410402
# agent 94 在 99 次迭代中的资源申请量为: 76.04946216451685
# agent 95 在 99 次迭代中的资源申请量为: 62.6706399128998
# agent 96 在 99 次迭代中的资源申请量为: 62.686466924839834
# agent 97 在 99 次迭代中的资源申请量为: 74.66188231986659
# agent 98 在 99 次迭代中的资源申请量为: 75.8778546355118
# agent 99 在 99 次迭代中的资源申请量为: 54.34241884209702
# agent 100 在 99 次迭代中的资源申请量为: 50.36053660933408
# 资源申请量总和为: 5229.257259790941
# ****************************************************************************
# 成本总和为: 366755.526621862
# ****************************************************************************
# agent 1 在 99 次迭代中的对偶变量为: -145.72926355305862
# agent 2 在 99 次迭代中的对偶变量为: -145.87506114754743
# agent 3 在 99 次迭代中的对偶变量为: -145.76547147447505
# agent 4 在 99 次迭代中的对偶变量为: -145.61763780883794
# agent 5 在 99 次迭代中的对偶变量为: -145.41701840834966
# agent 6 在 99 次迭代中的对偶变量为: -145.16774077478172
# agent 7 在 99 次迭代中的对偶变量为: -146.07531246266404
# agent 8 在 99 次迭代中的对偶变量为: -146.4399328257569
# agent 9 在 99 次迭代中的对偶变量为: -146.03631436405325
# agent 10 在 99 次迭代中的对偶变量为: -146.04650479267335
# agent 11 在 99 次迭代中的对偶变量为: -146.10891689997752
# agent 12 在 99 次迭代中的对偶变量为: -146.36389730899913
# agent 13 在 99 次迭代中的对偶变量为: -145.60637716234007
# agent 14 在 99 次迭代中的对偶变量为: -146.19329014222615
# agent 15 在 99 次迭代中的对偶变量为: -145.92161615888668
# agent 16 在 99 次迭代中的对偶变量为: -145.53197242170162
# agent 17 在 99 次迭代中的对偶变量为: -145.91962162793516
# agent 18 在 99 次迭代中的对偶变量为: -146.13972623331628
# agent 19 在 99 次迭代中的对偶变量为: -146.23192188914717
# agent 20 在 99 次迭代中的对偶变量为: -146.56810954013832
# agent 21 在 99 次迭代中的对偶变量为: -146.30592676614359
# agent 22 在 99 次迭代中的对偶变量为: -146.27189486073956
# agent 23 在 99 次迭代中的对偶变量为: -146.20690487577448
# agent 24 在 99 次迭代中的对偶变量为: -145.7638452361076
# agent 25 在 99 次迭代中的对偶变量为: -145.6279848179008
# agent 26 在 99 次迭代中的对偶变量为: -146.5152344687602
# agent 27 在 99 次迭代中的对偶变量为: -146.04701775887185
# agent 28 在 99 次迭代中的对偶变量为: -145.40963317767816
# agent 29 在 99 次迭代中的对偶变量为: -145.7961060080888
# agent 30 在 99 次迭代中的对偶变量为: -147.02107219237845
# agent 31 在 99 次迭代中的对偶变量为: -146.23173912138066
# agent 32 在 99 次迭代中的对偶变量为: -145.52227506814276
# agent 33 在 99 次迭代中的对偶变量为: -145.21478066670292
# agent 34 在 99 次迭代中的对偶变量为: -146.0601778523848
# agent 35 在 99 次迭代中的对偶变量为: -146.28740375870268
# agent 36 在 99 次迭代中的对偶变量为: -145.93968941514595
# agent 37 在 99 次迭代中的对偶变量为: -145.58362978247706
# agent 38 在 99 次迭代中的对偶变量为: -145.6057492826218
# agent 39 在 99 次迭代中的对偶变量为: -145.66463902816952
# agent 40 在 99 次迭代中的对偶变量为: -146.17678987651178
# agent 41 在 99 次迭代中的对偶变量为: -145.9375465407872
# agent 42 在 99 次迭代中的对偶变量为: -145.621231249267
# agent 43 在 99 次迭代中的对偶变量为: -145.10082853596415
# agent 44 在 99 次迭代中的对偶变量为: -145.8194148985491
# agent 45 在 99 次迭代中的对偶变量为: -145.61220203195194
# agent 46 在 99 次迭代中的对偶变量为: -146.7569132434398
# agent 47 在 99 次迭代中的对偶变量为: -146.09963517155464
# agent 48 在 99 次迭代中的对偶变量为: -145.9329249001674
# agent 49 在 99 次迭代中的对偶变量为: -145.04191939247838
# agent 50 在 99 次迭代中的对偶变量为: -145.5322355432584
# agent 51 在 99 次迭代中的对偶变量为: -145.89363917147824
# agent 52 在 99 次迭代中的对偶变量为: -145.5183061972136
# agent 53 在 99 次迭代中的对偶变量为: -145.64443757389103
# agent 54 在 99 次迭代中的对偶变量为: -146.39527830664304
# agent 55 在 99 次迭代中的对偶变量为: -145.97330501394487
# agent 56 在 99 次迭代中的对偶变量为: -145.76569661327602
# agent 57 在 99 次迭代中的对偶变量为: -146.6468251056108
# agent 58 在 99 次迭代中的对偶变量为: -146.1259161502696
# agent 59 在 99 次迭代中的对偶变量为: -146.06674683712453
# agent 60 在 99 次迭代中的对偶变量为: -146.05215375759516
# agent 61 在 99 次迭代中的对偶变量为: -145.32922263881548
# agent 62 在 99 次迭代中的对偶变量为: -145.5748136081266
# agent 63 在 99 次迭代中的对偶变量为: -146.22523030350158
# agent 64 在 99 次迭代中的对偶变量为: -145.6798593531234
# agent 65 在 99 次迭代中的对偶变量为: -145.37825021320427
# agent 66 在 99 次迭代中的对偶变量为: -145.14139128340963
# agent 67 在 99 次迭代中的对偶变量为: -145.57037888723843
# agent 68 在 99 次迭代中的对偶变量为: -145.58656550724712
# agent 69 在 99 次迭代中的对偶变量为: -145.58520445819187
# agent 70 在 99 次迭代中的对偶变量为: -145.62876248564214
# agent 71 在 99 次迭代中的对偶变量为: -145.0536431429114
# agent 72 在 99 次迭代中的对偶变量为: -145.83550489279256
# agent 73 在 99 次迭代中的对偶变量为: -145.42632671607237
# agent 74 在 99 次迭代中的对偶变量为: -145.6158108248027
# agent 75 在 99 次迭代中的对偶变量为: -145.61895341928252
# agent 76 在 99 次迭代中的对偶变量为: -145.54339466373955
# agent 77 在 99 次迭代中的对偶变量为: -145.44683860506345
# agent 78 在 99 次迭代中的对偶变量为: -145.64184889080917
# agent 79 在 99 次迭代中的对偶变量为: -146.41780630827023
# agent 80 在 99 次迭代中的对偶变量为: -145.3627107244759
# agent 81 在 99 次迭代中的对偶变量为: -146.0379917032744
# agent 82 在 99 次迭代中的对偶变量为: -146.41755774283152
# agent 83 在 99 次迭代中的对偶变量为: -145.79598589884364
# agent 84 在 99 次迭代中的对偶变量为: -145.849432407163
# agent 85 在 99 次迭代中的对偶变量为: -145.5012229879704
# agent 86 在 99 次迭代中的对偶变量为: -146.0556380492643
# agent 87 在 99 次迭代中的对偶变量为: -146.03480410235403
# agent 88 在 99 次迭代中的对偶变量为: -145.2437303972913
# agent 89 在 99 次迭代中的对偶变量为: -145.370056873967
# agent 90 在 99 次迭代中的对偶变量为: -145.64413708429055
# agent 91 在 99 次迭代中的对偶变量为: -145.4862437975762
# agent 92 在 99 次迭代中的对偶变量为: -146.185580868206
# agent 93 在 99 次迭代中的对偶变量为: -145.8744643947745
# agent 94 在 99 次迭代中的对偶变量为: -145.89892432903372
# agent 95 在 99 次迭代中的对偶变量为: -145.84953579095952
# agent 96 在 99 次迭代中的对偶变量为: -145.4075206196156
# agent 97 在 99 次迭代中的对偶变量为: -145.1237646397332
# agent 98 在 99 次迭代中的对偶变量为: -145.95570927102358
# agent 99 在 99 次迭代中的对偶变量为: -145.43877275787165
# agent 100 在 99 次迭代中的对偶变量为: -145.68160982800225
# *************************
# 迭代步长为: 0.06347736393621072
# ****************************************************************************
# 149 次迭代中的结果：
# agent 1 在 149 次迭代中的资源申请量为: 50.64546103007934
# agent 2 在 149 次迭代中的资源申请量为: 63.83967491955006
# agent 3 在 149 次迭代中的资源申请量为: 45.79657791531861
# agent 4 在 149 次迭代中的资源申请量为: 67.5033683715054
# agent 5 在 149 次迭代中的资源申请量为: 68.22962917189803
# agent 6 在 149 次迭代中的资源申请量为: 75.19630717598673
# agent 7 在 149 次迭代中的资源申请量为: 41.319927849899535
# agent 8 在 149 次迭代中的资源申请量为: 39.56123000195626
# agent 9 在 149 次迭代中的资源申请量为: 45.16674372208239
# agent 10 在 149 次迭代中的资源申请量为: 58.482102472003895
# agent 11 在 149 次迭代中的资源申请量为: 47.68783348741613
# agent 12 在 149 次迭代中的资源申请量为: 51.73064865759142
# agent 13 在 149 次迭代中的资源申请量为: 68.8042953508647
# agent 14 在 149 次迭代中的资源申请量为: 57.92376963537218
# agent 15 在 149 次迭代中的资源申请量为: 45.53339564899498
# agent 16 在 149 次迭代中的资源申请量为: 45.63897520107988
# agent 17 在 149 次迭代中的资源申请量为: 47.035234928207345
# agent 18 在 149 次迭代中的资源申请量为: 48.693497468939896
# agent 19 在 149 次迭代中的资源申请量为: 43.306318419635375
# agent 20 在 149 次迭代中的资源申请量为: 58.55315370611931
# agent 21 在 149 次迭代中的资源申请量为: 40.67188394992691
# agent 22 在 149 次迭代中的资源申请量为: 40.961718008710314
# agent 23 在 149 次迭代中的资源申请量为: 50.17166274193917
# agent 24 在 149 次迭代中的资源申请量为: 42.39348137314369
# agent 25 在 149 次迭代中的资源申请量为: 47.2614110076667
# agent 26 在 149 次迭代中的资源申请量为: 41.71218768876882
# agent 27 在 149 次迭代中的资源申请量为: 68.66763271085749
# agent 28 在 149 次迭代中的资源申请量为: 53.652199143314675
# agent 29 在 149 次迭代中的资源申请量为: 42.702955861948816
# agent 30 在 149 次迭代中的资源申请量为: 41.22528038234679
# agent 31 在 149 次迭代中的资源申请量为: 63.35754678317359
# agent 32 在 149 次迭代中的资源申请量为: 58.01038605064266
# agent 33 在 149 次迭代中的资源申请量为: 43.374288427611894
# agent 34 在 149 次迭代中的资源申请量为: 54.74354738259291
# agent 35 在 149 次迭代中的资源申请量为: 40.76967062488073
# agent 36 在 149 次迭代中的资源申请量为: 44.84359107576028
# agent 37 在 149 次迭代中的资源申请量为: 54.89994671125313
# agent 38 在 149 次迭代中的资源申请量为: 42.160237069657434
# agent 39 在 149 次迭代中的资源申请量为: 45.27131971014914
# agent 40 在 149 次迭代中的资源申请量为: 52.47350960172319
# agent 41 在 149 次迭代中的资源申请量为: 69.33277272911499
# agent 42 在 149 次迭代中的资源申请量为: 44.46305539664032
# agent 43 在 149 次迭代中的资源申请量为: 53.960286061765046
# agent 44 在 149 次迭代中的资源申请量为: 55.364707626855854
# agent 45 在 149 次迭代中的资源申请量为: 50.41318809439753
# agent 46 在 149 次迭代中的资源申请量为: 58.71101450340927
# agent 47 在 149 次迭代中的资源申请量为: 48.08612938818199
# agent 48 在 149 次迭代中的资源申请量为: 45.44160779634213
# agent 49 在 149 次迭代中的资源申请量为: 44.52501567600005
# agent 50 在 149 次迭代中的资源申请量为: 42.74362465506263
# agent 51 在 149 次迭代中的资源申请量为: 50.598004122473974
# agent 52 在 149 次迭代中的资源申请量为: 58.21084905771884
# agent 53 在 149 次迭代中的资源申请量为: 40.72484814086078
# agent 54 在 149 次迭代中的资源申请量为: 59.68698664122696
# agent 55 在 149 次迭代中的资源申请量为: 74.4256945056102
# agent 56 在 149 次迭代中的资源申请量为: 42.79501943514165
# agent 57 在 149 次迭代中的资源申请量为: 63.50650781998439
# agent 58 在 149 次迭代中的资源申请量为: 44.287289689464735
# agent 59 在 149 次迭代中的资源申请量为: 50.24197278066884
# agent 60 在 149 次迭代中的资源申请量为: 58.68175939984702
# agent 61 在 149 次迭代中的资源申请量为: 68.79981126857682
# agent 62 在 149 次迭代中的资源申请量为: 48.146897461123906
# agent 63 在 149 次迭代中的资源申请量为: 40.85070474165273
# agent 64 在 149 次迭代中的资源申请量为: 46.474640559052006
# agent 65 在 149 次迭代中的资源申请量为: 44.603217057853946
# agent 66 在 149 次迭代中的资源申请量为: 68.43190112747045
# agent 67 在 149 次迭代中的资源申请量为: 45.24864457886355
# agent 68 在 149 次迭代中的资源申请量为: 46.95024998967416
# agent 69 在 149 次迭代中的资源申请量为: 47.44875660990166
# agent 70 在 149 次迭代中的资源申请量为: 62.7501468556117
# agent 71 在 149 次迭代中的资源申请量为: 75.05108246737892
# agent 72 在 149 次迭代中的资源申请量为: 63.027721230761344
# agent 73 在 149 次迭代中的资源申请量为: 45.616448324951186
# agent 74 在 149 次迭代中的资源申请量为: 40.715841134244606
# agent 75 在 149 次迭代中的资源申请量为: 54.308106925159095
# agent 76 在 149 次迭代中的资源申请量为: 49.039351655628586
# agent 77 在 149 次迭代中的资源申请量为: 42.6248780698158
# agent 78 在 149 次迭代中的资源申请量为: 51.82242632289327
# agent 79 在 149 次迭代中的资源申请量为: 44.956689979689024
# agent 80 在 149 次迭代中的资源申请量为: 44.900096433107834
# agent 81 在 149 次迭代中的资源申请量为: 41.30559685291368
# agent 82 在 149 次迭代中的资源申请量为: 47.96554525821753
# agent 83 在 149 次迭代中的资源申请量为: 43.50454977453743
# agent 84 在 149 次迭代中的资源申请量为: 54.48372457450573
# agent 85 在 149 次迭代中的资源申请量为: 58.204022208691846
# agent 86 在 149 次迭代中的资源申请量为: 51.238409750746335
# agent 87 在 149 次迭代中的资源申请量为: 63.29289483393853
# agent 88 在 149 次迭代中的资源申请量为: 67.96825001452098
# agent 89 在 149 次迭代中的资源申请量为: 42.31093630429996
# agent 90 在 149 次迭代中的资源申请量为: 61.951042448825945
# agent 91 在 149 次迭代中的资源申请量为: 44.83010352111156
# agent 92 在 149 次迭代中的资源申请量为: 59.62323151354373
# agent 93 在 149 次迭代中的资源申请量为: 42.62056818248896
# agent 94 在 149 次迭代中的资源申请量为: 76.59585995330741
# agent 95 在 149 次迭代中的资源申请量为: 63.13085926644681
# agent 96 在 149 次迭代中的资源申请量为: 63.175491936412264
# agent 97 在 149 次迭代中的资源申请量为: 75.2761449187275
# agent 98 在 149 次迭代中的资源申请量为: 76.4206766582051
# agent 99 在 149 次迭代中的资源申请量为: 54.7575241929267
# agent 100 在 149 次迭代中的资源申请量为: 50.731667832722316
# 资源申请量总和为: 5267.327647751838
# ****************************************************************************
# 成本总和为: 372326.50117269123
# ****************************************************************************
# agent 1 在 149 次迭代中的对偶变量为: -146.83638309023803
# agent 2 在 149 次迭代中的对偶变量为: -146.97521980692014
# agent 3 在 149 次迭代中的对偶变量为: -146.86836491208325
# agent 4 在 149 次迭代中的对偶变量为: -146.7474104173119
# agent 5 在 149 次迭代中的对偶变量为: -146.58518417817567
# agent 6 在 149 次迭代中的对偶变量为: -146.39261435197346
# agent 7 在 149 次迭代中的对偶变量为: -147.13572582961822
# agent 8 在 149 次迭代中的对偶变量为: -147.44492000782503
# agent 9 在 149 次迭代中的对偶变量为: -147.1069286550801
# agent 10 在 149 次迭代中的对偶变量为: -147.11346642721014
# agent 11 在 149 次迭代中的对偶变量为: -147.16106715973163
# agent 12 在 149 次迭代中的对偶变量为: -147.39194597277427
# agent 13 在 149 次迭代中的对偶变量为: -146.74944977190236
# agent 14 在 149 次迭代中的对偶变量为: -147.22180105196767
# agent 15 在 149 次迭代中的对偶变量为: -146.99354520658295
# agent 16 在 149 次迭代中的对偶变量为: -146.67251568367158
# agent 17 在 149 次迭代中的对偶变量为: -146.9927517702635
# agent 18 在 149 次迭代中的对偶变量为: -147.1791919006077
# agent 19 在 149 次迭代中的对偶变量为: -147.26274631068736
# agent 20 在 149 次迭代中的对偶变量为: -147.5581996359102
# agent 21 在 149 次迭代中的对偶变量为: -147.33315900972224
# agent 22 在 149 次迭代中的对偶变量为: -147.2945284330992
# agent 23 在 149 次迭代中的对偶变量为: -147.2149882258175
# agent 24 在 149 次迭代中的对偶变量为: -146.85653294331732
# agent 25 在 149 次迭代中的对偶变量为: -146.75651522453347
# agent 26 在 149 次迭代中的对偶变量为: -147.4863132173215
# agent 27 在 149 次迭代中的对偶变量为: -147.1087919638865
# agent 28 在 149 次迭代中的对偶变量为: -146.5861576012811
# agent 29 在 149 次迭代中的对偶变量为: -146.89064110301572
# agent 30 在 149 次迭代中的对偶变量为: -147.9160654529178
# agent 31 在 149 次迭代中的对偶变量为: -147.2581122796166
# agent 32 在 149 次迭代中的对偶变量为: -146.66700373167092
# agent 33 在 149 次迭代中的对偶变量为: -146.4274383394028
# agent 34 在 149 次迭代中的对偶变量为: -147.12193267126014
# agent 35 在 149 次迭代中的对偶变量为: -147.32474837454677
# agent 36 在 149 次迭代中的对偶变量为: -147.02820965758494
# agent 37 在 149 次迭代中的对偶变量为: -146.71985079150875
# agent 38 在 149 次迭代中的对偶变量为: -146.73685345076677
# agent 39 在 149 次迭代中的对偶变量为: -146.7824870145071
# agent 40 在 149 次迭代中的对偶变量为: -147.22052880516958
# agent 41 在 149 次迭代中的对偶变量为: -147.032100004053
# agent 42 在 149 次迭代中的对偶变量为: -146.7543883485771
# agent 43 在 149 次迭代中的对偶变量为: -146.32880097294213
# agent 44 在 149 次迭代中的对偶变量为: -146.90118135519637
# agent 45 在 149 次迭代中的对偶变量为: -146.7395642831926
# agent 46 在 149 次迭代中的对偶变量为: -147.7086377088641
# agent 47 在 149 次迭代中的对偶变量为: -147.15561404218238
# agent 48 在 149 次迭代中的对偶变量为: -147.02146650756325
# agent 49 在 149 次迭代中的对偶变量为: -146.2850532984002
# agent 50 在 149 次迭代中的对偶变量为: -146.67704875822548
# agent 51 在 149 次迭代中的对偶变量为: -146.9940123674219
# agent 52 在 149 次迭代中的对偶变量为: -146.66820755006898
# agent 53 在 149 次迭代中的对偶变量为: -146.77442293527096
# agent 54 在 149 次迭代中的对偶变量为: -147.38616526719008
# agent 55 在 149 次迭代中的对偶变量为: -147.05138901122038
# agent 56 在 149 次迭代中的对偶变量为: -146.86206996650995
# agent 57 在 149 次迭代中的对偶变量为: -147.61561876796253
# agent 58 在 149 次迭代中的对偶变量为: -147.1767849441801
# agent 59 在 149 次迭代中的对偶变量为: -147.1259183420065
# agent 60 在 149 次迭代中的对偶变量为: -147.11257443960224
# agent 61 在 149 次迭代中的对偶变量为: -146.519584790869
# agent 62 在 149 次迭代中的对偶变量为: -146.71007187559653
# agent 63 在 149 次迭代中的对偶变量为: -147.25267801828036
# agent 64 在 149 次迭代中的对偶变量为: -146.79884978896644
# agent 65 在 149 次迭代中的对偶变量为: -146.55093799670342
# agent 66 在 149 次迭代中的对偶变量为: -146.370182480435
# agent 67 在 149 次迭代中的对偶变量为: -146.70539156813606
# agent 68 在 149 次迭代中的对偶变量为: -146.72079996695732
# agent 69 在 149 次迭代中的对偶变量为: -146.7160211516853
# agent 70 在 149 次迭代中的对偶变量为: -146.76035245346807
# agent 71 在 149 次迭代中的对偶变量为: -146.30216493475783
# agent 72 在 149 次迭代中的对偶变量为: -146.94653095382722
# agent 73 在 149 次迭代中的对偶变量为: -146.59592430483403
# agent 74 在 149 次迭代中的对偶变量为: -146.7401963101295
# agent 75 在 149 次迭代中的对偶变量为: -146.74269939044547
# agent 76 在 149 次迭代中的对偶变量为: -146.68592529801148
# agent 77 在 149 次迭代中的对偶变量为: -146.60956105133687
# agent 78 在 149 次迭代中的对偶变量为: -146.76727896867982
# agent 79 在 149 次迭代中的对偶变量为: -147.4127459309427
# agent 80 在 149 次迭代中的对偶变量为: -146.54032787256662
# agent 81 在 149 次迭代中的对偶变量为: -147.08126804107198
# agent 82 在 149 次迭代中的对偶变量为: -147.4097448262961
# agent 83 在 149 次迭代中的对偶变量为: -146.89637918833475
# agent 84 在 149 次迭代中的对偶变量为: -146.95442880861603
# agent 85 在 149 次迭代中的对偶变量为: -146.6504577425988
# agent 86 在 149 次迭代中的对偶变量为: -147.115229252239
# agent 87 在 149 次迭代中的对偶变量为: -147.10294760145246
# agent 88 在 149 次迭代中的对偶变量为: -146.45015003194615
# agent 89 在 149 次迭代中的对偶变量为: -146.55937069547986
# agent 90 在 149 次迭代中的对偶变量为: -146.76250187718227
# agent 91 在 149 次迭代中的对偶变量为: -146.6423519717793
# agent 92 在 149 次迭代中的对偶变量为: -147.2204019352137
# agent 93 在 149 次迭代中的对偶变量为: -146.95404545696027
# agent 94 在 149 次迭代中的对偶变量为: -146.99171990661483
# agent 95 在 149 次迭代中的对偶变量为: -146.95406223947234
# agent 96 在 149 次迭代中的对偶变量为: -146.58118064738943
# agent 97 在 149 次迭代中的对偶变量为: -146.352289837455
# agent 98 在 149 次迭代中的对偶变量为: -147.04135331641018
# agent 99 在 149 次迭代中的对偶变量为: -146.60106774019476
# agent 100 在 149 次迭代中的对偶变量为: -146.79500349816695
# *************************
# 迭代步长为: 0.04966932281851884
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: 50.87289851414304
# agent 2 在 199 次迭代中的资源申请量为: 64.12126189363785
# agent 3 在 199 次迭代中的资源申请量为: 45.9964371870011
# agent 4 在 199 次迭代中的资源申请量为: 67.81956359772389
# agent 5 在 199 次迭代中的资源申请量为: 68.55614805840992
# agent 6 在 199 次迭代中的资源申请量为: 75.5717208098059
# agent 7 在 199 次迭代中的资源申请量为: 41.49164625941292
# agent 8 在 199 次迭代中的资源申请量为: 39.715749725896394
# agent 9 在 199 次迭代中的资源申请量为: 45.360349026184466
# agent 10 在 199 次迭代中的资源申请量为: 58.73450722612924
# agent 11 在 199 次迭代中的资源申请量为: 47.89028896082014
# agent 12 在 199 次迭代中的资源申请量为: 51.94091251267181
# agent 13 在 199 次迭代中的资源申请量为: 69.12345746446452
# agent 14 在 199 次迭代中的资源申请量为: 58.167891899622695
# agent 15 在 199 次迭代中的资源申请量为: 45.72791227025518
# agent 16 在 199 次迭代中的资源申请量为: 45.84562464621759
# agent 17 在 199 次迭代中的资源申请量为: 47.242107578583905
# agent 18 在 199 次迭代中的资源申请量为: 48.89385298107674
# agent 19 在 199 次迭代中的资源申请量为: 43.48269916218336
# agent 20 在 199 次迭代中的资源申请量为: 58.787078135747564
# agent 21 在 199 次迭代中的资源申请量为: 40.838104796212484
# agent 22 在 199 次迭代中的资源申请量为: 41.12756636514474
# agent 23 在 199 次迭代中的资源申请量为: 50.37989358045579
# agent 24 在 199 次迭代中的资源申请量为: 42.58089394026519
# agent 25 在 199 次迭代中的资源申请量为: 47.47852111119017
# agent 26 在 199 次迭代中的资源申请量为: 41.870164645349455
# agent 27 在 199 次迭代中的资源申请量为: 68.96480858746096
# agent 28 在 199 次迭代中的资源申请量为: 53.910207139649316
# agent 29 在 199 次迭代中的资源申请量为: 42.89042560355555
# agent 30 在 199 次迭代中的资源申请量为: 41.37080114725065
# agent 31 在 199 次迭代中的资源申请量为: 63.62124424073963
# agent 32 在 199 次迭代中的资源申请量为: 58.281446683177094
# agent 33 在 199 次迭代中的资源申请量为: 43.58092121455712
# agent 34 在 199 次迭代中的资源申请量为: 54.97693569428918
# agent 35 在 199 次迭代中的资源申请量为: 40.937262021597824
# agent 36 在 199 次迭代中的资源申请量为: 45.04032370325128
# agent 37 在 199 次迭代中的资源申请量为: 55.14973969072018
# agent 38 在 199 次迭代中的资源申请量为: 42.35369739101808
# agent 39 在 199 次迭代中的资源申请量为: 45.47392702634435
# agent 40 在 199 次迭代中的资源申请量为: 52.687631078034265
# agent 41 在 199 次迭代中的资源申请量为: 69.63814241658544
# agent 42 在 199 次迭代中的资源申请量为: 44.668088529900295
# agent 43 在 199 次迭代中的资源申请量为: 54.22947662548724
# agent 44 在 199 次迭代中的资源申请量为: 55.60338653827924
# agent 45 在 199 次迭代中的资源申请量为: 50.64470285132675
# agent 46 在 199 次迭代中的资源申请量为: 58.93633025629915
# agent 47 在 199 次迭代中的资源申请量为: 48.2892094724255
# agent 48 在 199 次迭代中的资源申请量为: 45.63838517523948
# agent 49 在 199 次迭代中的资源申请量为: 44.74920779373325
# agent 50 在 199 次迭代中的资源申请量为: 42.939355660635734
# agent 51 在 199 次迭代中的资源申请量为: 50.823194299100834
# agent 52 在 199 次迭代中的资源申请量为: 58.4829058672755
# agent 53 在 199 次迭代中的资源申请量为: 40.90777014588979
# agent 54 在 199 次迭代中的资源申请量为: 59.9225130147354
# agent 55 在 199 次迭代中的资源申请量为: 74.75727261092435
# agent 56 在 199 次迭代中的资源申请量为: 42.98291033668775
# agent 57 在 199 次迭代中的资源申请量为: 63.7549890426353
# agent 58 在 199 次迭代中的资源申请量为: 44.47753828194535
# agent 59 在 199 次迭代中的资源申请量为: 50.45935367021671
# agent 60 在 199 次迭代中的资源申请量为: 58.932929805679045
# agent 61 在 199 次迭代中的资源申请量为: 69.13199389239388
# agent 62 在 199 次迭代中的资源申请量为: 48.36537812993073
# agent 63 在 199 次迭代中的资源申请量为: 41.017428457736884
# agent 64 在 199 次迭代中的资源申请量为: 46.68998871539779
# agent 65 在 199 次迭代中的资源申请量为: 44.81536174181185
# agent 66 在 199 次迭代中的资源申请量为: 68.77428329118611
# agent 67 在 199 次迭代中的资源申请量为: 45.45428565590397
# agent 68 在 199 次迭代中的资源申请量为: 47.16851432940043
# agent 69 在 199 次迭代中的资源申请量为: 47.66651199943792
# agent 70 在 199 次迭代中的资源申请量为: 63.04025457260218
# agent 71 在 199 次迭代中的资源申请量为: 75.43338061367872
# agent 72 在 199 次迭代中的资源申请量为: 63.31184015551402
# agent 73 在 199 次迭代中的资源申请量为: 45.82784715504463
# agent 74 在 199 次迭代中的资源申请量为: 40.89821684087348
# agent 75 在 199 次迭代中的资源申请量为: 54.555505191623055
# agent 76 在 199 次迭代中的资源申请量为: 49.259128543443694
# agent 77 在 199 次迭代中的资源申请量为: 42.82349955992701
# agent 78 在 199 次迭代中的资源申请量为: 52.053420718784714
# agent 79 在 199 次迭代中的资源申请量为: 45.137224733269825
# agent 80 在 199 次迭代中的资源申请量为: 45.11302465477802
# agent 81 在 199 次迭代中的资源申请量为: 41.47537230264613
# agent 82 在 199 次迭代中的资源申请量为: 48.156957942429436
# agent 83 在 199 次迭代中的资源申请量为: 43.69279375007277
# agent 84 在 199 次迭代中的资源申请量为: 54.726123471073855
# agent 85 在 199 次迭代中的资源申请量为: 58.476114326386096
# agent 86 在 199 次迭代中的资源申请量为: 51.45593875954851
# agent 87 在 199 次迭代中的资源申请量为: 63.56669181127195
# agent 88 在 199 次迭代中的资源申请量为: 68.30477539156524
# agent 89 在 199 次迭代中的资源申请量为: 42.51355296309691
# agent 90 在 199 次迭代中的资源申请量为: 62.23836951367935
# agent 91 在 199 次迭代中的资源申请量为: 45.039221021267984
# agent 92 在 199 次迭代中的资源申请量为: 59.86858312264174
# agent 93 在 199 次迭代中的资源申请量为: 42.80557482726627
# agent 94 在 199 次迭代中的资源申请量为: 76.93176531338294
# agent 95 在 199 次迭代中的资源申请量为: 63.41355816251241
# agent 96 在 199 次迭代中的资源申请量为: 63.47595772124044
# agent 97 在 199 次迭代中的资源申请量为: 75.65289520440862
# agent 98 在 199 次迭代中的资源申请量为: 76.75426563082723
# agent 99 在 199 次迭代中的资源申请量为: 55.012876664805454
# agent 100 在 199 次迭代中的资源申请量为: 50.96046770045405
# 资源申请量总和为: 5290.753230518571
# ****************************************************************************
# 成本总和为: 375775.41307320754
# ****************************************************************************
# agent 1 在 199 次迭代中的对偶变量为: -147.51869554242913
# agent 2 在 199 次迭代中的对偶变量为: -147.65102854473082
# agent 3 在 199 次迭代中的对偶变量为: -147.54788643580372
# agent 4 在 199 次迭代中的对偶变量为: -147.44303991499257
# agent 5 在 199 次迭代中的对偶变量为: -147.30352572850182
# agent 6 在 199 次迭代中的对偶变量为: -147.1434416196118
# agent 7 在 199 次迭代中的对偶变量为: -147.78825578576908
# agent 8 在 199 次迭代中的对偶变量为: -148.06299890358557
# agent 9 在 199 次迭代中的对偶变量为: -147.76518668902716
# agent 10 在 199 次迭代中的对偶变量为: -147.76971878793603
# agent 11 在 199 次迭代中的对偶变量为: -147.80892467462448
# agent 12 在 199 次迭代中的对偶变量为: -148.0227375380154
# agent 13 在 199 次迭代中的对偶变量为: -147.45160642182196
# agent 14 在 199 次迭代中的对偶变量为: -147.85651893901903
# agent 15 在 199 次迭代中的对偶变量为: -147.65490171886762
# agent 16 在 199 次迭代中的对偶变量为: -147.3751237971398
# agent 17 在 199 次迭代中的对偶变量为: -147.6547442514685
# agent 18 在 199 次迭代中的对偶变量为: -147.8203295394456
# agent 19 在 199 次迭代中的对偶变量为: -147.8977169838601
# agent 20 在 199 次迭代中的对偶变量为: -148.16640315294367
# agent 21 在 199 次迭代中的对偶变量为: -147.96479822560744
# agent 22 在 199 次迭代中的对偶变量为: -147.92475218755
# agent 23 在 199 次迭代中的对偶变量为: -147.83968074136737
# agent 24 在 199 次迭代中的对偶变量为: -147.5312181849547
# agent 25 在 199 次迭代中的对偶变量为: -147.45126755580856
# agent 26 在 199 次迭代中的对偶变量为: -148.0866256523279
# agent 27 在 199 次迭代中的对偶变量为: -147.76257889241413
# agent 28 在 199 次迭代中的对偶变量为: -147.3085799910181
# agent 29 在 199 次迭代中的对偶变量为: -147.56553217279998
# agent 30 在 199 次迭代中的对偶变量为: -148.46904435955247
# agent 31 在 199 次迭代中的对偶变量为: -147.8909861777751
# agent 32 在 199 次迭代中的对偶变量为: -147.37176137626045
# agent 33 在 199 次迭代中的对偶变量为: -147.17131637240564
# agent 34 在 199 次迭代中的对偶变量为: -147.7754199440097
# agent 35 在 199 次迭代中的对偶变量为: -147.96159568207173
# agent 36 在 199 次迭代中的对偶变量为: -147.69710059105435
# agent 37 在 199 次迭代中的对偶变量为: -147.4192711340165
# agent 38 在 199 次迭代中的对偶变量为: -147.4333106076651
# agent 39 在 199 次迭代中的对偶变量为: -147.4713518895708
# agent 40 在 199 次迭代中的对偶变量为: -147.8628932341028
# agent 41 在 199 次迭代中的对偶变量为: -147.70391331648798
# agent 42 在 199 次迭代中的对偶变量为: -147.451501001661
# agent 43 在 199 次迭代中的对偶变量为: -147.08253455136426
# agent 44 在 199 次迭代中的对偶变量为: -147.56948230718186
# agent 45 在 199 次迭代中的对偶变量为: -147.43410855398025
# agent 46 在 199 次迭代中的对偶变量为: -148.2944586663778
# agent 47 在 199 次迭代中的对偶变量为: -147.8054703117616
# agent 48 在 199 次迭代中的对偶变量为: -147.69050959581423
# agent 49 在 199 次迭代中的对偶变量为: -147.04730649869305
# agent 50 在 199 次迭代中的对偶变量为: -147.38168037828865
# agent 51 在 199 次迭代中的对偶变量为: -147.6695828973025
# agent 52 在 199 次迭代中的对偶变量为: -147.3755552549163
# agent 53 在 199 次迭代中的对偶变量为: -147.46952655438122
# agent 54 在 199 次迭代中的对偶变量为: -147.99853383831203
# agent 55 在 199 次迭代中的对偶变量为: -147.71454522184868
# agent 56 在 199 次迭代中的对偶变量为: -147.53847721207592
# agent 57 在 199 次迭代中的对偶变量为: -148.2119737023247
# agent 58 在 199 次迭代中的对偶变量为: -147.82363015861418
# agent 59 在 199 次迭代中的对偶变量为: -147.77806101065013
# agent 60 在 199 次迭代中的对偶变量为: -147.7656174947655
# agent 61 在 199 次迭代中的对偶变量为: -147.25038656326655
# agent 62 在 199 次迭代中的对偶变量为: -147.40921001577834
# agent 63 在 199 次迭代中的对偶变量为: -147.88622813940017
# agent 64 在 199 次迭代中的对偶变量为: -147.48796388927295
# agent 65 在 199 次迭代中的对偶变量为: -147.27222992216028
# agent 66 在 199 次迭代中的对偶变量为: -147.12342324060944
# agent 67 在 199 次迭代中的对偶变量为: -147.40457123007351
# agent 68 在 199 次迭代中的对偶变量为: -147.41924585408137
# agent 69 在 199 次迭代中的对偶变量为: -147.41283839820136
# agent 70 在 199 次迭代中的对偶变量为: -147.45661097424522
# agent 71 在 199 次迭代中的对偶变量为: -147.06676122735743
# agent 72 在 199 次迭代中的对偶变量为: -147.62841637323365
# agent 73 在 199 次迭代中的对偶变量为: -147.31468032715173
# agent 74 在 199 次迭代中的对偶变量为: -147.43322399531922
# agent 75 在 199 次迭代中的对偶变量为: -147.43541453654456
# agent 76 在 199 次迭代中的对偶变量为: -147.38921133901982
# agent 77 在 199 次迭代中的对偶变量为: -147.32459841573723
# agent 78 在 199 次迭代中的对偶变量为: -147.46026215635416
# agent 79 在 199 次迭代中的对偶变量为: -148.0265640931174
# agent 80 在 199 次迭代中的对偶变量为: -147.26428382624528
# agent 81 在 199 次迭代中的对偶变量为: -147.72641475005528
# agent 82 在 199 次迭代中的对偶变量为: -148.0222654157742
# agent 83 在 199 次迭代中的对偶变量为: -147.57405750026197
# agent 84 在 199 次迭代中的对偶变量为: -147.6331457190068
# agent 85 在 199 次迭代中的对偶变量为: -147.35789724860385
# agent 86 在 199 次迭代中的对偶变量为: -147.76781627864554
# agent 87 在 199 次迭代中的对偶变量为: -147.76006034705267
# agent 88 在 199 次迭代中的对偶变量为: -147.19050586144354
# agent 89 在 199 次迭代中的对偶变量为: -147.2887906671489
# agent 90 在 199 次迭代中的对偶变量为: -147.45208683283045
# agent 91 在 199 次迭代中的对偶变量为: -147.35335147231115
# agent 92 在 199 次迭代中的对偶变量为: -147.85831611886852
# agent 93 在 199 次迭代中的对偶变量为: -147.62006937815858
# agent 94 在 199 次迭代中的对偶变量为: -147.6635306267659
# agent 95 在 199 次迭代中的对偶变量为: -147.63253959002978
# agent 96 在 199 次迭代中的对偶变量为: -147.30229853097705
# agent 97 在 199 次迭代中的对偶变量为: -147.10579040881726
# agent 98 在 199 次迭代中的对偶变量为: -147.70853126165446
# agent 99 在 199 次迭代中的对偶变量为: -147.31605466145527
# agent 100 在 199 次迭代中的对偶变量为: -147.48140310136216
# *************************
# 迭代步长为: 0.04175304505755262
# ****************************************************************************
# 249 次迭代中的结果：
# agent 1 在 249 次迭代中的资源申请量为: 51.036121733564755
# agent 2 在 249 次迭代中的资源申请量为: 64.32261193196861
# agent 3 在 249 次迭代中的资源申请量为: 46.13982147966624
# agent 4 在 249 次迭代中的资源申请量为: 68.04622275163335
# agent 5 在 249 次迭代中的资源申请量为: 68.78986336785323
# agent 6 在 249 次迭代中的资源申请量为: 75.83948327429256
# agent 7 在 249 次迭代中的资源申请量为: 41.61466331167509
# agent 8 在 249 次迭代中的资源申请量为: 39.826389016016115
# agent 9 在 249 次迭代中的资源申请量为: 45.49891359474271
# agent 10 在 249 次迭代中的资源申请量为: 58.91524204948508
# agent 11 在 249 次迭代中的资源申请量为: 48.03542792040592
# agent 12 在 249 次迭代中的资源申请量为: 52.09105927094189
# agent 13 在 249 次迭代中的资源申请量为: 69.35166360887115
# agent 14 在 249 次迭代中的资源申请量为: 58.34334321626927
# agent 15 在 249 次迭代中的资源申请量为: 45.86767514093915
# agent 16 在 249 次迭代中的资源申请量为: 45.993846411690406
# agent 17 在 249 次迭代中的资源申请量为: 47.39071734122117
# agent 18 在 249 次迭代中的资源申请量为: 49.03775799205606
# agent 19 在 249 次迭代中的资源申请量为: 43.60920635946821
# agent 20 在 249 次迭代中的资源申请量为: 58.9543453239896
# agent 21 在 249 次迭代中的资源申请量为: 40.957091069401734
# agent 22 在 249 次迭代中的资源申请量为: 41.246575460284426
# agent 23 在 249 次迭代中的资源申请量为: 50.53023099652819
# agent 24 在 249 次迭代中的资源申请量为: 42.71567077763759
# agent 25 在 249 次迭代中的资源申请量为: 47.634139554429744
# agent 26 在 249 次迭代中的资源申请量为: 41.98391797503272
# agent 27 在 249 次迭代中的资源申请量为: 69.17785742533555
# agent 28 在 249 次迭代中的资源申请量为: 54.09460151746252
# agent 29 在 249 次迭代中的资源申请量为: 43.025030858204204
# agent 30 在 249 次迭代中的资源申请量为: 41.475524205861355
# agent 31 在 249 次迭代中的资源申请量为: 63.81058538723394
# agent 32 在 249 次迭代中的资源申请量为: 58.47575415414376
# agent 33 在 249 次迭代中的资源申请量为: 43.728442666297504
# agent 34 在 249 次迭代中的资源申请量为: 55.144173661609805
# agent 35 在 249 次迭代中的资源申请量为: 41.05702116927249
# agent 36 在 249 次迭代中的资源申请量为: 45.181042162567955
# agent 37 在 249 次迭代中的资源申请量为: 55.328756422520414
# agent 38 在 249 次迭代中的资源申请量为: 42.49239314254569
# agent 39 在 249 次迭代中的资源申请量为: 45.619310701463554
# agent 40 在 249 次迭代中的资源申请量为: 52.8410501614892
# agent 41 在 249 次迭代中的资源申请量为: 69.85628248459018
# agent 42 在 249 次迭代中的资源申请量为: 44.81493500925025
# agent 43 在 249 次迭代中的资源申请量为: 54.42177306304735
# agent 44 在 249 次迭代中的资源申请量为: 55.775123014940036
# agent 45 在 249 次迭代中的资源申请量为: 50.81078094712449
# agent 46 在 249 次迭代中的资源申请量为: 59.09779544195627
# agent 47 在 249 次迭代中的资源申请量为: 48.434714249657254
# agent 48 在 249 次迭代中的资源申请量为: 45.77916988751861
# agent 49 在 249 次迭代中的资源申请量为: 44.909173558475416
# agent 50 在 249 次迭代中的资源申请量为: 43.079612978144745
# agent 51 在 249 次迭代中的资源申请量为: 50.98410120722577
# agent 52 在 249 次迭代中的资源申请量为: 58.67773393286819
# agent 53 在 249 次迭代中的资源申请量为: 41.03876617938595
# agent 54 在 249 次迭代中的资源申请量为: 60.09205195084611
# agent 55 在 249 次迭代中的资源申请量为: 74.99472410098858
# agent 56 在 249 次迭代中的资源申请量为: 43.11790815171116
# agent 57 在 249 次迭代中的资源申请量为: 63.93306743011915
# agent 58 在 249 次迭代中的资源申请量为: 44.61388093573162
# agent 59 在 249 次迭代中的资源申请量为: 50.6151781853764
# agent 60 在 249 次迭代中的资源申请量为: 59.113020112203294
# agent 61 在 249 次迭代中的资源申请量为: 69.36934825785654
# agent 62 在 249 次迭代中的资源申请量为: 48.522035930160214
# agent 63 在 249 次迭代中的资源申请量为: 41.13713834601176
# agent 64 在 249 次迭代中的资源申请量为: 46.844392096972925
# agent 65 在 249 次迭代中的资源申请量为: 44.9672628014194
# agent 66 在 249 次迭代中的资源申请量为: 69.0185018125854
# agent 67 在 249 次迭代中的资源申请量为: 45.60176736780539
# agent 68 在 249 次迭代中的资源申请量为: 47.324988329073754
# agent 69 在 249 次迭代中的资源申请量为: 47.82274702887795
# agent 70 在 249 次迭代中的资源申请量为: 63.248049385827194
# agent 71 在 249 次迭代中的资源申请量为: 75.70576243122103
# agent 72 在 249 次迭代中的资源申请量为: 63.51479078575462
# agent 73 在 249 次迭代中的资源申请量为: 45.97906841835784
# agent 74 在 249 次迭代中的资源申请量为: 41.02911559601198
# agent 75 在 249 次迭代中的资源申请量为: 54.73307877142421
# agent 76 在 249 次迭代中的资源申请量为: 49.41663486996534
# agent 77 在 249 次迭代中的资源申请量为: 42.965691202422114
# agent 78 在 249 次迭代中的资源申请量为: 52.21902538434147
# agent 79 在 249 次迭代中的资源申请量为: 45.26693047649317
# agent 80 在 249 次迭代中的资源申请量为: 45.265406847936546
# agent 81 在 249 次迭代中的资源申请量为: 41.59766680783329
# agent 82 在 249 次迭代中的资源申请量为: 48.294576341728906
# agent 83 在 249 次迭代中的资源申请量为: 43.82777424876322
# agent 84 在 249 次迭代中的资源申请量为: 54.89942124731402
# agent 85 在 249 次迭代中的资源申请量为: 58.671110083395924
# agent 86 在 249 次迭代中的资源申请量为: 51.61191791633064
# agent 87 在 249 次迭代中的资源申请量为: 63.76277485416302
# agent 88 在 249 次迭代中的资源申请量为: 68.54511109706803
# agent 89 在 249 次迭代中的资源申请量为: 42.6581621256895
# agent 90 在 249 次迭代中的资源申请量为: 62.44466928042449
# agent 91 在 249 次迭代中的资源申请量为: 45.18893906043315
# agent 92 在 249 次迭代中的资源申请量为: 60.04469886229144
# agent 93 在 249 次迭代中的资源申请量为: 42.93849541716745
# agent 94 在 249 次迭代中的资源申请量为: 77.1721521968726
# agent 95 在 249 次迭代中的资源申请量为: 63.615688364696844
# agent 96 在 249 次迭代中的资源申请量为: 63.690841494217516
# agent 97 在 249 次迭代中的资源申请量为: 75.92179668113626
# agent 98 在 249 次迭代中的资源申请量为: 76.99289314917509
# agent 99 在 249 次迭代中的资源申请量为: 55.1957486545556
# agent 100 在 249 次迭代中的资源申请量为: 51.12471204971374
# 资源申请量总和为: 5307.534223460725
# ****************************************************************************
# 成本总和为: 378255.87089840067
# ...
# agent 61 在 57999 次迭代中的资源申请量为: 45.35594989347403
# agent 62 在 57999 次迭代中的资源申请量为: 37.777916501990724
# agent 63 在 57999 次迭代中的资源申请量为: 44.36024833408177
# agent 64 在 57999 次迭代中的资源申请量为: 50.59248382563158
# agent 65 在 57999 次迭代中的资源申请量为: 48.719342447654434
# agent 66 在 57999 次迭代中的资源申请量为: 53.47780999250294
# agent 67 在 57999 次迭代中的资源申请量为: 44.62937911116489
# agent 68 在 57999 次迭代中的资源申请量为: 38.64566746179317
# agent 69 在 57999 次迭代中的资源申请量为: 49.892139157742264
# agent 70 在 57999 次迭代中的资源申请量为: 43.38409217370307
# agent 71 在 57999 次迭代中的资源申请量为: 51.072439614453316
# agent 72 在 57999 次迭代中的资源申请量为: 51.63101181607402
# agent 73 在 57999 次迭代中的资源申请量为: 68.52493850742536
# agent 74 在 57999 次迭代中的资源申请量为: 63.033563690013715
# agent 75 在 57999 次迭代中的资源申请量为: 68.784860310892
# agent 76 在 57999 次迭代中的资源申请量为: 65.84231131075826
# agent 77 在 57999 次迭代中的资源申请量为: 37.33178559067635
# agent 78 在 57999 次迭代中的资源申请量为: 56.51515954674519
# agent 79 在 57999 次迭代中的资源申请量为: 35.71319766839764
# agent 80 在 57999 次迭代中的资源申请量为: 41.69438982489503
# agent 81 在 57999 次迭代中的资源申请量为: 64.43288578237497
# agent 82 在 57999 次迭代中的资源申请量为: 45.64920279686928
# agent 83 在 57999 次迭代中的资源申请量为: 54.00548947849253
# agent 84 在 57999 次迭代中的资源申请量为: 52.98642785861979
# agent 85 在 57999 次迭代中的资源申请量为: 58.685757530611916
# agent 86 在 57999 次迭代中的资源申请量为: 54.16278250297388
# agent 87 在 57999 次迭代中的资源申请量为: 50.183947875573004
# agent 88 在 57999 次迭代中的资源申请量为: 53.40486804038364
# agent 89 在 57999 次迭代中的资源申请量为: 44.037016821613456
# agent 90 在 57999 次迭代中的资源申请量为: 38.995841039652966
# agent 91 在 57999 次迭代中的资源申请量为: 43.58677066582213
# agent 92 在 57999 次迭代中的资源申请量为: 45.25809138455365
# agent 93 在 57999 次迭代中的资源申请量为: 35.68321481266967
# agent 94 在 57999 次迭代中的资源申请量为: 37.48060785879904
# 资源申请量平均值avg为: 49.99999999999654
# ****************************************************************************
# 平均成本为: 3240.481984531225
# ****************************************************************************
# agent 1 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 2 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 3 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 4 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 5 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 6 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 7 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 8 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 9 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 10 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 11 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 12 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 13 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 14 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 15 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 16 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 17 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 18 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 19 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 20 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 21 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 22 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 23 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 24 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 25 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 26 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 27 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 28 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 29 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 30 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 31 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 32 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 33 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 34 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 35 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 36 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 37 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 38 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 39 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 40 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 41 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 42 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 43 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 44 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 45 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 46 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 47 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 48 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 49 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 50 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 51 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 52 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 53 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 54 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 55 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 56 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 57 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 58 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 59 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 60 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 61 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 62 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 63 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 64 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 65 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 66 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 67 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 68 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 69 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 70 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 71 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 72 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 73 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 74 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 75 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 76 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 77 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 78 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 79 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 80 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 81 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 82 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 83 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 84 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 85 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 86 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 87 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 88 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 89 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 90 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 91 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 92 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 93 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 94 在 57999 次迭代中的对偶变量为: -135.14386653834575
# *************************
# 迭代步长为: 0.11151053484837568
# ****************************************************************************
# 59999 次迭代中的结果：
# agent 1 在 59999 次迭代中的资源申请量为: 56.19880558172988
# agent 2 在 59999 次迭代中的资源申请量为: 56.03871203978166
# agent 3 在 59999 次迭代中的资源申请量为: 60.64796214442871
# agent 4 在 59999 次迭代中的资源申请量为: 37.93333499802675
# agent 5 在 59999 次迭代中的资源申请量为: 57.56693686702461
# agent 6 在 59999 次迭代中的资源申请量为: 55.34212747123894
# agent 7 在 59999 次迭代中的资源申请量为: 65.6236567946489
# agent 8 在 59999 次迭代中的资源申请量为: 46.330946703602365
# agent 9 在 59999 次迭代中的资源申请量为: 65.64268770463663
# agent 10 在 59999 次迭代中的资源申请量为: 54.23914303693835
# agent 11 在 59999 次迭代中的资源申请量为: 65.4520437985654
# agent 12 在 59999 次迭代中的资源申请量为: 38.406222330358624
# agent 13 在 59999 次迭代中的资源申请量为: 49.70058714461363
# agent 14 在 59999 次迭代中的资源申请量为: 41.3659905551611
# agent 15 在 59999 次迭代中的资源申请量为: 42.48853939614691
# agent 16 在 59999 次迭代中的资源申请量为: 49.24530133808371
# agent 17 在 59999 次迭代中的资源申请量为: 50.11852704992918
# agent 18 在 59999 次迭代中的资源申请量为: 46.537297422347486
# agent 19 在 59999 次迭代中的资源申请量为: 44.77392156663175
# agent 20 在 59999 次迭代中的资源申请量为: 50.80339666473046
# agent 21 在 59999 次迭代中的资源申请量为: 69.93387670557085
# agent 22 在 59999 次迭代中的资源申请量为: 61.24199691647269
# agent 23 在 59999 次迭代中的资源申请量为: 61.627787986086716
# agent 24 在 59999 次迭代中的资源申请量为: 39.861352301782716
# agent 25 在 59999 次迭代中的资源申请量为: 52.95065687328203
# agent 26 在 59999 次迭代中的资源申请量为: 49.39633437684004
# agent 27 在 59999 次迭代中的资源申请量为: 47.51919637207136
# agent 28 在 59999 次迭代中的资源申请量为: 40.7413613830987
# agent 29 在 59999 次迭代中的资源申请量为: 44.38273034135506
# agent 30 在 59999 次迭代中的资源申请量为: 39.891745956789116
# agent 31 在 59999 次迭代中的资源申请量为: 65.76280653244551
# agent 32 在 59999 次迭代中的资源申请量为: 59.51901541924079
# agent 33 在 59999 次迭代中的资源申请量为: 48.23750867799392
# agent 34 在 59999 次迭代中的资源申请量为: 36.76532342510125
# agent 35 在 59999 次迭代中的资源申请量为: 41.086702696803464
# agent 36 在 59999 次迭代中的资源申请量为: 62.20889044924783
# agent 37 在 59999 次迭代中的资源申请量为: 40.47023795026076
# agent 38 在 59999 次迭代中的资源申请量为: 58.24733429492913
# agent 39 在 59999 次迭代中的资源申请量为: 37.39554726071002
# agent 40 在 59999 次迭代中的资源申请量为: 50.45313221045784
# agent 41 在 59999 次迭代中的资源申请量为: 36.73569742369616
# agent 42 在 59999 次迭代中的资源申请量为: 56.24242387150355
# agent 43 在 59999 次迭代中的资源申请量为: 61.52373322591861
# agent 44 在 59999 次迭代中的资源申请量为: 47.51525622305313
# agent 45 在 59999 次迭代中的资源申请量为: 41.36197014706921
# agent 46 在 59999 次迭代中的资源申请量为: 67.10436077257359
# agent 47 在 59999 次迭代中的资源申请量为: 65.57090570810219
# agent 48 在 59999 次迭代中的资源申请量为: 40.83836334458436
# agent 49 在 59999 次迭代中的资源申请量为: 39.16390664937778
# agent 50 在 59999 次迭代中的资源申请量为: 63.292999181236645
# agent 51 在 59999 次迭代中的资源申请量为: 36.39727688961264
# agent 52 在 59999 次迭代中的资源申请量为: 46.86937779818014
# agent 53 在 59999 次迭代中的资源申请量为: 43.572511920796444
# agent 54 在 59999 次迭代中的资源申请量为: 49.58201107681077
# agent 55 在 59999 次迭代中的资源申请量为: 47.173391517077015
# agent 56 在 59999 次迭代中的资源申请量为: 42.97971616155657
# agent 57 在 59999 次迭代中的资源申请量为: 36.90486251978384
# agent 58 在 59999 次迭代中的资源申请量为: 59.2566799113546
# agent 59 在 59999 次迭代中的资源申请量为: 59.891586060534515
# agent 60 在 59999 次迭代中的资源申请量为: 40.34169962872796
# agent 61 在 59999 次迭代中的资源申请量为: 45.35594989347582
# agent 62 在 59999 次迭代中的资源申请量为: 37.77791650199216
# agent 63 在 59999 次迭代中的资源申请量为: 44.360248334083515
# agent 64 在 59999 次迭代中的资源申请量为: 50.59248382563358
# agent 65 在 59999 次迭代中的资源申请量为: 48.71934244765636
# agent 66 在 59999 次迭代中的资源申请量为: 53.47780999250507
# agent 67 在 59999 次迭代中的资源申请量为: 44.62937911116663
# agent 68 在 59999 次迭代中的资源申请量为: 38.64566746179467
# agent 69 在 59999 次迭代中的资源申请量为: 49.89213915774424
# agent 70 在 59999 次迭代中的资源申请量为: 43.384092173704765
# agent 71 在 59999 次迭代中的资源申请量为: 51.07243961445531
# agent 72 在 59999 次迭代中的资源申请量为: 51.63101181607605
# agent 73 在 59999 次迭代中的资源申请量为: 68.52493850742809
# agent 74 在 59999 次迭代中的资源申请量为: 63.033563690016244
# agent 75 在 59999 次迭代中的资源申请量为: 68.78486031089474
# agent 76 在 59999 次迭代中的资源申请量为: 65.84231131076093
# agent 77 在 59999 次迭代中的资源申请量为: 37.33178559067781
# agent 78 在 59999 次迭代中的资源申请量为: 56.51515954674745
# agent 79 在 59999 次迭代中的资源申请量为: 35.713197668399026
# agent 80 在 59999 次迭代中的资源申请量为: 41.69438982489667
# agent 81 在 59999 次迭代中的资源申请量为: 64.43288578237754
# agent 82 在 59999 次迭代中的资源申请量为: 45.64920279687104
# agent 83 在 59999 次迭代中的资源申请量为: 54.00548947849467
# agent 84 在 59999 次迭代中的资源申请量为: 52.98642785862186
# agent 85 在 59999 次迭代中的资源申请量为: 58.685757530614225
# agent 86 在 59999 次迭代中的资源申请量为: 54.16278250297603
# agent 87 在 59999 次迭代中的资源申请量为: 50.18394787557497
# agent 88 在 59999 次迭代中的资源申请量为: 53.40486804038577
# agent 89 在 59999 次迭代中的资源申请量为: 44.03701682161516
# agent 90 在 59999 次迭代中的资源申请量为: 38.99584103965445
# agent 91 在 59999 次迭代中的资源申请量为: 43.58677066582381
# agent 92 在 59999 次迭代中的资源申请量为: 45.258091384555385
# agent 93 在 59999 次迭代中的资源申请量为: 35.68321481267107
# agent 94 在 59999 次迭代中的资源申请量为: 37.4806078588005
# 资源申请量平均值avg为: 49.9999999999985
# ****************************************************************************
# 平均成本为: 3240.4819845314896
# ****************************************************************************
# agent 1 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 2 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 3 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 4 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 5 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 6 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 7 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 8 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 9 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 10 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 11 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 12 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 13 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 14 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 15 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 16 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 17 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 18 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 19 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 20 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 21 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 22 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 23 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 24 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 25 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 26 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 27 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 28 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 29 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 30 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 31 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 32 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 33 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 34 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 35 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 36 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 37 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 38 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 39 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 40 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 41 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 42 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 43 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 44 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 45 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 46 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 47 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 48 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 49 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 50 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 51 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 52 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 53 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 54 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 55 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 56 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 57 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 58 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 59 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 60 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 61 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 62 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 63 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 64 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 65 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 66 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 67 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 68 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 69 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 70 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 71 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 72 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 73 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 74 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 75 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 76 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 77 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 78 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 79 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 80 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 81 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 82 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 83 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 84 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 85 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 86 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 87 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 88 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 89 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 90 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 91 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 92 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 93 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 94 在 59999 次迭代中的对偶变量为: -135.1438665383513
# *************************
# 迭代步长为: 0.11075700351730201
# ****************************************************************************
# 2023-05-29 15:40:13.737

# %%
np.savetxt('../data/01-DGD-agent_resource_quantity_large_value_deterministic_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/01-DGD-sum_cost_large_value_deterministic_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/01-DGD-sum_resource_large_value_deterministic_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
