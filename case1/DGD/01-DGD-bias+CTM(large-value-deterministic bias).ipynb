# %% [markdown]
# IWDGD中大值的确定性噪声 对应到DGD算法中是固定的对偶攻击值为-152.8 这样两个算法各自迭代1000次 所有用户的对偶迭代值均在150附近

# %% [markdown]
# 鲁棒聚合器CTM 每个用户剔除3个用户对偶信息（包含自身的信息）3-是网络中噪声用户数量的上界

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(100,1000)) #100个agent的资源量 
dual_variable = np.zeros(shape=(100,1000))#对偶变量
sum_resource=np.zeros(shape=(1,1000), dtype=np.float64)#存放每一次迭代后所有用户资源量的总和
sum_cost=np.zeros(shape=(1,1000), dtype=np.float64)#存放每一次迭代后所有用户成本的总和
iteration_update = 0.01#迭代步长
A=np.loadtxt("100_Network_Topology_Double_Random_Adjacency_Matrix_Degree_15.txt") #网络拓扑的邻接矩阵 对角元素要为0
W=np.zeros(shape=(100,100)) #双随机的网络拓扑矩阵W（对角线处非零）
iteration=[]#绘图横坐标
a=np.loadtxt("100_uniform_distribution_(1,2)_point1.txt")#每个agent的成本函数中的超参数
b=np.loadtxt("100_normal_distribution_(2,0.6)_point1.txt")#每个agent的成本函数中的超参数
q=3 #TM鲁棒聚合中丢弃的数据数量 
neighbor_help=[]

# %%
#根据邻接矩阵生成网络对应的双随机的权重混合矩阵
for i in range(0,100):
    for j in range(0,100):
        if A[i][j]!=0 or i==j:
            W[i][j]=1/16

#对偶变量的初始化 初始化一致
for i in range (0,100):
    dual_variable[i][0]=0
    
#资源量的初始化 资源量的初始化需要和对偶变量的初始值满足某种关系
for i in range (0,100):
    agent_resource_quantity[i][0]=50

iteration.append(0)

#总资源量 初始化
sum=0
for i in range (0,100):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

#用户总成本初始化
sum=0
for i in range(0,100):
    sum=sum+a[i]*(agent_resource_quantity[i][0]-b[i])*(agent_resource_quantity[i][0]-b[i])
sum_cost[0][0]=sum

#对每个用户的15个邻居进行初始化
for i in range (0,100):
    for j in range (0,100):
        if A[i][j]!=0:
            neighbor_help.append(j)
neighbor=np.array(neighbor_help).reshape(100,15)

# %%
#DGD算法 
def DGD_CTM_deterministic_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,neighbor):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************DGD算法+计算误差+CTM****************************")
    print("相关变量初始值为：")
    for i in range (0,100):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    for i in range(0,100):
        print("agent",(i+1),"的初始对偶变量为:",dual_variable[i][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):#迭代次数
        iteration.append(k)
        
        #所有用户对偶变量的迭代 
        #阶段一：梯度下降
        dual_variable_intermediate=[] #存放当前迭代中100个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,100):
            if i==7 or i==20 or i==34:
                dual_variable_intermediate.append(-152.8)
            else:
                dual_variable_intermediate.append(dual_variable[i][k-1]-iteration_update*(50-agent_resource_quantity[i][k-1]))       
        
        #阶段二：鲁棒聚合 每个用户用鲁棒聚合器CTM聚合自身以及邻居的对偶值   
        for i in range (0,100):
            mix_sum_dual=0
            sort_list=[]
            sum=0
            for j in range (0,15):
                sort_list.append(dual_variable_intermediate[neighbor[i,j]])
            sort_list.append(dual_variable_intermediate[i])
            sort_list.sort()
            #剔除最大的q个数据和最小的q个数据
            for j in range(0,int(q)):
                del sort_list[15-j]
            for j in range(0,int(q)):
                del sort_list[0]     
            for j in range(0,len(sort_list)):
                mix_sum_dual=mix_sum_dual+sort_list[j]
            #用户取剩下数据的平均
            dual_variable[i][k]=(1/(16-2*q))*(mix_sum_dual)
        
        #用户资源申请量的迭代
        for i in range (0,100):
            agent_resource_quantity[i][k]=(dual_variable[i][k]-2*a[i]*b[i])/(-2*a[i])

        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,100):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,100):
            sum2=sum2+a[i]*(agent_resource_quantity[i][k]-b[i])*(agent_resource_quantity[i][k]-b[i])
        sum_cost[0][k]=sum2
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%50==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,100):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            for i in range(0,100):
                print("agent",(i+1),"在",k,"次迭代中的对偶变量为:",dual_variable[i][k])   
            print("*************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        iteration_update=1/(pow(k+1,0.6)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
DGD_CTM_deterministic_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,neighbor)
# Out:
# ****************************DGD算法+计算误差+CTM****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 50.0
# agent 2 的初始资源申请量为: 50.0
# agent 3 的初始资源申请量为: 50.0
# agent 4 的初始资源申请量为: 50.0
# agent 5 的初始资源申请量为: 50.0
# agent 6 的初始资源申请量为: 50.0
# agent 7 的初始资源申请量为: 50.0
# agent 8 的初始资源申请量为: 50.0
# agent 9 的初始资源申请量为: 50.0
# agent 10 的初始资源申请量为: 50.0
# agent 11 的初始资源申请量为: 50.0
# agent 12 的初始资源申请量为: 50.0
# agent 13 的初始资源申请量为: 50.0
# agent 14 的初始资源申请量为: 50.0
# agent 15 的初始资源申请量为: 50.0
# agent 16 的初始资源申请量为: 50.0
# agent 17 的初始资源申请量为: 50.0
# agent 18 的初始资源申请量为: 50.0
# agent 19 的初始资源申请量为: 50.0
# agent 20 的初始资源申请量为: 50.0
# agent 21 的初始资源申请量为: 50.0
# agent 22 的初始资源申请量为: 50.0
# agent 23 的初始资源申请量为: 50.0
# agent 24 的初始资源申请量为: 50.0
# agent 25 的初始资源申请量为: 50.0
# agent 26 的初始资源申请量为: 50.0
# agent 27 的初始资源申请量为: 50.0
# agent 28 的初始资源申请量为: 50.0
# agent 29 的初始资源申请量为: 50.0
# agent 30 的初始资源申请量为: 50.0
# agent 31 的初始资源申请量为: 50.0
# agent 32 的初始资源申请量为: 50.0
# agent 33 的初始资源申请量为: 50.0
# agent 34 的初始资源申请量为: 50.0
# agent 35 的初始资源申请量为: 50.0
# agent 36 的初始资源申请量为: 50.0
# agent 37 的初始资源申请量为: 50.0
# agent 38 的初始资源申请量为: 50.0
# agent 39 的初始资源申请量为: 50.0
# agent 40 的初始资源申请量为: 50.0
# agent 41 的初始资源申请量为: 50.0
# agent 42 的初始资源申请量为: 50.0
# agent 43 的初始资源申请量为: 50.0
# agent 44 的初始资源申请量为: 50.0
# agent 45 的初始资源申请量为: 50.0
# agent 46 的初始资源申请量为: 50.0
# agent 47 的初始资源申请量为: 50.0
# agent 48 的初始资源申请量为: 50.0
# agent 49 的初始资源申请量为: 50.0
# agent 50 的初始资源申请量为: 50.0
# agent 51 的初始资源申请量为: 50.0
# agent 52 的初始资源申请量为: 50.0
# agent 53 的初始资源申请量为: 50.0
# agent 54 的初始资源申请量为: 50.0
# agent 55 的初始资源申请量为: 50.0
# agent 56 的初始资源申请量为: 50.0
# agent 57 的初始资源申请量为: 50.0
# agent 58 的初始资源申请量为: 50.0
# agent 59 的初始资源申请量为: 50.0
# agent 60 的初始资源申请量为: 50.0
# agent 61 的初始资源申请量为: 50.0
# agent 62 的初始资源申请量为: 50.0
# agent 63 的初始资源申请量为: 50.0
# agent 64 的初始资源申请量为: 50.0
# agent 65 的初始资源申请量为: 50.0
# agent 66 的初始资源申请量为: 50.0
# agent 67 的初始资源申请量为: 50.0
# agent 68 的初始资源申请量为: 50.0
# agent 69 的初始资源申请量为: 50.0
# agent 70 的初始资源申请量为: 50.0
# agent 71 的初始资源申请量为: 50.0
# agent 72 的初始资源申请量为: 50.0
# agent 73 的初始资源申请量为: 50.0
# agent 74 的初始资源申请量为: 50.0
# agent 75 的初始资源申请量为: 50.0
# agent 76 的初始资源申请量为: 50.0
# agent 77 的初始资源申请量为: 50.0
# agent 78 的初始资源申请量为: 50.0
# agent 79 的初始资源申请量为: 50.0
# agent 80 的初始资源申请量为: 50.0
# agent 81 的初始资源申请量为: 50.0
# agent 82 的初始资源申请量为: 50.0
# agent 83 的初始资源申请量为: 50.0
# agent 84 的初始资源申请量为: 50.0
# agent 85 的初始资源申请量为: 50.0
# agent 86 的初始资源申请量为: 50.0
# agent 87 的初始资源申请量为: 50.0
# agent 88 的初始资源申请量为: 50.0
# agent 89 的初始资源申请量为: 50.0
# agent 90 的初始资源申请量为: 50.0
# agent 91 的初始资源申请量为: 50.0
# agent 92 的初始资源申请量为: 50.0
# agent 93 的初始资源申请量为: 50.0
# agent 94 的初始资源申请量为: 50.0
# agent 95 的初始资源申请量为: 50.0
# agent 96 的初始资源申请量为: 50.0
# agent 97 的初始资源申请量为: 50.0
# agent 98 的初始资源申请量为: 50.0
# agent 99 的初始资源申请量为: 50.0
# agent 100 的初始资源申请量为: 50.0
# *************************
# 初始资源申请量总和为: 5000.0
# *************************
# 初始成本总和为: 346654.5889999999
# *************************
# agent 1 的初始对偶变量为: 0.0
# agent 2 的初始对偶变量为: 0.0
# agent 3 的初始对偶变量为: 0.0
# agent 4 的初始对偶变量为: 0.0
# agent 5 的初始对偶变量为: 0.0
# agent 6 的初始对偶变量为: 0.0
# agent 7 的初始对偶变量为: 0.0
# agent 8 的初始对偶变量为: 0.0
# agent 9 的初始对偶变量为: 0.0
# agent 10 的初始对偶变量为: 0.0
# agent 11 的初始对偶变量为: 0.0
# agent 12 的初始对偶变量为: 0.0
# agent 13 的初始对偶变量为: 0.0
# agent 14 的初始对偶变量为: 0.0
# agent 15 的初始对偶变量为: 0.0
# agent 16 的初始对偶变量为: 0.0
# agent 17 的初始对偶变量为: 0.0
# agent 18 的初始对偶变量为: 0.0
# agent 19 的初始对偶变量为: 0.0
# agent 20 的初始对偶变量为: 0.0
# agent 21 的初始对偶变量为: 0.0
# agent 22 的初始对偶变量为: 0.0
# agent 23 的初始对偶变量为: 0.0
# agent 24 的初始对偶变量为: 0.0
# agent 25 的初始对偶变量为: 0.0
# agent 26 的初始对偶变量为: 0.0
# agent 27 的初始对偶变量为: 0.0
# agent 28 的初始对偶变量为: 0.0
# agent 29 的初始对偶变量为: 0.0
# agent 30 的初始对偶变量为: 0.0
# agent 31 的初始对偶变量为: 0.0
# agent 32 的初始对偶变量为: 0.0
# agent 33 的初始对偶变量为: 0.0
# agent 34 的初始对偶变量为: 0.0
# agent 35 的初始对偶变量为: 0.0
# agent 36 的初始对偶变量为: 0.0
# agent 37 的初始对偶变量为: 0.0
# agent 38 的初始对偶变量为: 0.0
# agent 39 的初始对偶变量为: 0.0
# agent 40 的初始对偶变量为: 0.0
# agent 41 的初始对偶变量为: 0.0
# agent 42 的初始对偶变量为: 0.0
# agent 43 的初始对偶变量为: 0.0
# agent 44 的初始对偶变量为: 0.0
# agent 45 的初始对偶变量为: 0.0
# agent 46 的初始对偶变量为: 0.0
# agent 47 的初始对偶变量为: 0.0
# agent 48 的初始对偶变量为: 0.0
# agent 49 的初始对偶变量为: 0.0
# agent 50 的初始对偶变量为: 0.0
# agent 51 的初始对偶变量为: 0.0
# agent 52 的初始对偶变量为: 0.0
# agent 53 的初始对偶变量为: 0.0
# agent 54 的初始对偶变量为: 0.0
# agent 55 的初始对偶变量为: 0.0
# agent 56 的初始对偶变量为: 0.0
# agent 57 的初始对偶变量为: 0.0
# agent 58 的初始对偶变量为: 0.0
# agent 59 的初始对偶变量为: 0.0
# agent 60 的初始对偶变量为: 0.0
# agent 61 的初始对偶变量为: 0.0
# agent 62 的初始对偶变量为: 0.0
# agent 63 的初始对偶变量为: 0.0
# agent 64 的初始对偶变量为: 0.0
# agent 65 的初始对偶变量为: 0.0
# agent 66 的初始对偶变量为: 0.0
# agent 67 的初始对偶变量为: 0.0
# agent 68 的初始对偶变量为: 0.0
# agent 69 的初始对偶变量为: 0.0
# agent 70 的初始对偶变量为: 0.0
# agent 71 的初始对偶变量为: 0.0
# agent 72 的初始对偶变量为: 0.0
# agent 73 的初始对偶变量为: 0.0
# agent 74 的初始对偶变量为: 0.0
# agent 75 的初始对偶变量为: 0.0
# agent 76 的初始对偶变量为: 0.0
# agent 77 的初始对偶变量为: 0.0
# agent 78 的初始对偶变量为: 0.0
# agent 79 的初始对偶变量为: 0.0
# agent 80 的初始对偶变量为: 0.0
# agent 81 的初始对偶变量为: 0.0
# agent 82 的初始对偶变量为: 0.0
# agent 83 的初始对偶变量为: 0.0
# agent 84 的初始对偶变量为: 0.0
# agent 85 的初始对偶变量为: 0.0
# agent 86 的初始对偶变量为: 0.0
# agent 87 的初始对偶变量为: 0.0
# agent 88 的初始对偶变量为: 0.0
# agent 89 的初始对偶变量为: 0.0
# agent 90 的初始对偶变量为: 0.0
# agent 91 的初始对偶变量为: 0.0
# agent 92 的初始对偶变量为: 0.0
# agent 93 的初始对偶变量为: 0.0
# agent 94 的初始对偶变量为: 0.0
# agent 95 的初始对偶变量为: 0.0
# agent 96 的初始对偶变量为: 0.0
# agent 97 的初始对偶变量为: 0.0
# agent 98 的初始对偶变量为: 0.0
# agent 99 的初始对偶变量为: 0.0
# agent 100 的初始对偶变量为: 0.0
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 49 次迭代中的结果：
# agent 1 在 49 次迭代中的资源申请量为: 47.629305460486364
# agent 2 在 49 次迭代中的资源申请量为: 59.839557021916804
# agent 3 在 49 次迭代中的资源申请量为: 43.09378396509383
# agent 4 在 49 次迭代中的资源申请量为: 63.364709383551464
# agent 5 在 49 次迭代中的资源申请量为: 64.13598646619094
# agent 6 在 49 次迭代中的资源申请量为: 70.53918438166127
# agent 7 在 49 次迭代中的资源申请量为: 38.861570793385475
# agent 8 在 49 次迭代中的资源申请量为: 37.154713965898495
# agent 9 在 49 次迭代中的资源申请量为: 42.35773003856526
# agent 10 在 49 次迭代中的资源申请量为: 54.8141061860338
# agent 11 在 49 次迭代中的资源申请量为: 44.76798728962907
# agent 12 在 49 次迭代中的资源申请量为: 48.44006519891705
# agent 13 在 49 次迭代中的资源申请量为: 64.50379836185756
# agent 14 在 49 次迭代中的资源申请量为: 54.37132143605165
# agent 15 在 49 次迭代中的资源申请量为: 42.869050560412404
# agent 16 在 49 次迭代中的资源申请量为: 43.078468097237554
# agent 17 在 49 次迭代中的资源申请量为: 44.229430942949115
# agent 18 在 49 次迭代中的资源申请量为: 45.880385497286774
# agent 19 在 49 次迭代中的资源申请量为: 40.674129284380726
# agent 20 在 49 次迭代中的资源申请量为: 54.76906614322112
# agent 21 在 49 次迭代中的资源申请量为: 38.08278784449725
# agent 22 在 49 次迭代中的资源申请量为: 38.475177580853675
# agent 23 在 49 次迭代中的资源申请量为: 47.21138994489456
# agent 24 在 49 次迭代中的资源申请量为: 39.884589454025594
# agent 25 在 49 次迭代中的资源申请量为: 44.41124515078053
# agent 26 在 49 次迭代中的资源申请量为: 39.28092699747267
# agent 27 在 49 次迭代中的资源申请量为: 64.383064289108
# agent 28 在 49 次迭代中的资源申请量为: 50.3141894615227
# agent 29 在 49 次迭代中的资源申请量为: 40.191480171211516
# agent 30 在 49 次迭代中的资源申请量为: 38.70152772997693
# agent 31 在 49 次迭代中的资源申请量为: 59.44153114093044
# agent 32 在 49 次迭代中的资源申请量为: 54.46172872340814
# agent 33 在 49 次迭代中的资源申请量为: 40.741684090457845
# agent 34 在 49 次迭代中的资源申请量为: 51.37608801846776
# agent 35 在 49 次迭代中的资源申请量为: 38.189462776613894
# agent 36 在 49 次迭代中的资源申请量为: 42.05259359411569
# agent 37 在 49 次迭代中的资源申请量为: 51.622272068020315
# agent 38 在 49 次迭代中的资源申请量为: 39.665735074322136
# agent 39 在 49 次迭代中的资源申请量为: 42.62052060878952
# agent 40 在 49 次迭代中的资源申请量为: 49.35378678601524
# agent 41 在 49 次迭代中的资源申请量为: 64.95717707674976
# agent 42 在 49 次迭代中的资源申请量为: 41.7286932198428
# agent 43 在 49 次迭代中的资源申请量为: 50.66652299042211
# agent 44 在 49 次迭代中的资源申请量为: 52.22347968080386
# agent 45 在 49 次迭代中的资源申请量为: 47.35195154785526
# agent 46 在 49 次迭代中的资源申请量为: 54.973841512795964
# agent 47 在 49 次迭代中的资源申请量为: 45.13296781612551
# agent 48 在 49 次迭代中的资源申请量为: 42.637793134800475
# agent 49 在 49 次迭代中的资源申请量为: 41.77632754027569
# agent 50 在 49 次迭代中的资源申请量为: 40.23013931718636
# agent 51 在 49 次迭代中的资源申请量为: 47.4061338735364
# agent 52 在 49 次迭代中的资源申请量为: 54.692222364198024
# agent 53 在 49 次迭代中的资源申请量为: 38.31730179902142
# agent 54 在 49 次迭代中的资源申请量为: 56.178530968897775
# agent 55 在 49 次迭代中的资源申请量为: 69.7297384703158
# agent 56 在 49 次迭代中的资源申请量为: 40.325016437056846
# agent 57 在 49 次迭代中的资源申请量为: 59.47955572232786
# agent 58 在 49 次迭代中的资源申请量为: 41.51396361934673
# agent 59 在 49 次迭代中的资源申请量为: 47.124517218231375
# agent 60 在 49 次迭代中的资源申请量为: 55.081105218111944
# agent 61 在 49 次迭代中的资源申请量为: 64.60276924906117
# agent 62 在 49 次迭代中的资源申请量为: 45.31473071955405
# agent 63 在 49 次迭代中的资源申请量为: 38.387832849508044
# agent 64 在 49 次迭代中的资源申请量为: 43.64386635221071
# agent 65 在 49 次迭代中的资源申请量为: 41.93296781331244
# agent 66 在 49 次迭代中的资源申请量为: 64.13263545958031
# agent 67 在 49 次迭代中的资源申请量为: 42.62109163541627
# agent 68 在 49 次迭代中的资源申请量为: 44.13789367943874
# agent 69 在 49 次迭代中的资源申请量为: 44.6718290584669
# agent 70 在 49 次迭代中的资源申请量为: 58.90533078152674
# agent 71 在 49 次迭代中的资源申请量为: 70.29342901762301
# agent 72 在 49 次迭代中的资源申请量为: 58.9884902324853
# agent 73 在 49 次迭代中的资源申请量为: 42.875434689519295
# agent 74 在 49 次迭代中的资源申请量为: 38.35147158725813
# agent 75 在 49 次迭代中的资源申请量为: 51.068996315192905
# agent 76 在 49 次迭代中的资源申请量为: 46.160842814308594
# agent 77 在 49 次迭代中的资源申请量为: 40.094859105435326
# agent 78 在 49 次迭代中的资源申请量为: 48.81108920105182
# agent 79 在 49 次迭代中的资源申请量为: 42.219454660964665
# agent 80 在 49 次迭代中的资源申请量为: 42.19201404411776
# agent 81 在 49 次迭代中的资源申请量为: 38.91627815530533
# agent 82 在 49 次迭代中的资源申请量为: 45.04939369102548
# agent 83 在 49 次迭代中的资源申请量为: 40.93683610727725
# agent 84 在 49 次迭代中的资源申请量为: 51.10117254982066
# agent 85 在 49 次迭代中的资源申请量为: 54.72232049163537
# agent 86 在 49 次迭代中的资源申请量为: 48.094898313821
# agent 87 在 49 次迭代中的资源申请量为: 59.33476495001402
# agent 88 在 49 次迭代中的资源申请量为: 63.75204321752331
# agent 89 在 49 次迭代中的资源申请量为: 39.67780414811845
# agent 90 在 49 次迭代中的资源申请量为: 58.19131103915061
# agent 91 在 49 次迭代中的资源申请量为: 42.138064343057025
# agent 92 在 49 次迭代中的资源申请量为: 56.043437959845136
# agent 93 在 49 次迭代中的资源申请量为: 40.12889683311533
# agent 94 在 49 次迭代中的资源申请量为: 71.82831573511052
# agent 95 在 49 次迭代中的资源申请量为: 59.11022321407767
# agent 96 在 49 次迭代中的资源申请量为: 59.29595071686458
# agent 97 在 49 次迭代中的资源申请量为: 70.65310435334807
# agent 98 在 49 次迭代中的资源申请量为: 71.66489528650345
# agent 99 在 49 次迭代中的资源申请量为: 51.51550151825441
# agent 100 在 49 次迭代中的资源申请量为: 47.75719931857791
# 资源申请量总和为: 4946.68255271659
# ****************************************************************************
# 成本总和为: 326711.0515970169
# ****************************************************************************
# agent 1 在 49 次迭代中的对偶变量为: -137.7879163814591
# agent 2 在 49 次迭代中的对偶变量为: -137.3749368526003
# agent 3 在 49 次迭代中的对偶变量为: -137.678865481319
# agent 4 在 49 次迭代中的对偶变量为: -137.64236064381325
# agent 5 在 49 次迭代中的对偶变量为: -137.57917022562006
# agent 6 在 49 次迭代中的对偶变量为: -137.07836876332254
# agent 7 在 49 次迭代中的对偶变量为: -137.7939690148648
# agent 8 在 49 次迭代中的对偶变量为: -137.81885586359397
# agent 9 在 49 次迭代中的对偶变量为: -137.55628213112186
# agent 10 在 49 次迭代中的对偶变量为: -137.5766760836879
# agent 11 在 49 次迭代中的对偶变量为: -137.81755932681304
# agent 12 在 49 次迭代中的对偶变量为: -137.52019559675114
# agent 13 在 49 次迭代中的对偶变量为: -137.28835639608664
# agent 14 在 49 次迭代中的对偶变量为: -137.9854357337343
# agent 15 在 49 次迭代中的对偶变量为: -137.9347719054022
# agent 16 在 49 次迭代中的对偶变量为: -137.96679153060768
# agent 17 在 49 次迭代中的对偶变量为: -138.01417901743716
# agent 18 在 49 次迭代中的对偶变量为: -138.17723359131767
# agent 19 在 49 次迭代中的对偶变量为: -137.78686542377062
# agent 20 在 49 次迭代中的对偶变量为: -137.7195719723749
# agent 21 在 49 次迭代中的对偶变量为: -137.49459380908954
# agent 22 在 49 次迭代中的对偶变量为: -137.84567480724397
# agent 23 在 49 次迭代中的对偶变量为: -138.33416983468368
# agent 24 在 49 次迭代中的对偶变量为: -137.82452203449216
# agent 25 在 49 次迭代中的对偶变量为: -137.63598448249772
# agent 26 在 49 次迭代中的对偶变量为: -138.24752259039613
# agent 27 在 49 次迭代中的对偶变量为: -137.68274143603762
# agent 28 在 49 次迭代中的对偶变量为: -137.23973049226356
# agent 29 在 49 次迭代中的对偶变量为: -137.84932861636145
# agent 30 在 49 次迭代中的对偶变量为: -138.32580537391232
# agent 31 在 49 次迭代中的对偶变量为: -137.85967473823302
# agent 32 在 49 次迭代中的对偶变量为: -137.44049468086118
# agent 33 在 49 次迭代中的对偶变量为: -136.95006272564825
# agent 34 在 49 次迭代中的对偶变量为: -137.69304645170973
# agent 35 在 49 次迭代中的对偶变量为: -137.5199585511328
# agent 36 在 49 次迭代中的对偶变量为: -137.53881821999335
# agent 37 在 49 次迭代中的对偶变量为: -137.54236179045688
# agent 38 在 49 次迭代中的对偶变量为: -137.7566462675597
# agent 39 在 49 次迭代中的对偶变量为: -137.76977006988437
# agent 40 在 49 次迭代中的对偶变量为: -137.86136035804574
# agent 41 在 49 次迭代中的对偶变量为: -137.40578956884949
# agent 42 在 49 次迭代中的对偶变量为: -137.45755694746555
# agent 43 在 49 次迭代中的对偶变量为: -137.10626437318192
# agent 44 在 49 次迭代中的对偶变量为: -138.1057431062508
# agent 45 在 49 次迭代中的对偶变量为: -137.55585464356577
# agent 46 在 49 次迭代中的对偶变量为: -137.9919879332695
# agent 47 在 49 次迭代中的对偶变量为: -137.70549701160164
# agent 48 在 49 次迭代中的对偶变量为: -137.48849665832162
# agent 49 在 49 次迭代中的对偶变量为: -136.93951363693733
# agent 50 在 49 次迭代中的对偶变量为: -137.6285015418709
# agent 51 在 49 次迭代中的对偶变量为: -137.4184016206092
# agent 52 在 49 次迭代中的对偶变量为: -137.51977814691486
# agent 53 在 49 次迭代中的对偶变量为: -137.6257468362814
# agent 54 在 49 次迭代中的对偶变量为: -138.26418051913421
# agent 55 在 49 次迭代中的对偶变量为: -137.65947694063158
# agent 56 在 49 次迭代中的对偶变量为: -137.97005917340465
# agent 57 在 49 次迭代中的对偶变量为: -137.95093373358685
# agent 58 在 49 次迭代中的对偶变量为: -137.7474763057789
# agent 59 在 49 次迭代中的对偶变量为: -137.77355165469413
# agent 60 在 49 次迭代中的对偶变量为: -137.75087356709105
# agent 61 在 49 次迭代中的对偶变量为: -137.28609234793458
# agent 62 在 49 次迭代中的对偶变量为: -137.64713830257298
# agent 63 在 49 次迭代中的对偶变量为: -137.89376482813057
# agent 64 在 49 次迭代中的对偶变量为: -137.74037232707428
# agent 65 在 49 次迭代中的对偶变量为: -137.47209056526228
# agent 66 在 49 次迭代中的对偶变量为: -136.91179801107668
# agent 67 在 49 次迭代中的对偶变量为: -137.77171156041533
# agent 68 在 49 次迭代中的对偶变量为: -137.72125977420396
# agent 69 在 49 次迭代中的对偶变量为: -137.82985298709409
# agent 70 在 49 次迭代中的对偶变量为: -137.53279387566417
# agent 71 在 49 次迭代中的对偶变量为: -136.786858035246
# agent 72 在 49 次迭代中的对偶变量为: -137.2523765579647
# agent 73 在 49 次迭代中的对偶变量为: -137.2764779443656
# agent 74 在 49 次迭代中的对偶变量为: -137.7555920315809
# agent 75 在 49 次迭代中的对偶变量为: -137.67318968254014
# agent 76 在 49 次迭代中的对偶变量为: -137.4746970057875
# agent 77 在 49 次迭代中的对偶变量为: -137.50149277956717
# agent 78 在 49 次迭代中的对偶变量为: -137.73326760315547
# agent 79 在 49 次迭代中的对偶变量为: -138.10614584727986
# agent 80 在 49 次迭代中的对偶变量为: -137.33284775000038
# agent 81 在 49 次迭代中的对偶变量为: -138.00185699016023
# agent 82 在 49 次迭代中的对偶变量为: -138.07805981128152
# agent 83 在 49 次迭代中的对偶变量为: -137.65260998619812
# agent 84 在 49 次迭代中的对偶变量为: -137.48328313949784
# agent 85 在 49 次迭代中的对偶变量为: -137.59803327825196
# agent 86 在 49 次迭代中的对偶变量为: -137.684694941463
# agent 87 在 49 次迭代中的对偶变量为: -137.60343588003363
# agent 88 在 49 次迭代中的对偶变量为: -137.17449507855127
# agent 89 在 49 次迭代中的对偶变量为: -137.08009493322643
# agent 90 在 49 次迭代中的对偶变量为: -137.73914649396147
# agent 91 在 49 次迭代中的对偶变量为: -137.48941876639387
# agent 92 在 49 次迭代中的对偶变量为: -137.91293869559735
# agent 93 在 49 次迭代中的对偶变量为: -137.98402859921518
# agent 94 在 49 次迭代中的对偶变量为: -137.45663147022105
# agent 95 在 49 次迭代中的对偶变量为: -137.3045357137864
# agent 96 在 49 次迭代中的对偶变量为: -137.270281720475
# agent 97 在 49 次迭代中的对偶变量为: -137.10620870669615
# agent 98 在 49 次迭代中的对偶变量为: -137.5297905730069
# agent 99 在 49 次迭代中的对偶变量为: -137.52340425111234
# agent 100 在 49 次迭代中的对偶变量为: -137.87159795573373
# *************************
# 迭代步长为: 0.09680155905721156
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: 49.14414194937925
# agent 2 在 99 次迭代中的资源申请量为: 61.78842233575381
# agent 3 在 99 次迭代中的资源申请量为: 44.440801947074725
# agent 4 在 99 次迭代中的资源申请量为: 65.45090166497303
# agent 5 在 99 次迭代中的资源申请量为: 66.23089232707838
# agent 6 在 99 次迭代中的资源申请量为: 72.92399516672002
# agent 7 在 99 次迭代中的资源申请量为: 40.05718642032559
# agent 8 在 99 次迭代中的资源申请量为: 38.28870615082818
# agent 9 在 99 次迭代中的资源申请量为: 43.715527627049156
# agent 10 在 99 次迭代中的资源申请量为: 56.58798299208022
# agent 11 在 99 次迭代中的资源申请量为: 46.185258658689015
# agent 12 在 99 次迭代中的资源申请量为: 49.983447945748644
# agent 13 在 99 次迭代中的资源申请量为: 66.64196836766652
# agent 14 在 99 次迭代中的资源申请量为: 56.0944641047679
# agent 15 在 99 次迭代中的资源申请量为: 44.191868226519475
# agent 16 在 99 次迭代中的资源申请量为: 44.398355999692356
# agent 17 在 99 次迭代中的资源申请量为: 45.626824155199856
# agent 18 在 99 次迭代中的资源申请量为: 47.26189772697445
# agent 19 在 99 次迭代中的资源申请量为: 41.93687054453486
# agent 20 在 99 次迭代中的资源申请量为: 56.52595786099202
# agent 21 在 99 次迭代中的资源申请量为: 39.303587180517205
# agent 22 在 99 次迭代中的资源申请量为: 39.66639403224189
# agent 23 在 99 次迭代中的资源申请量为: 48.66779610402474
# agent 24 在 99 次迭代中的资源申请量为: 41.14351441446683
# agent 25 在 99 次迭代中的资源申请量为: 45.8466049925277
# agent 26 在 99 次迭代中的资源申请量为: 40.438008400716306
# agent 27 在 99 次迭代中的资源申请量为: 66.46288623962624
# agent 28 在 99 次迭代中的资源申请量为: 51.9992916440384
# agent 29 在 99 次迭代中的资源申请量为: 41.448041966635316
# agent 30 在 99 次迭代中的资源申请量为: 39.85209187648884
# agent 31 在 99 次迭代中的资源申请量为: 61.324815423653085
# agent 32 在 99 次迭代中的资源申请量为: 56.252395065880215
# agent 33 在 99 次迭代中的资源申请量为: 42.07845600824601
# agent 34 在 99 次迭代中的资源申请量为: 53.010075642324125
# agent 35 在 99 次迭代中的资源申请量为: 39.40819951430517
# agent 36 在 99 次迭代中的资源申请量为: 43.41247291886379
# agent 37 在 99 次迭代中的资源申请量为: 53.27306044258778
# agent 38 在 99 次迭代中的资源申请量为: 40.93096998659825
# agent 39 在 99 次迭代中的资源申请量为: 43.95911409371408
# agent 40 在 99 次迭代中的资源申请量为: 50.86091630917104
# agent 41 在 99 次迭代中的资源申请量为: 67.0781410946819
# agent 42 在 99 次迭代中的资源申请量为: 43.0959364448421
# agent 43 在 99 次迭代中的资源申请量为: 52.36719634222393
# agent 44 在 99 次迭代中的资源申请量为: 53.81022129111134
# agent 45 在 99 次迭代中的资源申请量为: 48.89149458754871
# agent 46 在 99 次迭代中的资源申请量为: 56.696500581294835
# agent 47 在 99 次迭代中的资源申请量为: 46.5611668888713
# agent 48 在 99 次迭代中的资源申请量为: 44.00205860397719
# agent 49 在 99 次迭代中的资源申请量为: 43.192139716667185
# agent 50 在 99 次迭代中的资源申请量为: 41.50633921991785
# agent 51 在 99 次迭代中的资源申请量为: 48.95956480917723
# agent 52 在 99 次迭代中的资源申请量为: 56.47321724325376
# agent 53 在 99 次迭代中的资源申请量为: 39.52718895601618
# agent 54 在 99 次迭代中的资源申请量为: 57.868054956108736
# agent 55 在 99 次迭代中的资源申请量为: 72.02245214718974
# agent 56 在 99 次迭代中的资源申请量为: 41.57127699113716
# agent 57 在 99 次迭代中的资源申请量为: 61.35127833702348
# agent 58 在 99 次迭代中的资源申请量为: 42.85418531001319
# agent 59 在 99 次迭代中的资源申请量为: 48.640849127986804
# agent 60 在 99 次迭代中的资源申请量为: 56.83355758749869
# agent 61 在 99 次迭代中的资源申请量为: 66.74130058850214
# agent 62 在 99 次迭代中的资源申请量为: 46.74891852893861
# agent 63 在 99 次迭代中的资源申请量为: 39.57460023624586
# agent 64 在 99 次迭代中的资源申请量为: 45.06808009288883
# agent 65 在 99 次迭代中的资源申请量为: 43.299065331377264
# agent 66 在 99 次迭代中的资源申请量为: 66.32493416510042
# agent 67 在 99 次迭代中的资源申请量为: 43.958581206191226
# agent 68 在 99 次迭代中的资源申请量为: 45.56418864189789
# agent 69 在 99 次迭代中的资源申请量为: 46.087862506929746
# agent 70 在 99 次迭代中的资源申请量为: 60.83229829605116
# agent 71 在 99 次迭代中的资源申请量为: 72.72500686475838
# agent 72 在 99 次迭代中的资源申请量为: 60.952993425903934
# agent 73 在 99 次迭代中的资源申请量为: 44.26005987026104
# agent 74 在 99 次迭代中的资源申请量为: 39.55005082276796
# agent 75 在 99 次迭代中的资源申请量为: 52.70446630367207
# agent 76 在 99 次迭代中的资源申请量为: 47.612007210815186
# agent 77 在 99 次迭代中的资源申请量为: 41.38218701309115
# agent 78 在 99 次迭代中的资源申请量为: 50.33155075776414
# agent 79 在 99 次迭代中的资源申请量为: 43.52623259539455
# agent 80 在 99 次迭代中的资源申请量为: 43.57118334548241
# agent 81 在 99 次迭代中的资源申请量为: 40.09402593113121
# agent 82 在 99 次迭代中的资源申请量为: 46.44069199476691
# agent 83 在 99 次迭代中的资源申请量为: 42.21122820488916
# agent 84 在 99 次迭代中的资源申请量为: 52.758522995762284
# agent 85 在 99 次迭代中的资源申请量为: 56.492968766228216
# agent 86 在 99 次迭代中的资源申请量为: 49.62004308793519
# agent 87 在 99 次迭代中的资源申请量为: 61.25231711894865
# agent 88 在 99 次迭代中的资源申请量为: 65.90643041346645
# agent 89 在 99 次迭代中的资源申请量为: 41.002815170892845
# agent 90 在 99 次迭代中的资源申请量为: 60.09081472449702
# agent 91 在 99 次迭代中的资源申请量为: 43.502687735877515
# agent 92 在 99 次迭代中的资源申请量为: 57.77587499870661
# agent 93 在 99 次迭代中的资源申请量为: 41.37401863217501
# agent 94 在 99 次迭代中的资源申请量为: 74.15250731252719
# agent 95 在 99 次迭代中的资源申请量为: 61.06748813452936
# agent 96 在 99 次迭代中的资源申请量为: 61.25810872062277
# agent 97 在 99 次迭代中的资源申请量为: 73.03358524620515
# agent 98 在 99 次迭代中的资源申请量为: 73.9780180473626
# agent 99 在 99 次迭代中的资源申请量为: 53.168470138574975
# agent 100 在 99 次迭代中的资源申请量为: 49.26256995427203
# 资源申请量总和为: 5105.375739798621
# ****************************************************************************
# 成本总和为: 348913.55002927355
# ****************************************************************************
# agent 1 在 99 次迭代中的对偶变量为: -142.33242584813775
# agent 2 在 99 次迭代中的对偶变量为: -142.05221360580913
# agent 3 在 99 次迭代中的对偶变量为: -142.25872662005406
# agent 4 在 99 次迭代中的对偶变量为: -142.23198366294068
# agent 5 在 99 次迭代中的对偶变量为: -142.18796311957243
# agent 6 在 99 次迭代中的对偶变量为: -141.84799033344004
# agent 7 在 99 次迭代中的对偶变量为: -142.33730839723725
# agent 8 在 99 次迭代中的对偶变量为: -142.35482460331272
# agent 9 在 99 次迭代中的对偶变量为: -142.1727939319671
# agent 10 在 99 次迭代中的对偶变量为: -142.18875577940858
# agent 11 在 99 次迭代中的对偶变量为: -142.35282770780486
# agent 12 在 99 次迭代中的对偶变量为: -142.1503438372459
# agent 13 在 99 次迭代中的对偶变量为: -141.99233040886637
# agent 14 在 99 次迭代中的对偶变量为: -142.46560667239655
# agent 15 在 99 次迭代中的对偶变量为: -142.43235197016622
# agent 16 在 99 次迭代中的对偶变量为: -142.454410398954
# agent 17 在 99 次迭代中的对偶变量为: -142.48583729663955
# agent 18 在 99 次迭代中的对偶变量为: -142.59807272631826
# agent 19 在 99 次迭代中的对偶变量为: -142.3327339603255
# agent 20 在 99 次迭代中的对偶变量为: -142.28749043857925
# agent 21 在 99 次迭代中的对偶变量为: -142.13363128596538
# agent 22 在 99 次迭代中的对偶变量为: -142.37229732251916
# agent 23 在 99 次迭代中的对偶变量为: -142.7033883120742
# agent 24 在 99 次迭代中的对偶变量为: -142.3566518920806
# agent 25 在 99 次迭代中的对偶变量为: -142.22913597608866
# agent 26 在 99 次迭代中的对偶变量为: -142.64443192272194
# agent 27 在 99 次迭代中的对偶变量为: -142.25834972717774
# agent 28 在 99 次迭代中的对偶变量为: -141.95801660330753
# agent 29 在 99 次迭代中的对偶变量为: -142.37295107988714
# agent 30 在 99 次迭代中的对偶变量为: -142.69794913065758
# agent 31 在 99 次迭代中的对偶变量为: -142.3795570167674
# agent 32 在 99 次迭代中的对偶变量为: -142.09622717128858
# agent 33 在 99 次迭代中的对偶变量为: -141.76244162968564
# agent 34 在 99 次迭代中的对偶变量为: -142.26821179850754
# agent 35 在 99 次迭代中的对偶变量为: -142.15115815435962
# agent 36 在 99 次迭代中的对偶变量为: -142.1624079241369
# agent 37 在 99 次迭代中的对偶变量为: -142.16456923924576
# agent 38 在 99 次迭代中的对偶变量为: -142.3114919517537
# agent 39 在 99 次迭代中的对偶变量为: -142.32098791862788
# agent 40 在 99 次迭代中的对偶变量为: -142.38274892751312
# agent 41 在 99 次迭代中的对偶变量为: -142.0719104083002
# agent 42 在 99 次迭代中的对偶变量为: -142.10618391246317
# agent 43 在 99 次迭代中的对偶变量为: -141.868149758227
# agent 44 在 99 次迭代中的对偶变量为: -142.54861961511173
# agent 45 在 99 次迭代中的对偶变量为: -142.17448376264613
# agent 46 在 99 次迭代中的对偶变量为: -142.47090151136658
# agent 47 在 99 次迭代中的对偶变量为: -142.27573404438817
# agent 48 在 99 次迭代中的对偶变量为: -142.12699925352246
# agent 49 在 99 次迭代中的对偶变量为: -141.75327503666844
# agent 50 在 99 次迭代中的对偶变量为: -142.22282119170427
# agent 51 在 99 次迭代中的对偶变量为: -142.07869442753167
# agent 52 在 99 次迭代中的对偶变量为: -142.15036483245976
# agent 53 在 99 次迭代中的对偶变量为: -142.2233180328615
# agent 54 在 99 次迭代中的对偶变量为: -142.6569428858827
# agent 55 在 99 次迭代中的对偶变量为: -142.24490429437947
# agent 56 在 99 次迭代中的对偶变量为: -142.4565971680938
# agent 57 在 99 次迭代中的对偶变量为: -142.44306800885633
# agent 58 在 99 次迭代中的对偶变量为: -142.30423005404484
# agent 59 在 99 次迭代中的对偶变量为: -142.32254738396043
# agent 60 在 99 次迭代中的对偶变量为: -142.30724972749658
# agent 61 在 99 次迭代中的对偶变量为: -141.99086129470473
# agent 62 在 99 次迭代中的对偶变量为: -142.23653929260354
# agent 63 在 99 次迭代中的对偶变量为: -142.40348089773425
# agent 64 在 99 次迭代中的对偶变量为: -142.29785629724427
# agent 65 在 99 次迭代中的对偶变量为: -142.1168221266827
# agent 66 在 99 次迭代中的对偶变量为: -141.7348551632209
# agent 67 在 99 次迭代中的对偶变量为: -142.31917610105018
# agent 68 在 99 次迭代中的对偶变量为: -142.28540365407326
# agent 69 在 99 次迭代中的对偶变量为: -142.3611600221752
# agent 70 在 99 次迭代中的对偶变量为: -142.15751591052276
# agent 71 在 99 次迭代中的对偶变量为: -141.65001372951676
# agent 72 在 99 次迭代中的对偶变量为: -141.96718422216944
# agent 73 在 99 次迭代中的对偶变量为: -141.98420355888751
# agent 74 在 99 次迭代中的对偶变量为: -142.31019312651824
# agent 75 在 99 次迭代中的对偶变量为: -142.2525056502818
# agent 76 在 99 次迭代中的对偶变量为: -142.1184230746086
# agent 77 在 99 次迭代中的对偶变量为: -142.13587324712813
# agent 78 在 99 次迭代中的对偶变量为: -142.29465227329243
# agent 79 在 99 次迭代中的对偶变量为: -142.54919082434148
# agent 80 在 99 次迭代中的对偶变量为: -142.02202337464018
# agent 81 在 99 次迭代中的对偶变量为: -142.4772985382986
# agent 82 在 99 次迭代中的对偶变量为: -142.5302143832541
# agent 83 在 99 次迭代中的对偶变量为: -142.24042153760098
# agent 84 在 99 次迭代中的对偶变量为: -142.1238643881344
# agent 85 在 99 次迭代中的对偶变量为: -142.20171879219336
# agent 86 在 99 次迭代中的对偶变量为: -142.26012926380557
# agent 87 在 99 次迭代中的对偶变量为: -142.20556108547675
# agent 88 在 99 次迭代中的对偶变量为: -141.9141469096262
# agent 89 在 99 次迭代中的对偶变量为: -141.85013461521424
# agent 90 在 99 次迭代中的对偶变量为: -142.29795533879286
# agent 91 在 99 次迭代中的对偶变量为: -142.12913830198355
# agent 92 在 99 次迭代中的对偶变量为: -142.4172749966372
# agent 93 在 99 次迭代中的对偶变量为: -142.46646707583005
# agent 94 在 99 次迭代中的对偶变量为: -142.1050146250544
# agent 95 在 99 次迭代中的对偶变量为: -142.00197152287046
# agent 96 在 99 次迭代中的对偶变量为: -141.97946092949465
# agent 97 在 99 次迭代中的对偶变量为: -141.8671704924103
# agent 98 在 99 次迭代中的对偶变量为: -142.15603609472518
# agent 99 在 99 次迭代中的对偶变量为: -142.15171638800993
# agent 100 在 99 次迭代中的对偶变量为: -142.38770986281608
# *************************
# 迭代步长为: 0.06347736393621072
# ****************************************************************************
# 149 次迭代中的结果：
# agent 1 在 149 次迭代中的资源申请量为: 49.48799484428189
# agent 2 在 149 次迭代中的资源申请量为: 62.24288044296841
# agent 3 在 149 次迭代中的资源申请量为: 44.74879404995499
# agent 4 在 149 次迭代中的资源申请量为: 65.92920058915922
# agent 5 在 149 次迭代中的资源申请量为: 66.71331037393925
# agent 6 在 149 次迭代中的资源申请量为: 73.49056257509618
# agent 7 在 149 次迭代中的资源申请量为: 40.328416234876926
# agent 8 在 149 次迭代中的资源申请量为: 38.54548198773162
# agent 9 在 149 次迭代中的资源申请量为: 44.02864417479435
# agent 10 在 149 次迭代中的资源申请量为: 56.99637605336461
# agent 11 在 149 次迭代中的资源申请量为: 46.50627601090047
# agent 12 在 149 次迭代中的资源申请量为: 50.3400546451361
# agent 13 在 149 次迭代中的资源申请量为: 67.1433217970276
# agent 14 在 149 次迭代中的资源申请量为: 56.48029554858582
# agent 15 在 149 次迭代中的资源申请量为: 44.489061200034485
# agent 16 在 149 次迭代中的资源申请量为: 44.694195814112994
# agent 17 在 149 次迭代中的资源申请量为: 45.939032809996036
# agent 18 在 149 次迭代中的资源申请量为: 47.5668095256437
# agent 19 在 149 次迭代中的资源申请量为: 42.22345822679548
# agent 20 在 149 次迭代中的资源申请量为: 56.926481856577844
# agent 21 在 149 次迭代中的资源申请量为: 39.586117957722806
# agent 22 在 149 次迭代中的资源申请量为: 39.93566826818238
# agent 23 在 149 次迭代中的资源申请量为: 48.985550009146635
# agent 24 在 149 次迭代中的资源申请量为: 41.42860581619532
# agent 25 在 149 次迭代中的资源申请量为: 46.17580485864242
# agent 26 在 149 次迭代中的资源申请量为: 40.69213596818917
# agent 27 在 149 次迭代中的资源申请量为: 66.93852468939838
# agent 28 在 149 次迭代中的资源申请量为: 52.395674284423556
# agent 29 在 149 次迭代中的资源申请量为: 41.73209277961749
# agent 30 在 149 次迭代中的资源申请量为: 40.10323406602798
# agent 31 在 149 次迭代中的资源申请量为: 61.750292146050626
# agent 32 在 149 次迭代中的资源申请量为: 56.66826617113607
# agent 33 在 149 次迭代中的资源申请量为: 42.3983270532066
# agent 34 在 149 次迭代中的资源申请量为: 53.38332215231267
# agent 35 在 149 次迭代中的资源申请量为: 39.68976732757871
# agent 36 在 149 次迭代中的资源申请量为: 43.72634065293752
# agent 37 在 149 次迭代中的资源申请量为: 53.653976882981404
# agent 38 在 149 次迭代中的资源申请量为: 41.218735029374294
# agent 39 在 149 次迭代中的资源申请量为: 44.26324096900273
# agent 40 在 149 次迭代中的资源申请量为: 51.20123247935562
# agent 41 在 149 次迭代中的资源申请量为: 67.57188765305807
# agent 42 在 149 次迭代中的资源申请量为: 43.41321802062242
# agent 43 在 149 次迭代中的资源申请量为: 52.77046250499109
# agent 44 在 149 次迭代中的资源申请量为: 54.16236025093098
# agent 45 在 149 次迭代中的资源申请量为: 49.24644722119583
# agent 46 在 149 次迭代中的资源申请量为: 57.08199348605319
# agent 47 在 149 次迭代中的资源申请量为: 46.88719353981371
# agent 48 在 149 次迭代中的资源申请量为: 44.318012218370484
# agent 49 在 149 次迭代中的资源申请量为: 43.53126250133434
# agent 50 在 149 次迭代中的资源申请量为: 41.79917509057724
# agent 51 在 149 次迭代中的资源申请量为: 49.321001769380906
# agent 52 在 149 次迭代中的资源申请量为: 56.884679789862375
# agent 53 在 149 次迭代中的资源申请量为: 39.80477388639469
# agent 54 在 149 次迭代中的资源申请量为: 58.23850456424148
# agent 55 在 149 次迭代中的资源申请量为: 72.54730360209223
# agent 56 在 149 次迭代中的资源申请量为: 41.850540740276
# agent 57 在 149 次迭代中的资源申请量为: 61.77132521147008
# agent 58 在 149 次迭代中的资源申请量为: 43.15926288366442
# agent 59 在 149 次迭代中的资源申请量为: 48.9853584395822
# agent 60 在 149 次迭代中的资源申请量为: 57.232312448961174
# agent 61 在 149 次迭代中的资源申请量为: 67.24279005398441
# agent 62 在 149 次迭代中的资源申请量为: 47.07753298891568
# agent 63 在 149 次迭代中的资源申请量为: 39.84204229086695
# agent 64 在 149 次迭代中的资源申请量为: 45.392534791868556
# agent 65 在 149 次迭代中的资源申请量为: 43.61576660407516
# agent 66 在 149 次迭代中的资源申请量为: 66.85085464926738
# agent 67 在 149 次迭代中的资源申请量为: 44.26262502329188
# agent 68 在 149 次迭代中的资源申请量为: 45.8894899457575
# agent 69 在 149 次迭代中的资源申请量为: 46.40831842185877
# agent 70 在 149 次迭代中的资源申请量为: 61.27726481032962
# agent 71 在 149 次迭代中的资源申请量为: 73.31244243864319
# agent 72 在 149 次迭代中的资源申请量为: 61.41472196327745
# agent 73 在 149 次迭代中的资源申请量为: 44.58497079629398
# agent 74 在 149 次迭代中的资源申请量为: 39.822677555770554
# agent 75 在 149 次迭代中的资源申请量为: 53.07864983446302
# agent 76 在 149 次迭代中的资源申请量为: 47.94834031104499
# agent 77 在 149 次迭代中的资源申请量为: 41.68008176345325
# agent 78 在 149 次迭代中的资源申请量为: 50.67791988763221
# agent 79 在 149 次迭代中的资源申请量为: 43.81619841700479
# agent 80 在 149 次迭代中的资源申请量为: 43.89372325173507
# agent 81 在 149 次迭代中的资源申请量为: 40.35739575548979
# agent 82 在 149 次迭代中的资源申请量为: 46.75001744095257
# agent 83 在 149 次迭代中的资源申请量为: 42.50313088717409
# agent 84 在 149 次迭代中的资源申请量为: 53.14246175560368
# agent 85 在 149 次迭代中的资源申请量为: 56.900111477673185
# agent 86 在 149 次迭代中的资源申请量为: 49.96877551668072
# agent 87 在 149 次迭代中的资源申请量为: 61.69311825770357
# agent 88 在 149 次迭代中的资源申请量为: 66.41517196176794
# agent 89 在 149 次迭代中的资源申请量为: 41.31751065715488
# agent 90 在 149 次迭代中的资源申请量为: 60.523448425383854
# agent 91 在 149 次迭代中的资源申请量为: 43.81864680881062
# agent 92 在 149 次迭代中的资源申请量为: 58.16570523548047
# agent 93 在 149 次迭代中的资源申请量为: 41.65276674833051
# agent 94 在 149 次迭代中的资源申请量为: 74.69186700358445
# agent 95 在 149 次迭代中的资源申请量为: 61.52610593581421
# agent 96 在 149 次迭代中的资源申请量为: 61.71879604834582
# agent 97 在 149 次迭代中的资源申请量为: 73.59811402247439
# agent 98 在 149 次迭代中的资源申请量为: 74.51217439663239
# agent 99 在 149 次迭代中的资源申请量为: 53.55039749068185
# agent 100 在 149 次迭代中的资源申请量为: 49.60239378118766
# 资源申请量总和为: 5141.821689551794
# ****************************************************************************
# 成本总和为: 354115.6155027925
# ****************************************************************************
# agent 1 在 149 次迭代中的对偶变量为: -143.36398453284568
# agent 2 在 149 次迭代中的对偶变量为: -143.14291306312418
# agent 3 在 149 次迭代中的对偶变量为: -143.30589976984695
# agent 4 在 149 次迭代中的对偶变量为: -143.2842412961503
# agent 5 在 149 次迭代中的对偶变量为: -143.24928282266634
# agent 6 在 149 次迭代中的对偶变量为: -142.98112515019236
# agent 7 在 149 次迭代中的对偶变量为: -143.3679816925323
# agent 8 在 149 次迭代中的对偶变量为: -143.38192795092647
# agent 9 在 149 次迭代中的对偶变量为: -143.2373901943008
# agent 10 在 149 次迭代中的对偶变量为: -143.25057773874798
# agent 11 在 149 次迭代中的对偶变量为: -143.3800832348815
# agent 12 在 149 次迭代中的对偶变量为: -143.2201639354083
# agent 13 在 149 次迭代中的对偶变量为: -143.09530795346072
# agent 14 在 149 次迭代中的对偶变量为: -143.46876842632315
# agent 15 在 149 次迭代中的对偶变量为: -143.44280808011726
# agent 16 在 149 次迭代中的对偶变量为: -143.46026576798417
# agent 17 在 149 次迭代中的对偶变量为: -143.48490499198732
# agent 18 在 149 次迭代中的对偶变量为: -143.57379048205985
# agent 19 在 149 次迭代中的对偶变量为: -143.3644496164637
# agent 20 在 149 次迭代中的对偶变量为: -143.3288528271024
# agent 21 在 149 次迭代中的对偶变量为: -143.20724823934665
# agent 22 在 149 次迭代中的对偶变量为: -143.39553941909307
# agent 23 在 149 次迭代中的对偶变量为: -143.6566500274399
# agent 24 在 149 次迭代中的对偶变量为: -143.38298093830318
# agent 25 在 149 次迭代中的对偶变量为: -143.28257554765577
# agent 26 在 149 次迭代中的对偶变量为: -143.61011667911882
# agent 27 在 149 次迭代中的对偶变量为: -143.30475431667642
# agent 28 在 149 次迭代中的对偶变量为: -143.06788799638596
# agent 29 在 149 次迭代中的对偶变量为: -143.39553400662297
# agent 30 在 149 次迭代中的对偶变量为: -143.6522894509063
# agent 31 在 149 次迭代中的对偶变量为: -143.40070115052148
# agent 32 在 149 次迭代中的对偶变量为: -143.1774920449538
# agent 33 在 149 次迭代中的对偶变量为: -142.91397739154377
# agent 34 在 149 次迭代中的对偶变量为: -143.31330202647547
# agent 35 在 149 次迭代中的对偶变量为: -143.22111584479907
# agent 36 在 149 次迭代中的对偶变量为: -143.22955821998758
# agent 37 在 149 次迭代中的对偶变量为: -143.23113527234793
# agent 38 在 149 次迭代中的对偶变量为: -143.34744610574748
# agent 39 在 149 次迭代中的对偶变量为: -143.3550192946093
# agent 40 在 149 次迭代中的对偶变量为: -143.40369743806687
# agent 41 在 149 次迭代中的对偶变量为: -143.15815283672777
# agent 42 在 149 次迭代中的对偶变量为: -143.18494127011624
# agent 43 在 149 次迭代中的对偶变量为: -142.99729501397505
# agent 44 在 149 次迭代中的对偶变量为: -143.53460870260673
# agent 45 在 149 次迭代中的对偶变量为: -143.23934166358748
# agent 46 在 149 次迭代中的对偶变量为: -143.4731830637383
# agent 47 在 149 次迭代中的对偶变量为: -143.31901932740388
# agent 48 在 149 次迭代中的对偶变量为: -143.20124154245966
# agent 49 在 149 次迭代中的对偶变量为: -142.90629250453676
# agent 50 在 149 次迭代中的对偶变量为: -143.2770303260781
# agent 51 在 149 次迭代中的对偶变量为: -143.16300530814271
# agent 52 在 149 次迭代中的对偶变量为: -143.22016745364218
# agent 53 在 149 次迭代中的对偶变量为: -143.27814076829983
# agent 54 在 149 次迭代中的对偶变量为: -143.62011186702784
# agent 55 在 149 次迭代中的对偶变量为: -143.29460720418444
# agent 56 在 149 次迭代中的对偶变量为: -143.46194666499363
# agent 57 在 149 次迭代中的对偶变量为: -143.45118050752816
# agent 58 在 149 次迭代中的对偶变量为: -143.34149380445902
# agent 59 在 149 次迭代中的对偶变量为: -143.3560753187466
# agent 60 在 149 次迭代中的对偶变量为: -143.34401236729906
# agent 61 在 149 次迭代中的对偶变量为: -143.0941381187657
# agent 62 在 149 次迭代中的对偶变量为: -143.28810556453016
# agent 63 在 149 次迭代中的对偶变量为: -143.4197607052944
# agent 64 在 149 次迭代中的对偶变量为: -143.3361113339794
# agent 65 在 149 次迭代中的对偶变量为: -143.19360645385555
# agent 66 在 149 次迭代中的对偶变量为: -142.89188022838823
# agent 67 在 149 次迭代中的对偶变量为: -143.3529250791924
# agent 68 在 149 次迭代中的对偶变量为: -143.326367826424
# agent 69 在 149 次迭代中的对偶变量为: -143.3866189499481
# agent 70 在 149 次迭代中的对偶变量为: -143.22543554479108
# agent 71 在 149 次迭代中的对偶变量为: -142.82488487728637
# agent 72 在 149 次迭代中的对偶变量为: -143.07533271186588
# agent 73 在 149 次迭代中的对偶变量为: -143.08890070739952
# agent 74 在 149 次迭代中的对偶变量为: -143.34617471192811
# agent 75 在 149 次迭代中的对偶变量为: -143.30021953649646
# agent 76 在 149 次迭代中的对偶变量为: -143.19468899534397
# agent 77 在 149 次迭代中的对偶变量为: -143.2082943484317
# agent 78 在 149 次迭代中的对偶变量为: -143.33375966289663
# agent 79 在 149 次迭代中的对偶变量为: -143.5350746178163
# agent 80 在 149 次迭代中的对偶变量为: -143.11865905589923
# agent 81 在 149 次迭代中的对偶变量为: -143.4781038708612
# agent 82 在 149 次迭代中的对偶变量为: -143.52005581104822
# agent 83 在 149 次迭代中的对偶变量为: -143.29127119382673
# agent 84 在 149 次迭代中的对偶变量为: -143.1988929156903
# agent 85 在 149 次迭代中的对偶变量为: -143.26028984195028
# agent 86 在 149 次迭代中的对偶变量为: -143.30632655004217
# agent 87 在 149 次迭代中的对偶变量为: -143.26348381848854
# agent 88 在 149 次迭代中的对偶变量为: -143.03337831588948
# agent 89 在 149 次迭代中的对偶变量为: -142.98303836575758
# agent 90 在 149 次迭代中的对偶变量为: -143.33627622092126
# agent 91 在 149 次迭代中的对偶变量为: -143.2033991499561
# agent 92 在 149 次迭代中的对偶变量为: -143.43083361224922
# agent 93 在 149 次迭代中的对偶变量为: -143.46996029398983
# agent 94 在 149 次迭代中的对偶变量为: -143.1837340071689
# agent 95 在 149 次迭代中的对偶变量为: -143.10265424595408
# agent 96 在 149 次迭代中的对偶变量为: -143.08511051602997
# agent 97 在 149 次迭代中的对偶变量为: -142.9962280449488
# agent 98 在 149 次迭代中的对偶变量为: -143.22434879326477
# agent 99 在 149 次迭代中的对偶变量为: -143.2211129739092
# agent 100 在 149 次迭代中的对偶变量为: -143.40718134356297
# *************************
# 迭代步长为: 0.04966932281851884
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: 49.60446386399094
# agent 2 在 199 次迭代中的资源申请量为: 62.40290322622677
# agent 3 在 199 次迭代中的资源申请量为: 44.85424496681603
# agent 4 在 199 次迭代中的资源申请量为: 66.09359475966635
# agent 5 在 199 次迭代中的资源申请量为: 66.88015810290551
# agent 6 在 199 次迭代中的资源申请量为: 73.69513853190614
# agent 7 在 199 次迭代中的资源申请量为: 40.420212978521164
# agent 8 在 199 次迭代中的资源申请量为: 38.63215352349711
# agent 9 在 199 次迭代中的资源申请量为: 44.13716067349834
# agent 10 在 199 次迭代中的资源申请量为: 57.137592589464134
# agent 11 在 199 次迭代中的资源申请量为: 46.6146709901909
# agent 12 在 199 次迭代中的资源申请量为: 50.464007722967786
# agent 13 在 199 次迭代中的资源申请量为: 67.3212111695814
# agent 14 在 199 次迭代中的资源申请量为: 56.60831004290111
# agent 15 在 199 次迭代中的资源申请量为: 44.588186195236105
# agent 16 在 199 次迭代中的资源申请量为: 44.79251998131047
# agent 17 在 199 次迭代中的资源申请量为: 46.042277497742674
# agent 18 在 199 次迭代中的资源申请量为: 47.66574005738459
# agent 19 在 199 次迭代中的资源申请量为: 42.32051885862442
# agent 20 在 199 次迭代中的资源申请量为: 57.06303507912011
# agent 21 在 199 次迭代中的资源申请量为: 39.68454651575752
# agent 22 在 199 次迭代中的资源申请量为: 40.02632146075399
# agent 23 在 199 次迭代中的资源申请量为: 49.08672130250975
# agent 24 在 199 次迭代中的资源申请量为: 41.52482539000182
# agent 25 在 199 次迭代中的资源申请量为: 46.28900510602282
# agent 26 在 199 次迭代中的资源申请量为: 40.773926352231015
# agent 27 在 199 次迭代中的资源申请量为: 67.10139733056685
# agent 28 在 199 次迭代中的资源申请量为: 52.53691883472254
# agent 29 在 199 次迭代中的资源申请量为: 41.82771510596818
# agent 30 在 199 次迭代中的资源申请量为: 40.183267892084864
# agent 31 在 199 次迭代中的资源申请量为: 61.89338771190051
# agent 32 在 199 次迭代中的资源申请量为: 56.81386752665504
# agent 33 在 199 次迭代中的资源申请量为: 42.51494155473948
# agent 34 在 199 次迭代中的资源申请量为: 53.5109374332038
# agent 35 在 199 次迭代中的资源申请量为: 39.787630116649055
# agent 36 在 199 次迭代中的资源申请量为: 43.83526322742983
# agent 37 在 199 次迭代中的资源申请量为: 53.786124994672434
# agent 38 在 199 次迭代中的资源申请量为: 41.31650244776353
# agent 39 在 199 次迭代中的资源申请量为: 44.36641419751961
# agent 40 在 199 次迭代中的资源申请量为: 51.31561805969647
# agent 41 在 199 次迭代中的资源申请量为: 67.74531513388389
# agent 42 在 199 次迭代中的资源申请量为: 43.52416651301538
# agent 43 在 199 次迭代中的资源申请量为: 52.915720065582754
# agent 44 在 199 次迭代中的资源申请量为: 54.27759884718231
# agent 45 在 199 次迭代中的资源申请量为: 49.369430976916334
# agent 46 在 199 次迭代中的资源申请量为: 57.20978394227972
# agent 47 在 199 次迭代中的资源申请量为: 46.998548608282796
# agent 48 在 199 次迭代中的资源申请量为: 44.42818677223438
# agent 49 在 199 次迭代中的资源申请量为: 43.655038425111634
# agent 50 在 199 次迭代中的资源申请量为: 41.899950661719046
# agent 51 在 199 次迭代中的资源申请量为: 49.44785151436076
# agent 52 在 199 次迭代中的资源申请量为: 57.02768850182647
# agent 53 在 199 次迭代中的资源申请量为: 39.90029074943238
# agent 54 在 199 次迭代中的资源申请量为: 58.357441484524514
# agent 55 在 199 次迭代中的资源申请量为: 72.72733771071144
# agent 56 在 199 次迭代中的资源申请量为: 41.94332062569841
# agent 57 在 199 次迭代中的资源申请量为: 61.91118785052085
# agent 58 在 199 次迭代中的资源申请量为: 43.26303082912579
# agent 59 在 199 次迭代中的资源申请量为: 49.10222050189703
# agent 60 在 199 次迭代中的资源申请量为: 57.36787464085171
# agent 61 在 199 次迭代中的资源申请量为: 67.42074854035219
# agent 62 在 199 次迭代中的资源申请量为: 47.19039520876128
# agent 63 在 199 次迭代中的资源申请量为: 39.931651950857315
# agent 64 在 199 次迭代中的资源申请量为: 45.50300710268381
# agent 65 在 199 次迭代中的资源申请量为: 43.726356414779985
# agent 66 在 199 次迭代中的资源申请量为: 67.04319867183715
# agent 67 在 199 次迭代中的资源申请量为: 44.365821429346255
# agent 68 在 199 次迭代中的资源申请量为: 46.00044560170649
# agent 69 在 199 次迭代中的资源申请量为: 46.516384906903205
# agent 70 在 199 次迭代中的资源申请量为: 61.4317868342453
# agent 71 在 199 次迭代中的资源申请量为: 73.5292512948669
# agent 72 在 199 次迭代中的资源申请量为: 61.57906561005259
# agent 73 在 199 次迭代中的资源申请量为: 44.70036818433808
# agent 74 在 199 次迭代中的资源申请量为: 39.915315399570645
# agent 75 在 199 次迭代中的资源申请量为: 53.206877274031505
# agent 76 在 199 次迭代中的资源申请量为: 48.065751638436545
# agent 77 在 199 次迭代中的资源申请量为: 41.783837441331805
# agent 78 在 199 次迭代中的资源申请量为: 50.79588201880958
# agent 79 在 199 次迭代中的资源申请量为: 43.911076083760975
# agent 80 在 199 次迭代中的资源申请量为: 44.007741292694064
# agent 81 在 199 次迭代中的资源申请量为: 40.44460982143944
# agent 82 在 199 次迭代中的资源申请量为: 46.851547918449064
# agent 83 在 199 次迭代中的资源申请量为: 42.603331889938126
# agent 84 在 199 次迭代中的资源申请量为: 53.27639811454404
# agent 85 在 199 次迭代中的资源申请量为: 57.04064241524923
# agent 86 在 199 次迭代中的资源申请量为: 50.08816345277679
# agent 87 在 199 次迭代中的资源申请量为: 61.845195879801246
# agent 88 在 199 次迭代中的资源申请量为: 66.59741472533668
# agent 89 在 199 次迭代中的资源申请量为: 41.43110522624377
# agent 90 在 199 次迭代中的资源申请量为: 60.67073103475437
# agent 91 在 199 次迭代中的资源申请量为: 43.92878877763837
# agent 92 在 199 次迭代中的资源申请量为: 58.29603741303728
# agent 93 在 199 次迭代中的资源申请量为: 41.74523629312906
# agent 94 在 199 次迭代中的资源申请量为: 74.88048993906172
# agent 95 在 199 次迭代中的资源申请量为: 61.688646525535155
# agent 96 在 199 次迭代中的资源申请量为: 61.88252593176226
# agent 97 在 199 次迭代中的资源申请量为: 73.80148543807785
# agent 98 在 199 次迭代中的资源申请量为: 74.69769390662744
# agent 99 在 199 次迭代中的资源申请量为: 53.683137039183215
# agent 100 在 199 次迭代中的资源申请量为: 49.71654183871866
# 资源申请量总和为: 5154.380104208226
# ****************************************************************************
# 成本总和为: 355917.0026591419
# ****************************************************************************
# agent 1 在 199 次迭代中的对偶变量为: -143.71339159197282
# agent 2 在 199 次迭代中的对偶变量为: -143.52696774294424
# agent 3 在 199 次迭代中的对偶变量为: -143.6644328871745
# agent 4 在 199 次迭代中的对偶变量为: -143.64590847126598
# agent 5 在 199 次迭代中的对偶变量为: -143.61634782639211
# agent 6 在 199 次迭代中的对偶变量为: -143.39027706381228
# agent 7 在 199 次迭代中的对偶变量为: -143.71680931838043
# agent 8 在 199 次迭代中的对偶变量为: -143.72861409398843
# agent 9 在 199 次迭代中的对偶变量为: -143.60634628989436
# agent 10 在 199 次迭代中的对偶变量为: -143.61774073260676
# agent 11 在 199 次迭代中的对偶变量为: -143.7269471686109
# agent 12 在 199 次迭代中的对偶变量为: -143.59202316890335
# agent 13 在 199 次迭代中的对偶变量为: -143.48666457307908
# agent 14 在 199 次迭代中的对偶变量为: -143.8016061115429
# agent 15 在 199 次迭代中的对偶变量为: -143.77983306380276
# agent 16 在 199 次迭代中的对偶变量为: -143.7945679364556
# agent 17 在 199 次迭代中的对偶变量为: -143.81528799277655
# agent 18 在 199 次迭代中的对偶变量为: -143.8903681836307
# agent 19 在 199 次迭代中的对偶变量为: -143.7138678910479
# agent 20 在 199 次迭代中的对偶变量为: -143.68389120571229
# agent 21 在 199 次迭代中的对偶变量为: -143.58127675987856
# agent 22 在 199 次迭代中的对偶变量为: -143.74002155086518
# agent 23 在 199 次迭代中的对偶变量为: -143.96016390752925
# agent 24 在 199 次迭代中的对偶变量为: -143.72937140400657
# agent 25 在 199 次迭代中的对偶变量为: -143.64481633927304
# agent 26 在 199 次迭代中的对偶变量为: -143.92092013847784
# agent 27 在 199 次迭代中的对偶变量为: -143.66307412724709
# agent 28 在 199 次迭代中的对偶变量为: -143.46337273722312
# agent 29 在 199 次迭代中的对偶变量为: -143.73977438148546
# agent 30 在 199 次迭代中的对偶变量为: -143.95641798992247
# agent 31 在 199 次迭代中的对偶变量为: -143.7441305085612
# agent 32 在 199 次迭代中的对偶变量为: -143.5560555693031
# agent 33 在 199 次迭代中的对偶变量为: -143.33378959706212
# agent 34 在 199 次迭代中的对偶变量为: -143.67062481297063
# agent 35 在 199 次迭代中的对偶变量为: -143.5929944432664
# agent 36 在 199 次迭代中的对偶变量为: -143.5998949732614
# agent 37 在 199 次迭代中的对偶变量为: -143.6011499850828
# agent 38 在 199 次迭代中的对偶变量为: -143.69940881194873
# agent 39 在 199 次迭代中的对偶变量为: -143.7058082715667
# agent 40 在 199 次迭代中的对偶变量为: -143.7468541790894
# agent 41 在 199 次迭代中的对偶变量为: -143.53969329454458
# agent 42 在 199 次迭代中的对偶变量为: -143.5621661442523
# agent 43 在 199 次迭代中的对偶变量为: -143.4040161836317
# agent 44 在 199 次迭代中的对偶变量为: -143.85727677211045
# agent 45 在 199 次迭代中的对偶变量为: -143.608292930749
# agent 46 在 199 次迭代中的对偶变量为: -143.80543824992728
# agent 47 在 199 次迭代中的对偶变量为: -143.67535554650496
# agent 48 在 199 次迭代中的对偶变量为: -143.57583502559692
# agent 49 在 199 次迭代中的对偶变量为: -143.32713064537955
# agent 50 在 199 次迭代中的对偶变量为: -143.63982238218858
# agent 51 在 199 次迭代中的对偶变量为: -143.54355454308225
# agent 52 在 199 次迭代中的对偶变量为: -143.59199010474882
# agent 53 在 199 次迭代中的对偶变量为: -143.64110484784305
# agent 54 在 199 次迭代中的对偶变量为: -143.92934785976374
# agent 55 在 199 次迭代中的对偶变量为: -143.65467542142287
# agent 56 在 199 次迭代中的对偶变量为: -143.7959542525143
# agent 57 在 199 次迭代中的对偶变量为: -143.78685084125001
# agent 58 在 199 次迭代中的对偶变量为: -143.69430481902768
# agent 59 在 199 次迭代中的对偶变量为: -143.7066615056911
# agent 60 在 199 次迭代中的对偶变量为: -143.69647406621445
# agent 61 在 199 次迭代中的对偶变量为: -143.48564678877483
# agent 62 在 199 次迭代中的对偶变量为: -143.64926466803612
# agent 63 在 199 次迭代中的对偶变量为: -143.7602774132578
# agent 64 在 199 次迭代中的对偶变量为: -143.6896227285882
# agent 65 在 199 次迭代中的对偶变量为: -143.56961181025196
# agent 66 在 199 次迭代中的对偶变量为: -143.31503707804174
# agent 67 在 199 次迭代中的对偶变量为: -143.70379285977728
# agent 68 在 199 次迭代中的对偶变量为: -143.68142592546076
# agent 69 在 199 次迭代中的对偶变量为: -143.73243170209025
# agent 70 在 199 次迭代中的对偶变量为: -143.59628840218872
# agent 71 在 199 次迭代中的对偶变量为: -143.25850258973378
# agent 72 在 199 次迭代中的对偶变量为: -143.46975746412622
# agent 73 在 199 次迭代中的对偶变量为: -143.48125182674949
# agent 74 在 199 次迭代中的对偶变量为: -143.69819851836846
# agent 75 在 199 次迭代中的对偶变量为: -143.6592563672882
# agent 76 在 199 次迭代中的对偶变量为: -143.57040524299694
# agent 77 在 199 次迭代中的对偶变量为: -143.5818147887945
# agent 78 在 199 次迭代中的对偶变量为: -143.68764605642875
# agent 79 在 199 次迭代中的对偶变量为: -143.8576586847873
# agent 80 在 199 次迭代中的对偶变量为: -143.5063203951598
# agent 81 在 199 次迭代中的对偶变量为: -143.80951732146988
# agent 82 在 199 次迭代中的对偶变量为: -143.844953339037
# agent 83 在 199 次迭代中的对偶变量为: -143.65199480377726
# agent 84 在 199 次迭代中的对偶变量为: -143.5739147207233
# agent 85 在 199 次迭代中的对偶变量为: -143.625670279648
# agent 86 在 199 次迭代中的对偶变量为: -143.66449035833037
# agent 87 在 199 次迭代中的对偶变量为: -143.62847011152297
# agent 88 在 199 次迭代中的对偶变量为: -143.43431239574068
# agent 89 在 199 次迭代中的对偶变量为: -143.3919788144776
# agent 90 在 199 次迭代中的对偶变量为: -143.6897544834105
# agent 91 在 199 次迭代中的对偶变量为: -143.57788184397043
# agent 92 在 199 次迭代中的对偶变量为: -143.76969727389692
# agent 93 在 199 次迭代中的对偶变量为: -143.80285065526462
# agent 94 在 199 次迭代中的对偶变量为: -143.56097987812345
# agent 95 在 199 次迭代中的对偶变量为: -143.49275166128436
# agent 96 在 199 次迭代中的对偶变量为: -143.47806223622942
# agent 97 在 199 次迭代中的对偶变量为: -143.4029708761557
# agent 98 在 199 次迭代中的对偶变量为: -143.59538781325486
# agent 99 在 199 次迭代中的对偶变量为: -143.592783709713
# agent 100 在 199 次迭代中的对偶变量为: -143.749625516156
# *************************
# 迭代步长为: 0.04175304505755262
# ****************************************************************************
# 249 次迭代中的结果：
# agent 1 在 249 次迭代中的资源申请量为: 49.65246689484493
# agent 2 在 249 次迭代中的资源申请量为: 62.47257713495342
# agent 3 在 249 次迭代中的资源申请量为: 44.8983966066774
# agent 4 在 249 次迭代中的资源申请量为: 66.16280909238347
# agent 5 在 249 次迭代中的资源申请量为: 66.95102767024143
# agent 6 在 249 次迭代中的资源申请量为: 73.7871895635957
# agent 7 在 249 次迭代中的资源申请量为: 40.45800349042459
# agent 8 在 249 次迭代中的资源申请量为: 38.667692236369795
# agent 9 在 249 次迭代中的资源申请量为: 44.18338754371426
# agent 10 在 249 次迭代中的资源申请量为: 57.19755790895905
# agent 11 在 249 次迭代中的资源申请量为: 46.6591406932112
# agent 12 在 249 次迭代中的资源申请量为: 50.5170293944999
# agent 13 在 249 次迭代中的资源申请量为: 67.3994613586149
# agent 14 在 249 次迭代中的资源申请量为: 56.65944005168675
# agent 15 在 249 次迭代中的资源申请量为: 44.62810209204833
# agent 16 在 249 次迭代中的资源申请量为: 44.83189740459293
# agent 17 在 249 次迭代中的资源申请量为: 46.083301080917074
# agent 18 在 249 次迭代中的资源申请量为: 47.703862006549805
# agent 19 在 249 次迭代中的资源申请量为: 42.36051659476102
# agent 20 在 249 次迭代中的资源申请量为: 57.11986052430132
# agent 21 在 249 次迭代中的资源申请量为: 39.72678132080324
# agent 22 在 249 次迭代中的资源申请量为: 40.063347085497945
# agent 23 在 249 次迭代中的资源申请量为: 49.12447666894243
# agent 24 在 249 次迭代中的资源申请量为: 41.56427035542135
# agent 25 在 249 次迭代中的资源申请量为: 46.33669302932532
# agent 26 在 249 次迭代中的资源申请量为: 40.805018827635266
# agent 27 在 249 次迭代中的资源申请量为: 67.16960580071297
# agent 28 在 249 次迭代中的资源申请量为: 52.59939958180832
# agent 29 在 249 次迭代中的资源申请量为: 41.86676737066133
# agent 30 在 249 次迭代中的资源申请量为: 40.21318389705144
# agent 31 在 249 次迭代中的资源申请量为: 61.95174260520085
# agent 32 在 249 次迭代中的资源申请量为: 56.876772554713405
# agent 33 在 249 次迭代中的资源申请量为: 42.568053944869064
# agent 34 在 249 次迭代中的资源申请量为: 53.56426293559468
# agent 35 在 249 次迭代中的资源申请量为: 39.82948616606713
# agent 36 在 249 次迭代中的资源申请量为: 43.881750767955445
# agent 37 在 249 次迭代中的资源申请量为: 53.84250113864583
# agent 38 在 249 次迭代中的资源申请量为: 41.356980346427044
# agent 39 在 249 次迭代中的资源申请量为: 44.40903867041404
# agent 40 在 249 次迭代中的资源申请量为: 51.3622240723896
# agent 41 在 249 次迭代中的资源申请量为: 67.82057198916335
# agent 42 在 249 次迭代中的资源申请量为: 43.57201951838874
# agent 43 在 249 次迭代中的资源申请量为: 52.980879096653474
# agent 44 在 249 次迭代中的资源申请量为: 54.32263081792176
# agent 45 在 249 次迭代中的资源申请量为: 49.42179990399408
# agent 46 在 249 次迭代中的资源申请量为: 57.26075469057356
# agent 47 在 249 次迭代中的资源申请量为: 47.045009092158914
# agent 48 在 249 次迭代中的资源申请量为: 44.47552424564666
# agent 49 在 249 次迭代中的资源申请量为: 43.71149177590612
# agent 50 在 249 次迭代中的资源申请量为: 41.942456682415816
# agent 51 在 249 次迭代中的资源申请量为: 49.50283552243972
# agent 52 在 249 次迭代中的资源申请量为: 57.08885674737375
# agent 53 在 249 次迭代中的资源申请量为: 39.940571082085825
# agent 54 在 249 次迭代中的资源申请量为: 58.402473029903454
# agent 55 在 249 次迭代中的资源申请量为: 72.80292597942749
# agent 56 在 249 次迭代中的资源申请量为: 41.980456433104536
# agent 57 在 249 次迭代中的资源申请量为: 61.9673604703443
# agent 58 在 249 次迭代中的资源申请量为: 43.30606416292302
# agent 59 在 249 次迭代中的资源申请量为: 49.15049052424481
# agent 60 在 249 次迭代中的资源申请量为: 57.42405292932506
# agent 61 在 249 次迭代中的资源申请量为: 67.49904211199484
# agent 62 在 249 次迭代中的资源申请量为: 47.23786412622411
# agent 63 在 249 次迭代中的资源申请量为: 39.967988939667684
# agent 64 在 249 次迭代中的资源申请量为: 45.54888856929596
# agent 65 在 249 次迭代中的资源申请量为: 43.773961332299066
# agent 66 在 249 次迭代中的资源申请量为: 67.13114564257367
# agent 67 在 249 次迭代中的资源申请量为: 44.40848319768894
# agent 68 在 249 次迭代中的资源申请量为: 46.04664757538278
# agent 69 在 249 次迭代中的资源申请量为: 46.56063540606475
# agent 70 在 249 次迭代中的资源申请量为: 61.49779908363853
# agent 71 在 249 次迭代中的资源申请量为: 73.62949890243527
# agent 72 在 249 次迭代中的资源申请量为: 61.651655199737796
# agent 73 在 249 次迭代中的资源申请量为: 44.75119476574633
# agent 74 在 249 次迭代中的资源申请量为: 39.953679476388835
# agent 75 在 249 次迭代中的资源申请量为: 53.26063722939446
# agent 76 在 249 次迭代中的资源申请量为: 48.11627581509852
# agent 77 在 249 次迭代中的资源申请量为: 41.828344154567084
# agent 78 在 249 次迭代中的资源申请量为: 50.844897179250886
# agent 79 在 249 次迭代中的资源申请量为: 43.948143647781386
# agent 80 在 249 次迭代中的资源申请量为: 44.05764667218092
# agent 81 在 249 次迭代中的资源申请量为: 40.47933908863668
# agent 82 在 249 次迭代中的资源申请量为: 46.891417324380356
# agent 83 在 249 次迭代中的资源申请量为: 42.645442911601094
# agent 84 在 249 次迭代中的资源申请量为: 53.333977343682406
# agent 85 在 249 次迭代中的资源申请量为: 57.100167560062026
# agent 86 在 249 次迭代中的资源申请量为: 50.13814298891979
# agent 87 在 249 次迭代中的资源申请量为: 61.90956616552838
# agent 88 在 249 次迭代中的资源申请量为: 66.67858962945816
# agent 89 在 249 次迭代中的资源申请量为: 41.4821987334341
# agent 90 在 249 次迭代中的资源申请量为: 60.731891103589675
# agent 91 在 249 次迭代中的资源申请量为: 43.976090607569674
# agent 92 在 249 次迭代中的资源申请量为: 58.34871182794552
# agent 93 在 249 次迭代中的资源申请量为: 41.782158968004865
# agent 94 在 249 次迭代中的资源申请量为: 74.96185936996645
# agent 95 在 249 次迭代中的资源申请量为: 61.76003410957427
# agent 96 在 249 次迭代中的资源申请量为: 61.95470129197787
# agent 97 在 249 次迭代中的资源申请量为: 73.89272962545927
# agent 98 在 249 次迭代中的资源申请量为: 74.7769655547895
# agent 99 在 249 次迭代中的资源申请量为: 53.739906321844764
# agent 100 在 249 次迭代中的资源申请量为: 49.76300449117419
# 资源申请量总和为: 5159.68662522249
# ****************************************************************************
# 成本总和为: 356679.52526566706
# ...
# agent 61 在 57999 次迭代中的资源申请量为: 45.35594989347403
# agent 62 在 57999 次迭代中的资源申请量为: 37.777916501990724
# agent 63 在 57999 次迭代中的资源申请量为: 44.36024833408177
# agent 64 在 57999 次迭代中的资源申请量为: 50.59248382563158
# agent 65 在 57999 次迭代中的资源申请量为: 48.719342447654434
# agent 66 在 57999 次迭代中的资源申请量为: 53.47780999250294
# agent 67 在 57999 次迭代中的资源申请量为: 44.62937911116489
# agent 68 在 57999 次迭代中的资源申请量为: 38.64566746179317
# agent 69 在 57999 次迭代中的资源申请量为: 49.892139157742264
# agent 70 在 57999 次迭代中的资源申请量为: 43.38409217370307
# agent 71 在 57999 次迭代中的资源申请量为: 51.072439614453316
# agent 72 在 57999 次迭代中的资源申请量为: 51.63101181607402
# agent 73 在 57999 次迭代中的资源申请量为: 68.52493850742536
# agent 74 在 57999 次迭代中的资源申请量为: 63.033563690013715
# agent 75 在 57999 次迭代中的资源申请量为: 68.784860310892
# agent 76 在 57999 次迭代中的资源申请量为: 65.84231131075826
# agent 77 在 57999 次迭代中的资源申请量为: 37.33178559067635
# agent 78 在 57999 次迭代中的资源申请量为: 56.51515954674519
# agent 79 在 57999 次迭代中的资源申请量为: 35.71319766839764
# agent 80 在 57999 次迭代中的资源申请量为: 41.69438982489503
# agent 81 在 57999 次迭代中的资源申请量为: 64.43288578237497
# agent 82 在 57999 次迭代中的资源申请量为: 45.64920279686928
# agent 83 在 57999 次迭代中的资源申请量为: 54.00548947849253
# agent 84 在 57999 次迭代中的资源申请量为: 52.98642785861979
# agent 85 在 57999 次迭代中的资源申请量为: 58.685757530611916
# agent 86 在 57999 次迭代中的资源申请量为: 54.16278250297388
# agent 87 在 57999 次迭代中的资源申请量为: 50.183947875573004
# agent 88 在 57999 次迭代中的资源申请量为: 53.40486804038364
# agent 89 在 57999 次迭代中的资源申请量为: 44.037016821613456
# agent 90 在 57999 次迭代中的资源申请量为: 38.995841039652966
# agent 91 在 57999 次迭代中的资源申请量为: 43.58677066582213
# agent 92 在 57999 次迭代中的资源申请量为: 45.25809138455365
# agent 93 在 57999 次迭代中的资源申请量为: 35.68321481266967
# agent 94 在 57999 次迭代中的资源申请量为: 37.48060785879904
# 资源申请量平均值avg为: 49.99999999999654
# ****************************************************************************
# 平均成本为: 3240.481984531225
# ****************************************************************************
# agent 1 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 2 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 3 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 4 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 5 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 6 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 7 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 8 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 9 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 10 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 11 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 12 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 13 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 14 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 15 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 16 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 17 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 18 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 19 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 20 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 21 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 22 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 23 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 24 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 25 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 26 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 27 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 28 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 29 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 30 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 31 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 32 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 33 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 34 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 35 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 36 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 37 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 38 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 39 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 40 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 41 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 42 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 43 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 44 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 45 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 46 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 47 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 48 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 49 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 50 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 51 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 52 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 53 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 54 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 55 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 56 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 57 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 58 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 59 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 60 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 61 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 62 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 63 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 64 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 65 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 66 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 67 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 68 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 69 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 70 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 71 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 72 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 73 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 74 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 75 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 76 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 77 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 78 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 79 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 80 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 81 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 82 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 83 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 84 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 85 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 86 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 87 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 88 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 89 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 90 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 91 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 92 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 93 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 94 在 57999 次迭代中的对偶变量为: -135.14386653834575
# *************************
# 迭代步长为: 0.11151053484837568
# ****************************************************************************
# 59999 次迭代中的结果：
# agent 1 在 59999 次迭代中的资源申请量为: 56.19880558172988
# agent 2 在 59999 次迭代中的资源申请量为: 56.03871203978166
# agent 3 在 59999 次迭代中的资源申请量为: 60.64796214442871
# agent 4 在 59999 次迭代中的资源申请量为: 37.93333499802675
# agent 5 在 59999 次迭代中的资源申请量为: 57.56693686702461
# agent 6 在 59999 次迭代中的资源申请量为: 55.34212747123894
# agent 7 在 59999 次迭代中的资源申请量为: 65.6236567946489
# agent 8 在 59999 次迭代中的资源申请量为: 46.330946703602365
# agent 9 在 59999 次迭代中的资源申请量为: 65.64268770463663
# agent 10 在 59999 次迭代中的资源申请量为: 54.23914303693835
# agent 11 在 59999 次迭代中的资源申请量为: 65.4520437985654
# agent 12 在 59999 次迭代中的资源申请量为: 38.406222330358624
# agent 13 在 59999 次迭代中的资源申请量为: 49.70058714461363
# agent 14 在 59999 次迭代中的资源申请量为: 41.3659905551611
# agent 15 在 59999 次迭代中的资源申请量为: 42.48853939614691
# agent 16 在 59999 次迭代中的资源申请量为: 49.24530133808371
# agent 17 在 59999 次迭代中的资源申请量为: 50.11852704992918
# agent 18 在 59999 次迭代中的资源申请量为: 46.537297422347486
# agent 19 在 59999 次迭代中的资源申请量为: 44.77392156663175
# agent 20 在 59999 次迭代中的资源申请量为: 50.80339666473046
# agent 21 在 59999 次迭代中的资源申请量为: 69.93387670557085
# agent 22 在 59999 次迭代中的资源申请量为: 61.24199691647269
# agent 23 在 59999 次迭代中的资源申请量为: 61.627787986086716
# agent 24 在 59999 次迭代中的资源申请量为: 39.861352301782716
# agent 25 在 59999 次迭代中的资源申请量为: 52.95065687328203
# agent 26 在 59999 次迭代中的资源申请量为: 49.39633437684004
# agent 27 在 59999 次迭代中的资源申请量为: 47.51919637207136
# agent 28 在 59999 次迭代中的资源申请量为: 40.7413613830987
# agent 29 在 59999 次迭代中的资源申请量为: 44.38273034135506
# agent 30 在 59999 次迭代中的资源申请量为: 39.891745956789116
# agent 31 在 59999 次迭代中的资源申请量为: 65.76280653244551
# agent 32 在 59999 次迭代中的资源申请量为: 59.51901541924079
# agent 33 在 59999 次迭代中的资源申请量为: 48.23750867799392
# agent 34 在 59999 次迭代中的资源申请量为: 36.76532342510125
# agent 35 在 59999 次迭代中的资源申请量为: 41.086702696803464
# agent 36 在 59999 次迭代中的资源申请量为: 62.20889044924783
# agent 37 在 59999 次迭代中的资源申请量为: 40.47023795026076
# agent 38 在 59999 次迭代中的资源申请量为: 58.24733429492913
# agent 39 在 59999 次迭代中的资源申请量为: 37.39554726071002
# agent 40 在 59999 次迭代中的资源申请量为: 50.45313221045784
# agent 41 在 59999 次迭代中的资源申请量为: 36.73569742369616
# agent 42 在 59999 次迭代中的资源申请量为: 56.24242387150355
# agent 43 在 59999 次迭代中的资源申请量为: 61.52373322591861
# agent 44 在 59999 次迭代中的资源申请量为: 47.51525622305313
# agent 45 在 59999 次迭代中的资源申请量为: 41.36197014706921
# agent 46 在 59999 次迭代中的资源申请量为: 67.10436077257359
# agent 47 在 59999 次迭代中的资源申请量为: 65.57090570810219
# agent 48 在 59999 次迭代中的资源申请量为: 40.83836334458436
# agent 49 在 59999 次迭代中的资源申请量为: 39.16390664937778
# agent 50 在 59999 次迭代中的资源申请量为: 63.292999181236645
# agent 51 在 59999 次迭代中的资源申请量为: 36.39727688961264
# agent 52 在 59999 次迭代中的资源申请量为: 46.86937779818014
# agent 53 在 59999 次迭代中的资源申请量为: 43.572511920796444
# agent 54 在 59999 次迭代中的资源申请量为: 49.58201107681077
# agent 55 在 59999 次迭代中的资源申请量为: 47.173391517077015
# agent 56 在 59999 次迭代中的资源申请量为: 42.97971616155657
# agent 57 在 59999 次迭代中的资源申请量为: 36.90486251978384
# agent 58 在 59999 次迭代中的资源申请量为: 59.2566799113546
# agent 59 在 59999 次迭代中的资源申请量为: 59.891586060534515
# agent 60 在 59999 次迭代中的资源申请量为: 40.34169962872796
# agent 61 在 59999 次迭代中的资源申请量为: 45.35594989347582
# agent 62 在 59999 次迭代中的资源申请量为: 37.77791650199216
# agent 63 在 59999 次迭代中的资源申请量为: 44.360248334083515
# agent 64 在 59999 次迭代中的资源申请量为: 50.59248382563358
# agent 65 在 59999 次迭代中的资源申请量为: 48.71934244765636
# agent 66 在 59999 次迭代中的资源申请量为: 53.47780999250507
# agent 67 在 59999 次迭代中的资源申请量为: 44.62937911116663
# agent 68 在 59999 次迭代中的资源申请量为: 38.64566746179467
# agent 69 在 59999 次迭代中的资源申请量为: 49.89213915774424
# agent 70 在 59999 次迭代中的资源申请量为: 43.384092173704765
# agent 71 在 59999 次迭代中的资源申请量为: 51.07243961445531
# agent 72 在 59999 次迭代中的资源申请量为: 51.63101181607605
# agent 73 在 59999 次迭代中的资源申请量为: 68.52493850742809
# agent 74 在 59999 次迭代中的资源申请量为: 63.033563690016244
# agent 75 在 59999 次迭代中的资源申请量为: 68.78486031089474
# agent 76 在 59999 次迭代中的资源申请量为: 65.84231131076093
# agent 77 在 59999 次迭代中的资源申请量为: 37.33178559067781
# agent 78 在 59999 次迭代中的资源申请量为: 56.51515954674745
# agent 79 在 59999 次迭代中的资源申请量为: 35.713197668399026
# agent 80 在 59999 次迭代中的资源申请量为: 41.69438982489667
# agent 81 在 59999 次迭代中的资源申请量为: 64.43288578237754
# agent 82 在 59999 次迭代中的资源申请量为: 45.64920279687104
# agent 83 在 59999 次迭代中的资源申请量为: 54.00548947849467
# agent 84 在 59999 次迭代中的资源申请量为: 52.98642785862186
# agent 85 在 59999 次迭代中的资源申请量为: 58.685757530614225
# agent 86 在 59999 次迭代中的资源申请量为: 54.16278250297603
# agent 87 在 59999 次迭代中的资源申请量为: 50.18394787557497
# agent 88 在 59999 次迭代中的资源申请量为: 53.40486804038577
# agent 89 在 59999 次迭代中的资源申请量为: 44.03701682161516
# agent 90 在 59999 次迭代中的资源申请量为: 38.99584103965445
# agent 91 在 59999 次迭代中的资源申请量为: 43.58677066582381
# agent 92 在 59999 次迭代中的资源申请量为: 45.258091384555385
# agent 93 在 59999 次迭代中的资源申请量为: 35.68321481267107
# agent 94 在 59999 次迭代中的资源申请量为: 37.4806078588005
# 资源申请量平均值avg为: 49.9999999999985
# ****************************************************************************
# 平均成本为: 3240.4819845314896
# ****************************************************************************
# agent 1 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 2 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 3 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 4 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 5 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 6 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 7 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 8 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 9 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 10 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 11 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 12 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 13 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 14 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 15 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 16 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 17 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 18 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 19 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 20 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 21 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 22 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 23 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 24 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 25 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 26 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 27 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 28 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 29 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 30 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 31 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 32 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 33 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 34 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 35 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 36 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 37 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 38 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 39 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 40 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 41 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 42 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 43 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 44 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 45 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 46 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 47 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 48 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 49 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 50 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 51 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 52 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 53 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 54 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 55 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 56 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 57 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 58 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 59 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 60 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 61 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 62 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 63 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 64 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 65 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 66 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 67 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 68 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 69 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 70 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 71 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 72 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 73 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 74 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 75 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 76 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 77 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 78 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 79 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 80 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 81 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 82 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 83 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 84 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 85 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 86 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 87 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 88 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 89 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 90 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 91 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 92 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 93 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 94 在 59999 次迭代中的对偶变量为: -135.1438665383513
# *************************
# 迭代步长为: 0.11075700351730201
# ****************************************************************************
# 2023-05-29 15:40:13.737

# %%
np.savetxt('../data/01-DGD-CTM-robust-agent_resource_quantity_large_value_deterministic_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/01-DGD-CTM-robust-sum_cost_large_value_deterministic_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/01-DGD-CTM-robust-sum_resource_large_value_deterministic_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
