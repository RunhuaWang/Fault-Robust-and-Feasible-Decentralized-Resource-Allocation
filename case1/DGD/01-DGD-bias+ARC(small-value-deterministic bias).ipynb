# %% [markdown]
# IWDGD中小值的确定性噪声 对应到DGD算法中是固定的对偶攻击值为-140.7 这样两个算法各自迭代1000次 所有用户的对偶迭代值均在140.2附近

# %% [markdown]
# 鲁棒聚合器ARC 该鲁棒聚合器跟IWDGD使用鲁棒聚合器的完全相同

# %%
#包文件
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime

# %%
#定义变量 
agent_resource_quantity = np.zeros(shape=(100,1000)) #100个agent的资源量 
dual_variable = np.zeros(shape=(100,1000))#对偶变量
sum_resource=np.zeros(shape=(1,1000), dtype=np.float64)#存放每一次迭代后所有用户资源量的总和
sum_cost=np.zeros(shape=(1,1000), dtype=np.float64)#存放每一次迭代后所有用户成本的总和
iteration_update = 0.01#迭代步长
A=np.loadtxt("100_Network_Topology_Double_Random_Adjacency_Matrix_Degree_15.txt") #网络拓扑的邻接矩阵 对角元素要为0
W=np.zeros(shape=(100,100)) #双随机的网络拓扑矩阵W（对角线处非零）
iteration=[]#绘图横坐标
a=np.loadtxt("100_uniform_distribution_(1,2)_point1.txt")#每个agent的成本函数中的超参数
b=np.loadtxt("100_normal_distribution_(2,0.6)_point1.txt")#每个agent的成本函数中的超参数
C=np.zeros(shape=(1,1000), dtype=np.float64)#adaptive robust clipping的裁剪参数 
#设置为全局第b大的梯度信息 b为网络中设备损坏的用户上界 每一次迭代就需要计算一次新的C值

# %%
#根据邻接矩阵生成网络对应的双随机的权重混合矩阵
for i in range(0,100):
    for j in range(0,100):
        if A[i][j]!=0 or i==j:
            W[i][j]=1/16

#对偶变量的初始化 初始化一致
for i in range (0,100):
    dual_variable[i][0]=0
    
#资源量的初始化 资源量的初始化需要和对偶变量的初始值满足某种关系
for i in range (0,100):
    agent_resource_quantity[i][0]=50

iteration.append(0)

#总资源量 初始化
sum=0
for i in range (0,100):
    sum=sum+agent_resource_quantity[i][0]
sum_resource[0]=sum

#用户总成本初始化
sum=0
for i in range(0,100):
    sum=sum+a[i]*(agent_resource_quantity[i][0]-b[i])*(agent_resource_quantity[i][0]-b[i])
sum_cost[0][0]=sum

# %%
#DGD算法 
def DGD_ARC_deterministic_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,C):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("****************************DGD算法+计算误差+ARC****************************")
    print("相关变量初始值为：")
    for i in range (0,100):
        print("agent",(i+1),"的初始资源申请量为:",agent_resource_quantity[i][0])
    print("*************************")
    print("初始资源申请量总和为:",sum_resource[0][0])
    print("*************************")
    print("初始成本总和为:",sum_cost[0][0])
    print("*************************")
    for i in range(0,100):
        print("agent",(i+1),"的初始对偶变量为:",dual_variable[i][0])
    print("*************************")
    print("迭代步长为:",iteration_update)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):#迭代次数
        iteration.append(k)
        
        #所有用户对偶变量的迭代 
        #阶段一：梯度下降 
        dual_variable_intermediate=[] #存放当前迭代中100个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,100):
            if i==7 or i==20 or i==34: 
                dual_variable_intermediate.append(-140.7)
            else:
                dual_variable_intermediate.append(dual_variable[i][k-1]-iteration_update*(50-agent_resource_quantity[i][k-1]))       
        
        #阶段二：鲁棒聚合 ARC  
        #先计算当前的clipping阈值C
        column_data = dual_variable_intermediate
        forth_largest = np.partition(np.abs(column_data), -4)[-4]
        C[0][k]=forth_largest
        #基于clipping阈值C每个用户进行clipping操作
        for i in range (0,100):
            mix_sum_dual=0
            for j in range(0,100):  
                if W[i][j]!=0 and np.abs(dual_variable_intermediate[j])>C[0][k]:
                    mix_sum_dual=mix_sum_dual+W[i][j]*(C[0][k]/np.abs(dual_variable_intermediate[j]))*dual_variable_intermediate[j]                  
                elif W[i][j]!=0 and np.abs(dual_variable_intermediate[j])<=C[0][k]:
                    mix_sum_dual=mix_sum_dual+W[i][j]*dual_variable_intermediate[j]
            dual_variable[i][k]=mix_sum_dual                      
        
        #用户资源申请量的迭代
        for i in range (0,100):
            agent_resource_quantity[i][k]=(dual_variable[i][k]-2*a[i]*b[i])/(-2*a[i])

        #计算所有用户的资源量总和
        sum1=np.float64(0)
        for i in range (0,100):
            sum1 = sum1 + agent_resource_quantity[i][k]
        sum_resource[0][k]=sum1
        
        #计算所有用户的成本总和
        sum2=np.float64(0)
        for i in range(0,100):
            sum2=sum2+a[i]*(agent_resource_quantity[i][k]-b[i])*(agent_resource_quantity[i][k]-b[i])
        sum_cost[0][k]=sum2
        
        #输出第k次迭代中的结果 每间隔2000次迭代输出一次结果
        if (k+1)%50==0:
        #if (k+1)%2000==0:
            print(k,"次迭代中的结果：")
            for i in range (0,100):
                print("agent",(i+1),"在",k,"次迭代中的资源申请量为:",agent_resource_quantity[i][k])
            print("资源申请量总和为:",sum_resource[0][k])
            print("****************************************************************************")
            print("成本总和为:",sum_cost[0][k])
            print("****************************************************************************")
            for i in range(0,100):
                print("agent",(i+1),"在",k,"次迭代中的对偶变量为:",dual_variable[i][k])   
            print("*************************")
            print("迭代步长为:",iteration_update)
            print("****************************************************************************")
        
        iteration_update=1/(pow(k+1,0.6)) #递减步长
        
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    
    return None

# %%
DGD_ARC_deterministic_bias(a,b,agent_resource_quantity,sum_resource,iteration_update,W,iteration,C)
# Out:
# ****************************DGD算法+计算误差+ARC****************************
# 相关变量初始值为：
# agent 1 的初始资源申请量为: 50.0
# agent 2 的初始资源申请量为: 50.0
# agent 3 的初始资源申请量为: 50.0
# agent 4 的初始资源申请量为: 50.0
# agent 5 的初始资源申请量为: 50.0
# agent 6 的初始资源申请量为: 50.0
# agent 7 的初始资源申请量为: 50.0
# agent 8 的初始资源申请量为: 50.0
# agent 9 的初始资源申请量为: 50.0
# agent 10 的初始资源申请量为: 50.0
# agent 11 的初始资源申请量为: 50.0
# agent 12 的初始资源申请量为: 50.0
# agent 13 的初始资源申请量为: 50.0
# agent 14 的初始资源申请量为: 50.0
# agent 15 的初始资源申请量为: 50.0
# agent 16 的初始资源申请量为: 50.0
# agent 17 的初始资源申请量为: 50.0
# agent 18 的初始资源申请量为: 50.0
# agent 19 的初始资源申请量为: 50.0
# agent 20 的初始资源申请量为: 50.0
# agent 21 的初始资源申请量为: 50.0
# agent 22 的初始资源申请量为: 50.0
# agent 23 的初始资源申请量为: 50.0
# agent 24 的初始资源申请量为: 50.0
# agent 25 的初始资源申请量为: 50.0
# agent 26 的初始资源申请量为: 50.0
# agent 27 的初始资源申请量为: 50.0
# agent 28 的初始资源申请量为: 50.0
# agent 29 的初始资源申请量为: 50.0
# agent 30 的初始资源申请量为: 50.0
# agent 31 的初始资源申请量为: 50.0
# agent 32 的初始资源申请量为: 50.0
# agent 33 的初始资源申请量为: 50.0
# agent 34 的初始资源申请量为: 50.0
# agent 35 的初始资源申请量为: 50.0
# agent 36 的初始资源申请量为: 50.0
# agent 37 的初始资源申请量为: 50.0
# agent 38 的初始资源申请量为: 50.0
# agent 39 的初始资源申请量为: 50.0
# agent 40 的初始资源申请量为: 50.0
# agent 41 的初始资源申请量为: 50.0
# agent 42 的初始资源申请量为: 50.0
# agent 43 的初始资源申请量为: 50.0
# agent 44 的初始资源申请量为: 50.0
# agent 45 的初始资源申请量为: 50.0
# agent 46 的初始资源申请量为: 50.0
# agent 47 的初始资源申请量为: 50.0
# agent 48 的初始资源申请量为: 50.0
# agent 49 的初始资源申请量为: 50.0
# agent 50 的初始资源申请量为: 50.0
# agent 51 的初始资源申请量为: 50.0
# agent 52 的初始资源申请量为: 50.0
# agent 53 的初始资源申请量为: 50.0
# agent 54 的初始资源申请量为: 50.0
# agent 55 的初始资源申请量为: 50.0
# agent 56 的初始资源申请量为: 50.0
# agent 57 的初始资源申请量为: 50.0
# agent 58 的初始资源申请量为: 50.0
# agent 59 的初始资源申请量为: 50.0
# agent 60 的初始资源申请量为: 50.0
# agent 61 的初始资源申请量为: 50.0
# agent 62 的初始资源申请量为: 50.0
# agent 63 的初始资源申请量为: 50.0
# agent 64 的初始资源申请量为: 50.0
# agent 65 的初始资源申请量为: 50.0
# agent 66 的初始资源申请量为: 50.0
# agent 67 的初始资源申请量为: 50.0
# agent 68 的初始资源申请量为: 50.0
# agent 69 的初始资源申请量为: 50.0
# agent 70 的初始资源申请量为: 50.0
# agent 71 的初始资源申请量为: 50.0
# agent 72 的初始资源申请量为: 50.0
# agent 73 的初始资源申请量为: 50.0
# agent 74 的初始资源申请量为: 50.0
# agent 75 的初始资源申请量为: 50.0
# agent 76 的初始资源申请量为: 50.0
# agent 77 的初始资源申请量为: 50.0
# agent 78 的初始资源申请量为: 50.0
# agent 79 的初始资源申请量为: 50.0
# agent 80 的初始资源申请量为: 50.0
# agent 81 的初始资源申请量为: 50.0
# agent 82 的初始资源申请量为: 50.0
# agent 83 的初始资源申请量为: 50.0
# agent 84 的初始资源申请量为: 50.0
# agent 85 的初始资源申请量为: 50.0
# agent 86 的初始资源申请量为: 50.0
# agent 87 的初始资源申请量为: 50.0
# agent 88 的初始资源申请量为: 50.0
# agent 89 的初始资源申请量为: 50.0
# agent 90 的初始资源申请量为: 50.0
# agent 91 的初始资源申请量为: 50.0
# agent 92 的初始资源申请量为: 50.0
# agent 93 的初始资源申请量为: 50.0
# agent 94 的初始资源申请量为: 50.0
# agent 95 的初始资源申请量为: 50.0
# agent 96 的初始资源申请量为: 50.0
# agent 97 的初始资源申请量为: 50.0
# agent 98 的初始资源申请量为: 50.0
# agent 99 的初始资源申请量为: 50.0
# agent 100 的初始资源申请量为: 50.0
# *************************
# 初始资源申请量总和为: 5000.0
# *************************
# 初始成本总和为: 346654.5889999999
# *************************
# agent 1 的初始对偶变量为: 0.0
# agent 2 的初始对偶变量为: 0.0
# agent 3 的初始对偶变量为: 0.0
# agent 4 的初始对偶变量为: 0.0
# agent 5 的初始对偶变量为: 0.0
# agent 6 的初始对偶变量为: 0.0
# agent 7 的初始对偶变量为: 0.0
# agent 8 的初始对偶变量为: 0.0
# agent 9 的初始对偶变量为: 0.0
# agent 10 的初始对偶变量为: 0.0
# agent 11 的初始对偶变量为: 0.0
# agent 12 的初始对偶变量为: 0.0
# agent 13 的初始对偶变量为: 0.0
# agent 14 的初始对偶变量为: 0.0
# agent 15 的初始对偶变量为: 0.0
# agent 16 的初始对偶变量为: 0.0
# agent 17 的初始对偶变量为: 0.0
# agent 18 的初始对偶变量为: 0.0
# agent 19 的初始对偶变量为: 0.0
# agent 20 的初始对偶变量为: 0.0
# agent 21 的初始对偶变量为: 0.0
# agent 22 的初始对偶变量为: 0.0
# agent 23 的初始对偶变量为: 0.0
# agent 24 的初始对偶变量为: 0.0
# agent 25 的初始对偶变量为: 0.0
# agent 26 的初始对偶变量为: 0.0
# agent 27 的初始对偶变量为: 0.0
# agent 28 的初始对偶变量为: 0.0
# agent 29 的初始对偶变量为: 0.0
# agent 30 的初始对偶变量为: 0.0
# agent 31 的初始对偶变量为: 0.0
# agent 32 的初始对偶变量为: 0.0
# agent 33 的初始对偶变量为: 0.0
# agent 34 的初始对偶变量为: 0.0
# agent 35 的初始对偶变量为: 0.0
# agent 36 的初始对偶变量为: 0.0
# agent 37 的初始对偶变量为: 0.0
# agent 38 的初始对偶变量为: 0.0
# agent 39 的初始对偶变量为: 0.0
# agent 40 的初始对偶变量为: 0.0
# agent 41 的初始对偶变量为: 0.0
# agent 42 的初始对偶变量为: 0.0
# agent 43 的初始对偶变量为: 0.0
# agent 44 的初始对偶变量为: 0.0
# agent 45 的初始对偶变量为: 0.0
# agent 46 的初始对偶变量为: 0.0
# agent 47 的初始对偶变量为: 0.0
# agent 48 的初始对偶变量为: 0.0
# agent 49 的初始对偶变量为: 0.0
# agent 50 的初始对偶变量为: 0.0
# agent 51 的初始对偶变量为: 0.0
# agent 52 的初始对偶变量为: 0.0
# agent 53 的初始对偶变量为: 0.0
# agent 54 的初始对偶变量为: 0.0
# agent 55 的初始对偶变量为: 0.0
# agent 56 的初始对偶变量为: 0.0
# agent 57 的初始对偶变量为: 0.0
# agent 58 的初始对偶变量为: 0.0
# agent 59 的初始对偶变量为: 0.0
# agent 60 的初始对偶变量为: 0.0
# agent 61 的初始对偶变量为: 0.0
# agent 62 的初始对偶变量为: 0.0
# agent 63 的初始对偶变量为: 0.0
# agent 64 的初始对偶变量为: 0.0
# agent 65 的初始对偶变量为: 0.0
# agent 66 的初始对偶变量为: 0.0
# agent 67 的初始对偶变量为: 0.0
# agent 68 的初始对偶变量为: 0.0
# agent 69 的初始对偶变量为: 0.0
# agent 70 的初始对偶变量为: 0.0
# agent 71 的初始对偶变量为: 0.0
# agent 72 的初始对偶变量为: 0.0
# agent 73 的初始对偶变量为: 0.0
# agent 74 的初始对偶变量为: 0.0
# agent 75 的初始对偶变量为: 0.0
# agent 76 的初始对偶变量为: 0.0
# agent 77 的初始对偶变量为: 0.0
# agent 78 的初始对偶变量为: 0.0
# agent 79 的初始对偶变量为: 0.0
# agent 80 的初始对偶变量为: 0.0
# agent 81 的初始对偶变量为: 0.0
# agent 82 的初始对偶变量为: 0.0
# agent 83 的初始对偶变量为: 0.0
# agent 84 的初始对偶变量为: 0.0
# agent 85 的初始对偶变量为: 0.0
# agent 86 的初始对偶变量为: 0.0
# agent 87 的初始对偶变量为: 0.0
# agent 88 的初始对偶变量为: 0.0
# agent 89 的初始对偶变量为: 0.0
# agent 90 的初始对偶变量为: 0.0
# agent 91 的初始对偶变量为: 0.0
# agent 92 的初始对偶变量为: 0.0
# agent 93 的初始对偶变量为: 0.0
# agent 94 的初始对偶变量为: 0.0
# agent 95 的初始对偶变量为: 0.0
# agent 96 的初始对偶变量为: 0.0
# agent 97 的初始对偶变量为: 0.0
# agent 98 的初始对偶变量为: 0.0
# agent 99 的初始对偶变量为: 0.0
# agent 100 的初始对偶变量为: 0.0
# *************************
# 迭代步长为: 0.01
# *****************************************************************************
# 49 次迭代中的结果：
# agent 1 在 49 次迭代中的资源申请量为: 46.46389908353958
# agent 2 在 49 次迭代中的资源申请量为: 58.42239441959957
# agent 3 在 49 次迭代中的资源申请量为: 42.091842474472195
# agent 4 在 49 次迭代中的资源申请量为: 61.774228930805435
# agent 5 在 49 次迭代中的资源申请量为: 62.481117751031995
# agent 6 在 49 次迭代中的资源申请量为: 68.75086514047523
# agent 7 在 49 次迭代中的资源申请量为: 37.915380103573725
# agent 8 在 49 次迭代中的资源申请量为: 36.26793118687117
# agent 9 在 49 次迭代中的资源申请量为: 41.34170488290279
# agent 10 在 49 次迭代中的资源申请量为: 53.497083219101455
# agent 11 在 49 次迭代中的资源申请量为: 43.65883643484145
# agent 12 在 49 次迭代中的资源申请量为: 47.262284993819485
# agent 13 在 49 次迭代中的资源申请量为: 62.9687535014716
# agent 14 在 49 次迭代中的资源申请量为: 53.036225778010426
# agent 15 在 49 次迭代中的资源申请量为: 41.84374936888603
# agent 16 在 49 次迭代中的资源申请量为: 41.963412671623175
# agent 17 在 49 次迭代中的资源申请量为: 43.10836200106691
# agent 18 在 49 次迭代中的资源申请量为: 44.712225708776195
# agent 19 在 49 次迭代中的资源申请量为: 39.7199512461485
# agent 20 在 49 次迭代中的资源申请量为: 53.40439980947918
# agent 21 在 49 次迭代中的资源申请量为: 37.21666691177673
# agent 22 在 49 次迭代中的资源申请量为: 37.567981020379925
# agent 23 在 49 次迭代中的资源申请量为: 46.074724318350626
# agent 24 在 49 次迭代中的资源申请量为: 38.95750665412585
# agent 25 在 49 次迭代中的资源申请量为: 43.32056046327439
# agent 26 在 49 次迭代中的资源申请量为: 38.360250209225484
# agent 27 在 49 次迭代中的资源申请量为: 62.82462095221518
# agent 28 在 49 次迭代中的资源申请量为: 49.084597183952376
# agent 29 在 49 次迭代中的资源申请量为: 39.219150699574136
# agent 30 在 49 次迭代中的资源申请量为: 37.7734070743457
# agent 31 在 49 次迭代中的资源申请量为: 58.01757441120521
# agent 32 在 49 次迭代中的资源申请量为: 53.18644456111242
# agent 33 在 49 次迭代中的资源申请量为: 39.81927040085455
# agent 34 在 49 次迭代中的资源申请量为: 50.13542218334216
# agent 35 在 49 次迭代中的资源申请量为: 37.277889508711894
# agent 36 在 49 次迭代中的资源申请量为: 41.017185472743286
# agent 37 在 49 次迭代中的资源申请量为: 50.39672772604449
# agent 38 在 49 次迭代中的资源申请量为: 38.66677146793463
# agent 39 在 49 次迭代中的资源申请量为: 41.58659106414094
# agent 40 在 49 次迭代中的资源申请量为: 48.14774062710104
# agent 41 在 49 次迭代中的资源申请量为: 63.36445790183992
# agent 42 在 49 次迭代中的资源申请量为: 40.73198444765166
# agent 43 在 49 次迭代中的资源申请量为: 49.42859835811802
# agent 44 在 49 次迭代中的资源申请量为: 50.950053029565886
# agent 45 在 49 次迭代中的资源申请量为: 46.23891383171881
# agent 46 在 49 次迭代中的资源申请量为: 53.593285193633285
# agent 47 在 49 次迭代中的资源申请量为: 44.04447342612035
# agent 48 在 49 次迭代中的资源申请量为: 41.62258148512782
# agent 49 在 49 次迭代中的资源申请量为: 40.76465345189606
# agent 50 在 49 次迭代中的资源申请量为: 39.24644453274674
# agent 51 在 49 次迭代中的资源申请量为: 46.235824059194336
# agent 52 在 49 次迭代中的资源申请量为: 53.34924242759186
# agent 53 在 49 次迭代中的资源申请量为: 37.38044974074702
# agent 54 在 49 次迭代中的资源申请量为: 54.80528271855989
# agent 55 在 49 次迭代中的资源申请量为: 67.96967100021696
# agent 56 在 49 次迭代中的资源申请量为: 39.334636509582076
# agent 57 在 49 次迭代中的资源申请量为: 57.990376301924506
# agent 58 在 49 次迭代中的资源申请量为: 40.48600107855381
# agent 59 在 49 次迭代中的资源申请量为: 45.949334101253186
# agent 60 在 49 次迭代中的资源申请量为: 53.73979790773285
# agent 61 在 49 次迭代中的资源申请量为: 62.9914134201061
# agent 62 在 49 次迭代中的资源申请量为: 44.22403180784224
# agent 63 在 49 次迭代中的资源申请量为: 37.47750692680548
# agent 64 在 49 次迭代中的资源申请量为: 42.53258890780196
# agent 65 在 49 次迭代中的资源申请量为: 40.90236829476456
# agent 66 在 49 次迭代中的资源申请量为: 62.58318676484103
# agent 67 在 49 次迭代中的资源申请量为: 41.56197777636361
# agent 68 在 49 次迭代中的资源申请量为: 43.01865464571745
# agent 69 在 49 次迭代中的资源申请量为: 43.542687453327886
# agent 70 在 49 次迭代中的资源申请量为: 57.46243090291947
# agent 71 在 49 次迭代中的资源申请量为: 68.57508239678968
# agent 72 在 49 次迭代中的资源申请量为: 57.57593668049944
# agent 73 在 49 次迭代中的资源申请量为: 41.878773973124
# agent 74 在 49 次迭代中的资源申请量为: 37.43366443024118
# agent 75 在 49 次迭代中的资源申请量为: 49.85155768343223
# agent 76 在 49 次迭代中的资源申请量为: 45.10715085059763
# agent 77 在 49 次迭代中的资源申请量为: 39.11387824670331
# agent 78 在 49 次迭代中的资源申请量为: 47.62224018270143
# agent 79 在 49 次迭代中的资源申请量为: 41.170644507354375
# agent 80 在 49 次迭代中的资源申请量为: 41.18608898126944
# agent 81 在 49 次迭代中的资源申请量为: 38.04630502235338
# agent 82 在 49 次迭代中的资源申请量为: 43.96265510986315
# agent 83 在 49 次迭代中的资源申请量为: 39.985447514804406
# agent 84 在 49 次迭代中的资源申请量为: 49.83716612021685
# agent 85 在 49 次迭代中的资源申请量为: 53.370014137835426
# agent 86 在 49 次迭代中的资源申请量为: 46.95771322055413
# agent 87 在 49 次迭代中的资源申请量为: 57.899165594330306
# agent 88 在 49 次迭代中的资源申请量为: 62.154265231388
# agent 89 在 49 次迭代中的资源申请量为: 38.723400698049225
# agent 90 在 49 次迭代中的资源申请量为: 56.759185241814514
# agent 91 在 49 次迭代中的资源申请量为: 41.10928356330247
# agent 92 在 49 次迭代中的资源申请量为: 54.69361630131198
# agent 93 在 49 次迭代中的资源申请量为: 39.14157115686365
# agent 94 在 49 次迭代中的资源申请量为: 70.12481037002168
# agent 95 在 49 次迭代中的资源申请量为: 57.71402183362813
# agent 96 在 49 次迭代中的资源申请量为: 57.87448603860028
# agent 97 在 49 次迭代中的资源申请量为: 68.87854570382261
# agent 98 在 49 次迭代中的资源申请量为: 69.9142527534469
# agent 99 在 49 次迭代中的资源申请量为: 50.2587401356536
# agent 100 在 49 次迭代中的资源申请量为: 46.56619076229501
# 资源申请量总和为: 4826.3444944640405
# ****************************************************************************
# 成本总和为: 310360.4247837031
# ****************************************************************************
# agent 1 在 49 次迭代中的对偶变量为: -134.29169725061874
# agent 2 在 49 次迭代中的对偶变量为: -133.97374660703895
# agent 3 在 49 次迭代中的对偶变量为: -134.27226441320545
# agent 4 在 49 次迭代中的对偶变量为: -134.14330364777197
# agent 5 在 49 次迭代中的对偶变量为: -133.9384590522704
# agent 6 在 49 次迭代中的对偶变量为: -133.50173028095045
# agent 7 在 49 次迭代中的对偶变量为: -134.19844439358016
# agent 8 在 49 次迭代中的对偶变量为: -134.27172474748465
# agent 9 在 49 次迭代中的对偶变量为: -134.10179660186947
# agent 10 在 49 次迭代中的对偶变量为: -134.1524163696638
# agent 11 在 49 次迭代中的对偶变量为: -134.26827659149265
# agent 12 在 49 次迭代中的对偶变量为: -133.98685498145844
# agent 13 在 49 次迭代中的对偶变量为: -133.91125770323754
# agent 14 在 49 次迭代中的对偶变量为: -134.51418702282712
# agent 15 在 49 次迭代中的对偶变量为: -134.4487478542125
# agent 16 在 49 次迭代中的对偶变量为: -134.17560308351878
# agent 17 在 49 次迭代中的对偶变量为: -134.4267584034141
# agent 18 在 49 次迭代中的对偶变量为: -134.43912226808385
# agent 19 在 49 次迭代中的对偶变量为: -134.3518244861346
# agent 20 在 49 次迭代中的对偶变量为: -134.17143950464586
# agent 21 在 49 次迭代中的对偶变量为: -134.20333426475156
# agent 22 在 49 次迭代中的对偶变量为: -134.3983278774437
# agent 23 在 49 次迭代中的对偶变量为: -134.92417295505186
# agent 24 在 49 次迭代中的对偶变量为: -134.48702395485307
# agent 25 在 49 次迭代中的对偶变量为: -134.14579348247807
# agent 26 在 49 次迭代中的对偶变量为: -134.74895079505683
# agent 27 在 49 次迭代中的对偶变量为: -134.2541660948734
# agent 28 在 49 次迭代中的对偶变量为: -133.79687211506666
# agent 29 在 49 次迭代中的对偶变量为: -134.34894251846688
# agent 30 在 49 次迭代中的对偶变量为: -134.79894688251363
# agent 31 在 49 次迭代中的对偶变量为: -134.44217858689248
# agent 32 在 49 次迭代中的对偶变量为: -134.12475585889229
# agent 33 在 49 次迭代中的对偶变量为: -133.6293734430764
# agent 34 在 49 次迭代中的对偶变量为: -134.21918211335804
# agent 35 在 49 次迭代中的对偶变量为: -134.0559801331052
# agent 36 在 49 次迭代中的对偶变量为: -134.01843060732716
# agent 37 在 49 次迭代中的对偶变量为: -134.11083763292456
# agent 38 在 49 次迭代中的对偶变量为: -134.16037728456467
# agent 39 在 49 次迭代中的对偶变量为: -134.2544096180792
# agent 40 在 49 次迭代中的对偶变量为: -134.24322188130313
# agent 41 在 49 次迭代中的对偶变量为: -133.90180738404783
# agent 42 在 49 次迭代中的对偶变量为: -134.06874712201565
# agent 43 在 49 次迭代中的对偶变量为: -133.64007540273047
# agent 44 在 49 次迭代中的对偶变量为: -134.54014848278447
# agent 45 在 49 次迭代中的对偶变量为: -134.21674149515644
# agent 46 在 49 次迭代中的对偶变量为: -134.40254150344654
# agent 47 在 49 次迭代中的对偶变量为: -134.22231496358512
# agent 48 在 49 次迭代中的对偶变量为: -134.0367770494346
# agent 49 在 49 次迭代中的对偶变量为: -133.4998217364466
# agent 50 在 49 次迭代中的对偶变量为: -134.0872003178883
# agent 51 在 49 次迭代中的对偶变量为: -133.907472177583
# agent 52 在 49 次迭代中的对偶变量为: -134.02803031173883
# agent 53 在 49 次迭代中的对偶变量为: -134.06570901483866
# agent 54 在 49 次迭代中的对偶变量为: -134.6937350682557
# agent 55 在 49 次迭代中的对偶变量为: -134.1393420004339
# agent 56 在 49 次迭代中的对偶变量为: -134.40469143449548
# agent 57 在 49 次迭代中的对偶变量为: -134.3769031246188
# agent 58 在 49 次迭代中的对偶变量为: -134.25240366708294
# agent 59 在 49 次迭代中的对偶变量为: -134.24800230375956
# agent 60 在 49 次迭代中的对偶变量为: -134.2634745601054
# agent 61 在 49 次迭代中的对偶变量为: -133.74110952423342
# agent 62 在 49 次迭代中的对偶变量为: -134.15690178509516
# agent 63 在 49 次迭代中的对偶变量为: -134.43452632186083
# agent 64 在 49 次迭代中的对偶变量为: -134.18428450496629
# agent 65 在 49 次迭代中的对偶变量为: -133.9680522021995
# agent 66 在 49 次迭代中的对偶变量为: -133.50301088265027
# agent 67 在 49 次迭代中的对偶变量为: -134.1707244396363
# agent 68 在 49 次迭代中的对偶变量为: -134.13969486629583
# agent 69 在 49 次迭代中的对偶变量为: -134.21659985064923
# agent 70 在 49 次迭代中的对偶变量为: -134.06983416700672
# agent 71 在 49 次迭代中的对偶变量为: -133.35016479357935
# agent 72 在 49 次迭代中的对偶变量为: -133.86224803319865
# agent 73 在 49 次迭代中的对偶变量为: -133.8878315086216
# agent 74 在 49 次迭代中的对偶变量为: -134.2679248349165
# agent 75 在 49 次迭代中的对偶变量为: -134.26436151361025
# agent 76 在 49 次迭代中的对偶变量为: -134.1028827219124
# agent 77 在 49 次迭代中的对偶变量为: -133.96996168813192
# agent 78 在 49 次迭代中的对偶变量为: -134.1667205481043
# agent 79 在 49 次迭代中的对偶变量为: -134.54019132500488
# agent 80 在 49 次迭代中的对偶变量为: -133.9127025363161
# agent 81 在 49 次迭代中的对偶变量为: -134.69595908494284
# agent 82 在 49 次迭代中的对偶变量为: -134.60049635156207
# agent 83 在 49 次迭代中的对偶变量为: -134.22761105329587
# agent 84 在 49 次迭代中的对偶变量为: -133.94406513660718
# agent 85 在 49 次迭代中的对偶变量为: -134.0820367583721
# agent 86 在 49 次迭代中的对偶变量为: -134.2731396616624
# agent 87 在 49 次迭代中的对偶变量为: -134.1579974263927
# agent 88 在 49 次迭代中的对偶变量为: -133.6593835090536
# agent 89 在 49 次迭代中的对偶变量为: -133.64424251297723
# agent 90 在 49 次迭代中的对偶变量为: -134.30204458035485
# agent 91 在 49 次迭代中的对偶变量为: -133.99156411522839
# agent 92 在 49 次迭代中的对偶变量为: -134.40340238341113
# agent 93 在 49 次迭代中的对偶变量为: -134.42965616470914
# agent 94 在 49 次迭代中的对偶变量为: -134.04962074004337
# agent 95 在 49 次迭代中的对偶变量为: -133.9536524007075
# agent 96 在 49 次迭代中的对偶变量为: -133.85876649264068
# agent 97 在 49 次迭代中的对偶变量为: -133.55709140764523
# agent 98 在 49 次迭代中的对偶变量为: -134.0285055068938
# agent 99 在 49 次迭代中的对偶变量为: -134.00447237983008
# agent 100 在 49 次迭代中的对偶变量为: -134.29857228688502
# *************************
# 迭代步长为: 0.09680155905721156
# ****************************************************************************
# 99 次迭代中的结果：
# agent 1 在 99 次迭代中的资源申请量为: 47.81099326923195
# agent 2 在 99 次迭代中的资源申请量为: 60.14890398616416
# agent 3 在 99 次迭代中的资源申请量为: 43.282172806468516
# agent 4 在 99 次迭代中的资源申请量为: 63.6319579886344
# agent 5 在 99 次迭代中的资源申请量为: 64.3685156172482
# agent 6 在 99 次迭代中的资源申请量为: 70.89730099538005
# agent 7 在 99 次迭代中的资源申请量为: 38.98657737373011
# agent 8 在 99 次迭代中的资源申请量为: 37.28007753330555
# agent 9 在 99 次迭代中的资源申请量为: 42.5477942791784
# agent 10 在 99 次迭代中的资源申请量为: 55.068505650628346
# agent 11 在 99 次迭代中的资源申请量为: 44.923858072568095
# agent 12 在 99 次迭代中的资源申请量为: 48.641845215390354
# agent 13 在 99 次迭代中的资源申请量为: 64.86100615848201
# agent 14 在 99 次迭代中的资源申请量为: 54.56273970896531
# agent 15 在 99 次迭代中的资源申请量为: 43.01730979515146
# agent 16 在 99 次迭代中的资源申请量为: 43.16269613110396
# agent 17 在 99 次迭代中的资源申请量为: 44.35738696512306
# agent 18 在 99 次迭代中的资源申请量为: 45.960032306081025
# agent 19 在 99 次迭代中的资源申请量为: 40.83711565798007
# agent 20 在 99 次迭代中的资源申请量为: 54.97365467879074
# agent 21 在 99 次迭代中的资源申请量为: 38.28763303848618
# agent 22 在 99 次迭代中的资源申请量为: 38.62227298607606
# agent 23 在 99 次迭代中的资源申请量为: 47.35390182031828
# agent 24 在 99 次迭代中的资源申请量为: 40.06248717910633
# agent 25 在 99 次迭代中的资源申请量为: 44.59790724296102
# agent 26 在 99 次迭代中的资源申请量为: 39.384899624806934
# agent 27 在 99 次迭代中的资源申请量为: 64.66653767694756
# agent 28 在 99 次迭代中的资源申请量为: 50.584370216486
# agent 29 在 99 次迭代中的资源申请量为: 40.3363477792748
# agent 30 在 99 次迭代中的资源申请量为: 38.79391852532783
# agent 31 在 99 次迭代中的资源申请量为: 59.680864680688735
# agent 32 在 99 次迭代中的资源申请量为: 54.76142010764914
# agent 33 在 99 次迭代中的资源申请量为: 41.0008287735005
# agent 34 在 99 次迭代中的资源申请量为: 51.58680805672482
# agent 35 在 99 次迭代中的资源申请量为: 38.361367488792354
# agent 36 在 99 次迭代中的资源申请量为: 42.23136614792607
# agent 37 在 99 次迭代中的资源申请量为: 51.860388679355694
# agent 38 在 99 次迭代中的资源申请量为: 39.80093336964951
# agent 39 在 99 次迭代中的资源申请量为: 42.77860521310434
# agent 40 在 99 次迭代中的资源申请量为: 49.499710243753775
# agent 41 在 99 次迭代中的资源申请量为: 65.25782895291607
# agent 42 在 99 次迭代中的资源申请量为: 41.94147865010864
# agent 43 在 99 次迭代中的资源申请量为: 50.94611377750066
# agent 44 在 99 次迭代中的资源申请量为: 52.36447331798781
# agent 45 在 99 次迭代中的资源申请量为: 47.59373183037915
# agent 46 在 99 次迭代中的资源申请量为: 55.133599598108354
# agent 47 在 99 次迭代中的资源申请量为: 45.3142102423687
# agent 48 在 99 次迭代中的资源申请量为: 42.83505073024624
# agent 49 在 99 次迭代中的资源申请量为: 42.02750519847291
# agent 50 在 99 次迭代中的资源申请量为: 40.386930247075504
# agent 51 在 99 次迭代中的资源申请量为: 47.62356929515092
# agent 52 在 99 次迭代中的资源申请量为: 54.93594972948767
# agent 53 在 99 次迭代中的资源申请量为: 38.46291026023916
# agent 54 在 99 次迭代中的资源申请量为: 56.30980971797534
# agent 55 在 99 次迭代中的资源申请量为: 70.01450748498753
# agent 56 在 99 次迭代中的资源申请量为: 40.44693957253777
# agent 57 在 99 次迭代中的资源申请量为: 59.662476044453776
# agent 58 在 99 次迭代中的资源申请量为: 41.67812102554098
# agent 59 在 99 次迭代中的资源申请量为: 47.30059508244208
# agent 60 在 99 次迭代中的资源申请量为: 55.29719561843709
# agent 61 在 99 次迭代中的资源申请量为: 64.90825211836815
# agent 62 在 99 次迭代中的资源申请量为: 45.50023888306389
# agent 63 在 99 次迭代中的资源申请量为: 38.52860813066047
# agent 64 在 99 次迭代中的资源申请量为: 43.80577956597014
# agent 65 在 99 次迭代中的资源申请量为: 42.121146035274336
# agent 66 在 99 次迭代中的资源申请量为: 64.53457854585122
# agent 67 在 99 次迭代中的资源申请量为: 42.76128008035306
# agent 68 在 99 次迭代中的资源申请量为: 44.29618185956265
# agent 69 在 99 次迭代中的资源申请量为: 44.812761549748295
# agent 70 在 99 次迭代中的资源申请量为: 59.17527468776393
# agent 71 在 99 次迭代中的资源申请量为: 70.74578580223132
# agent 72 在 99 次迭代中的资源申请量为: 59.3169284921573
# agent 73 在 99 次迭代中的资源申请量为: 43.10530758208456
# agent 74 在 99 次迭代中的资源申请量为: 38.499080128425
# agent 75 在 99 次迭代中的资源申请量为: 51.2973478838796
# agent 76 在 99 次迭代中的资源申请量为: 46.388747297490916
# agent 77 在 99 次迭代中的资源申请量为: 40.26485838788529
# agent 78 在 99 次迭代中的资源申请量为: 48.982440272713035
# agent 79 在 99 次迭代中的资源申请量为: 42.33566336060991
# agent 80 在 99 次迭代中的资源申请量为: 42.410343842707455
# agent 81 在 99 次迭代中的资源申请量为: 39.075539766707045
# agent 82 在 99 次迭代中的资源申请量为: 45.19434437131853
# agent 83 在 99 次迭代中的资源申请量为: 41.11363605623186
# agent 84 在 99 次迭代中的资源申请量为: 51.320040950856374
# agent 85 在 99 次迭代中的资源申请量为: 54.9496680585843
# agent 86 在 99 次迭代中的资源申请量为: 48.30617374814425
# agent 87 在 99 次迭代中的资源申请量为: 59.60032463084996
# agent 88 在 99 次迭代中的资源申请量为: 64.08257615986368
# agent 89 在 99 次迭代中的资源申请量为: 39.90333772220398
# agent 90 在 99 次迭代中的资源申请量为: 58.44109863258806
# agent 91 在 99 次迭代中的资源申请量为: 42.32607373706707
# agent 92 在 99 次迭代中的资源申请量为: 56.23377823627112
# agent 93 在 99 次迭代中的资源申请量为: 40.25176578297215
# agent 94 在 99 次迭代中的资源申请量为: 72.18385148114452
# agent 95 在 99 次迭代中的资源申请量为: 59.442766567376154
# agent 96 在 99 次迭代中的资源申请量为: 59.615770807011785
# agent 97 在 99 次迭代中的资源申请量为: 71.01640659646647
# agent 98 在 99 次迭代中的资源申请量为: 71.97654248712601
# agent 99 在 99 次迭代中的资源申请量为: 51.73475582757461
# agent 100 在 99 次迭代中的资源申请量为: 47.91194531703763
# 资源申请量总和为: 4967.577010861153
# ****************************************************************************
# 成本总和为: 329591.72977893567
# ****************************************************************************
# agent 1 在 99 次迭代中的对偶变量为: -138.33297980769586
# agent 2 在 99 次迭代中的对偶变量为: -138.11736956679397
# agent 3 在 99 次迭代中的对偶变量为: -138.31938754199294
# agent 4 在 99 次迭代中的对偶变量为: -138.2303075749957
# agent 5 在 99 次迭代中的对偶变量为: -138.09073435794605
# agent 6 在 99 次迭代中的对偶变量为: -137.7946019907601
# agent 7 在 99 次迭代中的对偶变量为: -138.2689940201744
# agent 8 在 99 次迭代中的对偶变量为: -138.3203101332222
# agent 9 在 99 次迭代中的对偶变量为: -138.20250054920655
# agent 10 在 99 次迭代中的对偶变量为: -138.2381146916337
# agent 11 在 99 次迭代中的对偶变量为: -138.3163458322179
# agent 12 在 99 次迭代中的对偶变量为: -138.12553564617104
# agent 13 在 99 次迭代中的对偶变量为: -138.07421354866042
# agent 14 在 99 次迭代中的对偶变量为: -138.48312324330982
# agent 15 在 99 次迭代中的对偶变量为: -138.43885330351497
# agent 16 在 99 次迭代中的对偶变量为: -138.25316684575344
# agent 17 在 99 次迭代中的对偶变量为: -138.4236382883938
# agent 18 在 99 次迭代中的对偶变量为: -138.4321033794593
# agent 19 在 99 次迭代中的对偶变量为: -138.37361636872828
# agent 20 在 99 次迭代中的对偶变量为: -138.2515021648559
# agent 21 在 99 次迭代中的对偶变量为: -138.27300554624748
# agent 22 在 99 次迭代中的对偶变量为: -138.40463734708905
# agent 23 在 99 次迭代中的对偶变量为: -138.76170546095483
# agent 24 在 99 次迭代中的对偶变量为: -138.4649538447828
# agent 25 在 99 次迭代中的对偶变量为: -138.23330317747528
# agent 26 在 99 次迭代中的对偶变量为: -138.64261857426632
# agent 27 在 99 次迭代中的对偶变量为: -138.30638288928463
# agent 28 在 99 次迭代中的对偶变量为: -137.9962366061608
# agent 29 在 99 次迭代中的对偶变量为: -138.37085200538928
# agent 30 在 99 次迭代中的对偶变量为: -138.67689039624574
# agent 31 在 99 次迭代中的对偶变量为: -138.43407523365295
# agent 32 在 99 次迭代中的对偶变量为: -138.21969227988777
# agent 33 在 99 次迭代中的对偶变量为: -137.88298358460182
# agent 34 在 99 次迭代中的对偶变量为: -138.2830625588295
# agent 35 在 99 次迭代中的对偶变量为: -138.17319645741094
# agent 36 在 99 次迭代中的对偶变量为: -138.14664490294862
# agent 37 在 99 次迭代中的对偶变量为: -138.20908830219594
# agent 38 在 99 次迭代中的对偶变量为: -138.24336013073827
# agent 39 在 99 次迭代中的对偶变量为: -138.30725772455477
# agent 40 在 99 次迭代中的对偶变量为: -138.29913073126133
# agent 41 在 99 次迭代中的对偶变量为: -138.06722369641537
# agent 42 在 99 次迭代中的对偶变量为: -138.18102741036938
# agent 43 在 99 次迭代中的对偶变量为: -137.88911857700185
# agent 44 在 99 次迭代中的对偶变量为: -138.50052529036586
# agent 45 在 99 次迭代中的对偶变量为: -138.28119549113745
# agent 46 在 99 次迭代中的对偶变量为: -138.40735895508172
# agent 47 在 99 次迭代中的对偶变量为: -138.28547277557985
# agent 48 在 99 次迭代中的对偶变量为: -138.15917248283722
# agent 49 在 99 次迭代中的对偶变量为: -137.7935176748079
# agent 50 在 99 次迭代中的对偶变量为: -138.19294888947184
# agent 51 在 99 次迭代中的对偶变量为: -138.07070788545275
# agent 52 在 99 次迭代中的对偶变量为: -138.15346929666794
# agent 53 在 99 次迭代中的对偶变量为: -138.17905898890882
# agent 54 在 99 次迭代中的对偶变量为: -138.6055052667359
# agent 55 在 99 次迭代中的对偶变量为: -138.22901496997505
# agent 56 在 99 次迭代中的对偶变量为: -138.408982461136
# agent 57 在 99 次迭代中的对偶变量为: -138.38994250668904
# agent 58 在 99 次迭代中的对偶变量为: -138.30561148683933
# agent 59 在 99 次迭代中的对偶变量为: -138.30178524732625
# agent 60 在 99 次迭代中的对偶变量为: -138.31270860793643
# agent 61 在 99 次迭代中的对偶变量为: -137.95815466040995
# agent 62 在 99 次迭代中的对偶变量为: -138.24076442580446
# agent 63 在 99 次迭代中的对偶变量为: -138.4287108965098
# agent 64 在 99 次迭代中的对偶变量为: -138.25849461110448
# agent 65 在 99 次迭代中的对偶变量为: -138.11189651993274
# agent 66 在 99 次迭代中的对偶变量为: -137.79607280087268
# agent 67 在 99 次迭代中的对偶变量为: -138.24835227320042
# agent 68 在 99 次迭代中的对偶变量为: -138.22778195060047
# agent 69 在 99 次迭代中的对偶变量为: -138.28083695919454
# agent 70 在 99 次迭代中的对偶变量为: -138.18065925063343
# agent 71 在 99 次迭代中的对偶变量为: -137.69157160446264
# agent 72 在 99 次迭代中的对偶变量为: -138.04062838117753
# agent 73 在 99 次迭代中的对偶变量为: -138.0580457790875
# agent 74 在 99 次迭代中的对偶变量为: -138.316504488015
# agent 75 在 99 次迭代中的对偶变量为: -138.31257407486288
# agent 76 在 99 次迭代中的对偶变量为: -138.20399135197093
# agent 77 在 99 次迭代中的对偶变量为: -138.11349019638703
# agent 78 在 99 次迭代中的对偶变量为: -138.24732081813912
# agent 79 在 99 次迭代中的对偶变量为: -138.50125542607367
# agent 80 在 99 次迭代中的对偶变量为: -138.07516906520533
# agent 81 在 99 次迭代中的对偶变量为: -138.60705111348676
# agent 82 在 99 次迭代中的对偶变量为: -138.54190198821928
# agent 83 在 99 次迭代中的对偶变量为: -138.28908980243472
# agent 84 在 99 次迭代中的对偶变量为: -138.09611466239784
# agent 85 在 99 次迭代中的对偶变量为: -138.1891369523192
# agent 86 在 99 次迭代中的对偶变量为: -138.31852124443276
# agent 87 在 99 次迭代中的对偶变量为: -138.2407791140399
# agent 88 在 99 次迭代中的对偶变量为: -137.9016675517001
# agent 89 在 99 次迭代中的对偶变量为: -137.89201579993434
# agent 90 在 99 次迭代中的对偶变量为: -138.33863671821135
# agent 91 在 99 次迭代中的对偶变量为: -138.12865070602803
# agent 92 在 99 次迭代中的对偶变量为: -138.40782341430491
# agent 93 在 99 次迭代中的对偶变量为: -138.42635681869976
# agent 94 在 99 次迭代中的对偶变量为: -138.16770296228904
# agent 95 在 99 次迭代中的对偶变量为: -138.10263976170276
# agent 96 在 99 次迭代中的对偶变量为: -138.03784993682828
# agent 97 在 99 次迭代中的对偶变量为: -137.83281319293295
# agent 98 在 99 次迭代中的对偶变量为: -138.153084974252
# agent 99 在 99 次迭代中的对偶变量为: -138.1373163172089
# agent 100 在 99 次迭代中的对偶变量为: -138.33583595111287
# *************************
# 迭代步长为: 0.06347736393621072
# ****************************************************************************
# 149 次迭代中的结果：
# agent 1 在 149 次迭代中的资源申请量为: 48.10444563434243
# agent 2 在 149 次迭代中的资源申请量为: 60.534684580861914
# agent 3 在 149 次迭代中的资源申请量为: 43.54191219171441
# agent 4 在 149 次迭代中的资源申请量为: 64.04173661449495
# agent 5 在 149 次迭代中的资源申请量为: 64.79161626071105
# agent 6 在 149 次迭代中的资源申请量为: 71.39399391879999
# agent 7 在 149 次迭代中的资源申请量为: 39.2217411910939
# agent 8 在 149 次迭代中的资源申请量为: 37.50088842240012
# agent 9 在 149 次迭代中的资源申请量为: 42.81470409784056
# agent 10 在 149 次迭代中的资源申请量为: 55.41477641953744
# agent 11 在 149 次迭代中的资源申请量为: 45.19998855563903
# agent 12 在 149 次迭代中的资源申请量为: 48.94983202523335
# agent 13 在 149 次迭代中的资源申请量为: 65.28596774483422
# agent 14 在 149 次迭代中的资源申请量为: 54.88906529790196
# agent 15 在 149 次迭代中的资源申请量为: 43.2696134010547
# agent 16 在 149 次迭代中的资源申请量为: 43.426476297289916
# agent 17 在 149 次迭代中的资源申请量为: 44.62642670325303
# agent 18 在 149 次迭代中的资源申请量为: 46.22849544986341
# agent 19 在 149 次迭代中的资源申请量为: 41.079262413624775
# agent 20 在 149 次迭代中的资源申请量为: 55.318873599083595
# agent 21 在 149 次迭代中的资源申请量为: 38.522634380199
# agent 22 在 149 次迭代中的资源申请量为: 38.849894071248
# agent 23 在 149 次迭代中的资源申请量为: 47.61711261172572
# agent 24 在 149 次迭代中的资源申请量为: 40.29926216860906
# agent 25 在 149 次迭代中的资源申请量为: 44.879569386411525
# agent 26 在 149 次迭代中的资源申请量为: 39.59931913146731
# agent 27 在 149 次迭代中的资源申请量为: 65.0691063570797
# agent 28 在 149 次迭代中的资源申请量为: 50.924082928072174
# agent 29 在 149 次迭代中的资源申请量为: 40.57858319285366
# agent 30 在 149 次迭代中的资源申请量为: 39.006450790129904
# agent 31 在 149 次迭代中的资源申请量为: 60.03867332864618
# agent 32 在 149 次迭代中的资源申请量为: 55.1092291609822
# agent 33 在 149 次迭代中的资源申请量为: 41.271739433328996
# agent 34 在 149 次迭代中的资源申请量为: 51.90491428126857
# agent 35 在 149 次迭代中的资源申请量为: 38.60194422279369
# agent 36 在 149 次迭代中的资源申请量为: 42.50178724076554
# agent 37 在 149 次迭代中的资源申请量为: 52.18401112017228
# agent 38 在 149 次迭代中的资源申请量为: 40.05069755710655
# agent 39 在 149 次迭代中的资源申请量为: 43.03906949051157
# agent 40 在 149 次迭代中的资源申请量为: 49.79543977498319
# agent 41 在 149 次迭代中的资源申请量为: 65.68334651810969
# agent 42 在 149 次迭代中的资源申请量为: 42.209790606992506
# agent 43 在 149 次迭代中的资源申请量为: 51.29383502356309
# agent 44 在 149 次迭代中的资源申请量为: 52.66611902944824
# agent 45 在 149 次迭代中的资源申请量为: 47.89075907300468
# agent 46 在 149 次迭代中的资源申请量为: 55.46605813282243
# agent 47 在 149 次迭代中的资源申请量为: 45.59242645651038
# agent 48 在 149 次迭代中的资源申请量为: 43.10468961300126
# agent 49 在 149 次迭代中的资源申请量为: 42.31977995674212
# agent 50 在 149 次迭代中的资源申请量为: 40.639582180378184
# agent 51 在 149 次迭代中的资源申请量为: 47.935335443077015
# agent 52 在 149 次迭代中的资源申请量为: 55.28904755495488
# agent 53 在 149 次迭代中的资源申请量为: 38.703089618260336
# agent 54 在 149 次迭代中的资源申请量为: 56.626216326508626
# agent 55 在 149 次迭代中的资源申请量为: 70.46554952366104
# agent 56 在 149 次迭代中的资源申请量为: 40.6869669322961
# agent 57 在 149 次迭代中的资源申请量为: 60.02416627913191
# agent 58 在 149 次迭代中的资源申请量为: 41.93870767747539
# agent 59 在 149 次迭代中的资源申请量为: 47.59609393858356
# agent 60 在 149 次迭代中的资源申请量为: 55.63729710598505
# agent 61 在 149 次迭代中的资源申请量为: 65.34419568970735
# agent 62 在 149 次迭代中的资源申请量为: 45.781347347403916
# agent 63 在 149 次迭代中的资源申请量为: 38.7548662553202
# agent 64 在 149 次迭代中的资源申请量为: 44.08566816277736
# agent 65 在 149 次迭代中的资源申请量为: 42.39370830873369
# agent 66 在 149 次迭代中的资源申请量为: 64.98605521954609
# agent 67 在 149 次迭代中的资源申请量为: 43.0252536473618
# agent 68 在 149 次迭代中的资源申请量为: 44.57804569040231
# agent 69 在 149 次迭代中的资源申请量为: 45.091185064703446
# agent 70 在 149 次迭代中的资源申请量为: 59.55525264597007
# agent 71 在 149 次迭代中的资源申请量为: 71.25334704486926
# agent 72 在 149 次迭代中的资源申请量为: 59.70935416062811
# agent 73 在 149 次迭代中的资源申请量为: 43.38122881092995
# agent 74 在 149 次迭代中的资源申请量为: 38.73162914083909
# agent 75 在 149 次迭代中的资源申请量为: 51.61310033410199
# agent 76 在 149 次迭代中的资源申请量为: 46.67229375613992
# agent 77 在 149 次迭代中的资源申请量为: 40.52218243696975
# agent 78 在 149 次迭代中的资源申请量为: 49.28182415611013
# agent 79 在 149 次迭代中的资源申请量为: 42.584091041280395
# agent 80 在 149 次迭代中的资源申请量为: 42.68523455109017
# agent 81 在 149 次迭代中的资源申请量为: 39.29196131167715
# agent 82 在 149 次迭代中的资源申请量为: 45.455584348021006
# agent 83 在 149 次迭代中的资源申请量为: 41.360715987014075
# agent 84 在 149 次迭代中的资源申请量为: 51.65221731007072
# agent 85 在 149 次迭代中的资源申请量为: 55.299757430655454
# agent 86 在 149 次迭代中的资源申请量为: 48.6004890537777
# agent 87 在 149 次迭代中的资源申请量为: 59.975079168730325
# agent 88 在 149 次迭代中的资源申请量为: 64.52382320130056
# agent 89 在 149 次迭代中的资源申请量为: 40.17362172763486
# agent 90 在 149 次迭代中的资源申请量为: 58.807232692847215
# agent 91 在 149 次迭代中的资源申请量为: 42.5976391416882
# agent 92 在 149 次迭代中的资源申请量为: 56.56618039450073
# agent 93 在 149 次迭代中的资源申请量为: 40.49080939753835
# agent 94 在 149 次迭代中的资源申请量为: 72.64130275744853
# agent 95 在 149 次迭代中的资源申请量为: 59.82974187989333
# agent 96 在 149 次迭代中的资源申请量为: 60.00842660626242
# agent 97 在 149 次迭代中的资源申请量为: 71.50913976153598
# agent 98 在 149 次迭代中的资源申请量为: 72.43550294989838
# agent 99 在 149 次迭代中的资源申请量为: 52.06385488336356
# agent 100 在 149 次迭代中的资源申请量为: 48.20505492033755
# 资源申请量总和为: 4998.764876827516
# ****************************************************************************
# 成本总和为: 333916.3518679501
# ****************************************************************************
# agent 1 在 149 次迭代中的对偶变量为: -139.2133369030273
# agent 2 在 149 次迭代中的对偶变量为: -139.04324299406858
# agent 3 在 149 次迭代中的对偶变量为: -139.202501451829
# agent 4 在 149 次迭代中的对偶变量为: -139.13182055188892
# agent 5 在 149 次迭代中的对偶变量为: -139.0215557735643
# agent 6 在 149 次迭代中的对偶变量为: -138.78798783759999
# agent 7 在 149 次迭代中的对偶变量为: -139.1626165261568
# agent 8 在 149 次迭代中的对偶变量为: -139.20355368960048
# agent 9 在 149 次迭代中的对偶变量为: -139.1099939326579
# agent 10 在 149 次迭代中的对偶变量为: -139.13841869079735
# agent 11 在 149 次迭代中的对偶变量为: -139.1999633780449
# agent 12 在 149 次迭代中的对偶变量为: -139.04949607570003
# agent 13 在 149 次迭代中的对偶变量为: -139.0091290386353
# agent 14 在 149 次迭代中的对偶变量为: -139.3315697745451
# agent 15 在 149 次迭代中的对偶变量为: -139.29668556358598
# agent 16 在 149 次迭代中的对偶变量为: -139.15001941078572
# agent 17 在 149 次迭代中的对偶变量为: -139.2845654504097
# agent 18 在 149 次迭代中的对偶变量为: -139.2911854395629
# agent 19 在 149 次迭代中的对偶变量为: -139.2453446890492
# agent 20 在 149 次迭代中的对偶变量为: -139.14907135761734
# agent 21 在 149 次迭代中的对偶变量为: -139.1660106447562
# agent 22 在 149 次迭代中的对偶变量为: -139.26959747074238
# agent 23 在 149 次迭代中的对偶变量为: -139.55133783517715
# agent 24 在 149 次迭代中的对偶变量为: -139.31734380699262
# agent 25 在 149 次迭代中的对偶变量为: -139.1346220365169
# agent 26 在 149 次迭代中的对偶变量为: -139.45741269957577
# agent 27 在 149 次迭代中的对偶变量为: -139.19203398557536
# agent 28 在 149 次迭代中的对偶变量为: -138.9474321986021
# agent 29 在 149 次迭代中的对偶变量为: -139.24289949427316
# agent 30 在 149 次迭代中的对偶变量为: -139.48451300249363
# agent 31 在 149 次迭代中的对偶变量为: -139.29281598875082
# agent 32 在 149 次迭代中的对偶变量为: -139.12399581855374
# agent 33 在 149 次迭代中的对偶变量为: -138.8582619599844
# agent 34 在 149 次迭代中的对偶变量为: -139.173759987552
# agent 35 在 149 次迭代中的对偶变量为: -139.087388046616
# agent 36 在 149 次迭代中的对偶变量为: -139.06607661860284
# agent 37 在 149 次迭代中的对偶变量为: -139.11523113648238
# agent 38 在 149 次迭代中的对偶变量为: -139.1425112055836
# agent 39 在 149 次迭代中的对偶变量为: -139.19283626773935
# agent 40 在 149 次迭代中的对偶变量为: -139.18631932494958
# agent 41 在 149 次迭代中的对偶变量为: -139.00336233984132
# agent 42 在 149 次迭代中的对偶变量为: -139.09328806377454
# agent 43 在 149 次迭代中的对偶变量为: -138.86273806597666
# agent 44 在 149 次迭代中的对偶变量为: -139.34513328245507
# agent 45 在 149 次迭代中的对偶变量为: -139.17227721901403
# agent 46 在 149 次迭代中的对偶变量为: -139.27175114533833
# agent 47 在 149 次迭代中的对偶变量为: -139.17576466083324
# agent 48 在 149 次迭代中的对偶变量为: -139.0759446842043
# agent 49 在 149 次迭代中的对偶变量为: -138.7872518529232
# agent 50 在 149 次迭代中的对偶变量为: -139.10249584936147
# agent 51 在 149 次迭代中的对偶变量为: -139.00600632923104
# agent 52 在 149 次迭代中的对偶变量为: -139.07152364288268
# agent 53 在 149 次迭代中的对偶变量为: -139.09174054938927
# agent 54 在 149 次迭代中的对偶变量为: -139.42816244892242
# agent 55 在 149 次迭代中的对偶变量为: -139.13109904732207
# agent 56 在 149 次迭代中的对偶变量为: -139.27308095626597
# agent 57 在 149 次迭代中的对偶变量为: -139.25799906991656
# agent 58 在 149 次迭代中的对偶变量为: -139.19160610341632
# agent 59 在 149 次迭代中的对偶变量为: -139.18828181575068
# agent 60 在 149 次迭代中的对偶变量为: -139.19697247556113
# agent 61 在 149 次迭代中的对偶变量为: -138.9172305173562
# agent 62 在 149 次迭代中的对偶变量为: -139.14031151169254
# agent 63 在 149 次迭代中的对偶变量为: -139.28849177021678
# agent 64 在 149 次迭代中的对偶变量为: -139.15413812088758
# agent 65 在 149 次迭代中的对偶变量为: -139.03860824969456
# agent 66 在 149 次迭代中的对偶变量为: -138.7893214830014
# agent 67 在 149 次迭代中的对偶变量为: -139.14586240103014
# agent 68 在 149 次迭代中的对偶变量为: -139.1297462092874
# agent 69 在 149 次迭代中的对偶变量为: -139.17179220705103
# agent 70 在 149 次迭代中的对偶变量为: -139.09260635032817
# agent 71 在 149 次迭代中的对偶变量为: -138.7066940897385
# agent 72 在 149 次迭代中的对偶变量为: -138.98244998550746
# agent 73 在 149 次迭代中的对偶变量为: -138.99617795716182
# agent 74 在 149 次迭代中的对偶变量为: -139.20019073518856
# agent 75 在 149 次迭代中的对偶变量为: -139.19668093548557
# agent 76 在 149 次迭代中的对偶变量为: -139.11134001964774
# agent 77 在 149 次迭代中的对偶变量为: -139.0398567730911
# agent 78 在 149 次迭代中的对偶变量为: -139.1454724683304
# agent 79 在 149 次迭代中的对偶变量为: -139.34590954035335
# agent 80 在 149 次迭代中的对偶变量为: -139.00979747370656
# agent 81 在 149 次迭代中的对偶变量为: -139.42945298437317
# agent 82 在 149 次迭代中的对偶变量为: -139.3778699136672
# agent 83 在 149 次迭代中的对偶变量为: -139.17857755325068
# agent 84 在 149 次迭代中的对偶变量为: -139.026208468198
# agent 85 在 149 次迭代中的对偶变量为: -139.09936931970418
# agent 86 在 149 次迭代中的对偶变量为: -139.2014671613331
# agent 87 在 149 次迭代中的对偶变量为: -139.14019000495276
# agent 88 在 149 次迭代中的对偶变量为: -138.87241104286122
# agent 89 在 149 次迭代中的对偶变量为: -138.8650382194855
# agent 90 在 149 次迭代中的对偶变量为: -139.21735846283332
# agent 91 在 149 次迭代中的对偶变量为: -139.05197308173987
# agent 92 在 149 次迭代中的对偶变量为: -139.2720690257019
# agent 93 在 149 次迭代中的对偶变量为: -139.28691383113807
# agent 94 在 149 次迭代中的对偶变量为: -139.08260551489707
# agent 95 在 149 次迭代中的对偶变量为: -139.03138051174398
# agent 96 在 149 次迭代中的对偶变量为: -138.9802238550298
# agent 97 在 149 次迭代中的对偶变量为: -138.81827952307196
# agent 98 在 149 次迭代中的对偶变量为: -139.07100589979675
# agent 99 在 149 次迭代中的对偶变量为: -139.05879367341797
# agent 100 在 149 次迭代中的对偶变量为: -139.21516476101266
# *************************
# 迭代步长为: 0.04966932281851884
# ****************************************************************************
# 199 次迭代中的结果：
# agent 1 在 199 次迭代中的资源申请量为: 48.20051467458899
# agent 2 在 199 次迭代中的资源申请量为: 60.66587389138369
# agent 3 在 199 次迭代中的资源申请量为: 43.6271633613142
# agent 4 在 199 次迭代中的资源申请量为: 64.17844270845033
# agent 5 在 199 次迭代中的资源申请量为: 64.93614510563216
# agent 6 在 199 次迭代中的资源申请量为: 71.57128858746793
# agent 7 在 199 次迭代中的资源申请量为: 39.299645060563016
# agent 8 在 199 次迭代中的资源申请量为: 37.57334588634621
# agent 9 在 199 次迭代中的资源申请量为: 42.90418254478888
# agent 10 在 199 次迭代中的资源申请量为: 55.53012967076174
# agent 11 在 199 次迭代中的资源申请量为: 45.290669103704154
# agent 12 在 199 次迭代中的资源申请量为: 49.05442986456791
# agent 13 在 199 次迭代中的资源申请量为: 65.43151561995566
# agent 14 在 199 次迭代中的资源申请量为: 54.992751526720966
# agent 15 在 199 次迭代中的资源申请量为: 43.35051650437922
# agent 16 在 199 次迭代中的资源申请量为: 43.51410944867048
# agent 17 在 199 次迭代中的资源申请量为: 44.71296019765167
# agent 18 在 199 次迭代中的资源申请量为: 46.31469023090472
# agent 19 在 199 次迭代中的资源申请量为: 41.157920002057
# agent 20 在 199 次迭代中的资源申请量为: 55.43359681250337
# agent 21 在 199 次迭代中的资源申请量为: 38.60042838477784
# agent 22 在 199 次迭代中的资源申请量为: 38.923380499044036
# agent 23 在 199 次迭代中的资源申请量为: 47.69548364970719
# agent 24 在 199 次迭代中的资源申请量为: 40.374782102659736
# agent 25 在 199 次迭代中的资源申请量为: 44.97348652590068
# agent 26 在 199 次迭代中的资源申请量为: 39.66507243983933
# agent 27 在 199 次迭代中的资源申请量为: 65.20155947099877
# agent 28 在 199 次迭代中的资源申请量为: 51.04185805269241
# agent 29 在 199 次迭代中的资源申请量为: 40.65731054316613
# agent 30 在 199 次迭代中的资源申请量为: 39.07109200072249
# agent 31 在 199 次迭代中的资源申请量为: 60.153518492296136
# agent 32 在 199 次迭代中的资源申请量为: 55.225471681828374
# agent 33 在 199 次迭代中的资源申请量为: 41.36725070004599
# agent 34 在 199 次迭代中的资源申请量为: 52.010028863266356
# agent 35 在 199 次迭代中的资源申请量为: 38.68299925508362
# agent 36 在 199 次迭代中的资源申请量为: 42.59330604175326
# agent 37 在 199 次迭代中的资源申请量为: 52.2923688747511
# agent 38 在 199 次迭代中的资源申请量为: 40.133823550366856
# agent 39 在 199 次迭代中的资源申请量为: 43.1247459975721
# agent 40 在 199 次迭代中的资源申请量为: 49.892868446175775
# agent 41 在 199 次迭代中的资源申请量为: 65.82924220602092
# agent 42 在 199 次迭代中的资源申请量为: 42.300068484657665
# agent 43 在 199 次迭代中的资源申请量为: 51.41632121974668
# agent 44 在 199 次迭代中的资源申请量为: 52.761603066714414
# agent 45 在 199 次迭代中的资源申请量为: 47.98894550848476
# agent 46 在 199 次迭代中的资源申请量为: 55.573337751020496
# agent 47 在 199 次迭代中的资源申请量为: 45.68431998485147
# agent 48 在 199 次迭代中的资源申请量为: 43.19574872082091
# agent 49 在 199 次迭代中的资源申请量为: 42.42412489383786
# agent 50 在 199 次迭代中的资源申请量为: 40.72441611572005
# agent 51 在 199 次迭代中的资源申请量为: 48.04217121366876
# agent 52 在 199 次迭代中的资源申请量为: 55.408406009990514
# agent 53 在 199 次迭代中的资源申请量为: 38.78392782420998
# agent 54 在 199 次迭代中的资源申请量为: 56.72407798915704
# agent 55 在 199 次迭代中的资源申请量为: 70.61603864157163
# agent 56 在 199 次迭代中的资源申请量为: 40.76439424267124
# agent 57 在 199 次迭代中的资源申请量为: 60.14128033445345
# agent 58 在 199 次迭代中的资源申请量为: 42.02446165995907
# agent 59 在 199 次迭代中的资源申请量为: 47.69340281207812
# agent 60 在 199 次迭代中的资源申请量为: 55.749060819479254
# agent 61 在 199 次迭代中的资源申请量为: 65.49619916610337
# agent 62 在 199 次迭代中的资源申请量为: 45.874943075140756
# agent 63 在 199 次迭代中的资源申请量为: 38.82756433387971
# agent 64 在 199 次迭代中的资源申请量为: 44.178570224784245
# agent 65 在 199 次迭代中的资源申请量为: 42.48649354402124
# agent 66 在 199 次迭代中的资源申请量为: 65.14717375202676
# agent 67 在 199 次迭代中的资源申请量为: 43.113034264726444
# agent 68 在 199 次迭代中的资源申请量为: 44.67211622677679
# agent 69 在 199 次迭代中的资源申请量为: 45.18321958301354
# agent 70 在 199 次迭代中的资源申请量为: 59.68310708831137
# agent 71 在 199 次迭代中的资源申请量为: 71.43701348422981
# agent 72 在 199 次迭代中的资源申请量为: 59.844470511169874
# agent 73 在 199 次迭代中的资源申请量为: 43.47596823879928
# agent 74 在 199 次迭代中的资源申请量为: 38.807993387216094
# agent 75 在 199 次迭代中的资源申请量为: 51.716868301704075
# agent 76 在 199 次迭代中的资源申请量为: 46.76731974510119
# agent 77 在 199 次迭代中的资源申请量为: 40.60975057983093
# agent 78 在 199 次迭代中的资源申请量为: 49.38138962006442
# agent 79 在 199 次迭代中的资源申请量为: 42.66271695070503
# agent 80 在 199 次迭代中的资源申请量为: 42.77936455434618
# agent 81 在 199 次迭代中的资源申请量为: 39.35887878854857
# agent 82 在 199 次迭代中的资源申请量为: 45.53754157571487
# agent 83 在 199 次迭代中的资源申请量为: 41.442267961382974
# agent 84 在 199 次迭代中的资源申请量为: 51.765579061295725
# agent 85 在 199 次迭代中的资源申请量为: 55.417383897635425
# agent 86 在 199 次迭代中的资源申请量为: 48.697112297050836
# agent 87 在 199 次迭代中的资源申请量为: 60.099864099569835
# agent 88 在 199 次迭代中的资源申请量为: 64.67896908451806
# agent 89 在 199 次迭代中的资源申请量为: 40.26878986341821
# agent 90 在 199 次迭代中的资源申请量为: 58.926965124900974
# agent 91 在 199 次迭代中的资源申请量为: 42.68982199142426
# agent 92 在 199 次迭代中的资源申请量为: 56.67342994510675
# agent 93 在 199 次迭代中的资源申请量为: 40.56765146082592
# agent 94 在 199 次迭代中的资源申请量为: 72.79556306793934
# agent 95 在 199 次迭代中的资源申请量为: 59.961666018105696
# agent 96 在 199 次迭代中的资源申请量为: 60.143690424419454
# agent 97 在 199 次迭代中的资源申请量为: 71.6840897504849
# agent 98 在 199 次迭代中的资源申请量为: 72.59065842785726
# agent 99 在 199 次迭代中的资源申请量为: 52.175408062506904
# agent 100 在 199 次迭代中的资源申请量为: 48.300970288029056
# 资源申请量总和为: 5009.187653696861
# ****************************************************************************
# 成本总和为: 335367.85927853757
# ****************************************************************************
# agent 1 在 199 次迭代中的对偶变量为: -139.50154402376697
# agent 2 在 199 次迭代中的对偶变量为: -139.35809733932084
# agent 3 在 199 次迭代中的对偶变量为: -139.49235542846827
# agent 4 在 199 次迭代中的对偶变量为: -139.43257395859075
# agent 5 在 199 次迭代中的对偶变量为: -139.33951923239076
# agent 6 在 199 次迭代中的对偶变量为: -139.14257717493587
# agent 7 在 199 次迭代中的对偶变量为: -139.45865123013945
# agent 8 在 199 次迭代中的对偶变量为: -139.49338354538483
# agent 9 在 199 次迭代中的对偶变量为: -139.41422065228218
# agent 10 在 199 次迭代中的对偶变量为: -139.43833714398053
# agent 11 在 199 次迭代中的对偶变量为: -139.4901411318533
# agent 12 在 199 次迭代中的对偶变量为: -139.3632895937037
# agent 13 在 199 次迭代中的对偶变量为: -139.32933436390246
# agent 14 在 199 次迭代中的对偶变量为: -139.60115396947452
# agent 15 在 199 次迭代中的对偶变量为: -139.57175611488935
# agent 16 在 199 次迭代中的对偶变量为: -139.44797212547962
# agent 17 在 199 次迭代中的对偶变量为: -139.56147263248533
# agent 18 在 199 次迭代中的对偶变量为: -139.5670087388951
# agent 19 在 199 次迭代中的对偶变量为: -139.52851200740517
# agent 20 在 199 次迭代中的对偶变量为: -139.44735171250875
# agent 21 在 199 次迭代中的对偶变量为: -139.4616278621558
# agent 22 在 199 次迭代中的对偶变量为: -139.54884589636734
# agent 23 在 199 次迭代中的对偶变量为: -139.78645094912156
# agent 24 在 199 次迭代中的对偶变量为: -139.58921556957506
# agent 25 在 199 次迭代中的对偶变量为: -139.4351568828822
# agent 26 在 199 次迭代中的对偶变量为: -139.70727527138942
# agent 27 在 199 次迭代中的对偶变量为: -139.4834308361973
# agent 28 在 199 次迭代中的对偶变量为: -139.27720254753876
# agent 29 在 199 次迭代中的对偶变量为: -139.52631795539807
# agent 30 在 199 次迭代中的对偶变量为: -139.73014960274543
# agent 31 在 199 次迭代中的对偶变量为: -139.56844438151072
# agent 32 在 199 次迭代中的对偶变量为: -139.42622637275377
# agent 33 在 199 次迭代中的对偶变量为: -139.20210252016557
# agent 34 在 199 次迭代中的对偶变量为: -139.4680808171458
# agent 35 在 199 次迭代中的对偶变量为: -139.39539716931776
# agent 36 在 199 次迭代中的对偶变量为: -139.37724054196107
# agent 37 在 199 次迭代中的对偶变量为: -139.41863284930307
# agent 38 在 199 次迭代中的对偶变量为: -139.4417647813207
# agent 39 在 199 次迭代中的对偶变量为: -139.48413639174515
# agent 40 在 199 次迭代中的对偶变量为: -139.47860533852733
# agent 41 在 199 次迭代中的对偶变量为: -139.32433285324603
# agent 42 在 199 次迭代中的对偶变量为: -139.40023284783607
# agent 43 在 199 次迭代中的对偶变量为: -139.2056994152907
# agent 44 在 199 次迭代中的对偶变量为: -139.61248858680034
# agent 45 在 199 次迭代中的对偶变量为: -139.46683652545428
# agent 46 在 199 次迭代中的对偶变量为: -139.5506781526533
# agent 47 在 199 次迭代中的对偶变量为: -139.46982395152472
# agent 48 在 199 次迭代中的对偶变量为: -139.3855456507911
# agent 49 在 199 次迭代中的对偶变量为: -139.14202463904874
# agent 50 在 199 次迭代中的对偶变量为: -139.40789801659218
# agent 51 在 199 次迭代中的对偶变量为: -139.32651364100627
# agent 52 在 199 次迭代中的对偶变量为: -139.38185562597533
# agent 53 在 199 次迭代中的对偶变量为: -139.39892573199793
# agent 54 在 199 次迭代中的对偶变量为: -139.6826027718083
# agent 55 在 199 次迭代中的对偶变量为: -139.43207728314326
# agent 56 在 199 次迭代中的对偶变量为: -139.55181927361647
# agent 57 在 199 次迭代中的对偶变量为: -139.53907280268825
# agent 58 在 199 次迭代中的对偶变量为: -139.48316964386083
# agent 59 在 199 次迭代中的对偶变量为: -139.48020843623436
# agent 60 在 199 次迭代中的对偶变量为: -139.48755813064605
# agent 61 在 199 次迭代中的对偶变量为: -139.2516381654274
# agent 62 在 199 次迭代中的对偶变量为: -139.43981784045042
# agent 63 在 199 次迭代中的对偶变量为: -139.5647444687429
# agent 64 在 199 次迭代中的对偶变量为: -139.4514247193096
# agent 65 在 199 次迭代中的对偶变量为: -139.35407804967224
# agent 66 在 199 次迭代中的对偶变量为: -139.14378225445887
# agent 67 在 199 次迭代中的对偶变量为: -139.44431650006993
# agent 68 在 199 次迭代中的对偶变量为: -139.43077192568572
# agent 69 在 199 次迭代中的对偶变量为: -139.46630266564333
# agent 70 在 199 次迭代中的对偶变量为: -139.39945701194728
# agent 71 在 199 次迭代中的对偶变量为: -139.0740269684596
# agent 72 在 199 次迭代中的对偶变量为: -139.3067292268077
# agent 73 在 199 次迭代中的对偶变量为: -139.31829201191755
# agent 74 在 199 次迭代中的对偶变量为: -139.49037487142115
# agent 75 在 199 次迭代中的对偶变量为: -139.4872312447714
# agent 76 在 199 次迭代中的对偶变量为: -139.4154231843238
# agent 77 在 199 次迭代中的对偶变量为: -139.35510208739134
# agent 78 在 199 次迭代中的对偶变量为: -139.44416886019326
# agent 79 在 199 次迭代中的对偶变量为: -139.6132376323971
# agent 80 在 199 次迭代中的对偶变量为: -139.329839484777
# agent 81 在 199 次迭代中的对偶变量为: -139.68373939648458
# agent 82 在 199 次迭代中的对偶变量为: -139.64013304228757
# agent 83 在 199 次迭代中的对偶变量为: -139.4721646609787
# agent 84 在 199 次迭代中的对偶变量为: -139.34362137162802
# agent 85 在 199 次迭代中的对偶变量为: -139.4051981338521
# agent 86 在 199 次迭代中的对偶变量为: -139.4913368911525
# agent 87 在 199 次迭代中的对偶变量为: -139.4396738389676
# agent 88 在 199 次迭代中的对偶变量为: -139.21373198593972
# agent 89 在 199 次迭代中的对偶变量为: -139.20764350830558
# agent 90 在 199 次迭代中的对偶变量为: -139.50471629976235
# agent 91 在 199 次迭代中的对偶变量为: -139.36539477084247
# agent 92 在 199 次迭代中的对偶变量为: -139.55091785727754
# agent 93 在 199 次迭代中的对偶变量为: -139.56354525897333
# agent 94 在 199 次迭代中的对偶变量为: -139.3911261358787
# agent 95 在 199 次迭代中的对偶变量为: -139.34799844345366
# agent 96 在 199 次迭代中的对偶变量为: -139.3048570186067
# agent 97 在 199 次迭代中的对偶变量为: -139.1681795009698
# agent 98 在 199 次迭代中的对偶变量为: -139.38131685571452
# agent 99 在 199 次迭代中的对偶变量为: -139.37114257501932
# agent 100 在 199 次迭代中的对偶变量为: -139.50291086408717
# *************************
# 迭代步长为: 0.04175304505755262
# ****************************************************************************
# 249 次迭代中的结果：
# agent 1 在 249 次迭代中的资源申请量为: 48.23881818364197
# agent 2 在 249 次迭代中的资源申请量为: 60.72118850788577
# agent 3 在 249 次迭代中的资源申请量为: 43.661288355992845
# agent 4 在 249 次迭代中的资源申请量为: 64.23451847211206
# agent 5 在 249 次迭代中的资源申请量为: 64.99746701832436
# agent 6 在 249 次迭代中的资源申请量为: 71.65100431674354
# agent 7 在 249 次迭代中的资源申请量为: 39.33127050033399
# agent 8 在 249 次迭代中的资源申请量为: 37.602339688311304
# agent 9 在 249 次迭代中的资源申请量为: 42.9411477087257
# agent 10 在 249 次迭代中的资源申请量为: 55.57734613484748
# agent 11 在 249 次迭代中的资源申请量为: 45.32699885554337
# agent 12 在 249 次迭代中的资源申请量为: 49.098451577590964
# agent 13 在 249 次迭代中的资源申请量为: 65.49349246960783
# agent 14 在 249 次迭代中的资源申请量为: 55.03215975863754
# agent 15 在 249 次迭代中的资源申请量为: 43.38173169179636
# agent 16 在 249 次迭代中的资源申请量为: 43.54983648691445
# agent 17 在 249 次迭代中的资源申请量为: 44.74651413918945
# agent 18 在 249 次迭代中的资源申请量为: 46.34801861594683
# agent 19 在 249 次迭代中的资源申请量为: 41.188903509429245
# agent 20 在 249 次迭代中的资源申请量为: 55.48038738072943
# agent 21 在 249 次迭代中的资源申请量为: 38.6319743307713
# agent 22 在 249 次迭代中的资源申请量为: 38.95204814508033
# agent 23 在 249 次迭代中的资源申请量为: 47.721941750485634
# agent 24 在 249 次迭代中的资源申请量为: 40.40366631625839
# agent 25 在 249 次迭代中的资源申请量为: 45.011979547013404
# agent 26 在 249 次迭代中的资源申请量为: 39.68855974257587
# agent 27 在 249 次迭代中的资源申请量为: 65.25477726422956
# agent 28 在 249 次迭代中的资源申请量为: 51.09284772312692
# agent 29 在 249 次迭代中的资源申请量为: 40.688347906759425
# agent 30 在 249 次迭代中的资源申请量为: 39.093832667788206
# agent 31 在 249 次迭代中的资源申请量为: 60.197899831227005
# agent 32 在 249 次迭代中的资源申请量为: 55.273279136071245
# agent 33 在 249 次迭代中的资源申请量为: 41.40952221277336
# agent 34 在 249 次迭代中的资源申请量为: 52.05253799657562
# agent 35 在 249 次迭代中的资源申请量为: 38.716726400365225
# agent 36 在 249 次迭代中的资源申请量为: 42.63163286300196
# agent 37 在 249 次迭代中的资源申请量为: 52.33705549895269
# agent 38 在 249 次迭代中的资源申请量为: 40.16780170445022
# agent 39 在 249 次迭代中的资源申请量为: 43.159157930877065
# agent 40 在 249 次迭代中的资源申请量为: 49.932092897170186
# agent 41 在 249 次迭代中的资源申请量为: 65.89146274112925
# agent 42 在 249 次迭代中的资源申请量为: 42.337561823820074
# agent 43 在 249 次迭代中的资源申请量为: 51.47047306321027
# agent 44 在 249 次迭代中的资源申请量为: 52.79766828622105
# agent 45 在 249 次迭代中的资源申请量为: 48.02867445002702
# agent 46 在 249 次迭代中的资源申请量为: 55.615154226756005
# agent 47 在 249 次迭代中的资源申请量为: 45.721457543075644
# agent 48 在 249 次迭代中的资源申请量为: 43.2337678401941
# agent 49 在 249 次迭代中的资源申请量为: 42.471049269032086
# agent 50 在 249 次迭代中的资源申请量为: 40.759544730518506
# agent 51 在 249 次迭代中的资源申请量为: 48.087699767535184
# agent 52 在 249 次迭代中的资源申请量为: 55.45830851211372
# agent 53 在 249 次迭代中的资源申请量为: 38.81751664819734
# agent 54 在 249 次迭代中的资源申请量为: 56.75958272179194
# agent 55 在 249 次迭代中的资源申请量为: 70.67778057393477
# agent 56 在 249 次迭代中的资源申请量为: 40.794558196141736
# agent 57 在 249 次迭代中的资源申请量为: 60.18718082787019
# agent 58 在 249 次迭代中的资源申请量为: 42.05892466845464
# agent 59 在 249 次迭代中的资源申请量为: 47.732551816303925
# agent 60 在 249 次迭代中的资源申请量为: 55.79388388309247
# agent 61 在 249 次迭代中的资源申请量为: 65.56251311335488
# agent 62 在 249 次迭代中的资源申请量为: 45.913225518464245
# agent 63 在 249 次迭代中的资源申请量为: 38.85570689430756
# agent 64 在 249 次迭代中的资源申请量为: 44.21639400705619
# agent 65 在 249 次迭代中的资源申请量为: 42.52567097349357
# agent 66 在 249 次迭代中的资源申请量为: 65.21959541561901
# agent 67 在 249 次迭代中的资源申请量为: 43.148871174407596
# agent 68 在 249 次迭代中的资源申请量为: 44.710727464779126
# agent 69 在 249 次迭代中的资源申请量为: 45.220460769614
# agent 70 在 249 次迭代中的资源申请量为: 59.736212094913924
# agent 71 在 249 次迭代中的资源申请量为: 71.52099748731452
# agent 72 在 249 次迭代中的资源申请量为: 59.90242636039901
# agent 73 在 249 次迭代中的资源申请量为: 43.516451859676174
# agent 74 在 249 次迭代中的资源申请量为: 38.83858492772035
# agent 75 在 249 次迭代中的资源申请量为: 51.75848806051616
# agent 76 在 249 次迭代中的资源申请量为: 46.8065594185341
# agent 77 在 249 次迭代中的资源申请量为: 40.646709193213155
# agent 78 在 249 次迭代中的资源申请量为: 49.422043890882065
# agent 79 在 249 次迭代中的资源申请量为: 42.69240653044879
# agent 80 在 249 次迭代中的资源申请量为: 42.81943710535213
# agent 81 在 249 次迭代中的资源申请量为: 39.3831428951944
# agent 82 在 249 次迭代中的资源申请量为: 45.56802986081053
# agent 83 在 249 次迭代中的资源申请量为: 41.47519203284371
# agent 84 在 249 次迭代中的资源申请量为: 51.81361364454665
# agent 85 在 249 次迭代中的资源申请量为: 55.46613776213678
# agent 86 在 249 次迭代中的资源申请量为: 48.73580324395169
# agent 87 在 249 次迭代中的资源申请量为: 60.150907723543035
# agent 88 在 249 次迭代中的资源申请量为: 64.74739964959797
# agent 89 在 249 次迭代中的资源申请量为: 40.310841178114536
# agent 90 在 249 次迭代中的资源申请量为: 58.97462546019887
# agent 91 在 249 次迭代中的资源申请量为: 42.72859080553656
# agent 92 在 249 次迭代中的资源申请量为: 56.71522772590876
# agent 93 在 249 次迭代中的资源申请量为: 40.597420110477195
# agent 94 在 249 次迭代中的资源申请量为: 72.85983702590917
# agent 95 在 249 次迭代中的资源申请量为: 60.017483631964765
# agent 96 在 249 次迭代中的资源申请量为: 60.201747324276674
# agent 97 在 249 次迭代中的资源申请量为: 71.76222714846105
# agent 98 在 249 次迭代中的资源申请量为: 72.65553548793605
# agent 99 在 249 次迭代中的资源申请量为: 52.22222864627254
# agent 100 在 249 次迭代中的资源申请量为: 48.339186051829124
# 资源申请量总和为: 5013.474026496853
# ****************************************************************************
# 成本总和为: 335965.6857400299
# ...
# agent 61 在 57999 次迭代中的资源申请量为: 45.35594989347403
# agent 62 在 57999 次迭代中的资源申请量为: 37.777916501990724
# agent 63 在 57999 次迭代中的资源申请量为: 44.36024833408177
# agent 64 在 57999 次迭代中的资源申请量为: 50.59248382563158
# agent 65 在 57999 次迭代中的资源申请量为: 48.719342447654434
# agent 66 在 57999 次迭代中的资源申请量为: 53.47780999250294
# agent 67 在 57999 次迭代中的资源申请量为: 44.62937911116489
# agent 68 在 57999 次迭代中的资源申请量为: 38.64566746179317
# agent 69 在 57999 次迭代中的资源申请量为: 49.892139157742264
# agent 70 在 57999 次迭代中的资源申请量为: 43.38409217370307
# agent 71 在 57999 次迭代中的资源申请量为: 51.072439614453316
# agent 72 在 57999 次迭代中的资源申请量为: 51.63101181607402
# agent 73 在 57999 次迭代中的资源申请量为: 68.52493850742536
# agent 74 在 57999 次迭代中的资源申请量为: 63.033563690013715
# agent 75 在 57999 次迭代中的资源申请量为: 68.784860310892
# agent 76 在 57999 次迭代中的资源申请量为: 65.84231131075826
# agent 77 在 57999 次迭代中的资源申请量为: 37.33178559067635
# agent 78 在 57999 次迭代中的资源申请量为: 56.51515954674519
# agent 79 在 57999 次迭代中的资源申请量为: 35.71319766839764
# agent 80 在 57999 次迭代中的资源申请量为: 41.69438982489503
# agent 81 在 57999 次迭代中的资源申请量为: 64.43288578237497
# agent 82 在 57999 次迭代中的资源申请量为: 45.64920279686928
# agent 83 在 57999 次迭代中的资源申请量为: 54.00548947849253
# agent 84 在 57999 次迭代中的资源申请量为: 52.98642785861979
# agent 85 在 57999 次迭代中的资源申请量为: 58.685757530611916
# agent 86 在 57999 次迭代中的资源申请量为: 54.16278250297388
# agent 87 在 57999 次迭代中的资源申请量为: 50.183947875573004
# agent 88 在 57999 次迭代中的资源申请量为: 53.40486804038364
# agent 89 在 57999 次迭代中的资源申请量为: 44.037016821613456
# agent 90 在 57999 次迭代中的资源申请量为: 38.995841039652966
# agent 91 在 57999 次迭代中的资源申请量为: 43.58677066582213
# agent 92 在 57999 次迭代中的资源申请量为: 45.25809138455365
# agent 93 在 57999 次迭代中的资源申请量为: 35.68321481266967
# agent 94 在 57999 次迭代中的资源申请量为: 37.48060785879904
# 资源申请量平均值avg为: 49.99999999999654
# ****************************************************************************
# 平均成本为: 3240.481984531225
# ****************************************************************************
# agent 1 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 2 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 3 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 4 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 5 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 6 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 7 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 8 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 9 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 10 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 11 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 12 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 13 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 14 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 15 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 16 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 17 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 18 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 19 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 20 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 21 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 22 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 23 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 24 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 25 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 26 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 27 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 28 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 29 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 30 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 31 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 32 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 33 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 34 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 35 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 36 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 37 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 38 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 39 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 40 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 41 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 42 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 43 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 44 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 45 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 46 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 47 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 48 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 49 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 50 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 51 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 52 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 53 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 54 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 55 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 56 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 57 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 58 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 59 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 60 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 61 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 62 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 63 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 64 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 65 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 66 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 67 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 68 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 69 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 70 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 71 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 72 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 73 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 74 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 75 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 76 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 77 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 78 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 79 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 80 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 81 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 82 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 83 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 84 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 85 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 86 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 87 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 88 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 89 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 90 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 91 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 92 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 93 在 57999 次迭代中的对偶变量为: -135.14386653834575
# agent 94 在 57999 次迭代中的对偶变量为: -135.14386653834575
# *************************
# 迭代步长为: 0.11151053484837568
# ****************************************************************************
# 59999 次迭代中的结果：
# agent 1 在 59999 次迭代中的资源申请量为: 56.19880558172988
# agent 2 在 59999 次迭代中的资源申请量为: 56.03871203978166
# agent 3 在 59999 次迭代中的资源申请量为: 60.64796214442871
# agent 4 在 59999 次迭代中的资源申请量为: 37.93333499802675
# agent 5 在 59999 次迭代中的资源申请量为: 57.56693686702461
# agent 6 在 59999 次迭代中的资源申请量为: 55.34212747123894
# agent 7 在 59999 次迭代中的资源申请量为: 65.6236567946489
# agent 8 在 59999 次迭代中的资源申请量为: 46.330946703602365
# agent 9 在 59999 次迭代中的资源申请量为: 65.64268770463663
# agent 10 在 59999 次迭代中的资源申请量为: 54.23914303693835
# agent 11 在 59999 次迭代中的资源申请量为: 65.4520437985654
# agent 12 在 59999 次迭代中的资源申请量为: 38.406222330358624
# agent 13 在 59999 次迭代中的资源申请量为: 49.70058714461363
# agent 14 在 59999 次迭代中的资源申请量为: 41.3659905551611
# agent 15 在 59999 次迭代中的资源申请量为: 42.48853939614691
# agent 16 在 59999 次迭代中的资源申请量为: 49.24530133808371
# agent 17 在 59999 次迭代中的资源申请量为: 50.11852704992918
# agent 18 在 59999 次迭代中的资源申请量为: 46.537297422347486
# agent 19 在 59999 次迭代中的资源申请量为: 44.77392156663175
# agent 20 在 59999 次迭代中的资源申请量为: 50.80339666473046
# agent 21 在 59999 次迭代中的资源申请量为: 69.93387670557085
# agent 22 在 59999 次迭代中的资源申请量为: 61.24199691647269
# agent 23 在 59999 次迭代中的资源申请量为: 61.627787986086716
# agent 24 在 59999 次迭代中的资源申请量为: 39.861352301782716
# agent 25 在 59999 次迭代中的资源申请量为: 52.95065687328203
# agent 26 在 59999 次迭代中的资源申请量为: 49.39633437684004
# agent 27 在 59999 次迭代中的资源申请量为: 47.51919637207136
# agent 28 在 59999 次迭代中的资源申请量为: 40.7413613830987
# agent 29 在 59999 次迭代中的资源申请量为: 44.38273034135506
# agent 30 在 59999 次迭代中的资源申请量为: 39.891745956789116
# agent 31 在 59999 次迭代中的资源申请量为: 65.76280653244551
# agent 32 在 59999 次迭代中的资源申请量为: 59.51901541924079
# agent 33 在 59999 次迭代中的资源申请量为: 48.23750867799392
# agent 34 在 59999 次迭代中的资源申请量为: 36.76532342510125
# agent 35 在 59999 次迭代中的资源申请量为: 41.086702696803464
# agent 36 在 59999 次迭代中的资源申请量为: 62.20889044924783
# agent 37 在 59999 次迭代中的资源申请量为: 40.47023795026076
# agent 38 在 59999 次迭代中的资源申请量为: 58.24733429492913
# agent 39 在 59999 次迭代中的资源申请量为: 37.39554726071002
# agent 40 在 59999 次迭代中的资源申请量为: 50.45313221045784
# agent 41 在 59999 次迭代中的资源申请量为: 36.73569742369616
# agent 42 在 59999 次迭代中的资源申请量为: 56.24242387150355
# agent 43 在 59999 次迭代中的资源申请量为: 61.52373322591861
# agent 44 在 59999 次迭代中的资源申请量为: 47.51525622305313
# agent 45 在 59999 次迭代中的资源申请量为: 41.36197014706921
# agent 46 在 59999 次迭代中的资源申请量为: 67.10436077257359
# agent 47 在 59999 次迭代中的资源申请量为: 65.57090570810219
# agent 48 在 59999 次迭代中的资源申请量为: 40.83836334458436
# agent 49 在 59999 次迭代中的资源申请量为: 39.16390664937778
# agent 50 在 59999 次迭代中的资源申请量为: 63.292999181236645
# agent 51 在 59999 次迭代中的资源申请量为: 36.39727688961264
# agent 52 在 59999 次迭代中的资源申请量为: 46.86937779818014
# agent 53 在 59999 次迭代中的资源申请量为: 43.572511920796444
# agent 54 在 59999 次迭代中的资源申请量为: 49.58201107681077
# agent 55 在 59999 次迭代中的资源申请量为: 47.173391517077015
# agent 56 在 59999 次迭代中的资源申请量为: 42.97971616155657
# agent 57 在 59999 次迭代中的资源申请量为: 36.90486251978384
# agent 58 在 59999 次迭代中的资源申请量为: 59.2566799113546
# agent 59 在 59999 次迭代中的资源申请量为: 59.891586060534515
# agent 60 在 59999 次迭代中的资源申请量为: 40.34169962872796
# agent 61 在 59999 次迭代中的资源申请量为: 45.35594989347582
# agent 62 在 59999 次迭代中的资源申请量为: 37.77791650199216
# agent 63 在 59999 次迭代中的资源申请量为: 44.360248334083515
# agent 64 在 59999 次迭代中的资源申请量为: 50.59248382563358
# agent 65 在 59999 次迭代中的资源申请量为: 48.71934244765636
# agent 66 在 59999 次迭代中的资源申请量为: 53.47780999250507
# agent 67 在 59999 次迭代中的资源申请量为: 44.62937911116663
# agent 68 在 59999 次迭代中的资源申请量为: 38.64566746179467
# agent 69 在 59999 次迭代中的资源申请量为: 49.89213915774424
# agent 70 在 59999 次迭代中的资源申请量为: 43.384092173704765
# agent 71 在 59999 次迭代中的资源申请量为: 51.07243961445531
# agent 72 在 59999 次迭代中的资源申请量为: 51.63101181607605
# agent 73 在 59999 次迭代中的资源申请量为: 68.52493850742809
# agent 74 在 59999 次迭代中的资源申请量为: 63.033563690016244
# agent 75 在 59999 次迭代中的资源申请量为: 68.78486031089474
# agent 76 在 59999 次迭代中的资源申请量为: 65.84231131076093
# agent 77 在 59999 次迭代中的资源申请量为: 37.33178559067781
# agent 78 在 59999 次迭代中的资源申请量为: 56.51515954674745
# agent 79 在 59999 次迭代中的资源申请量为: 35.713197668399026
# agent 80 在 59999 次迭代中的资源申请量为: 41.69438982489667
# agent 81 在 59999 次迭代中的资源申请量为: 64.43288578237754
# agent 82 在 59999 次迭代中的资源申请量为: 45.64920279687104
# agent 83 在 59999 次迭代中的资源申请量为: 54.00548947849467
# agent 84 在 59999 次迭代中的资源申请量为: 52.98642785862186
# agent 85 在 59999 次迭代中的资源申请量为: 58.685757530614225
# agent 86 在 59999 次迭代中的资源申请量为: 54.16278250297603
# agent 87 在 59999 次迭代中的资源申请量为: 50.18394787557497
# agent 88 在 59999 次迭代中的资源申请量为: 53.40486804038577
# agent 89 在 59999 次迭代中的资源申请量为: 44.03701682161516
# agent 90 在 59999 次迭代中的资源申请量为: 38.99584103965445
# agent 91 在 59999 次迭代中的资源申请量为: 43.58677066582381
# agent 92 在 59999 次迭代中的资源申请量为: 45.258091384555385
# agent 93 在 59999 次迭代中的资源申请量为: 35.68321481267107
# agent 94 在 59999 次迭代中的资源申请量为: 37.4806078588005
# 资源申请量平均值avg为: 49.9999999999985
# ****************************************************************************
# 平均成本为: 3240.4819845314896
# ****************************************************************************
# agent 1 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 2 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 3 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 4 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 5 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 6 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 7 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 8 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 9 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 10 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 11 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 12 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 13 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 14 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 15 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 16 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 17 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 18 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 19 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 20 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 21 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 22 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 23 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 24 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 25 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 26 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 27 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 28 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 29 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 30 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 31 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 32 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 33 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 34 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 35 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 36 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 37 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 38 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 39 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 40 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 41 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 42 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 43 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 44 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 45 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 46 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 47 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 48 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 49 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 50 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 51 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 52 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 53 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 54 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 55 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 56 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 57 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 58 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 59 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 60 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 61 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 62 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 63 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 64 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 65 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 66 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 67 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 68 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 69 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 70 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 71 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 72 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 73 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 74 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 75 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 76 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 77 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 78 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 79 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 80 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 81 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 82 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 83 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 84 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 85 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 86 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 87 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 88 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 89 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 90 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 91 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 92 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 93 在 59999 次迭代中的对偶变量为: -135.1438665383513
# agent 94 在 59999 次迭代中的对偶变量为: -135.1438665383513
# *************************
# 迭代步长为: 0.11075700351730201
# ****************************************************************************
# 2023-05-29 15:40:13.737

# %%
np.savetxt('../data/01-DGD-ARC-robust-agent_resource_quantity_small_value_deterministic_bias.txt',agent_resource_quantity,fmt='%0.8f')#用户资源量
np.savetxt('../data/01-DGD-ARC-robust-sum_cost_small_value_deterministic_bias.txt',sum_cost,fmt='%0.8f')#用户成本总和
np.savetxt('../data/01-DGD-ARC-robust-sum_resource_small_value_deterministic_bias.txt',sum_resource,fmt='%0.8f')#用户资源总和
